# %%
import torch
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Times New Roman"
import numpy as np
import torch.nn as nn 
import torch.nn.functional as F

class model(nn.Module):
    """ ReLU k shallow neural network
    Parameters: 
    input size: input dimension
    hidden_size1 : number of hidden layers 
    num_classes: output classes 
    k: degree of relu functions
    """
    def __init__(self, input_size, hidden_size1, num_classes,k = 1):
        super().__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, num_classes,bias = False)
        self.k = k 
    def forward(self, x):
        u1 = self.fc2(F.relu(self.fc1(x))**self.k)
        return u1

def print_convergence_order(err, neuron_num_exponent): 

    neuron_nums = [2**j for j in range(2,neuron_num_exponent)]
    err_list = [err[i] for i in neuron_nums ] 

    print("neuron num \t\t error \t\t order")
    for i, item in enumerate(err_list):
        if i == 0: 
            print(neuron_nums[i], end = "\t\t")
            print(item, end = "\t\t")
            print("*")
        else: 
            print(neuron_nums[i], end = "\t\t")
            print(item, end = "\t\t") 
            print(np.log(err_list[i-1]/err_list[i])/np.log(2))

# %% [markdown]
# ## ex1

# %%
## product of sine, relu 4

# %%
folder = './'
experiment_label = 'ex1'
err_list_relu_4_rand = []
for k in [4]: 
    for s in [2**1, 2**2, 2**3, 2**4,2**5]: 
        N0 = 2**5 
        exponent = 9  
        num_epochs=  2**exponent 
        print("relu {}, dict size {}".format(k,s * N0))

        filename = folder +"sin-product-4d_err_randDict_relu_{}_size_{}_num_neurons_{}.pt".format(k,s * N0,num_epochs)
        err = torch.load(filename)  
        err_list_relu_4_rand.append(err) 
        print_convergence_order(err,exponent+1) 

print("deterministic dictionary")
print() 

folder = './'
experiment_label = 'ex1'
err_list_relu_4_deterministic = []

for k in [4]: 
    for N in [2**10, 2**12,2**14,2**16]: 
        if N ==2**16:
            continue 
        exponent = 9  
        num_epochs=  2**exponent 
        print("relu {}, dict size {}".format(k,N))

        filename = folder + experiment_label +"_err_deterministic_Dict_relu_{}_size_{}_num_neurons_{}.pt".format(k,N,num_epochs)
        err = torch.load(filename)   
        err_list_relu_4_deterministic.append(err) 
        print_convergence_order(err,exponent+1)
# Out:
# relu 4, dict size 64
# neuron num 		 error 		 order
# 4		tensor(0.1994, dtype=torch.float64)		*
# 8		tensor(0.1594, dtype=torch.float64)		tensor(0.3228, dtype=torch.float64)
# 16		tensor(0.1175, dtype=torch.float64)		tensor(0.4403, dtype=torch.float64)
# 32		tensor(0.0970, dtype=torch.float64)		tensor(0.2761, dtype=torch.float64)
# 64		tensor(0.0379, dtype=torch.float64)		tensor(1.3571, dtype=torch.float64)
# 128		tensor(0.0184, dtype=torch.float64)		tensor(1.0382, dtype=torch.float64)
# 256		tensor(0.0037, dtype=torch.float64)		tensor(2.3277, dtype=torch.float64)
# 512		tensor(0.0010, dtype=torch.float64)		tensor(1.8768, dtype=torch.float64)
# relu 4, dict size 128
# neuron num 		 error 		 order
# 4		tensor(0.1717, dtype=torch.float64)		*
# 8		tensor(0.1442, dtype=torch.float64)		tensor(0.2524, dtype=torch.float64)
# 16		tensor(0.1098, dtype=torch.float64)		tensor(0.3928, dtype=torch.float64)
# 32		tensor(0.0890, dtype=torch.float64)		tensor(0.3036, dtype=torch.float64)
# 64		tensor(0.0374, dtype=torch.float64)		tensor(1.2491, dtype=torch.float64)
# 128		tensor(0.0166, dtype=torch.float64)		tensor(1.1772, dtype=torch.float64)
# 256		tensor(0.0036, dtype=torch.float64)		tensor(2.1877, dtype=torch.float64)
# 512		tensor(0.0009, dtype=torch.float64)		tensor(1.9820, dtype=torch.float64)
# relu 4, dict size 256
# neuron num 		 error 		 order
# 4		tensor(0.1796, dtype=torch.float64)		*
# 8		tensor(0.1294, dtype=torch.float64)		tensor(0.4728, dtype=torch.float64)
# 16		tensor(0.1112, dtype=torch.float64)		tensor(0.2188, dtype=torch.float64)
# 32		tensor(0.0830, dtype=torch.float64)		tensor(0.4217, dtype=torch.float64)
# 64		tensor(0.0372, dtype=torch.float64)		tensor(1.1599, dtype=torch.float64)
# 128		tensor(0.0152, dtype=torch.float64)		tensor(1.2931, dtype=torch.float64)
# 256		tensor(0.0031, dtype=torch.float64)		tensor(2.2710, dtype=torch.float64)
# 512		tensor(0.0008, dtype=torch.float64)		tensor(1.8888, dtype=torch.float64)
# relu 4, dict size 512
# neuron num 		 error 		 order
# 4		tensor(0.1745, dtype=torch.float64)		*
# 8		tensor(0.1367, dtype=torch.float64)		tensor(0.3518, dtype=torch.float64)
# 16		tensor(0.1091, dtype=torch.float64)		tensor(0.3256, dtype=torch.float64)
# 32		tensor(0.0762, dtype=torch.float64)		tensor(0.5172, dtype=torch.float64)
# 64		tensor(0.0380, dtype=torch.float64)		tensor(1.0037, dtype=torch.float64)
# 128		tensor(0.0153, dtype=torch.float64)		tensor(1.3169, dtype=torch.float64)
# 256		tensor(0.0029, dtype=torch.float64)		tensor(2.3918, dtype=torch.float64)
# 512		tensor(0.0008, dtype=torch.float64)		tensor(1.9026, dtype=torch.float64)
# relu 4, dict size 1024
# neuron num 		 error 		 order
# 4		tensor(0.1767, dtype=torch.float64)		*
# 8		tensor(0.1365, dtype=torch.float64)		tensor(0.3726, dtype=torch.float64)
# 16		tensor(0.1082, dtype=torch.float64)		tensor(0.3349, dtype=torch.float64)
# 32		tensor(0.0784, dtype=torch.float64)		tensor(0.4659, dtype=torch.float64)
# 64		tensor(0.0373, dtype=torch.float64)		tensor(1.0697, dtype=torch.float64)
# 128		tensor(0.0126, dtype=torch.float64)		tensor(1.5683, dtype=torch.float64)
# 256		tensor(0.0024, dtype=torch.float64)		tensor(2.4165, dtype=torch.float64)
# 512		tensor(0.0006, dtype=torch.float64)		tensor(1.8768, dtype=torch.float64)
# deterministic dictionary
#
# relu 4, dict size 1024
# neuron num 		 error 		 order
# 4		tensor(0.1956, dtype=torch.float64)		*
# 8		tensor(0.1736, dtype=torch.float64)		tensor(0.1724, dtype=torch.float64)
# 16		tensor(0.1092, dtype=torch.float64)		tensor(0.6683, dtype=torch.float64)
# 32		tensor(0.0865, dtype=torch.float64)		tensor(0.3359, dtype=torch.float64)
# 64		tensor(0.0536, dtype=torch.float64)		tensor(0.6922, dtype=torch.float64)
# 128		tensor(0.0497, dtype=torch.float64)		tensor(0.1066, dtype=torch.float64)
# 256		tensor(0.0497, dtype=torch.float64)		tensor(0.0013, dtype=torch.float64)
# 512		tensor(0.0497, dtype=torch.float64)		tensor(-0.0014, dtype=torch.float64)
# relu 4, dict size 4096
# neuron num 		 error 		 order
# 4		tensor(0.1893, dtype=torch.float64)		*
# 8		tensor(0.1525, dtype=torch.float64)		tensor(0.3113, dtype=torch.float64)
# 16		tensor(0.1078, dtype=torch.float64)		tensor(0.5006, dtype=torch.float64)
# 32		tensor(0.1009, dtype=torch.float64)		tensor(0.0962, dtype=torch.float64)
# 64		tensor(0.0386, dtype=torch.float64)		tensor(1.3865, dtype=torch.float64)
# 128		tensor(0.0133, dtype=torch.float64)		tensor(1.5380, dtype=torch.float64)
# 256		tensor(0.0074, dtype=torch.float64)		tensor(0.8351, dtype=torch.float64)
# 512		tensor(0.0073, dtype=torch.float64)		tensor(0.0337, dtype=torch.float64)
# relu 4, dict size 16384
# neuron num 		 error 		 order
# 4		tensor(0.1664, dtype=torch.float64)		*
# 8		tensor(0.1185, dtype=torch.float64)		tensor(0.4898, dtype=torch.float64)
# 16		tensor(0.1072, dtype=torch.float64)		tensor(0.1449, dtype=torch.float64)
# 32		tensor(0.1006, dtype=torch.float64)		tensor(0.0906, dtype=torch.float64)
# 64		tensor(0.0384, dtype=torch.float64)		tensor(1.3908, dtype=torch.float64)
# 128		tensor(0.0112, dtype=torch.float64)		tensor(1.7820, dtype=torch.float64)
# 256		tensor(0.0054, dtype=torch.float64)		tensor(1.0418, dtype=torch.float64)
# 512		tensor(0.0048, dtype=torch.float64)		tensor(0.1784, dtype=torch.float64)

# %%
filename = "4D_sinpix1x2x3x4_rand_deter_relu4_Dict_compare.png"
k = 4 
d = 4 
def plot_err_vs_neurons(k,d,err_list_relu_4_rand,err_list_relu_4_deterministic,filename, fig_title, exponent = 9, save = False, rescale_ref = 12):
    """ Neuron numbers 2^2, 2^3, 2^4, ..., 2^9. 
    """
    rate = -1/2 - (2 * k + 1)/(2 * d)


    f_size = 12  # Increased font size
    line_width = 2  # Thickness of the lines
    # Set global font size
    plt.rcParams.update({'font.size': f_size})
    
    neuron_nums = np.array([2**j for j in range(2,exponent+1)])  
    rand_size_exp_list = [6,7,8,9,10] 
    # dictionary_size_list= [[2**3,2**3,2**2,2**2], [2**3,2**3,2**3,2**3],[2**4,2**4,2**3,2**3],[2**4,2**4,2**4,2**4]]
    dictionary_size_exp_list = [10,12,14,16]

    plt.figure(dpi = 400)
    x = np.array(range(4, 2**exponent+1))
    ref = err_list_relu_4_rand[0][2**2]* (x/ 4)**(rate)*rescale_ref

    plt.plot(x,ref,'-.',linewidth=line_width,label = '$O(n^{{{}}})$'.format(rate))

    for i, err in enumerate(err_list_relu_4_rand): 
        if rand_size_exp_list[i] == 7 or rand_size_exp_list[i] == 9:
            continue
        plt.plot(neuron_nums, err[neuron_nums],'.-',linewidth=line_width,
                 label = "Randomized $2^{{{}}}$".format(rand_size_exp_list[i]))

    for i, err in enumerate(err_list_relu_4_deterministic): 
        plt.plot(neuron_nums, err[neuron_nums],'.-.', linewidth=line_width,
                label = "Deterministic $2^{{{}}}$ ".format(dictionary_size_exp_list[i])) 
    
    plt.title( fig_title+"   ReLU$^{}$ dictionary".format(k))
    plt.yscale('log')
    plt.xscale('log')
    # plt.grid("True")
    plt.xlabel("Iteration number $n$")
    plt.ylabel("$L^2$ error $||u-u_n||$")
    plt.xticks(neuron_nums,[rf"$2^{{{ns}}}$" for ns in range(2,exponent+1)])
    plt.legend(loc='lower left')    

    if save:
        plt.savefig(filename) 
    else:
        plt.show()
    return 0 
## plot results 
## read data: 

filename = "4D_sinpix1x2x3x4_rand_deter_relu4_Dict_compare.png"
k = 4 
d = 4 
fig_title = "$f(x) = \Pi_{{i=1}}^4 \sin(\pi x_i)$"
plot_err_vs_neurons(k,d,err_list_relu_4_rand,err_list_relu_4_deterministic,filename, fig_title, exponent = 9, save = True, rescale_ref=13)
# Out:
# 0

# %%
folder = './'
experiment_label = 'ex1'
err_list_relu_1_rand = []
for k in [1]: 
    for s in [2**1, 2**2, 2**3,2**4, 2**5]: 
        N0 = 2**5 
        exponent = 9  
        num_epochs=  2**exponent 
        print("relu {}, dict size {}".format(k,s * N0))

        filename = folder  +"sin-product-4d_err_randDict_relu_{}_size_{}_num_neurons_{}.pt".format(k,s * N0,num_epochs)
        err = torch.load(filename)  
        err_list_relu_1_rand.append(err) 
        print_convergence_order(err,exponent+1) 

print("deterministic dictionary")
print() 

folder = './'
experiment_label = 'ex1'
err_list_relu_1_deterministic = []

for k in [1]: 
    for N in [2**10, 2**12,2**14]: 
        if k == 1 and N ==2**16:
            continue 
        exponent = 9  
        num_epochs=  2**exponent 
        print("relu {}, dict size {}".format(k,N))

        filename = folder + experiment_label +"_err_deterministic_Dict_relu_{}_size_{}_num_neurons_{}.pt".format(k,N,num_epochs)
        err = torch.load(filename)   
        err_list_relu_1_deterministic.append(err) 
        print_convergence_order(err,exponent+1)
# Out:
# relu 1, dict size 64
# neuron num 		 error 		 order
# 4		tensor(0.1747, dtype=torch.float64)		*
# 8		tensor(0.1343, dtype=torch.float64)		tensor(0.3799, dtype=torch.float64)
# 16		tensor(0.0891, dtype=torch.float64)		tensor(0.5920, dtype=torch.float64)
# 32		tensor(0.0696, dtype=torch.float64)		tensor(0.3566, dtype=torch.float64)
# 64		tensor(0.0435, dtype=torch.float64)		tensor(0.6759, dtype=torch.float64)
# 128		tensor(0.0248, dtype=torch.float64)		tensor(0.8149, dtype=torch.float64)
# 256		tensor(0.0134, dtype=torch.float64)		tensor(0.8889, dtype=torch.float64)
# 512		tensor(0.0073, dtype=torch.float64)		tensor(0.8678, dtype=torch.float64)
# relu 1, dict size 128
# neuron num 		 error 		 order
# 4		tensor(0.1752, dtype=torch.float64)		*
# 8		tensor(0.1384, dtype=torch.float64)		tensor(0.3403, dtype=torch.float64)
# 16		tensor(0.0888, dtype=torch.float64)		tensor(0.6396, dtype=torch.float64)
# 32		tensor(0.0674, dtype=torch.float64)		tensor(0.3993, dtype=torch.float64)
# 64		tensor(0.0415, dtype=torch.float64)		tensor(0.6989, dtype=torch.float64)
# 128		tensor(0.0225, dtype=torch.float64)		tensor(0.8842, dtype=torch.float64)
# 256		tensor(0.0128, dtype=torch.float64)		tensor(0.8102, dtype=torch.float64)
# 512		tensor(0.0068, dtype=torch.float64)		tensor(0.9058, dtype=torch.float64)
# relu 1, dict size 256
# neuron num 		 error 		 order
# 4		tensor(0.1689, dtype=torch.float64)		*
# 8		tensor(0.1215, dtype=torch.float64)		tensor(0.4744, dtype=torch.float64)
# 16		tensor(0.0905, dtype=torch.float64)		tensor(0.4261, dtype=torch.float64)
# 32		tensor(0.0690, dtype=torch.float64)		tensor(0.3917, dtype=torch.float64)
# 64		tensor(0.0406, dtype=torch.float64)		tensor(0.7632, dtype=torch.float64)
# 128		tensor(0.0223, dtype=torch.float64)		tensor(0.8669, dtype=torch.float64)
# 256		tensor(0.0121, dtype=torch.float64)		tensor(0.8792, dtype=torch.float64)
# 512		tensor(0.0065, dtype=torch.float64)		tensor(0.8927, dtype=torch.float64)
# relu 1, dict size 512
# neuron num 		 error 		 order
# 4		tensor(0.1696, dtype=torch.float64)		*
# 8		tensor(0.1225, dtype=torch.float64)		tensor(0.4690, dtype=torch.float64)
# 16		tensor(0.0881, dtype=torch.float64)		tensor(0.4762, dtype=torch.float64)
# 32		tensor(0.0616, dtype=torch.float64)		tensor(0.5167, dtype=torch.float64)
# 64		tensor(0.0374, dtype=torch.float64)		tensor(0.7185, dtype=torch.float64)
# 128		tensor(0.0222, dtype=torch.float64)		tensor(0.7527, dtype=torch.float64)
# 256		tensor(0.0115, dtype=torch.float64)		tensor(0.9483, dtype=torch.float64)
# 512		tensor(0.0059, dtype=torch.float64)		tensor(0.9622, dtype=torch.float64)
# relu 1, dict size 1024
# neuron num 		 error 		 order
# 4		tensor(0.1720, dtype=torch.float64)		*
# 8		tensor(0.1204, dtype=torch.float64)		tensor(0.5141, dtype=torch.float64)
# 16		tensor(0.0840, dtype=torch.float64)		tensor(0.5193, dtype=torch.float64)
# 32		tensor(0.0617, dtype=torch.float64)		tensor(0.4461, dtype=torch.float64)
# 64		tensor(0.0379, dtype=torch.float64)		tensor(0.7019, dtype=torch.float64)
# 128		tensor(0.0214, dtype=torch.float64)		tensor(0.8259, dtype=torch.float64)
# 256		tensor(0.0110, dtype=torch.float64)		tensor(0.9594, dtype=torch.float64)
# 512		tensor(0.0061, dtype=torch.float64)		tensor(0.8590, dtype=torch.float64)
# deterministic dictionary
#
# relu 1, dict size 1024
# neuron num 		 error 		 order
# 4		tensor(0.1782, dtype=torch.float64)		*
# 8		tensor(0.1356, dtype=torch.float64)		tensor(0.3940, dtype=torch.float64)
# 16		tensor(0.0999, dtype=torch.float64)		tensor(0.4404, dtype=torch.float64)
# 32		tensor(0.0832, dtype=torch.float64)		tensor(0.2637, dtype=torch.float64)
# 64		tensor(0.0792, dtype=torch.float64)		tensor(0.0718, dtype=torch.float64)
# 128		tensor(0.0789, dtype=torch.float64)		tensor(0.0055, dtype=torch.float64)
# 256		tensor(0.0789, dtype=torch.float64)		tensor(3.9553e-05, dtype=torch.float64)
# 512		tensor(0.0789, dtype=torch.float64)		tensor(0., dtype=torch.float64)
# relu 1, dict size 4096
# neuron num 		 error 		 order
# 4		tensor(0.1718, dtype=torch.float64)		*
# 8		tensor(0.1398, dtype=torch.float64)		tensor(0.2977, dtype=torch.float64)
# 16		tensor(0.0820, dtype=torch.float64)		tensor(0.7701, dtype=torch.float64)
# 32		tensor(0.0580, dtype=torch.float64)		tensor(0.4996, dtype=torch.float64)
# 64		tensor(0.0358, dtype=torch.float64)		tensor(0.6945, dtype=torch.float64)
# 128		tensor(0.0226, dtype=torch.float64)		tensor(0.6627, dtype=torch.float64)
# 256		tensor(0.0178, dtype=torch.float64)		tensor(0.3467, dtype=torch.float64)
# 512		tensor(0.0166, dtype=torch.float64)		tensor(0.1016, dtype=torch.float64)
# relu 1, dict size 16384
# neuron num 		 error 		 order
# 4		tensor(0.1755, dtype=torch.float64)		*
# 8		tensor(0.1338, dtype=torch.float64)		tensor(0.3918, dtype=torch.float64)
# 16		tensor(0.0790, dtype=torch.float64)		tensor(0.7594, dtype=torch.float64)
# 32		tensor(0.0529, dtype=torch.float64)		tensor(0.5803, dtype=torch.float64)
# 64		tensor(0.0348, dtype=torch.float64)		tensor(0.6046, dtype=torch.float64)
# 128		tensor(0.0192, dtype=torch.float64)		tensor(0.8558, dtype=torch.float64)
# 256		tensor(0.0133, dtype=torch.float64)		tensor(0.5294, dtype=torch.float64)
# 512		tensor(0.0107, dtype=torch.float64)		tensor(0.3149, dtype=torch.float64)

# %%
filename = "4D_sinpix1x2x3x4_rand_deter_relu1_Dict_compare.png"
fig_title = "$f(x) = \Pi_{{i=1}}^4 \sin(\pi x_i)$" 
k = 1
d = 4 
plot_err_vs_neurons(k,d,err_list_relu_1_rand,err_list_relu_1_deterministic,filename,fig_title, exponent = 9, save = True, rescale_ref=3.05)
# Out:
# 0

# %% [markdown]
# ## ex2

# %%
folder = 'ex2/'
experiment_label = 'ex2'
# Load data 
err_list_relu_4_rand = []
for k in [4]: 
    for s in [2**1,2**2,2**3,2**4, 2**5]: 
        N0 = 2**5 
        exponent = 9  
        num_epochs=  2**exponent 
        print("relu {}, dict size {}".format(k,s * N0))

        filename = folder + experiment_label +"_err_randDict_relu_{}_size_{}_num_neurons_{}.pt".format(k,s * N0,num_epochs)
        err = torch.load(filename)  
        err_list_relu_4_rand.append(err)  
        print_convergence_order(err,exponent+1) 

print() 
print("deterministic dictionary")
print() 

folder = 'ex2/'
experiment_label = 'ex2'
err_list_relu_4_deterministic = []

for k in [4]: 
    for N in [2**10, 2**12,2**14,2**16]: 
        if N ==2**16:
            continue 
        exponent = 9  
        num_epochs=  2**exponent 
        print("relu {}, dict size {}".format(k,N))

        filename = folder + experiment_label +"_err_deterministic_Dict_relu_{}_size_{}_num_neurons_{}.pt".format(k,N,num_epochs)
        err = torch.load(filename)   
        err_list_relu_4_deterministic.append(err) 
        print_convergence_order(err,exponent+1)
# Out:
# relu 4, dict size 64
# neuron num 		 error 		 order
# 4		tensor(0.2046, dtype=torch.float64)		*
# 8		tensor(0.1624, dtype=torch.float64)		tensor(0.3335, dtype=torch.float64)
# 16		tensor(0.0583, dtype=torch.float64)		tensor(1.4786, dtype=torch.float64)
# 32		tensor(0.0484, dtype=torch.float64)		tensor(0.2661, dtype=torch.float64)
# 64		tensor(0.0104, dtype=torch.float64)		tensor(2.2183, dtype=torch.float64)
# 128		tensor(0.0047, dtype=torch.float64)		tensor(1.1588, dtype=torch.float64)
# 256		tensor(0.0009, dtype=torch.float64)		tensor(2.3064, dtype=torch.float64)
# 512		tensor(0.0002, dtype=torch.float64)		tensor(2.3491, dtype=torch.float64)
# relu 4, dict size 128
# neuron num 		 error 		 order
# 4		tensor(0.2002, dtype=torch.float64)		*
# 8		tensor(0.1689, dtype=torch.float64)		tensor(0.2458, dtype=torch.float64)
# 16		tensor(0.0596, dtype=torch.float64)		tensor(1.5023, dtype=torch.float64)
# 32		tensor(0.0481, dtype=torch.float64)		tensor(0.3093, dtype=torch.float64)
# 64		tensor(0.0099, dtype=torch.float64)		tensor(2.2865, dtype=torch.float64)
# 128		tensor(0.0043, dtype=torch.float64)		tensor(1.1930, dtype=torch.float64)
# 256		tensor(0.0006, dtype=torch.float64)		tensor(2.8183, dtype=torch.float64)
# 512		tensor(0.0002, dtype=torch.float64)		tensor(1.9424, dtype=torch.float64)
# relu 4, dict size 256
# neuron num 		 error 		 order
# 4		tensor(0.2001, dtype=torch.float64)		*
# 8		tensor(0.1712, dtype=torch.float64)		tensor(0.2249, dtype=torch.float64)
# 16		tensor(0.0572, dtype=torch.float64)		tensor(1.5815, dtype=torch.float64)
# 32		tensor(0.0479, dtype=torch.float64)		tensor(0.2565, dtype=torch.float64)
# 64		tensor(0.0100, dtype=torch.float64)		tensor(2.2594, dtype=torch.float64)
# 128		tensor(0.0039, dtype=torch.float64)		tensor(1.3563, dtype=torch.float64)
# 256		tensor(0.0006, dtype=torch.float64)		tensor(2.7302, dtype=torch.float64)
# 512		tensor(0.0001, dtype=torch.float64)		tensor(2.1006, dtype=torch.float64)
# relu 4, dict size 512
# neuron num 		 error 		 order
# 4		tensor(0.1965, dtype=torch.float64)		*
# 8		tensor(0.1330, dtype=torch.float64)		tensor(0.5630, dtype=torch.float64)
# 16		tensor(0.0577, dtype=torch.float64)		tensor(1.2054, dtype=torch.float64)
# 32		tensor(0.0467, dtype=torch.float64)		tensor(0.3055, dtype=torch.float64)
# 64		tensor(0.0100, dtype=torch.float64)		tensor(2.2158, dtype=torch.float64)
# 128		tensor(0.0037, dtype=torch.float64)		tensor(1.4273, dtype=torch.float64)
# 256		tensor(0.0005, dtype=torch.float64)		tensor(2.8048, dtype=torch.float64)
# 512		tensor(0.0001, dtype=torch.float64)		tensor(2.0565, dtype=torch.float64)
# relu 4, dict size 1024
# neuron num 		 error 		 order
# 4		tensor(0.1964, dtype=torch.float64)		*
# 8		tensor(0.1670, dtype=torch.float64)		tensor(0.2336, dtype=torch.float64)
# 16		tensor(0.0596, dtype=torch.float64)		tensor(1.4869, dtype=torch.float64)
# 32		tensor(0.0466, dtype=torch.float64)		tensor(0.3559, dtype=torch.float64)
# 64		tensor(0.0097, dtype=torch.float64)		tensor(2.2676, dtype=torch.float64)
# 128		tensor(0.0036, dtype=torch.float64)		tensor(1.4080, dtype=torch.float64)
# 256		tensor(0.0005, dtype=torch.float64)		tensor(2.8329, dtype=torch.float64)
# 512		tensor(0.0001, dtype=torch.float64)		tensor(2.0900, dtype=torch.float64)
#
# deterministic dictionary
#
# relu 4, dict size 1024
# neuron num 		 error 		 order
# 4		tensor(0.1960, dtype=torch.float64)		*
# 8		tensor(0.1140, dtype=torch.float64)		tensor(0.7823, dtype=torch.float64)
# 16		tensor(0.0579, dtype=torch.float64)		tensor(0.9761, dtype=torch.float64)
# 32		tensor(0.0483, dtype=torch.float64)		tensor(0.2618, dtype=torch.float64)
# 64		tensor(0.0100, dtype=torch.float64)		tensor(2.2671, dtype=torch.float64)
# 128		tensor(0.0071, dtype=torch.float64)		tensor(0.4927, dtype=torch.float64)
# 256		tensor(0.0069, dtype=torch.float64)		tensor(0.0466, dtype=torch.float64)
# 512		tensor(0.0070, dtype=torch.float64)		tensor(-0.0189, dtype=torch.float64)
# relu 4, dict size 4096
# neuron num 		 error 		 order
# 4		tensor(0.1976, dtype=torch.float64)		*
# 8		tensor(0.1440, dtype=torch.float64)		tensor(0.4559, dtype=torch.float64)
# 16		tensor(0.0607, dtype=torch.float64)		tensor(1.2461, dtype=torch.float64)
# 32		tensor(0.0495, dtype=torch.float64)		tensor(0.2951, dtype=torch.float64)
# 64		tensor(0.0094, dtype=torch.float64)		tensor(2.3926, dtype=torch.float64)
# 128		tensor(0.0032, dtype=torch.float64)		tensor(1.5792, dtype=torch.float64)
# 256		tensor(0.0010, dtype=torch.float64)		tensor(1.6734, dtype=torch.float64)
# 512		tensor(0.0009, dtype=torch.float64)		tensor(0.1958, dtype=torch.float64)
# relu 4, dict size 16384
# neuron num 		 error 		 order
# 4		tensor(0.1971, dtype=torch.float64)		*
# 8		tensor(0.1143, dtype=torch.float64)		tensor(0.7862, dtype=torch.float64)
# 16		tensor(0.0587, dtype=torch.float64)		tensor(0.9613, dtype=torch.float64)
# 32		tensor(0.0483, dtype=torch.float64)		tensor(0.2827, dtype=torch.float64)
# 64		tensor(0.0095, dtype=torch.float64)		tensor(2.3501, dtype=torch.float64)
# 128		tensor(0.0033, dtype=torch.float64)		tensor(1.5291, dtype=torch.float64)
# 256		tensor(0.0008, dtype=torch.float64)		tensor(2.1219, dtype=torch.float64)
# 512		tensor(0.0007, dtype=torch.float64)		tensor(0.2096, dtype=torch.float64)

# %%
## plot results 
## read data: 
exponent = 9 
k = 4 
d = 4 
filename = "4D_gaussian_rand_deter_relu4_Dict_compare.png"
fig_title = '4D Gaussian'
save =  True 
plot_err_vs_neurons(k,d,err_list_relu_4_rand,err_list_relu_4_deterministic,filename, fig_title, exponent = 9, save = save, rescale_ref=4)
# rate = -1/2 - (2 * k + 1)/(2 * d)
# Out:
# 0

# %%
folder = 'ex2/'
experiment_label = 'ex2'
# Load data 
err_list_relu_1_rand = []
for k in [1]: 
    for s in [2**1,2**2,2**3,2**4, 2**5]: 
        N0 = 2**5 
        exponent = 9  
        num_epochs=  2**exponent 
        print("relu {}, dict size {}".format(k,s * N0))

        filename = folder + experiment_label +"_err_randDict_relu_{}_size_{}_num_neurons_{}.pt".format(k,s * N0,num_epochs)
        err = torch.load(filename)  
        err_list_relu_1_rand.append(err)  
        print_convergence_order(err,exponent+1) 

print() 
print("deterministic dictionary")
print() 

folder = 'ex2/'
experiment_label = 'ex2'
err_list_relu_1_deterministic = []

for k in [1]: 
    for N in [2**10, 2**12,2**14,2**16]: 
        if N ==2**16:
            continue 
        exponent = 9  
        num_epochs=  2**exponent 
        print("relu {}, dict size {}".format(k,N))

        filename = folder + experiment_label +"_err_deterministic_Dict_relu_{}_size_{}_num_neurons_{}.pt".format(k,N,num_epochs)
        err = torch.load(filename)   
        err_list_relu_1_deterministic.append(err) 
        print_convergence_order(err,exponent+1)
# Out:
# relu 1, dict size 64
# neuron num 		 error 		 order
# 4		tensor(0.1640, dtype=torch.float64)		*
# 8		tensor(0.1250, dtype=torch.float64)		tensor(0.3915, dtype=torch.float64)
# 16		tensor(0.0606, dtype=torch.float64)		tensor(1.0439, dtype=torch.float64)
# 32		tensor(0.0378, dtype=torch.float64)		tensor(0.6823, dtype=torch.float64)
# 64		tensor(0.0201, dtype=torch.float64)		tensor(0.9133, dtype=torch.float64)
# 128		tensor(0.0110, dtype=torch.float64)		tensor(0.8705, dtype=torch.float64)
# 256		tensor(0.0057, dtype=torch.float64)		tensor(0.9416, dtype=torch.float64)
# 512		tensor(0.0030, dtype=torch.float64)		tensor(0.9531, dtype=torch.float64)
# relu 1, dict size 128
# neuron num 		 error 		 order
# 4		tensor(0.1559, dtype=torch.float64)		*
# 8		tensor(0.1271, dtype=torch.float64)		tensor(0.2947, dtype=torch.float64)
# 16		tensor(0.0556, dtype=torch.float64)		tensor(1.1937, dtype=torch.float64)
# 32		tensor(0.0312, dtype=torch.float64)		tensor(0.8352, dtype=torch.float64)
# 64		tensor(0.0180, dtype=torch.float64)		tensor(0.7917, dtype=torch.float64)
# 128		tensor(0.0097, dtype=torch.float64)		tensor(0.8970, dtype=torch.float64)
# 256		tensor(0.0051, dtype=torch.float64)		tensor(0.9202, dtype=torch.float64)
# 512		tensor(0.0027, dtype=torch.float64)		tensor(0.9181, dtype=torch.float64)
# relu 1, dict size 256
# neuron num 		 error 		 order
# 4		tensor(0.1657, dtype=torch.float64)		*
# 8		tensor(0.1126, dtype=torch.float64)		tensor(0.5564, dtype=torch.float64)
# 16		tensor(0.0453, dtype=torch.float64)		tensor(1.3143, dtype=torch.float64)
# 32		tensor(0.0290, dtype=torch.float64)		tensor(0.6423, dtype=torch.float64)
# 64		tensor(0.0173, dtype=torch.float64)		tensor(0.7480, dtype=torch.float64)
# 128		tensor(0.0092, dtype=torch.float64)		tensor(0.9084, dtype=torch.float64)
# 256		tensor(0.0046, dtype=torch.float64)		tensor(0.9905, dtype=torch.float64)
# 512		tensor(0.0025, dtype=torch.float64)		tensor(0.9039, dtype=torch.float64)
# relu 1, dict size 512
# neuron num 		 error 		 order
# 4		tensor(0.1543, dtype=torch.float64)		*
# 8		tensor(0.1089, dtype=torch.float64)		tensor(0.5030, dtype=torch.float64)
# 16		tensor(0.0465, dtype=torch.float64)		tensor(1.2267, dtype=torch.float64)
# 32		tensor(0.0282, dtype=torch.float64)		tensor(0.7205, dtype=torch.float64)
# 64		tensor(0.0166, dtype=torch.float64)		tensor(0.7691, dtype=torch.float64)
# 128		tensor(0.0087, dtype=torch.float64)		tensor(0.9271, dtype=torch.float64)
# 256		tensor(0.0047, dtype=torch.float64)		tensor(0.8999, dtype=torch.float64)
# 512		tensor(0.0024, dtype=torch.float64)		tensor(0.9650, dtype=torch.float64)
# relu 1, dict size 1024
# neuron num 		 error 		 order
# 4		tensor(0.1509, dtype=torch.float64)		*
# 8		tensor(0.0984, dtype=torch.float64)		tensor(0.6171, dtype=torch.float64)
# 16		tensor(0.0469, dtype=torch.float64)		tensor(1.0675, dtype=torch.float64)
# 32		tensor(0.0274, dtype=torch.float64)		tensor(0.7748, dtype=torch.float64)
# 64		tensor(0.0166, dtype=torch.float64)		tensor(0.7283, dtype=torch.float64)
# 128		tensor(0.0089, dtype=torch.float64)		tensor(0.8881, dtype=torch.float64)
# 256		tensor(0.0045, dtype=torch.float64)		tensor(0.9872, dtype=torch.float64)
# 512		tensor(0.0023, dtype=torch.float64)		tensor(0.9750, dtype=torch.float64)
#
# deterministic dictionary
#
# relu 1, dict size 1024
# neuron num 		 error 		 order
# 4		tensor(0.1642, dtype=torch.float64)		*
# 8		tensor(0.1043, dtype=torch.float64)		tensor(0.6554, dtype=torch.float64)
# 16		tensor(0.0503, dtype=torch.float64)		tensor(1.0532, dtype=torch.float64)
# 32		tensor(0.0438, dtype=torch.float64)		tensor(0.1980, dtype=torch.float64)
# 64		tensor(0.0410, dtype=torch.float64)		tensor(0.0952, dtype=torch.float64)
# 128		tensor(0.0404, dtype=torch.float64)		tensor(0.0205, dtype=torch.float64)
# 256		tensor(0.0404, dtype=torch.float64)		tensor(-4.1645e-15, dtype=torch.float64)
# 512		tensor(0.0404, dtype=torch.float64)		tensor(-1.0152e-11, dtype=torch.float64)
# relu 1, dict size 4096
# neuron num 		 error 		 order
# 4		tensor(0.1505, dtype=torch.float64)		*
# 8		tensor(0.0969, dtype=torch.float64)		tensor(0.6358, dtype=torch.float64)
# 16		tensor(0.0421, dtype=torch.float64)		tensor(1.2035, dtype=torch.float64)
# 32		tensor(0.0221, dtype=torch.float64)		tensor(0.9318, dtype=torch.float64)
# 64		tensor(0.0155, dtype=torch.float64)		tensor(0.5079, dtype=torch.float64)
# 128		tensor(0.0098, dtype=torch.float64)		tensor(0.6649, dtype=torch.float64)
# 256		tensor(0.0076, dtype=torch.float64)		tensor(0.3721, dtype=torch.float64)
# 512		tensor(0.0071, dtype=torch.float64)		tensor(0.0990, dtype=torch.float64)
# relu 1, dict size 16384
# neuron num 		 error 		 order
# 4		tensor(0.1505, dtype=torch.float64)		*
# 8		tensor(0.1043, dtype=torch.float64)		tensor(0.5289, dtype=torch.float64)
# 16		tensor(0.0410, dtype=torch.float64)		tensor(1.3487, dtype=torch.float64)
# 32		tensor(0.0242, dtype=torch.float64)		tensor(0.7596, dtype=torch.float64)
# 64		tensor(0.0152, dtype=torch.float64)		tensor(0.6661, dtype=torch.float64)
# 128		tensor(0.0093, dtype=torch.float64)		tensor(0.7185, dtype=torch.float64)
# 256		tensor(0.0062, dtype=torch.float64)		tensor(0.5890, dtype=torch.float64)
# 512		tensor(0.0050, dtype=torch.float64)		tensor(0.2996, dtype=torch.float64)

# %%
## plot results 
## read data: 
exponent = 9 
k = 1 
d = 4 
filename = "4D_gaussian_rand_deter_relu1_Dict_compare.png"
fig_title = '4D Gaussian'
save =  True   
plot_err_vs_neurons(k,d,err_list_relu_1_rand,err_list_relu_1_deterministic,filename, fig_title, exponent = 9, save = save, rescale_ref=1.5)
# rate = -1/2 - (2 * k + 1)/(2 * d)
# Out:
# 0

# %%
folder = 'ex3/'
experiment_label = 'ex3'
# Load data 
for k in [1,4]: 
    for s in [2**4, 2**5]: 
        N0 = 2**5 
        exponent = 9  
        num_epochs=  2**exponent 
        print("relu {}, dict size {}".format(k,s * N0))

        filename = folder + experiment_label +"_err_randDict_relu_{}_size_{}_num_neurons_{}.pt".format(k,s * N0,num_epochs)
        err = torch.load(filename)   
        print_convergence_order(err,exponent+1)
# Out:
# relu 1, dict size 512
# neuron num 		 error 		 order
# 4		tensor(0.0084, dtype=torch.float64)		*
# 8		tensor(0.0037, dtype=torch.float64)		tensor(1.1819, dtype=torch.float64)
# 16		tensor(0.0013, dtype=torch.float64)		tensor(1.4817, dtype=torch.float64)
# 32		tensor(0.0007, dtype=torch.float64)		tensor(0.8407, dtype=torch.float64)
# 64		tensor(0.0003, dtype=torch.float64)		tensor(1.2088, dtype=torch.float64)
# 128		tensor(0.0001, dtype=torch.float64)		tensor(1.1892, dtype=torch.float64)
# 256		tensor(7.9589e-05, dtype=torch.float64)		tensor(0.8227, dtype=torch.float64)
# 512		tensor(3.8734e-05, dtype=torch.float64)		tensor(1.0390, dtype=torch.float64)
# relu 1, dict size 1024
# neuron num 		 error 		 order
# 4		tensor(0.0083, dtype=torch.float64)		*
# 8		tensor(0.0026, dtype=torch.float64)		tensor(1.7023, dtype=torch.float64)
# 16		tensor(0.0013, dtype=torch.float64)		tensor(0.9894, dtype=torch.float64)
# 32		tensor(0.0006, dtype=torch.float64)		tensor(1.1270, dtype=torch.float64)
# 64		tensor(0.0003, dtype=torch.float64)		tensor(0.9023, dtype=torch.float64)
# 128		tensor(0.0001, dtype=torch.float64)		tensor(1.1373, dtype=torch.float64)
# 256		tensor(7.1210e-05, dtype=torch.float64)		tensor(1.0125, dtype=torch.float64)
# 512		tensor(3.9119e-05, dtype=torch.float64)		tensor(0.8642, dtype=torch.float64)
# relu 4, dict size 512
# neuron num 		 error 		 order
# 4		tensor(0.1267, dtype=torch.float64)		*
# 8		tensor(0.0581, dtype=torch.float64)		tensor(1.1248, dtype=torch.float64)
# 16		tensor(0.0129, dtype=torch.float64)		tensor(2.1731, dtype=torch.float64)
# 32		tensor(0.0015, dtype=torch.float64)		tensor(3.0688, dtype=torch.float64)
# 64		tensor(3.9812e-05, dtype=torch.float64)		tensor(5.2689, dtype=torch.float64)
# 128		tensor(1.9780e-06, dtype=torch.float64)		tensor(4.3311, dtype=torch.float64)
# 256		tensor(3.3864e-07, dtype=torch.float64)		tensor(2.5463, dtype=torch.float64)
# 512		tensor(1.5874e-06, dtype=torch.float64)		tensor(-2.2289, dtype=torch.float64)
# relu 4, dict size 1024
# neuron num 		 error 		 order
# 4		tensor(0.1303, dtype=torch.float64)		*
# 8		tensor(0.0568, dtype=torch.float64)		tensor(1.1983, dtype=torch.float64)
# 16		tensor(0.0116, dtype=torch.float64)		tensor(2.2922, dtype=torch.float64)
# 32		tensor(0.0020, dtype=torch.float64)		tensor(2.5650, dtype=torch.float64)
# 64		tensor(5.2523e-05, dtype=torch.float64)		tensor(5.2207, dtype=torch.float64)
# 128		tensor(1.3521e-06, dtype=torch.float64)		tensor(5.2797, dtype=torch.float64)
# 256		tensor(5.7276e-07, dtype=torch.float64)		tensor(1.2392, dtype=torch.float64)
# 512		tensor(7.0188e-06, dtype=torch.float64)		tensor(-3.6152, dtype=torch.float64)
