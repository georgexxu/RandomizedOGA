# %%
## This version of 1D greedy algorithm, the numerical quadrature used for assembling the linear system is consistent with 
## the quadrature used for the argmax subproblem.
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import time
import sys
import os 
from scipy.sparse import linalg
from pathlib import Path
if torch.cuda.is_available():  
    device = "cuda" 
else:  
    device = "cpu" 

pi = torch.tensor(np.pi,dtype=torch.float64)
torch.set_default_dtype(torch.float64)

class model(nn.Module):
    """ ReLU k shallow neural network
    Parameters: 
    input size: input dimension
    hidden_size1 : number of hidden layers 
    num_classes: output classes 
    k: degree of relu functions
    """
    def __init__(self, input_size, hidden_size1, num_classes,k = 1):
        super().__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, num_classes,bias = False)
        self.k = k 
    def forward(self, x):
        u1 = self.fc2(F.relu(self.fc1(x))**self.k)
        return u1

# %%
def PiecewiseGQ1D_weights_points(x_l,x_r,Nx, order):
    """ Output the coeffients and weights for piecewise Gauss Quadrature 
    Parameters
    ----------
    x_l : float 
    left endpoint of an interval 
    
    x_r: float
    right endpoint of an interval 
    
    integration_intervals: int
    number of subintervals for integration
    
    Returns
    -------
    coef1_expand
    
    gw_expand
    
    integration_points
    """
    x,w = np.polynomial.legendre.leggauss(order)
    gx = torch.tensor(x).to(device)
    gx = gx.view(1,-1) # row vector 
    gw = torch.tensor(w).to(device)    
    gw = gw.view(-1,1) # Column vector 
    nodes = torch.linspace(x_l,x_r,Nx+1).view(-1,1).to(device) 
    coef1 = ((nodes[1:,:] - nodes[:-1,:])/2) # n by 1  
    coef2 = ((nodes[1:,:] + nodes[:-1,:])/2) # n by 1  
    coef2_expand = coef2.expand(-1,gx.size(1)) # Expand to n by p shape, -1: keep the first dimension n , expand the 2nd dim (columns)
    integration_points = coef1@gx + coef2_expand
    integration_points = integration_points.flatten().view(-1,1) # Make it a column vector
    gw_expand = torch.tile(gw,(Nx,1)) # rows: n copies of current tensor, columns: 1 copy, no change
    # Modify coef1 to be compatible with func_values
    coef1_expand = coef1.expand(coef1.size(0),gx.size(1))    
    coef1_expand = coef1_expand.flatten().view(-1,1)

    return coef1_expand.to(device) * gw_expand.to(device), integration_points.to(device)


def minimize_linear_layer_explicit_assemble(model,target,weights, integration_points,solver="direct"):
    """
    calls the following functions (dependency): 
    1. GQ_piecewise_2D
    input: the nn model containing parameter 
    1. define the loss function  
    2. take derivative to extract the linear system A
    3. call the cg solver in scipy to solve the linear system 
    output: sol. solution of Ax = b
    """
    start_time = time.time() 
    w = model.fc1.weight.data 
    b = model.fc1.bias.data 
    basis_value_col = F.relu(integration_points @ w.t()+ b)**(model.k) 
    weighted_basis_value_col = basis_value_col * weights 
    jac = weighted_basis_value_col.t() @ basis_value_col 
     
    rhs = weighted_basis_value_col.t() @ (target(integration_points)) 
    print("assembling the matrix time taken: ", time.time()-start_time) 
    start_time = time.time()    
    if solver == "cg": 
        sol, exit_code = linalg.cg(np.array(jac.detach().cpu()),np.array(rhs.detach().cpu()),tol=1e-12)
        sol = torch.tensor(sol).view(1,-1)
    elif solver == "direct": 
#         sol = np.linalg.inv( np.array(jac.detach().cpu()) )@np.array(rhs.detach().cpu())
        sol = (torch.linalg.solve( jac.detach(), rhs.detach())).view(1,-1)
    elif solver == "ls":
        sol = (torch.linalg.lstsq(jac.detach().cpu(),rhs.detach().cpu(),driver='gelsd').solution).view(1,-1)
        # sol = (torch.linalg.lstsq(jac.detach(),rhs.detach()).solution).view(1,-1) # gpu/cpu, driver = 'gels', cannot solve singular
    print("solving Ax = b time taken: ", time.time()-start_time)
    return sol 


def plot_solution_modified(r1,r2,model,x_test,u_true,name=None): 
    # Plot function: test results 
    u_model_cpu = model(x_test).cpu().detach()
    
    w = model.fc1.weight.data.squeeze()
    b = model.fc1.bias.data.squeeze()
    x_model_pt = (-b/w).view(-1,1)
    u_model_pt = model(x_model_pt).cpu().detach()
    plt.figure(dpi = 100)
    plt.plot(x_test.cpu(),u_model_cpu,'-.',label = "nn function")
    plt.plot(x_test.cpu(),u_true.cpu(),label = "true")
#     plt.plot(x_model_pt,u_model_pt,'.r')
    if name!=None: 
        plt.title(name)
    plt.legend()
    plt.show()

# %% [markdown]
# ## OGA

# %%
# relu dictionary
def relu_dict(x_l,x_r,N):
    """generate relu dictionary parameters 
    
    Parameters
    ----------
    x_l: float 
    x_r: float
    N: int 
        number of degrbuhee of freedoms
        
    Returns
    torch tensor
        containing relu dictionary parameters, corresponds to nodal points
        
    """
    # w = 1 
    relu_dict_parameters = torch.zeros((N,2)).to(device)
    relu_dict_parameters[:N,0] = torch.ones(N)[:]
    relu_dict_parameters[:N,1] = torch.linspace(x_l,x_r,N+1)[:-1] # relu(x-bi)


    # relu_dict_parameters[N:,0] = -torch.ones(N)[:]
    # relu_dict_parameters[N:,1] = torch.linspace(x_l,x_r,N+1)[1:] # relu(x-bi)
    
    return relu_dict_parameters


def OGAL2FittingReLU1D(my_model,target,N,num_epochs,plot_freq = 10,Nx = 1024,order =5, k = 1, solver = 'direct'): 
    """ Orthogonal greedy algorithm using 1D ReLU dictionary over [-pi,pi]
    Parameters
    ----------
    my_model: 
        nn model 
    target: 
        target function
    num_epochs: int 
        number of training epochs 
    integration_intervals: int 
        number of subintervals for piecewise numerical quadrature 

    Returns
    -------
    err: tensor 
        rank 1 torch tensor to record the L2 error history  
    model: 
        trained nn model 
    """

    weights, integration_points = PiecewiseGQ1D_weights_points(x_l= -pi,x_r= pi, Nx = Nx,order =order)

    err = torch.zeros(num_epochs+1)
    if my_model == None: 
        func_values = target(integration_points)
        num_neuron = 0
        list_a = []
        list_b = []
        list_w = []
    else: 
        func_values = target(integration_points) - my_model(integration_points).detach()
        bias = my_model.fc1.bias.detach().data
        weights = my_model.fc1.weight.detach().data
        num_neuron = int(bias.size(0))
        list_a = list(my_model.fc2.weight.detach().data)
        list_b = list(bias)
        list_w = list(weights)
        
    func_values_sqrd = func_values*func_values
    err[0]= torch.sum(func_values_sqrd*weights)**0.5
    start_time = time.time()
    
    solver = "direct"
    print("using linear solver: ",solver)
    relu_dict_parameters = relu_dict(-pi,pi,N).to(device) 
    for i in range(num_epochs): 
        print('epoch: ',i+1)
        if num_neuron == 0: 
            func_values = target(integration_points)
        else: 
            func_values = target(integration_points) - my_model(integration_points).detach()

        weight_func_values = func_values*weights

#         basis_values = F.relu(integration_points - bi).T # uses broadcasting
        basis_values = (F.relu(relu_dict_parameters[:,0] *integration_points - relu_dict_parameters[:,1])**k).T # uses broadcasting
        
        output = torch.abs(torch.matmul(basis_values,weight_func_values)) # 

        neuron_index = torch.argmax(output.flatten())
        
        list_w.append(relu_dict_parameters[neuron_index,0])
        list_b.append(-relu_dict_parameters[neuron_index,1])
        num_neuron += 1
        my_model = model(1,num_neuron,1,k).to(device)
        my_model.fc1.weight.data[:,0] = torch.tensor(list_w)[:]
        my_model.fc1.bias.data[:] = torch.tensor(list_b)[:]
#         sol = minimize_linear_layer(my_model,target,solver,Nx,order)
        sol = minimize_linear_layer_explicit_assemble(my_model,target,weights, integration_points,solver=solver)
        my_model.fc2.weight.data[0,:] = sol[:]
        if (i+1)%plot_freq == 0: 
            x_test = torch.linspace(-pi,pi,200).view(-1,1).to(device)
            u_true = target(x_test)
            plot_solution_modified(-pi,pi,my_model,x_test,u_true)
        func_values = target(integration_points) - my_model(integration_points).detach()
        func_values_sqrd = func_values*func_values
        err[i+1]= torch.sum(func_values_sqrd*weights)**0.5
    print("time taken: ",time.time() - start_time)
    return err, my_model



##

# relu dictionary
def relu_dict_MC(x_l,x_r,N):
    """generate relu dictionary parameters 
    
    Parameters
    ----------
    x_l: float 
    x_r: float
    N: int 
        number of degree of freedoms
        
    Returns
    torch tensor
        containing relu dictionary parameters, corresponds to nodal points
        
    """
    # w = 1 
    relu_dict_parameters = torch.zeros((N,2)).to(device)
    relu_dict_parameters[:N,0] = torch.ones(N)[:]
    relu_dict_parameters[:N,1] = torch.rand(N)*(x_r-x_l) + x_l # relu(x-bi) 
    # torch.linspace(x_l,x_r,N+1)[:-1] # relu(x-bi)
    
    return relu_dict_parameters
def OGAL2FittingReLU1D_MC(my_model,target,N0,num_epochs,plot_freq = 10,Nx = 1024, order = 3, k = 1, solver = 'direct'): 
    """ Orthogonal greedy algorithm using 1D ReLU dictionary over [-pi,pi]
    Parameters
    ----------
    my_model: 
        nn model 
    target: 
        target function
    num_epochs: int 
        number of training epochs 
    integration_intervals: int 
        number of subintervals for piecewise numerical quadrature 

    Returns
    -------
    err: tensor 
        rank 1 torch tensor to record the L2 error history  
    model: 
        trained nn model 
    """

    weights, integration_points = PiecewiseGQ1D_weights_points(x_l= -pi,x_r= pi,Nx = Nx, order = order)

    err = torch.zeros(num_epochs+1)
    if my_model == None: 
        func_values = target(integration_points)
        num_neuron = 0
        list_a = []
        list_b = []
        list_w = []
    else: 
        func_values = target(integration_points) - my_model(integration_points).detach()
        bias = my_model.fc1.bias.detach().data
        weights = my_model.fc1.weight.detach().data
        num_neuron = int(bias.size(0))
        list_a = list(my_model.fc2.weight.detach().data)
        list_b = list(bias)
        list_w = list(weights)
        
    func_values_sqrd = func_values*func_values
    err[0]= torch.sum(func_values_sqrd*weights)**0.5
    start_time = time.time()
    
    for i in range(num_epochs): 
        print('epoch ',i + 1 )
        relu_dict_parameters = relu_dict_MC(-pi,pi,N0).to(device)
        if num_neuron == 0: 
            func_values = target(integration_points)
        else: 
            func_values = target(integration_points) - my_model(integration_points).detach()

        weight_func_values = func_values*weights

#         basis_values = F.relu(integration_points - bi).T # uses broadcasting
        basis_values = (F.relu(relu_dict_parameters[:,0] *integration_points - relu_dict_parameters[:,1])**k).T # uses broadcasting
        
        output = torch.abs(torch.matmul(basis_values,weight_func_values)) # 

        neuron_index = torch.argmax(output.flatten())
        
#         print(neuron_index)
        list_w.append(relu_dict_parameters[neuron_index,0])
        list_b.append(-relu_dict_parameters[neuron_index,1])
        num_neuron += 1
        my_model = model(1,num_neuron,1,k).to(device)
        my_model.fc1.weight.data[:,0] = torch.tensor(list_w)[:]
        my_model.fc1.bias.data[:] = torch.tensor(list_b)[:]
#         sol = minimize_linear_layer(my_model,target,solver, Nx, order)
        sol = minimize_linear_layer_explicit_assemble(my_model,target,weights, integration_points,solver=solver)
        my_model.fc2.weight.data[0,:] = sol[:]
        if (i+1)%plot_freq == 0: 
            x_test = torch.linspace(-pi,pi,200).view(-1,1).to(device)
            u_true = target(x_test)
            plot_solution_modified(-pi,pi,my_model,x_test,u_true)
        func_values = target(integration_points) - my_model(integration_points).detach()
        func_values_sqrd = func_values*func_values
        err[i+1]= torch.sum(func_values_sqrd*weights)**0.5
    # print("time taken: ",time.time() - start_time)
    return err, my_model

# relu dictionary

# %%
def show_convergence_order(err_l2,exponent,dict_size, filename,write2file = False):
    
    if write2file:
        file_mode = "a" if os.path.exists(filename) else "w"
        f_write = open(filename, file_mode)
    
    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_l2[i] for i in neuron_nums ]
#     err_list2 = [err_h10[i] for i in neuron_nums ] 
    # f_write.write('M:{}, relu {} \n'.format(M,k))
    if write2file:
        f_write.write('dictionary size: {}\n'.format(dict_size))
        f_write.write("neuron num \t\t error \t\t order \t\t h10 error \\ order \n")
    print("neuron num \t\t error \t\t order")
    for i, item in enumerate(err_list):
        if i == 0: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t")
            
            # print("*")
            print("{} \t\t {:.6f} \t\t *  \n".format(neuron_nums[i],item ) )
            if write2file: 
                f_write.write("{} \t\t {} \t\t * \t\t \n".format(neuron_nums[i],item ))
        else: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t") 
            # print(np.log(err_list[i-1]/err_list[i])/np.log(2))
            print("{} \t\t {:.6f} \t\t {:.6f} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2) ) )
            if write2file: 
                f_write.write("{} \t\t {} \t\t {} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2) ))
    if write2file:     
        f_write.write("\n")
        f_write.close()

def show_convergence_order_latex(err_l2,exponent,k=1,d=1): 
    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_l2[i] for i in neuron_nums ]
#     err_list2 = [err_h10[i] for i in neuron_nums ] 
    # f_write.write('M:{}, relu {} \n'.format(M,k))
    # f_write.write('randomized dictionary size: {}\n'.format(N))
    # f_write.write("neuron num \t\t error \t\t order \t\t h10 error \\ order \n")
    l2_order = -1/2-(2*k + 1)/(2*d)
#     h10_order = -1/2-(2*(k-1) + 1)/(2*d)
#     print("neuron num  & \t $\|u-u_n \|_{L^2}$ & \t order $O(n^{{{}})$ & \t $ | u -u_n |_{H^1}$ & \t order $O(n^{{{}})$ \\\ \hline \hline ".format(l2_order,h10_order))
    print("neuron num  & \t $\\|u-u_n \\|_{{L^2}}$ & \t order $O(n^{{{:.2f}}})$  \\\\ \\hline \\hline ".format(l2_order))
    for i, item in enumerate(err_list):
        if i == 0: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t")

            # print("*")
            print("{} \t\t & {:.6f} &\t\t *  \\\ \hline  \n".format(neuron_nums[i],item) )   
            # f_write.write("{} \t\t {} \t\t * \t\t {} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ))
        else: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t") 
            # print(np.log(err_list[i-1]/err_list[i])/np.log(2))
            print("{} \t\t &  {:.3e} &  \t\t {:.2f} \\\ \hline  \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2) ) )
            # f_write.write("{} \t\t {} \t\t {} \t\t {} \t\t {} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ))
    # f_write.write("\n")
    # f_write.close()

# %% [markdown]
# ## deterministic

# %%
def target(x):
    return torch.sin(x)

function_name = "sine1d" 
Nx = 2**12 
order = 3    
filename_write = "1DOGA-{}-order.txt".format(function_name)
f_write = open(filename_write, "a")
f_write.write("\n")
f_write.close() 

save = True  
write2file = True 

for N in [2**10]: # 2**12,2**14
    
    f_write = open(filename_write, "a")
    my_model = None 
    exponent = 9 
    num_epochs = 2**exponent  
    plot_freq = num_epochs 
    relu_k = 1 
    err_QMC2, my_model = OGAL2FittingReLU1D(None,target,N,num_epochs,plot_freq, Nx, order, k =relu_k, solver = "direct")
    
    if save: 
        folder = 'data/'
        filename = folder + 'err_OGA_1D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        torch.save(err_QMC2,filename) 
        folder = 'data/'
        filename = folder + 'model_OGA_1D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        torch.save(my_model,filename)
    show_convergence_order(err_QMC2,exponent,N,filename_write,write2file = write2file)
    show_convergence_order_latex(err_QMC2,exponent,k=relu_k,d=1)
# Out:
# using linear solver:  direct
# epoch:  1
# assembling the matrix time taken:  0.00030422210693359375
# solving Ax = b time taken:  0.00022792816162109375
# epoch:  2
# assembling the matrix time taken:  0.000293731689453125
# solving Ax = b time taken:  0.00023436546325683594
# epoch:  3
# assembling the matrix time taken:  0.00027561187744140625
# solving Ax = b time taken:  0.00020766258239746094
# epoch:  4
# assembling the matrix time taken:  0.0002522468566894531
# solving Ax = b time taken:  0.0002117156982421875
# epoch:  5
# assembling the matrix time taken:  0.0002579689025878906
# solving Ax = b time taken:  0.00019812583923339844
# epoch:  6
# assembling the matrix time taken:  0.00025653839111328125
# solving Ax = b time taken:  0.00018477439880371094
# epoch:  7
# assembling the matrix time taken:  0.0002593994140625
# solving Ax = b time taken:  0.0001914501190185547
# epoch:  8
# assembling the matrix time taken:  0.0002319812774658203
# solving Ax = b time taken:  0.00022935867309570312
# epoch:  9
# assembling the matrix time taken:  0.00027680397033691406
# solving Ax = b time taken:  0.0002117156982421875
# epoch:  10
# assembling the matrix time taken:  0.000240325927734375
# solving Ax = b time taken:  0.00021386146545410156
# epoch:  11
# assembling the matrix time taken:  0.00023245811462402344
# solving Ax = b time taken:  0.00021409988403320312
# epoch:  12
# assembling the matrix time taken:  0.0002281665802001953
# solving Ax = b time taken:  0.00022149085998535156
# epoch:  13
# assembling the matrix time taken:  0.0002498626708984375
# solving Ax = b time taken:  0.00022339820861816406
# epoch:  14
# assembling the matrix time taken:  0.00023436546325683594
# solving Ax = b time taken:  0.0002219676971435547
# epoch:  15
# assembling the matrix time taken:  0.00022912025451660156
# solving Ax = b time taken:  0.0002434253692626953
# epoch:  16
# assembling the matrix time taken:  0.0002722740173339844
# solving Ax = b time taken:  0.0002410411834716797
# epoch:  17
# assembling the matrix time taken:  0.0002739429473876953
# solving Ax = b time taken:  0.0002722740173339844
# epoch:  18
# assembling the matrix time taken:  0.00024390220642089844
# solving Ax = b time taken:  0.0002951622009277344
# epoch:  19
# assembling the matrix time taken:  0.00029540061950683594
# solving Ax = b time taken:  0.0002827644348144531
# epoch:  20
# assembling the matrix time taken:  0.00025963783264160156
# solving Ax = b time taken:  0.00029659271240234375
# epoch:  21
# assembling the matrix time taken:  0.0002288818359375
# solving Ax = b time taken:  0.00031256675720214844
# epoch:  22
# assembling the matrix time taken:  0.00026607513427734375
# solving Ax = b time taken:  0.00027871131896972656
# epoch:  23
# assembling the matrix time taken:  0.0002644062042236328
# solving Ax = b time taken:  0.00029206275939941406
# epoch:  24
# assembling the matrix time taken:  0.00027108192443847656
# solving Ax = b time taken:  0.0003025531768798828
# epoch:  25
# assembling the matrix time taken:  0.0002493858337402344
# solving Ax = b time taken:  0.00030350685119628906
# epoch:  26
# assembling the matrix time taken:  0.00024056434631347656
# solving Ax = b time taken:  0.00030994415283203125
# epoch:  27
# assembling the matrix time taken:  0.00026917457580566406
# solving Ax = b time taken:  0.00031828880310058594
# epoch:  28
# assembling the matrix time taken:  0.00023365020751953125
# solving Ax = b time taken:  0.00033164024353027344
# epoch:  29
# assembling the matrix time taken:  0.00028443336486816406
# solving Ax = b time taken:  0.00032258033752441406
# epoch:  30
# assembling the matrix time taken:  0.00029206275939941406
# solving Ax = b time taken:  0.00028395652770996094
# epoch:  31
# assembling the matrix time taken:  0.0002732276916503906
# solving Ax = b time taken:  0.0003342628479003906
# epoch:  32
# assembling the matrix time taken:  0.0002751350402832031
# solving Ax = b time taken:  0.0003209114074707031
# epoch:  33
# assembling the matrix time taken:  0.00022745132446289062
# solving Ax = b time taken:  0.0004935264587402344
# epoch:  34
# assembling the matrix time taken:  0.0002639293670654297
# solving Ax = b time taken:  0.0004749298095703125
# epoch:  35
# assembling the matrix time taken:  0.0002372264862060547
# solving Ax = b time taken:  0.000499725341796875
# epoch:  36
# assembling the matrix time taken:  0.0002579689025878906
# solving Ax = b time taken:  0.00047588348388671875
# epoch:  37
# assembling the matrix time taken:  0.00023651123046875
# solving Ax = b time taken:  0.0005238056182861328
# epoch:  38
# assembling the matrix time taken:  0.00023555755615234375
# solving Ax = b time taken:  0.0005235671997070312
# epoch:  39
# assembling the matrix time taken:  0.0002543926239013672
# solving Ax = b time taken:  0.0005364418029785156
# epoch:  40
# assembling the matrix time taken:  0.0002624988555908203
# solving Ax = b time taken:  0.0004975795745849609
# epoch:  41
# assembling the matrix time taken:  0.0002884864807128906
# solving Ax = b time taken:  0.0004935264587402344
# epoch:  42
# assembling the matrix time taken:  0.00026488304138183594
# solving Ax = b time taken:  0.0005173683166503906
# epoch:  43
# assembling the matrix time taken:  0.0002872943878173828
# solving Ax = b time taken:  0.0005116462707519531
# epoch:  44
# assembling the matrix time taken:  0.00028777122497558594
# solving Ax = b time taken:  0.0005068778991699219
# epoch:  45
# assembling the matrix time taken:  0.00024771690368652344
# solving Ax = b time taken:  0.0005497932434082031
# epoch:  46
# assembling the matrix time taken:  0.0002353191375732422
# solving Ax = b time taken:  0.0005154609680175781
# epoch:  47
# assembling the matrix time taken:  0.00025272369384765625
# solving Ax = b time taken:  0.0004990100860595703
# epoch:  48
# assembling the matrix time taken:  0.00023055076599121094
# solving Ax = b time taken:  0.0005180835723876953
# epoch:  49
# assembling the matrix time taken:  0.00023746490478515625
# solving Ax = b time taken:  0.0007371902465820312
# epoch:  50
# assembling the matrix time taken:  0.0002663135528564453
# solving Ax = b time taken:  0.0007076263427734375
# epoch:  51
# assembling the matrix time taken:  0.00025153160095214844
# solving Ax = b time taken:  0.0007662773132324219
# epoch:  52
# assembling the matrix time taken:  0.0002334117889404297
# solving Ax = b time taken:  0.0007390975952148438
# epoch:  53
# assembling the matrix time taken:  0.0002532005310058594
# solving Ax = b time taken:  0.0007224082946777344
# epoch:  54
# assembling the matrix time taken:  0.00022840499877929688
# solving Ax = b time taken:  0.0007579326629638672
# epoch:  55
# assembling the matrix time taken:  0.0002739429473876953
# solving Ax = b time taken:  0.0007450580596923828
# epoch:  56
# assembling the matrix time taken:  0.0003247261047363281
# solving Ax = b time taken:  0.0006878376007080078
# epoch:  57
# assembling the matrix time taken:  0.00023031234741210938
# solving Ax = b time taken:  0.0007777214050292969
# epoch:  58
# assembling the matrix time taken:  0.0003154277801513672
# solving Ax = b time taken:  0.0007531642913818359
# epoch:  59
# assembling the matrix time taken:  0.00027751922607421875
# solving Ax = b time taken:  0.0007345676422119141
# epoch:  60
# assembling the matrix time taken:  0.00023698806762695312
# solving Ax = b time taken:  0.0007786750793457031
# epoch:  61
# assembling the matrix time taken:  0.000255584716796875
# solving Ax = b time taken:  0.0007953643798828125
# epoch:  62
# assembling the matrix time taken:  0.0002567768096923828
# solving Ax = b time taken:  0.0007674694061279297
# epoch:  63
# assembling the matrix time taken:  0.00024771690368652344
# solving Ax = b time taken:  0.0007889270782470703
# epoch:  64
# assembling the matrix time taken:  0.00022673606872558594
# solving Ax = b time taken:  0.0007870197296142578
# epoch:  65
# assembling the matrix time taken:  0.0002460479736328125
# solving Ax = b time taken:  0.0019140243530273438
# epoch:  66
# assembling the matrix time taken:  0.00023436546325683594
# solving Ax = b time taken:  0.0019328594207763672
# epoch:  67
# assembling the matrix time taken:  0.0002472400665283203
# solving Ax = b time taken:  0.0019073486328125
# epoch:  68
# assembling the matrix time taken:  0.0002586841583251953
# solving Ax = b time taken:  0.0019278526306152344
# epoch:  69
# assembling the matrix time taken:  0.00022292137145996094
# solving Ax = b time taken:  0.001953125
# epoch:  70
# assembling the matrix time taken:  0.0002529621124267578
# solving Ax = b time taken:  0.0019485950469970703
# epoch:  71
# assembling the matrix time taken:  0.0002486705780029297
# solving Ax = b time taken:  0.0019655227661132812
# epoch:  72
# assembling the matrix time taken:  0.0002532005310058594
# solving Ax = b time taken:  0.0019652843475341797
# epoch:  73
# assembling the matrix time taken:  0.00026035308837890625
# solving Ax = b time taken:  0.0017933845520019531
# epoch:  74
# assembling the matrix time taken:  0.0002503395080566406
# solving Ax = b time taken:  0.0017919540405273438
# epoch:  75
# assembling the matrix time taken:  0.0002410411834716797
# solving Ax = b time taken:  0.0018041133880615234
# epoch:  76
# assembling the matrix time taken:  0.00025773048400878906
# solving Ax = b time taken:  0.0018002986907958984
# epoch:  77
# assembling the matrix time taken:  0.000247955322265625
# solving Ax = b time taken:  0.0018267631530761719
# epoch:  78
# assembling the matrix time taken:  0.0002257823944091797
# solving Ax = b time taken:  0.0018341541290283203
# epoch:  79
# assembling the matrix time taken:  0.0002532005310058594
# solving Ax = b time taken:  0.0018515586853027344
# epoch:  80
# assembling the matrix time taken:  0.00027251243591308594
# solving Ax = b time taken:  0.0018076896667480469
# epoch:  81
# assembling the matrix time taken:  0.0002770423889160156
# solving Ax = b time taken:  0.0017786026000976562
# epoch:  82
# assembling the matrix time taken:  0.00026106834411621094
# solving Ax = b time taken:  0.0018236637115478516
# epoch:  83
# assembling the matrix time taken:  0.00026917457580566406
# solving Ax = b time taken:  0.001811981201171875
# epoch:  84
# assembling the matrix time taken:  0.0002434253692626953
# solving Ax = b time taken:  0.0018773078918457031
# epoch:  85
# assembling the matrix time taken:  0.0002570152282714844
# solving Ax = b time taken:  0.0018372535705566406
# epoch:  86
# assembling the matrix time taken:  0.00025725364685058594
# solving Ax = b time taken:  0.0018341541290283203
# epoch:  87
# assembling the matrix time taken:  0.0002536773681640625
# solving Ax = b time taken:  0.001840829849243164
# epoch:  88
# assembling the matrix time taken:  0.0002791881561279297
# solving Ax = b time taken:  0.0018062591552734375
# epoch:  89
# assembling the matrix time taken:  0.0002300739288330078
# solving Ax = b time taken:  0.0018770694732666016
# epoch:  90
# assembling the matrix time taken:  0.000244140625
# solving Ax = b time taken:  0.0019054412841796875
# epoch:  91
# assembling the matrix time taken:  0.00023603439331054688
# solving Ax = b time taken:  0.0018947124481201172
# epoch:  92
# assembling the matrix time taken:  0.00025153160095214844
# solving Ax = b time taken:  0.0018587112426757812
# epoch:  93
# assembling the matrix time taken:  0.00026106834411621094
# solving Ax = b time taken:  0.0018668174743652344
# epoch:  94
# assembling the matrix time taken:  0.0002796649932861328
# solving Ax = b time taken:  0.0018680095672607422
# epoch:  95
# assembling the matrix time taken:  0.0002777576446533203
# solving Ax = b time taken:  0.0018618106842041016
# epoch:  96
# assembling the matrix time taken:  0.00027632713317871094
# solving Ax = b time taken:  0.0018808841705322266
# epoch:  97
# assembling the matrix time taken:  0.0002620220184326172
# solving Ax = b time taken:  0.0018856525421142578
# epoch:  98
# assembling the matrix time taken:  0.000286102294921875
# solving Ax = b time taken:  0.0018544197082519531
# epoch:  99
# assembling the matrix time taken:  0.00023651123046875
# solving Ax = b time taken:  0.0018982887268066406
# epoch:  100
# assembling the matrix time taken:  0.0002627372741699219
# solving Ax = b time taken:  0.0018787384033203125
# epoch:  101
# assembling the matrix time taken:  0.000232696533203125
# solving Ax = b time taken:  0.0019342899322509766
# epoch:  102
# assembling the matrix time taken:  0.0002377033233642578
# solving Ax = b time taken:  0.001918792724609375
# epoch:  103
# assembling the matrix time taken:  0.0002617835998535156
# solving Ax = b time taken:  0.0018973350524902344
# epoch:  104
# assembling the matrix time taken:  0.00024366378784179688
# solving Ax = b time taken:  0.0019259452819824219
# epoch:  105
# assembling the matrix time taken:  0.0002300739288330078
# solving Ax = b time taken:  0.0019142627716064453
# epoch:  106
# assembling the matrix time taken:  0.0002498626708984375
# solving Ax = b time taken:  0.0018870830535888672
# epoch:  107
# assembling the matrix time taken:  0.00024318695068359375
# solving Ax = b time taken:  0.0018837451934814453
# epoch:  108
# assembling the matrix time taken:  0.0002262592315673828
# solving Ax = b time taken:  0.0018854141235351562
# epoch:  109
# assembling the matrix time taken:  0.0002636909484863281
# solving Ax = b time taken:  0.0019335746765136719
# epoch:  110
# assembling the matrix time taken:  0.00023937225341796875
# solving Ax = b time taken:  0.0019605159759521484
# epoch:  111
# assembling the matrix time taken:  0.0003216266632080078
# solving Ax = b time taken:  0.0019116401672363281
# epoch:  112
# assembling the matrix time taken:  0.0002627372741699219
# solving Ax = b time taken:  0.0018875598907470703
# epoch:  113
# assembling the matrix time taken:  0.0002262592315673828
# solving Ax = b time taken:  0.0019466876983642578
# epoch:  114
# assembling the matrix time taken:  0.0002665519714355469
# solving Ax = b time taken:  0.0019114017486572266
# epoch:  115
# assembling the matrix time taken:  0.0002460479736328125
# solving Ax = b time taken:  0.0019297599792480469
# epoch:  116
# assembling the matrix time taken:  0.0002429485321044922
# solving Ax = b time taken:  0.0019359588623046875
# epoch:  117
# assembling the matrix time taken:  0.0002522468566894531
# solving Ax = b time taken:  0.001936197280883789
# epoch:  118
# assembling the matrix time taken:  0.00023293495178222656
# solving Ax = b time taken:  0.0019483566284179688
# epoch:  119
# assembling the matrix time taken:  0.0002512931823730469
# solving Ax = b time taken:  0.0019636154174804688
# epoch:  120
# assembling the matrix time taken:  0.00022912025451660156
# solving Ax = b time taken:  0.001966714859008789
# epoch:  121
# assembling the matrix time taken:  0.0002269744873046875
# solving Ax = b time taken:  0.0020554065704345703
# epoch:  122
# assembling the matrix time taken:  0.0002601146697998047
# solving Ax = b time taken:  0.0019693374633789062
# epoch:  123
# assembling the matrix time taken:  0.00028777122497558594
# solving Ax = b time taken:  0.0019636154174804688
# epoch:  124
# assembling the matrix time taken:  0.0002315044403076172
# solving Ax = b time taken:  0.0020465850830078125
# epoch:  125
# assembling the matrix time taken:  0.0002856254577636719
# solving Ax = b time taken:  0.002014636993408203
# epoch:  126
# assembling the matrix time taken:  0.00026679039001464844
# solving Ax = b time taken:  0.0020227432250976562
# epoch:  127
# assembling the matrix time taken:  0.0002651214599609375
# solving Ax = b time taken:  0.002049684524536133
# epoch:  128
# assembling the matrix time taken:  0.0002307891845703125
# solving Ax = b time taken:  0.0020513534545898438
# epoch:  129
# assembling the matrix time taken:  0.0002276897430419922
# solving Ax = b time taken:  0.003211498260498047
# epoch:  130
# assembling the matrix time taken:  0.0003063678741455078
# solving Ax = b time taken:  0.003172159194946289
# epoch:  131
# assembling the matrix time taken:  0.0002472400665283203
# solving Ax = b time taken:  0.0031709671020507812
# epoch:  132
# assembling the matrix time taken:  0.00025200843811035156
# solving Ax = b time taken:  0.0032460689544677734
# epoch:  133
# assembling the matrix time taken:  0.0002205371856689453
# solving Ax = b time taken:  0.0032482147216796875
# epoch:  134
# assembling the matrix time taken:  0.00026488304138183594
# solving Ax = b time taken:  0.003246307373046875
# epoch:  135
# assembling the matrix time taken:  0.00027632713317871094
# solving Ax = b time taken:  0.0032410621643066406
# epoch:  136
# assembling the matrix time taken:  0.00024056434631347656
# solving Ax = b time taken:  0.0032236576080322266
# epoch:  137
# assembling the matrix time taken:  0.0002295970916748047
# solving Ax = b time taken:  0.0032644271850585938
# epoch:  138
# assembling the matrix time taken:  0.00027561187744140625
# solving Ax = b time taken:  0.0032286643981933594
# epoch:  139
# assembling the matrix time taken:  0.0002696514129638672
# solving Ax = b time taken:  0.0032656192779541016
# epoch:  140
# assembling the matrix time taken:  0.000263214111328125
# solving Ax = b time taken:  0.003269195556640625
# epoch:  141
# assembling the matrix time taken:  0.0002598762512207031
# solving Ax = b time taken:  0.003268718719482422
# epoch:  142
# assembling the matrix time taken:  0.00024247169494628906
# solving Ax = b time taken:  0.0032706260681152344
# epoch:  143
# assembling the matrix time taken:  0.0002617835998535156
# solving Ax = b time taken:  0.00330352783203125
# epoch:  144
# assembling the matrix time taken:  0.00025463104248046875
# solving Ax = b time taken:  0.0032951831817626953
# epoch:  145
# assembling the matrix time taken:  0.0002455711364746094
# solving Ax = b time taken:  0.0033245086669921875
# epoch:  146
# assembling the matrix time taken:  0.0002536773681640625
# solving Ax = b time taken:  0.0033483505249023438
# epoch:  147
# assembling the matrix time taken:  0.0002415180206298828
# solving Ax = b time taken:  0.0033426284790039062
# epoch:  148
# assembling the matrix time taken:  0.00023651123046875
# solving Ax = b time taken:  0.0033669471740722656
# epoch:  149
# assembling the matrix time taken:  0.0002238750457763672
# solving Ax = b time taken:  0.0033779144287109375
# epoch:  150
# assembling the matrix time taken:  0.00022220611572265625
# solving Ax = b time taken:  0.003412008285522461
# epoch:  151
# assembling the matrix time taken:  0.00023221969604492188
# solving Ax = b time taken:  0.00341033935546875
# epoch:  152
# assembling the matrix time taken:  0.0002694129943847656
# solving Ax = b time taken:  0.003348112106323242
# epoch:  153
# assembling the matrix time taken:  0.00026297569274902344
# solving Ax = b time taken:  0.003392457962036133
# epoch:  154
# assembling the matrix time taken:  0.00022459030151367188
# solving Ax = b time taken:  0.0034134387969970703
# epoch:  155
# assembling the matrix time taken:  0.00023055076599121094
# solving Ax = b time taken:  0.003416776657104492
# epoch:  156
# assembling the matrix time taken:  0.0002551078796386719
# solving Ax = b time taken:  0.0034029483795166016
# epoch:  157
# assembling the matrix time taken:  0.00023365020751953125
# solving Ax = b time taken:  0.0034329891204833984
# epoch:  158
# assembling the matrix time taken:  0.00022292137145996094
# solving Ax = b time taken:  0.003435373306274414
# epoch:  159
# assembling the matrix time taken:  0.00029540061950683594
# solving Ax = b time taken:  0.0033860206604003906
# epoch:  160
# assembling the matrix time taken:  0.0002727508544921875
# solving Ax = b time taken:  0.003378152847290039
# epoch:  161
# assembling the matrix time taken:  0.0002598762512207031
# solving Ax = b time taken:  0.003453493118286133
# epoch:  162
# assembling the matrix time taken:  0.0002288818359375
# solving Ax = b time taken:  0.0034754276275634766
# epoch:  163
# assembling the matrix time taken:  0.0002529621124267578
# solving Ax = b time taken:  0.0034613609313964844
# epoch:  164
# assembling the matrix time taken:  0.0002281665802001953
# solving Ax = b time taken:  0.0034971237182617188
# epoch:  165
# assembling the matrix time taken:  0.0003008842468261719
# solving Ax = b time taken:  0.0034568309783935547
# epoch:  166
# assembling the matrix time taken:  0.000255584716796875
# solving Ax = b time taken:  0.0034782886505126953
# epoch:  167
# assembling the matrix time taken:  0.00026416778564453125
# solving Ax = b time taken:  0.003478527069091797
# epoch:  168
# assembling the matrix time taken:  0.00025773048400878906
# solving Ax = b time taken:  0.00347137451171875
# epoch:  169
# assembling the matrix time taken:  0.00024580955505371094
# solving Ax = b time taken:  0.00350189208984375
# epoch:  170
# assembling the matrix time taken:  0.0002777576446533203
# solving Ax = b time taken:  0.0034618377685546875
# epoch:  171
# assembling the matrix time taken:  0.0002715587615966797
# solving Ax = b time taken:  0.0034856796264648438
# epoch:  172
# assembling the matrix time taken:  0.000244140625
# solving Ax = b time taken:  0.003515005111694336
# epoch:  173
# assembling the matrix time taken:  0.0002429485321044922
# solving Ax = b time taken:  0.0035436153411865234
# epoch:  174
# assembling the matrix time taken:  0.0002396106719970703
# solving Ax = b time taken:  0.0035457611083984375
# epoch:  175
# assembling the matrix time taken:  0.0002334117889404297
# solving Ax = b time taken:  0.003557920455932617
# epoch:  176
# assembling the matrix time taken:  0.0002570152282714844
# solving Ax = b time taken:  0.003503561019897461
# epoch:  177
# assembling the matrix time taken:  0.00027751922607421875
# solving Ax = b time taken:  0.003560304641723633
# epoch:  178
# assembling the matrix time taken:  0.0002779960632324219
# solving Ax = b time taken:  0.003578662872314453
# epoch:  179
# assembling the matrix time taken:  0.0002617835998535156
# solving Ax = b time taken:  0.0035791397094726562
# epoch:  180
# assembling the matrix time taken:  0.0003039836883544922
# solving Ax = b time taken:  0.0035190582275390625
# epoch:  181
# assembling the matrix time taken:  0.0002455711364746094
# solving Ax = b time taken:  0.003624439239501953
# epoch:  182
# assembling the matrix time taken:  0.00025963783264160156
# solving Ax = b time taken:  0.003583192825317383
# epoch:  183
# assembling the matrix time taken:  0.0002300739288330078
# solving Ax = b time taken:  0.0036220550537109375
# epoch:  184
# assembling the matrix time taken:  0.00028324127197265625
# solving Ax = b time taken:  0.0035736560821533203
# epoch:  185
# assembling the matrix time taken:  0.00023221969604492188
# solving Ax = b time taken:  0.003612518310546875
# epoch:  186
# assembling the matrix time taken:  0.00025725364685058594
# solving Ax = b time taken:  0.0036160945892333984
# epoch:  187
# assembling the matrix time taken:  0.00026535987854003906
# solving Ax = b time taken:  0.003632783889770508
# epoch:  188
# assembling the matrix time taken:  0.00023055076599121094
# solving Ax = b time taken:  0.003669261932373047
# epoch:  189
# assembling the matrix time taken:  0.00022482872009277344
# solving Ax = b time taken:  0.0036711692810058594
# epoch:  190
# assembling the matrix time taken:  0.0002796649932861328
# solving Ax = b time taken:  0.003615140914916992
# epoch:  191
# assembling the matrix time taken:  0.0002512931823730469
# solving Ax = b time taken:  0.003645181655883789
# epoch:  192
# assembling the matrix time taken:  0.00023603439331054688
# solving Ax = b time taken:  0.003640413284301758
# epoch:  193
# assembling the matrix time taken:  0.00023555755615234375
# solving Ax = b time taken:  0.0054454803466796875
# epoch:  194
# assembling the matrix time taken:  0.00032067298889160156
# solving Ax = b time taken:  0.005356788635253906
# epoch:  195
# assembling the matrix time taken:  0.0002765655517578125
# solving Ax = b time taken:  0.0054378509521484375
# epoch:  196
# assembling the matrix time taken:  0.00023102760314941406
# solving Ax = b time taken:  0.0054607391357421875
# epoch:  197
# assembling the matrix time taken:  0.00023126602172851562
# solving Ax = b time taken:  0.005471706390380859
# epoch:  198
# assembling the matrix time taken:  0.0002720355987548828
# solving Ax = b time taken:  0.005448579788208008
# epoch:  199
# assembling the matrix time taken:  0.000240325927734375
# solving Ax = b time taken:  0.0054929256439208984
# epoch:  200
# assembling the matrix time taken:  0.00025653839111328125
# solving Ax = b time taken:  0.0054395198822021484
# epoch:  201
# assembling the matrix time taken:  0.0002734661102294922
# solving Ax = b time taken:  0.005458831787109375
# epoch:  202
# assembling the matrix time taken:  0.000225067138671875
# solving Ax = b time taken:  0.005513668060302734
# epoch:  203
# assembling the matrix time taken:  0.00021886825561523438
# solving Ax = b time taken:  0.005498409271240234
# epoch:  204
# assembling the matrix time taken:  0.0002505779266357422
# solving Ax = b time taken:  0.0054891109466552734
# epoch:  205
# assembling the matrix time taken:  0.0002760887145996094
# solving Ax = b time taken:  0.005473613739013672
# epoch:  206
# assembling the matrix time taken:  0.00022149085998535156
# solving Ax = b time taken:  0.005532741546630859
# epoch:  207
# assembling the matrix time taken:  0.00028395652770996094
# solving Ax = b time taken:  0.005477190017700195
# epoch:  208
# assembling the matrix time taken:  0.0002639293670654297
# solving Ax = b time taken:  0.005469083786010742
# epoch:  209
# assembling the matrix time taken:  0.0002446174621582031
# solving Ax = b time taken:  0.005540132522583008
# epoch:  210
# assembling the matrix time taken:  0.00022149085998535156
# solving Ax = b time taken:  0.0055849552154541016
# epoch:  211
# assembling the matrix time taken:  0.00022554397583007812
# solving Ax = b time taken:  0.005570888519287109
# epoch:  212
# assembling the matrix time taken:  0.00029778480529785156
# solving Ax = b time taken:  0.005492210388183594
# epoch:  213
# assembling the matrix time taken:  0.0002276897430419922
# solving Ax = b time taken:  0.005597114562988281
# epoch:  214
# assembling the matrix time taken:  0.0002551078796386719
# solving Ax = b time taken:  0.00555419921875
# epoch:  215
# assembling the matrix time taken:  0.00028705596923828125
# solving Ax = b time taken:  0.00554203987121582
# epoch:  216
# assembling the matrix time taken:  0.00026488304138183594
# solving Ax = b time taken:  0.005565166473388672
# epoch:  217
# assembling the matrix time taken:  0.00023221969604492188
# solving Ax = b time taken:  0.005612611770629883
# epoch:  218
# assembling the matrix time taken:  0.0002288818359375
# solving Ax = b time taken:  0.005616188049316406
# epoch:  219
# assembling the matrix time taken:  0.0002219676971435547
# solving Ax = b time taken:  0.005621671676635742
# epoch:  220
# assembling the matrix time taken:  0.00023627281188964844
# solving Ax = b time taken:  0.005619049072265625
# epoch:  221
# assembling the matrix time taken:  0.0002567768096923828
# solving Ax = b time taken:  0.005631208419799805
# epoch:  222
# assembling the matrix time taken:  0.00022745132446289062
# solving Ax = b time taken:  0.005631685256958008
# epoch:  223
# assembling the matrix time taken:  0.0002701282501220703
# solving Ax = b time taken:  0.0056149959564208984
# epoch:  224
# assembling the matrix time taken:  0.000225067138671875
# solving Ax = b time taken:  0.005630016326904297
# epoch:  225
# assembling the matrix time taken:  0.0002200603485107422
# solving Ax = b time taken:  0.005700588226318359
# epoch:  226
# assembling the matrix time taken:  0.00022339820861816406
# solving Ax = b time taken:  0.005690097808837891
# epoch:  227
# assembling the matrix time taken:  0.00022864341735839844
# solving Ax = b time taken:  0.0056917667388916016
# epoch:  228
# assembling the matrix time taken:  0.0002624988555908203
# solving Ax = b time taken:  0.005703926086425781
# epoch:  229
# assembling the matrix time taken:  0.0002346038818359375
# solving Ax = b time taken:  0.005708217620849609
# epoch:  230
# assembling the matrix time taken:  0.00024199485778808594
# solving Ax = b time taken:  0.005686759948730469
# epoch:  231
# assembling the matrix time taken:  0.00022530555725097656
# solving Ax = b time taken:  0.005718708038330078
# epoch:  232
# assembling the matrix time taken:  0.00021982192993164062
# solving Ax = b time taken:  0.0057179927825927734
# epoch:  233
# assembling the matrix time taken:  0.00025653839111328125
# solving Ax = b time taken:  0.005697011947631836
# epoch:  234
# assembling the matrix time taken:  0.00028133392333984375
# solving Ax = b time taken:  0.005650758743286133
# epoch:  235
# assembling the matrix time taken:  0.0002613067626953125
# solving Ax = b time taken:  0.005710601806640625
# epoch:  236
# assembling the matrix time taken:  0.0002377033233642578
# solving Ax = b time taken:  0.005717754364013672
# epoch:  237
# assembling the matrix time taken:  0.00022220611572265625
# solving Ax = b time taken:  0.00573420524597168
# epoch:  238
# assembling the matrix time taken:  0.00025916099548339844
# solving Ax = b time taken:  0.0057256221771240234
# epoch:  239
# assembling the matrix time taken:  0.0002601146697998047
# solving Ax = b time taken:  0.00576329231262207
# epoch:  240
# assembling the matrix time taken:  0.0002567768096923828
# solving Ax = b time taken:  0.006284475326538086
# epoch:  241
# assembling the matrix time taken:  0.0002353191375732422
# solving Ax = b time taken:  0.005796670913696289
# epoch:  242
# assembling the matrix time taken:  0.00022530555725097656
# solving Ax = b time taken:  0.0058116912841796875
# epoch:  243
# assembling the matrix time taken:  0.00025010108947753906
# solving Ax = b time taken:  0.0058002471923828125
# epoch:  244
# assembling the matrix time taken:  0.0002455711364746094
# solving Ax = b time taken:  0.0057947635650634766
# epoch:  245
# assembling the matrix time taken:  0.00022459030151367188
# solving Ax = b time taken:  0.005835771560668945
# epoch:  246
# assembling the matrix time taken:  0.0002770423889160156
# solving Ax = b time taken:  0.005766630172729492
# epoch:  247
# assembling the matrix time taken:  0.00028204917907714844
# solving Ax = b time taken:  0.005785226821899414
# epoch:  248
# assembling the matrix time taken:  0.0002346038818359375
# solving Ax = b time taken:  0.005787372589111328
# epoch:  249
# assembling the matrix time taken:  0.00024890899658203125
# solving Ax = b time taken:  0.005824565887451172
# epoch:  250
# assembling the matrix time taken:  0.0002949237823486328
# solving Ax = b time taken:  0.0057985782623291016
# epoch:  251
# assembling the matrix time taken:  0.00025272369384765625
# solving Ax = b time taken:  0.0058438777923583984
# epoch:  252
# assembling the matrix time taken:  0.0002315044403076172
# solving Ax = b time taken:  0.0058476924896240234
# epoch:  253
# assembling the matrix time taken:  0.0002281665802001953
# solving Ax = b time taken:  0.005865335464477539
# epoch:  254
# assembling the matrix time taken:  0.0002658367156982422
# solving Ax = b time taken:  0.005830526351928711
# epoch:  255
# assembling the matrix time taken:  0.00023174285888671875
# solving Ax = b time taken:  0.0058748722076416016
# epoch:  256
# assembling the matrix time taken:  0.0002830028533935547
# solving Ax = b time taken:  0.005803823471069336
# time taken:  2.547459602355957
# neuron num 		 error 		 order
# 4 		 0.280372 		 *
#
# 8 		 0.058896 		 2.251090
#
# 16 		 0.012430 		 2.244402
#
# 32 		 0.003002 		 2.049691
#
# 64 		 0.000767 		 1.968567
#
# 128 		 0.000183 		 2.063791
#
# 256 		 0.000047 		 1.973673
#
# neuron num  & 	 $\|u-u_n \|_{L^2}$ & 	 order $O(n^{-2.00})$  \\ \hline \hline
# 4 		 & 0.280372 &		 *  \\ \hline
#
# 8 		 &  5.890e-02 &  		 2.25 \\ \hline
#
# 16 		 &  1.243e-02 &  		 2.24 \\ \hline
#
# 32 		 &  3.002e-03 &  		 2.05 \\ \hline
#
# 64 		 &  7.671e-04 &  		 1.97 \\ \hline
#
# 128 		 &  1.835e-04 &  		 2.06 \\ \hline
#
# 256 		 &  4.671e-05 &  		 1.97 \\ \hline

# %% [markdown]
# ## randomized

# %%
def target(x):
    return torch.sin(x)

function_name = "sine1d" 
Nx = 2**12 
order = 3    
filename_write = "1DMCOGA-{}-order.txt".format(function_name)
f_write = open(filename_write, "a")
f_write.write("\n")
f_write.close() 

save = True  
write2file = True 

for N in [2**11]: # 2**12,2**14
    
    f_write = open(filename_write, "a")
    my_model = None 
    exponent = 9 
    num_epochs = 2**exponent  
    plot_freq = num_epochs 
    relu_k = 1 
    err_QMC2, my_model = OGAL2FittingReLU1D_MC(None,target,N,num_epochs,plot_freq, Nx, order, k =relu_k, solver = "direct")
    
    if save: 
        folder = 'data/'
        filename = folder + 'err_OGA_1D_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,num_epochs,N)
        torch.save(err_QMC2,filename) 
        folder = 'data/'
        filename = folder + 'model_OGA_1D_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,num_epochs,N)
        torch.save(my_model,filename)
        
    show_convergence_order(err_QMC2,exponent,N,filename_write,write2file = write2file)
    show_convergence_order_latex(err_QMC2,exponent,k=relu_k,d=1)
# Out:
# epoch  1
# assembling the matrix time taken:  0.00029540061950683594
# solving Ax = b time taken:  0.00024509429931640625
# epoch  2
# assembling the matrix time taken:  0.0002770423889160156
# solving Ax = b time taken:  0.00021386146545410156
# epoch  3
# assembling the matrix time taken:  0.00022721290588378906
# solving Ax = b time taken:  0.00021958351135253906
# epoch  4
# assembling the matrix time taken:  0.0002963542938232422
# solving Ax = b time taken:  0.000194549560546875
# epoch  5
# assembling the matrix time taken:  0.000270843505859375
# solving Ax = b time taken:  0.0002110004425048828
# epoch  6
# assembling the matrix time taken:  0.00029087066650390625
# solving Ax = b time taken:  0.00021004676818847656
# epoch  7
# assembling the matrix time taken:  0.00023555755615234375
# solving Ax = b time taken:  0.00018477439880371094
# epoch  8
# assembling the matrix time taken:  0.0002713203430175781
# solving Ax = b time taken:  0.0001876354217529297
# epoch  9
# assembling the matrix time taken:  0.00027680397033691406
# solving Ax = b time taken:  0.00024056434631347656
# epoch  10
# assembling the matrix time taken:  0.00024890899658203125
# solving Ax = b time taken:  0.0002315044403076172
# epoch  11
# assembling the matrix time taken:  0.0002491474151611328
# solving Ax = b time taken:  0.0002689361572265625
# epoch  12
# assembling the matrix time taken:  0.00023555755615234375
# solving Ax = b time taken:  0.00021266937255859375
# epoch  13
# assembling the matrix time taken:  0.00024580955505371094
# solving Ax = b time taken:  0.00024390220642089844
# epoch  14
# assembling the matrix time taken:  0.0002796649932861328
# solving Ax = b time taken:  0.00026488304138183594
# epoch  15
# assembling the matrix time taken:  0.0002474784851074219
# solving Ax = b time taken:  0.000244140625
# epoch  16
# assembling the matrix time taken:  0.0002415180206298828
# solving Ax = b time taken:  0.0002396106719970703
# epoch  17
# assembling the matrix time taken:  0.0002815723419189453
# solving Ax = b time taken:  0.0002949237823486328
# epoch  18
# assembling the matrix time taken:  0.00025653839111328125
# solving Ax = b time taken:  0.00026798248291015625
# epoch  19
# assembling the matrix time taken:  0.0002827644348144531
# solving Ax = b time taken:  0.0002753734588623047
# epoch  20
# assembling the matrix time taken:  0.00027561187744140625
# solving Ax = b time taken:  0.0002524852752685547
# epoch  21
# assembling the matrix time taken:  0.00025653839111328125
# solving Ax = b time taken:  0.0002982616424560547
# epoch  22
# assembling the matrix time taken:  0.00030541419982910156
# solving Ax = b time taken:  0.0002753734588623047
# epoch  23
# assembling the matrix time taken:  0.0002617835998535156
# solving Ax = b time taken:  0.000278472900390625
# epoch  24
# assembling the matrix time taken:  0.0002491474151611328
# solving Ax = b time taken:  0.00028204917907714844
# epoch  25
# assembling the matrix time taken:  0.0002589225769042969
# solving Ax = b time taken:  0.0002892017364501953
# epoch  26
# assembling the matrix time taken:  0.0002238750457763672
# solving Ax = b time taken:  0.0002932548522949219
# epoch  27
# assembling the matrix time taken:  0.0002262592315673828
# solving Ax = b time taken:  0.00029587745666503906
# epoch  28
# assembling the matrix time taken:  0.0002467632293701172
# solving Ax = b time taken:  0.0002980232238769531
# epoch  29
# assembling the matrix time taken:  0.00022935867309570312
# solving Ax = b time taken:  0.0003070831298828125
# epoch  30
# assembling the matrix time taken:  0.0002269744873046875
# solving Ax = b time taken:  0.0003147125244140625
# epoch  31
# assembling the matrix time taken:  0.00022673606872558594
# solving Ax = b time taken:  0.00032520294189453125
# epoch  32
# assembling the matrix time taken:  0.0003070831298828125
# solving Ax = b time taken:  0.0003058910369873047
# epoch  33
# assembling the matrix time taken:  0.0002524852752685547
# solving Ax = b time taken:  0.00043654441833496094
# epoch  34
# assembling the matrix time taken:  0.00025963783264160156
# solving Ax = b time taken:  0.0004353523254394531
# epoch  35
# assembling the matrix time taken:  0.00023055076599121094
# solving Ax = b time taken:  0.0004761219024658203
# epoch  36
# assembling the matrix time taken:  0.0002415180206298828
# solving Ax = b time taken:  0.0004458427429199219
# epoch  37
# assembling the matrix time taken:  0.0002589225769042969
# solving Ax = b time taken:  0.0004432201385498047
# epoch  38
# assembling the matrix time taken:  0.00023794174194335938
# solving Ax = b time taken:  0.00047135353088378906
# epoch  39
# assembling the matrix time taken:  0.0002701282501220703
# solving Ax = b time taken:  0.00044155120849609375
# epoch  40
# assembling the matrix time taken:  0.00022482872009277344
# solving Ax = b time taken:  0.0005018711090087891
# epoch  41
# assembling the matrix time taken:  0.00027632713317871094
# solving Ax = b time taken:  0.0005052089691162109
# epoch  42
# assembling the matrix time taken:  0.0002181529998779297
# solving Ax = b time taken:  0.0004818439483642578
# epoch  43
# assembling the matrix time taken:  0.0002377033233642578
# solving Ax = b time taken:  0.0005295276641845703
# epoch  44
# assembling the matrix time taken:  0.00026917457580566406
# solving Ax = b time taken:  0.00047707557678222656
# epoch  45
# assembling the matrix time taken:  0.00022840499877929688
# solving Ax = b time taken:  0.0004363059997558594
# epoch  46
# assembling the matrix time taken:  0.0002467632293701172
# solving Ax = b time taken:  0.00045037269592285156
# epoch  47
# assembling the matrix time taken:  0.00022840499877929688
# solving Ax = b time taken:  0.0004723072052001953
# epoch  48
# assembling the matrix time taken:  0.0002601146697998047
# solving Ax = b time taken:  0.00043892860412597656
# epoch  49
# assembling the matrix time taken:  0.00027370452880859375
# solving Ax = b time taken:  0.0006253719329833984
# epoch  50
# assembling the matrix time taken:  0.00022935867309570312
# solving Ax = b time taken:  0.0006644725799560547
# epoch  51
# assembling the matrix time taken:  0.0002963542938232422
# solving Ax = b time taken:  0.0006124973297119141
# epoch  52
# assembling the matrix time taken:  0.00027823448181152344
# solving Ax = b time taken:  0.0006148815155029297
# epoch  53
# assembling the matrix time taken:  0.00024437904357910156
# solving Ax = b time taken:  0.0006728172302246094
# epoch  54
# assembling the matrix time taken:  0.00023031234741210938
# solving Ax = b time taken:  0.0006859302520751953
# epoch  55
# assembling the matrix time taken:  0.0002410411834716797
# solving Ax = b time taken:  0.0006833076477050781
# epoch  56
# assembling the matrix time taken:  0.0002846717834472656
# solving Ax = b time taken:  0.0006201267242431641
# epoch  57
# assembling the matrix time taken:  0.0002799034118652344
# solving Ax = b time taken:  0.0006585121154785156
# epoch  58
# assembling the matrix time taken:  0.0002868175506591797
# solving Ax = b time taken:  0.0006604194641113281
# epoch  59
# assembling the matrix time taken:  0.000286102294921875
# solving Ax = b time taken:  0.0006568431854248047
# epoch  60
# assembling the matrix time taken:  0.00025963783264160156
# solving Ax = b time taken:  0.0006668567657470703
# epoch  61
# assembling the matrix time taken:  0.0002613067626953125
# solving Ax = b time taken:  0.0006856918334960938
# epoch  62
# assembling the matrix time taken:  0.0002677440643310547
# solving Ax = b time taken:  0.0006809234619140625
# epoch  63
# assembling the matrix time taken:  0.00024247169494628906
# solving Ax = b time taken:  0.0007116794586181641
# epoch  64
# assembling the matrix time taken:  0.0002739429473876953
# solving Ax = b time taken:  0.0006966590881347656
# epoch  65
# assembling the matrix time taken:  0.0002701282501220703
# solving Ax = b time taken:  0.0016856193542480469
# epoch  66
# assembling the matrix time taken:  0.00023031234741210938
# solving Ax = b time taken:  0.0017614364624023438
# epoch  67
# assembling the matrix time taken:  0.00023889541625976562
# solving Ax = b time taken:  0.0016427040100097656
# epoch  68
# assembling the matrix time taken:  0.00023102760314941406
# solving Ax = b time taken:  0.0016591548919677734
# epoch  69
# assembling the matrix time taken:  0.00022554397583007812
# solving Ax = b time taken:  0.0016837120056152344
# epoch  70
# assembling the matrix time taken:  0.0002505779266357422
# solving Ax = b time taken:  0.0016760826110839844
# epoch  71
# assembling the matrix time taken:  0.00021958351135253906
# solving Ax = b time taken:  0.0017063617706298828
# epoch  72
# assembling the matrix time taken:  0.0002586841583251953
# solving Ax = b time taken:  0.0016405582427978516
# epoch  73
# assembling the matrix time taken:  0.0002262592315673828
# solving Ax = b time taken:  0.001726388931274414
# epoch  74
# assembling the matrix time taken:  0.00025916099548339844
# solving Ax = b time taken:  0.0016646385192871094
# epoch  75
# assembling the matrix time taken:  0.00022983551025390625
# solving Ax = b time taken:  0.00170135498046875
# epoch  76
# assembling the matrix time taken:  0.0002384185791015625
# solving Ax = b time taken:  0.0017070770263671875
# epoch  77
# assembling the matrix time taken:  0.00023984909057617188
# solving Ax = b time taken:  0.0017056465148925781
# epoch  78
# assembling the matrix time taken:  0.00023651123046875
# solving Ax = b time taken:  0.0017495155334472656
# epoch  79
# assembling the matrix time taken:  0.0007777214050292969
# solving Ax = b time taken:  0.0009734630584716797
# epoch  80
# assembling the matrix time taken:  0.00023937225341796875
# solving Ax = b time taken:  0.0016999244689941406
# epoch  81
# assembling the matrix time taken:  0.0002510547637939453
# solving Ax = b time taken:  0.0017828941345214844
# epoch  82
# assembling the matrix time taken:  0.00026607513427734375
# solving Ax = b time taken:  0.001699686050415039
# epoch  83
# assembling the matrix time taken:  0.0002658367156982422
# solving Ax = b time taken:  0.0017571449279785156
# epoch  84
# assembling the matrix time taken:  0.0002415180206298828
# solving Ax = b time taken:  0.0017688274383544922
# epoch  85
# assembling the matrix time taken:  0.00024580955505371094
# solving Ax = b time taken:  0.0018074512481689453
# epoch  86
# assembling the matrix time taken:  0.0002694129943847656
# solving Ax = b time taken:  0.0017828941345214844
# epoch  87
# assembling the matrix time taken:  0.00022292137145996094
# solving Ax = b time taken:  0.0018153190612792969
# epoch  88
# assembling the matrix time taken:  0.00025963783264160156
# solving Ax = b time taken:  0.0017936229705810547
# epoch  89
# assembling the matrix time taken:  0.00028204917907714844
# solving Ax = b time taken:  0.001798868179321289
# epoch  90
# assembling the matrix time taken:  0.00022530555725097656
# solving Ax = b time taken:  0.0017855167388916016
# epoch  91
# assembling the matrix time taken:  0.00024509429931640625
# solving Ax = b time taken:  0.0018455982208251953
# epoch  92
# assembling the matrix time taken:  0.0002639293670654297
# solving Ax = b time taken:  0.001833200454711914
# epoch  93
# assembling the matrix time taken:  0.0002276897430419922
# solving Ax = b time taken:  0.0018689632415771484
# epoch  94
# assembling the matrix time taken:  0.00022840499877929688
# solving Ax = b time taken:  0.0018563270568847656
# epoch  95
# assembling the matrix time taken:  0.00022840499877929688
# solving Ax = b time taken:  0.0018723011016845703
# epoch  96
# assembling the matrix time taken:  0.0002536773681640625
# solving Ax = b time taken:  0.0017843246459960938
# epoch  97
# assembling the matrix time taken:  0.0002608299255371094
# solving Ax = b time taken:  0.0018193721771240234
# epoch  98
# assembling the matrix time taken:  0.0002579689025878906
# solving Ax = b time taken:  0.0018236637115478516
# epoch  99
# assembling the matrix time taken:  0.00025725364685058594
# solving Ax = b time taken:  0.0018475055694580078
# epoch  100
# assembling the matrix time taken:  0.0002758502960205078
# solving Ax = b time taken:  0.0017852783203125
# epoch  101
# assembling the matrix time taken:  0.0002200603485107422
# solving Ax = b time taken:  0.0018744468688964844
# epoch  102
# assembling the matrix time taken:  0.0002472400665283203
# solving Ax = b time taken:  0.0018591880798339844
# epoch  103
# assembling the matrix time taken:  0.0002472400665283203
# solving Ax = b time taken:  0.00189971923828125
# epoch  104
# assembling the matrix time taken:  0.00025916099548339844
# solving Ax = b time taken:  0.0018801689147949219
# epoch  105
# assembling the matrix time taken:  0.0002682209014892578
# solving Ax = b time taken:  0.0018613338470458984
# epoch  106
# assembling the matrix time taken:  0.0002677440643310547
# solving Ax = b time taken:  0.0019135475158691406
# epoch  107
# assembling the matrix time taken:  0.00022172927856445312
# solving Ax = b time taken:  0.0019474029541015625
# epoch  108
# assembling the matrix time taken:  0.00023794174194335938
# solving Ax = b time taken:  0.00189208984375
# epoch  109
# assembling the matrix time taken:  0.0002758502960205078
# solving Ax = b time taken:  0.0019006729125976562
# epoch  110
# assembling the matrix time taken:  0.0002694129943847656
# solving Ax = b time taken:  0.001951456069946289
# epoch  111
# assembling the matrix time taken:  0.0002205371856689453
# solving Ax = b time taken:  0.0019681453704833984
# epoch  112
# assembling the matrix time taken:  0.00024890899658203125
# solving Ax = b time taken:  0.0019338130950927734
# epoch  113
# assembling the matrix time taken:  0.000225067138671875
# solving Ax = b time taken:  0.001995086669921875
# epoch  114
# assembling the matrix time taken:  0.00024318695068359375
# solving Ax = b time taken:  0.0019752979278564453
# epoch  115
# assembling the matrix time taken:  0.00027108192443847656
# solving Ax = b time taken:  0.0019674301147460938
# epoch  116
# assembling the matrix time taken:  0.0002758502960205078
# solving Ax = b time taken:  0.001905202865600586
# epoch  117
# assembling the matrix time taken:  0.0002498626708984375
# solving Ax = b time taken:  0.0019397735595703125
# epoch  118
# assembling the matrix time taken:  0.000247955322265625
# solving Ax = b time taken:  0.0019419193267822266
# epoch  119
# assembling the matrix time taken:  0.0002377033233642578
# solving Ax = b time taken:  0.001960277557373047
# epoch  120
# assembling the matrix time taken:  0.00023031234741210938
# solving Ax = b time taken:  0.0019314289093017578
# epoch  121
# assembling the matrix time taken:  0.000274658203125
# solving Ax = b time taken:  0.001997232437133789
# epoch  122
# assembling the matrix time taken:  0.00022482872009277344
# solving Ax = b time taken:  0.002042531967163086
# epoch  123
# assembling the matrix time taken:  0.00025343894958496094
# solving Ax = b time taken:  0.002027750015258789
# epoch  124
# assembling the matrix time taken:  0.0002536773681640625
# solving Ax = b time taken:  0.001966714859008789
# epoch  125
# assembling the matrix time taken:  0.0002238750457763672
# solving Ax = b time taken:  0.0020599365234375
# epoch  126
# assembling the matrix time taken:  0.0002751350402832031
# solving Ax = b time taken:  0.002022981643676758
# epoch  127
# assembling the matrix time taken:  0.00022482872009277344
# solving Ax = b time taken:  0.0020751953125
# epoch  128
# assembling the matrix time taken:  0.0002448558807373047
# solving Ax = b time taken:  0.002027750015258789
# epoch  129
# assembling the matrix time taken:  0.00027632713317871094
# solving Ax = b time taken:  0.0032067298889160156
# epoch  130
# assembling the matrix time taken:  0.0002541542053222656
# solving Ax = b time taken:  0.003232717514038086
# epoch  131
# assembling the matrix time taken:  0.0002918243408203125
# solving Ax = b time taken:  0.003235340118408203
# epoch  132
# assembling the matrix time taken:  0.00027370452880859375
# solving Ax = b time taken:  0.003183126449584961
# epoch  133
# assembling the matrix time taken:  0.00026416778564453125
# solving Ax = b time taken:  0.003268003463745117
# epoch  134
# assembling the matrix time taken:  0.00028395652770996094
# solving Ax = b time taken:  0.0032224655151367188
# epoch  135
# assembling the matrix time taken:  0.00023555755615234375
# solving Ax = b time taken:  0.0032320022583007812
# epoch  136
# assembling the matrix time taken:  0.00024700164794921875
# solving Ax = b time taken:  0.003215789794921875
# epoch  137
# assembling the matrix time taken:  0.00027370452880859375
# solving Ax = b time taken:  0.0032498836517333984
# epoch  138
# assembling the matrix time taken:  0.0002846717834472656
# solving Ax = b time taken:  0.0031893253326416016
# epoch  139
# assembling the matrix time taken:  0.0002536773681640625
# solving Ax = b time taken:  0.003309965133666992
# epoch  140
# assembling the matrix time taken:  0.0002598762512207031
# solving Ax = b time taken:  0.0032753944396972656
# epoch  141
# assembling the matrix time taken:  0.0002925395965576172
# solving Ax = b time taken:  0.0032587051391601562
# epoch  142
# assembling the matrix time taken:  0.000232696533203125
# solving Ax = b time taken:  0.003340005874633789
# epoch  143
# assembling the matrix time taken:  0.00022602081298828125
# solving Ax = b time taken:  0.0033011436462402344
# epoch  144
# assembling the matrix time taken:  0.00025844573974609375
# solving Ax = b time taken:  0.003256082534790039
# epoch  145
# assembling the matrix time taken:  0.00023508071899414062
# solving Ax = b time taken:  0.0033605098724365234
# epoch  146
# assembling the matrix time taken:  0.0002377033233642578
# solving Ax = b time taken:  0.0033278465270996094
# epoch  147
# assembling the matrix time taken:  0.00022268295288085938
# solving Ax = b time taken:  0.0033905506134033203
# epoch  148
# assembling the matrix time taken:  0.00022983551025390625
# solving Ax = b time taken:  0.0033500194549560547
# epoch  149
# assembling the matrix time taken:  0.00028324127197265625
# solving Ax = b time taken:  0.003314495086669922
# epoch  150
# assembling the matrix time taken:  0.0002486705780029297
# solving Ax = b time taken:  0.0033540725708007812
# epoch  151
# assembling the matrix time taken:  0.00028324127197265625
# solving Ax = b time taken:  0.003315448760986328
# epoch  152
# assembling the matrix time taken:  0.0002703666687011719
# solving Ax = b time taken:  0.0033507347106933594
# epoch  153
# assembling the matrix time taken:  0.0002658367156982422
# solving Ax = b time taken:  0.003420114517211914
# epoch  154
# assembling the matrix time taken:  0.00023865699768066406
# solving Ax = b time taken:  0.003396749496459961
# epoch  155
# assembling the matrix time taken:  0.00022792816162109375
# solving Ax = b time taken:  0.00341796875
# epoch  156
# assembling the matrix time taken:  0.00022745132446289062
# solving Ax = b time taken:  0.0034265518188476562
# epoch  157
# assembling the matrix time taken:  0.00024628639221191406
# solving Ax = b time taken:  0.0034186840057373047
# epoch  158
# assembling the matrix time taken:  0.0002377033233642578
# solving Ax = b time taken:  0.003438234329223633
# epoch  159
# assembling the matrix time taken:  0.0002510547637939453
# solving Ax = b time taken:  0.003415822982788086
# epoch  160
# assembling the matrix time taken:  0.00026535987854003906
# solving Ax = b time taken:  0.0033903121948242188
# epoch  161
# assembling the matrix time taken:  0.0002315044403076172
# solving Ax = b time taken:  0.0034694671630859375
# epoch  162
# assembling the matrix time taken:  0.00022459030151367188
# solving Ax = b time taken:  0.003488779067993164
# epoch  163
# assembling the matrix time taken:  0.00022721290588378906
# solving Ax = b time taken:  0.0034973621368408203
# epoch  164
# assembling the matrix time taken:  0.0002422332763671875
# solving Ax = b time taken:  0.0034704208374023438
# epoch  165
# assembling the matrix time taken:  0.00022339820861816406
# solving Ax = b time taken:  0.0035076141357421875
# epoch  166
# assembling the matrix time taken:  0.00022673606872558594
# solving Ax = b time taken:  0.003497600555419922
# epoch  167
# assembling the matrix time taken:  0.000286102294921875
# solving Ax = b time taken:  0.0034716129302978516
# epoch  168
# assembling the matrix time taken:  0.0002422332763671875
# solving Ax = b time taken:  0.0034749507904052734
# epoch  169
# assembling the matrix time taken:  0.00026535987854003906
# solving Ax = b time taken:  0.0034797191619873047
# epoch  170
# assembling the matrix time taken:  0.00024247169494628906
# solving Ax = b time taken:  0.003485441207885742
# epoch  171
# assembling the matrix time taken:  0.0002715587615966797
# solving Ax = b time taken:  0.0034847259521484375
# epoch  172
# assembling the matrix time taken:  0.0002810955047607422
# solving Ax = b time taken:  0.003476858139038086
# epoch  173
# assembling the matrix time taken:  0.00022172927856445312
# solving Ax = b time taken:  0.003548860549926758
# epoch  174
# assembling the matrix time taken:  0.00024390220642089844
# solving Ax = b time taken:  0.0035448074340820312
# epoch  175
# assembling the matrix time taken:  0.00023627281188964844
# solving Ax = b time taken:  0.0035228729248046875
# epoch  176
# assembling the matrix time taken:  0.00022912025451660156
# solving Ax = b time taken:  0.003534555435180664
# epoch  177
# assembling the matrix time taken:  0.0002541542053222656
# solving Ax = b time taken:  0.003571033477783203
# epoch  178
# assembling the matrix time taken:  0.00027179718017578125
# solving Ax = b time taken:  0.003572702407836914
# epoch  179
# assembling the matrix time taken:  0.00023174285888671875
# solving Ax = b time taken:  0.0036072731018066406
# epoch  180
# assembling the matrix time taken:  0.00025725364685058594
# solving Ax = b time taken:  0.0035855770111083984
# epoch  181
# assembling the matrix time taken:  0.00024509429931640625
# solving Ax = b time taken:  0.003610372543334961
# epoch  182
# assembling the matrix time taken:  0.00025844573974609375
# solving Ax = b time taken:  0.0035858154296875
# epoch  183
# assembling the matrix time taken:  0.00022220611572265625
# solving Ax = b time taken:  0.003610849380493164
# epoch  184
# assembling the matrix time taken:  0.0002701282501220703
# solving Ax = b time taken:  0.0035643577575683594
# epoch  185
# assembling the matrix time taken:  0.0007243156433105469
# solving Ax = b time taken:  0.0030977725982666016
# epoch  186
# assembling the matrix time taken:  0.0002231597900390625
# solving Ax = b time taken:  0.0036356449127197266
# epoch  187
# assembling the matrix time taken:  0.0002281665802001953
# solving Ax = b time taken:  0.0036356449127197266
# epoch  188
# assembling the matrix time taken:  0.0002548694610595703
# solving Ax = b time taken:  0.003609180450439453
# epoch  189
# assembling the matrix time taken:  0.0002696514129638672
# solving Ax = b time taken:  0.0036444664001464844
# epoch  190
# assembling the matrix time taken:  0.00023484230041503906
# solving Ax = b time taken:  0.0036575794219970703
# epoch  191
# assembling the matrix time taken:  0.00023889541625976562
# solving Ax = b time taken:  0.003644704818725586
# epoch  192
# assembling the matrix time taken:  0.00024771690368652344
# solving Ax = b time taken:  0.003650188446044922
# epoch  193
# assembling the matrix time taken:  0.00022792816162109375
# solving Ax = b time taken:  0.0054473876953125
# epoch  194
# assembling the matrix time taken:  0.00023937225341796875
# solving Ax = b time taken:  0.00544428825378418
# epoch  195
# assembling the matrix time taken:  0.00024962425231933594
# solving Ax = b time taken:  0.005454540252685547
# epoch  196
# assembling the matrix time taken:  0.00023055076599121094
# solving Ax = b time taken:  0.005446434020996094
# epoch  197
# assembling the matrix time taken:  0.00022721290588378906
# solving Ax = b time taken:  0.005475759506225586
# epoch  198
# assembling the matrix time taken:  0.00022363662719726562
# solving Ax = b time taken:  0.005471944808959961
# epoch  199
# assembling the matrix time taken:  0.00022673606872558594
# solving Ax = b time taken:  0.005453586578369141
# epoch  200
# assembling the matrix time taken:  0.00025200843811035156
# solving Ax = b time taken:  0.0054438114166259766
# epoch  201
# assembling the matrix time taken:  0.00023412704467773438
# solving Ax = b time taken:  0.005490541458129883
# epoch  202
# assembling the matrix time taken:  0.00038504600524902344
# solving Ax = b time taken:  0.005356550216674805
# epoch  203
# assembling the matrix time taken:  0.00022149085998535156
# solving Ax = b time taken:  0.005521297454833984
# epoch  204
# assembling the matrix time taken:  0.0002238750457763672
# solving Ax = b time taken:  0.005499124526977539
# epoch  205
# assembling the matrix time taken:  0.00023293495178222656
# solving Ax = b time taken:  0.005513191223144531
# epoch  206
# assembling the matrix time taken:  0.000270843505859375
# solving Ax = b time taken:  0.005507707595825195
# epoch  207
# assembling the matrix time taken:  0.00022983551025390625
# solving Ax = b time taken:  0.00554203987121582
# epoch  208
# assembling the matrix time taken:  0.00029087066650390625
# solving Ax = b time taken:  0.005429744720458984
# epoch  209
# assembling the matrix time taken:  0.00023365020751953125
# solving Ax = b time taken:  0.005547046661376953
# epoch  210
# assembling the matrix time taken:  0.0002353191375732422
# solving Ax = b time taken:  0.005570411682128906
# epoch  211
# assembling the matrix time taken:  0.00022292137145996094
# solving Ax = b time taken:  0.005602121353149414
# epoch  212
# assembling the matrix time taken:  0.00023031234741210938
# solving Ax = b time taken:  0.005545139312744141
# epoch  213
# assembling the matrix time taken:  0.0002231597900390625
# solving Ax = b time taken:  0.00558781623840332
# epoch  214
# assembling the matrix time taken:  0.00022912025451660156
# solving Ax = b time taken:  0.005585432052612305
# epoch  215
# assembling the matrix time taken:  0.00022292137145996094
# solving Ax = b time taken:  0.005613088607788086
# epoch  216
# assembling the matrix time taken:  0.0002522468566894531
# solving Ax = b time taken:  0.005560636520385742
# epoch  217
# assembling the matrix time taken:  0.00026607513427734375
# solving Ax = b time taken:  0.005576372146606445
# epoch  218
# assembling the matrix time taken:  0.0002808570861816406
# solving Ax = b time taken:  0.005558967590332031
# epoch  219
# assembling the matrix time taken:  0.00028204917907714844
# solving Ax = b time taken:  0.005554914474487305
# epoch  220
# assembling the matrix time taken:  0.0002689361572265625
# solving Ax = b time taken:  0.005604267120361328
# epoch  221
# assembling the matrix time taken:  0.00028824806213378906
# solving Ax = b time taken:  0.005598306655883789
# epoch  222
# assembling the matrix time taken:  0.00023508071899414062
# solving Ax = b time taken:  0.005635261535644531
# epoch  223
# assembling the matrix time taken:  0.00024366378784179688
# solving Ax = b time taken:  0.005631208419799805
# epoch  224
# assembling the matrix time taken:  0.0002567768096923828
# solving Ax = b time taken:  0.00558018684387207
# epoch  225
# assembling the matrix time taken:  0.0002377033233642578
# solving Ax = b time taken:  0.005669116973876953
# epoch  226
# assembling the matrix time taken:  0.00022983551025390625
# solving Ax = b time taken:  0.005697488784790039
# epoch  227
# assembling the matrix time taken:  0.00023794174194335938
# solving Ax = b time taken:  0.005678892135620117
# epoch  228
# assembling the matrix time taken:  0.00022363662719726562
# solving Ax = b time taken:  0.005694389343261719
# epoch  229
# assembling the matrix time taken:  0.0002753734588623047
# solving Ax = b time taken:  0.005660295486450195
# epoch  230
# assembling the matrix time taken:  0.000240325927734375
# solving Ax = b time taken:  0.005696773529052734
# epoch  231
# assembling the matrix time taken:  0.00023746490478515625
# solving Ax = b time taken:  0.005706310272216797
# epoch  232
# assembling the matrix time taken:  0.000247955322265625
# solving Ax = b time taken:  0.005703449249267578
# epoch  233
# assembling the matrix time taken:  0.00022935867309570312
# solving Ax = b time taken:  0.005736351013183594
# epoch  234
# assembling the matrix time taken:  0.00026416778564453125
# solving Ax = b time taken:  0.0057430267333984375
# epoch  235
# assembling the matrix time taken:  0.00026297569274902344
# solving Ax = b time taken:  0.005713462829589844
# epoch  236
# assembling the matrix time taken:  0.00025177001953125
# solving Ax = b time taken:  0.0056917667388916016
# epoch  237
# assembling the matrix time taken:  0.0002694129943847656
# solving Ax = b time taken:  0.005699872970581055
# epoch  238
# assembling the matrix time taken:  0.0002562999725341797
# solving Ax = b time taken:  0.005744457244873047
# epoch  239
# assembling the matrix time taken:  0.0002589225769042969
# solving Ax = b time taken:  0.005755424499511719
# epoch  240
# assembling the matrix time taken:  0.0002624988555908203
# solving Ax = b time taken:  0.005716085433959961
# epoch  241
# assembling the matrix time taken:  0.00023293495178222656
# solving Ax = b time taken:  0.00579071044921875
# epoch  242
# assembling the matrix time taken:  0.00023365020751953125
# solving Ax = b time taken:  0.0058095455169677734
# epoch  243
# assembling the matrix time taken:  0.00022172927856445312
# solving Ax = b time taken:  0.00582122802734375
# epoch  244
# assembling the matrix time taken:  0.00023484230041503906
# solving Ax = b time taken:  0.00636601448059082
# epoch  245
# assembling the matrix time taken:  0.0002503395080566406
# solving Ax = b time taken:  0.005807638168334961
# epoch  246
# assembling the matrix time taken:  0.0002448558807373047
# solving Ax = b time taken:  0.005817413330078125
# epoch  247
# assembling the matrix time taken:  0.00026488304138183594
# solving Ax = b time taken:  0.005814075469970703
# epoch  248
# assembling the matrix time taken:  0.00022077560424804688
# solving Ax = b time taken:  0.005814552307128906
# epoch  249
# assembling the matrix time taken:  0.0002791881561279297
# solving Ax = b time taken:  0.0057446956634521484
# epoch  250
# assembling the matrix time taken:  0.0002548694610595703
# solving Ax = b time taken:  0.0058248043060302734
# epoch  251
# assembling the matrix time taken:  0.0002455711364746094
# solving Ax = b time taken:  0.005859851837158203
# epoch  252
# assembling the matrix time taken:  0.00024366378784179688
# solving Ax = b time taken:  0.005833148956298828
# epoch  253
# assembling the matrix time taken:  0.00022172927856445312
# solving Ax = b time taken:  0.005864858627319336
# epoch  254
# assembling the matrix time taken:  0.0002605915069580078
# solving Ax = b time taken:  0.005840778350830078
# epoch  255
# assembling the matrix time taken:  0.0002834796905517578
# solving Ax = b time taken:  0.005812168121337891
# epoch  256
# assembling the matrix time taken:  0.0002281665802001953
# solving Ax = b time taken:  0.0058443546295166016
# epoch  257
# assembling the matrix time taken:  0.00022220611572265625
# solving Ax = b time taken:  0.008400201797485352
# epoch  258
# assembling the matrix time taken:  0.00022602081298828125
# solving Ax = b time taken:  0.008429527282714844
# epoch  259
# assembling the matrix time taken:  0.00029349327087402344
# solving Ax = b time taken:  0.008386373519897461
# epoch  260
# assembling the matrix time taken:  0.0002989768981933594
# solving Ax = b time taken:  0.008355379104614258
# epoch  261
# assembling the matrix time taken:  0.000255584716796875
# solving Ax = b time taken:  0.008434534072875977
# epoch  262
# assembling the matrix time taken:  0.0002574920654296875
# solving Ax = b time taken:  0.008427858352661133
# epoch  263
# assembling the matrix time taken:  0.00023126602172851562
# solving Ax = b time taken:  0.008475065231323242
# epoch  264
# assembling the matrix time taken:  0.0002651214599609375
# solving Ax = b time taken:  0.008427619934082031
# epoch  265
# assembling the matrix time taken:  0.00024890899658203125
# solving Ax = b time taken:  0.008488893508911133
# epoch  266
# assembling the matrix time taken:  0.00029015541076660156
# solving Ax = b time taken:  0.008431434631347656
# epoch  267
# assembling the matrix time taken:  0.00026988983154296875
# solving Ax = b time taken:  0.008463621139526367
# epoch  268
# assembling the matrix time taken:  0.00024771690368652344
# solving Ax = b time taken:  0.008509159088134766
# epoch  269
# assembling the matrix time taken:  0.0002193450927734375
# solving Ax = b time taken:  0.00856328010559082
# epoch  270
# assembling the matrix time taken:  0.00024390220642089844
# solving Ax = b time taken:  0.0085296630859375
# epoch  271
# assembling the matrix time taken:  0.000293731689453125
# solving Ax = b time taken:  0.00849294662475586
# epoch  272
# assembling the matrix time taken:  0.0002791881561279297
# solving Ax = b time taken:  0.008489131927490234
# epoch  273
# assembling the matrix time taken:  0.0002601146697998047
# solving Ax = b time taken:  0.008643150329589844
# epoch  274
# assembling the matrix time taken:  0.00025725364685058594
# solving Ax = b time taken:  0.008638858795166016
# epoch  275
# assembling the matrix time taken:  0.00024437904357910156
# solving Ax = b time taken:  0.008679866790771484
# epoch  276
# assembling the matrix time taken:  0.00028061866760253906
# solving Ax = b time taken:  0.008638620376586914
# epoch  277
# assembling the matrix time taken:  0.0002446174621582031
# solving Ax = b time taken:  0.008687019348144531
# epoch  278
# assembling the matrix time taken:  0.00024366378784179688
# solving Ax = b time taken:  0.008694171905517578
# epoch  279
# assembling the matrix time taken:  0.00022292137145996094
# solving Ax = b time taken:  0.008699178695678711
# epoch  280
# assembling the matrix time taken:  0.0002570152282714844
# solving Ax = b time taken:  0.008707046508789062
# epoch  281
# assembling the matrix time taken:  0.0002582073211669922
# solving Ax = b time taken:  0.008697509765625
# epoch  282
# assembling the matrix time taken:  0.0002574920654296875
# solving Ax = b time taken:  0.008682012557983398
# epoch  283
# assembling the matrix time taken:  0.00022864341735839844
# solving Ax = b time taken:  0.008728265762329102
# epoch  284
# assembling the matrix time taken:  0.00022673606872558594
# solving Ax = b time taken:  0.008733272552490234
# epoch  285
# assembling the matrix time taken:  0.00028777122497558594
# solving Ax = b time taken:  0.008696317672729492
# epoch  286
# assembling the matrix time taken:  0.00030040740966796875
# solving Ax = b time taken:  0.008687257766723633
# epoch  287
# assembling the matrix time taken:  0.00022220611572265625
# solving Ax = b time taken:  0.00876164436340332
# epoch  288
# assembling the matrix time taken:  0.00021600723266601562
# solving Ax = b time taken:  0.008707046508789062
# epoch  289
# assembling the matrix time taken:  0.00022363662719726562
# solving Ax = b time taken:  0.008819341659545898
# epoch  290
# assembling the matrix time taken:  0.0002593994140625
# solving Ax = b time taken:  0.008774280548095703
# epoch  291
# assembling the matrix time taken:  0.00024890899658203125
# solving Ax = b time taken:  0.008791685104370117
# epoch  292
# assembling the matrix time taken:  0.00022983551025390625
# solving Ax = b time taken:  0.008828401565551758
# epoch  293
# assembling the matrix time taken:  0.00024175643920898438
# solving Ax = b time taken:  0.008828163146972656
# epoch  294
# assembling the matrix time taken:  0.00023174285888671875
# solving Ax = b time taken:  0.008832216262817383
# epoch  295
# assembling the matrix time taken:  0.00024771690368652344
# solving Ax = b time taken:  0.008819103240966797
# epoch  296
# assembling the matrix time taken:  0.00025010108947753906
# solving Ax = b time taken:  0.008814573287963867
# epoch  297
# assembling the matrix time taken:  0.0002281665802001953
# solving Ax = b time taken:  0.008834123611450195
# epoch  298
# assembling the matrix time taken:  0.0002529621124267578
# solving Ax = b time taken:  0.008837461471557617
# epoch  299
# assembling the matrix time taken:  0.00022459030151367188
# solving Ax = b time taken:  0.008861780166625977
# epoch  300
# assembling the matrix time taken:  0.00023937225341796875
# solving Ax = b time taken:  0.008829116821289062
# epoch  301
# assembling the matrix time taken:  0.00022745132446289062
# solving Ax = b time taken:  0.008862018585205078
# epoch  302
# assembling the matrix time taken:  0.0002682209014892578
# solving Ax = b time taken:  0.008849620819091797
# epoch  303
# assembling the matrix time taken:  0.0002338886260986328
# solving Ax = b time taken:  0.00889277458190918
# epoch  304
# assembling the matrix time taken:  0.00021886825561523438
# solving Ax = b time taken:  0.008845090866088867
# epoch  305
# assembling the matrix time taken:  0.00022220611572265625
# solving Ax = b time taken:  0.008939027786254883
# epoch  306
# assembling the matrix time taken:  0.000244140625
# solving Ax = b time taken:  0.008938312530517578
# epoch  307
# assembling the matrix time taken:  0.00022292137145996094
# solving Ax = b time taken:  0.008941411972045898
# epoch  308
# assembling the matrix time taken:  0.00025844573974609375
# solving Ax = b time taken:  0.008938312530517578
# epoch  309
# assembling the matrix time taken:  0.0002353191375732422
# solving Ax = b time taken:  0.008993148803710938
# epoch  310
# assembling the matrix time taken:  0.0002562999725341797
# solving Ax = b time taken:  0.008949995040893555
# epoch  311
# assembling the matrix time taken:  0.0002384185791015625
# solving Ax = b time taken:  0.008951187133789062
# epoch  312
# assembling the matrix time taken:  0.0002460479736328125
# solving Ax = b time taken:  0.008972644805908203
# epoch  313
# assembling the matrix time taken:  0.0002884864807128906
# solving Ax = b time taken:  0.008974790573120117
# epoch  314
# assembling the matrix time taken:  0.00023627281188964844
# solving Ax = b time taken:  0.009014129638671875
# epoch  315
# assembling the matrix time taken:  0.0002460479736328125
# solving Ax = b time taken:  0.008980512619018555
# epoch  316
# assembling the matrix time taken:  0.00024390220642089844
# solving Ax = b time taken:  0.008992433547973633
# epoch  317
# assembling the matrix time taken:  0.0002739429473876953
# solving Ax = b time taken:  0.00896763801574707
# epoch  318
# assembling the matrix time taken:  0.00021839141845703125
# solving Ax = b time taken:  0.009029865264892578
# epoch  319
# assembling the matrix time taken:  0.0002875328063964844
# solving Ax = b time taken:  0.008940696716308594
# epoch  320
# assembling the matrix time taken:  0.0002994537353515625
# solving Ax = b time taken:  0.008910417556762695
# epoch  321
# assembling the matrix time taken:  0.000270843505859375
# solving Ax = b time taken:  0.011983633041381836
# epoch  322
# assembling the matrix time taken:  0.0002942085266113281
# solving Ax = b time taken:  0.011983156204223633
# epoch  323
# assembling the matrix time taken:  0.00024890899658203125
# solving Ax = b time taken:  0.012036561965942383
# epoch  324
# assembling the matrix time taken:  0.00024890899658203125
# solving Ax = b time taken:  0.012021541595458984
# epoch  325
# assembling the matrix time taken:  0.0002949237823486328
# solving Ax = b time taken:  0.011985301971435547
# epoch  326
# assembling the matrix time taken:  0.00023627281188964844
# solving Ax = b time taken:  0.012037515640258789
# epoch  327
# assembling the matrix time taken:  0.0002503395080566406
# solving Ax = b time taken:  0.012041807174682617
# epoch  328
# assembling the matrix time taken:  0.0002465248107910156
# solving Ax = b time taken:  0.012036323547363281
# epoch  329
# assembling the matrix time taken:  0.0002205371856689453
# solving Ax = b time taken:  0.012076616287231445
# epoch  330
# assembling the matrix time taken:  0.0002276897430419922
# solving Ax = b time taken:  0.012085199356079102
# epoch  331
# assembling the matrix time taken:  0.00023436546325683594
# solving Ax = b time taken:  0.012079238891601562
# epoch  332
# assembling the matrix time taken:  0.000225067138671875
# solving Ax = b time taken:  0.012083768844604492
# epoch  333
# assembling the matrix time taken:  0.0002956390380859375
# solving Ax = b time taken:  0.012066364288330078
# epoch  334
# assembling the matrix time taken:  0.0002560615539550781
# solving Ax = b time taken:  0.012093782424926758
# epoch  335
# assembling the matrix time taken:  0.0002486705780029297
# solving Ax = b time taken:  0.012072086334228516
# epoch  336
# assembling the matrix time taken:  0.00024890899658203125
# solving Ax = b time taken:  0.012051105499267578
# epoch  337
# assembling the matrix time taken:  0.00026106834411621094
# solving Ax = b time taken:  0.012142658233642578
# epoch  338
# assembling the matrix time taken:  0.00022077560424804688
# solving Ax = b time taken:  0.012188911437988281
# epoch  339
# assembling the matrix time taken:  0.000278472900390625
# solving Ax = b time taken:  0.012124776840209961
# epoch  340
# assembling the matrix time taken:  0.0002295970916748047
# solving Ax = b time taken:  0.012170791625976562
# epoch  341
# assembling the matrix time taken:  0.0002880096435546875
# solving Ax = b time taken:  0.01217031478881836
# epoch  342
# assembling the matrix time taken:  0.00033736228942871094
# solving Ax = b time taken:  0.012092828750610352
# epoch  343
# assembling the matrix time taken:  0.0002262592315673828
# solving Ax = b time taken:  0.012195348739624023
# epoch  344
# assembling the matrix time taken:  0.00025844573974609375
# solving Ax = b time taken:  0.012163162231445312
# epoch  345
# assembling the matrix time taken:  0.0002200603485107422
# solving Ax = b time taken:  0.012226343154907227
# epoch  346
# assembling the matrix time taken:  0.00028514862060546875
# solving Ax = b time taken:  0.012155532836914062
# epoch  347
# assembling the matrix time taken:  0.0002384185791015625
# solving Ax = b time taken:  0.012219667434692383
# epoch  348
# assembling the matrix time taken:  0.0002529621124267578
# solving Ax = b time taken:  0.012208938598632812
# epoch  349
# assembling the matrix time taken:  0.0002467632293701172
# solving Ax = b time taken:  0.01222848892211914
# epoch  350
# assembling the matrix time taken:  0.0002338886260986328
# solving Ax = b time taken:  0.012238740921020508
# epoch  351
# assembling the matrix time taken:  0.0002486705780029297
# solving Ax = b time taken:  0.012239217758178711
# epoch  352
# assembling the matrix time taken:  0.00022554397583007812
# solving Ax = b time taken:  0.012200117111206055
# epoch  353
# assembling the matrix time taken:  0.0002567768096923828
# solving Ax = b time taken:  0.012279033660888672
# epoch  354
# assembling the matrix time taken:  0.00031065940856933594
# solving Ax = b time taken:  0.012246131896972656
# epoch  355
# assembling the matrix time taken:  0.00025343894958496094
# solving Ax = b time taken:  0.012325048446655273
# epoch  356
# assembling the matrix time taken:  0.00022745132446289062
# solving Ax = b time taken:  0.01230311393737793
# epoch  357
# assembling the matrix time taken:  0.00022459030151367188
# solving Ax = b time taken:  0.012359619140625
# epoch  358
# assembling the matrix time taken:  0.0002257823944091797
# solving Ax = b time taken:  0.012326955795288086
# epoch  359
# assembling the matrix time taken:  0.00026917457580566406
# solving Ax = b time taken:  0.012296438217163086
# epoch  360
# assembling the matrix time taken:  0.00023627281188964844
# solving Ax = b time taken:  0.012300491333007812
# epoch  361
# assembling the matrix time taken:  0.00022745132446289062
# solving Ax = b time taken:  0.012346267700195312
# epoch  362
# assembling the matrix time taken:  0.0002384185791015625
# solving Ax = b time taken:  0.012351274490356445
# epoch  363
# assembling the matrix time taken:  0.0002741813659667969
# solving Ax = b time taken:  0.012308597564697266
# epoch  364
# assembling the matrix time taken:  0.0002892017364501953
# solving Ax = b time taken:  0.012327909469604492
# epoch  365
# assembling the matrix time taken:  0.0002307891845703125
# solving Ax = b time taken:  0.012388944625854492
# epoch  366
# assembling the matrix time taken:  0.0002779960632324219
# solving Ax = b time taken:  0.012341022491455078
# epoch  367
# assembling the matrix time taken:  0.00030517578125
# solving Ax = b time taken:  0.012333393096923828
# epoch  368
# assembling the matrix time taken:  0.00023126602172851562
# solving Ax = b time taken:  0.012344598770141602
# epoch  369
# assembling the matrix time taken:  0.0002961158752441406
# solving Ax = b time taken:  0.01238393783569336
# epoch  370
# assembling the matrix time taken:  0.00024390220642089844
# solving Ax = b time taken:  0.012451171875
# epoch  371
# assembling the matrix time taken:  0.00023984909057617188
# solving Ax = b time taken:  0.012468338012695312
# epoch  372
# assembling the matrix time taken:  0.00025153160095214844
# solving Ax = b time taken:  0.012459516525268555
# epoch  373
# assembling the matrix time taken:  0.0002751350402832031
# solving Ax = b time taken:  0.012430191040039062
# epoch  374
# assembling the matrix time taken:  0.00024437904357910156
# solving Ax = b time taken:  0.012494087219238281
# epoch  375
# assembling the matrix time taken:  0.00028324127197265625
# solving Ax = b time taken:  0.012474298477172852
# epoch  376
# assembling the matrix time taken:  0.0002627372741699219
# solving Ax = b time taken:  0.012479066848754883
# epoch  377
# assembling the matrix time taken:  0.0002841949462890625
# solving Ax = b time taken:  0.012454509735107422
# epoch  378
# assembling the matrix time taken:  0.0002224445343017578
# solving Ax = b time taken:  0.012523651123046875
# epoch  379
# assembling the matrix time taken:  0.0002491474151611328
# solving Ax = b time taken:  0.012513875961303711
# epoch  380
# assembling the matrix time taken:  0.00027441978454589844
# solving Ax = b time taken:  0.01247549057006836
# epoch  381
# assembling the matrix time taken:  0.00023674964904785156
# solving Ax = b time taken:  0.012543678283691406
# epoch  382
# assembling the matrix time taken:  0.0002696514129638672
# solving Ax = b time taken:  0.012512922286987305
# epoch  383
# assembling the matrix time taken:  0.0002808570861816406
# solving Ax = b time taken:  0.012451171875
# epoch  384
# assembling the matrix time taken:  0.0002510547637939453
# solving Ax = b time taken:  0.012499809265136719
# epoch  385
# assembling the matrix time taken:  0.000278472900390625
# solving Ax = b time taken:  0.016071557998657227
# epoch  386
# assembling the matrix time taken:  0.0002510547637939453
# solving Ax = b time taken:  0.016075611114501953
# epoch  387
# assembling the matrix time taken:  0.0002377033233642578
# solving Ax = b time taken:  0.016121387481689453
# epoch  388
# assembling the matrix time taken:  0.00022673606872558594
# solving Ax = b time taken:  0.016124963760375977
# epoch  389
# assembling the matrix time taken:  0.000244140625
# solving Ax = b time taken:  0.015580892562866211
# epoch  390
# assembling the matrix time taken:  0.0002713203430175781
# solving Ax = b time taken:  0.016108989715576172
# epoch  391
# assembling the matrix time taken:  0.0002491474151611328
# solving Ax = b time taken:  0.016146183013916016
# epoch  392
# assembling the matrix time taken:  0.0002841949462890625
# solving Ax = b time taken:  0.016104698181152344
# epoch  393
# assembling the matrix time taken:  0.00023126602172851562
# solving Ax = b time taken:  0.016221284866333008
# epoch  394
# assembling the matrix time taken:  0.0002472400665283203
# solving Ax = b time taken:  0.01618337631225586
# epoch  395
# assembling the matrix time taken:  0.00023412704467773438
# solving Ax = b time taken:  0.016177654266357422
# epoch  396
# assembling the matrix time taken:  0.0002205371856689453
# solving Ax = b time taken:  0.016200542449951172
# epoch  397
# assembling the matrix time taken:  0.000244140625
# solving Ax = b time taken:  0.016213417053222656
# epoch  398
# assembling the matrix time taken:  0.0002410411834716797
# solving Ax = b time taken:  0.016208887100219727
# epoch  399
# assembling the matrix time taken:  0.0002353191375732422
# solving Ax = b time taken:  0.016229629516601562
# epoch  400
# assembling the matrix time taken:  0.0002505779266357422
# solving Ax = b time taken:  0.016130685806274414
# epoch  401
# assembling the matrix time taken:  0.00024271011352539062
# solving Ax = b time taken:  0.016268491744995117
# epoch  402
# assembling the matrix time taken:  0.00022649765014648438
# solving Ax = b time taken:  0.0159757137298584
# epoch  403
# assembling the matrix time taken:  0.0002675056457519531
# solving Ax = b time taken:  0.016263723373413086
# epoch  404
# assembling the matrix time taken:  0.0002808570861816406
# solving Ax = b time taken:  0.016238689422607422
# epoch  405
# assembling the matrix time taken:  0.00024771690368652344
# solving Ax = b time taken:  0.015996932983398438
# epoch  406
# assembling the matrix time taken:  0.0002257823944091797
# solving Ax = b time taken:  0.016297101974487305
# epoch  407
# assembling the matrix time taken:  0.00022983551025390625
# solving Ax = b time taken:  0.016308069229125977
# epoch  408
# assembling the matrix time taken:  0.0002696514129638672
# solving Ax = b time taken:  0.01624274253845215
# epoch  409
# assembling the matrix time taken:  0.00028443336486816406
# solving Ax = b time taken:  0.016265869140625
# epoch  410
# assembling the matrix time taken:  0.0002772808074951172
# solving Ax = b time taken:  0.01629924774169922
# epoch  411
# assembling the matrix time taken:  0.0002434253692626953
# solving Ax = b time taken:  0.016323089599609375
# epoch  412
# assembling the matrix time taken:  0.00025463104248046875
# solving Ax = b time taken:  0.016310691833496094
# epoch  413
# assembling the matrix time taken:  0.00029015541076660156
# solving Ax = b time taken:  0.016001224517822266
# epoch  414
# assembling the matrix time taken:  0.0002510547637939453
# solving Ax = b time taken:  0.01631641387939453
# epoch  415
# assembling the matrix time taken:  0.0002906322479248047
# solving Ax = b time taken:  0.016300439834594727
# epoch  416
# assembling the matrix time taken:  0.00024008750915527344
# solving Ax = b time taken:  0.016303300857543945
# epoch  417
# assembling the matrix time taken:  0.0003008842468261719
# solving Ax = b time taken:  0.016028881072998047
# epoch  418
# assembling the matrix time taken:  0.0002765655517578125
# solving Ax = b time taken:  0.01638054847717285
# epoch  419
# assembling the matrix time taken:  0.00025010108947753906
# solving Ax = b time taken:  0.01642465591430664
# epoch  420
# assembling the matrix time taken:  0.0002627372741699219
# solving Ax = b time taken:  0.015825986862182617
# epoch  421
# assembling the matrix time taken:  0.0002586841583251953
# solving Ax = b time taken:  0.016419410705566406
# epoch  422
# assembling the matrix time taken:  0.0002474784851074219
# solving Ax = b time taken:  0.016439199447631836
# epoch  423
# assembling the matrix time taken:  0.0002288818359375
# solving Ax = b time taken:  0.016471385955810547
# epoch  424
# assembling the matrix time taken:  0.0002307891845703125
# solving Ax = b time taken:  0.01645660400390625
# epoch  425
# assembling the matrix time taken:  0.00022268295288085938
# solving Ax = b time taken:  0.0164947509765625
# epoch  426
# assembling the matrix time taken:  0.0002713203430175781
# solving Ax = b time taken:  0.016448020935058594
# epoch  427
# assembling the matrix time taken:  0.0002505779266357422
# solving Ax = b time taken:  0.0164797306060791
# epoch  428
# assembling the matrix time taken:  0.00026988983154296875
# solving Ax = b time taken:  0.016464710235595703
# epoch  429
# assembling the matrix time taken:  0.00023889541625976562
# solving Ax = b time taken:  0.015936613082885742
# epoch  430
# assembling the matrix time taken:  0.00025844573974609375
# solving Ax = b time taken:  0.01645827293395996
# epoch  431
# assembling the matrix time taken:  0.0002505779266357422
# solving Ax = b time taken:  0.016497135162353516
# epoch  432
# assembling the matrix time taken:  0.0002357959747314453
# solving Ax = b time taken:  0.016451597213745117
# epoch  433
# assembling the matrix time taken:  0.00023245811462402344
# solving Ax = b time taken:  0.016569852828979492
# epoch  434
# assembling the matrix time taken:  0.00023055076599121094
# solving Ax = b time taken:  0.016568660736083984
# epoch  435
# assembling the matrix time taken:  0.00027251243591308594
# solving Ax = b time taken:  0.01653766632080078
# epoch  436
# assembling the matrix time taken:  0.0002791881561279297
# solving Ax = b time taken:  0.016536712646484375
# epoch  437
# assembling the matrix time taken:  0.0002586841583251953
# solving Ax = b time taken:  0.0165557861328125
# epoch  438
# assembling the matrix time taken:  0.00023412704467773438
# solving Ax = b time taken:  0.016304731369018555
# epoch  439
# assembling the matrix time taken:  0.0002472400665283203
# solving Ax = b time taken:  0.016597270965576172
# epoch  440
# assembling the matrix time taken:  0.0002739429473876953
# solving Ax = b time taken:  0.01653742790222168
# epoch  441
# assembling the matrix time taken:  0.00023245811462402344
# solving Ax = b time taken:  0.016625642776489258
# epoch  442
# assembling the matrix time taken:  0.00022864341735839844
# solving Ax = b time taken:  0.016650676727294922
# epoch  443
# assembling the matrix time taken:  0.00027370452880859375
# solving Ax = b time taken:  0.01656055450439453
# epoch  444
# assembling the matrix time taken:  0.0002551078796386719
# solving Ax = b time taken:  0.016600370407104492
# epoch  445
# assembling the matrix time taken:  0.00026798248291015625
# solving Ax = b time taken:  0.01661849021911621
# epoch  446
# assembling the matrix time taken:  0.0002532005310058594
# solving Ax = b time taken:  0.016633272171020508
# epoch  447
# assembling the matrix time taken:  0.0002543926239013672
# solving Ax = b time taken:  0.016659259796142578
# epoch  448
# assembling the matrix time taken:  0.00022912025451660156
# solving Ax = b time taken:  0.016643762588500977
# epoch  449
# assembling the matrix time taken:  0.00024199485778808594
# solving Ax = b time taken:  0.020262956619262695
# epoch  450
# assembling the matrix time taken:  0.00025081634521484375
# solving Ax = b time taken:  0.020269155502319336
# epoch  451
# assembling the matrix time taken:  0.00029850006103515625
# solving Ax = b time taken:  0.020193099975585938
# epoch  452
# assembling the matrix time taken:  0.00024008750915527344
# solving Ax = b time taken:  0.02029132843017578
# epoch  453
# assembling the matrix time taken:  0.00024056434631347656
# solving Ax = b time taken:  0.020287275314331055
# epoch  454
# assembling the matrix time taken:  0.000225067138671875
# solving Ax = b time taken:  0.0202939510345459
# epoch  455
# assembling the matrix time taken:  0.0002875328063964844
# solving Ax = b time taken:  0.02027416229248047
# epoch  456
# assembling the matrix time taken:  0.00022220611572265625
# solving Ax = b time taken:  0.020267724990844727
# epoch  457
# assembling the matrix time taken:  0.00022530555725097656
# solving Ax = b time taken:  0.02033066749572754
# epoch  458
# assembling the matrix time taken:  0.00023651123046875
# solving Ax = b time taken:  0.020336627960205078
# epoch  459
# assembling the matrix time taken:  0.0002334117889404297
# solving Ax = b time taken:  0.0203399658203125
# epoch  460
# assembling the matrix time taken:  0.00023221969604492188
# solving Ax = b time taken:  0.020325899124145508
# epoch  461
# assembling the matrix time taken:  0.0002543926239013672
# solving Ax = b time taken:  0.02032327651977539
# epoch  462
# assembling the matrix time taken:  0.0002911090850830078
# solving Ax = b time taken:  0.020287275314331055
# epoch  463
# assembling the matrix time taken:  0.0002269744873046875
# solving Ax = b time taken:  0.02035999298095703
# epoch  464
# assembling the matrix time taken:  0.00023412704467773438
# solving Ax = b time taken:  0.020299911499023438
# epoch  465
# assembling the matrix time taken:  0.0002853870391845703
# solving Ax = b time taken:  0.020379304885864258
# epoch  466
# assembling the matrix time taken:  0.00023365020751953125
# solving Ax = b time taken:  0.02043628692626953
# epoch  467
# assembling the matrix time taken:  0.0002593994140625
# solving Ax = b time taken:  0.020420074462890625
# epoch  468
# assembling the matrix time taken:  0.0002484321594238281
# solving Ax = b time taken:  0.02042698860168457
# epoch  469
# assembling the matrix time taken:  0.0002655982971191406
# solving Ax = b time taken:  0.020427227020263672
# epoch  470
# assembling the matrix time taken:  0.0002694129943847656
# solving Ax = b time taken:  0.020431041717529297
# epoch  471
# assembling the matrix time taken:  0.0002541542053222656
# solving Ax = b time taken:  0.02047276496887207
# epoch  472
# assembling the matrix time taken:  0.0002961158752441406
# solving Ax = b time taken:  0.020392656326293945
# epoch  473
# assembling the matrix time taken:  0.00026607513427734375
# solving Ax = b time taken:  0.02046346664428711
# epoch  474
# assembling the matrix time taken:  0.00024509429931640625
# solving Ax = b time taken:  0.020479202270507812
# epoch  475
# assembling the matrix time taken:  0.000301361083984375
# solving Ax = b time taken:  0.020422935485839844
# epoch  476
# assembling the matrix time taken:  0.00022101402282714844
# solving Ax = b time taken:  0.020516395568847656
# epoch  477
# assembling the matrix time taken:  0.00023698806762695312
# solving Ax = b time taken:  0.020546674728393555
# epoch  478
# assembling the matrix time taken:  0.0002346038818359375
# solving Ax = b time taken:  0.020521163940429688
# epoch  479
# assembling the matrix time taken:  0.00022077560424804688
# solving Ax = b time taken:  0.020542383193969727
# epoch  480
# assembling the matrix time taken:  0.0002448558807373047
# solving Ax = b time taken:  0.020441532135009766
# epoch  481
# assembling the matrix time taken:  0.00027251243591308594
# solving Ax = b time taken:  0.020571470260620117
# epoch  482
# assembling the matrix time taken:  0.00022292137145996094
# solving Ax = b time taken:  0.020607471466064453
# epoch  483
# assembling the matrix time taken:  0.0002694129943847656
# solving Ax = b time taken:  0.020589113235473633
# epoch  484
# assembling the matrix time taken:  0.00022077560424804688
# solving Ax = b time taken:  0.020627737045288086
# epoch  485
# assembling the matrix time taken:  0.0008497238159179688
# solving Ax = b time taken:  0.0204164981842041
# epoch  486
# assembling the matrix time taken:  0.0002503395080566406
# solving Ax = b time taken:  0.020619869232177734
# epoch  487
# assembling the matrix time taken:  0.00027441978454589844
# solving Ax = b time taken:  0.02060723304748535
# epoch  488
# assembling the matrix time taken:  0.00025010108947753906
# solving Ax = b time taken:  0.02062392234802246
# epoch  489
# assembling the matrix time taken:  0.00023174285888671875
# solving Ax = b time taken:  0.02067852020263672
# epoch  490
# assembling the matrix time taken:  0.00027179718017578125
# solving Ax = b time taken:  0.020613670349121094
# epoch  491
# assembling the matrix time taken:  0.00023245811462402344
# solving Ax = b time taken:  0.02068018913269043
# epoch  492
# assembling the matrix time taken:  0.00023508071899414062
# solving Ax = b time taken:  0.020674943923950195
# epoch  493
# assembling the matrix time taken:  0.00030684471130371094
# solving Ax = b time taken:  0.020629405975341797
# epoch  494
# assembling the matrix time taken:  0.00026345252990722656
# solving Ax = b time taken:  0.020659446716308594
# epoch  495
# assembling the matrix time taken:  0.0002276897430419922
# solving Ax = b time taken:  0.02069830894470215
# epoch  496
# assembling the matrix time taken:  0.0002334117889404297
# solving Ax = b time taken:  0.02062821388244629
# epoch  497
# assembling the matrix time taken:  0.00024437904357910156
# solving Ax = b time taken:  0.020755290985107422
# epoch  498
# assembling the matrix time taken:  0.000244140625
# solving Ax = b time taken:  0.020737409591674805
# epoch  499
# assembling the matrix time taken:  0.0002243518829345703
# solving Ax = b time taken:  0.020806074142456055
# epoch  500
# assembling the matrix time taken:  0.00027489662170410156
# solving Ax = b time taken:  0.020735979080200195
# epoch  501
# assembling the matrix time taken:  0.00022482872009277344
# solving Ax = b time taken:  0.02080059051513672
# epoch  502
# assembling the matrix time taken:  0.00023603439331054688
# solving Ax = b time taken:  0.02078986167907715
# epoch  503
# assembling the matrix time taken:  0.0002536773681640625
# solving Ax = b time taken:  0.020796537399291992
# epoch  504
# assembling the matrix time taken:  0.0002377033233642578
# solving Ax = b time taken:  0.020802974700927734
# epoch  505
# assembling the matrix time taken:  0.00025153160095214844
# solving Ax = b time taken:  0.02081751823425293
# epoch  506
# assembling the matrix time taken:  0.0002346038818359375
# solving Ax = b time taken:  0.020843505859375
# epoch  507
# assembling the matrix time taken:  0.00027561187744140625
# solving Ax = b time taken:  0.020784378051757812
# epoch  508
# assembling the matrix time taken:  0.00029087066650390625
# solving Ax = b time taken:  0.020824909210205078
# epoch  509
# assembling the matrix time taken:  0.000225067138671875
# solving Ax = b time taken:  0.020849227905273438
# epoch  510
# assembling the matrix time taken:  0.0002548694610595703
# solving Ax = b time taken:  0.020860910415649414
# epoch  511
# assembling the matrix time taken:  0.00023293495178222656
# solving Ax = b time taken:  0.020868539810180664
# epoch  512
# assembling the matrix time taken:  0.00022554397583007812
# solving Ax = b time taken:  0.020799875259399414
# neuron num 		 error 		 order
# 4 		 0.279588 		 *
#
# 8 		 0.058859 		 2.247971
#
# 16 		 0.012308 		 2.257636
#
# 32 		 0.003151 		 1.965934
#
# 64 		 0.000807 		 1.964144
#
# 128 		 0.000227 		 1.830202
#
# 256 		 0.000047 		 2.276893
#
# 512 		 0.000012 		 1.996200
#
# neuron num  & 	 $\|u-u_n \|_{L^2}$ & 	 order $O(n^{-2.00})$  \\ \hline \hline
# 4 		 & 0.279588 &		 *  \\ \hline
#
# 8 		 &  5.886e-02 &  		 2.25 \\ \hline
#
# 16 		 &  1.231e-02 &  		 2.26 \\ \hline
#
# 32 		 &  3.151e-03 &  		 1.97 \\ \hline
#
# 64 		 &  8.075e-04 &  		 1.96 \\ \hline
#
# 128 		 &  2.271e-04 &  		 1.83 \\ \hline
#
# 256 		 &  4.686e-05 &  		 2.28 \\ \hline
#
# 512 		 &  1.174e-05 &  		 2.00 \\ \hline

# %% [markdown]
# ## Other test functions

# %%
def target(x):
    return 10 * torch.sin(x) + 40 * torch.sin(15 * x) * torch.exp(-(x )**2) \
        - 10 * torch.sin(-pi) + 40 * torch.sin(15 * (-pi)) * torch.exp(-(-pi )**2)


def target(x):
    return 10*(torch.sin(x) + torch.sin(3*x)) + 10*( \
            torch.sin(4*x) + torch.sin(9*x) + torch.sin(13*x)- torch.sin(x) - torch.sin(3*x) \
            )* torch.heaviside(x,torch.tensor([0.0]))
