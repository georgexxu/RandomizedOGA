# %%
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import time
import sys
import os 
from scipy.sparse import linalg
from pathlib import Path
if torch.cuda.is_available():  
    device = "cuda" 
else:  
    device = "cpu" 

pi = torch.tensor(np.pi,dtype=torch.float64)
torch.set_default_dtype(torch.float64)

class model(nn.Module):
    """ ReLU k shallow neural network
    Parameters: 
    input size: input dimension
    hidden_size1 : number of hidden layers 
    num_classes: output classes 
    k: degree of relu functions
    """
    def __init__(self, input_size, hidden_size1, num_classes,k = 1):
        super().__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, num_classes,bias = False)
        self.k = k 
    def forward(self, x):
        u1 = self.fc2(F.relu(self.fc1(x))**self.k)
        return u1

# %%
def PiecewiseGQ1D_weights_points(x_l,x_r,Nx, order):
    """ Output the coeffients and weights for piecewise Gauss Quadrature 
    Parameters
    ----------
    x_l : float 
    left endpoint of an interval 
    
    x_r: float
    right endpoint of an interval 
    
    integration_intervals: int
    number of subintervals for integration
    
    Returns
    -------
    coef1_expand
    
    gw_expand
    
    integration_points
    """
    x,w = np.polynomial.legendre.leggauss(order)
    gx = torch.tensor(x).to(device)
    gx = gx.view(1,-1) # row vector 
    gw = torch.tensor(w).to(device)    
    gw = gw.view(-1,1) # Column vector 
    nodes = torch.linspace(x_l,x_r,Nx+1).view(-1,1).to(device) 
    coef1 = ((nodes[1:,:] - nodes[:-1,:])/2) # n by 1  
    coef2 = ((nodes[1:,:] + nodes[:-1,:])/2) # n by 1  
    coef2_expand = coef2.expand(-1,gx.size(1)) # Expand to n by p shape, -1: keep the first dimension n , expand the 2nd dim (columns)
    integration_points = coef1@gx + coef2_expand
    integration_points = integration_points.flatten().view(-1,1) # Make it a column vector
    gw_expand = torch.tile(gw,(Nx,1)) # rows: n copies of current tensor, columns: 1 copy, no change
    # Modify coef1 to be compatible with func_values
    coef1_expand = coef1.expand(coef1.size(0),gx.size(1))    
    coef1_expand = coef1_expand.flatten().view(-1,1)

    return coef1_expand.to(device) * gw_expand.to(device), integration_points.to(device)


def minimize_linear_layer_explicit_assemble(model,target,weights, integration_points,solver="direct"):
    """
    calls the following functions (dependency): 
    1. GQ_piecewise_2D
    input: the nn model containing parameter 
    1. define the loss function  
    2. take derivative to extract the linear system A
    3. call the cg solver in scipy to solve the linear system 
    output: sol. solution of Ax = b
    """
    start_time = time.time() 
    w = model.fc1.weight.data 
    b = model.fc1.bias.data 
    basis_value_col = F.relu(integration_points @ w.t()+ b)**(model.k) 
    weighted_basis_value_col = basis_value_col * weights 
    jac = weighted_basis_value_col.t() @ basis_value_col 
     
    rhs = weighted_basis_value_col.t() @ (target(integration_points)) 
    print("assembling the matrix time taken: ", time.time()-start_time) 
    start_time = time.time()    
    if solver == "cg": 
        sol, exit_code = linalg.cg(np.array(jac.detach().cpu()),np.array(rhs.detach().cpu()),tol=1e-12)
        sol = torch.tensor(sol).view(1,-1)
    elif solver == "direct": 
#         sol = np.linalg.inv( np.array(jac.detach().cpu()) )@np.array(rhs.detach().cpu())
        sol = (torch.linalg.solve( jac.detach(), rhs.detach())).view(1,-1)
    elif solver == "ls":
        sol = (torch.linalg.lstsq(jac.detach().cpu(),rhs.detach().cpu(),driver='gelsd').solution).view(1,-1)
        # sol = (torch.linalg.lstsq(jac.detach(),rhs.detach()).solution).view(1,-1) # gpu/cpu, driver = 'gels', cannot solve singular
    print("solving Ax = b time taken: ", time.time()-start_time)
    return sol 


def plot_solution_modified(r1,r2,model,x_test,u_true,name=None): 
    # Plot function: test results 
    u_model_cpu = model(x_test).cpu().detach()
    
    w = model.fc1.weight.data.squeeze()
    b = model.fc1.bias.data.squeeze()
    x_model_pt = (-b/w).view(-1,1)
    u_model_pt = model(x_model_pt).cpu().detach()
    plt.figure(dpi = 100)
    plt.plot(x_test.cpu(),u_model_cpu,'-.',label = "nn function")
    plt.plot(x_test.cpu(),u_true.cpu(),label = "true")
#     plt.plot(x_model_pt,u_model_pt,'.r')
    if name!=None: 
        plt.title(name)
    plt.legend()
    plt.show()


def plot_solution_adaptive(r1,r2,model,target,name=None): 
    # Plot function: test results 
    x_test = torch.linspace(r1,r2,200).view(-1,1).to(device)
    u_true = target(x_test)
    u_model_cpu = model(x_test).cpu().detach()
    
    w = model.fc1.weight.data.squeeze()
    b = model.fc1.bias.data.squeeze()
    x_model_pt = (-b/w).view(-1,1)
    u_model_pt = model(x_model_pt).cpu().detach()
    plt.figure(dpi = 200)
    plt.plot(x_test.cpu(),u_true.cpu(),label = "true")
    plt.plot(x_model_pt.cpu(),u_model_pt,'.',label = "nn function",markersize=3)
    # plt.plot(x_model_pt.cpu(),torch.ones(u_model_pt.size()) * 1.05* min(u_true.cpu()),'.',label = "nodes",markersize=4)
#     plt.plot(x_model_pt,u_model_pt,'.r')
    plt.xlim(r1,r2) 
    if name!=None: 
        plt.title(name)
    plt.legend()
    plt.show()

# %% [markdown]
# ## OGA

# %%
# relu dictionary
def relu_dict(x_l,x_r,N):
    """generate relu dictionary parameters 
    
    Parameters
    ----------
    x_l: float 
    x_r: float
    N: int 
        number of degrbuhee of freedoms
        
    Returns
    torch tensor
        containing relu dictionary parameters, corresponds to nodal points
        
    """
    # w = 1 
    relu_dict_parameters = torch.zeros((N,2)).to(device)
    relu_dict_parameters[:N,0] = torch.ones(N)[:]
    relu_dict_parameters[:N,1] = torch.linspace(x_l,x_r,N+1)[:-1] # relu(x-bi)


    # relu_dict_parameters[N:,0] = -torch.ones(N)[:]
    # relu_dict_parameters[N:,1] = torch.linspace(x_l,x_r,N+1)[1:] # relu(x-bi)
    
    return relu_dict_parameters


def OGAL2FittingReLU1D(my_model,target,N,num_epochs,plot_freq = 10,Nx = 1024,order =5, k = 1, solver = 'direct'): 
    """ Orthogonal greedy algorithm using 1D ReLU dictionary over [-pi,pi]
    Parameters
    ----------
    my_model: 
        nn model 
    target: 
        target function
    num_epochs: int 
        number of training epochs 
    integration_intervals: int 
        number of subintervals for piecewise numerical quadrature 

    Returns
    -------
    err: tensor 
        rank 1 torch tensor to record the L2 error history  
    model: 
        trained nn model 
    """

    weights, integration_points = PiecewiseGQ1D_weights_points(x_l= 0,x_r= 1, Nx = Nx,order =order)

    err = torch.zeros(num_epochs+1)
    if my_model == None: 
        func_values = target(integration_points)
        num_neuron = 0
        list_a = []
        list_b = []
        list_w = []
    else: 
        func_values = target(integration_points) - my_model(integration_points).detach()
        bias = my_model.fc1.bias.detach().data
        weights = my_model.fc1.weight.detach().data
        num_neuron = int(bias.size(0))
        list_a = list(my_model.fc2.weight.detach().data)
        list_b = list(bias)
        list_w = list(weights)
        
    func_values_sqrd = func_values*func_values
    err[0]= torch.sum(func_values_sqrd*weights)**0.5
    start_time = time.time()
    
    solver = "direct"
    print("using linear solver: ",solver)
    relu_dict_parameters = relu_dict(-pi,pi,N).to(device) 
    for i in range(num_epochs): 
        print('epoch: ',i+1)
        if num_neuron == 0: 
            func_values = target(integration_points)
        else: 
            func_values = target(integration_points) - my_model(integration_points).detach()

        weight_func_values = func_values*weights

#         basis_values = F.relu(integration_points - bi).T # uses broadcasting
        basis_values = (F.relu(relu_dict_parameters[:,0] *integration_points - relu_dict_parameters[:,1])**k).T # uses broadcasting
        
        output = torch.abs(torch.matmul(basis_values,weight_func_values)) # 

        neuron_index = torch.argmax(output.flatten())
        
        list_w.append(relu_dict_parameters[neuron_index,0])
        list_b.append(-relu_dict_parameters[neuron_index,1])
        num_neuron += 1
        my_model = model(1,num_neuron,1,k).to(device)
        my_model.fc1.weight.data[:,0] = torch.tensor(list_w)[:]
        my_model.fc1.bias.data[:] = torch.tensor(list_b)[:]
#         sol = minimize_linear_layer(my_model,target,solver,Nx,order)
        sol = minimize_linear_layer_explicit_assemble(my_model,target,weights, integration_points,solver=solver)
        my_model.fc2.weight.data[0,:] = sol[:]
        if (i+1)%plot_freq == 0: 
            x_test = torch.linspace(-pi,pi,200).view(-1,1).to(device)
            u_true = target(x_test)
            plot_solution_modified(-pi,pi,my_model,x_test,u_true)
        func_values = target(integration_points) - my_model(integration_points).detach()
        func_values_sqrd = func_values*func_values
        err[i+1]= torch.sum(func_values_sqrd*weights)**0.5
    print("time taken: ",time.time() - start_time)
    return err, my_model



##

# relu dictionary
def relu_dict_MC(x_l,x_r,N):
    """generate relu dictionary parameters 
    
    Parameters
    ----------
    x_l: float 
    x_r: float
    N: int 
        number of degree of freedoms
        
    Returns
    torch tensor
        containing relu dictionary parameters, corresponds to nodal points
        
    """
    # w = 1 
    relu_dict_parameters = torch.zeros((N,2)).to(device)
    relu_dict_parameters[:N,0] = torch.ones(N)[:]
    relu_dict_parameters[:N,1] = torch.rand(N)*(x_r-x_l) + x_l # relu(x-bi) 
    # torch.linspace(x_l,x_r,N+1)[:-1] # relu(x-bi)
    return relu_dict_parameters

def generate_relu_dict4plusD_sphere(dim, s,N0): # 
    samples = torch.randn(s*N0,dim +1) 
    samples = samples/samples.norm(dim=1,keepdim=True)  
    Wb = samples 
    return Wb 

def generate_relu_dict_1D_semicircle(s,N0):
    theta = (torch.rand(s*N0) - 0.5) * torch.pi  # [-π/2, π/2]
    # theta = (torch.linspace(0,1,s*N0+1)- 0.5)* torch.pi  # [-π/2, π/2]
    Wb = torch.stack([torch.cos(theta), torch.sin(theta)], dim=1)
    return Wb

def OGAL2FittingReLU1D_MC(my_model,target,N0,num_epochs,plot_freq = 10,Nx = 1024, order = 3, k = 1, solver = 'direct'): 
    """ Orthogonal greedy algorithm using 1D ReLU dictionary over [-pi,pi]
    Parameters
    ----------
    my_model: 
        nn model 
    target: 
        target function
    num_epochs: int 
        number of training epochs 
    integration_intervals: int 
        number of subintervals for piecewise numerical quadrature 

    Returns
    -------
    err: tensor 
        rank 1 torch tensor to record the L2 error history  
    model: 
        trained nn model 
    """
    x_l = 0 
    x_r = 1 
    weights, integration_points = PiecewiseGQ1D_weights_points(x_l= x_l ,x_r= x_r,Nx = Nx, order = order)

    err = torch.zeros(num_epochs+1)
    if my_model == None: 
        func_values = target(integration_points)
        num_neuron = 0
        list_a = []
        list_b = []
        list_w = []
    else: 
        func_values = target(integration_points) - my_model(integration_points).detach()
        bias = my_model.fc1.bias.detach().data
        weights = my_model.fc1.weight.detach().data
        num_neuron = int(bias.size(0))
        list_a = list(my_model.fc2.weight.detach().data)
        list_b = list(bias)
        list_w = list(weights)
        
    func_values_sqrd = func_values*func_values
    err[0]= torch.sum(func_values_sqrd*weights)**0.5
    start_time = time.time()
    
    for i in range(num_epochs): 
        print('epoch ',i + 1 )
        # relu_dict_parameters = relu_dict_MC(-pi,pi,N0).to(device)
#         relu_dict_parameters = generate_relu_dict4plusD_sphere(1,1, N0).to(device) 
        relu_dict_parameters = generate_relu_dict_1D_semicircle(1,N0).to(device)
        if num_neuron == 0: 
            func_values = target(integration_points)
        else: 
            func_values = target(integration_points) - my_model(integration_points).detach()

        weight_func_values = func_values*weights

#         basis_values = F.relu(integration_points - bi).T # uses broadcasting
        basis_values = (F.relu(relu_dict_parameters[:,0] *integration_points - relu_dict_parameters[:,1])**k).T # uses broadcasting
        
        output = torch.abs(torch.matmul(basis_values,weight_func_values)) # 

        neuron_index = torch.argmax(output.flatten())
        
        list_w.append(relu_dict_parameters[neuron_index,0])
        list_b.append(-relu_dict_parameters[neuron_index,1])
        num_neuron += 1
        my_model = model(1,num_neuron,1,k).to(device)
        my_model.fc1.weight.data[:,0] = torch.tensor(list_w)[:]
        my_model.fc1.bias.data[:] = torch.tensor(list_b)[:]
#         sol = minimize_linear_layer(my_model,target,solver, Nx, order)
        sol = minimize_linear_layer_explicit_assemble(my_model,target,weights, integration_points,solver=solver)
        my_model.fc2.weight.data[0,:] = sol[:]
        if (i+1)%plot_freq == 0: 
            x_test = torch.linspace(x_l,x_r,200).view(-1,1).to(device)
            u_true = target(x_test)
            plot_solution_modified(x_l,x_r,my_model,x_test,u_true)
        func_values = target(integration_points) - my_model(integration_points).detach()
        func_values_sqrd = func_values*func_values
        err[i+1]= torch.sum(func_values_sqrd*weights)**0.5
    # print("time taken: ",time.time() - start_time)
    return err, my_model

# relu dictionary

# %%
def show_convergence_order(err_l2,exponent,dict_size, filename,write2file = False):
    
    if write2file:
        file_mode = "a" if os.path.exists(filename) else "w"
        f_write = open(filename, file_mode)
    
    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_l2[i] for i in neuron_nums ]
#     err_list2 = [err_h10[i] for i in neuron_nums ] 
    # f_write.write('M:{}, relu {} \n'.format(M,k))
    if write2file:
        f_write.write('dictionary size: {}\n'.format(dict_size))
        f_write.write("neuron num \t\t error \t\t order \t\t h10 error \\ order \n")
    print("neuron num \t\t error \t\t order")
    for i, item in enumerate(err_list):
        if i == 0: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t")
            
            # print("*")
            print("{} \t\t {:.6f} \t\t *  \n".format(neuron_nums[i],item ) )
            if write2file: 
                f_write.write("{} \t\t {} \t\t * \t\t \n".format(neuron_nums[i],item ))
        else: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t") 
            # print(np.log(err_list[i-1]/err_list[i])/np.log(2))
            print("{} \t\t {:.6f} \t\t {:.6f} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2) ) )
            if write2file: 
                f_write.write("{} \t\t {} \t\t {} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2) ))
    if write2file:     
        f_write.write("\n")
        f_write.close()

def show_convergence_order_latex(err_l2,exponent,k=1,d=1): 
    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_l2[i] for i in neuron_nums ]
#     err_list2 = [err_h10[i] for i in neuron_nums ] 
    # f_write.write('M:{}, relu {} \n'.format(M,k))
    # f_write.write('randomized dictionary size: {}\n'.format(N))
    # f_write.write("neuron num \t\t error \t\t order \t\t h10 error \\ order \n")
    l2_order = -1/2-(2*k + 1)/(2*d)
#     h10_order = -1/2-(2*(k-1) + 1)/(2*d)
#     print("neuron num  & \t $\|u-u_n \|_{L^2}$ & \t order $O(n^{{{}})$ & \t $ | u -u_n |_{H^1}$ & \t order $O(n^{{{}})$ \\\ \hline \hline ".format(l2_order,h10_order))
    print("neuron num  & \t $\\|u-u_n \\|_{{L^2}}$ & \t order $O(n^{{{:.2f}}})$  \\\\ \\hline \\hline ".format(l2_order))
    for i, item in enumerate(err_list):
        if i == 0: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t")

            # print("*")
            print("{} \t\t & {:.6f} &\t\t *  \\\ \hline  \n".format(neuron_nums[i],item) )   
            # f_write.write("{} \t\t {} \t\t * \t\t {} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ))
        else: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t") 
            # print(np.log(err_list[i-1]/err_list[i])/np.log(2))
            print("{} \t\t &  {:.3e} &  \t\t {:.2f} \\\ \hline  \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2) ) )
            # f_write.write("{} \t\t {} \t\t {} \t\t {} \t\t {} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ))
    # f_write.write("\n")
    # f_write.close()

# %% [markdown]
# ## randomized

# %%
def target(x):
    return torch.sin(2*pi * x)

function_name = "sine1d" 
Nx = 2**10
order = 3    
filename_write = "1DMCOGA-{}-order.txt".format(function_name)
f_write = open(filename_write, "a")
f_write.write("\n")
f_write.close() 

save = True  
write2file = True 

for N in [2**11]: # 2**12,2**14
    
    f_write = open(filename_write, "a")
    my_model = None 
    exponent = 7
    num_epochs = 2**exponent
    plot_freq = num_epochs 
    relu_k = 1 
    err_QMC2, my_model = OGAL2FittingReLU1D_MC(None,target,N,num_epochs,plot_freq, Nx, order, k =relu_k, solver = "direct")

    if save: 
        folder = 'data/'
        filename = folder + 'err_OGA_1D_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,num_epochs,N)
        torch.save(err_QMC2,filename) 
        folder = 'data/'
        filename = folder + 'model_OGA_1D_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,num_epochs,N)
        torch.save(my_model.state_dict(),filename)
        
    show_convergence_order(err_QMC2,exponent,N,filename_write,write2file = write2file)
    show_convergence_order_latex(err_QMC2,exponent,k=relu_k,d=1)
# Out:
# epoch  1
# assembling the matrix time taken:  0.0002639293670654297
# solving Ax = b time taken:  0.00011086463928222656
# epoch  2
# assembling the matrix time taken:  0.00037407875061035156
# solving Ax = b time taken:  0.00010895729064941406
# epoch  3
# assembling the matrix time taken:  0.0003249645233154297
# solving Ax = b time taken:  0.0001201629638671875
# epoch  4
# assembling the matrix time taken:  0.0005319118499755859
# solving Ax = b time taken:  0.00011897087097167969
# epoch  5
# assembling the matrix time taken:  0.0003421306610107422
# solving Ax = b time taken:  0.00010895729064941406
# epoch  6
# assembling the matrix time taken:  0.0003325939178466797
# solving Ax = b time taken:  0.00010514259338378906
# epoch  7
# assembling the matrix time taken:  0.0003490447998046875
# solving Ax = b time taken:  0.00011491775512695312
# epoch  8
# assembling the matrix time taken:  0.00030803680419921875
# solving Ax = b time taken:  0.00010585784912109375
# epoch  9
# assembling the matrix time taken:  0.00036787986755371094
# solving Ax = b time taken:  0.0001201629638671875
# epoch  10
# assembling the matrix time taken:  0.0005528926849365234
# solving Ax = b time taken:  0.00011396408081054688
# epoch  11
# assembling the matrix time taken:  0.0005068778991699219
# solving Ax = b time taken:  0.00011515617370605469
# epoch  12
# assembling the matrix time taken:  0.0005109310150146484
# solving Ax = b time taken:  0.0001900196075439453
# epoch  13
# assembling the matrix time taken:  0.0005130767822265625
# solving Ax = b time taken:  0.00010132789611816406
# epoch  14
# assembling the matrix time taken:  0.000743865966796875
# solving Ax = b time taken:  0.00010204315185546875
# epoch  15
# assembling the matrix time taken:  0.0006792545318603516
# solving Ax = b time taken:  0.00011205673217773438
# epoch  16
# assembling the matrix time taken:  0.0005910396575927734
# solving Ax = b time taken:  0.0001811981201171875
# epoch  17
# assembling the matrix time taken:  0.0006301403045654297
# solving Ax = b time taken:  0.00013303756713867188
# epoch  18
# assembling the matrix time taken:  0.0006461143493652344
# solving Ax = b time taken:  0.00013899803161621094
# epoch  19
# assembling the matrix time taken:  0.0006380081176757812
# solving Ax = b time taken:  0.0001442432403564453
# epoch  20
# assembling the matrix time taken:  0.0007452964782714844
# solving Ax = b time taken:  0.0001380443572998047
# epoch  21
# assembling the matrix time taken:  0.0004909038543701172
# solving Ax = b time taken:  0.00012993812561035156
# epoch  22
# assembling the matrix time taken:  0.0004050731658935547
# solving Ax = b time taken:  0.0001232624053955078
# epoch  23
# assembling the matrix time taken:  0.0005960464477539062
# solving Ax = b time taken:  0.00013494491577148438
# epoch  24
# assembling the matrix time taken:  0.0003657341003417969
# solving Ax = b time taken:  0.0001220703125
# epoch  25
# assembling the matrix time taken:  0.0005099773406982422
# solving Ax = b time taken:  0.00013375282287597656
# epoch  26
# assembling the matrix time taken:  0.0004582405090332031
# solving Ax = b time taken:  0.00011992454528808594
# epoch  27
# assembling the matrix time taken:  0.0004990100860595703
# solving Ax = b time taken:  0.00012493133544921875
# epoch  28
# assembling the matrix time taken:  0.0004887580871582031
# solving Ax = b time taken:  0.0003681182861328125
# epoch  29
# assembling the matrix time taken:  0.0007491111755371094
# solving Ax = b time taken:  0.00022077560424804688
# epoch  30
# assembling the matrix time taken:  0.0006573200225830078
# solving Ax = b time taken:  0.00019407272338867188
# epoch  31
# assembling the matrix time taken:  0.0006940364837646484
# solving Ax = b time taken:  0.00014710426330566406
# epoch  32
# assembling the matrix time taken:  0.001154184341430664
# solving Ax = b time taken:  0.00016307830810546875
# epoch  33
# assembling the matrix time taken:  0.0011987686157226562
# solving Ax = b time taken:  0.00014591217041015625
# epoch  34
# assembling the matrix time taken:  0.0005459785461425781
# solving Ax = b time taken:  0.00013375282287597656
# epoch  35
# assembling the matrix time taken:  0.0006489753723144531
# solving Ax = b time taken:  0.0001270771026611328
# epoch  36
# assembling the matrix time taken:  0.00063323974609375
# solving Ax = b time taken:  0.00012803077697753906
# epoch  37
# assembling the matrix time taken:  0.0015630722045898438
# solving Ax = b time taken:  0.00026106834411621094
# epoch  38
# assembling the matrix time taken:  0.0005631446838378906
# solving Ax = b time taken:  0.00013017654418945312
# epoch  39
# assembling the matrix time taken:  0.0010581016540527344
# solving Ax = b time taken:  0.0001430511474609375
# epoch  40
# assembling the matrix time taken:  0.00098419189453125
# solving Ax = b time taken:  0.0001361370086669922
# epoch  41
# assembling the matrix time taken:  0.0025229454040527344
# solving Ax = b time taken:  0.00014328956604003906
# epoch  42
# assembling the matrix time taken:  0.002972841262817383
# solving Ax = b time taken:  0.00016999244689941406
# epoch  43
# assembling the matrix time taken:  0.0032808780670166016
# solving Ax = b time taken:  0.00016188621520996094
# epoch  44
# assembling the matrix time taken:  0.0008630752563476562
# solving Ax = b time taken:  0.00013375282287597656
# epoch  45
# assembling the matrix time taken:  0.003719806671142578
# solving Ax = b time taken:  0.00013589859008789062
# epoch  46
# assembling the matrix time taken:  0.0009920597076416016
# solving Ax = b time taken:  0.0001468658447265625
# epoch  47
# assembling the matrix time taken:  0.0007202625274658203
# solving Ax = b time taken:  0.00013709068298339844
# epoch  48
# assembling the matrix time taken:  0.0010700225830078125
# solving Ax = b time taken:  0.0003838539123535156
# epoch  49
# assembling the matrix time taken:  0.007534980773925781
# solving Ax = b time taken:  0.00014710426330566406
# epoch  50
# assembling the matrix time taken:  0.0009500980377197266
# solving Ax = b time taken:  0.0001380443572998047
# epoch  51
# assembling the matrix time taken:  0.0006372928619384766
# solving Ax = b time taken:  0.00014781951904296875
# epoch  52
# assembling the matrix time taken:  0.0007641315460205078
# solving Ax = b time taken:  0.0001380443572998047
# epoch  53
# assembling the matrix time taken:  0.0008120536804199219
# solving Ax = b time taken:  0.0001437664031982422
# epoch  54
# assembling the matrix time taken:  0.0010597705841064453
# solving Ax = b time taken:  0.0001571178436279297
# epoch  55
# assembling the matrix time taken:  0.001077890396118164
# solving Ax = b time taken:  0.00024008750915527344
# epoch  56
# assembling the matrix time taken:  0.000926971435546875
# solving Ax = b time taken:  0.00014400482177734375
# epoch  57
# assembling the matrix time taken:  0.0011098384857177734
# solving Ax = b time taken:  0.00015616416931152344
# epoch  58
# assembling the matrix time taken:  0.0008897781372070312
# solving Ax = b time taken:  0.0001552104949951172
# epoch  59
# assembling the matrix time taken:  0.0009641647338867188
# solving Ax = b time taken:  0.00034689903259277344
# epoch  60
# assembling the matrix time taken:  0.0009257793426513672
# solving Ax = b time taken:  0.0001430511474609375
# epoch  61
# assembling the matrix time taken:  0.001008749008178711
# solving Ax = b time taken:  0.00014519691467285156
# epoch  62
# assembling the matrix time taken:  0.0009088516235351562
# solving Ax = b time taken:  0.00015282630920410156
# epoch  63
# assembling the matrix time taken:  0.0012347698211669922
# solving Ax = b time taken:  0.00017189979553222656
# epoch  64
# assembling the matrix time taken:  0.001394033432006836
# solving Ax = b time taken:  0.00014901161193847656
# epoch  65
# assembling the matrix time taken:  0.0012798309326171875
# solving Ax = b time taken:  0.00016880035400390625
# epoch  66
# assembling the matrix time taken:  0.0010259151458740234
# solving Ax = b time taken:  0.00021910667419433594
# epoch  67
# assembling the matrix time taken:  0.0009682178497314453
# solving Ax = b time taken:  0.00015211105346679688
# epoch  68
# assembling the matrix time taken:  0.0030171871185302734
# solving Ax = b time taken:  0.00021886825561523438
# epoch  69
# assembling the matrix time taken:  0.0025069713592529297
# solving Ax = b time taken:  0.00017404556274414062
# epoch  70
# assembling the matrix time taken:  0.0014903545379638672
# solving Ax = b time taken:  0.0001709461212158203
# epoch  71
# assembling the matrix time taken:  0.0018949508666992188
# solving Ax = b time taken:  0.0002522468566894531
# epoch  72
# assembling the matrix time taken:  0.002379894256591797
# solving Ax = b time taken:  0.0001938343048095703
# epoch  73
# assembling the matrix time taken:  0.0021598339080810547
# solving Ax = b time taken:  0.00019478797912597656
# epoch  74
# assembling the matrix time taken:  0.010024070739746094
# solving Ax = b time taken:  0.00026488304138183594
# epoch  75
# assembling the matrix time taken:  0.0038940906524658203
# solving Ax = b time taken:  0.00024890899658203125
# epoch  76
# assembling the matrix time taken:  0.002179861068725586
# solving Ax = b time taken:  0.00043487548828125
# epoch  77
# assembling the matrix time taken:  0.0019469261169433594
# solving Ax = b time taken:  0.0002040863037109375
# epoch  78
# assembling the matrix time taken:  0.0013480186462402344
# solving Ax = b time taken:  0.00023603439331054688
# epoch  79
# assembling the matrix time taken:  0.0017800331115722656
# solving Ax = b time taken:  0.00021386146545410156
# epoch  80
# assembling the matrix time taken:  0.0019800662994384766
# solving Ax = b time taken:  0.00020194053649902344
# epoch  81
# assembling the matrix time taken:  0.0014100074768066406
# solving Ax = b time taken:  0.00019097328186035156
# epoch  82
# assembling the matrix time taken:  0.001474142074584961
# solving Ax = b time taken:  0.00018525123596191406
# epoch  83
# assembling the matrix time taken:  0.0011119842529296875
# solving Ax = b time taken:  0.0005359649658203125
# epoch  84
# assembling the matrix time taken:  0.0023488998413085938
# solving Ax = b time taken:  0.00021505355834960938
# epoch  85
# assembling the matrix time taken:  0.0018570423126220703
# solving Ax = b time taken:  0.0003209114074707031
# epoch  86
# assembling the matrix time taken:  0.002276897430419922
# solving Ax = b time taken:  0.00028324127197265625
# epoch  87
# assembling the matrix time taken:  0.0013480186462402344
# solving Ax = b time taken:  0.00020885467529296875
# epoch  88
# assembling the matrix time taken:  0.001664876937866211
# solving Ax = b time taken:  0.00018310546875
# epoch  89
# assembling the matrix time taken:  0.0023469924926757812
# solving Ax = b time taken:  0.0003361701965332031
# epoch  90
# assembling the matrix time taken:  0.0016510486602783203
# solving Ax = b time taken:  0.0003299713134765625
# epoch  91
# assembling the matrix time taken:  0.0020799636840820312
# solving Ax = b time taken:  0.00022292137145996094
# epoch  92
# assembling the matrix time taken:  0.0014650821685791016
# solving Ax = b time taken:  0.00021696090698242188
# epoch  93
# assembling the matrix time taken:  0.0018930435180664062
# solving Ax = b time taken:  0.0002682209014892578
# epoch  94
# assembling the matrix time taken:  0.0019290447235107422
# solving Ax = b time taken:  0.0002269744873046875
# epoch  95
# assembling the matrix time taken:  0.0020270347595214844
# solving Ax = b time taken:  0.00021505355834960938
# epoch  96
# assembling the matrix time taken:  0.001506805419921875
# solving Ax = b time taken:  0.0003299713134765625
# epoch  97
# assembling the matrix time taken:  0.0025191307067871094
# solving Ax = b time taken:  0.00028395652770996094
# epoch  98
# assembling the matrix time taken:  0.0018398761749267578
# solving Ax = b time taken:  0.00022602081298828125
# epoch  99
# assembling the matrix time taken:  0.0023250579833984375
# solving Ax = b time taken:  0.00024008750915527344
# epoch  100
# assembling the matrix time taken:  0.0021719932556152344
# solving Ax = b time taken:  0.00020813941955566406
# epoch  101
# assembling the matrix time taken:  0.002521038055419922
# solving Ax = b time taken:  0.0002789497375488281
# epoch  102
# assembling the matrix time taken:  0.0021631717681884766
# solving Ax = b time taken:  0.00025081634521484375
# epoch  103
# assembling the matrix time taken:  0.0027709007263183594
# solving Ax = b time taken:  0.0005040168762207031
# epoch  104
# assembling the matrix time taken:  0.0019261837005615234
# solving Ax = b time taken:  0.0002193450927734375
# epoch  105
# assembling the matrix time taken:  0.0028290748596191406
# solving Ax = b time taken:  0.00027298927307128906
# epoch  106
# assembling the matrix time taken:  0.0016829967498779297
# solving Ax = b time taken:  0.00021600723266601562
# epoch  107
# assembling the matrix time taken:  0.0018780231475830078
# solving Ax = b time taken:  0.0002338886260986328
# epoch  108
# assembling the matrix time taken:  0.0030808448791503906
# solving Ax = b time taken:  0.00022125244140625
# epoch  109
# assembling the matrix time taken:  0.0018367767333984375
# solving Ax = b time taken:  0.0002510547637939453
# epoch  110
# assembling the matrix time taken:  0.0013689994812011719
# solving Ax = b time taken:  0.00022792816162109375
# epoch  111
# assembling the matrix time taken:  0.0020668506622314453
# solving Ax = b time taken:  0.00024080276489257812
# epoch  112
# assembling the matrix time taken:  0.001374959945678711
# solving Ax = b time taken:  0.00025916099548339844
# epoch  113
# assembling the matrix time taken:  0.0019958019256591797
# solving Ax = b time taken:  0.0002961158752441406
# epoch  114
# assembling the matrix time taken:  0.0016398429870605469
# solving Ax = b time taken:  0.0002391338348388672
# epoch  115
# assembling the matrix time taken:  0.0027501583099365234
# solving Ax = b time taken:  0.0005638599395751953
# epoch  116
# assembling the matrix time taken:  0.0017788410186767578
# solving Ax = b time taken:  0.0002999305725097656
# epoch  117
# assembling the matrix time taken:  0.0017261505126953125
# solving Ax = b time taken:  0.0002570152282714844
# epoch  118
# assembling the matrix time taken:  0.002004861831665039
# solving Ax = b time taken:  0.0003039836883544922
# epoch  119
# assembling the matrix time taken:  0.0019559860229492188
# solving Ax = b time taken:  0.00023508071899414062
# epoch  120
# assembling the matrix time taken:  0.0015020370483398438
# solving Ax = b time taken:  0.0002422332763671875
# epoch  121
# assembling the matrix time taken:  0.0021271705627441406
# solving Ax = b time taken:  0.00026988983154296875
# epoch  122
# assembling the matrix time taken:  0.0015742778778076172
# solving Ax = b time taken:  0.0002810955047607422
# epoch  123
# assembling the matrix time taken:  0.003240823745727539
# solving Ax = b time taken:  0.0005548000335693359
# epoch  124
# assembling the matrix time taken:  0.002913951873779297
# solving Ax = b time taken:  0.00029206275939941406
# epoch  125
# assembling the matrix time taken:  0.0022430419921875
# solving Ax = b time taken:  0.0002868175506591797
# epoch  126
# assembling the matrix time taken:  0.0019207000732421875
# solving Ax = b time taken:  0.0003502368927001953
# epoch  127
# assembling the matrix time taken:  0.0023698806762695312
# solving Ax = b time taken:  0.0003027915954589844
# epoch  128
# assembling the matrix time taken:  0.003453969955444336
# solving Ax = b time taken:  0.0003681182861328125
# neuron num 		 error 		 order
# 4 		 0.135377 		 *
#
# 8 		 0.023702 		 2.513896
#
# 16 		 0.005292 		 2.163236
#
# 32 		 0.001242 		 2.091100
#
# 64 		 0.000297 		 2.064671
#
# 128 		 0.000074 		 2.010110
#
# neuron num  & 	 $\|u-u_n \|_{L^2}$ & 	 order $O(n^{-2.00})$  \\ \hline \hline
# 4 		 & 0.135377 &		 *  \\ \hline
#
# 8 		 &  2.370e-02 &  		 2.51 \\ \hline
#
# 16 		 &  5.292e-03 &  		 2.16 \\ \hline
#
# 32 		 &  1.242e-03 &  		 2.09 \\ \hline
#
# 64 		 &  2.969e-04 &  		 2.06 \\ \hline
#
# 128 		 &  7.370e-05 &  		 2.01 \\ \hline

# %%
plot_solution_adaptive(0, 1, my_model, target, name=None)

# %% [markdown]
# ## An oscillatory example  (added to thesis defense)

# %%
def target(x):
    return 10*(torch.sin(2*pi*x) + torch.sin(2*pi*3*x)) + 10*( \
            torch.sin(2*pi*4*x) + torch.sin(2*pi*9*x) + torch.sin(2*pi*13*x)- torch.sin(2*pi*x) - torch.sin(2*pi*3*x) \
            )* torch.heaviside(x-0.5,torch.tensor([0.0]))

# %%
x_coord = torch.linspace(0,1,1000)
u_true = target(x_coord) 
plt.plot(x_coord,u_true)
plt.show()

# %%
def target(x):
    return 10*(torch.sin(2*pi*x) + torch.sin(2*pi*3*x)) + 10*( \
            torch.sin(2*pi*4*x) + torch.sin(2*pi*9*x) + torch.sin(2*pi*13*x)- torch.sin(2*pi*x) - torch.sin(2*pi*3*x) \
            )* torch.heaviside(x-0.5,torch.tensor([0.0]))

x_coord = torch.linspace(0,1,1000)
u_true = target(x_coord) 
plt.plot(x_coord,u_true)
plt.show() 

function_name = "oscillatory1d" 
Nx = 2**11
order = 3    
filename_write = "1DMCOGA-{}-order.txt".format(function_name)
f_write = open(filename_write, "a")
f_write.write("\n")
f_write.close() 

save = True  
write2file = True 

for N in [2**11]: # 2**12,2**14
    
    f_write = open(filename_write, "a")
    my_model = None 
    exponent = 7
    num_epochs = 2**exponent
    plot_freq = num_epochs 
    relu_k = 1 
    err_QMC2, my_model = OGAL2FittingReLU1D_MC(None,target,N,num_epochs,plot_freq, Nx, order, k =relu_k, solver = "direct")

    if save: 
        folder = 'data/'
        filename = folder + 'err_OGA_1D_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,num_epochs,N)
        torch.save(err_QMC2,filename) 
        folder = 'data/'
        filename = folder + 'model_OGA_1D_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,num_epochs,N)
        torch.save(my_model.state_dict(),filename)
        
    show_convergence_order(err_QMC2,exponent,N,filename_write,write2file = write2file)
    show_convergence_order_latex(err_QMC2,exponent,k=relu_k,d=1)
# Out:
# epoch  1
# assembling the matrix time taken:  0.00864100456237793
# solving Ax = b time taken:  0.000225067138671875
# epoch  2
# assembling the matrix time taken:  0.0022058486938476562
# solving Ax = b time taken:  0.00015807151794433594
# epoch  3
# assembling the matrix time taken:  0.0015301704406738281
# solving Ax = b time taken:  0.00012683868408203125
# epoch  4
# assembling the matrix time taken:  0.001744985580444336
# solving Ax = b time taken:  0.0003693103790283203
# epoch  5
# assembling the matrix time taken:  0.002079010009765625
# solving Ax = b time taken:  0.0001277923583984375
# epoch  6
# assembling the matrix time taken:  0.00109100341796875
# solving Ax = b time taken:  0.00011420249938964844
# epoch  7
# assembling the matrix time taken:  0.0047571659088134766
# solving Ax = b time taken:  0.00015282630920410156
# epoch  8
# assembling the matrix time taken:  0.002753019332885742
# solving Ax = b time taken:  0.00012421607971191406
# epoch  9
# assembling the matrix time taken:  0.007720947265625
# solving Ax = b time taken:  0.00014781951904296875
# epoch  10
# assembling the matrix time taken:  0.0066471099853515625
# solving Ax = b time taken:  0.00015211105346679688
# epoch  11
# assembling the matrix time taken:  0.011634349822998047
# solving Ax = b time taken:  0.0005550384521484375
# epoch  12
# assembling the matrix time taken:  0.0036950111389160156
# solving Ax = b time taken:  0.00014901161193847656
# epoch  13
# assembling the matrix time taken:  0.0011899471282958984
# solving Ax = b time taken:  0.00012969970703125
# epoch  14
# assembling the matrix time taken:  0.008418083190917969
# solving Ax = b time taken:  0.00016117095947265625
# epoch  15
# assembling the matrix time taken:  0.0016829967498779297
# solving Ax = b time taken:  0.000141143798828125
# epoch  16
# assembling the matrix time taken:  0.0012428760528564453
# solving Ax = b time taken:  0.00012111663818359375
# epoch  17
# assembling the matrix time taken:  0.012368202209472656
# solving Ax = b time taken:  0.00020194053649902344
# epoch  18
# assembling the matrix time taken:  0.004206180572509766
# solving Ax = b time taken:  0.00022077560424804688
# epoch  19
# assembling the matrix time taken:  0.0038552284240722656
# solving Ax = b time taken:  0.0003647804260253906
# epoch  20
# assembling the matrix time taken:  0.0031299591064453125
# solving Ax = b time taken:  0.00016498565673828125
# epoch  21
# assembling the matrix time taken:  0.008873939514160156
# solving Ax = b time taken:  0.00018405914306640625
# epoch  22
# assembling the matrix time taken:  0.0018351078033447266
# solving Ax = b time taken:  0.0001819133758544922
# epoch  23
# assembling the matrix time taken:  0.004845142364501953
# solving Ax = b time taken:  0.000171661376953125
# epoch  24
# assembling the matrix time taken:  0.0039408206939697266
# solving Ax = b time taken:  0.0001609325408935547
# epoch  25
# assembling the matrix time taken:  0.0020499229431152344
# solving Ax = b time taken:  0.0001480579376220703
# epoch  26
# assembling the matrix time taken:  0.0013549327850341797
# solving Ax = b time taken:  0.00017595291137695312
# epoch  27
# assembling the matrix time taken:  0.008816957473754883
# solving Ax = b time taken:  0.00055694580078125
# epoch  28
# assembling the matrix time taken:  0.0021469593048095703
# solving Ax = b time taken:  0.0002219676971435547
# epoch  29
# assembling the matrix time taken:  0.0011348724365234375
# solving Ax = b time taken:  0.0002129077911376953
# epoch  30
# assembling the matrix time taken:  0.0014491081237792969
# solving Ax = b time taken:  0.00018906593322753906
# epoch  31
# assembling the matrix time taken:  0.0012726783752441406
# solving Ax = b time taken:  0.00015687942504882812
# epoch  32
# assembling the matrix time taken:  0.001055002212524414
# solving Ax = b time taken:  0.0001380443572998047
# epoch  33
# assembling the matrix time taken:  0.0014829635620117188
# solving Ax = b time taken:  0.00015997886657714844
# epoch  34
# assembling the matrix time taken:  0.008675098419189453
# solving Ax = b time taken:  0.00019669532775878906
# epoch  35
# assembling the matrix time taken:  0.0020112991333007812
# solving Ax = b time taken:  0.0001590251922607422
# epoch  36
# assembling the matrix time taken:  0.00800013542175293
# solving Ax = b time taken:  0.00024819374084472656
# epoch  37
# assembling the matrix time taken:  0.0036051273345947266
# solving Ax = b time taken:  0.0004360675811767578
# epoch  38
# assembling the matrix time taken:  0.0018901824951171875
# solving Ax = b time taken:  0.00018715858459472656
# epoch  39
# assembling the matrix time taken:  0.0020599365234375
# solving Ax = b time taken:  0.00017905235290527344
# epoch  40
# assembling the matrix time taken:  0.0013875961303710938
# solving Ax = b time taken:  0.0001571178436279297
# epoch  41
# assembling the matrix time taken:  0.008350849151611328
# solving Ax = b time taken:  0.00022411346435546875
# epoch  42
# assembling the matrix time taken:  0.0031960010528564453
# solving Ax = b time taken:  0.00017714500427246094
# epoch  43
# assembling the matrix time taken:  0.001397848129272461
# solving Ax = b time taken:  0.00015997886657714844
# epoch  44
# assembling the matrix time taken:  0.002924680709838867
# solving Ax = b time taken:  0.00017595291137695312
# epoch  45
# assembling the matrix time taken:  0.0016810894012451172
# solving Ax = b time taken:  0.00017404556274414062
# epoch  46
# assembling the matrix time taken:  0.0013949871063232422
# solving Ax = b time taken:  0.0001571178436279297
# epoch  47
# assembling the matrix time taken:  0.0013082027435302734
# solving Ax = b time taken:  0.00015211105346679688
# epoch  48
# assembling the matrix time taken:  0.0013039112091064453
# solving Ax = b time taken:  0.0001690387725830078
# epoch  49
# assembling the matrix time taken:  0.003390073776245117
# solving Ax = b time taken:  0.00047707557678222656
# epoch  50
# assembling the matrix time taken:  0.002031087875366211
# solving Ax = b time taken:  0.00017714500427246094
# epoch  51
# assembling the matrix time taken:  0.0015060901641845703
# solving Ax = b time taken:  0.00016307830810546875
# epoch  52
# assembling the matrix time taken:  0.0015177726745605469
# solving Ax = b time taken:  0.0001800060272216797
# epoch  53
# assembling the matrix time taken:  0.0019321441650390625
# solving Ax = b time taken:  0.00018596649169921875
# epoch  54
# assembling the matrix time taken:  0.0027551651000976562
# solving Ax = b time taken:  0.0002129077911376953
# epoch  55
# assembling the matrix time taken:  0.0035393238067626953
# solving Ax = b time taken:  0.00022101402282714844
# epoch  56
# assembling the matrix time taken:  0.0015799999237060547
# solving Ax = b time taken:  0.00017595291137695312
# epoch  57
# assembling the matrix time taken:  0.0020589828491210938
# solving Ax = b time taken:  0.00019621849060058594
# epoch  58
# assembling the matrix time taken:  0.0023839473724365234
# solving Ax = b time taken:  0.00018310546875
# epoch  59
# assembling the matrix time taken:  0.009240865707397461
# solving Ax = b time taken:  0.0009069442749023438
# epoch  60
# assembling the matrix time taken:  0.00220489501953125
# solving Ax = b time taken:  0.00019311904907226562
# epoch  61
# assembling the matrix time taken:  0.0030007362365722656
# solving Ax = b time taken:  0.00022912025451660156
# epoch  62
# assembling the matrix time taken:  0.002074003219604492
# solving Ax = b time taken:  0.00019407272338867188
# epoch  63
# assembling the matrix time taken:  0.0047032833099365234
# solving Ax = b time taken:  0.0002980232238769531
# epoch  64
# assembling the matrix time taken:  0.006476163864135742
# solving Ax = b time taken:  0.00026297569274902344
# epoch  65
# assembling the matrix time taken:  0.0018718242645263672
# solving Ax = b time taken:  0.0001766681671142578
# epoch  66
# assembling the matrix time taken:  0.003116130828857422
# solving Ax = b time taken:  0.0003466606140136719
# epoch  67
# assembling the matrix time taken:  0.0037920475006103516
# solving Ax = b time taken:  0.00046896934509277344
# epoch  68
# assembling the matrix time taken:  0.002115964889526367
# solving Ax = b time taken:  0.0001957416534423828
# epoch  69
# assembling the matrix time taken:  0.001958131790161133
# solving Ax = b time taken:  0.00018835067749023438
# epoch  70
# assembling the matrix time taken:  0.0031480789184570312
# solving Ax = b time taken:  0.0002181529998779297
# epoch  71
# assembling the matrix time taken:  0.0031671524047851562
# solving Ax = b time taken:  0.00018405914306640625
# epoch  72
# assembling the matrix time taken:  0.003431081771850586
# solving Ax = b time taken:  0.00030112266540527344
# epoch  73
# assembling the matrix time taken:  0.003915071487426758
# solving Ax = b time taken:  0.00022220611572265625
# epoch  74
# assembling the matrix time taken:  0.002672910690307617
# solving Ax = b time taken:  0.00025582313537597656
# epoch  75
# assembling the matrix time taken:  0.002146005630493164
# solving Ax = b time taken:  0.0002052783966064453
# epoch  76
# assembling the matrix time taken:  0.0021092891693115234
# solving Ax = b time taken:  0.0002529621124267578
# epoch  77
# assembling the matrix time taken:  0.0020008087158203125
# solving Ax = b time taken:  0.00018787384033203125
# epoch  78
# assembling the matrix time taken:  0.0019142627716064453
# solving Ax = b time taken:  0.00019311904907226562
# epoch  79
# assembling the matrix time taken:  0.001964092254638672
# solving Ax = b time taken:  0.0004253387451171875
# epoch  80
# assembling the matrix time taken:  0.003139972686767578
# solving Ax = b time taken:  0.00017380714416503906
# epoch  81
# assembling the matrix time taken:  0.0023679733276367188
# solving Ax = b time taken:  0.00017786026000976562
# epoch  82
# assembling the matrix time taken:  0.0026810169219970703
# solving Ax = b time taken:  0.00021195411682128906
# epoch  83
# assembling the matrix time taken:  0.003425121307373047
# solving Ax = b time taken:  0.00023603439331054688
# epoch  84
# assembling the matrix time taken:  0.0037679672241210938
# solving Ax = b time taken:  0.00022673606872558594
# epoch  85
# assembling the matrix time taken:  0.0028460025787353516
# solving Ax = b time taken:  0.00031185150146484375
# epoch  86
# assembling the matrix time taken:  0.0035021305084228516
# solving Ax = b time taken:  0.00022292137145996094
# epoch  87
# assembling the matrix time taken:  0.003222942352294922
# solving Ax = b time taken:  0.0002980232238769531
# epoch  88
# assembling the matrix time taken:  0.006551027297973633
# solving Ax = b time taken:  0.00030684471130371094
# epoch  89
# assembling the matrix time taken:  0.0034029483795166016
# solving Ax = b time taken:  0.0002796649932861328
# epoch  90
# assembling the matrix time taken:  0.0030891895294189453
# solving Ax = b time taken:  0.0002548694610595703
# epoch  91
# assembling the matrix time taken:  0.003833770751953125
# solving Ax = b time taken:  0.00023508071899414062
# epoch  92
# assembling the matrix time taken:  0.003566265106201172
# solving Ax = b time taken:  0.0002429485321044922
# epoch  93
# assembling the matrix time taken:  0.003326892852783203
# solving Ax = b time taken:  0.0002498626708984375
# epoch  94
# assembling the matrix time taken:  0.0030448436737060547
# solving Ax = b time taken:  0.0002372264862060547
# epoch  95
# assembling the matrix time taken:  0.00308990478515625
# solving Ax = b time taken:  0.0002319812774658203
# epoch  96
# assembling the matrix time taken:  0.002863168716430664
# solving Ax = b time taken:  0.00024175643920898438
# epoch  97
# assembling the matrix time taken:  0.0024759769439697266
# solving Ax = b time taken:  0.0002200603485107422
# epoch  98
# assembling the matrix time taken:  0.0030748844146728516
# solving Ax = b time taken:  0.0002770423889160156
# epoch  99
# assembling the matrix time taken:  0.0036711692810058594
# solving Ax = b time taken:  0.00031304359436035156
# epoch  100
# assembling the matrix time taken:  0.0032050609588623047
# solving Ax = b time taken:  0.00022482872009277344
# epoch  101
# assembling the matrix time taken:  0.0029120445251464844
# solving Ax = b time taken:  0.0002808570861816406
# epoch  102
# assembling the matrix time taken:  0.0035860538482666016
# solving Ax = b time taken:  0.0004918575286865234
# epoch  103
# assembling the matrix time taken:  0.0028760433197021484
# solving Ax = b time taken:  0.00025177001953125
# epoch  104
# assembling the matrix time taken:  0.004148006439208984
# solving Ax = b time taken:  0.00039076805114746094
# epoch  105
# assembling the matrix time taken:  0.005728960037231445
# solving Ax = b time taken:  0.0002586841583251953
# epoch  106
# assembling the matrix time taken:  0.005677938461303711
# solving Ax = b time taken:  0.00026798248291015625
# epoch  107
# assembling the matrix time taken:  0.004380226135253906
# solving Ax = b time taken:  0.000331878662109375
# epoch  108
# assembling the matrix time taken:  0.010036945343017578
# solving Ax = b time taken:  0.0002779960632324219
# epoch  109
# assembling the matrix time taken:  0.006716012954711914
# solving Ax = b time taken:  0.00028705596923828125
# epoch  110
# assembling the matrix time taken:  0.008747100830078125
# solving Ax = b time taken:  0.0005469322204589844
# epoch  111
# assembling the matrix time taken:  0.005454063415527344
# solving Ax = b time taken:  0.0002682209014892578
# epoch  112
# assembling the matrix time taken:  0.006099224090576172
# solving Ax = b time taken:  0.0002980232238769531
# epoch  113
# assembling the matrix time taken:  0.006500959396362305
# solving Ax = b time taken:  0.00033783912658691406
# epoch  114
# assembling the matrix time taken:  0.005529165267944336
# solving Ax = b time taken:  0.0002570152282714844
# epoch  115
# assembling the matrix time taken:  0.011786937713623047
# solving Ax = b time taken:  0.0003688335418701172
# epoch  116
# assembling the matrix time taken:  0.006618022918701172
# solving Ax = b time taken:  0.0002579689025878906
# epoch  117
# assembling the matrix time taken:  0.00960993766784668
# solving Ax = b time taken:  0.0006029605865478516
# epoch  118
# assembling the matrix time taken:  0.008862972259521484
# solving Ax = b time taken:  0.00026679039001464844
# epoch  119
# assembling the matrix time taken:  0.00466609001159668
# solving Ax = b time taken:  0.00028967857360839844
# epoch  120
# assembling the matrix time taken:  0.006300210952758789
# solving Ax = b time taken:  0.00027489662170410156
# epoch  121
# assembling the matrix time taken:  0.004729747772216797
# solving Ax = b time taken:  0.0002770423889160156
# epoch  122
# assembling the matrix time taken:  0.005570888519287109
# solving Ax = b time taken:  0.0003039836883544922
# epoch  123
# assembling the matrix time taken:  0.004087686538696289
# solving Ax = b time taken:  0.0002789497375488281
# epoch  124
# assembling the matrix time taken:  0.0036020278930664062
# solving Ax = b time taken:  0.0002677440643310547
# epoch  125
# assembling the matrix time taken:  0.004900932312011719
# solving Ax = b time taken:  0.0002827644348144531
# epoch  126
# assembling the matrix time taken:  0.0048372745513916016
# solving Ax = b time taken:  0.000591278076171875
# epoch  127
# assembling the matrix time taken:  0.004954099655151367
# solving Ax = b time taken:  0.00029206275939941406
# epoch  128
# assembling the matrix time taken:  0.003639698028564453
# solving Ax = b time taken:  0.0002849102020263672
# neuron num 		 error 		 order
# 4 		 9.030018 		 *
#
# 8 		 6.385628 		 0.499900
#
# 16 		 4.329298 		 0.560695
#
# 32 		 1.020454 		 2.084923
#
# 64 		 0.223305 		 2.192120
#
# 128 		 0.055327 		 2.012962
#
# neuron num  & 	 $\|u-u_n \|_{L^2}$ & 	 order $O(n^{-2.00})$  \\ \hline \hline
# 4 		 & 9.030018 &		 *  \\ \hline
#
# 8 		 &  6.386e+00 &  		 0.50 \\ \hline
#
# 16 		 &  4.329e+00 &  		 0.56 \\ \hline
#
# 32 		 &  1.020e+00 &  		 2.08 \\ \hline
#
# 64 		 &  2.233e-01 &  		 2.19 \\ \hline
#
# 128 		 &  5.533e-02 &  		 2.01 \\ \hline

# %%
plot_solution_adaptive(0, 1, my_model, target, name=None)
