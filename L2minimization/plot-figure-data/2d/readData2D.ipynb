# %%
import torch
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Times New Roman"
import numpy as np
import torch.nn as nn 
import torch.nn.functional as F

class model(nn.Module):
    """ ReLU k shallow neural network
    Parameters: 
    input size: input dimension
    hidden_size1 : number of hidden layers 
    num_classes: output classes 
    k: degree of relu functions
    """
    def __init__(self, input_size, hidden_size1, num_classes,k = 1):
        super().__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, num_classes,bias = False)
        self.k = k 
    def forward(self, x):
        u1 = self.fc2(F.relu(self.fc1(x))**self.k)
        return u1

def print_convergence_order(err, neuron_num_exponent): 

    neuron_nums = [2**j for j in range(2,neuron_num_exponent)]
    err_list = [err[i] for i in neuron_nums ] 

    print("neuron num \t\t error \t\t order")
    for i, item in enumerate(err_list):
        if i == 0: 
            print(neuron_nums[i], end = "\t\t")
            print(item, end = "\t\t")
            print("*")
        else: 
            print(neuron_nums[i], end = "\t\t")
            print(item, end = "\t\t") 
            print(np.log(err_list[i-1]/err_list[i])/np.log(2))

# %%
def plot_err_vs_neurons(k,d,err_list_relu_4_rand,err_list_relu_4_deterministic,filename, fig_title, exponent = 9, save = False, rescale_ref = 1.5):
    """ Neuron numbers 2^2, 2^3, 2^4, ..., 2^9. 
    """
    rate = -1/2 - (2 * k + 1)/(2 * d)

    f_size = 12  # Increased font size
    line_width = 2  # Thickness of the lines
    # Set global font size
    plt.rcParams.update({'font.size': f_size})

    neuron_nums = np.array([2**j for j in range(2,exponent+1)])  
    rand_size_exp_list = [6,7,8,9,10] 
#     rand_size_exp_list = [10,12,14,16]
    # dictionary_size_list= [[2**3,2**3,2**2,2**2], [2**3,2**3,2**3,2**3],[2**4,2**4,2**3,2**3],[2**4,2**4,2**4,2**4]]
    dictionary_size_exp_list = [10,12,14,16]

    plt.figure(dpi = 400)
    x = np.array(range(4, 2**exponent+1))
    ref = err_list_relu_4_rand[0][2**2]* (x/ 4)**(rate)*rescale_ref

    plt.plot(x,ref,'-.',linewidth=line_width,label = '$O(n^{{{}}})$'.format(rate))

    for i, err in enumerate(err_list_relu_4_rand): 
        if rand_size_exp_list[i] == 7 or rand_size_exp_list[i] == 9:
            continue
        plt.plot(neuron_nums, err[neuron_nums],'.-',linewidth=line_width,
                 label = "Randomized $2^{{{}}}$".format(rand_size_exp_list[i]))

    for i, err in enumerate(err_list_relu_4_deterministic): 
        plt.plot(neuron_nums, err[neuron_nums],'.-.', linewidth=line_width,
                label = "Deterministic $2^{{{}}}$ ".format(dictionary_size_exp_list[i])) 

    plt.title( fig_title+"   ReLU$^{}$ dictionary".format(k))
    plt.yscale('log')
    plt.xscale('log')
    # plt.grid("True")
    plt.xlabel("Iteration number $n$")
    plt.ylabel("$L^2$ error $||u-u_n||$")
    plt.xticks(neuron_nums,[rf"$2^{{{ns}}}$" for ns in range(2,exponent+1)])
    plt.legend(loc='lower left')    

    if save:
        plt.savefig(filename) 
    else:
        plt.show()
    return 0 
## plot results 
## read data: 
## plot results 
## read data:

# %%
folder = 'data/'
# experiment_label = 'ex1'
err_list_relu_4_rand = []
function_name = "gabor2d" 


for k in [1]: 
    for N0 in [2*3,2**4,2**5,2**6,2**7]:  
        s = 2**3
        exponent = 9  
        num_epochs=  2**exponent 
        print("relu {}, dict size {}".format(k,s * N0))
        
        filename = folder + 'err_OGA_2D_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,num_epochs,s*N0)
        
        err = torch.load(filename)  
        err_list_relu_4_rand.append(err) 
        print_convergence_order(err,exponent+1) 
               

print("deterministic dictionary")
# print() 
err_list_relu_4_deterministic = []
        
for k in [1]: 
    for N_list in  [[2**5,2**5],[2**6,2**6],[2**7,2**7]]: 
        N = np.prod(N_list)
        exponent = 9  
        num_epochs=  2**exponent 
        print("relu {}, dict size {}".format(k,N))

        filename = folder + 'err_OGA_2D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        err = torch.load(filename)   
        err_list_relu_4_deterministic.append(err) 
        print_convergence_order(err,exponent+1)
# Out:
# relu 1, dict size 48
# neuron num 		 error 		 order
# 4		tensor(0.1880, dtype=torch.float64)		*
# 8		tensor(0.1872, dtype=torch.float64)		tensor(0.0059, dtype=torch.float64)
# 16		tensor(0.1812, dtype=torch.float64)		tensor(0.0469, dtype=torch.float64)
# 32		tensor(0.1742, dtype=torch.float64)		tensor(0.0574, dtype=torch.float64)
# 64		tensor(0.1188, dtype=torch.float64)		tensor(0.5517, dtype=torch.float64)
# 128		tensor(0.0581, dtype=torch.float64)		tensor(1.0323, dtype=torch.float64)
# 256		tensor(0.0206, dtype=torch.float64)		tensor(1.4947, dtype=torch.float64)
# 512		tensor(0.0088, dtype=torch.float64)		tensor(1.2318, dtype=torch.float64)
# relu 1, dict size 128
# neuron num 		 error 		 order
# 4		tensor(0.1880, dtype=torch.float64)		*
# 8		tensor(0.1878, dtype=torch.float64)		tensor(0.0014, dtype=torch.float64)
# 16		tensor(0.1853, dtype=torch.float64)		tensor(0.0195, dtype=torch.float64)
# 32		tensor(0.1447, dtype=torch.float64)		tensor(0.3568, dtype=torch.float64)
# 64		tensor(0.1090, dtype=torch.float64)		tensor(0.4087, dtype=torch.float64)
# 128		tensor(0.0429, dtype=torch.float64)		tensor(1.3435, dtype=torch.float64)
# 256		tensor(0.0164, dtype=torch.float64)		tensor(1.3849, dtype=torch.float64)
# 512		tensor(0.0070, dtype=torch.float64)		tensor(1.2408, dtype=torch.float64)
# relu 1, dict size 256
# neuron num 		 error 		 order
# 4		tensor(0.1879, dtype=torch.float64)		*
# 8		tensor(0.1876, dtype=torch.float64)		tensor(0.0030, dtype=torch.float64)
# 16		tensor(0.1658, dtype=torch.float64)		tensor(0.1777, dtype=torch.float64)
# 32		tensor(0.1132, dtype=torch.float64)		tensor(0.5502, dtype=torch.float64)
# 64		tensor(0.0632, dtype=torch.float64)		tensor(0.8421, dtype=torch.float64)
# 128		tensor(0.0302, dtype=torch.float64)		tensor(1.0643, dtype=torch.float64)
# 256		tensor(0.0133, dtype=torch.float64)		tensor(1.1858, dtype=torch.float64)
# 512		tensor(0.0053, dtype=torch.float64)		tensor(1.3152, dtype=torch.float64)
# relu 1, dict size 512
# neuron num 		 error 		 order
# 4		tensor(0.1877, dtype=torch.float64)		*
# 8		tensor(0.1855, dtype=torch.float64)		tensor(0.0165, dtype=torch.float64)
# 16		tensor(0.1811, dtype=torch.float64)		tensor(0.0349, dtype=torch.float64)
# 32		tensor(0.1332, dtype=torch.float64)		tensor(0.4429, dtype=torch.float64)
# 64		tensor(0.0773, dtype=torch.float64)		tensor(0.7845, dtype=torch.float64)
# 128		tensor(0.0363, dtype=torch.float64)		tensor(1.0894, dtype=torch.float64)
# 256		tensor(0.0123, dtype=torch.float64)		tensor(1.5624, dtype=torch.float64)
# 512		tensor(0.0048, dtype=torch.float64)		tensor(1.3696, dtype=torch.float64)
# relu 1, dict size 1024
# neuron num 		 error 		 order
# 4		tensor(0.1874, dtype=torch.float64)		*
# 8		tensor(0.1836, dtype=torch.float64)		tensor(0.0293, dtype=torch.float64)
# 16		tensor(0.1714, dtype=torch.float64)		tensor(0.0994, dtype=torch.float64)
# 32		tensor(0.1299, dtype=torch.float64)		tensor(0.3999, dtype=torch.float64)
# 64		tensor(0.0851, dtype=torch.float64)		tensor(0.6102, dtype=torch.float64)
# 128		tensor(0.0291, dtype=torch.float64)		tensor(1.5491, dtype=torch.float64)
# 256		tensor(0.0116, dtype=torch.float64)		tensor(1.3218, dtype=torch.float64)
# 512		tensor(0.0045, dtype=torch.float64)		tensor(1.3781, dtype=torch.float64)
# deterministic dictionary
# relu 1, dict size 1024
# neuron num 		 error 		 order
# 4		tensor(0.1878, dtype=torch.float64)		*
# 8		tensor(0.1859, dtype=torch.float64)		tensor(0.0150, dtype=torch.float64)
# 16		tensor(0.1855, dtype=torch.float64)		tensor(0.0033, dtype=torch.float64)
# 32		tensor(0.1836, dtype=torch.float64)		tensor(0.0143, dtype=torch.float64)
# 64		tensor(0.1812, dtype=torch.float64)		tensor(0.0191, dtype=torch.float64)
# 128		tensor(0.1804, dtype=torch.float64)		tensor(0.0069, dtype=torch.float64)
# 256		tensor(0.1802, dtype=torch.float64)		tensor(0.0010, dtype=torch.float64)
# 512		tensor(0.1802, dtype=torch.float64)		tensor(0., dtype=torch.float64)
# relu 1, dict size 4096
# neuron num 		 error 		 order
# 4		tensor(0.1868, dtype=torch.float64)		*
# 8		tensor(0.1743, dtype=torch.float64)		tensor(0.0997, dtype=torch.float64)
# 16		tensor(0.1372, dtype=torch.float64)		tensor(0.3451, dtype=torch.float64)
# 32		tensor(0.1185, dtype=torch.float64)		tensor(0.2120, dtype=torch.float64)
# 64		tensor(0.0676, dtype=torch.float64)		tensor(0.8098, dtype=torch.float64)
# 128		tensor(0.0502, dtype=torch.float64)		tensor(0.4275, dtype=torch.float64)
# 256		tensor(0.0496, dtype=torch.float64)		tensor(0.0178, dtype=torch.float64)
# 512		tensor(0.0496, dtype=torch.float64)		tensor(0.0012, dtype=torch.float64)
# relu 1, dict size 16384
# neuron num 		 error 		 order
# 4		tensor(0.1859, dtype=torch.float64)		*
# 8		tensor(0.1628, dtype=torch.float64)		tensor(0.1916, dtype=torch.float64)
# 16		tensor(0.1524, dtype=torch.float64)		tensor(0.0952, dtype=torch.float64)
# 32		tensor(0.1236, dtype=torch.float64)		tensor(0.3019, dtype=torch.float64)
# 64		tensor(0.0689, dtype=torch.float64)		tensor(0.8445, dtype=torch.float64)
# 128		tensor(0.0247, dtype=torch.float64)		tensor(1.4783, dtype=torch.float64)
# 256		tensor(0.0108, dtype=torch.float64)		tensor(1.1970, dtype=torch.float64)
# 512		tensor(0.0067, dtype=torch.float64)		tensor(0.6934, dtype=torch.float64)

# %%
filename = "2D_gabor_rand_deter_relu1_Dict_compare.png"
k = 1
d = 2
fig_title = "Gabor function "
save = False 
plot_err_vs_neurons(k,d,err_list_relu_4_rand,err_list_relu_4_deterministic,filename, fig_title, exponent = 9, save = save, rescale_ref= 13.5)
# Out:
# 0

# %%
## read sinpix data 
folder = 'data2/'
# experiment_label = 'ex1'
err_list_relu_4_rand = []
function_name = "sinpix2d" 


for k in [1]: 
    for N0 in [2**6,2**7,2**8,2**9,2**10]:  
        s = 1 
        exponent = 9  
        num_epochs=  2**exponent 
        print("relu {}, dict size {}".format(k,s * N0))
        
        filename = folder + 'err_OGA_2D_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,num_epochs,s*N0)
        
        err = torch.load(filename)  
        err_list_relu_4_rand.append(err) 
        print_convergence_order(err,exponent+1) 
               

print("deterministic dictionary")
# print() 
err_list_relu_4_deterministic = []
        
for k in [1]: 
    for N_list in  [[2**5,2**5],[2**6,2**6],[2**7,2**7]]: 
        N = np.prod(N_list)
        exponent = 9  
        num_epochs=  2**exponent 
        print("relu {}, dict size {}".format(k,N))

        filename = folder + 'err_OGA_2D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        err = torch.load(filename)   
        err_list_relu_4_deterministic.append(err) 
        print_convergence_order(err,exponent+1)
# Out:
# relu 1, dict size 64
# neuron num 		 error 		 order
# 4		tensor(0.2250, dtype=torch.float64)		*
# 8		tensor(0.0649, dtype=torch.float64)		tensor(1.7929, dtype=torch.float64)
# 16		tensor(0.0270, dtype=torch.float64)		tensor(1.2661, dtype=torch.float64)
# 32		tensor(0.0088, dtype=torch.float64)		tensor(1.6196, dtype=torch.float64)
# 64		tensor(0.0040, dtype=torch.float64)		tensor(1.1310, dtype=torch.float64)
# 128		tensor(0.0017, dtype=torch.float64)		tensor(1.2220, dtype=torch.float64)
# 256		tensor(0.0007, dtype=torch.float64)		tensor(1.3051, dtype=torch.float64)
# 512		tensor(0.0003, dtype=torch.float64)		tensor(1.4304, dtype=torch.float64)
# relu 1, dict size 128
# neuron num 		 error 		 order
# 4		tensor(0.2200, dtype=torch.float64)		*
# 8		tensor(0.0571, dtype=torch.float64)		tensor(1.9454, dtype=torch.float64)
# 16		tensor(0.0261, dtype=torch.float64)		tensor(1.1313, dtype=torch.float64)
# 32		tensor(0.0106, dtype=torch.float64)		tensor(1.3013, dtype=torch.float64)
# 64		tensor(0.0046, dtype=torch.float64)		tensor(1.1970, dtype=torch.float64)
# 128		tensor(0.0016, dtype=torch.float64)		tensor(1.5465, dtype=torch.float64)
# 256		tensor(0.0006, dtype=torch.float64)		tensor(1.3701, dtype=torch.float64)
# 512		tensor(0.0002, dtype=torch.float64)		tensor(1.3238, dtype=torch.float64)
# relu 1, dict size 256
# neuron num 		 error 		 order
# 4		tensor(0.1995, dtype=torch.float64)		*
# 8		tensor(0.0532, dtype=torch.float64)		tensor(1.9082, dtype=torch.float64)
# 16		tensor(0.0242, dtype=torch.float64)		tensor(1.1380, dtype=torch.float64)
# 32		tensor(0.0094, dtype=torch.float64)		tensor(1.3655, dtype=torch.float64)
# 64		tensor(0.0039, dtype=torch.float64)		tensor(1.2487, dtype=torch.float64)
# 128		tensor(0.0015, dtype=torch.float64)		tensor(1.3770, dtype=torch.float64)
# 256		tensor(0.0006, dtype=torch.float64)		tensor(1.4317, dtype=torch.float64)
# 512		tensor(0.0002, dtype=torch.float64)		tensor(1.2762, dtype=torch.float64)
# relu 1, dict size 512
# neuron num 		 error 		 order
# 4		tensor(0.2102, dtype=torch.float64)		*
# 8		tensor(0.0426, dtype=torch.float64)		tensor(2.3023, dtype=torch.float64)
# 16		tensor(0.0216, dtype=torch.float64)		tensor(0.9776, dtype=torch.float64)
# 32		tensor(0.0080, dtype=torch.float64)		tensor(1.4311, dtype=torch.float64)
# 64		tensor(0.0034, dtype=torch.float64)		tensor(1.2231, dtype=torch.float64)
# 128		tensor(0.0013, dtype=torch.float64)		tensor(1.3506, dtype=torch.float64)
# 256		tensor(0.0005, dtype=torch.float64)		tensor(1.3224, dtype=torch.float64)
# 512		tensor(0.0002, dtype=torch.float64)		tensor(1.3168, dtype=torch.float64)
# relu 1, dict size 1024
# neuron num 		 error 		 order
# 4		tensor(0.2160, dtype=torch.float64)		*
# 8		tensor(0.0385, dtype=torch.float64)		tensor(2.4873, dtype=torch.float64)
# 16		tensor(0.0206, dtype=torch.float64)		tensor(0.9058, dtype=torch.float64)
# 32		tensor(0.0070, dtype=torch.float64)		tensor(1.5626, dtype=torch.float64)
# 64		tensor(0.0034, dtype=torch.float64)		tensor(1.0446, dtype=torch.float64)
# 128		tensor(0.0013, dtype=torch.float64)		tensor(1.4254, dtype=torch.float64)
# 256		tensor(0.0005, dtype=torch.float64)		tensor(1.3341, dtype=torch.float64)
# 512		tensor(0.0002, dtype=torch.float64)		tensor(1.3702, dtype=torch.float64)
# deterministic dictionary
# relu 1, dict size 1024
# neuron num 		 error 		 order
# 4		tensor(0.2003, dtype=torch.float64)		*
# 8		tensor(0.0458, dtype=torch.float64)		tensor(2.1282, dtype=torch.float64)
# 16		tensor(0.0209, dtype=torch.float64)		tensor(1.1343, dtype=torch.float64)
# 32		tensor(0.0099, dtype=torch.float64)		tensor(1.0801, dtype=torch.float64)
# 64		tensor(0.0033, dtype=torch.float64)		tensor(1.5608, dtype=torch.float64)
# 128		tensor(0.0018, dtype=torch.float64)		tensor(0.9311, dtype=torch.float64)
# 256		tensor(0.0015, dtype=torch.float64)		tensor(0.2645, dtype=torch.float64)
# 512		tensor(0.0015, dtype=torch.float64)		tensor(2.8831e-15, dtype=torch.float64)
# relu 1, dict size 4096
# neuron num 		 error 		 order
# 4		tensor(0.2075, dtype=torch.float64)		*
# 8		tensor(0.0395, dtype=torch.float64)		tensor(2.3946, dtype=torch.float64)
# 16		tensor(0.0219, dtype=torch.float64)		tensor(0.8489, dtype=torch.float64)
# 32		tensor(0.0082, dtype=torch.float64)		tensor(1.4170, dtype=torch.float64)
# 64		tensor(0.0033, dtype=torch.float64)		tensor(1.3339, dtype=torch.float64)
# 128		tensor(0.0012, dtype=torch.float64)		tensor(1.4744, dtype=torch.float64)
# 256		tensor(0.0005, dtype=torch.float64)		tensor(1.1278, dtype=torch.float64)
# 512		tensor(0.0003, dtype=torch.float64)		tensor(0.8442, dtype=torch.float64)
# relu 1, dict size 16384
# neuron num 		 error 		 order
# 4		tensor(0.2054, dtype=torch.float64)		*
# 8		tensor(0.0407, dtype=torch.float64)		tensor(2.3367, dtype=torch.float64)
# 16		tensor(0.0182, dtype=torch.float64)		tensor(1.1608, dtype=torch.float64)
# 32		tensor(0.0061, dtype=torch.float64)		tensor(1.5858, dtype=torch.float64)
# 64		tensor(0.0028, dtype=torch.float64)		tensor(1.1036, dtype=torch.float64)
# 128		tensor(0.0012, dtype=torch.float64)		tensor(1.1967, dtype=torch.float64)
# 256		tensor(0.0005, dtype=torch.float64)		tensor(1.4209, dtype=torch.float64)
# 512		tensor(0.0002, dtype=torch.float64)		tensor(1.4482, dtype=torch.float64)

# %%
filename = "2D_sinpix_rand_deter_relu1_Dict_compare.png"
k = 1
d = 2
fig_title = "$\sin(\pi x_1)\sin(\pi x_2)$ "
save = True 
plot_err_vs_neurons(k,d,err_list_relu_4_rand,err_list_relu_4_deterministic,filename, fig_title, exponent = 9, save = save, rescale_ref= 1.5)
# Out:
# 0
