# %%
import torch
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Times New Roman"
import numpy as np
import torch.nn as nn 
import torch.nn.functional as F

class model(nn.Module):
    """ ReLU k shallow neural network
    Parameters: 
    input size: input dimension
    hidden_size1 : number of hidden layers 
    num_classes: output classes 
    k: degree of relu functions
    """
    def __init__(self, input_size, hidden_size1, num_classes,k = 1):
        super().__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, num_classes,bias = False)
        self.k = k 
    def forward(self, x):
        u1 = self.fc2(F.relu(self.fc1(x))**self.k)
        return u1

def print_convergence_order(err, neuron_num_exponent): 

    neuron_nums = [2**j for j in range(2,neuron_num_exponent)]
    err_list = [err[i] for i in neuron_nums ] 

    print("neuron num \t\t error \t\t order")
    for i, item in enumerate(err_list):
        if i == 0: 
            print(neuron_nums[i], end = "\t\t")
            print(item, end = "\t\t")
            print("*")
        else: 
            print(neuron_nums[i], end = "\t\t")
            print(item, end = "\t\t") 
            print(np.log(err_list[i-1]/err_list[i])/np.log(2))

# %%
folder = 'data2/'
# experiment_label = 'ex1'
err_list_relu_4_rand = []
function_name = "sine1d" 


for k in [1]: 
    for N in [2**6, 2**7, 2**8,2**9,2**10]: 
        s = 1 
        exponent = 9  
        num_epochs=  2**exponent 
        print("relu {}, dict size {}".format(k,N))
        
        filename = folder + 'err_OGA_1D_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,num_epochs,N)
        
        err = torch.load(filename)  
        err_list_relu_4_rand.append(err) 
        print_convergence_order(err,exponent+1) 
               

print("deterministic dictionary")
# print() 
err_list_relu_4_deterministic = []
        
for k in [1]: 
    for N in  [2**10, 2**12, 2**14]: 
        exponent = 9  
        num_epochs=  2**exponent 
        print("relu {}, dict size {}".format(k,N))

        filename = folder + 'err_OGA_1D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        err = torch.load(filename)   
        err_list_relu_4_deterministic.append(err) 
        print_convergence_order(err,exponent+1)
# Out:
# relu 1, dict size 64
# neuron num 		 error 		 order
# 4		tensor(0.1130, dtype=torch.float64)		*
# 8		tensor(0.0248, dtype=torch.float64)		tensor(2.1894, dtype=torch.float64)
# 16		tensor(0.0070, dtype=torch.float64)		tensor(1.8203, dtype=torch.float64)
# 32		tensor(0.0017, dtype=torch.float64)		tensor(2.0327, dtype=torch.float64)
# 64		tensor(0.0004, dtype=torch.float64)		tensor(2.2567, dtype=torch.float64)
# 128		tensor(0.0002, dtype=torch.float64)		tensor(1.2012, dtype=torch.float64)
# 256		tensor(3.0531e-05, dtype=torch.float64)		tensor(2.3531, dtype=torch.float64)
# 512		tensor(1.0061e-05, dtype=torch.float64)		tensor(1.6015, dtype=torch.float64)
# relu 1, dict size 128
# neuron num 		 error 		 order
# 4		tensor(0.1100, dtype=torch.float64)		*
# 8		tensor(0.0249, dtype=torch.float64)		tensor(2.1463, dtype=torch.float64)
# 16		tensor(0.0079, dtype=torch.float64)		tensor(1.6573, dtype=torch.float64)
# 32		tensor(0.0015, dtype=torch.float64)		tensor(2.3997, dtype=torch.float64)
# 64		tensor(0.0006, dtype=torch.float64)		tensor(1.2323, dtype=torch.float64)
# 128		tensor(7.8620e-05, dtype=torch.float64)		tensor(3.0152, dtype=torch.float64)
# 256		tensor(2.0719e-05, dtype=torch.float64)		tensor(1.9240, dtype=torch.float64)
# 512		tensor(9.6141e-06, dtype=torch.float64)		tensor(1.1077, dtype=torch.float64)
# relu 1, dict size 256
# neuron num 		 error 		 order
# 4		tensor(0.1129, dtype=torch.float64)		*
# 8		tensor(0.0264, dtype=torch.float64)		tensor(2.0974, dtype=torch.float64)
# 16		tensor(0.0072, dtype=torch.float64)		tensor(1.8695, dtype=torch.float64)
# 32		tensor(0.0013, dtype=torch.float64)		tensor(2.4466, dtype=torch.float64)
# 64		tensor(0.0003, dtype=torch.float64)		tensor(2.1054, dtype=torch.float64)
# 128		tensor(8.8725e-05, dtype=torch.float64)		tensor(1.7952, dtype=torch.float64)
# 256		tensor(3.5855e-05, dtype=torch.float64)		tensor(1.3072, dtype=torch.float64)
# 512		tensor(5.8171e-06, dtype=torch.float64)		tensor(2.6238, dtype=torch.float64)
# relu 1, dict size 512
# neuron num 		 error 		 order
# 4		tensor(0.1122, dtype=torch.float64)		*
# 8		tensor(0.0243, dtype=torch.float64)		tensor(2.2095, dtype=torch.float64)
# 16		tensor(0.0055, dtype=torch.float64)		tensor(2.1425, dtype=torch.float64)
# 32		tensor(0.0015, dtype=torch.float64)		tensor(1.8967, dtype=torch.float64)
# 64		tensor(0.0005, dtype=torch.float64)		tensor(1.5144, dtype=torch.float64)
# 128		tensor(0.0001, dtype=torch.float64)		tensor(2.3154, dtype=torch.float64)
# 256		tensor(2.2007e-05, dtype=torch.float64)		tensor(2.2369, dtype=torch.float64)
# 512		tensor(6.7994e-06, dtype=torch.float64)		tensor(1.6945, dtype=torch.float64)
# relu 1, dict size 1024
# neuron num 		 error 		 order
# 4		tensor(0.1118, dtype=torch.float64)		*
# 8		tensor(0.0244, dtype=torch.float64)		tensor(2.1953, dtype=torch.float64)
# 16		tensor(0.0056, dtype=torch.float64)		tensor(2.1169, dtype=torch.float64)
# 32		tensor(0.0018, dtype=torch.float64)		tensor(1.6311, dtype=torch.float64)
# 64		tensor(0.0003, dtype=torch.float64)		tensor(2.5093, dtype=torch.float64)
# 128		tensor(0.0001, dtype=torch.float64)		tensor(1.6166, dtype=torch.float64)
# 256		tensor(1.8424e-05, dtype=torch.float64)		tensor(2.4980, dtype=torch.float64)
# 512		tensor(4.9734e-06, dtype=torch.float64)		tensor(1.8892, dtype=torch.float64)
# deterministic dictionary
# relu 1, dict size 1024
# neuron num 		 error 		 order
# 4		tensor(0.1119, dtype=torch.float64)		*
# 8		tensor(0.0235, dtype=torch.float64)		tensor(2.2511, dtype=torch.float64)
# 16		tensor(0.0050, dtype=torch.float64)		tensor(2.2444, dtype=torch.float64)
# 32		tensor(0.0012, dtype=torch.float64)		tensor(2.0497, dtype=torch.float64)
# 64		tensor(0.0003, dtype=torch.float64)		tensor(1.9686, dtype=torch.float64)
# 128		tensor(7.3196e-05, dtype=torch.float64)		tensor(2.0638, dtype=torch.float64)
# 256		tensor(1.8636e-05, dtype=torch.float64)		tensor(1.9737, dtype=torch.float64)
# 512		tensor(4.8132e-06, dtype=torch.float64)		tensor(1.9530, dtype=torch.float64)
# relu 1, dict size 4096
# neuron num 		 error 		 order
# 4		tensor(0.1125, dtype=torch.float64)		*
# 8		tensor(0.0235, dtype=torch.float64)		tensor(2.2563, dtype=torch.float64)
# 16		tensor(0.0049, dtype=torch.float64)		tensor(2.2543, dtype=torch.float64)
# 32		tensor(0.0012, dtype=torch.float64)		tensor(2.0438, dtype=torch.float64)
# 64		tensor(0.0003, dtype=torch.float64)		tensor(1.9857, dtype=torch.float64)
# 128		tensor(7.2670e-05, dtype=torch.float64)		tensor(2.0556, dtype=torch.float64)
# 256		tensor(1.7956e-05, dtype=torch.float64)		tensor(2.0169, dtype=torch.float64)
# 512		tensor(4.4842e-06, dtype=torch.float64)		tensor(2.0016, dtype=torch.float64)
# relu 1, dict size 16384
# neuron num 		 error 		 order
# 4		tensor(0.1124, dtype=torch.float64)		*
# 8		tensor(0.0235, dtype=torch.float64)		tensor(2.2557, dtype=torch.float64)
# 16		tensor(0.0049, dtype=torch.float64)		tensor(2.2533, dtype=torch.float64)
# 32		tensor(0.0012, dtype=torch.float64)		tensor(2.0430, dtype=torch.float64)
# 64		tensor(0.0003, dtype=torch.float64)		tensor(1.9602, dtype=torch.float64)
# 128		tensor(7.2785e-05, dtype=torch.float64)		tensor(2.0802, dtype=torch.float64)
# 256		tensor(1.7905e-05, dtype=torch.float64)		tensor(2.0233, dtype=torch.float64)
# 512		tensor(4.4661e-06, dtype=torch.float64)		tensor(2.0033, dtype=torch.float64)

# %%
def plot_err_vs_neurons(k,d,err_list_relu_4_rand,err_list_relu_4_deterministic,filename, fig_title, exponent = 9, save = False, rescale_ref = 1.5):
    """ Neuron numbers 2^2, 2^3, 2^4, ..., 2^9. 
    """
    rate = -1/2 - (2 * k + 1)/(2 * d)

    f_size = 12  # Increased font size
    line_width = 2  # Thickness of the lines
    # Set global font size
    plt.rcParams.update({'font.size': f_size})

    neuron_nums = np.array([2**j for j in range(2,exponent+1)])  
    rand_size_exp_list = [6,7,8,9,10] 
#     rand_size_exp_list = [10,12,14,16]
    # dictionary_size_list= [[2**3,2**3,2**2,2**2], [2**3,2**3,2**3,2**3],[2**4,2**4,2**3,2**3],[2**4,2**4,2**4,2**4]]
    dictionary_size_exp_list = [10,12,14,16]

    plt.figure(dpi = 400)
    x = np.array(range(4, 2**exponent+1))
    ref = err_list_relu_4_rand[0][2**2]* (x/ 4)**(rate)*rescale_ref

    plt.plot(x,ref,'-.',linewidth=line_width,label = '$O(n^{{{}}})$'.format(int(rate)))

    for i, err in enumerate(err_list_relu_4_rand): 
        if rand_size_exp_list[i] == 7 or rand_size_exp_list[i] == 9:
            continue
        plt.plot(neuron_nums, err[neuron_nums],'.-',linewidth=line_width, 
                 label = "Randomized $2^{{{}}}$".format(rand_size_exp_list[i]))

    for i, err in enumerate(err_list_relu_4_deterministic): 
        if i == 0: 
            plt.plot(neuron_nums, err[neuron_nums],'.-.',linewidth=line_width, 
                    label = "Deterministic $2^{{{}}}$ ".format(dictionary_size_exp_list[i])) 

    plt.title( fig_title+"   ReLU$^{}$ dictionary".format(k))
    plt.yscale('log')
    plt.xscale('log')
    # plt.grid("True")
    plt.xlabel("Iteration number $n$")
    plt.ylabel("$L^2$ error $||f-f_n||$")
    plt.xticks(neuron_nums,[rf"$2^{{{ns}}}$" for ns in range(2,exponent+1)])
    plt.legend(loc='lower left')    

    if save:
        plt.savefig(filename) 
    else:
        plt.show()
    return 0 
## plot results 
## read data: 

filename = "1D_sine_rand_deter_relu1_Dict_compare.png"
k = 1
d = 1 
fig_title = "$\sin(2\pi x)$ "
save = True 
plot_err_vs_neurons(k,d,err_list_relu_4_rand,err_list_relu_4_deterministic,filename, fig_title, exponent = 9, save = save)
# Out:
# 0

# %%
folder = 'data2/'
# experiment_label = 'ex1'
err_list_relu_4_rand = []
function_name = "gabor1d" 


for k in [1]: 
    for N in [2**6, 2**7, 2**8,2**9,2**10]: 
        s = 1 
        exponent = 9  
        num_epochs=  2**exponent 
        print("relu {}, dict size {}".format(k,N))
        
        filename = folder + 'err_OGA_1D_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,num_epochs,N)
        
        err = torch.load(filename)  
        err_list_relu_4_rand.append(err) 
        print_convergence_order(err,exponent+1) 
               

print("deterministic dictionary")
# print() 
err_list_relu_4_deterministic = []
        
for k in [1]: 
    for N in  [2**10, 2**12, 2**14]: 
        exponent = 9  
        num_epochs=  2**exponent 
        print("relu {}, dict size {}".format(k,N))

        filename = folder + 'err_OGA_1D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        err = torch.load(filename)   
        err_list_relu_4_deterministic.append(err) 
        print_convergence_order(err,exponent+1)
# Out:
# relu 1, dict size 64
# neuron num 		 error 		 order
# 4		tensor(0.4271, dtype=torch.float64)		*
# 8		tensor(0.2891, dtype=torch.float64)		tensor(0.5631, dtype=torch.float64)
# 16		tensor(0.1252, dtype=torch.float64)		tensor(1.2078, dtype=torch.float64)
# 32		tensor(0.0400, dtype=torch.float64)		tensor(1.6468, dtype=torch.float64)
# 64		tensor(0.0103, dtype=torch.float64)		tensor(1.9539, dtype=torch.float64)
# 128		tensor(0.0026, dtype=torch.float64)		tensor(1.9862, dtype=torch.float64)
# 256		tensor(0.0006, dtype=torch.float64)		tensor(2.1258, dtype=torch.float64)
# 512		tensor(0.0002, dtype=torch.float64)		tensor(1.9214, dtype=torch.float64)
# relu 1, dict size 128
# neuron num 		 error 		 order
# 4		tensor(0.4276, dtype=torch.float64)		*
# 8		tensor(0.3087, dtype=torch.float64)		tensor(0.4702, dtype=torch.float64)
# 16		tensor(0.1336, dtype=torch.float64)		tensor(1.2079, dtype=torch.float64)
# 32		tensor(0.0461, dtype=torch.float64)		tensor(1.5342, dtype=torch.float64)
# 64		tensor(0.0097, dtype=torch.float64)		tensor(2.2450, dtype=torch.float64)
# 128		tensor(0.0023, dtype=torch.float64)		tensor(2.0512, dtype=torch.float64)
# 256		tensor(0.0006, dtype=torch.float64)		tensor(1.9926, dtype=torch.float64)
# 512		tensor(0.0002, dtype=torch.float64)		tensor(1.9672, dtype=torch.float64)
# relu 1, dict size 256
# neuron num 		 error 		 order
# 4		tensor(0.4283, dtype=torch.float64)		*
# 8		tensor(0.2948, dtype=torch.float64)		tensor(0.5389, dtype=torch.float64)
# 16		tensor(0.1191, dtype=torch.float64)		tensor(1.3069, dtype=torch.float64)
# 32		tensor(0.0387, dtype=torch.float64)		tensor(1.6208, dtype=torch.float64)
# 64		tensor(0.0084, dtype=torch.float64)		tensor(2.2073, dtype=torch.float64)
# 128		tensor(0.0024, dtype=torch.float64)		tensor(1.8319, dtype=torch.float64)
# 256		tensor(0.0006, dtype=torch.float64)		tensor(2.0330, dtype=torch.float64)
# 512		tensor(0.0001, dtype=torch.float64)		tensor(2.0265, dtype=torch.float64)
# relu 1, dict size 512
# neuron num 		 error 		 order
# 4		tensor(0.4269, dtype=torch.float64)		*
# 8		tensor(0.2874, dtype=torch.float64)		tensor(0.5710, dtype=torch.float64)
# 16		tensor(0.0940, dtype=torch.float64)		tensor(1.6124, dtype=torch.float64)
# 32		tensor(0.0362, dtype=torch.float64)		tensor(1.3779, dtype=torch.float64)
# 64		tensor(0.0077, dtype=torch.float64)		tensor(2.2361, dtype=torch.float64)
# 128		tensor(0.0023, dtype=torch.float64)		tensor(1.7201, dtype=torch.float64)
# 256		tensor(0.0006, dtype=torch.float64)		tensor(2.0756, dtype=torch.float64)
# 512		tensor(0.0001, dtype=torch.float64)		tensor(1.9939, dtype=torch.float64)
# relu 1, dict size 1024
# neuron num 		 error 		 order
# 4		tensor(0.4273, dtype=torch.float64)		*
# 8		tensor(0.2890, dtype=torch.float64)		tensor(0.5644, dtype=torch.float64)
# 16		tensor(0.1085, dtype=torch.float64)		tensor(1.4133, dtype=torch.float64)
# 32		tensor(0.0386, dtype=torch.float64)		tensor(1.4915, dtype=torch.float64)
# 64		tensor(0.0083, dtype=torch.float64)		tensor(2.2129, dtype=torch.float64)
# 128		tensor(0.0022, dtype=torch.float64)		tensor(1.8924, dtype=torch.float64)
# 256		tensor(0.0005, dtype=torch.float64)		tensor(2.0681, dtype=torch.float64)
# 512		tensor(0.0001, dtype=torch.float64)		tensor(1.9437, dtype=torch.float64)
# deterministic dictionary
# relu 1, dict size 1024
# neuron num 		 error 		 order
# 4		tensor(0.4271, dtype=torch.float64)		*
# 8		tensor(0.2888, dtype=torch.float64)		tensor(0.5644, dtype=torch.float64)
# 16		tensor(0.1078, dtype=torch.float64)		tensor(1.4219, dtype=torch.float64)
# 32		tensor(0.0380, dtype=torch.float64)		tensor(1.5033, dtype=torch.float64)
# 64		tensor(0.0073, dtype=torch.float64)		tensor(2.3828, dtype=torch.float64)
# 128		tensor(0.0022, dtype=torch.float64)		tensor(1.7410, dtype=torch.float64)
# 256		tensor(0.0006, dtype=torch.float64)		tensor(1.9264, dtype=torch.float64)
# 512		tensor(0.0002, dtype=torch.float64)		tensor(1.8705, dtype=torch.float64)
# relu 1, dict size 4096
# neuron num 		 error 		 order
# 4		tensor(0.4271, dtype=torch.float64)		*
# 8		tensor(0.2889, dtype=torch.float64)		tensor(0.5640, dtype=torch.float64)
# 16		tensor(0.1078, dtype=torch.float64)		tensor(1.4225, dtype=torch.float64)
# 32		tensor(0.0382, dtype=torch.float64)		tensor(1.4950, dtype=torch.float64)
# 64		tensor(0.0075, dtype=torch.float64)		tensor(2.3549, dtype=torch.float64)
# 128		tensor(0.0021, dtype=torch.float64)		tensor(1.8286, dtype=torch.float64)
# 256		tensor(0.0005, dtype=torch.float64)		tensor(2.0560, dtype=torch.float64)
# 512		tensor(0.0001, dtype=torch.float64)		tensor(1.9530, dtype=torch.float64)
# relu 1, dict size 16384
# neuron num 		 error 		 order
# 4		tensor(0.4272, dtype=torch.float64)		*
# 8		tensor(0.2890, dtype=torch.float64)		tensor(0.5639, dtype=torch.float64)
# 16		tensor(0.1077, dtype=torch.float64)		tensor(1.4242, dtype=torch.float64)
# 32		tensor(0.0381, dtype=torch.float64)		tensor(1.4986, dtype=torch.float64)
# 64		tensor(0.0074, dtype=torch.float64)		tensor(2.3593, dtype=torch.float64)
# 128		tensor(0.0021, dtype=torch.float64)		tensor(1.8201, dtype=torch.float64)
# 256		tensor(0.0005, dtype=torch.float64)		tensor(2.0474, dtype=torch.float64)
# 512		tensor(0.0001, dtype=torch.float64)		tensor(1.9733, dtype=torch.float64)

# %%
filename = "1D_gabor_rand_deter_relu1_Dict_compare.png"
k = 1
d = 1 
fig_title = "1D Gabor "
save = True 
plot_err_vs_neurons(k,d,err_list_relu_4_rand,err_list_relu_4_deterministic,filename, fig_title, exponent = 9, save = save, rescale_ref = 7.5)
# Out:
# 0
