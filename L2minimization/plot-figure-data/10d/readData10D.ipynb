# %%
import torch
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Times New Roman"
import numpy as np
import torch.nn as nn 
import torch.nn.functional as F

class model(nn.Module):
    """ ReLU k shallow neural network
    Parameters: 
    input size: input dimension
    hidden_size1 : number of hidden layers 
    num_classes: output classes 
    k: degree of relu functions
    """
    def __init__(self, input_size, hidden_size1, num_classes,k = 1):
        super().__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, num_classes,bias = False)
        self.k = k 
    def forward(self, x):
        u1 = self.fc2(F.relu(self.fc1(x))**self.k)
        return u1

def print_convergence_order(err, neuron_num_exponent): 

    neuron_nums = [2**j for j in range(2,neuron_num_exponent)]
    err_list = [err[i] for i in neuron_nums ] 

    print("neuron num \t\t error \t\t order")
    for i, item in enumerate(err_list):
        if i == 0: 
            print(neuron_nums[i], end = "\t\t")
            print(item, end = "\t\t")
            print("*")
        else: 
            print(neuron_nums[i], end = "\t\t")
            print(item, end = "\t\t") 
            print(np.log(err_list[i-1]/err_list[i])/np.log(2))

def compute_rate(k,d):
    return 0.5 + (2*k +1)/(2*d)

for k in range(1,6): 
    print(k, compute_rate(k,10))
# Out:
# 1 0.65
# 2 0.75
# 3 0.85
# 4 0.95
# 5 1.05

# %% [markdown]
# ## ex1

# %%
folder = 'ex1/'
experiment_label = 'ex1'
err_list_relu_4_rand = []
for k in [1]: 
    for N0 in [2**7, 2**8, 2**9, 2**10,2**11,2**12,2**13,2**14]: 

        exponent = 9  
        num_epochs=  2**exponent 
        print("relu {}, dict size {}".format(k, N0))

        filename = folder + experiment_label +"_err_randDict_relu_{}_size_{}_num_neurons_{}.pt".format(k, N0,num_epochs)
        err = torch.load(filename)  
        err_list_relu_4_rand.append(err) 
        print_convergence_order(err,exponent+1) 

print("deterministic dictionary")
print() 


folder = 'ex1/'
experiment_label = 'ex1'
err_list_relu_4_rand2 = []
for k in [1]: 
    for N0 in [2**14,2**15,2**16]: 

        exponent = 10 
        num_epochs=  2**exponent 
        print("relu {}, dict size {}".format(k, N0))

        filename = folder + experiment_label +"_err_randDict_relu_{}_size_{}_num_neurons_{}.pt".format(k, N0,num_epochs)
        err = torch.load(filename)  
        err_list_relu_4_rand2.append(err) 
        print_convergence_order(err,exponent+1) 

print("deterministic dictionary")
print()
# Out:
# relu 1, dict size 128
# neuron num 		 error 		 order
# 4		tensor(0.0773, dtype=torch.float64)		*
# 8		tensor(0.0702, dtype=torch.float64)		tensor(0.1389, dtype=torch.float64)
# 16		tensor(0.0626, dtype=torch.float64)		tensor(0.1672, dtype=torch.float64)
# 32		tensor(0.0544, dtype=torch.float64)		tensor(0.2010, dtype=torch.float64)
# 64		tensor(0.0439, dtype=torch.float64)		tensor(0.3097, dtype=torch.float64)
# 128		tensor(0.0340, dtype=torch.float64)		tensor(0.3692, dtype=torch.float64)
# 256		tensor(0.0247, dtype=torch.float64)		tensor(0.4579, dtype=torch.float64)
# 512		tensor(0.0164, dtype=torch.float64)		tensor(0.5948, dtype=torch.float64)
# relu 1, dict size 256
# neuron num 		 error 		 order
# 4		tensor(0.0738, dtype=torch.float64)		*
# 8		tensor(0.0680, dtype=torch.float64)		tensor(0.1187, dtype=torch.float64)
# 16		tensor(0.0611, dtype=torch.float64)		tensor(0.1540, dtype=torch.float64)
# 32		tensor(0.0518, dtype=torch.float64)		tensor(0.2364, dtype=torch.float64)
# 64		tensor(0.0420, dtype=torch.float64)		tensor(0.3035, dtype=torch.float64)
# 128		tensor(0.0294, dtype=torch.float64)		tensor(0.5144, dtype=torch.float64)
# 256		tensor(0.0207, dtype=torch.float64)		tensor(0.5077, dtype=torch.float64)
# 512		tensor(0.0133, dtype=torch.float64)		tensor(0.6411, dtype=torch.float64)
# relu 1, dict size 512
# neuron num 		 error 		 order
# 4		tensor(0.0774, dtype=torch.float64)		*
# 8		tensor(0.0719, dtype=torch.float64)		tensor(0.1068, dtype=torch.float64)
# 16		tensor(0.0597, dtype=torch.float64)		tensor(0.2683, dtype=torch.float64)
# 32		tensor(0.0507, dtype=torch.float64)		tensor(0.2362, dtype=torch.float64)
# 64		tensor(0.0393, dtype=torch.float64)		tensor(0.3662, dtype=torch.float64)
# 128		tensor(0.0267, dtype=torch.float64)		tensor(0.5593, dtype=torch.float64)
# 256		tensor(0.0166, dtype=torch.float64)		tensor(0.6846, dtype=torch.float64)
# 512		tensor(0.0100, dtype=torch.float64)		tensor(0.7260, dtype=torch.float64)
# relu 1, dict size 1024
# neuron num 		 error 		 order
# 4		tensor(0.0772, dtype=torch.float64)		*
# 8		tensor(0.0701, dtype=torch.float64)		tensor(0.1402, dtype=torch.float64)
# 16		tensor(0.0589, dtype=torch.float64)		tensor(0.2512, dtype=torch.float64)
# 32		tensor(0.0472, dtype=torch.float64)		tensor(0.3200, dtype=torch.float64)
# 64		tensor(0.0343, dtype=torch.float64)		tensor(0.4589, dtype=torch.float64)
# 128		tensor(0.0215, dtype=torch.float64)		tensor(0.6723, dtype=torch.float64)
# 256		tensor(0.0129, dtype=torch.float64)		tensor(0.7387, dtype=torch.float64)
# 512		tensor(0.0078, dtype=torch.float64)		tensor(0.7201, dtype=torch.float64)
# relu 1, dict size 2048
# neuron num 		 error 		 order
# 4		tensor(0.0765, dtype=torch.float64)		*
# 8		tensor(0.0711, dtype=torch.float64)		tensor(0.1055, dtype=torch.float64)
# 16		tensor(0.0591, dtype=torch.float64)		tensor(0.2658, dtype=torch.float64)
# 32		tensor(0.0457, dtype=torch.float64)		tensor(0.3736, dtype=torch.float64)
# 64		tensor(0.0332, dtype=torch.float64)		tensor(0.4613, dtype=torch.float64)
# 128		tensor(0.0177, dtype=torch.float64)		tensor(0.9026, dtype=torch.float64)
# 256		tensor(0.0101, dtype=torch.float64)		tensor(0.8187, dtype=torch.float64)
# 512		tensor(0.0060, dtype=torch.float64)		tensor(0.7376, dtype=torch.float64)
# relu 1, dict size 4096
# neuron num 		 error 		 order
# 4		tensor(0.0772, dtype=torch.float64)		*
# 8		tensor(0.0716, dtype=torch.float64)		tensor(0.1080, dtype=torch.float64)
# 16		tensor(0.0581, dtype=torch.float64)		tensor(0.3016, dtype=torch.float64)
# 32		tensor(0.0444, dtype=torch.float64)		tensor(0.3878, dtype=torch.float64)
# 64		tensor(0.0277, dtype=torch.float64)		tensor(0.6819, dtype=torch.float64)
# 128		tensor(0.0152, dtype=torch.float64)		tensor(0.8695, dtype=torch.float64)
# 256		tensor(0.0086, dtype=torch.float64)		tensor(0.8157, dtype=torch.float64)
# 512		tensor(0.0052, dtype=torch.float64)		tensor(0.7397, dtype=torch.float64)
# relu 1, dict size 8192
# neuron num 		 error 		 order
# 4		tensor(0.0736, dtype=torch.float64)		*
# 8		tensor(0.0657, dtype=torch.float64)		tensor(0.1651, dtype=torch.float64)
# 16		tensor(0.0555, dtype=torch.float64)		tensor(0.2416, dtype=torch.float64)
# 32		tensor(0.0403, dtype=torch.float64)		tensor(0.4618, dtype=torch.float64)
# 64		tensor(0.0244, dtype=torch.float64)		tensor(0.7256, dtype=torch.float64)
# 128		tensor(0.0138, dtype=torch.float64)		tensor(0.8192, dtype=torch.float64)
# 256		tensor(0.0078, dtype=torch.float64)		tensor(0.8311, dtype=torch.float64)
# 512		tensor(0.0045, dtype=torch.float64)		tensor(0.7881, dtype=torch.float64)
# relu 1, dict size 16384
# neuron num 		 error 		 order
# 4		tensor(0.0765, dtype=torch.float64)		*
# 8		tensor(0.0696, dtype=torch.float64)		tensor(0.1373, dtype=torch.float64)
# 16		tensor(0.0562, dtype=torch.float64)		tensor(0.3073, dtype=torch.float64)
# 32		tensor(0.0398, dtype=torch.float64)		tensor(0.4990, dtype=torch.float64)
# 64		tensor(0.0208, dtype=torch.float64)		tensor(0.9343, dtype=torch.float64)
# 128		tensor(0.0120, dtype=torch.float64)		tensor(0.7926, dtype=torch.float64)
# 256		tensor(0.0069, dtype=torch.float64)		tensor(0.8073, dtype=torch.float64)
# 512		tensor(0.0040, dtype=torch.float64)		tensor(0.7651, dtype=torch.float64)
# deterministic dictionary
#
# relu 1, dict size 16384
# neuron num 		 error 		 order
# 4		tensor(0.0764, dtype=torch.float64)		*
# 8		tensor(0.0669, dtype=torch.float64)		tensor(0.1904, dtype=torch.float64)
# 16		tensor(0.0569, dtype=torch.float64)		tensor(0.2356, dtype=torch.float64)
# 32		tensor(0.0369, dtype=torch.float64)		tensor(0.6243, dtype=torch.float64)
# 64		tensor(0.0180, dtype=torch.float64)		tensor(1.0327, dtype=torch.float64)
# 128		tensor(0.0106, dtype=torch.float64)		tensor(0.7605, dtype=torch.float64)
# 256		tensor(0.0065, dtype=torch.float64)		tensor(0.7016, dtype=torch.float64)
# 512		tensor(0.0039, dtype=torch.float64)		tensor(0.7286, dtype=torch.float64)
# 1024		tensor(0.0025, dtype=torch.float64)		tensor(0.6866, dtype=torch.float64)
# relu 1, dict size 32768
# neuron num 		 error 		 order
# 4		tensor(0.0765, dtype=torch.float64)		*
# 8		tensor(0.0705, dtype=torch.float64)		tensor(0.1181, dtype=torch.float64)
# 16		tensor(0.0573, dtype=torch.float64)		tensor(0.2993, dtype=torch.float64)
# 32		tensor(0.0341, dtype=torch.float64)		tensor(0.7497, dtype=torch.float64)
# 64		tensor(0.0183, dtype=torch.float64)		tensor(0.8955, dtype=torch.float64)
# 128		tensor(0.0107, dtype=torch.float64)		tensor(0.7798, dtype=torch.float64)
# 256		tensor(0.0063, dtype=torch.float64)		tensor(0.7718, dtype=torch.float64)
# 512		tensor(0.0037, dtype=torch.float64)		tensor(0.7385, dtype=torch.float64)
# 1024		tensor(0.0023, dtype=torch.float64)		tensor(0.6788, dtype=torch.float64)
# relu 1, dict size 65536
# neuron num 		 error 		 order
# 4		tensor(0.0764, dtype=torch.float64)		*
# 8		tensor(0.0687, dtype=torch.float64)		tensor(0.1528, dtype=torch.float64)
# 16		tensor(0.0506, dtype=torch.float64)		tensor(0.4413, dtype=torch.float64)
# 32		tensor(0.0336, dtype=torch.float64)		tensor(0.5917, dtype=torch.float64)
# 64		tensor(0.0174, dtype=torch.float64)		tensor(0.9503, dtype=torch.float64)
# 128		tensor(0.0103, dtype=torch.float64)		tensor(0.7526, dtype=torch.float64)
# 256		tensor(0.0060, dtype=torch.float64)		tensor(0.7821, dtype=torch.float64)
# 512		tensor(0.0036, dtype=torch.float64)		tensor(0.7334, dtype=torch.float64)
# 1024		tensor(0.0023, dtype=torch.float64)		tensor(0.6773, dtype=torch.float64)
# deterministic dictionary

# %%
def plot_err_vs_neurons_10d(k,d,err_list_relu_4_rand,filename, fig_title, exponent = 9, save = False, rescale = 6):
    """ Neuron numbers 2^2, 2^3, 2^4, ..., 2^9. 
    """
    rate = -1/2 - (2 * k + 1)/(2 * d)

    f_size = 12  # Increased font size
    line_width = 2  # Thickness of the lines
    # Set global font size
    plt.rcParams.update({'font.size': f_size})
    
    neuron_nums = np.array([2**j for j in range(2,exponent+1)])  
    rand_size_exp_list = [7,8,9,10,11,12,13,14] 

    neuron_nums2 = np.array([2**j for j in range(2,exponent+2)])  
    rand_size_exp_list2 = [14,15,16] 

    plt.figure(dpi = 400)
    x = np.array(range(4, 2**(exponent) +1))
    ref = err_list_relu_4_rand[0][2**2]* (x/ 4)**(rate) * rescale 

    # plt.plot(x,ref,'-.',label = 'optimal rate = {}'.format(rate))
    plt.plot(x,ref,'-.',linewidth=line_width,label = '$O(n^{{{}}})$'.format(rate))

    for i, err in enumerate(err_list_relu_4_rand[:-1]): 
        if i%2 ==0: 
            plt.plot(neuron_nums, err[neuron_nums],'.-',linewidth=line_width,
                     label = "Randomized $2^{{{}}}$".format(rand_size_exp_list[i]))

    # for i, err in enumerate(err_list_relu_4_rand2): 
    #     # if i%2 ==0: 
    #     plt.plot(neuron_nums2, err[neuron_nums2],'.-',label = "Rand dictionary: $2^{{{}}}$".format(rand_size_exp_list2[i]))


    plt.title( fig_title+"   ReLU$^{}$ dictionary".format(k))
    plt.yscale('log')
    plt.xscale('log')
    # plt.grid("True")
    plt.xlabel("Iteration number $n$")
    plt.ylabel("$L^2$ error $||u-u_n||$")
    plt.xticks(neuron_nums,[rf"$2^{{{ns}}}$" for ns in range(2,exponent+1)])
    plt.legend(loc='lower left')    

    if save:
        plt.savefig(filename) 
    else:
        plt.show()
    return 0 
## plot results 
## read data: 

k = 1 
filename = "10D_gaussian_rand_relu{}_Dict.png".format(k)    
d = 10 
save = True  
fig_title = "10D Gaussian"
plot_err_vs_neurons_10d(k,d,err_list_relu_4_rand,filename, fig_title, exponent = 9, save = save, rescale=2.5)
# Out:
# 0

# %%
folder = 'ex1/'
experiment_label = 'ex1'
err_list_relu_4_rand = []
for k in [4]: 
    for N0 in [2**7, 2**8, 2**9, 2**10,2**11,2**12,2**13,2**14]: 

        exponent = 9  
        num_epochs=  2**exponent 
        print("relu {}, dict size {}".format(k, N0))

        filename = folder + experiment_label +"_err_randDict_relu_{}_size_{}_num_neurons_{}.pt".format(k, N0,num_epochs)
        err = torch.load(filename)  
        err_list_relu_4_rand.append(err) 
        print_convergence_order(err,exponent+1) 

print("deterministic dictionary")
print() 


folder = 'ex1/'
experiment_label = 'ex1'
err_list_relu_4_rand2 = []
for k in [4]: 
    for N0 in [2**14,2**15,2**16]: 

        exponent = 10 
        num_epochs=  2**exponent 
        print("relu {}, dict size {}".format(k, N0))

        filename = folder + experiment_label +"_err_randDict_relu_{}_size_{}_num_neurons_{}.pt".format(k, N0,num_epochs)
        err = torch.load(filename)  
        err_list_relu_4_rand2.append(err) 
        print_convergence_order(err,exponent+1) 

print("deterministic dictionary")
print()
# Out:
# relu 4, dict size 128
# neuron num 		 error 		 order
# 4		tensor(0.0960, dtype=torch.float64)		*
# 8		tensor(0.0896, dtype=torch.float64)		tensor(0.1000, dtype=torch.float64)
# 16		tensor(0.0755, dtype=torch.float64)		tensor(0.2462, dtype=torch.float64)
# 32		tensor(0.0520, dtype=torch.float64)		tensor(0.5375, dtype=torch.float64)
# 64		tensor(0.0311, dtype=torch.float64)		tensor(0.7409, dtype=torch.float64)
# 128		tensor(0.0105, dtype=torch.float64)		tensor(1.5689, dtype=torch.float64)
# 256		tensor(0.0065, dtype=torch.float64)		tensor(0.6981, dtype=torch.float64)
# 512		tensor(0.0041, dtype=torch.float64)		tensor(0.6470, dtype=torch.float64)
# relu 4, dict size 256
# neuron num 		 error 		 order
# 4		tensor(0.1427, dtype=torch.float64)		*
# 8		tensor(0.0896, dtype=torch.float64)		tensor(0.6713, dtype=torch.float64)
# 16		tensor(0.0787, dtype=torch.float64)		tensor(0.1875, dtype=torch.float64)
# 32		tensor(0.0517, dtype=torch.float64)		tensor(0.6066, dtype=torch.float64)
# 64		tensor(0.0257, dtype=torch.float64)		tensor(1.0067, dtype=torch.float64)
# 128		tensor(0.0102, dtype=torch.float64)		tensor(1.3398, dtype=torch.float64)
# 256		tensor(0.0063, dtype=torch.float64)		tensor(0.6829, dtype=torch.float64)
# 512		tensor(0.0038, dtype=torch.float64)		tensor(0.7362, dtype=torch.float64)
# relu 4, dict size 512
# neuron num 		 error 		 order
# 4		tensor(0.1021, dtype=torch.float64)		*
# 8		tensor(0.0910, dtype=torch.float64)		tensor(0.1662, dtype=torch.float64)
# 16		tensor(0.0800, dtype=torch.float64)		tensor(0.1858, dtype=torch.float64)
# 32		tensor(0.0544, dtype=torch.float64)		tensor(0.5565, dtype=torch.float64)
# 64		tensor(0.0228, dtype=torch.float64)		tensor(1.2514, dtype=torch.float64)
# 128		tensor(0.0085, dtype=torch.float64)		tensor(1.4205, dtype=torch.float64)
# 256		tensor(0.0063, dtype=torch.float64)		tensor(0.4363, dtype=torch.float64)
# 512		tensor(0.0035, dtype=torch.float64)		tensor(0.8327, dtype=torch.float64)
# relu 4, dict size 1024
# neuron num 		 error 		 order
# 4		tensor(0.1090, dtype=torch.float64)		*
# 8		tensor(0.0923, dtype=torch.float64)		tensor(0.2393, dtype=torch.float64)
# 16		tensor(0.0847, dtype=torch.float64)		tensor(0.1246, dtype=torch.float64)
# 32		tensor(0.0554, dtype=torch.float64)		tensor(0.6126, dtype=torch.float64)
# 64		tensor(0.0237, dtype=torch.float64)		tensor(1.2249, dtype=torch.float64)
# 128		tensor(0.0084, dtype=torch.float64)		tensor(1.5046, dtype=torch.float64)
# 256		tensor(0.0064, dtype=torch.float64)		tensor(0.3934, dtype=torch.float64)
# 512		tensor(0.0034, dtype=torch.float64)		tensor(0.9204, dtype=torch.float64)
# relu 4, dict size 2048
# neuron num 		 error 		 order
# 4		tensor(0.1078, dtype=torch.float64)		*
# 8		tensor(0.0889, dtype=torch.float64)		tensor(0.2786, dtype=torch.float64)
# 16		tensor(0.0817, dtype=torch.float64)		tensor(0.1212, dtype=torch.float64)
# 32		tensor(0.0512, dtype=torch.float64)		tensor(0.6748, dtype=torch.float64)
# 64		tensor(0.0213, dtype=torch.float64)		tensor(1.2647, dtype=torch.float64)
# 128		tensor(0.0084, dtype=torch.float64)		tensor(1.3495, dtype=torch.float64)
# 256		tensor(0.0063, dtype=torch.float64)		tensor(0.4085, dtype=torch.float64)
# 512		tensor(0.0031, dtype=torch.float64)		tensor(1.0225, dtype=torch.float64)
# relu 4, dict size 4096
# neuron num 		 error 		 order
# 4		tensor(0.1085, dtype=torch.float64)		*
# 8		tensor(0.0915, dtype=torch.float64)		tensor(0.2466, dtype=torch.float64)
# 16		tensor(0.0854, dtype=torch.float64)		tensor(0.0990, dtype=torch.float64)
# 32		tensor(0.0479, dtype=torch.float64)		tensor(0.8343, dtype=torch.float64)
# 64		tensor(0.0194, dtype=torch.float64)		tensor(1.3010, dtype=torch.float64)
# 128		tensor(0.0084, dtype=torch.float64)		tensor(1.2084, dtype=torch.float64)
# 256		tensor(0.0064, dtype=torch.float64)		tensor(0.4051, dtype=torch.float64)
# 512		tensor(0.0029, dtype=torch.float64)		tensor(1.1532, dtype=torch.float64)
# relu 4, dict size 8192
# neuron num 		 error 		 order
# 4		tensor(0.1049, dtype=torch.float64)		*
# 8		tensor(0.0927, dtype=torch.float64)		tensor(0.1785, dtype=torch.float64)
# 16		tensor(0.0833, dtype=torch.float64)		tensor(0.1550, dtype=torch.float64)
# 32		tensor(0.0513, dtype=torch.float64)		tensor(0.6990, dtype=torch.float64)
# 64		tensor(0.0196, dtype=torch.float64)		tensor(1.3856, dtype=torch.float64)
# 128		tensor(0.0086, dtype=torch.float64)		tensor(1.1891, dtype=torch.float64)
# 256		tensor(0.0064, dtype=torch.float64)		tensor(0.4349, dtype=torch.float64)
# 512		tensor(0.0026, dtype=torch.float64)		tensor(1.2832, dtype=torch.float64)
# relu 4, dict size 16384
# neuron num 		 error 		 order
# 4		tensor(0.1147, dtype=torch.float64)		*
# 8		tensor(0.0891, dtype=torch.float64)		tensor(0.3647, dtype=torch.float64)
# 16		tensor(0.0833, dtype=torch.float64)		tensor(0.0956, dtype=torch.float64)
# 32		tensor(0.0478, dtype=torch.float64)		tensor(0.8024, dtype=torch.float64)
# 64		tensor(0.0193, dtype=torch.float64)		tensor(1.3113, dtype=torch.float64)
# 128		tensor(0.0084, dtype=torch.float64)		tensor(1.1887, dtype=torch.float64)
# 256		tensor(0.0063, dtype=torch.float64)		tensor(0.4161, dtype=torch.float64)
# 512		tensor(0.0025, dtype=torch.float64)		tensor(1.3675, dtype=torch.float64)
# deterministic dictionary
#
# relu 4, dict size 16384
# neuron num 		 error 		 order
# 4		tensor(0.1094, dtype=torch.float64)		*
# 8		tensor(0.0908, dtype=torch.float64)		tensor(0.2684, dtype=torch.float64)
# 16		tensor(0.0824, dtype=torch.float64)		tensor(0.1403, dtype=torch.float64)
# 32		tensor(0.0495, dtype=torch.float64)		tensor(0.7345, dtype=torch.float64)
# 64		tensor(0.0192, dtype=torch.float64)		tensor(1.3657, dtype=torch.float64)
# 128		tensor(0.0081, dtype=torch.float64)		tensor(1.2418, dtype=torch.float64)
# 256		tensor(0.0064, dtype=torch.float64)		tensor(0.3513, dtype=torch.float64)
# 512		tensor(0.0025, dtype=torch.float64)		tensor(1.3733, dtype=torch.float64)
# 1024		tensor(0.0004, dtype=torch.float64)		tensor(2.7488, dtype=torch.float64)
# relu 4, dict size 32768
# neuron num 		 error 		 order
# 4		tensor(0.1052, dtype=torch.float64)		*
# 8		tensor(0.0891, dtype=torch.float64)		tensor(0.2404, dtype=torch.float64)
# 16		tensor(0.0835, dtype=torch.float64)		tensor(0.0934, dtype=torch.float64)
# 32		tensor(0.0493, dtype=torch.float64)		tensor(0.7595, dtype=torch.float64)
# 64		tensor(0.0193, dtype=torch.float64)		tensor(1.3497, dtype=torch.float64)
# 128		tensor(0.0083, dtype=torch.float64)		tensor(1.2141, dtype=torch.float64)
# 256		tensor(0.0063, dtype=torch.float64)		tensor(0.3947, dtype=torch.float64)
# 512		tensor(0.0023, dtype=torch.float64)		tensor(1.4926, dtype=torch.float64)
# 1024		tensor(0.0004, dtype=torch.float64)		tensor(2.6261, dtype=torch.float64)
# relu 4, dict size 65536
# neuron num 		 error 		 order
# 4		tensor(0.0997, dtype=torch.float64)		*
# 8		tensor(0.0909, dtype=torch.float64)		tensor(0.1342, dtype=torch.float64)
# 16		tensor(0.0837, dtype=torch.float64)		tensor(0.1176, dtype=torch.float64)
# 32		tensor(0.0547, dtype=torch.float64)		tensor(0.6153, dtype=torch.float64)
# 64		tensor(0.0219, dtype=torch.float64)		tensor(1.3185, dtype=torch.float64)
# 128		tensor(0.0085, dtype=torch.float64)		tensor(1.3688, dtype=torch.float64)
# 256		tensor(0.0064, dtype=torch.float64)		tensor(0.4141, dtype=torch.float64)
# 512		tensor(0.0021, dtype=torch.float64)		tensor(1.5865, dtype=torch.float64)
# 1024		tensor(0.0004, dtype=torch.float64)		tensor(2.5394, dtype=torch.float64)
# deterministic dictionary

# %%
k = 4 
filename = "10D_gaussian_rand_relu{}_Dict.png".format(k)    
d = 10 
fig_title = "10D Gaussian"
save = True 
plot_err_vs_neurons_10d(k,d,err_list_relu_4_rand,filename, fig_title, exponent = 9, save = save, rescale=4.5)
# Out:
# 0
