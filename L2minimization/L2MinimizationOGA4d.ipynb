# %%
# In this version of OGA with random dictionaries, we use QMC to evaluate the loss function. 
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import time
import sys
import os 
from scipy.sparse import linalg
from pathlib import Path
import itertools
if torch.cuda.is_available():  
    device = "cuda" 
else:  
    device = "cpu" 
pi = torch.tensor(np.pi,dtype=torch.float64)
torch.set_default_dtype(torch.float64)


class model(nn.Module):
    """ ReLU k shallow neural network
    Parameters: 
    input size: input dimension
    hidden_size1 : number of hidden layers 
    num_classes: output classes 
    k: degree of relu functions
    """
    def __init__(self, input_size, hidden_size1, num_classes,k = 1):
        super().__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, num_classes,bias = False)
        self.k = k 
    def forward(self, x):
        u1 = self.fc2(F.relu(self.fc1(x))**self.k)
        return u1
    

def show_convergence_order(err_l2,exponent,dict_size, filename,write2file = False):
    
    if write2file:
        file_mode = "a" if os.path.exists(filename) else "w"
        f_write = open(filename, file_mode)
    
    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_l2[i] for i in neuron_nums ]
    if write2file:
        f_write.write('dictionary size: {}\n'.format(dict_size))
        f_write.write("neuron num \t\t error \t\t order \t\t h10 error \\ order \n")
    print("neuron num \t\t error \t\t order")
    for i, item in enumerate(err_list):
        if i == 0: 
            print("{} \t\t {:.6f} \t\t *  \n".format(neuron_nums[i],item ) )
            if write2file: 
                f_write.write("{} \t\t {} \t\t * \t\t \n".format(neuron_nums[i],item ))
        else: 
            print("{} \t\t {:.6f} \t\t {:.6f} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2) ) )
            if write2file: 
                f_write.write("{} \t\t {} \t\t {} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2) ))
    if write2file:     
        f_write.write("\n")
        f_write.close()

def show_convergence_order_latex(err_l2,exponent,k=1,d=1): 
    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_l2[i] for i in neuron_nums ]
    l2_order = -1/2-(2*k + 1)/(2*d)
    print("neuron num  & \t $\\|u-u_n \\|_{{L^2}}$ & \t order $O(n^{{{:.2f}}})$  \\\\ \\hline \\hline ".format(l2_order))
    for i, item in enumerate(err_list):
        if i == 0: 
            print("{} \t\t & {:.6f} &\t\t *  \\\ \hline  \n".format(neuron_nums[i],item) )   
        else: 
            print("{} \t\t &  {:.3e} &  \t\t {:.2f} \\\ \hline  \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2) ) )


def print_convergence_order(err, neuron_num_exponent): 

    neuron_nums = [2**j for j in range(2,neuron_num_exponent)]
    err_list = [err[i] for i in neuron_nums ] 

    print("neuron num \t\t error \t\t order")
    for i, item in enumerate(err_list):
        if i == 0: 
            print(neuron_nums[i], end = "\t\t")
            print(item, end = "\t\t")
            print("*")
        else: 
            print(neuron_nums[i], end = "\t\t")
            print(item, end = "\t\t") 
            print(np.log(err_list[i-1]/err_list[i])/np.log(2))



def generate_relu_dict4D(N_list):
    
    N = np.prod(N_list) 

    grid_indices = [np.linspace(0,1,N_item,endpoint=False) for N_item in N_list]
    grid = np.meshgrid(*grid_indices,indexing='ij')
    grid_coordinates = np.column_stack([axis.ravel() for axis in grid]) 
    samples = torch.tensor(grid_coordinates) 

    T =torch.tensor([[pi,0,0,0],[0,pi,0,0],[0,0,2*pi,0],[0,0,0,2*2]]) # 2 * sqrt(d)
    shift = torch.tensor([0,0,0,-2])
    samples = samples@T + shift 

    f1 = torch.zeros(N,1) 
    f2 = torch.zeros(N,1)
    f3 = torch.zeros(N,1)
    f4 = torch.zeros(N,1)
    f5 = torch.zeros(N,1)

    f1[:,0] = torch.cos(samples[:,0]) 
    f2[:,0] = torch.sin(samples[:,0]) * torch.cos(samples[:,1])
    f3[:,0] = torch.sin(samples[:,0]) * torch.sin(samples[:,1]) * torch.cos(samples[:,2])
    f4[:,0] = torch.sin(samples[:,0]) * torch.sin(samples[:,1]) * torch.sin(samples[:,2])  
    f5[:,0] = samples[:,3]

    Wb_tensor = torch.cat([f1,f2,f3,f4,f5],1) # N x 4 
    return Wb_tensor.to(device)


def generate_relu_dict4D_QMC(s,N0):
    # Sob = torch.quasirandom.SobolEngine(dimension =4, scramble= True, seed=None) 
    # samples = Sob.draw(N0).double() 

    # for i in range(s-1):
    #     samples = torch.cat([samples,Sob.draw(N0).double()],0)

    # Monte Carlo 
    samples = torch.rand(s*N0,4) 

    T =torch.tensor([[pi,0,0,0],[0,pi,0,0],[0,0,2*pi,0],[0,0,0,2*2]])
    shift = torch.tensor([0,0,0,-2])
    samples = samples@T + shift 

    f1 = torch.zeros(s*N0,1) 
    f2 = torch.zeros(s*N0,1)
    f3 = torch.zeros(s*N0,1)
    f4 = torch.zeros(s*N0,1)
    f5 = torch.zeros(s*N0,1)

    f1[:,0] = torch.cos(samples[:,0]) 
    f2[:,0] = torch.sin(samples[:,0]) * torch.cos(samples[:,1])
    f3[:,0] = torch.sin(samples[:,0]) * torch.sin(samples[:,1]) * torch.cos(samples[:,2])
    f4[:,0] = torch.sin(samples[:,0]) * torch.sin(samples[:,1]) * torch.sin(samples[:,2])  
    f5[:,0] = samples[:,3]

    Wb_tensor = torch.cat([f1,f2,f3,f4,f5],1) # N x 4 
    return Wb_tensor.to(device)

def adjust_neuron_position(my_model, dims = 3):

    def create_mesh_grid(dims, pts):
        mesh = torch.tensor(list(itertools.product(pts,repeat=dims)))
        vertices = mesh.reshape(len(pts) ** dims, -1) 
        return vertices
    counter = 0 
    # positions = torch.tensor([[0.,0.],[0.,1.],[1.,1.],[1.,0.]])
    pts = torch.tensor([0.,1.])
    positions = create_mesh_grid(dims,pts) 
    neuron_num = my_model.fc1.bias.size(0)
    for i in range(neuron_num): 
        w = my_model.fc1.weight.data[i:i+1,:]
        b = my_model.fc1.bias.data[i]
    #     print(w,b)
        values = torch.matmul(positions,w.T) # + b
        left_end = - torch.max(values)
        right_end = - torch.min(values)
        offset = (right_end - left_end)/50
        if b <= left_end + offset/2 : 
            b = torch.rand(1)*(right_end - left_end - offset) + left_end + offset/2 
            my_model.fc1.bias.data[i] = b 
        if b >= right_end - offset/2 :
            if counter < (dims+1):
#                 print("here")
                counter += 1
            else: # (d + 1) or more 
                b = torch.rand(1)*(right_end - left_end - offset) + left_end + offset/2 
                my_model.fc1.bias.data[i] = b 
    return my_model

def MonteCarlo_Sobol_dDim_weights_points(M ,d = 4):
    Sob_integral = torch.quasirandom.SobolEngine(dimension =d, scramble= False, seed=None) 
    integration_points = Sob_integral.draw(M).double() 
    integration_points = integration_points.to(device)
    weights = torch.ones(M,1).to(device)/M 
    return weights.to(device), integration_points.to(device) 


def minimize_linear_layer_explicit_assemble(model,target,weights, integration_points,solver="direct"):
    """assemble the linear system and solve it 
    """
    start_time = time.time() 
    w = model.fc1.weight.data 
    b = model.fc1.bias.data 
    basis_value_col = F.relu(integration_points @ w.t()+ b)**(model.k) 
    weighted_basis_value_col = basis_value_col * weights 
    jac = weighted_basis_value_col.t() @ basis_value_col 
     
    rhs = weighted_basis_value_col.t() @ (target(integration_points)) 
    print("assembling the matrix time taken: ", time.time()-start_time) 
    start_time = time.time()    
    if solver == "cg": 
        sol, exit_code = linalg.cg(np.array(jac.detach().cpu()),np.array(rhs.detach().cpu()),tol=1e-12)
        sol = torch.tensor(sol).view(1,-1)
    elif solver == "direct": 
#         sol = np.linalg.inv( np.array(jac.detach().cpu()) )@np.array(rhs.detach().cpu())
        sol = (torch.linalg.solve( jac.detach(), rhs.detach())).view(1,-1)
    elif solver == "ls":
        sol = (torch.linalg.lstsq(jac.detach().cpu(),rhs.detach().cpu(),driver='gelsd').solution).view(1,-1)
        # sol = (torch.linalg.lstsq(jac.detach(),rhs.detach()).solution).view(1,-1) # gpu/cpu, driver = 'gels', cannot solve singular
    print("solving Ax = b time taken: ", time.time()-start_time)
    return sol 

def OGAL2FittingReLU4D(my_model,target,N_list,num_epochs, M, k =1, linear_solver = "direct",num_batches = 1): 
    
    """ Orthogonal greedy algorithm (0,1)^4 
    Parameters
    ----------
    my_model: 
        nn model 
    target: 
        target function
    num_epochs: int 
        number of training epochs 
    integration_intervals: int 
        number of subintervals for piecewise numerical quadrature 
    Returns
    -------
    err: tensor 
        rank 1 torch tensor to record the L2 error history  
    model: 
        trained nn model 
    """

    weights, integration_points = MonteCarlo_Sobol_dDim_weights_points(M ,d = 4) 

    err = torch.zeros(num_epochs+1)
    if my_model == None: 
        func_values = target(integration_points)
        num_neuron = 0

        list_b = []
        list_w = []

    else: 
        func_values = target(integration_points) - my_model(integration_points).detach()
        bias = my_model.fc1.bias.detach().data
        weights = my_model.fc1.weight.detach().data
        num_neuron = int(bias.size(0))

        list_b = list(bias)
        list_w = list(weights)
    
    # initial error Todo Done

    func_values_sqrd = func_values*func_values

    err[0]= torch.mean(func_values_sqrd)**0.5
    all_start_time = time.time()
    
    solver = linear_solver
    print("using linear solver: ",solver)
    N = np.prod(N_list) 
    relu_dict_parameters = generate_relu_dict4D(N_list).t() 
#     num_batches = 2**3 #8, divide dictionary elements 
    batch_size = N//num_batches # batch_size * i : batch_size * (i+1), i = 0,..., num_batches - 1 
    
    for i in range(num_epochs): 
  
        print("epoch: ",i+1, end = '\t')
        if num_neuron == 0: 
            func_values = target(integration_points)
        else: 
            with torch.no_grad(): 
                func_values = target(integration_points) - my_model(integration_points)

        start_time = time.time() 

        output = torch.zeros(N,1)
        
        for j in range(0,N,batch_size): 

            end_index = j + batch_size  
            basis_values_batch = (F.relu( torch.matmul(integration_points,relu_dict_parameters[0:4, j:end_index] ) - relu_dict_parameters[4, j:end_index])**k).T # uses broadcasting    
            output[j:end_index,0]  = (torch.abs(torch.matmul(basis_values_batch,func_values))/M)[:,0]
            
        neuron_index = torch.argmax(output.flatten())
        
        print("argmax time taken, ", time.time() - start_time)
        
        # print(neuron_index)
        list_w.append(relu_dict_parameters[0:4, neuron_index]) # 
        list_b.append(-relu_dict_parameters[4,neuron_index])
        num_neuron += 1
        my_model = model(4,num_neuron,1,k).to(device)
        w_tensor = torch.stack(list_w, 0 ) 
        b_tensor = torch.tensor(list_b)
        my_model.fc1.weight.data[:,:] = w_tensor[:,:]
        my_model.fc1.bias.data[:] = b_tensor[:]

        #Todo 
        start_time = time.time() 
        sol = minimize_linear_layer_explicit_assemble(my_model,target,weights,integration_points, solver)
        print("\t\t time taken minimize linear layer: ",time.time() - start_time) 
        my_model.fc2.weight.data[0,:] = sol[:]

        func_values = target(integration_points) - my_model(integration_points).detach()
        func_values_sqrd = func_values*func_values

        #Todo Done 
        err[i+1]= torch.mean(func_values_sqrd)**0.5
        print("current error: ",err[i+1]) 
    print("time taken: ",time.time() - all_start_time)
    return err, my_model


def OGAL2FittingReLU4D_QMC(my_model,target,s,N0,num_epochs, M, k =1, linear_solver = "direct", num_batches = 1): 
    
    """ Orthogonal greedy algorithm using 1D ReLU dictionary over [-pi,pi]
    Parameters
    ----------
    my_model: 
        nn model 
    target: 
        target function
    num_epochs: int 
        number of training epochs 
    integration_intervals: int 
        number of subintervals for piecewise numerical quadrature 

    Returns
    -------
    err: tensor 
        rank 1 torch tensor to record the L2 error history  
    model: 
        trained nn model 
    """
    #Todo Done
    # samples for QMC integral
    start_time = time.time()
    # Sob_integral = torch.quasirandom.SobolEngine(dimension =4, scramble= False, seed=None) 
    # integration_points = Sob_integral.draw(M).double() 
    # integration_points = integration_points.to(device)
    weights, integration_points = MonteCarlo_Sobol_dDim_weights_points(M ,d = 4) 
    print("generate sob sequence:", time.time() - start_time) 

    err = torch.zeros(num_epochs+1)
    if my_model == None: 
        func_values = target(integration_points)
        num_neuron = 0

        list_b = []
        list_w = []

    else: 
        func_values = target(integration_points) - my_model(integration_points).detach()
        bias = my_model.fc1.bias.detach().data
        weights = my_model.fc1.weight.detach().data
        num_neuron = int(bias.size(0))

        list_b = list(bias)
        list_w = list(weights)
    
    # initial error Todo Done

    func_values_sqrd = func_values*func_values
    # print(func_values_sqrd.size())
    # print(gw_expand.size() ) 

    err[0]= torch.mean(func_values_sqrd)**0.5
    all_start_time = time.time()
    
    solver = linear_solver
    print("using linear solver: ",solver)
    for i in range(num_epochs): 
        relu_dict_parameters = generate_relu_dict4D_QMC(s,N0).t()   
        print("epoch: ",i+1, end = '\t')
        if num_neuron == 0: 
            func_values = target(integration_points)
        else: 
            func_values = target(integration_points) - my_model(integration_points).detach()

        start_time = time.time() 
        
        N = s*N0 
        output = torch.zeros(N,1)
        batch_size = N//num_batches
        
        for j in range(0,N,batch_size): 

            end_index = j + batch_size  
            basis_values_batch = (F.relu( torch.matmul(integration_points,relu_dict_parameters[0:4, j:end_index] ) - relu_dict_parameters[4, j:end_index])**k).T # uses broadcasting    
            output[j:end_index,0]  = (torch.abs(torch.matmul(basis_values_batch,func_values))/M)[:,0]
            
        neuron_index = torch.argmax(output.flatten())
        
#         basis_values = (F.relu( torch.matmul(integration_points,relu_dict_parameters[:,0:4].T ) - relu_dict_parameters[:,4])**k).T # uses broadcasting
#         output = torch.abs(torch.matmul(basis_values,func_values))/M # 
#         neuron_index = torch.argmax(output.flatten())
        print("argmax time taken, ", time.time() - start_time)
        
        # print(neuron_index)
#         list_w.append(relu_dict_parameters[neuron_index,0:4]) # 
#         list_b.append(-relu_dict_parameters[neuron_index,4])
        list_w.append(relu_dict_parameters[0:4, neuron_index]) # 
        list_b.append(-relu_dict_parameters[4,neuron_index])
        num_neuron += 1
        my_model = model(4,num_neuron,1,k).to(device)
        w_tensor = torch.stack(list_w, 0 ) 
        b_tensor = torch.tensor(list_b)
        my_model.fc1.weight.data[:,:] = w_tensor[:,:]
        my_model.fc1.bias.data[:] = b_tensor[:]

        #Todo 
        start_time = time.time() 
        sol = minimize_linear_layer_explicit_assemble(my_model,target,weights,integration_points, solver)
        print("\t\t time taken minimize linear layer: ",time.time() - start_time) 
        my_model.fc2.weight.data[0,:] = sol[:]

        func_values = target(integration_points) - my_model(integration_points).detach()
        func_values_sqrd = func_values*func_values

        #Todo Done 
        err[i+1]= torch.mean(func_values_sqrd)**0.5
        print("current error: ",err[i+1]) 
    print("total duration: ",time.time() - all_start_time)
    return err, my_model

# %% [markdown]
# ## Deterministic dictionary

# %%
def target(x):
    return torch.sin(pi*x[:,0:1])*torch.sin(pi*x[:,1:2])*torch.sin(pi*x[:,2:3]) *torch.sin(pi*x[:,3:4])

dim = 4 
function_name = "sin-product-4d" 
filename_write = "data/2DOGA-{}-order.txt".format(function_name)
M = 2**19 # MC points around 50w 
f_write = open(filename_write, "a")
f_write.write("Integration points: Quasi Monte Carlo:  {}\n".format(M))
f_write.close() 
save = True 
write2file = True

for relu_k in [4]: 
    for N_list in [[2**4, 2**4, 2**3, 2**3]]: 
        N = np.prod(N_list) 
        print()
        print() 
        exponent = 9  
        num_epochs=  2**exponent 
    
        my_model = None 
        err, my_model = OGAL2FittingReLU4D(my_model,target,N_list,num_epochs, M, k = relu_k, linear_solver = "ls", num_batches= 2**3)
        
        if save: 
            folder = 'data/'
            filename = folder + function_name + "_err_deterministic_Dict_relu_{}_size_{}_num_neurons_{}.pt".format(relu_k,N,num_epochs)
            torch.save(err,filename)
            filename = folder + function_name + "_model_deterministic_Dict_relu_{}_size_{}_num_neurons_{}.pt".format(relu_k,N,num_epochs)
            torch.save(my_model.state_dict(),filename) 
            
        show_convergence_order(err,exponent,N,filename_write,write2file = write2file)
        show_convergence_order_latex(err,exponent,k=relu_k,d=dim)
# Out:
# using linear solver:  ls
# epoch:  1	argmax time taken,  0.43138813972473145
# assembling the matrix time taken:  0.0002498626708984375
# solving Ax = b time taken:  0.00015544891357421875
# 		 time taken minimize linear layer:  0.0004353523254394531
# current error:  tensor(0.2000)
# epoch:  2	argmax time taken,  0.41163158416748047
# assembling the matrix time taken:  0.0002880096435546875
# solving Ax = b time taken:  0.00026154518127441406
# 		 time taken minimize linear layer:  0.0005805492401123047
# current error:  tensor(0.1988)
# epoch:  3	argmax time taken,  0.4120492935180664
# assembling the matrix time taken:  0.0002505779266357422
# solving Ax = b time taken:  0.00029468536376953125
# 		 time taken minimize linear layer:  0.0005764961242675781
# current error:  tensor(0.1954)
# epoch:  4	argmax time taken,  0.41201114654541016
# assembling the matrix time taken:  0.0002665519714355469
# solving Ax = b time taken:  0.0003178119659423828
# 		 time taken minimize linear layer:  0.0006160736083984375
# current error:  tensor(0.1664)
# epoch:  5	argmax time taken,  0.41187596321105957
# assembling the matrix time taken:  0.00024962425231933594
# solving Ax = b time taken:  0.0003743171691894531
# 		 time taken minimize linear layer:  0.0006546974182128906
# current error:  tensor(0.1651)
# epoch:  6	argmax time taken,  0.4118790626525879
# assembling the matrix time taken:  0.00025582313537597656
# solving Ax = b time taken:  0.0004074573516845703
# 		 time taken minimize linear layer:  0.00069427490234375
# current error:  tensor(0.1430)
# epoch:  7	argmax time taken,  0.4120190143585205
# assembling the matrix time taken:  0.00025391578674316406
# solving Ax = b time taken:  0.0004315376281738281
# 		 time taken minimize linear layer:  0.0007174015045166016
# current error:  tensor(0.1419)
# epoch:  8	argmax time taken,  0.41196513175964355
# assembling the matrix time taken:  0.00025963783264160156
# solving Ax = b time taken:  0.00044989585876464844
# 		 time taken minimize linear layer:  0.0007402896881103516
# current error:  tensor(0.1185)
# epoch:  9	argmax time taken,  0.4122495651245117
# assembling the matrix time taken:  0.00025463104248046875
# solving Ax = b time taken:  0.0004975795745849609
# 		 time taken minimize linear layer:  0.0007834434509277344
# current error:  tensor(0.1115)
# epoch:  10	argmax time taken,  0.412168025970459
# assembling the matrix time taken:  0.0002675056457519531
# solving Ax = b time taken:  0.0005192756652832031
# 		 time taken minimize linear layer:  0.0008172988891601562
# current error:  tensor(0.1095)
# epoch:  11	argmax time taken,  0.41219115257263184
# assembling the matrix time taken:  0.00025200843811035156
# solving Ax = b time taken:  0.0005564689636230469
# 		 time taken minimize linear layer:  0.0008394718170166016
# current error:  tensor(0.1090)
# epoch:  12	argmax time taken,  0.4122135639190674
# assembling the matrix time taken:  0.0002598762512207031
# solving Ax = b time taken:  0.0005960464477539062
# 		 time taken minimize linear layer:  0.0008876323699951172
# current error:  tensor(0.1087)
# epoch:  13	argmax time taken,  0.4122440814971924
# assembling the matrix time taken:  0.00025391578674316406
# solving Ax = b time taken:  0.0006253719329833984
# 		 time taken minimize linear layer:  0.0009102821350097656
# current error:  tensor(0.1086)
# epoch:  14	argmax time taken,  0.4122755527496338
# assembling the matrix time taken:  0.00026488304138183594
# solving Ax = b time taken:  0.0006628036499023438
# 		 time taken minimize linear layer:  0.0009586811065673828
# current error:  tensor(0.1079)
# epoch:  15	argmax time taken,  0.4122896194458008
# assembling the matrix time taken:  0.0002529621124267578
# solving Ax = b time taken:  0.0006947517395019531
# 		 time taken minimize linear layer:  0.0009784698486328125
# current error:  tensor(0.1074)
# epoch:  16	argmax time taken,  0.4122180938720703
# assembling the matrix time taken:  0.00027108192443847656
# solving Ax = b time taken:  0.0007193088531494141
# 		 time taken minimize linear layer:  0.0010221004486083984
# current error:  tensor(0.1072)
# epoch:  17	argmax time taken,  0.41218090057373047
# assembling the matrix time taken:  0.0002548694610595703
# solving Ax = b time taken:  0.0007669925689697266
# 		 time taken minimize linear layer:  0.0010540485382080078
# current error:  tensor(0.1063)
# epoch:  18	argmax time taken,  0.4122307300567627
# assembling the matrix time taken:  0.0002620220184326172
# solving Ax = b time taken:  0.0008027553558349609
# 		 time taken minimize linear layer:  0.0010972023010253906
# current error:  tensor(0.1058)
# epoch:  19	argmax time taken,  0.4123549461364746
# assembling the matrix time taken:  0.0002541542053222656
# solving Ax = b time taken:  0.0008411407470703125
# 		 time taken minimize linear layer:  0.0011267662048339844
# current error:  tensor(0.1051)
# epoch:  20	argmax time taken,  0.41231703758239746
# assembling the matrix time taken:  0.0002741813659667969
# solving Ax = b time taken:  0.0008559226989746094
# 		 time taken minimize linear layer:  0.0011675357818603516
# current error:  tensor(0.1050)
# epoch:  21	argmax time taken,  0.41237330436706543
# assembling the matrix time taken:  0.000255584716796875
# solving Ax = b time taken:  0.0009157657623291016
# 		 time taken minimize linear layer:  0.0012025833129882812
# current error:  tensor(0.1048)
# epoch:  22	argmax time taken,  0.41242027282714844
# assembling the matrix time taken:  0.00026607513427734375
# solving Ax = b time taken:  0.0009617805480957031
# 		 time taken minimize linear layer:  0.0012600421905517578
# current error:  tensor(0.1046)
# epoch:  23	argmax time taken,  0.4123649597167969
# assembling the matrix time taken:  0.0002536773681640625
# solving Ax = b time taken:  0.0010135173797607422
# 		 time taken minimize linear layer:  0.0012989044189453125
# current error:  tensor(0.1044)
# epoch:  24	argmax time taken,  0.4124913215637207
# assembling the matrix time taken:  0.0002613067626953125
# solving Ax = b time taken:  0.0010178089141845703
# 		 time taken minimize linear layer:  0.0013113021850585938
# current error:  tensor(0.1042)
# epoch:  25	argmax time taken,  0.4123551845550537
# assembling the matrix time taken:  0.00026345252990722656
# solving Ax = b time taken:  0.0010755062103271484
# 		 time taken minimize linear layer:  0.0013701915740966797
# current error:  tensor(0.1039)
# epoch:  26	argmax time taken,  0.41217660903930664
# assembling the matrix time taken:  0.00025725364685058594
# solving Ax = b time taken:  0.0011484622955322266
# 		 time taken minimize linear layer:  0.0014379024505615234
# current error:  tensor(0.1038)
# epoch:  27	argmax time taken,  0.41239237785339355
# assembling the matrix time taken:  0.0002522468566894531
# solving Ax = b time taken:  0.0011768341064453125
# 		 time taken minimize linear layer:  0.0014660358428955078
# current error:  tensor(0.1034)
# epoch:  28	argmax time taken,  0.412569522857666
# assembling the matrix time taken:  0.0002601146697998047
# solving Ax = b time taken:  0.0012061595916748047
# 		 time taken minimize linear layer:  0.0014984607696533203
# current error:  tensor(0.1032)
# epoch:  29	argmax time taken,  0.4124312400817871
# assembling the matrix time taken:  0.0002651214599609375
# solving Ax = b time taken:  0.0012502670288085938
# 		 time taken minimize linear layer:  0.0015473365783691406
# current error:  tensor(0.1031)
# epoch:  30	argmax time taken,  0.41250109672546387
# assembling the matrix time taken:  0.0002617835998535156
# solving Ax = b time taken:  0.0012829303741455078
# 		 time taken minimize linear layer:  0.001577138900756836
# current error:  tensor(0.1029)
# epoch:  31	argmax time taken,  0.4127213954925537
# assembling the matrix time taken:  0.0002868175506591797
# solving Ax = b time taken:  0.0013532638549804688
# 		 time taken minimize linear layer:  0.0016758441925048828
# current error:  tensor(0.1021)
# epoch:  32	argmax time taken,  0.4124643802642822
# assembling the matrix time taken:  0.00027179718017578125
# solving Ax = b time taken:  0.0013229846954345703
# 		 time taken minimize linear layer:  0.0016283988952636719
# current error:  tensor(0.1006)
# epoch:  33	argmax time taken,  0.4124026298522949
# assembling the matrix time taken:  0.00026297569274902344
# solving Ax = b time taken:  0.001523733139038086
# 		 time taken minimize linear layer:  0.0018188953399658203
# current error:  tensor(0.0982)
# epoch:  34	argmax time taken,  0.41401195526123047
# assembling the matrix time taken:  0.00027680397033691406
# solving Ax = b time taken:  0.0015137195587158203
# 		 time taken minimize linear layer:  0.0018229484558105469
# current error:  tensor(0.0972)
# epoch:  35	argmax time taken,  0.4142005443572998
# assembling the matrix time taken:  0.0002543926239013672
# solving Ax = b time taken:  0.001592397689819336
# 		 time taken minimize linear layer:  0.0018787384033203125
# current error:  tensor(0.0925)
# epoch:  36	argmax time taken,  0.4140441417694092
# assembling the matrix time taken:  0.00026226043701171875
# solving Ax = b time taken:  0.0015718936920166016
# 		 time taken minimize linear layer:  0.0018663406372070312
# current error:  tensor(0.0885)
# epoch:  37	argmax time taken,  0.4140913486480713
# assembling the matrix time taken:  0.0002529621124267578
# solving Ax = b time taken:  0.001638650894165039
# 		 time taken minimize linear layer:  0.0019235610961914062
# current error:  tensor(0.0849)
# epoch:  38	argmax time taken,  0.4141073226928711
# assembling the matrix time taken:  0.00026679039001464844
# solving Ax = b time taken:  0.0016472339630126953
# 		 time taken minimize linear layer:  0.0019474029541015625
# current error:  tensor(0.0815)
# epoch:  39	argmax time taken,  0.4141116142272949
# assembling the matrix time taken:  0.00025153160095214844
# solving Ax = b time taken:  0.001697540283203125
# 		 time taken minimize linear layer:  0.0019817352294921875
# current error:  tensor(0.0767)
# epoch:  40	argmax time taken,  0.41405415534973145
# assembling the matrix time taken:  0.00026535987854003906
# solving Ax = b time taken:  0.0016825199127197266
# 		 time taken minimize linear layer:  0.0019800662994384766
# current error:  tensor(0.0715)
# epoch:  41	argmax time taken,  0.4141077995300293
# assembling the matrix time taken:  0.0002510547637939453
# solving Ax = b time taken:  0.0017809867858886719
# 		 time taken minimize linear layer:  0.0020644664764404297
# current error:  tensor(0.0680)
# epoch:  42	argmax time taken,  0.4143533706665039
# assembling the matrix time taken:  0.0002617835998535156
# solving Ax = b time taken:  0.001800537109375
# 		 time taken minimize linear layer:  0.0020949840545654297
# current error:  tensor(0.0616)
# epoch:  43	argmax time taken,  0.41428208351135254
# assembling the matrix time taken:  0.0002593994140625
# solving Ax = b time taken:  0.0018672943115234375
# 		 time taken minimize linear layer:  0.002159595489501953
# current error:  tensor(0.0598)
# epoch:  44	argmax time taken,  0.41426682472229004
# assembling the matrix time taken:  0.0002644062042236328
# solving Ax = b time taken:  0.0018661022186279297
# 		 time taken minimize linear layer:  0.0021631717681884766
# current error:  tensor(0.0555)
# epoch:  45	argmax time taken,  0.41443443298339844
# assembling the matrix time taken:  0.00026106834411621094
# solving Ax = b time taken:  0.0019431114196777344
# 		 time taken minimize linear layer:  0.002237081527709961
# current error:  tensor(0.0525)
# epoch:  46	argmax time taken,  0.4143669605255127
# assembling the matrix time taken:  0.00026154518127441406
# solving Ax = b time taken:  0.0019464492797851562
# 		 time taken minimize linear layer:  0.0022411346435546875
# current error:  tensor(0.0507)
# epoch:  47	argmax time taken,  0.41422486305236816
# assembling the matrix time taken:  0.00025534629821777344
# solving Ax = b time taken:  0.002016305923461914
# 		 time taken minimize linear layer:  0.002303600311279297
# current error:  tensor(0.0489)
# epoch:  48	argmax time taken,  0.4144258499145508
# assembling the matrix time taken:  0.0002627372741699219
# solving Ax = b time taken:  0.002032756805419922
# 		 time taken minimize linear layer:  0.0023279190063476562
# current error:  tensor(0.0473)
# epoch:  49	argmax time taken,  0.4143829345703125
# assembling the matrix time taken:  0.0002529621124267578
# solving Ax = b time taken:  0.0021681785583496094
# 		 time taken minimize linear layer:  0.002452850341796875
# current error:  tensor(0.0460)
# epoch:  50	argmax time taken,  0.4143691062927246
# assembling the matrix time taken:  0.00026226043701171875
# solving Ax = b time taken:  0.002199888229370117
# 		 time taken minimize linear layer:  0.00249481201171875
# current error:  tensor(0.0447)
# epoch:  51	argmax time taken,  0.4145078659057617
# assembling the matrix time taken:  0.0002493858337402344
# solving Ax = b time taken:  0.002268552780151367
# 		 time taken minimize linear layer:  0.002549886703491211
# current error:  tensor(0.0441)
# epoch:  52	argmax time taken,  0.41440582275390625
# assembling the matrix time taken:  0.0002651214599609375
# solving Ax = b time taken:  0.0022764205932617188
# 		 time taken minimize linear layer:  0.0025758743286132812
# current error:  tensor(0.0434)
# epoch:  53	argmax time taken,  0.41438889503479004
# assembling the matrix time taken:  0.0002510547637939453
# solving Ax = b time taken:  0.0023550987243652344
# 		 time taken minimize linear layer:  0.0026383399963378906
# current error:  tensor(0.0423)
# epoch:  54	argmax time taken,  0.41454362869262695
# assembling the matrix time taken:  0.00026988983154296875
# solving Ax = b time taken:  0.0023717880249023438
# 		 time taken minimize linear layer:  0.0026748180389404297
# current error:  tensor(0.0420)
# epoch:  55	argmax time taken,  0.4145669937133789
# assembling the matrix time taken:  0.00024890899658203125
# solving Ax = b time taken:  0.002454996109008789
# 		 time taken minimize linear layer:  0.0027365684509277344
# current error:  tensor(0.0414)
# epoch:  56	argmax time taken,  0.4146687984466553
# assembling the matrix time taken:  0.0002663135528564453
# solving Ax = b time taken:  0.0024306774139404297
# 		 time taken minimize linear layer:  0.002730131149291992
# current error:  tensor(0.0407)
# epoch:  57	argmax time taken,  0.4144160747528076
# assembling the matrix time taken:  0.00025010108947753906
# solving Ax = b time taken:  0.0025360584259033203
# 		 time taken minimize linear layer:  0.0028188228607177734
# current error:  tensor(0.0405)
# epoch:  58	argmax time taken,  0.4145781993865967
# assembling the matrix time taken:  0.00026297569274902344
# solving Ax = b time taken:  0.002555370330810547
# 		 time taken minimize linear layer:  0.0028519630432128906
# current error:  tensor(0.0397)
# epoch:  59	argmax time taken,  0.4145359992980957
# assembling the matrix time taken:  0.00025153160095214844
# solving Ax = b time taken:  0.002614736557006836
# 		 time taken minimize linear layer:  0.002899169921875
# current error:  tensor(0.0392)
# epoch:  60	argmax time taken,  0.41457533836364746
# assembling the matrix time taken:  0.00026488304138183594
# solving Ax = b time taken:  0.002617359161376953
# 		 time taken minimize linear layer:  0.0029144287109375
# current error:  tensor(0.0390)
# epoch:  61	argmax time taken,  0.4146137237548828
# assembling the matrix time taken:  0.00025725364685058594
# solving Ax = b time taken:  0.0026810169219970703
# 		 time taken minimize linear layer:  0.0029718875885009766
# current error:  tensor(0.0389)
# epoch:  62	argmax time taken,  0.41460657119750977
# assembling the matrix time taken:  0.00026154518127441406
# solving Ax = b time taken:  0.002725362777709961
# 		 time taken minimize linear layer:  0.003020048141479492
# current error:  tensor(0.0388)
# epoch:  63	argmax time taken,  0.41477513313293457
# assembling the matrix time taken:  0.0002532005310058594
# solving Ax = b time taken:  0.0027937889099121094
# 		 time taken minimize linear layer:  0.0030798912048339844
# current error:  tensor(0.0385)
# epoch:  64	argmax time taken,  0.41469240188598633
# assembling the matrix time taken:  0.000263214111328125
# solving Ax = b time taken:  0.002772808074951172
# 		 time taken minimize linear layer:  0.003069162368774414
# current error:  tensor(0.0384)
# epoch:  65	argmax time taken,  0.4146568775177002
# assembling the matrix time taken:  0.00025391578674316406
# solving Ax = b time taken:  0.0033583641052246094
# 		 time taken minimize linear layer:  0.0036449432373046875
# current error:  tensor(0.0383)
# epoch:  66	argmax time taken,  0.4147219657897949
# assembling the matrix time taken:  0.0002613067626953125
# solving Ax = b time taken:  0.003475666046142578
# 		 time taken minimize linear layer:  0.0037698745727539062
# current error:  tensor(0.0382)
# epoch:  67	argmax time taken,  0.4148831367492676
# assembling the matrix time taken:  0.0002512931823730469
# solving Ax = b time taken:  0.003447294235229492
# 		 time taken minimize linear layer:  0.00373077392578125
# current error:  tensor(0.0380)
# epoch:  68	argmax time taken,  0.4148569107055664
# assembling the matrix time taken:  0.0002636909484863281
# solving Ax = b time taken:  0.003436565399169922
# 		 time taken minimize linear layer:  0.0037326812744140625
# current error:  tensor(0.0377)
# epoch:  69	argmax time taken,  0.41465282440185547
# assembling the matrix time taken:  0.0002589225769042969
# solving Ax = b time taken:  0.0035605430603027344
# 		 time taken minimize linear layer:  0.003851652145385742
# current error:  tensor(0.0374)
# epoch:  70	argmax time taken,  0.4147167205810547
# assembling the matrix time taken:  0.00026226043701171875
# solving Ax = b time taken:  0.003690958023071289
# 		 time taken minimize linear layer:  0.003985404968261719
# current error:  tensor(0.0370)
# epoch:  71	argmax time taken,  0.41517210006713867
# assembling the matrix time taken:  0.0002498626708984375
# solving Ax = b time taken:  0.0036847591400146484
# 		 time taken minimize linear layer:  0.003967761993408203
# current error:  tensor(0.0369)
# epoch:  72	argmax time taken,  0.41497206687927246
# assembling the matrix time taken:  0.0002636909484863281
# solving Ax = b time taken:  0.003582000732421875
# 		 time taken minimize linear layer:  0.003878355026245117
# current error:  tensor(0.0367)
# epoch:  73	argmax time taken,  0.41527247428894043
# assembling the matrix time taken:  0.0002589225769042969
# solving Ax = b time taken:  0.003838777542114258
# 		 time taken minimize linear layer:  0.004130125045776367
# current error:  tensor(0.0362)
# epoch:  74	argmax time taken,  0.41498684883117676
# assembling the matrix time taken:  0.0002665519714355469
# solving Ax = b time taken:  0.003971099853515625
# 		 time taken minimize linear layer:  0.004270315170288086
# current error:  tensor(0.0349)
# epoch:  75	argmax time taken,  0.41475796699523926
# assembling the matrix time taken:  0.00025081634521484375
# solving Ax = b time taken:  0.004041433334350586
# 		 time taken minimize linear layer:  0.004325151443481445
# current error:  tensor(0.0348)
# epoch:  76	argmax time taken,  0.4148678779602051
# assembling the matrix time taken:  0.0002651214599609375
# solving Ax = b time taken:  0.003987789154052734
# 		 time taken minimize linear layer:  0.004285573959350586
# current error:  tensor(0.0345)
# epoch:  77	argmax time taken,  0.41556382179260254
# assembling the matrix time taken:  0.0002522468566894531
# solving Ax = b time taken:  0.004202604293823242
# 		 time taken minimize linear layer:  0.004487752914428711
# current error:  tensor(0.0341)
# epoch:  78	argmax time taken,  0.4149630069732666
# assembling the matrix time taken:  0.0002715587615966797
# solving Ax = b time taken:  0.0043447017669677734
# 		 time taken minimize linear layer:  0.004648685455322266
# current error:  tensor(0.0338)
# epoch:  79	argmax time taken,  0.41507697105407715
# assembling the matrix time taken:  0.0002593994140625
# solving Ax = b time taken:  0.00430750846862793
# 		 time taken minimize linear layer:  0.004599094390869141
# current error:  tensor(0.0332)
# epoch:  80	argmax time taken,  0.4150700569152832
# assembling the matrix time taken:  0.0002751350402832031
# solving Ax = b time taken:  0.004000186920166016
# 		 time taken minimize linear layer:  0.004308223724365234
# current error:  tensor(0.0327)
# epoch:  81	argmax time taken,  0.4160311222076416
# assembling the matrix time taken:  0.00025343894958496094
# solving Ax = b time taken:  0.004410982131958008
# 		 time taken minimize linear layer:  0.004697084426879883
# current error:  tensor(0.0322)
# epoch:  82	argmax time taken,  0.4151179790496826
# assembling the matrix time taken:  0.0002665519714355469
# solving Ax = b time taken:  0.004552602767944336
# 		 time taken minimize linear layer:  0.004852771759033203
# current error:  tensor(0.0314)
# epoch:  83	argmax time taken,  0.4158933162689209
# assembling the matrix time taken:  0.00025963783264160156
# solving Ax = b time taken:  0.004452943801879883
# 		 time taken minimize linear layer:  0.0047452449798583984
# current error:  tensor(0.0306)
# epoch:  84	argmax time taken,  0.41518425941467285
# assembling the matrix time taken:  0.00026535987854003906
# solving Ax = b time taken:  0.0044476985931396484
# 		 time taken minimize linear layer:  0.004746675491333008
# current error:  tensor(0.0298)
# epoch:  85	argmax time taken,  0.4151287078857422
# assembling the matrix time taken:  0.00025200843811035156
# solving Ax = b time taken:  0.004545688629150391
# 		 time taken minimize linear layer:  0.004830121994018555
# current error:  tensor(0.0292)
# epoch:  86	argmax time taken,  0.4150688648223877
# assembling the matrix time taken:  0.0002722740173339844
# solving Ax = b time taken:  0.004720211029052734
# 		 time taken minimize linear layer:  0.005024909973144531
# current error:  tensor(0.0273)
# epoch:  87	argmax time taken,  0.4163951873779297
# assembling the matrix time taken:  0.00025200843811035156
# solving Ax = b time taken:  0.004625558853149414
# 		 time taken minimize linear layer:  0.004915475845336914
# current error:  tensor(0.0267)
# epoch:  88	argmax time taken,  0.41518330574035645
# assembling the matrix time taken:  0.0002868175506591797
# solving Ax = b time taken:  0.004456758499145508
# 		 time taken minimize linear layer:  0.0047762393951416016
# current error:  tensor(0.0261)
# epoch:  89	argmax time taken,  0.41514015197753906
# assembling the matrix time taken:  0.0002491474151611328
# solving Ax = b time taken:  0.004701375961303711
# 		 time taken minimize linear layer:  0.004983425140380859
# current error:  tensor(0.0256)
# epoch:  90	argmax time taken,  0.4151172637939453
# assembling the matrix time taken:  0.0002682209014892578
# solving Ax = b time taken:  0.004911661148071289
# 		 time taken minimize linear layer:  0.005212306976318359
# current error:  tensor(0.0237)
# epoch:  91	argmax time taken,  0.41501426696777344
# assembling the matrix time taken:  0.00025844573974609375
# solving Ax = b time taken:  0.00478363037109375
# 		 time taken minimize linear layer:  0.005074501037597656
# current error:  tensor(0.0229)
# epoch:  92	argmax time taken,  0.41677045822143555
# assembling the matrix time taken:  0.000270843505859375
# solving Ax = b time taken:  0.004741668701171875
# 		 time taken minimize linear layer:  0.005045175552368164
# current error:  tensor(0.0220)
# epoch:  93	argmax time taken,  0.4152414798736572
# assembling the matrix time taken:  0.0002551078796386719
# solving Ax = b time taken:  0.00484919548034668
# 		 time taken minimize linear layer:  0.005136728286743164
# current error:  tensor(0.0211)
# epoch:  94	argmax time taken,  0.41522955894470215
# assembling the matrix time taken:  0.00026488304138183594
# solving Ax = b time taken:  0.00509953498840332
# 		 time taken minimize linear layer:  0.005397319793701172
# current error:  tensor(0.0206)
# epoch:  95	argmax time taken,  0.41692662239074707
# assembling the matrix time taken:  0.0002467632293701172
# solving Ax = b time taken:  0.004976511001586914
# 		 time taken minimize linear layer:  0.005255222320556641
# current error:  tensor(0.0202)
# epoch:  96	argmax time taken,  0.415264368057251
# assembling the matrix time taken:  0.0002620220184326172
# solving Ax = b time taken:  0.004599809646606445
# 		 time taken minimize linear layer:  0.00489497184753418
# current error:  tensor(0.0191)
# epoch:  97	argmax time taken,  0.41536879539489746
# assembling the matrix time taken:  0.0002512931823730469
# solving Ax = b time taken:  0.004990816116333008
# 		 time taken minimize linear layer:  0.005274295806884766
# current error:  tensor(0.0185)
# epoch:  98	argmax time taken,  0.41712260246276855
# assembling the matrix time taken:  0.00026416778564453125
# solving Ax = b time taken:  0.005214214324951172
# 		 time taken minimize linear layer:  0.005511045455932617
# current error:  tensor(0.0181)
# epoch:  99	argmax time taken,  0.41716456413269043
# assembling the matrix time taken:  0.0002562999725341797
# solving Ax = b time taken:  0.0051212310791015625
# 		 time taken minimize linear layer:  0.005410671234130859
# current error:  tensor(0.0177)
# epoch:  100	argmax time taken,  0.4153921604156494
# assembling the matrix time taken:  0.0002675056457519531
# solving Ax = b time taken:  0.0051136016845703125
# 		 time taken minimize linear layer:  0.005413532257080078
# current error:  tensor(0.0174)
# epoch:  101	argmax time taken,  0.4172220230102539
# assembling the matrix time taken:  0.0002570152282714844
# solving Ax = b time taken:  0.005238771438598633
# 		 time taken minimize linear layer:  0.00552821159362793
# current error:  tensor(0.0170)
# epoch:  102	argmax time taken,  0.41730237007141113
# assembling the matrix time taken:  0.00026488304138183594
# solving Ax = b time taken:  0.005480766296386719
# 		 time taken minimize linear layer:  0.0057790279388427734
# current error:  tensor(0.0167)
# epoch:  103	argmax time taken,  0.4156060218811035
# assembling the matrix time taken:  0.0002613067626953125
# solving Ax = b time taken:  0.005346775054931641
# 		 time taken minimize linear layer:  0.005640745162963867
# current error:  tensor(0.0165)
# epoch:  104	argmax time taken,  0.4154651165008545
# assembling the matrix time taken:  0.00026345252990722656
# solving Ax = b time taken:  0.005247592926025391
# 		 time taken minimize linear layer:  0.005543708801269531
# current error:  tensor(0.0163)
# epoch:  105	argmax time taken,  0.41558170318603516
# assembling the matrix time taken:  0.0002510547637939453
# solving Ax = b time taken:  0.005369901657104492
# 		 time taken minimize linear layer:  0.0056536197662353516
# current error:  tensor(0.0161)
# epoch:  106	argmax time taken,  0.41547441482543945
# assembling the matrix time taken:  0.0002639293670654297
# solving Ax = b time taken:  0.005666255950927734
# 		 time taken minimize linear layer:  0.005962848663330078
# current error:  tensor(0.0159)
# epoch:  107	argmax time taken,  0.4171454906463623
# assembling the matrix time taken:  0.00025272369384765625
# solving Ax = b time taken:  0.0055310726165771484
# 		 time taken minimize linear layer:  0.005816221237182617
# current error:  tensor(0.0158)
# epoch:  108	argmax time taken,  0.41732025146484375
# assembling the matrix time taken:  0.0002658367156982422
# solving Ax = b time taken:  0.005504131317138672
# 		 time taken minimize linear layer:  0.0058023929595947266
# current error:  tensor(0.0155)
# epoch:  109	argmax time taken,  0.4174008369445801
# assembling the matrix time taken:  0.00025200843811035156
# solving Ax = b time taken:  0.005604743957519531
# 		 time taken minimize linear layer:  0.005888700485229492
# current error:  tensor(0.0153)
# epoch:  110	argmax time taken,  0.4172520637512207
# assembling the matrix time taken:  0.00026798248291015625
# solving Ax = b time taken:  0.0058557987213134766
# 		 time taken minimize linear layer:  0.0061566829681396484
# current error:  tensor(0.0151)
# epoch:  111	argmax time taken,  0.41736698150634766
# assembling the matrix time taken:  0.0002484321594238281
# solving Ax = b time taken:  0.005727529525756836
# 		 time taken minimize linear layer:  0.006007671356201172
# current error:  tensor(0.0149)
# epoch:  112	argmax time taken,  0.41565561294555664
# assembling the matrix time taken:  0.00025010108947753906
# solving Ax = b time taken:  0.005585193634033203
# 		 time taken minimize linear layer:  0.005867719650268555
# current error:  tensor(0.0146)
# epoch:  113	argmax time taken,  0.41719484329223633
# assembling the matrix time taken:  0.00025200843811035156
# solving Ax = b time taken:  0.005966663360595703
# 		 time taken minimize linear layer:  0.00625157356262207
# current error:  tensor(0.0144)
# epoch:  114	argmax time taken,  0.41553497314453125
# assembling the matrix time taken:  0.0002498626708984375
# solving Ax = b time taken:  0.005837440490722656
# 		 time taken minimize linear layer:  0.006120204925537109
# current error:  tensor(0.0142)
# epoch:  115	argmax time taken,  0.41547608375549316
# assembling the matrix time taken:  0.0002510547637939453
# solving Ax = b time taken:  0.0059680938720703125
# 		 time taken minimize linear layer:  0.0062520503997802734
# current error:  tensor(0.0140)
# epoch:  116	argmax time taken,  0.4172637462615967
# assembling the matrix time taken:  0.0002512931823730469
# solving Ax = b time taken:  0.005896091461181641
# 		 time taken minimize linear layer:  0.0061795711517333984
# current error:  tensor(0.0139)
# epoch:  117	argmax time taken,  0.4156925678253174
# assembling the matrix time taken:  0.00025153160095214844
# solving Ax = b time taken:  0.006055116653442383
# 		 time taken minimize linear layer:  0.006338834762573242
# current error:  tensor(0.0138)
# epoch:  118	argmax time taken,  0.41744327545166016
# assembling the matrix time taken:  0.0002493858337402344
# solving Ax = b time taken:  0.006043672561645508
# 		 time taken minimize linear layer:  0.006325960159301758
# current error:  tensor(0.0130)
# epoch:  119	argmax time taken,  0.4174172878265381
# assembling the matrix time taken:  0.00025153160095214844
# solving Ax = b time taken:  0.006209373474121094
# 		 time taken minimize linear layer:  0.006493806838989258
# current error:  tensor(0.0126)
# epoch:  120	argmax time taken,  0.41730642318725586
# assembling the matrix time taken:  0.00025081634521484375
# solving Ax = b time taken:  0.006010770797729492
# 		 time taken minimize linear layer:  0.006294727325439453
# current error:  tensor(0.0124)
# epoch:  121	argmax time taken,  0.4158046245574951
# assembling the matrix time taken:  0.0002567768096923828
# solving Ax = b time taken:  0.006265163421630859
# 		 time taken minimize linear layer:  0.006554603576660156
# current error:  tensor(0.0122)
# epoch:  122	argmax time taken,  0.41750264167785645
# assembling the matrix time taken:  0.0002505779266357422
# solving Ax = b time taken:  0.006274700164794922
# 		 time taken minimize linear layer:  0.006558895111083984
# current error:  tensor(0.0120)
# epoch:  123	argmax time taken,  0.4176032543182373
# assembling the matrix time taken:  0.0002605915069580078
# solving Ax = b time taken:  0.006404399871826172
# 		 time taken minimize linear layer:  0.006697177886962891
# current error:  tensor(0.0119)
# epoch:  124	argmax time taken,  0.4158773422241211
# assembling the matrix time taken:  0.00025272369384765625
# solving Ax = b time taken:  0.006318330764770508
# 		 time taken minimize linear layer:  0.006604433059692383
# current error:  tensor(0.0118)
# epoch:  125	argmax time taken,  0.4177358150482178
# assembling the matrix time taken:  0.0002624988555908203
# solving Ax = b time taken:  0.006487846374511719
# 		 time taken minimize linear layer:  0.0067827701568603516
# current error:  tensor(0.0118)
# epoch:  126	argmax time taken,  0.41773462295532227
# assembling the matrix time taken:  0.0002560615539550781
# solving Ax = b time taken:  0.0064585208892822266
# 		 time taken minimize linear layer:  0.006747722625732422
# current error:  tensor(0.0116)
# epoch:  127	argmax time taken,  0.4177873134613037
# assembling the matrix time taken:  0.0002551078796386719
# solving Ax = b time taken:  0.006577014923095703
# 		 time taken minimize linear layer:  0.006864070892333984
# current error:  tensor(0.0115)
# epoch:  128	argmax time taken,  0.41786694526672363
# assembling the matrix time taken:  0.0002536773681640625
# solving Ax = b time taken:  0.0065288543701171875
# 		 time taken minimize linear layer:  0.00681614875793457
# current error:  tensor(0.0112)
# epoch:  129	argmax time taken,  0.41593170166015625
# assembling the matrix time taken:  0.0002548694610595703
# solving Ax = b time taken:  0.007807016372680664
# 		 time taken minimize linear layer:  0.00809478759765625
# current error:  tensor(0.0111)
# epoch:  130	argmax time taken,  0.4161827564239502
# assembling the matrix time taken:  0.00027489662170410156
# solving Ax = b time taken:  0.008159637451171875
# 		 time taken minimize linear layer:  0.008467912673950195
# current error:  tensor(0.0110)
# epoch:  131	argmax time taken,  0.4176762104034424
# assembling the matrix time taken:  0.00025343894958496094
# solving Ax = b time taken:  0.008002519607543945
# 		 time taken minimize linear layer:  0.008293628692626953
# current error:  tensor(0.0109)
# epoch:  132	argmax time taken,  0.41602158546447754
# assembling the matrix time taken:  0.0002639293670654297
# solving Ax = b time taken:  0.008083581924438477
# 		 time taken minimize linear layer:  0.008380413055419922
# current error:  tensor(0.0109)
# epoch:  133	argmax time taken,  0.4161231517791748
# assembling the matrix time taken:  0.0002512931823730469
# solving Ax = b time taken:  0.008075714111328125
# 		 time taken minimize linear layer:  0.008359193801879883
# current error:  tensor(0.0107)
# epoch:  134	argmax time taken,  0.4163811206817627
# assembling the matrix time taken:  0.0002627372741699219
# solving Ax = b time taken:  0.008279800415039062
# 		 time taken minimize linear layer:  0.008576154708862305
# current error:  tensor(0.0106)
# epoch:  135	argmax time taken,  0.41641688346862793
# assembling the matrix time taken:  0.00025582313537597656
# solving Ax = b time taken:  0.00821685791015625
# 		 time taken minimize linear layer:  0.008506536483764648
# current error:  tensor(0.0105)
# epoch:  136	argmax time taken,  0.4164714813232422
# assembling the matrix time taken:  0.00026297569274902344
# solving Ax = b time taken:  0.008295774459838867
# 		 time taken minimize linear layer:  0.008591175079345703
# current error:  tensor(0.0105)
# epoch:  137	argmax time taken,  0.416400671005249
# assembling the matrix time taken:  0.0002484321594238281
# solving Ax = b time taken:  0.008372068405151367
# 		 time taken minimize linear layer:  0.008653879165649414
# current error:  tensor(0.0103)
# epoch:  138	argmax time taken,  0.4167788028717041
# assembling the matrix time taken:  0.0002589225769042969
# solving Ax = b time taken:  0.008634805679321289
# 		 time taken minimize linear layer:  0.008926153182983398
# current error:  tensor(0.0103)
# epoch:  139	argmax time taken,  0.41662025451660156
# assembling the matrix time taken:  0.00025200843811035156
# solving Ax = b time taken:  0.008507013320922852
# 		 time taken minimize linear layer:  0.00879216194152832
# current error:  tensor(0.0102)
# epoch:  140	argmax time taken,  0.4167792797088623
# assembling the matrix time taken:  0.0002646446228027344
# solving Ax = b time taken:  0.008587837219238281
# 		 time taken minimize linear layer:  0.008885622024536133
# current error:  tensor(0.0101)
# epoch:  141	argmax time taken,  0.41791367530822754
# assembling the matrix time taken:  0.0002522468566894531
# solving Ax = b time taken:  0.008539676666259766
# 		 time taken minimize linear layer:  0.008824586868286133
# current error:  tensor(0.0101)
# epoch:  142	argmax time taken,  0.41703224182128906
# assembling the matrix time taken:  0.0002663135528564453
# solving Ax = b time taken:  0.008780241012573242
# 		 time taken minimize linear layer:  0.0090789794921875
# current error:  tensor(0.0101)
# epoch:  143	argmax time taken,  0.41787123680114746
# assembling the matrix time taken:  0.00025773048400878906
# solving Ax = b time taken:  0.008688926696777344
# 		 time taken minimize linear layer:  0.008979558944702148
# current error:  tensor(0.0099)
# epoch:  144	argmax time taken,  0.4170858860015869
# assembling the matrix time taken:  0.0002636909484863281
# solving Ax = b time taken:  0.008517026901245117
# 		 time taken minimize linear layer:  0.008814334869384766
# current error:  tensor(0.0097)
# epoch:  145	argmax time taken,  0.4179365634918213
# assembling the matrix time taken:  0.00026988983154296875
# solving Ax = b time taken:  0.010042667388916016
# 		 time taken minimize linear layer:  0.010345220565795898
# current error:  tensor(0.0096)
# epoch:  146	argmax time taken,  0.4172532558441162
# assembling the matrix time taken:  0.0002529621124267578
# solving Ax = b time taken:  0.009882926940917969
# 		 time taken minimize linear layer:  0.010168790817260742
# current error:  tensor(0.0096)
# epoch:  147	argmax time taken,  0.41724324226379395
# assembling the matrix time taken:  0.0002512931823730469
# solving Ax = b time taken:  0.010050296783447266
# 		 time taken minimize linear layer:  0.010334014892578125
# current error:  tensor(0.0095)
# epoch:  148	argmax time taken,  0.4172322750091553
# assembling the matrix time taken:  0.00025844573974609375
# solving Ax = b time taken:  0.00988626480102539
# 		 time taken minimize linear layer:  0.010178089141845703
# current error:  tensor(0.0094)
# epoch:  149	argmax time taken,  0.41722846031188965
# assembling the matrix time taken:  0.0002524852752685547
# solving Ax = b time taken:  0.010074853897094727
# 		 time taken minimize linear layer:  0.010360240936279297
# current error:  tensor(0.0094)
# epoch:  150	argmax time taken,  0.41757798194885254
# assembling the matrix time taken:  0.0002529621124267578
# solving Ax = b time taken:  0.010066032409667969
# 		 time taken minimize linear layer:  0.010352611541748047
# current error:  tensor(0.0092)
# epoch:  151	argmax time taken,  0.41811680793762207
# assembling the matrix time taken:  0.00025177001953125
# solving Ax = b time taken:  0.010252952575683594
# 		 time taken minimize linear layer:  0.01053762435913086
# current error:  tensor(0.0092)
# epoch:  152	argmax time taken,  0.4176754951477051
# assembling the matrix time taken:  0.00024890899658203125
# solving Ax = b time taken:  0.009784221649169922
# 		 time taken minimize linear layer:  0.010066032409667969
# current error:  tensor(0.0091)
# epoch:  153	argmax time taken,  0.4182472229003906
# assembling the matrix time taken:  0.00024700164794921875
# solving Ax = b time taken:  0.009233474731445312
# 		 time taken minimize linear layer:  0.009513378143310547
# current error:  tensor(0.0090)
# epoch:  154	argmax time taken,  0.4179551601409912
# assembling the matrix time taken:  0.00025153160095214844
# solving Ax = b time taken:  0.009237051010131836
# 		 time taken minimize linear layer:  0.009521484375
# current error:  tensor(0.0090)
# epoch:  155	argmax time taken,  0.41829681396484375
# assembling the matrix time taken:  0.00025010108947753906
# solving Ax = b time taken:  0.00940394401550293
# 		 time taken minimize linear layer:  0.00968623161315918
# current error:  tensor(0.0089)
# epoch:  156	argmax time taken,  0.418118953704834
# assembling the matrix time taken:  0.00024890899658203125
# solving Ax = b time taken:  0.009215116500854492
# 		 time taken minimize linear layer:  0.009497404098510742
# current error:  tensor(0.0089)
# epoch:  157	argmax time taken,  0.4183921813964844
# assembling the matrix time taken:  0.00031065940856933594
# solving Ax = b time taken:  0.009499549865722656
# 		 time taken minimize linear layer:  0.009847640991210938
# current error:  tensor(0.0088)
# epoch:  158	argmax time taken,  0.4182753562927246
# assembling the matrix time taken:  0.00025081634521484375
# solving Ax = b time taken:  0.00948023796081543
# 		 time taken minimize linear layer:  0.009763956069946289
# current error:  tensor(0.0088)
# epoch:  159	argmax time taken,  0.418292760848999
# assembling the matrix time taken:  0.000255584716796875
# solving Ax = b time taken:  0.009614944458007812
# 		 time taken minimize linear layer:  0.009903669357299805
# current error:  tensor(0.0087)
# epoch:  160	argmax time taken,  0.41825032234191895
# assembling the matrix time taken:  0.0002467632293701172
# solving Ax = b time taken:  0.00934290885925293
# 		 time taken minimize linear layer:  0.009621858596801758
# current error:  tensor(0.0086)
# epoch:  161	argmax time taken,  0.41830992698669434
# assembling the matrix time taken:  0.0002532005310058594
# solving Ax = b time taken:  0.009770393371582031
# 		 time taken minimize linear layer:  0.010056257247924805
# current error:  tensor(0.0086)
# epoch:  162	argmax time taken,  0.41833066940307617
# assembling the matrix time taken:  0.00024628639221191406
# solving Ax = b time taken:  0.009739875793457031
# 		 time taken minimize linear layer:  0.010018348693847656
# current error:  tensor(0.0085)
# epoch:  163	argmax time taken,  0.4182744026184082
# assembling the matrix time taken:  0.0002472400665283203
# solving Ax = b time taken:  0.009966850280761719
# 		 time taken minimize linear layer:  0.01024627685546875
# current error:  tensor(0.0083)
# epoch:  164	argmax time taken,  0.4182751178741455
# assembling the matrix time taken:  0.00025177001953125
# solving Ax = b time taken:  0.009784936904907227
# 		 time taken minimize linear layer:  0.01006937026977539
# current error:  tensor(0.0082)
# epoch:  165	argmax time taken,  0.4182591438293457
# assembling the matrix time taken:  0.00025391578674316406
# solving Ax = b time taken:  0.009980440139770508
# 		 time taken minimize linear layer:  0.010267019271850586
# current error:  tensor(0.0081)
# epoch:  166	argmax time taken,  0.41832828521728516
# assembling the matrix time taken:  0.0002524852752685547
# solving Ax = b time taken:  0.009984493255615234
# 		 time taken minimize linear layer:  0.010269403457641602
# current error:  tensor(0.0081)
# epoch:  167	argmax time taken,  0.41845202445983887
# assembling the matrix time taken:  0.00025153160095214844
# solving Ax = b time taken:  0.010130882263183594
# 		 time taken minimize linear layer:  0.010415315628051758
# current error:  tensor(0.0079)
# epoch:  168	argmax time taken,  0.4182877540588379
# assembling the matrix time taken:  0.0002484321594238281
# solving Ax = b time taken:  0.009901046752929688
# 		 time taken minimize linear layer:  0.010181665420532227
# current error:  tensor(0.0079)
# epoch:  169	argmax time taken,  0.41843414306640625
# assembling the matrix time taken:  0.00025463104248046875
# solving Ax = b time taken:  0.010219335556030273
# 		 time taken minimize linear layer:  0.01050710678100586
# current error:  tensor(0.0078)
# epoch:  170	argmax time taken,  0.418506383895874
# assembling the matrix time taken:  0.00024700164794921875
# solving Ax = b time taken:  0.010154247283935547
# 		 time taken minimize linear layer:  0.010434627532958984
# current error:  tensor(0.0078)
# epoch:  171	argmax time taken,  0.41843271255493164
# assembling the matrix time taken:  0.00025343894958496094
# solving Ax = b time taken:  0.010329723358154297
# 		 time taken minimize linear layer:  0.01061558723449707
# current error:  tensor(0.0076)
# epoch:  172	argmax time taken,  0.4186134338378906
# assembling the matrix time taken:  0.00024700164794921875
# solving Ax = b time taken:  0.010155677795410156
# 		 time taken minimize linear layer:  0.010436058044433594
# current error:  tensor(0.0075)
# epoch:  173	argmax time taken,  0.4185929298400879
# assembling the matrix time taken:  0.00025463104248046875
# solving Ax = b time taken:  0.010375738143920898
# 		 time taken minimize linear layer:  0.010663509368896484
# current error:  tensor(0.0075)
# epoch:  174	argmax time taken,  0.41860485076904297
# assembling the matrix time taken:  0.0002512931823730469
# solving Ax = b time taken:  0.010352134704589844
# 		 time taken minimize linear layer:  0.010636568069458008
# current error:  tensor(0.0074)
# epoch:  175	argmax time taken,  0.4184436798095703
# assembling the matrix time taken:  0.00024390220642089844
# solving Ax = b time taken:  0.010524749755859375
# 		 time taken minimize linear layer:  0.01080179214477539
# current error:  tensor(0.0074)
# epoch:  176	argmax time taken,  0.418623685836792
# assembling the matrix time taken:  0.00024628639221191406
# solving Ax = b time taken:  0.01031184196472168
# 		 time taken minimize linear layer:  0.010590791702270508
# current error:  tensor(0.0073)
# epoch:  177	argmax time taken,  0.4186108112335205
# assembling the matrix time taken:  0.0002522468566894531
# solving Ax = b time taken:  0.010656356811523438
# 		 time taken minimize linear layer:  0.010941743850708008
# current error:  tensor(0.0073)
# epoch:  178	argmax time taken,  0.4186379909515381
# assembling the matrix time taken:  0.0002455711364746094
# solving Ax = b time taken:  0.010656595230102539
# 		 time taken minimize linear layer:  0.010934591293334961
# current error:  tensor(0.0072)
# epoch:  179	argmax time taken,  0.4185667037963867
# assembling the matrix time taken:  0.0002455711364746094
# solving Ax = b time taken:  0.010814189910888672
# 		 time taken minimize linear layer:  0.011092662811279297
# current error:  tensor(0.0072)
# epoch:  180	argmax time taken,  0.41863250732421875
# assembling the matrix time taken:  0.00024962425231933594
# solving Ax = b time taken:  0.010735511779785156
# 		 time taken minimize linear layer:  0.011018037796020508
# current error:  tensor(0.0071)
# epoch:  181	argmax time taken,  0.41863536834716797
# assembling the matrix time taken:  0.0002415180206298828
# solving Ax = b time taken:  0.010911941528320312
# 		 time taken minimize linear layer:  0.011191129684448242
# current error:  tensor(0.0071)
# epoch:  182	argmax time taken,  0.4186978340148926
# assembling the matrix time taken:  0.00024700164794921875
# solving Ax = b time taken:  0.010833501815795898
# 		 time taken minimize linear layer:  0.011113643646240234
# current error:  tensor(0.0070)
# epoch:  183	argmax time taken,  0.418626070022583
# assembling the matrix time taken:  0.00024962425231933594
# solving Ax = b time taken:  0.011032819747924805
# 		 time taken minimize linear layer:  0.011315107345581055
# current error:  tensor(0.0070)
# epoch:  184	argmax time taken,  0.41879940032958984
# assembling the matrix time taken:  0.0002429485321044922
# solving Ax = b time taken:  0.010834455490112305
# 		 time taken minimize linear layer:  0.01110982894897461
# current error:  tensor(0.0070)
# epoch:  185	argmax time taken,  0.4186689853668213
# assembling the matrix time taken:  0.0002503395080566406
# solving Ax = b time taken:  0.011087656021118164
# 		 time taken minimize linear layer:  0.011370658874511719
# current error:  tensor(0.0069)
# epoch:  186	argmax time taken,  0.4187185764312744
# assembling the matrix time taken:  0.0002551078796386719
# solving Ax = b time taken:  0.011080741882324219
# 		 time taken minimize linear layer:  0.011368513107299805
# current error:  tensor(0.0069)
# epoch:  187	argmax time taken,  0.4187188148498535
# assembling the matrix time taken:  0.0002512931823730469
# solving Ax = b time taken:  0.01126241683959961
# 		 time taken minimize linear layer:  0.011545419692993164
# current error:  tensor(0.0069)
# epoch:  188	argmax time taken,  0.4187602996826172
# assembling the matrix time taken:  0.0002455711364746094
# solving Ax = b time taken:  0.011098861694335938
# 		 time taken minimize linear layer:  0.011377096176147461
# current error:  tensor(0.0069)
# epoch:  189	argmax time taken,  0.4187796115875244
# assembling the matrix time taken:  0.0002593994140625
# solving Ax = b time taken:  0.011338233947753906
# 		 time taken minimize linear layer:  0.011629819869995117
# current error:  tensor(0.0068)
# epoch:  190	argmax time taken,  0.41884946823120117
# assembling the matrix time taken:  0.0002415180206298828
# solving Ax = b time taken:  0.01134037971496582
# 		 time taken minimize linear layer:  0.011614799499511719
# current error:  tensor(0.0068)
# epoch:  191	argmax time taken,  0.41895484924316406
# assembling the matrix time taken:  0.0002455711364746094
# solving Ax = b time taken:  0.011541128158569336
# 		 time taken minimize linear layer:  0.011818885803222656
# current error:  tensor(0.0068)
# epoch:  192	argmax time taken,  0.4189155101776123
# assembling the matrix time taken:  0.00025200843811035156
# solving Ax = b time taken:  0.011337757110595703
# 		 time taken minimize linear layer:  0.011622905731201172
# current error:  tensor(0.0067)
# epoch:  193	argmax time taken,  0.4187734127044678
# assembling the matrix time taken:  0.0002486705780029297
# solving Ax = b time taken:  0.015890836715698242
# 		 time taken minimize linear layer:  0.016173124313354492
# current error:  tensor(0.0067)
# epoch:  194	argmax time taken,  0.4188380241394043
# assembling the matrix time taken:  0.00028014183044433594
# solving Ax = b time taken:  0.012967586517333984
# ...
# current error:  tensor(0.0050)
# epoch:  451	argmax time taken,  0.42540574073791504
# assembling the matrix time taken:  0.00024962425231933594
# solving Ax = b time taken:  0.04654836654663086
# 		 time taken minimize linear layer:  0.04683089256286621
# current error:  tensor(0.0048)
# epoch:  452	argmax time taken,  0.42545390129089355
# assembling the matrix time taken:  0.0002627372741699219
# solving Ax = b time taken:  0.044924020767211914
# 		 time taken minimize linear layer:  0.04521942138671875
# current error:  tensor(0.0049)
# epoch:  453	argmax time taken,  0.4237325191497803
# assembling the matrix time taken:  0.0002548694610595703
# solving Ax = b time taken:  0.04667067527770996
# 		 time taken minimize linear layer:  0.046958208084106445
# current error:  tensor(0.0049)
# epoch:  454	argmax time taken,  0.4257087707519531
# assembling the matrix time taken:  0.00026154518127441406
# solving Ax = b time taken:  0.04597282409667969
# 		 time taken minimize linear layer:  0.04626798629760742
# current error:  tensor(0.0049)
# epoch:  455	argmax time taken,  0.4239060878753662
# assembling the matrix time taken:  0.00024819374084472656
# solving Ax = b time taken:  0.04747724533081055
# 		 time taken minimize linear layer:  0.04775881767272949
# current error:  tensor(0.0052)
# epoch:  456	argmax time taken,  0.4257988929748535
# assembling the matrix time taken:  0.00025963783264160156
# solving Ax = b time taken:  0.04514503479003906
# 		 time taken minimize linear layer:  0.045438528060913086
# current error:  tensor(0.0048)
# epoch:  457	argmax time taken,  0.42403316497802734
# assembling the matrix time taken:  0.0002455711364746094
# solving Ax = b time taken:  0.04723024368286133
# 		 time taken minimize linear layer:  0.04750871658325195
# current error:  tensor(0.0048)
# epoch:  458	argmax time taken,  0.4260432720184326
# assembling the matrix time taken:  0.0002601146697998047
# solving Ax = b time taken:  0.04639124870300293
# 		 time taken minimize linear layer:  0.046684980392456055
# current error:  tensor(0.0048)
# epoch:  459	argmax time taken,  0.424694299697876
# assembling the matrix time taken:  0.0002491474151611328
# solving Ax = b time taken:  0.047426700592041016
# 		 time taken minimize linear layer:  0.04770922660827637
# current error:  tensor(0.0047)
# epoch:  460	argmax time taken,  0.4260983467102051
# assembling the matrix time taken:  0.0002639293670654297
# solving Ax = b time taken:  0.0458223819732666
# 		 time taken minimize linear layer:  0.04611921310424805
# current error:  tensor(0.0048)
# epoch:  461	argmax time taken,  0.4246792793273926
# assembling the matrix time taken:  0.0002465248107910156
# solving Ax = b time taken:  0.04763174057006836
# 		 time taken minimize linear layer:  0.0479123592376709
# current error:  tensor(0.0048)
# epoch:  462	argmax time taken,  0.4264054298400879
# assembling the matrix time taken:  0.0002639293670654297
# solving Ax = b time taken:  0.04694986343383789
# 		 time taken minimize linear layer:  0.04724740982055664
# current error:  tensor(0.0048)
# epoch:  463	argmax time taken,  0.4246025085449219
# assembling the matrix time taken:  0.0002493858337402344
# solving Ax = b time taken:  0.04784822463989258
# 		 time taken minimize linear layer:  0.048131465911865234
# current error:  tensor(0.0049)
# epoch:  464	argmax time taken,  0.4264359474182129
# assembling the matrix time taken:  0.0002663135528564453
# solving Ax = b time taken:  0.046031951904296875
# 		 time taken minimize linear layer:  0.04633140563964844
# current error:  tensor(0.0047)
# epoch:  465	argmax time taken,  0.4246244430541992
# assembling the matrix time taken:  0.0002562999725341797
# solving Ax = b time taken:  0.0481870174407959
# 		 time taken minimize linear layer:  0.048476457595825195
# current error:  tensor(0.0047)
# epoch:  466	argmax time taken,  0.4266812801361084
# assembling the matrix time taken:  0.0002636909484863281
# solving Ax = b time taken:  0.04751777648925781
# 		 time taken minimize linear layer:  0.047814130783081055
# current error:  tensor(0.0048)
# epoch:  467	argmax time taken,  0.4275784492492676
# assembling the matrix time taken:  0.00025177001953125
# solving Ax = b time taken:  0.04849576950073242
# 		 time taken minimize linear layer:  0.04878067970275879
# current error:  tensor(0.0048)
# epoch:  468	argmax time taken,  0.4241178035736084
# assembling the matrix time taken:  0.0002605915069580078
# solving Ax = b time taken:  0.046697378158569336
# 		 time taken minimize linear layer:  0.046991825103759766
# current error:  tensor(0.0050)
# epoch:  469	argmax time taken,  0.426987886428833
# assembling the matrix time taken:  0.000247955322265625
# solving Ax = b time taken:  0.04868364334106445
# 		 time taken minimize linear layer:  0.048964738845825195
# current error:  tensor(0.0054)
# epoch:  470	argmax time taken,  0.42551684379577637
# assembling the matrix time taken:  0.00026679039001464844
# solving Ax = b time taken:  0.04787755012512207
# 		 time taken minimize linear layer:  0.04817819595336914
# current error:  tensor(0.0049)
# epoch:  471	argmax time taken,  0.42731666564941406
# assembling the matrix time taken:  0.0002601146697998047
# solving Ax = b time taken:  0.04886913299560547
# 		 time taken minimize linear layer:  0.04916214942932129
# current error:  tensor(0.0054)
# epoch:  472	argmax time taken,  0.42737317085266113
# assembling the matrix time taken:  0.0002608299255371094
# solving Ax = b time taken:  0.0470883846282959
# 		 time taken minimize linear layer:  0.04738330841064453
# current error:  tensor(0.0054)
# epoch:  473	argmax time taken,  0.4270501136779785
# assembling the matrix time taken:  0.0002491474151611328
# solving Ax = b time taken:  0.04927659034729004
# 		 time taken minimize linear layer:  0.049558401107788086
# current error:  tensor(0.0049)
# epoch:  474	argmax time taken,  0.4273695945739746
# assembling the matrix time taken:  0.00027441978454589844
# solving Ax = b time taken:  0.04876971244812012
# 		 time taken minimize linear layer:  0.04907703399658203
# current error:  tensor(0.0047)
# epoch:  475	argmax time taken,  0.4276094436645508
# assembling the matrix time taken:  0.0002498626708984375
# solving Ax = b time taken:  0.049265384674072266
# 		 time taken minimize linear layer:  0.04954886436462402
# current error:  tensor(0.0048)
# epoch:  476	argmax time taken,  0.42748188972473145
# assembling the matrix time taken:  0.00026035308837890625
# solving Ax = b time taken:  0.04866170883178711
# 		 time taken minimize linear layer:  0.04895496368408203
# current error:  tensor(0.0049)
# epoch:  477	argmax time taken,  0.4258441925048828
# assembling the matrix time taken:  0.00024890899658203125
# solving Ax = b time taken:  0.04941272735595703
# 		 time taken minimize linear layer:  0.04969477653503418
# current error:  tensor(0.0053)
# epoch:  478	argmax time taken,  0.4274611473083496
# assembling the matrix time taken:  0.0002598762512207031
# solving Ax = b time taken:  0.04929208755493164
# 		 time taken minimize linear layer:  0.04958486557006836
# current error:  tensor(0.0048)
# epoch:  479	argmax time taken,  0.4261660575866699
# assembling the matrix time taken:  0.00024819374084472656
# solving Ax = b time taken:  0.049813270568847656
# 		 time taken minimize linear layer:  0.0500948429107666
# current error:  tensor(0.0052)
# epoch:  480	argmax time taken,  0.42760562896728516
# assembling the matrix time taken:  0.0002503395080566406
# solving Ax = b time taken:  0.0489201545715332
# 		 time taken minimize linear layer:  0.049202680587768555
# current error:  tensor(0.0052)
# epoch:  481	argmax time taken,  0.4258725643157959
# assembling the matrix time taken:  0.0002493858337402344
# solving Ax = b time taken:  0.04998302459716797
# 		 time taken minimize linear layer:  0.05026578903198242
# current error:  tensor(0.0053)
# epoch:  482	argmax time taken,  0.4275782108306885
# assembling the matrix time taken:  0.0002541542053222656
# solving Ax = b time taken:  0.05011796951293945
# 		 time taken minimize linear layer:  0.05040574073791504
# current error:  tensor(0.0053)
# epoch:  483	argmax time taken,  0.42591261863708496
# assembling the matrix time taken:  0.0002503395080566406
# solving Ax = b time taken:  0.05040597915649414
# 		 time taken minimize linear layer:  0.0506892204284668
# current error:  tensor(0.0052)
# epoch:  484	argmax time taken,  0.4242541790008545
# assembling the matrix time taken:  0.00024771690368652344
# solving Ax = b time taken:  0.04944920539855957
# 		 time taken minimize linear layer:  0.04972958564758301
# current error:  tensor(0.0051)
# epoch:  485	argmax time taken,  0.42432451248168945
# assembling the matrix time taken:  0.0002532005310058594
# solving Ax = b time taken:  0.050531625747680664
# 		 time taken minimize linear layer:  0.05081772804260254
# current error:  tensor(0.0048)
# epoch:  486	argmax time taken,  0.42425084114074707
# assembling the matrix time taken:  0.00024819374084472656
# solving Ax = b time taken:  0.05017352104187012
# 		 time taken minimize linear layer:  0.050459861755371094
# current error:  tensor(0.0053)
# epoch:  487	argmax time taken,  0.4242522716522217
# assembling the matrix time taken:  0.00024962425231933594
# solving Ax = b time taken:  0.05058145523071289
# 		 time taken minimize linear layer:  0.050864458084106445
# current error:  tensor(0.0049)
# epoch:  488	argmax time taken,  0.4242861270904541
# assembling the matrix time taken:  0.0002498626708984375
# solving Ax = b time taken:  0.049761295318603516
# 		 time taken minimize linear layer:  0.050043582916259766
# current error:  tensor(0.0049)
# epoch:  489	argmax time taken,  0.4243795871734619
# assembling the matrix time taken:  0.00024771690368652344
# solving Ax = b time taken:  0.05105757713317871
# 		 time taken minimize linear layer:  0.05133819580078125
# current error:  tensor(0.0049)
# epoch:  490	argmax time taken,  0.4244260787963867
# assembling the matrix time taken:  0.00024962425231933594
# solving Ax = b time taken:  0.05091404914855957
# 		 time taken minimize linear layer:  0.05119609832763672
# current error:  tensor(0.0053)
# epoch:  491	argmax time taken,  0.42446041107177734
# assembling the matrix time taken:  0.0002498626708984375
# solving Ax = b time taken:  0.051026105880737305
# 		 time taken minimize linear layer:  0.051308393478393555
# current error:  tensor(0.0048)
# epoch:  492	argmax time taken,  0.424485445022583
# assembling the matrix time taken:  0.00025653839111328125
# solving Ax = b time taken:  0.050604820251464844
# 		 time taken minimize linear layer:  0.05089449882507324
# current error:  tensor(0.0047)
# epoch:  493	argmax time taken,  0.4243950843811035
# assembling the matrix time taken:  0.00024271011352539062
# solving Ax = b time taken:  0.05138659477233887
# 		 time taken minimize linear layer:  0.051662445068359375
# current error:  tensor(0.0050)
# epoch:  494	argmax time taken,  0.42662692070007324
# assembling the matrix time taken:  0.0002646446228027344
# solving Ax = b time taken:  0.05146479606628418
# 		 time taken minimize linear layer:  0.05176258087158203
# current error:  tensor(0.0047)
# epoch:  495	argmax time taken,  0.4245288372039795
# assembling the matrix time taken:  0.00025010108947753906
# solving Ax = b time taken:  0.05174708366394043
# 		 time taken minimize linear layer:  0.05202937126159668
# current error:  tensor(0.0048)
# epoch:  496	argmax time taken,  0.42444705963134766
# assembling the matrix time taken:  0.00025653839111328125
# solving Ax = b time taken:  0.05031442642211914
# 		 time taken minimize linear layer:  0.05060386657714844
# current error:  tensor(0.0048)
# epoch:  497	argmax time taken,  0.4244401454925537
# assembling the matrix time taken:  0.0002543926239013672
# solving Ax = b time taken:  0.05204200744628906
# 		 time taken minimize linear layer:  0.05232858657836914
# current error:  tensor(0.0048)
# epoch:  498	argmax time taken,  0.42446064949035645
# assembling the matrix time taken:  0.00025200843811035156
# solving Ax = b time taken:  0.05211186408996582
# 		 time taken minimize linear layer:  0.05239677429199219
# current error:  tensor(0.0055)
# epoch:  499	argmax time taken,  0.4245145320892334
# assembling the matrix time taken:  0.00024700164794921875
# solving Ax = b time taken:  0.05225634574890137
# 		 time taken minimize linear layer:  0.0525357723236084
# current error:  tensor(0.0055)
# epoch:  500	argmax time taken,  0.4246041774749756
# assembling the matrix time taken:  0.00024962425231933594
# solving Ax = b time taken:  0.05145907402038574
# 		 time taken minimize linear layer:  0.05174112319946289
# current error:  tensor(0.0055)
# epoch:  501	argmax time taken,  0.4245331287384033
# assembling the matrix time taken:  0.000244140625
# solving Ax = b time taken:  0.05228853225708008
# 		 time taken minimize linear layer:  0.05256533622741699
# current error:  tensor(0.0047)
# epoch:  502	argmax time taken,  0.4245471954345703
# assembling the matrix time taken:  0.00024819374084472656
# solving Ax = b time taken:  0.05234265327453613
# 		 time taken minimize linear layer:  0.05262470245361328
# current error:  tensor(0.0055)
# epoch:  503	argmax time taken,  0.4246671199798584
# assembling the matrix time taken:  0.0002491474151611328
# solving Ax = b time taken:  0.05264687538146973
# 		 time taken minimize linear layer:  0.05292844772338867
# current error:  tensor(0.0055)
# epoch:  504	argmax time taken,  0.42792606353759766
# assembling the matrix time taken:  0.00024962425231933594
# solving Ax = b time taken:  0.051639556884765625
# 		 time taken minimize linear layer:  0.05192279815673828
# current error:  tensor(0.0055)
# epoch:  505	argmax time taken,  0.4246389865875244
# assembling the matrix time taken:  0.00024437904357910156
# solving Ax = b time taken:  0.05331277847290039
# 		 time taken minimize linear layer:  0.05359029769897461
# current error:  tensor(0.0054)
# epoch:  506	argmax time taken,  0.42809367179870605
# assembling the matrix time taken:  0.00026607513427734375
# solving Ax = b time taken:  0.05303454399108887
# 		 time taken minimize linear layer:  0.05333828926086426
# current error:  tensor(0.0055)
# epoch:  507	argmax time taken,  0.4246857166290283
# assembling the matrix time taken:  0.0002551078796386719
# solving Ax = b time taken:  0.053517818450927734
# 		 time taken minimize linear layer:  0.05380654335021973
# current error:  tensor(0.0047)
# epoch:  508	argmax time taken,  0.4280076026916504
# assembling the matrix time taken:  0.00025177001953125
# solving Ax = b time taken:  0.05272960662841797
# 		 time taken minimize linear layer:  0.05301499366760254
# current error:  tensor(0.0047)
# epoch:  509	argmax time taken,  0.4246494770050049
# assembling the matrix time taken:  0.00024819374084472656
# solving Ax = b time taken:  0.05387544631958008
# 		 time taken minimize linear layer:  0.05415606498718262
# current error:  tensor(0.0047)
# epoch:  510	argmax time taken,  0.4280703067779541
# assembling the matrix time taken:  0.000247955322265625
# solving Ax = b time taken:  0.05375933647155762
# 		 time taken minimize linear layer:  0.054039955139160156
# current error:  tensor(0.0055)
# epoch:  511	argmax time taken,  0.4248237609863281
# assembling the matrix time taken:  0.00024628639221191406
# solving Ax = b time taken:  0.05480837821960449
# 		 time taken minimize linear layer:  0.05508732795715332
# current error:  tensor(0.0047)
# epoch:  512	argmax time taken,  0.42475390434265137
# assembling the matrix time taken:  0.00025010108947753906
# solving Ax = b time taken:  0.06059622764587402
# 		 time taken minimize linear layer:  0.06087994575500488
# current error:  tensor(0.0048)
# time taken:  232.42023396492004
# neuron num 		 error 		 order
# 4 		 0.166379 		 *
#
# 8 		 0.118483 		 0.489794
#
# 16 		 0.107163 		 0.144880
#
# 32 		 0.100642 		 0.090566
#
# 64 		 0.038380 		 1.390823
#
# 128 		 0.011160 		 1.782012
#
# 256 		 0.005421 		 1.041822
#
# 512 		 0.004790 		 0.178448
#
# neuron num  & 	 $\|u-u_n \|_{L^2}$ & 	 order $O(n^{-1.62})$  \\ \hline \hline
# 4 		 & 0.166379 &		 *  \\ \hline
#
# 8 		 &  1.185e-01 &  		 0.49 \\ \hline
#
# 16 		 &  1.072e-01 &  		 0.14 \\ \hline
#
# 32 		 &  1.006e-01 &  		 0.09 \\ \hline
#
# 64 		 &  3.838e-02 &  		 1.39 \\ \hline
#
# 128 		 &  1.116e-02 &  		 1.78 \\ \hline
#
# 256 		 &  5.421e-03 &  		 1.04 \\ \hline
#
# 512 		 &  4.790e-03 &  		 0.18 \\ \hline

# %% [markdown]
# ## Random dictionary

# %%
def target(x):
    return torch.sin(pi*x[:,0:1])*torch.sin(pi*x[:,1:2])*torch.sin(pi*x[:,2:3]) *torch.sin(pi*x[:,3:4])

dim = 4 
function_name = "sin-product-4d" 
filename_write = "data/2DQMCOGA-{}-order.txt".format(function_name)
M = 2**19 # MC points around 50w 
f_write = open(filename_write, "a")
f_write.write("Integration points: Quasi Monte Carlo:  {}\n".format(M))
f_write.close() 
save = True 
write2file = True

for relu_k in [1]: 
    s = 1 
    for N0 in [2**6, 2**7, 2**8]: 
        N = np.prod(N_list) 
        print()
        print() 
        exponent = 9  
        num_epochs=  2**exponent 
    
        my_model = None 
        err, my_model = OGAL2FittingReLU4D_QMC(my_model,target, \
                    s,N0,num_epochs, M, k = relu_k, linear_solver = "direct", num_batches = 1)

        if save: 
            folder = 'data/'
            filename = folder + function_name + "_err_randDict_relu_{}_size_{}_num_neurons_{}.pt".format(relu_k,s * N0,num_epochs)
            torch.save(err,filename)
            filename = folder + function_name + "_model_randDict_relu_{}_size_{}_num_neurons_{}.pt".format(relu_k,s * N0,num_epochs)
            torch.save(my_model.state_dict(),filename) 
            
        show_convergence_order(err,exponent,N,filename_write,write2file = write2file)
        show_convergence_order_latex(err,exponent,k=relu_k,d=dim)
# Out:
# generate sob sequence: 0.005876302719116211
# using linear solver:  direct
# epoch:  1	argmax time taken,  0.0014488697052001953
# assembling the matrix time taken:  0.00025653839111328125
# solving Ax = b time taken:  3.698288679122925
# 		 time taken minimize linear layer:  3.698791742324829
# current error:  tensor(0.1894)
# epoch:  2	argmax time taken,  0.001430511474609375
# assembling the matrix time taken:  0.0002942085266113281
# solving Ax = b time taken:  0.0002727508544921875
# 		 time taken minimize linear layer:  0.0005979537963867188
# current error:  tensor(0.1856)
# epoch:  3	argmax time taken,  0.0015816688537597656
# assembling the matrix time taken:  0.00024771690368652344
# solving Ax = b time taken:  0.0003185272216796875
# 		 time taken minimize linear layer:  0.0005962848663330078
# current error:  tensor(0.1795)
# epoch:  4	argmax time taken,  0.0015726089477539062
# assembling the matrix time taken:  0.0002644062042236328
# solving Ax = b time taken:  0.0003197193145751953
# 		 time taken minimize linear layer:  0.0006124973297119141
# current error:  tensor(0.1752)
# epoch:  5	argmax time taken,  0.0015895366668701172
# assembling the matrix time taken:  0.0002639293670654297
# solving Ax = b time taken:  0.00036263465881347656
# 		 time taken minimize linear layer:  0.0006561279296875
# current error:  tensor(0.1709)
# epoch:  6	argmax time taken,  0.0015909671783447266
# assembling the matrix time taken:  0.00025773048400878906
# solving Ax = b time taken:  0.0003998279571533203
# 		 time taken minimize linear layer:  0.0006866455078125
# current error:  tensor(0.1680)
# epoch:  7	argmax time taken,  0.0016078948974609375
# assembling the matrix time taken:  0.00025463104248046875
# solving Ax = b time taken:  0.00040984153747558594
# 		 time taken minimize linear layer:  0.00069427490234375
# current error:  tensor(0.1595)
# epoch:  8	argmax time taken,  0.0016400814056396484
# assembling the matrix time taken:  0.0002579689025878906
# solving Ax = b time taken:  0.00044655799865722656
# 		 time taken minimize linear layer:  0.0007348060607910156
# current error:  tensor(0.1473)
# epoch:  9	argmax time taken,  0.0016396045684814453
# assembling the matrix time taken:  0.0002543926239013672
# solving Ax = b time taken:  0.002948760986328125
# 		 time taken minimize linear layer:  0.0032379627227783203
# current error:  tensor(0.1357)
# epoch:  10	argmax time taken,  0.001661062240600586
# assembling the matrix time taken:  0.00024962425231933594
# solving Ax = b time taken:  0.0005171298980712891
# 		 time taken minimize linear layer:  0.0007960796356201172
# current error:  tensor(0.1194)
# epoch:  11	argmax time taken,  0.0016520023345947266
# assembling the matrix time taken:  0.00024700164794921875
# solving Ax = b time taken:  0.0005431175231933594
# 		 time taken minimize linear layer:  0.000820159912109375
# current error:  tensor(0.1101)
# epoch:  12	argmax time taken,  0.0016794204711914062
# assembling the matrix time taken:  0.0002627372741699219
# solving Ax = b time taken:  0.0005609989166259766
# 		 time taken minimize linear layer:  0.0008523464202880859
# current error:  tensor(0.1047)
# epoch:  13	argmax time taken,  0.001683950424194336
# assembling the matrix time taken:  0.0002465248107910156
# solving Ax = b time taken:  0.0006053447723388672
# 		 time taken minimize linear layer:  0.000881195068359375
# current error:  tensor(0.0947)
# epoch:  14	argmax time taken,  0.0017054080963134766
# assembling the matrix time taken:  0.00025010108947753906
# solving Ax = b time taken:  0.0006279945373535156
# 		 time taken minimize linear layer:  0.0009076595306396484
# current error:  tensor(0.0923)
# epoch:  15	argmax time taken,  0.001722574234008789
# assembling the matrix time taken:  0.00025463104248046875
# solving Ax = b time taken:  0.0006542205810546875
# 		 time taken minimize linear layer:  0.0009388923645019531
# current error:  tensor(0.0916)
# epoch:  16	argmax time taken,  0.0017261505126953125
# assembling the matrix time taken:  0.0002529621124267578
# solving Ax = b time taken:  0.0006842613220214844
# 		 time taken minimize linear layer:  0.0009663105010986328
# current error:  tensor(0.0910)
# epoch:  17	argmax time taken,  0.0017077922821044922
# assembling the matrix time taken:  0.0002579689025878906
# solving Ax = b time taken:  0.0007698535919189453
# 		 time taken minimize linear layer:  0.0010581016540527344
# current error:  tensor(0.0905)
# epoch:  18	argmax time taken,  0.001745462417602539
# assembling the matrix time taken:  0.00025534629821777344
# solving Ax = b time taken:  0.0008051395416259766
# 		 time taken minimize linear layer:  0.0010917186737060547
# current error:  tensor(0.0883)
# epoch:  19	argmax time taken,  0.0017528533935546875
# assembling the matrix time taken:  0.000247955322265625
# solving Ax = b time taken:  0.0008080005645751953
# 		 time taken minimize linear layer:  0.001085042953491211
# current error:  tensor(0.0858)
# epoch:  20	argmax time taken,  0.0017673969268798828
# assembling the matrix time taken:  0.0002548694610595703
# solving Ax = b time taken:  0.0008287429809570312
# 		 time taken minimize linear layer:  0.001115560531616211
# current error:  tensor(0.0828)
# epoch:  21	argmax time taken,  0.0017740726470947266
# assembling the matrix time taken:  0.00025534629821777344
# solving Ax = b time taken:  0.0008645057678222656
# 		 time taken minimize linear layer:  0.0011491775512695312
# current error:  tensor(0.0823)
# epoch:  22	argmax time taken,  0.0018007755279541016
# assembling the matrix time taken:  0.00026416778564453125
# solving Ax = b time taken:  0.000881195068359375
# 		 time taken minimize linear layer:  0.0011749267578125
# current error:  tensor(0.0810)
# epoch:  23	argmax time taken,  0.0018146038055419922
# assembling the matrix time taken:  0.0002601146697998047
# solving Ax = b time taken:  0.0009174346923828125
# 		 time taken minimize linear layer:  0.001207113265991211
# current error:  tensor(0.0794)
# epoch:  24	argmax time taken,  0.0018351078033447266
# assembling the matrix time taken:  0.00026535987854003906
# solving Ax = b time taken:  0.0009253025054931641
# 		 time taken minimize linear layer:  0.0012199878692626953
# current error:  tensor(0.0786)
# epoch:  25	argmax time taken,  0.0018134117126464844
# assembling the matrix time taken:  0.00025534629821777344
# solving Ax = b time taken:  0.0009915828704833984
# 		 time taken minimize linear layer:  0.001275777816772461
# current error:  tensor(0.0773)
# epoch:  26	argmax time taken,  0.0018541812896728516
# assembling the matrix time taken:  0.0002548694610595703
# solving Ax = b time taken:  0.001016855239868164
# 		 time taken minimize linear layer:  0.0013015270233154297
# current error:  tensor(0.0760)
# epoch:  27	argmax time taken,  0.0018508434295654297
# assembling the matrix time taken:  0.0002512931823730469
# solving Ax = b time taken:  0.0010519027709960938
# 		 time taken minimize linear layer:  0.0013322830200195312
# current error:  tensor(0.0753)
# epoch:  28	argmax time taken,  0.0018689632415771484
# assembling the matrix time taken:  0.0002582073211669922
# solving Ax = b time taken:  0.0010695457458496094
# 		 time taken minimize linear layer:  0.0013577938079833984
# current error:  tensor(0.0745)
# epoch:  29	argmax time taken,  0.0018770694732666016
# assembling the matrix time taken:  0.0002512931823730469
# solving Ax = b time taken:  0.00112152099609375
# 		 time taken minimize linear layer:  0.0014102458953857422
# current error:  tensor(0.0734)
# epoch:  30	argmax time taken,  0.0019011497497558594
# assembling the matrix time taken:  0.0002582073211669922
# solving Ax = b time taken:  0.0011484622955322266
# 		 time taken minimize linear layer:  0.0014367103576660156
# current error:  tensor(0.0724)
# epoch:  31	argmax time taken,  0.0019154548645019531
# assembling the matrix time taken:  0.00025081634521484375
# solving Ax = b time taken:  0.0011897087097167969
# 		 time taken minimize linear layer:  0.0014710426330566406
# current error:  tensor(0.0719)
# epoch:  32	argmax time taken,  0.001958608627319336
# assembling the matrix time taken:  0.00026035308837890625
# solving Ax = b time taken:  0.0011706352233886719
# 		 time taken minimize linear layer:  0.0014607906341552734
# current error:  tensor(0.0708)
# epoch:  33	argmax time taken,  0.0019040107727050781
# assembling the matrix time taken:  0.00025343894958496094
# solving Ax = b time taken:  0.0013697147369384766
# 		 time taken minimize linear layer:  0.0016536712646484375
# current error:  tensor(0.0684)
# epoch:  34	argmax time taken,  0.003981828689575195
# assembling the matrix time taken:  0.0002663135528564453
# solving Ax = b time taken:  0.001375436782836914
# 		 time taken minimize linear layer:  0.00167083740234375
# current error:  tensor(0.0677)
# epoch:  35	argmax time taken,  0.003923654556274414
# assembling the matrix time taken:  0.0002472400665283203
# solving Ax = b time taken:  0.0014350414276123047
# 		 time taken minimize linear layer:  0.0017113685607910156
# current error:  tensor(0.0665)
# epoch:  36	argmax time taken,  0.00399017333984375
# assembling the matrix time taken:  0.000255584716796875
# solving Ax = b time taken:  0.0014216899871826172
# 		 time taken minimize linear layer:  0.0017066001892089844
# current error:  tensor(0.0652)
# epoch:  37	argmax time taken,  0.004004955291748047
# assembling the matrix time taken:  0.00024890899658203125
# solving Ax = b time taken:  0.0014824867248535156
# 		 time taken minimize linear layer:  0.0017676353454589844
# current error:  tensor(0.0637)
# epoch:  38	argmax time taken,  0.00399017333984375
# assembling the matrix time taken:  0.0006504058837890625
# solving Ax = b time taken:  0.001077413558959961
# 		 time taken minimize linear layer:  0.0017828941345214844
# current error:  tensor(0.0630)
# epoch:  39	argmax time taken,  0.004014730453491211
# assembling the matrix time taken:  0.0002467632293701172
# solving Ax = b time taken:  0.00154876708984375
# 		 time taken minimize linear layer:  0.0018262863159179688
# current error:  tensor(0.0621)
# epoch:  40	argmax time taken,  0.0040130615234375
# assembling the matrix time taken:  0.0002582073211669922
# solving Ax = b time taken:  0.0015077590942382812
# 		 time taken minimize linear layer:  0.001796722412109375
# current error:  tensor(0.0615)
# epoch:  41	argmax time taken,  0.004094600677490234
# assembling the matrix time taken:  0.00025725364685058594
# solving Ax = b time taken:  0.0014429092407226562
# 		 time taken minimize linear layer:  0.0017309188842773438
# current error:  tensor(0.0608)
# epoch:  42	argmax time taken,  0.0036172866821289062
# assembling the matrix time taken:  0.0002574920654296875
# solving Ax = b time taken:  0.001451253890991211
# 		 time taken minimize linear layer:  0.0017390251159667969
# current error:  tensor(0.0589)
# epoch:  43	argmax time taken,  0.0036203861236572266
# assembling the matrix time taken:  0.00024628639221191406
# solving Ax = b time taken:  0.0014889240264892578
# 		 time taken minimize linear layer:  0.0017650127410888672
# current error:  tensor(0.0583)
# epoch:  44	argmax time taken,  0.0036301612854003906
# assembling the matrix time taken:  0.0002562999725341797
# solving Ax = b time taken:  0.0014920234680175781
# 		 time taken minimize linear layer:  0.0017800331115722656
# current error:  tensor(0.0563)
# epoch:  45	argmax time taken,  0.0036652088165283203
# assembling the matrix time taken:  0.00024580955505371094
# solving Ax = b time taken:  0.0015511512756347656
# 		 time taken minimize linear layer:  0.001828908920288086
# current error:  tensor(0.0559)
# epoch:  46	argmax time taken,  0.003655672073364258
# assembling the matrix time taken:  0.0002582073211669922
# solving Ax = b time taken:  0.0015544891357421875
# 		 time taken minimize linear layer:  0.001842498779296875
# current error:  tensor(0.0548)
# epoch:  47	argmax time taken,  0.003709554672241211
# assembling the matrix time taken:  0.00025916099548339844
# solving Ax = b time taken:  0.0015790462493896484
# 		 time taken minimize linear layer:  0.0018682479858398438
# current error:  tensor(0.0542)
# epoch:  48	argmax time taken,  0.0037224292755126953
# assembling the matrix time taken:  0.00025725364685058594
# solving Ax = b time taken:  0.0015871524810791016
# 		 time taken minimize linear layer:  0.0018749237060546875
# current error:  tensor(0.0527)
# epoch:  49	argmax time taken,  0.00370025634765625
# assembling the matrix time taken:  0.0002474784851074219
# solving Ax = b time taken:  0.0016796588897705078
# 		 time taken minimize linear layer:  0.0019578933715820312
# current error:  tensor(0.0524)
# epoch:  50	argmax time taken,  0.003731250762939453
# assembling the matrix time taken:  0.00025725364685058594
# solving Ax = b time taken:  0.0016846656799316406
# 		 time taken minimize linear layer:  0.0019719600677490234
# current error:  tensor(0.0520)
# epoch:  51	argmax time taken,  0.0037682056427001953
# assembling the matrix time taken:  0.00024366378784179688
# solving Ax = b time taken:  0.001752614974975586
# 		 time taken minimize linear layer:  0.002026081085205078
# current error:  tensor(0.0515)
# epoch:  52	argmax time taken,  0.00380706787109375
# assembling the matrix time taken:  0.0002601146697998047
# solving Ax = b time taken:  0.0017330646514892578
# 		 time taken minimize linear layer:  0.0020227432250976562
# current error:  tensor(0.0514)
# epoch:  53	argmax time taken,  0.0037689208984375
# assembling the matrix time taken:  0.0002455711364746094
# solving Ax = b time taken:  0.0018069744110107422
# 		 time taken minimize linear layer:  0.0020818710327148438
# current error:  tensor(0.0505)
# epoch:  54	argmax time taken,  0.0038232803344726562
# assembling the matrix time taken:  0.0002570152282714844
# solving Ax = b time taken:  0.0018007755279541016
# 		 time taken minimize linear layer:  0.0020880699157714844
# current error:  tensor(0.0502)
# epoch:  55	argmax time taken,  0.003815889358520508
# assembling the matrix time taken:  0.0002529621124267578
# solving Ax = b time taken:  0.0018558502197265625
# 		 time taken minimize linear layer:  0.002138853073120117
# current error:  tensor(0.0488)
# epoch:  56	argmax time taken,  0.0038602352142333984
# assembling the matrix time taken:  0.00025963783264160156
# solving Ax = b time taken:  0.0018494129180908203
# 		 time taken minimize linear layer:  0.0021393299102783203
# current error:  tensor(0.0480)
# epoch:  57	argmax time taken,  0.003820657730102539
# assembling the matrix time taken:  0.0002446174621582031
# solving Ax = b time taken:  0.0019207000732421875
# 		 time taken minimize linear layer:  0.0021965503692626953
# current error:  tensor(0.0476)
# epoch:  58	argmax time taken,  0.003818511962890625
# assembling the matrix time taken:  0.00026488304138183594
# solving Ax = b time taken:  0.0019435882568359375
# 		 time taken minimize linear layer:  0.0022382736206054688
# current error:  tensor(0.0469)
# epoch:  59	argmax time taken,  0.003902912139892578
# assembling the matrix time taken:  0.0002486705780029297
# solving Ax = b time taken:  0.001989603042602539
# 		 time taken minimize linear layer:  0.002268552780151367
# current error:  tensor(0.0465)
# epoch:  60	argmax time taken,  0.0039501190185546875
# assembling the matrix time taken:  0.0002582073211669922
# solving Ax = b time taken:  0.0019991397857666016
# 		 time taken minimize linear layer:  0.002291440963745117
# current error:  tensor(0.0463)
# epoch:  61	argmax time taken,  0.0038878917694091797
# assembling the matrix time taken:  0.0002467632293701172
# solving Ax = b time taken:  0.002046823501586914
# 		 time taken minimize linear layer:  0.002323150634765625
# current error:  tensor(0.0458)
# epoch:  62	argmax time taken,  0.003972053527832031
# assembling the matrix time taken:  0.0002574920654296875
# solving Ax = b time taken:  0.002076387405395508
# 		 time taken minimize linear layer:  0.002362966537475586
# current error:  tensor(0.0449)
# epoch:  63	argmax time taken,  0.0039441585540771484
# assembling the matrix time taken:  0.00024580955505371094
# solving Ax = b time taken:  0.0021102428436279297
# 		 time taken minimize linear layer:  0.0023872852325439453
# current error:  tensor(0.0446)
# epoch:  64	argmax time taken,  0.003933429718017578
# assembling the matrix time taken:  0.0002636909484863281
# solving Ax = b time taken:  0.002089977264404297
# 		 time taken minimize linear layer:  0.0023839473724365234
# current error:  tensor(0.0441)
# epoch:  65	argmax time taken,  0.0038881301879882812
# assembling the matrix time taken:  0.0002548694610595703
# solving Ax = b time taken:  0.002659320831298828
# 		 time taken minimize linear layer:  0.002944469451904297
# current error:  tensor(0.0440)
# epoch:  66	argmax time taken,  0.003957986831665039
# assembling the matrix time taken:  0.0002574920654296875
# solving Ax = b time taken:  0.0027348995208740234
# 		 time taken minimize linear layer:  0.003022432327270508
# current error:  tensor(0.0437)
# epoch:  67	argmax time taken,  0.003909111022949219
# assembling the matrix time taken:  0.0002493858337402344
# solving Ax = b time taken:  0.0026879310607910156
# 		 time taken minimize linear layer:  0.0029740333557128906
# current error:  tensor(0.0424)
# epoch:  68	argmax time taken,  0.003931522369384766
# assembling the matrix time taken:  0.00026106834411621094
# solving Ax = b time taken:  0.002696990966796875
# 		 time taken minimize linear layer:  0.002989053726196289
# current error:  tensor(0.0421)
# epoch:  69	argmax time taken,  0.00394129753112793
# assembling the matrix time taken:  0.00025463104248046875
# solving Ax = b time taken:  0.0027840137481689453
# 		 time taken minimize linear layer:  0.0030684471130371094
# current error:  tensor(0.0419)
# epoch:  70	argmax time taken,  0.00396728515625
# assembling the matrix time taken:  0.00026035308837890625
# solving Ax = b time taken:  0.002944469451904297
# 		 time taken minimize linear layer:  0.0032346248626708984
# current error:  tensor(0.0415)
# epoch:  71	argmax time taken,  0.004021406173706055
# assembling the matrix time taken:  0.00024962425231933594
# solving Ax = b time taken:  0.0028235912322998047
# 		 time taken minimize linear layer:  0.0031027793884277344
# current error:  tensor(0.0412)
# epoch:  72	argmax time taken,  0.004046440124511719
# assembling the matrix time taken:  0.00025963783264160156
# solving Ax = b time taken:  0.0027761459350585938
# 		 time taken minimize linear layer:  0.003065824508666992
# current error:  tensor(0.0405)
# epoch:  73	argmax time taken,  0.00402522087097168
# assembling the matrix time taken:  0.0002474784851074219
# solving Ax = b time taken:  0.0030307769775390625
# 		 time taken minimize linear layer:  0.0033097267150878906
# current error:  tensor(0.0401)
# epoch:  74	argmax time taken,  0.0040700435638427734
# assembling the matrix time taken:  0.00025963783264160156
# solving Ax = b time taken:  0.00316619873046875
# 		 time taken minimize linear layer:  0.0034570693969726562
# current error:  tensor(0.0397)
# epoch:  75	argmax time taken,  0.004072427749633789
# assembling the matrix time taken:  0.00024700164794921875
# solving Ax = b time taken:  0.003136873245239258
# 		 time taken minimize linear layer:  0.0034208297729492188
# current error:  tensor(0.0395)
# epoch:  76	argmax time taken,  0.004743814468383789
# assembling the matrix time taken:  0.00026726722717285156
# solving Ax = b time taken:  0.003073453903198242
# 		 time taken minimize linear layer:  0.0033712387084960938
# current error:  tensor(0.0394)
# epoch:  77	argmax time taken,  0.004072666168212891
# assembling the matrix time taken:  0.00024700164794921875
# solving Ax = b time taken:  0.003312349319458008
# 		 time taken minimize linear layer:  0.0035898685455322266
# current error:  tensor(0.0391)
# epoch:  78	argmax time taken,  0.00501251220703125
# assembling the matrix time taken:  0.0002701282501220703
# solving Ax = b time taken:  0.0034525394439697266
# 		 time taken minimize linear layer:  0.0037529468536376953
# current error:  tensor(0.0388)
# epoch:  79	argmax time taken,  0.004117250442504883
# assembling the matrix time taken:  0.00024700164794921875
# solving Ax = b time taken:  0.0033762454986572266
# 		 time taken minimize linear layer:  0.0036542415618896484
# current error:  tensor(0.0386)
# epoch:  80	argmax time taken,  0.005038261413574219
# assembling the matrix time taken:  0.0002598762512207031
# solving Ax = b time taken:  0.0031023025512695312
# 		 time taken minimize linear layer:  0.003392457962036133
# current error:  tensor(0.0384)
# epoch:  81	argmax time taken,  0.0050008296966552734
# assembling the matrix time taken:  0.00024771690368652344
# solving Ax = b time taken:  0.0034325122833251953
# 		 time taken minimize linear layer:  0.0037102699279785156
# current error:  tensor(0.0381)
# epoch:  82	argmax time taken,  0.005223512649536133
# assembling the matrix time taken:  0.0002624988555908203
# solving Ax = b time taken:  0.003584623336791992
# 		 time taken minimize linear layer:  0.003877878189086914
# current error:  tensor(0.0380)
# epoch:  83	argmax time taken,  0.005174875259399414
# assembling the matrix time taken:  0.000247955322265625
# solving Ax = b time taken:  0.003477334976196289
# 		 time taken minimize linear layer:  0.003759622573852539
# current error:  tensor(0.0374)
# epoch:  84	argmax time taken,  0.0041561126708984375
# assembling the matrix time taken:  0.0002601146697998047
# solving Ax = b time taken:  0.003434896469116211
# 		 time taken minimize linear layer:  0.0037260055541992188
# current error:  tensor(0.0370)
# epoch:  85	argmax time taken,  0.005175590515136719
# assembling the matrix time taken:  0.00024890899658203125
# solving Ax = b time taken:  0.003515481948852539
# 		 time taken minimize linear layer:  0.003793478012084961
# current error:  tensor(0.0367)
# epoch:  86	argmax time taken,  0.005543231964111328
# assembling the matrix time taken:  0.0002567768096923828
# solving Ax = b time taken:  0.0036792755126953125
# 		 time taken minimize linear layer:  0.003965854644775391
# current error:  tensor(0.0365)
# epoch:  87	argmax time taken,  0.005465507507324219
# assembling the matrix time taken:  0.00024819374084472656
# solving Ax = b time taken:  0.003535747528076172
# 		 time taken minimize linear layer:  0.0038154125213623047
# current error:  tensor(0.0360)
# epoch:  88	argmax time taken,  0.005574941635131836
# assembling the matrix time taken:  0.0002582073211669922
# solving Ax = b time taken:  0.0034232139587402344
# 		 time taken minimize linear layer:  0.0037114620208740234
# current error:  tensor(0.0359)
# epoch:  89	argmax time taken,  0.0054607391357421875
# assembling the matrix time taken:  0.0002562999725341797
# solving Ax = b time taken:  0.0035910606384277344
# 		 time taken minimize linear layer:  0.003877401351928711
# current error:  tensor(0.0356)
# epoch:  90	argmax time taken,  0.005825519561767578
# assembling the matrix time taken:  0.00026106834411621094
# solving Ax = b time taken:  0.0037965774536132812
# 		 time taken minimize linear layer:  0.004088163375854492
# current error:  tensor(0.0352)
# epoch:  91	argmax time taken,  0.005774021148681641
# assembling the matrix time taken:  0.0002529621124267578
# solving Ax = b time taken:  0.0036444664001464844
# 		 time taken minimize linear layer:  0.003927469253540039
# current error:  tensor(0.0349)
# epoch:  92	argmax time taken,  0.005847930908203125
# assembling the matrix time taken:  0.00026035308837890625
# solving Ax = b time taken:  0.0036127567291259766
# 		 time taken minimize linear layer:  0.003904104232788086
# current error:  tensor(0.0345)
# epoch:  93	argmax time taken,  0.005764961242675781
# assembling the matrix time taken:  0.0002446174621582031
# solving Ax = b time taken:  0.003658294677734375
# 		 time taken minimize linear layer:  0.003933429718017578
# current error:  tensor(0.0342)
# epoch:  94	argmax time taken,  0.006161928176879883
# assembling the matrix time taken:  0.00026535987854003906
# solving Ax = b time taken:  0.0038712024688720703
# 		 time taken minimize linear layer:  0.004166841506958008
# current error:  tensor(0.0338)
# epoch:  95	argmax time taken,  0.006041765213012695
# assembling the matrix time taken:  0.00024318695068359375
# solving Ax = b time taken:  0.0037279129028320312
# 		 time taken minimize linear layer:  0.004002809524536133
# current error:  tensor(0.0336)
# epoch:  96	argmax time taken,  0.006160259246826172
# assembling the matrix time taken:  0.00025844573974609375
# solving Ax = b time taken:  0.003389120101928711
# 		 time taken minimize linear layer:  0.0036787986755371094
# current error:  tensor(0.0335)
# epoch:  97	argmax time taken,  0.006048440933227539
# assembling the matrix time taken:  0.00025391578674316406
# solving Ax = b time taken:  0.003696918487548828
# 		 time taken minimize linear layer:  0.003982067108154297
# current error:  tensor(0.0333)
# epoch:  98	argmax time taken,  0.006166696548461914
# assembling the matrix time taken:  0.0002605915069580078
# solving Ax = b time taken:  0.003941535949707031
# 		 time taken minimize linear layer:  0.004232883453369141
# current error:  tensor(0.0332)
# epoch:  99	argmax time taken,  0.00608515739440918
# assembling the matrix time taken:  0.00024700164794921875
# solving Ax = b time taken:  0.003779888153076172
# 		 time taken minimize linear layer:  0.004057168960571289
# current error:  tensor(0.0330)
# epoch:  100	argmax time taken,  0.006136655807495117
# assembling the matrix time taken:  0.0002639293670654297
# solving Ax = b time taken:  0.003804922103881836
# 		 time taken minimize linear layer:  0.004098653793334961
# current error:  tensor(0.0327)
# epoch:  101	argmax time taken,  0.006134986877441406
# assembling the matrix time taken:  0.0002510547637939453
# solving Ax = b time taken:  0.0038444995880126953
# 		 time taken minimize linear layer:  0.004126548767089844
# current error:  tensor(0.0325)
# epoch:  102	argmax time taken,  0.004455089569091797
# assembling the matrix time taken:  0.00026106834411621094
# solving Ax = b time taken:  0.004096031188964844
# 		 time taken minimize linear layer:  0.004387617111206055
# current error:  tensor(0.0324)
# epoch:  103	argmax time taken,  0.0061931610107421875
# assembling the matrix time taken:  0.0002474784851074219
# solving Ax = b time taken:  0.0038993358612060547
# 		 time taken minimize linear layer:  0.0041773319244384766
# current error:  tensor(0.0321)
# epoch:  104	argmax time taken,  0.006270647048950195
# assembling the matrix time taken:  0.00026702880859375
# solving Ax = b time taken:  0.003863811492919922
# 		 time taken minimize linear layer:  0.004161357879638672
# current error:  tensor(0.0316)
# epoch:  105	argmax time taken,  0.006195545196533203
# assembling the matrix time taken:  0.0002510547637939453
# solving Ax = b time taken:  0.003912925720214844
# 		 time taken minimize linear layer:  0.004194736480712891
# current error:  tensor(0.0315)
# epoch:  106	argmax time taken,  0.004490852355957031
# assembling the matrix time taken:  0.00027298927307128906
# solving Ax = b time taken:  0.004188060760498047
# 		 time taken minimize linear layer:  0.0044901371002197266
# current error:  tensor(0.0314)
# epoch:  107	argmax time taken,  0.006212949752807617
# assembling the matrix time taken:  0.00026226043701171875
# solving Ax = b time taken:  0.003988981246948242
# 		 time taken minimize linear layer:  0.0042819976806640625
# current error:  tensor(0.0309)
# epoch:  108	argmax time taken,  0.004550457000732422
# assembling the matrix time taken:  0.0002636909484863281
# solving Ax = b time taken:  0.004042387008666992
# 		 time taken minimize linear layer:  0.004336357116699219
# current error:  tensor(0.0309)
# epoch:  109	argmax time taken,  0.006257295608520508
# assembling the matrix time taken:  0.00025177001953125
# solving Ax = b time taken:  0.004055500030517578
# 		 time taken minimize linear layer:  0.00433802604675293
# current error:  tensor(0.0307)
# epoch:  110	argmax time taken,  0.004565000534057617
# assembling the matrix time taken:  0.000270843505859375
# solving Ax = b time taken:  0.004303455352783203
# 		 time taken minimize linear layer:  0.00460505485534668
# current error:  tensor(0.0305)
# epoch:  111	argmax time taken,  0.006268739700317383
# assembling the matrix time taken:  0.00025200843811035156
# solving Ax = b time taken:  0.0041065216064453125
# 		 time taken minimize linear layer:  0.004389286041259766
# current error:  tensor(0.0304)
# epoch:  112	argmax time taken,  0.00630497932434082
# assembling the matrix time taken:  0.0002524852752685547
# solving Ax = b time taken:  0.004023313522338867
# 		 time taken minimize linear layer:  0.004304647445678711
# current error:  tensor(0.0302)
# epoch:  113	argmax time taken,  0.006287813186645508
# assembling the matrix time taken:  0.00025200843811035156
# solving Ax = b time taken:  0.004192352294921875
# 		 time taken minimize linear layer:  0.004475831985473633
# current error:  tensor(0.0301)
# epoch:  114	argmax time taken,  0.004586696624755859
# assembling the matrix time taken:  0.00025272369384765625
# solving Ax = b time taken:  0.0042078495025634766
# 		 time taken minimize linear layer:  0.004491567611694336
# current error:  tensor(0.0299)
# epoch:  115	argmax time taken,  0.0063059329986572266
# assembling the matrix time taken:  0.00025177001953125
# solving Ax = b time taken:  0.0042514801025390625
# 		 time taken minimize linear layer:  0.004533529281616211
# current error:  tensor(0.0296)
# epoch:  116	argmax time taken,  0.0046045780181884766
# assembling the matrix time taken:  0.00025200843811035156
# solving Ax = b time taken:  0.0042324066162109375
# 		 time taken minimize linear layer:  0.004515171051025391
# current error:  tensor(0.0295)
# epoch:  117	argmax time taken,  0.004606008529663086
# assembling the matrix time taken:  0.00025391578674316406
# solving Ax = b time taken:  0.004292964935302734
# 		 time taken minimize linear layer:  0.0045778751373291016
# current error:  tensor(0.0293)
# epoch:  118	argmax time taken,  0.004656791687011719
# assembling the matrix time taken:  0.00025200843811035156
# solving Ax = b time taken:  0.004312753677368164
# 		 time taken minimize linear layer:  0.004594564437866211
# current error:  tensor(0.0292)
# epoch:  119	argmax time taken,  0.004692792892456055
# assembling the matrix time taken:  0.0002598762512207031
# solving Ax = b time taken:  0.004337787628173828
# 		 time taken minimize linear layer:  0.0046291351318359375
# current error:  tensor(0.0289)
# epoch:  120	argmax time taken,  0.004638195037841797
# assembling the matrix time taken:  0.0002536773681640625
# solving Ax = b time taken:  0.004282951354980469
# 		 time taken minimize linear layer:  0.004567623138427734
# current error:  tensor(0.0287)
# epoch:  121	argmax time taken,  0.00638127326965332
# assembling the matrix time taken:  0.00025582313537597656
# solving Ax = b time taken:  0.004430532455444336
# 		 time taken minimize linear layer:  0.004716634750366211
# current error:  tensor(0.0286)
# epoch:  122	argmax time taken,  0.004729270935058594
# assembling the matrix time taken:  0.000255584716796875
# solving Ax = b time taken:  0.004449367523193359
# 		 time taken minimize linear layer:  0.004735708236694336
# current error:  tensor(0.0284)
# epoch:  123	argmax time taken,  0.006455421447753906
# assembling the matrix time taken:  0.0002562999725341797
# solving Ax = b time taken:  0.004507541656494141
# 		 time taken minimize linear layer:  0.004793405532836914
# current error:  tensor(0.0283)
# epoch:  124	argmax time taken,  0.004721403121948242
# assembling the matrix time taken:  0.000255584716796875
# solving Ax = b time taken:  0.0044689178466796875
# 		 time taken minimize linear layer:  0.004753828048706055
# current error:  tensor(0.0281)
# epoch:  125	argmax time taken,  0.006448984146118164
# assembling the matrix time taken:  0.00025534629821777344
# solving Ax = b time taken:  0.004541158676147461
# 		 time taken minimize linear layer:  0.0048274993896484375
# current error:  tensor(0.0280)
# epoch:  126	argmax time taken,  0.004835844039916992
# assembling the matrix time taken:  0.0002543926239013672
# solving Ax = b time taken:  0.0045318603515625
# 		 time taken minimize linear layer:  0.00489354133605957
# current error:  tensor(0.0279)
# epoch:  127	argmax time taken,  0.006568193435668945
# assembling the matrix time taken:  0.00026106834411621094
# solving Ax = b time taken:  0.00458073616027832
# 		 time taken minimize linear layer:  0.004870891571044922
# current error:  tensor(0.0278)
# epoch:  128	argmax time taken,  0.0048677921295166016
# assembling the matrix time taken:  0.0002562999725341797
# solving Ax = b time taken:  0.004494190216064453
# 		 time taken minimize linear layer:  0.004779338836669922
# current error:  tensor(0.0277)
# epoch:  129	argmax time taken,  0.006434440612792969
# assembling the matrix time taken:  0.00025653839111328125
# solving Ax = b time taken:  0.007899999618530273
# 		 time taken minimize linear layer:  0.008193731307983398
# current error:  tensor(0.0274)
# epoch:  130	argmax time taken,  0.006462574005126953
# assembling the matrix time taken:  0.0002727508544921875
# solving Ax = b time taken:  0.006028413772583008
# 		 time taken minimize linear layer:  0.0063326358795166016
# current error:  tensor(0.0273)
# epoch:  131	argmax time taken,  0.004909992218017578
# assembling the matrix time taken:  0.000263214111328125
# solving Ax = b time taken:  0.005831003189086914
# 		 time taken minimize linear layer:  0.006125450134277344
# current error:  tensor(0.0271)
# epoch:  132	argmax time taken,  0.006489992141723633
# assembling the matrix time taken:  0.00026345252990722656
# solving Ax = b time taken:  0.0061037540435791016
# 		 time taken minimize linear layer:  0.00639796257019043
# current error:  tensor(0.0267)
# epoch:  133	argmax time taken,  0.004944324493408203
# assembling the matrix time taken:  0.0002639293670654297
# solving Ax = b time taken:  0.005876302719116211
# 		 time taken minimize linear layer:  0.006171226501464844
# current error:  tensor(0.0264)
# epoch:  134	argmax time taken,  0.006535053253173828
# assembling the matrix time taken:  0.0002665519714355469
# solving Ax = b time taken:  0.006196260452270508
# 		 time taken minimize linear layer:  0.0064928531646728516
# current error:  tensor(0.0263)
# epoch:  135	argmax time taken,  0.005193233489990234
# assembling the matrix time taken:  0.00026106834411621094
# solving Ax = b time taken:  0.005924701690673828
# 		 time taken minimize linear layer:  0.006216287612915039
# current error:  tensor(0.0261)
# epoch:  136	argmax time taken,  0.006576061248779297
# assembling the matrix time taken:  0.0002646446228027344
# solving Ax = b time taken:  0.006098508834838867
# 		 time taken minimize linear layer:  0.006394624710083008
# current error:  tensor(0.0259)
# epoch:  137	argmax time taken,  0.005201816558837891
# assembling the matrix time taken:  0.0002608299255371094
# solving Ax = b time taken:  0.006082773208618164
# 		 time taken minimize linear layer:  0.0063745975494384766
# current error:  tensor(0.0258)
# epoch:  138	argmax time taken,  0.0065724849700927734
# assembling the matrix time taken:  0.00026726722717285156
# solving Ax = b time taken:  0.006312131881713867
# 		 time taken minimize linear layer:  0.006609916687011719
# current error:  tensor(0.0251)
# epoch:  139	argmax time taken,  0.005587100982666016
# assembling the matrix time taken:  0.0002567768096923828
# solving Ax = b time taken:  0.006136894226074219
# 		 time taken minimize linear layer:  0.006424427032470703
# current error:  tensor(0.0249)
# epoch:  140	argmax time taken,  0.006623983383178711
# assembling the matrix time taken:  0.0002684593200683594
# solving Ax = b time taken:  0.0063114166259765625
# 		 time taken minimize linear layer:  0.0066106319427490234
# current error:  tensor(0.0248)
# epoch:  141	argmax time taken,  0.006723880767822266
# assembling the matrix time taken:  0.000263214111328125
# solving Ax = b time taken:  0.0061702728271484375
# 		 time taken minimize linear layer:  0.006464481353759766
# current error:  tensor(0.0247)
# epoch:  142	argmax time taken,  0.006662130355834961
# assembling the matrix time taken:  0.0002689361572265625
# solving Ax = b time taken:  0.006469249725341797
# 		 time taken minimize linear layer:  0.006770610809326172
# current error:  tensor(0.0244)
# epoch:  143	argmax time taken,  0.006752490997314453
# assembling the matrix time taken:  0.000263214111328125
# solving Ax = b time taken:  0.006234169006347656
# 		 time taken minimize linear layer:  0.006529331207275391
# current error:  tensor(0.0244)
# epoch:  144	argmax time taken,  0.006686210632324219
# assembling the matrix time taken:  0.0002543926239013672
# solving Ax = b time taken:  0.0061261653900146484
# 		 time taken minimize linear layer:  0.0064127445220947266
# current error:  tensor(0.0243)
# epoch:  145	argmax time taken,  0.005826711654663086
# assembling the matrix time taken:  0.000270843505859375
# solving Ax = b time taken:  0.0074961185455322266
# 		 time taken minimize linear layer:  0.007797956466674805
# current error:  tensor(0.0243)
# epoch:  146	argmax time taken,  0.00667881965637207
# assembling the matrix time taken:  0.00025844573974609375
# solving Ax = b time taken:  0.007425546646118164
# 		 time taken minimize linear layer:  0.007714748382568359
# current error:  tensor(0.0241)
# epoch:  147	argmax time taken,  0.006034374237060547
# assembling the matrix time taken:  0.0002532005310058594
# solving Ax = b time taken:  0.007651567459106445
# 		 time taken minimize linear layer:  0.007935523986816406
# current error:  tensor(0.0239)
# epoch:  148	argmax time taken,  0.006742238998413086
# assembling the matrix time taken:  0.00025725364685058594
# solving Ax = b time taken:  0.0073888301849365234
# 		 time taken minimize linear layer:  0.007677316665649414
# current error:  tensor(0.0237)
# epoch:  149	argmax time taken,  0.006804227828979492
# assembling the matrix time taken:  0.00026535987854003906
# solving Ax = b time taken:  0.0075190067291259766
# 		 time taken minimize linear layer:  0.007815361022949219
# current error:  tensor(0.0234)
# epoch:  150	argmax time taken,  0.006744384765625
# assembling the matrix time taken:  0.0002651214599609375
# solving Ax = b time taken:  0.0074465274810791016
# 		 time taken minimize linear layer:  0.007741689682006836
# current error:  tensor(0.0233)
# epoch:  151	argmax time taken,  0.0068852901458740234
# assembling the matrix time taken:  0.0002636909484863281
# solving Ax = b time taken:  0.007651805877685547
# 		 time taken minimize linear layer:  0.007946968078613281
# current error:  tensor(0.0230)
# epoch:  152	argmax time taken,  0.006864309310913086
# assembling the matrix time taken:  0.0002601146697998047
# solving Ax = b time taken:  0.007239580154418945
# 		 time taken minimize linear layer:  0.0075299739837646484
# current error:  tensor(0.0228)
# epoch:  153	argmax time taken,  0.006869077682495117
# assembling the matrix time taken:  0.0002532005310058594
# solving Ax = b time taken:  0.006518363952636719
# 		 time taken minimize linear layer:  0.006802558898925781
# current error:  tensor(0.0226)
# epoch:  154	argmax time taken,  0.006561279296875
# assembling the matrix time taken:  0.00025653839111328125
# solving Ax = b time taken:  0.006529092788696289
# 		 time taken minimize linear layer:  0.006816387176513672
# current error:  tensor(0.0225)
# epoch:  155	argmax time taken,  0.0065538883209228516
# assembling the matrix time taken:  0.0002567768096923828
# solving Ax = b time taken:  0.006573200225830078
# 		 time taken minimize linear layer:  0.0068607330322265625
# current error:  tensor(0.0224)
# epoch:  156	argmax time taken,  0.0065877437591552734
# assembling the matrix time taken:  0.0002536773681640625
# solving Ax = b time taken:  0.006539106369018555
# 		 time taken minimize linear layer:  0.006823539733886719
# current error:  tensor(0.0222)
# epoch:  157	argmax time taken,  0.00657200813293457
# assembling the matrix time taken:  0.0002562999725341797
# solving Ax = b time taken:  0.00662541389465332
# 		 time taken minimize linear layer:  0.006912946701049805
# current error:  tensor(0.0222)
# epoch:  158	argmax time taken,  0.006834268569946289
# assembling the matrix time taken:  0.0002593994140625
# solving Ax = b time taken:  0.006636142730712891
# 		 time taken minimize linear layer:  0.006926774978637695
# current error:  tensor(0.0221)
# epoch:  159	argmax time taken,  0.006865739822387695
# assembling the matrix time taken:  0.00024962425231933594
# solving Ax = b time taken:  0.006654977798461914
# 		 time taken minimize linear layer:  0.0069353580474853516
# current error:  tensor(0.0220)
# epoch:  160	argmax time taken,  0.0069179534912109375
# assembling the matrix time taken:  0.0002646446228027344
# solving Ax = b time taken:  0.006541252136230469
# 		 time taken minimize linear layer:  0.0068378448486328125
# current error:  tensor(0.0220)
# epoch:  161	argmax time taken,  0.008725881576538086
# assembling the matrix time taken:  0.0002639293670654297
# solving Ax = b time taken:  0.006747722625732422
# 		 time taken minimize linear layer:  0.0070421695709228516
# current error:  tensor(0.0219)
# epoch:  162	argmax time taken,  0.006929159164428711
# assembling the matrix time taken:  0.00025272369384765625
# solving Ax = b time taken:  0.00677037239074707
# 		 time taken minimize linear layer:  0.007054805755615234
# current error:  tensor(0.0218)
# epoch:  163	argmax time taken,  0.006917476654052734
# assembling the matrix time taken:  0.0002579689025878906
# solving Ax = b time taken:  0.006812334060668945
# 		 time taken minimize linear layer:  0.0071010589599609375
# current error:  tensor(0.0216)
# epoch:  164	argmax time taken,  0.006916046142578125
# assembling the matrix time taken:  0.00025200843811035156
# solving Ax = b time taken:  0.00680088996887207
# 		 time taken minimize linear layer:  0.0070836544036865234
# current error:  tensor(0.0215)
# epoch:  165	argmax time taken,  0.0070073604583740234
# assembling the matrix time taken:  0.0002536773681640625
# solving Ax = b time taken:  0.006855010986328125
# 		 time taken minimize linear layer:  0.007138967514038086
# current error:  tensor(0.0214)
# epoch:  166	argmax time taken,  0.008816242218017578
# assembling the matrix time taken:  0.0002529621124267578
# solving Ax = b time taken:  0.006883382797241211
# 		 time taken minimize linear layer:  0.00716710090637207
# current error:  tensor(0.0212)
# epoch:  167	argmax time taken,  0.00698089599609375
# assembling the matrix time taken:  0.0002567768096923828
# solving Ax = b time taken:  0.00693058967590332
# 		 time taken minimize linear layer:  0.007218599319458008
# current error:  tensor(0.0211)
# epoch:  168	argmax time taken,  0.008690595626831055
# assembling the matrix time taken:  0.0002510547637939453
# solving Ax = b time taken:  0.006821870803833008
# 		 time taken minimize linear layer:  0.007103681564331055
# current error:  tensor(0.0210)
# epoch:  169	argmax time taken,  0.006999969482421875
# assembling the matrix time taken:  0.0002560615539550781
# solving Ax = b time taken:  0.00696873664855957
# 		 time taken minimize linear layer:  0.007256507873535156
# current error:  tensor(0.0208)
# epoch:  170	argmax time taken,  0.007021427154541016
# assembling the matrix time taken:  0.00025582313537597656
# solving Ax = b time taken:  0.0069103240966796875
# 		 time taken minimize linear layer:  0.007196664810180664
# current error:  tensor(0.0208)
# epoch:  171	argmax time taken,  0.0071544647216796875
# assembling the matrix time taken:  0.00025773048400878906
# solving Ax = b time taken:  0.006938934326171875
# 		 time taken minimize linear layer:  0.007227659225463867
# current error:  tensor(0.0207)
# epoch:  172	argmax time taken,  0.007059812545776367
# assembling the matrix time taken:  0.00026154518127441406
# solving Ax = b time taken:  0.006930351257324219
# 		 time taken minimize linear layer:  0.007222652435302734
# current error:  tensor(0.0206)
# epoch:  173	argmax time taken,  0.007102012634277344
# assembling the matrix time taken:  0.0002636909484863281
# solving Ax = b time taken:  0.006982088088989258
# 		 time taken minimize linear layer:  0.007294178009033203
# current error:  tensor(0.0204)
# epoch:  174	argmax time taken,  0.007105112075805664
# assembling the matrix time taken:  0.0002613067626953125
# solving Ax = b time taken:  0.006999492645263672
# 		 time taken minimize linear layer:  0.007291316986083984
# current error:  tensor(0.0203)
# epoch:  175	argmax time taken,  0.007080078125
# assembling the matrix time taken:  0.000255584716796875
# solving Ax = b time taken:  0.007043123245239258
# 		 time taken minimize linear layer:  0.0073299407958984375
# current error:  tensor(0.0202)
# epoch:  176	argmax time taken,  0.007209062576293945
# assembling the matrix time taken:  0.0002593994140625
# solving Ax = b time taken:  0.00698399543762207
# 		 time taken minimize linear layer:  0.0072743892669677734
# current error:  tensor(0.0201)
# epoch:  177	argmax time taken,  0.007083892822265625
# assembling the matrix time taken:  0.0002536773681640625
# solving Ax = b time taken:  0.007128238677978516
# 		 time taken minimize linear layer:  0.00741267204284668
# current error:  tensor(0.0201)
# epoch:  178	argmax time taken,  0.007229804992675781
# assembling the matrix time taken:  0.0002620220184326172
# solving Ax = b time taken:  0.007131814956665039
# 		 time taken minimize linear layer:  0.007424116134643555
# current error:  tensor(0.0200)
# epoch:  179	argmax time taken,  0.007205963134765625
# assembling the matrix time taken:  0.0002543926239013672
# solving Ax = b time taken:  0.007162570953369141
# 		 time taken minimize linear layer:  0.007449626922607422
# current error:  tensor(0.0199)
# epoch:  180	argmax time taken,  0.0072176456451416016
# assembling the matrix time taken:  0.00025177001953125
# solving Ax = b time taken:  0.007229804992675781
# 		 time taken minimize linear layer:  0.007512807846069336
# current error:  tensor(0.0198)
# epoch:  181	argmax time taken,  0.0071446895599365234
# assembling the matrix time taken:  0.0002582073211669922
# solving Ax = b time taken:  0.007203817367553711
# 		 time taken minimize linear layer:  0.0074918270111083984
# current error:  tensor(0.0196)
# epoch:  182	argmax time taken,  0.0073089599609375
# assembling the matrix time taken:  0.00025391578674316406
# solving Ax = b time taken:  0.007234334945678711
# 		 time taken minimize linear layer:  0.0075190067291259766
# current error:  tensor(0.0195)
# epoch:  183	argmax time taken,  0.007236957550048828
# assembling the matrix time taken:  0.0002512931823730469
# solving Ax = b time taken:  0.007270336151123047
# 		 time taken minimize linear layer:  0.007552623748779297
# current error:  tensor(0.0194)
# epoch:  184	argmax time taken,  0.007219076156616211
# assembling the matrix time taken:  0.00025343894958496094
# solving Ax = b time taken:  0.007215023040771484
# 		 time taken minimize linear layer:  0.00749969482421875
# current error:  tensor(0.0194)
# epoch:  185	argmax time taken,  0.007218599319458008
# assembling the matrix time taken:  0.00025582313537597656
# solving Ax = b time taken:  0.0072863101959228516
# 		 time taken minimize linear layer:  0.007572650909423828
# current error:  tensor(0.0193)
# epoch:  186	argmax time taken,  0.007218122482299805
# assembling the matrix time taken:  0.00025272369384765625
# solving Ax = b time taken:  0.007315397262573242
# 		 time taken minimize linear layer:  0.007599353790283203
# current error:  tensor(0.0192)
# epoch:  187	argmax time taken,  0.007234334945678711
# assembling the matrix time taken:  0.00025653839111328125
# solving Ax = b time taken:  0.007333993911743164
# 		 time taken minimize linear layer:  0.007621049880981445
# current error:  tensor(0.0191)
# epoch:  188	argmax time taken,  0.007298946380615234
# assembling the matrix time taken:  0.0002551078796386719
# solving Ax = b time taken:  0.007330656051635742
# 		 time taken minimize linear layer:  0.007616758346557617
# current error:  tensor(0.0191)
# epoch:  189	argmax time taken,  0.007265806198120117
# assembling the matrix time taken:  0.0002522468566894531
# solving Ax = b time taken:  0.007384777069091797
# 		 time taken minimize linear layer:  0.0076673030853271484
# current error:  tensor(0.0189)
# epoch:  190	argmax time taken,  0.0073909759521484375
# assembling the matrix time taken:  0.0002562999725341797
# solving Ax = b time taken:  0.00741267204284668
# 		 time taken minimize linear layer:  0.007699728012084961
# current error:  tensor(0.0189)
# epoch:  191	argmax time taken,  0.0073282718658447266
# assembling the matrix time taken:  0.0002532005310058594
# solving Ax = b time taken:  0.007435798645019531
# 		 time taken minimize linear layer:  0.0077190399169921875
# current error:  tensor(0.0188)
# epoch:  192	argmax time taken,  0.0074100494384765625
# assembling the matrix time taken:  0.00025844573974609375
# solving Ax = b time taken:  0.0073587894439697266
# 		 time taken minimize linear layer:  0.00764775276184082
# current error:  tensor(0.0188)
# ...
# solving Ax = b time taken:  0.02778005599975586
# 		 time taken minimize linear layer:  0.028072595596313477
# current error:  tensor(0.0076)
# epoch:  452	argmax time taken,  0.014571189880371094
# assembling the matrix time taken:  0.00026345252990722656
# solving Ax = b time taken:  0.026844501495361328
# 		 time taken minimize linear layer:  0.027139663696289062
# current error:  tensor(0.0076)
# epoch:  453	argmax time taken,  0.016633272171020508
# assembling the matrix time taken:  0.0002651214599609375
# solving Ax = b time taken:  0.02783942222595215
# 		 time taken minimize linear layer:  0.028136014938354492
# current error:  tensor(0.0075)
# epoch:  454	argmax time taken,  0.014635086059570312
# assembling the matrix time taken:  0.0002620220184326172
# solving Ax = b time taken:  0.027333498001098633
# 		 time taken minimize linear layer:  0.02762627601623535
# current error:  tensor(0.0075)
# epoch:  455	argmax time taken,  0.016734838485717773
# assembling the matrix time taken:  0.0002532005310058594
# solving Ax = b time taken:  0.02804255485534668
# 		 time taken minimize linear layer:  0.028450489044189453
# current error:  tensor(0.0075)
# epoch:  456	argmax time taken,  0.014703989028930664
# assembling the matrix time taken:  0.0002613067626953125
# solving Ax = b time taken:  0.0268552303314209
# 		 time taken minimize linear layer:  0.02714824676513672
# current error:  tensor(0.0075)
# epoch:  457	argmax time taken,  0.016678810119628906
# assembling the matrix time taken:  0.0002543926239013672
# solving Ax = b time taken:  0.027964115142822266
# 		 time taken minimize linear layer:  0.028249740600585938
# current error:  tensor(0.0075)
# epoch:  458	argmax time taken,  0.01468348503112793
# assembling the matrix time taken:  0.0002644062042236328
# solving Ax = b time taken:  0.02751016616821289
# 		 time taken minimize linear layer:  0.027805566787719727
# current error:  tensor(0.0075)
# epoch:  459	argmax time taken,  0.016796350479125977
# assembling the matrix time taken:  0.0002560615539550781
# solving Ax = b time taken:  0.028152942657470703
# 		 time taken minimize linear layer:  0.028447866439819336
# current error:  tensor(0.0075)
# epoch:  460	argmax time taken,  0.014687299728393555
# assembling the matrix time taken:  0.0002720355987548828
# solving Ax = b time taken:  0.027017831802368164
# 		 time taken minimize linear layer:  0.02732086181640625
# current error:  tensor(0.0074)
# epoch:  461	argmax time taken,  0.01672053337097168
# assembling the matrix time taken:  0.0002522468566894531
# solving Ax = b time taken:  0.027982473373413086
# 		 time taken minimize linear layer:  0.028265714645385742
# current error:  tensor(0.0074)
# epoch:  462	argmax time taken,  0.014727354049682617
# assembling the matrix time taken:  0.0002624988555908203
# solving Ax = b time taken:  0.027498245239257812
# 		 time taken minimize linear layer:  0.027883529663085938
# current error:  tensor(0.0074)
# epoch:  463	argmax time taken,  0.016785621643066406
# assembling the matrix time taken:  0.0002541542053222656
# solving Ax = b time taken:  0.02809453010559082
# 		 time taken minimize linear layer:  0.02837967872619629
# current error:  tensor(0.0074)
# epoch:  464	argmax time taken,  0.014722824096679688
# assembling the matrix time taken:  0.00026416778564453125
# solving Ax = b time taken:  0.027034521102905273
# 		 time taken minimize linear layer:  0.027330875396728516
# current error:  tensor(0.0074)
# epoch:  465	argmax time taken,  0.0168306827545166
# assembling the matrix time taken:  0.0002548694610595703
# solving Ax = b time taken:  0.028191328048706055
# 		 time taken minimize linear layer:  0.028477191925048828
# current error:  tensor(0.0074)
# epoch:  466	argmax time taken,  0.01478266716003418
# assembling the matrix time taken:  0.0002701282501220703
# solving Ax = b time taken:  0.02772688865661621
# 		 time taken minimize linear layer:  0.028029203414916992
# current error:  tensor(0.0073)
# epoch:  467	argmax time taken,  0.016866683959960938
# assembling the matrix time taken:  0.00026345252990722656
# solving Ax = b time taken:  0.02820897102355957
# 		 time taken minimize linear layer:  0.0285036563873291
# current error:  tensor(0.0073)
# epoch:  468	argmax time taken,  0.014766454696655273
# assembling the matrix time taken:  0.0002651214599609375
# solving Ax = b time taken:  0.027304410934448242
# 		 time taken minimize linear layer:  0.027600765228271484
# current error:  tensor(0.0073)
# epoch:  469	argmax time taken,  0.01688241958618164
# assembling the matrix time taken:  0.00026345252990722656
# solving Ax = b time taken:  0.02827167510986328
# 		 time taken minimize linear layer:  0.028684616088867188
# current error:  tensor(0.0073)
# epoch:  470	argmax time taken,  0.014816761016845703
# assembling the matrix time taken:  0.0002639293670654297
# solving Ax = b time taken:  0.02786850929260254
# 		 time taken minimize linear layer:  0.028163671493530273
# current error:  tensor(0.0073)
# epoch:  471	argmax time taken,  0.016925811767578125
# assembling the matrix time taken:  0.00026345252990722656
# solving Ax = b time taken:  0.028298139572143555
# 		 time taken minimize linear layer:  0.02859330177307129
# current error:  tensor(0.0073)
# epoch:  472	argmax time taken,  0.014838218688964844
# assembling the matrix time taken:  0.00026416778564453125
# solving Ax = b time taken:  0.027303695678710938
# 		 time taken minimize linear layer:  0.027599334716796875
# current error:  tensor(0.0072)
# epoch:  473	argmax time taken,  0.016895055770874023
# assembling the matrix time taken:  0.00025963783264160156
# solving Ax = b time taken:  0.028345823287963867
# 		 time taken minimize linear layer:  0.028636455535888672
# current error:  tensor(0.0072)
# epoch:  474	argmax time taken,  0.014875650405883789
# assembling the matrix time taken:  0.0002741813659667969
# solving Ax = b time taken:  0.028536319732666016
# 		 time taken minimize linear layer:  0.02884197235107422
# current error:  tensor(0.0072)
# epoch:  475	argmax time taken,  0.016951799392700195
# assembling the matrix time taken:  0.0002532005310058594
# solving Ax = b time taken:  0.028467655181884766
# 		 time taken minimize linear layer:  0.02875232696533203
# current error:  tensor(0.0072)
# epoch:  476	argmax time taken,  0.014928579330444336
# assembling the matrix time taken:  0.0002620220184326172
# solving Ax = b time taken:  0.028558015823364258
# 		 time taken minimize linear layer:  0.028974533081054688
# current error:  tensor(0.0072)
# epoch:  477	argmax time taken,  0.016982078552246094
# assembling the matrix time taken:  0.00025534629821777344
# solving Ax = b time taken:  0.02851128578186035
# 		 time taken minimize linear layer:  0.028797626495361328
# current error:  tensor(0.0072)
# epoch:  478	argmax time taken,  0.014955997467041016
# assembling the matrix time taken:  0.00026416778564453125
# solving Ax = b time taken:  0.02860736846923828
# 		 time taken minimize linear layer:  0.028902769088745117
# current error:  tensor(0.0072)
# epoch:  479	argmax time taken,  0.016985416412353516
# assembling the matrix time taken:  0.0002543926239013672
# solving Ax = b time taken:  0.028528690338134766
# 		 time taken minimize linear layer:  0.028814077377319336
# current error:  tensor(0.0072)
# epoch:  480	argmax time taken,  0.014997720718383789
# assembling the matrix time taken:  0.00026226043701171875
# solving Ax = b time taken:  0.028371572494506836
# 		 time taken minimize linear layer:  0.028665542602539062
# current error:  tensor(0.0072)
# epoch:  481	argmax time taken,  0.016971588134765625
# assembling the matrix time taken:  0.0002613067626953125
# solving Ax = b time taken:  0.028599977493286133
# 		 time taken minimize linear layer:  0.028904199600219727
# current error:  tensor(0.0071)
# epoch:  482	argmax time taken,  0.01498866081237793
# assembling the matrix time taken:  0.0002582073211669922
# solving Ax = b time taken:  0.028586149215698242
# 		 time taken minimize linear layer:  0.028878211975097656
# current error:  tensor(0.0071)
# epoch:  483	argmax time taken,  0.017081499099731445
# assembling the matrix time taken:  0.0002663135528564453
# solving Ax = b time taken:  0.02868509292602539
# 		 time taken minimize linear layer:  0.029100418090820312
# current error:  tensor(0.0071)
# epoch:  484	argmax time taken,  0.015030622482299805
# assembling the matrix time taken:  0.0002524852752685547
# solving Ax = b time taken:  0.028589248657226562
# 		 time taken minimize linear layer:  0.028872966766357422
# current error:  tensor(0.0071)
# epoch:  485	argmax time taken,  0.017067909240722656
# assembling the matrix time taken:  0.00026702880859375
# solving Ax = b time taken:  0.0286710262298584
# 		 time taken minimize linear layer:  0.028968095779418945
# current error:  tensor(0.0071)
# epoch:  486	argmax time taken,  0.015011072158813477
# assembling the matrix time taken:  0.0002510547637939453
# solving Ax = b time taken:  0.0287015438079834
# 		 time taken minimize linear layer:  0.028983116149902344
# current error:  tensor(0.0070)
# epoch:  487	argmax time taken,  0.017091989517211914
# assembling the matrix time taken:  0.0002541542053222656
# solving Ax = b time taken:  0.028717994689941406
# 		 time taken minimize linear layer:  0.029003143310546875
# current error:  tensor(0.0070)
# epoch:  488	argmax time taken,  0.01502680778503418
# assembling the matrix time taken:  0.00025081634521484375
# solving Ax = b time taken:  0.02860426902770996
# 		 time taken minimize linear layer:  0.02888655662536621
# current error:  tensor(0.0070)
# epoch:  489	argmax time taken,  0.017071008682250977
# assembling the matrix time taken:  0.0002548694610595703
# solving Ax = b time taken:  0.028783559799194336
# 		 time taken minimize linear layer:  0.029069900512695312
# current error:  tensor(0.0070)
# epoch:  490	argmax time taken,  0.01506662368774414
# assembling the matrix time taken:  0.0002586841583251953
# solving Ax = b time taken:  0.028769254684448242
# 		 time taken minimize linear layer:  0.029183626174926758
# current error:  tensor(0.0070)
# epoch:  491	argmax time taken,  0.017158985137939453
# assembling the matrix time taken:  0.0002627372741699219
# solving Ax = b time taken:  0.028843164443969727
# 		 time taken minimize linear layer:  0.02913641929626465
# current error:  tensor(0.0070)
# epoch:  492	argmax time taken,  0.015088081359863281
# assembling the matrix time taken:  0.0002613067626953125
# solving Ax = b time taken:  0.028845787048339844
# 		 time taken minimize linear layer:  0.02913808822631836
# current error:  tensor(0.0070)
# epoch:  493	argmax time taken,  0.017177104949951172
# assembling the matrix time taken:  0.0002624988555908203
# solving Ax = b time taken:  0.028941869735717773
# 		 time taken minimize linear layer:  0.029235363006591797
# current error:  tensor(0.0069)
# epoch:  494	argmax time taken,  0.01514887809753418
# assembling the matrix time taken:  0.00025272369384765625
# solving Ax = b time taken:  0.028894662857055664
# 		 time taken minimize linear layer:  0.029179096221923828
# current error:  tensor(0.0069)
# epoch:  495	argmax time taken,  0.017231225967407227
# assembling the matrix time taken:  0.0002532005310058594
# solving Ax = b time taken:  0.028982162475585938
# 		 time taken minimize linear layer:  0.029266357421875
# current error:  tensor(0.0069)
# epoch:  496	argmax time taken,  0.015166997909545898
# assembling the matrix time taken:  0.00025153160095214844
# solving Ax = b time taken:  0.02885150909423828
# 		 time taken minimize linear layer:  0.02913379669189453
# current error:  tensor(0.0069)
# epoch:  497	argmax time taken,  0.017217397689819336
# assembling the matrix time taken:  0.00025582313537597656
# solving Ax = b time taken:  0.02895522117614746
# 		 time taken minimize linear layer:  0.029242515563964844
# current error:  tensor(0.0069)
# epoch:  498	argmax time taken,  0.015205144882202148
# assembling the matrix time taken:  0.00026106834411621094
# solving Ax = b time taken:  0.02893352508544922
# 		 time taken minimize linear layer:  0.029225587844848633
# current error:  tensor(0.0069)
# epoch:  499	argmax time taken,  0.017244577407836914
# assembling the matrix time taken:  0.000255584716796875
# solving Ax = b time taken:  0.02905440330505371
# 		 time taken minimize linear layer:  0.0293426513671875
# current error:  tensor(0.0069)
# epoch:  500	argmax time taken,  0.015254735946655273
# assembling the matrix time taken:  0.0002541542053222656
# solving Ax = b time taken:  0.02895498275756836
# 		 time taken minimize linear layer:  0.029331684112548828
# current error:  tensor(0.0068)
# epoch:  501	argmax time taken,  0.01724076271057129
# assembling the matrix time taken:  0.00025463104248046875
# solving Ax = b time taken:  0.029022216796875
# 		 time taken minimize linear layer:  0.029308319091796875
# current error:  tensor(0.0068)
# epoch:  502	argmax time taken,  0.015265703201293945
# assembling the matrix time taken:  0.0002512931823730469
# solving Ax = b time taken:  0.02903580665588379
# 		 time taken minimize linear layer:  0.029317855834960938
# current error:  tensor(0.0068)
# epoch:  503	argmax time taken,  0.017292022705078125
# assembling the matrix time taken:  0.0002529621124267578
# solving Ax = b time taken:  0.02912735939025879
# 		 time taken minimize linear layer:  0.029410362243652344
# current error:  tensor(0.0068)
# epoch:  504	argmax time taken,  0.015265464782714844
# assembling the matrix time taken:  0.0002605915069580078
# solving Ax = b time taken:  0.029083251953125
# 		 time taken minimize linear layer:  0.029373884201049805
# current error:  tensor(0.0068)
# epoch:  505	argmax time taken,  0.017383813858032227
# assembling the matrix time taken:  0.0002551078796386719
# solving Ax = b time taken:  0.029500246047973633
# 		 time taken minimize linear layer:  0.029786109924316406
# current error:  tensor(0.0068)
# epoch:  506	argmax time taken,  0.01532435417175293
# assembling the matrix time taken:  0.00025153160095214844
# solving Ax = b time taken:  0.029545307159423828
# 		 time taken minimize linear layer:  0.029828310012817383
# current error:  tensor(0.0068)
# epoch:  507	argmax time taken,  0.01734137535095215
# assembling the matrix time taken:  0.00025653839111328125
# solving Ax = b time taken:  0.029596805572509766
# 		 time taken minimize linear layer:  0.02988457679748535
# current error:  tensor(0.0068)
# epoch:  508	argmax time taken,  0.01533198356628418
# assembling the matrix time taken:  0.00025343894958496094
# solving Ax = b time taken:  0.029537439346313477
# 		 time taken minimize linear layer:  0.029822349548339844
# current error:  tensor(0.0068)
# epoch:  509	argmax time taken,  0.017416715621948242
# assembling the matrix time taken:  0.00025200843811035156
# solving Ax = b time taken:  0.029595136642456055
# 		 time taken minimize linear layer:  0.029877424240112305
# current error:  tensor(0.0067)
# epoch:  510	argmax time taken,  0.015444278717041016
# assembling the matrix time taken:  0.0002524852752685547
# solving Ax = b time taken:  0.029601097106933594
# 		 time taken minimize linear layer:  0.030005693435668945
# current error:  tensor(0.0067)
# epoch:  511	argmax time taken,  0.017491817474365234
# assembling the matrix time taken:  0.00026416778564453125
# solving Ax = b time taken:  0.029711484909057617
# 		 time taken minimize linear layer:  0.03000617027282715
# current error:  tensor(0.0067)
# epoch:  512	argmax time taken,  0.0154571533203125
# assembling the matrix time taken:  0.0002541542053222656
# solving Ax = b time taken:  0.0296480655670166
# 		 time taken minimize linear layer:  0.029932260513305664
# current error:  tensor(0.0067)
# total duration:  18.762224435806274
# neuron num 		 error 		 order
# 4 		 0.171949 		 *
#
# 8 		 0.143062 		 0.265338
#
# 16 		 0.088723 		 0.689253
#
# 32 		 0.068119 		 0.381262
#
# 64 		 0.042780 		 0.671112
#
# 128 		 0.024283 		 0.816990
#
# 256 		 0.013012 		 0.900152
#
# 512 		 0.006684 		 0.960998
#
# neuron num  & 	 $\|u-u_n \|_{L^2}$ & 	 order $O(n^{-0.88})$  \\ \hline \hline
# 4 		 & 0.171949 &		 *  \\ \hline
#
# 8 		 &  1.431e-01 &  		 0.27 \\ \hline
#
# 16 		 &  8.872e-02 &  		 0.69 \\ \hline
#
# 32 		 &  6.812e-02 &  		 0.38 \\ \hline
#
# 64 		 &  4.278e-02 &  		 0.67 \\ \hline
#
# 128 		 &  2.428e-02 &  		 0.82 \\ \hline
#
# 256 		 &  1.301e-02 &  		 0.90 \\ \hline
#
# 512 		 &  6.684e-03 &  		 0.96 \\ \hline
