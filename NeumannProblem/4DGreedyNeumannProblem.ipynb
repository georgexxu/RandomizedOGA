# %%
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import time
import sys
from scipy.sparse import linalg
from pathlib import Path
import itertools
if torch.cuda.is_available():  
    device = "cuda" 
else:  
    device = "cpu" 


torch.set_default_dtype(torch.float64)
pi = torch.tensor(np.pi,dtype=torch.float64)
zero = torch.tensor([0.]).to(device)

class model(nn.Module):
    """ ReLU k shallow neural network
    Parameters: 
    input size: input dimension
    hidden_size1 : number of hidden layers 
    num_classes: output classes 
    k: degree of relu functions
    """
    def __init__(self, input_size, hidden_size1, num_classes,k = 1):
        super().__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, num_classes,bias = False)
        self.k = k 
    def forward(self, x):
        u1 = self.fc2(F.relu(self.fc1(x))**self.k)
        return u1
    def evaluate_derivative(self, x, i):
        if self.k == 1:
            u1 = self.fc2(torch.heaviside(self.fc1(x),zero) * self.fc1.weight.t()[i-1:i,:] )
        else:
            u1 = self.fc2(self.k*F.relu(self.fc1(x))**(self.k-1) *self.fc1.weight.t()[i-1:i,:] )  
        return u1

def plot_2D(f): 
    
    Nx = 400
    Ny = 400 
    xs = np.linspace(0, 1, Nx)
    ys = np.linspace(0, 1, Ny)
    x, y = np.meshgrid(xs, ys, indexing='xy')
    xy_comb = np.stack((x.flatten(),y.flatten())).T
    xy_comb = torch.tensor(xy_comb)
    z = f(xy_comb).reshape(Nx,Ny)
    z = z.detach().numpy()
    plt.figure(dpi=200)
    ax = plt.axes(projection='3d')
    ax.plot_surface(x , y , z )

    plt.show()

def plot_subdomains(my_model):
    x_coord =torch.linspace(0,1,200)
    wi = my_model.fc1.weight.data
    bi = my_model.fc1.bias.data 
    for i, bias in enumerate(bi):  
        if wi[i,1] !=0: 
            plt.plot(x_coord, - wi[i,0]/wi[i,1]*x_coord - bias/wi[i,1])
        else: 
            plt.plot(x_coord,  - bias/wi[i,0]*torch.ones(x_coord.size()))

    plt.xlim([0,1])
    plt.ylim([0,1])
    plt.legend()
    plt.show()
    return 0   

def adjust_neuron_position(my_model, dims = 3):

    def create_mesh_grid(dims, pts):
        mesh = torch.tensor(list(itertools.product(pts,repeat=dims)))
        vertices = mesh.reshape(len(pts) ** dims, -1) 
        return vertices
    counter = 0 
    # positions = torch.tensor([[0.,0.],[0.,1.],[1.,1.],[1.,0.]])
    pts = torch.tensor([0.,1.])
    positions = create_mesh_grid(dims,pts) 
    neuron_num = my_model.fc1.bias.size(0)
    for i in range(neuron_num): 
        w = my_model.fc1.weight.data[i:i+1,:]
        b = my_model.fc1.bias.data[i]
    #     print(w,b)
        values = torch.matmul(positions,w.T) # + b
        left_end = - torch.max(values)
        right_end = - torch.min(values)
        offset = (right_end - left_end)/50
        if b <= left_end + offset/2 : 
            b = torch.rand(1)*(right_end - left_end - offset) + left_end + offset/2 
            my_model.fc1.bias.data[i] = b 
        if b >= right_end - offset/2 :
            if counter < (dims+1):
#                 print("here")
                counter += 1
            else: # (d + 1) or more 
                b = torch.rand(1)*(right_end - left_end - offset) + left_end + offset/2 
                my_model.fc1.bias.data[i] = b 
    return my_model

# %%
def MonteCarlo_Sobol_dDim_weights_points(M ,d = 4):
    Sob_integral = torch.quasirandom.SobolEngine(dimension =d, scramble= False, seed=None) 
    integration_points = Sob_integral.draw(M).double() 
    integration_points = integration_points.to(device)
    weights = torch.ones(M,1).to(device)/M 
    return weights, integration_points 

def generate_relu_dict4D(N_list):
    
    N = np.prod(N_list) 

    grid_indices = [np.linspace(0,1,N_item,endpoint=False) for N_item in N_list]
    grid = np.meshgrid(*grid_indices,indexing='ij')
    grid_coordinates = np.column_stack([axis.ravel() for axis in grid]) 
    samples = torch.tensor(grid_coordinates) 

    T =torch.tensor([[pi,0,0,0],[0,pi,0,0],[0,0,2*pi,0],[0,0,0,2*2]]) # 2 * sqrt(d)
    shift = torch.tensor([0,0,0,-2])
    samples = samples@T + shift 

    f1 = torch.zeros(N,1) 
    f2 = torch.zeros(N,1)
    f3 = torch.zeros(N,1)
    f4 = torch.zeros(N,1)
    f5 = torch.zeros(N,1)

    f1[:,0] = torch.cos(samples[:,0]) 
    f2[:,0] = torch.sin(samples[:,0]) * torch.cos(samples[:,1])
    f3[:,0] = torch.sin(samples[:,0]) * torch.sin(samples[:,1]) * torch.cos(samples[:,2])
    f4[:,0] = torch.sin(samples[:,0]) * torch.sin(samples[:,1]) * torch.sin(samples[:,2])  
    f5[:,0] = samples[:,3]

    Wb_tensor = torch.cat([f1,f2,f3,f4,f5],1) # N x 4 
    return Wb_tensor

def PiecewiseGQ3D_weights_points(Nx, order): 
    """ A slight modification of PiecewiseGQ2D function that only needs the weights and integration points.
    Parameters
    ----------

    Nx: int 
        number of intervals along the dimension. No Ny, assume Nx = Ny
    order: int 
        order of the Gauss Quadrature

    Returns
    -------
    long_weights: torch.tensor
    integration_points: torch.tensor
    """

    """
    Parameters
    ----------
    target : 
        Target function 
    Nx: int 
        number of intervals along the dimension. No Ny, assume Nx = Ny
    order: int 
        order of the Gauss Quadrature
    """

    # print("order: ",order )
    x, w = np.polynomial.legendre.leggauss(order)
    gauss_pts = np.array(np.meshgrid(x,x,x,indexing='ij')).reshape(3,-1).T
    weight_list = np.array(np.meshgrid(w,w,w,indexing='ij'))
    weights =   (weight_list[0]*weight_list[1]*weight_list[2]).ravel() 

    gauss_pts =torch.tensor(gauss_pts)
    weights = torch.tensor(weights)

    h = 1/Nx # 100 intervals 
    long_weights =  torch.tile(weights,(Nx**3,1))
    long_weights = long_weights.reshape(-1,1)
    long_weights = long_weights * h**3 /8 

    integration_points = torch.tile(gauss_pts,(Nx**3,1))
    # print("shape of integration_points", integration_points.size())
    scale_factor = h/2 
    integration_points = scale_factor * integration_points

    index = np.arange(1,Nx+1)-0.5
    ordered_pairs = np.array(np.meshgrid(index,index,index,indexing='ij'))
    ordered_pairs = ordered_pairs.reshape(3,-1).T

    # print(ordered_pairs)
    # print()
    ordered_pairs = torch.tensor(ordered_pairs)
    # print(ordered_pairs.size())
    ordered_pairs = torch.tile(ordered_pairs, (1,order**3)) # number of GQ points
    # print(ordered_pairs)

    ordered_pairs =  ordered_pairs.reshape(-1,3)
    # print(ordered_pairs)
    translation = ordered_pairs*h 
    # print(translation)

    integration_points = integration_points + translation 

    return long_weights.to(device), integration_points.to(device)


def generate_relu_dict4D_QMC(s,N0):
    # Sob = torch.quasirandom.SobolEngine(dimension =4, scramble= True, seed=None) 
    # samples = Sob.draw(N0).double() 

    # for i in range(s-1):
    #     samples = torch.cat([samples,Sob.draw(N0).double()],0)

    # Monte Carlo 
    samples = torch.rand(s*N0,4) 

    T =torch.tensor([[pi,0,0,0],[0,pi,0,0],[0,0,2*pi,0],[0,0,0,2*2]])
    shift = torch.tensor([0,0,0,-2])
    samples = samples@T + shift 

    f1 = torch.zeros(s*N0,1) 
    f2 = torch.zeros(s*N0,1)
    f3 = torch.zeros(s*N0,1)
    f4 = torch.zeros(s*N0,1)
    f5 = torch.zeros(s*N0,1)

    f1[:,0] = torch.cos(samples[:,0]) 
    f2[:,0] = torch.sin(samples[:,0]) * torch.cos(samples[:,1])
    f3[:,0] = torch.sin(samples[:,0]) * torch.sin(samples[:,1]) * torch.cos(samples[:,2])
    f4[:,0] = torch.sin(samples[:,0]) * torch.sin(samples[:,1]) * torch.sin(samples[:,2])  
    f5[:,0] = samples[:,3]

    Wb_tensor = torch.cat([f1,f2,f3,f4,f5],1) # N x 4 
    return Wb_tensor

def minimize_linear_layer_H1_explicit_assemble_efficient(model,alpha, target, g_N, weights, integration_points, w_bd, pts_bd, activation = 'relu',solver="direct" ):
    """ -div alpha grad u(x) + u = f 
    Parameters
    ----------
    model: 
        nn model
    alpha:
        alpha function
    target:
        rhs function f 
    pts_bd:
        integration points on the boundary, embdedded in the domain 
    """ 
    zero = torch.tensor([0.]).to(device)
    start_time = time.time() 
    w = model.fc1.weight.data 
    b = model.fc1.bias.data 
    neuron_num = b.size(0) 
    dim = integration_points.size(1) 
    
    coef_alpha = alpha(integration_points) # alpha  
    if activation == 'relu':
        basis_value_col = F.relu(integration_points @ w.t()+ b)**(model.k)
        weighted_basis_value_col = basis_value_col * weights 
        jac = weighted_basis_value_col.t() @ basis_value_col  # mass matrix 
        rhs = weighted_basis_value_col.t() @ (target(integration_points)) 

        # Todo1: assemble the boundary condition term <g,v>_{\Gamma_N} 
        size_pts_bd = int(pts_bd.size(0)/(2*dim))
        if g_N != None:
            bcs_N = g_N(dim)
            for ii, g_ii in bcs_N:
                # pts_bd_ii = pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
                weighted_g_N = -g_ii(pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:])* w_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
                basis_value_bd_col = F.relu(pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:] @ w.t()+ b)**(model.k)
                rhs += basis_value_bd_col.t() @ weighted_g_N

                weighted_g_N = g_ii(pts_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:])* w_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:]
                basis_value_bd_col = F.relu(pts_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:] @ w.t()+ b)**(model.k)
                rhs += basis_value_bd_col.t() @ weighted_g_N
        
        if model.k == 1:  
            for d in range(dim):
                basis_value_dxi_col = torch.heaviside(integration_points @ w.t()+ b, zero) * w.t()[d:d+1,:]
                weighted_basis_value_dx_col = basis_value_dxi_col * weights * coef_alpha 
                jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 
#             basis_value_dx_all_col = torch.stack([torch.heaviside(integration_points @ w.t()+ b, zero) * w.t()[d:d+1,:] for d in range(dim)])
            
        else: 
            for d in range(dim):
                basis_value_dxi_col = model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * w.t()[d:d+1,:]
                weighted_basis_value_dx_col = basis_value_dxi_col * weights * coef_alpha  
                jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 
#             basis_value_dx_all_col = torch.stack([model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * w.t()[d:d+1,:] for d in range(dim)]) 
            # basis_value_dx_col = model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * w.t()[0:1,:]
            # basis_value_dy_col = model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * w.t()[1:2,:] 

    print("assembling the mass matrix time taken: ", time.time()-start_time) 


    start_time = time.time()    
    if solver == "cg": 
        sol, exit_code = linalg.cg(np.array(jac.detach().cpu()),np.array(rhs.detach().cpu()),tol=1e-12)
        sol = torch.tensor(sol).view(1,-1)
    elif solver == "direct": 
#         sol = np.linalg.inv( np.array(jac.detach().cpu()) )@np.array(rhs.detach().cpu())
        sol = (torch.linalg.solve( jac.detach(), rhs.detach())).view(1,-1)
    elif solver == "ls":
        sol = (torch.linalg.lstsq(jac.detach().cpu(),rhs.detach().cpu(),driver='gelsd').solution).view(1,-1)
        # sol = (torch.linalg.lstsq(jac.detach(),rhs.detach()).solution).view(1,-1) # gpu/cpu, driver = 'gels', cannot solve singular
    print("solving Ax = b time taken: ", time.time()-start_time)
    return sol 

# def minimize_linear_layer_H1_explicit_assemble_efficient(model,alpha, target,weights, integration_points,activation = 'relu',solver="direct" ):
#     """ -div alpha grad u(x) + u = f 
#     Parameters
#     ----------
#     model: 
#         nn model
#     alpha:
#         alpha function
#     target:
#         rhs function f 
#     """ 
#     zero = torch.tensor([0.]).to(device)
#     start_time = time.time() 
#     w = model.fc1.weight.data 
#     b = model.fc1.bias.data 
#     neuron_num = b.size(0) 
#     dim = integration_points.size(1) 

#     if activation == 'relu':
#         basis_value_col = F.relu(integration_points @ w.t()+ b)**(model.k) 
#         if model.k == 1:  
#             basis_value_dx_all_col = torch.stack([torch.heaviside(integration_points @ w.t()+ b, zero) * w.t()[d:d+1,:] for d in range(dim)])
            
#         else: 
#             basis_value_dx_all_col = torch.stack([model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * w.t()[d:d+1,:] for d in range(dim)]) 
#             # basis_value_dx_col = model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * w.t()[0:1,:]
#             # basis_value_dy_col = model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * w.t()[1:2,:] 

#     weighted_basis_value_col = basis_value_col * weights 
#     jac = weighted_basis_value_col.t() @ basis_value_col  # mass matrix 
#     rhs = weighted_basis_value_col.t() @ (target(integration_points)) 
#     print("assembling the mass matrix time taken: ", time.time()-start_time) 

#     start_time = time.time() 
#     coef_alpha = alpha(integration_points) # alpha 
#     for basis_value_col_dx in basis_value_dx_all_col: 
#         weighted_basis_value_dx_col = basis_value_col_dx * weights * coef_alpha # alpha 
#         jac += weighted_basis_value_dx_col.t() @ basis_value_col_dx
#     # weighted_basis_value_dx_col = basis_value_dx_col * weights
#     # weighted_basis_value_dy_col = basis_value_dy_col * weights
#     # jac2 = weighted_basis_value_dx_col.t() @ basis_value_dx_col + weighted_basis_value_dy_col.t() @ basis_value_dy_col 
#     # print("assembling the stiffness matrix time taken: ", time.time()-start_time)   
#     # jac = jac1 + jac2    
    
#     start_time = time.time()    
#     if solver == "cg": 
#         sol, exit_code = linalg.cg(np.array(jac.detach().cpu()),np.array(rhs.detach().cpu()),tol=1e-12)
#         sol = torch.tensor(sol).view(1,-1)
#     elif solver == "direct": 
# #         sol = np.linalg.inv( np.array(jac.detach().cpu()) )@np.array(rhs.detach().cpu())
#         sol = (torch.linalg.solve( jac.detach(), rhs.detach())).view(1,-1)
#     elif solver == "ls":
#         sol = (torch.linalg.lstsq(jac.detach().cpu(),rhs.detach().cpu(),driver='gelsd').solution).view(1,-1)
#         # sol = (torch.linalg.lstsq(jac.detach(),rhs.detach()).solution).view(1,-1) # gpu/cpu, driver = 'gels', cannot solve singular
#     print("solving Ax = b time taken: ", time.time()-start_time)
#     return sol 


def OGANeumannReLU4D(my_model,alpha, target,g_N, u_exact, u_exact_grad, N_list,num_epochs,plot_freq, M, k =1, rand_deter = 'deter', linear_solver = "direct"): 
    """ Orthogonal greedy algorithm using 1D ReLU dictionary over [-pi,pi]
    Parameters
    ----------
    my_model: 
        nn model 
    target: 
        target function
    num_epochs: int 
        number of training epochs 
    integration_intervals: int 
        number of subintervals for piecewise numerical quadrature 

    Returns
    -------
    err: tensor 
        rank 1 torch tensor to record the L2 error history  
    model: 
        trained nn model 
    """
    #Todo Done
    dim = 4 
    gw_expand, integration_points = MonteCarlo_Sobol_dDim_weights_points(M, d=dim)
    gw_expand = gw_expand.to(device)
    integration_points = integration_points.to(device)

    # define integration on the boundary 
    gw_expand_bd, integration_points_bd = PiecewiseGQ3D_weights_points(25, order = 2) 
    size_pts_bd = integration_points_bd.size(0) 
    gw_expand_bd_faces = torch.tile(gw_expand_bd,(2*dim,1))

    integration_points_bd_faces = torch.zeros(2*dim*integration_points_bd.size(0),dim).to(device)
    integration_points_bd_faces[0:size_pts_bd,0:1] = 0 
    integration_points_bd_faces[0:size_pts_bd,1:] = integration_points_bd[:]

    integration_points_bd_faces[size_pts_bd:size_pts_bd*2,0:1] = 1
    integration_points_bd_faces[size_pts_bd:size_pts_bd*2,1:] = integration_points_bd[:,:]

    integration_points_bd_faces[size_pts_bd*2:size_pts_bd*3,1:2] = 0 
    integration_points_bd_faces[size_pts_bd*2:size_pts_bd*3, 0:1] = integration_points_bd[:,0:1]
    integration_points_bd_faces[size_pts_bd*2:size_pts_bd*3,2:] =  integration_points_bd[:,1:]

    integration_points_bd_faces[size_pts_bd*3:size_pts_bd*4,1:2] = 1
    integration_points_bd_faces[size_pts_bd*3:size_pts_bd*4, 0:1] = integration_points_bd[:,0:1]
    integration_points_bd_faces[size_pts_bd*3:size_pts_bd*4,2:] =  integration_points_bd[:,1:]

    integration_points_bd_faces[size_pts_bd*4:size_pts_bd*5,2:3] = 0
    integration_points_bd_faces[size_pts_bd*4:size_pts_bd*5,0:2] = integration_points_bd[:,0:2]
    integration_points_bd_faces[size_pts_bd*4:size_pts_bd*5,3:] = integration_points_bd[:,2:]

    integration_points_bd_faces[size_pts_bd*5:size_pts_bd*6,2:3] = 1
    integration_points_bd_faces[size_pts_bd*5:size_pts_bd*6,0:2] = integration_points_bd[:,0:2]
    integration_points_bd_faces[size_pts_bd*5:size_pts_bd*6,3:] = integration_points_bd[:,2:]

    integration_points_bd_faces[size_pts_bd*6:size_pts_bd*7,3:4] = 0
    integration_points_bd_faces[size_pts_bd*6:size_pts_bd*7,0:3] = integration_points_bd[:,:]

    integration_points_bd_faces[size_pts_bd*7:size_pts_bd*8,3:4] = 1 
    integration_points_bd_faces[size_pts_bd*7:size_pts_bd*8,0:3] = integration_points_bd[:,:]

    err = torch.zeros(num_epochs+1)
    err_h10 = torch.zeros(num_epochs+1) 
    if my_model == None: 
        func_values = - target(integration_points)
        num_neuron = 0

        list_b = []
        list_w = []
    else: 
        func_values = - (target(integration_points) - my_model(integration_points).detach())
        bias = my_model.fc1.bias.detach().data
        weights = my_model.fc1.weight.detach().data
        num_neuron = int(bias.size(0))

        list_b = list(bias)
        list_w = list(weights)
    
    # initial error Todo Done
    func_values_sqrd = func_values*func_values
    # print(func_values_sqrd.size())
    # print(gw_expand.size()) 
    err[0]= torch.sum(func_values_sqrd*gw_expand)**0.5
    ## h1 seminorm 
    if u_exact_grad != None:
        u_grad = u_exact_grad() 
        for grad_i in u_grad: 
            err_h10[0] += torch.sum((grad_i(integration_points))**2 * gw_expand)**0.5
    
    start_time = time.time()
    solver = linear_solver

    N0 = np.prod(N_list)
    if rand_deter == 'deter':
        relu_dict_parameters = generate_relu_dict4D(N_list).to(device)
    print("using linear solver: ",solver)

    for i in range(num_epochs): 
        print("epoch: ",i+1, end = '\t')
        if rand_deter == 'rand':
            relu_dict_parameters = generate_relu_dict4D_QMC(1,N0).to(device) 
        if num_neuron == 0: 
            func_values = - target(integration_points)
        else: 
            func_values = - target(integration_points) + my_model(integration_points).detach()

        weight_func_values = func_values*gw_expand  
        basis_values = (F.relu( torch.matmul(integration_points,relu_dict_parameters[:,0:4].T ) - relu_dict_parameters[:,4])**k).T # uses broadcasting, # dimension 4 
        output = torch.matmul(basis_values,weight_func_values) #
        
        # grad u part
        alpha_coef = alpha(integration_points) # alpha 
        if my_model!= None:
            if k == 1:  
                derivative_part = torch.heaviside(integration_points @ (relu_dict_parameters[:,0:4].T) - relu_dict_parameters[:,4], zero) # dimension 4 
                derivative_part *= alpha_coef # alpha 
                for dx_i in range(dim): 
                    weight_dbasis_values_dxi =  (derivative_part * relu_dict_parameters.t()[dx_i:dx_i+1,:]) *gw_expand   
                    dmy_model_dxi = my_model.evaluate_derivative(integration_points,dx_i+1).detach()
                    output += torch.matmul(weight_dbasis_values_dxi.t(), dmy_model_dxi) 

            else:  
                derivative_part = k * F.relu(integration_points @ (relu_dict_parameters[:,0:4].T) - relu_dict_parameters[:,4])**(k-1) # dimension 4 
                derivative_part *= alpha_coef # alpha
                for dx_i in range(dim): 
                    weight_dbasis_values_dxi =  (derivative_part * relu_dict_parameters.t()[dx_i:dx_i+1,:]) * gw_expand    
                    dmy_model_dxi = my_model.evaluate_derivative(integration_points,dx_i+1).detach()
                    output += torch.matmul(weight_dbasis_values_dxi.t(), dmy_model_dxi) 
        
        #Todo2 boundary condition term -<g,v>_{\Gamma_N}  
        if g_N != None:
            bcs_N = g_N(dim) 
            for ii, g_ii in bcs_N: 
                
                weighted_g_N = -g_ii(integration_points_bd_faces[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:])* gw_expand_bd_faces[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
                basis_values_bd_faces = (F.relu( torch.matmul(integration_points_bd_faces[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:],relu_dict_parameters[:,0:4].T ) - relu_dict_parameters[:,4])**k).T
                output -= torch.matmul(basis_values_bd_faces,weighted_g_N)
                
                weighted_g_N = g_ii(integration_points_bd_faces[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:])* gw_expand_bd_faces[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:]
                basis_values_bd_faces = (F.relu( torch.matmul(integration_points_bd_faces[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:],relu_dict_parameters[:,0:4].T ) - relu_dict_parameters[:,4])**k).T
                output -= torch.matmul(basis_values_bd_faces,weighted_g_N)

        
        # output = torch.abs(torch.matmul(basis_values,weight_func_values)) # 
        output = torch.abs(output)
        neuron_index = torch.argmax(output.flatten())
        
        # print(neuron_index)
        list_w.append(relu_dict_parameters[neuron_index,0:4]) # dimension 4 
        list_b.append(-relu_dict_parameters[neuron_index,4])
        num_neuron += 1
        my_model = model(4,num_neuron,1,k).to(device)
        w_tensor = torch.stack(list_w, 0 ) 
        b_tensor = torch.tensor(list_b)
        my_model.fc1.weight.data[:,:] = w_tensor[:,:]
        my_model.fc1.bias.data[:] = b_tensor[:]

        #Todo Done 
#         alpha = None 
        sol = minimize_linear_layer_H1_explicit_assemble_efficient(my_model,alpha, target, g_N, gw_expand, integration_points,gw_expand_bd_faces, integration_points_bd_faces,activation = 'relu',solver = solver)

        my_model.fc2.weight.data[0,:] = sol[:]

        model_values = my_model(integration_points).detach()
        # L2 error ||u - u_n||
        diff_values_sqrd = (u_exact(integration_points) - model_values)**2 
        err[i+1]= torch.sum(diff_values_sqrd*gw_expand)**0.5

        # H10 error || grad(u) - grad(u_n) ||
        if u_exact_grad != None:
            for ii, grad_i in enumerate(u_grad):  
                my_model_dxi = my_model.evaluate_derivative(integration_points,ii+1).detach()  
                err_h10[i+1] += torch.sum((grad_i(integration_points) - my_model_dxi)**2 * gw_expand)**0.5

    print("time taken: ",time.time() - start_time)
    return err, err_h10, my_model

# %% [markdown]
# In the following tests, we compare using deterministic dictionaries with using random dictionary for the following three target functions.
#
# - $\sin(\pi x_1) \sin(\pi x_2)$
# - $\sin(4\pi x_1) \sin(8\pi x_2)$
# - Gabor function

# %%
# gw_expand, integration_points =MonteCarlo_Sobol_dDim_weights_points(600000, d=4)
# my_model = model(4,320,1,1).to(device)
# my_model = adjust_neuron_position(my_model.cpu(),dims = 4).to(device) 
# def u_exact(x):
#     return torch.cos(pi*x[:,0:1])*torch.cos(pi*x[:,1:2] )*torch.cos(pi*x[:,2:3])*torch.cos(pi*x[:,3:4])
# def target(x):
#     z = (4 * pi**2 + 1)*torch.cos(pi*x[:,0:1])*torch.cos(pi*x[:,1:2] )*torch.cos(pi*x[:,2:3])*torch.cos(pi*x[:,3:4]) 
#     return z  
# solver = 'direct'
# alpha = None 
# sol = minimize_linear_layer_H1_explicit_assemble_efficient(my_model,alpha, target,gw_expand, integration_points,activation = 'relu',solver = solver)
# my_model.fc2.weight.data[0,:] = sol[:] 

# diff_values = (u_exact(integration_points) - my_model(integration_points).detach())**2 
# integral = torch.sum(diff_values*gw_expand)**0.5 
# print("L2 error: ",integral)

# %%
def u_exact(x):
    d = 4 
    cn =   7.03/d 
    return torch.exp(-torch.sum( cn**2 * (x - 0.5)**2,dim = 1, keepdim = True))  

def u_exact_grad():
    d = 4 
    cn = 7.03/d
    def make_grad_i(i):
        def grad_i(x):
            return torch.exp(-torch.sum(cn**2 * (x - 0.5)**2, dim=1, keepdim=True)) * (-2 * cn**2 * (x[:, i:i+1] - 0.5))
        return grad_i 
    
    u_grad=[] 
    for i in range(d):
        u_grad.append(make_grad_i(i))
    return u_grad


def alpha(x): 
    return torch.ones(x.size(0),1).to(device)
    # return 0.5 * torch.sin(6 * pi*x[:,0:1]) + 1. 

# def target(x):
# #     z = (  4 * (pi)**2 + 1)*torch.cos( pi*x[:,0:1])*torch.cos( pi*x[:,1:2] ) * torch.cos(pi*x[:,2:3]) * torch.cos( pi*x[:,3:4]) 
# #     return z 
#     z_c = torch.cos( pi*x[:,0:1])*torch.cos( pi*x[:,1:2] ) * torch.cos(pi*x[:,2:3]) * torch.cos( pi*x[:,3:4]) 
#     z1 = 3 * pi**2 * torch.sin(pi * x[:,0:1]) * torch.cos( 6*pi*x[:,1:2] ) * torch.cos(pi*x[:,2:3]) * torch.cos( pi*x[:,3:4]) 
#     z2 = 0.5 * pi**2 * torch.sin(6*pi * x[:,0:1])* z_c 
#     z = z1 + z2 + 3/2*pi**2 * torch.sin(6 * pi * x[:,0:1]) * z_c 
#     z += ( 4 * (pi)**2 + 1)*z_c 
#     return z 

def target(x):
    d = 4 
    cn =   7.03/d 
    z = torch.exp(-torch.sum( cn**2 * (x - 0.5)**2,dim = 1, keepdim = True)) 
    return z* ( -torch.sum(  (2 *cn**2 * (x - 0.5))**2 - 2*cn**2 ,dim = 1, keepdim = True) +1)

def g_N(dim):
    def make_g(i):
        def g_i(x):
            d = 4 
            cn = 7.03 / d
            return torch.exp(-torch.sum(cn**2 * (x - 0.5)**2, dim=1, keepdim=True)) * (-2 * cn**2 * (x[:, i:i+1] - 0.5))
        return g_i

    bcs_N = []
    for i in range(dim):
        bcs_N.append((i, make_g(i)))
    
    return bcs_N


function_name = "cospix" 
filename_write = "data-neumann/4DOGA-{}-order.txt".format(function_name)
f_write = open(filename_write, "a")
f_write.write("\n")
f_write.close() 
save = False 
for N_list in [[2**2,2**2,2**3,2**3]]: # ,[2**6,2**6],[2**7,2**7] 
    # save = True 
    f_write = open(filename_write, "a")
    my_model = None 
    # Nx = 50   
    # order = 3   
    M = 500000  
    exponent = 9
    num_epochs = 2**exponent  
    plot_freq = num_epochs 
    N = np.prod(N_list)
    err_QMC2, err_h10, my_model = OGANeumannReLU4D(my_model,alpha, target,g_N, u_exact,u_exact_grad, N_list,num_epochs,plot_freq, M, k = 2, rand_deter= 'rand', linear_solver = "direct")
    
    if save: 
        folder = 'data-neumann/'
        filename = folder + 'err_OGA_4D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        torch.save(err_QMC2,filename) 
        folder = 'data-neumann/'
        filename = folder + 'model_OGA_4D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        torch.save(my_model,filename)

    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_QMC2[i] for i in neuron_nums ]
    err_list2 = [err_h10[i] for i in neuron_nums ] 
    f_write.write('deterministic dictionary size: {}\n'.format(N))
    f_write.write("neuron num \t\t error \t\t order \t\t h10 error \\ order \n")
    print("neuron num \t\t error \t\t order")
    for i, item in enumerate(err_list):
        if i == 0: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t")
            
            # print("*")
            print("{} \t\t {} \t\t * \t\t {} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ) )   
            f_write.write("{} \t\t {} \t\t * \t\t {} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ))
        else: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t") 
            # print(np.log(err_list[i-1]/err_list[i])/np.log(2))
            print("{} \t\t {} \t\t {} \t\t {} \t\t {} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ) )
            f_write.write("{} \t\t {} \t\t {} \t\t {} \t\t {} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ))
    f_write.write("\n")
    f_write.close()
# Out:
# using linear solver:  direct
# epoch:  1	assembling the mass matrix time taken:  0.0034203529357910156
# solving Ax = b time taken:  0.0005359649658203125
# epoch:  2	assembling the mass matrix time taken:  0.0036268234252929688
# solving Ax = b time taken:  0.0037882328033447266
# epoch:  3	assembling the mass matrix time taken:  0.01637721061706543
# solving Ax = b time taken:  0.0036802291870117188
# epoch:  4	assembling the mass matrix time taken:  0.016672372817993164
# solving Ax = b time taken:  0.004155635833740234
# epoch:  5	assembling the mass matrix time taken:  0.0048792362213134766
# solving Ax = b time taken:  0.004472970962524414
# epoch:  6	assembling the mass matrix time taken:  0.016253948211669922
# solving Ax = b time taken:  0.005098819732666016
# epoch:  7	assembling the mass matrix time taken:  0.01663374900817871
# solving Ax = b time taken:  0.00569462776184082
# epoch:  8	assembling the mass matrix time taken:  0.016825437545776367
# solving Ax = b time taken:  0.006047725677490234
# epoch:  9	assembling the mass matrix time taken:  0.016932964324951172
# solving Ax = b time taken:  0.0065670013427734375
# epoch:  10	assembling the mass matrix time taken:  0.016687631607055664
# solving Ax = b time taken:  0.007215738296508789
# epoch:  11	assembling the mass matrix time taken:  0.004547595977783203
# solving Ax = b time taken:  0.007848739624023438
# epoch:  12	assembling the mass matrix time taken:  0.004608154296875
# solving Ax = b time taken:  0.0083465576171875
# epoch:  13	assembling the mass matrix time taken:  0.004799842834472656
# solving Ax = b time taken:  0.008754968643188477
# epoch:  14	assembling the mass matrix time taken:  0.016378402709960938
# solving Ax = b time taken:  0.009170293807983398
# epoch:  15	assembling the mass matrix time taken:  0.016936302185058594
# solving Ax = b time taken:  0.009623050689697266
# epoch:  16	assembling the mass matrix time taken:  0.01592278480529785
# solving Ax = b time taken:  0.010138273239135742
# epoch:  17	assembling the mass matrix time taken:  0.016989707946777344
# solving Ax = b time taken:  0.010416030883789062
# epoch:  18	assembling the mass matrix time taken:  0.004636526107788086
# solving Ax = b time taken:  0.011197090148925781
# epoch:  19	assembling the mass matrix time taken:  0.017130374908447266
# solving Ax = b time taken:  0.011754035949707031
# epoch:  20	assembling the mass matrix time taken:  0.004588127136230469
# solving Ax = b time taken:  0.012260675430297852
# epoch:  21	assembling the mass matrix time taken:  0.016098737716674805
# solving Ax = b time taken:  0.01287984848022461
# epoch:  22	assembling the mass matrix time taken:  0.004617929458618164
# solving Ax = b time taken:  0.013405323028564453
# epoch:  23	assembling the mass matrix time taken:  0.004854679107666016
# solving Ax = b time taken:  0.013663291931152344
# epoch:  24	assembling the mass matrix time taken:  0.017060041427612305
# solving Ax = b time taken:  0.014112472534179688
# epoch:  25	assembling the mass matrix time taken:  0.004218101501464844
# solving Ax = b time taken:  0.014958381652832031
# epoch:  26	assembling the mass matrix time taken:  0.016486644744873047
# solving Ax = b time taken:  0.01500701904296875
# epoch:  27	assembling the mass matrix time taken:  0.016696929931640625
# solving Ax = b time taken:  0.0161440372467041
# epoch:  28	assembling the mass matrix time taken:  0.017014265060424805
# solving Ax = b time taken:  0.016065597534179688
# epoch:  29	assembling the mass matrix time taken:  0.004205465316772461
# solving Ax = b time taken:  0.017017841339111328
# epoch:  30	assembling the mass matrix time taken:  0.004396915435791016
# solving Ax = b time taken:  0.0174560546875
# epoch:  31	assembling the mass matrix time taken:  0.016220808029174805
# solving Ax = b time taken:  0.018198251724243164
# epoch:  32	assembling the mass matrix time taken:  0.0047359466552734375
# solving Ax = b time taken:  0.018030881881713867
# epoch:  33	assembling the mass matrix time taken:  0.004239082336425781
# solving Ax = b time taken:  0.01978588104248047
# epoch:  34	assembling the mass matrix time taken:  0.016987085342407227
# solving Ax = b time taken:  0.019803524017333984
# epoch:  35	assembling the mass matrix time taken:  0.004285573959350586
# solving Ax = b time taken:  0.021037578582763672
# epoch:  36	assembling the mass matrix time taken:  0.004420042037963867
# solving Ax = b time taken:  0.02111220359802246
# epoch:  37	assembling the mass matrix time taken:  0.016500234603881836
# solving Ax = b time taken:  0.02174067497253418
# epoch:  38	assembling the mass matrix time taken:  0.0042688846588134766
# solving Ax = b time taken:  0.022249937057495117
# epoch:  39	assembling the mass matrix time taken:  0.016487836837768555
# solving Ax = b time taken:  0.0226593017578125
# epoch:  40	assembling the mass matrix time taken:  0.00417327880859375
# solving Ax = b time taken:  0.023181676864624023
# epoch:  41	assembling the mass matrix time taken:  0.004259347915649414
# solving Ax = b time taken:  0.02389979362487793
# epoch:  42	assembling the mass matrix time taken:  0.004662275314331055
# solving Ax = b time taken:  0.023855924606323242
# epoch:  43	assembling the mass matrix time taken:  0.01726078987121582
# solving Ax = b time taken:  0.024783849716186523
# epoch:  44	assembling the mass matrix time taken:  0.01648736000061035
# solving Ax = b time taken:  0.025171995162963867
# epoch:  45	assembling the mass matrix time taken:  0.016495943069458008
# solving Ax = b time taken:  0.026041269302368164
# epoch:  46	assembling the mass matrix time taken:  0.0044782161712646484
# solving Ax = b time taken:  0.025999784469604492
# epoch:  47	assembling the mass matrix time taken:  0.01658010482788086
# solving Ax = b time taken:  0.030692100524902344
# epoch:  48	assembling the mass matrix time taken:  0.016550540924072266
# solving Ax = b time taken:  0.0309445858001709
# epoch:  49	assembling the mass matrix time taken:  0.0040781497955322266
# solving Ax = b time taken:  0.031899452209472656
# epoch:  50	assembling the mass matrix time taken:  0.004206180572509766
# solving Ax = b time taken:  0.03226041793823242
# epoch:  51	assembling the mass matrix time taken:  0.004251003265380859
# solving Ax = b time taken:  0.033139944076538086
# epoch:  52	assembling the mass matrix time taken:  0.017410755157470703
# solving Ax = b time taken:  0.032691001892089844
# epoch:  53	assembling the mass matrix time taken:  0.016489505767822266
# solving Ax = b time taken:  0.03421449661254883
# epoch:  54	assembling the mass matrix time taken:  0.01637744903564453
# solving Ax = b time taken:  0.03455686569213867
# epoch:  55	assembling the mass matrix time taken:  0.004186391830444336
# solving Ax = b time taken:  0.03520703315734863
# epoch:  56	assembling the mass matrix time taken:  0.0040552616119384766
# solving Ax = b time taken:  0.035068511962890625
# epoch:  57	assembling the mass matrix time taken:  0.016694068908691406
# solving Ax = b time taken:  0.036132097244262695
# epoch:  58	assembling the mass matrix time taken:  0.0040395259857177734
# solving Ax = b time taken:  0.036498308181762695
# epoch:  59	assembling the mass matrix time taken:  0.016703367233276367
# solving Ax = b time taken:  0.03720545768737793
# epoch:  60	assembling the mass matrix time taken:  0.016955137252807617
# solving Ax = b time taken:  0.03673362731933594
# epoch:  61	assembling the mass matrix time taken:  0.016631126403808594
# solving Ax = b time taken:  0.037972450256347656
# epoch:  62	assembling the mass matrix time taken:  0.016270875930786133
# solving Ax = b time taken:  0.038716793060302734
# epoch:  63	assembling the mass matrix time taken:  0.017018795013427734
# solving Ax = b time taken:  0.039353132247924805
# epoch:  64	assembling the mass matrix time taken:  0.016533374786376953
# solving Ax = b time taken:  0.039151668548583984
# epoch:  65	assembling the mass matrix time taken:  0.004065752029418945
# solving Ax = b time taken:  0.04340934753417969
# epoch:  66	assembling the mass matrix time taken:  0.004446983337402344
# solving Ax = b time taken:  0.04343724250793457
# epoch:  67	assembling the mass matrix time taken:  0.016662120819091797
# solving Ax = b time taken:  0.04465889930725098
# epoch:  68	assembling the mass matrix time taken:  0.016384363174438477
# solving Ax = b time taken:  0.04399561882019043
# epoch:  69	assembling the mass matrix time taken:  0.017197847366333008
# solving Ax = b time taken:  0.045491695404052734
# epoch:  70	assembling the mass matrix time taken:  0.003973484039306641
# solving Ax = b time taken:  0.045923709869384766
# epoch:  71	assembling the mass matrix time taken:  0.004012107849121094
# solving Ax = b time taken:  0.04674124717712402
# epoch:  72	assembling the mass matrix time taken:  0.004068851470947266
# solving Ax = b time taken:  0.0461728572845459
# epoch:  73	assembling the mass matrix time taken:  0.004059553146362305
# solving Ax = b time taken:  0.04766654968261719
# epoch:  74	assembling the mass matrix time taken:  0.004382133483886719
# solving Ax = b time taken:  0.04758954048156738
# epoch:  75	assembling the mass matrix time taken:  0.003870725631713867
# solving Ax = b time taken:  0.04887032508850098
# epoch:  76	assembling the mass matrix time taken:  0.003991365432739258
# solving Ax = b time taken:  0.04823946952819824
# epoch:  77	assembling the mass matrix time taken:  0.016704797744750977
# solving Ax = b time taken:  0.04962348937988281
# epoch:  78	assembling the mass matrix time taken:  0.004563093185424805
# solving Ax = b time taken:  0.049424171447753906
# epoch:  79	assembling the mass matrix time taken:  0.004357576370239258
# solving Ax = b time taken:  0.050527095794677734
# epoch:  80	assembling the mass matrix time taken:  0.003920078277587891
# solving Ax = b time taken:  0.050243377685546875
# epoch:  81	assembling the mass matrix time taken:  0.004022121429443359
# solving Ax = b time taken:  0.05307364463806152
# epoch:  82	assembling the mass matrix time taken:  0.0042078495025634766
# solving Ax = b time taken:  0.05326271057128906
# epoch:  83	assembling the mass matrix time taken:  0.003952503204345703
# solving Ax = b time taken:  0.05448126792907715
# epoch:  84	assembling the mass matrix time taken:  0.003911495208740234
# solving Ax = b time taken:  0.053911447525024414
# epoch:  85	assembling the mass matrix time taken:  0.004045963287353516
# solving Ax = b time taken:  0.05527782440185547
# epoch:  86	assembling the mass matrix time taken:  0.004026889801025391
# solving Ax = b time taken:  0.0554656982421875
# epoch:  87	assembling the mass matrix time taken:  0.0039157867431640625
# solving Ax = b time taken:  0.056535959243774414
# epoch:  88	assembling the mass matrix time taken:  0.00393223762512207
# solving Ax = b time taken:  0.05585932731628418
# epoch:  89	assembling the mass matrix time taken:  0.00402522087097168
# solving Ax = b time taken:  0.057158470153808594
# epoch:  90	assembling the mass matrix time taken:  0.004027605056762695
# solving Ax = b time taken:  0.057462215423583984
# epoch:  91	assembling the mass matrix time taken:  0.004186153411865234
# solving Ax = b time taken:  0.05820870399475098
# epoch:  92	assembling the mass matrix time taken:  0.00393986701965332
# solving Ax = b time taken:  0.05785822868347168
# epoch:  93	assembling the mass matrix time taken:  0.00402069091796875
# solving Ax = b time taken:  0.05921816825866699
# epoch:  94	assembling the mass matrix time taken:  0.004032135009765625
# solving Ax = b time taken:  0.05959606170654297
# epoch:  95	assembling the mass matrix time taken:  0.004428863525390625
# solving Ax = b time taken:  0.059874534606933594
# epoch:  96	assembling the mass matrix time taken:  0.003946065902709961
# solving Ax = b time taken:  0.05987739562988281
# epoch:  97	assembling the mass matrix time taken:  0.0040242671966552734
# solving Ax = b time taken:  0.05999112129211426
# epoch:  98	assembling the mass matrix time taken:  0.004012584686279297
# solving Ax = b time taken:  0.06019234657287598
# epoch:  99	assembling the mass matrix time taken:  0.004452228546142578
# solving Ax = b time taken:  0.060764312744140625
# epoch:  100	assembling the mass matrix time taken:  0.0039212703704833984
# solving Ax = b time taken:  0.06059575080871582
# epoch:  101	assembling the mass matrix time taken:  0.0039975643157958984
# solving Ax = b time taken:  0.062129974365234375
# epoch:  102	assembling the mass matrix time taken:  0.003998517990112305
# solving Ax = b time taken:  0.06226706504821777
# epoch:  103	assembling the mass matrix time taken:  0.004338741302490234
# solving Ax = b time taken:  0.06289935111999512
# epoch:  104	assembling the mass matrix time taken:  0.0043299198150634766
# solving Ax = b time taken:  0.062328338623046875
# epoch:  105	assembling the mass matrix time taken:  0.004151582717895508
# solving Ax = b time taken:  0.06401658058166504
# epoch:  106	assembling the mass matrix time taken:  0.00395512580871582
# solving Ax = b time taken:  0.06457662582397461
# epoch:  107	assembling the mass matrix time taken:  0.004342555999755859
# solving Ax = b time taken:  0.06508326530456543
# epoch:  108	assembling the mass matrix time taken:  0.0038721561431884766
# solving Ax = b time taken:  0.06474709510803223
# epoch:  109	assembling the mass matrix time taken:  0.003962993621826172
# solving Ax = b time taken:  0.0663309097290039
# epoch:  110	assembling the mass matrix time taken:  0.004009723663330078
# solving Ax = b time taken:  0.06651020050048828
# epoch:  111	assembling the mass matrix time taken:  0.004392147064208984
# solving Ax = b time taken:  0.06716585159301758
# epoch:  112	assembling the mass matrix time taken:  0.0038645267486572266
# solving Ax = b time taken:  0.0668337345123291
# epoch:  113	assembling the mass matrix time taken:  0.004018068313598633
# solving Ax = b time taken:  0.06846284866333008
# epoch:  114	assembling the mass matrix time taken:  0.003987789154052734
# solving Ax = b time taken:  0.06826996803283691
# epoch:  115	assembling the mass matrix time taken:  0.0038979053497314453
# solving Ax = b time taken:  0.07049822807312012
# epoch:  116	assembling the mass matrix time taken:  0.004285335540771484
# solving Ax = b time taken:  0.06886029243469238
# epoch:  117	assembling the mass matrix time taken:  0.003988742828369141
# solving Ax = b time taken:  0.07121133804321289
# epoch:  118	assembling the mass matrix time taken:  0.003999471664428711
# solving Ax = b time taken:  0.07103085517883301
# epoch:  119	assembling the mass matrix time taken:  0.003898143768310547
# solving Ax = b time taken:  0.07256507873535156
# epoch:  120	assembling the mass matrix time taken:  0.004290342330932617
# solving Ax = b time taken:  0.0710453987121582
# epoch:  121	assembling the mass matrix time taken:  0.0039517879486083984
# solving Ax = b time taken:  0.07319378852844238
# epoch:  122	assembling the mass matrix time taken:  0.003988981246948242
# solving Ax = b time taken:  0.07352995872497559
# epoch:  123	assembling the mass matrix time taken:  0.0043468475341796875
# solving Ax = b time taken:  0.07392621040344238
# epoch:  124	assembling the mass matrix time taken:  0.0038399696350097656
# solving Ax = b time taken:  0.07352948188781738
# epoch:  125	assembling the mass matrix time taken:  0.003968477249145508
# solving Ax = b time taken:  0.07544183731079102
# epoch:  126	assembling the mass matrix time taken:  0.003964662551879883
# solving Ax = b time taken:  0.07552027702331543
# epoch:  127	assembling the mass matrix time taken:  0.00386810302734375
# solving Ax = b time taken:  0.07669687271118164
# epoch:  128	assembling the mass matrix time taken:  0.003900289535522461
# solving Ax = b time taken:  0.07560086250305176
# epoch:  129	assembling the mass matrix time taken:  0.0048329830169677734
# solving Ax = b time taken:  0.09116935729980469
# epoch:  130	assembling the mass matrix time taken:  0.0046291351318359375
# solving Ax = b time taken:  0.09150218963623047
# epoch:  131	assembling the mass matrix time taken:  0.004080057144165039
# solving Ax = b time taken:  0.09327316284179688
# epoch:  132	assembling the mass matrix time taken:  0.0041046142578125
# solving Ax = b time taken:  0.09161186218261719
# epoch:  133	assembling the mass matrix time taken:  0.004633426666259766
# solving Ax = b time taken:  0.09341907501220703
# epoch:  134	assembling the mass matrix time taken:  0.004715442657470703
# solving Ax = b time taken:  0.09346985816955566
# epoch:  135	assembling the mass matrix time taken:  0.0040721893310546875
# solving Ax = b time taken:  0.09535551071166992
# epoch:  136	assembling the mass matrix time taken:  0.004265546798706055
# solving Ax = b time taken:  0.09330391883850098
# epoch:  137	assembling the mass matrix time taken:  0.004236459732055664
# solving Ax = b time taken:  0.09601402282714844
# epoch:  138	assembling the mass matrix time taken:  0.004198551177978516
# solving Ax = b time taken:  0.09595489501953125
# epoch:  139	assembling the mass matrix time taken:  0.004119873046875
# solving Ax = b time taken:  0.09740328788757324
# epoch:  140	assembling the mass matrix time taken:  0.00420069694519043
# solving Ax = b time taken:  0.09571146965026855
# epoch:  141	assembling the mass matrix time taken:  0.0042095184326171875
# solving Ax = b time taken:  0.09818696975708008
# epoch:  142	assembling the mass matrix time taken:  0.004068613052368164
# solving Ax = b time taken:  0.09814190864562988
# epoch:  143	assembling the mass matrix time taken:  0.0041959285736083984
# solving Ax = b time taken:  0.09940052032470703
# epoch:  144	assembling the mass matrix time taken:  0.004589080810546875
# solving Ax = b time taken:  0.09694528579711914
# epoch:  145	assembling the mass matrix time taken:  0.004512786865234375
# solving Ax = b time taken:  0.09992790222167969
# epoch:  146	assembling the mass matrix time taken:  0.004059553146362305
# solving Ax = b time taken:  0.1001901626586914
# epoch:  147	assembling the mass matrix time taken:  0.004183053970336914
# solving Ax = b time taken:  0.10156655311584473
# epoch:  148	assembling the mass matrix time taken:  0.004171133041381836
# solving Ax = b time taken:  0.09959936141967773
# epoch:  149	assembling the mass matrix time taken:  0.004128932952880859
# solving Ax = b time taken:  0.10239028930664062
# epoch:  150	assembling the mass matrix time taken:  0.004052639007568359
# solving Ax = b time taken:  0.10236358642578125
# epoch:  151	assembling the mass matrix time taken:  0.0041887760162353516
# solving Ax = b time taken:  0.10375738143920898
# epoch:  152	assembling the mass matrix time taken:  0.004614353179931641
# solving Ax = b time taken:  0.10098695755004883
# epoch:  153	assembling the mass matrix time taken:  0.004031658172607422
# solving Ax = b time taken:  0.10451889038085938
# epoch:  154	assembling the mass matrix time taken:  0.004167079925537109
# solving Ax = b time taken:  0.10418891906738281
# epoch:  155	assembling the mass matrix time taken:  0.004166841506958008
# solving Ax = b time taken:  0.10573506355285645
# epoch:  156	assembling the mass matrix time taken:  0.004048585891723633
# solving Ax = b time taken:  0.10392427444458008
# epoch:  157	assembling the mass matrix time taken:  0.0040476322174072266
# solving Ax = b time taken:  0.1067190170288086
# epoch:  158	assembling the mass matrix time taken:  0.00421452522277832
# solving Ax = b time taken:  0.10634708404541016
# epoch:  159	assembling the mass matrix time taken:  0.004472017288208008
# solving Ax = b time taken:  0.1075282096862793
# epoch:  160	assembling the mass matrix time taken:  0.004480600357055664
# solving Ax = b time taken:  0.10508108139038086
# epoch:  161	assembling the mass matrix time taken:  0.004312992095947266
# solving Ax = b time taken:  0.10699582099914551
# epoch:  162	assembling the mass matrix time taken:  0.0042569637298583984
# solving Ax = b time taken:  0.10713791847229004
# epoch:  163	assembling the mass matrix time taken:  0.004102230072021484
# solving Ax = b time taken:  0.10859036445617676
# epoch:  164	assembling the mass matrix time taken:  0.004258632659912109
# solving Ax = b time taken:  0.10662317276000977
# epoch:  165	assembling the mass matrix time taken:  0.004679441452026367
# solving Ax = b time taken:  0.10880446434020996
# epoch:  166	assembling the mass matrix time taken:  0.004662275314331055
# solving Ax = b time taken:  0.10880756378173828
# epoch:  167	assembling the mass matrix time taken:  0.004122734069824219
# solving Ax = b time taken:  0.11078143119812012
# epoch:  168	assembling the mass matrix time taken:  0.004266500473022461
# solving Ax = b time taken:  0.10845494270324707
# epoch:  169	assembling the mass matrix time taken:  0.004241228103637695
# solving Ax = b time taken:  0.11167526245117188
# epoch:  170	assembling the mass matrix time taken:  0.0040972232818603516
# solving Ax = b time taken:  0.11126923561096191
# epoch:  171	assembling the mass matrix time taken:  0.004694223403930664
# solving Ax = b time taken:  0.11230301856994629
# epoch:  172	assembling the mass matrix time taken:  0.004243612289428711
# solving Ax = b time taken:  0.11071324348449707
# epoch:  173	assembling the mass matrix time taken:  0.004151821136474609
# solving Ax = b time taken:  0.11323261260986328
# epoch:  174	assembling the mass matrix time taken:  0.004087209701538086
# solving Ax = b time taken:  0.11311841011047363
# epoch:  175	assembling the mass matrix time taken:  0.004312992095947266
# solving Ax = b time taken:  0.1146855354309082
# epoch:  176	assembling the mass matrix time taken:  0.004571676254272461
# solving Ax = b time taken:  0.11223053932189941
# epoch:  177	assembling the mass matrix time taken:  0.0041294097900390625
# solving Ax = b time taken:  0.11565470695495605
# epoch:  178	assembling the mass matrix time taken:  0.004302501678466797
# solving Ax = b time taken:  0.11513233184814453
# epoch:  179	assembling the mass matrix time taken:  0.004286289215087891
# solving Ax = b time taken:  0.1167294979095459
# epoch:  180	assembling the mass matrix time taken:  0.004129886627197266
# solving Ax = b time taken:  0.11492586135864258
# epoch:  181	assembling the mass matrix time taken:  0.004228353500366211
# solving Ax = b time taken:  0.11764287948608398
# epoch:  182	assembling the mass matrix time taken:  0.004204273223876953
# solving Ax = b time taken:  0.11705970764160156
# epoch:  183	assembling the mass matrix time taken:  0.004052877426147461
# solving Ax = b time taken:  0.1188359260559082
# epoch:  184	assembling the mass matrix time taken:  0.0040585994720458984
# solving Ax = b time taken:  0.11653614044189453
# epoch:  185	assembling the mass matrix time taken:  0.00422215461730957
# solving Ax = b time taken:  0.11956930160522461
# epoch:  186	assembling the mass matrix time taken:  0.004723548889160156
# solving Ax = b time taken:  0.1189119815826416
# epoch:  187	assembling the mass matrix time taken:  0.004097700119018555
# solving Ax = b time taken:  0.12104105949401855
# epoch:  188	assembling the mass matrix time taken:  0.004470109939575195
# solving Ax = b time taken:  0.11843991279602051
# epoch:  189	assembling the mass matrix time taken:  0.004239797592163086
# solving Ax = b time taken:  0.12158703804016113
# epoch:  190	assembling the mass matrix time taken:  0.0045049190521240234
# solving Ax = b time taken:  0.12092304229736328
# epoch:  191	assembling the mass matrix time taken:  0.004254579544067383
# solving Ax = b time taken:  0.12242794036865234
# epoch:  192	assembling the mass matrix time taken:  0.004229068756103516
# solving Ax = b time taken:  0.12040042877197266
# epoch:  193	assembling the mass matrix time taken:  0.004207611083984375
# solving Ax = b time taken:  0.14104461669921875
# epoch:  194	assembling the mass matrix time taken:  0.004207611083984375
# solving Ax = b time taken:  0.14084672927856445
# epoch:  195	assembling the mass matrix time taken:  0.00434565544128418
# solving Ax = b time taken:  0.14272379875183105
# epoch:  196	assembling the mass matrix time taken:  0.004625082015991211
# solving Ax = b time taken:  0.13991713523864746
# epoch:  197	assembling the mass matrix time taken:  0.004201412200927734
# solving Ax = b time taken:  0.143418550491333
# epoch:  198	assembling the mass matrix time taken:  0.0043392181396484375
# solving Ax = b time taken:  0.14284181594848633
# epoch:  199	assembling the mass matrix time taken:  0.0047833919525146484
# solving Ax = b time taken:  0.1443636417388916
# epoch:  200	assembling the mass matrix time taken:  0.004164457321166992
# solving Ax = b time taken:  0.14159607887268066
# epoch:  201	assembling the mass matrix time taken:  0.004454374313354492
# solving Ax = b time taken:  0.14525175094604492
# epoch:  202	assembling the mass matrix time taken:  0.0044209957122802734
# solving Ax = b time taken:  0.14515066146850586
# epoch:  203	assembling the mass matrix time taken:  0.00420689582824707
# solving Ax = b time taken:  0.14708185195922852
# epoch:  204	assembling the mass matrix time taken:  0.004339933395385742
# solving Ax = b time taken:  0.14437532424926758
# epoch:  205	assembling the mass matrix time taken:  0.0047414302825927734
# solving Ax = b time taken:  0.146925687789917
# epoch:  206	assembling the mass matrix time taken:  0.004480838775634766
# solving Ax = b time taken:  0.14694786071777344
# epoch:  207	assembling the mass matrix time taken:  0.0041751861572265625
# solving Ax = b time taken:  0.14916753768920898
# epoch:  208	assembling the mass matrix time taken:  0.00432276725769043
# solving Ax = b time taken:  0.14623332023620605
# epoch:  209	assembling the mass matrix time taken:  0.004223823547363281
# solving Ax = b time taken:  0.1498725414276123
# epoch:  210	assembling the mass matrix time taken:  0.004227876663208008
# solving Ax = b time taken:  0.14933490753173828
# epoch:  211	assembling the mass matrix time taken:  0.0043103694915771484
# solving Ax = b time taken:  0.15113282203674316
# epoch:  212	assembling the mass matrix time taken:  0.00477147102355957
# solving Ax = b time taken:  0.1477680206298828
# epoch:  213	assembling the mass matrix time taken:  0.004166841506958008
# solving Ax = b time taken:  0.15163493156433105
# epoch:  214	assembling the mass matrix time taken:  0.004338502883911133
# solving Ax = b time taken:  0.15102195739746094
# epoch:  215	assembling the mass matrix time taken:  0.004727602005004883
# solving Ax = b time taken:  0.15266752243041992
# epoch:  216	assembling the mass matrix time taken:  0.004263162612915039
# solving Ax = b time taken:  0.15009546279907227
# epoch:  217	assembling the mass matrix time taken:  0.004349470138549805
# solving Ax = b time taken:  0.1536397933959961
# epoch:  218	assembling the mass matrix time taken:  0.004722118377685547
# solving Ax = b time taken:  0.152756929397583
# epoch:  219	assembling the mass matrix time taken:  0.004752159118652344
# solving Ax = b time taken:  0.15462613105773926
# epoch:  220	assembling the mass matrix time taken:  0.004312038421630859
# solving Ax = b time taken:  0.15237736701965332
# epoch:  221	assembling the mass matrix time taken:  0.004733085632324219
# solving Ax = b time taken:  0.15514087677001953
# epoch:  222	assembling the mass matrix time taken:  0.0046231746673583984
# solving Ax = b time taken:  0.15478968620300293
# epoch:  223	assembling the mass matrix time taken:  0.0044252872467041016
# solving Ax = b time taken:  0.157073974609375
# epoch:  224	assembling the mass matrix time taken:  0.004625558853149414
# solving Ax = b time taken:  0.15373849868774414
# epoch:  225	assembling the mass matrix time taken:  0.0041980743408203125
# solving Ax = b time taken:  0.15766668319702148
# epoch:  226	assembling the mass matrix time taken:  0.004354238510131836
# solving Ax = b time taken:  0.15784955024719238
# epoch:  227	assembling the mass matrix time taken:  0.0048770904541015625
# solving Ax = b time taken:  0.15897226333618164
# epoch:  228	assembling the mass matrix time taken:  0.004195451736450195
# solving Ax = b time taken:  0.15652680397033691
# epoch:  229	assembling the mass matrix time taken:  0.004340171813964844
# solving Ax = b time taken:  0.1604163646697998
# epoch:  230	assembling the mass matrix time taken:  0.0047397613525390625
# solving Ax = b time taken:  0.15948200225830078
# epoch:  231	assembling the mass matrix time taken:  0.004235029220581055
# solving Ax = b time taken:  0.16163134574890137
# epoch:  232	assembling the mass matrix time taken:  0.004346609115600586
# solving Ax = b time taken:  0.15815496444702148
# epoch:  233	assembling the mass matrix time taken:  0.0047245025634765625
# solving Ax = b time taken:  0.16147685050964355
# epoch:  234	assembling the mass matrix time taken:  0.004389524459838867
# solving Ax = b time taken:  0.16149187088012695
# epoch:  235	assembling the mass matrix time taken:  0.004436492919921875
# solving Ax = b time taken:  0.16351032257080078
# epoch:  236	assembling the mass matrix time taken:  0.004737377166748047
# solving Ax = b time taken:  0.16001534461975098
# epoch:  237	assembling the mass matrix time taken:  0.004183530807495117
# solving Ax = b time taken:  0.16402244567871094
# epoch:  238	assembling the mass matrix time taken:  0.00433039665222168
# solving Ax = b time taken:  0.16332149505615234
# epoch:  239	assembling the mass matrix time taken:  0.004631996154785156
# solving Ax = b time taken:  0.16509175300598145
# epoch:  240	assembling the mass matrix time taken:  0.004346132278442383
# solving Ax = b time taken:  0.16219735145568848
# epoch:  241	assembling the mass matrix time taken:  0.004233360290527344
# solving Ax = b time taken:  0.1661219596862793
# epoch:  242	assembling the mass matrix time taken:  0.004641532897949219
# solving Ax = b time taken:  0.16543245315551758
# epoch:  243	assembling the mass matrix time taken:  0.00409245491027832
# solving Ax = b time taken:  0.16759824752807617
# epoch:  244	assembling the mass matrix time taken:  0.004251003265380859
# solving Ax = b time taken:  0.1643671989440918
# epoch:  245	assembling the mass matrix time taken:  0.004557609558105469
# solving Ax = b time taken:  0.16750478744506836
# epoch:  246	assembling the mass matrix time taken:  0.004090309143066406
# solving Ax = b time taken:  0.16754865646362305
# epoch:  247	assembling the mass matrix time taken:  0.004256486892700195
# solving Ax = b time taken:  0.16940760612487793
# epoch:  248	assembling the mass matrix time taken:  0.0045168399810791016
# solving Ax = b time taken:  0.1658153533935547
# epoch:  249	assembling the mass matrix time taken:  0.004087924957275391
# solving Ax = b time taken:  0.17023563385009766
# epoch:  250	assembling the mass matrix time taken:  0.0041446685791015625
# solving Ax = b time taken:  0.16938209533691406
# epoch:  251	assembling the mass matrix time taken:  0.004692792892456055
# solving Ax = b time taken:  0.17090654373168945
# epoch:  252	assembling the mass matrix time taken:  0.004728555679321289
# solving Ax = b time taken:  0.16794347763061523
# epoch:  253	assembling the mass matrix time taken:  0.004099369049072266
# solving Ax = b time taken:  0.1721038818359375
# epoch:  254	assembling the mass matrix time taken:  0.004136800765991211
# solving Ax = b time taken:  0.17126226425170898
# epoch:  255	assembling the mass matrix time taken:  0.0042650699615478516
# solving Ax = b time taken:  0.17337608337402344
# epoch:  256	assembling the mass matrix time taken:  0.004097938537597656
# solving Ax = b time taken:  0.1701033115386963
# epoch:  257	assembling the mass matrix time taken:  0.0043103694915771484
# solving Ax = b time taken:  0.21309351921081543
# epoch:  258	assembling the mass matrix time taken:  0.0043141841888427734
# solving Ax = b time taken:  0.21261000633239746
# epoch:  259	assembling the mass matrix time taken:  0.0041658878326416016
# solving Ax = b time taken:  0.2147350311279297
# epoch:  260	assembling the mass matrix time taken:  0.004310131072998047
# solving Ax = b time taken:  0.2108316421508789
# epoch:  261	assembling the mass matrix time taken:  0.004583120346069336
# solving Ax = b time taken:  0.21504569053649902
# epoch:  262	assembling the mass matrix time taken:  0.004167318344116211
# solving Ax = b time taken:  0.215501070022583
# epoch:  263	assembling the mass matrix time taken:  0.0043182373046875
# solving Ax = b time taken:  0.21709561347961426
# epoch:  264	assembling the mass matrix time taken:  0.004587411880493164
# solving Ax = b time taken:  0.21208834648132324
# epoch:  265	assembling the mass matrix time taken:  0.00432586669921875
# solving Ax = b time taken:  0.2181708812713623
# epoch:  266	assembling the mass matrix time taken:  0.004317522048950195
# solving Ax = b time taken:  0.21672868728637695
# epoch:  267	assembling the mass matrix time taken:  0.004225254058837891
# solving Ax = b time taken:  0.21954107284545898
# epoch:  268	assembling the mass matrix time taken:  0.004741191864013672
# solving Ax = b time taken:  0.21487712860107422
# epoch:  269	assembling the mass matrix time taken:  0.0046215057373046875
# solving Ax = b time taken:  0.21954083442687988
# epoch:  270	assembling the mass matrix time taken:  0.004137516021728516
# solving Ax = b time taken:  0.21964740753173828
# epoch:  271	assembling the mass matrix time taken:  0.004334926605224609
# solving Ax = b time taken:  0.22164416313171387
# epoch:  272	assembling the mass matrix time taken:  0.0046138763427734375
# solving Ax = b time taken:  0.2160027027130127
# epoch:  273	assembling the mass matrix time taken:  0.004160642623901367
# solving Ax = b time taken:  0.2226567268371582
# epoch:  274	assembling the mass matrix time taken:  0.00426936149597168
# solving Ax = b time taken:  0.2219843864440918
# epoch:  275	assembling the mass matrix time taken:  0.004351377487182617
# solving Ax = b time taken:  0.22396039962768555
# epoch:  276	assembling the mass matrix time taken:  0.004663705825805664
# solving Ax = b time taken:  0.21888947486877441
# epoch:  277	assembling the mass matrix time taken:  0.004330158233642578
# solving Ax = b time taken:  0.2248990535736084
# epoch:  278	assembling the mass matrix time taken:  0.004145622253417969
# solving Ax = b time taken:  0.22360873222351074
# epoch:  279	assembling the mass matrix time taken:  0.004317283630371094
# solving Ax = b time taken:  0.22619152069091797
# epoch:  280	assembling the mass matrix time taken:  0.0045659542083740234
# solving Ax = b time taken:  0.2211897373199463
# epoch:  281	assembling the mass matrix time taken:  0.004338502883911133
# solving Ax = b time taken:  0.22739243507385254
# epoch:  282	assembling the mass matrix time taken:  0.004306793212890625
# solving Ax = b time taken:  0.22653937339782715
# epoch:  283	assembling the mass matrix time taken:  0.004172801971435547
# solving Ax = b time taken:  0.22860074043273926
# epoch:  284	assembling the mass matrix time taken:  0.004331111907958984
# solving Ax = b time taken:  0.22425150871276855
# epoch:  285	assembling the mass matrix time taken:  0.00461125373840332
# solving Ax = b time taken:  0.22976350784301758
# epoch:  286	assembling the mass matrix time taken:  0.004134178161621094
# solving Ax = b time taken:  0.22912859916687012
# epoch:  287	assembling the mass matrix time taken:  0.0044405460357666016
# solving Ax = b time taken:  0.23129701614379883
# epoch:  288	assembling the mass matrix time taken:  0.004164695739746094
# solving Ax = b time taken:  0.2254045009613037
# epoch:  289	assembling the mass matrix time taken:  0.004420757293701172
# solving Ax = b time taken:  0.22868061065673828
# epoch:  290	assembling the mass matrix time taken:  0.004420757293701172
# solving Ax = b time taken:  0.22911763191223145
# epoch:  291	assembling the mass matrix time taken:  0.004285335540771484
# solving Ax = b time taken:  0.23088836669921875
# epoch:  292	assembling the mass matrix time taken:  0.004866838455200195
# solving Ax = b time taken:  0.22571444511413574
# epoch:  293	assembling the mass matrix time taken:  0.004305362701416016
# solving Ax = b time taken:  0.23241043090820312
# epoch:  294	assembling the mass matrix time taken:  0.004431486129760742
# solving Ax = b time taken:  0.23079824447631836
# epoch:  295	assembling the mass matrix time taken:  0.004427433013916016
# solving Ax = b time taken:  0.23356199264526367
# epoch:  296	assembling the mass matrix time taken:  0.004739046096801758
# solving Ax = b time taken:  0.22786808013916016
# epoch:  297	assembling the mass matrix time taken:  0.004484415054321289
# solving Ax = b time taken:  0.23429203033447266
# epoch:  298	assembling the mass matrix time taken:  0.0047969818115234375
# solving Ax = b time taken:  0.23221373558044434
# epoch:  299	assembling the mass matrix time taken:  0.004446983337402344
# solving Ax = b time taken:  0.23444414138793945
# epoch:  300	assembling the mass matrix time taken:  0.004869699478149414
# solving Ax = b time taken:  0.2295384407043457
# epoch:  301	assembling the mass matrix time taken:  0.0043163299560546875
# solving Ax = b time taken:  0.2353076934814453
# epoch:  302	assembling the mass matrix time taken:  0.0044591426849365234
# solving Ax = b time taken:  0.2341017723083496
# epoch:  303	assembling the mass matrix time taken:  0.0048236846923828125
# solving Ax = b time taken:  0.23611950874328613
# epoch:  304	assembling the mass matrix time taken:  0.004761457443237305
# solving Ax = b time taken:  0.23184895515441895
# epoch:  305	assembling the mass matrix time taken:  0.0044460296630859375
# solving Ax = b time taken:  0.2374880313873291
# epoch:  306	assembling the mass matrix time taken:  0.0042934417724609375
# solving Ax = b time taken:  0.23682832717895508
# epoch:  307	assembling the mass matrix time taken:  0.0044651031494140625
# solving Ax = b time taken:  0.2384941577911377
# epoch:  308	assembling the mass matrix time taken:  0.00475001335144043
# solving Ax = b time taken:  0.2334461212158203
# epoch:  309	assembling the mass matrix time taken:  0.004459857940673828
# solving Ax = b time taken:  0.23903870582580566
# epoch:  310	assembling the mass matrix time taken:  0.004999399185180664
# solving Ax = b time taken:  0.23816490173339844
# epoch:  311	assembling the mass matrix time taken:  0.004310131072998047
# solving Ax = b time taken:  0.24091434478759766
# epoch:  312	assembling the mass matrix time taken:  0.004488229751586914
# solving Ax = b time taken:  0.2358553409576416
# epoch:  313	assembling the mass matrix time taken:  0.004776477813720703
# solving Ax = b time taken:  0.24072504043579102
# epoch:  314	assembling the mass matrix time taken:  0.004732370376586914
# solving Ax = b time taken:  0.24022793769836426
# epoch:  315	assembling the mass matrix time taken:  0.005295753479003906
# solving Ax = b time taken:  0.24260997772216797
# epoch:  316	assembling the mass matrix time taken:  0.0042955875396728516
# solving Ax = b time taken:  0.2388608455657959
# epoch:  317	assembling the mass matrix time taken:  0.004399776458740234
# solving Ax = b time taken:  0.2433161735534668
# epoch:  318	assembling the mass matrix time taken:  0.004743814468383789
# solving Ax = b time taken:  0.24173498153686523
# epoch:  319	assembling the mass matrix time taken:  0.004245758056640625
# solving Ax = b time taken:  0.24558281898498535
# epoch:  320	assembling the mass matrix time taken:  0.004426002502441406
# solving Ax = b time taken:  0.23949170112609863
# epoch:  321	assembling the mass matrix time taken:  0.004149436950683594
# solving Ax = b time taken:  0.26009154319763184
# epoch:  322	assembling the mass matrix time taken:  0.004288196563720703
# solving Ax = b time taken:  0.2593193054199219
# epoch:  323	assembling the mass matrix time taken:  0.004998207092285156
# solving Ax = b time taken:  0.2627253532409668
# epoch:  324	assembling the mass matrix time taken:  0.004170894622802734
# solving Ax = b time taken:  0.2582085132598877
# epoch:  325	assembling the mass matrix time taken:  0.004735231399536133
# solving Ax = b time taken:  0.2621488571166992
# epoch:  326	assembling the mass matrix time taken:  0.004176616668701172
# solving Ax = b time taken:  0.26267170906066895
# epoch:  327	assembling the mass matrix time taken:  0.0047817230224609375
# solving Ax = b time taken:  0.2642059326171875
# epoch:  328	assembling the mass matrix time taken:  0.004157304763793945
# solving Ax = b time taken:  0.2593419551849365
# epoch:  329	assembling the mass matrix time taken:  0.004306316375732422
# solving Ax = b time taken:  0.2648169994354248
# epoch:  330	assembling the mass matrix time taken:  0.004316091537475586
# solving Ax = b time taken:  0.2643120288848877
# epoch:  331	assembling the mass matrix time taken:  0.004355192184448242
# solving Ax = b time taken:  0.2668008804321289
# epoch:  332	assembling the mass matrix time taken:  0.004296779632568359
# solving Ax = b time taken:  0.26219987869262695
# epoch:  333	assembling the mass matrix time taken:  0.004168510437011719
# solving Ax = b time taken:  0.2671215534210205
# epoch:  334	assembling the mass matrix time taken:  0.0043370723724365234
# solving Ax = b time taken:  0.26730823516845703
# epoch:  335	assembling the mass matrix time taken:  0.005105733871459961
# solving Ax = b time taken:  0.2687840461730957
# epoch:  336	assembling the mass matrix time taken:  0.004118919372558594
# solving Ax = b time taken:  0.2644383907318115
# epoch:  337	assembling the mass matrix time taken:  0.00433349609375
# solving Ax = b time taken:  0.27051448822021484
# epoch:  338	assembling the mass matrix time taken:  0.00419926643371582
# solving Ax = b time taken:  0.26934337615966797
# epoch:  339	assembling the mass matrix time taken:  0.004308938980102539
# solving Ax = b time taken:  0.27185773849487305
# epoch:  340	assembling the mass matrix time taken:  0.004661083221435547
# solving Ax = b time taken:  0.26633763313293457
# epoch:  341	assembling the mass matrix time taken:  0.0041577816009521484
# solving Ax = b time taken:  0.27199411392211914
# epoch:  342	assembling the mass matrix time taken:  0.0043294429779052734
# solving Ax = b time taken:  0.270862340927124
# epoch:  343	assembling the mass matrix time taken:  0.004160642623901367
# solving Ax = b time taken:  0.2727689743041992
# epoch:  344	assembling the mass matrix time taken:  0.004322052001953125
# solving Ax = b time taken:  0.26829004287719727
# epoch:  345	assembling the mass matrix time taken:  0.004582881927490234
# solving Ax = b time taken:  0.27337098121643066
# epoch:  346	assembling the mass matrix time taken:  0.005033016204833984
# solving Ax = b time taken:  0.27247166633605957
# epoch:  347	assembling the mass matrix time taken:  0.00492095947265625
# solving Ax = b time taken:  0.27550315856933594
# epoch:  348	assembling the mass matrix time taken:  0.004162311553955078
# solving Ax = b time taken:  0.27152323722839355
# epoch:  349	assembling the mass matrix time taken:  0.004314899444580078
# solving Ax = b time taken:  0.27536749839782715
# epoch:  350	assembling the mass matrix time taken:  0.0041315555572509766
# solving Ax = b time taken:  0.2752573490142822
# epoch:  351	assembling the mass matrix time taken:  0.004317045211791992
# solving Ax = b time taken:  0.2774672508239746
# epoch:  352	assembling the mass matrix time taken:  0.004594087600708008
# solving Ax = b time taken:  0.2724647521972656
# epoch:  353	assembling the mass matrix time taken:  0.0046041011810302734
# solving Ax = b time taken:  0.2759401798248291
# epoch:  354	assembling the mass matrix time taken:  0.0048906803131103516
# solving Ax = b time taken:  0.2747781276702881
# epoch:  355	assembling the mass matrix time taken:  0.004155874252319336
# solving Ax = b time taken:  0.2776827812194824
# epoch:  356	assembling the mass matrix time taken:  0.004797458648681641
# solving Ax = b time taken:  0.27337193489074707
# epoch:  357	assembling the mass matrix time taken:  0.004170656204223633
# solving Ax = b time taken:  0.2783942222595215
# epoch:  358	assembling the mass matrix time taken:  0.004329204559326172
# solving Ax = b time taken:  0.27736449241638184
# epoch:  359	assembling the mass matrix time taken:  0.004609346389770508
# solving Ax = b time taken:  0.27919864654541016
# epoch:  360	assembling the mass matrix time taken:  0.004758596420288086
# solving Ax = b time taken:  0.2745652198791504
# epoch:  361	assembling the mass matrix time taken:  0.004319429397583008
# solving Ax = b time taken:  0.27974939346313477
# epoch:  362	assembling the mass matrix time taken:  0.004135608673095703
# solving Ax = b time taken:  0.27974534034729004
# epoch:  363	assembling the mass matrix time taken:  0.005093574523925781
# solving Ax = b time taken:  0.28175830841064453
# epoch:  364	assembling the mass matrix time taken:  0.004730939865112305
# solving Ax = b time taken:  0.2778487205505371
# epoch:  365	assembling the mass matrix time taken:  0.004827260971069336
# solving Ax = b time taken:  0.2818002700805664
# epoch:  366	assembling the mass matrix time taken:  0.00460052490234375
# solving Ax = b time taken:  0.28138065338134766
# epoch:  367	assembling the mass matrix time taken:  0.004311323165893555
# solving Ax = b time taken:  0.28410887718200684
# epoch:  368	assembling the mass matrix time taken:  0.004348278045654297
# solving Ax = b time taken:  0.27974677085876465
# epoch:  369	assembling the mass matrix time taken:  0.004156351089477539
# solving Ax = b time taken:  0.2847270965576172
# epoch:  370	assembling the mass matrix time taken:  0.004316806793212891
# solving Ax = b time taken:  0.28350281715393066
# epoch:  371	assembling the mass matrix time taken:  0.00417017936706543
# solving Ax = b time taken:  0.28674983978271484
# epoch:  372	assembling the mass matrix time taken:  0.00429534912109375
# solving Ax = b time taken:  0.28227734565734863
# epoch:  373	assembling the mass matrix time taken:  0.004119873046875
# solving Ax = b time taken:  0.2865159511566162
# epoch:  374	assembling the mass matrix time taken:  0.004211902618408203
# solving Ax = b time taken:  0.2858467102050781
# epoch:  375	assembling the mass matrix time taken:  0.004774332046508789
# solving Ax = b time taken:  0.28798818588256836
# epoch:  376	assembling the mass matrix time taken:  0.0041043758392333984
# solving Ax = b time taken:  0.2835531234741211
# epoch:  377	assembling the mass matrix time taken:  0.004240751266479492
# solving Ax = b time taken:  0.2886481285095215
# epoch:  378	assembling the mass matrix time taken:  0.004126071929931641
# solving Ax = b time taken:  0.2877037525177002
# epoch:  379	assembling the mass matrix time taken:  0.004259824752807617
# solving Ax = b time taken:  0.2905704975128174
# epoch:  380	assembling the mass matrix time taken:  0.0041239261627197266
# solving Ax = b time taken:  0.28614163398742676
# epoch:  381	assembling the mass matrix time taken:  0.004253864288330078
# solving Ax = b time taken:  0.2908182144165039
# epoch:  382	assembling the mass matrix time taken:  0.004534244537353516
# solving Ax = b time taken:  0.28949999809265137
# epoch:  383	assembling the mass matrix time taken:  0.0042569637298583984
# solving Ax = b time taken:  0.29280519485473633
# epoch:  384	assembling the mass matrix time taken:  0.004300355911254883
# solving Ax = b time taken:  0.28725147247314453
# epoch:  385	assembling the mass matrix time taken:  0.004502773284912109
# solving Ax = b time taken:  0.3455770015716553
# epoch:  386	assembling the mass matrix time taken:  0.005070686340332031
# solving Ax = b time taken:  0.3465571403503418
# epoch:  387	assembling the mass matrix time taken:  0.004154682159423828
# solving Ax = b time taken:  0.34723591804504395
# epoch:  388	assembling the mass matrix time taken:  0.004282474517822266
# solving Ax = b time taken:  0.34099650382995605
# epoch:  389	assembling the mass matrix time taken:  0.004098653793334961
# solving Ax = b time taken:  0.3484492301940918
# epoch:  390	assembling the mass matrix time taken:  0.004277706146240234
# solving Ax = b time taken:  0.3472914695739746
# epoch:  391	assembling the mass matrix time taken:  0.004151344299316406
# solving Ax = b time taken:  0.34772253036499023
# epoch:  392	assembling the mass matrix time taken:  0.004312753677368164
# solving Ax = b time taken:  0.33868908882141113
# epoch:  393	assembling the mass matrix time taken:  0.0047075748443603516
# solving Ax = b time taken:  0.3512129783630371
# epoch:  394	assembling the mass matrix time taken:  0.005005359649658203
# solving Ax = b time taken:  0.3497476577758789
# epoch:  395	assembling the mass matrix time taken:  0.004578828811645508
# solving Ax = b time taken:  0.35365867614746094
# epoch:  396	assembling the mass matrix time taken:  0.004308462142944336
# solving Ax = b time taken:  0.346116304397583
# epoch:  397	assembling the mass matrix time taken:  0.0042896270751953125
# solving Ax = b time taken:  0.35625672340393066
# epoch:  398	assembling the mass matrix time taken:  0.004567146301269531
# solving Ax = b time taken:  0.34990930557250977
# epoch:  399	assembling the mass matrix time taken:  0.004309892654418945
# solving Ax = b time taken:  0.3535311222076416
# epoch:  400	assembling the mass matrix time taken:  0.00475001335144043
# solving Ax = b time taken:  0.3464381694793701
# epoch:  401	assembling the mass matrix time taken:  0.004135608673095703
# solving Ax = b time taken:  0.3571357727050781
# epoch:  402	assembling the mass matrix time taken:  0.004472494125366211
# solving Ax = b time taken:  0.35326099395751953
# epoch:  403	assembling the mass matrix time taken:  0.00413060188293457
# solving Ax = b time taken:  0.35651373863220215
# epoch:  404	assembling the mass matrix time taken:  0.004303693771362305
# solving Ax = b time taken:  0.35050415992736816
# epoch:  405	assembling the mass matrix time taken:  0.00456547737121582
# solving Ax = b time taken:  0.3610384464263916
# epoch:  406	assembling the mass matrix time taken:  0.0042645931243896484
# solving Ax = b time taken:  0.35692477226257324
# epoch:  407	assembling the mass matrix time taken:  0.004566669464111328
# solving Ax = b time taken:  0.3616464138031006
# epoch:  408	assembling the mass matrix time taken:  0.004370212554931641
# solving Ax = b time taken:  0.3518214225769043
# epoch:  409	assembling the mass matrix time taken:  0.004839897155761719
# solving Ax = b time taken:  0.3615703582763672
# epoch:  410	assembling the mass matrix time taken:  0.004315853118896484
# solving Ax = b time taken:  0.3625960350036621
# epoch:  411	assembling the mass matrix time taken:  0.004294872283935547
# solving Ax = b time taken:  0.3636443614959717
# epoch:  412	assembling the mass matrix time taken:  0.004788637161254883
# solving Ax = b time taken:  0.35537147521972656
# epoch:  413	assembling the mass matrix time taken:  0.004279136657714844
# solving Ax = b time taken:  0.3643829822540283
# epoch:  414	assembling the mass matrix time taken:  0.0045893192291259766
# solving Ax = b time taken:  0.35933637619018555
# epoch:  415	assembling the mass matrix time taken:  0.004262685775756836
# solving Ax = b time taken:  0.36549878120422363
# epoch:  416	assembling the mass matrix time taken:  0.004133939743041992
# solving Ax = b time taken:  0.3526644706726074
# epoch:  417	assembling the mass matrix time taken:  0.004321575164794922
# solving Ax = b time taken:  0.35057830810546875
# epoch:  418	assembling the mass matrix time taken:  0.004132509231567383
# solving Ax = b time taken:  0.34798121452331543
# epoch:  419	assembling the mass matrix time taken:  0.004244089126586914
# solving Ax = b time taken:  0.3521108627319336
# epoch:  420	assembling the mass matrix time taken:  0.004082202911376953
# solving Ax = b time taken:  0.34455108642578125
# epoch:  421	assembling the mass matrix time taken:  0.004805803298950195
# solving Ax = b time taken:  0.35328102111816406
# epoch:  422	assembling the mass matrix time taken:  0.00446319580078125
# solving Ax = b time taken:  0.35043787956237793
# epoch:  423	assembling the mass matrix time taken:  0.004257678985595703
# solving Ax = b time taken:  0.35540127754211426
# epoch:  424	assembling the mass matrix time taken:  0.0040967464447021484
# solving Ax = b time taken:  0.34728360176086426
# epoch:  425	assembling the mass matrix time taken:  0.0042285919189453125
# solving Ax = b time taken:  0.3551959991455078
# epoch:  426	assembling the mass matrix time taken:  0.004071712493896484
# solving Ax = b time taken:  0.35390210151672363
# epoch:  427	assembling the mass matrix time taken:  0.004240512847900391
# solving Ax = b time taken:  0.35655832290649414
# epoch:  428	assembling the mass matrix time taken:  0.004882335662841797
# solving Ax = b time taken:  0.35011792182922363
# epoch:  429	assembling the mass matrix time taken:  0.00423884391784668
# solving Ax = b time taken:  0.3582582473754883
# epoch:  430	assembling the mass matrix time taken:  0.004541635513305664
# solving Ax = b time taken:  0.35534238815307617
# epoch:  431	assembling the mass matrix time taken:  0.004244327545166016
# solving Ax = b time taken:  0.3591136932373047
# epoch:  432	assembling the mass matrix time taken:  0.005186319351196289
# solving Ax = b time taken:  0.3513166904449463
# epoch:  433	assembling the mass matrix time taken:  0.004216670989990234
# solving Ax = b time taken:  0.3592691421508789
# epoch:  434	assembling the mass matrix time taken:  0.004532337188720703
# solving Ax = b time taken:  0.3562934398651123
# epoch:  435	assembling the mass matrix time taken:  0.004270315170288086
# solving Ax = b time taken:  0.36144161224365234
# epoch:  436	assembling the mass matrix time taken:  0.0045130252838134766
# solving Ax = b time taken:  0.3532588481903076
# epoch:  437	assembling the mass matrix time taken:  0.004254817962646484
# solving Ax = b time taken:  0.3609628677368164
# epoch:  438	assembling the mass matrix time taken:  0.004494190216064453
# solving Ax = b time taken:  0.3581688404083252
# epoch:  439	assembling the mass matrix time taken:  0.004202365875244141
# solving Ax = b time taken:  0.36357617378234863
# epoch:  440	assembling the mass matrix time taken:  0.004571437835693359
# solving Ax = b time taken:  0.3575263023376465
# epoch:  441	assembling the mass matrix time taken:  0.004673480987548828
# solving Ax = b time taken:  0.3644697666168213
# epoch:  442	assembling the mass matrix time taken:  0.004262685775756836
# solving Ax = b time taken:  0.36409592628479004
# epoch:  443	assembling the mass matrix time taken:  0.004105806350708008
# solving Ax = b time taken:  0.3655884265899658
# epoch:  444	assembling the mass matrix time taken:  0.00426030158996582
# solving Ax = b time taken:  0.3602638244628906
# epoch:  445	assembling the mass matrix time taken:  0.004125833511352539
# solving Ax = b time taken:  0.36527204513549805
# epoch:  446	assembling the mass matrix time taken:  0.0048220157623291016
# solving Ax = b time taken:  0.36341023445129395
# epoch:  447	assembling the mass matrix time taken:  0.0048274993896484375
# solving Ax = b time taken:  0.3674774169921875
# epoch:  448	assembling the mass matrix time taken:  0.0042498111724853516
# solving Ax = b time taken:  0.35801196098327637
# epoch:  449	assembling the mass matrix time taken:  0.004182100296020508
# solving Ax = b time taken:  0.4018669128417969
# epoch:  450	assembling the mass matrix time taken:  0.004330873489379883
# solving Ax = b time taken:  0.3997068405151367
# epoch:  451	assembling the mass matrix time taken:  0.00417017936706543
# solving Ax = b time taken:  0.403031587600708
# epoch:  452	assembling the mass matrix time taken:  0.004327297210693359
# solving Ax = b time taken:  0.39722228050231934
# epoch:  453	assembling the mass matrix time taken:  0.004116058349609375
# solving Ax = b time taken:  0.40257716178894043
# epoch:  454	assembling the mass matrix time taken:  0.004781246185302734
# solving Ax = b time taken:  0.3994925022125244
# epoch:  455	assembling the mass matrix time taken:  0.004301309585571289
# solving Ax = b time taken:  0.40503501892089844
# epoch:  456	assembling the mass matrix time taken:  0.004572629928588867
# solving Ax = b time taken:  0.3985152244567871
# epoch:  457	assembling the mass matrix time taken:  0.004297494888305664
# solving Ax = b time taken:  0.40475034713745117
# epoch:  458	assembling the mass matrix time taken:  0.004579305648803711
# solving Ax = b time taken:  0.4031410217285156
# epoch:  459	assembling the mass matrix time taken:  0.004322052001953125
# solving Ax = b time taken:  0.4075918197631836
# epoch:  460	assembling the mass matrix time taken:  0.004137516021728516
# solving Ax = b time taken:  0.4007985591888428
# epoch:  461	assembling the mass matrix time taken:  0.004298686981201172
# solving Ax = b time taken:  0.40634799003601074
# epoch:  462	assembling the mass matrix time taken:  0.004154682159423828
# solving Ax = b time taken:  0.4046802520751953
# epoch:  463	assembling the mass matrix time taken:  0.004322528839111328
# solving Ax = b time taken:  0.409726619720459
# epoch:  464	assembling the mass matrix time taken:  0.004148960113525391
# solving Ax = b time taken:  0.4033820629119873
# epoch:  465	assembling the mass matrix time taken:  0.004301548004150391
# solving Ax = b time taken:  0.40885496139526367
# epoch:  466	assembling the mass matrix time taken:  0.004140615463256836
# solving Ax = b time taken:  0.40778183937072754
# epoch:  467	assembling the mass matrix time taken:  0.004324674606323242
# solving Ax = b time taken:  0.4112062454223633
# epoch:  468	assembling the mass matrix time taken:  0.004139423370361328
# solving Ax = b time taken:  0.40532732009887695
# epoch:  469	assembling the mass matrix time taken:  0.0048940181732177734
# solving Ax = b time taken:  0.4129908084869385
# epoch:  470	assembling the mass matrix time taken:  0.004158496856689453
# solving Ax = b time taken:  0.4106874465942383
# epoch:  471	assembling the mass matrix time taken:  0.004273653030395508
# solving Ax = b time taken:  0.41559839248657227
# epoch:  472	assembling the mass matrix time taken:  0.004150867462158203
# solving Ax = b time taken:  0.40654587745666504
# epoch:  473	assembling the mass matrix time taken:  0.004304409027099609
# solving Ax = b time taken:  0.41445422172546387
# epoch:  474	assembling the mass matrix time taken:  0.004157304763793945
# solving Ax = b time taken:  0.41251540184020996
# epoch:  475	assembling the mass matrix time taken:  0.0046422481536865234
# solving Ax = b time taken:  0.4156169891357422
# epoch:  476	assembling the mass matrix time taken:  0.004319906234741211
# solving Ax = b time taken:  0.4104328155517578
# epoch:  477	assembling the mass matrix time taken:  0.004552125930786133
# solving Ax = b time taken:  0.41509366035461426
# epoch:  478	assembling the mass matrix time taken:  0.004320383071899414
# solving Ax = b time taken:  0.41780638694763184
# epoch:  479	assembling the mass matrix time taken:  0.004589080810546875
# solving Ax = b time taken:  0.4190788269042969
# epoch:  480	assembling the mass matrix time taken:  0.004311323165893555
# solving Ax = b time taken:  0.4115571975708008
# epoch:  481	assembling the mass matrix time taken:  0.004182338714599609
# solving Ax = b time taken:  0.4156460762023926
# epoch:  482	assembling the mass matrix time taken:  0.004242658615112305
# solving Ax = b time taken:  0.4162790775299072
# epoch:  483	assembling the mass matrix time taken:  0.004538297653198242
# solving Ax = b time taken:  0.42020106315612793
# epoch:  484	assembling the mass matrix time taken:  0.004342079162597656
# solving Ax = b time taken:  0.413316011428833
# epoch:  485	assembling the mass matrix time taken:  0.004120588302612305
# solving Ax = b time taken:  0.4199209213256836
# epoch:  486	assembling the mass matrix time taken:  0.004280805587768555
# solving Ax = b time taken:  0.4204447269439697
# epoch:  487	assembling the mass matrix time taken:  0.004132747650146484
# solving Ax = b time taken:  0.4234950542449951
# epoch:  488	assembling the mass matrix time taken:  0.2752976417541504
# solving Ax = b time taken:  0.23212122917175293
# epoch:  489	assembling the mass matrix time taken:  0.004958391189575195
# solving Ax = b time taken:  0.42183566093444824
# epoch:  490	assembling the mass matrix time taken:  0.0045168399810791016
# solving Ax = b time taken:  0.41917848587036133
# epoch:  491	assembling the mass matrix time taken:  0.005624055862426758
# solving Ax = b time taken:  0.42218494415283203
# epoch:  492	assembling the mass matrix time taken:  0.27438974380493164
# solving Ax = b time taken:  0.2318892478942871
# epoch:  493	assembling the mass matrix time taken:  0.00739288330078125
# solving Ax = b time taken:  0.4215080738067627
# epoch:  494	assembling the mass matrix time taken:  0.27635717391967773
# solving Ax = b time taken:  0.23373770713806152
# epoch:  495	assembling the mass matrix time taken:  0.006668806076049805
# solving Ax = b time taken:  0.4237072467803955
# epoch:  496	assembling the mass matrix time taken:  0.27646327018737793
# solving Ax = b time taken:  0.23404216766357422
# epoch:  497	assembling the mass matrix time taken:  0.006748199462890625
# solving Ax = b time taken:  0.42383432388305664
# epoch:  498	assembling the mass matrix time taken:  0.2772972583770752
# solving Ax = b time taken:  0.23485612869262695
# epoch:  499	assembling the mass matrix time taken:  0.006697654724121094
# solving Ax = b time taken:  0.42438316345214844
# epoch:  500	assembling the mass matrix time taken:  0.2794828414916992
# solving Ax = b time taken:  0.23470640182495117
# epoch:  501	assembling the mass matrix time taken:  0.0073032379150390625
# solving Ax = b time taken:  0.4252467155456543
# epoch:  502	assembling the mass matrix time taken:  0.27820634841918945
# solving Ax = b time taken:  0.23540496826171875
# epoch:  503	assembling the mass matrix time taken:  0.005678653717041016
# solving Ax = b time taken:  0.4301588535308838
# epoch:  504	assembling the mass matrix time taken:  0.2781383991241455
# solving Ax = b time taken:  0.23614907264709473
# epoch:  505	assembling the mass matrix time taken:  0.005795955657958984
# solving Ax = b time taken:  0.4291844367980957
# epoch:  506	assembling the mass matrix time taken:  0.2821829319000244
# solving Ax = b time taken:  0.23762273788452148
# epoch:  507	assembling the mass matrix time taken:  0.00568699836730957
# solving Ax = b time taken:  0.4322233200073242
# epoch:  508	assembling the mass matrix time taken:  0.27596259117126465
# solving Ax = b time taken:  0.23703241348266602
# epoch:  509	assembling the mass matrix time taken:  0.005873918533325195
# solving Ax = b time taken:  0.4314734935760498
# epoch:  510	assembling the mass matrix time taken:  0.2814459800720215
# solving Ax = b time taken:  0.23767447471618652
# epoch:  511	assembling the mass matrix time taken:  0.0059392452239990234
# solving Ax = b time taken:  0.433290958404541
# epoch:  512	assembling the mass matrix time taken:  0.27698373794555664
# solving Ax = b time taken:  0.2371382713317871
# time taken:  324.91310954093933
# neuron num 		 error 		 order
# 4		tensor(0.2112)		*
# 8		tensor(0.0873)		tensor(1.2749)
# 16		tensor(0.0673)		tensor(0.3744)
# 32		tensor(0.0538)		tensor(0.3240)
# 64		tensor(0.0110)		tensor(2.2945)
# 128		tensor(0.0042)		tensor(1.3947)
# 256		tensor(0.0006)		tensor(2.9005)
# 512		tensor(0.0001)		tensor(2.0698)

# %% [markdown]
# ## $\cos(\pi x_1) \cos( \pi x_2) \cos( \pi x_3) \cos( \pi x_4)$

# %%
def u_exact(x):
    return torch.cos(pi*x[:,0:1])*torch.cos( pi*x[:,1:2]) * torch.cos(pi*x[:,2:3]) * torch.cos(pi*x[:,3:4]) 
def alpha(x): 
#     return torch.ones(x.size(0),1).to(device)
    return 0.5 * torch.sin(6 * pi*x[:,0:1]) + 1. 

def target(x):
#     z = (  4 * (pi)**2 + 1)*torch.cos( pi*x[:,0:1])*torch.cos( pi*x[:,1:2] ) * torch.cos(pi*x[:,2:3]) * torch.cos( pi*x[:,3:4]) 
#     return z 
    z_c = torch.cos( pi*x[:,0:1])*torch.cos( pi*x[:,1:2] ) * torch.cos(pi*x[:,2:3]) * torch.cos( pi*x[:,3:4]) 
    z1 = 3 * pi**2 * torch.sin(pi * x[:,0:1]) * torch.cos( 6*pi*x[:,1:2] ) * torch.cos(pi*x[:,2:3]) * torch.cos( pi*x[:,3:4]) 
    z2 = 0.5 * pi**2 * torch.sin(6*pi * x[:,0:1])* z_c 
    z = z1 + z2 + 3/2*pi**2 * torch.sin(6 * pi * x[:,0:1]) * z_c 
    z += ( 4 * (pi)**2 + 1)*z_c 
    return z 

function_name = "cospix" 
filename_write = "data-neumann/4DOGA-{}-order.txt".format(function_name)
f_write = open(filename_write, "a")
f_write.write("\n")
f_write.close() 
save = False 
for N_list in [[2**2,2**2,2**2,2**2]]: # ,[2**6,2**6],[2**7,2**7] 
    # save = True 
    f_write = open(filename_write, "a")
    my_model = None 
    # Nx = 50   
    # order = 3   
    M = 500000  
    exponent = 8 
    num_epochs = 2**exponent  
    plot_freq = num_epochs 
    N = np.prod(N_list)
    err_QMC2, my_model = OGANeumannReLU4D(my_model,alpha, target,u_exact, N_list,num_epochs,plot_freq, M, k = 1, rand_deter= 'rand', linear_solver = "direct")
    
    if save: 
        folder = 'data-neumann/'
        filename = folder + 'err_OGA_4D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        torch.save(err_QMC2,filename) 
        folder = 'data-neumann/'
        filename = folder + 'model_OGA_4D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        torch.save(my_model,filename)

    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_QMC2[i] for i in neuron_nums ]
    f_write.write('deterministic dictionary size: {}\n'.format(N))
    f_write.write("neuron num \t\t error \t\t order\n")
    print("neuron num \t\t error \t\t order")
    for i, item in enumerate(err_list):
        if i == 0: 
            print(neuron_nums[i], end = "\t\t")
            print(item, end = "\t\t")
            print("*")
            f_write.write("{} \t\t {} \t\t * \n".format(neuron_nums[i],item))
        else: 
            print(neuron_nums[i], end = "\t\t")
            print(item, end = "\t\t") 
            print(np.log(err_list[i-1]/err_list[i])/np.log(2))
            f_write.write("{} \t\t {} \t\t {} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2)))
    f_write.write("\n")
    f_write.close()
# Out:
# using linear solver:  direct
# epoch:  1	assembling the mass matrix time taken:  0.0009791851043701172
# solving Ax = b time taken:  0.13031697273254395
# epoch:  2	assembling the mass matrix time taken:  0.0008194446563720703
# solving Ax = b time taken:  0.004035472869873047
# epoch:  3	assembling the mass matrix time taken:  0.000885009765625
# solving Ax = b time taken:  0.003545045852661133
# epoch:  4	assembling the mass matrix time taken:  0.0007338523864746094
# solving Ax = b time taken:  0.004254579544067383
# epoch:  5	assembling the mass matrix time taken:  0.0009253025054931641
# solving Ax = b time taken:  0.0042955875396728516
# epoch:  6	assembling the mass matrix time taken:  0.0008869171142578125
# solving Ax = b time taken:  0.0046536922454833984
# epoch:  7	assembling the mass matrix time taken:  0.0009019374847412109
# solving Ax = b time taken:  0.004832267761230469
# epoch:  8	assembling the mass matrix time taken:  0.0007388591766357422
# solving Ax = b time taken:  0.005568027496337891
# epoch:  9	assembling the mass matrix time taken:  0.0007827281951904297
# solving Ax = b time taken:  0.005856513977050781
# epoch:  10	assembling the mass matrix time taken:  0.0007655620574951172
# solving Ax = b time taken:  0.006134986877441406
# epoch:  11	assembling the mass matrix time taken:  0.0008866786956787109
# solving Ax = b time taken:  0.006257057189941406
# epoch:  12	assembling the mass matrix time taken:  0.0007898807525634766
# solving Ax = b time taken:  0.006696224212646484
# epoch:  13	assembling the mass matrix time taken:  0.0007390975952148438
# solving Ax = b time taken:  0.007154703140258789
# epoch:  14	assembling the mass matrix time taken:  0.0008444786071777344
# solving Ax = b time taken:  0.007314205169677734
# epoch:  15	assembling the mass matrix time taken:  0.0007884502410888672
# solving Ax = b time taken:  0.007746458053588867
# epoch:  16	assembling the mass matrix time taken:  0.000762939453125
# solving Ax = b time taken:  0.007961750030517578
# epoch:  17	assembling the mass matrix time taken:  0.0007970333099365234
# solving Ax = b time taken:  0.008486032485961914
# epoch:  18	assembling the mass matrix time taken:  0.0008084774017333984
# solving Ax = b time taken:  0.00873565673828125
# epoch:  19	assembling the mass matrix time taken:  0.0008242130279541016
# solving Ax = b time taken:  0.009102344512939453
# epoch:  20	assembling the mass matrix time taken:  0.0008780956268310547
# solving Ax = b time taken:  0.009086132049560547
# epoch:  21	assembling the mass matrix time taken:  0.0007922649383544922
# solving Ax = b time taken:  0.00979757308959961
# epoch:  22	assembling the mass matrix time taken:  0.0007660388946533203
# solving Ax = b time taken:  0.010028600692749023
# epoch:  23	assembling the mass matrix time taken:  0.0008673667907714844
# solving Ax = b time taken:  0.010296821594238281
# epoch:  24	assembling the mass matrix time taken:  0.0007357597351074219
# solving Ax = b time taken:  0.010675907135009766
# epoch:  25	assembling the mass matrix time taken:  0.0007357597351074219
# solving Ax = b time taken:  0.011189937591552734
# epoch:  26	assembling the mass matrix time taken:  0.0008692741394042969
# solving Ax = b time taken:  0.011237859725952148
# epoch:  27	assembling the mass matrix time taken:  0.0007593631744384766
# solving Ax = b time taken:  0.011859655380249023
# epoch:  28	assembling the mass matrix time taken:  0.0007236003875732422
# solving Ax = b time taken:  0.012242317199707031
# epoch:  29	assembling the mass matrix time taken:  0.000881195068359375
# solving Ax = b time taken:  0.012266874313354492
# epoch:  30	assembling the mass matrix time taken:  0.0007405281066894531
# solving Ax = b time taken:  0.012939214706420898
# epoch:  31	assembling the mass matrix time taken:  0.0007679462432861328
# solving Ax = b time taken:  0.013151168823242188
# epoch:  32	assembling the mass matrix time taken:  0.0008606910705566406
# solving Ax = b time taken:  0.013124227523803711
# epoch:  33	assembling the mass matrix time taken:  0.0008218288421630859
# solving Ax = b time taken:  0.014556169509887695
# epoch:  34	assembling the mass matrix time taken:  0.0007724761962890625
# solving Ax = b time taken:  0.014817237854003906
# epoch:  35	assembling the mass matrix time taken:  0.0008392333984375
# solving Ax = b time taken:  0.015088319778442383
# epoch:  36	assembling the mass matrix time taken:  0.0007650852203369141
# solving Ax = b time taken:  0.015233278274536133
# epoch:  37	assembling the mass matrix time taken:  0.0007622241973876953
# solving Ax = b time taken:  0.015918254852294922
# epoch:  38	assembling the mass matrix time taken:  0.0008411407470703125
# solving Ax = b time taken:  0.015866518020629883
# epoch:  39	assembling the mass matrix time taken:  0.0007987022399902344
# solving Ax = b time taken:  0.016574859619140625
# epoch:  40	assembling the mass matrix time taken:  0.0007855892181396484
# solving Ax = b time taken:  0.016431808471679688
# epoch:  41	assembling the mass matrix time taken:  0.0009188652038574219
# solving Ax = b time taken:  0.016781091690063477
# epoch:  42	assembling the mass matrix time taken:  0.0007748603820800781
# solving Ax = b time taken:  0.017467021942138672
# epoch:  43	assembling the mass matrix time taken:  0.0007257461547851562
# solving Ax = b time taken:  0.017789602279663086
# epoch:  44	assembling the mass matrix time taken:  0.0007288455963134766
# solving Ax = b time taken:  0.017980337142944336
# epoch:  45	assembling the mass matrix time taken:  0.0007817745208740234
# solving Ax = b time taken:  0.018399477005004883
# epoch:  46	assembling the mass matrix time taken:  0.0008413791656494141
# solving Ax = b time taken:  0.01862168312072754
# epoch:  47	assembling the mass matrix time taken:  0.000728607177734375
# solving Ax = b time taken:  0.0228729248046875
# epoch:  48	assembling the mass matrix time taken:  0.0007388591766357422
# solving Ax = b time taken:  0.02301788330078125
# epoch:  49	assembling the mass matrix time taken:  0.0007717609405517578
# solving Ax = b time taken:  0.02365398406982422
# epoch:  50	assembling the mass matrix time taken:  0.0007343292236328125
# solving Ax = b time taken:  0.023793697357177734
# epoch:  51	assembling the mass matrix time taken:  0.0008490085601806641
# solving Ax = b time taken:  0.024307966232299805
# epoch:  52	assembling the mass matrix time taken:  0.0007808208465576172
# solving Ax = b time taken:  0.024054288864135742
# epoch:  53	assembling the mass matrix time taken:  0.0008287429809570312
# solving Ax = b time taken:  0.024770498275756836
# epoch:  54	assembling the mass matrix time taken:  0.0007870197296142578
# solving Ax = b time taken:  0.024979352951049805
# epoch:  55	assembling the mass matrix time taken:  0.0007269382476806641
# solving Ax = b time taken:  0.02537250518798828
# epoch:  56	assembling the mass matrix time taken:  0.0007770061492919922
# solving Ax = b time taken:  0.025255918502807617
# epoch:  57	assembling the mass matrix time taken:  0.0007960796356201172
# solving Ax = b time taken:  0.02621150016784668
# epoch:  58	assembling the mass matrix time taken:  0.0007686614990234375
# solving Ax = b time taken:  0.026476144790649414
# epoch:  59	assembling the mass matrix time taken:  0.0008139610290527344
# solving Ax = b time taken:  0.026643037796020508
# epoch:  60	assembling the mass matrix time taken:  0.0007753372192382812
# solving Ax = b time taken:  0.026827573776245117
# epoch:  61	assembling the mass matrix time taken:  0.0007650852203369141
# solving Ax = b time taken:  0.02746868133544922
# epoch:  62	assembling the mass matrix time taken:  0.0007436275482177734
# solving Ax = b time taken:  0.027844667434692383
# epoch:  63	assembling the mass matrix time taken:  0.0007336139678955078
# solving Ax = b time taken:  0.028080463409423828
# epoch:  64	assembling the mass matrix time taken:  0.0007393360137939453
# solving Ax = b time taken:  0.028246164321899414
# epoch:  65	assembling the mass matrix time taken:  0.001293182373046875
# solving Ax = b time taken:  0.0315241813659668
# epoch:  66	assembling the mass matrix time taken:  0.0011954307556152344
# solving Ax = b time taken:  0.0316770076751709
# epoch:  67	assembling the mass matrix time taken:  0.001443624496459961
# solving Ax = b time taken:  0.03206992149353027
# epoch:  68	assembling the mass matrix time taken:  0.0013566017150878906
# solving Ax = b time taken:  0.031641244888305664
# epoch:  69	assembling the mass matrix time taken:  0.0011868476867675781
# solving Ax = b time taken:  0.03294014930725098
# epoch:  70	assembling the mass matrix time taken:  0.001155853271484375
# solving Ax = b time taken:  0.03295540809631348
# epoch:  71	assembling the mass matrix time taken:  0.0010988712310791016
# solving Ax = b time taken:  0.03379535675048828
# epoch:  72	assembling the mass matrix time taken:  0.0010988712310791016
# solving Ax = b time taken:  0.03316617012023926
# epoch:  73	assembling the mass matrix time taken:  0.0011415481567382812
# solving Ax = b time taken:  0.034349679946899414
# epoch:  74	assembling the mass matrix time taken:  0.0011341571807861328
# solving Ax = b time taken:  0.03452754020690918
# epoch:  75	assembling the mass matrix time taken:  0.0013167858123779297
# solving Ax = b time taken:  0.03442835807800293
# epoch:  76	assembling the mass matrix time taken:  0.0011687278747558594
# solving Ax = b time taken:  0.03463125228881836
# epoch:  77	assembling the mass matrix time taken:  0.001165628433227539
# solving Ax = b time taken:  0.03522133827209473
# epoch:  78	assembling the mass matrix time taken:  0.001125335693359375
# solving Ax = b time taken:  0.0358278751373291
# epoch:  79	assembling the mass matrix time taken:  0.0011725425720214844
# solving Ax = b time taken:  0.035935401916503906
# epoch:  80	assembling the mass matrix time taken:  0.0011131763458251953
# solving Ax = b time taken:  0.03597068786621094
# epoch:  81	assembling the mass matrix time taken:  0.001161813735961914
# solving Ax = b time taken:  0.03834891319274902
# epoch:  82	assembling the mass matrix time taken:  0.001306295394897461
# solving Ax = b time taken:  0.03812432289123535
# epoch:  83	assembling the mass matrix time taken:  0.0011372566223144531
# solving Ax = b time taken:  0.039166927337646484
# epoch:  84	assembling the mass matrix time taken:  0.0011086463928222656
# solving Ax = b time taken:  0.038451194763183594
# epoch:  85	assembling the mass matrix time taken:  0.0012264251708984375
# solving Ax = b time taken:  0.03954195976257324
# epoch:  86	assembling the mass matrix time taken:  0.0011451244354248047
# solving Ax = b time taken:  0.03962349891662598
# epoch:  87	assembling the mass matrix time taken:  0.07185101509094238
# solving Ax = b time taken:  0.025684118270874023
# epoch:  88	assembling the mass matrix time taken:  0.0028448104858398438
# solving Ax = b time taken:  0.04109501838684082
# epoch:  89	assembling the mass matrix time taken:  0.003411531448364258
# solving Ax = b time taken:  0.041898488998413086
# epoch:  90	assembling the mass matrix time taken:  0.0032787322998046875
# solving Ax = b time taken:  0.04234051704406738
# epoch:  91	assembling the mass matrix time taken:  0.002969980239868164
# solving Ax = b time taken:  0.042962074279785156
# epoch:  92	assembling the mass matrix time taken:  0.0020351409912109375
# solving Ax = b time taken:  0.040392160415649414
# epoch:  93	assembling the mass matrix time taken:  0.0011734962463378906
# solving Ax = b time taken:  0.0419468879699707
# epoch:  94	assembling the mass matrix time taken:  0.0012388229370117188
# solving Ax = b time taken:  0.042283058166503906
# epoch:  95	assembling the mass matrix time taken:  0.00116729736328125
# solving Ax = b time taken:  0.04263901710510254
# epoch:  96	assembling the mass matrix time taken:  0.0011780261993408203
# solving Ax = b time taken:  0.04241323471069336
# epoch:  97	assembling the mass matrix time taken:  0.0011620521545410156
# solving Ax = b time taken:  0.04206585884094238
# epoch:  98	assembling the mass matrix time taken:  0.001100301742553711
# solving Ax = b time taken:  0.04213738441467285
# epoch:  99	assembling the mass matrix time taken:  0.0011627674102783203
# solving Ax = b time taken:  0.042914390563964844
# epoch:  100	assembling the mass matrix time taken:  0.0011796951293945312
# solving Ax = b time taken:  0.042144775390625
# epoch:  101	assembling the mass matrix time taken:  0.0013079643249511719
# solving Ax = b time taken:  0.0431971549987793
# epoch:  102	assembling the mass matrix time taken:  0.0011169910430908203
# solving Ax = b time taken:  0.043409109115600586
# epoch:  103	assembling the mass matrix time taken:  0.001150369644165039
# solving Ax = b time taken:  0.04419970512390137
# epoch:  104	assembling the mass matrix time taken:  0.09151172637939453
# solving Ax = b time taken:  0.02741098403930664
# epoch:  105	assembling the mass matrix time taken:  0.0025854110717773438
# solving Ax = b time taken:  0.04779815673828125
# epoch:  106	assembling the mass matrix time taken:  0.0030736923217773438
# solving Ax = b time taken:  0.04719877243041992
# epoch:  107	assembling the mass matrix time taken:  0.003068208694458008
# solving Ax = b time taken:  0.047820091247558594
# epoch:  108	assembling the mass matrix time taken:  0.0036988258361816406
# solving Ax = b time taken:  0.04210329055786133
# epoch:  109	assembling the mass matrix time taken:  0.0013842582702636719
# solving Ax = b time taken:  0.04556155204772949
# epoch:  110	assembling the mass matrix time taken:  0.0011506080627441406
# solving Ax = b time taken:  0.04593300819396973
# epoch:  111	assembling the mass matrix time taken:  0.0011110305786132812
# solving Ax = b time taken:  0.04665970802307129
# epoch:  112	assembling the mass matrix time taken:  0.0010752677917480469
# solving Ax = b time taken:  0.04631185531616211
# epoch:  113	assembling the mass matrix time taken:  0.0012590885162353516
# solving Ax = b time taken:  0.04713273048400879
# epoch:  114	assembling the mass matrix time taken:  0.0011458396911621094
# solving Ax = b time taken:  0.04716849327087402
# epoch:  115	assembling the mass matrix time taken:  0.0010941028594970703
# solving Ax = b time taken:  0.049117088317871094
# epoch:  116	assembling the mass matrix time taken:  0.0011339187622070312
# solving Ax = b time taken:  0.04775738716125488
# epoch:  117	assembling the mass matrix time taken:  0.0010955333709716797
# solving Ax = b time taken:  0.04953169822692871
# epoch:  118	assembling the mass matrix time taken:  0.0011260509490966797
# solving Ax = b time taken:  0.04920005798339844
# epoch:  119	assembling the mass matrix time taken:  0.11037683486938477
# solving Ax = b time taken:  0.030644893646240234
# epoch:  120	assembling the mass matrix time taken:  0.0028371810913085938
# solving Ax = b time taken:  0.05227518081665039
# epoch:  121	assembling the mass matrix time taken:  0.0028557777404785156
# solving Ax = b time taken:  0.054170846939086914
# epoch:  122	assembling the mass matrix time taken:  0.003519296646118164
# solving Ax = b time taken:  0.05331587791442871
# epoch:  123	assembling the mass matrix time taken:  0.0028793811798095703
# solving Ax = b time taken:  0.04951596260070801
# epoch:  124	assembling the mass matrix time taken:  0.0011038780212402344
# solving Ax = b time taken:  0.05097460746765137
# epoch:  125	assembling the mass matrix time taken:  0.0014994144439697266
# solving Ax = b time taken:  0.051285505294799805
# epoch:  126	assembling the mass matrix time taken:  0.001203298568725586
# solving Ax = b time taken:  0.05207204818725586
# epoch:  127	assembling the mass matrix time taken:  0.0011696815490722656
# solving Ax = b time taken:  0.052545785903930664
# epoch:  128	assembling the mass matrix time taken:  0.001149892807006836
# solving Ax = b time taken:  0.05188393592834473
# epoch:  129	assembling the mass matrix time taken:  0.0011489391326904297
# solving Ax = b time taken:  0.06796097755432129
# epoch:  130	assembling the mass matrix time taken:  0.0011627674102783203
# solving Ax = b time taken:  0.067626953125
# epoch:  131	assembling the mass matrix time taken:  0.0011472702026367188
# solving Ax = b time taken:  0.06853318214416504
# epoch:  132	assembling the mass matrix time taken:  0.12411093711853027
# solving Ax = b time taken:  0.04738926887512207
# epoch:  133	assembling the mass matrix time taken:  0.002357006072998047
# solving Ax = b time taken:  0.07470583915710449
# epoch:  134	assembling the mass matrix time taken:  0.0029206275939941406
# solving Ax = b time taken:  0.0736076831817627
# epoch:  135	assembling the mass matrix time taken:  0.003197193145751953
# solving Ax = b time taken:  0.06801629066467285
# epoch:  136	assembling the mass matrix time taken:  0.0018346309661865234
# solving Ax = b time taken:  0.06773757934570312
# epoch:  137	assembling the mass matrix time taken:  0.0011310577392578125
# solving Ax = b time taken:  0.07063031196594238
# epoch:  138	assembling the mass matrix time taken:  0.0011513233184814453
# solving Ax = b time taken:  0.07039713859558105
# epoch:  139	assembling the mass matrix time taken:  0.001116037368774414
# solving Ax = b time taken:  0.07108044624328613
# epoch:  140	assembling the mass matrix time taken:  0.0011820793151855469
# solving Ax = b time taken:  0.07013225555419922
# epoch:  141	assembling the mass matrix time taken:  0.0014891624450683594
# solving Ax = b time taken:  0.07105183601379395
# epoch:  142	assembling the mass matrix time taken:  0.0012035369873046875
# solving Ax = b time taken:  0.0718529224395752
# epoch:  143	assembling the mass matrix time taken:  0.13692975044250488
# solving Ax = b time taken:  0.050829410552978516
# epoch:  144	assembling the mass matrix time taken:  0.0019388198852539062
# solving Ax = b time taken:  0.07647323608398438
# epoch:  145	assembling the mass matrix time taken:  0.003928184509277344
# solving Ax = b time taken:  0.07907772064208984
# epoch:  146	assembling the mass matrix time taken:  0.003245830535888672
# solving Ax = b time taken:  0.07055854797363281
# epoch:  147	assembling the mass matrix time taken:  0.0011348724365234375
# solving Ax = b time taken:  0.07405614852905273
# epoch:  148	assembling the mass matrix time taken:  0.0011341571807861328
# solving Ax = b time taken:  0.07238221168518066
# epoch:  149	assembling the mass matrix time taken:  0.001148223876953125
# solving Ax = b time taken:  0.07450723648071289
# epoch:  150	assembling the mass matrix time taken:  0.0011439323425292969
# solving Ax = b time taken:  0.07416844367980957
# epoch:  151	assembling the mass matrix time taken:  0.0010986328125
# solving Ax = b time taken:  0.07547569274902344
# epoch:  152	assembling the mass matrix time taken:  0.0011627674102783203
# solving Ax = b time taken:  0.07338070869445801
# epoch:  153	assembling the mass matrix time taken:  0.14851713180541992
# solving Ax = b time taken:  0.05374312400817871
# epoch:  154	assembling the mass matrix time taken:  0.002302408218383789
# solving Ax = b time taken:  0.08394145965576172
# epoch:  155	assembling the mass matrix time taken:  0.0042645931243896484
# solving Ax = b time taken:  0.08295798301696777
# epoch:  156	assembling the mass matrix time taken:  0.002781391143798828
# solving Ax = b time taken:  0.07371735572814941
# epoch:  157	assembling the mass matrix time taken:  0.0011677742004394531
# solving Ax = b time taken:  0.07692503929138184
# epoch:  158	assembling the mass matrix time taken:  0.0012278556823730469
# solving Ax = b time taken:  0.07714128494262695
# epoch:  159	assembling the mass matrix time taken:  0.0011661052703857422
# solving Ax = b time taken:  0.07767224311828613
# epoch:  160	assembling the mass matrix time taken:  0.0011897087097167969
# solving Ax = b time taken:  0.0762014389038086
# epoch:  161	assembling the mass matrix time taken:  0.0011599063873291016
# solving Ax = b time taken:  0.07730984687805176
# epoch:  162	assembling the mass matrix time taken:  0.0011594295501708984
# solving Ax = b time taken:  0.07695293426513672
# epoch:  163	assembling the mass matrix time taken:  0.24759221076965332
# solving Ax = b time taken:  0.04950833320617676
# epoch:  164	assembling the mass matrix time taken:  0.0027747154235839844
# solving Ax = b time taken:  0.08103203773498535
# epoch:  165	assembling the mass matrix time taken:  0.0037140846252441406
# solving Ax = b time taken:  0.07660651206970215
# epoch:  166	assembling the mass matrix time taken:  0.0019915103912353516
# solving Ax = b time taken:  0.07767367362976074
# epoch:  167	assembling the mass matrix time taken:  0.0015473365783691406
# solving Ax = b time taken:  0.07879972457885742
# epoch:  168	assembling the mass matrix time taken:  0.0012767314910888672
# solving Ax = b time taken:  0.07788777351379395
# epoch:  169	assembling the mass matrix time taken:  0.0012209415435791016
# solving Ax = b time taken:  0.07995867729187012
# epoch:  170	assembling the mass matrix time taken:  0.0011851787567138672
# solving Ax = b time taken:  0.07969141006469727
# epoch:  171	assembling the mass matrix time taken:  0.30129289627075195
# solving Ax = b time taken:  0.0510709285736084
# epoch:  172	assembling the mass matrix time taken:  0.002814054489135742
# solving Ax = b time taken:  0.08399176597595215
# epoch:  173	assembling the mass matrix time taken:  0.002882719039916992
# solving Ax = b time taken:  0.07953286170959473
# epoch:  174	assembling the mass matrix time taken:  0.0011448860168457031
# solving Ax = b time taken:  0.08101201057434082
# epoch:  175	assembling the mass matrix time taken:  0.0011835098266601562
# solving Ax = b time taken:  0.08177995681762695
# epoch:  176	assembling the mass matrix time taken:  0.0011820793151855469
# solving Ax = b time taken:  0.08053112030029297
# epoch:  177	assembling the mass matrix time taken:  0.0011327266693115234
# solving Ax = b time taken:  0.08250713348388672
# epoch:  178	assembling the mass matrix time taken:  0.0011668205261230469
# solving Ax = b time taken:  0.08236312866210938
# epoch:  179	assembling the mass matrix time taken:  0.20149970054626465
# solving Ax = b time taken:  0.0522303581237793
# epoch:  180	assembling the mass matrix time taken:  0.0030024051666259766
# solving Ax = b time taken:  0.08608341217041016
# epoch:  181	assembling the mass matrix time taken:  0.0038356781005859375
# solving Ax = b time taken:  0.08402752876281738
# epoch:  182	assembling the mass matrix time taken:  0.0021686553955078125
# solving Ax = b time taken:  0.08214139938354492
# epoch:  183	assembling the mass matrix time taken:  0.0011472702026367188
# solving Ax = b time taken:  0.0846242904663086
# epoch:  184	assembling the mass matrix time taken:  0.0011913776397705078
# solving Ax = b time taken:  0.08234143257141113
# epoch:  185	assembling the mass matrix time taken:  0.0011785030364990234
# solving Ax = b time taken:  0.0849909782409668
# epoch:  186	assembling the mass matrix time taken:  0.0011904239654541016
# solving Ax = b time taken:  0.0850074291229248
# epoch:  187	assembling the mass matrix time taken:  0.18354153633117676
# solving Ax = b time taken:  0.05366110801696777
# epoch:  188	assembling the mass matrix time taken:  0.003096342086791992
# solving Ax = b time taken:  0.0894474983215332
# epoch:  189	assembling the mass matrix time taken:  0.0040514469146728516
# solving Ax = b time taken:  0.08748531341552734
# epoch:  190	assembling the mass matrix time taken:  0.002205371856689453
# solving Ax = b time taken:  0.08517646789550781
# epoch:  191	assembling the mass matrix time taken:  0.0015146732330322266
# solving Ax = b time taken:  0.08635616302490234
# epoch:  192	assembling the mass matrix time taken:  0.0012285709381103516
# solving Ax = b time taken:  0.08563470840454102
# epoch:  193	assembling the mass matrix time taken:  0.0012359619140625
# solving Ax = b time taken:  0.10554838180541992
# epoch:  194	assembling the mass matrix time taken:  0.0028638839721679688
# solving Ax = b time taken:  0.10316967964172363
# epoch:  195	assembling the mass matrix time taken:  0.1929774284362793
# solving Ax = b time taken:  0.0727837085723877
# epoch:  196	assembling the mass matrix time taken:  0.003209352493286133
# solving Ax = b time taken:  0.10932374000549316
# epoch:  197	assembling the mass matrix time taken:  0.0050106048583984375
# solving Ax = b time taken:  0.1049952507019043
# epoch:  198	assembling the mass matrix time taken:  0.001605987548828125
# solving Ax = b time taken:  0.10559225082397461
# epoch:  199	assembling the mass matrix time taken:  0.0013136863708496094
# solving Ax = b time taken:  0.10750460624694824
# epoch:  200	assembling the mass matrix time taken:  0.0012061595916748047
# solving Ax = b time taken:  0.10509300231933594
# epoch:  201	assembling the mass matrix time taken:  0.0013341903686523438
# solving Ax = b time taken:  0.10789299011230469
# epoch:  202	assembling the mass matrix time taken:  0.19928860664367676
# solving Ax = b time taken:  0.0745084285736084
# epoch:  203	assembling the mass matrix time taken:  0.0037946701049804688
# solving Ax = b time taken:  0.11400127410888672
# epoch:  204	assembling the mass matrix time taken:  0.004908323287963867
# solving Ax = b time taken:  0.10314679145812988
# epoch:  205	assembling the mass matrix time taken:  0.0015497207641601562
# solving Ax = b time taken:  0.10838866233825684
# epoch:  206	assembling the mass matrix time taken:  0.0013837814331054688
# solving Ax = b time taken:  0.1088261604309082
# epoch:  207	assembling the mass matrix time taken:  0.0013966560363769531
# solving Ax = b time taken:  0.10943388938903809
# epoch:  208	assembling the mass matrix time taken:  0.003022909164428711
# solving Ax = b time taken:  0.10637426376342773
# epoch:  209	assembling the mass matrix time taken:  0.20831036567687988
# solving Ax = b time taken:  0.0757606029510498
# epoch:  210	assembling the mass matrix time taken:  0.003370523452758789
# solving Ax = b time taken:  0.11624550819396973
# epoch:  211	assembling the mass matrix time taken:  0.0034568309783935547
# solving Ax = b time taken:  0.10921692848205566
# epoch:  212	assembling the mass matrix time taken:  0.0015621185302734375
# solving Ax = b time taken:  0.10859274864196777
# epoch:  213	assembling the mass matrix time taken:  0.0014591217041015625
# solving Ax = b time taken:  0.11156225204467773
# epoch:  214	assembling the mass matrix time taken:  0.0030820369720458984
# solving Ax = b time taken:  0.10916376113891602
# epoch:  215	assembling the mass matrix time taken:  0.32437610626220703
# solving Ax = b time taken:  0.07681107521057129
# epoch:  216	assembling the mass matrix time taken:  0.0035941600799560547
# solving Ax = b time taken:  0.11219263076782227
# epoch:  217	assembling the mass matrix time taken:  0.0023441314697265625
# solving Ax = b time taken:  0.11210775375366211
# epoch:  218	assembling the mass matrix time taken:  0.001293182373046875
# solving Ax = b time taken:  0.1128230094909668
# epoch:  219	assembling the mass matrix time taken:  0.0012989044189453125
# solving Ax = b time taken:  0.11389517784118652
# epoch:  220	assembling the mass matrix time taken:  0.0030558109283447266
# solving Ax = b time taken:  0.11031150817871094
# epoch:  221	assembling the mass matrix time taken:  0.2195596694946289
# solving Ax = b time taken:  0.0777442455291748
# epoch:  222	assembling the mass matrix time taken:  0.0038967132568359375
# solving Ax = b time taken:  0.12004876136779785
# epoch:  223	assembling the mass matrix time taken:  0.003519773483276367
# solving Ax = b time taken:  0.11244678497314453
# epoch:  224	assembling the mass matrix time taken:  0.0012657642364501953
# solving Ax = b time taken:  0.11313414573669434
# epoch:  225	assembling the mass matrix time taken:  0.0013194084167480469
# solving Ax = b time taken:  0.11538958549499512
# epoch:  226	assembling the mass matrix time taken:  0.003977775573730469
# solving Ax = b time taken:  0.11241888999938965
# epoch:  227	assembling the mass matrix time taken:  0.22623109817504883
# solving Ax = b time taken:  0.07866668701171875
# epoch:  228	assembling the mass matrix time taken:  0.003740549087524414
# solving Ax = b time taken:  0.1209101676940918
# epoch:  229	assembling the mass matrix time taken:  0.003497600555419922
# solving Ax = b time taken:  0.1149759292602539
# epoch:  230	assembling the mass matrix time taken:  0.0012879371643066406
# solving Ax = b time taken:  0.11646747589111328
# epoch:  231	assembling the mass matrix time taken:  0.0013012886047363281
# solving Ax = b time taken:  0.11798524856567383
# epoch:  232	assembling the mass matrix time taken:  0.0035550594329833984
# solving Ax = b time taken:  0.11278152465820312
# epoch:  233	assembling the mass matrix time taken:  0.24171209335327148
# solving Ax = b time taken:  0.0796959400177002
# epoch:  234	assembling the mass matrix time taken:  0.0035371780395507812
# solving Ax = b time taken:  0.1249535083770752
# epoch:  235	assembling the mass matrix time taken:  0.003672361373901367
# solving Ax = b time taken:  0.11693572998046875
# epoch:  236	assembling the mass matrix time taken:  0.0012891292572021484
# solving Ax = b time taken:  0.11713933944702148
# epoch:  237	assembling the mass matrix time taken:  0.0013005733489990234
# solving Ax = b time taken:  0.11892461776733398
# epoch:  238	assembling the mass matrix time taken:  0.003143310546875
# solving Ax = b time taken:  0.11707615852355957
# epoch:  239	assembling the mass matrix time taken:  0.23733782768249512
# solving Ax = b time taken:  0.08069634437561035
# epoch:  240	assembling the mass matrix time taken:  0.0037851333618164062
# solving Ax = b time taken:  0.12487244606018066
# epoch:  241	assembling the mass matrix time taken:  0.003915309906005859
# solving Ax = b time taken:  0.1183779239654541
# epoch:  242	assembling the mass matrix time taken:  0.001348257064819336
# solving Ax = b time taken:  0.12047433853149414
# epoch:  243	assembling the mass matrix time taken:  0.0013108253479003906
# solving Ax = b time taken:  0.12154126167297363
# epoch:  244	assembling the mass matrix time taken:  0.2408759593963623
# solving Ax = b time taken:  0.08029699325561523
# epoch:  245	assembling the mass matrix time taken:  0.003663301467895508
# solving Ax = b time taken:  0.12618255615234375
# epoch:  246	assembling the mass matrix time taken:  0.0025358200073242188
# solving Ax = b time taken:  0.11993956565856934
# epoch:  247	assembling the mass matrix time taken:  0.0012388229370117188
# solving Ax = b time taken:  0.12291455268859863
# epoch:  248	assembling the mass matrix time taken:  0.0032334327697753906
# solving Ax = b time taken:  0.11815142631530762
# epoch:  249	assembling the mass matrix time taken:  0.37056994438171387
# solving Ax = b time taken:  0.08085989952087402
# epoch:  250	assembling the mass matrix time taken:  0.004180908203125
# solving Ax = b time taken:  0.11999082565307617
# epoch:  251	assembling the mass matrix time taken:  0.0012848377227783203
# solving Ax = b time taken:  0.12416338920593262
# epoch:  252	assembling the mass matrix time taken:  0.0012547969818115234
# solving Ax = b time taken:  0.12209510803222656
# epoch:  253	assembling the mass matrix time taken:  0.0011823177337646484
# solving Ax = b time taken:  0.12479782104492188
# epoch:  254	assembling the mass matrix time taken:  0.17721986770629883
# solving Ax = b time taken:  0.08145833015441895
# epoch:  255	assembling the mass matrix time taken:  0.003869771957397461
# solving Ax = b time taken:  0.12990450859069824
# epoch:  256	assembling the mass matrix time taken:  0.0025839805603027344
# solving Ax = b time taken:  0.12177467346191406
# time taken:  45.20642375946045
# neuron num 		 error 		 order
# 4		tensor(0.2476)		*
# 8		tensor(0.2326)		tensor(0.0901)
# 16		tensor(0.1947)		tensor(0.2565)
# 32		tensor(0.1250)		tensor(0.6395)
# 64		tensor(0.0780)		tensor(0.6799)
# 128		tensor(0.0437)		tensor(0.8347)
# 256		tensor(0.0267)		tensor(0.7146)

# %%
##
