# %%
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import time
import sys
import os 
from scipy.sparse import linalg
from pathlib import Path
import itertools
if torch.cuda.is_available():  
    device = "cuda" 
else:  
    device = "cpu" 


torch.set_default_dtype(torch.float64)
pi = torch.tensor(np.pi)
ZERO = torch.tensor([0.]).to(device)

class model(nn.Module):
    """ ReLU k shallow neural network
    Parameters: 
    input size: input dimension
    hidden_size1 : number of hidden layers 
    num_classes: output classes 
    k: degree of relu functions
    """
    def __init__(self, input_size, hidden_size1, num_classes,k = 1):
        super().__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, num_classes,bias = False)
        self.k = k 
    def forward(self, x):
        u1 = self.fc2(F.relu(self.fc1(x))**self.k)
        return u1
    def evaluate_derivative(self, x, i):
        if self.k == 1:
            u1 = self.fc2(torch.heaviside(self.fc1(x),ZERO) * self.fc1.weight.t()[i-1:i,:] )
        else:
            u1 = self.fc2(self.k*F.relu(self.fc1(x))**(self.k-1) *self.fc1.weight.t()[i-1:i,:] )  
        return u1


def plot_subdomains(my_model):
    x_coord =torch.linspace(0,1,200)
    wi = my_model.fc1.weight.data
    bi = my_model.fc1.bias.data 
    for i, bias in enumerate(bi):  
        if wi[i,1] !=0: 
            plt.plot(x_coord, - wi[i,0]/wi[i,1]*x_coord - bias/wi[i,1])
        else: 
            plt.plot(x_coord,  - bias/wi[i,0]*torch.ones(x_coord.size()))

    plt.xlim([0,1])
    plt.ylim([0,1])
    plt.legend()
    plt.show()
    return 0   

def adjust_neuron_position(my_model, dims = 3):

    def create_mesh_grid(dims, pts):
        mesh = torch.tensor(list(itertools.product(pts,repeat=dims)))
        vertices = mesh.reshape(len(pts) ** dims, -1) 
        return vertices
    counter = 0 
    # positions = torch.tensor([[0.,0.],[0.,1.],[1.,1.],[1.,0.]])
    pts = torch.tensor([0.,1.])
    positions = create_mesh_grid(dims,pts) 
    neuron_num = my_model.fc1.bias.size(0)
    for i in range(neuron_num): 
        w = my_model.fc1.weight.data[i:i+1,:]
        b = my_model.fc1.bias.data[i]
    #     print(w,b)
        values = torch.matmul(positions,w.T) # + b
        left_end = - torch.max(values)
        right_end = - torch.min(values)
        offset = (right_end - left_end)/50
        if b <= left_end + offset/2 : 
            b = torch.rand(1)*(right_end - left_end - offset) + left_end + offset/2 
            my_model.fc1.bias.data[i] = b 
        if b >= right_end - offset/2 :
            if counter < (dims+1):
#                 print("here")
                counter += 1
            else: # (d + 1) or more 
                b = torch.rand(1)*(right_end - left_end - offset) + left_end + offset/2 
                my_model.fc1.bias.data[i] = b 
    return my_model

# %%
def show_convergence_order2(err_l2,err_h10,exponent,dict_size, filename,write2file = False):
    
    if write2file:
        file_mode = "a" if os.path.exists(filename) else "w"
        f_write = open(filename, file_mode)
    
    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_l2[i] for i in neuron_nums ]
    err_list2 = [err_h10[i] for i in neuron_nums ] 
    # f_write.write('M:{}, relu {} \n'.format(M,k))
    if write2file:
        f_write.write('dictionary size: {}\n'.format(dict_size))
        f_write.write("neuron num \t\t error \t\t order \t\t h10 error \\ order \n")
    print("neuron num \t\t error \t\t order")
    for i, item in enumerate(err_list):
        if i == 0: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t")
            
            # print("*")
            print("{} \t\t {:.6f} \t\t * \t\t {:.6f} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ) )
            if write2file: 
                f_write.write("{} \t\t {} \t\t * \t\t {} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ))
        else: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t") 
            # print(np.log(err_list[i-1]/err_list[i])/np.log(2))
            print("{} \t\t {:.6f} \t\t {:.6f} \t\t {:.6f} \t\t {:.6f} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ) )
            if write2file: 
                f_write.write("{} \t\t {} \t\t {} \t\t {} \t\t {} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ))
    if write2file:     
        f_write.write("\n")
        f_write.close()

def show_convergence_order_latex2(err_l2,err_h10,exponent,k=1,d=1): 
    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_l2[i] for i in neuron_nums ]
    err_list2 = [err_h10[i] for i in neuron_nums ] 
    l2_order = -1/2-(2*k + 1)/(2*d)
    h1_order =  -1/2-(2*(k-1)+ 1)/(2*d)
    print("neuron num  & \t $\|u-u_n \|_{{L^2}}$ & \t order $O(n^{{{:.2f}}})$  & \t $ | u -u_n |_{{H^1}}$ & \t order $O(n^{{{:.2f}}})$  \\\ \hline \hline ".format(l2_order,h1_order))
    for i, item in enumerate(err_list):
        if i == 0: 
            print("{} \t\t & {:.6f} &\t\t * & \t\t {:.6f} & \t\t *  \\\ \hline  \n".format(neuron_nums[i],item, err_list2[i] ) )   
        else: 
            print("{} \t\t &  {:.3e} &  \t\t {:.2f} &  \t\t {:.3e} &  \t\t {:.2f} \\\ \hline  \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ) )

# %%
def MonteCarlo_Sobol_dDim_weights_points(M ,d = 4):
    Sob_integral = torch.quasirandom.SobolEngine(dimension =d, scramble= False, seed=None) 
    integration_points = Sob_integral.draw(M).double() 
    integration_points = integration_points.to(device)
    weights = torch.ones(M,1).to(device)/M 
    return weights, integration_points 

def generate_relu_dict4D(N_list):
    
    N = np.prod(N_list) 

    grid_indices = [np.linspace(0,1,N_item,endpoint=False) for N_item in N_list]
    grid = np.meshgrid(*grid_indices,indexing='ij')
    grid_coordinates = np.column_stack([axis.ravel() for axis in grid]) 
    samples = torch.tensor(grid_coordinates) 

    T =torch.tensor([[pi,0,0,0],[0,pi,0,0],[0,0,2*pi,0],[0,0,0,2*2]]) # 2 * sqrt(d)
    shift = torch.tensor([0,0,0,-2])
    samples = samples@T + shift 

    f1 = torch.zeros(N,1) 
    f2 = torch.zeros(N,1)
    f3 = torch.zeros(N,1)
    f4 = torch.zeros(N,1)
    f5 = torch.zeros(N,1)

    f1[:,0] = torch.cos(samples[:,0]) 
    f2[:,0] = torch.sin(samples[:,0]) * torch.cos(samples[:,1])
    f3[:,0] = torch.sin(samples[:,0]) * torch.sin(samples[:,1]) * torch.cos(samples[:,2])
    f4[:,0] = torch.sin(samples[:,0]) * torch.sin(samples[:,1]) * torch.sin(samples[:,2])  
    f5[:,0] = samples[:,3]

    Wb_tensor = torch.cat([f1,f2,f3,f4,f5],1) # N x 4 
    return Wb_tensor

def PiecewiseGQ3D_weights_points(Nx, order): 
    """ A slight modification of PiecewiseGQ2D function that only needs the weights and integration points.
    Parameters
    ----------

    Nx: int 
        number of intervals along the dimension. No Ny, assume Nx = Ny
    order: int 
        order of the Gauss Quadrature

    Returns
    -------
    long_weights: torch.tensor
    integration_points: torch.tensor
    """

    """
    Parameters
    ----------
    target : 
        Target function 
    Nx: int 
        number of intervals along the dimension. No Ny, assume Nx = Ny
    order: int 
        order of the Gauss Quadrature
    """

    # print("order: ",order )
    x, w = np.polynomial.legendre.leggauss(order)
    gauss_pts = np.array(np.meshgrid(x,x,x,indexing='ij')).reshape(3,-1).T
    weight_list = np.array(np.meshgrid(w,w,w,indexing='ij'))
    weights =   (weight_list[0]*weight_list[1]*weight_list[2]).ravel() 

    gauss_pts =torch.tensor(gauss_pts)
    weights = torch.tensor(weights)

    h = 1/Nx # 100 intervals 
    long_weights =  torch.tile(weights,(Nx**3,1))
    long_weights = long_weights.reshape(-1,1)
    long_weights = long_weights * h**3 /8 

    integration_points = torch.tile(gauss_pts,(Nx**3,1))
    # print("shape of integration_points", integration_points.size())
    scale_factor = h/2 
    integration_points = scale_factor * integration_points

    index = np.arange(1,Nx+1)-0.5
    ordered_pairs = np.array(np.meshgrid(index,index,index,indexing='ij'))
    ordered_pairs = ordered_pairs.reshape(3,-1).T

    # print(ordered_pairs)
    # print()
    ordered_pairs = torch.tensor(ordered_pairs)
    # print(ordered_pairs.size())
    ordered_pairs = torch.tile(ordered_pairs, (1,order**3)) # number of GQ points
    # print(ordered_pairs)

    ordered_pairs =  ordered_pairs.reshape(-1,3)
    # print(ordered_pairs)
    translation = ordered_pairs*h 
    # print(translation)

    integration_points = integration_points + translation 

    return long_weights.to(device), integration_points.to(device)


def generate_relu_dict4D_QMC(s,N0):
    # Sob = torch.quasirandom.SobolEngine(dimension =4, scramble= True, seed=None) 
    # samples = Sob.draw(N0).double() 

    # for i in range(s-1):
    #     samples = torch.cat([samples,Sob.draw(N0).double()],0)

    # Monte Carlo 
    samples = torch.rand(s*N0,4) 

    T =torch.tensor([[pi,0,0,0],[0,pi,0,0],[0,0,2*pi,0],[0,0,0,2*2]])
    shift = torch.tensor([0,0,0,-2])
    samples = samples@T + shift 

    f1 = torch.zeros(s*N0,1) 
    f2 = torch.zeros(s*N0,1)
    f3 = torch.zeros(s*N0,1)
    f4 = torch.zeros(s*N0,1)
    f5 = torch.zeros(s*N0,1)

    f1[:,0] = torch.cos(samples[:,0]) 
    f2[:,0] = torch.sin(samples[:,0]) * torch.cos(samples[:,1])
    f3[:,0] = torch.sin(samples[:,0]) * torch.sin(samples[:,1]) * torch.cos(samples[:,2])
    f4[:,0] = torch.sin(samples[:,0]) * torch.sin(samples[:,1]) * torch.sin(samples[:,2])  
    f5[:,0] = samples[:,3]

    Wb_tensor = torch.cat([f1,f2,f3,f4,f5],1) # N x 4 
    return Wb_tensor

def minimize_linear_layer_H1_explicit_assemble_efficient(model,alpha, target, g_N, weights, integration_points, w_bd, pts_bd, activation = 'relu',solver="direct" ):
    """ -div alpha grad u(x) + u = f 
    Parameters
    ----------
    model: 
        nn model
    alpha:
        alpha function
    target:
        rhs function f 
    pts_bd:
        integration points on the boundary, embdedded in the domain 
    """ 

    start_time = time.time() 
    w = model.fc1.weight.data 
    b = model.fc1.bias.data 
    neuron_num = b.size(0) 
    dim = integration_points.size(1) 
    
    coef_alpha = alpha(integration_points) # alpha  
    if activation == 'relu':
        basis_value_col = F.relu(integration_points @ w.t()+ b)**(model.k)
        weighted_basis_value_col = basis_value_col * weights 
        jac = weighted_basis_value_col.t() @ basis_value_col  # mass matrix 
        rhs = weighted_basis_value_col.t() @ (target(integration_points)) 

        # Todo1: assemble the boundary condition term <g,v>_{\Gamma_N} 
        size_pts_bd = int(pts_bd.size(0)/(2*dim))
        if g_N != None:
            bcs_N = g_N(dim)
            for ii, g_ii in bcs_N:
                # pts_bd_ii = pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
                weighted_g_N = -g_ii(pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:])* w_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
                basis_value_bd_col = F.relu(pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:] @ w.t()+ b)**(model.k)
                rhs += basis_value_bd_col.t() @ weighted_g_N

                weighted_g_N = g_ii(pts_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:])* w_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:]
                basis_value_bd_col = F.relu(pts_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:] @ w.t()+ b)**(model.k)
                rhs += basis_value_bd_col.t() @ weighted_g_N
        
        if model.k == 1:  
            for d in range(dim):
                basis_value_dxi_col = torch.heaviside(integration_points @ w.t()+ b, ZERO) * w.t()[d:d+1,:]
                weighted_basis_value_dx_col = basis_value_dxi_col * weights * coef_alpha 
                jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 
            
        else: 
            for d in range(dim):
                basis_value_dxi_col = model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * w.t()[d:d+1,:]
                weighted_basis_value_dx_col = basis_value_dxi_col * weights * coef_alpha  
                jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 
#             basis_value_dx_all_col = torch.stack([model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * w.t()[d:d+1,:] for d in range(dim)]) 
            # basis_value_dx_col = model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * w.t()[0:1,:]
            # basis_value_dy_col = model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * w.t()[1:2,:] 

    print("assembling the mass matrix time taken: ", time.time()-start_time) 


    start_time = time.time()    
    if solver == "cg": 
        sol, exit_code = linalg.cg(np.array(jac.detach().cpu()),np.array(rhs.detach().cpu()),tol=1e-12)
        sol = torch.tensor(sol).view(1,-1)
    elif solver == "direct": 
#         sol = np.linalg.inv( np.array(jac.detach().cpu()) )@np.array(rhs.detach().cpu())
        sol = (torch.linalg.solve( jac.detach(), rhs.detach())).view(1,-1)
    elif solver == "ls":
        sol = (torch.linalg.lstsq(jac.detach().cpu(),rhs.detach().cpu(),driver='gelsd').solution).view(1,-1)
        # sol = (torch.linalg.lstsq(jac.detach(),rhs.detach()).solution).view(1,-1) # gpu/cpu, driver = 'gels', cannot solve singular
    print("solving Ax = b time taken: ", time.time()-start_time)
    return sol 


def OGANeumannReLU4D(my_model,alpha, target,g_N, u_exact, u_exact_grad, N_list,num_epochs,plot_freq, M, k =1, rand_deter = 'deter', linear_solver = "direct"): 
    """ Orthogonal greedy algorithm using 1D ReLU dictionary over [-pi,pi]
    Parameters
    ----------
    my_model: 
        nn model 
    target: 
        target function
    num_epochs: int 
        number of training epochs 
    integration_intervals: int 
        number of subintervals for piecewise numerical quadrature 

    Returns
    -------
    err: tensor 
        rank 1 torch tensor to record the L2 error history  
    model: 
        trained nn model 
    """
    #Todo Done
    dim = 4 
    gw_expand, integration_points = MonteCarlo_Sobol_dDim_weights_points(M, d=dim)
    gw_expand = gw_expand.to(device)
    integration_points = integration_points.to(device)

    # define integration on the boundary 
    gw_expand_bd, integration_points_bd = PiecewiseGQ3D_weights_points(25, order = 2) 
    size_pts_bd = integration_points_bd.size(0) 
    gw_expand_bd_faces = torch.tile(gw_expand_bd,(2*dim,1))

    integration_points_bd_faces = torch.zeros(2*dim*integration_points_bd.size(0),dim).to(device)
    integration_points_bd_faces[0:size_pts_bd,0:1] = 0 
    integration_points_bd_faces[0:size_pts_bd,1:] = integration_points_bd[:]

    integration_points_bd_faces[size_pts_bd:size_pts_bd*2,0:1] = 1
    integration_points_bd_faces[size_pts_bd:size_pts_bd*2,1:] = integration_points_bd[:,:]

    integration_points_bd_faces[size_pts_bd*2:size_pts_bd*3,1:2] = 0 
    integration_points_bd_faces[size_pts_bd*2:size_pts_bd*3, 0:1] = integration_points_bd[:,0:1]
    integration_points_bd_faces[size_pts_bd*2:size_pts_bd*3,2:] =  integration_points_bd[:,1:]

    integration_points_bd_faces[size_pts_bd*3:size_pts_bd*4,1:2] = 1
    integration_points_bd_faces[size_pts_bd*3:size_pts_bd*4, 0:1] = integration_points_bd[:,0:1]
    integration_points_bd_faces[size_pts_bd*3:size_pts_bd*4,2:] =  integration_points_bd[:,1:]

    integration_points_bd_faces[size_pts_bd*4:size_pts_bd*5,2:3] = 0
    integration_points_bd_faces[size_pts_bd*4:size_pts_bd*5,0:2] = integration_points_bd[:,0:2]
    integration_points_bd_faces[size_pts_bd*4:size_pts_bd*5,3:] = integration_points_bd[:,2:]

    integration_points_bd_faces[size_pts_bd*5:size_pts_bd*6,2:3] = 1
    integration_points_bd_faces[size_pts_bd*5:size_pts_bd*6,0:2] = integration_points_bd[:,0:2]
    integration_points_bd_faces[size_pts_bd*5:size_pts_bd*6,3:] = integration_points_bd[:,2:]

    integration_points_bd_faces[size_pts_bd*6:size_pts_bd*7,3:4] = 0
    integration_points_bd_faces[size_pts_bd*6:size_pts_bd*7,0:3] = integration_points_bd[:,:]

    integration_points_bd_faces[size_pts_bd*7:size_pts_bd*8,3:4] = 1 
    integration_points_bd_faces[size_pts_bd*7:size_pts_bd*8,0:3] = integration_points_bd[:,:]

    err = torch.zeros(num_epochs+1)
    err_h10 = torch.zeros(num_epochs+1).to(device) 
    if my_model == None: 
        func_values = - target(integration_points)
        num_neuron = 0

        list_b = []
        list_w = []
    else: 
        func_values = - (target(integration_points) - my_model(integration_points).detach())
        bias = my_model.fc1.bias.detach().data
        weights = my_model.fc1.weight.detach().data
        num_neuron = int(bias.size(0))

        list_b = list(bias)
        list_w = list(weights)
    
    # initial error Todo Done
    func_values_sqrd = func_values*func_values
    # print(func_values_sqrd.size())
    # print(gw_expand.size()) 
    err[0]= torch.sum(func_values_sqrd*gw_expand)**0.5
    ## h1 seminorm 
    if u_exact_grad != None:
        u_grad = u_exact_grad() 
        for grad_i in u_grad: 
            err_h10[0] += torch.sum((grad_i(integration_points))**2 * gw_expand)**0.5
    
    start_time = time.time()
    solver = linear_solver

    N0 = np.prod(N_list)
    if rand_deter == 'deter':
        relu_dict_parameters = generate_relu_dict4D(N_list).to(device)
    print("using linear solver: ",solver)

    for i in range(num_epochs): 
        print("epoch: ",i+1, end = '\t')
        if rand_deter == 'rand':
            relu_dict_parameters = generate_relu_dict4D_QMC(1,N0).to(device) 
        if num_neuron == 0: 
            func_values = - target(integration_points)
        else: 
            func_values = - target(integration_points) + my_model(integration_points).detach()

        weight_func_values = func_values*gw_expand  
        basis_values = (F.relu( torch.matmul(integration_points,relu_dict_parameters[:,0:4].T ) - relu_dict_parameters[:,4])**k).T # uses broadcasting, # dimension 4 
        output = torch.matmul(basis_values,weight_func_values) #
        
        # grad u part
        alpha_coef = alpha(integration_points) # alpha 
        if my_model!= None:
            if k == 1:  
                derivative_part = torch.heaviside(integration_points @ (relu_dict_parameters[:,0:4].T) - relu_dict_parameters[:,4], ZERO) # dimension 4 
                derivative_part *= alpha_coef # alpha 
                for dx_i in range(dim): 
                    weight_dbasis_values_dxi =  (derivative_part * relu_dict_parameters.t()[dx_i:dx_i+1,:]) *gw_expand   
                    dmy_model_dxi = my_model.evaluate_derivative(integration_points,dx_i+1).detach()
                    output += torch.matmul(weight_dbasis_values_dxi.t(), dmy_model_dxi) 

            else:  
                derivative_part = k * F.relu(integration_points @ (relu_dict_parameters[:,0:4].T) - relu_dict_parameters[:,4])**(k-1) # dimension 4 
                derivative_part *= alpha_coef # alpha
                for dx_i in range(dim): 
                    weight_dbasis_values_dxi =  (derivative_part * relu_dict_parameters.t()[dx_i:dx_i+1,:]) * gw_expand    
                    dmy_model_dxi = my_model.evaluate_derivative(integration_points,dx_i+1).detach()
                    output += torch.matmul(weight_dbasis_values_dxi.t(), dmy_model_dxi) 
        
        #Todo2 boundary condition term -<g,v>_{\Gamma_N}  
        if g_N != None:
            bcs_N = g_N(dim) 
            for ii, g_ii in bcs_N: 
                
                weighted_g_N = -g_ii(integration_points_bd_faces[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:])* gw_expand_bd_faces[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
                basis_values_bd_faces = (F.relu( torch.matmul(integration_points_bd_faces[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:],relu_dict_parameters[:,0:4].T ) - relu_dict_parameters[:,4])**k).T
                output -= torch.matmul(basis_values_bd_faces,weighted_g_N)
                
                weighted_g_N = g_ii(integration_points_bd_faces[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:])* gw_expand_bd_faces[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:]
                basis_values_bd_faces = (F.relu( torch.matmul(integration_points_bd_faces[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:],relu_dict_parameters[:,0:4].T ) - relu_dict_parameters[:,4])**k).T
                output -= torch.matmul(basis_values_bd_faces,weighted_g_N)

        
        # output = torch.abs(torch.matmul(basis_values,weight_func_values)) # 
        output = torch.abs(output)
        neuron_index = torch.argmax(output.flatten())
        
        # print(neuron_index)
        list_w.append(relu_dict_parameters[neuron_index,0:4]) # dimension 4 
        list_b.append(-relu_dict_parameters[neuron_index,4])
        num_neuron += 1
        my_model = model(4,num_neuron,1,k).to(device)
        w_tensor = torch.stack(list_w, 0 ) 
        b_tensor = torch.tensor(list_b)
        my_model.fc1.weight.data[:,:] = w_tensor[:,:]
        my_model.fc1.bias.data[:] = b_tensor[:]

        #Todo Done 
#         alpha = None 
        sol = minimize_linear_layer_H1_explicit_assemble_efficient(my_model,alpha, target, g_N, gw_expand, integration_points,gw_expand_bd_faces, integration_points_bd_faces,activation = 'relu',solver = solver)

        my_model.fc2.weight.data[0,:] = sol[:]

        model_values = my_model(integration_points).detach()
        # L2 error ||u - u_n||
        diff_values_sqrd = (u_exact(integration_points) - model_values)**2 
        err[i+1]= torch.sum(diff_values_sqrd*gw_expand)**0.5

        # H10 error || grad(u) - grad(u_n) ||
        if u_exact_grad != None:
            for ii, grad_i in enumerate(u_grad):  
                my_model_dxi = my_model.evaluate_derivative(integration_points,ii+1).detach()  
                err_h10[i+1] += torch.sum((grad_i(integration_points) - my_model_dxi)**2 * gw_expand)**0.5

    print("time taken: ",time.time() - start_time)
    return err, err_h10.cpu(), my_model

# %% [markdown]
# In the following tests, we compare using deterministic dictionaries with using random dictionary for the following three target functions.
#
# - $\sin(\pi x_1) \sin(\pi x_2)$
# - $\sin(4\pi x_1) \sin(8\pi x_2)$
# - Gabor function

# %%
def u_exact(x):
    d = 4 
    cn =   7.03/d 
    return torch.exp(-torch.sum( cn**2 * (x - 0.5)**2,dim = 1, keepdim = True))  

def u_exact_grad():
    d = 4 
    cn = 7.03/d
    def make_grad_i(i):
        def grad_i(x):
            return torch.exp(-torch.sum(cn**2 * (x - 0.5)**2, dim=1, keepdim=True)) * (-2 * cn**2 * (x[:, i:i+1] - 0.5))
        return grad_i 
    
    u_grad=[] 
    for i in range(d):
        u_grad.append(make_grad_i(i))
    return u_grad


def alpha(x): 
    return torch.ones(x.size(0),1).to(device)
    # return 0.5 * torch.sin(6 * pi*x[:,0:1]) + 1. 

def target(x):
    d = 4 
    cn =   7.03/d 
    z = torch.exp(-torch.sum( cn**2 * (x - 0.5)**2,dim = 1, keepdim = True)) 
    return z* ( -torch.sum(  (2 *cn**2 * (x - 0.5))**2 - 2*cn**2 ,dim = 1, keepdim = True) +1)

def g_N(dim):
    def make_g(i):
        def g_i(x):
            d = 4 
            cn = 7.03 / d
            return torch.exp(-torch.sum(cn**2 * (x - 0.5)**2, dim=1, keepdim=True)) * (-2 * cn**2 * (x[:, i:i+1] - 0.5))
        return g_i

    bcs_N = []
    for i in range(dim):
        bcs_N.append((i, make_g(i)))
    
    return bcs_N

dim = 4 
function_name = "gaussian" 
filename_write = "data/4DOGA-{}-order.txt".format(function_name)
M = 500000  
f_write = open(filename_write, "a")
f_write.write("Numerical Integration MC points: {} \n".format(M))
f_write.close() 
save = True 
write2file = True
rand_deter = 'rand'


for N_list in [[2**2,2**2,2**3,2**3]]: # ,[2**6,2**6],[2**7,2**7] 

    f_write = open(filename_write, "a")
    my_model = None   
    exponent = 9  
    num_epochs = 2**exponent  
    plot_freq = num_epochs 
    N = np.prod(N_list)
    relu_k = 4 
    err_QMC2, err_h10, my_model = OGANeumannReLU4D(my_model,alpha, target,g_N, u_exact,u_exact_grad, N_list,num_epochs,plot_freq, M, k = relu_k, rand_deter= rand_deter, linear_solver = "direct")
    
    if save: 
        folder = 'data/'
        filename = folder + 'err_OGA_4D_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,num_epochs,N)
        torch.save(err_QMC2,filename) 
        folder = 'data/'
        filename = folder + 'model_OGA_4D_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,num_epochs,N)
        torch.save(my_model,filename)
    show_convergence_order2(err_QMC2,err_h10,exponent,N,filename_write,write2file = write2file)
    show_convergence_order_latex2(err_QMC2,err_h10,exponent,k=relu_k,d = dim)
# Out:
# using linear solver:  direct
# epoch:  1	assembling the mass matrix time taken:  0.002882719039916992
# solving Ax = b time taken:  0.000209808349609375
# epoch:  2	assembling the mass matrix time taken:  0.003682374954223633
# solving Ax = b time taken:  0.02903151512145996
# epoch:  3	assembling the mass matrix time taken:  0.002955913543701172
# solving Ax = b time taken:  0.0007290840148925781
# epoch:  4	assembling the mass matrix time taken:  0.0030450820922851562
# solving Ax = b time taken:  0.0008268356323242188
# epoch:  5	assembling the mass matrix time taken:  0.0029900074005126953
# solving Ax = b time taken:  0.0010879039764404297
# epoch:  6	assembling the mass matrix time taken:  0.003939628601074219
# solving Ax = b time taken:  0.0012705326080322266
# epoch:  7	assembling the mass matrix time taken:  0.002982616424560547
# solving Ax = b time taken:  0.0014963150024414062
# epoch:  8	assembling the mass matrix time taken:  0.0035283565521240234
# solving Ax = b time taken:  0.001605987548828125
# epoch:  9	assembling the mass matrix time taken:  0.002991914749145508
# solving Ax = b time taken:  0.0020198822021484375
# epoch:  10	assembling the mass matrix time taken:  0.0035028457641601562
# solving Ax = b time taken:  0.002018451690673828
# epoch:  11	assembling the mass matrix time taken:  0.0029754638671875
# solving Ax = b time taken:  0.0024285316467285156
# epoch:  12	assembling the mass matrix time taken:  0.003470897674560547
# solving Ax = b time taken:  0.0024077892303466797
# epoch:  13	assembling the mass matrix time taken:  0.0028836727142333984
# solving Ax = b time taken:  0.002968311309814453
# epoch:  14	assembling the mass matrix time taken:  0.0034971237182617188
# solving Ax = b time taken:  0.002900838851928711
# epoch:  15	assembling the mass matrix time taken:  0.0028798580169677734
# solving Ax = b time taken:  0.003348112106323242
# epoch:  16	assembling the mass matrix time taken:  0.0032958984375
# solving Ax = b time taken:  0.0033223628997802734
# epoch:  17	assembling the mass matrix time taken:  0.002955913543701172
# solving Ax = b time taken:  0.003607034683227539
# epoch:  18	assembling the mass matrix time taken:  0.0036416053771972656
# solving Ax = b time taken:  0.003644227981567383
# epoch:  19	assembling the mass matrix time taken:  0.003038644790649414
# solving Ax = b time taken:  0.004065275192260742
# epoch:  20	assembling the mass matrix time taken:  0.0031042098999023438
# solving Ax = b time taken:  0.0040874481201171875
# epoch:  21	assembling the mass matrix time taken:  0.002988100051879883
# solving Ax = b time taken:  0.0045626163482666016
# epoch:  22	assembling the mass matrix time taken:  0.0030698776245117188
# solving Ax = b time taken:  0.004624366760253906
# epoch:  23	assembling the mass matrix time taken:  0.003031492233276367
# solving Ax = b time taken:  0.00502467155456543
# epoch:  24	assembling the mass matrix time taken:  0.00308990478515625
# solving Ax = b time taken:  0.0050830841064453125
# epoch:  25	assembling the mass matrix time taken:  0.003004312515258789
# solving Ax = b time taken:  0.005490779876708984
# epoch:  26	assembling the mass matrix time taken:  0.003025531768798828
# solving Ax = b time taken:  0.005583524703979492
# epoch:  27	assembling the mass matrix time taken:  0.0030198097229003906
# solving Ax = b time taken:  0.0059757232666015625
# epoch:  28	assembling the mass matrix time taken:  0.003102540969848633
# solving Ax = b time taken:  0.006049156188964844
# epoch:  29	assembling the mass matrix time taken:  0.0030133724212646484
# solving Ax = b time taken:  0.0064203739166259766
# epoch:  30	assembling the mass matrix time taken:  0.0030753612518310547
# solving Ax = b time taken:  0.006575345993041992
# epoch:  31	assembling the mass matrix time taken:  0.002946615219116211
# solving Ax = b time taken:  0.006911516189575195
# epoch:  32	assembling the mass matrix time taken:  0.0030813217163085938
# solving Ax = b time taken:  0.007002115249633789
# epoch:  33	assembling the mass matrix time taken:  0.003076314926147461
# solving Ax = b time taken:  0.007693767547607422
# epoch:  34	assembling the mass matrix time taken:  0.0033576488494873047
# solving Ax = b time taken:  0.007659912109375
# epoch:  35	assembling the mass matrix time taken:  0.0029821395874023438
# solving Ax = b time taken:  0.008114099502563477
# epoch:  36	assembling the mass matrix time taken:  0.003082752227783203
# solving Ax = b time taken:  0.008068084716796875
# epoch:  37	assembling the mass matrix time taken:  0.0029730796813964844
# solving Ax = b time taken:  0.008554458618164062
# epoch:  38	assembling the mass matrix time taken:  0.003089427947998047
# solving Ax = b time taken:  0.008553266525268555
# epoch:  39	assembling the mass matrix time taken:  0.0028901100158691406
# solving Ax = b time taken:  0.00895547866821289
# epoch:  40	assembling the mass matrix time taken:  0.0030939579010009766
# solving Ax = b time taken:  0.008902549743652344
# epoch:  41	assembling the mass matrix time taken:  0.00289154052734375
# solving Ax = b time taken:  0.009373903274536133
# epoch:  42	assembling the mass matrix time taken:  0.0030739307403564453
# solving Ax = b time taken:  0.009372234344482422
# epoch:  43	assembling the mass matrix time taken:  0.003009319305419922
# solving Ax = b time taken:  0.010027885437011719
# epoch:  44	assembling the mass matrix time taken:  0.003034830093383789
# solving Ax = b time taken:  0.009839773178100586
# epoch:  45	assembling the mass matrix time taken:  0.009293556213378906
# solving Ax = b time taken:  0.010280847549438477
# epoch:  46	assembling the mass matrix time taken:  0.015874385833740234
# solving Ax = b time taken:  0.010287284851074219
# epoch:  47	assembling the mass matrix time taken:  0.009398221969604492
# solving Ax = b time taken:  0.010721206665039062
# epoch:  48	assembling the mass matrix time taken:  0.006517171859741211
# solving Ax = b time taken:  0.01068115234375
# epoch:  49	assembling the mass matrix time taken:  0.002916097640991211
# solving Ax = b time taken:  0.011241674423217773
# epoch:  50	assembling the mass matrix time taken:  0.003107786178588867
# solving Ax = b time taken:  0.011287927627563477
# epoch:  51	assembling the mass matrix time taken:  0.0029191970825195312
# solving Ax = b time taken:  0.011690139770507812
# epoch:  52	assembling the mass matrix time taken:  0.003065347671508789
# solving Ax = b time taken:  0.011739492416381836
# epoch:  53	assembling the mass matrix time taken:  0.0029573440551757812
# solving Ax = b time taken:  0.012247800827026367
# epoch:  54	assembling the mass matrix time taken:  0.003100156784057617
# solving Ax = b time taken:  0.012180089950561523
# epoch:  55	assembling the mass matrix time taken:  0.0037860870361328125
# solving Ax = b time taken:  0.012689352035522461
# epoch:  56	assembling the mass matrix time taken:  0.003029346466064453
# solving Ax = b time taken:  0.012672662734985352
# epoch:  57	assembling the mass matrix time taken:  0.0029287338256835938
# solving Ax = b time taken:  0.01311802864074707
# epoch:  58	assembling the mass matrix time taken:  0.0030748844146728516
# solving Ax = b time taken:  0.013208627700805664
# epoch:  59	assembling the mass matrix time taken:  0.002942323684692383
# solving Ax = b time taken:  0.013633489608764648
# epoch:  60	assembling the mass matrix time taken:  0.0030603408813476562
# solving Ax = b time taken:  0.013638496398925781
# epoch:  61	assembling the mass matrix time taken:  0.0028460025787353516
# solving Ax = b time taken:  0.014114618301391602
# epoch:  62	assembling the mass matrix time taken:  0.003032684326171875
# solving Ax = b time taken:  0.014412164688110352
# epoch:  63	assembling the mass matrix time taken:  0.002897500991821289
# solving Ax = b time taken:  0.0148773193359375
# epoch:  64	assembling the mass matrix time taken:  0.003066539764404297
# solving Ax = b time taken:  0.01457357406616211
# epoch:  65	assembling the mass matrix time taken:  0.00289154052734375
# solving Ax = b time taken:  0.01739192008972168
# epoch:  66	assembling the mass matrix time taken:  0.0031185150146484375
# solving Ax = b time taken:  0.017867565155029297
# epoch:  67	assembling the mass matrix time taken:  0.0029039382934570312
# solving Ax = b time taken:  0.017889022827148438
# epoch:  68	assembling the mass matrix time taken:  0.0031054019927978516
# solving Ax = b time taken:  0.017873764038085938
# epoch:  69	assembling the mass matrix time taken:  0.002904176712036133
# solving Ax = b time taken:  0.0184478759765625
# epoch:  70	assembling the mass matrix time taken:  0.0031137466430664062
# solving Ax = b time taken:  0.01894831657409668
# epoch:  71	assembling the mass matrix time taken:  0.0029048919677734375
# solving Ax = b time taken:  0.018827199935913086
# epoch:  72	assembling the mass matrix time taken:  0.0038046836853027344
# solving Ax = b time taken:  0.01790595054626465
# epoch:  73	assembling the mass matrix time taken:  0.002897500991821289
# solving Ax = b time taken:  0.019748210906982422
# epoch:  74	assembling the mass matrix time taken:  0.0030260086059570312
# solving Ax = b time taken:  0.020589113235473633
# epoch:  75	assembling the mass matrix time taken:  0.0029213428497314453
# solving Ax = b time taken:  0.020639419555664062
# epoch:  76	assembling the mass matrix time taken:  0.0030210018157958984
# solving Ax = b time taken:  0.020984411239624023
# epoch:  77	assembling the mass matrix time taken:  0.002910137176513672
# solving Ax = b time taken:  0.02158355712890625
# epoch:  78	assembling the mass matrix time taken:  0.0030999183654785156
# solving Ax = b time taken:  0.02251410484313965
# epoch:  79	assembling the mass matrix time taken:  0.002951383590698242
# solving Ax = b time taken:  0.022065162658691406
# epoch:  80	assembling the mass matrix time taken:  0.003117799758911133
# solving Ax = b time taken:  0.02086615562438965
# epoch:  81	assembling the mass matrix time taken:  0.002927064895629883
# solving Ax = b time taken:  0.02234029769897461
# epoch:  82	assembling the mass matrix time taken:  0.003178119659423828
# solving Ax = b time taken:  0.02332305908203125
# epoch:  83	assembling the mass matrix time taken:  0.010019063949584961
# solving Ax = b time taken:  0.022682666778564453
# epoch:  84	assembling the mass matrix time taken:  0.0030426979064941406
# solving Ax = b time taken:  0.02267289161682129
# epoch:  85	assembling the mass matrix time taken:  0.002988576889038086
# solving Ax = b time taken:  0.023054122924804688
# epoch:  86	assembling the mass matrix time taken:  0.003100872039794922
# solving Ax = b time taken:  0.024259090423583984
# epoch:  87	assembling the mass matrix time taken:  0.002914905548095703
# solving Ax = b time taken:  0.023502111434936523
# epoch:  88	assembling the mass matrix time taken:  0.003116607666015625
# solving Ax = b time taken:  0.023115873336791992
# epoch:  89	assembling the mass matrix time taken:  0.0029251575469970703
# solving Ax = b time taken:  0.023767948150634766
# epoch:  90	assembling the mass matrix time taken:  0.0030393600463867188
# solving Ax = b time taken:  0.02509331703186035
# epoch:  91	assembling the mass matrix time taken:  0.00301361083984375
# solving Ax = b time taken:  0.024286746978759766
# epoch:  92	assembling the mass matrix time taken:  0.0031807422637939453
# solving Ax = b time taken:  0.02426624298095703
# epoch:  93	assembling the mass matrix time taken:  0.0030117034912109375
# solving Ax = b time taken:  0.02463364601135254
# epoch:  94	assembling the mass matrix time taken:  0.0030291080474853516
# solving Ax = b time taken:  0.02602553367614746
# epoch:  95	assembling the mass matrix time taken:  0.0028896331787109375
# solving Ax = b time taken:  0.025113582611083984
# epoch:  96	assembling the mass matrix time taken:  0.0031080245971679688
# solving Ax = b time taken:  0.02370166778564453
# epoch:  97	assembling the mass matrix time taken:  0.0030870437622070312
# solving Ax = b time taken:  0.02521991729736328
# epoch:  98	assembling the mass matrix time taken:  0.0031621456146240234
# solving Ax = b time taken:  0.02673959732055664
# epoch:  99	assembling the mass matrix time taken:  0.0029778480529785156
# solving Ax = b time taken:  0.025622129440307617
# epoch:  100	assembling the mass matrix time taken:  0.003131866455078125
# solving Ax = b time taken:  0.025806903839111328
# epoch:  101	assembling the mass matrix time taken:  0.003103971481323242
# solving Ax = b time taken:  0.026168346405029297
# epoch:  102	assembling the mass matrix time taken:  0.003135204315185547
# solving Ax = b time taken:  0.027661561965942383
# epoch:  103	assembling the mass matrix time taken:  0.0029535293579101562
# solving Ax = b time taken:  0.026584386825561523
# epoch:  104	assembling the mass matrix time taken:  0.003312826156616211
# solving Ax = b time taken:  0.02663397789001465
# epoch:  105	assembling the mass matrix time taken:  0.002910137176513672
# solving Ax = b time taken:  0.026910781860351562
# epoch:  106	assembling the mass matrix time taken:  0.0030901432037353516
# solving Ax = b time taken:  0.028562307357788086
# epoch:  107	assembling the mass matrix time taken:  0.002923727035522461
# solving Ax = b time taken:  0.027398109436035156
# epoch:  108	assembling the mass matrix time taken:  0.003065824508666992
# solving Ax = b time taken:  0.02761983871459961
# epoch:  109	assembling the mass matrix time taken:  0.003046751022338867
# solving Ax = b time taken:  0.027855396270751953
# epoch:  110	assembling the mass matrix time taken:  0.0030298233032226562
# solving Ax = b time taken:  0.029531478881835938
# epoch:  111	assembling the mass matrix time taken:  0.0028514862060546875
# solving Ax = b time taken:  0.02828240394592285
# epoch:  112	assembling the mass matrix time taken:  0.0030002593994140625
# solving Ax = b time taken:  0.028315067291259766
# epoch:  113	assembling the mass matrix time taken:  0.003020048141479492
# solving Ax = b time taken:  0.028760194778442383
# epoch:  114	assembling the mass matrix time taken:  0.0029921531677246094
# solving Ax = b time taken:  0.029264211654663086
# epoch:  115	assembling the mass matrix time taken:  0.0029349327087402344
# solving Ax = b time taken:  0.029175519943237305
# epoch:  116	assembling the mass matrix time taken:  0.003004312515258789
# solving Ax = b time taken:  0.02930140495300293
# epoch:  117	assembling the mass matrix time taken:  0.002859830856323242
# solving Ax = b time taken:  0.02963566780090332
# epoch:  118	assembling the mass matrix time taken:  0.002965688705444336
# solving Ax = b time taken:  0.03021407127380371
# epoch:  119	assembling the mass matrix time taken:  0.0029494762420654297
# solving Ax = b time taken:  0.0299530029296875
# epoch:  120	assembling the mass matrix time taken:  0.002980470657348633
# solving Ax = b time taken:  0.030081987380981445
# epoch:  121	assembling the mass matrix time taken:  0.0029458999633789062
# solving Ax = b time taken:  0.030680179595947266
# epoch:  122	assembling the mass matrix time taken:  0.002905130386352539
# solving Ax = b time taken:  0.030844926834106445
# epoch:  123	assembling the mass matrix time taken:  0.0028734207153320312
# solving Ax = b time taken:  0.031032323837280273
# epoch:  124	assembling the mass matrix time taken:  0.002862215042114258
# solving Ax = b time taken:  0.03115391731262207
# epoch:  125	assembling the mass matrix time taken:  0.0028641223907470703
# solving Ax = b time taken:  0.03143787384033203
# epoch:  126	assembling the mass matrix time taken:  0.003006458282470703
# solving Ax = b time taken:  0.0315701961517334
# epoch:  127	assembling the mass matrix time taken:  0.0029087066650390625
# solving Ax = b time taken:  0.03191971778869629
# epoch:  128	assembling the mass matrix time taken:  0.002874135971069336
# solving Ax = b time taken:  0.03191494941711426
# epoch:  129	assembling the mass matrix time taken:  0.0029630661010742188
# solving Ax = b time taken:  0.038221120834350586
# epoch:  130	assembling the mass matrix time taken:  0.002951383590698242
# solving Ax = b time taken:  0.03991246223449707
# epoch:  131	assembling the mass matrix time taken:  0.002887725830078125
# solving Ax = b time taken:  0.038671016693115234
# epoch:  132	assembling the mass matrix time taken:  0.0030145645141601562
# solving Ax = b time taken:  0.03993988037109375
# epoch:  133	assembling the mass matrix time taken:  0.002942800521850586
# solving Ax = b time taken:  0.03903055191040039
# epoch:  134	assembling the mass matrix time taken:  0.0030465126037597656
# solving Ax = b time taken:  0.04058647155761719
# epoch:  135	assembling the mass matrix time taken:  0.002997875213623047
# solving Ax = b time taken:  0.03945136070251465
# epoch:  136	assembling the mass matrix time taken:  0.002977132797241211
# solving Ax = b time taken:  0.040686845779418945
# epoch:  137	assembling the mass matrix time taken:  0.0033521652221679688
# solving Ax = b time taken:  0.03978085517883301
# epoch:  138	assembling the mass matrix time taken:  0.0029287338256835938
# solving Ax = b time taken:  0.041652679443359375
# epoch:  139	assembling the mass matrix time taken:  0.002951383590698242
# solving Ax = b time taken:  0.04035782814025879
# epoch:  140	assembling the mass matrix time taken:  0.0031037330627441406
# solving Ax = b time taken:  0.04047346115112305
# epoch:  141	assembling the mass matrix time taken:  0.002858877182006836
# solving Ax = b time taken:  0.04076719284057617
# epoch:  142	assembling the mass matrix time taken:  0.0029296875
# solving Ax = b time taken:  0.0409390926361084
# epoch:  143	assembling the mass matrix time taken:  0.002900838851928711
# solving Ax = b time taken:  0.04121208190917969
# epoch:  144	assembling the mass matrix time taken:  0.003105640411376953
# solving Ax = b time taken:  0.041205644607543945
# epoch:  145	assembling the mass matrix time taken:  0.002973794937133789
# solving Ax = b time taken:  0.04720473289489746
# epoch:  146	assembling the mass matrix time taken:  0.0029077529907226562
# solving Ax = b time taken:  0.046761274337768555
# epoch:  147	assembling the mass matrix time taken:  0.0028829574584960938
# solving Ax = b time taken:  0.04750943183898926
# epoch:  148	assembling the mass matrix time taken:  0.002955198287963867
# solving Ax = b time taken:  0.04667019844055176
# epoch:  149	assembling the mass matrix time taken:  0.0029287338256835938
# solving Ax = b time taken:  0.047574758529663086
# epoch:  150	assembling the mass matrix time taken:  0.0028679370880126953
# solving Ax = b time taken:  0.04762554168701172
# epoch:  151	assembling the mass matrix time taken:  0.0029287338256835938
# solving Ax = b time taken:  0.04821467399597168
# epoch:  152	assembling the mass matrix time taken:  0.0028617382049560547
# solving Ax = b time taken:  0.04658794403076172
# epoch:  153	assembling the mass matrix time taken:  0.002959012985229492
# solving Ax = b time taken:  0.04339456558227539
# epoch:  154	assembling the mass matrix time taken:  0.0029344558715820312
# solving Ax = b time taken:  0.04348611831665039
# epoch:  155	assembling the mass matrix time taken:  0.003014087677001953
# solving Ax = b time taken:  0.043730974197387695
# epoch:  156	assembling the mass matrix time taken:  0.0029387474060058594
# solving Ax = b time taken:  0.04397392272949219
# epoch:  157	assembling the mass matrix time taken:  0.0029189586639404297
# solving Ax = b time taken:  0.04429912567138672
# epoch:  158	assembling the mass matrix time taken:  0.002931356430053711
# solving Ax = b time taken:  0.04434013366699219
# epoch:  159	assembling the mass matrix time taken:  0.0029664039611816406
# solving Ax = b time taken:  0.044518470764160156
# epoch:  160	assembling the mass matrix time taken:  0.0029256343841552734
# solving Ax = b time taken:  0.04452705383300781
# epoch:  161	assembling the mass matrix time taken:  0.0029273033142089844
# solving Ax = b time taken:  0.04502415657043457
# epoch:  162	assembling the mass matrix time taken:  0.002920389175415039
# solving Ax = b time taken:  0.04536747932434082
# epoch:  163	assembling the mass matrix time taken:  0.0030019283294677734
# solving Ax = b time taken:  0.04548311233520508
# epoch:  164	assembling the mass matrix time taken:  0.0028693675994873047
# solving Ax = b time taken:  0.04566502571105957
# epoch:  165	assembling the mass matrix time taken:  0.002890348434448242
# solving Ax = b time taken:  0.04589557647705078
# epoch:  166	assembling the mass matrix time taken:  0.0031273365020751953
# solving Ax = b time taken:  0.04614734649658203
# epoch:  167	assembling the mass matrix time taken:  0.0028443336486816406
# solving Ax = b time taken:  0.04635906219482422
# epoch:  168	assembling the mass matrix time taken:  0.0029249191284179688
# solving Ax = b time taken:  0.04638314247131348
# epoch:  169	assembling the mass matrix time taken:  0.0029544830322265625
# solving Ax = b time taken:  0.046584129333496094
# epoch:  170	assembling the mass matrix time taken:  0.002835988998413086
# solving Ax = b time taken:  0.04685044288635254
# epoch:  171	assembling the mass matrix time taken:  0.0028874874114990234
# solving Ax = b time taken:  0.04711747169494629
# epoch:  172	assembling the mass matrix time taken:  0.002907276153564453
# solving Ax = b time taken:  0.04724240303039551
# epoch:  173	assembling the mass matrix time taken:  0.0028715133666992188
# solving Ax = b time taken:  0.047640085220336914
# epoch:  174	assembling the mass matrix time taken:  0.0028676986694335938
# solving Ax = b time taken:  0.04784584045410156
# epoch:  175	assembling the mass matrix time taken:  0.0028569698333740234
# solving Ax = b time taken:  0.0479578971862793
# epoch:  176	assembling the mass matrix time taken:  0.002862691879272461
# solving Ax = b time taken:  0.047945261001586914
# epoch:  177	assembling the mass matrix time taken:  0.0029473304748535156
# solving Ax = b time taken:  0.04850602149963379
# epoch:  178	assembling the mass matrix time taken:  0.0029082298278808594
# solving Ax = b time taken:  0.04865860939025879
# epoch:  179	assembling the mass matrix time taken:  0.002898693084716797
# solving Ax = b time taken:  0.048990726470947266
# epoch:  180	assembling the mass matrix time taken:  0.0029077529907226562
# solving Ax = b time taken:  0.04906010627746582
# epoch:  181	assembling the mass matrix time taken:  0.0028738975524902344
# solving Ax = b time taken:  0.049274444580078125
# epoch:  182	assembling the mass matrix time taken:  0.003258943557739258
# solving Ax = b time taken:  0.049536705017089844
# epoch:  183	assembling the mass matrix time taken:  0.0032269954681396484
# solving Ax = b time taken:  0.049657583236694336
# epoch:  184	assembling the mass matrix time taken:  0.003139019012451172
# solving Ax = b time taken:  0.04977703094482422
# epoch:  185	assembling the mass matrix time taken:  0.002876758575439453
# solving Ax = b time taken:  0.05003690719604492
# epoch:  186	assembling the mass matrix time taken:  0.0028638839721679688
# solving Ax = b time taken:  0.050179481506347656
# epoch:  187	assembling the mass matrix time taken:  0.0028831958770751953
# solving Ax = b time taken:  0.05042672157287598
# epoch:  188	assembling the mass matrix time taken:  0.0031867027282714844
# solving Ax = b time taken:  0.05052518844604492
# epoch:  189	assembling the mass matrix time taken:  0.002969026565551758
# solving Ax = b time taken:  0.05087471008300781
# epoch:  190	assembling the mass matrix time taken:  0.0030341148376464844
# solving Ax = b time taken:  0.05103588104248047
# epoch:  191	assembling the mass matrix time taken:  0.0030355453491210938
# solving Ax = b time taken:  0.05118918418884277
# epoch:  192	assembling the mass matrix time taken:  0.003034353256225586
# solving Ax = b time taken:  0.05118274688720703
# epoch:  193	assembling the mass matrix time taken:  0.0028924942016601562
# solving Ax = b time taken:  0.07097411155700684
# epoch:  194	assembling the mass matrix time taken:  0.003020763397216797
# solving Ax = b time taken:  0.0584869384765625
# epoch:  195	assembling the mass matrix time taken:  0.0029578208923339844
# solving Ax = b time taken:  0.07008814811706543
# epoch:  196	assembling the mass matrix time taken:  0.002992868423461914
# solving Ax = b time taken:  0.058908939361572266
# epoch:  197	assembling the mass matrix time taken:  0.0029001235961914062
# solving Ax = b time taken:  0.07069969177246094
# epoch:  198	assembling the mass matrix time taken:  0.0029752254486083984
# solving Ax = b time taken:  0.05922985076904297
# epoch:  199	assembling the mass matrix time taken:  0.0028505325317382812
# solving Ax = b time taken:  0.0712742805480957
# epoch:  200	assembling the mass matrix time taken:  0.002981424331665039
# solving Ax = b time taken:  0.059580326080322266
# epoch:  201	assembling the mass matrix time taken:  0.0028901100158691406
# solving Ax = b time taken:  0.07175946235656738
# epoch:  202	assembling the mass matrix time taken:  0.0029456615447998047
# solving Ax = b time taken:  0.06041741371154785
# epoch:  203	assembling the mass matrix time taken:  0.0030794143676757812
# solving Ax = b time taken:  0.07227778434753418
# epoch:  204	assembling the mass matrix time taken:  0.0029823780059814453
# solving Ax = b time taken:  0.06055784225463867
# epoch:  205	assembling the mass matrix time taken:  0.002912282943725586
# solving Ax = b time taken:  0.07292699813842773
# epoch:  206	assembling the mass matrix time taken:  0.002944469451904297
# solving Ax = b time taken:  0.061168670654296875
# epoch:  207	assembling the mass matrix time taken:  0.0028481483459472656
# solving Ax = b time taken:  0.0732576847076416
# epoch:  208	assembling the mass matrix time taken:  0.0029191970825195312
# solving Ax = b time taken:  0.061415672302246094
# epoch:  209	assembling the mass matrix time taken:  0.002913236618041992
# solving Ax = b time taken:  0.07345843315124512
# epoch:  210	assembling the mass matrix time taken:  0.003117084503173828
# solving Ax = b time taken:  0.06318831443786621
# epoch:  211	assembling the mass matrix time taken:  0.0028696060180664062
# solving Ax = b time taken:  0.07346749305725098
# epoch:  212	assembling the mass matrix time taken:  0.0032913684844970703
# solving Ax = b time taken:  0.06243157386779785
# epoch:  213	assembling the mass matrix time taken:  0.0028922557830810547
# solving Ax = b time taken:  0.07384753227233887
# epoch:  214	assembling the mass matrix time taken:  0.0030183792114257812
# solving Ax = b time taken:  0.06416130065917969
# epoch:  215	assembling the mass matrix time taken:  0.0029175281524658203
# solving Ax = b time taken:  0.07415604591369629
# epoch:  216	assembling the mass matrix time taken:  0.0030975341796875
# solving Ax = b time taken:  0.0632028579711914
# epoch:  217	assembling the mass matrix time taken:  0.002928495407104492
# solving Ax = b time taken:  0.0745859146118164
# epoch:  218	assembling the mass matrix time taken:  0.0031065940856933594
# solving Ax = b time taken:  0.06576800346374512
# epoch:  219	assembling the mass matrix time taken:  0.0028607845306396484
# solving Ax = b time taken:  0.0749197006225586
# epoch:  220	assembling the mass matrix time taken:  0.0030486583709716797
# solving Ax = b time taken:  0.06443905830383301
# epoch:  221	assembling the mass matrix time taken:  0.0028629302978515625
# solving Ax = b time taken:  0.07536602020263672
# epoch:  222	assembling the mass matrix time taken:  0.0033140182495117188
# solving Ax = b time taken:  0.06666445732116699
# epoch:  223	assembling the mass matrix time taken:  0.0028595924377441406
# solving Ax = b time taken:  0.07550477981567383
# epoch:  224	assembling the mass matrix time taken:  0.003093719482421875
# solving Ax = b time taken:  0.06451892852783203
# epoch:  225	assembling the mass matrix time taken:  0.0028815269470214844
# solving Ax = b time taken:  0.06871414184570312
# epoch:  226	assembling the mass matrix time taken:  0.0030469894409179688
# solving Ax = b time taken:  0.06881856918334961
# epoch:  227	assembling the mass matrix time taken:  0.002930879592895508
# solving Ax = b time taken:  0.0692751407623291
# epoch:  228	assembling the mass matrix time taken:  0.0030324459075927734
# solving Ax = b time taken:  0.06814360618591309
# epoch:  229	assembling the mass matrix time taken:  0.002859830856323242
# solving Ax = b time taken:  0.06973862648010254
# epoch:  230	assembling the mass matrix time taken:  0.003083467483520508
# solving Ax = b time taken:  0.0700838565826416
# epoch:  231	assembling the mass matrix time taken:  0.002955198287963867
# solving Ax = b time taken:  0.07013511657714844
# epoch:  232	assembling the mass matrix time taken:  0.003102540969848633
# solving Ax = b time taken:  0.06877899169921875
# epoch:  233	assembling the mass matrix time taken:  0.002873659133911133
# solving Ax = b time taken:  0.07053947448730469
# epoch:  234	assembling the mass matrix time taken:  0.0029642581939697266
# solving Ax = b time taken:  0.07185864448547363
# epoch:  235	assembling the mass matrix time taken:  0.0029449462890625
# solving Ax = b time taken:  0.07087159156799316
# epoch:  236	assembling the mass matrix time taken:  0.0030548572540283203
# solving Ax = b time taken:  0.0711982250213623
# epoch:  237	assembling the mass matrix time taken:  0.0028638839721679688
# solving Ax = b time taken:  0.07129025459289551
# epoch:  238	assembling the mass matrix time taken:  0.002905607223510742
# solving Ax = b time taken:  0.07162141799926758
# epoch:  239	assembling the mass matrix time taken:  0.0028846263885498047
# solving Ax = b time taken:  0.07187342643737793
# epoch:  240	assembling the mass matrix time taken:  0.0029358863830566406
# solving Ax = b time taken:  0.07164430618286133
# epoch:  241	assembling the mass matrix time taken:  0.002893686294555664
# solving Ax = b time taken:  0.07242798805236816
# epoch:  242	assembling the mass matrix time taken:  0.0028884410858154297
# solving Ax = b time taken:  0.07268619537353516
# epoch:  243	assembling the mass matrix time taken:  0.002858400344848633
# solving Ax = b time taken:  0.07296228408813477
# epoch:  244	assembling the mass matrix time taken:  0.002933979034423828
# solving Ax = b time taken:  0.07283711433410645
# epoch:  245	assembling the mass matrix time taken:  0.0028591156005859375
# solving Ax = b time taken:  0.07311534881591797
# epoch:  246	assembling the mass matrix time taken:  0.0029458999633789062
# solving Ax = b time taken:  0.07324051856994629
# epoch:  247	assembling the mass matrix time taken:  0.002889394760131836
# solving Ax = b time taken:  0.0735313892364502
# epoch:  248	assembling the mass matrix time taken:  0.0029375553131103516
# solving Ax = b time taken:  0.07360243797302246
# epoch:  249	assembling the mass matrix time taken:  0.0028595924377441406
# solving Ax = b time taken:  0.07395315170288086
# epoch:  250	assembling the mass matrix time taken:  0.00295257568359375
# solving Ax = b time taken:  0.07431864738464355
# epoch:  251	assembling the mass matrix time taken:  0.002867460250854492
# solving Ax = b time taken:  0.0746462345123291
# epoch:  252	assembling the mass matrix time taken:  0.0028564929962158203
# solving Ax = b time taken:  0.07463574409484863
# epoch:  253	assembling the mass matrix time taken:  0.002858400344848633
# solving Ax = b time taken:  0.07502603530883789
# epoch:  254	assembling the mass matrix time taken:  0.002963542938232422
# solving Ax = b time taken:  0.07517576217651367
# epoch:  255	assembling the mass matrix time taken:  0.0028667449951171875
# solving Ax = b time taken:  0.07548809051513672
# epoch:  256	assembling the mass matrix time taken:  0.0029296875
# solving Ax = b time taken:  0.07523798942565918
# epoch:  257	assembling the mass matrix time taken:  0.002900838851928711
# solving Ax = b time taken:  0.08443093299865723
# epoch:  258	assembling the mass matrix time taken:  0.0030660629272460938
# solving Ax = b time taken:  0.08350729942321777
# epoch:  259	assembling the mass matrix time taken:  0.0029115676879882812
# solving Ax = b time taken:  0.08498096466064453
# epoch:  260	assembling the mass matrix time taken:  0.003101825714111328
# solving Ax = b time taken:  0.08294939994812012
# epoch:  261	assembling the mass matrix time taken:  0.0029516220092773438
# solving Ax = b time taken:  0.0857400894165039
# epoch:  262	assembling the mass matrix time taken:  0.0031332969665527344
# solving Ax = b time taken:  0.08442997932434082
# epoch:  263	assembling the mass matrix time taken:  0.0030333995819091797
# solving Ax = b time taken:  0.08594155311584473
# epoch:  264	assembling the mass matrix time taken:  0.0032100677490234375
# solving Ax = b time taken:  0.08349251747131348
# epoch:  265	assembling the mass matrix time taken:  0.0029501914978027344
# solving Ax = b time taken:  0.08636260032653809
# epoch:  266	assembling the mass matrix time taken:  0.0031647682189941406
# solving Ax = b time taken:  0.08511233329772949
# epoch:  267	assembling the mass matrix time taken:  0.002880096435546875
# solving Ax = b time taken:  0.10570859909057617
# epoch:  268	assembling the mass matrix time taken:  0.0031173229217529297
# solving Ax = b time taken:  0.08444571495056152
# epoch:  269	assembling the mass matrix time taken:  0.002857685089111328
# solving Ax = b time taken:  0.10673236846923828
# epoch:  270	assembling the mass matrix time taken:  0.003052949905395508
# solving Ax = b time taken:  0.08645009994506836
# epoch:  271	assembling the mass matrix time taken:  0.0029036998748779297
# solving Ax = b time taken:  0.10717964172363281
# epoch:  272	assembling the mass matrix time taken:  0.0030748844146728516
# solving Ax = b time taken:  0.08507180213928223
# epoch:  273	assembling the mass matrix time taken:  0.0029408931732177734
# solving Ax = b time taken:  0.10663080215454102
# epoch:  274	assembling the mass matrix time taken:  0.0030422210693359375
# solving Ax = b time taken:  0.08751893043518066
# epoch:  275	assembling the mass matrix time taken:  0.0029611587524414062
# solving Ax = b time taken:  0.1071772575378418
# epoch:  276	assembling the mass matrix time taken:  0.0031290054321289062
# solving Ax = b time taken:  0.08605432510375977
# epoch:  277	assembling the mass matrix time taken:  0.002936124801635742
# solving Ax = b time taken:  0.10754084587097168
# epoch:  278	assembling the mass matrix time taken:  0.0031194686889648438
# solving Ax = b time taken:  0.08812808990478516
# epoch:  279	assembling the mass matrix time taken:  0.003152132034301758
# solving Ax = b time taken:  0.10803055763244629
# epoch:  280	assembling the mass matrix time taken:  0.0030629634857177734
# solving Ax = b time taken:  0.08693718910217285
# epoch:  281	assembling the mass matrix time taken:  0.0029113292694091797
# solving Ax = b time taken:  0.10824322700500488
# epoch:  282	assembling the mass matrix time taken:  0.003051280975341797
# solving Ax = b time taken:  0.0889749526977539
# epoch:  283	assembling the mass matrix time taken:  0.002900362014770508
# solving Ax = b time taken:  0.10883331298828125
# epoch:  284	assembling the mass matrix time taken:  0.00304412841796875
# solving Ax = b time taken:  0.0874943733215332
# epoch:  285	assembling the mass matrix time taken:  0.0029172897338867188
# solving Ax = b time taken:  0.10837030410766602
# epoch:  286	assembling the mass matrix time taken:  0.003049612045288086
# solving Ax = b time taken:  0.08997154235839844
# epoch:  287	assembling the mass matrix time taken:  0.0029096603393554688
# solving Ax = b time taken:  0.10944104194641113
# epoch:  288	assembling the mass matrix time taken:  0.003087759017944336
# solving Ax = b time taken:  0.08793497085571289
# epoch:  289	assembling the mass matrix time taken:  0.0028753280639648438
# solving Ax = b time taken:  0.0916290283203125
# epoch:  290	assembling the mass matrix time taken:  0.00311279296875
# solving Ax = b time taken:  0.09369111061096191
# epoch:  291	assembling the mass matrix time taken:  0.0028696060180664062
# solving Ax = b time taken:  0.09212255477905273
# epoch:  292	assembling the mass matrix time taken:  0.0031151771545410156
# solving Ax = b time taken:  0.09234070777893066
# epoch:  293	assembling the mass matrix time taken:  0.002932310104370117
# solving Ax = b time taken:  0.09249067306518555
# epoch:  294	assembling the mass matrix time taken:  0.003113985061645508
# solving Ax = b time taken:  0.09475898742675781
# epoch:  295	assembling the mass matrix time taken:  0.002942800521850586
# solving Ax = b time taken:  0.0929718017578125
# epoch:  296	assembling the mass matrix time taken:  0.0030372142791748047
# solving Ax = b time taken:  0.09326767921447754
# epoch:  297	assembling the mass matrix time taken:  0.002887248992919922
# solving Ax = b time taken:  0.0932769775390625
# epoch:  298	assembling the mass matrix time taken:  0.0029642581939697266
# solving Ax = b time taken:  0.09508037567138672
# epoch:  299	assembling the mass matrix time taken:  0.0029494762420654297
# solving Ax = b time taken:  0.09380531311035156
# epoch:  300	assembling the mass matrix time taken:  0.0030698776245117188
# solving Ax = b time taken:  0.09419083595275879
# epoch:  301	assembling the mass matrix time taken:  0.002957582473754883
# solving Ax = b time taken:  0.09437179565429688
# epoch:  302	assembling the mass matrix time taken:  0.0031976699829101562
# solving Ax = b time taken:  0.0959928035736084
# epoch:  303	assembling the mass matrix time taken:  0.0028977394104003906
# solving Ax = b time taken:  0.0942683219909668
# epoch:  304	assembling the mass matrix time taken:  0.0029675960540771484
# solving Ax = b time taken:  0.09462618827819824
# epoch:  305	assembling the mass matrix time taken:  0.0028960704803466797
# solving Ax = b time taken:  0.09471487998962402
# epoch:  306	assembling the mass matrix time taken:  0.003070354461669922
# solving Ax = b time taken:  0.09675335884094238
# epoch:  307	assembling the mass matrix time taken:  0.0029582977294921875
# solving Ax = b time taken:  0.09512710571289062
# epoch:  308	assembling the mass matrix time taken:  0.0030107498168945312
# solving Ax = b time taken:  0.0957942008972168
# epoch:  309	assembling the mass matrix time taken:  0.0029418468475341797
# solving Ax = b time taken:  0.09576249122619629
# epoch:  310	assembling the mass matrix time taken:  0.003039121627807617
# solving Ax = b time taken:  0.0975186824798584
# epoch:  311	assembling the mass matrix time taken:  0.0028498172760009766
# solving Ax = b time taken:  0.09617924690246582
# epoch:  312	assembling the mass matrix time taken:  0.0030465126037597656
# solving Ax = b time taken:  0.0964958667755127
# epoch:  313	assembling the mass matrix time taken:  0.0028886795043945312
# solving Ax = b time taken:  0.09663534164428711
# epoch:  314	assembling the mass matrix time taken:  0.0030312538146972656
# solving Ax = b time taken:  0.09851241111755371
# epoch:  315	assembling the mass matrix time taken:  0.0029556751251220703
# solving Ax = b time taken:  0.09682130813598633
# epoch:  316	assembling the mass matrix time taken:  0.0031032562255859375
# solving Ax = b time taken:  0.09753131866455078
# epoch:  317	assembling the mass matrix time taken:  0.0028967857360839844
# solving Ax = b time taken:  0.09743046760559082
# epoch:  318	assembling the mass matrix time taken:  0.003036022186279297
# solving Ax = b time taken:  0.0993812084197998
# epoch:  319	assembling the mass matrix time taken:  0.002910137176513672
# solving Ax = b time taken:  0.09808206558227539
# epoch:  320	assembling the mass matrix time taken:  0.0030710697174072266
# solving Ax = b time taken:  0.09781289100646973
# epoch:  321	assembling the mass matrix time taken:  0.0028688907623291016
# solving Ax = b time taken:  0.11757421493530273
# epoch:  322	assembling the mass matrix time taken:  0.002973318099975586
# solving Ax = b time taken:  0.10844755172729492
# epoch:  323	assembling the mass matrix time taken:  0.0029268264770507812
# solving Ax = b time taken:  0.11816287040710449
# epoch:  324	assembling the mass matrix time taken:  0.002930879592895508
# solving Ax = b time taken:  0.10878372192382812
# epoch:  325	assembling the mass matrix time taken:  0.002919912338256836
# solving Ax = b time taken:  0.11841225624084473
# epoch:  326	assembling the mass matrix time taken:  0.0029592514038085938
# solving Ax = b time taken:  0.10964155197143555
# epoch:  327	assembling the mass matrix time taken:  0.0029354095458984375
# solving Ax = b time taken:  0.11897587776184082
# epoch:  328	assembling the mass matrix time taken:  0.0029571056365966797
# solving Ax = b time taken:  0.10903263092041016
# epoch:  329	assembling the mass matrix time taken:  0.002900838851928711
# solving Ax = b time taken:  0.11926817893981934
# epoch:  330	assembling the mass matrix time taken:  0.002997159957885742
# solving Ax = b time taken:  0.110565185546875
# epoch:  331	assembling the mass matrix time taken:  0.0028901100158691406
# solving Ax = b time taken:  0.11980915069580078
# epoch:  332	assembling the mass matrix time taken:  0.0029931068420410156
# solving Ax = b time taken:  0.11054754257202148
# epoch:  333	assembling the mass matrix time taken:  0.0029189586639404297
# solving Ax = b time taken:  0.12012100219726562
# epoch:  334	assembling the mass matrix time taken:  0.002966642379760742
# solving Ax = b time taken:  0.11150789260864258
# epoch:  335	assembling the mass matrix time taken:  0.0028641223907470703
# solving Ax = b time taken:  0.1205897331237793
# epoch:  336	assembling the mass matrix time taken:  0.002977609634399414
# solving Ax = b time taken:  0.11083841323852539
# epoch:  337	assembling the mass matrix time taken:  0.002882242202758789
# solving Ax = b time taken:  0.12079834938049316
# epoch:  338	assembling the mass matrix time taken:  0.0029449462890625
# solving Ax = b time taken:  0.11605095863342285
# epoch:  339	assembling the mass matrix time taken:  0.002877950668334961
# solving Ax = b time taken:  0.12136960029602051
# epoch:  340	assembling the mass matrix time taken:  0.003019571304321289
# solving Ax = b time taken:  0.1117863655090332
# epoch:  341	assembling the mass matrix time taken:  0.002967357635498047
# solving Ax = b time taken:  0.12160134315490723
# epoch:  342	assembling the mass matrix time taken:  0.003018617630004883
# solving Ax = b time taken:  0.11345171928405762
# epoch:  343	assembling the mass matrix time taken:  0.003153562545776367
# solving Ax = b time taken:  0.12209558486938477
# epoch:  344	assembling the mass matrix time taken:  0.0029997825622558594
# solving Ax = b time taken:  0.11236691474914551
# epoch:  345	assembling the mass matrix time taken:  0.0029718875885009766
# solving Ax = b time taken:  0.1227574348449707
# epoch:  346	assembling the mass matrix time taken:  0.0030202865600585938
# solving Ax = b time taken:  0.11456656455993652
# epoch:  347	assembling the mass matrix time taken:  0.0029850006103515625
# solving Ax = b time taken:  0.12281537055969238
# epoch:  348	assembling the mass matrix time taken:  0.0029528141021728516
# solving Ax = b time taken:  0.1135413646697998
# epoch:  349	assembling the mass matrix time taken:  0.0029592514038085938
# solving Ax = b time taken:  0.12344574928283691
# epoch:  350	assembling the mass matrix time taken:  0.0029478073120117188
# solving Ax = b time taken:  0.11564993858337402
# epoch:  351	assembling the mass matrix time taken:  0.002935647964477539
# solving Ax = b time taken:  0.12352418899536133
# epoch:  352	assembling the mass matrix time taken:  0.003014087677001953
# solving Ax = b time taken:  0.11399626731872559
# epoch:  353	assembling the mass matrix time taken:  0.0029630661010742188
# solving Ax = b time taken:  0.12466692924499512
# epoch:  354	assembling the mass matrix time taken:  0.002978086471557617
# solving Ax = b time taken:  0.11933374404907227
# epoch:  355	assembling the mass matrix time taken:  0.002919912338256836
# solving Ax = b time taken:  0.12508440017700195
# epoch:  356	assembling the mass matrix time taken:  0.002908468246459961
# solving Ax = b time taken:  0.12500405311584473
# epoch:  357	assembling the mass matrix time taken:  0.0029036998748779297
# solving Ax = b time taken:  0.12569332122802734
# epoch:  358	assembling the mass matrix time taken:  0.002948760986328125
# solving Ax = b time taken:  0.12576007843017578
# epoch:  359	assembling the mass matrix time taken:  0.0028641223907470703
# solving Ax = b time taken:  0.12604570388793945
# epoch:  360	assembling the mass matrix time taken:  0.002928018569946289
# solving Ax = b time taken:  0.12572813034057617
# epoch:  361	assembling the mass matrix time taken:  0.0028543472290039062
# solving Ax = b time taken:  0.12654614448547363
# epoch:  362	assembling the mass matrix time taken:  0.009965181350708008
# solving Ax = b time taken:  0.12673306465148926
# epoch:  363	assembling the mass matrix time taken:  0.00947427749633789
# solving Ax = b time taken:  0.1269669532775879
# epoch:  364	assembling the mass matrix time taken:  0.009352684020996094
# solving Ax = b time taken:  0.12686777114868164
# epoch:  365	assembling the mass matrix time taken:  0.00977182388305664
# solving Ax = b time taken:  0.12742400169372559
# epoch:  366	assembling the mass matrix time taken:  0.009457111358642578
# solving Ax = b time taken:  0.1275317668914795
# epoch:  367	assembling the mass matrix time taken:  0.003585338592529297
# solving Ax = b time taken:  0.1271343231201172
# epoch:  368	assembling the mass matrix time taken:  0.0029532909393310547
# solving Ax = b time taken:  0.12738299369812012
# epoch:  369	assembling the mass matrix time taken:  0.002957582473754883
# solving Ax = b time taken:  0.12845277786254883
# epoch:  370	assembling the mass matrix time taken:  0.0030417442321777344
# solving Ax = b time taken:  0.12836623191833496
# epoch:  371	assembling the mass matrix time taken:  0.0029001235961914062
# solving Ax = b time taken:  0.12856245040893555
# epoch:  372	assembling the mass matrix time taken:  0.0029931068420410156
# solving Ax = b time taken:  0.12858057022094727
# epoch:  373	assembling the mass matrix time taken:  0.002999544143676758
# solving Ax = b time taken:  0.12930798530578613
# epoch:  374	assembling the mass matrix time taken:  0.0031800270080566406
# solving Ax = b time taken:  0.12942099571228027
# epoch:  375	assembling the mass matrix time taken:  0.0029218196868896484
# solving Ax = b time taken:  0.12961077690124512
# epoch:  376	assembling the mass matrix time taken:  0.0029747486114501953
# solving Ax = b time taken:  0.12923026084899902
# epoch:  377	assembling the mass matrix time taken:  0.0028994083404541016
# solving Ax = b time taken:  0.13004040718078613
# epoch:  378	assembling the mass matrix time taken:  0.0028793811798095703
# solving Ax = b time taken:  0.13026881217956543
# epoch:  379	assembling the mass matrix time taken:  0.002895355224609375
# solving Ax = b time taken:  0.13034415245056152
# epoch:  380	assembling the mass matrix time taken:  0.002891063690185547
# solving Ax = b time taken:  0.1304912567138672
# epoch:  381	assembling the mass matrix time taken:  0.002923727035522461
# solving Ax = b time taken:  0.13087940216064453
# epoch:  382	assembling the mass matrix time taken:  0.009464025497436523
# solving Ax = b time taken:  0.13102006912231445
# epoch:  383	assembling the mass matrix time taken:  0.009297847747802734
# solving Ax = b time taken:  0.1310107707977295
# epoch:  384	assembling the mass matrix time taken:  0.003659486770629883
# solving Ax = b time taken:  0.1307508945465088
# epoch:  385	assembling the mass matrix time taken:  0.009514570236206055
# solving Ax = b time taken:  0.13810396194458008
# epoch:  386	assembling the mass matrix time taken:  0.00960230827331543
# solving Ax = b time taken:  0.1462860107421875
# epoch:  387	assembling the mass matrix time taken:  0.009528398513793945
# solving Ax = b time taken:  0.13883209228515625
# epoch:  388	assembling the mass matrix time taken:  0.0098114013671875
# solving Ax = b time taken:  0.1452314853668213
# epoch:  389	assembling the mass matrix time taken:  0.009873628616333008
# solving Ax = b time taken:  0.1394031047821045
# epoch:  390	assembling the mass matrix time taken:  0.00959920883178711
# solving Ax = b time taken:  0.14731955528259277
# epoch:  391	assembling the mass matrix time taken:  0.009323596954345703
# solving Ax = b time taken:  0.1396801471710205
# epoch:  392	assembling the mass matrix time taken:  0.009415626525878906
# solving Ax = b time taken:  0.14560556411743164
# epoch:  393	assembling the mass matrix time taken:  0.009412765502929688
# solving Ax = b time taken:  0.13990139961242676
# epoch:  394	assembling the mass matrix time taken:  0.009589433670043945
# solving Ax = b time taken:  0.1482696533203125
# epoch:  395	assembling the mass matrix time taken:  0.009493350982666016
# solving Ax = b time taken:  0.14032816886901855
# epoch:  396	assembling the mass matrix time taken:  0.003034353256225586
# solving Ax = b time taken:  0.14705681800842285
# epoch:  397	assembling the mass matrix time taken:  0.0028808116912841797
# solving Ax = b time taken:  0.14078235626220703
# epoch:  398	assembling the mass matrix time taken:  0.003044605255126953
# solving Ax = b time taken:  0.14925074577331543
# epoch:  399	assembling the mass matrix time taken:  0.0029070377349853516
# solving Ax = b time taken:  0.14113235473632812
# epoch:  400	assembling the mass matrix time taken:  0.002986431121826172
# solving Ax = b time taken:  0.1474161148071289
# epoch:  401	assembling the mass matrix time taken:  0.0029296875
# solving Ax = b time taken:  0.14174532890319824
# epoch:  402	assembling the mass matrix time taken:  0.0030236244201660156
# solving Ax = b time taken:  0.15002012252807617
# epoch:  403	assembling the mass matrix time taken:  0.0028781890869140625
# solving Ax = b time taken:  0.14207673072814941
# epoch:  404	assembling the mass matrix time taken:  0.0029821395874023438
# solving Ax = b time taken:  0.1486530303955078
# epoch:  405	assembling the mass matrix time taken:  0.002917051315307617
# solving Ax = b time taken:  0.14265012741088867
# epoch:  406	assembling the mass matrix time taken:  0.0030012130737304688
# solving Ax = b time taken:  0.15088772773742676
# epoch:  407	assembling the mass matrix time taken:  0.0029442310333251953
# solving Ax = b time taken:  0.14304566383361816
# epoch:  408	assembling the mass matrix time taken:  0.0030035972595214844
# solving Ax = b time taken:  0.14913225173950195
# epoch:  409	assembling the mass matrix time taken:  0.002951383590698242
# solving Ax = b time taken:  0.14328455924987793
# epoch:  410	assembling the mass matrix time taken:  0.003084897994995117
# solving Ax = b time taken:  0.14583420753479004
# epoch:  411	assembling the mass matrix time taken:  0.0028562545776367188
# solving Ax = b time taken:  0.1437702178955078
# epoch:  412	assembling the mass matrix time taken:  0.0029866695404052734
# solving Ax = b time taken:  0.14441514015197754
# epoch:  413	assembling the mass matrix time taken:  0.0029456615447998047
# solving Ax = b time taken:  0.14415240287780762
# epoch:  414	assembling the mass matrix time taken:  0.0030393600463867188
# solving Ax = b time taken:  0.1467418670654297
# epoch:  415	assembling the mass matrix time taken:  0.002885580062866211
# solving Ax = b time taken:  0.14458465576171875
# epoch:  416	assembling the mass matrix time taken:  0.003063678741455078
# solving Ax = b time taken:  0.1443474292755127
# epoch:  417	assembling the mass matrix time taken:  0.002948760986328125
# solving Ax = b time taken:  0.14512944221496582
# epoch:  418	assembling the mass matrix time taken:  0.0030770301818847656
# solving Ax = b time taken:  0.1474909782409668
# epoch:  419	assembling the mass matrix time taken:  0.002913951873779297
# solving Ax = b time taken:  0.1455979347229004
# epoch:  420	assembling the mass matrix time taken:  0.0030694007873535156
# solving Ax = b time taken:  0.14631199836730957
# epoch:  421	assembling the mass matrix time taken:  0.0029823780059814453
# solving Ax = b time taken:  0.1459054946899414
# epoch:  422	assembling the mass matrix time taken:  0.003062725067138672
# solving Ax = b time taken:  0.1483907699584961
# epoch:  423	assembling the mass matrix time taken:  0.0029561519622802734
# solving Ax = b time taken:  0.14635324478149414
# epoch:  424	assembling the mass matrix time taken:  0.0029969215393066406
# solving Ax = b time taken:  0.14687561988830566
# epoch:  425	assembling the mass matrix time taken:  0.0029876232147216797
# solving Ax = b time taken:  0.14818406105041504
# epoch:  426	assembling the mass matrix time taken:  0.003017902374267578
# solving Ax = b time taken:  0.15597057342529297
# epoch:  427	assembling the mass matrix time taken:  0.0029449462890625
# solving Ax = b time taken:  0.14853906631469727
# epoch:  428	assembling the mass matrix time taken:  0.003045797348022461
# solving Ax = b time taken:  0.15410709381103516
# epoch:  429	assembling the mass matrix time taken:  0.0029540061950683594
# solving Ax = b time taken:  0.1490485668182373
# epoch:  430	assembling the mass matrix time taken:  0.003035306930541992
# solving Ax = b time taken:  0.1571207046508789
# epoch:  431	assembling the mass matrix time taken:  0.002959728240966797
# solving Ax = b time taken:  0.14953970909118652
# epoch:  432	assembling the mass matrix time taken:  0.0028798580169677734
# solving Ax = b time taken:  0.15352249145507812
# epoch:  433	assembling the mass matrix time taken:  0.002853870391845703
# solving Ax = b time taken:  0.15026617050170898
# epoch:  434	assembling the mass matrix time taken:  0.002910137176513672
# solving Ax = b time taken:  0.1548457145690918
# epoch:  435	assembling the mass matrix time taken:  0.002900362014770508
# solving Ax = b time taken:  0.15068626403808594
# epoch:  436	assembling the mass matrix time taken:  0.002913236618041992
# solving Ax = b time taken:  0.15500092506408691
# epoch:  437	assembling the mass matrix time taken:  0.002888917922973633
# solving Ax = b time taken:  0.15099310874938965
# epoch:  438	assembling the mass matrix time taken:  0.002880096435546875
# solving Ax = b time taken:  0.155914306640625
# epoch:  439	assembling the mass matrix time taken:  0.0029687881469726562
# solving Ax = b time taken:  0.15148401260375977
# epoch:  440	assembling the mass matrix time taken:  0.0029349327087402344
# solving Ax = b time taken:  0.15561556816101074
# epoch:  441	assembling the mass matrix time taken:  0.0029425621032714844
# solving Ax = b time taken:  0.1518840789794922
# epoch:  442	assembling the mass matrix time taken:  0.002912282943725586
# solving Ax = b time taken:  0.15704131126403809
# epoch:  443	assembling the mass matrix time taken:  0.002934694290161133
# solving Ax = b time taken:  0.1523609161376953
# epoch:  444	assembling the mass matrix time taken:  0.002907991409301758
# solving Ax = b time taken:  0.15689921379089355
# epoch:  445	assembling the mass matrix time taken:  0.0032160282135009766
# solving Ax = b time taken:  0.15285253524780273
# epoch:  446	assembling the mass matrix time taken:  0.0029044151306152344
# solving Ax = b time taken:  0.15765666961669922
# epoch:  447	assembling the mass matrix time taken:  0.0029456615447998047
# solving Ax = b time taken:  0.15346646308898926
# epoch:  448	assembling the mass matrix time taken:  0.0029218196868896484
# solving Ax = b time taken:  0.1569521427154541
# epoch:  449	assembling the mass matrix time taken:  0.0029404163360595703
# solving Ax = b time taken:  0.16984820365905762
# epoch:  450	assembling the mass matrix time taken:  0.002973318099975586
# solving Ax = b time taken:  0.16838860511779785
# epoch:  451	assembling the mass matrix time taken:  0.0029375553131103516
# solving Ax = b time taken:  0.17020320892333984
# epoch:  452	assembling the mass matrix time taken:  0.003000497817993164
# solving Ax = b time taken:  0.16666436195373535
# epoch:  453	assembling the mass matrix time taken:  0.0029566287994384766
# solving Ax = b time taken:  0.1708536148071289
# epoch:  454	assembling the mass matrix time taken:  0.0030395984649658203
# solving Ax = b time taken:  0.16951227188110352
# epoch:  455	assembling the mass matrix time taken:  0.0029387474060058594
# solving Ax = b time taken:  0.17101287841796875
# epoch:  456	assembling the mass matrix time taken:  0.002974271774291992
# solving Ax = b time taken:  0.16719722747802734
# epoch:  457	assembling the mass matrix time taken:  0.002940654754638672
# solving Ax = b time taken:  0.1717064380645752
# epoch:  458	assembling the mass matrix time taken:  0.002936840057373047
# solving Ax = b time taken:  0.17023253440856934
# epoch:  459	assembling the mass matrix time taken:  0.0029418468475341797
# solving Ax = b time taken:  0.1719827651977539
# epoch:  460	assembling the mass matrix time taken:  0.002991199493408203
# solving Ax = b time taken:  0.1681516170501709
# epoch:  461	assembling the mass matrix time taken:  0.002888917922973633
# solving Ax = b time taken:  0.17257404327392578
# epoch:  462	assembling the mass matrix time taken:  0.0029211044311523438
# solving Ax = b time taken:  0.17066359519958496
# epoch:  463	assembling the mass matrix time taken:  0.002894163131713867
# solving Ax = b time taken:  0.1730053424835205
# epoch:  464	assembling the mass matrix time taken:  0.003010272979736328
# solving Ax = b time taken:  0.16839194297790527
# epoch:  465	assembling the mass matrix time taken:  0.0029382705688476562
# solving Ax = b time taken:  0.17329120635986328
# epoch:  466	assembling the mass matrix time taken:  0.0030274391174316406
# solving Ax = b time taken:  0.17183136940002441
# epoch:  467	assembling the mass matrix time taken:  0.003152132034301758
# solving Ax = b time taken:  0.17386960983276367
# epoch:  468	assembling the mass matrix time taken:  0.003017425537109375
# solving Ax = b time taken:  0.17053604125976562
# epoch:  469	assembling the mass matrix time taken:  0.002902507781982422
# solving Ax = b time taken:  0.1744985580444336
# epoch:  470	assembling the mass matrix time taken:  0.0030045509338378906
# solving Ax = b time taken:  0.1724550724029541
# epoch:  471	assembling the mass matrix time taken:  0.003014802932739258
# solving Ax = b time taken:  0.17479157447814941
# epoch:  472	assembling the mass matrix time taken:  0.0030035972595214844
# solving Ax = b time taken:  0.17102313041687012
# epoch:  473	assembling the mass matrix time taken:  0.002943277359008789
# solving Ax = b time taken:  0.1749420166015625
# epoch:  474	assembling the mass matrix time taken:  0.0035974979400634766
# solving Ax = b time taken:  0.17545151710510254
# epoch:  475	assembling the mass matrix time taken:  0.0029485225677490234
# solving Ax = b time taken:  0.17543649673461914
# epoch:  476	assembling the mass matrix time taken:  0.0030977725982666016
# solving Ax = b time taken:  0.17630958557128906
# epoch:  477	assembling the mass matrix time taken:  0.0029299259185791016
# solving Ax = b time taken:  0.1761155128479004
# epoch:  478	assembling the mass matrix time taken:  0.0029137134552001953
# solving Ax = b time taken:  0.17699408531188965
# epoch:  479	assembling the mass matrix time taken:  0.002920389175415039
# solving Ax = b time taken:  0.17639398574829102
# epoch:  480	assembling the mass matrix time taken:  0.003180980682373047
# solving Ax = b time taken:  0.17546534538269043
# epoch:  481	assembling the mass matrix time taken:  0.0028803348541259766
# solving Ax = b time taken:  0.17678117752075195
# epoch:  482	assembling the mass matrix time taken:  0.0028467178344726562
# solving Ax = b time taken:  0.1771996021270752
# epoch:  483	assembling the mass matrix time taken:  0.0029115676879882812
# solving Ax = b time taken:  0.17748451232910156
# epoch:  484	assembling the mass matrix time taken:  0.0029702186584472656
# solving Ax = b time taken:  0.1773521900177002
# epoch:  485	assembling the mass matrix time taken:  0.002920389175415039
# solving Ax = b time taken:  0.17794203758239746
# epoch:  486	assembling the mass matrix time taken:  0.0031790733337402344
# solving Ax = b time taken:  0.17805171012878418
# epoch:  487	assembling the mass matrix time taken:  0.0029463768005371094
# solving Ax = b time taken:  0.17835068702697754
# epoch:  488	assembling the mass matrix time taken:  0.002872943878173828
# solving Ax = b time taken:  0.17780470848083496
# epoch:  489	assembling the mass matrix time taken:  0.0029332637786865234
# solving Ax = b time taken:  0.17853522300720215
# epoch:  490	assembling the mass matrix time taken:  0.002878427505493164
# solving Ax = b time taken:  0.17885398864746094
# epoch:  491	assembling the mass matrix time taken:  0.0028917789459228516
# solving Ax = b time taken:  0.1791081428527832
# epoch:  492	assembling the mass matrix time taken:  0.0028738975524902344
# solving Ax = b time taken:  0.1790153980255127
# epoch:  493	assembling the mass matrix time taken:  0.0031528472900390625
# solving Ax = b time taken:  0.17951011657714844
# epoch:  494	assembling the mass matrix time taken:  0.0028710365295410156
# solving Ax = b time taken:  0.17972254753112793
# epoch:  495	assembling the mass matrix time taken:  0.0029087066650390625
# solving Ax = b time taken:  0.18001985549926758
# epoch:  496	assembling the mass matrix time taken:  0.0028810501098632812
# solving Ax = b time taken:  0.17935657501220703
# epoch:  497	assembling the mass matrix time taken:  0.0029556751251220703
# solving Ax = b time taken:  0.1804962158203125
# epoch:  498	assembling the mass matrix time taken:  0.002852201461791992
# solving Ax = b time taken:  0.18059420585632324
# epoch:  499	assembling the mass matrix time taken:  0.002887725830078125
# solving Ax = b time taken:  0.18089532852172852
# epoch:  500	assembling the mass matrix time taken:  0.0029468536376953125
# solving Ax = b time taken:  0.18074727058410645
# epoch:  501	assembling the mass matrix time taken:  0.002916574478149414
# solving Ax = b time taken:  0.18115496635437012
# epoch:  502	assembling the mass matrix time taken:  0.0029687881469726562
# solving Ax = b time taken:  0.18134188652038574
# epoch:  503	assembling the mass matrix time taken:  0.002856731414794922
# solving Ax = b time taken:  0.181746244430542
# epoch:  504	assembling the mass matrix time taken:  0.002873659133911133
# solving Ax = b time taken:  0.1812424659729004
# epoch:  505	assembling the mass matrix time taken:  0.002960681915283203
# solving Ax = b time taken:  0.18348050117492676
# epoch:  506	assembling the mass matrix time taken:  0.0029866695404052734
# solving Ax = b time taken:  0.18331170082092285
# epoch:  507	assembling the mass matrix time taken:  0.002900838851928711
# solving Ax = b time taken:  0.1835477352142334
# epoch:  508	assembling the mass matrix time taken:  0.002880573272705078
# solving Ax = b time taken:  0.18362760543823242
# epoch:  509	assembling the mass matrix time taken:  0.0032939910888671875
# solving Ax = b time taken:  0.18433904647827148
# epoch:  510	assembling the mass matrix time taken:  0.0028595924377441406
# solving Ax = b time taken:  0.18443751335144043
# epoch:  511	assembling the mass matrix time taken:  0.0028710365295410156
# solving Ax = b time taken:  0.18446564674377441
# epoch:  512	assembling the mass matrix time taken:  0.0029032230377197266
# solving Ax = b time taken:  0.18446946144104004
# time taken:  168.76232767105103
# neuron num 		 error 		 order
# 4 		 0.227605 		 * 		 2.269836 		 *
#
# 8 		 0.248335 		 -0.125755 		 1.890941 		 0.263483
#
# 16 		 0.070578 		 1.814991 		 1.125287 		 0.748811
#
# 32 		 0.050652 		 0.478607 		 0.966707 		 0.219142
#
# 64 		 0.010937 		 2.211428 		 0.266846 		 1.857072
#
# 128 		 0.004138 		 1.402171 		 0.107596 		 1.310384
#
# 256 		 0.000572 		 2.855339 		 0.019227 		 2.484387
#
# 512 		 0.000135 		 2.085739 		 0.005673 		 1.761017
#
# neuron num  & 	 $\|u-u_n \|_{L^2}$ & 	 order $O(n^{-1.62})$  & 	 $ | u -u_n |_{H^1}$ & 	 order $O(n^{-1.38})$  \\ \hline \hline
# 4 		 & 0.227605 &		 * & 		 2.269836 & 		 *  \\ \hline
#
# 8 		 &  2.483e-01 &  		 -0.13 &  		 1.891e+00 &  		 0.26 \\ \hline
#
# 16 		 &  7.058e-02 &  		 1.81 &  		 1.125e+00 &  		 0.75 \\ \hline
#
# 32 		 &  5.065e-02 &  		 0.48 &  		 9.667e-01 &  		 0.22 \\ \hline
#
# 64 		 &  1.094e-02 &  		 2.21 &  		 2.668e-01 &  		 1.86 \\ \hline
#
# 128 		 &  4.138e-03 &  		 1.40 &  		 1.076e-01 &  		 1.31 \\ \hline
#
# 256 		 &  5.718e-04 &  		 2.86 &  		 1.923e-02 &  		 2.48 \\ \hline
#
# 512 		 &  1.347e-04 &  		 2.09 &  		 5.673e-03 &  		 1.76 \\ \hline

# %% [markdown]
# ## $\cos(\pi x_1) \cos( \pi x_2) \cos( \pi x_3) \cos( \pi x_4)$
