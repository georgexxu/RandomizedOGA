# %%
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import time
import sys
import os 
from scipy.sparse import linalg
from pathlib import Path
if torch.cuda.is_available():  
    device = "cuda" 
else:  
    device = "cpu" 

torch.set_default_dtype(torch.float64)
pi = torch.tensor(np.pi)
ZERO = torch.tensor([0.]).to(device)

class model(nn.Module):
    """ ReLU k shallow neural network
    Parameters: 
    input size: input dimension
    hidden_size1 : number of hidden layers 
    num_classes: output classes 
    k: degree of relu functions
    """
    def __init__(self, input_size, hidden_size1, num_classes,k = 1):
        super().__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, num_classes,bias = False)
        self.k = k 
    def forward(self, x):
        u1 = self.fc2(F.relu(self.fc1(x))**self.k)
        return u1
    def evaluate_derivative(self, x, i):
        if self.k == 1:
            ## ZERO = torch.tensor([0.]).to(device)
            u1 = self.fc2(torch.heaviside(self.fc1(x),ZERO) * self.fc1.weight.t()[i-1:i,:] )
        else:
            u1 = self.fc2(self.k*F.relu(self.fc1(x))**(self.k-1) *self.fc1.weight.t()[i-1:i,:] )  
        return u1

# %%
def PiecewiseGQ1D_weights_points(x_l,x_r,Nx, order):
    """ Output the coeffients and weights for piecewise Gauss Quadrature 
    Parameters
    ----------
    x_l : float 
    left endpoint of an interval 
    x_r: float
    right endpoint of an interval 
    Nx: int 
    number of subintervals for integration
    order: int
    order of Gauss Quadrature 
    Returns
    -------
    vectorized quadrature weights and integration points
    """
    x,w = np.polynomial.legendre.leggauss(order)
    gx = torch.tensor(x).to(device)
    gx = gx.view(1,-1) # row vector 
    gw = torch.tensor(w).to(device)    
    gw = gw.view(-1,1) # Column vector 
    nodes = torch.linspace(x_l,x_r,Nx+1).view(-1,1).to(device) 
    coef1 = ((nodes[1:,:] - nodes[:-1,:])/2) # n by 1  
    coef2 = ((nodes[1:,:] + nodes[:-1,:])/2) # n by 1  
    coef2_expand = coef2.expand(-1,gx.size(1)) # Expand to n by p shape, -1: keep the first dimension n , expand the 2nd dim (columns)
    integration_points = coef1@gx + coef2_expand
    integration_points = integration_points.flatten().view(-1,1) # Make it a column vector
    gw_expand = torch.tile(gw,(Nx,1)) # rows: n copies of current tensor, columns: 1 copy, no change
    # Modify coef1 to be compatible with func_values
    coef1_expand = coef1.expand(coef1.size(0),gx.size(1))    
    coef1_expand = coef1_expand.flatten().view(-1,1)
    return coef1_expand.to(device) * gw_expand.to(device), integration_points.to(device)

def plot_solution_modified(r1,r2,model,x_test,u_true,name=None): 
    # Plot function: test results 
    u_model_cpu = model(x_test).cpu().detach()
    
    w = model.fc1.weight.data.squeeze()
    b = model.fc1.bias.data.squeeze()
    x_model_pt = (-b/w).view(-1,1)
    x_model_pt = x_model_pt[x_model_pt>=r1].reshape(-1,1)
    u_model_pt = model(x_model_pt).cpu().detach()
    plt.figure(dpi = 100)
    plt.plot(x_test.cpu(),u_model_cpu,'-.',label = "nn function")
    plt.plot(x_test.cpu(),u_true.cpu(),label = "true")
    plt.plot(x_model_pt.cpu(),u_model_pt.cpu(),'.r')
    if name!=None: 
        plt.title(name)
    plt.legend()
    plt.show()

def Neumann_boundary_quadrature_points(M, dim):
    """
    the boundary is in dimension dim - 1. 
    If 1D problem, the boundary is 0D, the quadrature points are 0 and 1. 
    """
    if dim == 1: 
        weights_bd = torch.tensor([1.,1.]).view(-1,1).to(device)
        integration_points_bd = torch.tensor([0.,1.]).view(-1,1).to(device) 
    
    return weights_bd.to(device), integration_points_bd.to(device) 

def minimize_linear_layer_neumann(model,target,weights, integration_points,weights_bd, integration_points_bd, g_N, activation = 'relu', solver = 'direct'):
    """
    calls the following functions (dependency): 
    1. GQ_piecewise_2D
    input: the nn model containing parameter 
    1. define the loss function  
    2. take derivative to extract the linear system A
    3. call the cg solver in scipy to solve the linear system 
    output: sol. solution of Ax = b
    """
    start_time = time.time() 
    w = model.fc1.weight.data 
    b = model.fc1.bias.data 
    basis_value_col = F.relu(integration_points @ w.t()+ b)**(model.k) 
    weighted_basis_value_col = basis_value_col * weights 
    
    coef_func = 1 # 3 * model(integration_points).detach()**2 #changing after each newton iteration 
    jac2 = weighted_basis_value_col.t() @ (coef_func*basis_value_col) 

    # stiffness matrix 
    if activation == 'relu':
        basis_value_col = F.relu(integration_points @ w.t()+ b)**(model.k) 
        if model.k == 1:  
            basis_value_dx_col = torch.heaviside(integration_points @ w.t()+ b, ZERO) * w.t()[0:1,:] 
        else: 
            basis_value_dx_col = model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * w.t()[0:1,:]
    weighted_basis_value_dx_col = basis_value_dx_col * weights
    jac1 =  weighted_basis_value_dx_col.t() @ basis_value_dx_col 
    jac = jac1 + jac2

    rhs1 = weighted_basis_value_col.t() @ (target(integration_points) )

    # Neumman boundary condition
    basis_value_col_bd = F.relu(integration_points_bd @ w.t()+ b)**(model.k) 
    weighted_basis_value_col_bd = basis_value_col_bd *weights_bd 
    dudn = g_N(integration_points_bd)* (torch.tensor([-1,1]).view(-1,1)).to(device) 
    rhs2 =  weighted_basis_value_col_bd.t() @ dudn

    rhs = rhs1 + rhs2 

    print("assembling the matrix time taken: ", time.time()-start_time) 
    start_time = time.time()    
    if solver == "cg": 
        sol, exit_code = linalg.cg(np.array(jac.detach().cpu()),np.array(rhs.detach().cpu()),tol=1e-12)
        sol = torch.tensor(sol).view(1,-1)
    elif solver == "direct": 
#         sol = np.linalg.inv( np.array(jac.detach().cpu()) )@np.array(rhs.detach().cpu())
        sol = (torch.linalg.solve( jac.detach(), rhs.detach())).view(1,-1)
    elif solver == "ls":
        sol = (torch.linalg.lstsq(jac.detach().cpu(),rhs.detach().cpu(),driver='gelsd').solution).view(1,-1)
        # sol = (torch.linalg.lstsq(jac.detach(),rhs.detach()).solution).view(1,-1) # gpu/cpu, driver = 'gels', cannot solve singular
    print("solving Ax = b time taken: ", time.time()-start_time)
    ## update the solution 
    return sol

# %%
def show_convergence_order2(err_l2,err_h10,exponent,dict_size, filename,write2file = False):
    
    if write2file:
        file_mode = "a" if os.path.exists(filename) else "w"
        f_write = open(filename, file_mode)
    
    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_l2[i] for i in neuron_nums ]
    err_list2 = [err_h10[i] for i in neuron_nums ] 
    # f_write.write('M:{}, relu {} \n'.format(M,k))
    if write2file:
        f_write.write('dictionary size: {}\n'.format(dict_size))
        f_write.write("neuron num \t\t error \t\t order \t\t h10 error \\ order \n")
    print("neuron num \t\t error \t\t order")
    for i, item in enumerate(err_list):
        if i == 0: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t")
            
            # print("*")
            print("{} \t\t {:.6f} \t\t * \t\t {:.6f} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ) )
            if write2file: 
                f_write.write("{} \t\t {} \t\t * \t\t {} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ))
        else: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t") 
            # print(np.log(err_list[i-1]/err_list[i])/np.log(2))
            print("{} \t\t {:.6f} \t\t {:.6f} \t\t {:.6f} \t\t {:.6f} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ) )
            if write2file: 
                f_write.write("{} \t\t {} \t\t {} \t\t {} \t\t {} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ))
    if write2file:     
        f_write.write("\n")
        f_write.close()

def show_convergence_order_latex2(err_l2,err_h10,exponent,k=1,d=1): 
    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_l2[i] for i in neuron_nums ]
    err_list2 = [err_h10[i] for i in neuron_nums ] 
    l2_order = -1/2-(2*k + 1)/(2*d)
    h1_order =  -1/2-(2*(k-1)+ 1)/(2*d)
    print("neuron num  & \t $\|u-u_n \|_{{L^2}}$ & \t order $O(n^{{{:.2f}}})$  & \t $ | u -u_n |_{{H^1}}$ & \t order $O(n^{{{:.2f}}})$  \\\ \hline \hline ".format(l2_order,h1_order))
    for i, item in enumerate(err_list):
        if i == 0: 
            print("{} \t\t & {:.6f} &\t\t * & \t\t {:.6f} & \t\t *  \\\ \hline  \n".format(neuron_nums[i],item, err_list2[i] ) )   
        else: 
            print("{} \t\t &  {:.3e} &  \t\t {:.2f} &  \t\t {:.3e} &  \t\t {:.2f} \\\ \hline  \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ) )

# %%
def relu_dict(x_l,x_r,N):
    """generate relu dictionary parameters 
    
    Parameters
    ----------
    x_l: float 
    x_r: float
    N: int 
        number of dictionary elements 
        
    Returns
    torch tensor
        containing relu dictionary parameters, corresponds to nodal points
        
    """
    # w = 1 
    relu_dict_parameters = torch.zeros((2*N,2)).to(device)
    relu_dict_parameters[:N,0] = torch.ones(N)[:]
    relu_dict_parameters[:N,1] = torch.linspace(x_l,x_r,N+1)[:-1] # relu(x-bi)  
    relu_dict_parameters[N:2*N,0] = -torch.ones(N)[:]
    relu_dict_parameters[N:2*N,1] = -torch.linspace(x_l,x_r,N+1)[1:] + 1/(2*N) # relu(-x - -bi) 
    
    return relu_dict_parameters

# relu dictionary
def relu_dict_MC(x_l,x_r,N):
    """generate relu dictionary parameters 
    
    Parameters
    ----------
    x_l: float 
    x_r: float
    N: int 
       number of dictionary elements  
        
    Returns
    torch tensor
        containing relu dictionary parameters, corresponds to nodal points
    """
    # w = 1 
    random_value = torch.randint(0, 2, (N,)) * 2 - 1 # +1 or -1  
    relu_dict_parameters = torch.zeros((N,2)).to(device)
    relu_dict_parameters[:N,0] = random_value[:]
    relu_dict_parameters[:N,1] = (torch.rand(N)*(x_r-x_l) + x_l)*random_value # relu(x-bi) 

    return relu_dict_parameters

def select_greedy_neuron_ind(relu_dict_parameters,my_model,target,weights, integration_points,g_N,weights_bd, integration_points_bd,k): 

    residual_values = - target(integration_points)
    if my_model!= None:
        residual_values +=  my_model(integration_points) 

    weight_func_values = residual_values*weights

    basis_values = (F.relu(relu_dict_parameters[:,0] *integration_points - relu_dict_parameters[:,1])**k).T # uses broadcasting

    output1 = torch.matmul(basis_values,weight_func_values) # 

    if k == 1:  
        dbasis_values_dx1 =  torch.heaviside(integration_points @ (relu_dict_parameters[:,0:1].T) - relu_dict_parameters[:,1], ZERO) * relu_dict_parameters.t()[0:1,:]   
    else:  
        dbasis_values_dx1 = k * F.relu(integration_points @ (relu_dict_parameters[:,0:1].T) - relu_dict_parameters[:,1])**(k-1) * relu_dict_parameters.t()[0:1,:] 

    weight_dbasis_values_dx1 =  dbasis_values_dx1 * weights
    
    # Neumann boundary condition 
    basis_values_bd_col = (F.relu(relu_dict_parameters[:,0] *integration_points_bd - relu_dict_parameters[:,1])**k) 
    weighted_basis_value_col_bd = basis_values_bd_col * weights_bd
    dudn = g_N(integration_points_bd)* (torch.tensor([-1,1]).view(-1,1)).to(device)
    output3 =  weighted_basis_value_col_bd.t() @ dudn

    if my_model!= None:
        dmy_model_dx1 = my_model.evaluate_derivative(integration_points,1).detach()
        output2 = torch.matmul(weight_dbasis_values_dx1.t(), dmy_model_dx1) 
        output = torch.abs(output1 + output2 - output3)
    else:
        output = torch.abs(output1 - output3)
    neuron_index = torch.argmax(output.flatten())
    
    return neuron_index 

def OGANeumannReLU1D(my_model,target,u_exact,du_exact,g_N, N,num_epochs,plot_freq = 10,Nx = 1024,order =5, k = 1,rand_deter = 'deter', solver = 'direct'): 
    """ Orthogonal greedy algorithm to solve a 1D Neumann problem 1D ReLU dictionary over [0,1]
    """

    weights, integration_points = PiecewiseGQ1D_weights_points(x_l= 0,x_r=1, Nx = Nx,order =order)
    weights_bd, integration_points_bd = Neumann_boundary_quadrature_points(M = 2,dim = 1) 

    err = torch.zeros(num_epochs+1)
    err_h10 = torch.zeros(num_epochs+1) 
    if my_model == None: 
        func_values = u_exact(integration_points)
        num_neuron = 0
        list_a = []
        list_b = []
        list_w = []
    else: 
        func_values = u_exact(integration_points) - my_model(integration_points).detach()
        bias = my_model.fc1.bias.detach().data
        weights = my_model.fc1.weight.detach().data
        num_neuron = int(bias.size(0))
        list_a = list(my_model.fc2.weight.detach().data)
        list_b = list(bias)
        list_w = list(weights)
        
    func_values_sqrd = func_values*func_values
    err[0]= torch.sum(func_values_sqrd*weights)**0.5
    if my_model!= None:
        err_h10[0] = torch.sum( (my_model.evaluate_derivative(integration_points,1).detach() - du_exact(integration_points) )**2*weights)**0.5
    else: 
        err_h10[0] = torch.sum( du_exact(integration_points)**2*weights)**0.5
    start_time = time.time()
    
    solver = "direct"
    print("using linear solver: ",solver)
    if rand_deter == 'deter': 
        relu_dict_parameters = relu_dict(0,1,N).to(device) 
    for i in range(num_epochs): 
        print('epoch: ',i+1)
        if rand_deter == 'rand': 
            relu_dict_parameters = relu_dict_MC(0,1,N).to(device)    
        # start_argmax = time.time() 
        neuron_index = select_greedy_neuron_ind(relu_dict_parameters,my_model,target,weights, integration_points,g_N,weights_bd, integration_points_bd, k) 
        # print("argmax time: ", time.time() - start_argmax) 
        # print("selected neuron index: ",neuron_index,relu_dict_parameters[neuron_index,0],-relu_dict_parameters[neuron_index,1] ) 
        list_w.append(relu_dict_parameters[neuron_index,0])
        list_b.append(-relu_dict_parameters[neuron_index,1]) # different sign convention 
        num_neuron += 1
        my_model = model(1,num_neuron,1,k).to(device)
        my_model.fc1.weight.data[:,0] = torch.tensor(list_w)[:]
        my_model.fc1.bias.data[:] = torch.tensor(list_b)[:]

        sol = minimize_linear_layer_neumann(my_model,target,weights, integration_points,weights_bd, integration_points_bd,g_N,activation ='relu', solver = solver)
        sol = sol.flatten() 
        my_model.fc2.weight.data[0,:] = sol[:]

        if (i+1)%plot_freq == 0: 
            x_test = torch.linspace(0,1,200).view(-1,1).to(device)
            u_true = u_exact(x_test)
            plot_solution_modified(0,1,my_model,x_test,u_true)
        func_values = u_exact(integration_points) - my_model(integration_points).detach()
        func_values_sqrd = func_values*func_values
        err[i+1]= torch.sum(func_values_sqrd*weights)**0.5
        err_h10[i+1] = torch.sum( (my_model.evaluate_derivative(integration_points,1).detach() - du_exact(integration_points) )**2*weights)**0.5 
    print("time taken: ",time.time() - start_time)
    return err, err_h10, my_model

# %% [markdown]
# ## deterministic dictionary

# %%
def u_exact(x):
    return torch.sin(4*pi*x)

def du_exact(x):
    return 4 *pi*torch.cos(4*pi*x)

def rhs(x):
    return  (4*pi)**2 * torch.sin(4*pi*x) + torch.sin(4*pi*x)

def g_N(x):
    return du_exact(x) 

dim = 1 
function_name = "sine1d" 
filename_write = "data/1DNeumannOGA-{}-order.txt".format(function_name)
Nx = 2**11 
order = 2  
f_write = open(filename_write, "a")
f_write.write("Integration points: Nx {}, order {} \n".format(Nx,order))
f_write.close() 

save = True 
write2file = True
rand_deter = 'deter'
for N in [2**10]: # 2**12,2**14
    f_write = open(filename_write, "a")
    my_model = None 
    exponent = 8 
    num_epochs = 2**exponent  
    plot_freq = num_epochs 
    relu_k = 1  
    err_QMC2, err_h10, my_model = OGANeumannReLU1D(None,rhs,u_exact,du_exact,g_N, N,num_epochs,plot_freq, Nx, order, k =relu_k, rand_deter = rand_deter,solver = "direct")

    if save: 
        folder = 'data/'
        filename = folder + 'err_NeumannOGA_1D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        torch.save(err_QMC2,filename) 
        folder = 'data/'
        filename = folder + 'model_NeumannOGA_1D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        torch.save(my_model,filename)

    show_convergence_order2(err_QMC2,err_h10,exponent,2*N,filename_write,write2file = write2file)
    show_convergence_order_latex2(err_QMC2,err_h10,exponent,k=relu_k,d = dim)
# Out:
# using linear solver:  direct
# epoch:  1
# assembling the matrix time taken:  0.0005815029144287109
# solving Ax = b time taken:  0.00017380714416503906
# epoch:  2
# assembling the matrix time taken:  0.0005478858947753906
# solving Ax = b time taken:  0.00012612342834472656
# epoch:  3
# assembling the matrix time taken:  0.0005433559417724609
# solving Ax = b time taken:  0.0001246929168701172
# epoch:  4
# assembling the matrix time taken:  0.0005421638488769531
# solving Ax = b time taken:  0.00012254714965820312
# epoch:  5
# assembling the matrix time taken:  0.0005428791046142578
# solving Ax = b time taken:  0.0001239776611328125
# epoch:  6
# assembling the matrix time taken:  0.0005419254302978516
# solving Ax = b time taken:  0.0001227855682373047
# epoch:  7
# assembling the matrix time taken:  0.0005364418029785156
# solving Ax = b time taken:  0.0001227855682373047
# epoch:  8
# assembling the matrix time taken:  0.0005364418029785156
# solving Ax = b time taken:  0.0001239776611328125
# epoch:  9
# assembling the matrix time taken:  0.0005390644073486328
# solving Ax = b time taken:  0.0001468658447265625
# epoch:  10
# assembling the matrix time taken:  0.0005397796630859375
# solving Ax = b time taken:  0.00013065338134765625
# epoch:  11
# assembling the matrix time taken:  0.000530242919921875
# solving Ax = b time taken:  0.0001327991485595703
# epoch:  12
# assembling the matrix time taken:  0.0005292892456054688
# solving Ax = b time taken:  0.0001304149627685547
# epoch:  13
# assembling the matrix time taken:  0.0005230903625488281
# solving Ax = b time taken:  0.0001392364501953125
# epoch:  14
# assembling the matrix time taken:  0.0005309581756591797
# solving Ax = b time taken:  0.00013875961303710938
# epoch:  15
# assembling the matrix time taken:  0.0005369186401367188
# solving Ax = b time taken:  0.0001456737518310547
# epoch:  16
# assembling the matrix time taken:  0.0005342960357666016
# solving Ax = b time taken:  0.0001385211944580078
# epoch:  17
# assembling the matrix time taken:  0.000530242919921875
# solving Ax = b time taken:  0.00018548965454101562
# epoch:  18
# assembling the matrix time taken:  0.0005319118499755859
# solving Ax = b time taken:  0.00018453598022460938
# epoch:  19
# assembling the matrix time taken:  0.0005369186401367188
# solving Ax = b time taken:  0.0001881122589111328
# epoch:  20
# assembling the matrix time taken:  0.0005393028259277344
# solving Ax = b time taken:  0.00018858909606933594
# epoch:  21
# assembling the matrix time taken:  0.0005319118499755859
# solving Ax = b time taken:  0.0001964569091796875
# epoch:  22
# assembling the matrix time taken:  0.0005440711975097656
# solving Ax = b time taken:  0.0001957416534423828
# epoch:  23
# assembling the matrix time taken:  0.0005640983581542969
# solving Ax = b time taken:  0.0001964569091796875
# epoch:  24
# assembling the matrix time taken:  0.0005700588226318359
# solving Ax = b time taken:  0.0001971721649169922
# epoch:  25
# assembling the matrix time taken:  0.0005640983581542969
# solving Ax = b time taken:  0.00020503997802734375
# epoch:  26
# assembling the matrix time taken:  0.0005738735198974609
# solving Ax = b time taken:  0.00020503997802734375
# epoch:  27
# assembling the matrix time taken:  0.000568389892578125
# solving Ax = b time taken:  0.00021386146545410156
# epoch:  28
# assembling the matrix time taken:  0.0005719661712646484
# solving Ax = b time taken:  0.00021338462829589844
# epoch:  29
# assembling the matrix time taken:  0.0005679130554199219
# solving Ax = b time taken:  0.0002224445343017578
# epoch:  30
# assembling the matrix time taken:  0.0005638599395751953
# solving Ax = b time taken:  0.00022125244140625
# epoch:  31
# assembling the matrix time taken:  0.0005736351013183594
# solving Ax = b time taken:  0.00022912025451660156
# epoch:  32
# assembling the matrix time taken:  0.0005691051483154297
# solving Ax = b time taken:  0.00022721290588378906
# epoch:  33
# assembling the matrix time taken:  0.0005655288696289062
# solving Ax = b time taken:  0.00026416778564453125
# epoch:  34
# assembling the matrix time taken:  0.0005691051483154297
# solving Ax = b time taken:  0.0002582073211669922
# epoch:  35
# assembling the matrix time taken:  0.0005738735198974609
# solving Ax = b time taken:  0.00025844573974609375
# epoch:  36
# assembling the matrix time taken:  0.0005726814270019531
# solving Ax = b time taken:  0.00026035308837890625
# epoch:  37
# assembling the matrix time taken:  0.0005600452423095703
# solving Ax = b time taken:  0.0002663135528564453
# epoch:  38
# assembling the matrix time taken:  0.0005612373352050781
# solving Ax = b time taken:  0.00026917457580566406
# epoch:  39
# assembling the matrix time taken:  0.0005624294281005859
# solving Ax = b time taken:  0.0002658367156982422
# epoch:  40
# assembling the matrix time taken:  0.0005712509155273438
# solving Ax = b time taken:  0.0002758502960205078
# epoch:  41
# assembling the matrix time taken:  0.0005705356597900391
# solving Ax = b time taken:  0.0002760887145996094
# epoch:  42
# assembling the matrix time taken:  0.0005679130554199219
# solving Ax = b time taken:  0.0002830028533935547
# epoch:  43
# assembling the matrix time taken:  0.0005753040313720703
# solving Ax = b time taken:  0.00028324127197265625
# epoch:  44
# assembling the matrix time taken:  0.0005705356597900391
# solving Ax = b time taken:  0.00028252601623535156
# epoch:  45
# assembling the matrix time taken:  0.0005710124969482422
# solving Ax = b time taken:  0.0002918243408203125
# epoch:  46
# assembling the matrix time taken:  0.0005624294281005859
# solving Ax = b time taken:  0.0002918243408203125
# epoch:  47
# assembling the matrix time taken:  0.0005657672882080078
# solving Ax = b time taken:  0.0002923011779785156
# epoch:  48
# assembling the matrix time taken:  0.0005638599395751953
# solving Ax = b time taken:  0.0002930164337158203
# epoch:  49
# assembling the matrix time taken:  0.0005664825439453125
# solving Ax = b time taken:  0.0003192424774169922
# epoch:  50
# assembling the matrix time taken:  0.0005767345428466797
# solving Ax = b time taken:  0.00032138824462890625
# epoch:  51
# assembling the matrix time taken:  0.0005719661712646484
# solving Ax = b time taken:  0.00032329559326171875
# epoch:  52
# assembling the matrix time taken:  0.0005643367767333984
# solving Ax = b time taken:  0.00032830238342285156
# epoch:  53
# assembling the matrix time taken:  0.0005657672882080078
# solving Ax = b time taken:  0.0003294944763183594
# epoch:  54
# assembling the matrix time taken:  0.0005748271942138672
# solving Ax = b time taken:  0.0003383159637451172
# epoch:  55
# assembling the matrix time taken:  0.00057220458984375
# solving Ax = b time taken:  0.0003376007080078125
# epoch:  56
# assembling the matrix time taken:  0.0009133815765380859
# solving Ax = b time taken:  0.0004220008850097656
# epoch:  57
# assembling the matrix time taken:  0.0005669593811035156
# solving Ax = b time taken:  0.0003478527069091797
# epoch:  58
# assembling the matrix time taken:  0.0005700588226318359
# solving Ax = b time taken:  0.00034499168395996094
# epoch:  59
# assembling the matrix time taken:  0.0005686283111572266
# solving Ax = b time taken:  0.000347137451171875
# epoch:  60
# assembling the matrix time taken:  0.0005602836608886719
# solving Ax = b time taken:  0.000347137451171875
# epoch:  61
# assembling the matrix time taken:  0.0005698204040527344
# solving Ax = b time taken:  0.0003533363342285156
# epoch:  62
# assembling the matrix time taken:  0.0005657672882080078
# solving Ax = b time taken:  0.00036025047302246094
# epoch:  63
# assembling the matrix time taken:  0.0005724430084228516
# solving Ax = b time taken:  0.00036263465881347656
# epoch:  64
# assembling the matrix time taken:  0.0005633831024169922
# solving Ax = b time taken:  0.0003612041473388672
# epoch:  65
# assembling the matrix time taken:  0.0005583763122558594
# solving Ax = b time taken:  0.00040149688720703125
# epoch:  66
# assembling the matrix time taken:  0.0005686283111572266
# solving Ax = b time taken:  0.0003941059112548828
# epoch:  67
# assembling the matrix time taken:  0.0005586147308349609
# solving Ax = b time taken:  0.00039315223693847656
# epoch:  68
# assembling the matrix time taken:  0.0005662441253662109
# solving Ax = b time taken:  0.00040030479431152344
# epoch:  69
# assembling the matrix time taken:  0.0005733966827392578
# solving Ax = b time taken:  0.000400543212890625
# epoch:  70
# assembling the matrix time taken:  0.0005578994750976562
# solving Ax = b time taken:  0.0004093647003173828
# epoch:  71
# assembling the matrix time taken:  0.0005600452423095703
# solving Ax = b time taken:  0.00041103363037109375
# epoch:  72
# assembling the matrix time taken:  0.0005652904510498047
# solving Ax = b time taken:  0.00040721893310546875
# epoch:  73
# assembling the matrix time taken:  0.000568389892578125
# solving Ax = b time taken:  0.00041794776916503906
# epoch:  74
# assembling the matrix time taken:  0.0005602836608886719
# solving Ax = b time taken:  0.0004177093505859375
# epoch:  75
# assembling the matrix time taken:  0.0005545616149902344
# solving Ax = b time taken:  0.00042176246643066406
# epoch:  76
# assembling the matrix time taken:  0.0005550384521484375
# solving Ax = b time taken:  0.0004258155822753906
# epoch:  77
# assembling the matrix time taken:  0.0005545616149902344
# solving Ax = b time taken:  0.0004336833953857422
# epoch:  78
# assembling the matrix time taken:  0.00055694580078125
# solving Ax = b time taken:  0.00043129920959472656
# epoch:  79
# assembling the matrix time taken:  0.0005650520324707031
# solving Ax = b time taken:  0.0004341602325439453
# epoch:  80
# assembling the matrix time taken:  0.0005652904510498047
# solving Ax = b time taken:  0.0004169940948486328
# epoch:  81
# assembling the matrix time taken:  0.0005648136138916016
# solving Ax = b time taken:  0.0004520416259765625
# epoch:  82
# assembling the matrix time taken:  0.0005636215209960938
# solving Ax = b time taken:  0.0004482269287109375
# epoch:  83
# assembling the matrix time taken:  0.0005705356597900391
# solving Ax = b time taken:  0.0004534721374511719
# epoch:  84
# assembling the matrix time taken:  0.0005636215209960938
# solving Ax = b time taken:  0.00044727325439453125
# epoch:  85
# assembling the matrix time taken:  0.0005581378936767578
# solving Ax = b time taken:  0.00046253204345703125
# epoch:  86
# assembling the matrix time taken:  0.0005540847778320312
# solving Ax = b time taken:  0.00046539306640625
# epoch:  87
# assembling the matrix time taken:  0.0005586147308349609
# solving Ax = b time taken:  0.00046372413635253906
# epoch:  88
# assembling the matrix time taken:  0.0005543231964111328
# solving Ax = b time taken:  0.00046372413635253906
# epoch:  89
# assembling the matrix time taken:  0.0005648136138916016
# solving Ax = b time taken:  0.00047206878662109375
# epoch:  90
# assembling the matrix time taken:  0.0005633831024169922
# solving Ax = b time taken:  0.00047326087951660156
# epoch:  91
# assembling the matrix time taken:  0.0005657672882080078
# solving Ax = b time taken:  0.0004734992980957031
# epoch:  92
# assembling the matrix time taken:  0.00055694580078125
# solving Ax = b time taken:  0.0004725456237792969
# epoch:  93
# assembling the matrix time taken:  0.0005705356597900391
# solving Ax = b time taken:  0.00048089027404785156
# epoch:  94
# assembling the matrix time taken:  0.0005674362182617188
# solving Ax = b time taken:  0.00048041343688964844
# epoch:  95
# assembling the matrix time taken:  0.0005617141723632812
# solving Ax = b time taken:  0.0004911422729492188
# epoch:  96
# assembling the matrix time taken:  0.0005648136138916016
# solving Ax = b time taken:  0.00048732757568359375
# epoch:  97
# assembling the matrix time taken:  0.0005717277526855469
# solving Ax = b time taken:  0.0005159378051757812
# epoch:  98
# assembling the matrix time taken:  0.0005640983581542969
# solving Ax = b time taken:  0.0005257129669189453
# epoch:  99
# assembling the matrix time taken:  0.0005693435668945312
# solving Ax = b time taken:  0.0005195140838623047
# epoch:  100
# assembling the matrix time taken:  0.0005586147308349609
# solving Ax = b time taken:  0.0005197525024414062
# epoch:  101
# assembling the matrix time taken:  0.0005669593811035156
# solving Ax = b time taken:  0.0005266666412353516
# epoch:  102
# assembling the matrix time taken:  0.0005602836608886719
# solving Ax = b time taken:  0.00052642822265625
# epoch:  103
# assembling the matrix time taken:  0.0005688667297363281
# solving Ax = b time taken:  0.0005357265472412109
# epoch:  104
# assembling the matrix time taken:  0.0005655288696289062
# solving Ax = b time taken:  0.0005342960357666016
# epoch:  105
# assembling the matrix time taken:  0.0005609989166259766
# solving Ax = b time taken:  0.0005426406860351562
# epoch:  106
# assembling the matrix time taken:  0.0005707740783691406
# solving Ax = b time taken:  0.0005428791046142578
# epoch:  107
# assembling the matrix time taken:  0.0005576610565185547
# solving Ax = b time taken:  0.0005457401275634766
# epoch:  108
# assembling the matrix time taken:  0.0005612373352050781
# solving Ax = b time taken:  0.0005447864532470703
# epoch:  109
# assembling the matrix time taken:  0.0005717277526855469
# solving Ax = b time taken:  0.0005512237548828125
# epoch:  110
# assembling the matrix time taken:  0.0005743503570556641
# solving Ax = b time taken:  0.000553131103515625
# epoch:  111
# assembling the matrix time taken:  0.0005626678466796875
# solving Ax = b time taken:  0.0005578994750976562
# epoch:  112
# assembling the matrix time taken:  0.0005588531494140625
# solving Ax = b time taken:  0.0005602836608886719
# epoch:  113
# assembling the matrix time taken:  0.00057220458984375
# solving Ax = b time taken:  0.0005996227264404297
# epoch:  114
# assembling the matrix time taken:  0.0005705356597900391
# solving Ax = b time taken:  0.0005877017974853516
# epoch:  115
# assembling the matrix time taken:  0.000576019287109375
# solving Ax = b time taken:  0.00058746337890625
# epoch:  116
# assembling the matrix time taken:  0.0005693435668945312
# solving Ax = b time taken:  0.0005884170532226562
# epoch:  117
# assembling the matrix time taken:  0.0005643367767333984
# solving Ax = b time taken:  0.0006108283996582031
# epoch:  118
# assembling the matrix time taken:  0.0005631446838378906
# solving Ax = b time taken:  0.0006031990051269531
# epoch:  119
# assembling the matrix time taken:  0.0005631446838378906
# solving Ax = b time taken:  0.0006043910980224609
# epoch:  120
# assembling the matrix time taken:  0.0005633831024169922
# solving Ax = b time taken:  0.0006060600280761719
# epoch:  121
# assembling the matrix time taken:  0.0005626678466796875
# solving Ax = b time taken:  0.0006136894226074219
# epoch:  122
# assembling the matrix time taken:  0.0005648136138916016
# solving Ax = b time taken:  0.0006132125854492188
# epoch:  123
# assembling the matrix time taken:  0.0005750656127929688
# solving Ax = b time taken:  0.0006139278411865234
# epoch:  124
# assembling the matrix time taken:  0.000576019287109375
# solving Ax = b time taken:  0.0006208419799804688
# epoch:  125
# assembling the matrix time taken:  0.0005693435668945312
# solving Ax = b time taken:  0.0006279945373535156
# epoch:  126
# assembling the matrix time taken:  0.0005664825439453125
# solving Ax = b time taken:  0.0006289482116699219
# epoch:  127
# assembling the matrix time taken:  0.0005669593811035156
# solving Ax = b time taken:  0.0006296634674072266
# epoch:  128
# assembling the matrix time taken:  0.0005593299865722656
# solving Ax = b time taken:  0.0006291866302490234
# epoch:  129
# assembling the matrix time taken:  0.0005788803100585938
# solving Ax = b time taken:  0.0006704330444335938
# epoch:  130
# assembling the matrix time taken:  0.0005846023559570312
# solving Ax = b time taken:  0.0006761550903320312
# epoch:  131
# assembling the matrix time taken:  0.0005738735198974609
# solving Ax = b time taken:  0.0006802082061767578
# epoch:  132
# assembling the matrix time taken:  0.0005819797515869141
# solving Ax = b time taken:  0.0007579326629638672
# epoch:  133
# assembling the matrix time taken:  0.0005750656127929688
# solving Ax = b time taken:  0.0006835460662841797
# epoch:  134
# assembling the matrix time taken:  0.0005843639373779297
# solving Ax = b time taken:  0.0006816387176513672
# epoch:  135
# assembling the matrix time taken:  0.0005757808685302734
# solving Ax = b time taken:  0.0006902217864990234
# epoch:  136
# assembling the matrix time taken:  0.0005717277526855469
# solving Ax = b time taken:  0.0006885528564453125
# epoch:  137
# assembling the matrix time taken:  0.0005776882171630859
# solving Ax = b time taken:  0.0006914138793945312
# epoch:  138
# assembling the matrix time taken:  0.0005714893341064453
# solving Ax = b time taken:  0.0006990432739257812
# epoch:  139
# assembling the matrix time taken:  0.0005807876586914062
# solving Ax = b time taken:  0.000698089599609375
# epoch:  140
# assembling the matrix time taken:  0.0005693435668945312
# solving Ax = b time taken:  0.0007114410400390625
# epoch:  141
# assembling the matrix time taken:  0.0005736351013183594
# solving Ax = b time taken:  0.0007076263427734375
# epoch:  142
# assembling the matrix time taken:  0.0005817413330078125
# solving Ax = b time taken:  0.0007066726684570312
# epoch:  143
# assembling the matrix time taken:  0.0005741119384765625
# solving Ax = b time taken:  0.0007114410400390625
# epoch:  144
# assembling the matrix time taken:  0.0005784034729003906
# solving Ax = b time taken:  0.0007157325744628906
# epoch:  145
# assembling the matrix time taken:  0.0005800724029541016
# solving Ax = b time taken:  0.0007503032684326172
# epoch:  146
# assembling the matrix time taken:  0.00057220458984375
# solving Ax = b time taken:  0.0007519721984863281
# epoch:  147
# assembling the matrix time taken:  0.0005753040313720703
# solving Ax = b time taken:  0.0007524490356445312
# epoch:  148
# assembling the matrix time taken:  0.0005834102630615234
# solving Ax = b time taken:  0.0007541179656982422
# epoch:  149
# assembling the matrix time taken:  0.0005838871002197266
# solving Ax = b time taken:  0.000766754150390625
# epoch:  150
# assembling the matrix time taken:  0.0005786418914794922
# solving Ax = b time taken:  0.0007607936859130859
# epoch:  151
# assembling the matrix time taken:  0.0005686283111572266
# solving Ax = b time taken:  0.0007688999176025391
# epoch:  152
# assembling the matrix time taken:  0.0005729198455810547
# solving Ax = b time taken:  0.0007677078247070312
# epoch:  153
# assembling the matrix time taken:  0.0005714893341064453
# solving Ax = b time taken:  0.0007784366607666016
# epoch:  154
# assembling the matrix time taken:  0.0005724430084228516
# solving Ax = b time taken:  0.0007803440093994141
# epoch:  155
# assembling the matrix time taken:  0.0005807876586914062
# solving Ax = b time taken:  0.0007803440093994141
# epoch:  156
# assembling the matrix time taken:  0.0005810260772705078
# solving Ax = b time taken:  0.0007793903350830078
# epoch:  157
# assembling the matrix time taken:  0.0005805492401123047
# solving Ax = b time taken:  0.0007843971252441406
# epoch:  158
# assembling the matrix time taken:  0.0005772113800048828
# solving Ax = b time taken:  0.0007882118225097656
# epoch:  159
# assembling the matrix time taken:  0.0005762577056884766
# solving Ax = b time taken:  0.0007846355438232422
# epoch:  160
# assembling the matrix time taken:  0.0005724430084228516
# solving Ax = b time taken:  0.0007853507995605469
# epoch:  161
# assembling the matrix time taken:  0.0005772113800048828
# solving Ax = b time taken:  0.0008223056793212891
# epoch:  162
# assembling the matrix time taken:  0.0005919933319091797
# solving Ax = b time taken:  0.00090789794921875
# epoch:  163
# assembling the matrix time taken:  0.0005774497985839844
# solving Ax = b time taken:  0.0008244514465332031
# epoch:  164
# assembling the matrix time taken:  0.0005791187286376953
# solving Ax = b time taken:  0.0008296966552734375
# epoch:  165
# assembling the matrix time taken:  0.0005855560302734375
# solving Ax = b time taken:  0.0008394718170166016
# epoch:  166
# assembling the matrix time taken:  0.0005857944488525391
# solving Ax = b time taken:  0.0008411407470703125
# epoch:  167
# assembling the matrix time taken:  0.0005762577056884766
# solving Ax = b time taken:  0.0008485317230224609
# epoch:  168
# assembling the matrix time taken:  0.0005757808685302734
# solving Ax = b time taken:  0.0008382797241210938
# epoch:  169
# assembling the matrix time taken:  0.0005829334259033203
# solving Ax = b time taken:  0.000858306884765625
# epoch:  170
# assembling the matrix time taken:  0.0005719661712646484
# solving Ax = b time taken:  0.0008549690246582031
# epoch:  171
# assembling the matrix time taken:  0.0005815029144287109
# solving Ax = b time taken:  0.0008633136749267578
# epoch:  172
# assembling the matrix time taken:  0.0005807876586914062
# solving Ax = b time taken:  0.0008625984191894531
# epoch:  173
# assembling the matrix time taken:  0.0005769729614257812
# solving Ax = b time taken:  0.0008614063262939453
# epoch:  174
# assembling the matrix time taken:  0.0005826950073242188
# solving Ax = b time taken:  0.0008633136749267578
# epoch:  175
# assembling the matrix time taken:  0.0005738735198974609
# solving Ax = b time taken:  0.0008623600006103516
# epoch:  176
# assembling the matrix time taken:  0.0005850791931152344
# solving Ax = b time taken:  0.0008637905120849609
# epoch:  177
# assembling the matrix time taken:  0.0005738735198974609
# solving Ax = b time taken:  0.0008969306945800781
# epoch:  178
# assembling the matrix time taken:  0.0005807876586914062
# solving Ax = b time taken:  0.0009021759033203125
# epoch:  179
# assembling the matrix time taken:  0.0005853176116943359
# solving Ax = b time taken:  0.0009021759033203125
# epoch:  180
# assembling the matrix time taken:  0.0005774497985839844
# solving Ax = b time taken:  0.0009019374847412109
# epoch:  181
# assembling the matrix time taken:  0.0005853176116943359
# solving Ax = b time taken:  0.0009107589721679688
# epoch:  182
# assembling the matrix time taken:  0.0005888938903808594
# solving Ax = b time taken:  0.0009105205535888672
# epoch:  183
# assembling the matrix time taken:  0.0005848407745361328
# solving Ax = b time taken:  0.0009157657623291016
# epoch:  184
# assembling the matrix time taken:  0.0005774497985839844
# solving Ax = b time taken:  0.0009176731109619141
# epoch:  185
# assembling the matrix time taken:  0.00058746337890625
# solving Ax = b time taken:  0.0009267330169677734
# epoch:  186
# assembling the matrix time taken:  0.0005860328674316406
# solving Ax = b time taken:  0.0009319782257080078
# epoch:  187
# assembling the matrix time taken:  0.0005803108215332031
# solving Ax = b time taken:  0.0009322166442871094
# epoch:  188
# assembling the matrix time taken:  0.0005769729614257812
# solving Ax = b time taken:  0.0009410381317138672
# epoch:  189
# assembling the matrix time taken:  0.00058746337890625
# solving Ax = b time taken:  0.0010161399841308594
# epoch:  190
# assembling the matrix time taken:  0.0005903244018554688
# solving Ax = b time taken:  0.0009505748748779297
# epoch:  191
# assembling the matrix time taken:  0.0005800724029541016
# solving Ax = b time taken:  0.0009515285491943359
# epoch:  192
# assembling the matrix time taken:  0.0005838871002197266
# solving Ax = b time taken:  0.000949859619140625
# epoch:  193
# assembling the matrix time taken:  0.0005741119384765625
# solving Ax = b time taken:  0.000986337661743164
# epoch:  194
# assembling the matrix time taken:  0.0005712509155273438
# solving Ax = b time taken:  0.0009846687316894531
# epoch:  195
# assembling the matrix time taken:  0.0005812644958496094
# solving Ax = b time taken:  0.0009799003601074219
# epoch:  196
# assembling the matrix time taken:  0.0005810260772705078
# solving Ax = b time taken:  0.0009779930114746094
# epoch:  197
# assembling the matrix time taken:  0.0005812644958496094
# solving Ax = b time taken:  0.0009899139404296875
# epoch:  198
# assembling the matrix time taken:  0.0005867481231689453
# solving Ax = b time taken:  0.000997304916381836
# epoch:  199
# assembling the matrix time taken:  0.0005853176116943359
# solving Ax = b time taken:  0.000997781753540039
# epoch:  200
# assembling the matrix time taken:  0.0005755424499511719
# solving Ax = b time taken:  0.0009975433349609375
# epoch:  201
# assembling the matrix time taken:  0.0005521774291992188
# solving Ax = b time taken:  0.0010046958923339844
# epoch:  202
# assembling the matrix time taken:  0.00055694580078125
# solving Ax = b time taken:  0.0010123252868652344
# epoch:  203
# assembling the matrix time taken:  0.0005614757537841797
# solving Ax = b time taken:  0.0010128021240234375
# epoch:  204
# assembling the matrix time taken:  0.00055694580078125
# solving Ax = b time taken:  0.0010132789611816406
# epoch:  205
# assembling the matrix time taken:  0.0005521774291992188
# solving Ax = b time taken:  0.0010204315185546875
# epoch:  206
# assembling the matrix time taken:  0.0005624294281005859
# solving Ax = b time taken:  0.0010197162628173828
# epoch:  207
# assembling the matrix time taken:  0.0005633831024169922
# solving Ax = b time taken:  0.0010216236114501953
# epoch:  208
# assembling the matrix time taken:  0.0005545616149902344
# solving Ax = b time taken:  0.001013040542602539
# epoch:  209
# assembling the matrix time taken:  0.0005757808685302734
# solving Ax = b time taken:  0.0010564327239990234
# epoch:  210
# assembling the matrix time taken:  0.0005514621734619141
# solving Ax = b time taken:  0.001056671142578125
# epoch:  211
# assembling the matrix time taken:  0.0005583763122558594
# solving Ax = b time taken:  0.001056671142578125
# epoch:  212
# assembling the matrix time taken:  0.0005559921264648438
# solving Ax = b time taken:  0.0010654926300048828
# epoch:  213
# assembling the matrix time taken:  0.0005624294281005859
# solving Ax = b time taken:  0.0010750293731689453
# epoch:  214
# assembling the matrix time taken:  0.0005593299865722656
# solving Ax = b time taken:  0.0011703968048095703
# epoch:  215
# assembling the matrix time taken:  0.0005540847778320312
# solving Ax = b time taken:  0.0010726451873779297
# epoch:  216
# assembling the matrix time taken:  0.0005676746368408203
# solving Ax = b time taken:  0.0010755062103271484
# epoch:  217
# assembling the matrix time taken:  0.0005276203155517578
# solving Ax = b time taken:  0.0010902881622314453
# epoch:  218
# assembling the matrix time taken:  0.0005364418029785156
# solving Ax = b time taken:  0.0010905265808105469
# epoch:  219
# assembling the matrix time taken:  0.0018024444580078125
# solving Ax = b time taken:  0.0010974407196044922
# epoch:  220
# assembling the matrix time taken:  0.0005335807800292969
# solving Ax = b time taken:  0.0010905265808105469
# epoch:  221
# assembling the matrix time taken:  0.0005254745483398438
# solving Ax = b time taken:  0.0010912418365478516
# epoch:  222
# assembling the matrix time taken:  0.0005350112915039062
# solving Ax = b time taken:  0.0010924339294433594
# epoch:  223
# assembling the matrix time taken:  0.0005352497100830078
# solving Ax = b time taken:  0.0010905265808105469
# epoch:  224
# assembling the matrix time taken:  0.0005269050598144531
# solving Ax = b time taken:  0.0010967254638671875
# epoch:  225
# assembling the matrix time taken:  0.0005266666412353516
# solving Ax = b time taken:  0.0011374950408935547
# epoch:  226
# assembling the matrix time taken:  0.0005304813385009766
# solving Ax = b time taken:  0.0011339187622070312
# epoch:  227
# assembling the matrix time taken:  0.0005350112915039062
# solving Ax = b time taken:  0.001138925552368164
# epoch:  228
# assembling the matrix time taken:  0.0005314350128173828
# solving Ax = b time taken:  0.0011446475982666016
# epoch:  229
# assembling the matrix time taken:  0.0005338191986083984
# solving Ax = b time taken:  0.0011458396911621094
# epoch:  230
# assembling the matrix time taken:  0.0005364418029785156
# solving Ax = b time taken:  0.0011548995971679688
# epoch:  231
# assembling the matrix time taken:  0.0005373954772949219
# solving Ax = b time taken:  0.0011496543884277344
# epoch:  232
# assembling the matrix time taken:  0.0005366802215576172
# solving Ax = b time taken:  0.0011525154113769531
# epoch:  233
# assembling the matrix time taken:  0.0005292892456054688
# solving Ax = b time taken:  0.0011622905731201172
# epoch:  234
# assembling the matrix time taken:  0.0005331039428710938
# solving Ax = b time taken:  0.001169443130493164
# epoch:  235
# assembling the matrix time taken:  0.0005304813385009766
# solving Ax = b time taken:  0.0011773109436035156
# epoch:  236
# assembling the matrix time taken:  0.0005300045013427734
# solving Ax = b time taken:  0.0011720657348632812
# epoch:  237
# assembling the matrix time taken:  0.0005309581756591797
# solving Ax = b time taken:  0.001255035400390625
# epoch:  238
# assembling the matrix time taken:  0.0005340576171875
# solving Ax = b time taken:  0.0011801719665527344
# epoch:  239
# assembling the matrix time taken:  0.0005319118499755859
# solving Ax = b time taken:  0.0011737346649169922
# epoch:  240
# assembling the matrix time taken:  0.0005297660827636719
# solving Ax = b time taken:  0.0011794567108154297
# epoch:  241
# assembling the matrix time taken:  0.0005276203155517578
# solving Ax = b time taken:  0.0012135505676269531
# epoch:  242
# assembling the matrix time taken:  0.0005245208740234375
# solving Ax = b time taken:  0.0012142658233642578
# epoch:  243
# assembling the matrix time taken:  0.0005292892456054688
# solving Ax = b time taken:  0.0012221336364746094
# epoch:  244
# assembling the matrix time taken:  0.0005254745483398438
# solving Ax = b time taken:  0.001215219497680664
# epoch:  245
# assembling the matrix time taken:  0.0005214214324951172
# solving Ax = b time taken:  0.0012221336364746094
# epoch:  246
# assembling the matrix time taken:  0.0005326271057128906
# solving Ax = b time taken:  0.001230478286743164
# epoch:  247
# assembling the matrix time taken:  0.0005247592926025391
# solving Ax = b time taken:  0.001230478286743164
# epoch:  248
# assembling the matrix time taken:  0.0005352497100830078
# solving Ax = b time taken:  0.001232147216796875
# epoch:  249
# assembling the matrix time taken:  0.0005242824554443359
# solving Ax = b time taken:  0.0012464523315429688
# epoch:  250
# assembling the matrix time taken:  0.0005373954772949219
# solving Ax = b time taken:  0.0012488365173339844
# epoch:  251
# assembling the matrix time taken:  0.0005257129669189453
# solving Ax = b time taken:  0.0012505054473876953
# epoch:  252
# assembling the matrix time taken:  0.0005373954772949219
# solving Ax = b time taken:  0.001247406005859375
# epoch:  253
# assembling the matrix time taken:  0.0005271434783935547
# solving Ax = b time taken:  0.0012483596801757812
# epoch:  254
# assembling the matrix time taken:  0.0005335807800292969
# solving Ax = b time taken:  0.0012562274932861328
# epoch:  255
# assembling the matrix time taken:  0.0005276203155517578
# solving Ax = b time taken:  0.0012507438659667969
# epoch:  256
# assembling the matrix time taken:  0.0005328655242919922
# solving Ax = b time taken:  0.0012493133544921875
# time taken:  1.714421033859253
# neuron num 		 error 		 order
# 4 		 0.252661 		 * 		 4.472712 		 *
#
# 8 		 0.130368 		 0.954617 		 2.889182 		 0.630489
#
# 16 		 0.038492 		 1.759969 		 1.578070 		 0.872500
#
# 32 		 0.009510 		 2.017061 		 0.867991 		 0.862410
#
# 64 		 0.002466 		 1.947093 		 0.451367 		 0.943378
#
# 128 		 0.000606 		 2.024097 		 0.227994 		 0.985307
#
# 256 		 0.000146 		 2.054530 		 0.115001 		 0.987349
#
# neuron num  & 	 $\|u-u_n \|_{L^2}$ & 	 order $O(n^{-2.00})$  & 	 $ | u -u_n |_{H^1}$ & 	 order $O(n^{-1.00})$  \\ \hline \hline
# 4 		 & 0.252661 &		 * & 		 4.472712 & 		 *  \\ \hline
#
# 8 		 &  1.304e-01 &  		 0.95 &  		 2.889e+00 &  		 0.63 \\ \hline
#
# 16 		 &  3.849e-02 &  		 1.76 &  		 1.578e+00 &  		 0.87 \\ \hline
#
# 32 		 &  9.510e-03 &  		 2.02 &  		 8.680e-01 &  		 0.86 \\ \hline
#
# 64 		 &  2.466e-03 &  		 1.95 &  		 4.514e-01 &  		 0.94 \\ \hline
#
# 128 		 &  6.063e-04 &  		 2.02 &  		 2.280e-01 &  		 0.99 \\ \hline
#
# 256 		 &  1.460e-04 &  		 2.05 &  		 1.150e-01 &  		 0.99 \\ \hline
