# %%
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import time
import sys
from scipy.sparse import linalg
from pathlib import Path
import itertools
if torch.cuda.is_available():  
    device = "cuda" 
else:  
    device = "cpu"    


torch.set_default_dtype(torch.float64)
pi = torch.tensor(np.pi,dtype=torch.float64)
zero = torch.tensor([0.]).to(device)
torch.set_printoptions(precision=6)

class model(nn.Module):
    """ ReLU k shallow neural network
    Parameters: 
    input size: input dimension
    hidden_size1 : number of hidden layers 
    num_classes: output classes 
    k: degree of relu functions
    """
    def __init__(self, input_size, hidden_size1, num_classes,k = 1):
        super().__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, num_classes,bias = False)
        self.k = k 
    def forward(self, x):
        u1 = self.fc2(F.relu(self.fc1(x))**self.k)
        return u1
    def evaluate_derivative(self, x, i):
        if self.k == 1:
            u1 = self.fc2(torch.heaviside(self.fc1(x),zero) * self.fc1.weight.t()[i-1:i,:] )
        else:
            u1 = self.fc2(self.k*F.relu(self.fc1(x))**(self.k-1) *self.fc1.weight.t()[i-1:i,:] )  
        return u1

def plot_2D(f): 
    
    Nx = 400
    Ny = 400 
    xs = np.linspace(0, 1, Nx)
    ys = np.linspace(0, 1, Ny)
    x, y = np.meshgrid(xs, ys, indexing='xy')
    xy_comb = np.stack((x.flatten(),y.flatten())).T
    xy_comb = torch.tensor(xy_comb)
    z = f(xy_comb).reshape(Nx,Ny)
    z = z.detach().numpy()
    plt.figure(dpi=200)
    ax = plt.axes(projection='3d')
    ax.plot_surface(x , y , z )

    plt.show()

def plot_subdomains(my_model):
    x_coord =torch.linspace(0,1,200)
    wi = my_model.fc1.weight.data
    bi = my_model.fc1.bias.data 
    for i, bias in enumerate(bi):  
        if wi[i,1] !=0: 
            plt.plot(x_coord, - wi[i,0]/wi[i,1]*x_coord - bias/wi[i,1])
        else: 
            plt.plot(x_coord,  - bias/wi[i,0]*torch.ones(x_coord.size()))

    plt.xlim([0,1])
    plt.ylim([0,1])
    plt.legend()
    plt.show()
    return 0   

def adjust_neuron_position(my_model, dims = 3):

    def create_mesh_grid(dims, pts):
        mesh = torch.tensor(list(itertools.product(pts,repeat=dims)))
        vertices = mesh.reshape(len(pts) ** dims, -1) 
        return vertices
    counter = 0 
    # positions = torch.tensor([[0.,0.],[0.,1.],[1.,1.],[1.,0.]])
    pts = torch.tensor([0.,1.])
    positions = create_mesh_grid(dims,pts) 
    neuron_num = my_model.fc1.bias.size(0)
    for i in range(neuron_num): 
        w = my_model.fc1.weight.data[i:i+1,:]
        b = my_model.fc1.bias.data[i]
    #     print(w,b)
        values = torch.matmul(positions,w.T) # + b
        left_end = - torch.max(values)
        right_end = - torch.min(values)
        offset = (right_end - left_end)/50
        if b <= left_end + offset/2 : 
            b = torch.rand(1)*(right_end - left_end - offset) + left_end + offset/2 
            my_model.fc1.bias.data[i] = b 
        if b >= right_end - offset/2 :
            if counter < (dims+1):
#                 print("here")
                counter += 1
            else: # (d + 1) or more 
                b = torch.rand(1)*(right_end - left_end - offset) + left_end + offset/2 
                my_model.fc1.bias.data[i] = b 
    return my_model

# %%
def PiecewiseGQ2D_weights_points(Nx, order): 
    """ A slight modification of PiecewiseGQ2D function that only needs the weights and integration points.
    Parameters
    ----------

    Nx: int 
        number of intervals along the dimension. No Ny, assume Nx = Ny
    order: int 
        order of the Gauss Quadrature

    Returns
    -------
    long_weights: torch.tensor
    integration_points: torch.tensor
    """

#     print("order: ",order )
    x, w = np.polynomial.legendre.leggauss(order)
    gauss_pts = np.array(np.meshgrid(x,x,indexing='ij')).reshape(2,-1).T
    weights =  (w*w[:,None]).ravel()

    gauss_pts =torch.tensor(gauss_pts)
    weights = torch.tensor(weights)

    h = 1/Nx # 100 intervals 
    long_weights =  torch.tile(weights,(Nx**2,1))
    long_weights = long_weights.reshape(-1,1)
    long_weights = long_weights * h**2 /4 

    integration_points = torch.tile(gauss_pts,(Nx**2,1))
    scale_factor = h/2 
    integration_points = scale_factor * integration_points

    index = np.arange(1,Nx+1)-0.5
    ordered_pairs = np.array(np.meshgrid(index,index,indexing='ij'))
    ordered_pairs = ordered_pairs.reshape(2,-1).T

    # print(ordered_pairs)
    # print()
    ordered_pairs = torch.tensor(ordered_pairs)
    # print(ordered_pairs.size())
    ordered_pairs = torch.tile(ordered_pairs, (1,order**2)) # number of GQ points
    # print(ordered_pairs)

    ordered_pairs =  ordered_pairs.reshape(-1,2)
    # print(ordered_pairs)
    translation = ordered_pairs*h 
    # print(translation)

    integration_points = integration_points + translation 
#     print(integration_points.size())
    # func_values = integrand2_torch(integration_points)
    return long_weights.to(device), integration_points.to(device)


def PiecewiseGQ3D_weights_points(Nx, order): 
    """ A slight modification of PiecewiseGQ2D function that only needs the weights and integration points.
    Parameters
    ----------

    Nx: int 
        number of intervals along the dimension. No Ny, assume Nx = Ny
    order: int 
        order of the Gauss Quadrature

    Returns
    -------
    long_weights: torch.tensor
    integration_points: torch.tensor
    """

    """
    Parameters
    ----------
    target : 
        Target function 
    Nx: int 
        number of intervals along the dimension. No Ny, assume Nx = Ny
    order: int 
        order of the Gauss Quadrature
    """

    # print("order: ",order )
    x, w = np.polynomial.legendre.leggauss(order)
    gauss_pts = np.array(np.meshgrid(x,x,x,indexing='ij')).reshape(3,-1).T
    weight_list = np.array(np.meshgrid(w,w,w,indexing='ij'))
    weights =   (weight_list[0]*weight_list[1]*weight_list[2]).ravel() 

    gauss_pts =torch.tensor(gauss_pts)
    weights = torch.tensor(weights)

    h = 1/Nx # 100 intervals 
    long_weights =  torch.tile(weights,(Nx**3,1))
    long_weights = long_weights.reshape(-1,1)
    long_weights = long_weights * h**3 /8 

    integration_points = torch.tile(gauss_pts,(Nx**3,1))
    # print("shape of integration_points", integration_points.size())
    scale_factor = h/2 
    integration_points = scale_factor * integration_points

    index = np.arange(1,Nx+1)-0.5
    ordered_pairs = np.array(np.meshgrid(index,index,index,indexing='ij'))
    ordered_pairs = ordered_pairs.reshape(3,-1).T

    # print(ordered_pairs)
    # print()
    ordered_pairs = torch.tensor(ordered_pairs)
    # print(ordered_pairs.size())
    ordered_pairs = torch.tile(ordered_pairs, (1,order**3)) # number of GQ points
    # print(ordered_pairs)

    ordered_pairs =  ordered_pairs.reshape(-1,3)
    # print(ordered_pairs)
    translation = ordered_pairs*h 
    # print(translation)

    integration_points = integration_points + translation 

    return long_weights.to(device), integration_points.to(device)


def generate_relu_dict3D(N_list):
    N1 = N_list[0]
    N2 = N_list[1]
    N3 = N_list[2]
    
    N = N1*N2*N3 
    theta1 = np.linspace(0, pi, N1, endpoint= True).reshape(N1,1)
    theta2 = np.linspace(0, 2*pi, N2, endpoint= False).reshape(N2,1)
    b = np.linspace(-1.732, 1.732, N3,endpoint=False).reshape(N3,1) # threshold: 3**0.5  
    coord3 = np.array(np.meshgrid(theta1,theta2,b,indexing='ij'))
    coord3 = coord3.reshape(3,-1).T # N1*N2*N3 x 3. coordinates for the grid points 
    coord3 = torch.tensor(coord3) 

    f1 = torch.zeros(N,1) 
    f2 = torch.zeros(N,1)
    f3 = torch.zeros(N,1)
    f4 = torch.zeros(N,1)

    f1[:,0] = torch.cos(coord3[:,0]) 
    f2[:,0] = torch.sin(coord3[:,0]) * torch.cos(coord3[:,1])
    f3[:,0] = torch.sin(coord3[:,0]) * torch.sin(coord3[:,1])
    f4[:,0] = coord3[:,2] 

    Wb_tensor = torch.cat([f1,f2,f3,f4],1) # N x 4 
    return Wb_tensor


def generate_relu_dict3D_QMC(s,N0):
#     Sob = torch.quasirandom.SobolEngine(dimension =3, scramble= True, seed=None) 
#     samples = Sob.draw(N0).double() 

#     for i in range(s-1):
#         samples = torch.cat([samples,Sob.draw(N0).double()],0)

    # Monte Carlo 
    samples = torch.rand(s*N0,3) 
    T =torch.tensor([[pi,0,0],[0,2*pi,0],[0,0,1.732*2]])
    shift = torch.tensor([0,0,-1.732])
    samples = samples@T + shift 

    f1 = torch.zeros(s*N0,1) 
    f2 = torch.zeros(s*N0,1)
    f3 = torch.zeros(s*N0,1)
    f4 = torch.zeros(s*N0,1)

    f1[:,0] = torch.cos(samples[:,0]) 
    f2[:,0] = torch.sin(samples[:,0]) * torch.cos(samples[:,1])
    f3[:,0] = torch.sin(samples[:,0]) * torch.sin(samples[:,1])
    f4[:,0] = samples[:,2] 

    Wb_tensor = torch.cat([f1,f2,f3,f4],1) # N x 4 
    return Wb_tensor


def minimize_linear_layer_H1_explicit_assemble_efficient(model,alpha, target, g_N, weights, integration_points, w_bd, pts_bd, activation = 'relu',solver="direct" ,memory=2**29):
    """ -div alpha grad u(x) + u = f 
    Parameters
    ----------
    model: 
        nn model
    alpha:
        alpha function
    target:
        rhs function f 
    pts_bd:
        integration points on the boundary, embdedded in the domain 
    """ 
    zero = torch.tensor([0.]).to(device)
    start_time = time.time() 
    w = model.fc1.weight.data 
    b = model.fc1.bias.data 
    neuron_num = b.size(0) 
    dim = integration_points.size(1) 
    M = integration_points.size(0)
    coef_alpha = alpha(integration_points) # alpha  

    
    total_size = neuron_num * M # memory, number of floating numbers 
    print('total size: {} {} = {}'.format(neuron_num,M,total_size))
    num_batch = total_size//memory + 1 # divide according to memory
    print("num batches: ",num_batch)
    batch_size = M//num_batch
    jac = torch.zeros(b.size(0),b.size(0)).to(device)
    rhs = torch.zeros(b.size(0),1).to(device)
    
    for j in range(0,M,batch_size): 
        end_index = j + batch_size
        basis_value_col = F.relu(integration_points[j:end_index] @ w.t()+ b)**(model.k) 
        weighted_basis_value_col = basis_value_col * weights[j:end_index] 
        jac += weighted_basis_value_col.t() @ basis_value_col 
        rhs += weighted_basis_value_col.t() @ (target(integration_points[j:end_index,:])) 
            
#     basis_value_col = F.relu(integration_points @ w.t()+ b)**(model.k)
#     weighted_basis_value_col = basis_value_col * weights 

#     jac = weighted_basis_value_col.t() @ basis_value_col  # mass matrix 
#     rhs = weighted_basis_value_col.t() @ (target(integration_points)) 

    # Assemble the boundary condition term <g,v>_{\Gamma_N} 
    size_pts_bd = int(pts_bd.size(0)/(2*dim))
    if g_N != None: # no batch operations for the boundary part, since it is only rhs on the boundary 
        bcs_N = g_N(dim)
        for ii, g_ii in bcs_N:
            # pts_bd_ii = pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
            weighted_g_N = -g_ii(pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:])* w_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
            basis_value_bd_col = F.relu(pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:] @ w.t()+ b)**(model.k)
            rhs += basis_value_bd_col.t() @ weighted_g_N

            weighted_g_N = g_ii(pts_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:])* w_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:]
            basis_value_bd_col = F.relu(pts_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:] @ w.t()+ b)**(model.k)
            rhs += basis_value_bd_col.t() @ weighted_g_N

    # Stiffness matrix term in the jacobian 
     
    for d in range(dim):
        if model.k == 1:  
            for j in range(0,M,batch_size):  
                end_index = j + batch_size 
                basis_value_dxi_col = torch.heaviside(integration_points[j:end_index] @ w.t()+ b, zero) * w.t()[d:d+1,:]
                weighted_basis_value_dx_col = basis_value_dxi_col * weights[j:end_index] * coef_alpha[j:end_index] 
                jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 
#             basis_value_dxi_col = torch.heaviside(integration_points @ w.t()+ b, zero) * w.t()[d:d+1,:]
#             weighted_basis_value_dx_col = basis_value_dxi_col * weights * coef_alpha 
#             jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 

        else:
            for j in range(0,M,batch_size):  
                end_index = j + batch_size 
                basis_value_dxi_col = model.k * F.relu(integration_points[j:end_index] @ w.t()+ b)**(model.k-1) * w.t()[d:d+1,:]
                weighted_basis_value_dx_col = basis_value_dxi_col * weights[j:end_index] * coef_alpha[j:end_index] 
                jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 
#             basis_value_dxi_col = model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * w.t()[d:d+1,:]
#             weighted_basis_value_dx_col = basis_value_dxi_col * weights * coef_alpha  
#             jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 

    print("assembling the mass matrix time taken: ", time.time()-start_time) 


    start_time = time.time()    
    if solver == "cg": 
        sol, exit_code = linalg.cg(np.array(jac.detach().cpu()),np.array(rhs.detach().cpu()),tol=1e-12)
        sol = torch.tensor(sol).view(1,-1)
    elif solver == "direct": 
#         sol = np.linalg.inv( np.array(jac.detach().cpu()) )@np.array(rhs.detach().cpu())
        sol = (torch.linalg.solve( jac.detach(), rhs.detach())).view(1,-1)
    elif solver == "ls":
        sol = (torch.linalg.lstsq(jac.detach().cpu(),rhs.detach().cpu(),driver='gelsd').solution).view(1,-1)
        # sol = (torch.linalg.lstsq(jac.detach(),rhs.detach()).solution).view(1,-1) # gpu/cpu, driver = 'gels', cannot solve singular
    print("solving Ax = b time taken: ", time.time()-start_time)
    return sol 


# def minimize_linear_layer_H1_explicit_assemble_efficient(model,alpha, target, g_N, weights, integration_points, w_bd, pts_bd, activation = 'relu',solver="direct" ):
#     """ -div alpha grad u(x) + u = f 
#     Parameters
#     ----------
#     model: 
#         nn model
#     alpha:
#         alpha function
#     target:
#         rhs function f 
#     pts_bd:
#         integration points on the boundary, embdedded in the domain 
#     """ 
#     zero = torch.tensor([0.]).to(device)
#     start_time = time.time() 
#     w = model.fc1.weight.data 
#     b = model.fc1.bias.data 
#     neuron_num = b.size(0) 
#     dim = integration_points.size(1) 
#     M = integration_points.size(0)
#     coef_alpha = alpha(integration_points) # alpha  
    
#     if activation == 'relu':
#         basis_value_col = F.relu(integration_points @ w.t()+ b)**(model.k)
#         weighted_basis_value_col = basis_value_col * weights 
#         jac = weighted_basis_value_col.t() @ basis_value_col  # mass matrix 
#         rhs = weighted_basis_value_col.t() @ (target(integration_points)) 

#         # Todo1: assemble the boundary condition term <g,v>_{\Gamma_N} 
#         size_pts_bd = int(pts_bd.size(0)/(2*dim))
#         if g_N != None:
#             bcs_N = g_N(dim)
#             for ii, g_ii in bcs_N:
#                 # pts_bd_ii = pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
#                 weighted_g_N = -g_ii(pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:])* w_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
#                 basis_value_bd_col = F.relu(pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:] @ w.t()+ b)**(model.k)
#                 rhs += basis_value_bd_col.t() @ weighted_g_N

#                 weighted_g_N = g_ii(pts_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:])* w_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:]
#                 basis_value_bd_col = F.relu(pts_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:] @ w.t()+ b)**(model.k)
#                 rhs += basis_value_bd_col.t() @ weighted_g_N
        
#         if model.k == 1:  
#             for d in range(dim):
#                 basis_value_dxi_col = torch.heaviside(integration_points @ w.t()+ b, zero) * w.t()[d:d+1,:]
#                 weighted_basis_value_dx_col = basis_value_dxi_col * weights * coef_alpha 
#                 jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 
# #             basis_value_dx_all_col = torch.stack([torch.heaviside(integration_points @ w.t()+ b, zero) * w.t()[d:d+1,:] for d in range(dim)])
            
#         else: 
#             for d in range(dim):
#                 basis_value_dxi_col = model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * w.t()[d:d+1,:]
#                 weighted_basis_value_dx_col = basis_value_dxi_col * weights * coef_alpha  
#                 jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 
# #             basis_value_dx_all_col = torch.stack([model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * w.t()[d:d+1,:] for d in range(dim)]) 
#             # basis_value_dx_col = model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * w.t()[0:1,:]
#             # basis_value_dy_col = model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * w.t()[1:2,:] 

#     print("assembling the mass matrix time taken: ", time.time()-start_time) 


#     start_time = time.time()    
#     if solver == "cg": 
#         sol, exit_code = linalg.cg(np.array(jac.detach().cpu()),np.array(rhs.detach().cpu()),tol=1e-12)
#         sol = torch.tensor(sol).view(1,-1)
#     elif solver == "direct": 
# #         sol = np.linalg.inv( np.array(jac.detach().cpu()) )@np.array(rhs.detach().cpu())
#         sol = (torch.linalg.solve( jac.detach(), rhs.detach())).view(1,-1)
#     elif solver == "ls":
#         sol = (torch.linalg.lstsq(jac.detach().cpu(),rhs.detach().cpu(),driver='gelsd').solution).view(1,-1)
#         # sol = (torch.linalg.lstsq(jac.detach(),rhs.detach()).solution).view(1,-1) # gpu/cpu, driver = 'gels', cannot solve singular
#     print("solving Ax = b time taken: ", time.time()-start_time)
#     return sol 


def OGANeumannReLU3D(my_model,alpha, target,g_N, u_exact, u_exact_grad, N_list,num_epochs,plot_freq, M, k =1, rand_deter = 'deter', linear_solver = "direct",memory = 2**29): 
    """ Orthogonal greedy algorithm using 1D ReLU dictionary over [-pi,pi]
    Parameters
    ----------
    my_model: 
        nn model 
    target: 
        target function
    num_epochs: int 
        number of training epochs 
    integration_intervals: int 
        number of subintervals for piecewise numerical quadrature 

    Returns
    -------
    err: tensor 
        rank 1 torch tensor to record the L2 error history  
    model: 
        trained nn model 
    """
    #Todo Done
    dim = 3 
    gw_expand, integration_points = PiecewiseGQ3D_weights_points(50, order = 3) 
    gw_expand = gw_expand.to(device)
    integration_points = integration_points.to(device)

    # define integration on the boundary 
    gw_expand_bd, integration_points_bd = PiecewiseGQ2D_weights_points(50, order = 3) 
    size_pts_bd = integration_points_bd.size(0) 
    gw_expand_bd_faces = torch.tile(gw_expand_bd,(2*dim,1))

    integration_points_bd_faces = torch.zeros(2*dim*integration_points_bd.size(0),dim).to(device)
    for ind in range(dim): 
        integration_points_bd_faces[2 *ind * size_pts_bd :(2 *ind +1) * size_pts_bd,ind:ind+1] = 0 
        integration_points_bd_faces[(2 *ind)*size_pts_bd :(2 * ind +1) * size_pts_bd,:ind] = integration_points_bd[:,:ind]
        integration_points_bd_faces[(2 *ind)*size_pts_bd :(2 * ind +1) * size_pts_bd,ind+1:] = integration_points_bd[:,ind:]

        integration_points_bd_faces[(2 *ind +1) * size_pts_bd:(2 *ind +2)*size_pts_bd,ind:ind+1] = 1
        integration_points_bd_faces[(2 *ind +1) * size_pts_bd:(2 *ind +2)*size_pts_bd,:ind] = integration_points_bd[:,:ind]        
        integration_points_bd_faces[(2 *ind +1) * size_pts_bd:(2 *ind +2)*size_pts_bd,ind+1:] = integration_points_bd[:,ind:]

    err = torch.zeros(num_epochs+1)
    err_h10 = torch.zeros(num_epochs+1).to(device) 
    if my_model == None: 
        func_values = - target(integration_points)
        num_neuron = 0

        list_b = []
        list_w = []
    else: 
        func_values = - (target(integration_points) - my_model(integration_points).detach())
        bias = my_model.fc1.bias.detach().data
        weights = my_model.fc1.weight.detach().data
        num_neuron = int(bias.size(0))

        list_b = list(bias)
        list_w = list(weights)
    
    # initial error Todo Done
    func_values_sqrd = func_values*func_values
    # print(func_values_sqrd.size())
    # print(gw_expand.size()) 
    err[0]= torch.sum(func_values_sqrd*gw_expand)**0.5
    ## h1 seminorm 
    if u_exact_grad != None:
        u_grad = u_exact_grad() 
        for grad_i in u_grad: 
            err_h10[0] += torch.sum((grad_i(integration_points))**2 * gw_expand)**0.5
    
    start_time = time.time()
    solver = linear_solver

    N0 = np.prod(N_list)
    if rand_deter == 'deter':
        relu_dict_parameters = generate_relu_dict3D(N_list).to(device)
    print("using linear solver: ",solver)
    M2 = integration_points.size(0) # add
    for i in range(num_epochs): 
        start_time = time.time()
        print("epoch: ",i+1, end = '\t')
        if rand_deter == 'rand':
            relu_dict_parameters = generate_relu_dict3D_QMC(1,N0).to(device) 
        if num_neuron == 0: 
            func_values = - target(integration_points)
        else: 
            func_values = - target(integration_points) + my_model(integration_points).detach()

        weight_func_values = func_values*gw_expand  

        ### ======================= 
        total_size = M2 * N0 
        num_batch = total_size//memory + 1 
        batch_size = N0//num_batch

        output = torch.zeros(N0,1).to(device)
        print("argmax batch num, ", num_batch) 
        
        for j in range(0,N0,batch_size):  
            end_index = j + batch_size  
            basis_values_batch = (F.relu( torch.matmul(integration_points,relu_dict_parameters[j:end_index,0:dim].T ) - relu_dict_parameters[j:end_index,dim])**k).T # uses broadcasting    
            output[j:end_index,:]  = torch.matmul(basis_values_batch,weight_func_values)[:,:]
        ### ======================= 
        
#         basis_values = (F.relu( torch.matmul(integration_points,relu_dict_parameters[:,0:dim].T ) - relu_dict_parameters[:,dim])**k).T # uses broadcasting, # dimension 4 
#         output = torch.matmul(basis_values,weight_func_values) #

        ##========
        # grad u part
        alpha_coef = alpha(integration_points) # alpha 
        if my_model!= None:

            if k == 1:  
                for j in range(0,N0,batch_size):  
                    end_index = j + batch_size 
                    derivative_part = torch.heaviside(integration_points @ (relu_dict_parameters[j:end_index,0:dim].T) - relu_dict_parameters[j:end_index,dim], zero) # dimension 4 
                    derivative_part *= alpha_coef # alpha 
                    for dx_i in range(dim): 

                        weight_dbasis_values_dxi =  (derivative_part * relu_dict_parameters.t()[dx_i:dx_i+1,j:end_index]) *gw_expand   
                        dmy_model_dxi = my_model.evaluate_derivative(integration_points,dx_i+1).detach()
                        output[j:end_index,:] += torch.matmul(weight_dbasis_values_dxi.t(), dmy_model_dxi) 

            else:  
                for j in range(0,N0,batch_size):  
                    end_index = j + batch_size 
                    derivative_part = k * F.relu(integration_points @ (relu_dict_parameters[j:end_index,0:dim].T) - relu_dict_parameters[j:end_index,dim])**(k-1) # dimension 4 
                    derivative_part *= alpha_coef # alpha
                    for dx_i in range(dim): 

                        weight_dbasis_values_dxi =  (derivative_part * relu_dict_parameters.t()[dx_i:dx_i+1,j:end_index]) * gw_expand    
                        dmy_model_dxi = my_model.evaluate_derivative(integration_points,dx_i+1).detach()
                        output[j:end_index,:] += torch.matmul(weight_dbasis_values_dxi.t(), dmy_model_dxi) 

        ##========
    
        #Boundary condition term -<g,v>_{\Gamma_N}  
        if g_N != None:
            bcs_N = g_N(dim) 
            for ii, g_ii in bcs_N: 
                
                weighted_g_N = -g_ii(integration_points_bd_faces[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:])* gw_expand_bd_faces[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
                basis_values_bd_faces = (F.relu( torch.matmul(integration_points_bd_faces[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:],relu_dict_parameters[:,0:dim].T ) - relu_dict_parameters[:,dim])**k).T
                output -= torch.matmul(basis_values_bd_faces,weighted_g_N)
                
                weighted_g_N = g_ii(integration_points_bd_faces[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:])* gw_expand_bd_faces[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:]
                basis_values_bd_faces = (F.relu( torch.matmul(integration_points_bd_faces[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:],relu_dict_parameters[:,0:dim].T ) - relu_dict_parameters[:,dim])**k).T
                output -= torch.matmul(basis_values_bd_faces,weighted_g_N)

        
        # output = torch.abs(torch.matmul(basis_values,weight_func_values)) # 
        output = torch.abs(output)
        neuron_index = torch.argmax(output.flatten())
        print("argmax time taken, ", time.time() - start_time)
        
        
        # print(neuron_index)
        list_w.append(relu_dict_parameters[neuron_index,0:dim]) # dimension 4 
        list_b.append(-relu_dict_parameters[neuron_index,dim])
        num_neuron += 1
        my_model = model(dim,num_neuron,1,k).to(device)
        w_tensor = torch.stack(list_w, 0 ) 
        b_tensor = torch.tensor(list_b)
        my_model.fc1.weight.data[:,:] = w_tensor[:,:]
        my_model.fc1.bias.data[:] = b_tensor[:]

        #Todo Done 
#         alpha = None 
        sol = minimize_linear_layer_H1_explicit_assemble_efficient(my_model,alpha, target, g_N, gw_expand, integration_points,gw_expand_bd_faces, integration_points_bd_faces,activation = 'relu',solver = solver)

        my_model.fc2.weight.data[0,:] = sol[:]

        model_values = my_model(integration_points).detach()
        # L2 error ||u - u_n||
        diff_values_sqrd = (u_exact(integration_points) - model_values)**2 
        err[i+1]= torch.sum(diff_values_sqrd*gw_expand)**0.5

        # H10 error || grad(u) - grad(u_n) ||
        if u_exact_grad != None:
            for ind, grad_i in enumerate(u_grad):  
                my_model_dxi = my_model.evaluate_derivative(integration_points,ind+1).detach() 
                err_h10[i+1] += torch.sum((grad_i(integration_points) - my_model_dxi)**2 * gw_expand)**0.5
        print("l2 error {:.6f}, h1 error {:.6f}".format(err[i+1],err_h10[i+1]))
    print("time taken: ",time.time() - start_time)
    return err, err_h10.cpu(), my_model

# %%
def u_exact(x):
    return torch.cos(pi*x[:,0:1])*torch.cos( pi*x[:,1:2]) * torch.cos(pi*x[:,2:3])  
def alpha(x): 
    return torch.ones(x.size(0),1).to(device)

def u_exact_grad():
    d = 3 

    def grad_1(x):
        return - pi* torch.sin(pi*x[:,0:1])*torch.cos( pi*x[:,1:2]) * torch.cos(pi*x[:,2:3])   
    def grad_2(x):
        return - pi* torch.cos(pi*x[:,0:1])*torch.sin( pi*x[:,1:2]) * torch.cos(pi*x[:,2:3])  
    def grad_3(x):
        return - pi* torch.cos(pi*x[:,0:1])*torch.cos( pi*x[:,1:2]) * torch.sin(pi*x[:,2:3])   

    
    u_grad=[grad_1, grad_2,grad_3] 

    return u_grad

def target(x):
    z = (  3 * (pi)**2 + 1)*torch.cos( pi*x[:,0:1])*torch.cos( pi*x[:,1:2] ) * torch.cos(pi*x[:,2:3]) 
    return z 

g_N = None 


function_name = "cospix" 
filename_write = "data-neumann/3DOGA-{}-order.txt".format(function_name)
f_write = open(filename_write, "a")
f_write.write("\n")
f_write.close() 
save = False 
for N_list in [[2**8]]: # ,[2**6,2**6],[2**7,2**7] 
    # save = True 
    f_write = open(filename_write, "a")
    my_model = None 
    # Nx = 50   
    # order = 3   
    M = 300000  
    exponent = 7
    num_epochs = 2**exponent  
    plot_freq = num_epochs 
    N = np.prod(N_list)
    err_QMC2, err_h10, my_model = OGANeumannReLU3D(my_model,alpha, target,g_N, u_exact,u_exact_grad, N_list,num_epochs,plot_freq, M, k = 3, rand_deter= 'rand', linear_solver = "direct")
    
    if save: 
        folder = 'data-neumann/'
        filename = folder + 'err_OGA_4D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        torch.save(err_QMC2,filename) 
        folder = 'data-neumann/'
        filename = folder + 'model_OGA_4D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        torch.save(my_model,filename)

    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_QMC2[i] for i in neuron_nums ]
    err_list2 = [err_h10[i] for i in neuron_nums ] 
    f_write.write('deterministic dictionary size: {}\n'.format(N))
    f_write.write("neuron num \t\t error \t\t order \t\t h10 error \\ order \n")
    print("neuron num \t\t error \t\t order")
    for i, item in enumerate(err_list):
        if i == 0: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t")
            
            # print("*")
            print("{} \t\t {:.6f} \t\t * \t\t {:.6f} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ) )   
            f_write.write("{} \t\t {} \t\t * \t\t {} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ))
        else: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t") 
            # print(np.log(err_list[i-1]/err_list[i])/np.log(2))
            print("{} \t\t {:.6f} \t\t {:.6f} \t\t {:.6f} \t\t {:.6f} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ) )
            f_write.write("{} \t\t {} \t\t {} \t\t {} \t\t {} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ))
    f_write.write("\n")
    f_write.close()
# Out:
# using linear solver:  direct
# epoch:  1	argmax batch num,  2
# argmax time taken,  0.3547232151031494
# total size: 1 3375000 = 3375000
# num batches:  1
# assembling the mass matrix time taken:  0.003964424133300781
# solving Ax = b time taken:  0.07999873161315918
# l2 error 0.353918, h1 error 3.331313
# epoch:  2	argmax batch num,  2
# argmax time taken,  0.04062366485595703
# total size: 2 3375000 = 6750000
# num batches:  1
# assembling the mass matrix time taken:  0.010634183883666992
# solving Ax = b time taken:  0.008073091506958008
# l2 error 0.353592, h1 error 3.330594
# epoch:  3	argmax batch num,  2
# argmax time taken,  0.04001593589782715
# total size: 3 3375000 = 10125000
# num batches:  1
# assembling the mass matrix time taken:  0.004316091537475586
# solving Ax = b time taken:  0.007856369018554688
# l2 error 0.353881, h1 error 3.326875
# epoch:  4	argmax batch num,  2
# argmax time taken,  0.03920435905456543
# total size: 4 3375000 = 13500000
# num batches:  1
# assembling the mass matrix time taken:  0.004181861877441406
# solving Ax = b time taken:  0.008629560470581055
# l2 error 0.358314, h1 error 3.320646
# epoch:  5	argmax batch num,  2
# argmax time taken,  0.039435386657714844
# total size: 5 3375000 = 16875000
# num batches:  1
# assembling the mass matrix time taken:  0.004144430160522461
# solving Ax = b time taken:  0.009676933288574219
# l2 error 0.352035, h1 error 3.312699
# epoch:  6	argmax batch num,  2
# argmax time taken,  0.03993725776672363
# total size: 6 3375000 = 20250000
# num batches:  1
# assembling the mass matrix time taken:  0.003319978713989258
# solving Ax = b time taken:  0.010709285736083984
# l2 error 0.346737, h1 error 3.253630
# epoch:  7	argmax batch num,  2
# argmax time taken,  0.039862632751464844
# total size: 7 3375000 = 23625000
# num batches:  1
# assembling the mass matrix time taken:  0.0036478042602539062
# solving Ax = b time taken:  0.011755704879760742
# l2 error 0.343471, h1 error 3.152471
# epoch:  8	argmax batch num,  2
# argmax time taken,  0.03984427452087402
# total size: 8 3375000 = 27000000
# num batches:  1
# assembling the mass matrix time taken:  0.003900766372680664
# solving Ax = b time taken:  0.012867450714111328
# l2 error 0.309506, h1 error 3.026425
# epoch:  9	argmax batch num,  2
# argmax time taken,  0.04072165489196777
# total size: 9 3375000 = 30375000
# num batches:  1
# assembling the mass matrix time taken:  0.004171848297119141
# solving Ax = b time taken:  0.012625694274902344
# l2 error 0.220029, h1 error 2.217575
# epoch:  10	argmax batch num,  2
# argmax time taken,  0.04671525955200195
# total size: 10 3375000 = 33750000
# num batches:  1
# assembling the mass matrix time taken:  0.0040149688720703125
# solving Ax = b time taken:  0.013403892517089844
# l2 error 0.160822, h1 error 1.896887
# epoch:  11	argmax batch num,  2
# argmax time taken,  0.04006791114807129
# total size: 11 3375000 = 37125000
# num batches:  1
# assembling the mass matrix time taken:  0.003964900970458984
# solving Ax = b time taken:  0.01430511474609375
# l2 error 0.140987, h1 error 1.854255
# epoch:  12	argmax batch num,  2
# argmax time taken,  0.04044198989868164
# total size: 12 3375000 = 40500000
# num batches:  1
# assembling the mass matrix time taken:  0.004067420959472656
# solving Ax = b time taken:  0.015532255172729492
# l2 error 0.130298, h1 error 1.763660
# epoch:  13	argmax batch num,  2
# argmax time taken,  0.04040932655334473
# total size: 13 3375000 = 43875000
# num batches:  1
# assembling the mass matrix time taken:  0.004080057144165039
# solving Ax = b time taken:  0.016449689865112305
# l2 error 0.125119, h1 error 1.729677
# epoch:  14	argmax batch num,  2
# argmax time taken,  0.04041624069213867
# total size: 14 3375000 = 47250000
# num batches:  1
# assembling the mass matrix time taken:  0.003927707672119141
# solving Ax = b time taken:  0.016870737075805664
# l2 error 0.098649, h1 error 1.565656
# epoch:  15	argmax batch num,  2
# argmax time taken,  0.04069328308105469
# total size: 15 3375000 = 50625000
# num batches:  1
# assembling the mass matrix time taken:  0.005640983581542969
# solving Ax = b time taken:  0.01787543296813965
# l2 error 0.097626, h1 error 1.556570
# epoch:  16	argmax batch num,  2
# argmax time taken,  0.04101896286010742
# total size: 16 3375000 = 54000000
# num batches:  1
# assembling the mass matrix time taken:  0.010303497314453125
# solving Ax = b time taken:  0.0187685489654541
# l2 error 0.096169, h1 error 1.546796
# epoch:  17	argmax batch num,  2
# argmax time taken,  0.040468692779541016
# total size: 17 3375000 = 57375000
# num batches:  1
# assembling the mass matrix time taken:  0.004914522171020508
# solving Ax = b time taken:  0.02045297622680664
# l2 error 0.094978, h1 error 1.539655
# epoch:  18	argmax batch num,  2
# argmax time taken,  0.040926456451416016
# total size: 18 3375000 = 60750000
# num batches:  1
# assembling the mass matrix time taken:  0.004210233688354492
# solving Ax = b time taken:  0.021439075469970703
# l2 error 0.094624, h1 error 1.537160
# epoch:  19	argmax batch num,  2
# argmax time taken,  0.04096531867980957
# total size: 19 3375000 = 64125000
# num batches:  1
# assembling the mass matrix time taken:  0.01058506965637207
# solving Ax = b time taken:  0.02225017547607422
# l2 error 0.094293, h1 error 1.534277
# epoch:  20	argmax batch num,  2
# argmax time taken,  0.041893959045410156
# total size: 20 3375000 = 67500000
# num batches:  1
# assembling the mass matrix time taken:  0.004650115966796875
# solving Ax = b time taken:  0.02310347557067871
# l2 error 0.093265, h1 error 1.514358
# epoch:  21	argmax batch num,  2
# argmax time taken,  0.04107332229614258
# total size: 21 3375000 = 70875000
# num batches:  1
# assembling the mass matrix time taken:  0.010517358779907227
# solving Ax = b time taken:  0.024103879928588867
# l2 error 0.092762, h1 error 1.510041
# epoch:  22	argmax batch num,  2
# argmax time taken,  0.04195070266723633
# total size: 22 3375000 = 74250000
# num batches:  1
# assembling the mass matrix time taken:  0.011113405227661133
# solving Ax = b time taken:  0.02504444122314453
# l2 error 0.081711, h1 error 1.364438
# epoch:  23	argmax batch num,  2
# argmax time taken,  0.041083335876464844
# total size: 23 3375000 = 77625000
# num batches:  1
# assembling the mass matrix time taken:  0.010145902633666992
# solving Ax = b time taken:  0.025963783264160156
# l2 error 0.078483, h1 error 1.314081
# epoch:  24	argmax batch num,  2
# argmax time taken,  0.04145479202270508
# total size: 24 3375000 = 81000000
# num batches:  1
# assembling the mass matrix time taken:  0.003923654556274414
# solving Ax = b time taken:  0.026663780212402344
# l2 error 0.072084, h1 error 1.220866
# epoch:  25	argmax batch num,  2
# argmax time taken,  0.04123520851135254
# total size: 25 3375000 = 84375000
# num batches:  1
# assembling the mass matrix time taken:  0.003780841827392578
# solving Ax = b time taken:  0.02787184715270996
# l2 error 0.068978, h1 error 1.164108
# epoch:  26	argmax batch num,  2
# argmax time taken,  0.04185843467712402
# total size: 26 3375000 = 87750000
# num batches:  1
# assembling the mass matrix time taken:  0.010408163070678711
# solving Ax = b time taken:  0.028680086135864258
# l2 error 0.061185, h1 error 1.067192
# epoch:  27	argmax batch num,  2
# argmax time taken,  0.04245400428771973
# total size: 27 3375000 = 91125000
# num batches:  1
# assembling the mass matrix time taken:  0.011064767837524414
# solving Ax = b time taken:  0.029607295989990234
# l2 error 0.057141, h1 error 1.013727
# epoch:  28	argmax batch num,  2
# argmax time taken,  0.0419313907623291
# total size: 28 3375000 = 94500000
# num batches:  1
# assembling the mass matrix time taken:  0.010739326477050781
# solving Ax = b time taken:  0.03053760528564453
# l2 error 0.051641, h1 error 0.944868
# epoch:  29	argmax batch num,  2
# argmax time taken,  0.04209113121032715
# total size: 29 3375000 = 97875000
# num batches:  1
# assembling the mass matrix time taken:  0.010338544845581055
# solving Ax = b time taken:  0.031426429748535156
# l2 error 0.042798, h1 error 0.807641
# epoch:  30	argmax batch num,  2
# argmax time taken,  0.04270792007446289
# total size: 30 3375000 = 101250000
# num batches:  1
# assembling the mass matrix time taken:  0.004000663757324219
# solving Ax = b time taken:  0.03237175941467285
# l2 error 0.037437, h1 error 0.738128
# epoch:  31	argmax batch num,  2
# argmax time taken,  0.04219222068786621
# total size: 31 3375000 = 104625000
# num batches:  1
# assembling the mass matrix time taken:  0.010829448699951172
# solving Ax = b time taken:  0.03324770927429199
# l2 error 0.034639, h1 error 0.691265
# epoch:  32	argmax batch num,  2
# argmax time taken,  0.04273581504821777
# total size: 32 3375000 = 108000000
# num batches:  1
# assembling the mass matrix time taken:  0.010801315307617188
# solving Ax = b time taken:  0.03394365310668945
# l2 error 0.031748, h1 error 0.639582
# epoch:  33	argmax batch num,  2
# argmax time taken,  0.04247140884399414
# total size: 33 3375000 = 111375000
# num batches:  1
# assembling the mass matrix time taken:  0.0041446685791015625
# solving Ax = b time taken:  0.03676581382751465
# l2 error 0.030042, h1 error 0.612379
# epoch:  34	argmax batch num,  2
# argmax time taken,  0.04286694526672363
# total size: 34 3375000 = 114750000
# num batches:  1
# assembling the mass matrix time taken:  0.011685848236083984
# solving Ax = b time taken:  0.037505388259887695
# l2 error 0.028852, h1 error 0.597848
# epoch:  35	argmax batch num,  2
# argmax time taken,  0.04281306266784668
# total size: 35 3375000 = 118125000
# num batches:  1
# assembling the mass matrix time taken:  0.010434150695800781
# solving Ax = b time taken:  0.038402557373046875
# l2 error 0.026507, h1 error 0.565063
# epoch:  36	argmax batch num,  2
# argmax time taken,  0.04338383674621582
# total size: 36 3375000 = 121500000
# num batches:  1
# assembling the mass matrix time taken:  0.0038285255432128906
# solving Ax = b time taken:  0.03916144371032715
# l2 error 0.024456, h1 error 0.535295
# epoch:  37	argmax batch num,  2
# argmax time taken,  0.04326200485229492
# total size: 37 3375000 = 124875000
# num batches:  1
# assembling the mass matrix time taken:  0.011208534240722656
# solving Ax = b time taken:  0.04005861282348633
# l2 error 0.022434, h1 error 0.489118
# epoch:  38	argmax batch num,  2
# argmax time taken,  0.04373741149902344
# total size: 38 3375000 = 128250000
# num batches:  1
# assembling the mass matrix time taken:  0.010482072830200195
# solving Ax = b time taken:  0.04089689254760742
# l2 error 0.019727, h1 error 0.435275
# epoch:  39	argmax batch num,  2
# argmax time taken,  0.04374504089355469
# total size: 39 3375000 = 131625000
# num batches:  1
# assembling the mass matrix time taken:  0.010261297225952148
# solving Ax = b time taken:  0.041782379150390625
# l2 error 0.018607, h1 error 0.412026
# epoch:  40	argmax batch num,  2
# argmax time taken,  0.04360532760620117
# total size: 40 3375000 = 135000000
# num batches:  1
# assembling the mass matrix time taken:  0.003922462463378906
# solving Ax = b time taken:  0.042378902435302734
# l2 error 0.017309, h1 error 0.389221
# epoch:  41	argmax batch num,  2
# argmax time taken,  0.04395461082458496
# total size: 41 3375000 = 138375000
# num batches:  1
# assembling the mass matrix time taken:  0.011146783828735352
# solving Ax = b time taken:  0.04335927963256836
# l2 error 0.016531, h1 error 0.374216
# epoch:  42	argmax batch num,  2
# argmax time taken,  0.04404258728027344
# total size: 42 3375000 = 141750000
# num batches:  1
# assembling the mass matrix time taken:  0.005155324935913086
# solving Ax = b time taken:  0.044165611267089844
# l2 error 0.016015, h1 error 0.362388
# epoch:  43	argmax batch num,  2
# argmax time taken,  0.04414200782775879
# total size: 43 3375000 = 145125000
# num batches:  1
# assembling the mass matrix time taken:  0.010522127151489258
# solving Ax = b time taken:  0.045058250427246094
# l2 error 0.015095, h1 error 0.346939
# epoch:  44	argmax batch num,  2
# argmax time taken,  0.04402565956115723
# total size: 44 3375000 = 148500000
# num batches:  1
# assembling the mass matrix time taken:  0.004641056060791016
# solving Ax = b time taken:  0.045459747314453125
# l2 error 0.014464, h1 error 0.333400
# epoch:  45	argmax batch num,  2
# argmax time taken,  0.044406890869140625
# total size: 45 3375000 = 151875000
# num batches:  1
# assembling the mass matrix time taken:  0.004671573638916016
# solving Ax = b time taken:  0.04634833335876465
# l2 error 0.012911, h1 error 0.303355
# epoch:  46	argmax batch num,  2
# argmax time taken,  0.044296979904174805
# total size: 46 3375000 = 155250000
# num batches:  1
# assembling the mass matrix time taken:  0.010629415512084961
# solving Ax = b time taken:  0.04733085632324219
# l2 error 0.012464, h1 error 0.296310
# epoch:  47	argmax batch num,  2
# argmax time taken,  0.0443263053894043
# total size: 47 3375000 = 158625000
# num batches:  1
# assembling the mass matrix time taken:  0.004606485366821289
# solving Ax = b time taken:  0.04825758934020996
# l2 error 0.012180, h1 error 0.289268
# epoch:  48	argmax batch num,  2
# argmax time taken,  0.044385671615600586
# total size: 48 3375000 = 162000000
# num batches:  1
# assembling the mass matrix time taken:  0.011764764785766602
# solving Ax = b time taken:  0.04893088340759277
# l2 error 0.011821, h1 error 0.285092
# epoch:  49	argmax batch num,  2
# argmax time taken,  0.044402122497558594
# total size: 49 3375000 = 165375000
# num batches:  1
# assembling the mass matrix time taken:  0.010930299758911133
# solving Ax = b time taken:  0.050240516662597656
# l2 error 0.010797, h1 error 0.258536
# epoch:  50	argmax batch num,  2
# argmax time taken,  0.04540061950683594
# total size: 50 3375000 = 168750000
# num batches:  1
# assembling the mass matrix time taken:  0.004163503646850586
# solving Ax = b time taken:  0.05123591423034668
# l2 error 0.010263, h1 error 0.251054
# epoch:  51	argmax batch num,  2
# argmax time taken,  0.04454636573791504
# total size: 51 3375000 = 172125000
# num batches:  1
# assembling the mass matrix time taken:  0.004221677780151367
# solving Ax = b time taken:  0.052056074142456055
# l2 error 0.009527, h1 error 0.241464
# epoch:  52	argmax batch num,  2
# argmax time taken,  0.04527902603149414
# total size: 52 3375000 = 175500000
# num batches:  1
# assembling the mass matrix time taken:  0.011196613311767578
# solving Ax = b time taken:  0.05299639701843262
# l2 error 0.008729, h1 error 0.220956
# epoch:  53	argmax batch num,  2
# argmax time taken,  0.04483175277709961
# total size: 53 3375000 = 178875000
# num batches:  1
# assembling the mass matrix time taken:  0.010833740234375
# solving Ax = b time taken:  0.05405235290527344
# l2 error 0.008027, h1 error 0.206262
# epoch:  54	argmax batch num,  2
# argmax time taken,  0.04521012306213379
# total size: 54 3375000 = 182250000
# num batches:  1
# assembling the mass matrix time taken:  0.004558563232421875
# solving Ax = b time taken:  0.05504465103149414
# l2 error 0.007593, h1 error 0.201095
# epoch:  55	argmax batch num,  2
# argmax time taken,  0.045278310775756836
# total size: 55 3375000 = 185625000
# num batches:  1
# assembling the mass matrix time taken:  0.004464864730834961
# solving Ax = b time taken:  0.05598092079162598
# l2 error 0.007440, h1 error 0.197113
# epoch:  56	argmax batch num,  2
# argmax time taken,  0.0460352897644043
# total size: 56 3375000 = 189000000
# num batches:  1
# assembling the mass matrix time taken:  0.004624605178833008
# solving Ax = b time taken:  0.05684804916381836
# l2 error 0.007300, h1 error 0.191795
# epoch:  57	argmax batch num,  2
# argmax time taken,  0.04497051239013672
# total size: 57 3375000 = 192375000
# num batches:  1
# assembling the mass matrix time taken:  0.010865926742553711
# solving Ax = b time taken:  0.05810856819152832
# l2 error 0.007070, h1 error 0.187347
# epoch:  58	argmax batch num,  2
# argmax time taken,  0.04571723937988281
# total size: 58 3375000 = 195750000
# num batches:  1
# assembling the mass matrix time taken:  0.004109859466552734
# solving Ax = b time taken:  0.05899310111999512
# l2 error 0.006983, h1 error 0.183497
# epoch:  59	argmax batch num,  2
# argmax time taken,  0.045881032943725586
# total size: 59 3375000 = 199125000
# num batches:  1
# assembling the mass matrix time taken:  0.0044727325439453125
# solving Ax = b time taken:  0.06009364128112793
# l2 error 0.006464, h1 error 0.175528
# epoch:  60	argmax batch num,  2
# argmax time taken,  0.04618477821350098
# total size: 60 3375000 = 202500000
# num batches:  1
# assembling the mass matrix time taken:  0.004423379898071289
# solving Ax = b time taken:  0.06097531318664551
# l2 error 0.006334, h1 error 0.172794
# epoch:  61	argmax batch num,  2
# argmax time taken,  0.04576873779296875
# total size: 61 3375000 = 205875000
# num batches:  1
# assembling the mass matrix time taken:  0.004279136657714844
# solving Ax = b time taken:  0.06211376190185547
# l2 error 0.006106, h1 error 0.168204
# epoch:  62	argmax batch num,  2
# argmax time taken,  0.04646420478820801
# total size: 62 3375000 = 209250000
# num batches:  1
# assembling the mass matrix time taken:  0.004211902618408203
# solving Ax = b time taken:  0.06292939186096191
# l2 error 0.005547, h1 error 0.159457
# epoch:  63	argmax batch num,  2
# argmax time taken,  0.04622006416320801
# total size: 63 3375000 = 212625000
# num batches:  1
# assembling the mass matrix time taken:  0.00475311279296875
# solving Ax = b time taken:  0.06406116485595703
# l2 error 0.005209, h1 error 0.154808
# epoch:  64	argmax batch num,  2
# argmax time taken,  0.04658055305480957
# total size: 64 3375000 = 216000000
# num batches:  1
# assembling the mass matrix time taken:  0.0041658878326416016
# solving Ax = b time taken:  0.06455135345458984
# l2 error 0.005125, h1 error 0.150838
# epoch:  65	argmax batch num,  2
# argmax time taken,  0.04613614082336426
# total size: 65 3375000 = 219375000
# num batches:  1
# assembling the mass matrix time taken:  0.0061511993408203125
# solving Ax = b time taken:  0.07966399192810059
# l2 error 0.005038, h1 error 0.149120
# epoch:  66	argmax batch num,  2
# argmax time taken,  0.04713320732116699
# total size: 66 3375000 = 222750000
# num batches:  1
# assembling the mass matrix time taken:  0.10678529739379883
# solving Ax = b time taken:  0.040819644927978516
# l2 error 0.004830, h1 error 0.144056
# epoch:  67	argmax batch num,  2
# argmax time taken,  0.062032461166381836
# total size: 67 3375000 = 226125000
# num batches:  1
# assembling the mass matrix time taken:  0.020194530487060547
# solving Ax = b time taken:  0.08643937110900879
# l2 error 0.004440, h1 error 0.133331
# epoch:  68	argmax batch num,  2
# argmax time taken,  0.06114649772644043
# total size: 68 3375000 = 229500000
# num batches:  1
# assembling the mass matrix time taken:  0.019756793975830078
# solving Ax = b time taken:  0.07873749732971191
# l2 error 0.004255, h1 error 0.127865
# epoch:  69	argmax batch num,  2
# argmax time taken,  0.04827690124511719
# total size: 69 3375000 = 232875000
# num batches:  1
# assembling the mass matrix time taken:  0.005792379379272461
# solving Ax = b time taken:  0.08675074577331543
# l2 error 0.004198, h1 error 0.124451
# epoch:  70	argmax batch num,  2
# argmax time taken,  0.04781770706176758
# total size: 70 3375000 = 236250000
# num batches:  1
# assembling the mass matrix time taken:  0.004835844039916992
# solving Ax = b time taken:  0.0815582275390625
# l2 error 0.004119, h1 error 0.122479
# epoch:  71	argmax batch num,  2
# argmax time taken,  0.047591209411621094
# total size: 71 3375000 = 239625000
# num batches:  1
# assembling the mass matrix time taken:  0.004639863967895508
# solving Ax = b time taken:  0.08961725234985352
# l2 error 0.003823, h1 error 0.116808
# epoch:  72	argmax batch num,  2
# argmax time taken,  0.04786086082458496
# total size: 72 3375000 = 243000000
# num batches:  1
# assembling the mass matrix time taken:  0.007725954055786133
# solving Ax = b time taken:  0.0806732177734375
# l2 error 0.003637, h1 error 0.111976
# epoch:  73	argmax batch num,  2
# argmax time taken,  0.054590702056884766
# total size: 73 3375000 = 246375000
# num batches:  1
# assembling the mass matrix time taken:  0.4003136157989502
# solving Ax = b time taken:  0.04907560348510742
# l2 error 0.003568, h1 error 0.107186
# epoch:  74	argmax batch num,  2
# argmax time taken,  0.06261825561523438
# total size: 74 3375000 = 249750000
# num batches:  1
# assembling the mass matrix time taken:  0.020091772079467773
# solving Ax = b time taken:  0.08431482315063477
# l2 error 0.003400, h1 error 0.101691
# epoch:  75	argmax batch num,  2
# argmax time taken,  0.049420833587646484
# total size: 75 3375000 = 253125000
# num batches:  1
# assembling the mass matrix time taken:  0.006024360656738281
# solving Ax = b time taken:  0.09336423873901367
# l2 error 0.003208, h1 error 0.095716
# epoch:  76	argmax batch num,  2
# argmax time taken,  0.048502206802368164
# total size: 76 3375000 = 256500000
# num batches:  1
# assembling the mass matrix time taken:  0.004976511001586914
# solving Ax = b time taken:  0.08633756637573242
# l2 error 0.003086, h1 error 0.093018
# epoch:  77	argmax batch num,  2
# argmax time taken,  0.0487217903137207
# total size: 77 3375000 = 259875000
# num batches:  1
# assembling the mass matrix time taken:  0.0046880245208740234
# solving Ax = b time taken:  0.09682965278625488
# l2 error 0.003057, h1 error 0.091680
# epoch:  78	argmax batch num,  2
# argmax time taken,  0.048528432846069336
# total size: 78 3375000 = 263250000
# num batches:  1
# assembling the mass matrix time taken:  0.006976604461669922
# solving Ax = b time taken:  0.0858309268951416
# l2 error 0.002964, h1 error 0.089596
# epoch:  79	argmax batch num,  2
# argmax time taken,  0.048699378967285156
# total size: 79 3375000 = 266625000
# num batches:  1
# assembling the mass matrix time taken:  0.24910759925842285
# solving Ax = b time taken:  0.06429910659790039
# l2 error 0.002899, h1 error 0.088340
# epoch:  80	argmax batch num,  2
# argmax time taken,  0.0625753402709961
# total size: 80 3375000 = 270000000
# num batches:  1
# assembling the mass matrix time taken:  0.020397424697875977
# solving Ax = b time taken:  0.08881664276123047
# l2 error 0.002839, h1 error 0.086594
# epoch:  81	argmax batch num,  2
# argmax time taken,  0.06299638748168945
# total size: 81 3375000 = 273375000
# num batches:  1
# assembling the mass matrix time taken:  0.00654292106628418
# solving Ax = b time taken:  0.0990302562713623
# l2 error 0.002823, h1 error 0.085953
# epoch:  82	argmax batch num,  2
# argmax time taken,  0.05017495155334473
# total size: 82 3375000 = 276750000
# num batches:  1
# assembling the mass matrix time taken:  0.005276918411254883
# solving Ax = b time taken:  0.09186697006225586
# l2 error 0.002760, h1 error 0.085140
# epoch:  83	argmax batch num,  2
# argmax time taken,  0.04980158805847168
# total size: 83 3375000 = 280125000
# num batches:  1
# assembling the mass matrix time taken:  0.005759000778198242
# solving Ax = b time taken:  0.10672378540039062
# l2 error 0.002683, h1 error 0.083037
# epoch:  84	argmax batch num,  2
# argmax time taken,  0.050051212310791016
# total size: 84 3375000 = 283500000
# num batches:  1
# assembling the mass matrix time taken:  0.1629037857055664
# solving Ax = b time taken:  0.05536460876464844
# l2 error 0.002642, h1 error 0.081801
# epoch:  85	argmax batch num,  2
# argmax time taken,  0.0636298656463623
# total size: 85 3375000 = 286875000
# num batches:  1
# assembling the mass matrix time taken:  0.23941493034362793
# solving Ax = b time taken:  0.0889277458190918
# l2 error 0.002618, h1 error 0.081450
# epoch:  86	argmax batch num,  2
# argmax time taken,  0.05011296272277832
# total size: 86 3375000 = 290250000
# num batches:  1
# assembling the mass matrix time taken:  0.005482673645019531
# solving Ax = b time taken:  0.10010004043579102
# l2 error 0.002588, h1 error 0.080565
# epoch:  87	argmax batch num,  2
# argmax time taken,  0.05050253868103027
# total size: 87 3375000 = 293625000
# num batches:  1
# assembling the mass matrix time taken:  0.0050275325775146484
# solving Ax = b time taken:  0.11039113998413086
# l2 error 0.002514, h1 error 0.079441
# epoch:  88	argmax batch num,  2
# argmax time taken,  0.05048799514770508
# total size: 88 3375000 = 297000000
# num batches:  1
# assembling the mass matrix time taken:  0.0067365169525146484
# solving Ax = b time taken:  0.10627388954162598
# l2 error 0.002459, h1 error 0.078100
# epoch:  89	argmax batch num,  2
# argmax time taken,  0.05055999755859375
# total size: 89 3375000 = 300375000
# num batches:  1
# assembling the mass matrix time taken:  0.2247917652130127
# solving Ax = b time taken:  0.07393193244934082
# l2 error 0.002411, h1 error 0.076131
# epoch:  90	argmax batch num,  2
# argmax time taken,  0.06540989875793457
# total size: 90 3375000 = 303750000
# num batches:  1
# assembling the mass matrix time taken:  0.02031254768371582
# solving Ax = b time taken:  0.11359763145446777
# l2 error 0.002331, h1 error 0.072995
# epoch:  91	argmax batch num,  2
# argmax time taken,  0.06458377838134766
# total size: 91 3375000 = 307125000
# num batches:  1
# assembling the mass matrix time taken:  0.006994962692260742
# solving Ax = b time taken:  0.10971689224243164
# l2 error 0.002259, h1 error 0.071300
# epoch:  92	argmax batch num,  2
# argmax time taken,  0.050646305084228516
# total size: 92 3375000 = 310500000
# num batches:  1
# assembling the mass matrix time taken:  0.004831075668334961
# solving Ax = b time taken:  0.11104655265808105
# l2 error 0.002158, h1 error 0.069200
# epoch:  93	argmax batch num,  2
# argmax time taken,  0.05089616775512695
# total size: 93 3375000 = 313875000
# num batches:  1
# assembling the mass matrix time taken:  0.008634090423583984
# solving Ax = b time taken:  0.11028623580932617
# l2 error 0.002124, h1 error 0.068417
# epoch:  94	argmax batch num,  2
# argmax time taken,  0.05141329765319824
# total size: 94 3375000 = 317250000
# num batches:  1
# assembling the mass matrix time taken:  0.4382913112640381
# solving Ax = b time taken:  0.09020209312438965
# l2 error 0.002077, h1 error 0.067641
# epoch:  95	argmax batch num,  2
# argmax time taken,  0.0652613639831543
# total size: 95 3375000 = 320625000
# num batches:  1
# assembling the mass matrix time taken:  0.023000001907348633
# solving Ax = b time taken:  0.11284112930297852
# l2 error 0.001983, h1 error 0.064576
# epoch:  96	argmax batch num,  2
# argmax time taken,  0.05147123336791992
# total size: 96 3375000 = 324000000
# num batches:  1
# assembling the mass matrix time taken:  0.0050890445709228516
# solving Ax = b time taken:  0.10824131965637207
# l2 error 0.001886, h1 error 0.061563
# epoch:  97	argmax batch num,  2
# argmax time taken,  0.051061153411865234
# total size: 97 3375000 = 327375000
# num batches:  1
# assembling the mass matrix time taken:  0.005532503128051758
# solving Ax = b time taken:  0.1101081371307373
# l2 error 0.001864, h1 error 0.060985
# epoch:  98	argmax batch num,  2
# argmax time taken,  0.05150461196899414
# total size: 98 3375000 = 330750000
# num batches:  1
# assembling the mass matrix time taken:  0.0068247318267822266
# solving Ax = b time taken:  0.10933041572570801
# l2 error 0.001826, h1 error 0.060387
# epoch:  99	argmax batch num,  2
# argmax time taken,  0.05158257484436035
# total size: 99 3375000 = 334125000
# num batches:  1
# assembling the mass matrix time taken:  0.42466020584106445
# solving Ax = b time taken:  0.07017064094543457
# l2 error 0.001765, h1 error 0.058719
# epoch:  100	argmax batch num,  2
# argmax time taken,  0.06563949584960938
# total size: 100 3375000 = 337500000
# num batches:  1
# assembling the mass matrix time taken:  0.02145242691040039
# solving Ax = b time taken:  0.1117856502532959
# l2 error 0.001740, h1 error 0.058409
# epoch:  101	argmax batch num,  2
# argmax time taken,  0.052330732345581055
# total size: 101 3375000 = 340875000
# num batches:  1
# assembling the mass matrix time taken:  0.0063974857330322266
# solving Ax = b time taken:  0.11274313926696777
# l2 error 0.001729, h1 error 0.058147
# epoch:  102	argmax batch num,  2
# argmax time taken,  0.05214047431945801
# total size: 102 3375000 = 344250000
# num batches:  1
# assembling the mass matrix time taken:  0.0059010982513427734
# solving Ax = b time taken:  0.11368894577026367
# l2 error 0.001699, h1 error 0.057528
# epoch:  103	argmax batch num,  2
# argmax time taken,  0.05258655548095703
# total size: 103 3375000 = 347625000
# num batches:  1
# assembling the mass matrix time taken:  0.2016429901123047
# solving Ax = b time taken:  0.06162762641906738
# l2 error 0.001641, h1 error 0.056218
# epoch:  104	argmax batch num,  2
# argmax time taken,  0.06667709350585938
# total size: 104 3375000 = 351000000
# num batches:  1
# assembling the mass matrix time taken:  0.02162027359008789
# solving Ax = b time taken:  0.11584210395812988
# l2 error 0.001606, h1 error 0.055216
# epoch:  105	argmax batch num,  2
# argmax time taken,  0.05292367935180664
# total size: 105 3375000 = 354375000
# num batches:  1
# assembling the mass matrix time taken:  0.006190061569213867
# solving Ax = b time taken:  0.11597728729248047
# l2 error 0.001565, h1 error 0.054573
# epoch:  106	argmax batch num,  2
# argmax time taken,  0.05363178253173828
# total size: 106 3375000 = 357750000
# num batches:  1
# assembling the mass matrix time taken:  0.1347496509552002
# solving Ax = b time taken:  0.09092950820922852
# l2 error 0.001548, h1 error 0.054137
# epoch:  107	argmax batch num,  2
# argmax time taken,  0.05291271209716797
# total size: 107 3375000 = 361125000
# num batches:  1
# assembling the mass matrix time taken:  0.2690448760986328
# solving Ax = b time taken:  0.07411885261535645
# l2 error 0.001528, h1 error 0.053476
# epoch:  108	argmax batch num,  2
# argmax time taken,  0.06737017631530762
# total size: 108 3375000 = 364500000
# num batches:  1
# assembling the mass matrix time taken:  0.021549224853515625
# solving Ax = b time taken:  0.11956501007080078
# l2 error 0.001502, h1 error 0.052432
# epoch:  109	argmax batch num,  2
# argmax time taken,  0.05301046371459961
# total size: 109 3375000 = 367875000
# num batches:  1
# assembling the mass matrix time taken:  0.00622248649597168
# solving Ax = b time taken:  0.12015986442565918
# l2 error 0.001490, h1 error 0.051739
# epoch:  110	argmax batch num,  2
# argmax time taken,  0.05349588394165039
# total size: 110 3375000 = 371250000
# num batches:  1
# assembling the mass matrix time taken:  0.007830381393432617
# solving Ax = b time taken:  0.11868715286254883
# l2 error 0.001447, h1 error 0.050723
# epoch:  111	argmax batch num,  2
# argmax time taken,  0.053818464279174805
# total size: 111 3375000 = 374625000
# num batches:  1
# assembling the mass matrix time taken:  0.5024583339691162
# solving Ax = b time taken:  0.0655369758605957
# l2 error 0.001437, h1 error 0.050496
# epoch:  112	argmax batch num,  2
# argmax time taken,  0.06751656532287598
# total size: 112 3375000 = 378000000
# num batches:  1
# assembling the mass matrix time taken:  0.007919073104858398
# solving Ax = b time taken:  0.1192471981048584
# l2 error 0.001412, h1 error 0.049789
# epoch:  113	argmax batch num,  2
# argmax time taken,  0.053235769271850586
# total size: 113 3375000 = 381375000
# num batches:  1
# assembling the mass matrix time taken:  0.005856752395629883
# solving Ax = b time taken:  0.12509489059448242
# l2 error 0.001379, h1 error 0.048876
# epoch:  114	argmax batch num,  2
# argmax time taken,  0.05389976501464844
# total size: 114 3375000 = 384750000
# num batches:  1
# assembling the mass matrix time taken:  0.008990287780761719
# solving Ax = b time taken:  0.12257933616638184
# l2 error 0.001356, h1 error 0.048030
# epoch:  115	argmax batch num,  2
# argmax time taken,  0.05420541763305664
# total size: 115 3375000 = 388125000
# num batches:  1
# assembling the mass matrix time taken:  0.49906373023986816
# solving Ax = b time taken:  0.0673210620880127
# l2 error 0.001343, h1 error 0.047833
# epoch:  116	argmax batch num,  2
# argmax time taken,  0.06825852394104004
# total size: 116 3375000 = 391500000
# num batches:  1
# assembling the mass matrix time taken:  0.008594274520874023
# solving Ax = b time taken:  0.12414288520812988
# l2 error 0.001320, h1 error 0.047202
# epoch:  117	argmax batch num,  2
# argmax time taken,  0.05388522148132324
# total size: 117 3375000 = 394875000
# num batches:  1
# assembling the mass matrix time taken:  0.0073735713958740234
# solving Ax = b time taken:  0.12560796737670898
# l2 error 0.001308, h1 error 0.046938
# epoch:  118	argmax batch num,  2
# argmax time taken,  0.053931236267089844
# total size: 118 3375000 = 398250000
# num batches:  1
# assembling the mass matrix time taken:  0.008941411972045898
# solving Ax = b time taken:  0.12580251693725586
# l2 error 0.001295, h1 error 0.046631
# epoch:  119	argmax batch num,  2
# argmax time taken,  0.0545957088470459
# total size: 119 3375000 = 401625000
# num batches:  1
# assembling the mass matrix time taken:  0.5990386009216309
# solving Ax = b time taken:  0.06924724578857422
# l2 error 0.001273, h1 error 0.045762
# epoch:  120	argmax batch num,  2
# argmax time taken,  0.06890606880187988
# total size: 120 3375000 = 405000000
# num batches:  1
# assembling the mass matrix time taken:  0.007493734359741211
# solving Ax = b time taken:  0.12700128555297852
# l2 error 0.001260, h1 error 0.045543
# epoch:  121	argmax batch num,  2
# argmax time taken,  0.05425834655761719
# total size: 121 3375000 = 408375000
# num batches:  1
# assembling the mass matrix time taken:  0.006598472595214844
# solving Ax = b time taken:  0.12951898574829102
# l2 error 0.001248, h1 error 0.044949
# epoch:  122	argmax batch num,  2
# argmax time taken,  0.05473828315734863
# total size: 122 3375000 = 411750000
# num batches:  1
# assembling the mass matrix time taken:  0.009750604629516602
# solving Ax = b time taken:  0.12720608711242676
# l2 error 0.001231, h1 error 0.044318
# epoch:  123	argmax batch num,  2
# argmax time taken,  0.0547940731048584
# total size: 123 3375000 = 415125000
# num batches:  1
# assembling the mass matrix time taken:  0.6989245414733887
# solving Ax = b time taken:  0.07104778289794922
# l2 error 0.001221, h1 error 0.044130
# epoch:  124	argmax batch num,  2
# argmax time taken,  0.06869864463806152
# total size: 124 3375000 = 418500000
# num batches:  1
# assembling the mass matrix time taken:  0.0076024532318115234
# solving Ax = b time taken:  0.13064885139465332
# l2 error 0.001185, h1 error 0.043459
# epoch:  125	argmax batch num,  2
# argmax time taken,  0.0550837516784668
# total size: 125 3375000 = 421875000
# num batches:  1
# assembling the mass matrix time taken:  0.006732940673828125
# solving Ax = b time taken:  0.13318634033203125
# l2 error 0.001139, h1 error 0.042485
# epoch:  126	argmax batch num,  2
# argmax time taken,  0.056194305419921875
# total size: 126 3375000 = 425250000
# num batches:  1
# assembling the mass matrix time taken:  0.24336767196655273
# solving Ax = b time taken:  0.07239460945129395
# l2 error 0.001122, h1 error 0.041081
# epoch:  127	argmax batch num,  2
# argmax time taken,  0.07007980346679688
# total size: 127 3375000 = 428625000
# num batches:  1
# assembling the mass matrix time taken:  0.022411584854125977
# solving Ax = b time taken:  0.13437795639038086
# l2 error 0.001095, h1 error 0.040390
# epoch:  128	argmax batch num,  2
# argmax time taken,  0.05597734451293945
# total size: 128 3375000 = 432000000
# num batches:  1
# assembling the mass matrix time taken:  0.008765935897827148
# solving Ax = b time taken:  0.13177871704101562
# l2 error 0.001083, h1 error 0.040118
# time taken:  0.5529196262359619
# neuron num 		 error 		 order
# 4 		 0.358314 		 * 		 3.320646 		 *
#
# 8 		 0.309506 		 0.211258 		 3.026425 		 0.133849
#
# 16 		 0.096169 		 1.686317 		 1.546796 		 0.968332
#
# 32 		 0.031748 		 1.598904 		 0.639582 		 1.274080
#
# 64 		 0.005125 		 2.630972 		 0.150838 		 2.084127
#
# 128 		 0.001083 		 2.242199 		 0.040118 		 1.910677

# %%
4 		 0.354911 		 * 		 3.321857 		 * 

8 		 0.349854 		 0.020703 		 3.112930 		 0.093717 

16 		 0.095583 		 1.871927 		 1.543768 		 1.011817 

32 		 0.023397 		 2.030455 		 0.493063 		 1.646611 

64 		 0.005072 		 2.205648 		 0.140732 		 1.808820 

128 		 0.000975 		 2.378595 		 0.037545 		 1.906242 

256 		 0.000242 		 2.013625 		 0.012579 		 1.577634 

512 		 0.00006747 		 1.839831 		 0.004548 		 1.467792
# Out:
# [tensor(0.354911),
#  tensor(0.349854),
#  tensor(0.095583),
#  tensor(0.023397),
#  tensor(0.005072),
#  tensor(0.000975),
#  tensor(0.000242),
#  tensor(6.747653e-05)]

# %% [markdown]
# ## oscillatory coefficient

# %%
def u_exact(x):
    return torch.cos(pi*x[:,0:1])*torch.cos( pi*x[:,1:2]) * torch.cos(pi*x[:,2:3]) 
def alpha(x): 
#     return torch.ones(x.size(0),1).to(device)
    return 0.5 * torch.sin(6 * pi*x[:,0:1]) + 1. 

def u_exact_grad():
    d = 3 

    def grad_1(x):
        return - pi* torch.sin(pi*x[:,0:1])*torch.cos( pi*x[:,1:2]) * torch.cos(pi*x[:,2:3])   
    def grad_2(x):
        return - pi* torch.cos(pi*x[:,0:1])*torch.sin( pi*x[:,1:2]) * torch.cos(pi*x[:,2:3])  
    def grad_3(x):
        return - pi* torch.cos(pi*x[:,0:1])*torch.cos( pi*x[:,1:2]) * torch.sin(pi*x[:,2:3])   

    u_grad=[grad_1, grad_2,grad_3] 

    return u_grad

def target(x):

    z_c = torch.cos( pi*x[:,0:1])*torch.cos( pi*x[:,1:2] ) * torch.cos(pi*x[:,2:3]) 
    z1 = 3 * pi**2 * torch.sin(pi * x[:,0:1]) * torch.cos( 6*pi*x[:,0:1] ) * torch.cos( pi*x[:,1:2] )* torch.cos(pi*x[:,2:3]) 
    z2 = 0.5 * pi**2 * torch.sin(6*pi * x[:,0:1])* z_c 
    z = z1 + z2 + 2/2*pi**2 * torch.sin(6 * pi * x[:,0:1]) * z_c 
    z += ( 3 * (pi)**2 + 1)*z_c 
    return z 

g_N = None 


function_name = "cospix" 
filename_write = "data-neumann/3DOGA-{}-order.txt".format(function_name)
f_write = open(filename_write, "a")
f_write.write("\n")
f_write.close() 
save = False 
for N_list in [[2**8]]: # ,[2**6,2**6],[2**7,2**7] 
    # save = True 
    f_write = open(filename_write, "a")
    my_model = None 
    # Nx = 50   
    # order = 3   
    M = 300000  
    exponent = 9
    num_epochs = 2**exponent  
    plot_freq = num_epochs 
    N = np.prod(N_list)
    err_QMC2, err_h10, my_model = OGANeumannReLU3D(my_model,alpha, target,g_N, u_exact,u_exact_grad, N_list,num_epochs,plot_freq, M, k = 3, rand_deter= 'rand', linear_solver = "direct")
    
    if save: 
        folder = 'data-neumann/'
        filename = folder + 'err_OGA_4D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        torch.save(err_QMC2,filename) 
        folder = 'data-neumann/'
        filename = folder + 'model_OGA_4D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        torch.save(my_model,filename)

    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_QMC2[i] for i in neuron_nums ]
    err_list2 = [err_h10[i] for i in neuron_nums ] 
    f_write.write('deterministic dictionary size: {}\n'.format(N))
    f_write.write("neuron num \t\t error \t\t order \t\t h10 error \\ order \n")
    print("neuron num \t\t error \t\t order")
    for i, item in enumerate(err_list):
        if i == 0: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t")
            
            # print("*")
            print("{} \t\t {:.6f} \t\t * \t\t {:.6f} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ) )   
            f_write.write("{} \t\t {} \t\t * \t\t {} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ))
        else: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t") 
            # print(np.log(err_list[i-1]/err_list[i])/np.log(2))
            print("{} \t\t {:.6f} \t\t {:.6f} \t\t {:.6f} \t\t {:.6f} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ) )
            f_write.write("{} \t\t {} \t\t {} \t\t {} \t\t {} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ))
    f_write.write("\n")
    f_write.close()
# Out:
# using linear solver:  direct
# epoch:  1	argmax batch num,  2
# argmax time taken,  0.0036385059356689453
# total size: 1 3375000 = 3375000
# num batches:  1
# assembling the mass matrix time taken:  0.0011341571807861328
# solving Ax = b time taken:  0.0030100345611572266
# l2 error 0.354379, h1 error 3.330438
# epoch:  2	argmax batch num,  2
# argmax time taken,  0.00457000732421875
# total size: 2 3375000 = 6750000
# num batches:  1
# assembling the mass matrix time taken:  0.0013885498046875
# solving Ax = b time taken:  0.009688377380371094
# l2 error 0.353762, h1 error 3.330066
# epoch:  3	argmax batch num,  2
# argmax time taken,  0.0059392452239990234
# total size: 3 3375000 = 10125000
# num batches:  1
# assembling the mass matrix time taken:  0.001375436782836914
# solving Ax = b time taken:  0.00920867919921875
# l2 error 0.355635, h1 error 3.327806
# epoch:  4	argmax batch num,  2
# argmax time taken,  0.005828380584716797
# total size: 4 3375000 = 13500000
# num batches:  1
# assembling the mass matrix time taken:  0.0015294551849365234
# solving Ax = b time taken:  0.009825944900512695
# l2 error 0.355877, h1 error 3.322601
# epoch:  5	argmax batch num,  2
# argmax time taken,  0.005814075469970703
# total size: 5 3375000 = 16875000
# num batches:  1
# assembling the mass matrix time taken:  0.0013763904571533203
# solving Ax = b time taken:  0.011026382446289062
# l2 error 0.351965, h1 error 3.313557
# epoch:  6	argmax batch num,  2
# argmax time taken,  0.006194353103637695
# total size: 6 3375000 = 20250000
# num batches:  1
# assembling the mass matrix time taken:  0.0013806819915771484
# solving Ax = b time taken:  0.012077808380126953
# l2 error 0.356709, h1 error 3.301008
# epoch:  7	argmax batch num,  2
# argmax time taken,  0.006070852279663086
# total size: 7 3375000 = 23625000
# num batches:  1
# assembling the mass matrix time taken:  0.0014476776123046875
# solving Ax = b time taken:  0.013122797012329102
# l2 error 0.350807, h1 error 3.295856
# epoch:  8	argmax batch num,  2
# argmax time taken,  0.006318092346191406
# total size: 8 3375000 = 27000000
# num batches:  1
# assembling the mass matrix time taken:  0.0014150142669677734
# solving Ax = b time taken:  0.014108896255493164
# l2 error 0.332912, h1 error 3.179593
# epoch:  9	argmax batch num,  2
# argmax time taken,  0.0064280033111572266
# total size: 9 3375000 = 30375000
# num batches:  1
# assembling the mass matrix time taken:  0.0013976097106933594
# solving Ax = b time taken:  0.013898372650146484
# l2 error 0.220228, h1 error 2.382135
# epoch:  10	argmax batch num,  2
# argmax time taken,  0.006544828414916992
# total size: 10 3375000 = 33750000
# num batches:  1
# assembling the mass matrix time taken:  0.0014851093292236328
# solving Ax = b time taken:  0.014656305313110352
# l2 error 0.152395, h1 error 1.925640
# epoch:  11	argmax batch num,  2
# argmax time taken,  0.006497621536254883
# total size: 11 3375000 = 37125000
# num batches:  1
# assembling the mass matrix time taken:  0.0014083385467529297
# solving Ax = b time taken:  0.015536785125732422
# l2 error 0.171872, h1 error 1.797004
# epoch:  12	argmax batch num,  2
# argmax time taken,  0.0067865848541259766
# total size: 12 3375000 = 40500000
# num batches:  1
# assembling the mass matrix time taken:  0.0014171600341796875
# solving Ax = b time taken:  0.016753196716308594
# l2 error 0.114306, h1 error 1.675009
# epoch:  13	argmax batch num,  2
# argmax time taken,  0.006888151168823242
# total size: 13 3375000 = 43875000
# num batches:  1
# assembling the mass matrix time taken:  0.0014073848724365234
# solving Ax = b time taken:  0.01775527000427246
# l2 error 0.101931, h1 error 1.589530
# epoch:  14	argmax batch num,  2
# argmax time taken,  0.007163524627685547
# total size: 14 3375000 = 47250000
# num batches:  1
# assembling the mass matrix time taken:  0.001421213150024414
# solving Ax = b time taken:  0.018170833587646484
# l2 error 0.098621, h1 error 1.565527
# epoch:  15	argmax batch num,  2
# argmax time taken,  0.007149219512939453
# total size: 15 3375000 = 50625000
# num batches:  1
# assembling the mass matrix time taken:  0.0014107227325439453
# solving Ax = b time taken:  0.019039154052734375
# l2 error 0.097366, h1 error 1.555570
# epoch:  16	argmax batch num,  2
# argmax time taken,  0.007385730743408203
# total size: 16 3375000 = 54000000
# num batches:  1
# assembling the mass matrix time taken:  0.0014042854309082031
# solving Ax = b time taken:  0.019907712936401367
# l2 error 0.095527, h1 error 1.544408
# epoch:  17	argmax batch num,  2
# argmax time taken,  0.0072286128997802734
# total size: 17 3375000 = 57375000
# num batches:  1
# assembling the mass matrix time taken:  0.0013687610626220703
# solving Ax = b time taken:  0.021678924560546875
# l2 error 0.094742, h1 error 1.539496
# epoch:  18	argmax batch num,  2
# argmax time taken,  0.007474184036254883
# total size: 18 3375000 = 60750000
# num batches:  1
# assembling the mass matrix time taken:  0.001386880874633789
# solving Ax = b time taken:  0.022548913955688477
# l2 error 0.092824, h1 error 1.519000
# epoch:  19	argmax batch num,  2
# argmax time taken,  0.0075304508209228516
# total size: 19 3375000 = 64125000
# num batches:  1
# assembling the mass matrix time taken:  0.0013849735260009766
# solving Ax = b time taken:  0.0234527587890625
# l2 error 0.092044, h1 error 1.514176
# epoch:  20	argmax batch num,  2
# argmax time taken,  0.007716655731201172
# total size: 20 3375000 = 67500000
# num batches:  1
# assembling the mass matrix time taken:  0.0013272762298583984
# solving Ax = b time taken:  0.02428460121154785
# l2 error 0.088246, h1 error 1.437519
# epoch:  21	argmax batch num,  2
# argmax time taken,  0.007651567459106445
# total size: 21 3375000 = 70875000
# num batches:  1
# assembling the mass matrix time taken:  0.001276254653930664
# solving Ax = b time taken:  0.025333642959594727
# l2 error 0.082594, h1 error 1.370021
# epoch:  22	argmax batch num,  2
# argmax time taken,  0.007896184921264648
# total size: 22 3375000 = 74250000
# num batches:  1
# assembling the mass matrix time taken:  0.0013012886047363281
# solving Ax = b time taken:  0.026142597198486328
# l2 error 0.080272, h1 error 1.352954
# epoch:  23	argmax batch num,  2
# argmax time taken,  0.007833242416381836
# total size: 23 3375000 = 77625000
# num batches:  1
# assembling the mass matrix time taken:  0.001316070556640625
# solving Ax = b time taken:  0.027091264724731445
# l2 error 0.078803, h1 error 1.340175
# epoch:  24	argmax batch num,  2
# argmax time taken,  0.008076906204223633
# total size: 24 3375000 = 81000000
# num batches:  1
# assembling the mass matrix time taken:  0.0028314590454101562
# solving Ax = b time taken:  0.026302576065063477
# l2 error 0.074131, h1 error 1.260616
# epoch:  25	argmax batch num,  2
# argmax time taken,  0.007944345474243164
# total size: 25 3375000 = 84375000
# num batches:  1
# assembling the mass matrix time taken:  0.0014791488647460938
# solving Ax = b time taken:  0.028945446014404297
# l2 error 0.070475, h1 error 1.218135
# epoch:  26	argmax batch num,  2
# argmax time taken,  0.008270025253295898
# total size: 26 3375000 = 87750000
# num batches:  1
# assembling the mass matrix time taken:  0.001355886459350586
# solving Ax = b time taken:  0.029868602752685547
# l2 error 0.060222, h1 error 1.057531
# epoch:  27	argmax batch num,  2
# argmax time taken,  0.00832223892211914
# total size: 27 3375000 = 91125000
# num batches:  1
# assembling the mass matrix time taken:  0.0013670921325683594
# solving Ax = b time taken:  0.03076910972595215
# l2 error 0.053054, h1 error 0.947216
# epoch:  28	argmax batch num,  2
# argmax time taken,  0.008498907089233398
# total size: 28 3375000 = 94500000
# num batches:  1
# assembling the mass matrix time taken:  0.0014710426330566406
# solving Ax = b time taken:  0.03149294853210449
# l2 error 0.047240, h1 error 0.878193
# epoch:  29	argmax batch num,  2
# argmax time taken,  0.008496284484863281
# total size: 29 3375000 = 97875000
# num batches:  1
# assembling the mass matrix time taken:  0.0014913082122802734
# solving Ax = b time taken:  0.03248906135559082
# l2 error 0.043967, h1 error 0.854313
# epoch:  30	argmax batch num,  2
# argmax time taken,  0.009066343307495117
# total size: 30 3375000 = 101250000
# num batches:  1
# assembling the mass matrix time taken:  0.0014476776123046875
# solving Ax = b time taken:  0.0333859920501709
# l2 error 0.040048, h1 error 0.799225
# epoch:  31	argmax batch num,  2
# argmax time taken,  0.008835077285766602
# total size: 31 3375000 = 104625000
# num batches:  1
# assembling the mass matrix time taken:  0.001363515853881836
# solving Ax = b time taken:  0.03434395790100098
# l2 error 0.037423, h1 error 0.757754
# epoch:  32	argmax batch num,  2
# argmax time taken,  0.009147167205810547
# total size: 32 3375000 = 108000000
# num batches:  1
# assembling the mass matrix time taken:  0.0013141632080078125
# solving Ax = b time taken:  0.03507256507873535
# l2 error 0.033077, h1 error 0.670404
# epoch:  33	argmax batch num,  2
# argmax time taken,  0.00873565673828125
# total size: 33 3375000 = 111375000
# num batches:  1
# assembling the mass matrix time taken:  0.0012848377227783203
# solving Ax = b time taken:  0.037856340408325195
# l2 error 0.030766, h1 error 0.641923
# epoch:  34	argmax batch num,  2
# argmax time taken,  0.00903630256652832
# total size: 34 3375000 = 114750000
# num batches:  1
# assembling the mass matrix time taken:  0.0013196468353271484
# solving Ax = b time taken:  0.03862905502319336
# l2 error 0.029273, h1 error 0.616638
# epoch:  35	argmax batch num,  2
# argmax time taken,  0.009188652038574219
# total size: 35 3375000 = 118125000
# num batches:  1
# assembling the mass matrix time taken:  0.0013098716735839844
# solving Ax = b time taken:  0.03953218460083008
# l2 error 0.025691, h1 error 0.547179
# epoch:  36	argmax batch num,  2
# argmax time taken,  0.009634971618652344
# total size: 36 3375000 = 121500000
# num batches:  1
# assembling the mass matrix time taken:  0.0012907981872558594
# solving Ax = b time taken:  0.040201425552368164
# l2 error 0.024394, h1 error 0.525451
# epoch:  37	argmax batch num,  2
# argmax time taken,  0.009482145309448242
# total size: 37 3375000 = 124875000
# num batches:  1
# assembling the mass matrix time taken:  0.001314401626586914
# solving Ax = b time taken:  0.04120016098022461
# l2 error 0.023676, h1 error 0.516091
# epoch:  38	argmax batch num,  2
# argmax time taken,  0.009889841079711914
# total size: 38 3375000 = 128250000
# num batches:  1
# assembling the mass matrix time taken:  0.0012936592102050781
# solving Ax = b time taken:  0.04199028015136719
# l2 error 0.023091, h1 error 0.506567
# epoch:  39	argmax batch num,  2
# argmax time taken,  0.010016918182373047
# total size: 39 3375000 = 131625000
# num batches:  1
# assembling the mass matrix time taken:  0.0013165473937988281
# solving Ax = b time taken:  0.04280877113342285
# l2 error 0.022041, h1 error 0.492537
# epoch:  40	argmax batch num,  2
# argmax time taken,  0.010168313980102539
# total size: 40 3375000 = 135000000
# num batches:  1
# assembling the mass matrix time taken:  0.0012936592102050781
# solving Ax = b time taken:  0.043482065200805664
# l2 error 0.021415, h1 error 0.484268
# epoch:  41	argmax batch num,  2
# argmax time taken,  0.009945154190063477
# total size: 41 3375000 = 138375000
# num batches:  1
# assembling the mass matrix time taken:  0.0012862682342529297
# solving Ax = b time taken:  0.044501543045043945
# l2 error 0.018992, h1 error 0.443387
# epoch:  42	argmax batch num,  2
# argmax time taken,  0.010018348693847656
# total size: 42 3375000 = 141750000
# num batches:  1
# assembling the mass matrix time taken:  0.0012674331665039062
# solving Ax = b time taken:  0.045355796813964844
# l2 error 0.017203, h1 error 0.406270
# epoch:  43	argmax batch num,  2
# argmax time taken,  0.010123729705810547
# total size: 43 3375000 = 145125000
# num batches:  1
# assembling the mass matrix time taken:  0.0012829303741455078
# solving Ax = b time taken:  0.04620957374572754
# l2 error 0.016628, h1 error 0.395925
# epoch:  44	argmax batch num,  2
# argmax time taken,  0.010300636291503906
# total size: 44 3375000 = 148500000
# num batches:  1
# assembling the mass matrix time taken:  0.001264333724975586
# solving Ax = b time taken:  0.04692435264587402
# l2 error 0.015892, h1 error 0.372264
# epoch:  45	argmax batch num,  2
# argmax time taken,  0.010413408279418945
# total size: 45 3375000 = 151875000
# num batches:  1
# assembling the mass matrix time taken:  0.001308441162109375
# solving Ax = b time taken:  0.0478672981262207
# l2 error 0.015398, h1 error 0.363249
# epoch:  46	argmax batch num,  2
# argmax time taken,  0.010537147521972656
# total size: 46 3375000 = 155250000
# num batches:  1
# assembling the mass matrix time taken:  0.0012402534484863281
# solving Ax = b time taken:  0.048821449279785156
# l2 error 0.013558, h1 error 0.319693
# epoch:  47	argmax batch num,  2
# argmax time taken,  0.010616064071655273
# total size: 47 3375000 = 158625000
# num batches:  1
# assembling the mass matrix time taken:  0.001241445541381836
# solving Ax = b time taken:  0.049796104431152344
# l2 error 0.012629, h1 error 0.302405
# epoch:  48	argmax batch num,  2
# argmax time taken,  0.010805845260620117
# total size: 48 3375000 = 162000000
# num batches:  1
# assembling the mass matrix time taken:  0.0012371540069580078
# solving Ax = b time taken:  0.05051922798156738
# l2 error 0.012098, h1 error 0.285980
# epoch:  49	argmax batch num,  2
# argmax time taken,  0.0106964111328125
# total size: 49 3375000 = 165375000
# num batches:  1
# assembling the mass matrix time taken:  0.001268625259399414
# solving Ax = b time taken:  0.05181765556335449
# l2 error 0.011758, h1 error 0.279814
# epoch:  50	argmax batch num,  2
# argmax time taken,  0.01101231575012207
# total size: 50 3375000 = 168750000
# num batches:  1
# assembling the mass matrix time taken:  0.0012485980987548828
# solving Ax = b time taken:  0.05264735221862793
# l2 error 0.010871, h1 error 0.258444
# epoch:  51	argmax batch num,  2
# argmax time taken,  0.011091470718383789
# total size: 51 3375000 = 172125000
# num batches:  1
# assembling the mass matrix time taken:  0.0012483596801757812
# solving Ax = b time taken:  0.05364513397216797
# l2 error 0.010092, h1 error 0.243723
# epoch:  52	argmax batch num,  2
# argmax time taken,  0.011272192001342773
# total size: 52 3375000 = 175500000
# num batches:  1
# assembling the mass matrix time taken:  0.0012214183807373047
# solving Ax = b time taken:  0.054522037506103516
# l2 error 0.009947, h1 error 0.238348
# epoch:  53	argmax batch num,  2
# argmax time taken,  0.011365175247192383
# total size: 53 3375000 = 178875000
# num batches:  1
# assembling the mass matrix time taken:  0.0012235641479492188
# solving Ax = b time taken:  0.05559897422790527
# l2 error 0.009235, h1 error 0.219327
# epoch:  54	argmax batch num,  2
# argmax time taken,  0.011551380157470703
# total size: 54 3375000 = 182250000
# num batches:  1
# assembling the mass matrix time taken:  0.0012502670288085938
# solving Ax = b time taken:  0.05660533905029297
# l2 error 0.008409, h1 error 0.207574
# epoch:  55	argmax batch num,  2
# argmax time taken,  0.011609792709350586
# total size: 55 3375000 = 185625000
# num batches:  1
# assembling the mass matrix time taken:  0.0012710094451904297
# solving Ax = b time taken:  0.05775022506713867
# l2 error 0.008158, h1 error 0.198024
# epoch:  56	argmax batch num,  2
# argmax time taken,  0.01184535026550293
# total size: 56 3375000 = 189000000
# num batches:  1
# assembling the mass matrix time taken:  0.0012667179107666016
# solving Ax = b time taken:  0.058342695236206055
# l2 error 0.007338, h1 error 0.184805
# epoch:  57	argmax batch num,  2
# argmax time taken,  0.011765241622924805
# total size: 57 3375000 = 192375000
# num batches:  1
# assembling the mass matrix time taken:  0.0012514591217041016
# solving Ax = b time taken:  0.05963945388793945
# l2 error 0.006771, h1 error 0.173857
# epoch:  58	argmax batch num,  2
# argmax time taken,  0.012109994888305664
# total size: 58 3375000 = 195750000
# num batches:  1
# assembling the mass matrix time taken:  0.0012607574462890625
# solving Ax = b time taken:  0.06057167053222656
# l2 error 0.006356, h1 error 0.166293
# epoch:  59	argmax batch num,  2
# argmax time taken,  0.012121438980102539
# total size: 59 3375000 = 199125000
# num batches:  1
# assembling the mass matrix time taken:  0.0012416839599609375
# solving Ax = b time taken:  0.061614990234375
# l2 error 0.006122, h1 error 0.161297
# epoch:  60	argmax batch num,  2
# argmax time taken,  0.012331247329711914
# total size: 60 3375000 = 202500000
# num batches:  1
# assembling the mass matrix time taken:  0.0012230873107910156
# solving Ax = b time taken:  0.06248140335083008
# l2 error 0.005784, h1 error 0.156061
# epoch:  61	argmax batch num,  2
# argmax time taken,  0.012362003326416016
# total size: 61 3375000 = 205875000
# num batches:  1
# assembling the mass matrix time taken:  0.0012385845184326172
# solving Ax = b time taken:  0.06368660926818848
# l2 error 0.005303, h1 error 0.143669
# epoch:  62	argmax batch num,  2
# argmax time taken,  0.012518644332885742
# total size: 62 3375000 = 209250000
# num batches:  1
# assembling the mass matrix time taken:  0.0012328624725341797
# solving Ax = b time taken:  0.06453537940979004
# l2 error 0.005207, h1 error 0.138958
# epoch:  63	argmax batch num,  2
# argmax time taken,  0.012609004974365234
# total size: 63 3375000 = 212625000
# num batches:  1
# assembling the mass matrix time taken:  0.0012362003326416016
# solving Ax = b time taken:  0.06568264961242676
# l2 error 0.004961, h1 error 0.134527
# epoch:  64	argmax batch num,  2
# argmax time taken,  0.01297140121459961
# total size: 64 3375000 = 216000000
# num batches:  1
# assembling the mass matrix time taken:  0.001226663589477539
# solving Ax = b time taken:  0.06610703468322754
# l2 error 0.004861, h1 error 0.131810
# epoch:  65	argmax batch num,  2
# argmax time taken,  0.012532711029052734
# total size: 65 3375000 = 219375000
# num batches:  1
# assembling the mass matrix time taken:  0.0012481212615966797
# solving Ax = b time taken:  0.08424854278564453
# l2 error 0.004709, h1 error 0.129483
# epoch:  66	argmax batch num,  2
# argmax time taken,  0.013500690460205078
# total size: 66 3375000 = 222750000
# num batches:  1
# assembling the mass matrix time taken:  0.0013332366943359375
# solving Ax = b time taken:  0.08042693138122559
# l2 error 0.004638, h1 error 0.127867
# epoch:  67	argmax batch num,  2
# argmax time taken,  0.013609886169433594
# total size: 67 3375000 = 226125000
# num batches:  1
# assembling the mass matrix time taken:  0.0012798309326171875
# solving Ax = b time taken:  0.08629870414733887
# l2 error 0.004390, h1 error 0.124657
# epoch:  68	argmax batch num,  2
# argmax time taken,  0.01378774642944336
# total size: 68 3375000 = 229500000
# num batches:  1
# assembling the mass matrix time taken:  0.0013248920440673828
# solving Ax = b time taken:  0.08191609382629395
# l2 error 0.004301, h1 error 0.122833
# epoch:  69	argmax batch num,  2
# argmax time taken,  0.013954401016235352
# total size: 69 3375000 = 232875000
# num batches:  1
# assembling the mass matrix time taken:  0.001279592514038086
# solving Ax = b time taken:  0.08928322792053223
# l2 error 0.004262, h1 error 0.121005
# epoch:  70	argmax batch num,  2
# argmax time taken,  0.014074087142944336
# total size: 70 3375000 = 236250000
# num batches:  1
# assembling the mass matrix time taken:  0.0013031959533691406
# solving Ax = b time taken:  0.08380126953125
# l2 error 0.004162, h1 error 0.117715
# epoch:  71	argmax batch num,  2
# argmax time taken,  0.014144420623779297
# total size: 71 3375000 = 239625000
# num batches:  1
# assembling the mass matrix time taken:  0.001247406005859375
# solving Ax = b time taken:  0.09179210662841797
# l2 error 0.004014, h1 error 0.115425
# epoch:  72	argmax batch num,  2
# argmax time taken,  0.014259576797485352
# total size: 72 3375000 = 243000000
# num batches:  1
# assembling the mass matrix time taken:  0.0013306140899658203
# solving Ax = b time taken:  0.08504915237426758
# l2 error 0.003787, h1 error 0.110982
# epoch:  73	argmax batch num,  2
# argmax time taken,  0.014276981353759766
# total size: 73 3375000 = 246375000
# num batches:  1
# assembling the mass matrix time taken:  0.00127410888671875
# solving Ax = b time taken:  0.09402036666870117
# l2 error 0.003660, h1 error 0.106682
# epoch:  74	argmax batch num,  2
# argmax time taken,  0.014485597610473633
# total size: 74 3375000 = 249750000
# num batches:  1
# assembling the mass matrix time taken:  0.001329183578491211
# solving Ax = b time taken:  0.08693575859069824
# l2 error 0.003496, h1 error 0.103998
# epoch:  75	argmax batch num,  2
# argmax time taken,  0.014572620391845703
# total size: 75 3375000 = 253125000
# num batches:  1
# assembling the mass matrix time taken:  0.0012483596801757812
# solving Ax = b time taken:  0.09664273262023926
# l2 error 0.003404, h1 error 0.101771
# epoch:  76	argmax batch num,  2
# argmax time taken,  0.014771699905395508
# total size: 76 3375000 = 256500000
# num batches:  1
# assembling the mass matrix time taken:  0.0013234615325927734
# solving Ax = b time taken:  0.08848977088928223
# l2 error 0.003296, h1 error 0.099159
# epoch:  77	argmax batch num,  2
# argmax time taken,  0.014853477478027344
# total size: 77 3375000 = 259875000
# num batches:  1
# assembling the mass matrix time taken:  0.0012607574462890625
# solving Ax = b time taken:  0.09897136688232422
# l2 error 0.003273, h1 error 0.098055
# epoch:  78	argmax batch num,  2
# argmax time taken,  0.015028953552246094
# total size: 78 3375000 = 263250000
# num batches:  1
# assembling the mass matrix time taken:  0.0013320446014404297
# solving Ax = b time taken:  0.09025931358337402
# l2 error 0.003187, h1 error 0.096478
# epoch:  79	argmax batch num,  2
# argmax time taken,  0.015100240707397461
# total size: 79 3375000 = 266625000
# num batches:  1
# assembling the mass matrix time taken:  0.0012629032135009766
# solving Ax = b time taken:  0.10111403465270996
# l2 error 0.003141, h1 error 0.095119
# epoch:  80	argmax batch num,  2
# argmax time taken,  0.015267610549926758
# total size: 80 3375000 = 270000000
# num batches:  1
# assembling the mass matrix time taken:  0.00139617919921875
# solving Ax = b time taken:  0.0915381908416748
# l2 error 0.003084, h1 error 0.094238
# epoch:  81	argmax batch num,  2
# argmax time taken,  0.015336751937866211
# total size: 81 3375000 = 273375000
# num batches:  1
# assembling the mass matrix time taken:  0.0013387203216552734
# solving Ax = b time taken:  0.10313916206359863
# l2 error 0.003038, h1 error 0.092712
# epoch:  82	argmax batch num,  2
# argmax time taken,  0.015733957290649414
# total size: 82 3375000 = 276750000
# num batches:  1
# assembling the mass matrix time taken:  0.0014164447784423828
# solving Ax = b time taken:  0.09665966033935547
# l2 error 0.002997, h1 error 0.091774
# epoch:  83	argmax batch num,  2
# argmax time taken,  0.015772342681884766
# total size: 83 3375000 = 280125000
# num batches:  1
# assembling the mass matrix time taken:  0.001359701156616211
# solving Ax = b time taken:  0.10920429229736328
# l2 error 0.002891, h1 error 0.089251
# epoch:  84	argmax batch num,  2
# argmax time taken,  0.01593804359436035
# total size: 84 3375000 = 283500000
# num batches:  1
# assembling the mass matrix time taken:  0.0014030933380126953
# solving Ax = b time taken:  0.10404729843139648
# l2 error 0.002838, h1 error 0.088412
# epoch:  85	argmax batch num,  2
# argmax time taken,  0.016003847122192383
# total size: 85 3375000 = 286875000
# num batches:  1
# assembling the mass matrix time taken:  0.001340627670288086
# solving Ax = b time taken:  0.1111609935760498
# l2 error 0.002759, h1 error 0.085570
# epoch:  86	argmax batch num,  2
# argmax time taken,  0.01625657081604004
# total size: 86 3375000 = 290250000
# num batches:  1
# assembling the mass matrix time taken:  0.0013873577117919922
# solving Ax = b time taken:  0.10957479476928711
# l2 error 0.002706, h1 error 0.083016
# epoch:  87	argmax batch num,  2
# argmax time taken,  0.016446352005004883
# total size: 87 3375000 = 293625000
# num batches:  1
# assembling the mass matrix time taken:  0.0013561248779296875
# solving Ax = b time taken:  0.1128542423248291
# l2 error 0.002550, h1 error 0.079385
# epoch:  88	argmax batch num,  2
# argmax time taken,  0.01653289794921875
# total size: 88 3375000 = 297000000
# num batches:  1
# assembling the mass matrix time taken:  0.0013403892517089844
# solving Ax = b time taken:  0.11054539680480957
# l2 error 0.002484, h1 error 0.078146
# epoch:  89	argmax batch num,  2
# argmax time taken,  0.016659021377563477
# total size: 89 3375000 = 300375000
# num batches:  1
# assembling the mass matrix time taken:  0.0013701915740966797
# solving Ax = b time taken:  0.11361384391784668
# l2 error 0.002446, h1 error 0.076855
# epoch:  90	argmax batch num,  2
# argmax time taken,  0.017136573791503906
# total size: 90 3375000 = 303750000
# num batches:  1
# assembling the mass matrix time taken:  0.0013318061828613281
# solving Ax = b time taken:  0.11309242248535156
# l2 error 0.002396, h1 error 0.075098
# epoch:  91	argmax batch num,  2
# argmax time taken,  0.017014265060424805
# total size: 91 3375000 = 307125000
# num batches:  1
# assembling the mass matrix time taken:  0.0013740062713623047
# solving Ax = b time taken:  0.11421775817871094
# l2 error 0.002371, h1 error 0.074298
# epoch:  92	argmax batch num,  2
# argmax time taken,  0.01712489128112793
# total size: 92 3375000 = 310500000
# num batches:  1
# assembling the mass matrix time taken:  0.0013413429260253906
# solving Ax = b time taken:  0.11330699920654297
# l2 error 0.002347, h1 error 0.073286
# epoch:  93	argmax batch num,  2
# argmax time taken,  0.01712775230407715
# total size: 93 3375000 = 313875000
# num batches:  1
# assembling the mass matrix time taken:  0.0013458728790283203
# solving Ax = b time taken:  0.11499309539794922
# l2 error 0.002290, h1 error 0.072503
# epoch:  94	argmax batch num,  2
# argmax time taken,  0.01738452911376953
# total size: 94 3375000 = 317250000
# num batches:  1
# assembling the mass matrix time taken:  0.0013782978057861328
# solving Ax = b time taken:  0.11504173278808594
# l2 error 0.002235, h1 error 0.071146
# epoch:  95	argmax batch num,  2
# argmax time taken,  0.01749396324157715
# total size: 95 3375000 = 320625000
# num batches:  1
# assembling the mass matrix time taken:  0.0013933181762695312
# solving Ax = b time taken:  0.11611127853393555
# l2 error 0.002176, h1 error 0.069992
# epoch:  96	argmax batch num,  2
# argmax time taken,  0.017624855041503906
# total size: 96 3375000 = 324000000
# num batches:  1
# assembling the mass matrix time taken:  0.0013837814331054688
# solving Ax = b time taken:  0.1102292537689209
# l2 error 0.002061, h1 error 0.067072
# epoch:  97	argmax batch num,  2
# argmax time taken,  0.01754283905029297
# total size: 97 3375000 = 327375000
# num batches:  1
# assembling the mass matrix time taken:  0.0013263225555419922
# solving Ax = b time taken:  0.11226844787597656
# l2 error 0.002010, h1 error 0.065969
# epoch:  98	argmax batch num,  2
# argmax time taken,  0.017739534378051758
# total size: 98 3375000 = 330750000
# num batches:  1
# assembling the mass matrix time taken:  0.0013718605041503906
# solving Ax = b time taken:  0.11346864700317383
# l2 error 0.001981, h1 error 0.064662
# epoch:  99	argmax batch num,  2
# argmax time taken,  0.017906665802001953
# total size: 99 3375000 = 334125000
# num batches:  1
# assembling the mass matrix time taken:  0.0013458728790283203
# solving Ax = b time taken:  0.11435842514038086
# l2 error 0.001964, h1 error 0.064254
# epoch:  100	argmax batch num,  2
# argmax time taken,  0.018062353134155273
# total size: 100 3375000 = 337500000
# num batches:  1
# assembling the mass matrix time taken:  0.0013833045959472656
# solving Ax = b time taken:  0.11470770835876465
# l2 error 0.001824, h1 error 0.061049
# epoch:  101	argmax batch num,  2
# argmax time taken,  0.01811981201171875
# total size: 101 3375000 = 340875000
# num batches:  1
# assembling the mass matrix time taken:  0.0013892650604248047
# solving Ax = b time taken:  0.11593341827392578
# l2 error 0.001799, h1 error 0.060584
# epoch:  102	argmax batch num,  2
# argmax time taken,  0.018462181091308594
# total size: 102 3375000 = 344250000
# num batches:  1
# assembling the mass matrix time taken:  0.0013966560363769531
# solving Ax = b time taken:  0.1171107292175293
# l2 error 0.001775, h1 error 0.059644
# epoch:  103	argmax batch num,  2
# argmax time taken,  0.018502235412597656
# total size: 103 3375000 = 347625000
# num batches:  1
# assembling the mass matrix time taken:  0.0013885498046875
# solving Ax = b time taken:  0.11841535568237305
# l2 error 0.001746, h1 error 0.059084
# epoch:  104	argmax batch num,  2
# argmax time taken,  0.01870107650756836
# total size: 104 3375000 = 351000000
# num batches:  1
# assembling the mass matrix time taken:  0.0013575553894042969
# solving Ax = b time taken:  0.11835336685180664
# l2 error 0.001725, h1 error 0.058227
# epoch:  105	argmax batch num,  2
# argmax time taken,  0.018575191497802734
# total size: 105 3375000 = 354375000
# num batches:  1
# assembling the mass matrix time taken:  0.001354217529296875
# solving Ax = b time taken:  0.11999654769897461
# l2 error 0.001684, h1 error 0.056459
# epoch:  106	argmax batch num,  2
# argmax time taken,  0.01883530616760254
# total size: 106 3375000 = 357750000
# num batches:  1
# assembling the mass matrix time taken:  0.001390218734741211
# solving Ax = b time taken:  0.1210336685180664
# l2 error 0.001637, h1 error 0.055638
# epoch:  107	argmax batch num,  2
# argmax time taken,  0.018954992294311523
# total size: 107 3375000 = 361125000
# num batches:  1
# assembling the mass matrix time taken:  0.0013470649719238281
# solving Ax = b time taken:  0.12140560150146484
# l2 error 0.001609, h1 error 0.055097
# epoch:  108	argmax batch num,  2
# argmax time taken,  0.019023656845092773
# total size: 108 3375000 = 364500000
# num batches:  1
# assembling the mass matrix time taken:  0.0013921260833740234
# solving Ax = b time taken:  0.1223146915435791
# l2 error 0.001563, h1 error 0.054217
# epoch:  109	argmax batch num,  2
# argmax time taken,  0.019138813018798828
# total size: 109 3375000 = 367875000
# num batches:  1
# assembling the mass matrix time taken:  0.001407623291015625
# solving Ax = b time taken:  0.12356901168823242
# l2 error 0.001513, h1 error 0.052982
# epoch:  110	argmax batch num,  2
# argmax time taken,  0.01941704750061035
# total size: 110 3375000 = 371250000
# num batches:  1
# assembling the mass matrix time taken:  0.0013604164123535156
# solving Ax = b time taken:  0.12434625625610352
# l2 error 0.001487, h1 error 0.052064
# epoch:  111	argmax batch num,  2
# argmax time taken,  0.019474029541015625
# total size: 111 3375000 = 374625000
# num batches:  1
# assembling the mass matrix time taken:  0.0013620853424072266
# solving Ax = b time taken:  0.12543296813964844
# l2 error 0.001465, h1 error 0.051708
# epoch:  112	argmax batch num,  2
# argmax time taken,  0.019564390182495117
# total size: 112 3375000 = 378000000
# num batches:  1
# assembling the mass matrix time taken:  0.0014035701751708984
# solving Ax = b time taken:  0.12434959411621094
# l2 error 0.001443, h1 error 0.051129
# epoch:  113	argmax batch num,  2
# argmax time taken,  0.019361019134521484
# total size: 113 3375000 = 381375000
# num batches:  1
# assembling the mass matrix time taken:  0.0013871192932128906
# solving Ax = b time taken:  0.12765049934387207
# l2 error 0.001427, h1 error 0.050705
# epoch:  114	argmax batch num,  2
# argmax time taken,  0.019833087921142578
# total size: 114 3375000 = 384750000
# num batches:  1
# assembling the mass matrix time taken:  0.0013933181762695312
# solving Ax = b time taken:  0.12835979461669922
# l2 error 0.001411, h1 error 0.050574
# epoch:  115	argmax batch num,  2
# argmax time taken,  0.019963741302490234
# total size: 115 3375000 = 388125000
# num batches:  1
# assembling the mass matrix time taken:  0.001401662826538086
# solving Ax = b time taken:  0.12926197052001953
# l2 error 0.001409, h1 error 0.050422
# epoch:  116	argmax batch num,  2
# argmax time taken,  0.02010178565979004
# total size: 116 3375000 = 391500000
# num batches:  1
# assembling the mass matrix time taken:  0.0013463497161865234
# solving Ax = b time taken:  0.12975525856018066
# l2 error 0.001392, h1 error 0.049989
# epoch:  117	argmax batch num,  2
# argmax time taken,  0.020030736923217773
# total size: 117 3375000 = 394875000
# num batches:  1
# assembling the mass matrix time taken:  0.001374959945678711
# solving Ax = b time taken:  0.1304764747619629
# l2 error 0.001374, h1 error 0.049563
# epoch:  118	argmax batch num,  2
# argmax time taken,  0.020359516143798828
# total size: 118 3375000 = 398250000
# num batches:  1
# assembling the mass matrix time taken:  0.00139617919921875
# solving Ax = b time taken:  0.13206863403320312
# l2 error 0.001362, h1 error 0.048997
# epoch:  119	argmax batch num,  2
# argmax time taken,  0.020607709884643555
# total size: 119 3375000 = 401625000
# num batches:  1
# assembling the mass matrix time taken:  0.0013916492462158203
# solving Ax = b time taken:  0.13207268714904785
# l2 error 0.001349, h1 error 0.048690
# epoch:  120	argmax batch num,  2
# argmax time taken,  0.020729541778564453
# total size: 120 3375000 = 405000000
# num batches:  1
# assembling the mass matrix time taken:  0.0013914108276367188
# solving Ax = b time taken:  0.13206195831298828
# l2 error 0.001297, h1 error 0.047186
# epoch:  121	argmax batch num,  2
# argmax time taken,  0.020623445510864258
# total size: 121 3375000 = 408375000
# num batches:  1
# assembling the mass matrix time taken:  0.0013413429260253906
# solving Ax = b time taken:  0.1333479881286621
# l2 error 0.001271, h1 error 0.046580
# epoch:  122	argmax batch num,  2
# argmax time taken,  0.020919084548950195
# total size: 122 3375000 = 411750000
# num batches:  1
# assembling the mass matrix time taken:  0.0013415813446044922
# solving Ax = b time taken:  0.1335618495941162
# l2 error 0.001236, h1 error 0.045581
# epoch:  123	argmax batch num,  2
# argmax time taken,  0.020946025848388672
# total size: 123 3375000 = 415125000
# num batches:  1
# assembling the mass matrix time taken:  0.001352071762084961
# solving Ax = b time taken:  0.13482451438903809
# l2 error 0.001175, h1 error 0.043967
# epoch:  124	argmax batch num,  2
# argmax time taken,  0.021141529083251953
# total size: 124 3375000 = 418500000
# num batches:  1
# assembling the mass matrix time taken:  0.0013659000396728516
# solving Ax = b time taken:  0.13514113426208496
# l2 error 0.001155, h1 error 0.043583
# epoch:  125	argmax batch num,  2
# argmax time taken,  0.021178245544433594
# total size: 125 3375000 = 421875000
# num batches:  1
# assembling the mass matrix time taken:  0.0013704299926757812
# solving Ax = b time taken:  0.13677597045898438
# l2 error 0.001146, h1 error 0.043335
# epoch:  126	argmax batch num,  2
# argmax time taken,  0.021949291229248047
# total size: 126 3375000 = 425250000
# num batches:  1
# assembling the mass matrix time taken:  0.0013766288757324219
# solving Ax = b time taken:  0.13763976097106934
# l2 error 0.001136, h1 error 0.042992
# epoch:  127	argmax batch num,  2
# argmax time taken,  0.022043943405151367
# total size: 127 3375000 = 428625000
# num batches:  1
# assembling the mass matrix time taken:  0.0013799667358398438
# solving Ax = b time taken:  0.138214111328125
# l2 error 0.001123, h1 error 0.042477
# epoch:  128	argmax batch num,  2
# argmax time taken,  0.0220797061920166
# total size: 128 3375000 = 432000000
# num batches:  1
# assembling the mass matrix time taken:  0.0013225078582763672
# solving Ax = b time taken:  0.13741445541381836
# l2 error 0.001110, h1 error 0.042079
# epoch:  129	argmax batch num,  2
# argmax time taken,  0.020907163619995117
# total size: 129 3375000 = 435375000
# num batches:  1
# assembling the mass matrix time taken:  0.5587160587310791
# solving Ax = b time taken:  0.10742950439453125
# l2 error 0.001090, h1 error 0.041680
# epoch:  130	argmax batch num,  2
# argmax time taken,  0.022463083267211914
# total size: 130 3375000 = 438750000
# num batches:  1
# assembling the mass matrix time taken:  0.007086753845214844
# solving Ax = b time taken:  0.1898026466369629
# l2 error 0.001086, h1 error 0.041490
# epoch:  131	argmax batch num,  2
# argmax time taken,  0.02257061004638672
# total size: 131 3375000 = 442125000
# num batches:  1
# assembling the mass matrix time taken:  0.009942770004272461
# solving Ax = b time taken:  0.16779756546020508
# l2 error 0.001069, h1 error 0.041128
# epoch:  132	argmax batch num,  2
# argmax time taken,  0.022233247756958008
# total size: 132 3375000 = 445500000
# num batches:  1
# assembling the mass matrix time taken:  0.8551709651947021
# solving Ax = b time taken:  0.13704514503479004
# l2 error 0.001050, h1 error 0.040674
# epoch:  133	argmax batch num,  2
# argmax time taken,  0.022985458374023438
# total size: 133 3375000 = 448875000
# num batches:  1
# assembling the mass matrix time taken:  0.0065762996673583984
# solving Ax = b time taken:  0.17547941207885742
# l2 error 0.001034, h1 error 0.040382
# epoch:  134	argmax batch num,  2
# argmax time taken,  0.022491931915283203
# total size: 134 3375000 = 452250000
# num batches:  1
# assembling the mass matrix time taken:  0.011266946792602539
# solving Ax = b time taken:  0.17753314971923828
# l2 error 0.001025, h1 error 0.040119
# epoch:  135	argmax batch num,  2
# argmax time taken,  0.022716522216796875
# total size: 135 3375000 = 455625000
# num batches:  1
# assembling the mass matrix time taken:  0.9166154861450195
# solving Ax = b time taken:  0.09179425239562988
# l2 error 0.001017, h1 error 0.039821
# epoch:  136	argmax batch num,  2
# argmax time taken,  0.023422956466674805
# total size: 136 3375000 = 459000000
# num batches:  1
# assembling the mass matrix time taken:  0.3002314567565918
# solving Ax = b time taken:  0.08868741989135742
# l2 error 0.001013, h1 error 0.039307
# epoch:  137	argmax batch num,  2
# argmax time taken,  0.02271723747253418
# total size: 137 3375000 = 462375000
# num batches:  1
# assembling the mass matrix time taken:  0.04324007034301758
# solving Ax = b time taken:  0.1376662254333496
# l2 error 0.001003, h1 error 0.038983
# epoch:  138	argmax batch num,  2
# argmax time taken,  0.023077011108398438
# total size: 138 3375000 = 465750000
# num batches:  1
# assembling the mass matrix time taken:  1.0391101837158203
# solving Ax = b time taken:  0.10263466835021973
# l2 error 0.000994, h1 error 0.038647
# epoch:  139	argmax batch num,  2
# argmax time taken,  0.02381134033203125
# total size: 139 3375000 = 469125000
# num batches:  1
# assembling the mass matrix time taken:  0.018615007400512695
# solving Ax = b time taken:  0.16576194763183594
# l2 error 0.000984, h1 error 0.038369
# epoch:  140	argmax batch num,  2
# argmax time taken,  0.02319955825805664
# total size: 140 3375000 = 472500000
# num batches:  1
# assembling the mass matrix time taken:  0.011118650436401367
# solving Ax = b time taken:  0.18268322944641113
# l2 error 0.000973, h1 error 0.037798
# epoch:  141	argmax batch num,  2
# argmax time taken,  0.023626327514648438
# total size: 141 3375000 = 475875000
# num batches:  1
# assembling the mass matrix time taken:  1.1470990180969238
# solving Ax = b time taken:  0.09440183639526367
# l2 error 0.000948, h1 error 0.037175
# epoch:  142	argmax batch num,  2
# argmax time taken,  0.024294614791870117
# total size: 142 3375000 = 479250000
# num batches:  1
# assembling the mass matrix time taken:  0.4016280174255371
# solving Ax = b time taken:  0.10063385963439941
# l2 error 0.000941, h1 error 0.036999
# epoch:  143	argmax batch num,  2
# argmax time taken,  0.02365589141845703
# total size: 143 3375000 = 482625000
# num batches:  1
# assembling the mass matrix time taken:  0.008958101272583008
# solving Ax = b time taken:  0.17566156387329102
# l2 error 0.000928, h1 error 0.036746
# epoch:  144	argmax batch num,  2
# argmax time taken,  0.023864269256591797
# total size: 144 3375000 = 486000000
# num batches:  1
# assembling the mass matrix time taken:  0.9283542633056641
# solving Ax = b time taken:  0.11021232604980469
# l2 error 0.000894, h1 error 0.035674
# epoch:  145	argmax batch num,  2
# argmax time taken,  0.024260282516479492
# total size: 145 3375000 = 489375000
# num batches:  1
# assembling the mass matrix time taken:  0.22733569145202637
# solving Ax = b time taken:  0.09470701217651367
# l2 error 0.000885, h1 error 0.035451
# epoch:  146	argmax batch num,  2
# argmax time taken,  0.02392292022705078
# total size: 146 3375000 = 492750000
# num batches:  1
# assembling the mass matrix time taken:  0.38800597190856934
# solving Ax = b time taken:  0.09645605087280273
# l2 error 0.000866, h1 error 0.034522
# epoch:  147	argmax batch num,  2
# argmax time taken,  0.024934768676757812
# total size: 147 3375000 = 496125000
# num batches:  1
# assembling the mass matrix time taken:  0.43729686737060547
# solving Ax = b time taken:  0.09553194046020508
# l2 error 0.000856, h1 error 0.034378
# epoch:  148	argmax batch num,  2
# argmax time taken,  0.024242401123046875
# total size: 148 3375000 = 499500000
# num batches:  1
# assembling the mass matrix time taken:  0.3475308418273926
# solving Ax = b time taken:  0.09703469276428223
# l2 error 0.000839, h1 error 0.033742
# epoch:  149	argmax batch num,  2
# argmax time taken,  0.02503037452697754
# total size: 149 3375000 = 502875000
# num batches:  1
# assembling the mass matrix time taken:  0.4938089847564697
# solving Ax = b time taken:  0.14487671852111816
# l2 error 0.000826, h1 error 0.033238
# epoch:  150	argmax batch num,  2
# argmax time taken,  0.024524927139282227
# total size: 150 3375000 = 506250000
# num batches:  1
# assembling the mass matrix time taken:  0.012002706527709961
# solving Ax = b time taken:  0.18000483512878418
# l2 error 0.000818, h1 error 0.033111
# epoch:  151	argmax batch num,  2
# argmax time taken,  0.024739980697631836
# total size: 151 3375000 = 509625000
# num batches:  1
# assembling the mass matrix time taken:  1.259814739227295
# solving Ax = b time taken:  0.09878039360046387
# l2 error 0.000802, h1 error 0.032624
# epoch:  152	argmax batch num,  2
# argmax time taken,  0.025540590286254883
# total size: 152 3375000 = 513000000
# num batches:  1
# assembling the mass matrix time taken:  0.0064966678619384766
# solving Ax = b time taken:  0.18754315376281738
# l2 error 0.000794, h1 error 0.032142
# epoch:  153	argmax batch num,  2
# argmax time taken,  0.024730443954467773
# total size: 153 3375000 = 516375000
# num batches:  1
# assembling the mass matrix time taken:  0.8159506320953369
# solving Ax = b time taken:  0.10009884834289551
# l2 error 0.000767, h1 error 0.031472
# epoch:  154	argmax batch num,  2
# argmax time taken,  0.025828838348388672
# total size: 154 3375000 = 519750000
# num batches:  1
# assembling the mass matrix time taken:  0.06348991394042969
# solving Ax = b time taken:  0.1463327407836914
# l2 error 0.000750, h1 error 0.031127
# epoch:  155	argmax batch num,  2
# argmax time taken,  0.025208234786987305
# total size: 155 3375000 = 523125000
# num batches:  1
# assembling the mass matrix time taken:  0.608839750289917
# solving Ax = b time taken:  0.10088086128234863
# l2 error 0.000744, h1 error 0.030903
# epoch:  156	argmax batch num,  2
# argmax time taken,  0.02608799934387207
# total size: 156 3375000 = 526500000
# num batches:  1
# assembling the mass matrix time taken:  0.16785812377929688
# solving Ax = b time taken:  0.14628100395202637
# l2 error 0.000721, h1 error 0.030088
# epoch:  157	argmax batch num,  2
# argmax time taken,  0.025497913360595703
# total size: 157 3375000 = 529875000
# num batches:  1
# assembling the mass matrix time taken:  0.6157903671264648
# solving Ax = b time taken:  0.10193133354187012
# l2 error 0.000712, h1 error 0.029748
# epoch:  158	argmax batch num,  2
# argmax time taken,  0.02660369873046875
# total size: 158 3375000 = 533250000
# num batches:  1
# assembling the mass matrix time taken:  0.1747910976409912
# solving Ax = b time taken:  0.18494963645935059
# l2 error 0.000705, h1 error 0.029607
# epoch:  159	argmax batch num,  2
# argmax time taken,  0.025740623474121094
# total size: 159 3375000 = 536625000
# num batches:  1
# assembling the mass matrix time taken:  0.7178168296813965
# solving Ax = b time taken:  0.10255098342895508
# l2 error 0.000696, h1 error 0.029205
# epoch:  160	argmax batch num,  2
# argmax time taken,  0.02662491798400879
# total size: 160 3375000 = 540000000
# num batches:  2
# assembling the mass matrix time taken:  0.0029544830322265625
# solving Ax = b time taken:  0.19607162475585938
# l2 error 0.000682, h1 error 0.028814
# epoch:  161	argmax batch num,  2
# argmax time taken,  0.025759458541870117
# total size: 161 3375000 = 543375000
# num batches:  2
# assembling the mass matrix time taken:  0.0024547576904296875
# solving Ax = b time taken:  0.19625234603881836
# l2 error 0.000678, h1 error 0.028743
# epoch:  162	argmax batch num,  2
# argmax time taken,  0.02615666389465332
# total size: 162 3375000 = 546750000
# num batches:  2
# assembling the mass matrix time taken:  0.002310037612915039
# solving Ax = b time taken:  0.19863414764404297
# l2 error 0.000674, h1 error 0.028622
# epoch:  163	argmax batch num,  2
# argmax time taken,  0.026414871215820312
# total size: 163 3375000 = 550125000
# num batches:  2
# assembling the mass matrix time taken:  0.0023365020751953125
# solving Ax = b time taken:  0.19845056533813477
# l2 error 0.000667, h1 error 0.028305
# epoch:  164	argmax batch num,  2
# argmax time taken,  0.028272390365600586
# total size: 164 3375000 = 553500000
# num batches:  2
# assembling the mass matrix time taken:  0.005211353302001953
# solving Ax = b time taken:  0.20351076126098633
# l2 error 0.000663, h1 error 0.027909
# epoch:  165	argmax batch num,  2
# argmax time taken,  0.026744842529296875
# total size: 165 3375000 = 556875000
# num batches:  2
# assembling the mass matrix time taken:  0.0024023056030273438
# solving Ax = b time taken:  0.19923973083496094
# l2 error 0.000655, h1 error 0.027718
# epoch:  166	argmax batch num,  2
# argmax time taken,  0.02668166160583496
# total size: 166 3375000 = 560250000
# num batches:  2
# assembling the mass matrix time taken:  0.002366304397583008
# solving Ax = b time taken:  0.20186328887939453
# l2 error 0.000647, h1 error 0.027498
# epoch:  167	argmax batch num,  2
# argmax time taken,  0.027042627334594727
# total size: 167 3375000 = 563625000
# num batches:  2
# assembling the mass matrix time taken:  0.0023572444915771484
# solving Ax = b time taken:  0.20146775245666504
# l2 error 0.000636, h1 error 0.027238
# epoch:  168	argmax batch num,  2
# argmax time taken,  0.24045658111572266
# total size: 168 3375000 = 567000000
# num batches:  2
# assembling the mass matrix time taken:  0.005030155181884766
# solving Ax = b time taken:  0.20659399032592773
# l2 error 0.000632, h1 error 0.027101
# epoch:  169	argmax batch num,  2
# argmax time taken,  0.027712345123291016
# total size: 169 3375000 = 570375000
# num batches:  2
# assembling the mass matrix time taken:  0.0024671554565429688
# solving Ax = b time taken:  0.20307469367980957
# l2 error 0.000626, h1 error 0.026825
# epoch:  170	argmax batch num,  2
# argmax time taken,  0.02715301513671875
# total size: 170 3375000 = 573750000
# num batches:  2
# assembling the mass matrix time taken:  0.0023741722106933594
# solving Ax = b time taken:  0.20451927185058594
# l2 error 0.000620, h1 error 0.026589
# epoch:  171	argmax batch num,  2
# argmax time taken,  0.02742314338684082
# total size: 171 3375000 = 577125000
# num batches:  2
# assembling the mass matrix time taken:  0.0023965835571289062
# solving Ax = b time taken:  0.20489811897277832
# l2 error 0.000610, h1 error 0.026251
# epoch:  172	argmax batch num,  2
# argmax time taken,  0.15024232864379883
# total size: 172 3375000 = 580500000
# num batches:  2
# assembling the mass matrix time taken:  0.004258871078491211
# solving Ax = b time taken:  0.21079802513122559
# l2 error 0.000609, h1 error 0.026082
# epoch:  173	argmax batch num,  2
# argmax time taken,  0.02845144271850586
# total size: 173 3375000 = 583875000
# num batches:  2
# assembling the mass matrix time taken:  0.0025365352630615234
# solving Ax = b time taken:  0.20653104782104492
# l2 error 0.000591, h1 error 0.025471
# epoch:  174	argmax batch num,  2
# argmax time taken,  0.02797842025756836
# total size: 174 3375000 = 587250000
# num batches:  2
# assembling the mass matrix time taken:  0.002500772476196289
# solving Ax = b time taken:  0.2086334228515625
# l2 error 0.000591, h1 error 0.025400
# epoch:  175	argmax batch num,  2
# argmax time taken,  0.02841353416442871
# total size: 175 3375000 = 590625000
# num batches:  2
# assembling the mass matrix time taken:  0.002468585968017578
# solving Ax = b time taken:  0.20786190032958984
# l2 error 0.000579, h1 error 0.025147
# epoch:  176	argmax batch num,  2
# argmax time taken,  0.2722022533416748
# total size: 176 3375000 = 594000000
# num batches:  2
# assembling the mass matrix time taken:  0.004613161087036133
# solving Ax = b time taken:  0.21118712425231934
# l2 error 0.000578, h1 error 0.025065
# epoch:  177	argmax batch num,  2
# argmax time taken,  0.027993202209472656
# total size: 177 3375000 = 597375000
# num batches:  2
# assembling the mass matrix time taken:  0.0024673938751220703
# solving Ax = b time taken:  0.20988965034484863
# l2 error 0.000570, h1 error 0.024821
# epoch:  178	argmax batch num,  2
# ...
# solving Ax = b time taken:  0.7799994945526123
# l2 error 0.000082, h1 error 0.005202
# epoch:  456	argmax batch num,  2
# argmax time taken,  0.09054398536682129
# total size: 456 3375000 = 1539000000
# num batches:  3
# assembling the mass matrix time taken:  0.016632795333862305
# solving Ax = b time taken:  0.7674462795257568
# l2 error 0.000081, h1 error 0.005190
# epoch:  457	argmax batch num,  2
# argmax time taken,  0.08990955352783203
# total size: 457 3375000 = 1542375000
# num batches:  3
# assembling the mass matrix time taken:  0.016347169876098633
# solving Ax = b time taken:  0.7811074256896973
# l2 error 0.000081, h1 error 0.005154
# epoch:  458	argmax batch num,  2
# argmax time taken,  0.0907437801361084
# total size: 458 3375000 = 1545750000
# num batches:  3
# assembling the mass matrix time taken:  0.0164031982421875
# solving Ax = b time taken:  0.8089194297790527
# l2 error 0.000080, h1 error 0.005139
# epoch:  459	argmax batch num,  2
# argmax time taken,  0.09106016159057617
# total size: 459 3375000 = 1549125000
# num batches:  3
# assembling the mass matrix time taken:  0.016320466995239258
# solving Ax = b time taken:  0.7869887351989746
# l2 error 0.000080, h1 error 0.005130
# epoch:  460	argmax batch num,  2
# argmax time taken,  0.09144735336303711
# total size: 460 3375000 = 1552500000
# num batches:  3
# assembling the mass matrix time taken:  0.01651477813720703
# solving Ax = b time taken:  0.7730100154876709
# l2 error 0.000080, h1 error 0.005124
# epoch:  461	argmax batch num,  2
# argmax time taken,  0.09211277961730957
# total size: 461 3375000 = 1555875000
# num batches:  3
# assembling the mass matrix time taken:  0.01637434959411621
# solving Ax = b time taken:  0.7836394309997559
# l2 error 0.000080, h1 error 0.005115
# epoch:  462	argmax batch num,  2
# argmax time taken,  0.0914299488067627
# total size: 462 3375000 = 1559250000
# num batches:  3
# assembling the mass matrix time taken:  0.016581296920776367
# solving Ax = b time taken:  0.8131353855133057
# l2 error 0.000079, h1 error 0.005098
# epoch:  463	argmax batch num,  2
# argmax time taken,  0.06588292121887207
# total size: 463 3375000 = 1562625000
# num batches:  3
# assembling the mass matrix time taken:  0.0033788681030273438
# solving Ax = b time taken:  0.785902738571167
# l2 error 0.000079, h1 error 0.005090
# epoch:  464	argmax batch num,  2
# argmax time taken,  0.09190821647644043
# total size: 464 3375000 = 1566000000
# num batches:  3
# assembling the mass matrix time taken:  0.016548633575439453
# solving Ax = b time taken:  0.7699980735778809
# l2 error 0.000079, h1 error 0.005081
# epoch:  465	argmax batch num,  2
# argmax time taken,  0.09213089942932129
# total size: 465 3375000 = 1569375000
# num batches:  3
# assembling the mass matrix time taken:  0.016541719436645508
# solving Ax = b time taken:  0.7861223220825195
# l2 error 0.000079, h1 error 0.005067
# epoch:  466	argmax batch num,  2
# argmax time taken,  0.08668684959411621
# total size: 466 3375000 = 1572750000
# num batches:  3
# assembling the mass matrix time taken:  0.009862899780273438
# solving Ax = b time taken:  0.8151407241821289
# l2 error 0.000078, h1 error 0.005054
# epoch:  467	argmax batch num,  2
# argmax time taken,  0.06647133827209473
# total size: 467 3375000 = 1576125000
# num batches:  3
# assembling the mass matrix time taken:  0.009864330291748047
# solving Ax = b time taken:  0.790241003036499
# l2 error 0.000078, h1 error 0.005049
# epoch:  468	argmax batch num,  2
# argmax time taken,  0.06655168533325195
# total size: 468 3375000 = 1579500000
# num batches:  3
# assembling the mass matrix time taken:  0.010080099105834961
# solving Ax = b time taken:  0.7813031673431396
# l2 error 0.000078, h1 error 0.005039
# epoch:  469	argmax batch num,  2
# argmax time taken,  0.08672213554382324
# total size: 469 3375000 = 1582875000
# num batches:  3
# assembling the mass matrix time taken:  0.010028362274169922
# solving Ax = b time taken:  0.7932970523834229
# l2 error 0.000077, h1 error 0.004997
# epoch:  470	argmax batch num,  2
# argmax time taken,  0.08635997772216797
# total size: 470 3375000 = 1586250000
# num batches:  3
# assembling the mass matrix time taken:  0.010106086730957031
# solving Ax = b time taken:  0.8199379444122314
# l2 error 0.000077, h1 error 0.004991
# epoch:  471	argmax batch num,  2
# argmax time taken,  0.08659791946411133
# total size: 471 3375000 = 1589625000
# num batches:  3
# assembling the mass matrix time taken:  0.010040760040283203
# solving Ax = b time taken:  0.7958817481994629
# l2 error 0.000077, h1 error 0.004983
# epoch:  472	argmax batch num,  2
# argmax time taken,  0.08675837516784668
# total size: 472 3375000 = 1593000000
# num batches:  3
# assembling the mass matrix time taken:  0.010339975357055664
# solving Ax = b time taken:  0.7832052707672119
# l2 error 0.000077, h1 error 0.004969
# epoch:  473	argmax batch num,  2
# argmax time taken,  0.0870809555053711
# total size: 473 3375000 = 1596375000
# num batches:  3
# assembling the mass matrix time taken:  0.010183334350585938
# solving Ax = b time taken:  0.7972760200500488
# l2 error 0.000077, h1 error 0.004963
# epoch:  474	argmax batch num,  2
# argmax time taken,  0.0849001407623291
# total size: 474 3375000 = 1599750000
# num batches:  3
# assembling the mass matrix time taken:  0.010532617568969727
# solving Ax = b time taken:  0.8079872131347656
# l2 error 0.000077, h1 error 0.004954
# epoch:  475	argmax batch num,  2
# argmax time taken,  0.0873725414276123
# total size: 475 3375000 = 1603125000
# num batches:  3
# assembling the mass matrix time taken:  0.010251522064208984
# solving Ax = b time taken:  0.7987923622131348
# l2 error 0.000076, h1 error 0.004951
# epoch:  476	argmax batch num,  2
# argmax time taken,  0.08765697479248047
# total size: 476 3375000 = 1606500000
# num batches:  3
# assembling the mass matrix time taken:  0.010263204574584961
# solving Ax = b time taken:  0.7977392673492432
# l2 error 0.000076, h1 error 0.004943
# epoch:  477	argmax batch num,  2
# argmax time taken,  0.08774518966674805
# total size: 477 3375000 = 1609875000
# num batches:  3
# assembling the mass matrix time taken:  0.010078191757202148
# solving Ax = b time taken:  0.7991647720336914
# l2 error 0.000076, h1 error 0.004930
# epoch:  478	argmax batch num,  2
# argmax time taken,  0.08750033378601074
# total size: 478 3375000 = 1613250000
# num batches:  4
# assembling the mass matrix time taken:  0.011078119277954102
# solving Ax = b time taken:  0.8058373928070068
# l2 error 0.000075, h1 error 0.004906
# epoch:  479	argmax batch num,  2
# argmax time taken,  0.08762788772583008
# total size: 479 3375000 = 1616625000
# num batches:  4
# assembling the mass matrix time taken:  0.010978937149047852
# solving Ax = b time taken:  0.7969028949737549
# l2 error 0.000075, h1 error 0.004859
# epoch:  480	argmax batch num,  2
# argmax time taken,  0.08732867240905762
# total size: 480 3375000 = 1620000000
# num batches:  4
# assembling the mass matrix time taken:  0.011039018630981445
# solving Ax = b time taken:  0.8046963214874268
# l2 error 0.000075, h1 error 0.004852
# epoch:  481	argmax batch num,  2
# argmax time taken,  0.08764863014221191
# total size: 481 3375000 = 1623375000
# num batches:  4
# assembling the mass matrix time taken:  0.013260126113891602
# solving Ax = b time taken:  0.8000204563140869
# l2 error 0.000074, h1 error 0.004828
# epoch:  482	argmax batch num,  2
# argmax time taken,  0.11358642578125
# total size: 482 3375000 = 1626750000
# num batches:  4
# assembling the mass matrix time taken:  0.017361879348754883
# solving Ax = b time taken:  0.7984495162963867
# l2 error 0.000074, h1 error 0.004806
# epoch:  483	argmax batch num,  2
# argmax time taken,  0.09107422828674316
# total size: 483 3375000 = 1630125000
# num batches:  4
# assembling the mass matrix time taken:  0.004332780838012695
# solving Ax = b time taken:  0.8006908893585205
# l2 error 0.000073, h1 error 0.004790
# epoch:  484	argmax batch num,  2
# argmax time taken,  0.06862092018127441
# total size: 484 3375000 = 1633500000
# num batches:  4
# assembling the mass matrix time taken:  0.004257678985595703
# solving Ax = b time taken:  0.8045716285705566
# l2 error 0.000073, h1 error 0.004778
# epoch:  485	argmax batch num,  2
# argmax time taken,  0.06931710243225098
# total size: 485 3375000 = 1636875000
# num batches:  4
# assembling the mass matrix time taken:  0.004447221755981445
# solving Ax = b time taken:  0.8035767078399658
# l2 error 0.000072, h1 error 0.004746
# epoch:  486	argmax batch num,  2
# argmax time taken,  0.06870627403259277
# total size: 486 3375000 = 1640250000
# num batches:  4
# assembling the mass matrix time taken:  0.004319429397583008
# solving Ax = b time taken:  0.8025097846984863
# l2 error 0.000072, h1 error 0.004733
# epoch:  487	argmax batch num,  2
# argmax time taken,  0.06884074211120605
# total size: 487 3375000 = 1643625000
# num batches:  4
# assembling the mass matrix time taken:  0.0043256282806396484
# solving Ax = b time taken:  0.8032057285308838
# l2 error 0.000072, h1 error 0.004721
# epoch:  488	argmax batch num,  2
# argmax time taken,  0.06890511512756348
# total size: 488 3375000 = 1647000000
# num batches:  4
# assembling the mass matrix time taken:  0.004317522048950195
# solving Ax = b time taken:  0.8042593002319336
# l2 error 0.000072, h1 error 0.004711
# epoch:  489	argmax batch num,  2
# argmax time taken,  0.06938385963439941
# total size: 489 3375000 = 1650375000
# num batches:  4
# assembling the mass matrix time taken:  0.004324197769165039
# solving Ax = b time taken:  0.8077080249786377
# l2 error 0.000071, h1 error 0.004644
# epoch:  490	argmax batch num,  2
# argmax time taken,  0.06918120384216309
# total size: 490 3375000 = 1653750000
# num batches:  4
# assembling the mass matrix time taken:  0.004352092742919922
# solving Ax = b time taken:  0.806098222732544
# l2 error 0.000071, h1 error 0.004637
# epoch:  491	argmax batch num,  2
# argmax time taken,  0.06935572624206543
# total size: 491 3375000 = 1657125000
# num batches:  4
# assembling the mass matrix time taken:  0.004335880279541016
# solving Ax = b time taken:  0.8098258972167969
# l2 error 0.000070, h1 error 0.004627
# epoch:  492	argmax batch num,  2
# argmax time taken,  0.06948280334472656
# total size: 492 3375000 = 1660500000
# num batches:  4
# assembling the mass matrix time taken:  0.01726555824279785
# solving Ax = b time taken:  0.8107399940490723
# l2 error 0.000070, h1 error 0.004620
# epoch:  493	argmax batch num,  2
# argmax time taken,  0.09580349922180176
# total size: 493 3375000 = 1663875000
# num batches:  4
# assembling the mass matrix time taken:  0.017130613327026367
# solving Ax = b time taken:  0.8089027404785156
# l2 error 0.000070, h1 error 0.004603
# epoch:  494	argmax batch num,  2
# argmax time taken,  0.07868003845214844
# total size: 494 3375000 = 1667250000
# num batches:  4
# assembling the mass matrix time taken:  0.01718282699584961
# solving Ax = b time taken:  0.8088502883911133
# l2 error 0.000070, h1 error 0.004580
# epoch:  495	argmax batch num,  2
# argmax time taken,  0.09552979469299316
# total size: 495 3375000 = 1670625000
# num batches:  4
# assembling the mass matrix time taken:  0.01067352294921875
# solving Ax = b time taken:  0.8129539489746094
# l2 error 0.000069, h1 error 0.004557
# epoch:  496	argmax batch num,  2
# argmax time taken,  0.06991267204284668
# total size: 496 3375000 = 1674000000
# num batches:  4
# assembling the mass matrix time taken:  0.010596513748168945
# solving Ax = b time taken:  0.8113229274749756
# l2 error 0.000069, h1 error 0.004553
# epoch:  497	argmax batch num,  2
# argmax time taken,  0.07016944885253906
# total size: 497 3375000 = 1677375000
# num batches:  4
# assembling the mass matrix time taken:  0.0042688846588134766
# solving Ax = b time taken:  0.8134326934814453
# l2 error 0.000069, h1 error 0.004543
# epoch:  498	argmax batch num,  2
# argmax time taken,  0.07018399238586426
# total size: 498 3375000 = 1680750000
# num batches:  4
# assembling the mass matrix time taken:  0.010761022567749023
# solving Ax = b time taken:  0.8119533061981201
# l2 error 0.000069, h1 error 0.004535
# epoch:  499	argmax batch num,  2
# argmax time taken,  0.07021474838256836
# total size: 499 3375000 = 1684125000
# num batches:  4
# assembling the mass matrix time taken:  0.010906696319580078
# solving Ax = b time taken:  0.8170149326324463
# l2 error 0.000069, h1 error 0.004527
# epoch:  500	argmax batch num,  2
# argmax time taken,  0.07053780555725098
# total size: 500 3375000 = 1687500000
# num batches:  4
# assembling the mass matrix time taken:  0.010787487030029297
# solving Ax = b time taken:  0.8187391757965088
# l2 error 0.000068, h1 error 0.004518
# epoch:  501	argmax batch num,  2
# argmax time taken,  0.0774836540222168
# total size: 501 3375000 = 1690875000
# num batches:  4
# assembling the mass matrix time taken:  0.010983705520629883
# solving Ax = b time taken:  0.8175842761993408
# l2 error 0.000068, h1 error 0.004509
# epoch:  502	argmax batch num,  2
# argmax time taken,  0.07056856155395508
# total size: 502 3375000 = 1694250000
# num batches:  4
# assembling the mass matrix time taken:  0.010732650756835938
# solving Ax = b time taken:  0.8163273334503174
# l2 error 0.000068, h1 error 0.004449
# epoch:  503	argmax batch num,  2
# argmax time taken,  0.07108616828918457
# total size: 503 3375000 = 1697625000
# num batches:  4
# assembling the mass matrix time taken:  0.011047124862670898
# solving Ax = b time taken:  0.818932056427002
# l2 error 0.000068, h1 error 0.004447
# epoch:  504	argmax batch num,  2
# argmax time taken,  0.07082700729370117
# total size: 504 3375000 = 1701000000
# num batches:  4
# assembling the mass matrix time taken:  0.010996341705322266
# solving Ax = b time taken:  0.8216567039489746
# l2 error 0.000067, h1 error 0.004426
# epoch:  505	argmax batch num,  2
# argmax time taken,  0.07143735885620117
# total size: 505 3375000 = 1704375000
# num batches:  4
# assembling the mass matrix time taken:  0.010943889617919922
# solving Ax = b time taken:  0.8305826187133789
# l2 error 0.000067, h1 error 0.004420
# epoch:  506	argmax batch num,  2
# argmax time taken,  0.07116866111755371
# total size: 506 3375000 = 1707750000
# num batches:  4
# assembling the mass matrix time taken:  0.016466140747070312
# solving Ax = b time taken:  0.8294754028320312
# l2 error 0.000067, h1 error 0.004412
# epoch:  507	argmax batch num,  2
# argmax time taken,  0.0971992015838623
# total size: 507 3375000 = 1711125000
# num batches:  4
# assembling the mass matrix time taken:  0.01719379425048828
# solving Ax = b time taken:  0.8319964408874512
# l2 error 0.000067, h1 error 0.004396
# epoch:  508	argmax batch num,  2
# argmax time taken,  0.0944511890411377
# total size: 508 3375000 = 1714500000
# num batches:  4
# assembling the mass matrix time taken:  0.01723337173461914
# solving Ax = b time taken:  0.832970380783081
# l2 error 0.000067, h1 error 0.004389
# epoch:  509	argmax batch num,  2
# argmax time taken,  0.09803891181945801
# total size: 509 3375000 = 1717875000
# num batches:  4
# assembling the mass matrix time taken:  0.004448413848876953
# solving Ax = b time taken:  0.8335344791412354
# l2 error 0.000066, h1 error 0.004375
# epoch:  510	argmax batch num,  2
# argmax time taken,  0.0722205638885498
# total size: 510 3375000 = 1721250000
# num batches:  4
# assembling the mass matrix time taken:  0.004310131072998047
# solving Ax = b time taken:  0.8334434032440186
# l2 error 0.000065, h1 error 0.004331
# epoch:  511	argmax batch num,  2
# argmax time taken,  0.07713127136230469
# total size: 511 3375000 = 1724625000
# num batches:  4
# assembling the mass matrix time taken:  0.010831356048583984
# solving Ax = b time taken:  0.8359940052032471
# l2 error 0.000065, h1 error 0.004319
# epoch:  512	argmax batch num,  2
# argmax time taken,  0.07249116897583008
# total size: 512 3375000 = 1728000000
# num batches:  4
# assembling the mass matrix time taken:  0.004283905029296875
# solving Ax = b time taken:  0.8307063579559326
# l2 error 0.000065, h1 error 0.004318
# time taken:  3.1024208068847656
# neuron num 		 error 		 order
# 4 		 0.355877 		 * 		 3.322601 		 *
#
# 8 		 0.332912 		 0.096240 		 3.179593 		 0.063471
#
# 16 		 0.095527 		 1.801162 		 1.544408 		 1.041788
#
# 32 		 0.033077 		 1.530097 		 0.670404 		 1.203951
#
# 64 		 0.004861 		 2.766485 		 0.131810 		 2.346571
#
# 128 		 0.001110 		 2.131217 		 0.042079 		 1.647304
#
# 256 		 0.000265 		 2.065511 		 0.013437 		 1.646892
#
# 512 		 0.000065 		 2.028127 		 0.004318 		 1.637881

# %%
4 		 0.355877 		 * 		 3.322601 		 * 

8 		 0.332912 		 0.096240 		 3.179593 		 0.063471 

16 		 0.095527 		 1.801162 		 1.544408 		 1.041788 

32 		 0.033077 		 1.530097 		 0.670404 		 1.203951 

64 		 0.004861 		 2.766485 		 0.131810 		 2.346571 

128 		 0.001110 		 2.131217 		 0.042079 		 1.647304 

256 		 0.000265 		 2.065511 		 0.013437 		 1.646892 

512 		 0.000065 		 2.028127 		 0.004318 		 1.637881

# %% [markdown]
# ## gaussian example

# %%
def u_exact(x):
    d = 3 
    cn =   7.03/d 
    return torch.exp(-torch.sum( cn**2 * (x - 0.5)**2,dim = 1, keepdim = True))  

def u_exact_grad():
    d = 3 
    def make_grad_i(i):
        def grad_i(x):
            d = 3  
            cn = 7.03/d
            return torch.exp(-torch.sum(cn**2 * (x - 0.5)**2, dim=1, keepdim=True)) * (-2 * cn**2 * (x[:, i:i+1] - 0.5))
        return grad_i 
    
    u_grad=[] 
    for i in range(d):
        u_grad.append(make_grad_i(i))
    return u_grad
                                                                
                                                                    
def alpha(x): 
    return torch.ones(x.size(0),1).to(device)
    # return 0.5 * torch.sin(6 * pi*x[:,0:1]) + 1. 

# def target(x):
# #     z = (  4 * (pi)**2 + 1)*torch.cos( pi*x[:,0:1])*torch.cos( pi*x[:,1:2] ) * torch.cos(pi*x[:,2:3]) * torch.cos( pi*x[:,3:4]) 
# #     return z 
#     z_c = torch.cos( pi*x[:,0:1])*torch.cos( pi*x[:,1:2] ) * torch.cos(pi*x[:,2:3]) * torch.cos( pi*x[:,3:4]) 
#     z1 = 3 * pi**2 * torch.sin(pi * x[:,0:1]) * torch.cos( 6*pi*x[:,1:2] ) * torch.cos(pi*x[:,2:3]) * torch.cos( pi*x[:,3:4]) 
#     z2 = 0.5 * pi**2 * torch.sin(6*pi * x[:,0:1])* z_c 
#     z = z1 + z2 + 3/2*pi**2 * torch.sin(6 * pi * x[:,0:1]) * z_c 
#     z += ( 4 * (pi)**2 + 1)*z_c 
#     return z 

def target(x):
    d = 3 
    cn =   7.03/d 
    z = torch.exp(-torch.sum( cn**2 * (x - 0.5)**2,dim = 1, keepdim = True)) 
    return z* ( -torch.sum(  (2 *cn**2 * (x - 0.5))**2 - 2*cn**2 ,dim = 1, keepdim = True) +1)

def g_N(dim):
    def make_g(i):
        def g_i(x):
            d = 3 
            cn = 7.03 / d
            return torch.exp(-torch.sum(cn**2 * (x - 0.5)**2, dim=1, keepdim=True)) * (-2 * cn**2 * (x[:, i:i+1] - 0.5))
        return g_i

    bcs_N = []
    for i in range(dim):
        bcs_N.append((i, make_g(i)))
    
    return bcs_N


function_name = "cospix" 
filename_write = "data-neumann/3DOGA-{}-order.txt".format(function_name)
f_write = open(filename_write, "a")
f_write.write("\n")
f_write.close() 
save = False 
for N_list in [[2**2,2**3,2**3]]: # ,[2**6,2**6],[2**7,2**7] 
    # save = True 
    f_write = open(filename_write, "a")
    my_model = None 
    # Nx = 50   
    # order = 3   
    M = 300000  
    exponent = 8
    num_epochs = 2**exponent  
    plot_freq = num_epochs 
    N = np.prod(N_list)
    err_QMC2, err_h10, my_model = OGANeumannReLU3D(my_model,alpha, target,g_N, u_exact,u_exact_grad, N_list,num_epochs,plot_freq, M, k =2, rand_deter= 'rand', linear_solver = "direct")
    
    if save: 
        folder = 'data-neumann/'
        filename = folder + 'err_OGA_4D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        torch.save(err_QMC2,filename) 
        folder = 'data-neumann/'
        filename = folder + 'model_OGA_4D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        torch.save(my_model,filename)

    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_QMC2[i] for i in neuron_nums ]
    err_list2 = [err_h10[i] for i in neuron_nums ] 
    f_write.write('deterministic dictionary size: {}\n'.format(N))
    f_write.write("neuron num \t\t error \t\t order \t\t h10 error \\ order \n")
    print("neuron num \t\t error \t\t order")
    for i, item in enumerate(err_list):
        if i == 0: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t")
            
            # print("*")
            print("{} \t\t {:.6f} \t\t * \t\t {:.6f} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ) )   
            f_write.write("{} \t\t {} \t\t * \t\t {} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ))
        else: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t") 
            # print(np.log(err_list[i-1]/err_list[i])/np.log(2))
            print("{} \t\t {:.6f} \t\t {:.6f} \t\t {:.6f} \t\t {:.6f} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ) )
            f_write.write("{} \t\t {} \t\t {} \t\t {} \t\t {} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ))
    f_write.write("\n")
    f_write.close()
# Out:
# using linear solver:  direct
# epoch:  1	assembling the mass matrix time taken:  0.004244804382324219
# solving Ax = b time taken:  0.1321420669555664
# l2 error 0.274375, h1 error 2.522434
# epoch:  2	assembling the mass matrix time taken:  0.005568742752075195
# solving Ax = b time taken:  0.004712104797363281
# l2 error 0.213882, h1 error 2.411771
# epoch:  3	assembling the mass matrix time taken:  0.0041046142578125
# solving Ax = b time taken:  0.005236625671386719
# l2 error 0.204598, h1 error 2.114279
# epoch:  4	assembling the mass matrix time taken:  0.0047397613525390625
# solving Ax = b time taken:  0.005539417266845703
# l2 error 0.187524, h1 error 2.010464
# epoch:  5	assembling the mass matrix time taken:  0.004512786865234375
# solving Ax = b time taken:  0.005780696868896484
# l2 error 0.201255, h1 error 1.951563
# epoch:  6	assembling the mass matrix time taken:  0.0047681331634521484
# solving Ax = b time taken:  0.00668644905090332
# l2 error 0.167274, h1 error 1.863414
# epoch:  7	assembling the mass matrix time taken:  0.0040950775146484375
# solving Ax = b time taken:  0.007455587387084961
# l2 error 0.122039, h1 error 1.568123
# epoch:  8	assembling the mass matrix time taken:  0.005191326141357422
# solving Ax = b time taken:  0.007800579071044922
# l2 error 0.095435, h1 error 1.434597
# epoch:  9	assembling the mass matrix time taken:  0.004552364349365234
# solving Ax = b time taken:  0.008511781692504883
# l2 error 0.086551, h1 error 1.394909
# epoch:  10	assembling the mass matrix time taken:  0.016914844512939453
# solving Ax = b time taken:  0.009311676025390625
# l2 error 0.086279, h1 error 1.393708
# epoch:  11	assembling the mass matrix time taken:  0.004362344741821289
# solving Ax = b time taken:  0.009978771209716797
# l2 error 0.085404, h1 error 1.369874
# epoch:  12	assembling the mass matrix time taken:  0.004769563674926758
# solving Ax = b time taken:  0.010133981704711914
# l2 error 0.083436, h1 error 1.327301
# epoch:  13	assembling the mass matrix time taken:  0.00433659553527832
# solving Ax = b time taken:  0.011221647262573242
# l2 error 0.082394, h1 error 1.298430
# epoch:  14	assembling the mass matrix time taken:  0.004408359527587891
# solving Ax = b time taken:  0.011671304702758789
# l2 error 0.080292, h1 error 1.261603
# epoch:  15	assembling the mass matrix time taken:  0.00426173210144043
# solving Ax = b time taken:  0.012375593185424805
# l2 error 0.075560, h1 error 1.186964
# epoch:  16	assembling the mass matrix time taken:  0.004111051559448242
# solving Ax = b time taken:  0.013092756271362305
# l2 error 0.069121, h1 error 1.094796
# epoch:  17	assembling the mass matrix time taken:  0.004168987274169922
# solving Ax = b time taken:  0.013869524002075195
# l2 error 0.063906, h1 error 1.017382
# epoch:  18	assembling the mass matrix time taken:  0.004058837890625
# solving Ax = b time taken:  0.01436305046081543
# l2 error 0.058086, h1 error 0.921053
# epoch:  19	assembling the mass matrix time taken:  0.004118204116821289
# solving Ax = b time taken:  0.015161991119384766
# l2 error 0.055571, h1 error 0.898980
# epoch:  20	assembling the mass matrix time taken:  0.0043179988861083984
# solving Ax = b time taken:  0.01571488380432129
# l2 error 0.050052, h1 error 0.829349
# epoch:  21	assembling the mass matrix time taken:  0.004294872283935547
# solving Ax = b time taken:  0.016371488571166992
# l2 error 0.046632, h1 error 0.784787
# epoch:  22	assembling the mass matrix time taken:  0.004267692565917969
# solving Ax = b time taken:  0.01685166358947754
# l2 error 0.041751, h1 error 0.711891
# epoch:  23	assembling the mass matrix time taken:  0.004311561584472656
# solving Ax = b time taken:  0.01753830909729004
# l2 error 0.038645, h1 error 0.669272
# epoch:  24	assembling the mass matrix time taken:  0.0043795108795166016
# solving Ax = b time taken:  0.018171310424804688
# l2 error 0.036008, h1 error 0.642972
# epoch:  25	assembling the mass matrix time taken:  0.004426479339599609
# solving Ax = b time taken:  0.01877903938293457
# l2 error 0.033956, h1 error 0.613179
# epoch:  26	assembling the mass matrix time taken:  0.004105806350708008
# solving Ax = b time taken:  0.019487619400024414
# l2 error 0.030201, h1 error 0.565958
# epoch:  27	assembling the mass matrix time taken:  0.004367828369140625
# solving Ax = b time taken:  0.020099401473999023
# l2 error 0.027739, h1 error 0.537239
# epoch:  28	assembling the mass matrix time taken:  0.004080772399902344
# solving Ax = b time taken:  0.020926237106323242
# l2 error 0.025800, h1 error 0.514304
# epoch:  29	assembling the mass matrix time taken:  0.004156589508056641
# solving Ax = b time taken:  0.021493196487426758
# l2 error 0.024546, h1 error 0.493252
# epoch:  30	assembling the mass matrix time taken:  0.00431060791015625
# solving Ax = b time taken:  0.02199101448059082
# l2 error 0.023222, h1 error 0.464002
# epoch:  31	assembling the mass matrix time taken:  0.004408121109008789
# solving Ax = b time taken:  0.02283000946044922
# l2 error 0.021949, h1 error 0.448871
# epoch:  32	assembling the mass matrix time taken:  0.004845380783081055
# solving Ax = b time taken:  0.022348880767822266
# l2 error 0.019694, h1 error 0.413667
# epoch:  33	assembling the mass matrix time taken:  0.004897356033325195
# solving Ax = b time taken:  0.02563190460205078
# l2 error 0.018237, h1 error 0.392894
# epoch:  34	assembling the mass matrix time taken:  0.004412174224853516
# solving Ax = b time taken:  0.026401996612548828
# l2 error 0.016814, h1 error 0.374403
# epoch:  35	assembling the mass matrix time taken:  0.01648116111755371
# solving Ax = b time taken:  0.02751016616821289
# l2 error 0.016448, h1 error 0.368667
# epoch:  36	assembling the mass matrix time taken:  0.004812002182006836
# solving Ax = b time taken:  0.027471303939819336
# l2 error 0.015252, h1 error 0.352667
# epoch:  37	assembling the mass matrix time taken:  0.01675701141357422
# solving Ax = b time taken:  0.02853679656982422
# l2 error 0.014727, h1 error 0.344178
# epoch:  38	assembling the mass matrix time taken:  0.016878366470336914
# solving Ax = b time taken:  0.029350757598876953
# l2 error 0.013272, h1 error 0.325543
# epoch:  39	assembling the mass matrix time taken:  0.01683640480041504
# solving Ax = b time taken:  0.030029296875
# l2 error 0.012759, h1 error 0.315377
# epoch:  40	assembling the mass matrix time taken:  0.016600847244262695
# solving Ax = b time taken:  0.02978968620300293
# l2 error 0.012403, h1 error 0.306606
# epoch:  41	assembling the mass matrix time taken:  0.017162799835205078
# solving Ax = b time taken:  0.030933380126953125
# l2 error 0.012299, h1 error 0.301293
# epoch:  42	assembling the mass matrix time taken:  0.016858577728271484
# solving Ax = b time taken:  0.03187680244445801
# l2 error 0.012105, h1 error 0.296701
# epoch:  43	assembling the mass matrix time taken:  0.004113435745239258
# solving Ax = b time taken:  0.032515525817871094
# l2 error 0.011859, h1 error 0.291703
# epoch:  44	assembling the mass matrix time taken:  0.01615285873413086
# solving Ax = b time taken:  0.03246140480041504
# l2 error 0.011107, h1 error 0.282680
# epoch:  45	assembling the mass matrix time taken:  0.0042798519134521484
# solving Ax = b time taken:  0.03417038917541504
# l2 error 0.010820, h1 error 0.276396
# epoch:  46	assembling the mass matrix time taken:  0.004530668258666992
# solving Ax = b time taken:  0.03421902656555176
# l2 error 0.010570, h1 error 0.271585
# epoch:  47	assembling the mass matrix time taken:  0.017194271087646484
# solving Ax = b time taken:  0.03807520866394043
# l2 error 0.010262, h1 error 0.265470
# epoch:  48	assembling the mass matrix time taken:  0.01742410659790039
# solving Ax = b time taken:  0.03818345069885254
# l2 error 0.010000, h1 error 0.259308
# epoch:  49	assembling the mass matrix time taken:  0.004560947418212891
# solving Ax = b time taken:  0.03961467742919922
# l2 error 0.009755, h1 error 0.253879
# epoch:  50	assembling the mass matrix time taken:  0.016566991806030273
# solving Ax = b time taken:  0.04033803939819336
# l2 error 0.009461, h1 error 0.246943
# epoch:  51	assembling the mass matrix time taken:  0.01632857322692871
# solving Ax = b time taken:  0.041048288345336914
# l2 error 0.009410, h1 error 0.243598
# epoch:  52	assembling the mass matrix time taken:  0.01699972152709961
# solving Ax = b time taken:  0.041127681732177734
# l2 error 0.009155, h1 error 0.238404
# epoch:  53	assembling the mass matrix time taken:  0.017168521881103516
# solving Ax = b time taken:  0.04207324981689453
# l2 error 0.009000, h1 error 0.234303
# epoch:  54	assembling the mass matrix time taken:  0.004387378692626953
# solving Ax = b time taken:  0.042840003967285156
# l2 error 0.008760, h1 error 0.229233
# epoch:  55	assembling the mass matrix time taken:  0.017067670822143555
# solving Ax = b time taken:  0.04342222213745117
# l2 error 0.008520, h1 error 0.223530
# epoch:  56	assembling the mass matrix time taken:  0.0171816349029541
# solving Ax = b time taken:  0.043412208557128906
# l2 error 0.008266, h1 error 0.218048
# epoch:  57	assembling the mass matrix time taken:  0.016373395919799805
# solving Ax = b time taken:  0.04475760459899902
# l2 error 0.007885, h1 error 0.212589
# epoch:  58	assembling the mass matrix time taken:  0.01629638671875
# solving Ax = b time taken:  0.04501008987426758
# l2 error 0.007483, h1 error 0.207104
# epoch:  59	assembling the mass matrix time taken:  0.0166471004486084
# solving Ax = b time taken:  0.04608273506164551
# l2 error 0.007253, h1 error 0.202618
# epoch:  60	assembling the mass matrix time taken:  0.0043752193450927734
# solving Ax = b time taken:  0.04609227180480957
# l2 error 0.006911, h1 error 0.195746
# epoch:  61	assembling the mass matrix time taken:  0.01726078987121582
# solving Ax = b time taken:  0.04725337028503418
# l2 error 0.006782, h1 error 0.191585
# epoch:  62	assembling the mass matrix time taken:  0.0045435428619384766
# solving Ax = b time taken:  0.04790925979614258
# l2 error 0.006656, h1 error 0.188485
# epoch:  63	assembling the mass matrix time taken:  0.0045244693756103516
# solving Ax = b time taken:  0.04853248596191406
# l2 error 0.006391, h1 error 0.184035
# epoch:  64	assembling the mass matrix time taken:  0.0041675567626953125
# solving Ax = b time taken:  0.048595428466796875
# l2 error 0.006184, h1 error 0.182143
# epoch:  65	assembling the mass matrix time taken:  0.0075092315673828125
# solving Ax = b time taken:  0.05735898017883301
# l2 error 0.005952, h1 error 0.178383
# epoch:  66	assembling the mass matrix time taken:  0.01650381088256836
# solving Ax = b time taken:  0.058272600173950195
# l2 error 0.005800, h1 error 0.175671
# epoch:  67	assembling the mass matrix time taken:  0.01696324348449707
# solving Ax = b time taken:  0.059110164642333984
# l2 error 0.005694, h1 error 0.173052
# epoch:  68	assembling the mass matrix time taken:  0.016536951065063477
# solving Ax = b time taken:  0.0589141845703125
# l2 error 0.005431, h1 error 0.168825
# epoch:  69	assembling the mass matrix time taken:  0.016527652740478516
# solving Ax = b time taken:  0.060407161712646484
# l2 error 0.005301, h1 error 0.166189
# epoch:  70	assembling the mass matrix time taken:  0.005529642105102539
# solving Ax = b time taken:  0.06100034713745117
# l2 error 0.005283, h1 error 0.164963
# epoch:  71	assembling the mass matrix time taken:  0.005373239517211914
# solving Ax = b time taken:  0.061753034591674805
# l2 error 0.005226, h1 error 0.162653
# epoch:  72	assembling the mass matrix time taken:  0.0045506954193115234
# solving Ax = b time taken:  0.06113409996032715
# l2 error 0.005012, h1 error 0.158990
# epoch:  73	assembling the mass matrix time taken:  0.017017841339111328
# solving Ax = b time taken:  0.06319928169250488
# l2 error 0.004977, h1 error 0.156964
# epoch:  74	assembling the mass matrix time taken:  0.004278421401977539
# solving Ax = b time taken:  0.06356430053710938
# l2 error 0.004966, h1 error 0.155439
# epoch:  75	assembling the mass matrix time taken:  0.016831159591674805
# solving Ax = b time taken:  0.06435561180114746
# l2 error 0.004801, h1 error 0.152065
# epoch:  76	assembling the mass matrix time taken:  0.016953706741333008
# solving Ax = b time taken:  0.06392431259155273
# l2 error 0.004743, h1 error 0.150979
# epoch:  77	assembling the mass matrix time taken:  0.004316806793212891
# solving Ax = b time taken:  0.06567502021789551
# l2 error 0.004679, h1 error 0.149148
# epoch:  78	assembling the mass matrix time taken:  0.004317760467529297
# solving Ax = b time taken:  0.06609058380126953
# l2 error 0.004617, h1 error 0.146939
# epoch:  79	assembling the mass matrix time taken:  0.004364490509033203
# solving Ax = b time taken:  0.06698298454284668
# l2 error 0.004606, h1 error 0.145461
# epoch:  80	assembling the mass matrix time taken:  0.004438638687133789
# solving Ax = b time taken:  0.06621742248535156
# l2 error 0.004419, h1 error 0.142944
# epoch:  81	assembling the mass matrix time taken:  0.004169940948486328
# solving Ax = b time taken:  0.0696108341217041
# l2 error 0.004395, h1 error 0.141632
# epoch:  82	assembling the mass matrix time taken:  0.004241228103637695
# solving Ax = b time taken:  0.06988835334777832
# l2 error 0.004341, h1 error 0.140281
# epoch:  83	assembling the mass matrix time taken:  0.016808509826660156
# solving Ax = b time taken:  0.07086730003356934
# l2 error 0.004280, h1 error 0.138719
# epoch:  84	assembling the mass matrix time taken:  0.004330158233642578
# solving Ax = b time taken:  0.07014870643615723
# l2 error 0.004232, h1 error 0.137665
# epoch:  85	assembling the mass matrix time taken:  0.004348039627075195
# solving Ax = b time taken:  0.07203006744384766
# l2 error 0.004154, h1 error 0.135921
# epoch:  86	assembling the mass matrix time taken:  0.004454374313354492
# solving Ax = b time taken:  0.07210564613342285
# l2 error 0.004003, h1 error 0.132810
# epoch:  87	assembling the mass matrix time taken:  0.0041697025299072266
# solving Ax = b time taken:  0.07332563400268555
# l2 error 0.003970, h1 error 0.131694
# epoch:  88	assembling the mass matrix time taken:  0.004155874252319336
# solving Ax = b time taken:  0.07248234748840332
# l2 error 0.003912, h1 error 0.130918
# epoch:  89	assembling the mass matrix time taken:  0.004341840744018555
# solving Ax = b time taken:  0.07445669174194336
# l2 error 0.003851, h1 error 0.129877
# epoch:  90	assembling the mass matrix time taken:  0.004358768463134766
# solving Ax = b time taken:  0.07496929168701172
# l2 error 0.003801, h1 error 0.128799
# epoch:  91	assembling the mass matrix time taken:  0.004322528839111328
# solving Ax = b time taken:  0.07576131820678711
# l2 error 0.003703, h1 error 0.127002
# epoch:  92	assembling the mass matrix time taken:  0.0041656494140625
# solving Ax = b time taken:  0.07509207725524902
# l2 error 0.003679, h1 error 0.126266
# epoch:  93	assembling the mass matrix time taken:  0.004149198532104492
# solving Ax = b time taken:  0.07712435722351074
# l2 error 0.003632, h1 error 0.125267
# epoch:  94	assembling the mass matrix time taken:  0.004452228546142578
# solving Ax = b time taken:  0.0773630142211914
# l2 error 0.003562, h1 error 0.123897
# epoch:  95	assembling the mass matrix time taken:  0.004340648651123047
# solving Ax = b time taken:  0.07825732231140137
# l2 error 0.003491, h1 error 0.121960
# epoch:  96	assembling the mass matrix time taken:  0.004940032958984375
# solving Ax = b time taken:  0.07691478729248047
# l2 error 0.003455, h1 error 0.120927
# epoch:  97	assembling the mass matrix time taken:  0.005098104476928711
# solving Ax = b time taken:  0.07759928703308105
# l2 error 0.003356, h1 error 0.118805
# epoch:  98	assembling the mass matrix time taken:  0.004673004150390625
# solving Ax = b time taken:  0.07866072654724121
# l2 error 0.003328, h1 error 0.117112
# epoch:  99	assembling the mass matrix time taken:  0.00462031364440918
# solving Ax = b time taken:  0.07929873466491699
# l2 error 0.003285, h1 error 0.115808
# epoch:  100	assembling the mass matrix time taken:  0.0048065185546875
# solving Ax = b time taken:  0.07866907119750977
# l2 error 0.003206, h1 error 0.114407
# epoch:  101	assembling the mass matrix time taken:  0.004872322082519531
# solving Ax = b time taken:  0.08046793937683105
# l2 error 0.003151, h1 error 0.112784
# epoch:  102	assembling the mass matrix time taken:  0.0048792362213134766
# solving Ax = b time taken:  0.08106231689453125
# l2 error 0.003113, h1 error 0.111904
# epoch:  103	assembling the mass matrix time taken:  0.004818916320800781
# solving Ax = b time taken:  0.08174920082092285
# l2 error 0.003086, h1 error 0.111010
# epoch:  104	assembling the mass matrix time taken:  0.004614353179931641
# solving Ax = b time taken:  0.0812063217163086
# l2 error 0.003038, h1 error 0.109829
# epoch:  105	assembling the mass matrix time taken:  0.004582405090332031
# solving Ax = b time taken:  0.08321690559387207
# l2 error 0.003000, h1 error 0.109223
# epoch:  106	assembling the mass matrix time taken:  0.004843235015869141
# solving Ax = b time taken:  0.08366155624389648
# l2 error 0.002967, h1 error 0.108168
# epoch:  107	assembling the mass matrix time taken:  0.0048754215240478516
# solving Ax = b time taken:  0.08427834510803223
# l2 error 0.002941, h1 error 0.107546
# epoch:  108	assembling the mass matrix time taken:  0.004924774169921875
# solving Ax = b time taken:  0.08354330062866211
# l2 error 0.002922, h1 error 0.106939
# epoch:  109	assembling the mass matrix time taken:  0.004589080810546875
# solving Ax = b time taken:  0.08572793006896973
# l2 error 0.002891, h1 error 0.105978
# epoch:  110	assembling the mass matrix time taken:  0.00465846061706543
# solving Ax = b time taken:  0.08625912666320801
# l2 error 0.002825, h1 error 0.104590
# epoch:  111	assembling the mass matrix time taken:  0.0048999786376953125
# solving Ax = b time taken:  0.08682680130004883
# l2 error 0.002750, h1 error 0.102649
# epoch:  112	assembling the mass matrix time taken:  0.004828691482543945
# solving Ax = b time taken:  0.08611297607421875
# l2 error 0.002710, h1 error 0.101959
# epoch:  113	assembling the mass matrix time taken:  0.004904270172119141
# solving Ax = b time taken:  0.0880131721496582
# l2 error 0.002671, h1 error 0.100585
# epoch:  114	assembling the mass matrix time taken:  0.004637479782104492
# solving Ax = b time taken:  0.08879327774047852
# l2 error 0.002661, h1 error 0.100053
# epoch:  115	assembling the mass matrix time taken:  0.0046482086181640625
# solving Ax = b time taken:  0.0901949405670166
# l2 error 0.002623, h1 error 0.098670
# epoch:  116	assembling the mass matrix time taken:  0.004887104034423828
# solving Ax = b time taken:  0.08922767639160156
# l2 error 0.002583, h1 error 0.097663
# epoch:  117	assembling the mass matrix time taken:  0.004906177520751953
# solving Ax = b time taken:  0.09121155738830566
# l2 error 0.002535, h1 error 0.096656
# epoch:  118	assembling the mass matrix time taken:  0.00493621826171875
# solving Ax = b time taken:  0.09173297882080078
# l2 error 0.002514, h1 error 0.096134
# epoch:  119	assembling the mass matrix time taken:  0.0046710968017578125
# solving Ax = b time taken:  0.09263324737548828
# l2 error 0.002499, h1 error 0.095674
# epoch:  120	assembling the mass matrix time taken:  0.08982729911804199
# solving Ax = b time taken:  0.05226635932922363
# l2 error 0.002472, h1 error 0.094816
# epoch:  121	assembling the mass matrix time taken:  0.012424468994140625
# solving Ax = b time taken:  0.09969735145568848
# l2 error 0.002462, h1 error 0.094211
# epoch:  122	assembling the mass matrix time taken:  0.007096529006958008
# solving Ax = b time taken:  0.09215545654296875
# l2 error 0.002432, h1 error 0.093711
# epoch:  123	assembling the mass matrix time taken:  0.004602193832397461
# solving Ax = b time taken:  0.09520530700683594
# l2 error 0.002410, h1 error 0.093033
# epoch:  124	assembling the mass matrix time taken:  0.0045604705810546875
# solving Ax = b time taken:  0.09449338912963867
# l2 error 0.002355, h1 error 0.092002
# epoch:  125	assembling the mass matrix time taken:  0.005003213882446289
# solving Ax = b time taken:  0.09620094299316406
# l2 error 0.002339, h1 error 0.091427
# epoch:  126	assembling the mass matrix time taken:  0.004832029342651367
# solving Ax = b time taken:  0.09695720672607422
# l2 error 0.002314, h1 error 0.090470
# epoch:  127	assembling the mass matrix time taken:  0.00503087043762207
# solving Ax = b time taken:  0.0974581241607666
# l2 error 0.002308, h1 error 0.089738
# epoch:  128	assembling the mass matrix time taken:  0.004597663879394531
# solving Ax = b time taken:  0.0967264175415039
# l2 error 0.002288, h1 error 0.089017
# epoch:  129	assembling the mass matrix time taken:  0.005445957183837891
# solving Ax = b time taken:  0.12212514877319336
# l2 error 0.002270, h1 error 0.088316
# epoch:  130	assembling the mass matrix time taken:  0.005760669708251953
# solving Ax = b time taken:  0.12196922302246094
# l2 error 0.002238, h1 error 0.087540
# epoch:  131	assembling the mass matrix time taken:  0.005707502365112305
# solving Ax = b time taken:  0.12329816818237305
# l2 error 0.002211, h1 error 0.086456
# epoch:  132	assembling the mass matrix time taken:  0.1148080825805664
# solving Ax = b time taken:  0.06911587715148926
# l2 error 0.002184, h1 error 0.085596
# epoch:  133	assembling the mass matrix time taken:  0.01014256477355957
# solving Ax = b time taken:  0.12001347541809082
# l2 error 0.002148, h1 error 0.084696
# epoch:  134	assembling the mass matrix time taken:  0.005709171295166016
# solving Ax = b time taken:  0.12468099594116211
# l2 error 0.002127, h1 error 0.084103
# epoch:  135	assembling the mass matrix time taken:  0.005647182464599609
# solving Ax = b time taken:  0.12591814994812012
# l2 error 0.002087, h1 error 0.083302
# epoch:  136	assembling the mass matrix time taken:  0.005897998809814453
# solving Ax = b time taken:  0.12350249290466309
# l2 error 0.002036, h1 error 0.082000
# epoch:  137	assembling the mass matrix time taken:  0.0054111480712890625
# solving Ax = b time taken:  0.12746477127075195
# l2 error 0.002025, h1 error 0.081583
# epoch:  138	assembling the mass matrix time taken:  0.19528770446777344
# solving Ax = b time taken:  0.07252931594848633
# l2 error 0.002005, h1 error 0.081003
# epoch:  139	assembling the mass matrix time taken:  0.01015329360961914
# solving Ax = b time taken:  0.1241309642791748
# l2 error 0.001976, h1 error 0.080179
# epoch:  140	assembling the mass matrix time taken:  0.017778873443603516
# solving Ax = b time taken:  0.12644028663635254
# l2 error 0.001956, h1 error 0.079529
# epoch:  141	assembling the mass matrix time taken:  0.018113136291503906
# solving Ax = b time taken:  0.1299915313720703
# l2 error 0.001939, h1 error 0.078954
# epoch:  142	assembling the mass matrix time taken:  0.018146753311157227
# solving Ax = b time taken:  0.12970495223999023
# l2 error 0.001901, h1 error 0.078026
# epoch:  143	assembling the mass matrix time taken:  0.12801289558410645
# solving Ax = b time taken:  0.07524299621582031
# l2 error 0.001881, h1 error 0.077409
# epoch:  144	assembling the mass matrix time taken:  0.010310649871826172
# solving Ax = b time taken:  0.12391376495361328
# l2 error 0.001850, h1 error 0.076767
# epoch:  145	assembling the mass matrix time taken:  0.005370140075683594
# solving Ax = b time taken:  0.13272643089294434
# l2 error 0.001823, h1 error 0.076129
# epoch:  146	assembling the mass matrix time taken:  0.0062334537506103516
# solving Ax = b time taken:  0.13175654411315918
# l2 error 0.001811, h1 error 0.075398
# epoch:  147	assembling the mass matrix time taken:  0.006205081939697266
# solving Ax = b time taken:  0.13326120376586914
# l2 error 0.001812, h1 error 0.074992
# epoch:  148	assembling the mass matrix time taken:  0.12882518768310547
# solving Ax = b time taken:  0.07632923126220703
# l2 error 0.001794, h1 error 0.074580
# epoch:  149	assembling the mass matrix time taken:  0.010608673095703125
# solving Ax = b time taken:  0.13009262084960938
# l2 error 0.001786, h1 error 0.074270
# epoch:  150	assembling the mass matrix time taken:  0.02960205078125
# solving Ax = b time taken:  0.1110069751739502
# l2 error 0.001769, h1 error 0.073963
# epoch:  151	assembling the mass matrix time taken:  0.005866050720214844
# solving Ax = b time taken:  0.13623833656311035
# l2 error 0.001749, h1 error 0.073419
# epoch:  152	assembling the mass matrix time taken:  0.0076215267181396484
# solving Ax = b time taken:  0.13314533233642578
# l2 error 0.001737, h1 error 0.072897
# epoch:  153	assembling the mass matrix time taken:  0.17753171920776367
# solving Ax = b time taken:  0.08023428916931152
# l2 error 0.001723, h1 error 0.072539
# epoch:  154	assembling the mass matrix time taken:  0.010258913040161133
# solving Ax = b time taken:  0.13295793533325195
# l2 error 0.001697, h1 error 0.071972
# epoch:  155	assembling the mass matrix time taken:  0.0057489871978759766
# solving Ax = b time taken:  0.13907313346862793
# l2 error 0.001691, h1 error 0.071593
# epoch:  156	assembling the mass matrix time taken:  0.005470752716064453
# solving Ax = b time taken:  0.13691091537475586
# l2 error 0.001688, h1 error 0.071251
# epoch:  157	assembling the mass matrix time taken:  0.006441354751586914
# solving Ax = b time taken:  0.1397724151611328
# l2 error 0.001672, h1 error 0.070613
# epoch:  158	assembling the mass matrix time taken:  0.18477892875671387
# solving Ax = b time taken:  0.09980916976928711
# l2 error 0.001650, h1 error 0.069962
# epoch:  159	assembling the mass matrix time taken:  0.010071039199829102
# solving Ax = b time taken:  0.13744473457336426
# l2 error 0.001616, h1 error 0.069251
# epoch:  160	assembling the mass matrix time taken:  0.005541324615478516
# solving Ax = b time taken:  0.1387178897857666
# l2 error 0.001572, h1 error 0.068309
# epoch:  161	assembling the mass matrix time taken:  0.00565791130065918
# solving Ax = b time taken:  0.14049720764160156
# l2 error 0.001556, h1 error 0.067910
# epoch:  162	assembling the mass matrix time taken:  0.007859468460083008
# solving Ax = b time taken:  0.1388721466064453
# l2 error 0.001539, h1 error 0.067381
# epoch:  163	assembling the mass matrix time taken:  0.22953104972839355
# solving Ax = b time taken:  0.07926440238952637
# l2 error 0.001520, h1 error 0.067023
# epoch:  164	assembling the mass matrix time taken:  0.009721994400024414
# solving Ax = b time taken:  0.13570690155029297
# l2 error 0.001511, h1 error 0.066737
# epoch:  165	assembling the mass matrix time taken:  0.0057373046875
# solving Ax = b time taken:  0.14311456680297852
# l2 error 0.001499, h1 error 0.066292
# epoch:  166	assembling the mass matrix time taken:  0.005478620529174805
# solving Ax = b time taken:  0.14322400093078613
# l2 error 0.001497, h1 error 0.066148
# epoch:  167	assembling the mass matrix time taken:  0.014842987060546875
# solving Ax = b time taken:  0.13520216941833496
# l2 error 0.001471, h1 error 0.065360
# epoch:  168	assembling the mass matrix time taken:  0.2999606132507324
# solving Ax = b time taken:  0.08019065856933594
# l2 error 0.001463, h1 error 0.064972
# epoch:  169	assembling the mass matrix time taken:  0.008491039276123047
# solving Ax = b time taken:  0.14302706718444824
# l2 error 0.001439, h1 error 0.064343
# epoch:  170	assembling the mass matrix time taken:  0.005444765090942383
# solving Ax = b time taken:  0.14571833610534668
# l2 error 0.001416, h1 error 0.063888
# epoch:  171	assembling the mass matrix time taken:  0.005766153335571289
# solving Ax = b time taken:  0.14689397811889648
# l2 error 0.001412, h1 error 0.063579
# epoch:  172	assembling the mass matrix time taken:  0.1454784870147705
# solving Ax = b time taken:  0.0824739933013916
# l2 error 0.001403, h1 error 0.063206
# epoch:  173	assembling the mass matrix time taken:  0.010104179382324219
# solving Ax = b time taken:  0.14375686645507812
# l2 error 0.001402, h1 error 0.062941
# epoch:  174	assembling the mass matrix time taken:  0.005736351013183594
# solving Ax = b time taken:  0.14804959297180176
# l2 error 0.001391, h1 error 0.062572
# epoch:  175	assembling the mass matrix time taken:  0.0057756900787353516
# solving Ax = b time taken:  0.14944124221801758
# l2 error 0.001378, h1 error 0.062145
# epoch:  176	assembling the mass matrix time taken:  0.18151021003723145
# solving Ax = b time taken:  0.08319425582885742
# l2 error 0.001364, h1 error 0.061735
# epoch:  177	assembling the mass matrix time taken:  0.009695768356323242
# solving Ax = b time taken:  0.14670538902282715
# l2 error 0.001352, h1 error 0.061256
# epoch:  178	assembling the mass matrix time taken:  0.005722999572753906
# solving Ax = b time taken:  0.15051984786987305
# l2 error 0.001336, h1 error 0.060740
# epoch:  179	assembling the mass matrix time taken:  0.005794525146484375
# solving Ax = b time taken:  0.15188884735107422
# l2 error 0.001324, h1 error 0.060395
# epoch:  180	assembling the mass matrix time taken:  0.1880342960357666
# solving Ax = b time taken:  0.0850071907043457
# l2 error 0.001316, h1 error 0.060122
# epoch:  181	assembling the mass matrix time taken:  0.010174036026000977
# solving Ax = b time taken:  0.14884495735168457
# l2 error 0.001296, h1 error 0.059468
# epoch:  182	assembling the mass matrix time taken:  0.005947589874267578
# solving Ax = b time taken:  0.15281414985656738
# l2 error 0.001288, h1 error 0.059185
# epoch:  183	assembling the mass matrix time taken:  0.00550389289855957
# solving Ax = b time taken:  0.15472698211669922
# l2 error 0.001271, h1 error 0.058719
# epoch:  184	assembling the mass matrix time taken:  0.24637150764465332
# solving Ax = b time taken:  0.08632993698120117
# l2 error 0.001262, h1 error 0.058425
# epoch:  185	assembling the mass matrix time taken:  0.00909113883972168
# solving Ax = b time taken:  0.1525113582611084
# l2 error 0.001253, h1 error 0.058205
# epoch:  186	assembling the mass matrix time taken:  0.005492448806762695
# solving Ax = b time taken:  0.1557140350341797
# l2 error 0.001231, h1 error 0.057685
# epoch:  187	assembling the mass matrix time taken:  0.007230997085571289
# solving Ax = b time taken:  0.15553021430969238
# l2 error 0.001213, h1 error 0.057087
# epoch:  188	assembling the mass matrix time taken:  0.21692824363708496
# solving Ax = b time taken:  0.10477089881896973
# l2 error 0.001210, h1 error 0.056869
# epoch:  189	assembling the mass matrix time taken:  0.009560346603393555
# solving Ax = b time taken:  0.15437006950378418
# l2 error 0.001200, h1 error 0.056606
# epoch:  190	assembling the mass matrix time taken:  0.005426645278930664
# solving Ax = b time taken:  0.15835833549499512
# l2 error 0.001195, h1 error 0.056329
# epoch:  191	assembling the mass matrix time taken:  0.00759124755859375
# solving Ax = b time taken:  0.15784049034118652
# l2 error 0.001190, h1 error 0.056173
# epoch:  192	assembling the mass matrix time taken:  0.295011043548584
# solving Ax = b time taken:  0.08889222145080566
# l2 error 0.001175, h1 error 0.055617
# epoch:  193	assembling the mass matrix time taken:  0.008630752563476562
# solving Ax = b time taken:  0.18796229362487793
# l2 error 0.001166, h1 error 0.055418
# epoch:  194	assembling the mass matrix time taken:  0.006362199783325195
# solving Ax = b time taken:  0.19060611724853516
# l2 error 0.001163, h1 error 0.055199
# epoch:  195	assembling the mass matrix time taken:  0.009510517120361328
# solving Ax = b time taken:  0.18833518028259277
# l2 error 0.001156, h1 error 0.054808
# epoch:  196	assembling the mass matrix time taken:  0.1924748420715332
# solving Ax = b time taken:  0.12844276428222656
# l2 error 0.001152, h1 error 0.054633
# epoch:  197	assembling the mass matrix time taken:  0.010597705841064453
# solving Ax = b time taken:  0.18852663040161133
# l2 error 0.001129, h1 error 0.053995
# epoch:  198	assembling the mass matrix time taken:  0.0059621334075927734
# solving Ax = b time taken:  0.19298577308654785
# l2 error 0.001119, h1 error 0.053714
# epoch:  199	assembling the mass matrix time taken:  0.008148193359375
# solving Ax = b time taken:  0.19159507751464844
# l2 error 0.001109, h1 error 0.053395
# epoch:  200	assembling the mass matrix time taken:  0.32031726837158203
# solving Ax = b time taken:  0.10631322860717773
# l2 error 0.001103, h1 error 0.053171
# epoch:  201	assembling the mass matrix time taken:  0.008761167526245117
# solving Ax = b time taken:  0.19202160835266113
# l2 error 0.001090, h1 error 0.052601
# epoch:  202	assembling the mass matrix time taken:  0.005461692810058594
# solving Ax = b time taken:  0.19499540328979492
# l2 error 0.001087, h1 error 0.052471
# epoch:  203	assembling the mass matrix time taken:  0.007816314697265625
# solving Ax = b time taken:  0.1943206787109375
# l2 error 0.001081, h1 error 0.052293
# epoch:  204	assembling the mass matrix time taken:  0.291975736618042
# solving Ax = b time taken:  0.10866117477416992
# l2 error 0.001080, h1 error 0.052023
# epoch:  205	assembling the mass matrix time taken:  0.008981943130493164
# solving Ax = b time taken:  0.19432568550109863
# l2 error 0.001068, h1 error 0.051666
# epoch:  206	assembling the mass matrix time taken:  0.006768703460693359
# solving Ax = b time taken:  0.19629526138305664
# l2 error 0.001057, h1 error 0.051356
# epoch:  207	assembling the mass matrix time taken:  0.008671283721923828
# solving Ax = b time taken:  0.1960620880126953
# l2 error 0.001050, h1 error 0.051111
# epoch:  208	assembling the mass matrix time taken:  0.2971682548522949
# solving Ax = b time taken:  0.13338422775268555
# l2 error 0.001044, h1 error 0.050998
# epoch:  209	assembling the mass matrix time taken:  0.009136199951171875
# solving Ax = b time taken:  0.19691967964172363
# l2 error 0.001035, h1 error 0.050684
# epoch:  210	assembling the mass matrix time taken:  0.005898237228393555
# solving Ax = b time taken:  0.19962215423583984
# l2 error 0.001030, h1 error 0.050361
# epoch:  211	assembling the mass matrix time taken:  0.008592605590820312
# solving Ax = b time taken:  0.1985642910003662
# l2 error 0.001024, h1 error 0.050189
# epoch:  212	assembling the mass matrix time taken:  0.3036653995513916
# solving Ax = b time taken:  0.1352989673614502
# l2 error 0.001019, h1 error 0.049999
# epoch:  213	assembling the mass matrix time taken:  0.00924372673034668
# solving Ax = b time taken:  0.19916582107543945
# l2 error 0.001013, h1 error 0.049817
# epoch:  214	assembling the mass matrix time taken:  0.006047725677490234
# solving Ax = b time taken:  0.20202136039733887
# l2 error 0.001014, h1 error 0.049608
# epoch:  215	assembling the mass matrix time taken:  0.23576831817626953
# solving Ax = b time taken:  0.11326241493225098
# l2 error 0.001010, h1 error 0.049514
# epoch:  216	assembling the mass matrix time taken:  0.00902414321899414
# solving Ax = b time taken:  0.19700837135314941
# l2 error 0.001007, h1 error 0.049396
# epoch:  217	assembling the mass matrix time taken:  0.006096363067626953
# solving Ax = b time taken:  0.2048656940460205
# l2 error 0.001001, h1 error 0.048999
# epoch:  218	assembling the mass matrix time taken:  0.23630166053771973
# solving Ax = b time taken:  0.11404895782470703
# l2 error 0.000992, h1 error 0.048678
# epoch:  219	assembling the mass matrix time taken:  0.009225130081176758
# solving Ax = b time taken:  0.202866792678833
# l2 error 0.000984, h1 error 0.048403
# epoch:  220	assembling the mass matrix time taken:  0.006072521209716797
# solving Ax = b time taken:  0.2028195858001709
# l2 error 0.000983, h1 error 0.048223
# epoch:  221	assembling the mass matrix time taken:  0.20193243026733398
# solving Ax = b time taken:  0.11548066139221191
# l2 error 0.000972, h1 error 0.047845
# epoch:  222	assembling the mass matrix time taken:  0.009957313537597656
# solving Ax = b time taken:  0.202986478805542
# l2 error 0.000965, h1 error 0.047681
# epoch:  223	assembling the mass matrix time taken:  0.005953788757324219
# solving Ax = b time taken:  0.20879268646240234
# l2 error 0.000959, h1 error 0.047496
# epoch:  224	assembling the mass matrix time taken:  0.19781851768493652
# solving Ax = b time taken:  0.11520099639892578
# l2 error 0.000957, h1 error 0.047386
# epoch:  225	assembling the mass matrix time taken:  0.009589910507202148
# solving Ax = b time taken:  0.20627069473266602
# l2 error 0.000956, h1 error 0.047194
# epoch:  226	assembling the mass matrix time taken:  0.0060846805572509766
# solving Ax = b time taken:  0.20975613594055176
# l2 error 0.000947, h1 error 0.046957
# epoch:  227	assembling the mass matrix time taken:  0.24835538864135742
# solving Ax = b time taken:  0.11804008483886719
# l2 error 0.000940, h1 error 0.046735
# epoch:  228	assembling the mass matrix time taken:  0.00975656509399414
# solving Ax = b time taken:  0.20429062843322754
# l2 error 0.000936, h1 error 0.046585
# epoch:  229	assembling the mass matrix time taken:  0.005978822708129883
# solving Ax = b time taken:  0.21327686309814453
# l2 error 0.000923, h1 error 0.046128
# epoch:  230	assembling the mass matrix time taken:  0.29573798179626465
# solving Ax = b time taken:  0.11879348754882812
# l2 error 0.000915, h1 error 0.045960
# epoch:  231	assembling the mass matrix time taken:  0.009244203567504883
# solving Ax = b time taken:  0.21088719367980957
# l2 error 0.000910, h1 error 0.045815
# epoch:  232	assembling the mass matrix time taken:  0.006433725357055664
# solving Ax = b time taken:  0.2096402645111084
# l2 error 0.000909, h1 error 0.045672
# epoch:  233	assembling the mass matrix time taken:  0.3667585849761963
# solving Ax = b time taken:  0.12007689476013184
# l2 error 0.000906, h1 error 0.045522
# epoch:  234	assembling the mass matrix time taken:  0.007982492446899414
# solving Ax = b time taken:  0.21280622482299805
# l2 error 0.000896, h1 error 0.045169
# epoch:  235	assembling the mass matrix time taken:  0.00680232048034668
# solving Ax = b time taken:  0.21564435958862305
# l2 error 0.000894, h1 error 0.044940
# epoch:  236	assembling the mass matrix time taken:  0.22945117950439453
# solving Ax = b time taken:  0.14508819580078125
# l2 error 0.000889, h1 error 0.044685
# epoch:  237	assembling the mass matrix time taken:  0.009934186935424805
# solving Ax = b time taken:  0.2137773036956787
# l2 error 0.000884, h1 error 0.044512
# epoch:  238	assembling the mass matrix time taken:  0.006983280181884766
# solving Ax = b time taken:  0.21597075462341309
# l2 error 0.000881, h1 error 0.044289
# epoch:  239	assembling the mass matrix time taken:  0.3761904239654541
# solving Ax = b time taken:  0.12225937843322754
# l2 error 0.000874, h1 error 0.044109
# epoch:  240	assembling the mass matrix time taken:  0.007956266403198242
# solving Ax = b time taken:  0.21310043334960938
# l2 error 0.000868, h1 error 0.043880
# epoch:  241	assembling the mass matrix time taken:  0.006811618804931641
# solving Ax = b time taken:  0.21927762031555176
# l2 error 0.000859, h1 error 0.043617
# epoch:  242	assembling the mass matrix time taken:  0.2367541790008545
# solving Ax = b time taken:  0.14867854118347168
# l2 error 0.000850, h1 error 0.043394
# epoch:  243	assembling the mass matrix time taken:  0.009463071823120117
# solving Ax = b time taken:  0.21792268753051758
# l2 error 0.000850, h1 error 0.043290
# epoch:  244	assembling the mass matrix time taken:  0.007321357727050781
# solving Ax = b time taken:  0.21646380424499512
# l2 error 0.000843, h1 error 0.043126
# epoch:  245	assembling the mass matrix time taken:  0.38320040702819824
# solving Ax = b time taken:  0.12448573112487793
# l2 error 0.000839, h1 error 0.042939
# epoch:  246	assembling the mass matrix time taken:  0.008927583694458008
# solving Ax = b time taken:  0.22009921073913574
# l2 error 0.000838, h1 error 0.042781
# epoch:  247	assembling the mass matrix time taken:  0.0075206756591796875
# solving Ax = b time taken:  0.22247576713562012
# l2 error 0.000829, h1 error 0.042581
# epoch:  248	assembling the mass matrix time taken:  0.240586519241333
# solving Ax = b time taken:  0.14960050582885742
# l2 error 0.000824, h1 error 0.042419
# epoch:  249	assembling the mass matrix time taken:  0.010509490966796875
# solving Ax = b time taken:  0.22080349922180176
# l2 error 0.000822, h1 error 0.042312
# epoch:  250	assembling the mass matrix time taken:  0.007442951202392578
# solving Ax = b time taken:  0.22311806678771973
# l2 error 0.000820, h1 error 0.042143
# epoch:  251	assembling the mass matrix time taken:  0.31363558769226074
# solving Ax = b time taken:  0.15307998657226562
# l2 error 0.000808, h1 error 0.041658
# epoch:  252	assembling the mass matrix time taken:  0.01003122329711914
# solving Ax = b time taken:  0.21878671646118164
# l2 error 0.000805, h1 error 0.041538
# epoch:  253	assembling the mass matrix time taken:  0.008048534393310547
# solving Ax = b time taken:  0.22560572624206543
# l2 error 0.000800, h1 error 0.041391
# epoch:  254	assembling the mass matrix time taken:  0.4964907169342041
# solving Ax = b time taken:  0.12155652046203613
# l2 error 0.000794, h1 error 0.041158
# epoch:  255	assembling the mass matrix time taken:  0.007303476333618164
# solving Ax = b time taken:  0.22768449783325195
# l2 error 0.000788, h1 error 0.041010
# epoch:  256	assembling the mass matrix time taken:  0.00807499885559082
# solving Ax = b time taken:  0.22280502319335938
# l2 error 0.000785, h1 error 0.040882
# time taken:  106.92102432250977
# neuron num 		 error 		 order
# 4 		 0.187524 		 * 		 2.010464 		 *
#
# 8 		 0.095435 		 0.974486 		 1.434597 		 0.486883
#
# 16 		 0.069121 		 0.465389 		 1.094796 		 0.389983
#
# 32 		 0.019694 		 1.811391 		 0.413667 		 1.404119
#
# 64 		 0.006184 		 1.671084 		 0.182143 		 1.183400
#
# 128 		 0.002288 		 1.434211 		 0.089017 		 1.032920
#
# 256 		 0.000785 		 1.543761 		 0.040882 		 1.122602
