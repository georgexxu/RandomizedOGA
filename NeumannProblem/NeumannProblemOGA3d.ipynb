# %%
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import time
import sys
import os 
from scipy.sparse import linalg
from pathlib import Path
import itertools
if torch.cuda.is_available():  
    device = "cuda" 
else:  
    device = "cpu"    


torch.set_default_dtype(torch.float64)
pi = torch.tensor(np.pi)
ZERO = torch.tensor([0.]).to(device)
torch.set_printoptions(precision=6)

class model(nn.Module):
    """ ReLU k shallow neural network
    Parameters: 
    input size: input dimension
    hidden_size1 : number of hidden layers 
    num_classes: output classes 
    k: degree of relu functions
    """
    def __init__(self, input_size, hidden_size1, num_classes,k = 1):
        super().__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, num_classes,bias = False)
        self.k = k 
    def forward(self, x):
        u1 = self.fc2(F.relu(self.fc1(x))**self.k)
        return u1
    def evaluate_derivative(self, x, i):
        if self.k == 1:
            u1 = self.fc2(torch.heaviside(self.fc1(x),ZERO) * self.fc1.weight.t()[i-1:i,:] )
        else:
            u1 = self.fc2(self.k*F.relu(self.fc1(x))**(self.k-1) *self.fc1.weight.t()[i-1:i,:] )  
        return u1

def adjust_neuron_position(my_model, dims = 3):

    def create_mesh_grid(dims, pts):
        mesh = torch.tensor(list(itertools.product(pts,repeat=dims)))
        vertices = mesh.reshape(len(pts) ** dims, -1) 
        return vertices
    counter = 0 
    # positions = torch.tensor([[0.,0.],[0.,1.],[1.,1.],[1.,0.]])
    pts = torch.tensor([0.,1.])
    positions = create_mesh_grid(dims,pts) 
    neuron_num = my_model.fc1.bias.size(0)
    for i in range(neuron_num): 
        w = my_model.fc1.weight.data[i:i+1,:]
        b = my_model.fc1.bias.data[i]
    #     print(w,b)
        values = torch.matmul(positions,w.T) # + b
        left_end = - torch.max(values)
        right_end = - torch.min(values)
        offset = (right_end - left_end)/50
        if b <= left_end + offset/2 : 
            b = torch.rand(1)*(right_end - left_end - offset) + left_end + offset/2 
            my_model.fc1.bias.data[i] = b 
        if b >= right_end - offset/2 :
            if counter < (dims+1):
#                 print("here")
                counter += 1
            else: # (d + 1) or more 
                b = torch.rand(1)*(right_end - left_end - offset) + left_end + offset/2 
                my_model.fc1.bias.data[i] = b 
    return my_model

# %%
def show_convergence_order2(err_l2,err_h10,exponent,dict_size, filename,write2file = False):
    
    if write2file:
        file_mode = "a" if os.path.exists(filename) else "w"
        f_write = open(filename, file_mode)
    
    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_l2[i] for i in neuron_nums ]
    err_list2 = [err_h10[i] for i in neuron_nums ] 
    # f_write.write('M:{}, relu {} \n'.format(M,k))
    if write2file:
        f_write.write('dictionary size: {}\n'.format(dict_size))
        f_write.write("neuron num \t\t error \t\t order \t\t h10 error \\ order \n")
    print("neuron num \t\t error \t\t order")
    for i, item in enumerate(err_list):
        if i == 0: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t")
            
            # print("*")
            print("{} \t\t {:.6f} \t\t * \t\t {:.6f} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ) )
            if write2file: 
                f_write.write("{} \t\t {} \t\t * \t\t {} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ))
        else: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t") 
            # print(np.log(err_list[i-1]/err_list[i])/np.log(2))
            print("{} \t\t {:.6f} \t\t {:.6f} \t\t {:.6f} \t\t {:.6f} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ) )
            if write2file: 
                f_write.write("{} \t\t {} \t\t {} \t\t {} \t\t {} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ))
    if write2file:     
        f_write.write("\n")
        f_write.close()

def show_convergence_order_latex2(err_l2,err_h10,exponent,k=1,d=1): 
    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_l2[i] for i in neuron_nums ]
    err_list2 = [err_h10[i] for i in neuron_nums ] 
    l2_order = -1/2-(2*k + 1)/(2*d)
    h1_order =  -1/2-(2*(k-1)+ 1)/(2*d)
    print("neuron num  & \t $\|u-u_n \|_{{L^2}}$ & \t order $O(n^{{{:.2f}}})$  & \t $ | u -u_n |_{{H^1}}$ & \t order $O(n^{{{:.2f}}})$  \\\ \hline \hline ".format(l2_order,h1_order))
    for i, item in enumerate(err_list):
        if i == 0: 
            print("{} \t\t & {:.6f} &\t\t * & \t\t {:.6f} & \t\t *  \\\ \hline  \n".format(neuron_nums[i],item, err_list2[i] ) )   
        else: 
            print("{} \t\t &  {:.3e} &  \t\t {:.2f} &  \t\t {:.3e} &  \t\t {:.2f} \\\ \hline  \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ) )

# %%
def PiecewiseGQ2D_weights_points(Nx, order): 
    """ A slight modification of PiecewiseGQ2D function that only needs the weights and integration points.
    Parameters
    ----------

    Nx: int 
        number of intervals along the dimension. No Ny, assume Nx = Ny
    order: int 
        order of the Gauss Quadrature

    Returns
    -------
    long_weights: torch.tensor
    integration_points: torch.tensor
    """

#     print("order: ",order )
    x, w = np.polynomial.legendre.leggauss(order)
    gauss_pts = np.array(np.meshgrid(x,x,indexing='ij')).reshape(2,-1).T
    weights =  (w*w[:,None]).ravel()

    gauss_pts =torch.tensor(gauss_pts)
    weights = torch.tensor(weights)

    h = 1/Nx # 100 intervals 
    long_weights =  torch.tile(weights,(Nx**2,1))
    long_weights = long_weights.reshape(-1,1)
    long_weights = long_weights * h**2 /4 

    integration_points = torch.tile(gauss_pts,(Nx**2,1))
    scale_factor = h/2 
    integration_points = scale_factor * integration_points

    index = np.arange(1,Nx+1)-0.5
    ordered_pairs = np.array(np.meshgrid(index,index,indexing='ij'))
    ordered_pairs = ordered_pairs.reshape(2,-1).T

    # print(ordered_pairs)
    # print()
    ordered_pairs = torch.tensor(ordered_pairs)
    # print(ordered_pairs.size())
    ordered_pairs = torch.tile(ordered_pairs, (1,order**2)) # number of GQ points
    # print(ordered_pairs)

    ordered_pairs =  ordered_pairs.reshape(-1,2)
    # print(ordered_pairs)
    translation = ordered_pairs*h 
    # print(translation)

    integration_points = integration_points + translation 
#     print(integration_points.size())
    # func_values = integrand2_torch(integration_points)
    return long_weights.to(device), integration_points.to(device)


def PiecewiseGQ3D_weights_points(Nx, order): 
    """ A slight modification of PiecewiseGQ2D function that only needs the weights and integration points.
    Parameters
    ----------

    Nx: int 
        number of intervals along the dimension. No Ny, assume Nx = Ny
    order: int 
        order of the Gauss Quadrature

    Returns
    -------
    long_weights: torch.tensor
    integration_points: torch.tensor
    """

    """
    Parameters
    ----------
    target : 
        Target function 
    Nx: int 
        number of intervals along the dimension. No Ny, assume Nx = Ny
    order: int 
        order of the Gauss Quadrature
    """

    # print("order: ",order )
    x, w = np.polynomial.legendre.leggauss(order)
    gauss_pts = np.array(np.meshgrid(x,x,x,indexing='ij')).reshape(3,-1).T
    weight_list = np.array(np.meshgrid(w,w,w,indexing='ij'))
    weights =   (weight_list[0]*weight_list[1]*weight_list[2]).ravel() 

    gauss_pts =torch.tensor(gauss_pts)
    weights = torch.tensor(weights)

    h = 1/Nx # 100 intervals 
    long_weights =  torch.tile(weights,(Nx**3,1))
    long_weights = long_weights.reshape(-1,1)
    long_weights = long_weights * h**3 /8 

    integration_points = torch.tile(gauss_pts,(Nx**3,1))
    # print("shape of integration_points", integration_points.size())
    scale_factor = h/2 
    integration_points = scale_factor * integration_points

    index = np.arange(1,Nx+1)-0.5
    ordered_pairs = np.array(np.meshgrid(index,index,index,indexing='ij'))
    ordered_pairs = ordered_pairs.reshape(3,-1).T

    # print(ordered_pairs)
    # print()
    ordered_pairs = torch.tensor(ordered_pairs)
    # print(ordered_pairs.size())
    ordered_pairs = torch.tile(ordered_pairs, (1,order**3)) # number of GQ points
    # print(ordered_pairs)

    ordered_pairs =  ordered_pairs.reshape(-1,3)
    # print(ordered_pairs)
    translation = ordered_pairs*h 
    # print(translation)

    integration_points = integration_points + translation 

    return long_weights.to(device), integration_points.to(device)


def generate_relu_dict3D(N_list):
    N1 = N_list[0]
    N2 = N_list[1]
    N3 = N_list[2]
    
    N = N1*N2*N3 
    theta1 = np.linspace(0, pi, N1, endpoint= True).reshape(N1,1)
    theta2 = np.linspace(0, 2*pi, N2, endpoint= False).reshape(N2,1)
    b = np.linspace(-1.732, 1.732, N3,endpoint=False).reshape(N3,1) # threshold: 3**0.5  
    coord3 = np.array(np.meshgrid(theta1,theta2,b,indexing='ij'))
    coord3 = coord3.reshape(3,-1).T # N1*N2*N3 x 3. coordinates for the grid points 
    coord3 = torch.tensor(coord3) 

    f1 = torch.zeros(N,1) 
    f2 = torch.zeros(N,1)
    f3 = torch.zeros(N,1)
    f4 = torch.zeros(N,1)

    f1[:,0] = torch.cos(coord3[:,0]) 
    f2[:,0] = torch.sin(coord3[:,0]) * torch.cos(coord3[:,1])
    f3[:,0] = torch.sin(coord3[:,0]) * torch.sin(coord3[:,1])
    f4[:,0] = coord3[:,2] 

    Wb_tensor = torch.cat([f1,f2,f3,f4],1) # N x 4 
    return Wb_tensor


def generate_relu_dict3D_QMC(s,N0):
#     Sob = torch.quasirandom.SobolEngine(dimension =3, scramble= True, seed=None) 
#     samples = Sob.draw(N0).double() 

#     for i in range(s-1):
#         samples = torch.cat([samples,Sob.draw(N0).double()],0)

    # Monte Carlo 
    samples = torch.rand(s*N0,3) 
    T =torch.tensor([[pi,0,0],[0,2*pi,0],[0,0,1.732*2]])
    shift = torch.tensor([0,0,-1.732])
    samples = samples@T + shift 

    f1 = torch.zeros(s*N0,1) 
    f2 = torch.zeros(s*N0,1)
    f3 = torch.zeros(s*N0,1)
    f4 = torch.zeros(s*N0,1)

    f1[:,0] = torch.cos(samples[:,0]) 
    f2[:,0] = torch.sin(samples[:,0]) * torch.cos(samples[:,1])
    f3[:,0] = torch.sin(samples[:,0]) * torch.sin(samples[:,1])
    f4[:,0] = samples[:,2] 

    Wb_tensor = torch.cat([f1,f2,f3,f4],1) # N x 4 
    return Wb_tensor

def generate_relu_dict3D_sphere(s,N0):
    # add this method to your notes... otherwise you will forget it 
    samples = torch.randn(s*N0,4) 
    samples = samples/samples.norm(dim=1,keepdim=True)  
    Wb = samples 
    return Wb 


def minimize_linear_layer_H1_explicit_assemble_efficient(model,alpha, target, g_N, weights, integration_points, w_bd, pts_bd, activation = 'relu',solver="direct" ,memory=2**29):
    """ -div alpha grad u(x) + u = f 
    Parameters
    ----------
    model: 
        nn model
    alpha:
        alpha function
    target:
        rhs function f 
    pts_bd:
        integration points on the boundary, embdedded in the domain 
    """ 
    ZERO = torch.tensor([0.]).to(device)
    start_time = time.time() 
    w = model.fc1.weight.data 
    b = model.fc1.bias.data 
    neuron_num = b.size(0) 
    dim = integration_points.size(1) 
    M = integration_points.size(0)
    coef_alpha = alpha(integration_points) # alpha  

    
    total_size = neuron_num * M # memory, number of floating numbers 
    print('total size: {} {} = {}'.format(neuron_num,M,total_size))
    num_batch = total_size//memory + 1 # divide according to memory
    print("num batches: ",num_batch)
    batch_size = M//num_batch
    jac = torch.zeros(b.size(0),b.size(0)).to(device)
    rhs = torch.zeros(b.size(0),1).to(device)
    
    for j in range(0,M,batch_size): 
        end_index = j + batch_size
        basis_value_col = F.relu(integration_points[j:end_index] @ w.t()+ b)**(model.k) 
        weighted_basis_value_col = basis_value_col * weights[j:end_index] 
        jac += weighted_basis_value_col.t() @ basis_value_col 
        rhs += weighted_basis_value_col.t() @ (target(integration_points[j:end_index,:])) 

    # Assemble the boundary condition term <g,v>_{\Gamma_N} 
    size_pts_bd = int(pts_bd.size(0)/(2*dim))
    if g_N != None: # no batch operations for the boundary part, since it is only rhs on the boundary 
        bcs_N = g_N(dim)
        for ii, g_ii in bcs_N:
            # pts_bd_ii = pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
            weighted_g_N = -g_ii(pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:])* w_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
            basis_value_bd_col = F.relu(pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:] @ w.t()+ b)**(model.k)
            rhs += basis_value_bd_col.t() @ weighted_g_N

            weighted_g_N = g_ii(pts_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:])* w_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:]
            basis_value_bd_col = F.relu(pts_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:] @ w.t()+ b)**(model.k)
            rhs += basis_value_bd_col.t() @ weighted_g_N

    # Stiffness matrix term in the jacobian 
     
    for d in range(dim):
        if model.k == 1:  
            for j in range(0,M,batch_size):  
                end_index = j + batch_size 
                basis_value_dxi_col = torch.heaviside(integration_points[j:end_index] @ w.t()+ b, ZERO) * w.t()[d:d+1,:]
                weighted_basis_value_dx_col = basis_value_dxi_col * weights[j:end_index] * coef_alpha[j:end_index] 
                jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 
#             basis_value_dxi_col = torch.heaviside(integration_points @ w.t()+ b, zero) * w.t()[d:d+1,:]
#             weighted_basis_value_dx_col = basis_value_dxi_col * weights * coef_alpha 
#             jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 

        else:
            for j in range(0,M,batch_size):  
                end_index = j + batch_size 
                basis_value_dxi_col = model.k * F.relu(integration_points[j:end_index] @ w.t()+ b)**(model.k-1) * w.t()[d:d+1,:]
                weighted_basis_value_dx_col = basis_value_dxi_col * weights[j:end_index] * coef_alpha[j:end_index] 
                jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 
#             basis_value_dxi_col = model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * w.t()[d:d+1,:]
#             weighted_basis_value_dx_col = basis_value_dxi_col * weights * coef_alpha  
#             jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 

    print("assembling the mass matrix time taken: ", time.time()-start_time) 


    start_time = time.time()    
    if solver == "cg": 
        sol, exit_code = linalg.cg(np.array(jac.detach().cpu()),np.array(rhs.detach().cpu()),tol=1e-12)
        sol = torch.tensor(sol).view(1,-1)
    elif solver == "direct": 
#         sol = np.linalg.inv( np.array(jac.detach().cpu()) )@np.array(rhs.detach().cpu())
        sol = (torch.linalg.solve( jac.detach(), rhs.detach())).view(1,-1)
    elif solver == "ls":
        sol = (torch.linalg.lstsq(jac.detach().cpu(),rhs.detach().cpu(),driver='gelsd').solution).view(1,-1)
        # sol = (torch.linalg.lstsq(jac.detach(),rhs.detach()).solution).view(1,-1) # gpu/cpu, driver = 'gels', cannot solve singular
    print("solving Ax = b time taken: ", time.time()-start_time)
    return sol 


def OGANeumannReLU3D(my_model,alpha, target,g_N, u_exact, u_exact_grad, N_list,num_epochs,plot_freq, Nx,order, k =1, rand_deter = 'deter', linear_solver = "direct",memory = 2**29): 
    """ Orthogonal greedy algorithm using 1D ReLU dictionary over [-pi,pi]
    Parameters
    ----------
    my_model: 
        nn model 
    target: 
        target function
    num_epochs: int 
        number of training epochs 
    integration_intervals: int 
        number of subintervals for piecewise numerical quadrature 

    Returns
    -------
    err: tensor 
        rank 1 torch tensor to record the L2 error history  
    model: 
        trained nn model 
    """
    #Todo Done
    dim = 3 
    gw_expand, integration_points = PiecewiseGQ3D_weights_points(Nx, order = order) 
    gw_expand = gw_expand.to(device)
    integration_points = integration_points.to(device)

    # define integration on the boundary 
    gw_expand_bd, integration_points_bd = PiecewiseGQ2D_weights_points(50, order = 3) 
    size_pts_bd = integration_points_bd.size(0) 
    gw_expand_bd_faces = torch.tile(gw_expand_bd,(2*dim,1))

    integration_points_bd_faces = torch.zeros(2*dim*integration_points_bd.size(0),dim).to(device)
    for ind in range(dim): 
        integration_points_bd_faces[2 *ind * size_pts_bd :(2 *ind +1) * size_pts_bd,ind:ind+1] = 0 
        integration_points_bd_faces[(2 *ind)*size_pts_bd :(2 * ind +1) * size_pts_bd,:ind] = integration_points_bd[:,:ind]
        integration_points_bd_faces[(2 *ind)*size_pts_bd :(2 * ind +1) * size_pts_bd,ind+1:] = integration_points_bd[:,ind:]

        integration_points_bd_faces[(2 *ind +1) * size_pts_bd:(2 *ind +2)*size_pts_bd,ind:ind+1] = 1
        integration_points_bd_faces[(2 *ind +1) * size_pts_bd:(2 *ind +2)*size_pts_bd,:ind] = integration_points_bd[:,:ind]        
        integration_points_bd_faces[(2 *ind +1) * size_pts_bd:(2 *ind +2)*size_pts_bd,ind+1:] = integration_points_bd[:,ind:]

    err = torch.zeros(num_epochs+1)
    err_h10 = torch.zeros(num_epochs+1).to(device) 
    if my_model == None: 
        func_values = - target(integration_points)
        num_neuron = 0

        list_b = []
        list_w = []
    else: 
        func_values = - (target(integration_points) - my_model(integration_points).detach())
        bias = my_model.fc1.bias.detach().data
        weights = my_model.fc1.weight.detach().data
        num_neuron = int(bias.size(0))

        list_b = list(bias)
        list_w = list(weights)
    
    # initial error Todo Done
    func_values_sqrd = func_values*func_values
    # print(func_values_sqrd.size())
    # print(gw_expand.size()) 
    err[0]= torch.sum(func_values_sqrd*gw_expand)**0.5
    ## h1 seminorm 
    if u_exact_grad != None:
        u_grad = u_exact_grad() 
        for grad_i in u_grad: 
            err_h10[0] += torch.sum((grad_i(integration_points))**2 * gw_expand)**0.5
    
    start_time = time.time()
    solver = linear_solver

    N0 = np.prod(N_list)
    if rand_deter == 'deter':
        relu_dict_parameters = generate_relu_dict3D(N_list).to(device)
    print("using linear solver: ",solver)
    M2 = integration_points.size(0) # add
    for i in range(num_epochs): 
        start_time = time.time()
        print("epoch: ",i+1, end = '\t')
        if rand_deter == 'rand':
            # relu_dict_parameters = generate_relu_dict3D_QMC(1,N0).to(device) 
            relu_dict_parameters = generate_relu_dict3D_sphere(1,N0)
        if num_neuron == 0: 
            func_values = - target(integration_points)
        else: 
            func_values = - target(integration_points) + my_model(integration_points).detach()

        weight_func_values = func_values*gw_expand  

        ### ======================= 
        total_size = M2 * N0 
        num_batch = total_size//memory + 1 
        batch_size = N0//num_batch

        output = torch.zeros(N0,1).to(device)
        print("argmax batch num, ", num_batch) 
        
        for j in range(0,N0,batch_size):  
            end_index = j + batch_size  
            basis_values_batch = (F.relu( torch.matmul(integration_points,relu_dict_parameters[j:end_index,0:dim].T ) - relu_dict_parameters[j:end_index,dim])**k).T # uses broadcasting    
            output[j:end_index,:]  = torch.matmul(basis_values_batch,weight_func_values)[:,:]
        ### ======================= 
        
#         basis_values = (F.relu( torch.matmul(integration_points,relu_dict_parameters[:,0:dim].T ) - relu_dict_parameters[:,dim])**k).T # uses broadcasting, # dimension 4 
#         output = torch.matmul(basis_values,weight_func_values) #

        ##========
        # grad u part
        alpha_coef = alpha(integration_points) # alpha 
        if my_model!= None:

            if k == 1:  
                for j in range(0,N0,batch_size):  
                    end_index = j + batch_size 
                    derivative_part = torch.heaviside(integration_points @ (relu_dict_parameters[j:end_index,0:dim].T) - relu_dict_parameters[j:end_index,dim], ZERO) # dimension 4 
                    derivative_part *= alpha_coef # alpha 
                    for dx_i in range(dim): 

                        weight_dbasis_values_dxi =  (derivative_part * relu_dict_parameters.t()[dx_i:dx_i+1,j:end_index]) *gw_expand   
                        dmy_model_dxi = my_model.evaluate_derivative(integration_points,dx_i+1).detach()
                        output[j:end_index,:] += torch.matmul(weight_dbasis_values_dxi.t(), dmy_model_dxi) 

            else:  
                for j in range(0,N0,batch_size):  
                    end_index = j + batch_size 
                    derivative_part = k * F.relu(integration_points @ (relu_dict_parameters[j:end_index,0:dim].T) - relu_dict_parameters[j:end_index,dim])**(k-1) # dimension 4 
                    derivative_part *= alpha_coef # alpha
                    for dx_i in range(dim): 

                        weight_dbasis_values_dxi =  (derivative_part * relu_dict_parameters.t()[dx_i:dx_i+1,j:end_index]) * gw_expand    
                        dmy_model_dxi = my_model.evaluate_derivative(integration_points,dx_i+1).detach()
                        output[j:end_index,:] += torch.matmul(weight_dbasis_values_dxi.t(), dmy_model_dxi) 

        ##========
    
        #Boundary condition term -<g,v>_{\Gamma_N}  
        if g_N != None:
            bcs_N = g_N(dim) 
            for ii, g_ii in bcs_N: 
                
                weighted_g_N = -g_ii(integration_points_bd_faces[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:])* gw_expand_bd_faces[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
                basis_values_bd_faces = (F.relu( torch.matmul(integration_points_bd_faces[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:],relu_dict_parameters[:,0:dim].T ) - relu_dict_parameters[:,dim])**k).T
                output -= torch.matmul(basis_values_bd_faces,weighted_g_N)
                
                weighted_g_N = g_ii(integration_points_bd_faces[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:])* gw_expand_bd_faces[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:]
                basis_values_bd_faces = (F.relu( torch.matmul(integration_points_bd_faces[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:],relu_dict_parameters[:,0:dim].T ) - relu_dict_parameters[:,dim])**k).T
                output -= torch.matmul(basis_values_bd_faces,weighted_g_N)

        
        # output = torch.abs(torch.matmul(basis_values,weight_func_values)) # 
        output = torch.abs(output)
        neuron_index = torch.argmax(output.flatten())
        print("argmax time taken, ", time.time() - start_time)
        
        
        # print(neuron_index)
        list_w.append(relu_dict_parameters[neuron_index,0:dim]) # dimension 4 
        list_b.append(-relu_dict_parameters[neuron_index,dim])
        num_neuron += 1
        my_model = model(dim,num_neuron,1,k).to(device)
        w_tensor = torch.stack(list_w, 0 ) 
        b_tensor = torch.tensor(list_b)
        my_model.fc1.weight.data[:,:] = w_tensor[:,:]
        my_model.fc1.bias.data[:] = b_tensor[:]

        #Todo Done 
#         alpha = None 
        sol = minimize_linear_layer_H1_explicit_assemble_efficient(my_model,alpha, target, g_N, gw_expand, integration_points,gw_expand_bd_faces, integration_points_bd_faces,activation = 'relu',solver = solver)

        my_model.fc2.weight.data[0,:] = sol[:]

        model_values = my_model(integration_points).detach()
        # L2 error ||u - u_n||
        diff_values_sqrd = (u_exact(integration_points) - model_values)**2 
        err[i+1]= torch.sum(diff_values_sqrd*gw_expand)**0.5

        # H10 error || grad(u) - grad(u_n) ||
        if u_exact_grad != None:
            for ind, grad_i in enumerate(u_grad):  
                my_model_dxi = my_model.evaluate_derivative(integration_points,ind+1).detach() 
                err_h10[i+1] += torch.sum((grad_i(integration_points) - my_model_dxi)**2 * gw_expand)**0.5
        print("l2 error {:.6f}, h1 error {:.6f}".format(err[i+1],err_h10[i+1]))
    print("time taken: ",time.time() - start_time)
    return err, err_h10.cpu(), my_model

# %%
def u_exact(x):
    return torch.cos(pi*x[:,0:1])*torch.cos( pi*x[:,1:2]) * torch.cos(pi*x[:,2:3])  
def alpha(x): 
    return torch.ones(x.size(0),1).to(device)

def u_exact_grad():
    d = 3 

    def grad_1(x):
        return - pi* torch.sin(pi*x[:,0:1])*torch.cos( pi*x[:,1:2]) * torch.cos(pi*x[:,2:3])   
    def grad_2(x):
        return - pi* torch.cos(pi*x[:,0:1])*torch.sin( pi*x[:,1:2]) * torch.cos(pi*x[:,2:3])  
    def grad_3(x):
        return - pi* torch.cos(pi*x[:,0:1])*torch.cos( pi*x[:,1:2]) * torch.sin(pi*x[:,2:3])   

    u_grad=[grad_1, grad_2,grad_3] 

    return u_grad

def target(x):
    z = (  3 * (pi)**2 + 1)*torch.cos( pi*x[:,0:1])*torch.cos( pi*x[:,1:2] ) * torch.cos(pi*x[:,2:3]) 
    return z 
g_N = None 

dim = 3 
function_name = "cospix" 
filename_write = "data-revision/3DOGA-{}-order.txt".format(function_name)
Nx = 25   
order = 3   
relu_k = 3 
f_write = open(filename_write, "a" if os.path.exists(filename_write) else "w")
f_write.write("RELU k = {}, Integration points: Nx {}, order {} \n".format(relu_k,Nx,order))
f_write.close() 
save = True
write2file = True
rand_deter = 'rand'

trial_num = 3 
for N_list in [[2**3,2**3,2**3]]: # ,[2**6,2**6],[2**7,2**7] 
    for trial in range(trial_num): 
        f_write = open(filename_write, "a")
        my_model = None 
        exponent = 4
        num_epochs = 2**exponent  
        plot_freq = num_epochs 
        N = np.prod(N_list)
        err_QMC2, err_h10, my_model = OGANeumannReLU3D(my_model,alpha, target,g_N, u_exact,u_exact_grad, N_list,num_epochs,plot_freq, Nx = Nx, order = order, k = relu_k, rand_deter= rand_deter, linear_solver = "direct")
        
        if save: 
            folder = 'data-revision/'
            filename = folder + 'errl2_NeumannOGA_3D_{}_neuron_{}_N_{}_randomized_trial_{}.pt'.format(function_name,num_epochs,N,trial)
            torch.save(err_QMC2,filename) 
            filename = folder + 'errh10_NeumannOGA_3D_{}_neuron_{}_N_{}_randomized_trial_{}.pt'.format(function_name,num_epochs,N,trial)
            torch.save(err_h10,filename) 
            folder = 'data-revision/'
            filename = folder + 'model_NeumannOGA_3D_{}_neuron_{}_N_{}_randomized_trial_{}.pt'.format(function_name,num_epochs,N,trial)
            torch.save(my_model.state_dict(),filename)
        
        show_convergence_order2(err_QMC2,err_h10,exponent,N,filename_write,write2file = write2file)
        show_convergence_order_latex2(err_QMC2,err_h10,exponent,k=relu_k,d = dim)
# Out:
# using linear solver:  direct
# epoch:  1	argmax batch num,  1
# argmax time taken,  2.216546058654785
# total size: 1 421875 = 421875
# num batches:  1
# assembling the mass matrix time taken:  0.028872966766357422
# solving Ax = b time taken:  0.00025916099548339844
# l2 error 0.354257, h1 error 3.305051
# epoch:  2	argmax batch num,  1
# argmax time taken,  10.939883708953857
# total size: 2 421875 = 843750
# num batches:  1
# assembling the mass matrix time taken:  0.08472394943237305
# solving Ax = b time taken:  0.00035834312438964844
# l2 error 0.353550, h1 error 3.287425
# epoch:  3	argmax batch num,  1
# argmax time taken,  9.988693714141846
# total size: 3 421875 = 1265625
# num batches:  1
# assembling the mass matrix time taken:  0.07349205017089844
# solving Ax = b time taken:  0.000453948974609375
# l2 error 0.345039, h1 error 3.259470
# epoch:  4	argmax batch num,  1
# argmax time taken,  10.159780025482178
# total size: 4 421875 = 1687500
# num batches:  1
# assembling the mass matrix time taken:  0.10046792030334473
# solving Ax = b time taken:  0.0006539821624755859
# l2 error 0.362607, h1 error 3.147881
# epoch:  5	argmax batch num,  1
# argmax time taken,  9.102701902389526
# total size: 5 421875 = 2109375
# num batches:  1
# assembling the mass matrix time taken:  0.07136702537536621
# solving Ax = b time taken:  0.00044274330139160156
# l2 error 0.362389, h1 error 3.112649
# epoch:  6	argmax batch num,  1
# argmax time taken,  8.25634217262268
# total size: 6 421875 = 2531250
# num batches:  1
# assembling the mass matrix time taken:  0.08732485771179199
# solving Ax = b time taken:  0.00039005279541015625
# l2 error 0.349068, h1 error 3.067229
# epoch:  7	argmax batch num,  1
# argmax time taken,  9.014309883117676
# total size: 7 421875 = 2953125
# num batches:  1
# assembling the mass matrix time taken:  0.10365009307861328
# solving Ax = b time taken:  0.002493143081665039
# l2 error 0.364900, h1 error 2.807265
# epoch:  8	argmax batch num,  1
# argmax time taken,  7.829239130020142
# total size: 8 421875 = 3375000
# num batches:  1
# assembling the mass matrix time taken:  0.1148381233215332
# solving Ax = b time taken:  0.0003600120544433594
# l2 error 0.469320, h1 error 2.681364
# epoch:  9	argmax batch num,  1
# argmax time taken,  9.237320899963379
# total size: 9 421875 = 3796875
# num batches:  1
# assembling the mass matrix time taken:  0.13817596435546875
# solving Ax = b time taken:  0.0073299407958984375
# l2 error 0.383199, h1 error 2.535624
# epoch:  10	argmax batch num,  1
# argmax time taken,  9.2103853225708
# total size: 10 421875 = 4218750
# num batches:  1
# assembling the mass matrix time taken:  0.14673495292663574
# solving Ax = b time taken:  0.00034689903259277344
# l2 error 0.224866, h1 error 2.452401
# epoch:  11	argmax batch num,  1
# argmax time taken,  8.398849725723267
# total size: 11 421875 = 4640625
# num batches:  1
# assembling the mass matrix time taken:  0.1652212142944336
# solving Ax = b time taken:  0.002174854278564453
# l2 error 0.179407, h1 error 2.132349
# epoch:  12	argmax batch num,  1
# argmax time taken,  9.05748701095581
# total size: 12 421875 = 5062500
# num batches:  1
# assembling the mass matrix time taken:  0.15458321571350098
# solving Ax = b time taken:  0.00046515464782714844
# l2 error 0.186167, h1 error 2.085134
# epoch:  13	argmax batch num,  1
# argmax time taken,  9.237640142440796
# total size: 13 421875 = 5484375
# num batches:  1
# assembling the mass matrix time taken:  0.17661714553833008
# solving Ax = b time taken:  0.0005290508270263672
# l2 error 0.147705, h1 error 1.820801
# epoch:  14	argmax batch num,  1
# argmax time taken,  8.649978160858154
# total size: 14 421875 = 5906250
# num batches:  1
# assembling the mass matrix time taken:  0.17857670783996582
# solving Ax = b time taken:  0.0005278587341308594
# l2 error 0.131228, h1 error 1.754619
# epoch:  15	argmax batch num,  1
# argmax time taken,  8.438117027282715
# total size: 15 421875 = 6328125
# num batches:  1
# assembling the mass matrix time taken:  0.21166396141052246
# solving Ax = b time taken:  0.0005788803100585938
# l2 error 0.103881, h1 error 1.566113
# epoch:  16	argmax batch num,  1
# argmax time taken,  8.15153980255127
# total size: 16 421875 = 6750000
# num batches:  1
# assembling the mass matrix time taken:  0.20837903022766113
# solving Ax = b time taken:  0.0006389617919921875
# l2 error 0.093266, h1 error 1.486097
# time taken:  8.454396724700928
# neuron num 		 error 		 order
# 4 		 0.362607 		 * 		 3.147881 		 *
#
# 8 		 0.469320 		 -0.372164 		 2.681364 		 0.231414
#
# 16 		 0.093266 		 2.331153 		 1.486097 		 0.851438
#
# neuron num  & 	 $\|u-u_n \|_{L^2}$ & 	 order $O(n^{-1.67})$  & 	 $ | u -u_n |_{H^1}$ & 	 order $O(n^{-1.33})$  \\ \hline \hline
# 4 		 & 0.362607 &		 * & 		 3.147881 & 		 *  \\ \hline
#
# 8 		 &  4.693e-01 &  		 -0.37 &  		 2.681e+00 &  		 0.23 \\ \hline
#
# 16 		 &  9.327e-02 &  		 2.33 &  		 1.486e+00 &  		 0.85 \\ \hline
#
# using linear solver:  direct
# epoch:  1	argmax batch num,  1
# argmax time taken,  1.02298903465271
# total size: 1 421875 = 421875
# num batches:  1
# assembling the mass matrix time taken:  0.03144502639770508
# solving Ax = b time taken:  0.00015306472778320312
# l2 error 0.354614, h1 error 3.314119
# epoch:  2	argmax batch num,  1
# argmax time taken,  5.615417718887329
# total size: 2 421875 = 843750
# num batches:  1
# assembling the mass matrix time taken:  0.07464790344238281
# solving Ax = b time taken:  0.00036787986755371094
# l2 error 0.352990, h1 error 3.304244
# epoch:  3	argmax batch num,  1
# argmax time taken,  7.907907962799072
# total size: 3 421875 = 1265625
# num batches:  1
# assembling the mass matrix time taken:  0.04324626922607422
# solving Ax = b time taken:  0.00033211708068847656
# l2 error 0.352282, h1 error 3.274282
# epoch:  4	argmax batch num,  1
# argmax time taken,  7.430002927780151
# total size: 4 421875 = 1687500
# num batches:  1
# assembling the mass matrix time taken:  0.06556296348571777
# solving Ax = b time taken:  0.0014820098876953125
# l2 error 0.348133, h1 error 3.257092
# epoch:  5	argmax batch num,  1
# argmax time taken,  7.423904895782471
# total size: 5 421875 = 2109375
# num batches:  1
# assembling the mass matrix time taken:  0.07166600227355957
# solving Ax = b time taken:  0.0004038810729980469
# l2 error 0.341263, h1 error 3.229969
# epoch:  6	argmax batch num,  1
# argmax time taken,  9.612711191177368
# total size: 6 421875 = 2531250
# num batches:  1
# assembling the mass matrix time taken:  0.08597612380981445
# solving Ax = b time taken:  0.0003859996795654297
# l2 error 0.374038, h1 error 3.128570
# epoch:  7	argmax batch num,  1
# argmax time taken,  8.573268413543701
# total size: 7 421875 = 2953125
# num batches:  1
# assembling the mass matrix time taken:  0.10317087173461914
# solving Ax = b time taken:  0.0003581047058105469
# l2 error 0.486142, h1 error 2.973205
# epoch:  8	argmax batch num,  1
# argmax time taken,  8.114949226379395
# total size: 8 421875 = 3375000
# num batches:  1
# assembling the mass matrix time taken:  0.10597872734069824
# solving Ax = b time taken:  0.00038886070251464844
# l2 error 0.268336, h1 error 2.715563
# epoch:  9	argmax batch num,  1
# argmax time taken,  8.18351697921753
# total size: 9 421875 = 3796875
# num batches:  1
# assembling the mass matrix time taken:  0.13184618949890137
# solving Ax = b time taken:  0.0003771781921386719
# l2 error 0.213852, h1 error 2.338822
# epoch:  10	argmax batch num,  1
# argmax time taken,  8.666412830352783
# total size: 10 421875 = 4218750
# num batches:  1
# assembling the mass matrix time taken:  0.13656902313232422
# solving Ax = b time taken:  0.00040078163146972656
# l2 error 0.208381, h1 error 2.245905
# epoch:  11	argmax batch num,  1
# argmax time taken,  8.659471273422241
# total size: 11 421875 = 4640625
# num batches:  1
# assembling the mass matrix time taken:  0.18734097480773926
# solving Ax = b time taken:  0.0007448196411132812
# l2 error 0.183766, h1 error 2.182473
# epoch:  12	argmax batch num,  1
# argmax time taken,  9.686260223388672
# total size: 12 421875 = 5062500
# num batches:  1
# assembling the mass matrix time taken:  0.15799784660339355
# solving Ax = b time taken:  0.00038504600524902344
# l2 error 0.157817, h1 error 1.975887
# epoch:  13	argmax batch num,  1
# argmax time taken,  8.213521957397461
# total size: 13 421875 = 5484375
# num batches:  1
# assembling the mass matrix time taken:  0.16888999938964844
# solving Ax = b time taken:  0.0005450248718261719
# l2 error 0.128686, h1 error 1.754037
# epoch:  14	argmax batch num,  1
# argmax time taken,  8.108690738677979
# total size: 14 421875 = 5906250
# num batches:  1
# assembling the mass matrix time taken:  0.17058110237121582
# solving Ax = b time taken:  0.0004329681396484375
# l2 error 0.116836, h1 error 1.678650
# epoch:  15	argmax batch num,  1
# argmax time taken,  8.535192251205444
# total size: 15 421875 = 6328125
# num batches:  1
# assembling the mass matrix time taken:  0.23177313804626465
# solving Ax = b time taken:  0.0006017684936523438
# l2 error 0.106309, h1 error 1.594523
# epoch:  16	argmax batch num,  1
# argmax time taken,  8.20726990699768
# total size: 16 421875 = 6750000
# num batches:  1
# assembling the mass matrix time taken:  0.21674609184265137
# solving Ax = b time taken:  0.0006849765777587891
# l2 error 0.100371, h1 error 1.554871
# time taken:  8.525089979171753
# neuron num 		 error 		 order
# 4 		 0.348133 		 * 		 3.257092 		 *
#
# 8 		 0.268336 		 0.375596 		 2.715563 		 0.262333
#
# 16 		 0.100371 		 1.418695 		 1.554871 		 0.804456
#
# neuron num  & 	 $\|u-u_n \|_{L^2}$ & 	 order $O(n^{-1.67})$  & 	 $ | u -u_n |_{H^1}$ & 	 order $O(n^{-1.33})$  \\ \hline \hline
# 4 		 & 0.348133 &		 * & 		 3.257092 & 		 *  \\ \hline
#
# 8 		 &  2.683e-01 &  		 0.38 &  		 2.716e+00 &  		 0.26 \\ \hline
#
# 16 		 &  1.004e-01 &  		 1.42 &  		 1.555e+00 &  		 0.80 \\ \hline
#
# using linear solver:  direct
# epoch:  1	argmax batch num,  1
# argmax time taken,  1.0332810878753662
# total size: 1 421875 = 421875
# num batches:  1
# assembling the mass matrix time taken:  0.03332996368408203
# solving Ax = b time taken:  0.00013208389282226562
# l2 error 0.354560, h1 error 3.324309
# epoch:  2	argmax batch num,  1
# argmax time taken,  5.573925971984863
# total size: 2 421875 = 843750
# num batches:  1
# assembling the mass matrix time taken:  0.07080292701721191
# solving Ax = b time taken:  0.0003380775451660156
# l2 error 0.362958, h1 error 3.299681
# epoch:  3	argmax batch num,  1
# argmax time taken,  8.525990724563599
# total size: 3 421875 = 1265625
# num batches:  1
# assembling the mass matrix time taken:  0.05592799186706543
# solving Ax = b time taken:  0.0003941059112548828
# l2 error 0.377168, h1 error 3.270400
# epoch:  4	argmax batch num,  1
# argmax time taken,  10.377197027206421
# total size: 4 421875 = 1687500
# num batches:  1
# assembling the mass matrix time taken:  0.08159708976745605
# solving Ax = b time taken:  0.0007419586181640625
# l2 error 0.396449, h1 error 3.240878
# epoch:  5	argmax batch num,  1
# argmax time taken,  8.499230146408081
# total size: 5 421875 = 2109375
# num batches:  1
# assembling the mass matrix time taken:  0.08597779273986816
# solving Ax = b time taken:  0.0004470348358154297
# l2 error 0.354615, h1 error 3.204289
# epoch:  6	argmax batch num,  1
# argmax time taken,  8.357743978500366
# total size: 6 421875 = 2531250
# num batches:  1
# assembling the mass matrix time taken:  0.08863377571105957
# solving Ax = b time taken:  0.00035190582275390625
# l2 error 0.338667, h1 error 3.155631
# epoch:  7	argmax batch num,  1
# argmax time taken,  8.21725606918335
# total size: 7 421875 = 2953125
# num batches:  1
# assembling the mass matrix time taken:  0.10583019256591797
# solving Ax = b time taken:  0.0003902912139892578
# l2 error 0.382455, h1 error 2.958862
# epoch:  8	argmax batch num,  1
# argmax time taken,  9.812183856964111
# total size: 8 421875 = 3375000
# num batches:  1
# assembling the mass matrix time taken:  0.1214139461517334
# solving Ax = b time taken:  0.00041413307189941406
# l2 error 0.451021, h1 error 2.803413
# epoch:  9	argmax batch num,  1
# argmax time taken,  10.098489999771118
# total size: 9 421875 = 3796875
# num batches:  1
# assembling the mass matrix time taken:  0.14374399185180664
# solving Ax = b time taken:  0.0005879402160644531
# l2 error 0.233790, h1 error 2.320378
# epoch:  10	argmax batch num,  1
# argmax time taken,  11.596703052520752
# total size: 10 421875 = 4218750
# num batches:  1
# assembling the mass matrix time taken:  0.15722084045410156
# solving Ax = b time taken:  0.0004961490631103516
# l2 error 0.138789, h1 error 1.829590
# epoch:  11	argmax batch num,  1
# argmax time taken,  9.16022801399231
# total size: 11 421875 = 4640625
# num batches:  1
# assembling the mass matrix time taken:  0.1737511157989502
# solving Ax = b time taken:  0.0004937648773193359
# l2 error 0.130682, h1 error 1.781239
# epoch:  12	argmax batch num,  1
# argmax time taken,  9.336253881454468
# total size: 12 421875 = 5062500
# num batches:  1
# assembling the mass matrix time taken:  0.1540980339050293
# solving Ax = b time taken:  0.0003910064697265625
# l2 error 0.102445, h1 error 1.591879
# epoch:  13	argmax batch num,  1
# argmax time taken,  8.787199974060059
# total size: 13 421875 = 5484375
# num batches:  1
# assembling the mass matrix time taken:  0.16805601119995117
# solving Ax = b time taken:  0.00038623809814453125
# l2 error 0.098430, h1 error 1.561312
# epoch:  14	argmax batch num,  1
# argmax time taken,  8.46591067314148
# total size: 14 421875 = 5906250
# num batches:  1
# assembling the mass matrix time taken:  0.18623900413513184
# solving Ax = b time taken:  0.0004181861877441406
# l2 error 0.095550, h1 error 1.541529
# epoch:  15	argmax batch num,  1
# argmax time taken,  9.530223846435547
# total size: 15 421875 = 6328125
# num batches:  1
# assembling the mass matrix time taken:  0.23678994178771973
# solving Ax = b time taken:  0.0008587837219238281
# l2 error 0.094269, h1 error 1.531588
# epoch:  16	argmax batch num,  1
# argmax time taken,  10.677453994750977
# total size: 16 421875 = 6750000
# num batches:  1
# assembling the mass matrix time taken:  0.22106313705444336
# solving Ax = b time taken:  0.0007271766662597656
# l2 error 0.093544, h1 error 1.525811
# time taken:  11.001677989959717
# neuron num 		 error 		 order
# 4 		 0.396449 		 * 		 3.240878 		 *
#
# 8 		 0.451021 		 -0.186058 		 2.803413 		 0.209201
#
# 16 		 0.093544 		 2.269470 		 1.525811 		 0.877608
#
# neuron num  & 	 $\|u-u_n \|_{L^2}$ & 	 order $O(n^{-1.67})$  & 	 $ | u -u_n |_{H^1}$ & 	 order $O(n^{-1.33})$  \\ \hline \hline
# 4 		 & 0.396449 &		 * & 		 3.240878 & 		 *  \\ \hline
#
# 8 		 &  4.510e-01 &  		 -0.19 &  		 2.803e+00 &  		 0.21 \\ \hline
#
# 16 		 &  9.354e-02 &  		 2.27 &  		 1.526e+00 &  		 0.88 \\ \hline

# %%
show_convergence_order2(err_QMC2,err_h10,exponent,2*N,filename_write,write2file = write2file)
show_convergence_order_latex2(err_QMC2,err_h10,exponent,k=relu_k,d = dim)
# Out:
# neuron num 		 error 		 order
# 4 		 0.358174 		 * 		 3.318033 		 *
#
# 8 		 0.373086 		 -0.058849 		 3.054734 		 0.119282
#
# 16 		 0.094217 		 1.985454 		 1.523022 		 1.004110
#
# 32 		 0.027010 		 1.802477 		 0.563074 		 1.435541
#
# 64 		 0.004953 		 2.447055 		 0.140089 		 2.006984
#
# 128 		 0.000860 		 2.525422 		 0.034445 		 2.023984
#
# 256 		 0.000205 		 2.066843 		 0.010990 		 1.648127
#
# 512 		 0.000054 		 1.936588 		 0.003723 		 1.561493
#
# neuron num  & 	 $\|u-u_n \|_{L^2}$ & 	 order $O(n^{-1.67})$  & 	 $ | u -u_n |_{H^1}$ & 	 order $O(n^{-1.33})$  \\ \hline \hline
# 4 		 & 0.358174 &		 * & 		 3.318033 & 		 *  \\ \hline
#
# 8 		 &  3.731e-01 &  		 -0.06 &  		 3.055e+00 &  		 0.12 \\ \hline
#
# 16 		 &  9.422e-02 &  		 1.99 &  		 1.523e+00 &  		 1.00 \\ \hline
#
# 32 		 &  2.701e-02 &  		 1.80 &  		 5.631e-01 &  		 1.44 \\ \hline
#
# 64 		 &  4.953e-03 &  		 2.45 &  		 1.401e-01 &  		 2.01 \\ \hline
#
# 128 		 &  8.603e-04 &  		 2.53 &  		 3.444e-02 &  		 2.02 \\ \hline
#
# 256 		 &  2.053e-04 &  		 2.07 &  		 1.099e-02 &  		 1.65 \\ \hline
#
# 512 		 &  5.364e-05 &  		 1.94 &  		 3.723e-03 &  		 1.56 \\ \hline

# %% [markdown]
# ## oscillatory coefficient

# %%
def u_exact(x):
    return torch.cos(pi*x[:,0:1])*torch.cos( pi*x[:,1:2]) * torch.cos(pi*x[:,2:3]) 
def alpha(x): 
#     return torch.ones(x.size(0),1).to(device)
    return 0.5 * torch.sin(6 * pi*x[:,0:1]) + 1. 

def u_exact_grad():
    d = 3 

    def grad_1(x):
        return - pi* torch.sin(pi*x[:,0:1])*torch.cos( pi*x[:,1:2]) * torch.cos(pi*x[:,2:3])   
    def grad_2(x):
        return - pi* torch.cos(pi*x[:,0:1])*torch.sin( pi*x[:,1:2]) * torch.cos(pi*x[:,2:3])  
    def grad_3(x):
        return - pi* torch.cos(pi*x[:,0:1])*torch.cos( pi*x[:,1:2]) * torch.sin(pi*x[:,2:3])   

    u_grad=[grad_1, grad_2,grad_3] 

    return u_grad

def target(x):

    z_c = torch.cos( pi*x[:,0:1])*torch.cos( pi*x[:,1:2] ) * torch.cos(pi*x[:,2:3]) 
    z1 = 3 * pi**2 * torch.sin(pi * x[:,0:1]) * torch.cos( 6*pi*x[:,0:1] ) * torch.cos( pi*x[:,1:2] )* torch.cos(pi*x[:,2:3]) 
    z2 = 0.5 * pi**2 * torch.sin(6*pi * x[:,0:1])* z_c 
    z = z1 + z2 + 2/2*pi**2 * torch.sin(6 * pi * x[:,0:1]) * z_c 
    z += ( 3 * (pi)**2 + 1)*z_c 
    return z 

g_N = None 

dim = 3 
function_name = "cospix-osci-coef" 
filename_write = "data-revision/3DOGA-{}-order.txt".format(function_name)
Nx = 50   
order = 3   
relu_k = 3 
f_write = open(filename_write, "a" if os.path.exists(filename_write) else "w")
f_write.write("RELU k = {}, Integration points: Nx {}, order {} \n".format(relu_k,Nx,order))
f_write.close() 
save = True
write2file = True
rand_deter = 'rand'

trial_num = 5
for N_list in [[2**3,2**3,2**3]]: 
    for trial in range(trial_num):
        f_write = open(filename_write, "a")
        my_model = None 
        exponent = 9 
        num_epochs = 2**exponent  
        plot_freq = num_epochs 
        N = np.prod(N_list)
        err_QMC2, err_h10, my_model = OGANeumannReLU3D(my_model,alpha, target,g_N, u_exact,u_exact_grad, N_list,num_epochs,plot_freq, Nx = Nx, order = order, k = relu_k, rand_deter= rand_deter, linear_solver = "direct")
        
        if save: 
            folder = 'data-revision/'
            filename = folder + 'errl2_NeumannOGA_OsciCoeff_3D_{}_neuron_{}_N_{}_randomized_trial_{}.pt'.format(function_name,num_epochs,N,trial)
            torch.save(err_QMC2,filename) 
            filename = folder + 'errh10_NeumannOGA_OsciCoeff_3D_{}_neuron_{}_N_{}_randomized_trial_{}.pt'.format(function_name,num_epochs,N,trial)
            torch.save(err_h10,filename) 
            filename = folder + 'model_NeumannOGA_OsciCoeff_3D_{}_neuron_{}_N_{}_randomized_trial_{}.pt'.format(function_name,num_epochs,N,trial)
            torch.save(my_model.state_dict(),filename)

        show_convergence_order2(err_QMC2,err_h10,exponent,N,filename_write,write2file = write2file)
        show_convergence_order_latex2(err_QMC2,err_h10,exponent,k=relu_k,d = dim)
# Out:
# using linear solver:  direct
# epoch:  1	argmax batch num,  4
# argmax time taken,  0.0039675235748291016
# total size: 1 3375000 = 3375000
# num batches:  1
# assembling the mass matrix time taken:  0.001203775405883789
# solving Ax = b time taken:  0.0029745101928710938
# l2 error 0.354324, h1 error 3.331350
# epoch:  2	argmax batch num,  4
# argmax time taken,  0.006653785705566406
# total size: 2 3375000 = 6750000
# num batches:  1
# assembling the mass matrix time taken:  0.001329183578491211
# solving Ax = b time taken:  0.008353948593139648
# l2 error 0.353771, h1 error 3.331324
# epoch:  3	argmax batch num,  4
# argmax time taken,  0.007819890975952148
# total size: 3 3375000 = 10125000
# num batches:  1
# assembling the mass matrix time taken:  0.0014786720275878906
# solving Ax = b time taken:  0.009195804595947266
# l2 error 0.355522, h1 error 3.330669
# epoch:  4	argmax batch num,  4
# argmax time taken,  0.008081674575805664
# total size: 4 3375000 = 13500000
# num batches:  1
# assembling the mass matrix time taken:  0.001322031021118164
# solving Ax = b time taken:  0.010049104690551758
# l2 error 0.355201, h1 error 3.328693
# epoch:  5	argmax batch num,  4
# argmax time taken,  0.008074045181274414
# total size: 5 3375000 = 16875000
# num batches:  1
# assembling the mass matrix time taken:  0.0013577938079833984
# solving Ax = b time taken:  0.011051177978515625
# l2 error 0.351670, h1 error 3.312006
# epoch:  6	argmax batch num,  4
# argmax time taken,  0.008336544036865234
# total size: 6 3375000 = 20250000
# num batches:  1
# assembling the mass matrix time taken:  0.001354217529296875
# solving Ax = b time taken:  0.012070417404174805
# l2 error 0.353387, h1 error 3.294525
# epoch:  7	argmax batch num,  4
# argmax time taken,  0.008375167846679688
# total size: 7 3375000 = 23625000
# num batches:  1
# assembling the mass matrix time taken:  0.0013241767883300781
# solving Ax = b time taken:  0.013168096542358398
# l2 error 0.346070, h1 error 3.225031
# epoch:  8	argmax batch num,  4
# argmax time taken,  0.008531808853149414
# total size: 8 3375000 = 27000000
# num batches:  1
# assembling the mass matrix time taken:  0.0013933181762695312
# solving Ax = b time taken:  0.014154672622680664
# l2 error 0.319866, h1 error 2.532866
# epoch:  9	argmax batch num,  4
# argmax time taken,  0.008445978164672852
# total size: 9 3375000 = 30375000
# num batches:  1
# assembling the mass matrix time taken:  0.001325368881225586
# solving Ax = b time taken:  0.013961553573608398
# l2 error 0.200980, h1 error 2.193746
# epoch:  10	argmax batch num,  4
# argmax time taken,  0.00867915153503418
# total size: 10 3375000 = 33750000
# num batches:  1
# assembling the mass matrix time taken:  0.00133514404296875
# solving Ax = b time taken:  0.014754295349121094
# l2 error 0.187877, h1 error 2.161263
# epoch:  11	argmax batch num,  4
# argmax time taken,  0.008779764175415039
# total size: 11 3375000 = 37125000
# num batches:  1
# assembling the mass matrix time taken:  0.0013151168823242188
# solving Ax = b time taken:  0.015609502792358398
# l2 error 0.172705, h1 error 2.118464
# epoch:  12	argmax batch num,  4
# argmax time taken,  0.008903980255126953
# total size: 12 3375000 = 40500000
# num batches:  1
# assembling the mass matrix time taken:  0.0014033317565917969
# solving Ax = b time taken:  0.016771316528320312
# l2 error 0.162997, h1 error 2.034559
# epoch:  13	argmax batch num,  4
# argmax time taken,  0.00894927978515625
# total size: 13 3375000 = 43875000
# num batches:  1
# assembling the mass matrix time taken:  0.0013322830200195312
# solving Ax = b time taken:  0.01775050163269043
# l2 error 0.129453, h1 error 1.781797
# epoch:  14	argmax batch num,  4
# argmax time taken,  0.009205341339111328
# total size: 14 3375000 = 47250000
# num batches:  1
# assembling the mass matrix time taken:  0.00136566162109375
# solving Ax = b time taken:  0.018224000930786133
# l2 error 0.116022, h1 error 1.686829
# epoch:  15	argmax batch num,  4
# argmax time taken,  0.009299993515014648
# total size: 15 3375000 = 50625000
# num batches:  1
# assembling the mass matrix time taken:  0.0013267993927001953
# solving Ax = b time taken:  0.019101381301879883
# l2 error 0.108514, h1 error 1.621651
# epoch:  16	argmax batch num,  4
# argmax time taken,  0.009467363357543945
# total size: 16 3375000 = 54000000
# num batches:  1
# assembling the mass matrix time taken:  0.0013535022735595703
# solving Ax = b time taken:  0.019944190979003906
# l2 error 0.095728, h1 error 1.543874
# epoch:  17	argmax batch num,  4
# argmax time taken,  0.009299278259277344
# total size: 17 3375000 = 57375000
# num batches:  1
# assembling the mass matrix time taken:  0.0013194084167480469
# solving Ax = b time taken:  0.021651744842529297
# l2 error 0.094719, h1 error 1.537923
# epoch:  18	argmax batch num,  4
# argmax time taken,  0.009668111801147461
# total size: 18 3375000 = 60750000
# num batches:  1
# assembling the mass matrix time taken:  0.001375436782836914
# solving Ax = b time taken:  0.02257513999938965
# l2 error 0.093955, h1 error 1.532525
# epoch:  19	argmax batch num,  4
# argmax time taken,  0.009648323059082031
# total size: 19 3375000 = 64125000
# num batches:  1
# assembling the mass matrix time taken:  0.0013475418090820312
# solving Ax = b time taken:  0.02344512939453125
# l2 error 0.092863, h1 error 1.520444
# epoch:  20	argmax batch num,  4
# argmax time taken,  0.009873628616333008
# total size: 20 3375000 = 67500000
# num batches:  1
# assembling the mass matrix time taken:  0.0013575553894042969
# solving Ax = b time taken:  0.0242769718170166
# l2 error 0.091991, h1 error 1.508590
# epoch:  21	argmax batch num,  4
# argmax time taken,  0.009774923324584961
# total size: 21 3375000 = 70875000
# num batches:  1
# assembling the mass matrix time taken:  0.0013246536254882812
# solving Ax = b time taken:  0.02533435821533203
# l2 error 0.086021, h1 error 1.449716
# epoch:  22	argmax batch num,  4
# argmax time taken,  0.010072708129882812
# total size: 22 3375000 = 74250000
# num batches:  1
# assembling the mass matrix time taken:  0.0013492107391357422
# solving Ax = b time taken:  0.02618408203125
# l2 error 0.082114, h1 error 1.398210
# epoch:  23	argmax batch num,  4
# argmax time taken,  0.010125160217285156
# total size: 23 3375000 = 77625000
# num batches:  1
# assembling the mass matrix time taken:  0.0013778209686279297
# solving Ax = b time taken:  0.027050495147705078
# l2 error 0.076532, h1 error 1.339954
# epoch:  24	argmax batch num,  4
# argmax time taken,  0.010351896286010742
# total size: 24 3375000 = 81000000
# num batches:  1
# assembling the mass matrix time taken:  0.0013267993927001953
# solving Ax = b time taken:  0.027817249298095703
# l2 error 0.070369, h1 error 1.253819
# epoch:  25	argmax batch num,  4
# argmax time taken,  0.010174274444580078
# total size: 25 3375000 = 84375000
# num batches:  1
# assembling the mass matrix time taken:  0.0013327598571777344
# solving Ax = b time taken:  0.0289459228515625
# l2 error 0.063009, h1 error 1.103994
# epoch:  26	argmax batch num,  4
# argmax time taken,  0.010548114776611328
# total size: 26 3375000 = 87750000
# num batches:  1
# assembling the mass matrix time taken:  0.0013532638549804688
# solving Ax = b time taken:  0.029773712158203125
# l2 error 0.050355, h1 error 0.949346
# epoch:  27	argmax batch num,  4
# argmax time taken,  0.010632514953613281
# total size: 27 3375000 = 91125000
# num batches:  1
# assembling the mass matrix time taken:  0.0013437271118164062
# solving Ax = b time taken:  0.030675172805786133
# l2 error 0.047208, h1 error 0.905544
# epoch:  28	argmax batch num,  4
# argmax time taken,  0.011041402816772461
# total size: 28 3375000 = 94500000
# num batches:  1
# assembling the mass matrix time taken:  0.0013468265533447266
# solving Ax = b time taken:  0.031543731689453125
# l2 error 0.046016, h1 error 0.885912
# epoch:  29	argmax batch num,  4
# argmax time taken,  0.010719776153564453
# total size: 29 3375000 = 97875000
# num batches:  1
# assembling the mass matrix time taken:  0.0013341903686523438
# solving Ax = b time taken:  0.03248405456542969
# l2 error 0.043401, h1 error 0.847790
# epoch:  30	argmax batch num,  4
# argmax time taken,  0.01103973388671875
# total size: 30 3375000 = 101250000
# num batches:  1
# assembling the mass matrix time taken:  0.0013344287872314453
# solving Ax = b time taken:  0.03339648246765137
# l2 error 0.036184, h1 error 0.704985
# epoch:  31	argmax batch num,  4
# argmax time taken,  0.011007070541381836
# total size: 31 3375000 = 104625000
# num batches:  1
# assembling the mass matrix time taken:  0.001313924789428711
# solving Ax = b time taken:  0.03434038162231445
# l2 error 0.035735, h1 error 0.692044
# epoch:  32	argmax batch num,  4
# argmax time taken,  0.011472225189208984
# total size: 32 3375000 = 108000000
# num batches:  1
# assembling the mass matrix time taken:  0.0013408660888671875
# solving Ax = b time taken:  0.03499341011047363
# l2 error 0.033666, h1 error 0.661404
# epoch:  33	argmax batch num,  4
# argmax time taken,  0.011051654815673828
# total size: 33 3375000 = 111375000
# num batches:  1
# assembling the mass matrix time taken:  0.0013408660888671875
# solving Ax = b time taken:  0.037834882736206055
# l2 error 0.029557, h1 error 0.592801
# epoch:  34	argmax batch num,  4
# argmax time taken,  0.011394739151000977
# total size: 34 3375000 = 114750000
# num batches:  1
# assembling the mass matrix time taken:  0.0013391971588134766
# solving Ax = b time taken:  0.03859853744506836
# l2 error 0.026958, h1 error 0.552359
# epoch:  35	argmax batch num,  4
# argmax time taken,  0.011512279510498047
# total size: 35 3375000 = 118125000
# num batches:  1
# assembling the mass matrix time taken:  0.0013737678527832031
# solving Ax = b time taken:  0.03949618339538574
# l2 error 0.023896, h1 error 0.512556
# epoch:  36	argmax batch num,  4
# argmax time taken,  0.01203775405883789
# total size: 36 3375000 = 121500000
# num batches:  1
# assembling the mass matrix time taken:  0.0013418197631835938
# solving Ax = b time taken:  0.04022502899169922
# l2 error 0.023080, h1 error 0.500378
# epoch:  37	argmax batch num,  4
# argmax time taken,  0.011878728866577148
# total size: 37 3375000 = 124875000
# num batches:  1
# assembling the mass matrix time taken:  0.0013697147369384766
# solving Ax = b time taken:  0.041158199310302734
# l2 error 0.022393, h1 error 0.495155
# epoch:  38	argmax batch num,  4
# argmax time taken,  0.012293577194213867
# total size: 38 3375000 = 128250000
# num batches:  1
# assembling the mass matrix time taken:  0.0013375282287597656
# solving Ax = b time taken:  0.04196476936340332
# l2 error 0.021679, h1 error 0.466462
# epoch:  39	argmax batch num,  4
# argmax time taken,  0.012352705001831055
# total size: 39 3375000 = 131625000
# num batches:  1
# assembling the mass matrix time taken:  0.0013470649719238281
# solving Ax = b time taken:  0.04281735420227051
# l2 error 0.019491, h1 error 0.430081
# epoch:  40	argmax batch num,  4
# argmax time taken,  0.012433767318725586
# total size: 40 3375000 = 135000000
# num batches:  1
# assembling the mass matrix time taken:  0.0013225078582763672
# solving Ax = b time taken:  0.04347491264343262
# l2 error 0.018449, h1 error 0.405552
# epoch:  41	argmax batch num,  4
# argmax time taken,  0.012224197387695312
# total size: 41 3375000 = 138375000
# num batches:  1
# assembling the mass matrix time taken:  0.0013418197631835938
# solving Ax = b time taken:  0.044437408447265625
# l2 error 0.017113, h1 error 0.383163
# epoch:  42	argmax batch num,  4
# argmax time taken,  0.012408733367919922
# total size: 42 3375000 = 141750000
# num batches:  1
# assembling the mass matrix time taken:  0.0013477802276611328
# solving Ax = b time taken:  0.045295000076293945
# l2 error 0.016625, h1 error 0.376383
# epoch:  43	argmax batch num,  4
# argmax time taken,  0.012545585632324219
# total size: 43 3375000 = 145125000
# num batches:  1
# assembling the mass matrix time taken:  0.001360177993774414
# solving Ax = b time taken:  0.04615664482116699
# l2 error 0.015447, h1 error 0.359393
# epoch:  44	argmax batch num,  4
# argmax time taken,  0.012705564498901367
# total size: 44 3375000 = 148500000
# num batches:  1
# assembling the mass matrix time taken:  0.0013380050659179688
# solving Ax = b time taken:  0.046907663345336914
# l2 error 0.013842, h1 error 0.333743
# epoch:  45	argmax batch num,  4
# argmax time taken,  0.01271510124206543
# total size: 45 3375000 = 151875000
# num batches:  1
# assembling the mass matrix time taken:  0.0013155937194824219
# solving Ax = b time taken:  0.04788708686828613
# l2 error 0.013212, h1 error 0.319037
# epoch:  46	argmax batch num,  4
# argmax time taken,  0.012879371643066406
# total size: 46 3375000 = 155250000
# num batches:  1
# assembling the mass matrix time taken:  0.0012958049774169922
# solving Ax = b time taken:  0.04875946044921875
# l2 error 0.012519, h1 error 0.310935
# epoch:  47	argmax batch num,  4
# argmax time taken,  0.012915849685668945
# total size: 47 3375000 = 158625000
# num batches:  1
# assembling the mass matrix time taken:  0.001306772232055664
# solving Ax = b time taken:  0.04977059364318848
# l2 error 0.011059, h1 error 0.278648
# epoch:  48	argmax batch num,  4
# argmax time taken,  0.013128995895385742
# total size: 48 3375000 = 162000000
# num batches:  1
# assembling the mass matrix time taken:  0.0013070106506347656
# solving Ax = b time taken:  0.050426483154296875
# l2 error 0.010522, h1 error 0.268487
# epoch:  49	argmax batch num,  4
# argmax time taken,  0.013051271438598633
# total size: 49 3375000 = 165375000
# num batches:  1
# assembling the mass matrix time taken:  0.001310586929321289
# solving Ax = b time taken:  0.05165290832519531
# l2 error 0.009297, h1 error 0.242711
# epoch:  50	argmax batch num,  4
# argmax time taken,  0.013326883316040039
# total size: 50 3375000 = 168750000
# num batches:  1
# assembling the mass matrix time taken:  0.0012996196746826172
# solving Ax = b time taken:  0.052600860595703125
# l2 error 0.008124, h1 error 0.215697
# epoch:  51	argmax batch num,  4
# argmax time taken,  0.013309478759765625
# total size: 51 3375000 = 172125000
# num batches:  1
# assembling the mass matrix time taken:  0.001280069351196289
# solving Ax = b time taken:  0.05358409881591797
# l2 error 0.007374, h1 error 0.196500
# epoch:  52	argmax batch num,  4
# argmax time taken,  0.013507604598999023
# total size: 52 3375000 = 175500000
# num batches:  1
# assembling the mass matrix time taken:  0.0013141632080078125
# solving Ax = b time taken:  0.05441594123840332
# l2 error 0.007016, h1 error 0.188648
# epoch:  53	argmax batch num,  4
# argmax time taken,  0.013691186904907227
# total size: 53 3375000 = 178875000
# num batches:  1
# assembling the mass matrix time taken:  0.0012989044189453125
# solving Ax = b time taken:  0.0555117130279541
# l2 error 0.006618, h1 error 0.182485
# epoch:  54	argmax batch num,  4
# argmax time taken,  0.013843774795532227
# total size: 54 3375000 = 182250000
# num batches:  1
# assembling the mass matrix time taken:  0.0012917518615722656
# solving Ax = b time taken:  0.056520938873291016
# l2 error 0.006453, h1 error 0.178953
# epoch:  55	argmax batch num,  4
# argmax time taken,  0.01387786865234375
# total size: 55 3375000 = 185625000
# num batches:  1
# assembling the mass matrix time taken:  0.0012655258178710938
# solving Ax = b time taken:  0.05754899978637695
# l2 error 0.006227, h1 error 0.174468
# epoch:  56	argmax batch num,  4
# argmax time taken,  0.014023303985595703
# total size: 56 3375000 = 189000000
# num batches:  1
# assembling the mass matrix time taken:  0.0012755393981933594
# solving Ax = b time taken:  0.05833005905151367
# l2 error 0.006119, h1 error 0.166441
# epoch:  57	argmax batch num,  4
# argmax time taken,  0.013962984085083008
# total size: 57 3375000 = 192375000
# num batches:  1
# assembling the mass matrix time taken:  0.001283407211303711
# solving Ax = b time taken:  0.059623003005981445
# l2 error 0.005881, h1 error 0.162672
# epoch:  58	argmax batch num,  4
# argmax time taken,  0.014299154281616211
# total size: 58 3375000 = 195750000
# num batches:  1
# assembling the mass matrix time taken:  0.0012903213500976562
# solving Ax = b time taken:  0.060533761978149414
# l2 error 0.005680, h1 error 0.155429
# epoch:  59	argmax batch num,  4
# argmax time taken,  0.014383554458618164
# total size: 59 3375000 = 199125000
# num batches:  1
# assembling the mass matrix time taken:  0.0012927055358886719
# solving Ax = b time taken:  0.061615705490112305
# l2 error 0.005652, h1 error 0.152224
# epoch:  60	argmax batch num,  4
# argmax time taken,  0.014597177505493164
# total size: 60 3375000 = 202500000
# num batches:  1
# assembling the mass matrix time taken:  0.0013132095336914062
# solving Ax = b time taken:  0.06240725517272949
# l2 error 0.005341, h1 error 0.148156
# epoch:  61	argmax batch num,  4
# argmax time taken,  0.014693021774291992
# total size: 61 3375000 = 205875000
# num batches:  1
# assembling the mass matrix time taken:  0.001285552978515625
# solving Ax = b time taken:  0.06358218193054199
# l2 error 0.005141, h1 error 0.143120
# epoch:  62	argmax batch num,  4
# argmax time taken,  0.01475977897644043
# total size: 62 3375000 = 209250000
# num batches:  1
# assembling the mass matrix time taken:  0.001264333724975586
# solving Ax = b time taken:  0.06447863578796387
# l2 error 0.005049, h1 error 0.141966
# epoch:  63	argmax batch num,  4
# argmax time taken,  0.014801263809204102
# total size: 63 3375000 = 212625000
# num batches:  1
# assembling the mass matrix time taken:  0.001291036605834961
# solving Ax = b time taken:  0.06549692153930664
# l2 error 0.004946, h1 error 0.139728
# epoch:  64	argmax batch num,  4
# argmax time taken,  0.015197038650512695
# total size: 64 3375000 = 216000000
# num batches:  1
# assembling the mass matrix time taken:  0.0013914108276367188
# solving Ax = b time taken:  0.06596779823303223
# l2 error 0.004313, h1 error 0.123774
# epoch:  65	argmax batch num,  4
# argmax time taken,  0.014883756637573242
# total size: 65 3375000 = 219375000
# num batches:  1
# assembling the mass matrix time taken:  0.002452373504638672
# solving Ax = b time taken:  0.08246493339538574
# l2 error 0.004204, h1 error 0.121599
# epoch:  66	argmax batch num,  4
# argmax time taken,  0.015760421752929688
# total size: 66 3375000 = 222750000
# num batches:  1
# assembling the mass matrix time taken:  0.0022134780883789062
# solving Ax = b time taken:  0.07950854301452637
# l2 error 0.004164, h1 error 0.119376
# epoch:  67	argmax batch num,  4
# argmax time taken,  0.015871286392211914
# total size: 67 3375000 = 226125000
# num batches:  1
# assembling the mass matrix time taken:  0.002062559127807617
# solving Ax = b time taken:  0.08594250679016113
# l2 error 0.004109, h1 error 0.116862
# epoch:  68	argmax batch num,  4
# argmax time taken,  0.01601552963256836
# total size: 68 3375000 = 229500000
# num batches:  1
# assembling the mass matrix time taken:  0.0021736621856689453
# solving Ax = b time taken:  0.08112812042236328
# l2 error 0.003961, h1 error 0.114201
# epoch:  69	argmax batch num,  4
# argmax time taken,  0.016290903091430664
# total size: 69 3375000 = 232875000
# num batches:  1
# assembling the mass matrix time taken:  0.002084970474243164
# solving Ax = b time taken:  0.08828854560852051
# l2 error 0.003909, h1 error 0.112693
# epoch:  70	argmax batch num,  4
# argmax time taken,  0.016396760940551758
# total size: 70 3375000 = 236250000
# num batches:  1
# assembling the mass matrix time taken:  0.002165555953979492
# solving Ax = b time taken:  0.0829169750213623
# l2 error 0.003787, h1 error 0.110145
# epoch:  71	argmax batch num,  4
# argmax time taken,  0.016369104385375977
# total size: 71 3375000 = 239625000
# num batches:  1
# assembling the mass matrix time taken:  0.0020449161529541016
# solving Ax = b time taken:  0.09064745903015137
# l2 error 0.003669, h1 error 0.107757
# epoch:  72	argmax batch num,  4
# argmax time taken,  0.016503095626831055
# total size: 72 3375000 = 243000000
# num batches:  1
# assembling the mass matrix time taken:  0.0021321773529052734
# solving Ax = b time taken:  0.08423066139221191
# l2 error 0.003586, h1 error 0.104817
# epoch:  73	argmax batch num,  4
# argmax time taken,  0.016431093215942383
# total size: 73 3375000 = 246375000
# num batches:  1
# assembling the mass matrix time taken:  0.0020596981048583984
# solving Ax = b time taken:  0.09285497665405273
# l2 error 0.003524, h1 error 0.103124
# epoch:  74	argmax batch num,  4
# argmax time taken,  0.01667642593383789
# total size: 74 3375000 = 249750000
# num batches:  1
# assembling the mass matrix time taken:  0.002131223678588867
# solving Ax = b time taken:  0.08636474609375
# l2 error 0.003413, h1 error 0.100255
# epoch:  75	argmax batch num,  4
# argmax time taken,  0.0167238712310791
# total size: 75 3375000 = 253125000
# num batches:  1
# assembling the mass matrix time taken:  0.22243118286132812
# solving Ax = b time taken:  0.06190848350524902
# l2 error 0.003344, h1 error 0.099171
# epoch:  76	argmax batch num,  4
# argmax time taken,  0.017368316650390625
# total size: 76 3375000 = 256500000
# num batches:  1
# assembling the mass matrix time taken:  0.0056438446044921875
# solving Ax = b time taken:  0.08603453636169434
# l2 error 0.003259, h1 error 0.097082
# epoch:  77	argmax batch num,  4
# argmax time taken,  0.017389774322509766
# total size: 77 3375000 = 259875000
# num batches:  1
# assembling the mass matrix time taken:  0.16759657859802246
# solving Ax = b time taken:  0.07508373260498047
# l2 error 0.003203, h1 error 0.096044
# epoch:  78	argmax batch num,  4
# argmax time taken,  0.017348766326904297
# total size: 78 3375000 = 263250000
# num batches:  1
# assembling the mass matrix time taken:  0.0021185874938964844
# solving Ax = b time taken:  0.0898287296295166
# l2 error 0.003116, h1 error 0.094005
# epoch:  79	argmax batch num,  4
# argmax time taken,  0.01732015609741211
# total size: 79 3375000 = 266625000
# num batches:  1
# assembling the mass matrix time taken:  0.0021038055419921875
# solving Ax = b time taken:  0.10047650337219238
# l2 error 0.003037, h1 error 0.092533
# epoch:  80	argmax batch num,  4
# argmax time taken,  0.017524242401123047
# total size: 80 3375000 = 270000000
# num batches:  1
# assembling the mass matrix time taken:  0.002260446548461914
# solving Ax = b time taken:  0.09082770347595215
# l2 error 0.002929, h1 error 0.090195
# epoch:  81	argmax batch num,  4
# argmax time taken,  0.01766037940979004
# total size: 81 3375000 = 273375000
# num batches:  1
# assembling the mass matrix time taken:  0.002198934555053711
# solving Ax = b time taken:  0.10194516181945801
# l2 error 0.002830, h1 error 0.087107
# epoch:  82	argmax batch num,  4
# argmax time taken,  0.017972946166992188
# total size: 82 3375000 = 276750000
# num batches:  1
# assembling the mass matrix time taken:  0.0023055076599121094
# solving Ax = b time taken:  0.09444475173950195
# l2 error 0.002710, h1 error 0.084643
# epoch:  83	argmax batch num,  4
# argmax time taken,  0.018140077590942383
# total size: 83 3375000 = 280125000
# num batches:  1
# assembling the mass matrix time taken:  0.18130993843078613
# solving Ax = b time taken:  0.08362412452697754
# l2 error 0.002651, h1 error 0.082746
# epoch:  84	argmax batch num,  4
# argmax time taken,  0.018328428268432617
# total size: 84 3375000 = 283500000
# num batches:  1
# assembling the mass matrix time taken:  0.2509801387786865
# solving Ax = b time taken:  0.05535626411437988
# l2 error 0.002550, h1 error 0.081211
# epoch:  85	argmax batch num,  4
# argmax time taken,  0.018823623657226562
# total size: 85 3375000 = 286875000
# num batches:  1
# assembling the mass matrix time taken:  0.005909919738769531
# solving Ax = b time taken:  0.11166191101074219
# l2 error 0.002488, h1 error 0.079409
# epoch:  86	argmax batch num,  4
# argmax time taken,  0.019123315811157227
# total size: 86 3375000 = 290250000
# num batches:  1
# assembling the mass matrix time taken:  0.005903959274291992
# solving Ax = b time taken:  0.1018378734588623
# l2 error 0.002426, h1 error 0.077522
# epoch:  87	argmax batch num,  4
# argmax time taken,  0.018832683563232422
# total size: 87 3375000 = 293625000
# num batches:  1
# assembling the mass matrix time taken:  0.0022306442260742188
# solving Ax = b time taken:  0.11133313179016113
# l2 error 0.002323, h1 error 0.074280
# epoch:  88	argmax batch num,  4
# argmax time taken,  0.019164562225341797
# total size: 88 3375000 = 297000000
# num batches:  1
# assembling the mass matrix time taken:  0.0022673606872558594
# solving Ax = b time taken:  0.10933065414428711
# l2 error 0.002269, h1 error 0.072489
# epoch:  89	argmax batch num,  4
# argmax time taken,  0.019204139709472656
# total size: 89 3375000 = 300375000
# num batches:  1
# assembling the mass matrix time taken:  0.12090635299682617
# solving Ax = b time taken:  0.0874180793762207
# l2 error 0.002145, h1 error 0.069526
# epoch:  90	argmax batch num,  4
# argmax time taken,  0.01916050910949707
# total size: 90 3375000 = 303750000
# num batches:  1
# assembling the mass matrix time taken:  0.0023126602172851562
# solving Ax = b time taken:  0.11219906806945801
# l2 error 0.002084, h1 error 0.067631
# epoch:  91	argmax batch num,  4
# argmax time taken,  0.019605159759521484
# total size: 91 3375000 = 307125000
# num batches:  1
# assembling the mass matrix time taken:  0.002330780029296875
# solving Ax = b time taken:  0.11259222030639648
# l2 error 0.002002, h1 error 0.064994
# epoch:  92	argmax batch num,  4
# argmax time taken,  0.019489049911499023
# total size: 92 3375000 = 310500000
# num batches:  1
# assembling the mass matrix time taken:  0.2928042411804199
# solving Ax = b time taken:  0.06045341491699219
# l2 error 0.001948, h1 error 0.063992
# epoch:  93	argmax batch num,  4
# argmax time taken,  0.02001166343688965
# total size: 93 3375000 = 313875000
# num batches:  1
# assembling the mass matrix time taken:  0.0063953399658203125
# solving Ax = b time taken:  0.11511683464050293
# l2 error 0.001898, h1 error 0.062263
# epoch:  94	argmax batch num,  4
# argmax time taken,  0.020126819610595703
# total size: 94 3375000 = 317250000
# num batches:  1
# assembling the mass matrix time taken:  0.005449771881103516
# solving Ax = b time taken:  0.11117339134216309
# l2 error 0.001853, h1 error 0.061319
# epoch:  95	argmax batch num,  4
# argmax time taken,  0.0198209285736084
# total size: 95 3375000 = 320625000
# num batches:  1
# assembling the mass matrix time taken:  0.0023162364959716797
# solving Ax = b time taken:  0.1149909496307373
# l2 error 0.001790, h1 error 0.060473
# epoch:  96	argmax batch num,  4
# argmax time taken,  0.019987106323242188
# total size: 96 3375000 = 324000000
# num batches:  1
# assembling the mass matrix time taken:  0.0023145675659179688
# solving Ax = b time taken:  0.10947060585021973
# l2 error 0.001730, h1 error 0.058914
# epoch:  97	argmax batch num,  4
# argmax time taken,  0.019956588745117188
# total size: 97 3375000 = 327375000
# num batches:  1
# assembling the mass matrix time taken:  0.0022804737091064453
# solving Ax = b time taken:  0.11156225204467773
# l2 error 0.001705, h1 error 0.058452
# epoch:  98	argmax batch num,  4
# argmax time taken,  0.02007269859313965
# total size: 98 3375000 = 330750000
# num batches:  1
# assembling the mass matrix time taken:  0.002315998077392578
# solving Ax = b time taken:  0.11270999908447266
# l2 error 0.001658, h1 error 0.057436
# epoch:  99	argmax batch num,  4
# argmax time taken,  0.020312070846557617
# total size: 99 3375000 = 334125000
# num batches:  1
# assembling the mass matrix time taken:  0.18729114532470703
# solving Ax = b time taken:  0.05980348587036133
# l2 error 0.001643, h1 error 0.057157
# epoch:  100	argmax batch num,  4
# argmax time taken,  0.020939111709594727
# total size: 100 3375000 = 337500000
# num batches:  1
# assembling the mass matrix time taken:  0.0061070919036865234
# solving Ax = b time taken:  0.11242341995239258
# l2 error 0.001596, h1 error 0.056142
# epoch:  101	argmax batch num,  4
# argmax time taken,  0.02093338966369629
# total size: 101 3375000 = 340875000
# num batches:  1
# assembling the mass matrix time taken:  0.005703926086425781
# solving Ax = b time taken:  0.11173343658447266
# l2 error 0.001583, h1 error 0.055585
# epoch:  102	argmax batch num,  4
# argmax time taken,  0.020816326141357422
# total size: 102 3375000 = 344250000
# num batches:  1
# assembling the mass matrix time taken:  0.0023527145385742188
# solving Ax = b time taken:  0.11610007286071777
# l2 error 0.001550, h1 error 0.054588
# epoch:  103	argmax batch num,  4
# argmax time taken,  0.020886659622192383
# total size: 103 3375000 = 347625000
# num batches:  1
# assembling the mass matrix time taken:  0.0023703575134277344
# solving Ax = b time taken:  0.11747980117797852
# l2 error 0.001512, h1 error 0.053199
# epoch:  104	argmax batch num,  4
# argmax time taken,  0.021056652069091797
# total size: 104 3375000 = 351000000
# num batches:  1
# assembling the mass matrix time taken:  0.0023534297943115234
# solving Ax = b time taken:  0.1173865795135498
# l2 error 0.001486, h1 error 0.052610
# epoch:  105	argmax batch num,  4
# argmax time taken,  0.020953893661499023
# total size: 105 3375000 = 354375000
# num batches:  1
# assembling the mass matrix time taken:  0.0030727386474609375
# solving Ax = b time taken:  0.11831402778625488
# l2 error 0.001476, h1 error 0.052076
# epoch:  106	argmax batch num,  4
# argmax time taken,  0.021214723587036133
# total size: 106 3375000 = 357750000
# num batches:  1
# assembling the mass matrix time taken:  0.32583189010620117
# solving Ax = b time taken:  0.06338858604431152
# l2 error 0.001444, h1 error 0.051310
# epoch:  107	argmax batch num,  4
# argmax time taken,  0.021860122680664062
# total size: 107 3375000 = 361125000
# num batches:  1
# assembling the mass matrix time taken:  0.00707554817199707
# solving Ax = b time taken:  0.1188662052154541
# l2 error 0.001386, h1 error 0.049908
# epoch:  108	argmax batch num,  4
# argmax time taken,  0.021904468536376953
# total size: 108 3375000 = 364500000
# num batches:  1
# assembling the mass matrix time taken:  0.005166053771972656
# solving Ax = b time taken:  0.11852669715881348
# l2 error 0.001357, h1 error 0.049309
# epoch:  109	argmax batch num,  4
# argmax time taken,  0.021582603454589844
# total size: 109 3375000 = 367875000
# num batches:  1
# assembling the mass matrix time taken:  0.0023550987243652344
# solving Ax = b time taken:  0.12255358695983887
# l2 error 0.001338, h1 error 0.048370
# epoch:  110	argmax batch num,  4
# argmax time taken,  0.021819114685058594
# total size: 110 3375000 = 371250000
# num batches:  1
# assembling the mass matrix time taken:  0.0023941993713378906
# solving Ax = b time taken:  0.12323403358459473
# l2 error 0.001311, h1 error 0.047998
# epoch:  111	argmax batch num,  4
# argmax time taken,  0.021863222122192383
# total size: 111 3375000 = 374625000
# num batches:  1
# assembling the mass matrix time taken:  0.002347230911254883
# solving Ax = b time taken:  0.12432575225830078
# l2 error 0.001295, h1 error 0.047495
# epoch:  112	argmax batch num,  4
# argmax time taken,  0.021971702575683594
# total size: 112 3375000 = 378000000
# num batches:  1
# assembling the mass matrix time taken:  0.21081948280334473
# solving Ax = b time taken:  0.06540417671203613
# l2 error 0.001272, h1 error 0.046618
# epoch:  113	argmax batch num,  4
# argmax time taken,  0.0220792293548584
# total size: 113 3375000 = 381375000
# num batches:  1
# assembling the mass matrix time taken:  0.006775856018066406
# solving Ax = b time taken:  0.12566065788269043
# l2 error 0.001253, h1 error 0.046038
# epoch:  114	argmax batch num,  4
# argmax time taken,  0.022673845291137695
# total size: 114 3375000 = 384750000
# num batches:  1
# assembling the mass matrix time taken:  0.005387783050537109
# solving Ax = b time taken:  0.12421703338623047
# l2 error 0.001228, h1 error 0.044928
# epoch:  115	argmax batch num,  4
# argmax time taken,  0.022245407104492188
# total size: 115 3375000 = 388125000
# num batches:  1
# assembling the mass matrix time taken:  0.0023343563079833984
# solving Ax = b time taken:  0.12813162803649902
# l2 error 0.001212, h1 error 0.044027
# epoch:  116	argmax batch num,  4
# argmax time taken,  0.022429466247558594
# total size: 116 3375000 = 391500000
# num batches:  1
# assembling the mass matrix time taken:  0.0023462772369384766
# solving Ax = b time taken:  0.12861871719360352
# l2 error 0.001164, h1 error 0.042502
# epoch:  117	argmax batch num,  4
# argmax time taken,  0.022466182708740234
# total size: 117 3375000 = 394875000
# num batches:  1
# assembling the mass matrix time taken:  0.0024614334106445312
# solving Ax = b time taken:  0.12917399406433105
# l2 error 0.001124, h1 error 0.041835
# epoch:  118	argmax batch num,  4
# argmax time taken,  0.022756576538085938
# total size: 118 3375000 = 398250000
# num batches:  1
# assembling the mass matrix time taken:  0.3675224781036377
# solving Ax = b time taken:  0.06916928291320801
# l2 error 0.001097, h1 error 0.041214
# epoch:  119	argmax batch num,  4
# argmax time taken,  0.023580312728881836
# total size: 119 3375000 = 401625000
# num batches:  1
# assembling the mass matrix time taken:  0.007384777069091797
# solving Ax = b time taken:  0.1297905445098877
# l2 error 0.001080, h1 error 0.040722
# epoch:  120	argmax batch num,  4
# argmax time taken,  0.02358412742614746
# total size: 120 3375000 = 405000000
# num batches:  1
# assembling the mass matrix time taken:  0.004594087600708008
# solving Ax = b time taken:  0.12885308265686035
# l2 error 0.001068, h1 error 0.040436
# epoch:  121	argmax batch num,  4
# argmax time taken,  0.022992610931396484
# total size: 121 3375000 = 408375000
# num batches:  1
# assembling the mass matrix time taken:  0.24261832237243652
# solving Ax = b time taken:  0.10341000556945801
# l2 error 0.001049, h1 error 0.039880
# epoch:  122	argmax batch num,  4
# argmax time taken,  0.023234128952026367
# total size: 122 3375000 = 411750000
# num batches:  1
# assembling the mass matrix time taken:  0.0025789737701416016
# solving Ax = b time taken:  0.13240647315979004
# l2 error 0.001040, h1 error 0.039539
# epoch:  123	argmax batch num,  4
# argmax time taken,  0.023329973220825195
# total size: 123 3375000 = 415125000
# num batches:  1
# assembling the mass matrix time taken:  0.0032727718353271484
# solving Ax = b time taken:  0.1329329013824463
# l2 error 0.001031, h1 error 0.038948
# epoch:  124	argmax batch num,  4
# argmax time taken,  0.023456335067749023
# total size: 124 3375000 = 418500000
# num batches:  1
# assembling the mass matrix time taken:  0.5269227027893066
# solving Ax = b time taken:  0.07139921188354492
# l2 error 0.001019, h1 error 0.038503
# epoch:  125	argmax batch num,  4
# argmax time taken,  0.024055004119873047
# total size: 125 3375000 = 421875000
# num batches:  1
# assembling the mass matrix time taken:  0.007004261016845703
# solving Ax = b time taken:  0.1347641944885254
# l2 error 0.001007, h1 error 0.038283
# epoch:  126	argmax batch num,  4
# argmax time taken,  0.0242462158203125
# total size: 126 3375000 = 425250000
# num batches:  1
# assembling the mass matrix time taken:  0.003780364990234375
# solving Ax = b time taken:  0.13522100448608398
# l2 error 0.000988, h1 error 0.037752
# epoch:  127	argmax batch num,  4
# argmax time taken,  0.0244600772857666
# total size: 127 3375000 = 428625000
# num batches:  1
# assembling the mass matrix time taken:  0.0024259090423583984
# solving Ax = b time taken:  0.13711786270141602
# l2 error 0.000979, h1 error 0.037590
# epoch:  128	argmax batch num,  4
# argmax time taken,  0.024422168731689453
# total size: 128 3375000 = 432000000
# num batches:  1
# assembling the mass matrix time taken:  0.002381563186645508
# solving Ax = b time taken:  0.1364731788635254
# l2 error 0.000971, h1 error 0.037357
# epoch:  129	argmax batch num,  4
# argmax time taken,  0.02336859703063965
# total size: 129 3375000 = 435375000
# num batches:  1
# assembling the mass matrix time taken:  0.73689866065979
# solving Ax = b time taken:  0.08870458602905273
# l2 error 0.000950, h1 error 0.036404
# epoch:  130	argmax batch num,  4
# argmax time taken,  0.024867773056030273
# total size: 130 3375000 = 438750000
# num batches:  1
# assembling the mass matrix time taken:  0.06110858917236328
# solving Ax = b time taken:  0.1292128562927246
# l2 error 0.000926, h1 error 0.035350
# epoch:  131	argmax batch num,  4
# argmax time taken,  0.02428460121154785
# total size: 131 3375000 = 442125000
# num batches:  1
# assembling the mass matrix time taken:  0.008807659149169922
# solving Ax = b time taken:  0.166978120803833
# l2 error 0.000911, h1 error 0.035079
# epoch:  132	argmax batch num,  4
# argmax time taken,  0.02462005615234375
# total size: 132 3375000 = 445500000
# num batches:  1
# assembling the mass matrix time taken:  0.6696949005126953
# solving Ax = b time taken:  0.11980485916137695
# l2 error 0.000904, h1 error 0.034933
# epoch:  133	argmax batch num,  4
# argmax time taken,  0.026251792907714844
# total size: 133 3375000 = 448875000
# num batches:  1
# assembling the mass matrix time taken:  0.00823664665222168
# solving Ax = b time taken:  0.17545652389526367
# l2 error 0.000893, h1 error 0.034198
# epoch:  134	argmax batch num,  4
# argmax time taken,  0.024939775466918945
# total size: 134 3375000 = 452250000
# num batches:  1
# assembling the mass matrix time taken:  0.008117198944091797
# solving Ax = b time taken:  0.18129777908325195
# l2 error 0.000879, h1 error 0.033760
# epoch:  135	argmax batch num,  4
# argmax time taken,  0.025063753128051758
# total size: 135 3375000 = 455625000
# num batches:  1
# assembling the mass matrix time taken:  0.7773261070251465
# solving Ax = b time taken:  0.1380467414855957
# l2 error 0.000859, h1 error 0.033111
# epoch:  136	argmax batch num,  4
# argmax time taken,  0.02581000328063965
# total size: 136 3375000 = 459000000
# num batches:  1
# assembling the mass matrix time taken:  0.009091854095458984
# solving Ax = b time taken:  0.16860604286193848
# l2 error 0.000840, h1 error 0.032634
# epoch:  137	argmax batch num,  4
# argmax time taken,  0.025156736373901367
# total size: 137 3375000 = 462375000
# num batches:  1
# assembling the mass matrix time taken:  0.009066104888916016
# solving Ax = b time taken:  0.17158031463623047
# l2 error 0.000828, h1 error 0.032389
# epoch:  138	argmax batch num,  4
# argmax time taken,  0.02543950080871582
# total size: 138 3375000 = 465750000
# num batches:  1
# assembling the mass matrix time taken:  0.9420034885406494
# solving Ax = b time taken:  0.15511584281921387
# l2 error 0.000807, h1 error 0.031816
# epoch:  139	argmax batch num,  4
# argmax time taken,  0.026162385940551758
# total size: 139 3375000 = 469125000
# num batches:  1
# assembling the mass matrix time taken:  0.007550477981567383
# solving Ax = b time taken:  0.17766833305358887
# l2 error 0.000795, h1 error 0.031521
# epoch:  140	argmax batch num,  4
# argmax time taken,  0.025709152221679688
# total size: 140 3375000 = 472500000
# num batches:  1
# assembling the mass matrix time taken:  0.008331298828125
# solving Ax = b time taken:  0.1838059425354004
# l2 error 0.000784, h1 error 0.031219
# epoch:  141	argmax batch num,  4
# argmax time taken,  0.026112794876098633
# total size: 141 3375000 = 475875000
# num batches:  1
# assembling the mass matrix time taken:  1.4184648990631104
# solving Ax = b time taken:  0.0946354866027832
# l2 error 0.000780, h1 error 0.031138
# epoch:  142	argmax batch num,  4
# argmax time taken,  0.026622772216796875
# total size: 142 3375000 = 479250000
# num batches:  1
# assembling the mass matrix time taken:  0.007134675979614258
# solving Ax = b time taken:  0.19532465934753418
# l2 error 0.000776, h1 error 0.031092
# epoch:  143	argmax batch num,  4
# argmax time taken,  0.025936603546142578
# total size: 143 3375000 = 482625000
# num batches:  1
# assembling the mass matrix time taken:  0.008423566818237305
# solving Ax = b time taken:  0.17657828330993652
# l2 error 0.000759, h1 error 0.030707
# epoch:  144	argmax batch num,  4
# argmax time taken,  0.026329517364501953
# total size: 144 3375000 = 486000000
# num batches:  1
# assembling the mass matrix time taken:  1.1145052909851074
# solving Ax = b time taken:  0.09185075759887695
# l2 error 0.000744, h1 error 0.030184
# epoch:  145	argmax batch num,  4
# argmax time taken,  0.02660346031188965
# total size: 145 3375000 = 489375000
# num batches:  1
# assembling the mass matrix time taken:  0.007264852523803711
# solving Ax = b time taken:  0.18326997756958008
# l2 error 0.000732, h1 error 0.029853
# epoch:  146	argmax batch num,  4
# argmax time taken,  0.02633976936340332
# total size: 146 3375000 = 492750000
# num batches:  1
# assembling the mass matrix time taken:  0.008462190628051758
# solving Ax = b time taken:  0.17885446548461914
# l2 error 0.000711, h1 error 0.029327
# epoch:  147	argmax batch num,  4
# argmax time taken,  0.026570558547973633
# total size: 147 3375000 = 496125000
# num batches:  1
# assembling the mass matrix time taken:  1.1028318405151367
# solving Ax = b time taken:  0.09773969650268555
# l2 error 0.000704, h1 error 0.029022
# epoch:  148	argmax batch num,  4
# argmax time taken,  0.02730250358581543
# total size: 148 3375000 = 499500000
# num batches:  1
# assembling the mass matrix time taken:  0.006951570510864258
# solving Ax = b time taken:  0.1853039264678955
# l2 error 0.000688, h1 error 0.028630
# epoch:  149	argmax batch num,  4
# argmax time taken,  0.02673482894897461
# total size: 149 3375000 = 502875000
# num batches:  1
# assembling the mass matrix time taken:  0.5062499046325684
# solving Ax = b time taken:  0.10114407539367676
# l2 error 0.000671, h1 error 0.028042
# epoch:  150	argmax batch num,  4
# argmax time taken,  0.027695655822753906
# total size: 150 3375000 = 506250000
# num batches:  1
# assembling the mass matrix time taken:  0.007893085479736328
# solving Ax = b time taken:  0.18749117851257324
# l2 error 0.000658, h1 error 0.027712
# epoch:  151	argmax batch num,  4
# argmax time taken,  0.027035951614379883
# total size: 151 3375000 = 509625000
# num batches:  1
# assembling the mass matrix time taken:  0.3761863708496094
# solving Ax = b time taken:  0.10005998611450195
# l2 error 0.000655, h1 error 0.027385
# epoch:  152	argmax batch num,  4
# argmax time taken,  0.027968406677246094
# total size: 152 3375000 = 513000000
# num batches:  1
# assembling the mass matrix time taken:  0.06735539436340332
# solving Ax = b time taken:  0.1305370330810547
# l2 error 0.000641, h1 error 0.026813
# epoch:  153	argmax batch num,  4
# argmax time taken,  0.02715134620666504
# total size: 153 3375000 = 516375000
# num batches:  1
# assembling the mass matrix time taken:  0.358234167098999
# solving Ax = b time taken:  0.10162138938903809
# l2 error 0.000634, h1 error 0.026664
# epoch:  154	argmax batch num,  4
# argmax time taken,  0.02817678451538086
# total size: 154 3375000 = 519750000
# num batches:  1
# assembling the mass matrix time taken:  0.1550307273864746
# solving Ax = b time taken:  0.09865570068359375
# l2 error 0.000625, h1 error 0.026430
# epoch:  155	argmax batch num,  4
# argmax time taken,  0.02741408348083496
# total size: 155 3375000 = 523125000
# num batches:  1
# assembling the mass matrix time taken:  0.4181020259857178
# solving Ax = b time taken:  0.10487699508666992
# l2 error 0.000619, h1 error 0.026286
# epoch:  156	argmax batch num,  4
# argmax time taken,  0.028360366821289062
# total size: 156 3375000 = 526500000
# num batches:  1
# assembling the mass matrix time taken:  0.010354042053222656
# solving Ax = b time taken:  0.1893911361694336
# l2 error 0.000610, h1 error 0.026054
# epoch:  157	argmax batch num,  4
# argmax time taken,  0.02776646614074707
# total size: 157 3375000 = 529875000
# num batches:  1
# assembling the mass matrix time taken:  0.6172435283660889
# solving Ax = b time taken:  0.10598635673522949
# l2 error 0.000598, h1 error 0.025755
# epoch:  158	argmax batch num,  4
# argmax time taken,  0.02868485450744629
# total size: 158 3375000 = 533250000
# num batches:  1
# assembling the mass matrix time taken:  0.01095438003540039
# solving Ax = b time taken:  0.19076037406921387
# l2 error 0.000590, h1 error 0.025328
# epoch:  159	argmax batch num,  4
# argmax time taken,  0.028046846389770508
# total size: 159 3375000 = 536625000
# num batches:  1
# assembling the mass matrix time taken:  0.60689377784729
# solving Ax = b time taken:  0.10544586181640625
# l2 error 0.000584, h1 error 0.025201
# epoch:  160	argmax batch num,  4
# argmax time taken,  0.029035329818725586
# total size: 160 3375000 = 540000000
# num batches:  2
# assembling the mass matrix time taken:  0.002433300018310547
# solving Ax = b time taken:  0.19502663612365723
# l2 error 0.000581, h1 error 0.025078
# epoch:  161	argmax batch num,  4
# argmax time taken,  0.028133392333984375
# total size: 161 3375000 = 543375000
# num batches:  2
# assembling the mass matrix time taken:  0.0025246143341064453
# solving Ax = b time taken:  0.19664645195007324
# l2 error 0.000575, h1 error 0.024895
# epoch:  162	argmax batch num,  4
# argmax time taken,  0.028577089309692383
# total size: 162 3375000 = 546750000
# num batches:  2
# assembling the mass matrix time taken:  0.002406597137451172
# solving Ax = b time taken:  0.19898509979248047
# l2 error 0.000575, h1 error 0.024849
# epoch:  163	argmax batch num,  4
# argmax time taken,  0.02887105941772461
# total size: 163 3375000 = 550125000
# num batches:  2
# assembling the mass matrix time taken:  0.002392292022705078
# solving Ax = b time taken:  0.19871783256530762
# l2 error 0.000574, h1 error 0.024787
# epoch:  164	argmax batch num,  4
# argmax time taken,  0.6073429584503174
# total size: 164 3375000 = 553500000
# num batches:  2
# assembling the mass matrix time taken:  0.005223274230957031
# solving Ax = b time taken:  0.1975390911102295
# l2 error 0.000569, h1 error 0.024697
# epoch:  165	argmax batch num,  4
# argmax time taken,  0.02910304069519043
# total size: 165 3375000 = 556875000
# num batches:  2
# assembling the mass matrix time taken:  0.0024292469024658203
# solving Ax = b time taken:  0.19955754280090332
# l2 error 0.000570, h1 error 0.024572
# epoch:  166	argmax batch num,  4
# argmax time taken,  0.029057979583740234
# total size: 166 3375000 = 560250000
# num batches:  2
# assembling the mass matrix time taken:  0.0023980140686035156
# solving Ax = b time taken:  0.20212006568908691
# l2 error 0.000565, h1 error 0.024459
# epoch:  167	argmax batch num,  4
# argmax time taken,  0.029535770416259766
# total size: 167 3375000 = 563625000
# num batches:  2
# assembling the mass matrix time taken:  0.0024499893188476562
# solving Ax = b time taken:  0.2018885612487793
# l2 error 0.000563, h1 error 0.024421
# epoch:  168	argmax batch num,  4
# argmax time taken,  0.15986061096191406
# total size: 168 3375000 = 567000000
# num batches:  2
# assembling the mass matrix time taken:  0.0069048404693603516
# solving Ax = b time taken:  0.20387768745422363
# l2 error 0.000559, h1 error 0.024312
# epoch:  169	argmax batch num,  4
# argmax time taken,  0.0294644832611084
# total size: 169 3375000 = 570375000
# num batches:  2
# assembling the mass matrix time taken:  0.0024292469024658203
# solving Ax = b time taken:  0.20341253280639648
# l2 error 0.000555, h1 error 0.024136
# epoch:  170	argmax batch num,  4
# argmax time taken,  0.029552936553955078
# total size: 170 3375000 = 573750000
# num batches:  2
# assembling the mass matrix time taken:  0.0024127960205078125
# solving Ax = b time taken:  0.20478153228759766
# l2 error 0.000542, h1 error 0.023692
# epoch:  171	argmax batch num,  4
# argmax time taken,  0.02990245819091797
# total size: 171 3375000 = 577125000
# num batches:  2
# assembling the mass matrix time taken:  0.002451181411743164
# solving Ax = b time taken:  0.20515680313110352
# l2 error 0.000537, h1 error 0.023579
# epoch:  172	argmax batch num,  4
# argmax time taken,  0.38451552391052246
# total size: 172 3375000 = 580500000
# num batches:  2
# assembling the mass matrix time taken:  0.006035327911376953
# solving Ax = b time taken:  0.20365333557128906
# l2 error 0.000525, h1 error 0.023242
# epoch:  173	argmax batch num,  4
# argmax time taken,  0.03020191192626953
# total size: 173 3375000 = 583875000
# num batches:  2
# assembling the mass matrix time taken:  0.0023813247680664062
# solving Ax = b time taken:  0.2071537971496582
# l2 error 0.000524, h1 error 0.023004
# epoch:  174	argmax batch num,  4
# argmax time taken,  0.030103206634521484
# total size: 174 3375000 = 587250000
# num batches:  2
# assembling the mass matrix time taken:  0.002396821975708008
# solving Ax = b time taken:  0.2089555263519287
# l2 error 0.000519, h1 error 0.022941
# epoch:  175	argmax batch num,  4
# argmax time taken,  0.030507564544677734
# total size: 175 3375000 = 590625000
# num batches:  2
# assembling the mass matrix time taken:  0.00243377685546875
# solving Ax = b time taken:  0.20824623107910156
# l2 error 0.000516, h1 error 0.022763
# epoch:  176	argmax batch num,  4
# argmax time taken,  0.03285408020019531
# total size: 176 3375000 = 594000000
# num batches:  2
# assembling the mass matrix time taken:  0.00680851936340332
# solving Ax = b time taken:  0.20516037940979004
# l2 error 0.000512, h1 error 0.022646
# epoch:  177	argmax batch num,  4
# argmax time taken,  0.03027796745300293
# total size: 177 3375000 = 597375000
# num batches:  2
# assembling the mass matrix time taken:  0.002393960952758789
# solving Ax = b time taken:  0.21018004417419434
# l2 error 0.000508, h1 error 0.022539
# epoch:  178	argmax batch num,  4
# argmax time taken,  0.030510902404785156
# ...
# argmax time taken,  0.1171567440032959
# total size: 458 3375000 = 1545750000
# num batches:  3
# assembling the mass matrix time taken:  0.010512828826904297
# solving Ax = b time taken:  0.7932989597320557
# l2 error 0.000078, h1 error 0.005110
# epoch:  459	argmax batch num,  4
# argmax time taken,  0.07407808303833008
# total size: 459 3375000 = 1549125000
# num batches:  3
# assembling the mass matrix time taken:  0.010107755661010742
# solving Ax = b time taken:  0.785332441329956
# l2 error 0.000078, h1 error 0.005088
# epoch:  460	argmax batch num,  4
# argmax time taken,  0.07382822036743164
# total size: 460 3375000 = 1552500000
# num batches:  3
# assembling the mass matrix time taken:  0.010565519332885742
# solving Ax = b time taken:  0.7722632884979248
# l2 error 0.000078, h1 error 0.005084
# epoch:  461	argmax batch num,  4
# argmax time taken,  0.07303404808044434
# total size: 461 3375000 = 1555875000
# num batches:  3
# assembling the mass matrix time taken:  0.010335683822631836
# solving Ax = b time taken:  0.7862858772277832
# l2 error 0.000078, h1 error 0.005079
# epoch:  462	argmax batch num,  4
# argmax time taken,  0.07445478439331055
# total size: 462 3375000 = 1559250000
# num batches:  3
# assembling the mass matrix time taken:  0.010364770889282227
# solving Ax = b time taken:  0.7980732917785645
# l2 error 0.000078, h1 error 0.005072
# epoch:  463	argmax batch num,  4
# argmax time taken,  0.0747532844543457
# total size: 463 3375000 = 1562625000
# num batches:  3
# assembling the mass matrix time taken:  0.010434865951538086
# solving Ax = b time taken:  0.7869634628295898
# l2 error 0.000078, h1 error 0.005067
# epoch:  464	argmax batch num,  4
# argmax time taken,  0.07487201690673828
# total size: 464 3375000 = 1566000000
# num batches:  3
# assembling the mass matrix time taken:  0.003743410110473633
# solving Ax = b time taken:  0.7678267955780029
# l2 error 0.000077, h1 error 0.005048
# epoch:  465	argmax batch num,  4
# argmax time taken,  0.3636655807495117
# total size: 465 3375000 = 1569375000
# num batches:  3
# assembling the mass matrix time taken:  0.0035965442657470703
# solving Ax = b time taken:  0.7884268760681152
# l2 error 0.000077, h1 error 0.005038
# epoch:  466	argmax batch num,  4
# argmax time taken,  0.07528948783874512
# total size: 466 3375000 = 1572750000
# num batches:  3
# assembling the mass matrix time taken:  0.010573387145996094
# solving Ax = b time taken:  0.8024883270263672
# l2 error 0.000077, h1 error 0.005032
# epoch:  467	argmax batch num,  4
# argmax time taken,  0.07513928413391113
# total size: 467 3375000 = 1576125000
# num batches:  3
# assembling the mass matrix time taken:  0.003642559051513672
# solving Ax = b time taken:  0.7913105487823486
# l2 error 0.000076, h1 error 0.004988
# epoch:  468	argmax batch num,  4
# argmax time taken,  0.07526993751525879
# total size: 468 3375000 = 1579500000
# num batches:  3
# assembling the mass matrix time taken:  0.010406494140625
# solving Ax = b time taken:  0.7825906276702881
# l2 error 0.000075, h1 error 0.004946
# epoch:  469	argmax batch num,  4
# argmax time taken,  0.07641077041625977
# total size: 469 3375000 = 1582875000
# num batches:  3
# assembling the mass matrix time taken:  0.010253429412841797
# solving Ax = b time taken:  0.7936837673187256
# l2 error 0.000075, h1 error 0.004929
# epoch:  470	argmax batch num,  4
# argmax time taken,  0.0758216381072998
# total size: 470 3375000 = 1586250000
# num batches:  3
# assembling the mass matrix time taken:  0.010269403457641602
# solving Ax = b time taken:  0.8055486679077148
# l2 error 0.000075, h1 error 0.004923
# epoch:  471	argmax batch num,  4
# argmax time taken,  0.07613825798034668
# total size: 471 3375000 = 1589625000
# num batches:  3
# assembling the mass matrix time taken:  0.010448217391967773
# solving Ax = b time taken:  0.7947399616241455
# l2 error 0.000075, h1 error 0.004903
# epoch:  472	argmax batch num,  4
# argmax time taken,  0.0764625072479248
# total size: 472 3375000 = 1593000000
# num batches:  3
# assembling the mass matrix time taken:  0.010560035705566406
# solving Ax = b time taken:  0.7801315784454346
# l2 error 0.000074, h1 error 0.004859
# epoch:  473	argmax batch num,  4
# argmax time taken,  0.07647275924682617
# total size: 473 3375000 = 1596375000
# num batches:  3
# assembling the mass matrix time taken:  0.010056495666503906
# solving Ax = b time taken:  0.796628475189209
# l2 error 0.000074, h1 error 0.004850
# epoch:  474	argmax batch num,  4
# argmax time taken,  0.07631373405456543
# total size: 474 3375000 = 1599750000
# num batches:  3
# assembling the mass matrix time taken:  0.003926515579223633
# solving Ax = b time taken:  0.8085503578186035
# l2 error 0.000073, h1 error 0.004834
# epoch:  475	argmax batch num,  4
# argmax time taken,  0.07664322853088379
# total size: 475 3375000 = 1603125000
# num batches:  3
# assembling the mass matrix time taken:  0.0038928985595703125
# solving Ax = b time taken:  0.7984504699707031
# l2 error 0.000073, h1 error 0.004823
# epoch:  476	argmax batch num,  4
# argmax time taken,  0.07490968704223633
# total size: 476 3375000 = 1606500000
# num batches:  3
# assembling the mass matrix time taken:  0.003608226776123047
# solving Ax = b time taken:  0.7998392581939697
# l2 error 0.000073, h1 error 0.004813
# epoch:  477	argmax batch num,  4
# argmax time taken,  0.07742667198181152
# total size: 477 3375000 = 1609875000
# num batches:  3
# assembling the mass matrix time taken:  0.010204553604125977
# solving Ax = b time taken:  0.7993357181549072
# l2 error 0.000073, h1 error 0.004791
# epoch:  478	argmax batch num,  4
# argmax time taken,  0.0769350528717041
# total size: 478 3375000 = 1613250000
# num batches:  4
# assembling the mass matrix time taken:  0.011113882064819336
# solving Ax = b time taken:  0.8044393062591553
# l2 error 0.000072, h1 error 0.004781
# epoch:  479	argmax batch num,  4
# argmax time taken,  0.07686328887939453
# total size: 479 3375000 = 1616625000
# num batches:  4
# assembling the mass matrix time taken:  0.011357307434082031
# solving Ax = b time taken:  0.7976834774017334
# l2 error 0.000072, h1 error 0.004765
# epoch:  480	argmax batch num,  4
# argmax time taken,  0.07717347145080566
# total size: 480 3375000 = 1620000000
# num batches:  4
# assembling the mass matrix time taken:  0.011239767074584961
# solving Ax = b time taken:  0.8052480220794678
# l2 error 0.000072, h1 error 0.004760
# epoch:  481	argmax batch num,  4
# argmax time taken,  0.07681870460510254
# total size: 481 3375000 = 1623375000
# num batches:  4
# assembling the mass matrix time taken:  0.004685878753662109
# solving Ax = b time taken:  0.8017399311065674
# l2 error 0.000072, h1 error 0.004752
# epoch:  482	argmax batch num,  4
# argmax time taken,  0.07745742797851562
# total size: 482 3375000 = 1626750000
# num batches:  4
# assembling the mass matrix time taken:  0.010957002639770508
# solving Ax = b time taken:  0.799781084060669
# l2 error 0.000072, h1 error 0.004745
# epoch:  483	argmax batch num,  4
# argmax time taken,  0.07552957534790039
# total size: 483 3375000 = 1630125000
# num batches:  4
# assembling the mass matrix time taken:  0.0045623779296875
# solving Ax = b time taken:  0.8016815185546875
# l2 error 0.000072, h1 error 0.004731
# epoch:  484	argmax batch num,  4
# argmax time taken,  0.07561087608337402
# total size: 484 3375000 = 1633500000
# num batches:  4
# assembling the mass matrix time taken:  0.004469394683837891
# solving Ax = b time taken:  0.806119441986084
# l2 error 0.000071, h1 error 0.004711
# epoch:  485	argmax batch num,  4
# argmax time taken,  0.08466219902038574
# total size: 485 3375000 = 1636875000
# num batches:  4
# assembling the mass matrix time taken:  0.011265754699707031
# solving Ax = b time taken:  0.8045501708984375
# l2 error 0.000071, h1 error 0.004692
# epoch:  486	argmax batch num,  4
# argmax time taken,  0.0778501033782959
# total size: 486 3375000 = 1640250000
# num batches:  4
# assembling the mass matrix time taken:  0.00448298454284668
# solving Ax = b time taken:  0.8045799732208252
# l2 error 0.000070, h1 error 0.004677
# epoch:  487	argmax batch num,  4
# argmax time taken,  0.07768630981445312
# total size: 487 3375000 = 1643625000
# num batches:  4
# assembling the mass matrix time taken:  0.0045299530029296875
# solving Ax = b time taken:  0.8054826259613037
# l2 error 0.000070, h1 error 0.004668
# epoch:  488	argmax batch num,  4
# argmax time taken,  0.07797741889953613
# total size: 488 3375000 = 1647000000
# num batches:  4
# assembling the mass matrix time taken:  0.004499197006225586
# solving Ax = b time taken:  0.8076610565185547
# l2 error 0.000070, h1 error 0.004660
# epoch:  489	argmax batch num,  4
# argmax time taken,  0.07841944694519043
# total size: 489 3375000 = 1650375000
# num batches:  4
# assembling the mass matrix time taken:  0.009078502655029297
# solving Ax = b time taken:  0.8071703910827637
# l2 error 0.000070, h1 error 0.004653
# epoch:  490	argmax batch num,  4
# argmax time taken,  0.07829070091247559
# total size: 490 3375000 = 1653750000
# num batches:  4
# assembling the mass matrix time taken:  0.011005163192749023
# solving Ax = b time taken:  0.8076202869415283
# l2 error 0.000070, h1 error 0.004642
# epoch:  491	argmax batch num,  4
# argmax time taken,  0.08140707015991211
# total size: 491 3375000 = 1657125000
# num batches:  4
# assembling the mass matrix time taken:  0.011159658432006836
# solving Ax = b time taken:  0.8101785182952881
# l2 error 0.000069, h1 error 0.004626
# epoch:  492	argmax batch num,  4
# argmax time taken,  0.07673907279968262
# total size: 492 3375000 = 1660500000
# num batches:  4
# assembling the mass matrix time taken:  0.011013507843017578
# solving Ax = b time taken:  0.8099699020385742
# l2 error 0.000069, h1 error 0.004615
# epoch:  493	argmax batch num,  4
# argmax time taken,  0.0794837474822998
# total size: 493 3375000 = 1663875000
# num batches:  4
# assembling the mass matrix time taken:  0.010980606079101562
# solving Ax = b time taken:  0.8123819828033447
# l2 error 0.000069, h1 error 0.004604
# epoch:  494	argmax batch num,  4
# argmax time taken,  0.07898712158203125
# total size: 494 3375000 = 1667250000
# num batches:  4
# assembling the mass matrix time taken:  0.004452228546142578
# solving Ax = b time taken:  0.8113579750061035
# l2 error 0.000069, h1 error 0.004592
# epoch:  495	argmax batch num,  4
# argmax time taken,  0.07902646064758301
# total size: 495 3375000 = 1670625000
# num batches:  4
# assembling the mass matrix time taken:  0.004599332809448242
# solving Ax = b time taken:  0.8139126300811768
# l2 error 0.000068, h1 error 0.004565
# epoch:  496	argmax batch num,  4
# argmax time taken,  0.07909893989562988
# total size: 496 3375000 = 1674000000
# num batches:  4
# assembling the mass matrix time taken:  0.010969877243041992
# solving Ax = b time taken:  0.8154928684234619
# l2 error 0.000068, h1 error 0.004552
# epoch:  497	argmax batch num,  4
# argmax time taken,  0.07945132255554199
# total size: 497 3375000 = 1677375000
# num batches:  4
# assembling the mass matrix time taken:  0.011518239974975586
# solving Ax = b time taken:  0.8149175643920898
# l2 error 0.000067, h1 error 0.004520
# epoch:  498	argmax batch num,  4
# argmax time taken,  0.07925176620483398
# total size: 498 3375000 = 1680750000
# num batches:  4
# assembling the mass matrix time taken:  0.004515409469604492
# solving Ax = b time taken:  0.8124034404754639
# l2 error 0.000067, h1 error 0.004513
# epoch:  499	argmax batch num,  4
# argmax time taken,  0.07947373390197754
# total size: 499 3375000 = 1684125000
# num batches:  4
# assembling the mass matrix time taken:  0.01109933853149414
# solving Ax = b time taken:  0.8167405128479004
# l2 error 0.000067, h1 error 0.004505
# epoch:  500	argmax batch num,  4
# argmax time taken,  0.07981443405151367
# total size: 500 3375000 = 1687500000
# num batches:  4
# assembling the mass matrix time taken:  0.011109352111816406
# solving Ax = b time taken:  0.8206348419189453
# l2 error 0.000067, h1 error 0.004483
# epoch:  501	argmax batch num,  4
# argmax time taken,  0.08024168014526367
# total size: 501 3375000 = 1690875000
# num batches:  4
# assembling the mass matrix time taken:  0.00484919548034668
# solving Ax = b time taken:  0.8179736137390137
# l2 error 0.000066, h1 error 0.004473
# epoch:  502	argmax batch num,  4
# argmax time taken,  0.07980155944824219
# total size: 502 3375000 = 1694250000
# num batches:  4
# assembling the mass matrix time taken:  0.011074542999267578
# solving Ax = b time taken:  0.8163228034973145
# l2 error 0.000066, h1 error 0.004441
# epoch:  503	argmax batch num,  4
# argmax time taken,  0.08006930351257324
# total size: 503 3375000 = 1697625000
# num batches:  4
# assembling the mass matrix time taken:  0.01115107536315918
# solving Ax = b time taken:  0.8199150562286377
# l2 error 0.000066, h1 error 0.004437
# epoch:  504	argmax batch num,  4
# argmax time taken,  0.08018302917480469
# total size: 504 3375000 = 1701000000
# num batches:  4
# assembling the mass matrix time taken:  0.004445314407348633
# solving Ax = b time taken:  0.8230109214782715
# l2 error 0.000065, h1 error 0.004417
# epoch:  505	argmax batch num,  4
# argmax time taken,  0.18061137199401855
# total size: 505 3375000 = 1704375000
# num batches:  4
# assembling the mass matrix time taken:  0.011418819427490234
# solving Ax = b time taken:  0.8322563171386719
# l2 error 0.000065, h1 error 0.004412
# epoch:  506	argmax batch num,  4
# argmax time taken,  0.07842493057250977
# total size: 506 3375000 = 1707750000
# num batches:  4
# assembling the mass matrix time taken:  0.004502058029174805
# solving Ax = b time taken:  0.8311905860900879
# l2 error 0.000065, h1 error 0.004409
# epoch:  507	argmax batch num,  4
# argmax time taken,  0.0785224437713623
# total size: 507 3375000 = 1711125000
# num batches:  4
# assembling the mass matrix time taken:  0.0045664310455322266
# solving Ax = b time taken:  0.8326056003570557
# l2 error 0.000065, h1 error 0.004394
# epoch:  508	argmax batch num,  4
# argmax time taken,  0.07864594459533691
# total size: 508 3375000 = 1714500000
# num batches:  4
# assembling the mass matrix time taken:  0.011297941207885742
# solving Ax = b time taken:  0.8353724479675293
# l2 error 0.000064, h1 error 0.004383
# epoch:  509	argmax batch num,  4
# argmax time taken,  0.07939577102661133
# total size: 509 3375000 = 1717875000
# num batches:  4
# assembling the mass matrix time taken:  0.011064529418945312
# solving Ax = b time taken:  0.8356144428253174
# l2 error 0.000064, h1 error 0.004380
# epoch:  510	argmax batch num,  4
# argmax time taken,  0.07934856414794922
# total size: 510 3375000 = 1721250000
# num batches:  4
# assembling the mass matrix time taken:  0.004651308059692383
# solving Ax = b time taken:  0.8351006507873535
# l2 error 0.000064, h1 error 0.004374
# epoch:  511	argmax batch num,  4
# argmax time taken,  0.07979798316955566
# total size: 511 3375000 = 1724625000
# num batches:  4
# assembling the mass matrix time taken:  0.011101484298706055
# solving Ax = b time taken:  0.837517261505127
# l2 error 0.000064, h1 error 0.004347
# epoch:  512	argmax batch num,  4
# argmax time taken,  0.07983279228210449
# total size: 512 3375000 = 1728000000
# num batches:  4
# assembling the mass matrix time taken:  0.011147499084472656
# solving Ax = b time taken:  0.8337693214416504
# l2 error 0.000064, h1 error 0.004344
# time taken:  4.096958160400391
# neuron num 		 error 		 order
# 4 		 0.355201 		 * 		 3.328693 		 *
#
# 8 		 0.319866 		 0.151168 		 2.532866 		 0.394185
#
# 16 		 0.095728 		 1.740456 		 1.543874 		 0.714216
#
# 32 		 0.033666 		 1.507641 		 0.661404 		 1.222951
#
# 64 		 0.004313 		 2.964441 		 0.123774 		 2.417822
#
# 128 		 0.000971 		 2.150573 		 0.037357 		 1.728258
#
# 256 		 0.000220 		 2.140245 		 0.011513 		 1.698078
#
# 512 		 0.000064 		 1.789719 		 0.004344 		 1.406267
#
# neuron num  & 	 $\|u-u_n \|_{L^2}$ & 	 order $O(n^{-1.67})$  & 	 $ | u -u_n |_{H^1}$ & 	 order $O(n^{-1.33})$  \\ \hline \hline
# 4 		 & 0.355201 &		 * & 		 3.328693 & 		 *  \\ \hline
#
# 8 		 &  3.199e-01 &  		 0.15 &  		 2.533e+00 &  		 0.39 \\ \hline
#
# 16 		 &  9.573e-02 &  		 1.74 &  		 1.544e+00 &  		 0.71 \\ \hline
#
# 32 		 &  3.367e-02 &  		 1.51 &  		 6.614e-01 &  		 1.22 \\ \hline
#
# 64 		 &  4.313e-03 &  		 2.96 &  		 1.238e-01 &  		 2.42 \\ \hline
#
# 128 		 &  9.715e-04 &  		 2.15 &  		 3.736e-02 &  		 1.73 \\ \hline
#
# 256 		 &  2.204e-04 &  		 2.14 &  		 1.151e-02 &  		 1.70 \\ \hline
#
# 512 		 &  6.374e-05 &  		 1.79 &  		 4.344e-03 &  		 1.41 \\ \hline

# %% [markdown]
# ## gaussian example

# %%
def u_exact(x):
    d = 3 
    cn =   7.03/d 
    return torch.exp(-torch.sum( cn**2 * (x - 0.5)**2,dim = 1, keepdim = True))  

def u_exact_grad():
    d = 3 
    def make_grad_i(i):
        def grad_i(x):
            d = 3  
            cn = 7.03/d
            return torch.exp(-torch.sum(cn**2 * (x - 0.5)**2, dim=1, keepdim=True)) * (-2 * cn**2 * (x[:, i:i+1] - 0.5))
        return grad_i 
    
    u_grad=[] 
    for i in range(d):
        u_grad.append(make_grad_i(i))
    return u_grad
                                                                
                                                                    
def alpha(x): 
    return torch.ones(x.size(0),1).to(device)
    # return 0.5 * torch.sin(6 * pi*x[:,0:1]) + 1. 


def target(x):
    d = 3 
    cn =   7.03/d 
    z = torch.exp(-torch.sum( cn**2 * (x - 0.5)**2,dim = 1, keepdim = True)) 
    return z* ( -torch.sum(  (2 *cn**2 * (x - 0.5))**2 - 2*cn**2 ,dim = 1, keepdim = True) +1)

def g_N(dim):
    def make_g(i):
        def g_i(x):
            d = 3 
            cn = 7.03 / d
            return torch.exp(-torch.sum(cn**2 * (x - 0.5)**2, dim=1, keepdim=True)) * (-2 * cn**2 * (x[:, i:i+1] - 0.5))
        return g_i

    bcs_N = []
    for i in range(dim):
        bcs_N.append((i, make_g(i)))
    
    return bcs_N


function_name = "gaussian"
filename_write = "data-revision/3DOGA-{}-order.txt".format(function_name)
Nx = 50
order = 3
relu_k = 2
f_write = open(filename_write, "a" if os.path.exists(filename_write) else "w")
f_write.write("RELU k = {}, Integration points: Nx {}, order {} \n".format(relu_k,Nx,order))
f_write.close() 
save = True 
write2file = True
rand_deter = 'rand'

trial_num = 3 
for N_list in [[2**2, 2**3, 2**3]]:
    for trial in range(trial_num):
        f_write = open(filename_write, "a")
        my_model = None

        exponent = 8
        num_epochs = 2**exponent
        plot_freq = num_epochs
        N = np.prod(N_list)
    
        err_QMC2, err_h10, my_model = OGANeumannReLU3D(my_model, alpha, target, g_N, u_exact, u_exact_grad, N_list, num_epochs, plot_freq, Nx=Nx, order=order, k=relu_k, rand_deter='rand', linear_solver="direct")

        if save:
            folder = 'data-revision/'
            filename = folder + 'err_OGA_3D_{}_neuron_{}_N_{}_randomized_trial_{}.pt'.format(function_name, num_epochs, N, trial)
            torch.save(err_QMC2, filename)
            filename = folder + 'model_OGA_3D_{}_neuron_{}_N_{}_randomized_trial_{}.pt'.format(function_name, num_epochs, N, trial)
            torch.save(my_model.state_dict(), filename)

        show_convergence_order2(err_QMC2, err_h10, exponent, N, filename_write, write2file=write2file)
        show_convergence_order_latex2(err_QMC2, err_h10, exponent, k=relu_k, d=dim)
# Out:
# using linear solver:  direct
# epoch:  1	assembling the mass matrix time taken:  0.004244804382324219
# solving Ax = b time taken:  0.1321420669555664
# l2 error 0.274375, h1 error 2.522434
# epoch:  2	assembling the mass matrix time taken:  0.005568742752075195
# solving Ax = b time taken:  0.004712104797363281
# l2 error 0.213882, h1 error 2.411771
# epoch:  3	assembling the mass matrix time taken:  0.0041046142578125
# solving Ax = b time taken:  0.005236625671386719
# l2 error 0.204598, h1 error 2.114279
# epoch:  4	assembling the mass matrix time taken:  0.0047397613525390625
# solving Ax = b time taken:  0.005539417266845703
# l2 error 0.187524, h1 error 2.010464
# epoch:  5	assembling the mass matrix time taken:  0.004512786865234375
# solving Ax = b time taken:  0.005780696868896484
# l2 error 0.201255, h1 error 1.951563
# epoch:  6	assembling the mass matrix time taken:  0.0047681331634521484
# solving Ax = b time taken:  0.00668644905090332
# l2 error 0.167274, h1 error 1.863414
# epoch:  7	assembling the mass matrix time taken:  0.0040950775146484375
# solving Ax = b time taken:  0.007455587387084961
# l2 error 0.122039, h1 error 1.568123
# epoch:  8	assembling the mass matrix time taken:  0.005191326141357422
# solving Ax = b time taken:  0.007800579071044922
# l2 error 0.095435, h1 error 1.434597
# epoch:  9	assembling the mass matrix time taken:  0.004552364349365234
# solving Ax = b time taken:  0.008511781692504883
# l2 error 0.086551, h1 error 1.394909
# epoch:  10	assembling the mass matrix time taken:  0.016914844512939453
# solving Ax = b time taken:  0.009311676025390625
# l2 error 0.086279, h1 error 1.393708
# epoch:  11	assembling the mass matrix time taken:  0.004362344741821289
# solving Ax = b time taken:  0.009978771209716797
# l2 error 0.085404, h1 error 1.369874
# epoch:  12	assembling the mass matrix time taken:  0.004769563674926758
# solving Ax = b time taken:  0.010133981704711914
# l2 error 0.083436, h1 error 1.327301
# epoch:  13	assembling the mass matrix time taken:  0.00433659553527832
# solving Ax = b time taken:  0.011221647262573242
# l2 error 0.082394, h1 error 1.298430
# epoch:  14	assembling the mass matrix time taken:  0.004408359527587891
# solving Ax = b time taken:  0.011671304702758789
# l2 error 0.080292, h1 error 1.261603
# epoch:  15	assembling the mass matrix time taken:  0.00426173210144043
# solving Ax = b time taken:  0.012375593185424805
# l2 error 0.075560, h1 error 1.186964
# epoch:  16	assembling the mass matrix time taken:  0.004111051559448242
# solving Ax = b time taken:  0.013092756271362305
# l2 error 0.069121, h1 error 1.094796
# epoch:  17	assembling the mass matrix time taken:  0.004168987274169922
# solving Ax = b time taken:  0.013869524002075195
# l2 error 0.063906, h1 error 1.017382
# epoch:  18	assembling the mass matrix time taken:  0.004058837890625
# solving Ax = b time taken:  0.01436305046081543
# l2 error 0.058086, h1 error 0.921053
# epoch:  19	assembling the mass matrix time taken:  0.004118204116821289
# solving Ax = b time taken:  0.015161991119384766
# l2 error 0.055571, h1 error 0.898980
# epoch:  20	assembling the mass matrix time taken:  0.0043179988861083984
# solving Ax = b time taken:  0.01571488380432129
# l2 error 0.050052, h1 error 0.829349
# epoch:  21	assembling the mass matrix time taken:  0.004294872283935547
# solving Ax = b time taken:  0.016371488571166992
# l2 error 0.046632, h1 error 0.784787
# epoch:  22	assembling the mass matrix time taken:  0.004267692565917969
# solving Ax = b time taken:  0.01685166358947754
# l2 error 0.041751, h1 error 0.711891
# epoch:  23	assembling the mass matrix time taken:  0.004311561584472656
# solving Ax = b time taken:  0.01753830909729004
# l2 error 0.038645, h1 error 0.669272
# epoch:  24	assembling the mass matrix time taken:  0.0043795108795166016
# solving Ax = b time taken:  0.018171310424804688
# l2 error 0.036008, h1 error 0.642972
# epoch:  25	assembling the mass matrix time taken:  0.004426479339599609
# solving Ax = b time taken:  0.01877903938293457
# l2 error 0.033956, h1 error 0.613179
# epoch:  26	assembling the mass matrix time taken:  0.004105806350708008
# solving Ax = b time taken:  0.019487619400024414
# l2 error 0.030201, h1 error 0.565958
# epoch:  27	assembling the mass matrix time taken:  0.004367828369140625
# solving Ax = b time taken:  0.020099401473999023
# l2 error 0.027739, h1 error 0.537239
# epoch:  28	assembling the mass matrix time taken:  0.004080772399902344
# solving Ax = b time taken:  0.020926237106323242
# l2 error 0.025800, h1 error 0.514304
# epoch:  29	assembling the mass matrix time taken:  0.004156589508056641
# solving Ax = b time taken:  0.021493196487426758
# l2 error 0.024546, h1 error 0.493252
# epoch:  30	assembling the mass matrix time taken:  0.00431060791015625
# solving Ax = b time taken:  0.02199101448059082
# l2 error 0.023222, h1 error 0.464002
# epoch:  31	assembling the mass matrix time taken:  0.004408121109008789
# solving Ax = b time taken:  0.02283000946044922
# l2 error 0.021949, h1 error 0.448871
# epoch:  32	assembling the mass matrix time taken:  0.004845380783081055
# solving Ax = b time taken:  0.022348880767822266
# l2 error 0.019694, h1 error 0.413667
# epoch:  33	assembling the mass matrix time taken:  0.004897356033325195
# solving Ax = b time taken:  0.02563190460205078
# l2 error 0.018237, h1 error 0.392894
# epoch:  34	assembling the mass matrix time taken:  0.004412174224853516
# solving Ax = b time taken:  0.026401996612548828
# l2 error 0.016814, h1 error 0.374403
# epoch:  35	assembling the mass matrix time taken:  0.01648116111755371
# solving Ax = b time taken:  0.02751016616821289
# l2 error 0.016448, h1 error 0.368667
# epoch:  36	assembling the mass matrix time taken:  0.004812002182006836
# solving Ax = b time taken:  0.027471303939819336
# l2 error 0.015252, h1 error 0.352667
# epoch:  37	assembling the mass matrix time taken:  0.01675701141357422
# solving Ax = b time taken:  0.02853679656982422
# l2 error 0.014727, h1 error 0.344178
# epoch:  38	assembling the mass matrix time taken:  0.016878366470336914
# solving Ax = b time taken:  0.029350757598876953
# l2 error 0.013272, h1 error 0.325543
# epoch:  39	assembling the mass matrix time taken:  0.01683640480041504
# solving Ax = b time taken:  0.030029296875
# l2 error 0.012759, h1 error 0.315377
# epoch:  40	assembling the mass matrix time taken:  0.016600847244262695
# solving Ax = b time taken:  0.02978968620300293
# l2 error 0.012403, h1 error 0.306606
# epoch:  41	assembling the mass matrix time taken:  0.017162799835205078
# solving Ax = b time taken:  0.030933380126953125
# l2 error 0.012299, h1 error 0.301293
# epoch:  42	assembling the mass matrix time taken:  0.016858577728271484
# solving Ax = b time taken:  0.03187680244445801
# l2 error 0.012105, h1 error 0.296701
# epoch:  43	assembling the mass matrix time taken:  0.004113435745239258
# solving Ax = b time taken:  0.032515525817871094
# l2 error 0.011859, h1 error 0.291703
# epoch:  44	assembling the mass matrix time taken:  0.01615285873413086
# solving Ax = b time taken:  0.03246140480041504
# l2 error 0.011107, h1 error 0.282680
# epoch:  45	assembling the mass matrix time taken:  0.0042798519134521484
# solving Ax = b time taken:  0.03417038917541504
# l2 error 0.010820, h1 error 0.276396
# epoch:  46	assembling the mass matrix time taken:  0.004530668258666992
# solving Ax = b time taken:  0.03421902656555176
# l2 error 0.010570, h1 error 0.271585
# epoch:  47	assembling the mass matrix time taken:  0.017194271087646484
# solving Ax = b time taken:  0.03807520866394043
# l2 error 0.010262, h1 error 0.265470
# epoch:  48	assembling the mass matrix time taken:  0.01742410659790039
# solving Ax = b time taken:  0.03818345069885254
# l2 error 0.010000, h1 error 0.259308
# epoch:  49	assembling the mass matrix time taken:  0.004560947418212891
# solving Ax = b time taken:  0.03961467742919922
# l2 error 0.009755, h1 error 0.253879
# epoch:  50	assembling the mass matrix time taken:  0.016566991806030273
# solving Ax = b time taken:  0.04033803939819336
# l2 error 0.009461, h1 error 0.246943
# epoch:  51	assembling the mass matrix time taken:  0.01632857322692871
# solving Ax = b time taken:  0.041048288345336914
# l2 error 0.009410, h1 error 0.243598
# epoch:  52	assembling the mass matrix time taken:  0.01699972152709961
# solving Ax = b time taken:  0.041127681732177734
# l2 error 0.009155, h1 error 0.238404
# epoch:  53	assembling the mass matrix time taken:  0.017168521881103516
# solving Ax = b time taken:  0.04207324981689453
# l2 error 0.009000, h1 error 0.234303
# epoch:  54	assembling the mass matrix time taken:  0.004387378692626953
# solving Ax = b time taken:  0.042840003967285156
# l2 error 0.008760, h1 error 0.229233
# epoch:  55	assembling the mass matrix time taken:  0.017067670822143555
# solving Ax = b time taken:  0.04342222213745117
# l2 error 0.008520, h1 error 0.223530
# epoch:  56	assembling the mass matrix time taken:  0.0171816349029541
# solving Ax = b time taken:  0.043412208557128906
# l2 error 0.008266, h1 error 0.218048
# epoch:  57	assembling the mass matrix time taken:  0.016373395919799805
# solving Ax = b time taken:  0.04475760459899902
# l2 error 0.007885, h1 error 0.212589
# epoch:  58	assembling the mass matrix time taken:  0.01629638671875
# solving Ax = b time taken:  0.04501008987426758
# l2 error 0.007483, h1 error 0.207104
# epoch:  59	assembling the mass matrix time taken:  0.0166471004486084
# solving Ax = b time taken:  0.04608273506164551
# l2 error 0.007253, h1 error 0.202618
# epoch:  60	assembling the mass matrix time taken:  0.0043752193450927734
# solving Ax = b time taken:  0.04609227180480957
# l2 error 0.006911, h1 error 0.195746
# epoch:  61	assembling the mass matrix time taken:  0.01726078987121582
# solving Ax = b time taken:  0.04725337028503418
# l2 error 0.006782, h1 error 0.191585
# epoch:  62	assembling the mass matrix time taken:  0.0045435428619384766
# solving Ax = b time taken:  0.04790925979614258
# l2 error 0.006656, h1 error 0.188485
# epoch:  63	assembling the mass matrix time taken:  0.0045244693756103516
# solving Ax = b time taken:  0.04853248596191406
# l2 error 0.006391, h1 error 0.184035
# epoch:  64	assembling the mass matrix time taken:  0.0041675567626953125
# solving Ax = b time taken:  0.048595428466796875
# l2 error 0.006184, h1 error 0.182143
# epoch:  65	assembling the mass matrix time taken:  0.0075092315673828125
# solving Ax = b time taken:  0.05735898017883301
# l2 error 0.005952, h1 error 0.178383
# epoch:  66	assembling the mass matrix time taken:  0.01650381088256836
# solving Ax = b time taken:  0.058272600173950195
# l2 error 0.005800, h1 error 0.175671
# epoch:  67	assembling the mass matrix time taken:  0.01696324348449707
# solving Ax = b time taken:  0.059110164642333984
# l2 error 0.005694, h1 error 0.173052
# epoch:  68	assembling the mass matrix time taken:  0.016536951065063477
# solving Ax = b time taken:  0.0589141845703125
# l2 error 0.005431, h1 error 0.168825
# epoch:  69	assembling the mass matrix time taken:  0.016527652740478516
# solving Ax = b time taken:  0.060407161712646484
# l2 error 0.005301, h1 error 0.166189
# epoch:  70	assembling the mass matrix time taken:  0.005529642105102539
# solving Ax = b time taken:  0.06100034713745117
# l2 error 0.005283, h1 error 0.164963
# epoch:  71	assembling the mass matrix time taken:  0.005373239517211914
# solving Ax = b time taken:  0.061753034591674805
# l2 error 0.005226, h1 error 0.162653
# epoch:  72	assembling the mass matrix time taken:  0.0045506954193115234
# solving Ax = b time taken:  0.06113409996032715
# l2 error 0.005012, h1 error 0.158990
# epoch:  73	assembling the mass matrix time taken:  0.017017841339111328
# solving Ax = b time taken:  0.06319928169250488
# l2 error 0.004977, h1 error 0.156964
# epoch:  74	assembling the mass matrix time taken:  0.004278421401977539
# solving Ax = b time taken:  0.06356430053710938
# l2 error 0.004966, h1 error 0.155439
# epoch:  75	assembling the mass matrix time taken:  0.016831159591674805
# solving Ax = b time taken:  0.06435561180114746
# l2 error 0.004801, h1 error 0.152065
# epoch:  76	assembling the mass matrix time taken:  0.016953706741333008
# solving Ax = b time taken:  0.06392431259155273
# l2 error 0.004743, h1 error 0.150979
# epoch:  77	assembling the mass matrix time taken:  0.004316806793212891
# solving Ax = b time taken:  0.06567502021789551
# l2 error 0.004679, h1 error 0.149148
# epoch:  78	assembling the mass matrix time taken:  0.004317760467529297
# solving Ax = b time taken:  0.06609058380126953
# l2 error 0.004617, h1 error 0.146939
# epoch:  79	assembling the mass matrix time taken:  0.004364490509033203
# solving Ax = b time taken:  0.06698298454284668
# l2 error 0.004606, h1 error 0.145461
# epoch:  80	assembling the mass matrix time taken:  0.004438638687133789
# solving Ax = b time taken:  0.06621742248535156
# l2 error 0.004419, h1 error 0.142944
# epoch:  81	assembling the mass matrix time taken:  0.004169940948486328
# solving Ax = b time taken:  0.0696108341217041
# l2 error 0.004395, h1 error 0.141632
# epoch:  82	assembling the mass matrix time taken:  0.004241228103637695
# solving Ax = b time taken:  0.06988835334777832
# l2 error 0.004341, h1 error 0.140281
# epoch:  83	assembling the mass matrix time taken:  0.016808509826660156
# solving Ax = b time taken:  0.07086730003356934
# l2 error 0.004280, h1 error 0.138719
# epoch:  84	assembling the mass matrix time taken:  0.004330158233642578
# solving Ax = b time taken:  0.07014870643615723
# l2 error 0.004232, h1 error 0.137665
# epoch:  85	assembling the mass matrix time taken:  0.004348039627075195
# solving Ax = b time taken:  0.07203006744384766
# l2 error 0.004154, h1 error 0.135921
# epoch:  86	assembling the mass matrix time taken:  0.004454374313354492
# solving Ax = b time taken:  0.07210564613342285
# l2 error 0.004003, h1 error 0.132810
# epoch:  87	assembling the mass matrix time taken:  0.0041697025299072266
# solving Ax = b time taken:  0.07332563400268555
# l2 error 0.003970, h1 error 0.131694
# epoch:  88	assembling the mass matrix time taken:  0.004155874252319336
# solving Ax = b time taken:  0.07248234748840332
# l2 error 0.003912, h1 error 0.130918
# epoch:  89	assembling the mass matrix time taken:  0.004341840744018555
# solving Ax = b time taken:  0.07445669174194336
# l2 error 0.003851, h1 error 0.129877
# epoch:  90	assembling the mass matrix time taken:  0.004358768463134766
# solving Ax = b time taken:  0.07496929168701172
# l2 error 0.003801, h1 error 0.128799
# epoch:  91	assembling the mass matrix time taken:  0.004322528839111328
# solving Ax = b time taken:  0.07576131820678711
# l2 error 0.003703, h1 error 0.127002
# epoch:  92	assembling the mass matrix time taken:  0.0041656494140625
# solving Ax = b time taken:  0.07509207725524902
# l2 error 0.003679, h1 error 0.126266
# epoch:  93	assembling the mass matrix time taken:  0.004149198532104492
# solving Ax = b time taken:  0.07712435722351074
# l2 error 0.003632, h1 error 0.125267
# epoch:  94	assembling the mass matrix time taken:  0.004452228546142578
# solving Ax = b time taken:  0.0773630142211914
# l2 error 0.003562, h1 error 0.123897
# epoch:  95	assembling the mass matrix time taken:  0.004340648651123047
# solving Ax = b time taken:  0.07825732231140137
# l2 error 0.003491, h1 error 0.121960
# epoch:  96	assembling the mass matrix time taken:  0.004940032958984375
# solving Ax = b time taken:  0.07691478729248047
# l2 error 0.003455, h1 error 0.120927
# epoch:  97	assembling the mass matrix time taken:  0.005098104476928711
# solving Ax = b time taken:  0.07759928703308105
# l2 error 0.003356, h1 error 0.118805
# epoch:  98	assembling the mass matrix time taken:  0.004673004150390625
# solving Ax = b time taken:  0.07866072654724121
# l2 error 0.003328, h1 error 0.117112
# epoch:  99	assembling the mass matrix time taken:  0.00462031364440918
# solving Ax = b time taken:  0.07929873466491699
# l2 error 0.003285, h1 error 0.115808
# epoch:  100	assembling the mass matrix time taken:  0.0048065185546875
# solving Ax = b time taken:  0.07866907119750977
# l2 error 0.003206, h1 error 0.114407
# epoch:  101	assembling the mass matrix time taken:  0.004872322082519531
# solving Ax = b time taken:  0.08046793937683105
# l2 error 0.003151, h1 error 0.112784
# epoch:  102	assembling the mass matrix time taken:  0.0048792362213134766
# solving Ax = b time taken:  0.08106231689453125
# l2 error 0.003113, h1 error 0.111904
# epoch:  103	assembling the mass matrix time taken:  0.004818916320800781
# solving Ax = b time taken:  0.08174920082092285
# l2 error 0.003086, h1 error 0.111010
# epoch:  104	assembling the mass matrix time taken:  0.004614353179931641
# solving Ax = b time taken:  0.0812063217163086
# l2 error 0.003038, h1 error 0.109829
# epoch:  105	assembling the mass matrix time taken:  0.004582405090332031
# solving Ax = b time taken:  0.08321690559387207
# l2 error 0.003000, h1 error 0.109223
# epoch:  106	assembling the mass matrix time taken:  0.004843235015869141
# solving Ax = b time taken:  0.08366155624389648
# l2 error 0.002967, h1 error 0.108168
# epoch:  107	assembling the mass matrix time taken:  0.0048754215240478516
# solving Ax = b time taken:  0.08427834510803223
# l2 error 0.002941, h1 error 0.107546
# epoch:  108	assembling the mass matrix time taken:  0.004924774169921875
# solving Ax = b time taken:  0.08354330062866211
# l2 error 0.002922, h1 error 0.106939
# epoch:  109	assembling the mass matrix time taken:  0.004589080810546875
# solving Ax = b time taken:  0.08572793006896973
# l2 error 0.002891, h1 error 0.105978
# epoch:  110	assembling the mass matrix time taken:  0.00465846061706543
# solving Ax = b time taken:  0.08625912666320801
# l2 error 0.002825, h1 error 0.104590
# epoch:  111	assembling the mass matrix time taken:  0.0048999786376953125
# solving Ax = b time taken:  0.08682680130004883
# l2 error 0.002750, h1 error 0.102649
# epoch:  112	assembling the mass matrix time taken:  0.004828691482543945
# solving Ax = b time taken:  0.08611297607421875
# l2 error 0.002710, h1 error 0.101959
# epoch:  113	assembling the mass matrix time taken:  0.004904270172119141
# solving Ax = b time taken:  0.0880131721496582
# l2 error 0.002671, h1 error 0.100585
# epoch:  114	assembling the mass matrix time taken:  0.004637479782104492
# solving Ax = b time taken:  0.08879327774047852
# l2 error 0.002661, h1 error 0.100053
# epoch:  115	assembling the mass matrix time taken:  0.0046482086181640625
# solving Ax = b time taken:  0.0901949405670166
# l2 error 0.002623, h1 error 0.098670
# epoch:  116	assembling the mass matrix time taken:  0.004887104034423828
# solving Ax = b time taken:  0.08922767639160156
# l2 error 0.002583, h1 error 0.097663
# epoch:  117	assembling the mass matrix time taken:  0.004906177520751953
# solving Ax = b time taken:  0.09121155738830566
# l2 error 0.002535, h1 error 0.096656
# epoch:  118	assembling the mass matrix time taken:  0.00493621826171875
# solving Ax = b time taken:  0.09173297882080078
# l2 error 0.002514, h1 error 0.096134
# epoch:  119	assembling the mass matrix time taken:  0.0046710968017578125
# solving Ax = b time taken:  0.09263324737548828
# l2 error 0.002499, h1 error 0.095674
# epoch:  120	assembling the mass matrix time taken:  0.08982729911804199
# solving Ax = b time taken:  0.05226635932922363
# l2 error 0.002472, h1 error 0.094816
# epoch:  121	assembling the mass matrix time taken:  0.012424468994140625
# solving Ax = b time taken:  0.09969735145568848
# l2 error 0.002462, h1 error 0.094211
# epoch:  122	assembling the mass matrix time taken:  0.007096529006958008
# solving Ax = b time taken:  0.09215545654296875
# l2 error 0.002432, h1 error 0.093711
# epoch:  123	assembling the mass matrix time taken:  0.004602193832397461
# solving Ax = b time taken:  0.09520530700683594
# l2 error 0.002410, h1 error 0.093033
# epoch:  124	assembling the mass matrix time taken:  0.0045604705810546875
# solving Ax = b time taken:  0.09449338912963867
# l2 error 0.002355, h1 error 0.092002
# epoch:  125	assembling the mass matrix time taken:  0.005003213882446289
# solving Ax = b time taken:  0.09620094299316406
# l2 error 0.002339, h1 error 0.091427
# epoch:  126	assembling the mass matrix time taken:  0.004832029342651367
# solving Ax = b time taken:  0.09695720672607422
# l2 error 0.002314, h1 error 0.090470
# epoch:  127	assembling the mass matrix time taken:  0.00503087043762207
# solving Ax = b time taken:  0.0974581241607666
# l2 error 0.002308, h1 error 0.089738
# epoch:  128	assembling the mass matrix time taken:  0.004597663879394531
# solving Ax = b time taken:  0.0967264175415039
# l2 error 0.002288, h1 error 0.089017
# epoch:  129	assembling the mass matrix time taken:  0.005445957183837891
# solving Ax = b time taken:  0.12212514877319336
# l2 error 0.002270, h1 error 0.088316
# epoch:  130	assembling the mass matrix time taken:  0.005760669708251953
# solving Ax = b time taken:  0.12196922302246094
# l2 error 0.002238, h1 error 0.087540
# epoch:  131	assembling the mass matrix time taken:  0.005707502365112305
# solving Ax = b time taken:  0.12329816818237305
# l2 error 0.002211, h1 error 0.086456
# epoch:  132	assembling the mass matrix time taken:  0.1148080825805664
# solving Ax = b time taken:  0.06911587715148926
# l2 error 0.002184, h1 error 0.085596
# epoch:  133	assembling the mass matrix time taken:  0.01014256477355957
# solving Ax = b time taken:  0.12001347541809082
# l2 error 0.002148, h1 error 0.084696
# epoch:  134	assembling the mass matrix time taken:  0.005709171295166016
# solving Ax = b time taken:  0.12468099594116211
# l2 error 0.002127, h1 error 0.084103
# epoch:  135	assembling the mass matrix time taken:  0.005647182464599609
# solving Ax = b time taken:  0.12591814994812012
# l2 error 0.002087, h1 error 0.083302
# epoch:  136	assembling the mass matrix time taken:  0.005897998809814453
# solving Ax = b time taken:  0.12350249290466309
# l2 error 0.002036, h1 error 0.082000
# epoch:  137	assembling the mass matrix time taken:  0.0054111480712890625
# solving Ax = b time taken:  0.12746477127075195
# l2 error 0.002025, h1 error 0.081583
# epoch:  138	assembling the mass matrix time taken:  0.19528770446777344
# solving Ax = b time taken:  0.07252931594848633
# l2 error 0.002005, h1 error 0.081003
# epoch:  139	assembling the mass matrix time taken:  0.01015329360961914
# solving Ax = b time taken:  0.1241309642791748
# l2 error 0.001976, h1 error 0.080179
# epoch:  140	assembling the mass matrix time taken:  0.017778873443603516
# solving Ax = b time taken:  0.12644028663635254
# l2 error 0.001956, h1 error 0.079529
# epoch:  141	assembling the mass matrix time taken:  0.018113136291503906
# solving Ax = b time taken:  0.1299915313720703
# l2 error 0.001939, h1 error 0.078954
# epoch:  142	assembling the mass matrix time taken:  0.018146753311157227
# solving Ax = b time taken:  0.12970495223999023
# l2 error 0.001901, h1 error 0.078026
# epoch:  143	assembling the mass matrix time taken:  0.12801289558410645
# solving Ax = b time taken:  0.07524299621582031
# l2 error 0.001881, h1 error 0.077409
# epoch:  144	assembling the mass matrix time taken:  0.010310649871826172
# solving Ax = b time taken:  0.12391376495361328
# l2 error 0.001850, h1 error 0.076767
# epoch:  145	assembling the mass matrix time taken:  0.005370140075683594
# solving Ax = b time taken:  0.13272643089294434
# l2 error 0.001823, h1 error 0.076129
# epoch:  146	assembling the mass matrix time taken:  0.0062334537506103516
# solving Ax = b time taken:  0.13175654411315918
# l2 error 0.001811, h1 error 0.075398
# epoch:  147	assembling the mass matrix time taken:  0.006205081939697266
# solving Ax = b time taken:  0.13326120376586914
# l2 error 0.001812, h1 error 0.074992
# epoch:  148	assembling the mass matrix time taken:  0.12882518768310547
# solving Ax = b time taken:  0.07632923126220703
# l2 error 0.001794, h1 error 0.074580
# epoch:  149	assembling the mass matrix time taken:  0.010608673095703125
# solving Ax = b time taken:  0.13009262084960938
# l2 error 0.001786, h1 error 0.074270
# epoch:  150	assembling the mass matrix time taken:  0.02960205078125
# solving Ax = b time taken:  0.1110069751739502
# l2 error 0.001769, h1 error 0.073963
# epoch:  151	assembling the mass matrix time taken:  0.005866050720214844
# solving Ax = b time taken:  0.13623833656311035
# l2 error 0.001749, h1 error 0.073419
# epoch:  152	assembling the mass matrix time taken:  0.0076215267181396484
# solving Ax = b time taken:  0.13314533233642578
# l2 error 0.001737, h1 error 0.072897
# epoch:  153	assembling the mass matrix time taken:  0.17753171920776367
# solving Ax = b time taken:  0.08023428916931152
# l2 error 0.001723, h1 error 0.072539
# epoch:  154	assembling the mass matrix time taken:  0.010258913040161133
# solving Ax = b time taken:  0.13295793533325195
# l2 error 0.001697, h1 error 0.071972
# epoch:  155	assembling the mass matrix time taken:  0.0057489871978759766
# solving Ax = b time taken:  0.13907313346862793
# l2 error 0.001691, h1 error 0.071593
# epoch:  156	assembling the mass matrix time taken:  0.005470752716064453
# solving Ax = b time taken:  0.13691091537475586
# l2 error 0.001688, h1 error 0.071251
# epoch:  157	assembling the mass matrix time taken:  0.006441354751586914
# solving Ax = b time taken:  0.1397724151611328
# l2 error 0.001672, h1 error 0.070613
# epoch:  158	assembling the mass matrix time taken:  0.18477892875671387
# solving Ax = b time taken:  0.09980916976928711
# l2 error 0.001650, h1 error 0.069962
# epoch:  159	assembling the mass matrix time taken:  0.010071039199829102
# solving Ax = b time taken:  0.13744473457336426
# l2 error 0.001616, h1 error 0.069251
# epoch:  160	assembling the mass matrix time taken:  0.005541324615478516
# solving Ax = b time taken:  0.1387178897857666
# l2 error 0.001572, h1 error 0.068309
# epoch:  161	assembling the mass matrix time taken:  0.00565791130065918
# solving Ax = b time taken:  0.14049720764160156
# l2 error 0.001556, h1 error 0.067910
# epoch:  162	assembling the mass matrix time taken:  0.007859468460083008
# solving Ax = b time taken:  0.1388721466064453
# l2 error 0.001539, h1 error 0.067381
# epoch:  163	assembling the mass matrix time taken:  0.22953104972839355
# solving Ax = b time taken:  0.07926440238952637
# l2 error 0.001520, h1 error 0.067023
# epoch:  164	assembling the mass matrix time taken:  0.009721994400024414
# solving Ax = b time taken:  0.13570690155029297
# l2 error 0.001511, h1 error 0.066737
# epoch:  165	assembling the mass matrix time taken:  0.0057373046875
# solving Ax = b time taken:  0.14311456680297852
# l2 error 0.001499, h1 error 0.066292
# epoch:  166	assembling the mass matrix time taken:  0.005478620529174805
# solving Ax = b time taken:  0.14322400093078613
# l2 error 0.001497, h1 error 0.066148
# epoch:  167	assembling the mass matrix time taken:  0.014842987060546875
# solving Ax = b time taken:  0.13520216941833496
# l2 error 0.001471, h1 error 0.065360
# epoch:  168	assembling the mass matrix time taken:  0.2999606132507324
# solving Ax = b time taken:  0.08019065856933594
# l2 error 0.001463, h1 error 0.064972
# epoch:  169	assembling the mass matrix time taken:  0.008491039276123047
# solving Ax = b time taken:  0.14302706718444824
# l2 error 0.001439, h1 error 0.064343
# epoch:  170	assembling the mass matrix time taken:  0.005444765090942383
# solving Ax = b time taken:  0.14571833610534668
# l2 error 0.001416, h1 error 0.063888
# epoch:  171	assembling the mass matrix time taken:  0.005766153335571289
# solving Ax = b time taken:  0.14689397811889648
# l2 error 0.001412, h1 error 0.063579
# epoch:  172	assembling the mass matrix time taken:  0.1454784870147705
# solving Ax = b time taken:  0.0824739933013916
# l2 error 0.001403, h1 error 0.063206
# epoch:  173	assembling the mass matrix time taken:  0.010104179382324219
# solving Ax = b time taken:  0.14375686645507812
# l2 error 0.001402, h1 error 0.062941
# epoch:  174	assembling the mass matrix time taken:  0.005736351013183594
# solving Ax = b time taken:  0.14804959297180176
# l2 error 0.001391, h1 error 0.062572
# epoch:  175	assembling the mass matrix time taken:  0.0057756900787353516
# solving Ax = b time taken:  0.14944124221801758
# l2 error 0.001378, h1 error 0.062145
# epoch:  176	assembling the mass matrix time taken:  0.18151021003723145
# solving Ax = b time taken:  0.08319425582885742
# l2 error 0.001364, h1 error 0.061735
# epoch:  177	assembling the mass matrix time taken:  0.009695768356323242
# solving Ax = b time taken:  0.14670538902282715
# l2 error 0.001352, h1 error 0.061256
# epoch:  178	assembling the mass matrix time taken:  0.005722999572753906
# solving Ax = b time taken:  0.15051984786987305
# l2 error 0.001336, h1 error 0.060740
# epoch:  179	assembling the mass matrix time taken:  0.005794525146484375
# solving Ax = b time taken:  0.15188884735107422
# l2 error 0.001324, h1 error 0.060395
# epoch:  180	assembling the mass matrix time taken:  0.1880342960357666
# solving Ax = b time taken:  0.0850071907043457
# l2 error 0.001316, h1 error 0.060122
# epoch:  181	assembling the mass matrix time taken:  0.010174036026000977
# solving Ax = b time taken:  0.14884495735168457
# l2 error 0.001296, h1 error 0.059468
# epoch:  182	assembling the mass matrix time taken:  0.005947589874267578
# solving Ax = b time taken:  0.15281414985656738
# l2 error 0.001288, h1 error 0.059185
# epoch:  183	assembling the mass matrix time taken:  0.00550389289855957
# solving Ax = b time taken:  0.15472698211669922
# l2 error 0.001271, h1 error 0.058719
# epoch:  184	assembling the mass matrix time taken:  0.24637150764465332
# solving Ax = b time taken:  0.08632993698120117
# l2 error 0.001262, h1 error 0.058425
# epoch:  185	assembling the mass matrix time taken:  0.00909113883972168
# solving Ax = b time taken:  0.1525113582611084
# l2 error 0.001253, h1 error 0.058205
# epoch:  186	assembling the mass matrix time taken:  0.005492448806762695
# solving Ax = b time taken:  0.1557140350341797
# l2 error 0.001231, h1 error 0.057685
# epoch:  187	assembling the mass matrix time taken:  0.007230997085571289
# solving Ax = b time taken:  0.15553021430969238
# l2 error 0.001213, h1 error 0.057087
# epoch:  188	assembling the mass matrix time taken:  0.21692824363708496
# solving Ax = b time taken:  0.10477089881896973
# l2 error 0.001210, h1 error 0.056869
# epoch:  189	assembling the mass matrix time taken:  0.009560346603393555
# solving Ax = b time taken:  0.15437006950378418
# l2 error 0.001200, h1 error 0.056606
# epoch:  190	assembling the mass matrix time taken:  0.005426645278930664
# solving Ax = b time taken:  0.15835833549499512
# l2 error 0.001195, h1 error 0.056329
# epoch:  191	assembling the mass matrix time taken:  0.00759124755859375
# solving Ax = b time taken:  0.15784049034118652
# l2 error 0.001190, h1 error 0.056173
# epoch:  192	assembling the mass matrix time taken:  0.295011043548584
# solving Ax = b time taken:  0.08889222145080566
# l2 error 0.001175, h1 error 0.055617
# epoch:  193	assembling the mass matrix time taken:  0.008630752563476562
# solving Ax = b time taken:  0.18796229362487793
# l2 error 0.001166, h1 error 0.055418
# epoch:  194	assembling the mass matrix time taken:  0.006362199783325195
# solving Ax = b time taken:  0.19060611724853516
# l2 error 0.001163, h1 error 0.055199
# epoch:  195	assembling the mass matrix time taken:  0.009510517120361328
# solving Ax = b time taken:  0.18833518028259277
# l2 error 0.001156, h1 error 0.054808
# epoch:  196	assembling the mass matrix time taken:  0.1924748420715332
# solving Ax = b time taken:  0.12844276428222656
# l2 error 0.001152, h1 error 0.054633
# epoch:  197	assembling the mass matrix time taken:  0.010597705841064453
# solving Ax = b time taken:  0.18852663040161133
# l2 error 0.001129, h1 error 0.053995
# epoch:  198	assembling the mass matrix time taken:  0.0059621334075927734
# solving Ax = b time taken:  0.19298577308654785
# l2 error 0.001119, h1 error 0.053714
# epoch:  199	assembling the mass matrix time taken:  0.008148193359375
# solving Ax = b time taken:  0.19159507751464844
# l2 error 0.001109, h1 error 0.053395
# epoch:  200	assembling the mass matrix time taken:  0.32031726837158203
# solving Ax = b time taken:  0.10631322860717773
# l2 error 0.001103, h1 error 0.053171
# epoch:  201	assembling the mass matrix time taken:  0.008761167526245117
# solving Ax = b time taken:  0.19202160835266113
# l2 error 0.001090, h1 error 0.052601
# epoch:  202	assembling the mass matrix time taken:  0.005461692810058594
# solving Ax = b time taken:  0.19499540328979492
# l2 error 0.001087, h1 error 0.052471
# epoch:  203	assembling the mass matrix time taken:  0.007816314697265625
# solving Ax = b time taken:  0.1943206787109375
# l2 error 0.001081, h1 error 0.052293
# epoch:  204	assembling the mass matrix time taken:  0.291975736618042
# solving Ax = b time taken:  0.10866117477416992
# l2 error 0.001080, h1 error 0.052023
# epoch:  205	assembling the mass matrix time taken:  0.008981943130493164
# solving Ax = b time taken:  0.19432568550109863
# l2 error 0.001068, h1 error 0.051666
# epoch:  206	assembling the mass matrix time taken:  0.006768703460693359
# solving Ax = b time taken:  0.19629526138305664
# l2 error 0.001057, h1 error 0.051356
# epoch:  207	assembling the mass matrix time taken:  0.008671283721923828
# solving Ax = b time taken:  0.1960620880126953
# l2 error 0.001050, h1 error 0.051111
# epoch:  208	assembling the mass matrix time taken:  0.2971682548522949
# solving Ax = b time taken:  0.13338422775268555
# l2 error 0.001044, h1 error 0.050998
# epoch:  209	assembling the mass matrix time taken:  0.009136199951171875
# solving Ax = b time taken:  0.19691967964172363
# l2 error 0.001035, h1 error 0.050684
# epoch:  210	assembling the mass matrix time taken:  0.005898237228393555
# solving Ax = b time taken:  0.19962215423583984
# l2 error 0.001030, h1 error 0.050361
# epoch:  211	assembling the mass matrix time taken:  0.008592605590820312
# solving Ax = b time taken:  0.1985642910003662
# l2 error 0.001024, h1 error 0.050189
# epoch:  212	assembling the mass matrix time taken:  0.3036653995513916
# solving Ax = b time taken:  0.1352989673614502
# l2 error 0.001019, h1 error 0.049999
# epoch:  213	assembling the mass matrix time taken:  0.00924372673034668
# solving Ax = b time taken:  0.19916582107543945
# l2 error 0.001013, h1 error 0.049817
# epoch:  214	assembling the mass matrix time taken:  0.006047725677490234
# solving Ax = b time taken:  0.20202136039733887
# l2 error 0.001014, h1 error 0.049608
# epoch:  215	assembling the mass matrix time taken:  0.23576831817626953
# solving Ax = b time taken:  0.11326241493225098
# l2 error 0.001010, h1 error 0.049514
# epoch:  216	assembling the mass matrix time taken:  0.00902414321899414
# solving Ax = b time taken:  0.19700837135314941
# l2 error 0.001007, h1 error 0.049396
# epoch:  217	assembling the mass matrix time taken:  0.006096363067626953
# solving Ax = b time taken:  0.2048656940460205
# l2 error 0.001001, h1 error 0.048999
# epoch:  218	assembling the mass matrix time taken:  0.23630166053771973
# solving Ax = b time taken:  0.11404895782470703
# l2 error 0.000992, h1 error 0.048678
# epoch:  219	assembling the mass matrix time taken:  0.009225130081176758
# solving Ax = b time taken:  0.202866792678833
# l2 error 0.000984, h1 error 0.048403
# epoch:  220	assembling the mass matrix time taken:  0.006072521209716797
# solving Ax = b time taken:  0.2028195858001709
# l2 error 0.000983, h1 error 0.048223
# epoch:  221	assembling the mass matrix time taken:  0.20193243026733398
# solving Ax = b time taken:  0.11548066139221191
# l2 error 0.000972, h1 error 0.047845
# epoch:  222	assembling the mass matrix time taken:  0.009957313537597656
# solving Ax = b time taken:  0.202986478805542
# l2 error 0.000965, h1 error 0.047681
# epoch:  223	assembling the mass matrix time taken:  0.005953788757324219
# solving Ax = b time taken:  0.20879268646240234
# l2 error 0.000959, h1 error 0.047496
# epoch:  224	assembling the mass matrix time taken:  0.19781851768493652
# solving Ax = b time taken:  0.11520099639892578
# l2 error 0.000957, h1 error 0.047386
# epoch:  225	assembling the mass matrix time taken:  0.009589910507202148
# solving Ax = b time taken:  0.20627069473266602
# l2 error 0.000956, h1 error 0.047194
# epoch:  226	assembling the mass matrix time taken:  0.0060846805572509766
# solving Ax = b time taken:  0.20975613594055176
# l2 error 0.000947, h1 error 0.046957
# epoch:  227	assembling the mass matrix time taken:  0.24835538864135742
# solving Ax = b time taken:  0.11804008483886719
# l2 error 0.000940, h1 error 0.046735
# epoch:  228	assembling the mass matrix time taken:  0.00975656509399414
# solving Ax = b time taken:  0.20429062843322754
# l2 error 0.000936, h1 error 0.046585
# epoch:  229	assembling the mass matrix time taken:  0.005978822708129883
# solving Ax = b time taken:  0.21327686309814453
# l2 error 0.000923, h1 error 0.046128
# epoch:  230	assembling the mass matrix time taken:  0.29573798179626465
# solving Ax = b time taken:  0.11879348754882812
# l2 error 0.000915, h1 error 0.045960
# epoch:  231	assembling the mass matrix time taken:  0.009244203567504883
# solving Ax = b time taken:  0.21088719367980957
# l2 error 0.000910, h1 error 0.045815
# epoch:  232	assembling the mass matrix time taken:  0.006433725357055664
# solving Ax = b time taken:  0.2096402645111084
# l2 error 0.000909, h1 error 0.045672
# epoch:  233	assembling the mass matrix time taken:  0.3667585849761963
# solving Ax = b time taken:  0.12007689476013184
# l2 error 0.000906, h1 error 0.045522
# epoch:  234	assembling the mass matrix time taken:  0.007982492446899414
# solving Ax = b time taken:  0.21280622482299805
# l2 error 0.000896, h1 error 0.045169
# epoch:  235	assembling the mass matrix time taken:  0.00680232048034668
# solving Ax = b time taken:  0.21564435958862305
# l2 error 0.000894, h1 error 0.044940
# epoch:  236	assembling the mass matrix time taken:  0.22945117950439453
# solving Ax = b time taken:  0.14508819580078125
# l2 error 0.000889, h1 error 0.044685
# epoch:  237	assembling the mass matrix time taken:  0.009934186935424805
# solving Ax = b time taken:  0.2137773036956787
# l2 error 0.000884, h1 error 0.044512
# epoch:  238	assembling the mass matrix time taken:  0.006983280181884766
# solving Ax = b time taken:  0.21597075462341309
# l2 error 0.000881, h1 error 0.044289
# epoch:  239	assembling the mass matrix time taken:  0.3761904239654541
# solving Ax = b time taken:  0.12225937843322754
# l2 error 0.000874, h1 error 0.044109
# epoch:  240	assembling the mass matrix time taken:  0.007956266403198242
# solving Ax = b time taken:  0.21310043334960938
# l2 error 0.000868, h1 error 0.043880
# epoch:  241	assembling the mass matrix time taken:  0.006811618804931641
# solving Ax = b time taken:  0.21927762031555176
# l2 error 0.000859, h1 error 0.043617
# epoch:  242	assembling the mass matrix time taken:  0.2367541790008545
# solving Ax = b time taken:  0.14867854118347168
# l2 error 0.000850, h1 error 0.043394
# epoch:  243	assembling the mass matrix time taken:  0.009463071823120117
# solving Ax = b time taken:  0.21792268753051758
# l2 error 0.000850, h1 error 0.043290
# epoch:  244	assembling the mass matrix time taken:  0.007321357727050781
# solving Ax = b time taken:  0.21646380424499512
# l2 error 0.000843, h1 error 0.043126
# epoch:  245	assembling the mass matrix time taken:  0.38320040702819824
# solving Ax = b time taken:  0.12448573112487793
# l2 error 0.000839, h1 error 0.042939
# epoch:  246	assembling the mass matrix time taken:  0.008927583694458008
# solving Ax = b time taken:  0.22009921073913574
# l2 error 0.000838, h1 error 0.042781
# epoch:  247	assembling the mass matrix time taken:  0.0075206756591796875
# solving Ax = b time taken:  0.22247576713562012
# l2 error 0.000829, h1 error 0.042581
# epoch:  248	assembling the mass matrix time taken:  0.240586519241333
# solving Ax = b time taken:  0.14960050582885742
# l2 error 0.000824, h1 error 0.042419
# epoch:  249	assembling the mass matrix time taken:  0.010509490966796875
# solving Ax = b time taken:  0.22080349922180176
# l2 error 0.000822, h1 error 0.042312
# epoch:  250	assembling the mass matrix time taken:  0.007442951202392578
# solving Ax = b time taken:  0.22311806678771973
# l2 error 0.000820, h1 error 0.042143
# epoch:  251	assembling the mass matrix time taken:  0.31363558769226074
# solving Ax = b time taken:  0.15307998657226562
# l2 error 0.000808, h1 error 0.041658
# epoch:  252	assembling the mass matrix time taken:  0.01003122329711914
# solving Ax = b time taken:  0.21878671646118164
# l2 error 0.000805, h1 error 0.041538
# epoch:  253	assembling the mass matrix time taken:  0.008048534393310547
# solving Ax = b time taken:  0.22560572624206543
# l2 error 0.000800, h1 error 0.041391
# epoch:  254	assembling the mass matrix time taken:  0.4964907169342041
# solving Ax = b time taken:  0.12155652046203613
# l2 error 0.000794, h1 error 0.041158
# epoch:  255	assembling the mass matrix time taken:  0.007303476333618164
# solving Ax = b time taken:  0.22768449783325195
# l2 error 0.000788, h1 error 0.041010
# epoch:  256	assembling the mass matrix time taken:  0.00807499885559082
# solving Ax = b time taken:  0.22280502319335938
# l2 error 0.000785, h1 error 0.040882
# time taken:  106.92102432250977
# neuron num 		 error 		 order
# 4 		 0.187524 		 * 		 2.010464 		 *
#
# 8 		 0.095435 		 0.974486 		 1.434597 		 0.486883
#
# 16 		 0.069121 		 0.465389 		 1.094796 		 0.389983
#
# 32 		 0.019694 		 1.811391 		 0.413667 		 1.404119
#
# 64 		 0.006184 		 1.671084 		 0.182143 		 1.183400
#
# 128 		 0.002288 		 1.434211 		 0.089017 		 1.032920
#
# 256 		 0.000785 		 1.543761 		 0.040882 		 1.122602
