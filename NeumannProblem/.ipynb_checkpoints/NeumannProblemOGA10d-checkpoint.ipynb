# %%
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import time
import sys
import os 
from scipy.sparse import linalg
from pathlib import Path
import itertools
if torch.cuda.is_available():  
    device = "cuda" 
else:  
    device = "cpu"    


torch.set_default_dtype(torch.float64)
pi = torch.tensor(np.pi,dtype=torch.float64)
ZERO = torch.tensor([0.]).to(device)
torch.set_printoptions(precision=6)

class model(nn.Module):
    """ ReLU k shallow neural network
    Parameters: 
    input size: input dimension
    hidden_size1 : number of hidden layers 
    num_classes: output classes 
    k: degree of relu functions
    """
    def __init__(self, input_size, hidden_size1, num_classes,k = 1):
        super().__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, num_classes,bias = False)
        self.k = k 
    def forward(self, x):
        u1 = self.fc2(F.relu(self.fc1(x))**self.k)
        return u1
    def evaluate_derivative(self, x, i):
        if self.k == 1:
            u1 = self.fc2(torch.heaviside(self.fc1(x),ZERO) * self.fc1.weight.t()[i-1:i,:] )
        else:
            u1 = self.fc2(self.k*F.relu(self.fc1(x))**(self.k-1) *self.fc1.weight.t()[i-1:i,:] )  
        return u1

def adjust_neuron_position(my_model, dims = 3):

    def create_mesh_grid(dims, pts):
        mesh = torch.tensor(list(itertools.product(pts,repeat=dims)))
        vertices = mesh.reshape(len(pts) ** dims, -1) 
        return vertices
    counter = 0 
    # positions = torch.tensor([[0.,0.],[0.,1.],[1.,1.],[1.,0.]])
    pts = torch.tensor([0.,1.])
    positions = create_mesh_grid(dims,pts) 
    neuron_num = my_model.fc1.bias.size(0)
    for i in range(neuron_num): 
        w = my_model.fc1.weight.data[i:i+1,:]
        b = my_model.fc1.bias.data[i]
    #     print(w,b)
        values = torch.matmul(positions,w.T) # + b
        left_end = - torch.max(values)
        right_end = - torch.min(values)
        offset = (right_end - left_end)/50
        if b <= left_end + offset/2 : 
            b = torch.rand(1)*(right_end - left_end - offset) + left_end + offset/2 
            my_model.fc1.bias.data[i] = b 
        if b >= right_end - offset/2 :
            if counter < (dims+1):
#                 print("here")
                counter += 1
            else: # (d + 1) or more 
                b = torch.rand(1)*(right_end - left_end - offset) + left_end + offset/2 
                my_model.fc1.bias.data[i] = b 
    return my_model

# %%
def show_convergence_order2(err_l2,err_h10,exponent,dict_size, filename,write2file = False):
    
    if write2file:
        file_mode = "a" if os.path.exists(filename) else "w"
        f_write = open(filename, file_mode)
    
    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_l2[i] for i in neuron_nums ]
    err_list2 = [err_h10[i] for i in neuron_nums ] 
    # f_write.write('M:{}, relu {} \n'.format(M,k))
    if write2file:
        f_write.write('dictionary size: {}\n'.format(dict_size))
        f_write.write("neuron num \t\t error \t\t order \t\t h10 error \\ order \n")
    print("neuron num \t\t error \t\t order")
    for i, item in enumerate(err_list):
        if i == 0: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t")
            
            # print("*")
            print("{} \t\t {:.6f} \t\t * \t\t {:.6f} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ) )
            if write2file: 
                f_write.write("{} \t\t {} \t\t * \t\t {} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ))
        else: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t") 
            # print(np.log(err_list[i-1]/err_list[i])/np.log(2))
            print("{} \t\t {:.6f} \t\t {:.6f} \t\t {:.6f} \t\t {:.6f} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ) )
            if write2file: 
                f_write.write("{} \t\t {} \t\t {} \t\t {} \t\t {} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ))
    if write2file:     
        f_write.write("\n")
        f_write.close()

def show_convergence_order_latex2(err_l2,err_h10,exponent,k=1,d=1): 
    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_l2[i] for i in neuron_nums ]
    err_list2 = [err_h10[i] for i in neuron_nums ] 
    l2_order = -1/2-(2*k + 1)/(2*d)
    h1_order =  -1/2-(2*(k-1)+ 1)/(2*d)
    print("neuron num  & \t $\|u-u_n \|_{{L^2}}$ & \t order $O(n^{{{:.2f}}})$  & \t $ | u -u_n |_{{H^1}}$ & \t order $O(n^{{{:.2f}}})$  \\\ \hline \hline ".format(l2_order,h1_order))
    for i, item in enumerate(err_list):
        if i == 0: 
            print("{} \t\t & {:.6f} &\t\t * & \t\t {:.6f} & \t\t *  \\\ \hline  \n".format(neuron_nums[i],item, err_list2[i] ) )   
        else: 
            print("{} \t\t &  {:.3e} &  \t\t {:.2f} &  \t\t {:.3e} &  \t\t {:.2f} \\\ \hline  \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ) )

# %%
def MonteCarlo_Sobol_dDim_weights_points(M ,d = 4):
    Sob_integral = torch.quasirandom.SobolEngine(dimension =d, scramble= False, seed=None) 
    integration_points = Sob_integral.draw(M).double() 
    integration_points = integration_points.to(device)
    weights = torch.ones(M,1).to(device)/M 
    return weights, integration_points 

def generate_relu_dict4D(N_list):
    
    N = np.prod(N_list) 

    grid_indices = [np.linspace(0,1,N_item,endpoint=False) for N_item in N_list]
    grid = np.meshgrid(*grid_indices,indexing='ij')
    grid_coordinates = np.column_stack([axis.ravel() for axis in grid]) 
    samples = torch.tensor(grid_coordinates) 

    T =torch.tensor([[pi,0,0,0],[0,pi,0,0],[0,0,2*pi,0],[0,0,0,2*2]]) # 2 * sqrt(d)
    shift = torch.tensor([0,0,0,-2])
    samples = samples@T + shift 

    f1 = torch.zeros(N,1) 
    f2 = torch.zeros(N,1)
    f3 = torch.zeros(N,1)
    f4 = torch.zeros(N,1)
    f5 = torch.zeros(N,1)

    f1[:,0] = torch.cos(samples[:,0]) 
    f2[:,0] = torch.sin(samples[:,0]) * torch.cos(samples[:,1])
    f3[:,0] = torch.sin(samples[:,0]) * torch.sin(samples[:,1]) * torch.cos(samples[:,2])
    f4[:,0] = torch.sin(samples[:,0]) * torch.sin(samples[:,1]) * torch.sin(samples[:,2])  
    f5[:,0] = samples[:,3]

    Wb_tensor = torch.cat([f1,f2,f3,f4,f5],1) # N x 4 
    return Wb_tensor

def generate_relu_dict4plusD_QMC(dim, s,N0):
    # s*N0 is the total number of samples 
    samples = torch.rand(s*N0,dim)  

    # for i in range(s-1):
        # samples = torch.cat([samples,Sob.draw(N0).double()],0)
    # Form the transformation matrix and shift vector 
    diagonal = torch.ones(dim)*pi  
    diagonal[-1] =  2*dim**0.5
    diagonal[-2] = 2*pi 
    T = torch.diag(diagonal)

    shift = torch.zeros(dim)
    shift[-1] = -dim**0.5 
    samples = samples@T + shift 

    Wb_tensor = torch.ones(s*N0,dim+1) # each neuron parameter stored in rows  
    for i in range(dim): # 0, 1, ... dim-1 
        for j in range(i+1): # 0, 1, ... i 
            if i == 0: 
                Wb_tensor[:,i] = Wb_tensor[:,i]*torch.cos(samples[:,j])
            if i == (dim - 1):
                if j != i:
                    Wb_tensor[:,i] = Wb_tensor[:,i] * torch.sin(samples[:,j]) 
            if i != 0 and i != (dim - 1): 
                if j != i: 
                    Wb_tensor[:,i] = Wb_tensor[:,i] * torch.sin(samples[:,j]) 
                else: 
                    Wb_tensor[:,i] = Wb_tensor[:,i] * torch.cos(samples[:,j]) 
            
    Wb_tensor[:,dim] = samples[:,-1] 

    return Wb_tensor.to(device)

def minimize_linear_layer_H1_explicit_assemble_efficient(model,alpha, target, g_N, weights, integration_points, w_bd, pts_bd, activation = 'relu',solver="direct",memory = 2**29 ):
    """ -div alpha grad u(x) + u = f 
    Parameters
    ----------
    model: 
        nn model
    alpha:
        alpha function
    target:
        rhs function f 
    pts_bd:
        integration points on the boundary, embdedded in the domain 
    """ 
    start_time = time.time() 
    w = model.fc1.weight.data 
    b = model.fc1.bias.data 
    neuron_num = b.size(0) 
    dim = integration_points.size(1) 
    M = integration_points.size(0)
    coef_alpha = alpha(integration_points) # alpha  
    
    total_size = neuron_num * M # memory, number of floating numbers 
    print('total size: {} {} = {}'.format(neuron_num,M,total_size))
    num_batch = total_size//memory + 1 # divide according to memory
    print("num batches: ",num_batch)
    batch_size = M//num_batch
    start_ind = 0
    end_ind = 0 
    jac = torch.zeros(b.size(0),b.size(0)).to(device)
    rhs = torch.zeros(b.size(0),1).to(device)

    for j in range(0,M,batch_size): # batch operation in data points 
        end_ind = j + batch_size
        basis_value_col = F.relu(integration_points[j:end_ind] @ w.t()+ b)**(model.k) 
        weighted_basis_value_col = basis_value_col * weights[j:end_ind] 
        jac += weighted_basis_value_col.t() @ basis_value_col 
        rhs += weighted_basis_value_col.t() @ (target(integration_points[j:end_ind,:])) 

    # Assemble the boundary condition term <g,v>_{\Gamma_N} 
    size_pts_bd = int(pts_bd.size(0)/(2*dim))
    # M_bc = size_pts_bd 
    # total_size = M_bc * neuron_num 
    # num_batch = total_size//memory + 1 
    # batch_size = M_bc//num_batch
    if g_N != None:
        bcs_N = g_N(dim)
        for ii, g_ii in bcs_N:
            weighted_g_N = -g_ii(pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:])* w_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
            basis_value_bd_col = F.relu(pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:] @ w.t()+ b)**(model.k)
            rhs += basis_value_bd_col.t() @ weighted_g_N

            weighted_g_N = g_ii(pts_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:])* w_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:]
            basis_value_bd_col = F.relu(pts_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:] @ w.t()+ b)**(model.k)
            rhs += basis_value_bd_col.t() @ weighted_g_N
            
    # Stiffness matrix term in the jacobian 
    for d in range(dim):
        end_ind = 0 
        if model.k == 1:  
            for j in range(0,M,batch_size): 
                end_ind = j + batch_size 
                basis_value_dxi_col = torch.heaviside(integration_points[j:end_ind] @ w.t()+ b, ZERO) * w.t()[d:d+1,:]
                weighted_basis_value_dx_col = basis_value_dxi_col * weights[j:end_ind] * coef_alpha[j:end_ind] 
                jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 
#             basis_value_dxi_col = torch.heaviside(integration_points @ w.t()+ b, zero) * w.t()[d:d+1,:]
#             weighted_basis_value_dx_col = basis_value_dxi_col * weights * coef_alpha 
#             jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 

        else: 
            for j in range(0,M,batch_size):  
                end_ind = j + batch_size 
                basis_value_dxi_col = model.k * F.relu(integration_points[j:end_ind] @ w.t()+ b)**(model.k-1) * w.t()[d:d+1,:]
                weighted_basis_value_dx_col = basis_value_dxi_col * weights[j:end_ind] * coef_alpha[j:end_ind] 
                jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 
#             basis_value_dxi_col = model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * w.t()[d:d+1,:]
#             weighted_basis_value_dx_col = basis_value_dxi_col * weights * coef_alpha  
#             jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 

    print("assembling the mass matrix time taken: ", time.time()-start_time) 

    start_time = time.time()    
    if solver == "cg": 
        sol, exit_code = linalg.cg(np.array(jac.detach().cpu()),np.array(rhs.detach().cpu()),tol=1e-12)
        sol = torch.tensor(sol).view(1,-1)
    elif solver == "direct": 
#         sol = np.linalg.inv( np.array(jac.detach().cpu()) )@np.array(rhs.detach().cpu())
        sol = (torch.linalg.solve( jac.detach(), rhs.detach())).view(1,-1)
    elif solver == "ls":
        sol = (torch.linalg.lstsq(jac.detach().cpu(),rhs.detach().cpu(),driver='gelsd').solution).view(1,-1)
        # sol = (torch.linalg.lstsq(jac.detach(),rhs.detach()).solution).view(1,-1) # gpu/cpu, driver = 'gels', cannot solve singular
    print("solving Ax = b time taken: ", time.time()-start_time)
    return sol 


def OGANeumannReLU10D(my_model,alpha, target,g_N, u_exact, u_exact_grad, N_list,num_epochs,plot_freq, M, k =1, rand_deter = 'deter', linear_solver = "direct",memory = 2**29): 
    """ Orthogonal greedy algorithm using 1D ReLU dictionary over [-pi,pi]
    Parameters
    ----------
    my_model: 
        nn model 
    target: 
        target function
    num_epochs: int 
        number of training epochs 
    integration_intervals: int 
        number of subintervals for piecewise numerical quadrature 

    Returns
    -------
    err: tensor 
        rank 1 torch tensor to record the L2 error history  
    model: 
        trained nn model 
    """
    #Todo Done
    dim = 10 
    gw_expand, integration_points = MonteCarlo_Sobol_dDim_weights_points(M, d=dim)
    gw_expand = gw_expand.to(device)
    integration_points = integration_points.to(device)

    # define integration on the boundary 
    gw_expand_bd, integration_points_bd = MonteCarlo_Sobol_dDim_weights_points(M//10, d=dim-1)
    size_pts_bd = integration_points_bd.size(0) 
    gw_expand_bd_faces = torch.tile(gw_expand_bd,(2*dim,1))
    
    integration_points_bd_faces = torch.zeros(2*dim*integration_points_bd.size(0),dim).to(device)
    for ind in range(dim): 
        integration_points_bd_faces[2 *ind * size_pts_bd :(2 *ind +1) * size_pts_bd,ind:ind+1] = 0 
        integration_points_bd_faces[(2 *ind)*size_pts_bd :(2 * ind +1) * size_pts_bd,:ind] = integration_points_bd[:,:ind]
        integration_points_bd_faces[(2 *ind)*size_pts_bd :(2 * ind +1) * size_pts_bd,ind+1:] = integration_points_bd[:,ind:]

        integration_points_bd_faces[(2 *ind +1) * size_pts_bd:(2 *ind +2)*size_pts_bd,ind:ind+1] = 1
        integration_points_bd_faces[(2 *ind +1) * size_pts_bd:(2 *ind +2)*size_pts_bd,:ind] = integration_points_bd[:,:ind]        
        integration_points_bd_faces[(2 *ind +1) * size_pts_bd:(2 *ind +2)*size_pts_bd,ind+1:] = integration_points_bd[:,ind:]


    err = torch.zeros(num_epochs+1)
    err_h10 = torch.zeros(num_epochs+1).to(device) 
    if my_model == None: 
        func_values = - target(integration_points)
        num_neuron = 0

        list_b = []
        list_w = []
    else: 
        func_values = - (target(integration_points) + my_model(integration_points).detach())
        bias = my_model.fc1.bias.detach().data
        weights = my_model.fc1.weight.detach().data
        num_neuron = int(bias.size(0))

        list_b = list(bias)
        list_w = list(weights)
    
    ## l2 error 
    func_values_sqrd = func_values*func_values
    err[0]= torch.sum(func_values_sqrd*gw_expand)**0.5
    ## h1 seminorm 
    if u_exact_grad != None:
        u_grad = u_exact_grad() 
        for grad_i in u_grad: 
            err_h10[0] += torch.sum((grad_i(integration_points))**2 * gw_expand)**0.5
    
    start_time = time.time()
    solver = linear_solver

    N0 = np.prod(N_list)
    if rand_deter == 'deter':
#         relu_dict_parameters = generate_relu_dict4D(N_list).to(device)
        assert rand_deter == "rand", "no deterministic dictionary, dimension"+str(dim)+"too large"
    
    print("using linear solver: ",solver)
    M2 = integration_points.size(0) # add 
    for i in range(num_epochs): 
        start_time = time.time()
        print("epoch: ",i+1, end = '\t')
        if rand_deter == 'rand':
            relu_dict_parameters = generate_relu_dict4plusD_QMC(dim, 1,N0).to(device) 
        if num_neuron == 0: 
            func_values = - target(integration_points)
        else: 
            func_values = - target(integration_points) + my_model(integration_points).detach()

        weight_func_values = func_values*gw_expand 

        ### ======================= 
        total_size = M2 * N0 
        num_batch = total_size//memory + 1 
        batch_size = N0//num_batch
        output = torch.zeros(N0,1).to(device)
        print("argmax batch num, ", num_batch) 
        
        for j in range(0,N0,batch_size):  
            end_index = j + batch_size  
            basis_values_batch = (F.relu( torch.matmul(integration_points,relu_dict_parameters[j:end_index,0:dim].T ) - relu_dict_parameters[j:end_index,dim])**k).T # uses broadcasting    
            output[j:end_index,:]  = torch.matmul(basis_values_batch,weight_func_values)[:,:] 
        
        # grad u part
        alpha_coef = alpha(integration_points) # alpha 
        if my_model!= None:
            if k == 1:  
                for j in range(0,N0,batch_size):  
                    end_index = j + batch_size 
                    derivative_part = torch.heaviside(integration_points @ (relu_dict_parameters[j:end_index,0:dim].T) - relu_dict_parameters[j:end_index,dim], ZERO) # dimension 4 
                    derivative_part *= alpha_coef # alpha 
                    for dx_i in range(dim): 

                        weight_dbasis_values_dxi =  (derivative_part * relu_dict_parameters.t()[dx_i:dx_i+1,j:end_index]) *gw_expand   
                        dmy_model_dxi = my_model.evaluate_derivative(integration_points,dx_i+1).detach()
                        output[j:end_index,:] += torch.matmul(weight_dbasis_values_dxi.t(), dmy_model_dxi) 


            else:  
                for j in range(0,N0,batch_size):  
                    end_index = j + batch_size 
                    derivative_part = k * F.relu(integration_points @ (relu_dict_parameters[j:end_index,0:dim].T) - relu_dict_parameters[j:end_index,dim])**(k-1) # dimension 4 
                    derivative_part *= alpha_coef # alpha
                    for dx_i in range(dim): 

                        weight_dbasis_values_dxi =  (derivative_part * relu_dict_parameters.t()[dx_i:dx_i+1,j:end_index]) * gw_expand    
                        dmy_model_dxi = my_model.evaluate_derivative(integration_points,dx_i+1).detach()
                        output[j:end_index,:] += torch.matmul(weight_dbasis_values_dxi.t(), dmy_model_dxi) 

        
        #Boundary condition term -<g,v>_{\Gamma_N}  
        M_bc = size_pts_bd 
        total_size = M_bc * N0 
        num_batch = total_size//memory + 1 
        batch_size = N0//num_batch
        if g_N != None:
            bcs_N = g_N(dim) 
            for ii, g_ii in bcs_N: 
                
                weighted_g_N = -g_ii(integration_points_bd_faces[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:])* gw_expand_bd_faces[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
                ## todo 
                for j in range(0,N0,batch_size):  
                    end_index = j + batch_size 
                    basis_values_bd_faces = (F.relu( torch.matmul(integration_points_bd_faces[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:],relu_dict_parameters[j:end_index,0:dim].T ) - relu_dict_parameters[j:end_index,dim])**k).T
                    output[j:end_index,:] -= torch.matmul(basis_values_bd_faces,weighted_g_N)
                # basis_values_bd_faces = (F.relu( torch.matmul(integration_points_bd_faces[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:],relu_dict_parameters[:,0:dim].T ) - relu_dict_parameters[:,dim])**k).T
                # output -= torch.matmul(basis_values_bd_faces,weighted_g_N)
                
                weighted_g_N = g_ii(integration_points_bd_faces[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:])* gw_expand_bd_faces[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:]
                ## todo  
                for j in range(0,N0,batch_size): 
                    end_index = j + batch_size 
                    basis_values_bd_faces = (F.relu( torch.matmul(integration_points_bd_faces[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:],relu_dict_parameters[j:end_index,0:dim].T ) - relu_dict_parameters[j:end_index,dim])**k).T
                    output[j:end_index,:] -= torch.matmul(basis_values_bd_faces,weighted_g_N)

                # basis_values_bd_faces = (F.relu( torch.matmul(integration_points_bd_faces[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:],relu_dict_parameters[:,0:dim].T ) - relu_dict_parameters[:,dim])**k).T
                # output -= torch.matmul(basis_values_bd_faces,weighted_g_N)
        
        # output = torch.abs(torch.matmul(basis_values,weight_func_values)) # 
        output = torch.abs(output)
        neuron_index = torch.argmax(output.flatten())
        print("argmax time taken, ", time.time() - start_time)
        # print(neuron_index)
        list_w.append(relu_dict_parameters[neuron_index,0:dim]) # dimension 4 
        list_b.append(-relu_dict_parameters[neuron_index,dim])
        num_neuron += 1
        my_model = model(dim,num_neuron,1,k).to(device)
        w_tensor = torch.stack(list_w, 0 ) 
        b_tensor = torch.tensor(list_b)
        my_model.fc1.weight.data[:,:] = w_tensor[:,:]
        my_model.fc1.bias.data[:] = b_tensor[:]

        #Todo Done 
#         alpha = None 
        sol = minimize_linear_layer_H1_explicit_assemble_efficient(my_model,alpha, target, g_N, gw_expand, integration_points,gw_expand_bd_faces, integration_points_bd_faces,activation = 'relu',solver = solver)

        my_model.fc2.weight.data[0,:] = sol[:]
        with torch.no_grad():
            model_values = my_model(integration_points)
        # L2 error ||u - u_n||
        diff_values_sqrd = (u_exact(integration_points) - model_values)**2 
        err[i+1]= torch.sum(diff_values_sqrd*gw_expand)**0.5

        # H10 error || grad(u) - grad(u_n) ||
        if u_exact_grad != None:
            for ind, grad_i in enumerate(u_grad):  
                with torch.no_grad():
                    my_model_dxi = my_model.evaluate_derivative(integration_points,ind+1).detach() 
                err_h10[i+1] += torch.sum((grad_i(integration_points) - my_model_dxi)**2 * gw_expand)**0.5
        print("l2 error {:.6f}, h1 error {:.6f}".format(err[i+1],err_h10[i+1]))
        print()
    print("time taken: ",time.time() - start_time)
    return err, err_h10.cpu(), my_model

# %% [markdown]
# In the following tests, we compare using deterministic dictionaries with using random dictionary for the following three target functions.
#
# - $\sin(\pi x_1) \sin(\pi x_2)$
# - $\sin(4\pi x_1) \sin(8\pi x_2)$
# - Gabor function

# %%
def u_exact(x):
    d = 10  
    cn =   7.03/d 
    return torch.exp(-torch.sum( cn**2 * (x - 0.5)**2,dim = 1, keepdim = True))  

def u_exact_grad():

    def make_grad_i(i):
        def grad_i(x):
            d = 10  
            cn = 7.03/d
            return torch.exp(-torch.sum(cn**2 * (x - 0.5)**2, dim=1, keepdim=True)) * (-2 * cn**2 * (x[:, i:i+1] - 0.5))
        return grad_i 
    
    u_grad=[] 
    for i in range(10):
        u_grad.append(make_grad_i(i))
    return u_grad
                                                                
                                                                    
def alpha(x): 
    return torch.ones(x.size(0),1).to(device)

def target(x):
    d = 10 
    cn =   7.03/d 
    z = torch.exp(-torch.sum( cn**2 * (x - 0.5)**2,dim = 1, keepdim = True)) 
    return z* ( -torch.sum(  (2 *cn**2 * (x - 0.5))**2 - 2*cn**2 ,dim = 1, keepdim = True) +1)

def g_N(dim):
    def make_g(i):
        def g_i(x):
            d = 10  
            cn = 7.03 / d
            return torch.exp(-torch.sum(cn**2 * (x - 0.5)**2, dim=1, keepdim=True)) * (-2 * cn**2 * (x[:, i:i+1] - 0.5))
        return g_i

    bcs_N = []
    for i in range(dim):
        bcs_N.append((i, make_g(i)))
    
    return bcs_N

dim = 10 
function_name = "gaussian" 
filename_write = "data/10DOGA-{}-order.txt".format(function_name)
M = int(2**19) 
f_write = open(filename_write, "a")
f_write.write("Numerical Integration MC points: {} \n".format(M))
f_write.close() 
save = True 
write2file = True
rand_deter = 'rand'

for N_list in [[2**10]]: # ,[2**6,2**6],[2**7,2**7] 
    # save = True 
    f_write = open(filename_write, "a")
    my_model = None 
    exponent = 9 
    num_epochs = 2**exponent  
    plot_freq = num_epochs 
    N = np.prod(N_list)
    relu_k = 4 
    err_QMC2, err_h10, my_model = OGANeumannReLU10D(my_model,alpha, target,g_N, u_exact,u_exact_grad, N_list,num_epochs,plot_freq, M, k = relu_k, rand_deter= rand_deter, linear_solver = "direct")
    
    if save: 
        folder = 'data/'
        filename = folder + 'err_OGA_10D_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,num_epochs,N)
        torch.save(err_QMC2,filename) 
        folder = 'data/'
        filename = folder + 'model_OGA_10D_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,num_epochs,N)
        torch.save(my_model,filename)
        
    show_convergence_order2(err_QMC2,err_h10,exponent,N,filename_write,write2file = write2file)
    show_convergence_order_latex2(err_QMC2,err_h10,exponent,k=relu_k,d = dim)
# Out:
# using linear solver:  direct
# epoch:  1	argmax batch num,  2
# argmax time taken,  0.03701353073120117
# total size: 1 524288 = 524288
# num batches:  1
# assembling the mass matrix time taken:  0.0060312747955322266
# solving Ax = b time taken:  0.00018405914306640625
# l2 error 0.386720, h1 error 2.107200
#
# epoch:  2	argmax batch num,  2
# argmax time taken,  0.0413057804107666
# total size: 2 524288 = 1048576
# num batches:  1
# assembling the mass matrix time taken:  0.0075109004974365234
# solving Ax = b time taken:  0.0015666484832763672
# l2 error 0.257125, h1 error 2.122811
#
# epoch:  3	argmax batch num,  2
# argmax time taken,  0.03828740119934082
# total size: 3 524288 = 1572864
# num batches:  1
# assembling the mass matrix time taken:  0.006812572479248047
# solving Ax = b time taken:  0.0018534660339355469
# l2 error 0.196146, h1 error 2.100717
#
# epoch:  4	argmax batch num,  2
# argmax time taken,  0.038239479064941406
# total size: 4 524288 = 2097152
# num batches:  1
# assembling the mass matrix time taken:  0.007157087326049805
# solving Ax = b time taken:  0.0021965503692626953
# l2 error 0.167917, h1 error 2.081836
#
# epoch:  5	argmax batch num,  2
# argmax time taken,  0.0383753776550293
# total size: 5 524288 = 2621440
# num batches:  1
# assembling the mass matrix time taken:  0.013281822204589844
# solving Ax = b time taken:  0.0027441978454589844
# l2 error 0.156279, h1 error 2.070751
#
# epoch:  6	argmax batch num,  2
# argmax time taken,  0.03832101821899414
# total size: 6 524288 = 3145728
# num batches:  1
# assembling the mass matrix time taken:  0.013973712921142578
# solving Ax = b time taken:  0.003304004669189453
# l2 error 0.141083, h1 error 2.061061
#
# epoch:  7	argmax batch num,  2
# argmax time taken,  0.05777144432067871
# total size: 7 524288 = 3670016
# num batches:  1
# assembling the mass matrix time taken:  0.006926536560058594
# solving Ax = b time taken:  0.003726959228515625
# l2 error 0.136976, h1 error 2.046094
#
# epoch:  8	argmax batch num,  2
# argmax time taken,  0.03850507736206055
# total size: 8 524288 = 4194304
# num batches:  1
# assembling the mass matrix time taken:  0.006966829299926758
# solving Ax = b time taken:  0.004110574722290039
# l2 error 0.127425, h1 error 2.024406
#
# epoch:  9	argmax batch num,  2
# argmax time taken,  0.038378238677978516
# total size: 9 524288 = 4718592
# num batches:  1
# assembling the mass matrix time taken:  0.013112545013427734
# solving Ax = b time taken:  0.004552364349365234
# l2 error 0.129158, h1 error 2.006011
#
# epoch:  10	argmax batch num,  2
# argmax time taken,  0.0385434627532959
# total size: 10 524288 = 5242880
# num batches:  1
# assembling the mass matrix time taken:  0.0070953369140625
# solving Ax = b time taken:  0.004976987838745117
# l2 error 0.122356, h1 error 1.978855
#
# epoch:  11	argmax batch num,  2
# argmax time taken,  0.03849935531616211
# total size: 11 524288 = 5767168
# num batches:  1
# assembling the mass matrix time taken:  0.019338607788085938
# solving Ax = b time taken:  0.0054056644439697266
# l2 error 0.111249, h1 error 1.929399
#
# epoch:  12	argmax batch num,  2
# argmax time taken,  0.06422948837280273
# total size: 12 524288 = 6291456
# num batches:  1
# assembling the mass matrix time taken:  0.019357919692993164
# solving Ax = b time taken:  0.0058155059814453125
# l2 error 0.102566, h1 error 1.873923
#
# epoch:  13	argmax batch num,  2
# argmax time taken,  0.06425118446350098
# total size: 13 524288 = 6815744
# num batches:  1
# assembling the mass matrix time taken:  0.019195556640625
# solving Ax = b time taken:  0.006199359893798828
# l2 error 0.097864, h1 error 1.862403
#
# epoch:  14	argmax batch num,  2
# argmax time taken,  0.06426048278808594
# total size: 14 524288 = 7340032
# num batches:  1
# assembling the mass matrix time taken:  0.007090091705322266
# solving Ax = b time taken:  0.006529331207275391
# l2 error 0.096010, h1 error 1.840879
#
# epoch:  15	argmax batch num,  2
# argmax time taken,  0.03850865364074707
# total size: 15 524288 = 7864320
# num batches:  1
# assembling the mass matrix time taken:  0.0069730281829833984
# solving Ax = b time taken:  0.0070819854736328125
# l2 error 0.099196, h1 error 1.815215
#
# epoch:  16	argmax batch num,  2
# argmax time taken,  0.03856062889099121
# total size: 16 524288 = 8388608
# num batches:  1
# assembling the mass matrix time taken:  0.01309347152709961
# solving Ax = b time taken:  0.0073702335357666016
# l2 error 0.091959, h1 error 1.776684
#
# epoch:  17	argmax batch num,  2
# argmax time taken,  0.03864121437072754
# total size: 17 524288 = 8912896
# num batches:  1
# assembling the mass matrix time taken:  0.019272804260253906
# solving Ax = b time taken:  0.007809638977050781
# l2 error 0.086773, h1 error 1.722263
#
# epoch:  18	argmax batch num,  2
# argmax time taken,  0.06432080268859863
# total size: 18 524288 = 9437184
# num batches:  1
# assembling the mass matrix time taken:  0.01938033103942871
# solving Ax = b time taken:  0.00819706916809082
# l2 error 0.088485, h1 error 1.664980
#
# epoch:  19	argmax batch num,  2
# argmax time taken,  0.06431794166564941
# total size: 19 524288 = 9961472
# num batches:  1
# assembling the mass matrix time taken:  0.019179821014404297
# solving Ax = b time taken:  0.008623600006103516
# l2 error 0.086503, h1 error 1.645545
#
# epoch:  20	argmax batch num,  2
# argmax time taken,  0.06432414054870605
# total size: 20 524288 = 10485760
# num batches:  1
# assembling the mass matrix time taken:  0.020734071731567383
# solving Ax = b time taken:  0.009032011032104492
# l2 error 0.081489, h1 error 1.554506
#
# epoch:  21	argmax batch num,  2
# argmax time taken,  0.06460905075073242
# total size: 21 524288 = 11010048
# num batches:  1
# assembling the mass matrix time taken:  0.019268512725830078
# solving Ax = b time taken:  0.00939321517944336
# l2 error 0.080884, h1 error 1.533418
#
# epoch:  22	argmax batch num,  2
# argmax time taken,  0.05374288558959961
# total size: 22 524288 = 11534336
# num batches:  1
# assembling the mass matrix time taken:  0.0068857669830322266
# solving Ax = b time taken:  0.00982975959777832
# l2 error 0.080551, h1 error 1.531494
#
# epoch:  23	argmax batch num,  2
# argmax time taken,  0.0387423038482666
# total size: 23 524288 = 12058624
# num batches:  1
# assembling the mass matrix time taken:  0.013193368911743164
# solving Ax = b time taken:  0.010232925415039062
# l2 error 0.079535, h1 error 1.512888
#
# epoch:  24	argmax batch num,  2
# argmax time taken,  0.03873705863952637
# total size: 24 524288 = 12582912
# num batches:  1
# assembling the mass matrix time taken:  0.013571739196777344
# solving Ax = b time taken:  0.010652780532836914
# l2 error 0.075290, h1 error 1.393253
#
# epoch:  25	argmax batch num,  2
# argmax time taken,  0.03880620002746582
# total size: 25 524288 = 13107200
# num batches:  1
# assembling the mass matrix time taken:  0.0067920684814453125
# solving Ax = b time taken:  0.011009931564331055
# l2 error 0.073021, h1 error 1.363878
#
# epoch:  26	argmax batch num,  2
# argmax time taken,  0.03885054588317871
# total size: 26 524288 = 13631488
# num batches:  1
# assembling the mass matrix time taken:  0.013384342193603516
# solving Ax = b time taken:  0.01150202751159668
# l2 error 0.068899, h1 error 1.303975
#
# epoch:  27	argmax batch num,  2
# argmax time taken,  0.0388493537902832
# total size: 27 524288 = 14155776
# num batches:  1
# assembling the mass matrix time taken:  0.013161897659301758
# solving Ax = b time taken:  0.012033939361572266
# l2 error 0.066572, h1 error 1.278485
#
# epoch:  28	argmax batch num,  2
# argmax time taken,  0.03892111778259277
# total size: 28 524288 = 14680064
# num batches:  1
# assembling the mass matrix time taken:  0.013276100158691406
# solving Ax = b time taken:  0.01241159439086914
# l2 error 0.061869, h1 error 1.222920
#
# epoch:  29	argmax batch num,  2
# argmax time taken,  0.0389409065246582
# total size: 29 524288 = 15204352
# num batches:  1
# assembling the mass matrix time taken:  0.019395112991333008
# solving Ax = b time taken:  0.012988567352294922
# l2 error 0.058930, h1 error 1.150094
#
# epoch:  30	argmax batch num,  2
# argmax time taken,  0.06465888023376465
# total size: 30 524288 = 15728640
# num batches:  1
# assembling the mass matrix time taken:  0.0073087215423583984
# solving Ax = b time taken:  0.013489723205566406
# l2 error 0.057527, h1 error 1.113883
#
# epoch:  31	argmax batch num,  2
# argmax time taken,  0.039122581481933594
# total size: 31 524288 = 16252928
# num batches:  1
# assembling the mass matrix time taken:  0.0066070556640625
# solving Ax = b time taken:  0.013979196548461914
# l2 error 0.057401, h1 error 1.095833
#
# epoch:  32	argmax batch num,  2
# argmax time taken,  0.03902626037597656
# total size: 32 524288 = 16777216
# num batches:  1
# assembling the mass matrix time taken:  0.01963639259338379
# solving Ax = b time taken:  0.015250921249389648
# l2 error 0.057717, h1 error 1.073740
#
# epoch:  33	argmax batch num,  2
# argmax time taken,  0.06463003158569336
# total size: 33 524288 = 17301504
# num batches:  1
# assembling the mass matrix time taken:  0.019628286361694336
# solving Ax = b time taken:  0.01607203483581543
# l2 error 0.056793, h1 error 1.052732
#
# epoch:  34	argmax batch num,  2
# argmax time taken,  0.05412626266479492
# total size: 34 524288 = 17825792
# num batches:  1
# assembling the mass matrix time taken:  0.006832599639892578
# solving Ax = b time taken:  0.0156705379486084
# l2 error 0.056269, h1 error 1.038782
#
# epoch:  35	argmax batch num,  2
# argmax time taken,  0.04066658020019531
# total size: 35 524288 = 18350080
# num batches:  1
# assembling the mass matrix time taken:  0.006727933883666992
# solving Ax = b time taken:  0.017001628875732422
# l2 error 0.054811, h1 error 1.022528
#
# epoch:  36	argmax batch num,  2
# argmax time taken,  0.04070591926574707
# total size: 36 524288 = 18874368
# num batches:  1
# assembling the mass matrix time taken:  0.007529258728027344
# solving Ax = b time taken:  0.016428709030151367
# l2 error 0.053283, h1 error 1.004472
#
# epoch:  37	argmax batch num,  2
# argmax time taken,  0.040448904037475586
# total size: 37 524288 = 19398656
# num batches:  1
# assembling the mass matrix time taken:  0.013005971908569336
# solving Ax = b time taken:  0.017972469329833984
# l2 error 0.051844, h1 error 0.963505
#
# epoch:  38	argmax batch num,  2
# argmax time taken,  0.040506601333618164
# total size: 38 524288 = 19922944
# num batches:  1
# assembling the mass matrix time taken:  0.007425785064697266
# solving Ax = b time taken:  0.016857624053955078
# l2 error 0.050134, h1 error 0.931667
#
# epoch:  39	argmax batch num,  2
# argmax time taken,  0.040567874908447266
# total size: 39 524288 = 20447232
# num batches:  1
# assembling the mass matrix time taken:  0.006460905075073242
# solving Ax = b time taken:  0.01883220672607422
# l2 error 0.049298, h1 error 0.913985
#
# epoch:  40	argmax batch num,  2
# argmax time taken,  0.0406193733215332
# total size: 40 524288 = 20971520
# num batches:  1
# assembling the mass matrix time taken:  0.007264614105224609
# solving Ax = b time taken:  0.017916440963745117
# l2 error 0.045833, h1 error 0.856563
#
# epoch:  41	argmax batch num,  2
# argmax time taken,  0.040680885314941406
# total size: 41 524288 = 21495808
# num batches:  1
# assembling the mass matrix time taken:  0.006692409515380859
# solving Ax = b time taken:  0.019398927688598633
# l2 error 0.044321, h1 error 0.824597
#
# epoch:  42	argmax batch num,  2
# argmax time taken,  0.04071187973022461
# total size: 42 524288 = 22020096
# num batches:  1
# assembling the mass matrix time taken:  0.007035017013549805
# solving Ax = b time taken:  0.019042491912841797
# l2 error 0.043103, h1 error 0.808359
#
# epoch:  43	argmax batch num,  2
# argmax time taken,  0.04074883460998535
# total size: 43 524288 = 22544384
# num batches:  1
# assembling the mass matrix time taken:  0.006734132766723633
# solving Ax = b time taken:  0.020377397537231445
# l2 error 0.042611, h1 error 0.796587
#
# epoch:  44	argmax batch num,  2
# argmax time taken,  0.04068303108215332
# total size: 44 524288 = 23068672
# num batches:  1
# assembling the mass matrix time taken:  0.00729823112487793
# solving Ax = b time taken:  0.019787073135375977
# l2 error 0.041996, h1 error 0.785884
#
# epoch:  45	argmax batch num,  2
# argmax time taken,  0.04080629348754883
# total size: 45 524288 = 23592960
# num batches:  1
# assembling the mass matrix time taken:  0.006670475006103516
# solving Ax = b time taken:  0.021314382553100586
# l2 error 0.038473, h1 error 0.726479
#
# epoch:  46	argmax batch num,  2
# argmax time taken,  0.04079413414001465
# total size: 46 524288 = 24117248
# num batches:  1
# assembling the mass matrix time taken:  0.006989955902099609
# solving Ax = b time taken:  0.020956754684448242
# l2 error 0.035373, h1 error 0.688672
#
# epoch:  47	argmax batch num,  2
# argmax time taken,  0.040953636169433594
# total size: 47 524288 = 24641536
# num batches:  1
# assembling the mass matrix time taken:  0.006500244140625
# solving Ax = b time taken:  0.02225184440612793
# l2 error 0.034871, h1 error 0.681404
#
# epoch:  48	argmax batch num,  2
# argmax time taken,  0.040886878967285156
# total size: 48 524288 = 25165824
# num batches:  1
# assembling the mass matrix time taken:  0.006974458694458008
# solving Ax = b time taken:  0.021821975708007812
# l2 error 0.033333, h1 error 0.665513
#
# epoch:  49	argmax batch num,  2
# argmax time taken,  0.04087257385253906
# total size: 49 524288 = 25690112
# num batches:  1
# assembling the mass matrix time taken:  0.006626129150390625
# solving Ax = b time taken:  0.0233762264251709
# l2 error 0.032927, h1 error 0.658033
#
# epoch:  50	argmax batch num,  2
# argmax time taken,  0.04086184501647949
# total size: 50 524288 = 26214400
# num batches:  1
# assembling the mass matrix time taken:  0.007006168365478516
# solving Ax = b time taken:  0.02293252944946289
# l2 error 0.031977, h1 error 0.644976
#
# epoch:  51	argmax batch num,  2
# argmax time taken,  0.04097867012023926
# total size: 51 524288 = 26738688
# num batches:  1
# assembling the mass matrix time taken:  0.006736278533935547
# solving Ax = b time taken:  0.024250030517578125
# l2 error 0.030097, h1 error 0.621079
#
# epoch:  52	argmax batch num,  2
# argmax time taken,  0.04086613655090332
# total size: 52 524288 = 27262976
# num batches:  1
# assembling the mass matrix time taken:  0.006905078887939453
# solving Ax = b time taken:  0.024028778076171875
# l2 error 0.029350, h1 error 0.603028
#
# epoch:  53	argmax batch num,  2
# argmax time taken,  0.04087233543395996
# total size: 53 524288 = 27787264
# num batches:  1
# assembling the mass matrix time taken:  0.017482280731201172
# solving Ax = b time taken:  0.025181055068969727
# l2 error 0.027799, h1 error 0.571447
#
# epoch:  54	argmax batch num,  2
# argmax time taken,  0.05469799041748047
# total size: 54 524288 = 28311552
# num batches:  1
# assembling the mass matrix time taken:  0.007066249847412109
# solving Ax = b time taken:  0.0251157283782959
# l2 error 0.026277, h1 error 0.541746
#
# epoch:  55	argmax batch num,  2
# argmax time taken,  0.04091501235961914
# total size: 55 524288 = 28835840
# num batches:  1
# assembling the mass matrix time taken:  0.006935596466064453
# solving Ax = b time taken:  0.026093721389770508
# l2 error 0.025700, h1 error 0.536088
#
# epoch:  56	argmax batch num,  2
# argmax time taken,  0.04117989540100098
# total size: 56 524288 = 29360128
# num batches:  1
# assembling the mass matrix time taken:  0.007055997848510742
# solving Ax = b time taken:  0.025971651077270508
# l2 error 0.024964, h1 error 0.523083
#
# epoch:  57	argmax batch num,  2
# argmax time taken,  0.04104042053222656
# total size: 57 524288 = 29884416
# num batches:  1
# assembling the mass matrix time taken:  0.0066013336181640625
# solving Ax = b time taken:  0.027231693267822266
# l2 error 0.023803, h1 error 0.504572
#
# epoch:  58	argmax batch num,  2
# argmax time taken,  0.04102325439453125
# total size: 58 524288 = 30408704
# num batches:  1
# assembling the mass matrix time taken:  0.0070040225982666016
# solving Ax = b time taken:  0.027143478393554688
# l2 error 0.023585, h1 error 0.498438
#
# epoch:  59	argmax batch num,  2
# argmax time taken,  0.041028738021850586
# total size: 59 524288 = 30932992
# num batches:  1
# assembling the mass matrix time taken:  0.0066449642181396484
# solving Ax = b time taken:  0.02826523780822754
# l2 error 0.022886, h1 error 0.492519
#
# epoch:  60	argmax batch num,  2
# argmax time taken,  0.04101133346557617
# total size: 60 524288 = 31457280
# num batches:  1
# assembling the mass matrix time taken:  0.007098197937011719
# solving Ax = b time taken:  0.028082609176635742
# l2 error 0.022828, h1 error 0.489979
#
# epoch:  61	argmax batch num,  2
# argmax time taken,  0.04109382629394531
# total size: 61 524288 = 31981568
# num batches:  1
# assembling the mass matrix time taken:  0.00648808479309082
# solving Ax = b time taken:  0.029215574264526367
# l2 error 0.022198, h1 error 0.480096
#
# epoch:  62	argmax batch num,  2
# argmax time taken,  0.041159629821777344
# total size: 62 524288 = 32505856
# num batches:  1
# assembling the mass matrix time taken:  0.00694727897644043
# solving Ax = b time taken:  0.02918839454650879
# l2 error 0.021957, h1 error 0.475027
#
# epoch:  63	argmax batch num,  2
# argmax time taken,  0.04105639457702637
# total size: 63 524288 = 33030144
# num batches:  1
# assembling the mass matrix time taken:  0.007050037384033203
# solving Ax = b time taken:  0.02982163429260254
# l2 error 0.021455, h1 error 0.464228
#
# epoch:  64	argmax batch num,  2
# argmax time taken,  0.04116559028625488
# total size: 64 524288 = 33554432
# num batches:  1
# assembling the mass matrix time taken:  0.006968498229980469
# solving Ax = b time taken:  0.030119895935058594
# l2 error 0.020773, h1 error 0.454340
#
# epoch:  65	argmax batch num,  2
# argmax time taken,  0.041120052337646484
# total size: 65 524288 = 34078720
# num batches:  1
# assembling the mass matrix time taken:  0.00667119026184082
# solving Ax = b time taken:  0.03687596321105957
# l2 error 0.020173, h1 error 0.442320
#
# epoch:  66	argmax batch num,  2
# argmax time taken,  0.0411074161529541
# total size: 66 524288 = 34603008
# num batches:  1
# assembling the mass matrix time taken:  0.007039546966552734
# solving Ax = b time taken:  0.03758645057678223
# l2 error 0.019469, h1 error 0.433239
#
# epoch:  67	argmax batch num,  2
# argmax time taken,  0.04133439064025879
# total size: 67 524288 = 35127296
# num batches:  1
# assembling the mass matrix time taken:  0.006590366363525391
# solving Ax = b time taken:  0.03781628608703613
# l2 error 0.018146, h1 error 0.415549
#
# epoch:  68	argmax batch num,  2
# argmax time taken,  0.04136490821838379
# total size: 68 524288 = 35651584
# num batches:  1
# assembling the mass matrix time taken:  0.007103443145751953
# solving Ax = b time taken:  0.03830218315124512
# l2 error 0.017853, h1 error 0.409224
#
# epoch:  69	argmax batch num,  2
# argmax time taken,  0.041611433029174805
# total size: 69 524288 = 36175872
# num batches:  1
# assembling the mass matrix time taken:  0.006789445877075195
# solving Ax = b time taken:  0.03890872001647949
# l2 error 0.017581, h1 error 0.404372
#
# epoch:  70	argmax batch num,  2
# argmax time taken,  0.041339874267578125
# total size: 70 524288 = 36700160
# num batches:  1
# assembling the mass matrix time taken:  0.00710296630859375
# solving Ax = b time taken:  0.039379119873046875
# l2 error 0.017243, h1 error 0.399429
#
# epoch:  71	argmax batch num,  2
# argmax time taken,  0.04125857353210449
# total size: 71 524288 = 37224448
# num batches:  1
# assembling the mass matrix time taken:  0.006678104400634766
# solving Ax = b time taken:  0.039980173110961914
# l2 error 0.017068, h1 error 0.395838
#
# epoch:  72	argmax batch num,  2
# argmax time taken,  0.04139065742492676
# total size: 72 524288 = 37748736
# num batches:  1
# assembling the mass matrix time taken:  0.007068634033203125
# solving Ax = b time taken:  0.0399627685546875
# l2 error 0.016699, h1 error 0.389420
#
# epoch:  73	argmax batch num,  2
# argmax time taken,  0.0413365364074707
# total size: 73 524288 = 38273024
# num batches:  1
# assembling the mass matrix time taken:  0.006547451019287109
# solving Ax = b time taken:  0.041861534118652344
# l2 error 0.016560, h1 error 0.385698
#
# epoch:  74	argmax batch num,  2
# argmax time taken,  0.04135847091674805
# total size: 74 524288 = 38797312
# num batches:  1
# assembling the mass matrix time taken:  0.006917476654052734
# solving Ax = b time taken:  0.04283761978149414
# l2 error 0.016060, h1 error 0.373257
#
# epoch:  75	argmax batch num,  2
# argmax time taken,  0.04195976257324219
# total size: 75 524288 = 39321600
# num batches:  1
# assembling the mass matrix time taken:  0.006649017333984375
# solving Ax = b time taken:  0.04363584518432617
# l2 error 0.015268, h1 error 0.358365
#
# epoch:  76	argmax batch num,  2
# argmax time taken,  0.04200887680053711
# total size: 76 524288 = 39845888
# num batches:  1
# assembling the mass matrix time taken:  0.007062435150146484
# solving Ax = b time taken:  0.04337954521179199
# l2 error 0.015131, h1 error 0.355200
#
# epoch:  77	argmax batch num,  2
# argmax time taken,  0.042037248611450195
# total size: 77 524288 = 40370176
# num batches:  1
# assembling the mass matrix time taken:  0.006669521331787109
# solving Ax = b time taken:  0.04581308364868164
# l2 error 0.014949, h1 error 0.351601
#
# epoch:  78	argmax batch num,  2
# argmax time taken,  0.042330265045166016
# total size: 78 524288 = 40894464
# num batches:  1
# assembling the mass matrix time taken:  0.00705409049987793
# solving Ax = b time taken:  0.047341346740722656
# l2 error 0.014812, h1 error 0.350019
#
# epoch:  79	argmax batch num,  2
# argmax time taken,  0.04150962829589844
# total size: 79 524288 = 41418752
# num batches:  1
# assembling the mass matrix time taken:  0.0066759586334228516
# solving Ax = b time taken:  0.047095298767089844
# l2 error 0.014503, h1 error 0.345415
#
# epoch:  80	argmax batch num,  2
# argmax time taken,  0.042376041412353516
# total size: 80 524288 = 41943040
# num batches:  1
# assembling the mass matrix time taken:  0.007036685943603516
# solving Ax = b time taken:  0.04390597343444824
# l2 error 0.014325, h1 error 0.342758
#
# epoch:  81	argmax batch num,  2
# argmax time taken,  0.041500091552734375
# total size: 81 524288 = 42467328
# num batches:  1
# assembling the mass matrix time taken:  0.00653076171875
# solving Ax = b time taken:  0.04758572578430176
# l2 error 0.014217, h1 error 0.340477
#
# epoch:  82	argmax batch num,  2
# argmax time taken,  0.042508840560913086
# total size: 82 524288 = 42991616
# num batches:  1
# assembling the mass matrix time taken:  0.007139682769775391
# solving Ax = b time taken:  0.048833608627319336
# l2 error 0.013915, h1 error 0.334581
#
# epoch:  83	argmax batch num,  2
# argmax time taken,  0.041548967361450195
# total size: 83 524288 = 43515904
# num batches:  1
# assembling the mass matrix time taken:  0.0067021846771240234
# solving Ax = b time taken:  0.04813385009765625
# l2 error 0.013785, h1 error 0.332632
#
# epoch:  84	argmax batch num,  2
# argmax time taken,  0.041535139083862305
# total size: 84 524288 = 44040192
# num batches:  1
# assembling the mass matrix time taken:  0.00710749626159668
# solving Ax = b time taken:  0.04853510856628418
# l2 error 0.013533, h1 error 0.329128
#
# epoch:  85	argmax batch num,  2
# argmax time taken,  0.042630672454833984
# total size: 85 524288 = 44564480
# num batches:  1
# assembling the mass matrix time taken:  0.00661015510559082
# solving Ax = b time taken:  0.049002647399902344
# l2 error 0.013403, h1 error 0.327344
#
# epoch:  86	argmax batch num,  2
# argmax time taken,  0.04282188415527344
# total size: 86 524288 = 45088768
# num batches:  1
# assembling the mass matrix time taken:  0.007256031036376953
# solving Ax = b time taken:  0.050024986267089844
# l2 error 0.013020, h1 error 0.321990
#
# epoch:  87	argmax batch num,  2
# argmax time taken,  0.04294538497924805
# total size: 87 524288 = 45613056
# num batches:  1
# assembling the mass matrix time taken:  0.006673097610473633
# solving Ax = b time taken:  0.0497736930847168
# l2 error 0.012897, h1 error 0.319828
#
# epoch:  88	argmax batch num,  2
# argmax time taken,  0.042867183685302734
# total size: 88 524288 = 46137344
# num batches:  1
# assembling the mass matrix time taken:  0.006983041763305664
# solving Ax = b time taken:  0.04931211471557617
# l2 error 0.012784, h1 error 0.318235
#
# epoch:  89	argmax batch num,  2
# argmax time taken,  0.04294180870056152
# total size: 89 524288 = 46661632
# num batches:  1
# assembling the mass matrix time taken:  0.006624460220336914
# solving Ax = b time taken:  0.050489187240600586
# l2 error 0.012468, h1 error 0.312722
#
# epoch:  90	argmax batch num,  2
# argmax time taken,  0.043172597885131836
# total size: 90 524288 = 47185920
# num batches:  1
# assembling the mass matrix time taken:  0.007091045379638672
# solving Ax = b time taken:  0.052079200744628906
# l2 error 0.012191, h1 error 0.309171
#
# epoch:  91	argmax batch num,  2
# argmax time taken,  0.043044090270996094
# total size: 91 524288 = 47710208
# num batches:  1
# assembling the mass matrix time taken:  0.006683826446533203
# solving Ax = b time taken:  0.05134320259094238
# l2 error 0.012058, h1 error 0.307484
#
# epoch:  92	argmax batch num,  2
# argmax time taken,  0.04320216178894043
# total size: 92 524288 = 48234496
# num batches:  1
# assembling the mass matrix time taken:  0.007046699523925781
# solving Ax = b time taken:  0.05159401893615723
# l2 error 0.011978, h1 error 0.305926
#
# epoch:  93	argmax batch num,  2
# argmax time taken,  0.04319620132446289
# total size: 93 524288 = 48758784
# num batches:  1
# assembling the mass matrix time taken:  0.006672382354736328
# solving Ax = b time taken:  0.05223441123962402
# l2 error 0.011838, h1 error 0.302641
#
# epoch:  94	argmax batch num,  2
# argmax time taken,  0.04351401329040527
# total size: 94 524288 = 49283072
# num batches:  1
# assembling the mass matrix time taken:  0.0070934295654296875
# solving Ax = b time taken:  0.053807735443115234
# l2 error 0.011679, h1 error 0.300405
#
# epoch:  95	argmax batch num,  2
# argmax time taken,  0.043485403060913086
# total size: 95 524288 = 49807360
# num batches:  1
# assembling the mass matrix time taken:  0.0067138671875
# solving Ax = b time taken:  0.05333733558654785
# l2 error 0.011447, h1 error 0.296838
#
# epoch:  96	argmax batch num,  2
# argmax time taken,  0.04183387756347656
# total size: 96 524288 = 50331648
# num batches:  1
# assembling the mass matrix time taken:  0.007111549377441406
# solving Ax = b time taken:  0.04956793785095215
# l2 error 0.011198, h1 error 0.292853
#
# epoch:  97	argmax batch num,  2
# argmax time taken,  0.041672706604003906
# total size: 97 524288 = 50855936
# num batches:  1
# assembling the mass matrix time taken:  0.006546497344970703
# solving Ax = b time taken:  0.05324864387512207
# l2 error 0.011088, h1 error 0.291725
#
# epoch:  98	argmax batch num,  2
# argmax time taken,  0.04359292984008789
# total size: 98 524288 = 51380224
# num batches:  1
# assembling the mass matrix time taken:  0.007203102111816406
# solving Ax = b time taken:  0.05499696731567383
# l2 error 0.010959, h1 error 0.289518
#
# epoch:  99	argmax batch num,  2
# argmax time taken,  0.04193425178527832
# total size: 99 524288 = 51904512
# num batches:  1
# assembling the mass matrix time taken:  0.006712436676025391
# solving Ax = b time taken:  0.054155588150024414
# l2 error 0.010722, h1 error 0.286240
#
# epoch:  100	argmax batch num,  2
# argmax time taken,  0.04365110397338867
# total size: 100 524288 = 52428800
# num batches:  1
# assembling the mass matrix time taken:  0.007034778594970703
# solving Ax = b time taken:  0.054181575775146484
# l2 error 0.010685, h1 error 0.285675
#
# epoch:  101	argmax batch num,  2
# argmax time taken,  0.043633222579956055
# total size: 101 524288 = 52953088
# num batches:  1
# assembling the mass matrix time taken:  0.006675004959106445
# solving Ax = b time taken:  0.055123090744018555
# l2 error 0.010640, h1 error 0.284952
#
# epoch:  102	argmax batch num,  2
# argmax time taken,  0.041855573654174805
# total size: 102 524288 = 53477376
# num batches:  1
# assembling the mass matrix time taken:  0.007061958312988281
# solving Ax = b time taken:  0.056937456130981445
# l2 error 0.010533, h1 error 0.282752
#
# epoch:  103	argmax batch num,  2
# argmax time taken,  0.043599843978881836
# total size: 103 524288 = 54001664
# num batches:  1
# assembling the mass matrix time taken:  0.006623506546020508
# solving Ax = b time taken:  0.05599403381347656
# l2 error 0.010445, h1 error 0.280733
#
# epoch:  104	argmax batch num,  2
# argmax time taken,  0.04357409477233887
# total size: 104 524288 = 54525952
# num batches:  1
# assembling the mass matrix time taken:  0.007153987884521484
# solving Ax = b time taken:  0.055808305740356445
# l2 error 0.010291, h1 error 0.278691
#
# epoch:  105	argmax batch num,  2
# argmax time taken,  0.041939496994018555
# total size: 105 524288 = 55050240
# num batches:  1
# assembling the mass matrix time taken:  0.006642818450927734
# solving Ax = b time taken:  0.05681467056274414
# l2 error 0.010205, h1 error 0.277242
#
# epoch:  106	argmax batch num,  2
# argmax time taken,  0.0419154167175293
# total size: 106 524288 = 55574528
# num batches:  1
# assembling the mass matrix time taken:  0.0070574283599853516
# solving Ax = b time taken:  0.05896639823913574
# l2 error 0.010162, h1 error 0.276530
#
# epoch:  107	argmax batch num,  2
# argmax time taken,  0.04043292999267578
# total size: 107 524288 = 56098816
# num batches:  1
# assembling the mass matrix time taken:  0.006649017333984375
# solving Ax = b time taken:  0.0577237606048584
# l2 error 0.010099, h1 error 0.275051
#
# epoch:  108	argmax batch num,  2
# argmax time taken,  0.04044961929321289
# total size: 108 524288 = 56623104
# num batches:  1
# assembling the mass matrix time taken:  0.007281780242919922
# solving Ax = b time taken:  0.05744457244873047
# l2 error 0.009957, h1 error 0.273060
#
# epoch:  109	argmax batch num,  2
# argmax time taken,  0.04050087928771973
# total size: 109 524288 = 57147392
# num batches:  1
# assembling the mass matrix time taken:  0.0066187381744384766
# solving Ax = b time taken:  0.058632612228393555
# l2 error 0.009855, h1 error 0.271149
#
# epoch:  110	argmax batch num,  2
# argmax time taken,  0.040537118911743164
# total size: 110 524288 = 57671680
# num batches:  1
# assembling the mass matrix time taken:  0.006985187530517578
# solving Ax = b time taken:  0.060903072357177734
# l2 error 0.009833, h1 error 0.270747
#
# epoch:  111	argmax batch num,  2
# argmax time taken,  0.04056215286254883
# total size: 111 524288 = 58195968
# num batches:  1
# assembling the mass matrix time taken:  0.00661158561706543
# solving Ax = b time taken:  0.059567928314208984
# l2 error 0.009783, h1 error 0.269872
#
# epoch:  112	argmax batch num,  2
# argmax time taken,  0.04052233695983887
# total size: 112 524288 = 58720256
# num batches:  1
# assembling the mass matrix time taken:  0.007013082504272461
# solving Ax = b time taken:  0.05943036079406738
# l2 error 0.009708, h1 error 0.268964
#
# epoch:  113	argmax batch num,  2
# argmax time taken,  0.040505170822143555
# total size: 113 524288 = 59244544
# num batches:  1
# assembling the mass matrix time taken:  0.00662684440612793
# solving Ax = b time taken:  0.060529232025146484
# l2 error 0.009625, h1 error 0.267606
#
# epoch:  114	argmax batch num,  2
# argmax time taken,  0.04056692123413086
# total size: 114 524288 = 59768832
# num batches:  1
# assembling the mass matrix time taken:  0.007032632827758789
# solving Ax = b time taken:  0.06291460990905762
# l2 error 0.009556, h1 error 0.266367
#
# epoch:  115	argmax batch num,  2
# argmax time taken,  0.04059338569641113
# total size: 115 524288 = 60293120
# num batches:  1
# assembling the mass matrix time taken:  0.006669521331787109
# solving Ax = b time taken:  0.06134152412414551
# l2 error 0.009414, h1 error 0.264170
#
# epoch:  116	argmax batch num,  2
# argmax time taken,  0.04062342643737793
# total size: 116 524288 = 60817408
# num batches:  1
# assembling the mass matrix time taken:  0.006921052932739258
# solving Ax = b time taken:  0.06174802780151367
# l2 error 0.009350, h1 error 0.263098
#
# epoch:  117	argmax batch num,  2
# argmax time taken,  0.040547847747802734
# total size: 117 524288 = 61341696
# num batches:  1
# assembling the mass matrix time taken:  0.00662684440612793
# solving Ax = b time taken:  0.06228446960449219
# l2 error 0.009283, h1 error 0.262237
#
# epoch:  118	argmax batch num,  2
# argmax time taken,  0.04076576232910156
# total size: 118 524288 = 61865984
# num batches:  1
# assembling the mass matrix time taken:  0.007153511047363281
# solving Ax = b time taken:  0.06471419334411621
# l2 error 0.009260, h1 error 0.261742
#
# epoch:  119	argmax batch num,  2
# argmax time taken,  0.0408167839050293
# total size: 119 524288 = 62390272
# num batches:  1
# assembling the mass matrix time taken:  0.006669044494628906
# solving Ax = b time taken:  0.06317305564880371
# l2 error 0.009180, h1 error 0.260536
#
# epoch:  120	argmax batch num,  2
# argmax time taken,  0.040758609771728516
# total size: 120 524288 = 62914560
# num batches:  1
# assembling the mass matrix time taken:  0.007074594497680664
# solving Ax = b time taken:  0.06346297264099121
# l2 error 0.009138, h1 error 0.259662
#
# epoch:  121	argmax batch num,  2
# argmax time taken,  0.04073286056518555
# total size: 121 524288 = 63438848
# num batches:  1
# assembling the mass matrix time taken:  0.006485462188720703
# solving Ax = b time taken:  0.06490683555603027
# l2 error 0.009075, h1 error 0.258646
#
# epoch:  122	argmax batch num,  2
# argmax time taken,  0.04072260856628418
# total size: 122 524288 = 63963136
# num batches:  1
# assembling the mass matrix time taken:  0.00693964958190918
# solving Ax = b time taken:  0.06766891479492188
# l2 error 0.008980, h1 error 0.257527
#
# epoch:  123	argmax batch num,  2
# argmax time taken,  0.04072141647338867
# total size: 123 524288 = 64487424
# num batches:  1
# assembling the mass matrix time taken:  0.0066568851470947266
# solving Ax = b time taken:  0.06576418876647949
# l2 error 0.008858, h1 error 0.255392
#
# epoch:  124	argmax batch num,  2
# argmax time taken,  0.04082632064819336
# total size: 124 524288 = 65011712
# num batches:  1
# assembling the mass matrix time taken:  0.0070726871490478516
# solving Ax = b time taken:  0.06629085540771484
# l2 error 0.008822, h1 error 0.254406
#
# epoch:  125	argmax batch num,  2
# argmax time taken,  0.040795326232910156
# total size: 125 524288 = 65536000
# num batches:  1
# assembling the mass matrix time taken:  0.006627559661865234
# solving Ax = b time taken:  0.06675529479980469
# l2 error 0.008792, h1 error 0.253500
#
# epoch:  126	argmax batch num,  2
# argmax time taken,  0.04093289375305176
# total size: 126 524288 = 66060288
# num batches:  1
# assembling the mass matrix time taken:  0.007048130035400391
# solving Ax = b time taken:  0.06939387321472168
# l2 error 0.008775, h1 error 0.253103
#
# epoch:  127	argmax batch num,  2
# argmax time taken,  0.04092741012573242
# total size: 127 524288 = 66584576
# num batches:  1
# assembling the mass matrix time taken:  0.0066564083099365234
# solving Ax = b time taken:  0.06754350662231445
# l2 error 0.008719, h1 error 0.252224
#
# epoch:  128	argmax batch num,  2
# argmax time taken,  0.04097270965576172
# total size: 128 524288 = 67108864
# num batches:  1
# assembling the mass matrix time taken:  0.01989603042602539
# solving Ax = b time taken:  0.0671541690826416
# l2 error 0.008683, h1 error 0.251652
#
# epoch:  129	argmax batch num,  2
# argmax time taken,  0.06660676002502441
# total size: 129 524288 = 67633152
# num batches:  1
# assembling the mass matrix time taken:  0.01915597915649414
# solving Ax = b time taken:  0.08231115341186523
# l2 error 0.008587, h1 error 0.249555
#
# epoch:  130	argmax batch num,  2
# argmax time taken,  0.0697019100189209
# total size: 130 524288 = 68157440
# num batches:  1
# assembling the mass matrix time taken:  0.019556522369384766
# solving Ax = b time taken:  0.08793807029724121
# l2 error 0.008552, h1 error 0.248841
#
# epoch:  131	argmax batch num,  2
# argmax time taken,  0.06048011779785156
# total size: 131 524288 = 68681728
# num batches:  1
# assembling the mass matrix time taken:  0.007020235061645508
# solving Ax = b time taken:  0.08275389671325684
# l2 error 0.008450, h1 error 0.247375
#
# epoch:  132	argmax batch num,  2
# argmax time taken,  0.044350385665893555
# total size: 132 524288 = 69206016
# num batches:  1
# assembling the mass matrix time taken:  0.006793498992919922
# solving Ax = b time taken:  0.08575034141540527
# l2 error 0.008423, h1 error 0.246862
#
# epoch:  133	argmax batch num,  2
# argmax time taken,  0.04395246505737305
# total size: 133 524288 = 69730304
# num batches:  1
# assembling the mass matrix time taken:  0.006528615951538086
# solving Ax = b time taken:  0.08391141891479492
# l2 error 0.008397, h1 error 0.246457
#
# epoch:  134	argmax batch num,  2
# argmax time taken,  0.04408454895019531
# total size: 134 524288 = 70254592
# num batches:  1
# assembling the mass matrix time taken:  0.007024526596069336
# solving Ax = b time taken:  0.08988428115844727
# l2 error 0.008327, h1 error 0.245613
#
# epoch:  135	argmax batch num,  2
# argmax time taken,  0.04303264617919922
# total size: 135 524288 = 70778880
# num batches:  1
# assembling the mass matrix time taken:  0.006494998931884766
# solving Ax = b time taken:  0.08474254608154297
# l2 error 0.008317, h1 error 0.245377
#
# epoch:  136	argmax batch num,  2
# argmax time taken,  0.04407691955566406
# total size: 136 524288 = 71303168
# num batches:  1
# assembling the mass matrix time taken:  0.007017374038696289
# solving Ax = b time taken:  0.08750033378601074
# l2 error 0.008278, h1 error 0.244649
#
# epoch:  137	argmax batch num,  2
# argmax time taken,  0.04329967498779297
# total size: 137 524288 = 71827456
# num batches:  1
# assembling the mass matrix time taken:  0.006862640380859375
# solving Ax = b time taken:  0.08553552627563477
# l2 error 0.008185, h1 error 0.243222
#
# epoch:  138	argmax batch num,  2
# argmax time taken,  0.04309868812561035
# total size: 138 524288 = 72351744
# num batches:  1
# assembling the mass matrix time taken:  0.007181882858276367
# solving Ax = b time taken:  0.0921485424041748
# l2 error 0.008161, h1 error 0.242735
#
# epoch:  139	argmax batch num,  2
# argmax time taken,  0.04416370391845703
# total size: 139 524288 = 72876032
# num batches:  1
# assembling the mass matrix time taken:  0.0065228939056396484
# solving Ax = b time taken:  0.08647966384887695
# l2 error 0.008104, h1 error 0.241855
#
# epoch:  140	argmax batch num,  2
# argmax time taken,  0.043343305587768555
# total size: 140 524288 = 73400320
# num batches:  1
# assembling the mass matrix time taken:  0.006980419158935547
# solving Ax = b time taken:  0.08936572074890137
# l2 error 0.008077, h1 error 0.241471
#
# epoch:  141	argmax batch num,  2
# argmax time taken,  0.04475259780883789
# total size: 141 524288 = 73924608
# num batches:  1
# assembling the mass matrix time taken:  0.006492137908935547
# solving Ax = b time taken:  0.08747720718383789
# l2 error 0.008045, h1 error 0.241049
#
# epoch:  142	argmax batch num,  2
# argmax time taken,  0.04430389404296875
# total size: 142 524288 = 74448896
# num batches:  1
# assembling the mass matrix time taken:  0.0068819522857666016
# solving Ax = b time taken:  0.09408736228942871
# l2 error 0.007941, h1 error 0.239630
#
# epoch:  143	argmax batch num,  2
# argmax time taken,  0.04338526725769043
# total size: 143 524288 = 74973184
# num batches:  1
# assembling the mass matrix time taken:  0.006457328796386719
# solving Ax = b time taken:  0.08829498291015625
# l2 error 0.007912, h1 error 0.239119
#
# epoch:  144	argmax batch num,  2
# argmax time taken,  0.0445103645324707
# total size: 144 524288 = 75497472
# num batches:  1
# assembling the mass matrix time taken:  0.006911277770996094
# solving Ax = b time taken:  0.08833527565002441
# l2 error 0.007889, h1 error 0.238813
#
# epoch:  145	argmax batch num,  2
# argmax time taken,  0.04355883598327637
# total size: 145 524288 = 76021760
# num batches:  1
# assembling the mass matrix time taken:  0.006735324859619141
# solving Ax = b time taken:  0.10151481628417969
# l2 error 0.007883, h1 error 0.238654
#
# epoch:  146	argmax batch num,  2
# argmax time taken,  0.04443717002868652
# total size: 146 524288 = 76546048
# num batches:  1
# assembling the mass matrix time taken:  0.007086277008056641
# solving Ax = b time taken:  0.10471343994140625
# l2 error 0.007820, h1 error 0.237379
#
# epoch:  147	argmax batch num,  2
# argmax time taken,  0.0436244010925293
# total size: 147 524288 = 77070336
# num batches:  1
# assembling the mass matrix time taken:  0.0065555572509765625
# solving Ax = b time taken:  0.10248708724975586
# l2 error 0.007776, h1 error 0.236815
#
# epoch:  148	argmax batch num,  2
# argmax time taken,  0.0444333553314209
# total size: 148 524288 = 77594624
# num batches:  1
# assembling the mass matrix time taken:  0.006867408752441406
# solving Ax = b time taken:  0.10149025917053223
# l2 error 0.007764, h1 error 0.236689
#
# epoch:  149	argmax batch num,  2
# argmax time taken,  0.04455423355102539
# total size: 149 524288 = 78118912
# num batches:  1
# assembling the mass matrix time taken:  0.006523847579956055
# solving Ax = b time taken:  0.1035149097442627
# l2 error 0.007752, h1 error 0.236427
#
# epoch:  150	argmax batch num,  2
# argmax time taken,  0.04399466514587402
# total size: 150 524288 = 78643200
# num batches:  1
# assembling the mass matrix time taken:  0.006916046142578125
# solving Ax = b time taken:  0.1069028377532959
# l2 error 0.007721, h1 error 0.235764
#
# epoch:  151	argmax batch num,  2
# argmax time taken,  0.04452991485595703
# total size: 151 524288 = 79167488
# num batches:  1
# assembling the mass matrix time taken:  0.0064847469329833984
# solving Ax = b time taken:  0.10431742668151855
# l2 error 0.007703, h1 error 0.235453
#
# epoch:  152	argmax batch num,  2
# argmax time taken,  0.0440363883972168
# total size: 152 524288 = 79691776
# num batches:  1
# assembling the mass matrix time taken:  0.006829977035522461
# solving Ax = b time taken:  0.10108065605163574
# l2 error 0.007674, h1 error 0.234878
#
# epoch:  153	argmax batch num,  2
# argmax time taken,  0.04443097114562988
# total size: 153 524288 = 80216064
# num batches:  1
# assembling the mass matrix time taken:  0.0068378448486328125
# solving Ax = b time taken:  0.09229588508605957
# l2 error 0.007647, h1 error 0.234375
#
# epoch:  154	argmax batch num,  2
# argmax time taken,  0.04457831382751465
# total size: 154 524288 = 80740352
# num batches:  1
# assembling the mass matrix time taken:  0.0068933963775634766
# solving Ax = b time taken:  0.09659290313720703
# l2 error 0.007567, h1 error 0.233591
#
# epoch:  155	argmax batch num,  2
# argmax time taken,  0.04434680938720703
# total size: 155 524288 = 81264640
# num batches:  1
# assembling the mass matrix time taken:  0.0066509246826171875
# solving Ax = b time taken:  0.09339356422424316
# l2 error 0.007510, h1 error 0.232564
#
# epoch:  156	argmax batch num,  2
# argmax time taken,  0.04441332817077637
# total size: 156 524288 = 81788928
# num batches:  1
# assembling the mass matrix time taken:  0.006920337677001953
# solving Ax = b time taken:  0.0944364070892334
# l2 error 0.007501, h1 error 0.232390
#
# epoch:  157	argmax batch num,  2
# argmax time taken,  0.044724464416503906
# total size: 157 524288 = 82313216
# num batches:  1
# assembling the mass matrix time taken:  0.006536245346069336
# solving Ax = b time taken:  0.09430384635925293
# l2 error 0.007479, h1 error 0.232020
#
# epoch:  158	argmax batch num,  2
# argmax time taken,  0.04460024833679199
# total size: 158 524288 = 82837504
# num batches:  1
# assembling the mass matrix time taken:  0.006813764572143555
# solving Ax = b time taken:  0.098388671875
# l2 error 0.007461, h1 error 0.231772
#
# epoch:  159	argmax batch num,  2
# argmax time taken,  0.04462552070617676
# total size: 159 524288 = 83361792
# num batches:  1
# assembling the mass matrix time taken:  0.0065746307373046875
# solving Ax = b time taken:  0.09513163566589355
# l2 error 0.007452, h1 error 0.231668
#
# epoch:  160	argmax batch num,  2
# argmax time taken,  0.044606924057006836
# total size: 160 524288 = 83886080
# num batches:  1
# assembling the mass matrix time taken:  0.0067675113677978516
# solving Ax = b time taken:  0.09454965591430664
# l2 error 0.007437, h1 error 0.231515
#
# epoch:  161	argmax batch num,  2
# argmax time taken,  0.04464840888977051
# total size: 161 524288 = 84410368
# num batches:  1
# assembling the mass matrix time taken:  0.006493091583251953
# solving Ax = b time taken:  0.09609580039978027
# l2 error 0.007420, h1 error 0.231259
#
# epoch:  162	argmax batch num,  2
# argmax time taken,  0.04477858543395996
# total size: 162 524288 = 84934656
# num batches:  1
# assembling the mass matrix time taken:  0.006907224655151367
# solving Ax = b time taken:  0.10039591789245605
# l2 error 0.007376, h1 error 0.230604
#
# epoch:  163	argmax batch num,  2
# argmax time taken,  0.044703006744384766
# total size: 163 524288 = 85458944
# num batches:  1
# assembling the mass matrix time taken:  0.006673097610473633
# solving Ax = b time taken:  0.09688138961791992
# l2 error 0.007333, h1 error 0.229941
#
# epoch:  164	argmax batch num,  2
# argmax time taken,  0.044696807861328125
# total size: 164 524288 = 85983232
# num batches:  1
# assembling the mass matrix time taken:  0.007088184356689453
# solving Ax = b time taken:  0.0981435775756836
# l2 error 0.007317, h1 error 0.229701
#
# epoch:  165	argmax batch num,  2
# argmax time taken,  0.0448300838470459
# total size: 165 524288 = 86507520
# num batches:  1
# assembling the mass matrix time taken:  0.0066640377044677734
# solving Ax = b time taken:  0.09776592254638672
# l2 error 0.007301, h1 error 0.229495
#
# epoch:  166	argmax batch num,  2
# argmax time taken,  0.04480290412902832
# total size: 166 524288 = 87031808
# num batches:  1
# assembling the mass matrix time taken:  0.007115364074707031
# solving Ax = b time taken:  0.1021113395690918
# l2 error 0.007278, h1 error 0.229162
#
# epoch:  167	argmax batch num,  2
# argmax time taken,  0.044898271560668945
# total size: 167 524288 = 87556096
# num batches:  1
# assembling the mass matrix time taken:  0.006688594818115234
# solving Ax = b time taken:  0.09853196144104004
# l2 error 0.007251, h1 error 0.228814
#
# epoch:  168	argmax batch num,  2
# argmax time taken,  0.04489016532897949
# total size: 168 524288 = 88080384
# num batches:  1
# assembling the mass matrix time taken:  0.006952524185180664
# solving Ax = b time taken:  0.09961938858032227
# l2 error 0.007232, h1 error 0.228548
#
# epoch:  169	argmax batch num,  2
# argmax time taken,  0.04642987251281738
# total size: 169 524288 = 88604672
# num batches:  1
# assembling the mass matrix time taken:  0.006624698638916016
# solving Ax = b time taken:  0.09946775436401367
# l2 error 0.007224, h1 error 0.228420
#
# epoch:  170	argmax batch num,  2
# argmax time taken,  0.045004844665527344
# total size: 170 524288 = 89128960
# num batches:  1
# assembling the mass matrix time taken:  0.006936311721801758
# solving Ax = b time taken:  0.10409832000732422
# l2 error 0.007212, h1 error 0.228237
#
# epoch:  171	argmax batch num,  2
# argmax time taken,  0.04650759696960449
# total size: 171 524288 = 89653248
# num batches:  1
# assembling the mass matrix time taken:  0.007090330123901367
# solving Ax = b time taken:  0.09962701797485352
# l2 error 0.007187, h1 error 0.227948
#
# epoch:  172	argmax batch num,  2
# argmax time taken,  0.04499340057373047
# total size: 172 524288 = 90177536
# num batches:  1
# assembling the mass matrix time taken:  0.007362842559814453
# solving Ax = b time taken:  0.10147881507873535
# l2 error 0.007136, h1 error 0.227274
#
# epoch:  173	argmax batch num,  2
# argmax time taken,  0.04502224922180176
# total size: 173 524288 = 90701824
# num batches:  1
# assembling the mass matrix time taken:  0.006658315658569336
# solving Ax = b time taken:  0.10100698471069336
# l2 error 0.007131, h1 error 0.227155
#
# epoch:  174	argmax batch num,  2
# argmax time taken,  0.045966148376464844
# total size: 174 524288 = 91226112
# num batches:  1
# assembling the mass matrix time taken:  0.007443666458129883
# solving Ax = b time taken:  0.10582900047302246
# l2 error 0.007108, h1 error 0.226891
#
# epoch:  175	argmax batch num,  2
# argmax time taken,  0.04529857635498047
# total size: 175 524288 = 91750400
# num batches:  1
# assembling the mass matrix time taken:  0.006968021392822266
# solving Ax = b time taken:  0.10157155990600586
# l2 error 0.007106, h1 error 0.226799
#
# epoch:  176	argmax batch num,  2
# argmax time taken,  0.04521322250366211
# total size: 176 524288 = 92274688
# num batches:  1
# assembling the mass matrix time taken:  0.007201671600341797
# solving Ax = b time taken:  0.10283923149108887
# l2 error 0.007078, h1 error 0.226462
#
# epoch:  177	argmax batch num,  2
# argmax time taken,  0.04501700401306152
# total size: 177 524288 = 92798976
# num batches:  1
# assembling the mass matrix time taken:  0.006491422653198242
# solving Ax = b time taken:  0.10284852981567383
# l2 error 0.007064, h1 error 0.226290
#
# epoch:  178	argmax batch num,  2
# argmax time taken,  0.045178890228271484
# total size: 178 524288 = 93323264
# num batches:  1
# assembling the mass matrix time taken:  0.007076740264892578
# solving Ax = b time taken:  0.10796570777893066
# l2 error 0.007024, h1 error 0.225861
#
# epoch:  179	argmax batch num,  2
# ...
#
# epoch:  458	argmax batch num,  2
# argmax time taken,  0.047850608825683594
# total size: 458 524288 = 240123904
# num batches:  1
# assembling the mass matrix time taken:  0.1157371997833252
# solving Ax = b time taken:  0.3189857006072998
# l2 error 0.003982, h1 error 0.114602
#
# epoch:  459	argmax batch num,  2
# argmax time taken,  0.0479121208190918
# total size: 459 524288 = 240648192
# num batches:  1
# assembling the mass matrix time taken:  0.27111053466796875
# solving Ax = b time taken:  0.30916309356689453
# l2 error 0.003957, h1 error 0.114015
#
# epoch:  460	argmax batch num,  2
# argmax time taken,  0.04786419868469238
# total size: 460 524288 = 241172480
# num batches:  1
# assembling the mass matrix time taken:  0.009110212326049805
# solving Ax = b time taken:  0.36469125747680664
# l2 error 0.003942, h1 error 0.113444
#
# epoch:  461	argmax batch num,  2
# argmax time taken,  0.04793906211853027
# total size: 461 524288 = 241696768
# num batches:  1
# assembling the mass matrix time taken:  0.009204626083374023
# solving Ax = b time taken:  0.3710513114929199
# l2 error 0.003928, h1 error 0.113093
#
# epoch:  462	argmax batch num,  2
# argmax time taken,  0.047733306884765625
# total size: 462 524288 = 242221056
# num batches:  1
# assembling the mass matrix time taken:  0.27526330947875977
# solving Ax = b time taken:  0.31056833267211914
# l2 error 0.003918, h1 error 0.112919
#
# epoch:  463	argmax batch num,  2
# argmax time taken,  0.04781508445739746
# total size: 463 524288 = 242745344
# num batches:  1
# assembling the mass matrix time taken:  0.009284734725952148
# solving Ax = b time taken:  0.371793270111084
# l2 error 0.003900, h1 error 0.112524
#
# epoch:  464	argmax batch num,  2
# argmax time taken,  0.04795265197753906
# total size: 464 524288 = 243269632
# num batches:  1
# assembling the mass matrix time taken:  0.009221315383911133
# solving Ax = b time taken:  0.3663482666015625
# l2 error 0.003898, h1 error 0.112462
#
# epoch:  465	argmax batch num,  2
# argmax time taken,  0.04793500900268555
# total size: 465 524288 = 243793920
# num batches:  1
# assembling the mass matrix time taken:  0.26094794273376465
# solving Ax = b time taken:  0.31134891510009766
# l2 error 0.003880, h1 error 0.111740
#
# epoch:  466	argmax batch num,  2
# argmax time taken,  0.04804253578186035
# total size: 466 524288 = 244318208
# num batches:  1
# assembling the mass matrix time taken:  0.009145021438598633
# solving Ax = b time taken:  0.37442779541015625
# l2 error 0.003878, h1 error 0.111699
#
# epoch:  467	argmax batch num,  2
# argmax time taken,  0.047995567321777344
# total size: 467 524288 = 244842496
# num batches:  1
# assembling the mass matrix time taken:  0.009271860122680664
# solving Ax = b time taken:  0.3736433982849121
# l2 error 0.003874, h1 error 0.111314
#
# epoch:  468	argmax batch num,  2
# argmax time taken,  0.04797720909118652
# total size: 468 524288 = 245366784
# num batches:  1
# assembling the mass matrix time taken:  0.39407873153686523
# solving Ax = b time taken:  0.2880704402923584
# l2 error 0.003873, h1 error 0.111263
#
# epoch:  469	argmax batch num,  2
# argmax time taken,  0.04820966720581055
# total size: 469 524288 = 245891072
# num batches:  1
# assembling the mass matrix time taken:  0.008641481399536133
# solving Ax = b time taken:  0.3755044937133789
# l2 error 0.003865, h1 error 0.110772
#
# epoch:  470	argmax batch num,  2
# argmax time taken,  0.048163414001464844
# total size: 470 524288 = 246415360
# num batches:  1
# assembling the mass matrix time taken:  0.24881768226623535
# solving Ax = b time taken:  0.2943887710571289
# l2 error 0.003852, h1 error 0.110459
#
# epoch:  471	argmax batch num,  2
# argmax time taken,  0.04822230339050293
# total size: 471 524288 = 246939648
# num batches:  1
# assembling the mass matrix time taken:  0.00859522819519043
# solving Ax = b time taken:  0.3762941360473633
# l2 error 0.003841, h1 error 0.110024
#
# epoch:  472	argmax batch num,  2
# argmax time taken,  0.04817390441894531
# total size: 472 524288 = 247463936
# num batches:  1
# assembling the mass matrix time taken:  0.24588489532470703
# solving Ax = b time taken:  0.2896888256072998
# l2 error 0.003823, h1 error 0.109016
#
# epoch:  473	argmax batch num,  2
# argmax time taken,  0.04813098907470703
# total size: 473 524288 = 247988224
# num batches:  1
# assembling the mass matrix time taken:  0.008717536926269531
# solving Ax = b time taken:  0.3769106864929199
# l2 error 0.003808, h1 error 0.108614
#
# epoch:  474	argmax batch num,  2
# argmax time taken,  0.04811429977416992
# total size: 474 524288 = 248512512
# num batches:  1
# assembling the mass matrix time taken:  0.250974178314209
# solving Ax = b time taken:  0.297588586807251
# l2 error 0.003801, h1 error 0.108364
#
# epoch:  475	argmax batch num,  2
# argmax time taken,  0.04828023910522461
# total size: 475 524288 = 249036800
# num batches:  1
# assembling the mass matrix time taken:  0.008710384368896484
# solving Ax = b time taken:  0.3782370090484619
# l2 error 0.003795, h1 error 0.108178
#
# epoch:  476	argmax batch num,  2
# argmax time taken,  0.0482938289642334
# total size: 476 524288 = 249561088
# num batches:  1
# assembling the mass matrix time taken:  0.23765039443969727
# solving Ax = b time taken:  0.2979929447174072
# l2 error 0.003778, h1 error 0.107863
#
# epoch:  477	argmax batch num,  2
# argmax time taken,  0.049298763275146484
# total size: 477 524288 = 250085376
# num batches:  1
# assembling the mass matrix time taken:  0.007645845413208008
# solving Ax = b time taken:  0.3801157474517822
# l2 error 0.003764, h1 error 0.107540
#
# epoch:  478	argmax batch num,  2
# argmax time taken,  0.04813075065612793
# total size: 478 524288 = 250609664
# num batches:  1
# assembling the mass matrix time taken:  0.25476574897766113
# solving Ax = b time taken:  0.2990763187408447
# l2 error 0.003752, h1 error 0.107130
#
# epoch:  479	argmax batch num,  2
# argmax time taken,  0.04889321327209473
# total size: 479 524288 = 251133952
# num batches:  1
# assembling the mass matrix time taken:  0.00833439826965332
# solving Ax = b time taken:  0.38024353981018066
# l2 error 0.003750, h1 error 0.106922
#
# epoch:  480	argmax batch num,  2
# argmax time taken,  0.048253536224365234
# total size: 480 524288 = 251658240
# num batches:  1
# assembling the mass matrix time taken:  0.23856234550476074
# solving Ax = b time taken:  0.2969779968261719
# l2 error 0.003741, h1 error 0.106503
#
# epoch:  481	argmax batch num,  2
# argmax time taken,  0.04830026626586914
# total size: 481 524288 = 252182528
# num batches:  1
# assembling the mass matrix time taken:  0.00826120376586914
# solving Ax = b time taken:  0.3809051513671875
# l2 error 0.003739, h1 error 0.106274
#
# epoch:  482	argmax batch num,  2
# argmax time taken,  0.04822397232055664
# total size: 482 524288 = 252706816
# num batches:  1
# assembling the mass matrix time taken:  0.2500119209289551
# solving Ax = b time taken:  0.29805445671081543
# l2 error 0.003732, h1 error 0.106001
#
# epoch:  483	argmax batch num,  2
# argmax time taken,  0.04827475547790527
# total size: 483 524288 = 253231104
# num batches:  1
# assembling the mass matrix time taken:  0.009107351303100586
# solving Ax = b time taken:  0.3813145160675049
# l2 error 0.003728, h1 error 0.105733
#
# epoch:  484	argmax batch num,  2
# argmax time taken,  0.04841446876525879
# total size: 484 524288 = 253755392
# num batches:  1
# assembling the mass matrix time taken:  0.2397012710571289
# solving Ax = b time taken:  0.2985701560974121
# l2 error 0.003706, h1 error 0.105112
#
# epoch:  485	argmax batch num,  2
# argmax time taken,  0.04836273193359375
# total size: 485 524288 = 254279680
# num batches:  1
# assembling the mass matrix time taken:  0.008644342422485352
# solving Ax = b time taken:  0.38274335861206055
# l2 error 0.003689, h1 error 0.104804
#
# epoch:  486	argmax batch num,  2
# argmax time taken,  0.048341989517211914
# total size: 486 524288 = 254803968
# num batches:  1
# assembling the mass matrix time taken:  0.25380396842956543
# solving Ax = b time taken:  0.2995645999908447
# l2 error 0.003685, h1 error 0.104564
#
# epoch:  487	argmax batch num,  2
# argmax time taken,  0.04837679862976074
# total size: 487 524288 = 255328256
# num batches:  1
# assembling the mass matrix time taken:  0.009125471115112305
# solving Ax = b time taken:  0.3833174705505371
# l2 error 0.003684, h1 error 0.104429
#
# epoch:  488	argmax batch num,  2
# argmax time taken,  0.04844045639038086
# total size: 488 524288 = 255852544
# num batches:  1
# assembling the mass matrix time taken:  0.23937487602233887
# solving Ax = b time taken:  0.29996442794799805
# l2 error 0.003678, h1 error 0.104215
#
# epoch:  489	argmax batch num,  2
# argmax time taken,  0.048532724380493164
# total size: 489 524288 = 256376832
# num batches:  1
# assembling the mass matrix time taken:  0.00920724868774414
# solving Ax = b time taken:  0.38370680809020996
# l2 error 0.003667, h1 error 0.103953
#
# epoch:  490	argmax batch num,  2
# argmax time taken,  0.048519134521484375
# total size: 490 524288 = 256901120
# num batches:  1
# assembling the mass matrix time taken:  0.25634193420410156
# solving Ax = b time taken:  0.30080699920654297
# l2 error 0.003645, h1 error 0.103155
#
# epoch:  491	argmax batch num,  2
# argmax time taken,  0.048368215560913086
# total size: 491 524288 = 257425408
# num batches:  1
# assembling the mass matrix time taken:  0.009131431579589844
# solving Ax = b time taken:  0.3850104808807373
# l2 error 0.003645, h1 error 0.103081
#
# epoch:  492	argmax batch num,  2
# argmax time taken,  0.04840278625488281
# total size: 492 524288 = 257949696
# num batches:  1
# assembling the mass matrix time taken:  0.24079251289367676
# solving Ax = b time taken:  0.30164551734924316
# l2 error 0.003643, h1 error 0.103003
#
# epoch:  493	argmax batch num,  2
# argmax time taken,  0.04868125915527344
# total size: 493 524288 = 258473984
# num batches:  1
# assembling the mass matrix time taken:  0.008938789367675781
# solving Ax = b time taken:  0.3861818313598633
# l2 error 0.003643, h1 error 0.102947
#
# epoch:  494	argmax batch num,  2
# argmax time taken,  0.048447370529174805
# total size: 494 524288 = 258998272
# num batches:  1
# assembling the mass matrix time taken:  0.2565915584564209
# solving Ax = b time taken:  0.30173587799072266
# l2 error 0.003641, h1 error 0.102814
#
# epoch:  495	argmax batch num,  2
# argmax time taken,  0.04975485801696777
# total size: 495 524288 = 259522560
# num batches:  1
# assembling the mass matrix time taken:  0.008458614349365234
# solving Ax = b time taken:  0.38716840744018555
# l2 error 0.003636, h1 error 0.102665
#
# epoch:  496	argmax batch num,  2
# argmax time taken,  0.04857230186462402
# total size: 496 524288 = 260046848
# num batches:  1
# assembling the mass matrix time taken:  0.24337100982666016
# solving Ax = b time taken:  0.30268025398254395
# l2 error 0.003632, h1 error 0.102578
#
# epoch:  497	argmax batch num,  2
# argmax time taken,  0.049707651138305664
# total size: 497 524288 = 260571136
# num batches:  1
# assembling the mass matrix time taken:  0.008610010147094727
# solving Ax = b time taken:  0.3884878158569336
# l2 error 0.003627, h1 error 0.102078
#
# epoch:  498	argmax batch num,  2
# argmax time taken,  0.04879283905029297
# total size: 498 524288 = 261095424
# num batches:  1
# assembling the mass matrix time taken:  0.25330591201782227
# solving Ax = b time taken:  0.3033030033111572
# l2 error 0.003622, h1 error 0.101962
#
# epoch:  499	argmax batch num,  2
# argmax time taken,  0.04861927032470703
# total size: 499 524288 = 261619712
# num batches:  1
# assembling the mass matrix time taken:  0.00826573371887207
# solving Ax = b time taken:  0.3890516757965088
# l2 error 0.003618, h1 error 0.101788
#
# epoch:  500	argmax batch num,  2
# argmax time taken,  0.04855966567993164
# total size: 500 524288 = 262144000
# num batches:  1
# assembling the mass matrix time taken:  0.2457129955291748
# solving Ax = b time taken:  0.3040611743927002
# l2 error 0.003606, h1 error 0.101478
#
# epoch:  501	argmax batch num,  2
# argmax time taken,  0.049355268478393555
# total size: 501 524288 = 262668288
# num batches:  1
# assembling the mass matrix time taken:  0.007693290710449219
# solving Ax = b time taken:  0.39089059829711914
# l2 error 0.003579, h1 error 0.100609
#
# epoch:  502	argmax batch num,  2
# argmax time taken,  0.04859614372253418
# total size: 502 524288 = 263192576
# num batches:  1
# assembling the mass matrix time taken:  0.20937609672546387
# solving Ax = b time taken:  0.3058004379272461
# l2 error 0.003557, h1 error 0.100136
#
# epoch:  503	argmax batch num,  2
# argmax time taken,  0.04884791374206543
# total size: 503 524288 = 263716864
# num batches:  1
# assembling the mass matrix time taken:  0.008291482925415039
# solving Ax = b time taken:  0.39057397842407227
# l2 error 0.003537, h1 error 0.099705
#
# epoch:  504	argmax batch num,  2
# argmax time taken,  0.04861712455749512
# total size: 504 524288 = 264241152
# num batches:  1
# assembling the mass matrix time taken:  0.25645923614501953
# solving Ax = b time taken:  0.3049602508544922
# l2 error 0.003514, h1 error 0.099110
#
# epoch:  505	argmax batch num,  2
# argmax time taken,  0.04873204231262207
# total size: 505 524288 = 264765440
# num batches:  1
# assembling the mass matrix time taken:  0.00918722152709961
# solving Ax = b time taken:  0.39458250999450684
# l2 error 0.003478, h1 error 0.098138
#
# epoch:  506	argmax batch num,  2
# argmax time taken,  0.04874110221862793
# total size: 506 524288 = 265289728
# num batches:  1
# assembling the mass matrix time taken:  0.26347994804382324
# solving Ax = b time taken:  0.30915188789367676
# l2 error 0.003477, h1 error 0.097865
#
# epoch:  507	argmax batch num,  2
# argmax time taken,  0.048882484436035156
# total size: 507 524288 = 265814016
# num batches:  1
# assembling the mass matrix time taken:  0.009233236312866211
# solving Ax = b time taken:  0.395963191986084
# l2 error 0.003473, h1 error 0.097634
#
# epoch:  508	argmax batch num,  2
# argmax time taken,  0.04868292808532715
# total size: 508 524288 = 266338304
# num batches:  1
# assembling the mass matrix time taken:  0.5096232891082764
# solving Ax = b time taken:  0.3100705146789551
# l2 error 0.003468, h1 error 0.097357
#
# epoch:  509	argmax batch num,  2
# argmax time taken,  0.048740386962890625
# total size: 509 524288 = 266862592
# num batches:  1
# assembling the mass matrix time taken:  0.00909566879272461
# solving Ax = b time taken:  0.3959493637084961
# l2 error 0.003459, h1 error 0.097145
#
# epoch:  510	argmax batch num,  2
# argmax time taken,  0.04885673522949219
# total size: 510 524288 = 267386880
# num batches:  1
# assembling the mass matrix time taken:  0.2633321285247803
# solving Ax = b time taken:  0.31040263175964355
# l2 error 0.003447, h1 error 0.096861
#
# epoch:  511	argmax batch num,  2
# argmax time taken,  0.04938817024230957
# total size: 511 524288 = 267911168
# num batches:  1
# assembling the mass matrix time taken:  0.010215520858764648
# solving Ax = b time taken:  0.3968491554260254
# l2 error 0.003440, h1 error 0.096618
#
# epoch:  512	argmax batch num,  2
# argmax time taken,  0.04895639419555664
# total size: 512 524288 = 268435456
# num batches:  1
# assembling the mass matrix time taken:  0.2638378143310547
# solving Ax = b time taken:  0.31116795539855957
# l2 error 0.003426, h1 error 0.096104
#
# time taken:  1.2417058944702148
# neuron num 		 error 		 order
# 4 		 0.167917 		 * 		 2.081836 		 *
#
# 8 		 0.127425 		 0.398099 		 2.024406 		 0.040358
#
# 16 		 0.091959 		 0.470587 		 1.776684 		 0.188311
#
# 32 		 0.057717 		 0.672001 		 1.073740 		 0.726543
#
# 64 		 0.020773 		 1.474251 		 0.454340 		 1.240799
#
# 128 		 0.008683 		 1.258518 		 0.251652 		 0.852345
#
# 256 		 0.006464 		 0.425759 		 0.211366 		 0.251684
#
# 512 		 0.003426 		 0.915667 		 0.096104 		 1.137080
#
# neuron num  & 	 $\|u-u_n \|_{L^2}$ & 	 order $O(n^{-0.95})$  & 	 $ | u -u_n |_{H^1}$ & 	 order $O(n^{-0.85})$  \\ \hline \hline
# 4 		 & 0.167917 &		 * & 		 2.081836 & 		 *  \\ \hline
#
# 8 		 &  1.274e-01 &  		 0.40 &  		 2.024e+00 &  		 0.04 \\ \hline
#
# 16 		 &  9.196e-02 &  		 0.47 &  		 1.777e+00 &  		 0.19 \\ \hline
#
# 32 		 &  5.772e-02 &  		 0.67 &  		 1.074e+00 &  		 0.73 \\ \hline
#
# 64 		 &  2.077e-02 &  		 1.47 &  		 4.543e-01 &  		 1.24 \\ \hline
#
# 128 		 &  8.683e-03 &  		 1.26 &  		 2.517e-01 &  		 0.85 \\ \hline
#
# 256 		 &  6.464e-03 &  		 0.43 &  		 2.114e-01 &  		 0.25 \\ \hline
#
# 512 		 &  3.426e-03 &  		 0.92 &  		 9.610e-02 &  		 1.14 \\ \hline
