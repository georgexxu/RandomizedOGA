# %%
"""
This version of code is modified to incorporate more batch operations by Xiaofeng. 
The following parts are covered: Error computations, argmax subproblems, nonlinear Newton solver
Oct 13rd 2024.
"""

import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import time
import sys
import os 
from scipy.sparse import linalg
from pathlib import Path
import itertools
if torch.cuda.is_available():  
    device = "cuda" 
else:  
    device = "cpu" 

torch.set_default_dtype(torch.float64)
pi = torch.tensor(np.pi,dtype=torch.float64)
ZERO = torch.tensor([0.]).to(device)


class model(nn.Module):
    """ ReLU k shallow neural network
    Parameters: 
    input size: input dimension
    hidden_size1 : number of hidden layers 
    num_classes: output classes 
    k: degree of relu functions
    """
    def __init__(self, input_size, hidden_size1, num_classes,k = 1):
        super().__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, num_classes,bias = False)
        self.k = k 
    def forward(self, x):
        u1 = self.fc2(F.relu(self.fc1(x))**self.k)
        return u1
    def evaluate_derivative(self, x, i):
        if self.k == 1:
            u1 = self.fc2(torch.heaviside(self.fc1(x),ZERO) * self.fc1.weight.t()[i-1:i,:] )
        else:
            u1 = self.fc2(self.k*F.relu(self.fc1(x))**(self.k-1) *self.fc1.weight.t()[i-1:i,:] )  
        return u1

def plot_2D(f): 
    
    Nx = 400
    Ny = 400 
    xs = np.linspace(0, 1, Nx)
    ys = np.linspace(0, 1, Ny)
    x, y = np.meshgrid(xs, ys, indexing='xy')
    xy_comb = np.stack((x.flatten(),y.flatten())).T
    xy_comb = torch.tensor(xy_comb)
    z = f(xy_comb).reshape(Nx,Ny)
    z = z.detach().numpy()
    plt.figure(dpi=200)
    ax = plt.axes(projection='3d')
    ax.plot_surface(x , y , z )

    plt.show()

def plot_subdomains(my_model):
    x_coord =torch.linspace(0,1,200)
    wi = my_model.fc1.weight.data
    bi = my_model.fc1.bias.data 
    for i, bias in enumerate(bi):  
        if wi[i,1] !=0: 
            plt.plot(x_coord, - wi[i,0]/wi[i,1]*x_coord - bias/wi[i,1])
        else: 
            plt.plot(x_coord,  - bias/wi[i,0]*torch.ones(x_coord.size()))

    plt.xlim([0,1])
    plt.ylim([0,1])
    plt.legend()
    plt.show()
    return 0   

def adjust_neuron_position(my_model, dims = 3):

    def create_mesh_grid(dims, pts):
        mesh = torch.tensor(list(itertools.product(pts,repeat=dims)))
        vertices = mesh.reshape(len(pts) ** dims, -1) 
        return vertices
    counter = 0 
    # positions = torch.tensor([[0.,0.],[0.,1.],[1.,1.],[1.,0.]])
    pts = torch.tensor([0.,1.])
    positions = create_mesh_grid(dims,pts) 
    neuron_num = my_model.fc1.bias.size(0)
    for i in range(neuron_num): 
        w = my_model.fc1.weight.data[i:i+1,:]
        b = my_model.fc1.bias.data[i]
    #     print(w,b)
        values = torch.matmul(positions,w.T) # + b
        left_end = - torch.max(values)
        right_end = - torch.min(values)
        offset = (right_end - left_end)/50
        if b <= left_end + offset/2 : 
            b = torch.rand(1)*(right_end - left_end - offset) + left_end + offset/2 
            my_model.fc1.bias.data[i] = b 
        if b >= right_end - offset/2 :
            if counter < (dims+1):
#                 print("here")
                counter += 1
            else: # (d + 1) or more 
                b = torch.rand(1)*(right_end - left_end - offset) + left_end + offset/2 
                my_model.fc1.bias.data[i] = b 
    return my_model

# %%
def show_convergence_order(err_l2,err_h10,exponent,dict_size, filename,write2file = False):
    
    if write2file:
        file_mode = "a" if os.path.exists(filename) else "w"
        f_write = open(filename, file_mode)
    
    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_l2[i] for i in neuron_nums ]
    err_list2 = [err_h10[i] for i in neuron_nums ] 
    # f_write.write('M:{}, relu {} \n'.format(M,k))
    if write2file:
        f_write.write('dictionary size: {}\n'.format(dict_size))
        f_write.write("neuron num \t\t error \t\t order \t\t h10 error \\ order \n")
    print("neuron num \t\t error \t\t order")
    for i, item in enumerate(err_list):
        if i == 0: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t")
            
            # print("*")
            print("{} \t\t {:.6f} \t\t * \t\t {:.6f} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ) )
            if write2file: 
                f_write.write("{} \t\t {} \t\t * \t\t {} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ))
        else: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t") 
            # print(np.log(err_list[i-1]/err_list[i])/np.log(2))
            print("{} \t\t {:.6f} \t\t {:.6f} \t\t {:.6f} \t\t {:.6f} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ) )
            if write2file: 
                f_write.write("{} \t\t {} \t\t {} \t\t {} \t\t {} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ))
    if write2file:     
        f_write.write("\n")
        f_write.close()

def show_convergence_order_latex(err_l2,err_h10,exponent,k=1,d=1): 
    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_l2[i] for i in neuron_nums ]
    err_list2 = [err_h10[i] for i in neuron_nums ] 
    # f_write.write('M:{}, relu {} \n'.format(M,k))
    # f_write.write('randomized dictionary size: {}\n'.format(N))
    # f_write.write("neuron num \t\t error \t\t order \t\t h10 error \\ order \n")
    l2_order = -1/2-(2*k + 1)/(2*d)
    h10_order = -1/2-(2*(k-1) + 1)/(2*d)
#     print("neuron num  & \t $\|u-u_n \|_{L^2}$ & \t order $O(n^{{{}})$ & \t $ | u -u_n |_{H^1}$ & \t order $O(n^{{{}})$ \\\ \hline \hline ".format(l2_order,h10_order))
    print("neuron num  & \t $\\|u-u_n \\|_{{L^2}}$ & \t order $O(n^{{{:.2f}}})$ & \t $ | u -u_n |_{{H^1}}$ & \t order $O(n^{{{:.2f}}})$ \\\\ \\hline \\hline ".format(l2_order, h10_order))
    for i, item in enumerate(err_list):
        if i == 0: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t")

            # print("*")
            print("{} \t\t & {:.6f} &\t\t * & \t\t {:.6f} & \t\t *  \\\ \hline  \n".format(neuron_nums[i],item, err_list2[i] ) )   
            # f_write.write("{} \t\t {} \t\t * \t\t {} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ))
        else: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t") 
            # print(np.log(err_list[i-1]/err_list[i])/np.log(2))
            print("{} \t\t &  {:.3e} &  \t\t {:.2f} &  \t\t {:.3e} &  \t\t {:.2f} \\\ \hline  \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ) )
            # f_write.write("{} \t\t {} \t\t {} \t\t {} \t\t {} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ))
    # f_write.write("\n")
    # f_write.close()

# %%
def PiecewiseGQ1D_weights_points(x_l,x_r,Nx, order):
    """ Output the coeffients and weights for piecewise Gauss Quadrature 
    Parameters
    ----------
    x_l : float 
    left endpoint of an interval 
    x_r: float
    right endpoint of an interval 
    Nx: int 
    number of subintervals for integration
    order: int
    order of Gauss Quadrature 
    Returns
    -------
    vectorized quadrature weights and integration points
    """
    x,w = np.polynomial.legendre.leggauss(order)
    gx = torch.tensor(x).to(device)
    gx = gx.view(1,-1) # row vector 
    gw = torch.tensor(w).to(device)    
    gw = gw.view(-1,1) # Column vector 
    nodes = torch.linspace(x_l,x_r,Nx+1).view(-1,1).to(device) 
    coef1 = ((nodes[1:,:] - nodes[:-1,:])/2) # n by 1  
    coef2 = ((nodes[1:,:] + nodes[:-1,:])/2) # n by 1  
    coef2_expand = coef2.expand(-1,gx.size(1)) # Expand to n by p shape, -1: keep the first dimension n , expand the 2nd dim (columns)
    integration_points = coef1@gx + coef2_expand
    integration_points = integration_points.flatten().view(-1,1) # Make it a column vector
    gw_expand = torch.tile(gw,(Nx,1)) # rows: n copies of current tensor, columns: 1 copy, no change
    # Modify coef1 to be compatible with func_values
    coef1_expand = coef1.expand(coef1.size(0),gx.size(1))    
    coef1_expand = coef1_expand.flatten().view(-1,1)
    return coef1_expand.to(device) * gw_expand.to(device), integration_points.to(device)

def PiecewiseGQ2D_weights_points(Nx, order): 
    """ A slight modification of PiecewiseGQ2D function that only needs the weights and integration points.
    Parameters
    ----------

    Nx: int 
        number of intervals along the dimension. No Ny, assume Nx = Ny
    order: int 
        order of the Gauss Quadrature

    Returns
    -------
    long_weights: torch.tensor
    integration_points: torch.tensor
    """

#     print("order: ",order )
    x, w = np.polynomial.legendre.leggauss(order)
    gauss_pts = np.array(np.meshgrid(x,x,indexing='ij')).reshape(2,-1).T
    weights =  (w*w[:,None]).ravel()

    gauss_pts =torch.tensor(gauss_pts)
    weights = torch.tensor(weights)

    h = 1/Nx # 100 intervals 
    long_weights =  torch.tile(weights,(Nx**2,1))
    long_weights = long_weights.reshape(-1,1)
    long_weights = long_weights * h**2 /4 

    integration_points = torch.tile(gauss_pts,(Nx**2,1))
    scale_factor = h/2 
    integration_points = scale_factor * integration_points

    index = np.arange(1,Nx+1)-0.5
    ordered_pairs = np.array(np.meshgrid(index,index,indexing='ij'))
    ordered_pairs = ordered_pairs.reshape(2,-1).T

    # print(ordered_pairs)
    # print()
    ordered_pairs = torch.tensor(ordered_pairs)
    # print(ordered_pairs.size())
    ordered_pairs = torch.tile(ordered_pairs, (1,order**2)) # number of GQ points
    # print(ordered_pairs)

    ordered_pairs =  ordered_pairs.reshape(-1,2)
    # print(ordered_pairs)
    translation = ordered_pairs*h 
    # print(translation)

    integration_points = integration_points + translation 
#     print(integration_points.size())
    # func_values = integrand2_torch(integration_points)
    return long_weights.to(device), integration_points.to(device)

def PiecewiseGQ3D_weights_points(Nx, order): 
    """ A slight modification of PiecewiseGQ2D function that only needs the weights and integration points.
    Parameters
    ----------

    Nx: int 
        number of intervals along the dimension. No Ny, assume Nx = Ny
    order: int 
        order of the Gauss Quadrature

    Returns
    -------
    long_weights: torch.tensor
    integration_points: torch.tensor
    """

    """
    Parameters
    ----------
    target : 
        Target function 
    Nx: int 
        number of intervals along the dimension. No Ny, assume Nx = Ny
    order: int 
        order of the Gauss Quadrature
    """

    # print("order: ",order )
    x, w = np.polynomial.legendre.leggauss(order)
    gauss_pts = np.array(np.meshgrid(x,x,x,indexing='ij')).reshape(3,-1).T
    weight_list = np.array(np.meshgrid(w,w,w,indexing='ij'))
    weights =   (weight_list[0]*weight_list[1]*weight_list[2]).ravel() 

    gauss_pts =torch.tensor(gauss_pts)
    weights = torch.tensor(weights)

    h = 1/Nx # 100 intervals 
    long_weights =  torch.tile(weights,(Nx**3,1))
    long_weights = long_weights.reshape(-1,1)
    long_weights = long_weights * h**3 /8 

    integration_points = torch.tile(gauss_pts,(Nx**3,1))
    # print("shape of integration_points", integration_points.size())
    scale_factor = h/2 
    integration_points = scale_factor * integration_points

    index = np.arange(1,Nx+1)-0.5
    ordered_pairs = np.array(np.meshgrid(index,index,index,indexing='ij'))
    ordered_pairs = ordered_pairs.reshape(3,-1).T

    # print(ordered_pairs)
    # print()
    ordered_pairs = torch.tensor(ordered_pairs)
    # print(ordered_pairs.size())
    ordered_pairs = torch.tile(ordered_pairs, (1,order**3)) # number of GQ points
    # print(ordered_pairs)

    ordered_pairs =  ordered_pairs.reshape(-1,3)
    # print(ordered_pairs)
    translation = ordered_pairs*h 
    # print(translation)

    integration_points = integration_points + translation 

    return long_weights.to(device), integration_points.to(device)

def MonteCarlo_Sobol_dDim_weights_points(M ,d = 4):
    Sob_integral = torch.quasirandom.SobolEngine(dimension =d, scramble= False, seed=None) 
    integration_points = Sob_integral.draw(M).double() 
    integration_points = integration_points.to(device)
    weights = torch.ones(M,1).to(device)/M 
    return weights, integration_points 

def Neumann_boundary_quadrature_points_weights(M,d):
    def generate_quadpts_on_boundary(gw_expand_bd, integration_points_bd,d):
        size_pts_bd = integration_points_bd.size(0) 
        gw_expand_bd_faces = torch.tile(gw_expand_bd,(2*d,1)) # 2d boundaries, 拉成长条

        integration_points_bd_faces = torch.zeros(2*d*integration_points_bd.size(0),d).to(device)
        for ind in range(d): 
            integration_points_bd_faces[2 *ind * size_pts_bd :(2 *ind +1) * size_pts_bd,ind:ind+1] = 0 
            integration_points_bd_faces[(2 *ind)*size_pts_bd :(2 * ind +1) * size_pts_bd,:ind] = integration_points_bd[:,:ind]
            integration_points_bd_faces[(2 *ind)*size_pts_bd :(2 * ind +1) * size_pts_bd,ind+1:] = integration_points_bd[:,ind:]

            integration_points_bd_faces[(2 *ind +1) * size_pts_bd:(2 *ind +2)*size_pts_bd,ind:ind+1] = 1
            integration_points_bd_faces[(2 *ind +1) * size_pts_bd:(2 *ind +2)*size_pts_bd,:ind] = integration_points_bd[:,:ind]        
            integration_points_bd_faces[(2 *ind +1) * size_pts_bd:(2 *ind +2)*size_pts_bd,ind+1:] = integration_points_bd[:,ind:]
        return gw_expand_bd_faces, integration_points_bd_faces
    
    if d == 1: 
        print('dim',d)
        gw_expand_bd_faces = torch.tensor([1.,1.]).view(-1,1).to(device)
        integration_points_bd_faces = torch.tensor([0.,1.]).view(-1,1).to(device) 
    elif d == 2: 
        print('dim',d)
        gw_expand_bd, integration_points_bd = PiecewiseGQ1D_weights_points(0,1,8192, order = 3) 
    elif d == 3: 
        gw_expand_bd, integration_points_bd = PiecewiseGQ2D_weights_points(200, order = 3) 
    elif d == 4: 
        gw_expand_bd, integration_points_bd = PiecewiseGQ3D_weights_points(25, order = 3) 
        print('dim',d)
    else: 
        gw_expand_bd, integration_points_bd = MonteCarlo_Sobol_dDim_weights_points(M ,d = d)
        print('dim >=5 ')
    gw_expand_bd_faces, integration_points_bd_faces = generate_quadpts_on_boundary(gw_expand_bd, integration_points_bd,d)
    return gw_expand_bd_faces.to(device), integration_points_bd_faces.to(device) 

def generate_relu_dict3D(N_list):
    N1 = N_list[0]
    N2 = N_list[1]
    N3 = N_list[2]
    
    N = N1*N2*N3 
    theta1 = np.linspace(0, pi, N1, endpoint= True).reshape(N1,1)
    theta2 = np.linspace(0, 2*pi, N2, endpoint= False).reshape(N2,1)
    b = np.linspace(-1.732, 1.732, N3,endpoint=False).reshape(N3,1) # threshold: 3**0.5  
    coord3 = np.array(np.meshgrid(theta1,theta2,b,indexing='ij'))
    coord3 = coord3.reshape(3,-1).T # N1*N2*N3 x 3. coordinates for the grid points 
    coord3 = torch.tensor(coord3) 

    f1 = torch.zeros(N,1) 
    f2 = torch.zeros(N,1)
    f3 = torch.zeros(N,1)
    f4 = torch.zeros(N,1)

    f1[:,0] = torch.cos(coord3[:,0]) 
    f2[:,0] = torch.sin(coord3[:,0]) * torch.cos(coord3[:,1])
    f3[:,0] = torch.sin(coord3[:,0]) * torch.sin(coord3[:,1])
    f4[:,0] = coord3[:,2] 

    Wb_tensor = torch.cat([f1,f2,f3,f4],1) # N x 4 
    return Wb_tensor


def generate_relu_dict3D_QMC(s,N0):
#     Sob = torch.quasirandom.SobolEngine(dimension =3, scramble= True, seed=None) 
#     samples = Sob.draw(N0).double() 

#     for i in range(s-1):
#         samples = torch.cat([samples,Sob.draw(N0).double()],0)

    # Monte Carlo 
    samples = torch.rand(s*N0,3) 
    T =torch.tensor([[pi,0,0],[0,2*pi,0],[0,0,1.732*2]])
    shift = torch.tensor([0,0,-1.732])
    samples = samples@T + shift 

    f1 = torch.zeros(s*N0,1) 
    f2 = torch.zeros(s*N0,1)
    f3 = torch.zeros(s*N0,1)
    f4 = torch.zeros(s*N0,1)

    f1[:,0] = torch.cos(samples[:,0]) 
    f2[:,0] = torch.sin(samples[:,0]) * torch.cos(samples[:,1])
    f3[:,0] = torch.sin(samples[:,0]) * torch.sin(samples[:,1])
    f4[:,0] = samples[:,2] 

    Wb_tensor = torch.cat([f1,f2,f3,f4],1) # N x 4 
    return Wb_tensor


def minimize_linear_layer_H1_explicit_assemble_efficient(model,alpha, target, g_N, weights, integration_points, w_bd, pts_bd, activation = 'relu',solver="direct" ,memory=2**29):
    """ -div alpha grad u(x) + u = f 
    Parameters
    ----------
    model: 
        nn model
    alpha:
        alpha function
    target:
        rhs function f 
    pts_bd:
        integration points on the boundary, embdedded in the domain 
    """ 
    zero = torch.tensor([0.]).to(device)
    start_time = time.time() 
    w = model.fc1.weight.data 
    b = model.fc1.bias.data 
    neuron_num = b.size(0) 
    dim = integration_points.size(1) 
    M = integration_points.size(0)
    coef_alpha = alpha(integration_points) # alpha  

    total_size = neuron_num * M # memory, number of floating numbers 
    print('total size: {} {} = {}'.format(neuron_num,M,total_size))
    num_batch = total_size//memory + 1 # divide according to memory
    print("num batches: ",num_batch)
    batch_size = M//num_batch
    jac = torch.zeros(b.size(0),b.size(0)).to(device)
    rhs = torch.zeros(b.size(0),1).to(device)
    
    # Assemble the mass matrix <g_j,g_i>_{\Omega} and the rhs <f,g_i>_{\Omega} 
    for j in range(0,M,batch_size): 
        end_index = j + batch_size
        basis_value_col = F.relu(integration_points[j:end_index] @ w.t()+ b)**(model.k) 
        weighted_basis_value_col = basis_value_col * weights[j:end_index] 
        jac += weighted_basis_value_col.t() @ basis_value_col 
        rhs += weighted_basis_value_col.t() @ (target(integration_points[j:end_index,:])) 
        
    # Assemble the boundary condition term <g,v>_{\Gamma_N} 
    if g_N != None: # no batch operations for the boundary part, since it is only rhs on the boundary 
        size_pts_bd = int(pts_bd.size(0)/(2*dim))
        bcs_N = g_N(dim)
        for ii, g_ii in bcs_N:
            # pts_bd_ii = pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
            weighted_g_N = -g_ii(pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:])* w_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
            basis_value_bd_col = F.relu(pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:] @ w.t()+ b)**(model.k)
            rhs += basis_value_bd_col.t() @ weighted_g_N

            weighted_g_N = g_ii(pts_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:])* w_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:]
            basis_value_bd_col = F.relu(pts_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:] @ w.t()+ b)**(model.k)
            rhs += basis_value_bd_col.t() @ weighted_g_N

    # Stiffness matrix term in the jacobian 
    for d in range(dim):
        if model.k == 1:  
            for j in range(0,M,batch_size):  
                end_index = j + batch_size 
                basis_value_dxi_col = torch.heaviside(integration_points[j:end_index] @ w.t()+ b, zero) * w.t()[d:d+1,:]
                weighted_basis_value_dx_col = basis_value_dxi_col * weights[j:end_index] * coef_alpha[j:end_index] 
                jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 
#             basis_value_dxi_col = torch.heaviside(integration_points @ w.t()+ b, zero) * w.t()[d:d+1,:]
#             weighted_basis_value_dx_col = basis_value_dxi_col * weights * coef_alpha 
#             jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 

        else:
            for j in range(0,M,batch_size):  
                end_index = j + batch_size 
                basis_value_dxi_col = model.k * F.relu(integration_points[j:end_index] @ w.t()+ b)**(model.k-1) * w.t()[d:d+1,:]
                weighted_basis_value_dx_col = basis_value_dxi_col * weights[j:end_index] * coef_alpha[j:end_index] 
                jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 
#             basis_value_dxi_col = model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * w.t()[d:d+1,:]
#             weighted_basis_value_dx_col = basis_value_dxi_col * weights * coef_alpha  
#             jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 

    print("assembling the mass matrix time taken: ", time.time()-start_time) 

    start_time = time.time()    
    if solver == "cg": 
        sol, exit_code = linalg.cg(np.array(jac.detach().cpu()),np.array(rhs.detach().cpu()),tol=1e-12)
        sol = torch.tensor(sol).view(1,-1)
    elif solver == "direct": 
#         sol = np.linalg.inv( np.array(jac.detach().cpu()) )@np.array(rhs.detach().cpu())
        sol = (torch.linalg.solve( jac.detach(), rhs.detach())).view(1,-1)
    elif solver == "ls":
        sol = (torch.linalg.lstsq(jac.detach().cpu(),rhs.detach().cpu(),driver='gelsd').solution).view(1,-1)
        # sol = (torch.linalg.lstsq(jac.detach(),rhs.detach()).solution).view(1,-1) # gpu/cpu, driver = 'gels', cannot solve singular
    print("solving Ax = b time taken: ", time.time()-start_time)
    return sol 


def minimize_linear_layer_explicit_assemble(model,target,weights, integration_points,solver="direct"):
    """
    calls the following functions (dependency): 
    1. GQ_piecewise_2D
    input: the nn model containing parameter 
    1. define the loss function  
    2. take derivative to extract the linear system A
    3. call the cg solver in scipy to solve the linear system 
    output: sol. solution of Ax = b
    """
    start_time = time.time() 
    w = model.fc1.weight.data 
    b = model.fc1.bias.data 
    basis_value_col = F.relu(integration_points @ w.t()+ b)**(model.k) 
    weighted_basis_value_col = basis_value_col * weights 
    jac = weighted_basis_value_col.t() @ basis_value_col 
     
    rhs = weighted_basis_value_col.t() @ (target(integration_points)) 
    print("assembling the matrix time taken: ", time.time()-start_time) 
    start_time = time.time()    
    if solver == "cg": 
        sol, exit_code = linalg.cg(np.array(jac.detach().cpu()),np.array(rhs.detach().cpu()),tol=1e-12)
        sol = torch.tensor(sol).view(1,-1)
    elif solver == "direct": 
#         sol = np.linalg.inv( np.array(jac.detach().cpu()) )@np.array(rhs.detach().cpu())
        sol = (torch.linalg.solve( jac.detach(), rhs.detach())).view(1,-1)
    elif solver == "ls":
        sol = (torch.linalg.lstsq(jac.detach().cpu(),rhs.detach().cpu(),driver='gelsd').solution).view(1,-1)
        # sol = (torch.linalg.lstsq(jac.detach(),rhs.detach()).solution).view(1,-1) # gpu/cpu, driver = 'gels', cannot solve singular
    print("solving Ax = b time taken: ", time.time()-start_time)
    return sol

# %% [markdown]
# ### Test $L^2$ projection

# %%
def test_l2_projection():

    def u_exact(x):
        return torch.cos(pi*x[:,0:1])*torch.cos( pi*x[:,1:2]) * torch.cos(pi*x[:,2:3])  
    def alpha(x): 
        return torch.ones(x.size(0),1).to(device)

    g_N = None 
    integration_weights, integration_points = PiecewiseGQ3D_weights_points(30, 3)
    err_l2_list = [] 
    for neuron_num in [10,20,40,80,160]: 
        my_model = model(3, neuron_num, 1, k = 1).to(device) 
        my_model = adjust_neuron_position(my_model.cpu(),3).to(device)
        sol = minimize_linear_layer_explicit_assemble(my_model,u_exact,integration_weights, integration_points)
        my_model.fc2.weight.data[0,:] = sol[:] 
        diff_sqrd = (my_model(integration_points).detach() - u_exact(integration_points))**2
        err_l2 = torch.sqrt(torch.sum(integration_weights * diff_sqrd)) 
        print(err_l2)
        err_l2_list.append(err_l2) 
    print(err_l2_list) 

# test_l2_projection()

# %% [markdown]
# ### Test Neumann problem

# %%
def test_linear_neumann():

    def u_exact(x):
        return torch.cos(pi*x[:,0:1])*torch.cos( pi*x[:,1:2]) * torch.cos(pi*x[:,2:3])  
    def alpha(x): 
        return torch.ones(x.size(0),1).to(device)

    def u_exact_grad():
        d = 3 
        def grad_1(x):
            return - pi* torch.sin(pi*x[:,0:1])*torch.cos( pi*x[:,1:2]) * torch.cos(pi*x[:,2:3])   
        def grad_2(x):
            return - pi* torch.cos(pi*x[:,0:1])*torch.sin( pi*x[:,1:2]) * torch.cos(pi*x[:,2:3])  
        def grad_3(x):
            return - pi* torch.cos(pi*x[:,0:1])*torch.cos( pi*x[:,1:2]) * torch.sin(pi*x[:,2:3])   
        
        u_grad=[grad_1, grad_2,grad_3] 

        return u_grad

    def target(x):
        z = (  3 * (pi)**2 + 1)*torch.cos( pi*x[:,0:1])*torch.cos( pi*x[:,1:2] ) * torch.cos(pi*x[:,2:3]) 
        return z 

    g_N = None 
    
    def g_N(dim):
        u_grad = u_exact_grad() 
        bcs_N = []
        for i in range(dim):
            bcs_N.append((i, u_grad[i]))
        return bcs_N
    
    integration_weights, integration_points = PiecewiseGQ3D_weights_points(50, 3)
    weights_bd, pts_bd = Neumann_boundary_quadrature_points_weights(M = 999,d =3)   
    err_l2_list = [] 
    for neuron_num in [10,20,40,80]: 
        my_model = model(3, neuron_num, 1, k = 1).to(device) 
        my_model = adjust_neuron_position(my_model.cpu(),3).to(device) 
        sol = minimize_linear_layer_H1_explicit_assemble_efficient(my_model,alpha, target,  \
                            g_N, integration_weights, integration_points, w_bd = weights_bd, pts_bd = pts_bd, \
                            activation = 'relu',solver="direct" ,memory=2**29)
        my_model.fc2.weight.data[0,:] = sol[:] 
        diff_sqrd = (my_model(integration_points).detach() - u_exact(integration_points))**2
        err_l2 = torch.sqrt(torch.sum(integration_weights * diff_sqrd)) 
        print(err_l2)
        err_l2_list.append(err_l2) 
    print(err_l2_list) 


def test_linear_neumann2():

    def u_exact(x):
        return torch.sin(pi*x[:,0:1])*torch.sin( pi*x[:,1:2]) * torch.sin(pi*x[:,2:3])  
    def alpha(x): 
        return torch.ones(x.size(0),1).to(device)

    def u_exact_grad():
        d = 3 
        def grad_1(x):
            return  pi* torch.cos(pi*x[:,0:1])*torch.sin( pi*x[:,1:2]) * torch.sin(pi*x[:,2:3])   
        def grad_2(x):
            return pi* torch.sin(pi*x[:,0:1])*torch.cos( pi*x[:,1:2]) * torch.sin(pi*x[:,2:3])  
        def grad_3(x):
            return pi* torch.sin(pi*x[:,0:1])*torch.sin( pi*x[:,1:2]) * torch.cos(pi*x[:,2:3])   
        
        u_grad=[grad_1, grad_2,grad_3] 

        return u_grad
    def laplace_u_exact(x):
        return - 3*pi**2 * torch.sin(pi*x[:,0:1])*torch.sin( pi*x[:,1:2]) * torch.sin(pi*x[:,2:3])
    
    def target(x):
        return - laplace_u_exact(x) + u_exact(x) 
    
    def g_N(dim):
        u_grad = u_exact_grad() 
        bcs_N = []
        for i in range(dim):
            bcs_N.append((i, u_grad[i]))
        return bcs_N
    
    integration_weights, integration_points = PiecewiseGQ3D_weights_points(25, 3)
    weights_bd, pts_bd = Neumann_boundary_quadrature_points_weights(M = 999,d =3)   
    err_l2_list = [] 
    for neuron_num in [10,20,40,80]: 
        my_model = model(3, neuron_num, 1, k = 1).to(device) 
        my_model = adjust_neuron_position(my_model.cpu(),3).to(device) 
        sol = minimize_linear_layer_H1_explicit_assemble_efficient(my_model,alpha, target,  \
                            g_N, integration_weights, integration_points, w_bd = weights_bd, pts_bd = pts_bd, \
                            activation = 'relu',solver="direct" ,memory=2**29)
        my_model.fc2.weight.data[0,:] = sol[:] 
        diff_sqrd = (my_model(integration_points).detach() - u_exact(integration_points))**2
        err_l2 = torch.sqrt(torch.sum(integration_weights * diff_sqrd)) 
        print(err_l2)
        err_l2_list.append(err_l2) 
    print(err_l2_list) 

# print("test zero flux")
# # test_linear_neumann() # zero flux 
# print()

# print("test non-zero flux")
# test_linear_neumann2() # with non-zero flux

# %%
def test_linear_neumann3(): 
    freq = 2
    sigma = 0.15 
    def gaussian(x):
        return torch.exp(-torch.sum( (x - 0.5)**2,dim=1,keepdim=True)/(2 *sigma**2) ) 
    def gaussian_grad_1(x):
        return  gaussian(x) * (- (x[:,0:1] - 0.5)/(sigma**2) ) 
    def gaussian_grad_2(x):
        return  gaussian(x) * (- (x[:,1:2] - 0.5)/(sigma**2) ) 
    def gaussian_grad_3(x):
        return  gaussian(x) * (- (x[:,2:3] - 0.5)/(sigma**2) ) 
    
    def u_exact(x):
        return gaussian(x) * torch.cos(2*pi*freq*x[:,0:1]) 
    def alpha(x): 
        return torch.ones(x.size(0),1).to(device)

    def u_grad_1(x):
        return  torch.cos(2*pi*freq*x[:,0:1]) *gaussian_grad_1(x) \
                - 2*pi*freq * torch.sin(2*pi*freq*x[:,0:1]) * gaussian(x) 
    def u_grad_2(x):
        return torch.cos(2*pi*freq*x[:,0:1]) * gaussian_grad_2(x)
    def u_grad_3(x):
        return  torch.cos(2*pi*freq*x[:,0:1]) * gaussian_grad_3(x)

    def u_exact_grad():
        d = 3 
        def u_grad_1(x):
            return  torch.cos(2*pi*freq*x[:,0:1]) *gaussian_grad_1(x) \
                    - 2*pi*freq * torch.sin(2*pi*freq*x[:,0:1]) * gaussian(x) 
        def u_grad_2(x):
            return torch.cos(2*pi*freq*x[:,0:1]) * gaussian_grad_2(x)
        def u_grad_3(x):
            return  torch.cos(2*pi*freq*x[:,0:1]) * gaussian_grad_3(x)

        u_grad=[u_grad_1, u_grad_2,u_grad_3] 
        return u_grad
    
    def laplace_u_exact(x):
        return - 2*pi*freq * torch.sin(2*pi*freq*x[:,0:1]) *gaussian_grad_1(x) \
                + torch.cos(2*pi*freq*x[:,0:1])*( gaussian(x) * ( ((x[:,0:1] - 0.5)/(sigma**2))**2 -1/(sigma**2))  ) \
                -( (2*pi*freq)**2 * torch.cos(2*pi*freq*x[:,0:1]) * gaussian(x) + (2*pi*freq)*torch.sin(2*pi*freq*x[:,0:1]) * gaussian_grad_1(x) ) \
                + torch.cos(2*pi*freq*x[:,0:1]) * (gaussian(x) * ( ((x[:,1:2] - 0.5)/(sigma**2))**2 -1/(sigma**2) )  ) \
                + torch.cos(2*pi*freq*x[:,0:1]) * ( gaussian(x) * ( ((x[:,2:3] - 0.5)/(sigma**2))**2 -1/(sigma**2) )   ) \

    def target(x):
        return - laplace_u_exact(x) + u_exact(x)**3  
    
    def g_N(dim):
        u_grad = u_exact_grad() 
        bcs_N = []
        for i in range(dim):
            bcs_N.append((i, u_grad[i]))
        return bcs_N
    
    
    integration_weights, integration_points = PiecewiseGQ3D_weights_points(50, 3)
    weights_bd, pts_bd = Neumann_boundary_quadrature_points_weights(M = 999,d =3)   
    err_l2_list = [] 
    for neuron_num in [160,320]: 
        my_model = model(3, neuron_num, 1, k = 1).to(device) 
        my_model = adjust_neuron_position(my_model.cpu(),3).to(device) 
        sol = minimize_linear_layer_H1_explicit_assemble_efficient(my_model,alpha, target,  \
                            g_N, integration_weights, integration_points, w_bd = weights_bd, pts_bd = pts_bd, \
                            activation = 'relu',solver="direct" ,memory=2**29)
        my_model.fc2.weight.data[0,:] = sol[:] 
        diff_sqrd = (my_model(integration_points).detach() - u_exact(integration_points))**2
        err_l2 = torch.sqrt(torch.sum(integration_weights * diff_sqrd)) 
        print(err_l2)
        err_l2_list.append(err_l2) 
    print(err_l2_list) 
# test_linear_neumann3()

# %%
###

# %% [markdown]
# ### Test Newton solver

# %%
    
## define the nonlinearity 
def nonlinear(v):
    return torch.sinh(v)

def nonlinear_prime(v):
    return torch.cosh(v)

def minimize_linear_layer_newton_method(model,alpha,target,weights, integration_points,weights_bd, integration_points_bd, g_N,activation = 'relu', solver = 'direct',memory=2**29):
    """
    calls the following functions (dependency): 
    1. GQ_piecewise_2D
    input: the nn model containing parameter 
    1. define the loss function  
    2. take derivative to extract the linear system A
    3. call the cg solver in scipy to solve the linear system 
    output: sol. solution of Ax = b
    """
    start_time = time.time() 
    w = model.fc1.weight.data 
    b = model.fc1.bias.data 
    neuron_num = b.size(0) 
    M = integration_points.size(0)
    dim = integration_points.size(1) 
    coef_alpha = alpha(integration_points) # alpha  
    basis_value_col = F.relu(integration_points @ w.t()+ b)**(model.k) 
    weighted_basis_value_col = basis_value_col * weights 
    newton_iters = 20 

    total_size = neuron_num * M # memory, number of floating numbers 
    print('total size: {} {} = {}'.format(neuron_num,M,total_size))
    num_batch = total_size//memory + 1 # divide according to memory
    print("num batches: ",num_batch)
    batch_size = M//num_batch
    
    jac = torch.zeros(b.size(0),b.size(0)).to(device)
    jac_fixed_part = torch.zeros(b.size(0),b.size(0)).to(device)
    rhs = torch.zeros(b.size(0),1).to(device)
    rhs_gN = torch.zeros(b.size(0),1).to(device)
    
    # Stiffness matrix term in the jacobian && gradient term in rhs
    for j in range(0,M,batch_size): 
        end_index = j + batch_size
        if model.k == 1:  
            derivative_comm_part = torch.heaviside(integration_points[j:end_index] @ w.t()+ b, ZERO) 
            for d in range(dim): 
                basis_value_dxi_col = derivative_comm_part * w.t()[d:d+1,:]
                weighted_basis_value_dx_col = basis_value_dxi_col * weights[j:end_index] * coef_alpha[j:end_index] 
                jac_fixed_part += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 
        else:
            derivative_comm_part = model.k * F.relu(integration_points[j:end_index] @ w.t()+ b)**(model.k-1)
            for d in range(dim):  
                basis_value_dxi_col = derivative_comm_part * w.t()[d:d+1,:]
                weighted_basis_value_dx_col = basis_value_dxi_col * weights[j:end_index] * coef_alpha[j:end_index] 
                jac_fixed_part += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 
    jac[:,:] = jac_fixed_part[:,:]
    # neumann boundary condition 
    if g_N != None:
        size_pts_bd = int(integration_points_bd.size(0)/(2*dim))
        bcs_N = g_N(dim)
        for ii, g_ii in bcs_N:
            #Another for loop needed if we need to divide the integration points into batches 
            weighted_g_N = -g_ii(integration_points_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:])* weights_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
            basis_value_bd_col = F.relu(integration_points_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:] @ w.t()+ b)**(model.k)
            rhs_gN += basis_value_bd_col.t() @ weighted_g_N

            weighted_g_N = g_ii(integration_points_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:])* weights_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:]
            basis_value_bd_col = F.relu(integration_points_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:] @ w.t()+ b)**(model.k)
            rhs_gN += basis_value_bd_col.t() @ weighted_g_N
    
    for i in range(newton_iters): 
        print("newton iteration: ", i+1) 
        for j in range(0,M,batch_size): 
            end_index = j + batch_size
            basis_value_col = F.relu(integration_points[j:end_index] @ w.t()+ b)**(model.k) 
            weighted_basis_value_col = basis_value_col * weights[j:end_index] 
            coef_func = nonlinear_prime(model(integration_points[j:end_index]).detach()) # Nonlinearity dependent
            # mass matrix with variable coefficients  
            jac += weighted_basis_value_col.t() @ (coef_func * basis_value_col)
            # f- u^3 term 
            rhs += weighted_basis_value_col.t() @ (target(integration_points[j:end_index]) - nonlinear(model(integration_points[j:end_index]).detach()) )

        # Gradient term in rhs
        for j in range(0,M,batch_size): 
            end_index = j + batch_size
            if model.k == 1:  
                derivative_comm_part = torch.heaviside(integration_points[j:end_index] @ w.t()+ b, ZERO) 
                for d in range(dim): 
                    basis_value_dxi_col = derivative_comm_part * w.t()[d:d+1,:]
                    weighted_basis_value_dx_col = basis_value_dxi_col * weights[j:end_index] * coef_alpha[j:end_index] 
#                     jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 
                    dmy_model_dxi = model.evaluate_derivative(integration_points[j:end_index],d+1).detach() # this can be further optimized 
                    rhs -= weighted_basis_value_dx_col.t() @ dmy_model_dxi
            else:
                derivative_comm_part = model.k * F.relu(integration_points[j:end_index] @ w.t()+ b)**(model.k-1)
                for d in range(dim):  

                    basis_value_dxi_col = derivative_comm_part * w.t()[d:d+1,:]
                    weighted_basis_value_dx_col = basis_value_dxi_col * weights[j:end_index] * coef_alpha[j:end_index] 
#                     jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 
                    dmy_model_dxi = model.evaluate_derivative(integration_points[j:end_index],d+1).detach() # this can be further optimized 
                    rhs -= weighted_basis_value_dx_col.t() @ dmy_model_dxi

        rhs += rhs_gN
        
        # print("assembling the matrix time taken: ", time.time()-start_time) 
        start_time = time.time()    
        if solver == "cg": 
            sol, exit_code = linalg.cg(np.array(jac.detach().cpu()),np.array(rhs.detach().cpu()),tol=1e-12)
            sol = torch.tensor(sol).view(1,-1)
        elif solver == "direct": 
    #         sol = np.linalg.inv( np.array(jac.detach().cpu()) )@np.array(rhs.detach().cpu())
            sol = (torch.linalg.solve( jac.detach(), rhs.detach())).view(1,-1)
        elif solver == "ls":
            sol = (torch.linalg.lstsq(jac.detach().cpu(),rhs.detach().cpu(),driver='gelsd').solution).view(1,-1)
            # sol = (torch.linalg.lstsq(jac.detach(),rhs.detach()).solution).view(1,-1) # gpu/cpu, driver = 'gels', cannot solve singular
        # print("solving Ax = b time taken: ", time.time()-start_time)
        ## update the solution 
        model.fc2.weight.data[0,:] += sol[0,:]
        
        # print("newton iteration: ", i) 
        sol_update_l2_norm = torch.norm(sol)
        nn_linear_layer_l2_norm = torch.norm(model.fc2.weight.data[0,:])
        residual_l2_norm = torch.norm(rhs) 
        # print("sol_update_l2_norm:{} \t residual l2 norm: {} ".format(sol_update_l2_norm, residual_l2_norm))
        tol = 1e-10
        print("sol_update_l2_norm:{} \t residual l2 norm: {} ".format(sol_update_l2_norm, residual_l2_norm))
        
        jac[:,:] = jac_fixed_part[:,:] 
        rhs[:,0] = 0

        if sol_update_l2_norm < tol*nn_linear_layer_l2_norm or sol_update_l2_norm < tol or residual_l2_norm < tol*1e-1: 
            print("converged at iteration: ", i+1 )
            print("sol_update_l2_norm:{} \t residual l2 norm: {} ".format(sol_update_l2_norm, residual_l2_norm))
            return model.fc2.weight.data[:,:] 
        
    print("Newton solver NOT converged at iteration!!! ")
    print("sol_update_l2_norm:{} \t residual l2 norm: {} ".format(sol_update_l2_norm, residual_l2_norm))

    return model.fc2.weight.data[:,:]

# %%
def test_nonlinear_cubic():
    freq = 2 

    def u_exact(x):
        return torch.sin(pi*x[:,0:1])*torch.sin( pi*x[:,1:2]) * torch.sin(pi*x[:,2:3])  
    def alpha(x): 
        return torch.ones(x.size(0),1).to(device)

    def u_exact_grad():
        d = 3 
        def grad_1(x):
            return  pi* torch.cos(pi*x[:,0:1])*torch.sin( pi*x[:,1:2]) * torch.sin(pi*x[:,2:3])   
        def grad_2(x):
            return pi* torch.sin(pi*x[:,0:1])*torch.cos( pi*x[:,1:2]) * torch.sin(pi*x[:,2:3])  
        def grad_3(x):
            return pi* torch.sin(pi*x[:,0:1])*torch.sin( pi*x[:,1:2]) * torch.cos(pi*x[:,2:3])   
        
        u_grad=[grad_1, grad_2,grad_3] 

        return u_grad
    def laplace_u_exact(x):
        return - 3*pi**2 * torch.sin(pi*x[:,0:1])*torch.sin( pi*x[:,1:2]) * torch.sin(pi*x[:,2:3])
    
    def target(x):
        return - laplace_u_exact(x) + nonlinear(u_exact(x)) 
    
    def g_N(dim):
        u_grad = u_exact_grad() 
        bcs_N = []
        for i in range(dim):
            bcs_N.append((i, u_grad[i]))
        return bcs_N
    
    def u_exact_approx(x):
        return 0.7 * u_exact(x)

    def rhs(x):
        return  -laplace_u_exact(x) + nonlinear(u_exact(x)) 

    
    err_l2_list = [] 
    err_h10_list = []  
    weights, integration_points = PiecewiseGQ3D_weights_points(40, order = 3) 
    weights_bd, integration_points_bd = Neumann_boundary_quadrature_points_weights(999, d = 3) 
#     weights_bd, integration_points_bd = None, None   
    for neuron_num in [16,32,64,128,256]: 
        my_model = model(3, neuron_num, 1, k = 3).to(device) 
        my_model = adjust_neuron_position(my_model.cpu(),3).to(device)
        sol = minimize_linear_layer_explicit_assemble(my_model,u_exact_approx,weights, integration_points,solver="direct")
        # sol = minimize_linear_layer_neumann(my_model,rhs_neumann,weights, integration_points,activation = 'relu', solver = 'direct')
        my_model.fc2.weight.data[0,:] = sol[0,:]   
        sol = minimize_linear_layer_newton_method(my_model,alpha,rhs, \
                    weights, integration_points,weights_bd, integration_points_bd,\
                     g_N,activation = 'relu',solver="direct",memory=2**29) 
        my_model.fc2.weight.data[0,:] = sol[0,:]
        # plot_2D(my_model)
        diff_sqrd = (my_model(integration_points).detach() - u_exact(integration_points))**2
        err_l2 = (weights.t() @ diff_sqrd)**0.5 
        err_l2_list.append(err_l2)
    print(err_l2_list)   
    return 0 
    
test_nonlinear_cubic()
# Out:
# assembling the matrix time taken:  0.00035572052001953125
# solving Ax = b time taken:  0.0019559860229492188
# total size: 16 1728000 = 27648000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:154504.80790412513 	 residual l2 norm: 0.14961280827288506
# newton iteration:  2
# sol_update_l2_norm:1.4411919917686873 	 residual l2 norm: 0.00023887759256700398
# newton iteration:  3
# sol_update_l2_norm:2.697788426533029e-06 	 residual l2 norm: 4.676468689361084e-10
# newton iteration:  4
# sol_update_l2_norm:9.695976516407447e-12 	 residual l2 norm: 1.2578361866822073e-15
# converged at iteration:  4
# sol_update_l2_norm:9.695976516407447e-12 	 residual l2 norm: 1.2578361866822073e-15
# assembling the matrix time taken:  0.00025463104248046875
# solving Ax = b time taken:  0.003767251968383789
# total size: 32 1728000 = 55296000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:11977.98123713716 	 residual l2 norm: 0.21064818628149498
# newton iteration:  2
# sol_update_l2_norm:1.6228859664869282 	 residual l2 norm: 0.0014907733605459086
# newton iteration:  3
# sol_update_l2_norm:0.0002452285282966255 	 residual l2 norm: 4.0623680306533643e-07
# newton iteration:  4
# sol_update_l2_norm:4.671170754263045e-10 	 residual l2 norm: 2.3620497178269968e-14
# converged at iteration:  4
# sol_update_l2_norm:4.671170754263045e-10 	 residual l2 norm: 2.3620497178269968e-14
# assembling the matrix time taken:  0.00025081634521484375
# solving Ax = b time taken:  0.006716489791870117
# total size: 64 1728000 = 110592000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:66857.68043829453 	 residual l2 norm: 0.3038912828413382
# newton iteration:  2
# sol_update_l2_norm:2.63911642139894 	 residual l2 norm: 0.0016753387861296741
# newton iteration:  3
# sol_update_l2_norm:0.0005026525983509719 	 residual l2 norm: 6.706876682440761e-07
# newton iteration:  4
# sol_update_l2_norm:7.698219686440388e-09 	 residual l2 norm: 9.601660052570428e-14
# converged at iteration:  4
# sol_update_l2_norm:7.698219686440388e-09 	 residual l2 norm: 9.601660052570428e-14
# assembling the matrix time taken:  0.00025153160095214844
# solving Ax = b time taken:  0.014101982116699219
# total size: 128 1728000 = 221184000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:30523.893195737295 	 residual l2 norm: 0.42949692896015457
# newton iteration:  2
# sol_update_l2_norm:4.648257661374537 	 residual l2 norm: 0.0023127852698955295
# newton iteration:  3
# sol_update_l2_norm:0.00040385483414595314 	 residual l2 norm: 9.495744919247247e-07
# newton iteration:  4
# sol_update_l2_norm:2.023981104578043e-07 	 residual l2 norm: 1.4601053871787175e-13
# converged at iteration:  4
# sol_update_l2_norm:2.023981104578043e-07 	 residual l2 norm: 1.4601053871787175e-13
# assembling the matrix time taken:  0.00027060508728027344
# solving Ax = b time taken:  0.035309791564941406
# total size: 256 1728000 = 442368000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:8852.180476986285 	 residual l2 norm: 0.5961636075742442
# newton iteration:  2
# sol_update_l2_norm:3.500402326063615 	 residual l2 norm: 0.0017941806602551466
# newton iteration:  3
# sol_update_l2_norm:0.0005997863709620975 	 residual l2 norm: 7.836406904029472e-07
# newton iteration:  4
# sol_update_l2_norm:8.241550531162683e-06 	 residual l2 norm: 1.1647796053581658e-13
# converged at iteration:  4
# sol_update_l2_norm:8.241550531162683e-06 	 residual l2 norm: 1.1647796053581658e-13
# [tensor([[0.1919]], device='cuda:0'), tensor([[0.0817]], device='cuda:0'), tensor([[0.0271]], device='cuda:0'), tensor([[0.0065]], device='cuda:0'), tensor([[0.0017]], device='cuda:0')]
# 0

# %% [markdown]
# #### Test Gabor function

# %%
def test2_nonlinear_cubic():
    freq = 3
    sigma = 0.15 
    def gaussian(x):
        return torch.exp(-torch.sum( (x - 0.5)**2,dim=1,keepdim=True)/(2 *sigma**2) ) 
    def gaussian_grad_1(x):
        return  gaussian(x) * (- (x[:,0:1] - 0.5)/(sigma**2) ) 
    def gaussian_grad_2(x):
        return  gaussian(x) * (- (x[:,1:2] - 0.5)/(sigma**2) ) 
    def gaussian_grad_3(x):
        return  gaussian(x) * (- (x[:,2:3] - 0.5)/(sigma**2) ) 
    
    def u_exact(x):
        return gaussian(x) * torch.cos(2*pi*freq*x[:,0:1]) 
    def alpha(x): 
        return torch.ones(x.size(0),1).to(device)

    def u_grad_1(x):
        return  torch.cos(2*pi*freq*x[:,0:1]) *gaussian_grad_1(x) \
                - 2*pi*freq * torch.sin(2*pi*freq*x[:,0:1]) * gaussian(x) 
    def u_grad_2(x):
        return torch.cos(2*pi*freq*x[:,0:1]) * gaussian_grad_2(x)
    def u_grad_3(x):
        return  torch.cos(2*pi*freq*x[:,0:1]) * gaussian_grad_3(x)

    def u_exact_grad():
        d = 3 
        def u_grad_1(x):
            return  torch.cos(2*pi*freq*x[:,0:1]) *gaussian_grad_1(x) \
                    - 2*pi*freq * torch.sin(2*pi*freq*x[:,0:1]) * gaussian(x) 
        def u_grad_2(x):
            return torch.cos(2*pi*freq*x[:,0:1]) * gaussian_grad_2(x)
        def u_grad_3(x):
            return  torch.cos(2*pi*freq*x[:,0:1]) * gaussian_grad_3(x)

        u_grad=[u_grad_1, u_grad_2,u_grad_3] 
        return u_grad
    
    def laplace_u_exact(x):
        return - 2*pi*freq * torch.sin(2*pi*freq*x[:,0:1]) *gaussian_grad_1(x) \
                + torch.cos(2*pi*freq*x[:,0:1])*( gaussian(x) * ( ((x[:,0:1] - 0.5)/(sigma**2))**2 -1/(sigma**2))  ) \
                -( (2*pi*freq)**2 * torch.cos(2*pi*freq*x[:,0:1]) * gaussian(x) + (2*pi*freq)*torch.sin(2*pi*freq*x[:,0:1]) * gaussian_grad_1(x) ) \
                + torch.cos(2*pi*freq*x[:,0:1]) * (gaussian(x) * ( ((x[:,1:2] - 0.5)/(sigma**2))**2 -1/(sigma**2) )  ) \
                + torch.cos(2*pi*freq*x[:,0:1]) * ( gaussian(x) * ( ((x[:,2:3] - 0.5)/(sigma**2))**2 -1/(sigma**2) )   ) \

    def target(x):
        return - laplace_u_exact(x) + nonlinear(u_exact(x)) 
    
    def g_N(dim):
        u_grad = u_exact_grad() 
        bcs_N = []
        for i in range(dim):
            bcs_N.append((i, u_grad[i]))
        return bcs_N
    
    def u_exact_approx(x):
        return 0.99 * u_exact(x)

    def rhs(x):
        return  -laplace_u_exact(x) + nonlinear(u_exact(x)) 

    err_l2_list = [] 
    err_h10_list = []  
    weights, integration_points = PiecewiseGQ3D_weights_points(50, order = 3) 
    weights_bd, integration_points_bd = Neumann_boundary_quadrature_points_weights(999, d = 3) 
#     weights_bd, integration_points_bd = None, None   
    for neuron_num in [64,128]: 
        my_model = model(3, neuron_num, 1, k = 3).to(device) 
        my_model = adjust_neuron_position(my_model.cpu(),3).to(device)
        sol = minimize_linear_layer_explicit_assemble(my_model,u_exact_approx,weights, integration_points,solver="direct")
        # sol = minimize_linear_layer_neumann(my_model,rhs_neumann,weights, integration_points,activation = 'relu', solver = 'direct')
        my_model.fc2.weight.data[0,:] = sol[0,:]   
        sol = minimize_linear_layer_newton_method(my_model,alpha,rhs, \
                    weights, integration_points,weights_bd, integration_points_bd,\
                     g_N,activation = 'relu',solver="direct",memory=2**29) 
        my_model.fc2.weight.data[0,:] = sol[0,:]
        # plot_2D(my_model)
        diff_sqrd = (my_model(integration_points).detach() - u_exact(integration_points))**2
        err_l2 = (weights.t() @ diff_sqrd)**0.5 
        err_l2_list.append(err_l2)
    print(err_l2_list)   
    return 0 

# test2_nonlinear_cubic()

# %% [markdown]
# ## compare autograd and manually computing derivatives

# %%
import torch

# Constants
freq = 2
sigma = 0.15
pi = torch.pi
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Gaussian function and its gradients
def gaussian(x):
    return torch.exp(-torch.sum((x - 0.5)**2, dim=1, keepdim=True) / (2 * sigma**2))

def gaussian_grad_1(x):
    return gaussian(x) * (-(x[:, 0:1] - 0.5) / (sigma**2))

def gaussian_grad_2(x):
    return gaussian(x) * (-(x[:, 1:2] - 0.5) / (sigma**2))

def gaussian_grad_3(x):
    return gaussian(x) * (-(x[:, 2:3] - 0.5) / (sigma**2))

# Exact function u_exact
def u_exact(x):
    return gaussian(x) * torch.cos(2 * pi * freq * x[:, 0:1])

# Manually computed gradients
def u_grad_1(x):
    return torch.cos(2 * pi * freq * x[:, 0:1]) * gaussian_grad_1(x) - 2 * pi * freq * torch.sin(2 * pi * freq * x[:, 0:1]) * gaussian(x)

def u_grad_2(x):
    return torch.cos(2 * pi * freq * x[:, 0:1]) * gaussian_grad_2(x)

def u_grad_3(x):
    return torch.cos(2 * pi * freq * x[:, 0:1]) * gaussian_grad_3(x)

# Collecting the gradients in a list
def u_exact_grad():
    return [u_grad_1, u_grad_2, u_grad_3]

# # Manually computed Laplacian
def laplace_u_exact(x):
    return - 2*pi*freq * torch.sin(2*pi*freq*x[:,0:1]) *gaussian_grad_1(x) \
            + torch.cos(2*pi*freq*x[:,0:1])*( gaussian(x) * ( ((x[:,0:1] - 0.5)/(sigma**2))**2 -1/(sigma**2))  ) \
            -( (2*pi*freq)**2 * torch.cos(2*pi*freq*x[:,0:1]) * gaussian(x) + (2*pi*freq)*torch.sin(2*pi*freq*x[:,0:1]) * gaussian_grad_1(x) ) \
            + torch.cos(2*pi*freq*x[:,0:1]) * (gaussian(x) * ( ((x[:,1:2] - 0.5)/(sigma**2))**2 -1/(sigma**2) )  ) \
            + torch.cos(2*pi*freq*x[:,0:1]) * ( gaussian(x) * ( ((x[:,2:3] - 0.5)/(sigma**2))**2 -1/(sigma**2) )   ) \


# def laplace_u_exact(x):
#     # Second derivative w.r.t x_1
#     term_1 = -(2 * pi * freq)**2 * torch.cos(2 * pi * freq * x[:, 0:1]) * gaussian(x)
#     term_1 += torch.cos(2 * pi * freq * x[:, 0:1]) * gaussian(x) * ((x[:, 0:1] - 0.5)**2 / sigma**4 - 1 / sigma**2)
#     term_1 += 2 * pi * freq * torch.sin(2 * pi * freq * x[:, 0:1]) * gaussian_grad_1(x)

#     # Second derivative w.r.t x_2
#     term_2 = torch.cos(2 * pi * freq * x[:, 0:1]) * gaussian(x) * ((x[:, 1:2] - 0.5)**2 / sigma**4 - 1 / sigma**2)

#     # Second derivative w.r.t x_3
#     term_3 = torch.cos(2 * pi * freq * x[:, 0:1]) * gaussian(x) * ((x[:, 2:3] - 0.5)**2 / sigma**4 - 1 / sigma**2)

#     return term_1 + term_2 + term_3


# Function to compute gradient using autograd
def compute_autograd_grad(u_func, x):
    x.requires_grad_(True)  # Enable gradient tracking for input x
    u = u_func(x)
    u_grad = torch.autograd.grad(outputs=u, inputs=x,
                                 grad_outputs=torch.ones_like(u),
                                 create_graph=True, retain_graph=True)[0]
    return u_grad

# Function to compute Laplacian using autograd
def compute_autograd_laplace(u_func, x):
    u_grad = compute_autograd_grad(u_func, x)
    
    laplacian = 0
    for i in range(x.shape[1]):
        grad_i = u_grad[:, i:i+1]
        u_grad2_i = torch.autograd.grad(outputs=grad_i, inputs=x,
                                        grad_outputs=torch.ones_like(grad_i),
                                        create_graph=True, retain_graph=True)[0][:, i:i+1]
        laplacian += u_grad2_i
    return laplacian

# Generate sample input points
x = torch.rand(1000, 3).to(device)  # Random 3D points

# Compute the manually computed gradients and Laplacian
s_time = time.time()
u_grad_manual_1 = u_grad_1(x)
u_grad_manual_2 = u_grad_2(x)
u_grad_manual_3 = u_grad_3(x)
laplace_manual = laplace_u_exact(x)
print("manully compute derivative: ",time.time() - s_time)

# Compute the gradients and Laplacian using autograd
s_time = time.time()
u_grad_autograd = compute_autograd_grad(u_exact, x)
laplace_autograd = compute_autograd_laplace(u_exact, x)
print("autograd for derivative: ",time.time() - s_time)
# Compute differences for comparison
grad_diff_1 = torch.abs(u_grad_manual_1 - u_grad_autograd[:, 0:1])
grad_diff_2 = torch.abs(u_grad_manual_2 - u_grad_autograd[:, 1:2])
grad_diff_3 = torch.abs(u_grad_manual_3 - u_grad_autograd[:, 2:3])
laplace_diff = torch.abs(laplace_manual - laplace_autograd)

# Display the results
print("Manual Gradient 1 vs Autograd Gradient 1 Difference:")
print(grad_diff_1.sum())

print("\nManual Gradient 2 vs Autograd Gradient 2 Difference:")
print(grad_diff_2.sum())

print("\nManual Gradient 3 vs Autograd Gradient 3 Difference:")
print(grad_diff_3.sum())

print("\nManual Laplacian vs Autograd Laplacian Difference:")
print(laplace_diff.sum())
# Out:
# manully compute derivative:  0.0022568702697753906
# autograd for derivative:  0.0037720203399658203
# Manual Gradient 1 vs Autograd Gradient 1 Difference:
# tensor(3.5875e-14, device='cuda:0', grad_fn=<SumBackward0>)
#
# Manual Gradient 2 vs Autograd Gradient 2 Difference:
# tensor(1.6071e-14, device='cuda:0', grad_fn=<SumBackward0>)
#
# Manual Gradient 3 vs Autograd Gradient 3 Difference:
# tensor(1.4882e-14, device='cuda:0', grad_fn=<SumBackward0>)
#
# Manual Laplacian vs Autograd Laplacian Difference:
# tensor(1.0734e-12, device='cuda:0', grad_fn=<SumBackward0>)

# %% [markdown]
# ## CGA Nonlinear Problem

# %%
def select_greedy_neuron_ind(relu_dict_parameters,my_model,target,gw_expand, integration_points,g_N,weights_bd, integration_points_bd,k,memory = 2**29):
    dim = integration_points.size(1) 
    M = integration_points.size(0)
    N0 = relu_dict_parameters.size(0)   
    neuron_num = my_model.fc2.weight.size(1) if my_model != None else 0

    output = torch.zeros(N0,1).to(device) 
    s_time = time.time()
    total_size2 = M*(neuron_num+1)
    num_batch2 = total_size2//memory + 1 
    batch_size_2 = M//num_batch2 # integration points 
    # N(u) - f terms, divide the integration points into batches 
    if my_model != None: 
        func_values = - target(integration_points) 
        for jj in range(0,M,batch_size_2): 
            end_index = jj + batch_size_2 
            model_values = nonlinear(my_model(integration_points[jj:end_index,:]).detach()) 
            func_values[jj:end_index,:] += model_values #Change 1.  
    else: 
        func_values = - target(integration_points)    
    weight_func_values = func_values*gw_expand  
    
    total_size = M * N0 
    num_batch = total_size//memory + 1 
    batch_size_1 = N0//num_batch # dictionary elements
    print("======argmax subproblem:f and N(u) terms, num batches: ",num_batch)
    for j in range(0,N0,batch_size_1):
        end_index = j + batch_size_1 
        basis_values = (F.relu( torch.matmul(integration_points,relu_dict_parameters[j:end_index,0:dim].T ) - relu_dict_parameters[j:end_index,dim])**k).T # uses broadcasting
        output[j:end_index] += torch.matmul(basis_values,weight_func_values) #
    print('======TIME=======f and N(u) terms time :',time.time()-s_time)
    
    # Gradient term: <\nabla u_n, \nabla g_i>, i = 1,2,3,...,N
    ## ============================================================================
    s_time =time.time() 
    if my_model!= None:
        #compute the derivative of the model 
        model_derivative_values = torch.zeros(M,dim).to(device) 
        for d in range(dim): ## there is a more efficient way 
            for jj in range(0,M,batch_size_2):
                end_index = jj + batch_size_2 
                model_derivative_values[jj:end_index,d:d+1] = my_model.evaluate_derivative(integration_points[jj:end_index,:],d+1).detach()
                
        if my_model.k == 1: 
            #compute the derivative of the dictionary elements 
            for j in range(0,N0,batch_size_1): 
                end_index = j + batch_size_1 
                weighted_derivative_part = gw_expand * torch.heaviside(integration_points@ (relu_dict_parameters[j:end_index,0:dim].T) - relu_dict_parameters[j:end_index,dim], ZERO)
                for d in range(dim):
                    weighted_basis_value_dx_col = weighted_derivative_part * relu_dict_parameters.t()[d:d+1,j:end_index] 
                    output[j:end_index] += weighted_basis_value_dx_col.t() @ model_derivative_values[:,d:d+1]
        else:
            #compute the derivative of the dictionary elements 
            for j in range(0,N0,batch_size_1):  
                end_index = j + batch_size_1
                weighted_derivative_part = gw_expand *my_model.k * F.relu(integration_points@ (relu_dict_parameters[j:end_index,0:dim].T) - relu_dict_parameters[j:end_index,dim])**(my_model.k-1)
                for d in range(dim):
                    weighted_basis_value_dx_col = weighted_derivative_part * relu_dict_parameters.t()[d:d+1,j:end_index]
                    output[j:end_index] += weighted_basis_value_dx_col.t() @ model_derivative_values[:,d:d+1]

    print('======TIME=======stiffness matrix terms time :',time.time()-s_time)
    
    #Neumann boundary condition
    s_time =time.time()  
    output4 = 0 
    if g_N != None:
        size_pts_bd = int(integration_points_bd.size(0)/(2*dim)) # pre-defined rules for integration points on bdries
        bcs_N = g_N(dim)
        for ii, g_ii in bcs_N:
            # pts_bd_ii = pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
            weighted_g_N = -g_ii(integration_points_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:])* weights_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
            basis_value_bd_col = F.relu(integration_points_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:] @ (relu_dict_parameters[:,0:dim].T) - relu_dict_parameters[:,dim] )**(k)
            output4 += basis_value_bd_col.t() @ weighted_g_N

            weighted_g_N = g_ii(integration_points_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:])* weights_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:]
            basis_value_bd_col = F.relu(integration_points_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:] @ (relu_dict_parameters[:,0:dim].T) - relu_dict_parameters[:,dim])**(k)
            output4 += basis_value_bd_col.t() @ weighted_g_N
    print('======TIME=======neumann bd terms time :',time.time()-s_time) 
    output -= output4
    output = torch.abs(output) 
    
    neuron_index = torch.argmax(output.flatten())
    return neuron_index 

def L2_projection_init(model,sol,weights,integration_points,activation = 'relu', solver = 'direct'):
    start_time = time.time() 
    w = model.fc1.weight.data 
    b = model.fc1.bias.data 
    basis_value_col = F.relu(integration_points @ w.t()+ b)**(model.k) 
    weighted_basis_value_col = basis_value_col * weights 
    jac = weighted_basis_value_col.t() @ basis_value_col 
      
    rhs = jac[:,:-1] @ sol.t()

    print("assembling the matrix time taken: ", time.time()-start_time) 
    start_time = time.time()    
    if solver == "cg": 
        sol, exit_code = linalg.cg(np.array(jac.detach().cpu()),np.array(rhs.detach().cpu()),tol=1e-12)
        sol = torch.tensor(sol).view(1,-1)
    elif solver == "direct": 
#         sol = np.linalg.inv( np.array(jac.detach().cpu()) )@np.array(rhs.detach().cpu())
        sol = (torch.linalg.solve( jac.detach(), rhs.detach())).view(1,-1)
    elif solver == "ls":
        sol = (torch.linalg.lstsq(jac.detach().cpu(),rhs.detach().cpu(),driver='gelsd').solution).view(1,-1)
        # sol = (torch.linalg.lstsq(jac.detach(),rhs.detach()).solution).view(1,-1) # gpu/cpu, driver = 'gels', cannot solve singular
    print("solving Ax = b time taken: ", time.time()-start_time)
    model.fc2.weight.data[0,:] = sol[0,:]  
    return model 

def CGANonlinearPoissonReLU3D(my_model,target,alpha,u_exact, u_exact_grad,g_N, N_list,num_epochs,plot_freq, Nx, order, k =1, rand_deter = 'deter', linear_solver = "direct",memory = 2**29): 
    """ Orthogonal greedy algorithm using 1D ReLU dictionary over [-pi,pi]
    Parameters
    ----------
    my_model: 
        nn model 
    target: 
        rhs hand side function for a PDE 
    u_exact:
        exact solution 
    u_exact_grad:
        a function that returns gradient of the exact solution in a list 
    g_N: 
        a function that returns gradient of the exact solution with numbers  
    num_epochs: int 
        number of training epochs 
    integration_intervals: int 
        number of subintervals for piecewise numerical quadrature 

    Returns
    -------
    err: tensor 
        rank 1 torch tensor to record the L2 error history  
    model: 
        trained nn model 
    """
    gw_expand, integration_points = PiecewiseGQ3D_weights_points(Nx, order)
    dim = integration_points.size(1) 
    M = integration_points.size(0)
    weights_bd, integration_points_bd = Neumann_boundary_quadrature_points_weights(99999999,dim) 

    # Compute initial L2 error and the gradient error 
    err = torch.zeros(num_epochs+1).to(device)
    err_h10 = torch.zeros(num_epochs+1).to(device)
    num_neuron = 0 if my_model == None else int(my_model.fc1.bias.detach().data.size(0))
    total_size2 = M*(num_neuron+1)
    num_batch2 = total_size2//memory + 1 
    batch_size_2 = M//num_batch2 # integration points 
    if my_model == None: 
        for jj in range(0,M,batch_size_2): 
            end_index = jj + batch_size_2 
            func_values = target(integration_points[jj:end_index,:])
            err[0] += torch.sum(func_values**2 * gw_expand[jj:end_index,:])**0.5
        list_b = []
        list_w = []
    else: 
        bias = my_model.fc1.bias.detach().data
        weights = my_model.fc1.weight.detach().data
        for jj in range(0,M,batch_size_2): 
            end_index = jj + batch_size_2 
            func_values = u_exact(integration_points[jj:end_index,:]) - my_model(integration_points[jj:end_index,:]).detach()
            err[0] += torch.sum(func_values**2 * gw_expand[jj:end_index,:])**0.5
        list_b = list(bias)
        list_w = list(weights)
        sol = my_model.fc2.weight.data[0,:]

    # initial gradient error 
    if u_exact_grad != None and my_model!=None:
        u_grad = u_exact_grad() 
        for ii, grad_i in enumerate(u_grad): 
            for jj in range(0,M,batch_size_2): 
                end_index = jj + batch_size_2 
                my_model_dxi = my_model.evaluate_derivative(integration_points[jj:end_index,:],ii+1).detach() 
                err_h10[0] += torch.sum((grad_i(integration_points[jj:end_index,:]) - my_model_dxi)**2 * gw_expand[jj:end_index,:])**0.5
    elif u_exact_grad != None and my_model==None:
        u_grad = u_exact_grad() 
        for grad_i in u_grad: 
            for jj in range(0,M,batch_size_2): 
                end_index = jj + batch_size_2 
                err_h10[0] += torch.sum((grad_i(integration_points[jj:end_index,:]))**2 * gw_expand[jj:end_index,:])**0.5
    
    start_time = time.time()
    solver = linear_solver
    N0 = np.prod(N_list)
    if rand_deter == 'deter':
        relu_dict_parameters = generate_relu_dict3D(N_list).to(device)
    print("using linear solver: ",solver)
    # CGA training loop 
    for i in range(num_epochs): 
        print("epoch: ",i+1, end = '\t')
        if rand_deter == 'rand':
            relu_dict_parameters = generate_relu_dict3D_QMC(1,N0).to(device) 
        
        time_argmax = time.time()
        neuron_index = select_greedy_neuron_ind(relu_dict_parameters,my_model,target,gw_expand, integration_points,g_N,weights_bd, integration_points_bd,k,memory=memory)
        print("=======> argmax subproblem time: ",time.time() - time_argmax)
        # print(neuron_index)
        list_w.append(relu_dict_parameters[neuron_index,0:dim]) # 
        list_b.append(-relu_dict_parameters[neuron_index,dim])
        num_neuron += 1
        my_model = model(dim,num_neuron,1,k).to(device)
        w_tensor = torch.stack(list_w, 0 ) 
        b_tensor = torch.tensor(list_b)
        my_model.fc1.weight.data[:,:] = w_tensor[:,:]
        my_model.fc1.bias.data[:] = b_tensor[:]

        ##todo 
        if num_neuron <=2: 
            my_model.fc2.weight.data[0,:] = 0.0001
        else: 
            ## L2 projection onto previous solution as the initial guess 
            my_model.fc2.weight.data[0,:num_neuron -1 ] = sol[:] # projection of previous solution
            my_model = L2_projection_init(my_model,sol,gw_expand,integration_points,activation = 'relu', solver = solver) 

        sol = minimize_linear_layer_newton_method(my_model,alpha, target,\
                    gw_expand, integration_points,weights_bd, integration_points_bd,\
                    g_N,activation ='relu', solver = solver)
        
        sol = sol.flatten() 
        my_model.fc2.weight.data[0,:] = sol[:]

        # Get L2 error and gradient error 
        total_size2 = M*(num_neuron+1)
        num_batch2 = total_size2//memory + 1 
        batch_size_2 = M//num_batch2 # integration points 
        
        for jj in range(0,M,batch_size_2):
            end_index = jj + batch_size_2 
            func_values = u_exact(integration_points[jj:end_index,:]) - my_model(integration_points[jj:end_index,:]).detach()
            func_values = func_values**2 
            err[i+1]+= torch.sum(func_values*gw_expand[jj:end_index,:])**0.5

        if u_exact_grad != None:
            for ii, grad_i in enumerate(u_grad): 
                for jj in range(0,M,batch_size_2): 
                    end_index = jj + batch_size_2 
                    my_model_dxi = my_model.evaluate_derivative(integration_points[jj:end_index,:],ii+1).detach() 
                    err_h10[i+1] += torch.sum((grad_i(integration_points[jj:end_index,:]) - my_model_dxi)**2 * gw_expand[jj:end_index,:])**0.5

    print("time taken: ",time.time() - start_time)
    return err.cpu(), err_h10.cpu(), my_model

# %%
freq = 1
def u_exact(x):
    return torch.cos(freq*pi*x[:,0:1])*torch.cos( freq*pi*x[:,1:2]) * torch.cos(freq*pi*x[:,2:3])  
def alpha(x): 
    return torch.ones(x.size(0),1).to(device)

def u_exact_grad():
    d = 3 
    def grad_1(x):
        return - freq*pi* torch.sin(freq*pi*x[:,0:1])*torch.cos( freq*pi*x[:,1:2]) * torch.cos(freq*pi*x[:,2:3])   
    def grad_2(x):
        return - freq*pi* torch.cos(freq*pi*x[:,0:1])*torch.sin( freq*pi*x[:,1:2]) * torch.cos(freq*pi*x[:,2:3])  
    def grad_3(x):
        return - freq*pi* torch.cos(freq*pi*x[:,0:1])*torch.cos( freq*pi*x[:,1:2]) * torch.sin(freq*pi*x[:,2:3])   
    
    u_grad=[grad_1, grad_2,grad_3] 

    return u_grad
def laplace_u_exact(x):
    return -3*(freq*pi)**2 * torch.cos(freq*pi*x[:,0:1])*torch.cos( freq*pi*x[:,1:2]) * torch.cos(freq*pi*x[:,2:3])
# def target(x):
#     z = -laplace_u_exact(x) + u_exact(x)**3 
#     return z 

def u_exact_approx(x):
    return 0.7 * u_exact(x)

def rhs(x):
    return  -laplace_u_exact(x) + nonlinear(u_exact(x))

g_N = None 

function_name = "cos4pix" 
filename_write = "3DCGA-{}-order.txt".format(function_name)
f_write = open(filename_write, "a")
f_write.write("\n")
f_write.close() 
save = False 
relu_k = 3
for N_list in [[2**3,2**3,2**3]]: # ,[2**6,2**6],[2**7,2**7] 
    # save = True 
    f_write = open(filename_write, "a")
    my_model = None 
    Nx = 100
    order = 3
    exponent = 5
    num_epochs = 2**exponent  
    plot_freq = num_epochs 
    N = np.prod(N_list)
    err_QMC2, err_h10, my_model = CGANonlinearPoissonReLU3D(my_model,rhs,alpha, u_exact, u_exact_grad,g_N, N_list,num_epochs,plot_freq, Nx, order, k = relu_k, rand_deter = 'rand', linear_solver = "direct")
    if save: 
        folder = 'data-neumann/'
        filename = folder + 'err_OGA_2D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        torch.save(err_QMC2,filename) 
        folder = 'data-neumann/'
        filename = folder + 'model_OGA_2D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        torch.save(my_model,filename)

    show_convergence_order(err_QMC2,err_h10,exponent,N,filename_write,False)
    show_convergence_order_latex(err_QMC2,err_h10,exponent,k =relu_k,d = 3)
# Out:
# using linear solver:  direct
# epoch:  1	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.00968623161315918
# ======TIME=======stiffness matrix terms time : 1.6689300537109375e-06
# ======TIME=======neumann bd terms time : 9.298324584960938e-06
# =======> argmax subproblem time:  0.009844064712524414
# total size: 1 27000000 = 27000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.01078851561903999 	 residual l2 norm: 0.2939186666048791
# newton iteration:  2
# sol_update_l2_norm:5.375800649556315e-07 	 residual l2 norm: 1.4647860005823077e-05
# newton iteration:  3
# sol_update_l2_norm:4.106123599433748e-15 	 residual l2 norm: 1.1188272530660015e-13
# converged at iteration:  3
# sol_update_l2_norm:4.106123599433748e-15 	 residual l2 norm: 1.1188272530660015e-13
# epoch:  2	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.009660482406616211
# ======TIME=======stiffness matrix terms time : 1.0908148288726807
# ======TIME=======neumann bd terms time : 1.1920928955078125e-06
# =======> argmax subproblem time:  1.1079354286193848
# total size: 2 27000000 = 54000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.016145727921363942 	 residual l2 norm: 0.30159206821167717
# newton iteration:  2
# sol_update_l2_norm:2.1704640831503995e-07 	 residual l2 norm: 1.4446451249101614e-05
# newton iteration:  3
# sol_update_l2_norm:3.5194155383788287e-16 	 residual l2 norm: 3.857222461491054e-14
# converged at iteration:  3
# sol_update_l2_norm:3.5194155383788287e-16 	 residual l2 norm: 3.857222461491054e-14
# epoch:  3	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.009874343872070312
# ======TIME=======stiffness matrix terms time : 1.1208264827728271
# ======TIME=======neumann bd terms time : 1.430511474609375e-06
# =======> argmax subproblem time:  1.1381721496582031
# assembling the matrix time taken:  0.0004911422729492188
# solving Ax = b time taken:  0.015106678009033203
# total size: 3 27000000 = 81000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.028306560962379705 	 residual l2 norm: 1.2659707602397265
# newton iteration:  2
# sol_update_l2_norm:5.648699318749937e-06 	 residual l2 norm: 0.0004221881058659032
# newton iteration:  3
# sol_update_l2_norm:1.3342422769076345e-12 	 residual l2 norm: 1.3435010548900106e-10
# converged at iteration:  3
# sol_update_l2_norm:1.3342422769076345e-12 	 residual l2 norm: 1.3435010548900106e-10
# epoch:  4	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.009836673736572266
# ======TIME=======stiffness matrix terms time : 1.129058837890625
# ======TIME=======neumann bd terms time : 9.5367431640625e-07
# =======> argmax subproblem time:  1.146355390548706
# assembling the matrix time taken:  0.00042700767517089844
# solving Ax = b time taken:  0.016297340393066406
# total size: 4 27000000 = 108000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.043427085777755565 	 residual l2 norm: 0.7543476789865513
# newton iteration:  2
# sol_update_l2_norm:3.5134983289204713e-06 	 residual l2 norm: 0.0006583436327251247
# newton iteration:  3
# sol_update_l2_norm:1.0172029919048834e-12 	 residual l2 norm: 7.522607167910923e-11
# converged at iteration:  3
# sol_update_l2_norm:1.0172029919048834e-12 	 residual l2 norm: 7.522607167910923e-11
# epoch:  5	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.009860038757324219
# ======TIME=======stiffness matrix terms time : 1.1309762001037598
# ======TIME=======neumann bd terms time : 1.6689300537109375e-06
# =======> argmax subproblem time:  1.1482927799224854
# assembling the matrix time taken:  0.0004508495330810547
# solving Ax = b time taken:  0.01747918128967285
# total size: 5 27000000 = 135000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.017693273311954003 	 residual l2 norm: 1.159475116386384
# newton iteration:  2
# sol_update_l2_norm:7.257234636784974e-07 	 residual l2 norm: 0.00010240586873073665
# newton iteration:  3
# sol_update_l2_norm:2.0932222054038022e-14 	 residual l2 norm: 1.4472582134329614e-12
# converged at iteration:  3
# sol_update_l2_norm:2.0932222054038022e-14 	 residual l2 norm: 1.4472582134329614e-12
# epoch:  6	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.010092020034790039
# ======TIME=======stiffness matrix terms time : 1.1368465423583984
# ======TIME=======neumann bd terms time : 2.1457672119140625e-06
# =======> argmax subproblem time:  1.1544055938720703
# assembling the matrix time taken:  0.0005052089691162109
# solving Ax = b time taken:  0.01862311363220215
# total size: 6 27000000 = 162000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.09145354501491805 	 residual l2 norm: 0.5375683968646331
# newton iteration:  2
# sol_update_l2_norm:3.1460100084628556e-06 	 residual l2 norm: 0.00011240453705891446
# newton iteration:  3
# sol_update_l2_norm:2.7253126183949662e-14 	 residual l2 norm: 5.021640920420788e-13
# converged at iteration:  3
# sol_update_l2_norm:2.7253126183949662e-14 	 residual l2 norm: 5.021640920420788e-13
# epoch:  7	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.009827136993408203
# ======TIME=======stiffness matrix terms time : 1.1408345699310303
# ======TIME=======neumann bd terms time : 2.1457672119140625e-06
# =======> argmax subproblem time:  1.1581344604492188
# assembling the matrix time taken:  0.0004563331604003906
# solving Ax = b time taken:  0.019499540328979492
# total size: 7 27000000 = 189000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.11979397560014042 	 residual l2 norm: 0.7146121133856782
# newton iteration:  2
# sol_update_l2_norm:3.492797638273919e-05 	 residual l2 norm: 0.001489450075514125
# newton iteration:  3
# sol_update_l2_norm:5.63176734175411e-11 	 residual l2 norm: 3.7195178911941038e-09
# converged at iteration:  3
# sol_update_l2_norm:5.63176734175411e-11 	 residual l2 norm: 3.7195178911941038e-09
# epoch:  8	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.009876728057861328
# ======TIME=======stiffness matrix terms time : 1.1490013599395752
# ======TIME=======neumann bd terms time : 1.430511474609375e-06
# =======> argmax subproblem time:  1.1663610935211182
# assembling the matrix time taken:  0.00045609474182128906
# solving Ax = b time taken:  0.020570993423461914
# total size: 8 27000000 = 216000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.5142700035743386 	 residual l2 norm: 0.8001654964650007
# newton iteration:  2
# sol_update_l2_norm:0.00017775126096517118 	 residual l2 norm: 0.005962249567191119
# newton iteration:  3
# sol_update_l2_norm:1.4400631739170844e-09 	 residual l2 norm: 5.6472097552599675e-08
# newton iteration:  4
# sol_update_l2_norm:3.16463024661575e-16 	 residual l2 norm: 1.0241956074881825e-14
# converged at iteration:  4
# sol_update_l2_norm:3.16463024661575e-16 	 residual l2 norm: 1.0241956074881825e-14
# epoch:  9	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.009849071502685547
# ======TIME=======stiffness matrix terms time : 1.148864984512329
# ======TIME=======neumann bd terms time : 9.5367431640625e-07
# =======> argmax subproblem time:  1.1661741733551025
# assembling the matrix time taken:  0.0004189014434814453
# solving Ax = b time taken:  0.02176523208618164
# total size: 9 27000000 = 243000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:3.2814925199663922 	 residual l2 norm: 1.218253238027278
# newton iteration:  2
# sol_update_l2_norm:0.0025648633530793025 	 residual l2 norm: 0.02212340066492782
# newton iteration:  3
# sol_update_l2_norm:1.1749372532821164e-07 	 residual l2 norm: 5.110264634059955e-07
# newton iteration:  4
# sol_update_l2_norm:3.744131350188663e-15 	 residual l2 norm: 3.58819811967434e-14
# converged at iteration:  4
# sol_update_l2_norm:3.744131350188663e-15 	 residual l2 norm: 3.58819811967434e-14
# epoch:  10	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.009846687316894531
# ======TIME=======stiffness matrix terms time : 1.1586072444915771
# ======TIME=======neumann bd terms time : 2.1457672119140625e-06
# =======> argmax subproblem time:  1.1759252548217773
# assembling the matrix time taken:  0.00042939186096191406
# solving Ax = b time taken:  0.02275872230529785
# total size: 10 27000000 = 270000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.6856423719610536 	 residual l2 norm: 0.8654217504138438
# newton iteration:  2
# sol_update_l2_norm:0.0009038680919743307 	 residual l2 norm: 0.012018091922618837
# newton iteration:  3
# sol_update_l2_norm:1.9819741922646746e-08 	 residual l2 norm: 3.304949232477068e-07
# newton iteration:  4
# sol_update_l2_norm:5.6361912502261825e-15 	 residual l2 norm: 7.203592748597016e-14
# converged at iteration:  4
# sol_update_l2_norm:5.6361912502261825e-15 	 residual l2 norm: 7.203592748597016e-14
# epoch:  11	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.010068416595458984
# ======TIME=======stiffness matrix terms time : 1.1592226028442383
# ======TIME=======neumann bd terms time : 1.6689300537109375e-06
# =======> argmax subproblem time:  1.1767821311950684
# assembling the matrix time taken:  0.00045180320739746094
# solving Ax = b time taken:  0.023944854736328125
# total size: 11 27000000 = 297000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:1.3009466984778992 	 residual l2 norm: 0.5845602239665436
# newton iteration:  2
# sol_update_l2_norm:0.0010236187882163715 	 residual l2 norm: 0.007101562193244814
# newton iteration:  3
# sol_update_l2_norm:7.868609253440561e-09 	 residual l2 norm: 2.2010838211066648e-07
# newton iteration:  4
# sol_update_l2_norm:3.651954010057867e-15 	 residual l2 norm: 9.195287553885311e-14
# converged at iteration:  4
# sol_update_l2_norm:3.651954010057867e-15 	 residual l2 norm: 9.195287553885311e-14
# epoch:  12	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.009864091873168945
# ======TIME=======stiffness matrix terms time : 1.167945384979248
# ======TIME=======neumann bd terms time : 1.6689300537109375e-06
# =======> argmax subproblem time:  1.1852819919586182
# assembling the matrix time taken:  0.00045418739318847656
# solving Ax = b time taken:  0.02504277229309082
# total size: 12 27000000 = 324000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:1.2520491978218955 	 residual l2 norm: 0.5846465624853525
# newton iteration:  2
# sol_update_l2_norm:0.0009212628427836678 	 residual l2 norm: 0.009598649138720291
# newton iteration:  3
# sol_update_l2_norm:8.403280050571416e-09 	 residual l2 norm: 1.439626283895362e-07
# newton iteration:  4
# sol_update_l2_norm:7.946978647827011e-15 	 residual l2 norm: 4.586306071197028e-14
# converged at iteration:  4
# sol_update_l2_norm:7.946978647827011e-15 	 residual l2 norm: 4.586306071197028e-14
# epoch:  13	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.00987100601196289
# ======TIME=======stiffness matrix terms time : 1.1713287830352783
# ======TIME=======neumann bd terms time : 1.6689300537109375e-06
# =======> argmax subproblem time:  1.1886646747589111
# assembling the matrix time taken:  0.00045609474182128906
# solving Ax = b time taken:  0.026406049728393555
# total size: 13 27000000 = 351000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.999037967863613 	 residual l2 norm: 0.1311445713861985
# newton iteration:  2
# sol_update_l2_norm:0.00033621897586674125 	 residual l2 norm: 0.0022053834624913187
# newton iteration:  3
# sol_update_l2_norm:2.804699605420961e-10 	 residual l2 norm: 5.30867771085741e-09
# converged at iteration:  3
# sol_update_l2_norm:2.804699605420961e-10 	 residual l2 norm: 5.30867771085741e-09
# epoch:  14	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.010101079940795898
# ======TIME=======stiffness matrix terms time : 1.1806278228759766
# ======TIME=======neumann bd terms time : 2.1457672119140625e-06
# =======> argmax subproblem time:  1.1982159614562988
# assembling the matrix time taken:  0.0004494190216064453
# solving Ax = b time taken:  0.027563810348510742
# total size: 14 27000000 = 378000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:1.234873844092963 	 residual l2 norm: 0.06147119953554633
# newton iteration:  2
# sol_update_l2_norm:0.00013383099074531753 	 residual l2 norm: 0.0011721386099788327
# newton iteration:  3
# sol_update_l2_norm:1.0595283710091953e-10 	 residual l2 norm: 2.2477992377235183e-09
# converged at iteration:  3
# sol_update_l2_norm:1.0595283710091953e-10 	 residual l2 norm: 2.2477992377235183e-09
# epoch:  15	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.009892940521240234
# ======TIME=======stiffness matrix terms time : 1.181490182876587
# ======TIME=======neumann bd terms time : 1.9073486328125e-06
# =======> argmax subproblem time:  1.1988587379455566
# assembling the matrix time taken:  0.0004444122314453125
# solving Ax = b time taken:  0.028994083404541016
# total size: 15 27000000 = 405000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.4679692890485168 	 residual l2 norm: 0.02981637599769094
# newton iteration:  2
# sol_update_l2_norm:2.1011833334897903e-05 	 residual l2 norm: 7.223033027966959e-05
# newton iteration:  3
# sol_update_l2_norm:8.795706014534791e-13 	 residual l2 norm: 1.627695944605446e-11
# converged at iteration:  3
# sol_update_l2_norm:8.795706014534791e-13 	 residual l2 norm: 1.627695944605446e-11
# epoch:  16	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.009817123413085938
# ======TIME=======stiffness matrix terms time : 1.191406488418579
# ======TIME=======neumann bd terms time : 1.6689300537109375e-06
# =======> argmax subproblem time:  1.208693027496338
# assembling the matrix time taken:  0.00043892860412597656
# solving Ax = b time taken:  0.029810428619384766
# total size: 16 27000000 = 432000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.37952763653074156 	 residual l2 norm: 0.024627741044920458
# newton iteration:  2
# sol_update_l2_norm:6.3079085306176204e-06 	 residual l2 norm: 2.5083065787260886e-05
# newton iteration:  3
# sol_update_l2_norm:9.400165842832986e-14 	 residual l2 norm: 7.908174890696314e-13
# converged at iteration:  3
# sol_update_l2_norm:9.400165842832986e-14 	 residual l2 norm: 7.908174890696314e-13
# epoch:  17	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.010160207748413086
# ======TIME=======stiffness matrix terms time : 1.1861443519592285
# ======TIME=======neumann bd terms time : 1.6689300537109375e-06
# =======> argmax subproblem time:  1.2037789821624756
# assembling the matrix time taken:  0.0004582405090332031
# solving Ax = b time taken:  0.03156423568725586
# total size: 17 27000000 = 459000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.7924093051094017 	 residual l2 norm: 0.017645138441077877
# newton iteration:  2
# sol_update_l2_norm:3.936750974050154e-05 	 residual l2 norm: 0.00012518190113691341
# newton iteration:  3
# sol_update_l2_norm:4.083592891193886e-12 	 residual l2 norm: 1.8019730723095822e-11
# converged at iteration:  3
# sol_update_l2_norm:4.083592891193886e-12 	 residual l2 norm: 1.8019730723095822e-11
# epoch:  18	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.009899377822875977
# ======TIME=======stiffness matrix terms time : 1.2000138759613037
# ======TIME=======neumann bd terms time : 1.1920928955078125e-06
# =======> argmax subproblem time:  1.2173993587493896
# assembling the matrix time taken:  0.0005450248718261719
# solving Ax = b time taken:  0.03262186050415039
# total size: 18 27000000 = 486000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.9153308363990071 	 residual l2 norm: 0.014292452128946614
# newton iteration:  2
# sol_update_l2_norm:2.3033665861649836e-05 	 residual l2 norm: 8.737334038795971e-05
# newton iteration:  3
# sol_update_l2_norm:1.635321467314652e-12 	 residual l2 norm: 2.458983720657973e-11
# converged at iteration:  3
# sol_update_l2_norm:1.635321467314652e-12 	 residual l2 norm: 2.458983720657973e-11
# epoch:  19	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.009855508804321289
# ======TIME=======stiffness matrix terms time : 1.2003979682922363
# ======TIME=======neumann bd terms time : 1.9073486328125e-06
# =======> argmax subproblem time:  1.2177391052246094
# assembling the matrix time taken:  0.00046181678771972656
# solving Ax = b time taken:  0.03406929969787598
# total size: 19 27000000 = 513000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.9892556824692966 	 residual l2 norm: 0.016649582812112547
# newton iteration:  2
# sol_update_l2_norm:1.9400007508736594e-05 	 residual l2 norm: 9.955551382601156e-05
# newton iteration:  3
# sol_update_l2_norm:7.526343171068411e-13 	 residual l2 norm: 1.8031683024873528e-11
# converged at iteration:  3
# sol_update_l2_norm:7.526343171068411e-13 	 residual l2 norm: 1.8031683024873528e-11
# epoch:  20	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.010226249694824219
# ======TIME=======stiffness matrix terms time : 1.2095553874969482
# ======TIME=======neumann bd terms time : 1.6689300537109375e-06
# =======> argmax subproblem time:  1.227254867553711
# assembling the matrix time taken:  0.0004761219024658203
# solving Ax = b time taken:  0.03514266014099121
# total size: 20 27000000 = 540000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:3.7572575864749584 	 residual l2 norm: 0.016190870055407362
# newton iteration:  2
# sol_update_l2_norm:0.00010617030984307188 	 residual l2 norm: 0.0003537774914142732
# newton iteration:  3
# sol_update_l2_norm:2.1257196016007276e-11 	 residual l2 norm: 7.321235908204499e-11
# converged at iteration:  3
# sol_update_l2_norm:2.1257196016007276e-11 	 residual l2 norm: 7.321235908204499e-11
# epoch:  21	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.01022028923034668
# ======TIME=======stiffness matrix terms time : 1.2092437744140625
# ======TIME=======neumann bd terms time : 1.1920928955078125e-06
# =======> argmax subproblem time:  1.2269189357757568
# assembling the matrix time taken:  0.00046944618225097656
# solving Ax = b time taken:  0.036687612533569336
# total size: 21 27000000 = 567000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:17.001944943764276 	 residual l2 norm: 0.02351833869606006
# newton iteration:  2
# sol_update_l2_norm:0.002236704672094468 	 residual l2 norm: 0.00372169225247587
# newton iteration:  3
# sol_update_l2_norm:1.2470330564432276e-09 	 residual l2 norm: 1.303171595632578e-08
# converged at iteration:  3
# sol_update_l2_norm:1.2470330564432276e-09 	 residual l2 norm: 1.303171595632578e-08
# epoch:  22	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.010156631469726562
# ======TIME=======stiffness matrix terms time : 1.2210612297058105
# ======TIME=======neumann bd terms time : 2.1457672119140625e-06
# =======> argmax subproblem time:  1.238694429397583
# assembling the matrix time taken:  0.0004754066467285156
# solving Ax = b time taken:  0.03769373893737793
# total size: 22 27000000 = 594000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:15.394125148299947 	 residual l2 norm: 0.017398456461673584
# newton iteration:  2
# sol_update_l2_norm:0.0008160040756878597 	 residual l2 norm: 0.0006451829662856493
# newton iteration:  3
# sol_update_l2_norm:1.4627468918628584e-09 	 residual l2 norm: 5.442438157593797e-09
# converged at iteration:  3
# sol_update_l2_norm:1.4627468918628584e-09 	 residual l2 norm: 5.442438157593797e-09
# epoch:  23	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.010487079620361328
# ======TIME=======stiffness matrix terms time : 1.2217235565185547
# ======TIME=======neumann bd terms time : 1.1920928955078125e-06
# =======> argmax subproblem time:  1.2396810054779053
# assembling the matrix time taken:  0.0005362033843994141
# solving Ax = b time taken:  0.038867950439453125
# total size: 23 27000000 = 621000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:8.383370634920599 	 residual l2 norm: 0.01394891052441038
# newton iteration:  2
# sol_update_l2_norm:0.0018130596194369682 	 residual l2 norm: 0.004164566467784075
# newton iteration:  3
# sol_update_l2_norm:7.708927019191129e-09 	 residual l2 norm: 2.4969054603772216e-08
# newton iteration:  4
# sol_update_l2_norm:4.358762478263067e-12 	 residual l2 norm: 5.502528181013341e-13
# converged at iteration:  4
# sol_update_l2_norm:4.358762478263067e-12 	 residual l2 norm: 5.502528181013341e-13
# epoch:  24	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.010539531707763672
# ======TIME=======stiffness matrix terms time : 1.2312393188476562
# ======TIME=======neumann bd terms time : 9.5367431640625e-07
# =======> argmax subproblem time:  1.249237060546875
# assembling the matrix time taken:  0.0004658699035644531
# solving Ax = b time taken:  0.039736032485961914
# total size: 24 27000000 = 648000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:5.518568267787722 	 residual l2 norm: 0.0159527176069611
# newton iteration:  2
# sol_update_l2_norm:0.00024389718097403385 	 residual l2 norm: 0.0006359111644628754
# newton iteration:  3
# sol_update_l2_norm:8.61740641647849e-11 	 residual l2 norm: 4.062366182555709e-10
# converged at iteration:  3
# sol_update_l2_norm:8.61740641647849e-11 	 residual l2 norm: 4.062366182555709e-10
# epoch:  25	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.01042795181274414
# ======TIME=======stiffness matrix terms time : 1.227018117904663
# ======TIME=======neumann bd terms time : 1.1920928955078125e-06
# =======> argmax subproblem time:  1.2449278831481934
# assembling the matrix time taken:  0.0004611015319824219
# solving Ax = b time taken:  0.04109930992126465
# total size: 25 27000000 = 675000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:18.005775019705972 	 residual l2 norm: 0.010465568256110539
# newton iteration:  2
# sol_update_l2_norm:0.0040901546214204415 	 residual l2 norm: 0.002843373090384338
# newton iteration:  3
# sol_update_l2_norm:1.0816063375575796e-08 	 residual l2 norm: 1.753742384442722e-08
# newton iteration:  4
# sol_update_l2_norm:2.2384268708575316e-12 	 residual l2 norm: 6.833063004531769e-13
# converged at iteration:  4
# sol_update_l2_norm:2.2384268708575316e-12 	 residual l2 norm: 6.833063004531769e-13
# epoch:  26	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.010208606719970703
# ======TIME=======stiffness matrix terms time : 1.2409601211547852
# ======TIME=======neumann bd terms time : 2.1457672119140625e-06
# =======> argmax subproblem time:  1.2586369514465332
# assembling the matrix time taken:  0.00045561790466308594
# solving Ax = b time taken:  0.041948795318603516
# total size: 26 27000000 = 702000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:12.542401903682135 	 residual l2 norm: 0.014787494743661214
# newton iteration:  2
# sol_update_l2_norm:0.000595202014790467 	 residual l2 norm: 0.0012263018693190186
# newton iteration:  3
# sol_update_l2_norm:7.560765866210429e-10 	 residual l2 norm: 3.561506464175092e-09
# converged at iteration:  3
# sol_update_l2_norm:7.560765866210429e-10 	 residual l2 norm: 3.561506464175092e-09
# epoch:  27	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.010488510131835938
# ======TIME=======stiffness matrix terms time : 1.2419660091400146
# ======TIME=======neumann bd terms time : 1.6689300537109375e-06
# =======> argmax subproblem time:  1.2599341869354248
# assembling the matrix time taken:  0.000469207763671875
# solving Ax = b time taken:  0.04326486587524414
# total size: 27 27000000 = 729000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:10.881687074183358 	 residual l2 norm: 0.006563942724700058
# newton iteration:  2
# sol_update_l2_norm:0.0004093106919089188 	 residual l2 norm: 0.000173952446359783
# newton iteration:  3
# sol_update_l2_norm:4.450475025937332e-11 	 residual l2 norm: 1.1973050974251057e-10
# converged at iteration:  3
# sol_update_l2_norm:4.450475025937332e-11 	 residual l2 norm: 1.1973050974251057e-10
# epoch:  28	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.010313987731933594
# ======TIME=======stiffness matrix terms time : 1.250641107559204
# ======TIME=======neumann bd terms time : 1.430511474609375e-06
# =======> argmax subproblem time:  1.2684528827667236
# assembling the matrix time taken:  0.0004878044128417969
# solving Ax = b time taken:  0.043949127197265625
# total size: 28 27000000 = 756000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:7.766073054907539 	 residual l2 norm: 0.008705229450404015
# newton iteration:  2
# sol_update_l2_norm:0.0005776627023410875 	 residual l2 norm: 0.0003619768959102803
# newton iteration:  3
# sol_update_l2_norm:1.6782279924346238e-10 	 residual l2 norm: 3.2438479946347287e-10
# converged at iteration:  3
# sol_update_l2_norm:1.6782279924346238e-10 	 residual l2 norm: 3.2438479946347287e-10
# epoch:  29	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.010272979736328125
# ======TIME=======stiffness matrix terms time : 1.2492146492004395
# ======TIME=======neumann bd terms time : 1.1920928955078125e-06
# =======> argmax subproblem time:  1.2669594287872314
# assembling the matrix time taken:  0.00046515464782714844
# solving Ax = b time taken:  0.04535937309265137
# total size: 29 27000000 = 783000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:8.034355665597747 	 residual l2 norm: 0.004354992643040975
# newton iteration:  2
# sol_update_l2_norm:0.00017193678232079555 	 residual l2 norm: 5.5880088754825416e-05
# newton iteration:  3
# sol_update_l2_norm:8.292652468023292e-12 	 residual l2 norm: 1.8721995510581585e-11
# converged at iteration:  3
# sol_update_l2_norm:8.292652468023292e-12 	 residual l2 norm: 1.8721995510581585e-11
# epoch:  30	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.010296821594238281
# ======TIME=======stiffness matrix terms time : 1.261716365814209
# ======TIME=======neumann bd terms time : 1.1920928955078125e-06
# =======> argmax subproblem time:  1.2795028686523438
# assembling the matrix time taken:  0.00045299530029296875
# solving Ax = b time taken:  0.0462644100189209
# total size: 30 27000000 = 810000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:2.5019902645418184 	 residual l2 norm: 0.003909997858796503
# newton iteration:  2
# sol_update_l2_norm:8.30508812710793e-05 	 residual l2 norm: 2.9451106031032326e-05
# newton iteration:  3
# sol_update_l2_norm:7.549095947523908e-12 	 residual l2 norm: 5.287088986792304e-13
# converged at iteration:  3
# sol_update_l2_norm:7.549095947523908e-12 	 residual l2 norm: 5.287088986792304e-13
# epoch:  31	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.01029205322265625
# ======TIME=======stiffness matrix terms time : 1.264800786972046
# ======TIME=======neumann bd terms time : 9.5367431640625e-07
# =======> argmax subproblem time:  1.2825748920440674
# assembling the matrix time taken:  0.0004706382751464844
# solving Ax = b time taken:  0.04761958122253418
# total size: 31 27000000 = 837000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:6.520462433421608 	 residual l2 norm: 0.0033435580733862467
# newton iteration:  2
# sol_update_l2_norm:0.00011008012517234538 	 residual l2 norm: 3.271400118240336e-05
# newton iteration:  3
# sol_update_l2_norm:5.8494599020544334e-12 	 residual l2 norm: 2.9449564109353902e-12
# converged at iteration:  3
# sol_update_l2_norm:5.8494599020544334e-12 	 residual l2 norm: 2.9449564109353902e-12
# epoch:  32	======argmax subproblem:f and N(u) terms, num batches:  26
# ======TIME=======f and N(u) terms time : 0.010339021682739258
# ======TIME=======stiffness matrix terms time : 1.2801799774169922
# ======TIME=======neumann bd terms time : 1.6689300537109375e-06
# =======> argmax subproblem time:  1.298013687133789
# assembling the matrix time taken:  0.0004937648773193359
# solving Ax = b time taken:  0.04814004898071289
# total size: 32 27000000 = 864000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:8.275623274424603 	 residual l2 norm: 0.004035048916980727
# newton iteration:  2
# sol_update_l2_norm:0.000133260216562625 	 residual l2 norm: 0.00012370040473804137
# newton iteration:  3
# sol_update_l2_norm:2.486968177934935e-11 	 residual l2 norm: 7.448412279451261e-11
# converged at iteration:  3
# sol_update_l2_norm:2.486968177934935e-11 	 residual l2 norm: 7.448412279451261e-11
# time taken:  108.69157385826111
# neuron num 		 error 		 order
# 4 		 0.352646 		 * 		 3.318723 		 *
#
# 8 		 0.347609 		 0.020755 		 3.191303 		 0.056483
#
# 16 		 0.095116 		 1.869713 		 1.535333 		 1.055594
#
# 32 		 0.038973 		 1.287201 		 0.813785 		 0.915833
#
# neuron num  & 	 $\|u-u_n \|_{L^2}$ & 	 order $O(n^{-1.67})$ & 	 $ | u -u_n |_{H^1}$ & 	 order $O(n^{-1.33})$ \\ \hline \hline
# 4 		 & 0.352646 &		 * & 		 3.318723 & 		 *  \\ \hline
#
# 8 		 &  3.476e-01 &  		 0.02 &  		 3.191e+00 &  		 0.06 \\ \hline
#
# 16 		 &  9.512e-02 &  		 1.87 &  		 1.535e+00 &  		 1.06 \\ \hline
#
# 32 		 &  3.897e-02 &  		 1.29 &  		 8.138e-01 &  		 0.92 \\ \hline

# %% [markdown]
# ## Gabor function

# %%
## Gabor function test 
freq = 2
sigma = 0.15 
def gaussian(x):
    return torch.exp(-torch.sum( (x - 0.5)**2,dim=1,keepdim=True)/(2 *sigma**2) ) 
def gaussian_grad_1(x):
    return  gaussian(x) * (- (x[:,0:1] - 0.5)/(sigma**2) ) 
def gaussian_grad_2(x):
    return  gaussian(x) * (- (x[:,1:2] - 0.5)/(sigma**2) ) 
def gaussian_grad_3(x):
    return  gaussian(x) * (- (x[:,2:3] - 0.5)/(sigma**2) ) 

def u_exact(x):
    return gaussian(x) * torch.cos(2*pi*freq*x[:,0:1]) 
def alpha(x): 
    return torch.ones(x.size(0),1).to(device)

def u_grad_1(x):
    return  torch.cos(2*pi*freq*x[:,0:1]) *gaussian_grad_1(x) \
            - 2*pi*freq * torch.sin(2*pi*freq*x[:,0:1]) * gaussian(x) 
def u_grad_2(x):
    return torch.cos(2*pi*freq*x[:,0:1]) * gaussian_grad_2(x)
def u_grad_3(x):
    return  torch.cos(2*pi*freq*x[:,0:1]) * gaussian_grad_3(x)

def u_exact_grad():
    d = 3 
    def u_grad_1(x):
        return  torch.cos(2*pi*freq*x[:,0:1]) *gaussian_grad_1(x) \
                - 2*pi*freq * torch.sin(2*pi*freq*x[:,0:1]) * gaussian(x) 
    def u_grad_2(x):
        return torch.cos(2*pi*freq*x[:,0:1]) * gaussian_grad_2(x)
    def u_grad_3(x):
        return  torch.cos(2*pi*freq*x[:,0:1]) * gaussian_grad_3(x)

    u_grad=[u_grad_1, u_grad_2,u_grad_3] 
    return u_grad

def laplace_u_exact(x):
    return - 2*pi*freq * torch.sin(2*pi*freq*x[:,0:1]) *gaussian_grad_1(x) \
            + torch.cos(2*pi*freq*x[:,0:1])*( gaussian(x) * ( ((x[:,0:1] - 0.5)/(sigma**2))**2 -1/(sigma**2))  ) \
            -( (2*pi*freq)**2 * torch.cos(2*pi*freq*x[:,0:1]) * gaussian(x) + (2*pi*freq)*torch.sin(2*pi*freq*x[:,0:1]) * gaussian_grad_1(x) ) \
            + torch.cos(2*pi*freq*x[:,0:1]) * (gaussian(x) * ( ((x[:,1:2] - 0.5)/(sigma**2))**2 -1/(sigma**2) )  ) \
            + torch.cos(2*pi*freq*x[:,0:1]) * ( gaussian(x) * ( ((x[:,2:3] - 0.5)/(sigma**2))**2 -1/(sigma**2) )   ) \

def target(x):
    return - laplace_u_exact(x) + nonlinear(u_exact(x)) 

def g_N(dim):
    u_grad = u_exact_grad() 
    bcs_N = []
    for i in range(dim):
        bcs_N.append((i, u_grad[i]))
    return bcs_N

def u_exact_approx(x):
    return 0.99 * u_exact(x)

def rhs(x):
    return  -laplace_u_exact(x) + nonlinear(u_exact(x)) 


function_name = "gabor" 
filename_write = "3DCGA-{}-order.txt".format(function_name)
f_write = open(filename_write, "a")
f_write.write("\n")
f_write.close() 
save = True 

relu_k = 3
load_model_data = {'loadOrNot':True ,
                  'model_filename':"data-pb/model_OGA_3D_gabor_relu_3_neuron_512_N_384_randomized.pt",
                   'errl2_filename':'data-pb/errl2_OGA_3D_gabor_relu_3_neuron_512_N_384_randomized.pt',
                   'errh10_filename':'data-pb/errh10_OGA_3D_gabor_relu_3_neuron_512_N_384_randomized.pt',
                  'relu_k':3,
                  'neuron_num': 512}
for N_list in [[2**3,2**3,2**3]]: # ,[2**6,2**6],[2**7,2**7] 
    f_write = open(filename_write, "a")
    if load_model_data['loadOrNot'] == True: 
        my_model = model(3,load_model_data['neuron_num'],1,load_model_data['relu_k']).to(device)
        my_model.load_state_dict(torch.load(load_model_data['model_filename']))
    else: 
        my_model = None 
    Nx = 50
    order = 2
    exponent = 10
    num_epochs = (2**exponent) - load_model_data["neuron_num"] if load_model_data['loadOrNot'] else 2**exponent  
    plot_freq = num_epochs 
    N = np.prod(N_list)
    memomry_size = 2**30 
    err_QMC2, err_h10, my_model = CGANonlinearPoissonReLU3D(my_model,rhs,alpha, u_exact, u_exact_grad,g_N,\
                                        N_list,num_epochs,plot_freq, Nx, order, k = relu_k, \
                                        rand_deter = 'rand', linear_solver = "direct",memory = memomry_size)
    print(err_QMC2)
    print(err_h10)
    if load_model_data['loadOrNot']: # append the previous errrs 
        err_l2_previous = torch.load(load_model_data['errl2_filename'])
        err_h10_previous = torch.load(load_model_data['errh10_filename'])
        err_l2_combined = torch.zeros(2**exponent+1)
        err_h10_combined = torch.zeros(2**exponent+1)
        err_l2_combined[:load_model_data['neuron_num']+1] = err_l2_previous[:]
        err_l2_combined[load_model_data['neuron_num']+1 :] =  err_QMC2[1:]
        err_h10_combined[:load_model_data['neuron_num']+1] = err_h10_previous[:]
        err_h10_combined[load_model_data['neuron_num']+1 :] = err_h10[1:]
        err_QMC2 = err_l2_combined
        err_h10 = err_h10_combined 
    if save: 
        folder = 'data-pb/'
        neuron_num_save = load_model_data['neuron_num'] + num_epochs if load_model_data['loadOrNot'] else num_epochs
        filename = folder + 'errl2_OGA_3D_{}_relu_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,relu_k,neuron_num_save,N)
        torch.save(err_QMC2,filename) 
        filename = folder + 'errh10_OGA_3D_{}_relu_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,relu_k,neuron_num_save,N)
        torch.save(err_h10,filename) 
        filename = folder + 'model_OGA_3D_{}_relu_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,relu_k,neuron_num_save,N)
        torch.save(my_model.state_dict(),filename)

    show_convergence_order(err_QMC2,err_h10,exponent,N,filename_write,True)
    show_convergence_order_latex(err_QMC2,err_h10,exponent,k =relu_k,d = 3)
# Out:
# using linear solver:  direct
# epoch:  1	======TIME=======f and N(u) terms time : 0.0027904510498046875
# ======TIME=======stiffness matrix terms time : 0.04333353042602539
# ======TIME=======neumann bd terms time : 0.002124786376953125
# =======> argmax subproblem time:  0.04854106903076172
# assembling the matrix time taken:  0.0009076595306396484
# solving Ax = b time taken:  0.12247443199157715
# total size: 513 1000000 = 513000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:7.3996045114237745 	 residual l2 norm: 5.100221031323618e-05
# newton iteration:  2
# sol_update_l2_norm:0.0012292564692304626 	 residual l2 norm: 1.2066984239983582e-11
# newton iteration:  3
# sol_update_l2_norm:4.313037564659111e-06 	 residual l2 norm: 2.556211501847181e-12
# converged at iteration:  3
# sol_update_l2_norm:4.313037564659111e-06 	 residual l2 norm: 2.556211501847181e-12
# epoch:  2	======TIME=======f and N(u) terms time : 0.002566099166870117
# ======TIME=======stiffness matrix terms time : 0.041524648666381836
# ======TIME=======neumann bd terms time : 0.0017189979553222656
# =======> argmax subproblem time:  0.04595947265625
# assembling the matrix time taken:  0.42492198944091797
# solving Ax = b time taken:  0.072357177734375
# total size: 514 1000000 = 514000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:13.104673670362375 	 residual l2 norm: 4.533964400186347e-06
# newton iteration:  2
# sol_update_l2_norm:5.0509687925593376e-05 	 residual l2 norm: 1.5545659485416288e-08
# newton iteration:  3
# sol_update_l2_norm:3.008178855933073e-06 	 residual l2 norm: 7.600827801647959e-13
# converged at iteration:  3
# sol_update_l2_norm:3.008178855933073e-06 	 residual l2 norm: 7.600827801647959e-13
# epoch:  3	======TIME=======f and N(u) terms time : 0.0025565624237060547
# ======TIME=======stiffness matrix terms time : 0.041728973388671875
# ======TIME=======neumann bd terms time : 0.0017130374908447266
# =======> argmax subproblem time:  0.04615044593811035
# assembling the matrix time taken:  0.36440396308898926
# solving Ax = b time taken:  0.05814194679260254
# total size: 515 1000000 = 515000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:7.232895218395239 	 residual l2 norm: 1.784067758732943e-05
# newton iteration:  2
# sol_update_l2_norm:0.001072871077177687 	 residual l2 norm: 2.645337750620259e-09
# newton iteration:  3
# sol_update_l2_norm:7.829771558368322e-06 	 residual l2 norm: 2.4768997412767224e-12
# converged at iteration:  3
# sol_update_l2_norm:7.829771558368322e-06 	 residual l2 norm: 2.4768997412767224e-12
# epoch:  4	======TIME=======f and N(u) terms time : 0.002535581588745117
# ======TIME=======stiffness matrix terms time : 0.04161691665649414
# ======TIME=======neumann bd terms time : 0.0017085075378417969
# =======> argmax subproblem time:  0.046009063720703125
# assembling the matrix time taken:  0.46959972381591797
# solving Ax = b time taken:  0.05590081214904785
# total size: 516 1000000 = 516000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:21.117371160263723 	 residual l2 norm: 3.705306044603683e-05
# newton iteration:  2
# sol_update_l2_norm:0.002240968686239226 	 residual l2 norm: 3.605645842686032e-09
# newton iteration:  3
# sol_update_l2_norm:4.977480445099672e-07 	 residual l2 norm: 2.5750475712184463e-12
# converged at iteration:  3
# sol_update_l2_norm:4.977480445099672e-07 	 residual l2 norm: 2.5750475712184463e-12
# epoch:  5	======TIME=======f and N(u) terms time : 0.0025370121002197266
# ======TIME=======stiffness matrix terms time : 0.041608572006225586
# ======TIME=======neumann bd terms time : 0.0017046928405761719
# =======> argmax subproblem time:  0.04600238800048828
# assembling the matrix time taken:  0.4643137454986572
# solving Ax = b time taken:  0.05829501152038574
# total size: 517 1000000 = 517000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:4.900108938636949 	 residual l2 norm: 6.640248443894304e-06
# newton iteration:  2
# sol_update_l2_norm:0.0001695270444596972 	 residual l2 norm: 2.60348860826213e-09
# newton iteration:  3
# sol_update_l2_norm:2.1906382288652946e-07 	 residual l2 norm: 1.25215599378009e-12
# converged at iteration:  3
# sol_update_l2_norm:2.1906382288652946e-07 	 residual l2 norm: 1.25215599378009e-12
# epoch:  6	======TIME=======f and N(u) terms time : 0.0025925636291503906
# ======TIME=======stiffness matrix terms time : 0.04178929328918457
# ======TIME=======neumann bd terms time : 0.0017080307006835938
# =======> argmax subproblem time:  0.046241044998168945
# assembling the matrix time taken:  0.36014437675476074
# solving Ax = b time taken:  0.06981897354125977
# total size: 518 1000000 = 518000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:16.882754776295286 	 residual l2 norm: 1.9401455234168554e-05
# newton iteration:  2
# sol_update_l2_norm:0.000833469828985861 	 residual l2 norm: 5.033324591500622e-10
# newton iteration:  3
# sol_update_l2_norm:1.3755707507776893e-06 	 residual l2 norm: 1.8819606563659935e-12
# converged at iteration:  3
# sol_update_l2_norm:1.3755707507776893e-06 	 residual l2 norm: 1.8819606563659935e-12
# epoch:  7	======TIME=======f and N(u) terms time : 0.0025632381439208984
# ======TIME=======stiffness matrix terms time : 0.0417020320892334
# ======TIME=======neumann bd terms time : 0.0017278194427490234
# =======> argmax subproblem time:  0.046141862869262695
# assembling the matrix time taken:  0.46965813636779785
# solving Ax = b time taken:  0.05831003189086914
# total size: 519 1000000 = 519000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:12.354536740371637 	 residual l2 norm: 7.705396317077061e-06
# newton iteration:  2
# sol_update_l2_norm:0.000452432357122312 	 residual l2 norm: 5.804008986109254e-09
# newton iteration:  3
# sol_update_l2_norm:7.531457511614447e-06 	 residual l2 norm: 1.8408904504544494e-12
# converged at iteration:  3
# sol_update_l2_norm:7.531457511614447e-06 	 residual l2 norm: 1.8408904504544494e-12
# epoch:  8	======TIME=======f and N(u) terms time : 0.0025475025177001953
# ======TIME=======stiffness matrix terms time : 0.047988176345825195
# ======TIME=======neumann bd terms time : 0.0016951560974121094
# =======> argmax subproblem time:  0.052384138107299805
# assembling the matrix time taken:  0.466505765914917
# solving Ax = b time taken:  0.055773019790649414
# total size: 520 1000000 = 520000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:13.039888746500706 	 residual l2 norm: 1.6992884939889328e-05
# newton iteration:  2
# sol_update_l2_norm:0.00010487717413037565 	 residual l2 norm: 7.832908536584267e-10
# newton iteration:  3
# sol_update_l2_norm:8.397068606429966e-06 	 residual l2 norm: 1.0706997276216503e-12
# converged at iteration:  3
# sol_update_l2_norm:8.397068606429966e-06 	 residual l2 norm: 1.0706997276216503e-12
# epoch:  9	======TIME=======f and N(u) terms time : 0.002560853958129883
# ======TIME=======stiffness matrix terms time : 0.041616201400756836
# ======TIME=======neumann bd terms time : 0.0016982555389404297
# =======> argmax subproblem time:  0.046029090881347656
# assembling the matrix time taken:  0.5816650390625
# solving Ax = b time taken:  0.058175086975097656
# total size: 521 1000000 = 521000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:25.904606112695557 	 residual l2 norm: 2.2903483144971632e-05
# newton iteration:  2
# sol_update_l2_norm:0.002364834933196412 	 residual l2 norm: 4.885703787057777e-09
# newton iteration:  3
# sol_update_l2_norm:5.11066601392611e-07 	 residual l2 norm: 7.841026180924124e-13
# converged at iteration:  3
# sol_update_l2_norm:5.11066601392611e-07 	 residual l2 norm: 7.841026180924124e-13
# epoch:  10	======TIME=======f and N(u) terms time : 0.002553701400756836
# ======TIME=======stiffness matrix terms time : 0.04500913619995117
# ======TIME=======neumann bd terms time : 0.0017247200012207031
# =======> argmax subproblem time:  0.04943704605102539
# assembling the matrix time taken:  0.4691810607910156
# solving Ax = b time taken:  0.07269048690795898
# total size: 522 1000000 = 522000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:9.089944193904914 	 residual l2 norm: 1.172144996837108e-05
# newton iteration:  2
# sol_update_l2_norm:0.0006962626475033657 	 residual l2 norm: 8.144503519565172e-11
# newton iteration:  3
# sol_update_l2_norm:2.2686491191616286e-07 	 residual l2 norm: 1.7631713835354577e-12
# converged at iteration:  3
# sol_update_l2_norm:2.2686491191616286e-07 	 residual l2 norm: 1.7631713835354577e-12
# epoch:  11	======TIME=======f and N(u) terms time : 0.0025446414947509766
# ======TIME=======stiffness matrix terms time : 0.041637420654296875
# ======TIME=======neumann bd terms time : 0.001706838607788086
# =======> argmax subproblem time:  0.04603838920593262
# assembling the matrix time taken:  0.2561969757080078
# solving Ax = b time taken:  0.060782432556152344
# total size: 523 1000000 = 523000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:5.192089777434378 	 residual l2 norm: 4.400892483673619e-05
# newton iteration:  2
# sol_update_l2_norm:0.00048074930277528405 	 residual l2 norm: 6.239859991461614e-09
# newton iteration:  3
# sol_update_l2_norm:2.9528482973433453e-06 	 residual l2 norm: 1.577014378248071e-12
# converged at iteration:  3
# sol_update_l2_norm:2.9528482973433453e-06 	 residual l2 norm: 1.577014378248071e-12
# epoch:  12	======TIME=======f and N(u) terms time : 0.0025594234466552734
# ======TIME=======stiffness matrix terms time : 0.04506325721740723
# ======TIME=======neumann bd terms time : 0.0017168521881103516
# =======> argmax subproblem time:  0.049486637115478516
# assembling the matrix time taken:  0.47027039527893066
# solving Ax = b time taken:  0.05621147155761719
# total size: 524 1000000 = 524000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:26.788957318077713 	 residual l2 norm: 4.53408207154151e-05
# newton iteration:  2
# sol_update_l2_norm:0.001709098158686788 	 residual l2 norm: 9.744863025943478e-09
# newton iteration:  3
# sol_update_l2_norm:4.329682349801823e-06 	 residual l2 norm: 1.9851879253974114e-12
# converged at iteration:  3
# sol_update_l2_norm:4.329682349801823e-06 	 residual l2 norm: 1.9851879253974114e-12
# epoch:  13	======TIME=======f and N(u) terms time : 0.0025315284729003906
# ======TIME=======stiffness matrix terms time : 0.0416712760925293
# ======TIME=======neumann bd terms time : 0.0017094612121582031
# =======> argmax subproblem time:  0.0460658073425293
# assembling the matrix time taken:  0.6322224140167236
# solving Ax = b time taken:  0.05865073204040527
# total size: 525 1000000 = 525000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:20.683474611436807 	 residual l2 norm: 9.572974412468603e-06
# newton iteration:  2
# sol_update_l2_norm:0.0007593175621086454 	 residual l2 norm: 5.8599854981659325e-09
# newton iteration:  3
# sol_update_l2_norm:4.029063631108224e-06 	 residual l2 norm: 5.822463130503922e-12
# converged at iteration:  3
# sol_update_l2_norm:4.029063631108224e-06 	 residual l2 norm: 5.822463130503922e-12
# epoch:  14	======TIME=======f and N(u) terms time : 0.0025594234466552734
# ======TIME=======stiffness matrix terms time : 0.04512524604797363
# ======TIME=======neumann bd terms time : 0.001718759536743164
# =======> argmax subproblem time:  0.04956364631652832
# assembling the matrix time taken:  0.3563075065612793
# solving Ax = b time taken:  0.07080340385437012
# total size: 526 1000000 = 526000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:46.94162457427357 	 residual l2 norm: 3.6338512217934195e-05
# newton iteration:  2
# sol_update_l2_norm:0.005588711050050346 	 residual l2 norm: 4.0507705379031014e-08
# newton iteration:  3
# sol_update_l2_norm:1.0558095643548815e-06 	 residual l2 norm: 1.316861066611958e-12
# converged at iteration:  3
# sol_update_l2_norm:1.0558095643548815e-06 	 residual l2 norm: 1.316861066611958e-12
# epoch:  15	======TIME=======f and N(u) terms time : 0.002562284469604492
# ======TIME=======stiffness matrix terms time : 0.041818857192993164
# ======TIME=======neumann bd terms time : 0.0017514228820800781
# =======> argmax subproblem time:  0.04628920555114746
# assembling the matrix time taken:  0.47412562370300293
# solving Ax = b time taken:  0.05876016616821289
# total size: 527 1000000 = 527000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:5.828091280009116 	 residual l2 norm: 6.378411290302259e-06
# newton iteration:  2
# sol_update_l2_norm:0.0001419047554280858 	 residual l2 norm: 1.937575600829976e-09
# newton iteration:  3
# sol_update_l2_norm:1.0744497155064608e-06 	 residual l2 norm: 8.688095537244185e-13
# converged at iteration:  3
# sol_update_l2_norm:1.0744497155064608e-06 	 residual l2 norm: 8.688095537244185e-13
# epoch:  16	======TIME=======f and N(u) terms time : 0.0025606155395507812
# ======TIME=======stiffness matrix terms time : 0.04503607749938965
# ======TIME=======neumann bd terms time : 0.001718282699584961
# =======> argmax subproblem time:  0.04947090148925781
# assembling the matrix time taken:  0.4744117259979248
# solving Ax = b time taken:  0.055997371673583984
# total size: 528 1000000 = 528000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:8.93535756060084 	 residual l2 norm: 2.523714977595952e-05
# newton iteration:  2
# sol_update_l2_norm:0.000292414453693159 	 residual l2 norm: 2.6394318835506905e-09
# newton iteration:  3
# sol_update_l2_norm:9.544094562611997e-07 	 residual l2 norm: 3.36692887146082e-12
# converged at iteration:  3
# sol_update_l2_norm:9.544094562611997e-07 	 residual l2 norm: 3.36692887146082e-12
# epoch:  17	======TIME=======f and N(u) terms time : 0.002549409866333008
# ======TIME=======stiffness matrix terms time : 0.0417025089263916
# ======TIME=======neumann bd terms time : 0.0017306804656982422
# =======> argmax subproblem time:  0.04613375663757324
# assembling the matrix time taken:  0.5884897708892822
# solving Ax = b time taken:  0.05880284309387207
# total size: 529 1000000 = 529000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:12.672069978742554 	 residual l2 norm: 7.962688429390332e-06
# newton iteration:  2
# sol_update_l2_norm:0.0008976696360337298 	 residual l2 norm: 4.206591761186813e-10
# newton iteration:  3
# sol_update_l2_norm:3.0844652808554915e-06 	 residual l2 norm: 1.878125744422919e-12
# converged at iteration:  3
# sol_update_l2_norm:3.0844652808554915e-06 	 residual l2 norm: 1.878125744422919e-12
# epoch:  18	======TIME=======f and N(u) terms time : 0.002568483352661133
# ======TIME=======stiffness matrix terms time : 0.04518604278564453
# ======TIME=======neumann bd terms time : 0.0017521381378173828
# =======> argmax subproblem time:  0.04966378211975098
# assembling the matrix time taken:  0.47681689262390137
# solving Ax = b time taken:  0.06408262252807617
# total size: 530 1000000 = 530000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:23.568403326614707 	 residual l2 norm: 4.141118012822907e-05
# newton iteration:  2
# sol_update_l2_norm:0.0007806749006844799 	 residual l2 norm: 8.073187911560567e-10
# newton iteration:  3
# sol_update_l2_norm:9.173164132658596e-07 	 residual l2 norm: 8.935530093617395e-13
# converged at iteration:  3
# sol_update_l2_norm:9.173164132658596e-07 	 residual l2 norm: 8.935530093617395e-13
# epoch:  19	======TIME=======f and N(u) terms time : 0.002557992935180664
# ======TIME=======stiffness matrix terms time : 0.04192638397216797
# ======TIME=======neumann bd terms time : 0.0017197132110595703
# =======> argmax subproblem time:  0.046349525451660156
# assembling the matrix time taken:  0.34448981285095215
# solving Ax = b time taken:  0.061203718185424805
# total size: 531 1000000 = 531000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:21.18975744318736 	 residual l2 norm: 2.0882298426929857e-05
# newton iteration:  2
# sol_update_l2_norm:0.000775235516872975 	 residual l2 norm: 1.3976582423663804e-10
# newton iteration:  3
# sol_update_l2_norm:4.051512997522889e-06 	 residual l2 norm: 1.4031819115116963e-12
# converged at iteration:  3
# sol_update_l2_norm:4.051512997522889e-06 	 residual l2 norm: 1.4031819115116963e-12
# epoch:  20	======TIME=======f and N(u) terms time : 0.0025768280029296875
# ======TIME=======stiffness matrix terms time : 0.04513287544250488
# ======TIME=======neumann bd terms time : 0.0017278194427490234
# =======> argmax subproblem time:  0.049585580825805664
# assembling the matrix time taken:  0.6955902576446533
# solving Ax = b time taken:  0.05664420127868652
# total size: 532 1000000 = 532000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:22.05414785539475 	 residual l2 norm: 2.8072884047777493e-05
# newton iteration:  2
# sol_update_l2_norm:0.000346774249261171 	 residual l2 norm: 1.937106012106286e-09
# newton iteration:  3
# sol_update_l2_norm:3.052784091092186e-06 	 residual l2 norm: 8.673681103681993e-13
# converged at iteration:  3
# sol_update_l2_norm:3.052784091092186e-06 	 residual l2 norm: 8.673681103681993e-13
# epoch:  21	======TIME=======f and N(u) terms time : 0.0025887489318847656
# ======TIME=======stiffness matrix terms time : 0.04202985763549805
# ======TIME=======neumann bd terms time : 0.001735687255859375
# =======> argmax subproblem time:  0.046500444412231445
# assembling the matrix time taken:  0.5880794525146484
# solving Ax = b time taken:  0.059009552001953125
# total size: 533 1000000 = 533000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:17.15572824391222 	 residual l2 norm: 2.3045965703925213e-05
# newton iteration:  2
# sol_update_l2_norm:0.004711549403891258 	 residual l2 norm: 4.447022320379019e-09
# newton iteration:  3
# sol_update_l2_norm:2.6690684127462968e-06 	 residual l2 norm: 1.9167934458411273e-12
# converged at iteration:  3
# sol_update_l2_norm:2.6690684127462968e-06 	 residual l2 norm: 1.9167934458411273e-12
# epoch:  22	======TIME=======f and N(u) terms time : 0.0025835037231445312
# ======TIME=======stiffness matrix terms time : 0.04529929161071777
# ======TIME=======neumann bd terms time : 0.001737356185913086
# =======> argmax subproblem time:  0.04976940155029297
# assembling the matrix time taken:  0.3714172840118408
# solving Ax = b time taken:  0.07105445861816406
# total size: 534 1000000 = 534000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:22.915770926396515 	 residual l2 norm: 2.4642747581666103e-05
# newton iteration:  2
# sol_update_l2_norm:0.0026164123815765484 	 residual l2 norm: 8.128488886314982e-10
# newton iteration:  3
# sol_update_l2_norm:4.020460658944696e-07 	 residual l2 norm: 1.377387525483035e-12
# converged at iteration:  3
# sol_update_l2_norm:4.020460658944696e-07 	 residual l2 norm: 1.377387525483035e-12
# epoch:  23	======TIME=======f and N(u) terms time : 0.0025916099548339844
# ======TIME=======stiffness matrix terms time : 0.042104482650756836
# ======TIME=======neumann bd terms time : 0.0017545223236083984
# =======> argmax subproblem time:  0.046614646911621094
# assembling the matrix time taken:  0.26276373863220215
# solving Ax = b time taken:  0.061354637145996094
# total size: 535 1000000 = 535000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:17.095521526716755 	 residual l2 norm: 5.49203186950026e-06
# newton iteration:  2
# sol_update_l2_norm:0.0005397652406257543 	 residual l2 norm: 3.3898274252995605e-10
# newton iteration:  3
# sol_update_l2_norm:4.022798211581984e-06 	 residual l2 norm: 2.6164428566674495e-12
# converged at iteration:  3
# sol_update_l2_norm:4.022798211581984e-06 	 residual l2 norm: 2.6164428566674495e-12
# epoch:  24	======TIME=======f and N(u) terms time : 0.0025730133056640625
# ======TIME=======stiffness matrix terms time : 0.04540514945983887
# ======TIME=======neumann bd terms time : 0.0017113685607910156
# =======> argmax subproblem time:  0.0498347282409668
# assembling the matrix time taken:  0.5910804271697998
# solving Ax = b time taken:  0.0565338134765625
# total size: 536 1000000 = 536000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:51.05878712912393 	 residual l2 norm: 9.942239332140554e-06
# newton iteration:  2
# sol_update_l2_norm:0.0005584944355037274 	 residual l2 norm: 4.441529204164122e-08
# newton iteration:  3
# sol_update_l2_norm:5.528854638956109e-06 	 residual l2 norm: 1.22891759829857e-12
# converged at iteration:  3
# sol_update_l2_norm:5.528854638956109e-06 	 residual l2 norm: 1.22891759829857e-12
# epoch:  25	======TIME=======f and N(u) terms time : 0.0025866031646728516
# ======TIME=======stiffness matrix terms time : 0.04201173782348633
# ======TIME=======neumann bd terms time : 0.0017123222351074219
# =======> argmax subproblem time:  0.04645419120788574
# assembling the matrix time taken:  0.36308979988098145
# solving Ax = b time taken:  0.05914115905761719
# total size: 537 1000000 = 537000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:12.401962460648198 	 residual l2 norm: 5.269268480451941e-05
# newton iteration:  2
# sol_update_l2_norm:0.0008644756924808669 	 residual l2 norm: 4.499094205088369e-09
# newton iteration:  3
# sol_update_l2_norm:3.5556120301227238e-06 	 residual l2 norm: 3.953487498494343e-12
# converged at iteration:  3
# sol_update_l2_norm:3.5556120301227238e-06 	 residual l2 norm: 3.953487498494343e-12
# epoch:  26	======TIME=======f and N(u) terms time : 0.0025603771209716797
# ======TIME=======stiffness matrix terms time : 0.047266483306884766
# ======TIME=======neumann bd terms time : 0.001745462417602539
# =======> argmax subproblem time:  0.05173230171203613
# assembling the matrix time taken:  0.6577329635620117
# solving Ax = b time taken:  0.0671229362487793
# total size: 538 1000000 = 538000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:37.774730728617975 	 residual l2 norm: 1.5474570901154857e-05
# newton iteration:  2
# sol_update_l2_norm:0.0007425399157910685 	 residual l2 norm: 4.560919570941122e-09
# newton iteration:  3
# sol_update_l2_norm:3.7158569473293634e-07 	 residual l2 norm: 2.5209769618015424e-12
# converged at iteration:  3
# sol_update_l2_norm:3.7158569473293634e-07 	 residual l2 norm: 2.5209769618015424e-12
# epoch:  27	======TIME=======f and N(u) terms time : 0.0025517940521240234
# ======TIME=======stiffness matrix terms time : 0.04399514198303223
# ======TIME=======neumann bd terms time : 0.0017387866973876953
# =======> argmax subproblem time:  0.04844188690185547
# assembling the matrix time taken:  0.12650775909423828
# solving Ax = b time taken:  0.05944490432739258
# total size: 539 1000000 = 539000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:29.6124964562847 	 residual l2 norm: 4.698325891214233e-05
# newton iteration:  2
# sol_update_l2_norm:0.0011296574252617785 	 residual l2 norm: 3.199782820452673e-09
# newton iteration:  3
# sol_update_l2_norm:6.634173498389849e-06 	 residual l2 norm: 2.2987333044117675e-12
# converged at iteration:  3
# sol_update_l2_norm:6.634173498389849e-06 	 residual l2 norm: 2.2987333044117675e-12
# epoch:  28	======TIME=======f and N(u) terms time : 0.0025513172149658203
# ======TIME=======stiffness matrix terms time : 0.04607677459716797
# ======TIME=======neumann bd terms time : 0.0016984939575195312
# =======> argmax subproblem time:  0.05047249794006348
# assembling the matrix time taken:  0.2931208610534668
# solving Ax = b time taken:  0.0574183464050293
# total size: 540 1000000 = 540000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:13.913112319202243 	 residual l2 norm: 3.2400363941453195e-05
# newton iteration:  2
# sol_update_l2_norm:0.0002747806862850855 	 residual l2 norm: 2.4479822093388595e-09
# newton iteration:  3
# sol_update_l2_norm:1.1266275442125154e-06 	 residual l2 norm: 4.2478499915457056e-12
# converged at iteration:  3
# sol_update_l2_norm:1.1266275442125154e-06 	 residual l2 norm: 4.2478499915457056e-12
# epoch:  29	======TIME=======f and N(u) terms time : 0.002560138702392578
# ======TIME=======stiffness matrix terms time : 0.043940067291259766
# ======TIME=======neumann bd terms time : 0.0017323493957519531
# =======> argmax subproblem time:  0.04838967323303223
# assembling the matrix time taken:  0.2999086380004883
# solving Ax = b time taken:  0.05948281288146973
# total size: 541 1000000 = 541000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:12.689590572459402 	 residual l2 norm: 5.2941802619297366e-05
# newton iteration:  2
# sol_update_l2_norm:0.0008746032481657509 	 residual l2 norm: 2.7603005779329573e-10
# newton iteration:  3
# sol_update_l2_norm:6.9635908962257975e-06 	 residual l2 norm: 2.8298885669308953e-12
# converged at iteration:  3
# sol_update_l2_norm:6.9635908962257975e-06 	 residual l2 norm: 2.8298885669308953e-12
# epoch:  30	======TIME=======f and N(u) terms time : 0.0025827884674072266
# ======TIME=======stiffness matrix terms time : 0.04743313789367676
# ======TIME=======neumann bd terms time : 0.0017325878143310547
# =======> argmax subproblem time:  0.05190610885620117
# assembling the matrix time taken:  0.24167299270629883
# solving Ax = b time taken:  0.059207916259765625
# total size: 542 1000000 = 542000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:15.776830179650148 	 residual l2 norm: 1.911759034722617e-05
# newton iteration:  2
# sol_update_l2_norm:2.629260556143032e-05 	 residual l2 norm: 2.1628232601920546e-09
# newton iteration:  3
# sol_update_l2_norm:3.1576353942053317e-06 	 residual l2 norm: 4.3447282935548256e-12
# converged at iteration:  3
# sol_update_l2_norm:3.1576353942053317e-06 	 residual l2 norm: 4.3447282935548256e-12
# epoch:  31	======TIME=======f and N(u) terms time : 0.0025615692138671875
# ======TIME=======stiffness matrix terms time : 0.044011831283569336
# ======TIME=======neumann bd terms time : 0.0017247200012207031
# =======> argmax subproblem time:  0.0484461784362793
# assembling the matrix time taken:  0.2980670928955078
# solving Ax = b time taken:  0.05954289436340332
# total size: 543 1000000 = 543000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:23.44728876028796 	 residual l2 norm: 5.2279829001388544e-05
# newton iteration:  2
# sol_update_l2_norm:0.0018042951811587764 	 residual l2 norm: 1.5738437385183695e-09
# newton iteration:  3
# sol_update_l2_norm:4.098204036145432e-06 	 residual l2 norm: 2.1455172712302415e-12
# converged at iteration:  3
# sol_update_l2_norm:4.098204036145432e-06 	 residual l2 norm: 2.1455172712302415e-12
# epoch:  32	======TIME=======f and N(u) terms time : 0.0025436878204345703
# ======TIME=======stiffness matrix terms time : 0.04749155044555664
# ======TIME=======neumann bd terms time : 0.0017197132110595703
# =======> argmax subproblem time:  0.051904916763305664
# assembling the matrix time taken:  0.127701997756958
# solving Ax = b time taken:  0.0591890811920166
# total size: 544 1000000 = 544000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:27.941803789786395 	 residual l2 norm: 7.775808342508173e-05
# newton iteration:  2
# sol_update_l2_norm:0.0006417282796115167 	 residual l2 norm: 7.252198207168101e-09
# newton iteration:  3
# sol_update_l2_norm:4.406659676512631e-06 	 residual l2 norm: 8.077922359267765e-13
# converged at iteration:  3
# sol_update_l2_norm:4.406659676512631e-06 	 residual l2 norm: 8.077922359267765e-13
# epoch:  33	======TIME=======f and N(u) terms time : 0.0025827884674072266
# ======TIME=======stiffness matrix terms time : 0.04408979415893555
# ======TIME=======neumann bd terms time : 0.0017304420471191406
# =======> argmax subproblem time:  0.04855680465698242
# assembling the matrix time taken:  0.2961537837982178
# solving Ax = b time taken:  0.05979132652282715
# total size: 545 1000000 = 545000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:7.93615031891341 	 residual l2 norm: 3.182360021088958e-05
# newton iteration:  2
# sol_update_l2_norm:0.001123676400227399 	 residual l2 norm: 3.8816606739461525e-10
# newton iteration:  3
# sol_update_l2_norm:1.9402761287722574e-06 	 residual l2 norm: 1.2592278426657317e-12
# converged at iteration:  3
# sol_update_l2_norm:1.9402761287722574e-06 	 residual l2 norm: 1.2592278426657317e-12
# epoch:  34	======TIME=======f and N(u) terms time : 0.0025725364685058594
# ======TIME=======stiffness matrix terms time : 0.047508955001831055
# ======TIME=======neumann bd terms time : 0.0017354488372802734
# =======> argmax subproblem time:  0.05197429656982422
# assembling the matrix time taken:  0.29587364196777344
# solving Ax = b time taken:  0.05969977378845215
# total size: 546 1000000 = 546000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:9.090372328979681 	 residual l2 norm: 2.7065667713186763e-05
# newton iteration:  2
# sol_update_l2_norm:0.00016560455615785663 	 residual l2 norm: 5.349177508405295e-10
# newton iteration:  3
# sol_update_l2_norm:3.1490091866397376e-06 	 residual l2 norm: 9.094474597118342e-13
# converged at iteration:  3
# sol_update_l2_norm:3.1490091866397376e-06 	 residual l2 norm: 9.094474597118342e-13
# epoch:  35	======TIME=======f and N(u) terms time : 0.0025784969329833984
# ======TIME=======stiffness matrix terms time : 0.04423189163208008
# ======TIME=======neumann bd terms time : 0.0017292499542236328
# =======> argmax subproblem time:  0.048693180084228516
# assembling the matrix time taken:  0.30428600311279297
# solving Ax = b time taken:  0.05956888198852539
# total size: 547 1000000 = 547000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:32.77727861684891 	 residual l2 norm: 6.2471734470532335e-06
# newton iteration:  2
# sol_update_l2_norm:0.005493925216994956 	 residual l2 norm: 3.436692833828921e-09
# newton iteration:  3
# sol_update_l2_norm:1.1409414043264431e-06 	 residual l2 norm: 1.6586552639725235e-12
# converged at iteration:  3
# sol_update_l2_norm:1.1409414043264431e-06 	 residual l2 norm: 1.6586552639725235e-12
# epoch:  36	======TIME=======f and N(u) terms time : 0.0025644302368164062
# ======TIME=======stiffness matrix terms time : 0.04762697219848633
# ======TIME=======neumann bd terms time : 0.0017278194427490234
# =======> argmax subproblem time:  0.05207252502441406
# assembling the matrix time taken:  0.298443078994751
# solving Ax = b time taken:  0.05963921546936035
# total size: 548 1000000 = 548000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:25.891021675601518 	 residual l2 norm: 8.272522624238055e-06
# newton iteration:  2
# sol_update_l2_norm:8.160633179302044e-05 	 residual l2 norm: 4.841874037160303e-09
# newton iteration:  3
# sol_update_l2_norm:4.117248964106728e-06 	 residual l2 norm: 9.044832206054261e-13
# converged at iteration:  3
# sol_update_l2_norm:4.117248964106728e-06 	 residual l2 norm: 9.044832206054261e-13
# epoch:  37	======TIME=======f and N(u) terms time : 0.0025682449340820312
# ======TIME=======stiffness matrix terms time : 0.04416203498840332
# ======TIME=======neumann bd terms time : 0.0017194747924804688
# =======> argmax subproblem time:  0.048605918884277344
# assembling the matrix time taken:  0.298295259475708
# solving Ax = b time taken:  0.059953927993774414
# total size: 549 1000000 = 549000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:6.5707068617406685 	 residual l2 norm: 2.219034085112264e-05
# newton iteration:  2
# sol_update_l2_norm:0.00035335231642180724 	 residual l2 norm: 1.300096663350025e-09
# newton iteration:  3
# sol_update_l2_norm:4.789454014463885e-06 	 residual l2 norm: 1.0627639860452113e-12
# converged at iteration:  3
# sol_update_l2_norm:4.789454014463885e-06 	 residual l2 norm: 1.0627639860452113e-12
# epoch:  38	======TIME=======f and N(u) terms time : 0.0025768280029296875
# ======TIME=======stiffness matrix terms time : 0.04764676094055176
# ======TIME=======neumann bd terms time : 0.0017347335815429688
# =======> argmax subproblem time:  0.052121639251708984
# assembling the matrix time taken:  0.298328161239624
# solving Ax = b time taken:  0.059888362884521484
# total size: 550 1000000 = 550000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:31.86349623665393 	 residual l2 norm: 7.179062305593899e-06
# newton iteration:  2
# sol_update_l2_norm:0.003400070965707535 	 residual l2 norm: 3.0126000302668973e-09
# newton iteration:  3
# sol_update_l2_norm:6.433345426265077e-06 	 residual l2 norm: 1.6156427331377951e-12
# converged at iteration:  3
# sol_update_l2_norm:6.433345426265077e-06 	 residual l2 norm: 1.6156427331377951e-12
# epoch:  39	======TIME=======f and N(u) terms time : 0.0025708675384521484
# ======TIME=======stiffness matrix terms time : 0.04429149627685547
# ======TIME=======neumann bd terms time : 0.0017268657684326172
# =======> argmax subproblem time:  0.048743486404418945
# assembling the matrix time taken:  0.13558530807495117
# solving Ax = b time taken:  0.06005549430847168
# total size: 551 1000000 = 551000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:23.329885086858642 	 residual l2 norm: 1.969345861162541e-05
# newton iteration:  2
# sol_update_l2_norm:0.0008545305216764732 	 residual l2 norm: 2.1371699331565844e-09
# newton iteration:  3
# sol_update_l2_norm:6.106726349774324e-06 	 residual l2 norm: 9.7020787097099e-13
# converged at iteration:  3
# sol_update_l2_norm:6.106726349774324e-06 	 residual l2 norm: 9.7020787097099e-13
# epoch:  40	======TIME=======f and N(u) terms time : 0.0025589466094970703
# ======TIME=======stiffness matrix terms time : 0.04765653610229492
# ======TIME=======neumann bd terms time : 0.0017616748809814453
# =======> argmax subproblem time:  0.05212831497192383
# assembling the matrix time taken:  0.32666897773742676
# solving Ax = b time taken:  0.05980730056762695
# total size: 552 1000000 = 552000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:27.696833166884666 	 residual l2 norm: 1.408238620460425e-05
# newton iteration:  2
# sol_update_l2_norm:0.0047601589714445225 	 residual l2 norm: 7.017920156290236e-09
# newton iteration:  3
# sol_update_l2_norm:6.9483859715251455e-06 	 residual l2 norm: 1.2027170261538544e-12
# converged at iteration:  3
# sol_update_l2_norm:6.9483859715251455e-06 	 residual l2 norm: 1.2027170261538544e-12
# epoch:  41	======TIME=======f and N(u) terms time : 0.0025670528411865234
# ======TIME=======stiffness matrix terms time : 0.04425477981567383
# ======TIME=======neumann bd terms time : 0.0017185211181640625
# =======> argmax subproblem time:  0.04869484901428223
# assembling the matrix time taken:  0.30037522315979004
# solving Ax = b time taken:  0.06003451347351074
# total size: 553 1000000 = 553000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:13.621701057810489 	 residual l2 norm: 8.977887679378141e-06
# newton iteration:  2
# sol_update_l2_norm:0.0007672521224570966 	 residual l2 norm: 8.995222950893676e-10
# newton iteration:  3
# sol_update_l2_norm:5.451464662951044e-06 	 residual l2 norm: 1.2147168267421757e-12
# converged at iteration:  3
# sol_update_l2_norm:5.451464662951044e-06 	 residual l2 norm: 1.2147168267421757e-12
# epoch:  42	======TIME=======f and N(u) terms time : 0.002580404281616211
# ======TIME=======stiffness matrix terms time : 0.04771876335144043
# ======TIME=======neumann bd terms time : 0.0017192363739013672
# =======> argmax subproblem time:  0.05218243598937988
# assembling the matrix time taken:  0.29982590675354004
# solving Ax = b time taken:  0.060028076171875
# total size: 554 1000000 = 554000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:10.876840307813046 	 residual l2 norm: 8.866475574324089e-06
# newton iteration:  2
# sol_update_l2_norm:0.0008553688524717295 	 residual l2 norm: 2.4825587962140184e-10
# newton iteration:  3
# sol_update_l2_norm:9.6122163499453e-06 	 residual l2 norm: 4.1355374617569516e-13
# converged at iteration:  3
# sol_update_l2_norm:9.6122163499453e-06 	 residual l2 norm: 4.1355374617569516e-13
# epoch:  43	======TIME=======f and N(u) terms time : 0.002588987350463867
# ======TIME=======stiffness matrix terms time : 0.04436612129211426
# ======TIME=======neumann bd terms time : 0.0017268657684326172
# =======> argmax subproblem time:  0.04883694648742676
# assembling the matrix time taken:  0.30254173278808594
# solving Ax = b time taken:  0.06018495559692383
# total size: 555 1000000 = 555000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:9.398916121206996 	 residual l2 norm: 1.5790799077419596e-05
# newton iteration:  2
# sol_update_l2_norm:0.0002061296213658757 	 residual l2 norm: 7.461801244626683e-10
# newton iteration:  3
# sol_update_l2_norm:2.2260752062290786e-06 	 residual l2 norm: 1.1058589559135385e-12
# converged at iteration:  3
# sol_update_l2_norm:2.2260752062290786e-06 	 residual l2 norm: 1.1058589559135385e-12
# epoch:  44	======TIME=======f and N(u) terms time : 0.0025658607482910156
# ======TIME=======stiffness matrix terms time : 0.04774808883666992
# ======TIME=======neumann bd terms time : 0.0017321109771728516
# =======> argmax subproblem time:  0.0522000789642334
# assembling the matrix time taken:  0.3020761013031006
# solving Ax = b time taken:  0.059989213943481445
# total size: 556 1000000 = 556000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:10.216049700038893 	 residual l2 norm: 1.8465192264514358e-05
# newton iteration:  2
# sol_update_l2_norm:0.0002818166475981421 	 residual l2 norm: 6.916170030233197e-10
# newton iteration:  3
# sol_update_l2_norm:4.234512238067871e-06 	 residual l2 norm: 8.416826580326538e-13
# converged at iteration:  3
# sol_update_l2_norm:4.234512238067871e-06 	 residual l2 norm: 8.416826580326538e-13
# epoch:  45	======TIME=======f and N(u) terms time : 0.002557039260864258
# ======TIME=======stiffness matrix terms time : 0.044373512268066406
# ======TIME=======neumann bd terms time : 0.0017275810241699219
# =======> argmax subproblem time:  0.0488128662109375
# assembling the matrix time taken:  0.3022646903991699
# solving Ax = b time taken:  0.060361385345458984
# total size: 557 1000000 = 557000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:18.752627621915877 	 residual l2 norm: 2.736663024237977e-05
# newton iteration:  2
# sol_update_l2_norm:0.0007625682199869536 	 residual l2 norm: 8.676459452020633e-10
# newton iteration:  3
# sol_update_l2_norm:4.4351407748791135e-06 	 residual l2 norm: 2.550345040484704e-12
# converged at iteration:  3
# sol_update_l2_norm:4.4351407748791135e-06 	 residual l2 norm: 2.550345040484704e-12
# epoch:  46	======TIME=======f and N(u) terms time : 0.002570629119873047
# ======TIME=======stiffness matrix terms time : 0.04790043830871582
# ======TIME=======neumann bd terms time : 0.0017402172088623047
# =======> argmax subproblem time:  0.05237293243408203
# assembling the matrix time taken:  0.30249476432800293
# solving Ax = b time taken:  0.06022810935974121
# total size: 558 1000000 = 558000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:9.567809272505983 	 residual l2 norm: 2.700048853852323e-05
# newton iteration:  2
# sol_update_l2_norm:6.771739689648732e-05 	 residual l2 norm: 1.9769911647578266e-10
# newton iteration:  3
# sol_update_l2_norm:6.115335337757645e-06 	 residual l2 norm: 1.625425002331963e-12
# converged at iteration:  3
# sol_update_l2_norm:6.115335337757645e-06 	 residual l2 norm: 1.625425002331963e-12
# epoch:  47	======TIME=======f and N(u) terms time : 0.002553701400756836
# ======TIME=======stiffness matrix terms time : 0.04450678825378418
# ======TIME=======neumann bd terms time : 0.0017354488372802734
# =======> argmax subproblem time:  0.048959970474243164
# assembling the matrix time taken:  0.13087248802185059
# solving Ax = b time taken:  0.060384511947631836
# total size: 559 1000000 = 559000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:21.447377581042183 	 residual l2 norm: 3.065443643838441e-05
# newton iteration:  2
# sol_update_l2_norm:0.0013982393529481773 	 residual l2 norm: 4.560309207851228e-10
# newton iteration:  3
# sol_update_l2_norm:8.385817139210119e-07 	 residual l2 norm: 1.5203605175156366e-12
# converged at iteration:  3
# sol_update_l2_norm:8.385817139210119e-07 	 residual l2 norm: 1.5203605175156366e-12
# epoch:  48	======TIME=======f and N(u) terms time : 0.002557039260864258
# ======TIME=======stiffness matrix terms time : 0.047788143157958984
# ======TIME=======neumann bd terms time : 0.0017333030700683594
# =======> argmax subproblem time:  0.05224013328552246
# assembling the matrix time taken:  0.3035709857940674
# solving Ax = b time taken:  0.06017947196960449
# total size: 560 1000000 = 560000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:21.699253442718494 	 residual l2 norm: 1.596332684873712e-05
# newton iteration:  2
# sol_update_l2_norm:0.0010431345137319392 	 residual l2 norm: 1.2110161178754105e-08
# newton iteration:  3
# sol_update_l2_norm:6.708451054537328e-06 	 residual l2 norm: 1.277297345608835e-12
# converged at iteration:  3
# sol_update_l2_norm:6.708451054537328e-06 	 residual l2 norm: 1.277297345608835e-12
# epoch:  49	======TIME=======f and N(u) terms time : 0.0025482177734375
# ======TIME=======stiffness matrix terms time : 0.044464111328125
# ======TIME=======neumann bd terms time : 0.0017268657684326172
# =======> argmax subproblem time:  0.04889392852783203
# assembling the matrix time taken:  0.3044006824493408
# solving Ax = b time taken:  0.06026911735534668
# total size: 561 1000000 = 561000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:6.70500463357767 	 residual l2 norm: 5.409560145224957e-06
# newton iteration:  2
# sol_update_l2_norm:3.7142976524888294e-05 	 residual l2 norm: 6.764804521021851e-10
# newton iteration:  3
# sol_update_l2_norm:8.500470587329543e-07 	 residual l2 norm: 1.8458174903673744e-12
# converged at iteration:  3
# sol_update_l2_norm:8.500470587329543e-07 	 residual l2 norm: 1.8458174903673744e-12
# epoch:  50	======TIME=======f and N(u) terms time : 0.002553701400756836
# ======TIME=======stiffness matrix terms time : 0.047971487045288086
# ======TIME=======neumann bd terms time : 0.001753091812133789
# =======> argmax subproblem time:  0.0524444580078125
# assembling the matrix time taken:  0.26401424407958984
# solving Ax = b time taken:  0.06049489974975586
# total size: 562 1000000 = 562000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:4.147751358883401 	 residual l2 norm: 2.3007251796243932e-05
# newton iteration:  2
# sol_update_l2_norm:0.00022173884158732419 	 residual l2 norm: 1.236435419672606e-09
# newton iteration:  3
# sol_update_l2_norm:5.693991217774883e-06 	 residual l2 norm: 1.7003170844594443e-12
# converged at iteration:  3
# sol_update_l2_norm:5.693991217774883e-06 	 residual l2 norm: 1.7003170844594443e-12
# epoch:  51	======TIME=======f and N(u) terms time : 0.0025169849395751953
# ======TIME=======stiffness matrix terms time : 0.04467010498046875
# ======TIME=======neumann bd terms time : 0.0017421245574951172
# =======> argmax subproblem time:  0.049094438552856445
# assembling the matrix time taken:  0.3052055835723877
# solving Ax = b time taken:  0.06070351600646973
# total size: 563 1000000 = 563000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:3.09530875252779 	 residual l2 norm: 4.1546429629587225e-06
# newton iteration:  2
# sol_update_l2_norm:0.00011574691982091009 	 residual l2 norm: 2.3808735684597774e-11
# newton iteration:  3
# sol_update_l2_norm:9.019585859494308e-06 	 residual l2 norm: 1.6614399452773979e-12
# converged at iteration:  3
# sol_update_l2_norm:9.019585859494308e-06 	 residual l2 norm: 1.6614399452773979e-12
# epoch:  52	======TIME=======f and N(u) terms time : 0.0025815963745117188
# ======TIME=======stiffness matrix terms time : 0.04790639877319336
# ======TIME=======neumann bd terms time : 0.0017292499542236328
# =======> argmax subproblem time:  0.05237555503845215
# assembling the matrix time taken:  0.2503077983856201
# solving Ax = b time taken:  0.06042766571044922
# total size: 564 1000000 = 564000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:30.31235583027458 	 residual l2 norm: 1.451569570409895e-05
# newton iteration:  2
# sol_update_l2_norm:8.329573263978717e-05 	 residual l2 norm: 2.3703153353621593e-09
# newton iteration:  3
# sol_update_l2_norm:6.689440539476302e-07 	 residual l2 norm: 8.562464493973973e-13
# converged at iteration:  3
# sol_update_l2_norm:6.689440539476302e-07 	 residual l2 norm: 8.562464493973973e-13
# epoch:  53	======TIME=======f and N(u) terms time : 0.002541065216064453
# ======TIME=======stiffness matrix terms time : 0.04456472396850586
# ======TIME=======neumann bd terms time : 0.0017223358154296875
# =======> argmax subproblem time:  0.04899430274963379
# assembling the matrix time taken:  0.13159799575805664
# solving Ax = b time taken:  0.06076836585998535
# total size: 565 1000000 = 565000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:97.24510305276603 	 residual l2 norm: 2.31424708487603e-05
# newton iteration:  2
# sol_update_l2_norm:0.009045550905620354 	 residual l2 norm: 3.590495120990546e-08
# newton iteration:  3
# sol_update_l2_norm:1.8095808843945015e-06 	 residual l2 norm: 2.9221026763967136e-12
# converged at iteration:  3
# sol_update_l2_norm:1.8095808843945015e-06 	 residual l2 norm: 2.9221026763967136e-12
# epoch:  54	======TIME=======f and N(u) terms time : 0.0025658607482910156
# ======TIME=======stiffness matrix terms time : 0.04807615280151367
# ======TIME=======neumann bd terms time : 0.0017287731170654297
# =======> argmax subproblem time:  0.05253171920776367
# assembling the matrix time taken:  0.3069729804992676
# solving Ax = b time taken:  0.06063365936279297
# total size: 566 1000000 = 566000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:6.450681557723703 	 residual l2 norm: 5.187589136108268e-06
# newton iteration:  2
# sol_update_l2_norm:0.0007516920015525484 	 residual l2 norm: 7.073946855994467e-11
# newton iteration:  3
# sol_update_l2_norm:4.564022229107555e-07 	 residual l2 norm: 2.2855909722235363e-12
# converged at iteration:  3
# sol_update_l2_norm:4.564022229107555e-07 	 residual l2 norm: 2.2855909722235363e-12
# epoch:  55	======TIME=======f and N(u) terms time : 0.00251007080078125
# ======TIME=======stiffness matrix terms time : 0.04462599754333496
# ======TIME=======neumann bd terms time : 0.001730203628540039
# =======> argmax subproblem time:  0.04901933670043945
# assembling the matrix time taken:  0.3087775707244873
# solving Ax = b time taken:  0.06085062026977539
# total size: 567 1000000 = 567000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:3.3151690537002305 	 residual l2 norm: 7.033267431144118e-06
# newton iteration:  2
# sol_update_l2_norm:0.00014465248658770058 	 residual l2 norm: 2.28106328206881e-10
# newton iteration:  3
# sol_update_l2_norm:2.3691363567592592e-06 	 residual l2 norm: 1.7668234272028612e-12
# converged at iteration:  3
# sol_update_l2_norm:2.3691363567592592e-06 	 residual l2 norm: 1.7668234272028612e-12
# epoch:  56	======TIME=======f and N(u) terms time : 0.0025784969329833984
# ======TIME=======stiffness matrix terms time : 0.04802513122558594
# ======TIME=======neumann bd terms time : 0.0017499923706054688
# =======> argmax subproblem time:  0.05251049995422363
# assembling the matrix time taken:  0.25044727325439453
# solving Ax = b time taken:  0.06061100959777832
# total size: 568 1000000 = 568000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:14.52726806260561 	 residual l2 norm: 1.7269676713877687e-05
# newton iteration:  2
# sol_update_l2_norm:0.0019711115947251075 	 residual l2 norm: 2.1776221256668263e-09
# newton iteration:  3
# sol_update_l2_norm:9.90606455474105e-06 	 residual l2 norm: 1.5946470078426078e-12
# converged at iteration:  3
# sol_update_l2_norm:9.90606455474105e-06 	 residual l2 norm: 1.5946470078426078e-12
# epoch:  57	======TIME=======f and N(u) terms time : 0.002552509307861328
# ======TIME=======stiffness matrix terms time : 0.04469418525695801
# ======TIME=======neumann bd terms time : 0.0017299652099609375
# =======> argmax subproblem time:  0.049134254455566406
# assembling the matrix time taken:  0.3138291835784912
# solving Ax = b time taken:  0.06151866912841797
# total size: 569 1000000 = 569000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:24.876667590310326 	 residual l2 norm: 1.4630227114785048e-05
# newton iteration:  2
# sol_update_l2_norm:0.004983414069545592 	 residual l2 norm: 1.9611716982815137e-08
# newton iteration:  3
# sol_update_l2_norm:2.570488140576496e-06 	 residual l2 norm: 3.432469359391603e-12
# converged at iteration:  3
# sol_update_l2_norm:2.570488140576496e-06 	 residual l2 norm: 3.432469359391603e-12
# epoch:  58	======TIME=======f and N(u) terms time : 0.002565145492553711
# ======TIME=======stiffness matrix terms time : 0.048139095306396484
# ======TIME=======neumann bd terms time : 0.0017359256744384766
# =======> argmax subproblem time:  0.05260944366455078
# ...
# =======> argmax subproblem time:  0.06650114059448242
# assembling the matrix time taken:  0.8433573246002197
# solving Ax = b time taken:  0.15732192993164062
# total size: 1018 1000000 = 1018000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:4.819801338010679 	 residual l2 norm: 1.593635437190789e-05
# newton iteration:  2
# sol_update_l2_norm:0.003306436431042165 	 residual l2 norm: 1.0986939625529962e-11
# newton iteration:  3
# sol_update_l2_norm:4.9153262693446526e-05 	 residual l2 norm: 1.2643545068782565e-12
# converged at iteration:  3
# sol_update_l2_norm:4.9153262693446526e-05 	 residual l2 norm: 1.2643545068782565e-12
# epoch:  507	======TIME=======f and N(u) terms time : 0.0025300979614257812
# ======TIME=======stiffness matrix terms time : 0.06428003311157227
# ======TIME=======neumann bd terms time : 0.0018982887268066406
# =======> argmax subproblem time:  0.06890010833740234
# assembling the matrix time taken:  0.9493510723114014
# solving Ax = b time taken:  0.1564946174621582
# total size: 1019 1000000 = 1019000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:13.618002391226328 	 residual l2 norm: 3.055333060810228e-05
# newton iteration:  2
# sol_update_l2_norm:0.022521031548571383 	 residual l2 norm: 8.814481146556221e-12
# converged at iteration:  2
# sol_update_l2_norm:0.022521031548571383 	 residual l2 norm: 8.814481146556221e-12
# epoch:  508	======TIME=======f and N(u) terms time : 0.0025243759155273438
# ======TIME=======stiffness matrix terms time : 0.06213879585266113
# ======TIME=======neumann bd terms time : 0.0018763542175292969
# =======> argmax subproblem time:  0.06672024726867676
# assembling the matrix time taken:  0.8456559181213379
# solving Ax = b time taken:  0.15705060958862305
# total size: 1020 1000000 = 1020000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:7.558577415800791 	 residual l2 norm: 1.8864125444081427e-05
# newton iteration:  2
# sol_update_l2_norm:0.00043401478370073634 	 residual l2 norm: 4.861765419995127e-11
# newton iteration:  3
# sol_update_l2_norm:4.525952676427028e-06 	 residual l2 norm: 1.0212869651407525e-12
# converged at iteration:  3
# sol_update_l2_norm:4.525952676427028e-06 	 residual l2 norm: 1.0212869651407525e-12
# epoch:  509	======TIME=======f and N(u) terms time : 0.002537250518798828
# ======TIME=======stiffness matrix terms time : 0.06423139572143555
# ======TIME=======neumann bd terms time : 0.001888275146484375
# =======> argmax subproblem time:  0.06884264945983887
# assembling the matrix time taken:  0.8458051681518555
# solving Ax = b time taken:  0.15740156173706055
# total size: 1021 1000000 = 1021000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:4.10814650216479 	 residual l2 norm: 3.5843776267399924e-05
# newton iteration:  2
# sol_update_l2_norm:0.0002747511956875403 	 residual l2 norm: 6.127750505781257e-11
# newton iteration:  3
# sol_update_l2_norm:2.7191489163203454e-05 	 residual l2 norm: 9.610484872797809e-13
# converged at iteration:  3
# sol_update_l2_norm:2.7191489163203454e-05 	 residual l2 norm: 9.610484872797809e-13
# epoch:  510	======TIME=======f and N(u) terms time : 0.0025358200073242188
# ======TIME=======stiffness matrix terms time : 0.06205868721008301
# ======TIME=======neumann bd terms time : 0.0018608570098876953
# =======> argmax subproblem time:  0.06663060188293457
# assembling the matrix time taken:  0.848132848739624
# solving Ax = b time taken:  0.15658140182495117
# total size: 1022 1000000 = 1022000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:4.448815311916088 	 residual l2 norm: 2.041101341289069e-05
# newton iteration:  2
# sol_update_l2_norm:0.0028410512384542366 	 residual l2 norm: 2.234260829891003e-10
# newton iteration:  3
# sol_update_l2_norm:1.3100587694104663e-05 	 residual l2 norm: 8.816545755859713e-13
# converged at iteration:  3
# sol_update_l2_norm:1.3100587694104663e-05 	 residual l2 norm: 8.816545755859713e-13
# epoch:  511	======TIME=======f and N(u) terms time : 0.00255584716796875
# ======TIME=======stiffness matrix terms time : 0.06447052955627441
# ======TIME=======neumann bd terms time : 0.0019185543060302734
# =======> argmax subproblem time:  0.06915664672851562
# assembling the matrix time taken:  0.8502187728881836
# solving Ax = b time taken:  0.1568903923034668
# total size: 1023 1000000 = 1023000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:8.975613784276685 	 residual l2 norm: 2.224184142926332e-05
# newton iteration:  2
# sol_update_l2_norm:0.004082455494850788 	 residual l2 norm: 1.5828313182153852e-10
# newton iteration:  3
# sol_update_l2_norm:2.94336559887709e-05 	 residual l2 norm: 4.900611966266498e-13
# converged at iteration:  3
# sol_update_l2_norm:2.94336559887709e-05 	 residual l2 norm: 4.900611966266498e-13
# epoch:  512	======TIME=======f and N(u) terms time : 0.0025043487548828125
# ======TIME=======stiffness matrix terms time : 0.06217169761657715
# ======TIME=======neumann bd terms time : 0.0018630027770996094
# =======> argmax subproblem time:  0.06671595573425293
# assembling the matrix time taken:  0.847888708114624
# solving Ax = b time taken:  0.15687179565429688
# total size: 1024 1000000 = 1024000000
# num batches:  2
# newton iteration:  1
# sol_update_l2_norm:2.7191297192570345 	 residual l2 norm: 1.4423390266525204e-05
# newton iteration:  2
# sol_update_l2_norm:0.0017198269340950776 	 residual l2 norm: 2.3852266288360913e-11
# newton iteration:  3
# sol_update_l2_norm:3.146183099287388e-05 	 residual l2 norm: 5.222705502131e-13
# converged at iteration:  3
# sol_update_l2_norm:3.146183099287388e-05 	 residual l2 norm: 5.222705502131e-13
# time taken:  1769.2595319747925
# tensor([0.0019, 0.0019, 0.0019, 0.0019, 0.0019, 0.0019, 0.0019, 0.0018, 0.0018,
#         0.0018, 0.0018, 0.0018, 0.0018, 0.0018, 0.0018, 0.0018, 0.0018, 0.0018,
#         0.0018, 0.0018, 0.0018, 0.0017, 0.0017, 0.0017, 0.0017, 0.0017, 0.0017,
#         0.0017, 0.0017, 0.0017, 0.0017, 0.0017, 0.0017, 0.0016, 0.0016, 0.0016,
#         0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016,
#         0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0015, 0.0015,
#         0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015,
#         0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015, 0.0015,
#         0.0015, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014,
#         0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014,
#         0.0014, 0.0014, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013,
#         0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013,
#         0.0013, 0.0013, 0.0013, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012,
#         0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012,
#         0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012,
#         0.0012, 0.0012, 0.0012, 0.0012, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011,
#         0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011,
#         0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011,
#         0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011,
#         0.0011, 0.0011, 0.0011, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010,
#         0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010,
#         0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010,
#         0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010,
#         0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0009, 0.0009, 0.0009,
#         0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009,
#         0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009,
#         0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009,
#         0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008,
#         0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008,
#         0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008,
#         0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008,
#         0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008,
#         0.0008, 0.0008, 0.0008, 0.0008, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007,
#         0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007,
#         0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007,
#         0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007,
#         0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007,
#         0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007,
#         0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0006,
#         0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#         0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#         0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#         0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#         0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#         0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#         0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#         0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#         0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0005, 0.0005, 0.0005, 0.0005,
#         0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005,
#         0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005,
#         0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005,
#         0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005,
#         0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005,
#         0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005,
#         0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005,
#         0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005,
#         0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005])
# tensor([0.1214, 0.1214, 0.1209, 0.1208, 0.1203, 0.1202, 0.1197, 0.1194, 0.1191,
#         0.1186, 0.1185, 0.1184, 0.1176, 0.1171, 0.1163, 0.1162, 0.1160, 0.1159,
#         0.1154, 0.1150, 0.1147, 0.1143, 0.1140, 0.1138, 0.1127, 0.1124, 0.1119,
#         0.1111, 0.1109, 0.1106, 0.1103, 0.1097, 0.1092, 0.1090, 0.1089, 0.1086,
#         0.1081, 0.1080, 0.1077, 0.1073, 0.1068, 0.1066, 0.1065, 0.1063, 0.1061,
#         0.1058, 0.1057, 0.1055, 0.1049, 0.1047, 0.1046, 0.1045, 0.1040, 0.1021,
#         0.1020, 0.1019, 0.1017, 0.1013, 0.1012, 0.1011, 0.1008, 0.1006, 0.1004,
#         0.0997, 0.0996, 0.0995, 0.0994, 0.0993, 0.0992, 0.0991, 0.0987, 0.0985,
#         0.0984, 0.0982, 0.0980, 0.0975, 0.0971, 0.0970, 0.0970, 0.0967, 0.0964,
#         0.0957, 0.0950, 0.0948, 0.0945, 0.0944, 0.0938, 0.0938, 0.0937, 0.0935,
#         0.0934, 0.0926, 0.0925, 0.0922, 0.0919, 0.0917, 0.0913, 0.0912, 0.0907,
#         0.0906, 0.0901, 0.0897, 0.0892, 0.0890, 0.0886, 0.0885, 0.0883, 0.0879,
#         0.0878, 0.0876, 0.0874, 0.0871, 0.0867, 0.0865, 0.0860, 0.0859, 0.0858,
#         0.0857, 0.0852, 0.0850, 0.0850, 0.0849, 0.0849, 0.0846, 0.0842, 0.0841,
#         0.0838, 0.0836, 0.0835, 0.0833, 0.0832, 0.0829, 0.0829, 0.0828, 0.0825,
#         0.0824, 0.0821, 0.0821, 0.0820, 0.0816, 0.0814, 0.0811, 0.0810, 0.0807,
#         0.0806, 0.0804, 0.0800, 0.0797, 0.0796, 0.0794, 0.0791, 0.0790, 0.0790,
#         0.0787, 0.0785, 0.0785, 0.0783, 0.0782, 0.0781, 0.0781, 0.0781, 0.0780,
#         0.0780, 0.0779, 0.0778, 0.0777, 0.0776, 0.0775, 0.0769, 0.0768, 0.0766,
#         0.0765, 0.0765, 0.0764, 0.0763, 0.0762, 0.0761, 0.0761, 0.0760, 0.0758,
#         0.0757, 0.0756, 0.0756, 0.0755, 0.0755, 0.0753, 0.0748, 0.0747, 0.0747,
#         0.0746, 0.0745, 0.0744, 0.0744, 0.0743, 0.0741, 0.0740, 0.0737, 0.0734,
#         0.0733, 0.0730, 0.0729, 0.0727, 0.0725, 0.0724, 0.0723, 0.0723, 0.0722,
#         0.0721, 0.0719, 0.0713, 0.0711, 0.0710, 0.0709, 0.0706, 0.0704, 0.0701,
#         0.0697, 0.0697, 0.0695, 0.0690, 0.0688, 0.0687, 0.0685, 0.0683, 0.0682,
#         0.0681, 0.0678, 0.0677, 0.0677, 0.0675, 0.0674, 0.0673, 0.0670, 0.0669,
#         0.0668, 0.0665, 0.0664, 0.0662, 0.0657, 0.0656, 0.0654, 0.0653, 0.0650,
#         0.0647, 0.0646, 0.0645, 0.0644, 0.0642, 0.0640, 0.0638, 0.0638, 0.0636,
#         0.0636, 0.0634, 0.0633, 0.0632, 0.0632, 0.0631, 0.0631, 0.0630, 0.0629,
#         0.0628, 0.0628, 0.0626, 0.0624, 0.0624, 0.0621, 0.0620, 0.0618, 0.0615,
#         0.0614, 0.0611, 0.0611, 0.0610, 0.0609, 0.0608, 0.0608, 0.0605, 0.0605,
#         0.0602, 0.0600, 0.0600, 0.0599, 0.0598, 0.0596, 0.0596, 0.0595, 0.0594,
#         0.0593, 0.0591, 0.0590, 0.0590, 0.0588, 0.0588, 0.0586, 0.0585, 0.0584,
#         0.0584, 0.0583, 0.0582, 0.0582, 0.0582, 0.0581, 0.0581, 0.0579, 0.0577,
#         0.0577, 0.0576, 0.0576, 0.0575, 0.0574, 0.0569, 0.0568, 0.0566, 0.0564,
#         0.0563, 0.0562, 0.0562, 0.0561, 0.0561, 0.0561, 0.0560, 0.0558, 0.0558,
#         0.0557, 0.0556, 0.0555, 0.0554, 0.0553, 0.0552, 0.0551, 0.0551, 0.0550,
#         0.0547, 0.0545, 0.0544, 0.0544, 0.0542, 0.0542, 0.0541, 0.0541, 0.0540,
#         0.0540, 0.0537, 0.0535, 0.0532, 0.0531, 0.0530, 0.0528, 0.0528, 0.0524,
#         0.0523, 0.0523, 0.0522, 0.0521, 0.0520, 0.0519, 0.0517, 0.0516, 0.0516,
#         0.0515, 0.0514, 0.0514, 0.0512, 0.0511, 0.0510, 0.0510, 0.0509, 0.0509,
#         0.0508, 0.0508, 0.0507, 0.0507, 0.0505, 0.0503, 0.0503, 0.0502, 0.0501,
#         0.0501, 0.0500, 0.0500, 0.0500, 0.0499, 0.0499, 0.0498, 0.0498, 0.0497,
#         0.0496, 0.0495, 0.0494, 0.0494, 0.0493, 0.0491, 0.0490, 0.0490, 0.0489,
#         0.0486, 0.0486, 0.0484, 0.0483, 0.0483, 0.0482, 0.0482, 0.0482, 0.0481,
#         0.0480, 0.0480, 0.0478, 0.0477, 0.0476, 0.0475, 0.0474, 0.0473, 0.0472,
#         0.0471, 0.0470, 0.0470, 0.0470, 0.0468, 0.0467, 0.0466, 0.0466, 0.0465,
#         0.0464, 0.0464, 0.0464, 0.0463, 0.0463, 0.0461, 0.0460, 0.0459, 0.0459,
#         0.0458, 0.0457, 0.0456, 0.0455, 0.0453, 0.0453, 0.0452, 0.0450, 0.0450,
#         0.0449, 0.0449, 0.0448, 0.0448, 0.0447, 0.0446, 0.0446, 0.0446, 0.0445,
#         0.0445, 0.0444, 0.0443, 0.0443, 0.0442, 0.0440, 0.0439, 0.0439, 0.0438,
#         0.0437, 0.0437, 0.0436, 0.0436, 0.0436, 0.0436, 0.0435, 0.0434, 0.0433,
#         0.0432, 0.0430, 0.0429, 0.0429, 0.0428, 0.0428, 0.0427, 0.0427, 0.0426,
#         0.0426, 0.0426, 0.0424, 0.0424, 0.0423, 0.0423, 0.0423, 0.0421, 0.0420,
#         0.0420, 0.0419, 0.0419, 0.0419, 0.0417, 0.0417, 0.0417, 0.0416, 0.0416,
#         0.0415, 0.0415, 0.0415, 0.0413, 0.0413, 0.0412, 0.0411, 0.0411, 0.0409,
#         0.0409, 0.0408, 0.0408, 0.0407, 0.0407, 0.0406, 0.0406, 0.0405, 0.0405])
# neuron num 		 error 		 order
# 4 		 0.097603 		 * 		 2.228954 		 *
#
# 8 		 0.096918 		 0.010171 		 2.227903 		 0.000680
#
# 16 		 0.092131 		 0.073069 		 2.208027 		 0.012929
#
# 32 		 0.081754 		 0.172400 		 2.079563 		 0.086477
#
# 64 		 0.055663 		 0.554575 		 1.646714 		 0.336691
#
# 128 		 0.025734 		 1.113048 		 1.314845 		 0.324698
#
# 256 		 0.008012 		 1.683515 		 0.647107 		 1.022816
#
# 512 		 0.001891 		 2.082839 		 0.171632 		 1.914683
#
# 1024 		 0.000465 		 2.023039 		 0.040511 		 2.082952
#
# neuron num  & 	 $\|u-u_n \|_{L^2}$ & 	 order $O(n^{-1.67})$ & 	 $ | u -u_n |_{H^1}$ & 	 order $O(n^{-1.33})$ \\ \hline \hline
# 4 		 & 0.097603 &		 * & 		 2.228954 & 		 *  \\ \hline
#
# 8 		 &  9.692e-02 &  		 0.01 &  		 2.228e+00 &  		 0.00 \\ \hline
#
# 16 		 &  9.213e-02 &  		 0.07 &  		 2.208e+00 &  		 0.01 \\ \hline
#
# 32 		 &  8.175e-02 &  		 0.17 &  		 2.080e+00 &  		 0.09 \\ \hline
#
# 64 		 &  5.566e-02 &  		 0.55 &  		 1.647e+00 &  		 0.34 \\ \hline
#
# 128 		 &  2.573e-02 &  		 1.11 &  		 1.315e+00 &  		 0.32 \\ \hline
#
# 256 		 &  8.012e-03 &  		 1.68 &  		 6.471e-01 &  		 1.02 \\ \hline
#
# 512 		 &  1.891e-03 &  		 2.08 &  		 1.716e-01 &  		 1.91 \\ \hline
#
# 1024 		 &  4.653e-04 &  		 2.02 &  		 4.051e-02 &  		 2.08 \\ \hline

# %%
folder = 'data-pb/'
neuron_num_save = load_model_data['neuron_num'] + num_epochs if load_model_data['loadOrNot'] else num_epochs
filename = folder + 'errl2_OGA_3D_{}_relu_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,relu_k,neuron_num_save,N)
torch.save(err_QMC2,filename) 
filename = folder + 'errh10_OGA_3D_{}_relu_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,relu_k,neuron_num_save,N)
torch.save(err_h10,filename) 
filename = folder + 'model_OGA_3D_{}_relu_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,relu_k,neuron_num_save,N)
torch.save(my_model.state_dict(),filename)

# %%
err_l2_512 = torch.load(folder + 'errl2_OGA_3D_{}_relu_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,relu_k,neuron_num_save,N))
err_h10_512 = torch.load(folder + 'errh10_OGA_3D_{}_relu_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,relu_k,neuron_num_save,N))
show_convergence_order_latex(err_QMC2,err_h10,exponent,k =relu_k,d = 3)
# Out:
# neuron num  & 	 $\|u-u_n \|_{L^2}$ & 	 order $O(n^{-1.67})$ & 	 $ | u -u_n |_{H^1}$ & 	 order $O(n^{-1.33})$ \\ \hline \hline
# 4 		 & 0.097603 &		 * & 		 2.228954 & 		 *  \\ \hline
#
# 8 		 &  9.692e-02 &  		 0.01 &  		 2.228e+00 &  		 0.00 \\ \hline
#
# 16 		 &  9.213e-02 &  		 0.07 &  		 2.208e+00 &  		 0.01 \\ \hline
#
# 32 		 &  8.175e-02 &  		 0.17 &  		 2.080e+00 &  		 0.09 \\ \hline
#
# 64 		 &  5.566e-02 &  		 0.55 &  		 1.647e+00 &  		 0.34 \\ \hline
#
# 128 		 &  2.573e-02 &  		 1.11 &  		 1.315e+00 &  		 0.32 \\ \hline
#
# 256 		 &  8.012e-03 &  		 1.68 &  		 6.471e-01 &  		 1.02 \\ \hline
#
# 512 		 &  1.891e-03 &  		 2.08 &  		 1.716e-01 &  		 1.91 \\ \hline

# %% [markdown]
# ## Test cosine function

# %%
freq = 2 
def u_exact(x):
    return torch.cos(freq*pi*x[:,0:1])*torch.cos( freq*pi*x[:,1:2]) * torch.cos(freq*pi*x[:,2:3])  
def alpha(x): 
    return torch.ones(x.size(0),1).to(device)

def u_exact_grad():
    d = 3 
    def grad_1(x):
        return - freq*pi* torch.sin(freq*pi*x[:,0:1])*torch.cos( freq*pi*x[:,1:2]) * torch.cos(freq*pi*x[:,2:3])   
    def grad_2(x):
        return - freq*pi* torch.cos(freq*pi*x[:,0:1])*torch.sin( freq*pi*x[:,1:2]) * torch.cos(freq*pi*x[:,2:3])  
    def grad_3(x):
        return - freq*pi* torch.cos(freq*pi*x[:,0:1])*torch.cos( freq*pi*x[:,1:2]) * torch.sin(freq*pi*x[:,2:3])   
    
    u_grad=[grad_1, grad_2,grad_3] 

    return u_grad
def laplace_u_exact(x):
    return -3*(freq*pi)**2 * torch.cos(freq*pi*x[:,0:1])*torch.cos( freq*pi*x[:,1:2]) * torch.cos(freq*pi*x[:,2:3])
# def target(x):
#     z = -laplace_u_exact(x) + u_exact(x)**3 
#     return z 

def u_exact_approx(x):
    return 0.7 * u_exact(x)

def rhs(x):
    return  -laplace_u_exact(x) + nonlinear(u_exact(x))

g_N = None 


function_name = "cos4pix" 
filename_write = "3DCGA-{}-order.txt".format(function_name)
f_write = open(filename_write, "a")
f_write.write("\n")
f_write.close() 
save = False 
relu_k = 3
for N_list in [[2*3,2**3,2**3]]: # ,[2**6,2**6],[2**7,2**7] 
    # save = True 
    f_write = open(filename_write, "a")
    my_model = None 
    Nx = 50
    order = 3
    exponent = 7
    num_epochs = 2**exponent  
    plot_freq = num_epochs 
    N = np.prod(N_list)
    err_QMC2, err_h10, my_model = CGANonlinearPoissonReLU3D(my_model,rhs,alpha, u_exact, u_exact_grad,g_N, N_list,num_epochs,plot_freq, Nx, order, k = relu_k, rand_deter = 'rand', linear_solver = "direct")
    if save: 
        folder = 'data-neumann/'
        filename = folder + 'err_OGA_2D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        torch.save(err_QMC2,filename) 
        folder = 'data-neumann/'
        filename = folder + 'model_OGA_2D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        torch.save(my_model,filename)

    show_convergence_order(err_QMC2,err_h10,exponent,N,filename_write,False)
    show_convergence_order_latex(err_QMC2,err_h10,exponent,k =relu_k,d = 3)
# Out:
# using linear solver:  direct
# epoch:  1	======TIME=======f and u^3 terms time : 0.00040221214294433594
# ======TIME=======stiffness matrix terms time : 9.5367431640625e-07
# ======TIME=======neumann bd terms time : 2.384185791015625e-07
# =======> argmax subproblem time:  0.000537872314453125
# total size: 1 1000000 = 1000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.22455818462385624 	 residual l2 norm: 0.022839427539190275
# newton iteration:  2
# sol_update_l2_norm:5.874028747627114e-06 	 residual l2 norm: 5.974843031962551e-07
# newton iteration:  3
# sol_update_l2_norm:1.2049027379020042e-14 	 residual l2 norm: 1.2255821357776142e-15
# converged at iteration:  3
# sol_update_l2_norm:1.2049027379020042e-14 	 residual l2 norm: 1.2255821357776142e-15
# epoch:  2	======TIME=======f and u^3 terms time : 0.0011060237884521484
# ======TIME=======stiffness matrix terms time : 0.01655411720275879
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.017806053161621094
# total size: 2 1000000 = 2000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.3126126918518323 	 residual l2 norm: 0.03523913364146597
# newton iteration:  2
# sol_update_l2_norm:4.9761037633837134e-06 	 residual l2 norm: 2.1671035356643933e-05
# newton iteration:  3
# sol_update_l2_norm:2.300104667963837e-14 	 residual l2 norm: 1.7766352505469985e-13
# converged at iteration:  3
# sol_update_l2_norm:2.300104667963837e-14 	 residual l2 norm: 1.7766352505469985e-13
# epoch:  3	======TIME=======f and u^3 terms time : 0.0011067390441894531
# ======TIME=======stiffness matrix terms time : 0.016889095306396484
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.01813220977783203
# assembling the matrix time taken:  0.0001704692840576172
# solving Ax = b time taken:  0.00043392181396484375
# total size: 3 1000000 = 3000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.03283085202724588 	 residual l2 norm: 0.3249058078147389
# newton iteration:  2
# sol_update_l2_norm:4.958304106872741e-07 	 residual l2 norm: 1.2526890727935722e-05
# newton iteration:  3
# sol_update_l2_norm:1.55567931431469e-15 	 residual l2 norm: 2.1537796376180908e-14
# converged at iteration:  3
# sol_update_l2_norm:1.55567931431469e-15 	 residual l2 norm: 2.1537796376180908e-14
# epoch:  4	======TIME=======f and u^3 terms time : 0.0011088848114013672
# ======TIME=======stiffness matrix terms time : 0.016942977905273438
# ======TIME=======neumann bd terms time : 2.384185791015625e-07
# =======> argmax subproblem time:  0.01819586753845215
# assembling the matrix time taken:  0.0002117156982421875
# solving Ax = b time taken:  0.0004267692565917969
# total size: 4 1000000 = 4000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.01697731599927981 	 residual l2 norm: 0.11780418150872975
# newton iteration:  2
# sol_update_l2_norm:1.9452050241894974e-06 	 residual l2 norm: 1.4859715328914981e-05
# newton iteration:  3
# sol_update_l2_norm:1.8546359427104285e-14 	 residual l2 norm: 1.645878828512447e-13
# converged at iteration:  3
# sol_update_l2_norm:1.8546359427104285e-14 	 residual l2 norm: 1.645878828512447e-13
# epoch:  5	======TIME=======f and u^3 terms time : 0.0011107921600341797
# ======TIME=======stiffness matrix terms time : 0.01706838607788086
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.01832723617553711
# assembling the matrix time taken:  0.00017142295837402344
# solving Ax = b time taken:  0.0005171298980712891
# total size: 5 1000000 = 5000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.023487306548772235 	 residual l2 norm: 0.3168667636439398
# newton iteration:  2
# sol_update_l2_norm:6.158507595633069e-07 	 residual l2 norm: 9.637736113279338e-06
# newton iteration:  3
# sol_update_l2_norm:3.037926667752073e-15 	 residual l2 norm: 3.2865595676865894e-14
# converged at iteration:  3
# sol_update_l2_norm:3.037926667752073e-15 	 residual l2 norm: 3.2865595676865894e-14
# epoch:  6	======TIME=======f and u^3 terms time : 0.0011043548583984375
# ======TIME=======stiffness matrix terms time : 0.017062664031982422
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.018326520919799805
# assembling the matrix time taken:  0.00017523765563964844
# solving Ax = b time taken:  0.0005545616149902344
# total size: 6 1000000 = 6000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.14151153880468587 	 residual l2 norm: 0.15586734707439842
# newton iteration:  2
# sol_update_l2_norm:2.56515949751245e-06 	 residual l2 norm: 8.712477702794249e-05
# newton iteration:  3
# sol_update_l2_norm:1.1505596757764267e-13 	 residual l2 norm: 1.5917260822574766e-12
# converged at iteration:  3
# sol_update_l2_norm:1.1505596757764267e-13 	 residual l2 norm: 1.5917260822574766e-12
# epoch:  7	======TIME=======f and u^3 terms time : 0.0011043548583984375
# ======TIME=======stiffness matrix terms time : 0.01718592643737793
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.018444061279296875
# assembling the matrix time taken:  0.00017309188842773438
# solving Ax = b time taken:  0.0005776882171630859
# total size: 7 1000000 = 7000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.08228177147763432 	 residual l2 norm: 0.11317235512232501
# newton iteration:  2
# sol_update_l2_norm:5.665022327097344e-07 	 residual l2 norm: 5.363416668849251e-06
# newton iteration:  3
# sol_update_l2_norm:4.593564104196743e-16 	 residual l2 norm: 5.087111037169998e-15
# converged at iteration:  3
# sol_update_l2_norm:4.593564104196743e-16 	 residual l2 norm: 5.087111037169998e-15
# epoch:  8	======TIME=======f and u^3 terms time : 0.0011048316955566406
# ======TIME=======stiffness matrix terms time : 0.01702284812927246
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.01826333999633789
# assembling the matrix time taken:  0.0001633167266845703
# solving Ax = b time taken:  0.0006551742553710938
# total size: 8 1000000 = 8000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.03257422169361061 	 residual l2 norm: 0.10849609006439459
# newton iteration:  2
# sol_update_l2_norm:3.520528178893402e-07 	 residual l2 norm: 7.28494207123004e-06
# newton iteration:  3
# sol_update_l2_norm:1.2608976780617098e-15 	 residual l2 norm: 8.036108603725668e-15
# converged at iteration:  3
# sol_update_l2_norm:1.2608976780617098e-15 	 residual l2 norm: 8.036108603725668e-15
# epoch:  9	======TIME=======f and u^3 terms time : 0.0011088848114013672
# ======TIME=======stiffness matrix terms time : 0.01716756820678711
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.01842665672302246
# assembling the matrix time taken:  0.00017380714416503906
# solving Ax = b time taken:  0.0007147789001464844
# total size: 9 1000000 = 9000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.03906601645294473 	 residual l2 norm: 0.07188756493917442
# newton iteration:  2
# sol_update_l2_norm:1.2520101535040905e-07 	 residual l2 norm: 4.6711820525389696e-06
# newton iteration:  3
# sol_update_l2_norm:2.376590844433064e-15 	 residual l2 norm: 2.400956200619675e-15
# converged at iteration:  3
# sol_update_l2_norm:2.376590844433064e-15 	 residual l2 norm: 2.400956200619675e-15
# epoch:  10	======TIME=======f and u^3 terms time : 0.0011675357818603516
# ======TIME=======stiffness matrix terms time : 0.017226219177246094
# ======TIME=======neumann bd terms time : 9.5367431640625e-07
# =======> argmax subproblem time:  0.018708229064941406
# assembling the matrix time taken:  0.00017642974853515625
# solving Ax = b time taken:  0.0007486343383789062
# total size: 10 1000000 = 10000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:2.59284906381562 	 residual l2 norm: 0.04354564093171406
# newton iteration:  2
# sol_update_l2_norm:0.0002215370691417574 	 residual l2 norm: 0.0009586551155681981
# newton iteration:  3
# sol_update_l2_norm:2.1920894469180348e-10 	 residual l2 norm: 1.3152851824438048e-09
# newton iteration:  4
# sol_update_l2_norm:5.451781601316184e-15 	 residual l2 norm: 2.5775278016003238e-15
# converged at iteration:  4
# sol_update_l2_norm:5.451781601316184e-15 	 residual l2 norm: 2.5775278016003238e-15
# epoch:  11	======TIME=======f and u^3 terms time : 0.0011038780212402344
# ======TIME=======stiffness matrix terms time : 0.017102718353271484
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.018350601196289062
# assembling the matrix time taken:  0.00016927719116210938
# solving Ax = b time taken:  0.0008065700531005859
# total size: 11 1000000 = 11000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:1.1506040648352203 	 residual l2 norm: 0.3834231126213789
# newton iteration:  2
# sol_update_l2_norm:3.309394373151348e-05 	 residual l2 norm: 0.0006865011218170626
# newton iteration:  3
# sol_update_l2_norm:5.606191346042096e-11 	 residual l2 norm: 2.7649771104675013e-10
# newton iteration:  4
# sol_update_l2_norm:1.9311167608906874e-14 	 residual l2 norm: 1.0529796514390734e-14
# converged at iteration:  4
# sol_update_l2_norm:1.9311167608906874e-14 	 residual l2 norm: 1.0529796514390734e-14
# epoch:  12	======TIME=======f and u^3 terms time : 0.001107931137084961
# ======TIME=======stiffness matrix terms time : 0.01717209815979004
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.0184323787689209
# assembling the matrix time taken:  0.00018143653869628906
# solving Ax = b time taken:  0.0008037090301513672
# total size: 12 1000000 = 12000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.29456007169800663 	 residual l2 norm: 0.11534735216379899
# newton iteration:  2
# sol_update_l2_norm:1.0135690649990655e-05 	 residual l2 norm: 5.305637885335858e-05
# newton iteration:  3
# sol_update_l2_norm:2.334639919494561e-13 	 residual l2 norm: 9.319451047539626e-13
# converged at iteration:  3
# sol_update_l2_norm:2.334639919494561e-13 	 residual l2 norm: 9.319451047539626e-13
# epoch:  13	======TIME=======f and u^3 terms time : 0.001119375228881836
# ======TIME=======stiffness matrix terms time : 0.01729297637939453
# ======TIME=======neumann bd terms time : 9.5367431640625e-07
# =======> argmax subproblem time:  0.01856851577758789
# assembling the matrix time taken:  0.00017070770263671875
# solving Ax = b time taken:  0.0008883476257324219
# total size: 13 1000000 = 13000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:1.0315567433989434 	 residual l2 norm: 0.06757552637224393
# newton iteration:  2
# sol_update_l2_norm:2.012557669955244e-05 	 residual l2 norm: 3.0455188558135095e-05
# newton iteration:  3
# sol_update_l2_norm:2.0583564579846088e-13 	 residual l2 norm: 6.337185011802743e-13
# converged at iteration:  3
# sol_update_l2_norm:2.0583564579846088e-13 	 residual l2 norm: 6.337185011802743e-13
# epoch:  14	======TIME=======f and u^3 terms time : 0.0011107921600341797
# ======TIME=======stiffness matrix terms time : 0.01712775230407715
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.018381834030151367
# assembling the matrix time taken:  0.0001690387725830078
# solving Ax = b time taken:  0.0009429454803466797
# total size: 14 1000000 = 14000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:1.5374145484083406 	 residual l2 norm: 0.042497916588585066
# newton iteration:  2
# sol_update_l2_norm:3.1213154103752736e-05 	 residual l2 norm: 4.216987663744543e-05
# newton iteration:  3
# sol_update_l2_norm:3.747720015478835e-13 	 residual l2 norm: 1.4568901049425913e-12
# converged at iteration:  3
# sol_update_l2_norm:3.747720015478835e-13 	 residual l2 norm: 1.4568901049425913e-12
# epoch:  15	======TIME=======f and u^3 terms time : 0.0011475086212158203
# ======TIME=======stiffness matrix terms time : 0.017253637313842773
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.01855015754699707
# assembling the matrix time taken:  0.000179290771484375
# solving Ax = b time taken:  0.0009968280792236328
# total size: 15 1000000 = 15000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.9963013306958786 	 residual l2 norm: 0.057628219914070175
# newton iteration:  2
# sol_update_l2_norm:1.7269699281097047e-05 	 residual l2 norm: 3.480906685543887e-05
# newton iteration:  3
# sol_update_l2_norm:1.0177618783642401e-13 	 residual l2 norm: 3.5434159389567027e-13
# converged at iteration:  3
# sol_update_l2_norm:1.0177618783642401e-13 	 residual l2 norm: 3.5434159389567027e-13
# epoch:  16	======TIME=======f and u^3 terms time : 0.0011107921600341797
# ======TIME=======stiffness matrix terms time : 0.017343521118164062
# ======TIME=======neumann bd terms time : 1.1920928955078125e-06
# =======> argmax subproblem time:  0.018619298934936523
# assembling the matrix time taken:  0.00017380714416503906
# solving Ax = b time taken:  0.0010275840759277344
# total size: 16 1000000 = 16000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:1.1869282823546428 	 residual l2 norm: 0.0425618250538743
# newton iteration:  2
# sol_update_l2_norm:1.92918929018901e-05 	 residual l2 norm: 1.870807821060137e-05
# newton iteration:  3
# sol_update_l2_norm:3.645589931317422e-14 	 residual l2 norm: 8.784756149603309e-14
# converged at iteration:  3
# sol_update_l2_norm:3.645589931317422e-14 	 residual l2 norm: 8.784756149603309e-14
# epoch:  17	======TIME=======f and u^3 terms time : 0.0011365413665771484
# ======TIME=======stiffness matrix terms time : 0.017201662063598633
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.01862335205078125
# assembling the matrix time taken:  0.00017714500427246094
# solving Ax = b time taken:  0.0011153221130371094
# total size: 17 1000000 = 17000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:1.4837321199179716 	 residual l2 norm: 0.03326351207449635
# newton iteration:  2
# sol_update_l2_norm:3.4476095359390184e-05 	 residual l2 norm: 2.8829227155026774e-05
# newton iteration:  3
# sol_update_l2_norm:1.0249410205297529e-13 	 residual l2 norm: 3.251491160773339e-13
# converged at iteration:  3
# sol_update_l2_norm:1.0249410205297529e-13 	 residual l2 norm: 3.251491160773339e-13
# epoch:  18	======TIME=======f and u^3 terms time : 0.0011243820190429688
# ======TIME=======stiffness matrix terms time : 0.017407655715942383
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.018694400787353516
# assembling the matrix time taken:  0.000171661376953125
# solving Ax = b time taken:  0.001169443130493164
# total size: 18 1000000 = 18000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:44.5721918566062 	 residual l2 norm: 0.03606856167059472
# newton iteration:  2
# sol_update_l2_norm:0.003691585908047616 	 residual l2 norm: 0.0012539180952092673
# newton iteration:  3
# sol_update_l2_norm:4.764420257765271e-10 	 residual l2 norm: 9.378093259557812e-10
# converged at iteration:  3
# sol_update_l2_norm:4.764420257765271e-10 	 residual l2 norm: 9.378093259557812e-10
# epoch:  19	======TIME=======f and u^3 terms time : 0.0011258125305175781
# ======TIME=======stiffness matrix terms time : 0.017235755920410156
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.018497943878173828
# assembling the matrix time taken:  0.00018215179443359375
# solving Ax = b time taken:  0.0011980533599853516
# total size: 19 1000000 = 19000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:16.081425195961536 	 residual l2 norm: 0.15075441555901484
# newton iteration:  2
# sol_update_l2_norm:0.0014110128065722605 	 residual l2 norm: 0.0005018912298702132
# newton iteration:  3
# sol_update_l2_norm:3.3811275872844155e-10 	 residual l2 norm: 4.432996432510262e-10
# converged at iteration:  3
# sol_update_l2_norm:3.3811275872844155e-10 	 residual l2 norm: 4.432996432510262e-10
# epoch:  20	======TIME=======f and u^3 terms time : 0.001119852066040039
# ======TIME=======stiffness matrix terms time : 0.017367839813232422
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.018642425537109375
# assembling the matrix time taken:  0.00016927719116210938
# solving Ax = b time taken:  0.0012645721435546875
# total size: 20 1000000 = 20000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:16.466323571760725 	 residual l2 norm: 0.1456863403281408
# newton iteration:  2
# sol_update_l2_norm:0.0024740520811466055 	 residual l2 norm: 0.0009018824656661345
# newton iteration:  3
# sol_update_l2_norm:3.8882645957631487e-10 	 residual l2 norm: 3.976973157102083e-10
# converged at iteration:  3
# sol_update_l2_norm:3.8882645957631487e-10 	 residual l2 norm: 3.976973157102083e-10
# epoch:  21	======TIME=======f and u^3 terms time : 0.0011162757873535156
# ======TIME=======stiffness matrix terms time : 0.017518043518066406
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.01879262924194336
# assembling the matrix time taken:  0.00018095970153808594
# solving Ax = b time taken:  0.0013017654418945312
# total size: 21 1000000 = 21000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:21.469002117488085 	 residual l2 norm: 0.1399015275917418
# newton iteration:  2
# sol_update_l2_norm:0.0022558161668318217 	 residual l2 norm: 0.0006098465306824805
# newton iteration:  3
# sol_update_l2_norm:3.401390377036313e-11 	 residual l2 norm: 5.6590906101049593e-11
# converged at iteration:  3
# sol_update_l2_norm:3.401390377036313e-11 	 residual l2 norm: 5.6590906101049593e-11
# epoch:  22	======TIME=======f and u^3 terms time : 0.0012099742889404297
# ======TIME=======stiffness matrix terms time : 0.01757526397705078
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.018944740295410156
# assembling the matrix time taken:  0.0001735687255859375
# solving Ax = b time taken:  0.0013599395751953125
# total size: 22 1000000 = 22000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:4.30957433251461 	 residual l2 norm: 0.01722801594252449
# newton iteration:  2
# sol_update_l2_norm:0.00022237126682813038 	 residual l2 norm: 6.39326953010149e-05
# newton iteration:  3
# sol_update_l2_norm:8.407345482550571e-13 	 residual l2 norm: 2.9479996817107977e-12
# converged at iteration:  3
# sol_update_l2_norm:8.407345482550571e-13 	 residual l2 norm: 2.9479996817107977e-12
# epoch:  23	======TIME=======f and u^3 terms time : 0.0011577606201171875
# ======TIME=======stiffness matrix terms time : 0.01742243766784668
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.018718481063842773
# assembling the matrix time taken:  0.00016641616821289062
# solving Ax = b time taken:  0.0014088153839111328
# total size: 23 1000000 = 23000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:1.2622169341693181 	 residual l2 norm: 0.014578077803039395
# newton iteration:  2
# sol_update_l2_norm:5.86630372878789e-05 	 residual l2 norm: 2.2558632331597758e-05
# newton iteration:  3
# sol_update_l2_norm:1.49915314330398e-12 	 residual l2 norm: 6.650597192962242e-13
# converged at iteration:  3
# sol_update_l2_norm:1.49915314330398e-12 	 residual l2 norm: 6.650597192962242e-13
# epoch:  24	======TIME=======f and u^3 terms time : 0.0011239051818847656
# ======TIME=======stiffness matrix terms time : 0.01761341094970703
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.018893003463745117
# assembling the matrix time taken:  0.00016880035400390625
# solving Ax = b time taken:  0.0014629364013671875
# total size: 24 1000000 = 24000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:5.377628506381402 	 residual l2 norm: 0.03813389241198335
# newton iteration:  2
# sol_update_l2_norm:0.00048816580289643986 	 residual l2 norm: 0.00011420707051184815
# newton iteration:  3
# sol_update_l2_norm:2.498008896425604e-12 	 residual l2 norm: 5.1308697775378965e-12
# converged at iteration:  3
# sol_update_l2_norm:2.498008896425604e-12 	 residual l2 norm: 5.1308697775378965e-12
# epoch:  25	======TIME=======f and u^3 terms time : 0.0011112689971923828
# ======TIME=======stiffness matrix terms time : 0.017488718032836914
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.01873612403869629
# assembling the matrix time taken:  0.00016307830810546875
# solving Ax = b time taken:  0.00152587890625
# total size: 25 1000000 = 25000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:35.792613712787826 	 residual l2 norm: 0.02002325312929446
# newton iteration:  2
# sol_update_l2_norm:0.0023150034738949766 	 residual l2 norm: 0.0009494625535374098
# newton iteration:  3
# sol_update_l2_norm:2.2883755060859798e-10 	 residual l2 norm: 7.986695944191307e-10
# converged at iteration:  3
# sol_update_l2_norm:2.2883755060859798e-10 	 residual l2 norm: 7.986695944191307e-10
# epoch:  26	======TIME=======f and u^3 terms time : 0.0011267662048339844
# ======TIME=======stiffness matrix terms time : 0.01766681671142578
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.018944978713989258
# assembling the matrix time taken:  0.00016689300537109375
# solving Ax = b time taken:  0.0015797615051269531
# total size: 26 1000000 = 26000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:73.42694668168824 	 residual l2 norm: 0.0207047003106543
# newton iteration:  2
# sol_update_l2_norm:0.0037482041469253323 	 residual l2 norm: 0.0008602443143357878
# newton iteration:  3
# sol_update_l2_norm:2.955797254469979e-10 	 residual l2 norm: 6.550432336221382e-10
# converged at iteration:  3
# sol_update_l2_norm:2.955797254469979e-10 	 residual l2 norm: 6.550432336221382e-10
# epoch:  27	======TIME=======f and u^3 terms time : 0.0012111663818359375
# ======TIME=======stiffness matrix terms time : 0.017521381378173828
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.01888298988342285
# assembling the matrix time taken:  0.00017547607421875
# solving Ax = b time taken:  0.0016357898712158203
# total size: 27 1000000 = 27000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:8.4858100067225 	 residual l2 norm: 0.02849896332646717
# newton iteration:  2
# sol_update_l2_norm:0.0012539342036130498 	 residual l2 norm: 0.0013489115592605332
# newton iteration:  3
# sol_update_l2_norm:5.11723476307324e-10 	 residual l2 norm: 8.429928630105828e-10
# converged at iteration:  3
# sol_update_l2_norm:5.11723476307324e-10 	 residual l2 norm: 8.429928630105828e-10
# epoch:  28	======TIME=======f and u^3 terms time : 0.00112152099609375
# ======TIME=======stiffness matrix terms time : 0.017663955688476562
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.018940448760986328
# assembling the matrix time taken:  0.00016927719116210938
# solving Ax = b time taken:  0.0016698837280273438
# total size: 28 1000000 = 28000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:17.717961263781998 	 residual l2 norm: 0.028997346926492643
# newton iteration:  2
# sol_update_l2_norm:0.002351431573851853 	 residual l2 norm: 0.0007210737345578616
# newton iteration:  3
# sol_update_l2_norm:5.269682003558858e-10 	 residual l2 norm: 6.164082690206588e-10
# converged at iteration:  3
# sol_update_l2_norm:5.269682003558858e-10 	 residual l2 norm: 6.164082690206588e-10
# epoch:  29	======TIME=======f and u^3 terms time : 0.0011172294616699219
# ======TIME=======stiffness matrix terms time : 0.017563343048095703
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.018819808959960938
# assembling the matrix time taken:  0.00017690658569335938
# solving Ax = b time taken:  0.001699209213256836
# total size: 29 1000000 = 29000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:62.051925440559444 	 residual l2 norm: 0.021909254454492638
# newton iteration:  2
# sol_update_l2_norm:0.003436318247663865 	 residual l2 norm: 0.0011463719255214923
# newton iteration:  3
# sol_update_l2_norm:9.475338151554041e-10 	 residual l2 norm: 1.1723187935953932e-09
# converged at iteration:  3
# sol_update_l2_norm:9.475338151554041e-10 	 residual l2 norm: 1.1723187935953932e-09
# epoch:  30	======TIME=======f and u^3 terms time : 0.0012197494506835938
# ======TIME=======stiffness matrix terms time : 0.01758742332458496
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.01896071434020996
# assembling the matrix time taken:  0.00017404556274414062
# solving Ax = b time taken:  0.0017702579498291016
# total size: 30 1000000 = 30000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:63.8887536080933 	 residual l2 norm: 0.02137125781631405
# newton iteration:  2
# sol_update_l2_norm:0.005878935297360359 	 residual l2 norm: 0.002906808482263438
# newton iteration:  3
# sol_update_l2_norm:7.094700060694022e-09 	 residual l2 norm: 6.885714081598038e-09
# newton iteration:  4
# sol_update_l2_norm:1.0468616802423512e-12 	 residual l2 norm: 1.842747157365393e-12
# converged at iteration:  4
# sol_update_l2_norm:1.0468616802423512e-12 	 residual l2 norm: 1.842747157365393e-12
# epoch:  31	======TIME=======f and u^3 terms time : 0.0012056827545166016
# ======TIME=======stiffness matrix terms time : 0.017814159393310547
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.01935100555419922
# assembling the matrix time taken:  0.00017380714416503906
# solving Ax = b time taken:  0.0018188953399658203
# total size: 31 1000000 = 31000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:20.026198667080898 	 residual l2 norm: 0.023986201465906225
# newton iteration:  2
# sol_update_l2_norm:0.002690523424336921 	 residual l2 norm: 0.0005984493293561621
# newton iteration:  3
# sol_update_l2_norm:2.0413840745597447e-10 	 residual l2 norm: 3.817255910532672e-10
# converged at iteration:  3
# sol_update_l2_norm:2.0413840745597447e-10 	 residual l2 norm: 3.817255910532672e-10
# epoch:  32	======TIME=======f and u^3 terms time : 0.0011212825775146484
# ======TIME=======stiffness matrix terms time : 0.017807960510253906
# ======TIME=======neumann bd terms time : 9.5367431640625e-07
# =======> argmax subproblem time:  0.019083023071289062
# assembling the matrix time taken:  0.0001690387725830078
# solving Ax = b time taken:  0.001857757568359375
# total size: 32 1000000 = 32000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:25.63694001910547 	 residual l2 norm: 0.019754579993270873
# newton iteration:  2
# sol_update_l2_norm:0.005522978800452294 	 residual l2 norm: 0.0005450210036557745
# newton iteration:  3
# sol_update_l2_norm:5.682605322918412e-10 	 residual l2 norm: 4.996066269762029e-10
# converged at iteration:  3
# sol_update_l2_norm:5.682605322918412e-10 	 residual l2 norm: 4.996066269762029e-10
# epoch:  33	======TIME=======f and u^3 terms time : 0.0012269020080566406
# ======TIME=======stiffness matrix terms time : 0.017725467681884766
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.019107341766357422
# assembling the matrix time taken:  0.00017380714416503906
# solving Ax = b time taken:  0.0020668506622314453
# total size: 33 1000000 = 33000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:51.65411700873382 	 residual l2 norm: 0.016204070586340977
# newton iteration:  2
# sol_update_l2_norm:0.004079200247483148 	 residual l2 norm: 0.00021413117546439434
# newton iteration:  3
# sol_update_l2_norm:1.2887401540998542e-10 	 residual l2 norm: 1.6081478463677954e-10
# converged at iteration:  3
# sol_update_l2_norm:1.2887401540998542e-10 	 residual l2 norm: 1.6081478463677954e-10
# epoch:  34	======TIME=======f and u^3 terms time : 0.0011970996856689453
# ======TIME=======stiffness matrix terms time : 0.02094411849975586
# ======TIME=======neumann bd terms time : 9.5367431640625e-07
# =======> argmax subproblem time:  0.022475004196166992
# assembling the matrix time taken:  0.00018334388732910156
# solving Ax = b time taken:  0.0020928382873535156
# total size: 34 1000000 = 34000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:60.2701821396901 	 residual l2 norm: 0.025958526264395633
# newton iteration:  2
# sol_update_l2_norm:0.005648579052254733 	 residual l2 norm: 0.0010747497769728821
# newton iteration:  3
# sol_update_l2_norm:2.632924517151843e-09 	 residual l2 norm: 2.5771335067215187e-09
# newton iteration:  4
# sol_update_l2_norm:2.234773640208201e-12 	 residual l2 norm: 1.2027672229492393e-12
# converged at iteration:  4
# sol_update_l2_norm:2.234773640208201e-12 	 residual l2 norm: 1.2027672229492393e-12
# epoch:  35	======TIME=======f and u^3 terms time : 0.00119781494140625
# ======TIME=======stiffness matrix terms time : 0.020855188369750977
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.022243499755859375
# assembling the matrix time taken:  0.0001811981201171875
# solving Ax = b time taken:  0.0021359920501708984
# total size: 35 1000000 = 35000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:11.269978925815288 	 residual l2 norm: 0.015175185499883274
# newton iteration:  2
# sol_update_l2_norm:0.0014397686431383897 	 residual l2 norm: 0.00010985002922253113
# newton iteration:  3
# sol_update_l2_norm:2.112072666735338e-11 	 residual l2 norm: 1.2576708490964687e-11
# converged at iteration:  3
# sol_update_l2_norm:2.112072666735338e-11 	 residual l2 norm: 1.2576708490964687e-11
# epoch:  36	======TIME=======f and u^3 terms time : 0.0012128353118896484
# ======TIME=======stiffness matrix terms time : 0.020964622497558594
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.022467613220214844
# assembling the matrix time taken:  0.00017452239990234375
# solving Ax = b time taken:  0.002183198928833008
# total size: 36 1000000 = 36000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:10.12919737910399 	 residual l2 norm: 0.015520889428400995
# newton iteration:  2
# sol_update_l2_norm:0.0013032750576723769 	 residual l2 norm: 0.00029536638868320176
# newton iteration:  3
# sol_update_l2_norm:8.940512803615579e-11 	 residual l2 norm: 1.0913986745262902e-10
# converged at iteration:  3
# sol_update_l2_norm:8.940512803615579e-11 	 residual l2 norm: 1.0913986745262902e-10
# epoch:  37	======TIME=======f and u^3 terms time : 0.0011420249938964844
# ======TIME=======stiffness matrix terms time : 0.02084040641784668
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02214336395263672
# assembling the matrix time taken:  0.0001747608184814453
# solving Ax = b time taken:  0.0021979808807373047
# total size: 37 1000000 = 37000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:19.162474957336325 	 residual l2 norm: 0.01696216065888149
# newton iteration:  2
# sol_update_l2_norm:0.0021388476199210647 	 residual l2 norm: 0.0014354504668771576
# newton iteration:  3
# sol_update_l2_norm:1.7642080804170216e-09 	 residual l2 norm: 9.032663417153546e-10
# converged at iteration:  3
# sol_update_l2_norm:1.7642080804170216e-09 	 residual l2 norm: 9.032663417153546e-10
# epoch:  38	======TIME=======f and u^3 terms time : 0.0011293888092041016
# ======TIME=======stiffness matrix terms time : 0.020938396453857422
# ======TIME=======neumann bd terms time : 9.5367431640625e-07
# =======> argmax subproblem time:  0.022221803665161133
# assembling the matrix time taken:  0.0001747608184814453
# solving Ax = b time taken:  0.0022635459899902344
# total size: 38 1000000 = 38000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:18.021783163857915 	 residual l2 norm: 0.013290904361231651
# newton iteration:  2
# sol_update_l2_norm:0.0019041824435687598 	 residual l2 norm: 0.00020383107681570304
# newton iteration:  3
# sol_update_l2_norm:4.893536169195263e-11 	 residual l2 norm: 1.7537099354749745e-11
# converged at iteration:  3
# sol_update_l2_norm:4.893536169195263e-11 	 residual l2 norm: 1.7537099354749745e-11
# epoch:  39	======TIME=======f and u^3 terms time : 0.0011301040649414062
# ======TIME=======stiffness matrix terms time : 0.020949602127075195
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02223968505859375
# assembling the matrix time taken:  0.0001723766326904297
# solving Ax = b time taken:  0.002306699752807617
# total size: 39 1000000 = 39000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:41.14717174034268 	 residual l2 norm: 0.012680038081385299
# newton iteration:  2
# sol_update_l2_norm:0.005257981576183577 	 residual l2 norm: 0.0005996432900423627
# newton iteration:  3
# sol_update_l2_norm:2.3570779570660093e-09 	 residual l2 norm: 1.0366629035825454e-09
# converged at iteration:  3
# sol_update_l2_norm:2.3570779570660093e-09 	 residual l2 norm: 1.0366629035825454e-09
# epoch:  40	======TIME=======f and u^3 terms time : 0.0011391639709472656
# ======TIME=======stiffness matrix terms time : 0.021086931228637695
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.022378921508789062
# assembling the matrix time taken:  0.00018453598022460938
# solving Ax = b time taken:  0.0023164749145507812
# total size: 40 1000000 = 40000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:43.99697812659512 	 residual l2 norm: 0.01767799954899277
# newton iteration:  2
# sol_update_l2_norm:0.004675165850602679 	 residual l2 norm: 0.001132680956012221
# newton iteration:  3
# sol_update_l2_norm:2.347320161513514e-09 	 residual l2 norm: 1.4285923580248833e-09
# converged at iteration:  3
# sol_update_l2_norm:2.347320161513514e-09 	 residual l2 norm: 1.4285923580248833e-09
# epoch:  41	======TIME=======f and u^3 terms time : 0.0011348724365234375
# ======TIME=======stiffness matrix terms time : 0.021088600158691406
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02237558364868164
# assembling the matrix time taken:  0.00017023086547851562
# solving Ax = b time taken:  0.002378225326538086
# total size: 41 1000000 = 41000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:44.245493092111005 	 residual l2 norm: 0.013209282270043799
# newton iteration:  2
# sol_update_l2_norm:0.0034238647309506433 	 residual l2 norm: 0.0002528936882429181
# newton iteration:  3
# sol_update_l2_norm:1.0332011367386784e-10 	 residual l2 norm: 7.353785407989837e-11
# converged at iteration:  3
# sol_update_l2_norm:1.0332011367386784e-10 	 residual l2 norm: 7.353785407989837e-11
# epoch:  42	======TIME=======f and u^3 terms time : 0.001112222671508789
# ======TIME=======stiffness matrix terms time : 0.021060466766357422
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.022329092025756836
# assembling the matrix time taken:  0.00016808509826660156
# solving Ax = b time taken:  0.0024042129516601562
# total size: 42 1000000 = 42000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:48.30338153204043 	 residual l2 norm: 0.014330393735808933
# newton iteration:  2
# sol_update_l2_norm:0.003355491273143261 	 residual l2 norm: 0.00023875489486797354
# newton iteration:  3
# sol_update_l2_norm:1.0066046525182027e-10 	 residual l2 norm: 6.441656692369942e-11
# converged at iteration:  3
# sol_update_l2_norm:1.0066046525182027e-10 	 residual l2 norm: 6.441656692369942e-11
# epoch:  43	======TIME=======f and u^3 terms time : 0.0011134147644042969
# ======TIME=======stiffness matrix terms time : 0.021121740341186523
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02239060401916504
# assembling the matrix time taken:  0.00016880035400390625
# solving Ax = b time taken:  0.002445220947265625
# total size: 43 1000000 = 43000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:60.90758558523185 	 residual l2 norm: 0.0100541935526407
# newton iteration:  2
# sol_update_l2_norm:0.005240421315187705 	 residual l2 norm: 0.0026072949539005844
# newton iteration:  3
# sol_update_l2_norm:5.655070731574752e-09 	 residual l2 norm: 3.0019700775244495e-09
# newton iteration:  4
# sol_update_l2_norm:4.631810146919888e-12 	 residual l2 norm: 8.284928974010859e-13
# converged at iteration:  4
# sol_update_l2_norm:4.631810146919888e-12 	 residual l2 norm: 8.284928974010859e-13
# epoch:  44	======TIME=======f and u^3 terms time : 0.0011191368103027344
# ======TIME=======stiffness matrix terms time : 0.02113819122314453
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.022409677505493164
# assembling the matrix time taken:  0.00017118453979492188
# solving Ax = b time taken:  0.0024764537811279297
# total size: 44 1000000 = 44000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:24.313266875684864 	 residual l2 norm: 0.010804695521924862
# newton iteration:  2
# sol_update_l2_norm:0.001596613598874812 	 residual l2 norm: 4.277684687634604e-05
# newton iteration:  3
# sol_update_l2_norm:1.8076875415444906e-11 	 residual l2 norm: 1.4422585109290618e-11
# converged at iteration:  3
# sol_update_l2_norm:1.8076875415444906e-11 	 residual l2 norm: 1.4422585109290618e-11
# epoch:  45	======TIME=======f and u^3 terms time : 0.0011136531829833984
# ======TIME=======stiffness matrix terms time : 0.02120685577392578
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.022485971450805664
# assembling the matrix time taken:  0.00017142295837402344
# solving Ax = b time taken:  0.002539396286010742
# total size: 45 1000000 = 45000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:35.916474989166794 	 residual l2 norm: 0.009930119163826747
# newton iteration:  2
# sol_update_l2_norm:0.0026482159864965583 	 residual l2 norm: 0.00012791163679431588
# newton iteration:  3
# sol_update_l2_norm:7.453582228739659e-11 	 residual l2 norm: 9.637403569427592e-11
# converged at iteration:  3
# sol_update_l2_norm:7.453582228739659e-11 	 residual l2 norm: 9.637403569427592e-11
# epoch:  46	======TIME=======f and u^3 terms time : 0.001119852066040039
# ======TIME=======stiffness matrix terms time : 0.021165132522583008
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02243971824645996
# assembling the matrix time taken:  0.00016832351684570312
# solving Ax = b time taken:  0.002581357955932617
# total size: 46 1000000 = 46000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:47.99322018521568 	 residual l2 norm: 0.007353823799841184
# newton iteration:  2
# sol_update_l2_norm:0.0021065180391154274 	 residual l2 norm: 0.00017114570322005452
# newton iteration:  3
# sol_update_l2_norm:4.4220341567620855e-11 	 residual l2 norm: 1.6115023039714303e-11
# converged at iteration:  3
# sol_update_l2_norm:4.4220341567620855e-11 	 residual l2 norm: 1.6115023039714303e-11
# epoch:  47	======TIME=======f and u^3 terms time : 0.0011396408081054688
# ======TIME=======stiffness matrix terms time : 0.021159648895263672
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.022448301315307617
# assembling the matrix time taken:  0.0001678466796875
# solving Ax = b time taken:  0.0026319026947021484
# total size: 47 1000000 = 47000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:108.29971374267652 	 residual l2 norm: 0.009990045824088028
# newton iteration:  2
# sol_update_l2_norm:0.004990068607978634 	 residual l2 norm: 0.00037466657460166573
# newton iteration:  3
# sol_update_l2_norm:3.6272438469779495e-10 	 residual l2 norm: 4.089433197626107e-10
# converged at iteration:  3
# sol_update_l2_norm:3.6272438469779495e-10 	 residual l2 norm: 4.089433197626107e-10
# epoch:  48	======TIME=======f and u^3 terms time : 0.0011169910430908203
# ======TIME=======stiffness matrix terms time : 0.021266698837280273
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.0225369930267334
# assembling the matrix time taken:  0.00018024444580078125
# solving Ax = b time taken:  0.0026743412017822266
# total size: 48 1000000 = 48000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:37.77452868773267 	 residual l2 norm: 0.007419140310701316
# newton iteration:  2
# sol_update_l2_norm:0.0017830457775926997 	 residual l2 norm: 0.00033686116467271805
# newton iteration:  3
# sol_update_l2_norm:2.457904547505973e-10 	 residual l2 norm: 2.177754542551934e-10
# converged at iteration:  3
# sol_update_l2_norm:2.457904547505973e-10 	 residual l2 norm: 2.177754542551934e-10
# epoch:  49	======TIME=======f and u^3 terms time : 0.0011148452758789062
# ======TIME=======stiffness matrix terms time : 0.021263599395751953
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02253127098083496
# assembling the matrix time taken:  0.0001697540283203125
# solving Ax = b time taken:  0.00275421142578125
# total size: 49 1000000 = 49000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:49.54117929948138 	 residual l2 norm: 0.007747620282640735
# newton iteration:  2
# sol_update_l2_norm:0.003119574833914276 	 residual l2 norm: 0.0004270819574704752
# newton iteration:  3
# sol_update_l2_norm:2.550132466757833e-10 	 residual l2 norm: 9.020891367058982e-11
# converged at iteration:  3
# sol_update_l2_norm:2.550132466757833e-10 	 residual l2 norm: 9.020891367058982e-11
# epoch:  50	======TIME=======f and u^3 terms time : 0.0011138916015625
# ======TIME=======stiffness matrix terms time : 0.021344661712646484
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.022611379623413086
# assembling the matrix time taken:  0.00016498565673828125
# solving Ax = b time taken:  0.002800464630126953
# total size: 50 1000000 = 50000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:57.689104996524975 	 residual l2 norm: 0.005813372222542507
# newton iteration:  2
# sol_update_l2_norm:0.0021501291296697972 	 residual l2 norm: 0.00021777709549884074
# newton iteration:  3
# sol_update_l2_norm:5.547308974510258e-11 	 residual l2 norm: 7.984693468325425e-11
# converged at iteration:  3
# sol_update_l2_norm:5.547308974510258e-11 	 residual l2 norm: 7.984693468325425e-11
# epoch:  51	======TIME=======f and u^3 terms time : 0.001224517822265625
# ======TIME=======stiffness matrix terms time : 0.021379947662353516
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.022755861282348633
# assembling the matrix time taken:  0.0001666545867919922
# solving Ax = b time taken:  0.002835988998413086
# total size: 51 1000000 = 51000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:37.574235628506294 	 residual l2 norm: 0.009756352984682987
# newton iteration:  2
# sol_update_l2_norm:0.001670994229729918 	 residual l2 norm: 0.0004159291820468439
# newton iteration:  3
# sol_update_l2_norm:1.0817106015940336e-10 	 residual l2 norm: 1.379982535517693e-10
# converged at iteration:  3
# sol_update_l2_norm:1.0817106015940336e-10 	 residual l2 norm: 1.379982535517693e-10
# epoch:  52	======TIME=======f and u^3 terms time : 0.0011315345764160156
# ======TIME=======stiffness matrix terms time : 0.021404743194580078
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02269148826599121
# assembling the matrix time taken:  0.00017499923706054688
# solving Ax = b time taken:  0.0028738975524902344
# total size: 52 1000000 = 52000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:25.26805676270598 	 residual l2 norm: 0.004566141553527656
# newton iteration:  2
# sol_update_l2_norm:0.001542748477525642 	 residual l2 norm: 0.0002223335499867548
# newton iteration:  3
# sol_update_l2_norm:1.3456078579386672e-10 	 residual l2 norm: 2.487722912844747e-11
# converged at iteration:  3
# sol_update_l2_norm:1.3456078579386672e-10 	 residual l2 norm: 2.487722912844747e-11
# epoch:  53	======TIME=======f and u^3 terms time : 0.0011103153228759766
# ======TIME=======stiffness matrix terms time : 0.021342754364013672
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.022602319717407227
# assembling the matrix time taken:  0.00017404556274414062
# solving Ax = b time taken:  0.0029375553131103516
# total size: 53 1000000 = 53000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:27.80742862728076 	 residual l2 norm: 0.003298465747634518
# newton iteration:  2
# sol_update_l2_norm:0.0006340900385659686 	 residual l2 norm: 6.356762650440034e-05
# newton iteration:  3
# sol_update_l2_norm:8.005076963969824e-12 	 residual l2 norm: 6.66551538673978e-12
# converged at iteration:  3
# sol_update_l2_norm:8.005076963969824e-12 	 residual l2 norm: 6.66551538673978e-12
# epoch:  54	======TIME=======f and u^3 terms time : 0.0011341571807861328
# ======TIME=======stiffness matrix terms time : 0.021366119384765625
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.022660017013549805
# assembling the matrix time taken:  0.00017642974853515625
# solving Ax = b time taken:  0.0030045509338378906
# total size: 54 1000000 = 54000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:25.096887989372867 	 residual l2 norm: 0.003187346878807644
# newton iteration:  2
# sol_update_l2_norm:0.0005154592942309754 	 residual l2 norm: 0.0001160411916215077
# newton iteration:  3
# sol_update_l2_norm:1.3681615812216977e-11 	 residual l2 norm: 1.4325747281368664e-11
# converged at iteration:  3
# sol_update_l2_norm:1.3681615812216977e-11 	 residual l2 norm: 1.4325747281368664e-11
# epoch:  55	======TIME=======f and u^3 terms time : 0.0011196136474609375
# ======TIME=======stiffness matrix terms time : 0.02135920524597168
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02263641357421875
# assembling the matrix time taken:  0.00016808509826660156
# solving Ax = b time taken:  0.0030519962310791016
# total size: 55 1000000 = 55000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:43.55328160848357 	 residual l2 norm: 0.00415389245118684
# newton iteration:  2
# sol_update_l2_norm:0.0008727153858658015 	 residual l2 norm: 0.0001718991310323916
# newton iteration:  3
# sol_update_l2_norm:4.7291750620364096e-11 	 residual l2 norm: 4.718642428008542e-11
# converged at iteration:  3
# sol_update_l2_norm:4.7291750620364096e-11 	 residual l2 norm: 4.718642428008542e-11
# epoch:  56	======TIME=======f and u^3 terms time : 0.001135110855102539
# ======TIME=======stiffness matrix terms time : 0.021446704864501953
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.022739171981811523
# assembling the matrix time taken:  0.00017881393432617188
# solving Ax = b time taken:  0.003095865249633789
# total size: 56 1000000 = 56000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:21.101958561470624 	 residual l2 norm: 0.002711192005608684
# newton iteration:  2
# sol_update_l2_norm:0.0004885656503628695 	 residual l2 norm: 6.190229146507009e-05
# newton iteration:  3
# sol_update_l2_norm:8.8622124408363e-12 	 residual l2 norm: 7.619305715651763e-12
# converged at iteration:  3
# sol_update_l2_norm:8.8622124408363e-12 	 residual l2 norm: 7.619305715651763e-12
# epoch:  57	======TIME=======f and u^3 terms time : 0.0011210441589355469
# ======TIME=======stiffness matrix terms time : 0.021384239196777344
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.022661447525024414
# assembling the matrix time taken:  0.00022149085998535156
# solving Ax = b time taken:  0.003114938735961914
# total size: 57 1000000 = 57000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:34.55703107105579 	 residual l2 norm: 0.0029303393182827965
# newton iteration:  2
# sol_update_l2_norm:0.0005436500074045142 	 residual l2 norm: 9.51834906716313e-05
# newton iteration:  3
# sol_update_l2_norm:6.217751068981608e-12 	 residual l2 norm: 1.2751955661817255e-12
# converged at iteration:  3
# ...
# ======TIME=======stiffness matrix terms time : 0.023021459579467773
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02435612678527832
# assembling the matrix time taken:  0.00017189979553222656
# solving Ax = b time taken:  0.006911277770996094
# total size: 111 1000000 = 111000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:25.847010022758262 	 residual l2 norm: 0.0004270013260163316
# newton iteration:  2
# sol_update_l2_norm:7.955928717541253e-05 	 residual l2 norm: 1.684514197475536e-05
# newton iteration:  3
# sol_update_l2_norm:8.628688267784549e-11 	 residual l2 norm: 1.3584132607734492e-12
# converged at iteration:  3
# sol_update_l2_norm:8.628688267784549e-11 	 residual l2 norm: 1.3584132607734492e-12
# epoch:  112	======TIME=======f and u^3 terms time : 0.0012540817260742188
# ======TIME=======stiffness matrix terms time : 0.023059368133544922
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02448272705078125
# assembling the matrix time taken:  0.0001742839813232422
# solving Ax = b time taken:  0.006910085678100586
# total size: 112 1000000 = 112000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:50.997304388270706 	 residual l2 norm: 0.0003858202268943168
# newton iteration:  2
# sol_update_l2_norm:0.00022151076302884522 	 residual l2 norm: 6.518593149453554e-06
# newton iteration:  3
# sol_update_l2_norm:8.282389932382968e-11 	 residual l2 norm: 1.551962609998893e-12
# converged at iteration:  3
# sol_update_l2_norm:8.282389932382968e-11 	 residual l2 norm: 1.551962609998893e-12
# epoch:  113	======TIME=======f and u^3 terms time : 0.0011670589447021484
# ======TIME=======stiffness matrix terms time : 0.026245594024658203
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02760481834411621
# assembling the matrix time taken:  0.0001659393310546875
# solving Ax = b time taken:  0.0069997310638427734
# total size: 113 1000000 = 113000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:75.28040660397843 	 residual l2 norm: 0.00034967832949200933
# newton iteration:  2
# sol_update_l2_norm:0.0008195260028892696 	 residual l2 norm: 9.163395224328132e-05
# newton iteration:  3
# sol_update_l2_norm:8.80172288545831e-11 	 residual l2 norm: 1.4902709863242865e-11
# converged at iteration:  3
# sol_update_l2_norm:8.80172288545831e-11 	 residual l2 norm: 1.4902709863242865e-11
# epoch:  114	======TIME=======f and u^3 terms time : 0.0012562274932861328
# ======TIME=======stiffness matrix terms time : 0.026302576065063477
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.027730941772460938
# assembling the matrix time taken:  0.0001735687255859375
# solving Ax = b time taken:  0.00700831413269043
# total size: 114 1000000 = 114000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:48.36833515470097 	 residual l2 norm: 0.0005196809307178344
# newton iteration:  2
# sol_update_l2_norm:0.00021330678029904813 	 residual l2 norm: 1.4256645088465022e-05
# newton iteration:  3
# sol_update_l2_norm:3.234925659219173e-11 	 residual l2 norm: 2.0836083009019937e-12
# converged at iteration:  3
# sol_update_l2_norm:3.234925659219173e-11 	 residual l2 norm: 2.0836083009019937e-12
# epoch:  115	======TIME=======f and u^3 terms time : 0.0011730194091796875
# ======TIME=======stiffness matrix terms time : 0.02632284164428711
# ======TIME=======neumann bd terms time : 9.5367431640625e-07
# =======> argmax subproblem time:  0.027664899826049805
# assembling the matrix time taken:  0.000164031982421875
# solving Ax = b time taken:  0.00710749626159668
# total size: 115 1000000 = 115000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:53.125904141055635 	 residual l2 norm: 0.0003677357842337922
# newton iteration:  2
# sol_update_l2_norm:0.0003423537001758833 	 residual l2 norm: 9.519780111217083e-06
# newton iteration:  3
# sol_update_l2_norm:3.000434476408167e-11 	 residual l2 norm: 6.558981946351738e-13
# converged at iteration:  3
# sol_update_l2_norm:3.000434476408167e-11 	 residual l2 norm: 6.558981946351738e-13
# epoch:  116	======TIME=======f and u^3 terms time : 0.0011703968048095703
# ======TIME=======stiffness matrix terms time : 0.02635478973388672
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.027715444564819336
# assembling the matrix time taken:  0.00017070770263671875
# solving Ax = b time taken:  0.007127523422241211
# total size: 116 1000000 = 116000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:17.823866890548008 	 residual l2 norm: 0.0003152945813027687
# newton iteration:  2
# sol_update_l2_norm:4.95225239608627e-05 	 residual l2 norm: 3.3040741006463263e-06
# newton iteration:  3
# sol_update_l2_norm:1.9450590629867317e-11 	 residual l2 norm: 4.687606970093398e-13
# converged at iteration:  3
# sol_update_l2_norm:1.9450590629867317e-11 	 residual l2 norm: 4.687606970093398e-13
# epoch:  117	======TIME=======f and u^3 terms time : 0.0011413097381591797
# ======TIME=======stiffness matrix terms time : 0.02315998077392578
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.024468660354614258
# assembling the matrix time taken:  0.00016450881958007812
# solving Ax = b time taken:  0.007194995880126953
# total size: 117 1000000 = 117000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:23.952701479984142 	 residual l2 norm: 0.00026986726533654334
# newton iteration:  2
# sol_update_l2_norm:6.395870604088004e-05 	 residual l2 norm: 7.192231166191831e-07
# newton iteration:  3
# sol_update_l2_norm:4.445300948017188e-11 	 residual l2 norm: 1.4213707346947846e-12
# converged at iteration:  3
# sol_update_l2_norm:4.445300948017188e-11 	 residual l2 norm: 1.4213707346947846e-12
# epoch:  118	======TIME=======f and u^3 terms time : 0.00115966796875
# ======TIME=======stiffness matrix terms time : 0.023221492767333984
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.024558305740356445
# assembling the matrix time taken:  0.0001621246337890625
# solving Ax = b time taken:  0.007238864898681641
# total size: 118 1000000 = 118000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:73.33985467000666 	 residual l2 norm: 0.000276652866220907
# newton iteration:  2
# sol_update_l2_norm:0.00016656821611065885 	 residual l2 norm: 2.5497045593136234e-05
# newton iteration:  3
# sol_update_l2_norm:3.406313414917023e-11 	 residual l2 norm: 5.976848599290014e-13
# converged at iteration:  3
# sol_update_l2_norm:3.406313414917023e-11 	 residual l2 norm: 5.976848599290014e-13
# epoch:  119	======TIME=======f and u^3 terms time : 0.0011370182037353516
# ======TIME=======stiffness matrix terms time : 0.023265838623046875
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.02468395233154297
# assembling the matrix time taken:  0.00016570091247558594
# solving Ax = b time taken:  0.007272005081176758
# total size: 119 1000000 = 119000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:12.909886773097767 	 residual l2 norm: 0.00027181090153758784
# newton iteration:  2
# sol_update_l2_norm:3.3492939401937685e-05 	 residual l2 norm: 1.0344597592889226e-06
# newton iteration:  3
# sol_update_l2_norm:3.619501098602926e-11 	 residual l2 norm: 2.040212363332361e-12
# converged at iteration:  3
# sol_update_l2_norm:3.619501098602926e-11 	 residual l2 norm: 2.040212363332361e-12
# epoch:  120	======TIME=======f and u^3 terms time : 0.0011301040649414062
# ======TIME=======stiffness matrix terms time : 0.02332448959350586
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02462148666381836
# assembling the matrix time taken:  0.00016355514526367188
# solving Ax = b time taken:  0.00732111930847168
# total size: 120 1000000 = 120000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:34.29976389792156 	 residual l2 norm: 0.00027826791109056807
# newton iteration:  2
# sol_update_l2_norm:7.151458032882718e-05 	 residual l2 norm: 4.486294404206705e-06
# newton iteration:  3
# sol_update_l2_norm:7.388906766464032e-11 	 residual l2 norm: 8.063835016943161e-13
# converged at iteration:  3
# sol_update_l2_norm:7.388906766464032e-11 	 residual l2 norm: 8.063835016943161e-13
# epoch:  121	======TIME=======f and u^3 terms time : 0.0012121200561523438
# ======TIME=======stiffness matrix terms time : 0.02652454376220703
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02790689468383789
# assembling the matrix time taken:  0.00017881393432617188
# solving Ax = b time taken:  0.0073587894439697266
# total size: 121 1000000 = 121000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:24.520566100106297 	 residual l2 norm: 0.0002222623834699619
# newton iteration:  2
# sol_update_l2_norm:2.9740001587630777e-05 	 residual l2 norm: 7.661923280214365e-06
# newton iteration:  3
# sol_update_l2_norm:3.1844622793766635e-11 	 residual l2 norm: 8.462065311263194e-13
# converged at iteration:  3
# sol_update_l2_norm:3.1844622793766635e-11 	 residual l2 norm: 8.462065311263194e-13
# epoch:  122	======TIME=======f and u^3 terms time : 0.00118255615234375
# ======TIME=======stiffness matrix terms time : 0.023398876190185547
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.024916410446166992
# assembling the matrix time taken:  0.0001761913299560547
# solving Ax = b time taken:  0.007397890090942383
# total size: 122 1000000 = 122000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:57.412913265944034 	 residual l2 norm: 0.000319812680696411
# newton iteration:  2
# sol_update_l2_norm:0.0003359612797043747 	 residual l2 norm: 5.1963681932593344e-06
# newton iteration:  3
# sol_update_l2_norm:5.6883098994642655e-11 	 residual l2 norm: 7.123881661122451e-13
# converged at iteration:  3
# sol_update_l2_norm:5.6883098994642655e-11 	 residual l2 norm: 7.123881661122451e-13
# epoch:  123	======TIME=======f and u^3 terms time : 0.0011887550354003906
# ======TIME=======stiffness matrix terms time : 0.023345232009887695
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.024705886840820312
# assembling the matrix time taken:  0.0001647472381591797
# solving Ax = b time taken:  0.007447004318237305
# total size: 123 1000000 = 123000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:46.333457388972995 	 residual l2 norm: 0.0002630806141862867
# newton iteration:  2
# sol_update_l2_norm:8.726402845410391e-05 	 residual l2 norm: 2.3179794329216553e-06
# newton iteration:  3
# sol_update_l2_norm:8.374264278072867e-11 	 residual l2 norm: 2.4419757433822946e-12
# converged at iteration:  3
# sol_update_l2_norm:8.374264278072867e-11 	 residual l2 norm: 2.4419757433822946e-12
# epoch:  124	======TIME=======f and u^3 terms time : 0.0012440681457519531
# ======TIME=======stiffness matrix terms time : 0.023329973220825195
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.024745941162109375
# assembling the matrix time taken:  0.00016689300537109375
# solving Ax = b time taken:  0.007482767105102539
# total size: 124 1000000 = 124000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:32.69839699539918 	 residual l2 norm: 0.0003233713889806698
# newton iteration:  2
# sol_update_l2_norm:6.368856460884515e-05 	 residual l2 norm: 1.5908471415485726e-05
# newton iteration:  3
# sol_update_l2_norm:3.9185433273019695e-11 	 residual l2 norm: 1.887328297573768e-12
# converged at iteration:  3
# sol_update_l2_norm:3.9185433273019695e-11 	 residual l2 norm: 1.887328297573768e-12
# epoch:  125	======TIME=======f and u^3 terms time : 0.0011591911315917969
# ======TIME=======stiffness matrix terms time : 0.023413896560668945
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.024892807006835938
# assembling the matrix time taken:  0.00017333030700683594
# solving Ax = b time taken:  0.007532596588134766
# total size: 125 1000000 = 125000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:14.05352694431333 	 residual l2 norm: 0.000387807741857618
# newton iteration:  2
# sol_update_l2_norm:2.611207878973738e-05 	 residual l2 norm: 3.996282995614491e-06
# newton iteration:  3
# sol_update_l2_norm:3.813570565511454e-11 	 residual l2 norm: 1.8510771554339084e-12
# converged at iteration:  3
# sol_update_l2_norm:3.813570565511454e-11 	 residual l2 norm: 1.8510771554339084e-12
# epoch:  126	======TIME=======f and u^3 terms time : 0.0012478828430175781
# ======TIME=======stiffness matrix terms time : 0.026926755905151367
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.028339147567749023
# assembling the matrix time taken:  0.00016808509826660156
# solving Ax = b time taken:  0.007543325424194336
# total size: 126 1000000 = 126000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:16.056108319894076 	 residual l2 norm: 0.00028098272995778436
# newton iteration:  2
# sol_update_l2_norm:3.648561424968245e-05 	 residual l2 norm: 5.32815520306832e-06
# newton iteration:  3
# sol_update_l2_norm:6.256677139696513e-11 	 residual l2 norm: 1.274281672591281e-12
# converged at iteration:  3
# sol_update_l2_norm:6.256677139696513e-11 	 residual l2 norm: 1.274281672591281e-12
# epoch:  127	======TIME=======f and u^3 terms time : 0.0011663436889648438
# ======TIME=======stiffness matrix terms time : 0.023628950119018555
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02496337890625
# assembling the matrix time taken:  0.0001647472381591797
# solving Ax = b time taken:  0.007612466812133789
# total size: 127 1000000 = 127000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:34.30422922520548 	 residual l2 norm: 0.00027470989713213777
# newton iteration:  2
# sol_update_l2_norm:4.7631566678164095e-05 	 residual l2 norm: 1.105984669198834e-05
# newton iteration:  3
# sol_update_l2_norm:5.5964722179648564e-11 	 residual l2 norm: 1.6554254458336307e-12
# converged at iteration:  3
# sol_update_l2_norm:5.5964722179648564e-11 	 residual l2 norm: 1.6554254458336307e-12
# epoch:  128	======TIME=======f and u^3 terms time : 0.0011510848999023438
# ======TIME=======stiffness matrix terms time : 0.027070283889770508
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02840876579284668
# assembling the matrix time taken:  0.0001735687255859375
# solving Ax = b time taken:  0.007635593414306641
# total size: 128 1000000 = 128000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:29.197999550071604 	 residual l2 norm: 0.00023089979782647143
# newton iteration:  2
# sol_update_l2_norm:5.333644114064348e-05 	 residual l2 norm: 5.768057386287419e-06
# newton iteration:  3
# sol_update_l2_norm:4.1910326542173285e-11 	 residual l2 norm: 2.8126170226742727e-12
# converged at iteration:  3
# sol_update_l2_norm:4.1910326542173285e-11 	 residual l2 norm: 2.8126170226742727e-12
# time taken:  31.799713611602783
# neuron num 		 error 		 order
# 4 		 0.354711 		 * 		 6.662283 		 *
#
# 8 		 0.353662 		 0.004272 		 6.661078 		 0.000261
#
# 16 		 0.352766 		 0.003660 		 6.619183 		 0.009103
#
# 32 		 0.253861 		 0.474671 		 5.051937 		 0.389817
#
# 64 		 0.080530 		 1.656446 		 2.242332 		 1.171837
#
# 128 		 0.017442 		 2.206955 		 0.663695 		 1.756408
#
# neuron num  & 	 $\|u-u_n \|_{L^2}$ & 	 order $O(n^{-1.67})$ & 	 $ | u -u_n |_{H^1}$ & 	 order $O(n^{-1.33})$ \\ \hline \hline
# 4 		 & 0.354711 &		 * & 		 6.662283 & 		 *  \\ \hline
#
# 8 		 &  3.537e-01 &  		 0.00 &  		 6.661e+00 &  		 0.00 \\ \hline
#
# 16 		 &  3.528e-01 &  		 0.00 &  		 6.619e+00 &  		 0.01 \\ \hline
#
# 32 		 &  2.539e-01 &  		 0.47 &  		 5.052e+00 &  		 0.39 \\ \hline
#
# 64 		 &  8.053e-02 &  		 1.66 &  		 2.242e+00 &  		 1.17 \\ \hline
#
# 128 		 &  1.744e-02 &  		 2.21 &  		 6.637e-01 &  		 1.76 \\ \hline

# %%
N_list = [2**3,2**3,2**3]
N = np.prod(N_list)
N
# Out:
# 512

# %%
load_model_data = {'loadOrNot':False,
                  'model_filename':"data-pb/xxx",
                  'relu_k':3,
                  'neuron_num': 128}
# Out:
# False

# %%
err = torch.load('data-pb/err_OGA_3D_gabor_relu_3_neuron_128_N_384_randomized.pt')
err.size()
# Out:
# torch.Size([129])
