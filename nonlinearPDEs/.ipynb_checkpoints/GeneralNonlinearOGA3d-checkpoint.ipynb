# %%
"""
This version of code is modified to incorporate more batch operations by Xiaofeng. 
The following parts are covered: Error computations, argmax subproblems, nonlinear Newton solver
Oct 13rd 2024.
"""

import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import time
import sys
import os 
from scipy.sparse import linalg
from pathlib import Path
import itertools
if torch.cuda.is_available():  
    device = "cuda" 
else:  
    device = "cpu" 

torch.set_default_dtype(torch.float64)
pi = torch.tensor(np.pi,dtype=torch.float64)
ZERO = torch.tensor([0.]).to(device)

class model(nn.Module):
    """ ReLU k shallow neural network
    Parameters: 
    input size: input dimension
    hidden_size1 : number of hidden layers 
    num_classes: output classes 
    k: degree of relu functions
    """
    def __init__(self, input_size, hidden_size1, num_classes,k = 1):
        super().__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, num_classes,bias = False)
        self.k = k 
    def forward(self, x):
        u1 = self.fc2(F.relu(self.fc1(x))**self.k)
        return u1
    def evaluate_derivative(self, x, i):
        if self.k == 1:
            u1 = self.fc2(torch.heaviside(self.fc1(x),ZERO) * self.fc1.weight.t()[i-1:i,:] )
        else:
            u1 = self.fc2(self.k*F.relu(self.fc1(x))**(self.k-1) *self.fc1.weight.t()[i-1:i,:] )  
        return u1

def plot_2D(f): 
    
    Nx = 400
    Ny = 400 
    xs = np.linspace(0, 1, Nx)
    ys = np.linspace(0, 1, Ny)
    x, y = np.meshgrid(xs, ys, indexing='xy')
    xy_comb = np.stack((x.flatten(),y.flatten())).T
    xy_comb = torch.tensor(xy_comb)
    z = f(xy_comb).reshape(Nx,Ny)
    z = z.detach().numpy()
    plt.figure(dpi=200)
    ax = plt.axes(projection='3d')
    ax.plot_surface(x , y , z )

    plt.show()

def plot_subdomains(my_model):
    x_coord =torch.linspace(0,1,200)
    wi = my_model.fc1.weight.data
    bi = my_model.fc1.bias.data 
    for i, bias in enumerate(bi):  
        if wi[i,1] !=0: 
            plt.plot(x_coord, - wi[i,0]/wi[i,1]*x_coord - bias/wi[i,1])
        else: 
            plt.plot(x_coord,  - bias/wi[i,0]*torch.ones(x_coord.size()))

    plt.xlim([0,1])
    plt.ylim([0,1])
    plt.legend()
    plt.show()
    return 0   

def adjust_neuron_position(my_model, dims = 3):

    def create_mesh_grid(dims, pts):
        mesh = torch.tensor(list(itertools.product(pts,repeat=dims)))
        vertices = mesh.reshape(len(pts) ** dims, -1) 
        return vertices
    counter = 0 
    # positions = torch.tensor([[0.,0.],[0.,1.],[1.,1.],[1.,0.]])
    pts = torch.tensor([0.,1.])
    positions = create_mesh_grid(dims,pts) 
    neuron_num = my_model.fc1.bias.size(0)
    for i in range(neuron_num): 
        w = my_model.fc1.weight.data[i:i+1,:]
        b = my_model.fc1.bias.data[i]
    #     print(w,b)
        values = torch.matmul(positions,w.T) # + b
        left_end = - torch.max(values)
        right_end = - torch.min(values)
        offset = (right_end - left_end)/50
        if b <= left_end + offset/2 : 
            b = torch.rand(1)*(right_end - left_end - offset) + left_end + offset/2 
            my_model.fc1.bias.data[i] = b 
        if b >= right_end - offset/2 :
            if counter < (dims+1):
#                 print("here")
                counter += 1
            else: # (d + 1) or more 
                b = torch.rand(1)*(right_end - left_end - offset) + left_end + offset/2 
                my_model.fc1.bias.data[i] = b 
    return my_model

# %%
def show_convergence_order2(err_l2,err_h10,exponent,dict_size, filename,write2file = False):
    
    if write2file:
        file_mode = "a" if os.path.exists(filename) else "w"
        f_write = open(filename, file_mode)
    
    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_l2[i] for i in neuron_nums ]
    err_list2 = [err_h10[i] for i in neuron_nums ] 
    # f_write.write('M:{}, relu {} \n'.format(M,k))
    if write2file:
        f_write.write('dictionary size: {}\n'.format(dict_size))
        f_write.write("neuron num \t\t error \t\t order \t\t h10 error \\ order \n")
    print("neuron num \t\t error \t\t order")
    for i, item in enumerate(err_list):
        if i == 0: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t")
            
            # print("*")
            print("{} \t\t {:.6f} \t\t * \t\t {:.6f} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ) )
            if write2file: 
                f_write.write("{} \t\t {} \t\t * \t\t {} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ))
        else: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t") 
            # print(np.log(err_list[i-1]/err_list[i])/np.log(2))
            print("{} \t\t {:.6f} \t\t {:.6f} \t\t {:.6f} \t\t {:.6f} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ) )
            if write2file: 
                f_write.write("{} \t\t {} \t\t {} \t\t {} \t\t {} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ))
    if write2file:     
        f_write.write("\n")
        f_write.close()

def show_convergence_order_latex2(err_l2,err_h10,exponent,k=1,d=1): 
    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_l2[i] for i in neuron_nums ]
    err_list2 = [err_h10[i] for i in neuron_nums ] 
    # f_write.write('M:{}, relu {} \n'.format(M,k))
    # f_write.write('randomized dictionary size: {}\n'.format(N))
    # f_write.write("neuron num \t\t error \t\t order \t\t h10 error \\ order \n")
    l2_order = -1/2-(2*k + 1)/(2*d)
    h10_order = -1/2-(2*(k-1) + 1)/(2*d)
#     print("neuron num  & \t $\|u-u_n \|_{L^2}$ & \t order $O(n^{{{}})$ & \t $ | u -u_n |_{H^1}$ & \t order $O(n^{{{}})$ \\\ \hline \hline ".format(l2_order,h10_order))
    print("neuron num  & \t $\\|u-u_n \\|_{{L^2}}$ & \t order $O(n^{{{:.2f}}})$ & \t $ | u -u_n |_{{H^1}}$ & \t order $O(n^{{{:.2f}}})$ \\\\ \\hline \\hline ".format(l2_order, h10_order))
    for i, item in enumerate(err_list):
        if i == 0: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t")

            # print("*")
            print("{} \t\t & {:.6f} &\t\t * & \t\t {:.6f} & \t\t *  \\\ \hline  \n".format(neuron_nums[i],item, err_list2[i] ) )   
            # f_write.write("{} \t\t {} \t\t * \t\t {} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ))
        else: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t") 
            # print(np.log(err_list[i-1]/err_list[i])/np.log(2))
            print("{} \t\t &  {:.3e} &  \t\t {:.2f} &  \t\t {:.3e} &  \t\t {:.2f} \\\ \hline  \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ) )
            # f_write.write("{} \t\t {} \t\t {} \t\t {} \t\t {} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ))
    # f_write.write("\n")
    # f_write.close()

# %%
def PiecewiseGQ1D_weights_points(x_l,x_r,Nx, order):
    """ Output the coeffients and weights for piecewise Gauss Quadrature 
    Parameters
    ----------
    x_l : float 
    left endpoint of an interval 
    x_r: float
    right endpoint of an interval 
    Nx: int 
    number of subintervals for integration
    order: int
    order of Gauss Quadrature 
    Returns
    -------
    vectorized quadrature weights and integration points
    """
    x,w = np.polynomial.legendre.leggauss(order)
    gx = torch.tensor(x).to(device)
    gx = gx.view(1,-1) # row vector 
    gw = torch.tensor(w).to(device)    
    gw = gw.view(-1,1) # Column vector 
    nodes = torch.linspace(x_l,x_r,Nx+1).view(-1,1).to(device) 
    coef1 = ((nodes[1:,:] - nodes[:-1,:])/2) # n by 1  
    coef2 = ((nodes[1:,:] + nodes[:-1,:])/2) # n by 1  
    coef2_expand = coef2.expand(-1,gx.size(1)) # Expand to n by p shape, -1: keep the first dimension n , expand the 2nd dim (columns)
    integration_points = coef1@gx + coef2_expand
    integration_points = integration_points.flatten().view(-1,1) # Make it a column vector
    gw_expand = torch.tile(gw,(Nx,1)) # rows: n copies of current tensor, columns: 1 copy, no change
    # Modify coef1 to be compatible with func_values
    coef1_expand = coef1.expand(coef1.size(0),gx.size(1))    
    coef1_expand = coef1_expand.flatten().view(-1,1)
    return coef1_expand.to(device) * gw_expand.to(device), integration_points.to(device)

def PiecewiseGQ2D_weights_points(Nx, order): 
    """ A slight modification of PiecewiseGQ2D function that only needs the weights and integration points.
    Parameters
    ----------

    Nx: int 
        number of intervals along the dimension. No Ny, assume Nx = Ny
    order: int 
        order of the Gauss Quadrature

    Returns
    -------
    long_weights: torch.tensor
    integration_points: torch.tensor
    """

#     print("order: ",order )
    x, w = np.polynomial.legendre.leggauss(order)
    gauss_pts = np.array(np.meshgrid(x,x,indexing='ij')).reshape(2,-1).T
    weights =  (w*w[:,None]).ravel()

    gauss_pts =torch.tensor(gauss_pts)
    weights = torch.tensor(weights)

    h = 1/Nx # 100 intervals 
    long_weights =  torch.tile(weights,(Nx**2,1))
    long_weights = long_weights.reshape(-1,1)
    long_weights = long_weights * h**2 /4 

    integration_points = torch.tile(gauss_pts,(Nx**2,1))
    scale_factor = h/2 
    integration_points = scale_factor * integration_points

    index = np.arange(1,Nx+1)-0.5
    ordered_pairs = np.array(np.meshgrid(index,index,indexing='ij'))
    ordered_pairs = ordered_pairs.reshape(2,-1).T

    # print(ordered_pairs)
    # print()
    ordered_pairs = torch.tensor(ordered_pairs)
    # print(ordered_pairs.size())
    ordered_pairs = torch.tile(ordered_pairs, (1,order**2)) # number of GQ points
    # print(ordered_pairs)

    ordered_pairs =  ordered_pairs.reshape(-1,2)
    # print(ordered_pairs)
    translation = ordered_pairs*h 
    # print(translation)

    integration_points = integration_points + translation 
#     print(integration_points.size())
    # func_values = integrand2_torch(integration_points)
    return long_weights.to(device), integration_points.to(device)

def PiecewiseGQ3D_weights_points(Nx, order): 
    """ A slight modification of PiecewiseGQ2D function that only needs the weights and integration points.
    Parameters
    ----------

    Nx: int 
        number of intervals along the dimension. No Ny, assume Nx = Ny
    order: int 
        order of the Gauss Quadrature

    Returns
    -------
    long_weights: torch.tensor
    integration_points: torch.tensor
    """

    """
    Parameters
    ----------
    target : 
        Target function 
    Nx: int 
        number of intervals along the dimension. No Ny, assume Nx = Ny
    order: int 
        order of the Gauss Quadrature
    """

    # print("order: ",order )
    x, w = np.polynomial.legendre.leggauss(order)
    gauss_pts = np.array(np.meshgrid(x,x,x,indexing='ij')).reshape(3,-1).T
    weight_list = np.array(np.meshgrid(w,w,w,indexing='ij'))
    weights =   (weight_list[0]*weight_list[1]*weight_list[2]).ravel() 

    gauss_pts =torch.tensor(gauss_pts)
    weights = torch.tensor(weights)

    h = 1/Nx # 100 intervals 
    long_weights =  torch.tile(weights,(Nx**3,1))
    long_weights = long_weights.reshape(-1,1)
    long_weights = long_weights * h**3 /8 

    integration_points = torch.tile(gauss_pts,(Nx**3,1))
    # print("shape of integration_points", integration_points.size())
    scale_factor = h/2 
    integration_points = scale_factor * integration_points

    index = np.arange(1,Nx+1)-0.5
    ordered_pairs = np.array(np.meshgrid(index,index,index,indexing='ij'))
    ordered_pairs = ordered_pairs.reshape(3,-1).T

    # print(ordered_pairs)
    # print()
    ordered_pairs = torch.tensor(ordered_pairs)
    # print(ordered_pairs.size())
    ordered_pairs = torch.tile(ordered_pairs, (1,order**3)) # number of GQ points
    # print(ordered_pairs)

    ordered_pairs =  ordered_pairs.reshape(-1,3)
    # print(ordered_pairs)
    translation = ordered_pairs*h 
    # print(translation)

    integration_points = integration_points + translation 

    return long_weights.to(device), integration_points.to(device)

def MonteCarlo_Sobol_dDim_weights_points(M ,d = 4):
    Sob_integral = torch.quasirandom.SobolEngine(dimension =d, scramble= False, seed=None) 
    integration_points = Sob_integral.draw(M).double() 
    integration_points = integration_points.to(device)
    weights = torch.ones(M,1).to(device)/M 
    return weights, integration_points 

def Neumann_boundary_quadrature_points_weights(M,d):
    def generate_quadpts_on_boundary(gw_expand_bd, integration_points_bd,d):
        size_pts_bd = integration_points_bd.size(0) 
        gw_expand_bd_faces = torch.tile(gw_expand_bd,(2*d,1)) # 2d boundaries, 拉成长条

        integration_points_bd_faces = torch.zeros(2*d*integration_points_bd.size(0),d).to(device)
        for ind in range(d): 
            integration_points_bd_faces[2 *ind * size_pts_bd :(2 *ind +1) * size_pts_bd,ind:ind+1] = 0 
            integration_points_bd_faces[(2 *ind)*size_pts_bd :(2 * ind +1) * size_pts_bd,:ind] = integration_points_bd[:,:ind]
            integration_points_bd_faces[(2 *ind)*size_pts_bd :(2 * ind +1) * size_pts_bd,ind+1:] = integration_points_bd[:,ind:]

            integration_points_bd_faces[(2 *ind +1) * size_pts_bd:(2 *ind +2)*size_pts_bd,ind:ind+1] = 1
            integration_points_bd_faces[(2 *ind +1) * size_pts_bd:(2 *ind +2)*size_pts_bd,:ind] = integration_points_bd[:,:ind]        
            integration_points_bd_faces[(2 *ind +1) * size_pts_bd:(2 *ind +2)*size_pts_bd,ind+1:] = integration_points_bd[:,ind:]
        return gw_expand_bd_faces, integration_points_bd_faces
    
    if d == 1: 
        print('dim',d)
        gw_expand_bd_faces = torch.tensor([1.,1.]).view(-1,1).to(device)
        integration_points_bd_faces = torch.tensor([0.,1.]).view(-1,1).to(device) 
    elif d == 2: 
        print('dim',d)
        gw_expand_bd, integration_points_bd = PiecewiseGQ1D_weights_points(0,1,8192, order = 3) 
    elif d == 3: 
        gw_expand_bd, integration_points_bd = PiecewiseGQ2D_weights_points(200, order = 3) 
    elif d == 4: 
        gw_expand_bd, integration_points_bd = PiecewiseGQ3D_weights_points(25, order = 3) 
        print('dim',d)
    else: 
        gw_expand_bd, integration_points_bd = MonteCarlo_Sobol_dDim_weights_points(M ,d = d)
        print('dim >=5 ')
    gw_expand_bd_faces, integration_points_bd_faces = generate_quadpts_on_boundary(gw_expand_bd, integration_points_bd,d)
    return gw_expand_bd_faces.to(device), integration_points_bd_faces.to(device) 

def generate_relu_dict3D(N_list):
    N1 = N_list[0]
    N2 = N_list[1]
    N3 = N_list[2]
    
    N = N1*N2*N3 
    theta1 = np.linspace(0, pi, N1, endpoint= True).reshape(N1,1)
    theta2 = np.linspace(0, 2*pi, N2, endpoint= False).reshape(N2,1)
    b = np.linspace(-1.732, 1.732, N3,endpoint=False).reshape(N3,1) # threshold: 3**0.5  
    coord3 = np.array(np.meshgrid(theta1,theta2,b,indexing='ij'))
    coord3 = coord3.reshape(3,-1).T # N1*N2*N3 x 3. coordinates for the grid points 
    coord3 = torch.tensor(coord3) 

    f1 = torch.zeros(N,1) 
    f2 = torch.zeros(N,1)
    f3 = torch.zeros(N,1)
    f4 = torch.zeros(N,1)

    f1[:,0] = torch.cos(coord3[:,0]) 
    f2[:,0] = torch.sin(coord3[:,0]) * torch.cos(coord3[:,1])
    f3[:,0] = torch.sin(coord3[:,0]) * torch.sin(coord3[:,1])
    f4[:,0] = coord3[:,2] 

    Wb_tensor = torch.cat([f1,f2,f3,f4],1) # N x 4 
    return Wb_tensor


def generate_relu_dict3D_QMC(s,N0):
#     Sob = torch.quasirandom.SobolEngine(dimension =3, scramble= True, seed=None) 
#     samples = Sob.draw(N0).double() 


    # Monte Carlo 
    samples = torch.rand(s*N0,3) 
    T =torch.tensor([[pi,0,0],[0,2*pi,0],[0,0,1.732*2]])
    shift = torch.tensor([0,0,-1.732])
    samples = samples@T + shift 

    f1 = torch.zeros(s*N0,1) 
    f2 = torch.zeros(s*N0,1)
    f3 = torch.zeros(s*N0,1)
    f4 = torch.zeros(s*N0,1)

    f1[:,0] = torch.cos(samples[:,0]) 
    f2[:,0] = torch.sin(samples[:,0]) * torch.cos(samples[:,1])
    f3[:,0] = torch.sin(samples[:,0]) * torch.sin(samples[:,1])
    f4[:,0] = samples[:,2] 

    Wb_tensor = torch.cat([f1,f2,f3,f4],1) # N x 4 
    return Wb_tensor


def minimize_linear_layer_H1_explicit_assemble_efficient(model,alpha, target, g_N, weights, integration_points, w_bd, pts_bd, activation = 'relu',solver="direct" ,memory=2**29):
    """ -div alpha grad u(x) + u = f 
    Parameters
    ----------
    model: 
        nn model
    alpha:
        alpha function
    target:
        rhs function f 
    pts_bd:
        integration points on the boundary, embdedded in the domain 
    """ 
    zero = torch.tensor([0.]).to(device)
    start_time = time.time() 
    w = model.fc1.weight.data 
    b = model.fc1.bias.data 
    neuron_num = b.size(0) 
    dim = integration_points.size(1) 
    M = integration_points.size(0)
    coef_alpha = alpha(integration_points) # alpha  

    total_size = neuron_num * M # memory, number of floating numbers 
    print('total size: {} {} = {}'.format(neuron_num,M,total_size))
    num_batch = total_size//memory + 1 # divide according to memory
    print("num batches: ",num_batch)
    batch_size = M//num_batch
    jac = torch.zeros(b.size(0),b.size(0)).to(device)
    rhs = torch.zeros(b.size(0),1).to(device)
    
    # Assemble the mass matrix <g_j,g_i>_{\Omega} and the rhs <f,g_i>_{\Omega} 
    for j in range(0,M,batch_size): 
        end_index = j + batch_size
        basis_value_col = F.relu(integration_points[j:end_index] @ w.t()+ b)**(model.k) 
        weighted_basis_value_col = basis_value_col * weights[j:end_index] 
        jac += weighted_basis_value_col.t() @ basis_value_col 
        rhs += weighted_basis_value_col.t() @ (target(integration_points[j:end_index,:])) 
        
    # Assemble the boundary condition term <g,v>_{\Gamma_N} 
    if g_N != None: # no batch operations for the boundary part, since it is only rhs on the boundary 
        size_pts_bd = int(pts_bd.size(0)/(2*dim))
        bcs_N = g_N(dim)
        for ii, g_ii in bcs_N:
            # pts_bd_ii = pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
            weighted_g_N = -g_ii(pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:])* w_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
            basis_value_bd_col = F.relu(pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:] @ w.t()+ b)**(model.k)
            rhs += basis_value_bd_col.t() @ weighted_g_N

            weighted_g_N = g_ii(pts_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:])* w_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:]
            basis_value_bd_col = F.relu(pts_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:] @ w.t()+ b)**(model.k)
            rhs += basis_value_bd_col.t() @ weighted_g_N

    # Stiffness matrix term in the jacobian 
    for d in range(dim):
        if model.k == 1:  
            for j in range(0,M,batch_size):  
                end_index = j + batch_size 
                basis_value_dxi_col = torch.heaviside(integration_points[j:end_index] @ w.t()+ b, zero) * w.t()[d:d+1,:]
                weighted_basis_value_dx_col = basis_value_dxi_col * weights[j:end_index] * coef_alpha[j:end_index] 
                jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 
#             basis_value_dxi_col = torch.heaviside(integration_points @ w.t()+ b, zero) * w.t()[d:d+1,:]
#             weighted_basis_value_dx_col = basis_value_dxi_col * weights * coef_alpha 
#             jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 

        else:
            for j in range(0,M,batch_size):  
                end_index = j + batch_size 
                basis_value_dxi_col = model.k * F.relu(integration_points[j:end_index] @ w.t()+ b)**(model.k-1) * w.t()[d:d+1,:]
                weighted_basis_value_dx_col = basis_value_dxi_col * weights[j:end_index] * coef_alpha[j:end_index] 
                jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 
#             basis_value_dxi_col = model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * w.t()[d:d+1,:]
#             weighted_basis_value_dx_col = basis_value_dxi_col * weights * coef_alpha  
#             jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 

    print("assembling the mass matrix time taken: ", time.time()-start_time) 

    start_time = time.time()    
    if solver == "cg": 
        sol, exit_code = linalg.cg(np.array(jac.detach().cpu()),np.array(rhs.detach().cpu()),tol=1e-12)
        sol = torch.tensor(sol).view(1,-1)
    elif solver == "direct": 
#         sol = np.linalg.inv( np.array(jac.detach().cpu()) )@np.array(rhs.detach().cpu())
        sol = (torch.linalg.solve( jac.detach(), rhs.detach())).view(1,-1)
    elif solver == "ls":
        sol = (torch.linalg.lstsq(jac.detach().cpu(),rhs.detach().cpu(),driver='gelsd').solution).view(1,-1)
        # sol = (torch.linalg.lstsq(jac.detach(),rhs.detach()).solution).view(1,-1) # gpu/cpu, driver = 'gels', cannot solve singular
    print("solving Ax = b time taken: ", time.time()-start_time)
    return sol 


def minimize_linear_layer_explicit_assemble(model,target,weights, integration_points,solver="direct"):
    """
    calls the following functions (dependency): 
    1. GQ_piecewise_2D
    input: the nn model containing parameter 
    1. define the loss function  
    2. take derivative to extract the linear system A
    3. call the cg solver in scipy to solve the linear system 
    output: sol. solution of Ax = b
    """
    start_time = time.time() 
    w = model.fc1.weight.data 
    b = model.fc1.bias.data 
    basis_value_col = F.relu(integration_points @ w.t()+ b)**(model.k) 
    weighted_basis_value_col = basis_value_col * weights 
    jac = weighted_basis_value_col.t() @ basis_value_col 
     
    rhs = weighted_basis_value_col.t() @ (target(integration_points)) 
    print("assembling the matrix time taken: ", time.time()-start_time) 
    start_time = time.time()    
    if solver == "cg": 
        sol, exit_code = linalg.cg(np.array(jac.detach().cpu()),np.array(rhs.detach().cpu()),tol=1e-12)
        sol = torch.tensor(sol).view(1,-1)
    elif solver == "direct": 
#         sol = np.linalg.inv( np.array(jac.detach().cpu()) )@np.array(rhs.detach().cpu())
        sol = (torch.linalg.solve( jac.detach(), rhs.detach())).view(1,-1)
    elif solver == "ls":
        sol = (torch.linalg.lstsq(jac.detach().cpu(),rhs.detach().cpu(),driver='gelsd').solution).view(1,-1)
        # sol = (torch.linalg.lstsq(jac.detach(),rhs.detach()).solution).view(1,-1) # gpu/cpu, driver = 'gels', cannot solve singular
    print("solving Ax = b time taken: ", time.time()-start_time)
    return sol

# %% [markdown]
# ### Test Newton solver

# %%
    
## define the nonlinearity 
def nonlinear(v):
    return torch.sinh(v)

def nonlinear_prime(v):
    return torch.cosh(v)

def minimize_linear_layer_newton_method(model,alpha,target,weights, integration_points,weights_bd, integration_points_bd, g_N,activation = 'relu', solver = 'direct',memory=2**29):
    """
    calls the following functions (dependency): 
    1. GQ_piecewise_2D
    input: the nn model containing parameter 
    1. define the loss function  
    2. take derivative to extract the linear system A
    3. call the cg solver in scipy to solve the linear system 
    output: sol. solution of Ax = b
    """
    start_time = time.time() 
    w = model.fc1.weight.data 
    b = model.fc1.bias.data 
    neuron_num = b.size(0) 
    M = integration_points.size(0)
    dim = integration_points.size(1) 
    coef_alpha = alpha(integration_points) # alpha  
    basis_value_col = F.relu(integration_points @ w.t()+ b)**(model.k) 
    weighted_basis_value_col = basis_value_col * weights 
    newton_iters = 20 

    total_size = neuron_num * M # memory, number of floating numbers 
    print('total size: {} {} = {}'.format(neuron_num,M,total_size))
    num_batch = total_size//memory + 1 # divide according to memory
    print("num batches: ",num_batch)
    batch_size = M//num_batch
    
    jac = torch.zeros(b.size(0),b.size(0)).to(device)
    jac_fixed_part = torch.zeros(b.size(0),b.size(0)).to(device)
    rhs = torch.zeros(b.size(0),1).to(device)
    rhs_gN = torch.zeros(b.size(0),1).to(device)
    
    # Stiffness matrix term in the jacobian && gradient term in rhs
    for j in range(0,M,batch_size): 
        end_index = j + batch_size
        if model.k == 1:  
            derivative_comm_part = torch.heaviside(integration_points[j:end_index] @ w.t()+ b, ZERO) 
            for d in range(dim): 
                basis_value_dxi_col = derivative_comm_part * w.t()[d:d+1,:]
                weighted_basis_value_dx_col = basis_value_dxi_col * weights[j:end_index] * coef_alpha[j:end_index] 
                jac_fixed_part += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 
        else:
            derivative_comm_part = model.k * F.relu(integration_points[j:end_index] @ w.t()+ b)**(model.k-1)
            for d in range(dim):  
                basis_value_dxi_col = derivative_comm_part * w.t()[d:d+1,:]
                weighted_basis_value_dx_col = basis_value_dxi_col * weights[j:end_index] * coef_alpha[j:end_index] 
                jac_fixed_part += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 
    jac[:,:] = jac_fixed_part[:,:]
    # neumann boundary condition 
    if g_N != None:
        size_pts_bd = int(integration_points_bd.size(0)/(2*dim))
        bcs_N = g_N(dim)
        for ii, g_ii in bcs_N:
            #Another for loop needed if we need to divide the integration points into batches 
            weighted_g_N = -g_ii(integration_points_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:])* weights_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
            basis_value_bd_col = F.relu(integration_points_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:] @ w.t()+ b)**(model.k)
            rhs_gN += basis_value_bd_col.t() @ weighted_g_N

            weighted_g_N = g_ii(integration_points_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:])* weights_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:]
            basis_value_bd_col = F.relu(integration_points_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:] @ w.t()+ b)**(model.k)
            rhs_gN += basis_value_bd_col.t() @ weighted_g_N
    
    for i in range(newton_iters): 
        print("newton iteration: ", i+1) 
        for j in range(0,M,batch_size): 
            end_index = j + batch_size
            basis_value_col = F.relu(integration_points[j:end_index] @ w.t()+ b)**(model.k) 
            weighted_basis_value_col = basis_value_col * weights[j:end_index] 
            coef_func = nonlinear_prime(model(integration_points[j:end_index]).detach()) # Nonlinearity dependent
            # mass matrix with variable coefficients  
            jac += weighted_basis_value_col.t() @ (coef_func * basis_value_col)
            # f- u^3 term 
            rhs += weighted_basis_value_col.t() @ (target(integration_points[j:end_index]) - nonlinear(model(integration_points[j:end_index]).detach()) )

        # Gradient term in rhs
        for j in range(0,M,batch_size): 
            end_index = j + batch_size
            if model.k == 1:  
                derivative_comm_part = torch.heaviside(integration_points[j:end_index] @ w.t()+ b, ZERO) 
                for d in range(dim): 
                    basis_value_dxi_col = derivative_comm_part * w.t()[d:d+1,:]
                    weighted_basis_value_dx_col = basis_value_dxi_col * weights[j:end_index] * coef_alpha[j:end_index] 
#                     jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 
                    dmy_model_dxi = model.evaluate_derivative(integration_points[j:end_index],d+1).detach() # this can be further optimized 
                    rhs -= weighted_basis_value_dx_col.t() @ dmy_model_dxi
            else:
                derivative_comm_part = model.k * F.relu(integration_points[j:end_index] @ w.t()+ b)**(model.k-1)
                for d in range(dim):  

                    basis_value_dxi_col = derivative_comm_part * w.t()[d:d+1,:]
                    weighted_basis_value_dx_col = basis_value_dxi_col * weights[j:end_index] * coef_alpha[j:end_index] 
#                     jac += weighted_basis_value_dx_col.t() @ basis_value_dxi_col 
                    dmy_model_dxi = model.evaluate_derivative(integration_points[j:end_index],d+1).detach() # this can be further optimized 
                    rhs -= weighted_basis_value_dx_col.t() @ dmy_model_dxi

        rhs += rhs_gN
        
        # print("assembling the matrix time taken: ", time.time()-start_time) 
        start_time = time.time()    
        if solver == "cg": 
            sol, exit_code = linalg.cg(np.array(jac.detach().cpu()),np.array(rhs.detach().cpu()),tol=1e-12)
            sol = torch.tensor(sol).view(1,-1)
        elif solver == "direct": 
    #         sol = np.linalg.inv( np.array(jac.detach().cpu()) )@np.array(rhs.detach().cpu())
            sol = (torch.linalg.solve( jac.detach(), rhs.detach())).view(1,-1)
        elif solver == "ls":
            sol = (torch.linalg.lstsq(jac.detach().cpu(),rhs.detach().cpu(),driver='gelsd').solution).view(1,-1)
            # sol = (torch.linalg.lstsq(jac.detach(),rhs.detach()).solution).view(1,-1) # gpu/cpu, driver = 'gels', cannot solve singular
        # print("solving Ax = b time taken: ", time.time()-start_time)
        ## update the solution 
        model.fc2.weight.data[0,:] += sol[0,:]
        
        # print("newton iteration: ", i) 
        sol_update_l2_norm = torch.norm(sol)
        nn_linear_layer_l2_norm = torch.norm(model.fc2.weight.data[0,:])
        residual_l2_norm = torch.norm(rhs) 
        # print("sol_update_l2_norm:{} \t residual l2 norm: {} ".format(sol_update_l2_norm, residual_l2_norm))
        tol = 1e-10
        print("sol_update_l2_norm:{} \t residual l2 norm: {} ".format(sol_update_l2_norm, residual_l2_norm))
        
        jac[:,:] = jac_fixed_part[:,:] 
        rhs[:,0] = 0

        if sol_update_l2_norm < tol*nn_linear_layer_l2_norm or sol_update_l2_norm < tol or residual_l2_norm < tol*1e-1: 
            print("converged at iteration: ", i+1 )
            print("sol_update_l2_norm:{} \t residual l2 norm: {} ".format(sol_update_l2_norm, residual_l2_norm))
            return model.fc2.weight.data[:,:] 
        
    print("Newton solver NOT converged at iteration!!! ")
    print("sol_update_l2_norm:{} \t residual l2 norm: {} ".format(sol_update_l2_norm, residual_l2_norm))

    return model.fc2.weight.data[:,:]

# %%
def select_greedy_neuron_ind(relu_dict_parameters,my_model,target,gw_expand, integration_points,g_N,weights_bd, integration_points_bd,k,memory = 2**29):
    dim = integration_points.size(1) 
    M = integration_points.size(0)
    N0 = relu_dict_parameters.size(0)   
    neuron_num = my_model.fc2.weight.size(1) if my_model != None else 0

    output = torch.zeros(N0,1).to(device) 
    s_time = time.time()
    total_size2 = M*(neuron_num+1)
    num_batch2 = total_size2//memory + 1 
    batch_size_2 = M//num_batch2 # integration points 
    # N(u) - f terms, divide the integration points into batches 
    if my_model != None: 
        func_values = - target(integration_points) 
        for jj in range(0,M,batch_size_2): 
            end_index = jj + batch_size_2 
            model_values = nonlinear(my_model(integration_points[jj:end_index,:]).detach()) 
            func_values[jj:end_index,:] += model_values #Change 1.  
    else: 
        func_values = - target(integration_points)    
    weight_func_values = func_values*gw_expand  
    
    total_size = M * N0 
    num_batch = total_size//memory + 1 
    batch_size_1 = N0//num_batch # dictionary elements
    print("======argmax subproblem:f and N(u) terms, num batches: ",num_batch)
    for j in range(0,N0,batch_size_1):
        end_index = j + batch_size_1 
        basis_values = (F.relu( torch.matmul(integration_points,relu_dict_parameters[j:end_index,0:dim].T ) - relu_dict_parameters[j:end_index,dim])**k).T # uses broadcasting
        output[j:end_index] += torch.matmul(basis_values,weight_func_values) #
    print('======TIME=======f and N(u) terms time :',time.time()-s_time)
    
    # Gradient term: <\nabla u_n, \nabla g_i>, i = 1,2,3,...,N
    ## ============================================================================
    s_time =time.time() 
    if my_model!= None:
        #compute the derivative of the model 
        model_derivative_values = torch.zeros(M,dim).to(device) 
        for d in range(dim): ## there is a more efficient way 
            for jj in range(0,M,batch_size_2):
                end_index = jj + batch_size_2 
                model_derivative_values[jj:end_index,d:d+1] = my_model.evaluate_derivative(integration_points[jj:end_index,:],d+1).detach()
                
        if my_model.k == 1: 
            #compute the derivative of the dictionary elements 
            for j in range(0,N0,batch_size_1): 
                end_index = j + batch_size_1 
                weighted_derivative_part = gw_expand * torch.heaviside(integration_points@ (relu_dict_parameters[j:end_index,0:dim].T) - relu_dict_parameters[j:end_index,dim], ZERO)
                for d in range(dim):
                    weighted_basis_value_dx_col = weighted_derivative_part * relu_dict_parameters.t()[d:d+1,j:end_index] 
                    output[j:end_index] += weighted_basis_value_dx_col.t() @ model_derivative_values[:,d:d+1]
        else:
            #compute the derivative of the dictionary elements 
            for j in range(0,N0,batch_size_1):  
                end_index = j + batch_size_1
                weighted_derivative_part = gw_expand *my_model.k * F.relu(integration_points@ (relu_dict_parameters[j:end_index,0:dim].T) - relu_dict_parameters[j:end_index,dim])**(my_model.k-1)
                for d in range(dim):
                    weighted_basis_value_dx_col = weighted_derivative_part * relu_dict_parameters.t()[d:d+1,j:end_index]
                    output[j:end_index] += weighted_basis_value_dx_col.t() @ model_derivative_values[:,d:d+1]

    print('======TIME=======stiffness matrix terms time :',time.time()-s_time)
    
    #Neumann boundary condition
    s_time =time.time()  
    output4 = 0 
    if g_N != None:
        size_pts_bd = int(integration_points_bd.size(0)/(2*dim)) # pre-defined rules for integration points on bdries
        bcs_N = g_N(dim)
        for ii, g_ii in bcs_N:
            # pts_bd_ii = pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
            weighted_g_N = -g_ii(integration_points_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:])* weights_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
            basis_value_bd_col = F.relu(integration_points_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:] @ (relu_dict_parameters[:,0:dim].T) - relu_dict_parameters[:,dim] )**(k)
            output4 += basis_value_bd_col.t() @ weighted_g_N

            weighted_g_N = g_ii(integration_points_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:])* weights_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:]
            basis_value_bd_col = F.relu(integration_points_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:] @ (relu_dict_parameters[:,0:dim].T) - relu_dict_parameters[:,dim])**(k)
            output4 += basis_value_bd_col.t() @ weighted_g_N
    print('======TIME=======neumann bd terms time :',time.time()-s_time) 
    output -= output4
    output = torch.abs(output) 
    
    neuron_index = torch.argmax(output.flatten())
    return neuron_index 

def L2_projection_init(model,sol,weights,integration_points,activation = 'relu', solver = 'direct'):
    start_time = time.time() 
    w = model.fc1.weight.data 
    b = model.fc1.bias.data 
    basis_value_col = F.relu(integration_points @ w.t()+ b)**(model.k) 
    weighted_basis_value_col = basis_value_col * weights 
    jac = weighted_basis_value_col.t() @ basis_value_col 
      
    rhs = jac[:,:-1] @ sol.t()

    print("assembling the matrix time taken: ", time.time()-start_time) 
    start_time = time.time()    
    if solver == "cg": 
        sol, exit_code = linalg.cg(np.array(jac.detach().cpu()),np.array(rhs.detach().cpu()),tol=1e-12)
        sol = torch.tensor(sol).view(1,-1)
    elif solver == "direct": 
#         sol = np.linalg.inv( np.array(jac.detach().cpu()) )@np.array(rhs.detach().cpu())
        sol = (torch.linalg.solve( jac.detach(), rhs.detach())).view(1,-1)
    elif solver == "ls":
        sol = (torch.linalg.lstsq(jac.detach().cpu(),rhs.detach().cpu(),driver='gelsd').solution).view(1,-1)
        # sol = (torch.linalg.lstsq(jac.detach(),rhs.detach()).solution).view(1,-1) # gpu/cpu, driver = 'gels', cannot solve singular
    print("solving Ax = b time taken: ", time.time()-start_time)
    model.fc2.weight.data[0,:] = sol[0,:]  
    return model 

def CGANonlinearPoissonReLU3D(my_model,target,alpha,u_exact, u_exact_grad,g_N, N_list,num_epochs,plot_freq, Nx, order, k =1, rand_deter = 'deter', linear_solver = "direct",memory = 2**29): 
    """ Orthogonal greedy algorithm using 1D ReLU dictionary over [-pi,pi]
    Parameters
    ----------
    my_model: 
        nn model 
    target: 
        rhs hand side function for a PDE 
    u_exact:
        exact solution 
    u_exact_grad:
        a function that returns gradient of the exact solution in a list 
    g_N: 
        a function that returns gradient of the exact solution with numbers  
    num_epochs: int 
        number of training epochs 
    integration_intervals: int 
        number of subintervals for piecewise numerical quadrature 

    Returns
    -------
    err: tensor 
        rank 1 torch tensor to record the L2 error history  
    model: 
        trained nn model 
    """
    gw_expand, integration_points = PiecewiseGQ3D_weights_points(Nx, order)
    dim = integration_points.size(1) 
    M = integration_points.size(0)
    weights_bd, integration_points_bd = Neumann_boundary_quadrature_points_weights(99999999,dim) 

    # Compute initial L2 error and the gradient error 
    err = torch.zeros(num_epochs+1).to(device)
    err_h10 = torch.zeros(num_epochs+1).to(device)
    num_neuron = 0 if my_model == None else int(my_model.fc1.bias.detach().data.size(0))
    total_size2 = M*(num_neuron+1)
    num_batch2 = total_size2//memory + 1 
    batch_size_2 = M//num_batch2 # integration points 
    if my_model == None: 
        for jj in range(0,M,batch_size_2): 
            end_index = jj + batch_size_2 
            func_values = target(integration_points[jj:end_index,:])
            err[0] += torch.sum(func_values**2 * gw_expand[jj:end_index,:])**0.5
        list_b = []
        list_w = []
    else: 
        bias = my_model.fc1.bias.detach().data
        weights = my_model.fc1.weight.detach().data
        for jj in range(0,M,batch_size_2): 
            end_index = jj + batch_size_2 
            func_values = u_exact(integration_points[jj:end_index,:]) - my_model(integration_points[jj:end_index,:]).detach()
            err[0] += torch.sum(func_values**2 * gw_expand[jj:end_index,:])**0.5
        list_b = list(bias)
        list_w = list(weights)
        sol = my_model.fc2.weight.data[0,:]

    # initial gradient error 
    if u_exact_grad != None and my_model!=None:
        u_grad = u_exact_grad() 
        for ii, grad_i in enumerate(u_grad): 
            for jj in range(0,M,batch_size_2): 
                end_index = jj + batch_size_2 
                my_model_dxi = my_model.evaluate_derivative(integration_points[jj:end_index,:],ii+1).detach() 
                err_h10[0] += torch.sum((grad_i(integration_points[jj:end_index,:]) - my_model_dxi)**2 * gw_expand[jj:end_index,:])**0.5
    elif u_exact_grad != None and my_model==None:
        u_grad = u_exact_grad() 
        for grad_i in u_grad: 
            for jj in range(0,M,batch_size_2): 
                end_index = jj + batch_size_2 
                err_h10[0] += torch.sum((grad_i(integration_points[jj:end_index,:]))**2 * gw_expand[jj:end_index,:])**0.5
    
    start_time = time.time()
    solver = linear_solver
    N0 = np.prod(N_list)
    if rand_deter == 'deter':
        relu_dict_parameters = generate_relu_dict3D(N_list).to(device)
    print("using linear solver: ",solver)
    # CGA training loop 
    for i in range(num_epochs): 
        print("epoch: ",i+1, end = '\t')
        if rand_deter == 'rand':
            relu_dict_parameters = generate_relu_dict3D_QMC(1,N0).to(device) 
        
        time_argmax = time.time()
        neuron_index = select_greedy_neuron_ind(relu_dict_parameters,my_model,target,gw_expand, integration_points,g_N,weights_bd, integration_points_bd,k,memory=memory)
        print("=======> argmax subproblem time: ",time.time() - time_argmax)
        # print(neuron_index)
        list_w.append(relu_dict_parameters[neuron_index,0:dim]) # 
        list_b.append(-relu_dict_parameters[neuron_index,dim])
        num_neuron += 1
        my_model = model(dim,num_neuron,1,k).to(device)
        w_tensor = torch.stack(list_w, 0 ) 
        b_tensor = torch.tensor(list_b)
        my_model.fc1.weight.data[:,:] = w_tensor[:,:]
        my_model.fc1.bias.data[:] = b_tensor[:]

        ##todo 
        if num_neuron <=2: 
            my_model.fc2.weight.data[0,:] = 0.0001
        else: 
            ## L2 projection onto previous solution as the initial guess 
            my_model.fc2.weight.data[0,:num_neuron -1 ] = sol[:] # projection of previous solution
            my_model = L2_projection_init(my_model,sol,gw_expand,integration_points,activation = 'relu', solver = solver) 

        sol = minimize_linear_layer_newton_method(my_model,alpha, target,\
                    gw_expand, integration_points,weights_bd, integration_points_bd,\
                    g_N,activation ='relu', solver = solver)
        
        sol = sol.flatten() 
        my_model.fc2.weight.data[0,:] = sol[:]

        # Get L2 error and gradient error 
        total_size2 = M*(num_neuron+1)
        num_batch2 = total_size2//memory + 1 
        batch_size_2 = M//num_batch2 # integration points 
        
        for jj in range(0,M,batch_size_2):
            end_index = jj + batch_size_2 
            func_values = u_exact(integration_points[jj:end_index,:]) - my_model(integration_points[jj:end_index,:]).detach()
            func_values = func_values**2 
            err[i+1]+= torch.sum(func_values*gw_expand[jj:end_index,:])**0.5

        if u_exact_grad != None:
            for ii, grad_i in enumerate(u_grad): 
                for jj in range(0,M,batch_size_2): 
                    end_index = jj + batch_size_2 
                    my_model_dxi = my_model.evaluate_derivative(integration_points[jj:end_index,:],ii+1).detach() 
                    err_h10[i+1] += torch.sum((grad_i(integration_points[jj:end_index,:]) - my_model_dxi)**2 * gw_expand[jj:end_index,:])**0.5

    print("time taken: ",time.time() - start_time)
    return err.cpu(), err_h10.cpu(), my_model

# %% [markdown]
# ## CGA Nonlinear Problem

# %%
freq = 1
def u_exact(x):
    return torch.cos(freq*pi*x[:,0:1])*torch.cos( freq*pi*x[:,1:2]) * torch.cos(freq*pi*x[:,2:3])  
def alpha(x): 
    return torch.ones(x.size(0),1).to(device)

def u_exact_grad():
    d = 3 
    def grad_1(x):
        return - freq*pi* torch.sin(freq*pi*x[:,0:1])*torch.cos( freq*pi*x[:,1:2]) * torch.cos(freq*pi*x[:,2:3])   
    def grad_2(x):
        return - freq*pi* torch.cos(freq*pi*x[:,0:1])*torch.sin( freq*pi*x[:,1:2]) * torch.cos(freq*pi*x[:,2:3])  
    def grad_3(x):
        return - freq*pi* torch.cos(freq*pi*x[:,0:1])*torch.cos( freq*pi*x[:,1:2]) * torch.sin(freq*pi*x[:,2:3])   
    
    u_grad=[grad_1, grad_2,grad_3] 

    return u_grad
def laplace_u_exact(x):
    return -3*(freq*pi)**2 * torch.cos(freq*pi*x[:,0:1])*torch.cos( freq*pi*x[:,1:2]) * torch.cos(freq*pi*x[:,2:3])

def u_exact_approx(x):
    return 0.7 * u_exact(x)

def rhs(x):
    return  -laplace_u_exact(x) + nonlinear(u_exact(x))
g_N = None 

dim = 3 
function_name = "cospix" 
filename_write = "data/3DCGA-{}-order.txt".format(function_name)
Nx = 50
order = 3
f_write = open(filename_write, "a")
f_write.write("Numerical integration Nx: {}, order: {} \n".format(Nx, order))
f_write.close() 
save = True 
write2file = True 
memory = 2**29 
for N_list in [[2**3,2**3,2**3]]: # ,[2**6,2**6],[2**7,2**7] 
    f_write = open(filename_write, "a")
    my_model = None 
    exponent = 9 
    num_epochs = 2**exponent  
    plot_freq = num_epochs 
    N = np.prod(N_list)
    relu_k = 3
    err_QMC2, err_h10, my_model = CGANonlinearPoissonReLU3D(my_model,rhs,alpha, u_exact, u_exact_grad,g_N, N_list,num_epochs,plot_freq, Nx, order, k = relu_k, rand_deter = 'rand', linear_solver = "direct", memory = memory)
    if save: 
        folder = 'data/'
        filename = folder + 'err_OGA_2D_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,num_epochs,N)
        torch.save(err_QMC2,filename) 
        folder = 'data/'
        filename = folder + 'model_OGA_2D_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,num_epochs,N)
        torch.save(my_model,filename)

    show_convergence_order2(err_QMC2,err_h10,exponent,N,filename_write,write2file)
    show_convergence_order_latex2(err_QMC2,err_h10,exponent,k =relu_k,d = dim)
# Out:
# using linear solver:  direct
# epoch:  1	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0009386539459228516
# ======TIME=======stiffness matrix terms time : 7.152557373046875e-07
# ======TIME=======neumann bd terms time : 2.384185791015625e-07
# =======> argmax subproblem time:  0.0010900497436523438
# total size: 1 3375000 = 3375000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.0015130942989986008 	 residual l2 norm: 0.27165767650802247
# newton iteration:  2
# sol_update_l2_norm:2.2540728429803833e-08 	 residual l2 norm: 4.047084506145215e-06
# newton iteration:  3
# sol_update_l2_norm:1.7468449401940283e-17 	 residual l2 norm: 3.1363800445660672e-15
# converged at iteration:  3
# sol_update_l2_norm:1.7468449401940283e-17 	 residual l2 norm: 3.1363800445660672e-15
# epoch:  2	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0010333061218261719
# ======TIME=======stiffness matrix terms time : 0.07878947257995605
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.08000445365905762
# total size: 2 3375000 = 6750000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.0031130738966368347 	 residual l2 norm: 0.41676970175381234
# newton iteration:  2
# sol_update_l2_norm:7.872351294092358e-09 	 residual l2 norm: 1.157460029412612e-06
# newton iteration:  3
# sol_update_l2_norm:5.87150817727947e-18 	 residual l2 norm: 1.3788683915077173e-15
# converged at iteration:  3
# sol_update_l2_norm:5.87150817727947e-18 	 residual l2 norm: 1.3788683915077173e-15
# epoch:  3	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0011401176452636719
# ======TIME=======stiffness matrix terms time : 0.07932043075561523
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.08065152168273926
# assembling the matrix time taken:  0.00034308433532714844
# solving Ax = b time taken:  0.0014307498931884766
# total size: 3 3375000 = 10125000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.007570496859413595 	 residual l2 norm: 0.5115272708993521
# newton iteration:  2
# sol_update_l2_norm:1.8008261927104166e-07 	 residual l2 norm: 3.2107894549351365e-05
# newton iteration:  3
# sol_update_l2_norm:1.232744354879309e-15 	 residual l2 norm: 2.681751242322996e-13
# converged at iteration:  3
# sol_update_l2_norm:1.232744354879309e-15 	 residual l2 norm: 2.681751242322996e-13
# epoch:  4	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0010900497436523438
# ======TIME=======stiffness matrix terms time : 0.07854795455932617
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.0798182487487793
# assembling the matrix time taken:  0.0003154277801513672
# solving Ax = b time taken:  0.0015921592712402344
# total size: 4 3375000 = 13500000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.011354856724312508 	 residual l2 norm: 0.6911542853719672
# newton iteration:  2
# sol_update_l2_norm:2.7742125798606643e-06 	 residual l2 norm: 0.00034657085609374747
# newton iteration:  3
# sol_update_l2_norm:8.357965292744676e-13 	 residual l2 norm: 1.2166467731040589e-10
# converged at iteration:  3
# sol_update_l2_norm:8.357965292744676e-13 	 residual l2 norm: 1.2166467731040589e-10
# epoch:  5	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.001134634017944336
# ======TIME=======stiffness matrix terms time : 0.07872176170349121
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.08004236221313477
# assembling the matrix time taken:  0.0003006458282470703
# solving Ax = b time taken:  0.0017561912536621094
# total size: 5 3375000 = 16875000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.09363436934237104 	 residual l2 norm: 0.47050069639637665
# newton iteration:  2
# sol_update_l2_norm:3.536074132393643e-06 	 residual l2 norm: 0.00047092449056750503
# newton iteration:  3
# sol_update_l2_norm:1.3627769149354708e-12 	 residual l2 norm: 1.5683094100424174e-10
# converged at iteration:  3
# sol_update_l2_norm:1.3627769149354708e-12 	 residual l2 norm: 1.5683094100424174e-10
# epoch:  6	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0010857582092285156
# ======TIME=======stiffness matrix terms time : 0.07910919189453125
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.08037686347961426
# assembling the matrix time taken:  0.0003066062927246094
# solving Ax = b time taken:  0.0018818378448486328
# total size: 6 3375000 = 20250000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.12852666382337727 	 residual l2 norm: 0.7887869697507502
# newton iteration:  2
# sol_update_l2_norm:1.2049322148657062e-05 	 residual l2 norm: 0.001343287524692744
# newton iteration:  3
# sol_update_l2_norm:1.2936326090426161e-11 	 residual l2 norm: 4.940971767640881e-10
# converged at iteration:  3
# sol_update_l2_norm:1.2936326090426161e-11 	 residual l2 norm: 4.940971767640881e-10
# epoch:  7	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.001123666763305664
# ======TIME=======stiffness matrix terms time : 0.07923650741577148
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.08055901527404785
# assembling the matrix time taken:  0.0003218650817871094
# solving Ax = b time taken:  0.001992940902709961
# total size: 7 3375000 = 23625000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.10573559826785363 	 residual l2 norm: 1.1477942016371585
# newton iteration:  2
# sol_update_l2_norm:2.0920461524457994e-05 	 residual l2 norm: 0.0005580894555848026
# newton iteration:  3
# sol_update_l2_norm:9.96135399054673e-13 	 residual l2 norm: 2.2611147427873537e-11
# converged at iteration:  3
# sol_update_l2_norm:9.96135399054673e-13 	 residual l2 norm: 2.2611147427873537e-11
# epoch:  8	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0011093616485595703
# ======TIME=======stiffness matrix terms time : 0.0797121524810791
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.08101439476013184
# assembling the matrix time taken:  0.0003199577331542969
# solving Ax = b time taken:  0.0021562576293945312
# total size: 8 3375000 = 27000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.5514529437840529 	 residual l2 norm: 0.80292812566439
# newton iteration:  2
# sol_update_l2_norm:0.00012606455246948165 	 residual l2 norm: 0.00393489462712225
# newton iteration:  3
# sol_update_l2_norm:4.3432848816804484e-10 	 residual l2 norm: 1.645684341335975e-08
# newton iteration:  4
# sol_update_l2_norm:2.745062809903406e-15 	 residual l2 norm: 7.458313615740632e-15
# converged at iteration:  4
# sol_update_l2_norm:2.745062809903406e-15 	 residual l2 norm: 7.458313615740632e-15
# epoch:  9	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0010950565338134766
# ======TIME=======stiffness matrix terms time : 0.07980704307556152
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.08108711242675781
# assembling the matrix time taken:  0.0003135204315185547
# solving Ax = b time taken:  0.002306699752807617
# total size: 9 3375000 = 30375000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:3.525464566105984 	 residual l2 norm: 1.131049479048313
# newton iteration:  2
# sol_update_l2_norm:0.0026733113551315212 	 residual l2 norm: 0.026141836989306434
# newton iteration:  3
# sol_update_l2_norm:3.1092920538332425e-08 	 residual l2 norm: 8.912885794483515e-07
# newton iteration:  4
# sol_update_l2_norm:9.022418937016696e-15 	 residual l2 norm: 6.782593417575618e-14
# converged at iteration:  4
# sol_update_l2_norm:9.022418937016696e-15 	 residual l2 norm: 6.782593417575618e-14
# epoch:  10	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0011174678802490234
# ======TIME=======stiffness matrix terms time : 0.07962799072265625
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.08093714714050293
# assembling the matrix time taken:  0.00029659271240234375
# solving Ax = b time taken:  0.002453327178955078
# total size: 10 3375000 = 33750000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.7575948353162476 	 residual l2 norm: 1.11936468185092
# newton iteration:  2
# sol_update_l2_norm:0.0013815713373131779 	 residual l2 norm: 0.009877503682251008
# newton iteration:  3
# sol_update_l2_norm:1.6419190802457055e-08 	 residual l2 norm: 2.0835978684633866e-07
# newton iteration:  4
# sol_update_l2_norm:1.4274970383415872e-14 	 residual l2 norm: 7.724356918704581e-14
# converged at iteration:  4
# sol_update_l2_norm:1.4274970383415872e-14 	 residual l2 norm: 7.724356918704581e-14
# epoch:  11	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0011467933654785156
# ======TIME=======stiffness matrix terms time : 0.08004474639892578
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.08149909973144531
# assembling the matrix time taken:  0.00029778480529785156
# solving Ax = b time taken:  0.0026230812072753906
# total size: 11 3375000 = 37125000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:1.6100770425226179 	 residual l2 norm: 0.3790749591520789
# newton iteration:  2
# sol_update_l2_norm:0.0007855415281948072 	 residual l2 norm: 0.0036088827148787134
# newton iteration:  3
# sol_update_l2_norm:1.2699900461007886e-09 	 residual l2 norm: 1.8127911249764102e-08
# newton iteration:  4
# sol_update_l2_norm:6.671398128501544e-15 	 residual l2 norm: 6.313516538987735e-14
# converged at iteration:  4
# sol_update_l2_norm:6.671398128501544e-15 	 residual l2 norm: 6.313516538987735e-14
# epoch:  12	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0011398792266845703
# ======TIME=======stiffness matrix terms time : 0.07971596717834473
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.08104467391967773
# assembling the matrix time taken:  0.00030922889709472656
# solving Ax = b time taken:  0.002732992172241211
# total size: 12 3375000 = 40500000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.8873972888026963 	 residual l2 norm: 0.230984755488026
# newton iteration:  2
# sol_update_l2_norm:0.00028741463325426624 	 residual l2 norm: 0.00110386662860027
# newton iteration:  3
# sol_update_l2_norm:2.1498197372428142e-10 	 residual l2 norm: 3.1739832049749393e-09
# converged at iteration:  3
# sol_update_l2_norm:2.1498197372428142e-10 	 residual l2 norm: 3.1739832049749393e-09
# epoch:  13	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0011742115020751953
# ======TIME=======stiffness matrix terms time : 0.08013486862182617
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.08150076866149902
# assembling the matrix time taken:  0.00030612945556640625
# solving Ax = b time taken:  0.002899169921875
# total size: 13 3375000 = 43875000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.6914191833325537 	 residual l2 norm: 0.13479189008650805
# newton iteration:  2
# sol_update_l2_norm:0.00014099447623869114 	 residual l2 norm: 0.0009665203180387355
# newton iteration:  3
# sol_update_l2_norm:4.986189908117225e-11 	 residual l2 norm: 7.233453708501122e-10
# converged at iteration:  3
# sol_update_l2_norm:4.986189908117225e-11 	 residual l2 norm: 7.233453708501122e-10
# epoch:  14	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.001148223876953125
# ======TIME=======stiffness matrix terms time : 0.08053421974182129
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.08197164535522461
# assembling the matrix time taken:  0.00030684471130371094
# solving Ax = b time taken:  0.0031080245971679688
# total size: 14 3375000 = 47250000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:1.6211442730254946 	 residual l2 norm: 0.09656596290319339
# newton iteration:  2
# sol_update_l2_norm:0.0003344291941318182 	 residual l2 norm: 0.00227991278200043
# newton iteration:  3
# sol_update_l2_norm:2.8399678982317915e-10 	 residual l2 norm: 4.999245052595299e-09
# converged at iteration:  3
# sol_update_l2_norm:2.8399678982317915e-10 	 residual l2 norm: 4.999245052595299e-09
# epoch:  15	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0011706352233886719
# ======TIME=======stiffness matrix terms time : 0.08019900321960449
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.08156561851501465
# assembling the matrix time taken:  0.00029659271240234375
# solving Ax = b time taken:  0.003232717514038086
# total size: 15 3375000 = 50625000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:1.4179356326854358 	 residual l2 norm: 0.0484175667933515
# newton iteration:  2
# sol_update_l2_norm:0.00010314430084481167 	 residual l2 norm: 0.00026461886232563483
# newton iteration:  3
# sol_update_l2_norm:2.2202365400790223e-11 	 residual l2 norm: 1.0365258133684411e-10
# converged at iteration:  3
# sol_update_l2_norm:2.2202365400790223e-11 	 residual l2 norm: 1.0365258133684411e-10
# epoch:  16	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0011599063873291016
# ======TIME=======stiffness matrix terms time : 0.0803074836730957
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.08178114891052246
# assembling the matrix time taken:  0.0002989768981933594
# solving Ax = b time taken:  0.0033807754516601562
# total size: 16 3375000 = 54000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.8611942444528949 	 residual l2 norm: 0.06000984864264148
# newton iteration:  2
# sol_update_l2_norm:7.446943070725198e-05 	 residual l2 norm: 0.00019459874493900434
# newton iteration:  3
# sol_update_l2_norm:1.1416655463525417e-11 	 residual l2 norm: 6.583257385768036e-11
# converged at iteration:  3
# sol_update_l2_norm:1.1416655463525417e-11 	 residual l2 norm: 6.583257385768036e-11
# epoch:  17	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0011017322540283203
# ======TIME=======stiffness matrix terms time : 0.08033537864685059
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.0816197395324707
# assembling the matrix time taken:  0.0003132820129394531
# solving Ax = b time taken:  0.0036001205444335938
# total size: 17 3375000 = 57375000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:1.3987716745435137 	 residual l2 norm: 0.02559856145129326
# newton iteration:  2
# sol_update_l2_norm:5.493974477646939e-05 	 residual l2 norm: 0.00020000691762756532
# newton iteration:  3
# sol_update_l2_norm:1.862347178183736e-11 	 residual l2 norm: 1.62650553741426e-10
# converged at iteration:  3
# sol_update_l2_norm:1.862347178183736e-11 	 residual l2 norm: 1.62650553741426e-10
# epoch:  18	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0011169910430908203
# ======TIME=======stiffness matrix terms time : 0.08061885833740234
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.08213305473327637
# assembling the matrix time taken:  0.0002970695495605469
# solving Ax = b time taken:  0.0037841796875
# total size: 18 3375000 = 60750000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.3894668376025847 	 residual l2 norm: 0.0186299484921613
# newton iteration:  2
# sol_update_l2_norm:1.0255022531995778e-05 	 residual l2 norm: 4.300020848620704e-05
# newton iteration:  3
# sol_update_l2_norm:2.330387666347063e-13 	 residual l2 norm: 4.647382134161818e-12
# converged at iteration:  3
# sol_update_l2_norm:2.330387666347063e-13 	 residual l2 norm: 4.647382134161818e-12
# epoch:  19	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0011830329895019531
# ======TIME=======stiffness matrix terms time : 0.08038187026977539
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.08176326751708984
# assembling the matrix time taken:  0.0003216266632080078
# solving Ax = b time taken:  0.003908872604370117
# total size: 19 3375000 = 64125000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.9414592575150622 	 residual l2 norm: 0.016345072819113973
# newton iteration:  2
# sol_update_l2_norm:1.18421378177835e-05 	 residual l2 norm: 0.00010841484410544264
# newton iteration:  3
# sol_update_l2_norm:7.581040544067726e-13 	 residual l2 norm: 1.2543221493514354e-11
# converged at iteration:  3
# sol_update_l2_norm:7.581040544067726e-13 	 residual l2 norm: 1.2543221493514354e-11
# epoch:  20	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0011818408966064453
# ======TIME=======stiffness matrix terms time : 0.08057332038879395
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.08216524124145508
# assembling the matrix time taken:  0.0003056526184082031
# solving Ax = b time taken:  0.0040895938873291016
# total size: 20 3375000 = 67500000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:1.9623024131676796 	 residual l2 norm: 0.010950267527537241
# newton iteration:  2
# sol_update_l2_norm:3.0365631273203143e-05 	 residual l2 norm: 0.0001010979899946054
# newton iteration:  3
# sol_update_l2_norm:2.9427766568716355e-12 	 residual l2 norm: 2.9299113783479275e-11
# converged at iteration:  3
# sol_update_l2_norm:2.9427766568716355e-12 	 residual l2 norm: 2.9299113783479275e-11
# epoch:  21	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0012264251708984375
# ======TIME=======stiffness matrix terms time : 0.08064126968383789
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.08207488059997559
# assembling the matrix time taken:  0.0002968311309814453
# solving Ax = b time taken:  0.004247903823852539
# total size: 21 3375000 = 70875000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:8.403877586282427 	 residual l2 norm: 0.014746191875615842
# newton iteration:  2
# sol_update_l2_norm:0.00024042835532335526 	 residual l2 norm: 0.0006896588196863717
# newton iteration:  3
# sol_update_l2_norm:1.391069527202859e-10 	 residual l2 norm: 1.1602924938967077e-09
# converged at iteration:  3
# sol_update_l2_norm:1.391069527202859e-10 	 residual l2 norm: 1.1602924938967077e-09
# epoch:  22	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0012831687927246094
# ======TIME=======stiffness matrix terms time : 0.08080077171325684
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.08251285552978516
# assembling the matrix time taken:  0.0002913475036621094
# solving Ax = b time taken:  0.0044252872467041016
# total size: 22 3375000 = 74250000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:8.032588654576799 	 residual l2 norm: 0.011520898736360946
# newton iteration:  2
# sol_update_l2_norm:0.0014461515362190031 	 residual l2 norm: 0.0026096345565426744
# newton iteration:  3
# sol_update_l2_norm:2.295199255226229e-09 	 residual l2 norm: 1.0949513766373243e-08
# newton iteration:  4
# sol_update_l2_norm:7.286469187255772e-13 	 residual l2 norm: 1.0255707543734556e-13
# converged at iteration:  4
# sol_update_l2_norm:7.286469187255772e-13 	 residual l2 norm: 1.0255707543734556e-13
# epoch:  23	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0011963844299316406
# ======TIME=======stiffness matrix terms time : 0.08091163635253906
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.08251833915710449
# assembling the matrix time taken:  0.0002994537353515625
# solving Ax = b time taken:  0.004608869552612305
# total size: 23 3375000 = 77625000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:6.517448571837781 	 residual l2 norm: 0.011613218866646865
# newton iteration:  2
# sol_update_l2_norm:0.0013365413020471773 	 residual l2 norm: 0.0017800762086804811
# newton iteration:  3
# sol_update_l2_norm:2.963038370992817e-09 	 residual l2 norm: 9.436058514548866e-09
# newton iteration:  4
# sol_update_l2_norm:1.490233171671401e-13 	 residual l2 norm: 2.7547810070692945e-13
# converged at iteration:  4
# sol_update_l2_norm:1.490233171671401e-13 	 residual l2 norm: 2.7547810070692945e-13
# epoch:  24	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0012645721435546875
# ======TIME=======stiffness matrix terms time : 0.08087611198425293
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.08256816864013672
# assembling the matrix time taken:  0.00031113624572753906
# solving Ax = b time taken:  0.0047419071197509766
# total size: 24 3375000 = 81000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:6.11855717853023 	 residual l2 norm: 0.013394564080044436
# newton iteration:  2
# sol_update_l2_norm:0.00022788206587870952 	 residual l2 norm: 0.0005702463495660863
# newton iteration:  3
# sol_update_l2_norm:9.641663721368073e-11 	 residual l2 norm: 5.79721932657264e-10
# converged at iteration:  3
# sol_update_l2_norm:9.641663721368073e-11 	 residual l2 norm: 5.79721932657264e-10
# epoch:  25	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.001218557357788086
# ======TIME=======stiffness matrix terms time : 0.08104467391967773
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.0824739933013916
# assembling the matrix time taken:  0.00030803680419921875
# solving Ax = b time taken:  0.004907846450805664
# total size: 25 3375000 = 84375000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:7.579033089037289 	 residual l2 norm: 0.009555548116166922
# newton iteration:  2
# sol_update_l2_norm:0.0012338420052654276 	 residual l2 norm: 0.0007341227142583312
# newton iteration:  3
# sol_update_l2_norm:1.1754090520417436e-09 	 residual l2 norm: 1.908969687726208e-09
# converged at iteration:  3
# sol_update_l2_norm:1.1754090520417436e-09 	 residual l2 norm: 1.908969687726208e-09
# epoch:  26	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0011668205261230469
# ======TIME=======stiffness matrix terms time : 0.08147287368774414
# ======TIME=======neumann bd terms time : 9.5367431640625e-07
# =======> argmax subproblem time:  0.0830068588256836
# assembling the matrix time taken:  0.00029850006103515625
# solving Ax = b time taken:  0.005086660385131836
# total size: 26 3375000 = 87750000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:10.480165759279183 	 residual l2 norm: 0.012715026979323342
# newton iteration:  2
# sol_update_l2_norm:0.0005264232801313077 	 residual l2 norm: 0.0009997268673728578
# newton iteration:  3
# sol_update_l2_norm:6.079638177080237e-10 	 residual l2 norm: 3.24094846456719e-09
# converged at iteration:  3
# sol_update_l2_norm:6.079638177080237e-10 	 residual l2 norm: 3.24094846456719e-09
# epoch:  27	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0012335777282714844
# ======TIME=======stiffness matrix terms time : 0.08188819885253906
# ======TIME=======neumann bd terms time : 9.5367431640625e-07
# =======> argmax subproblem time:  0.08345532417297363
# assembling the matrix time taken:  0.0002963542938232422
# solving Ax = b time taken:  0.005260467529296875
# total size: 27 3375000 = 91125000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:18.405662267882462 	 residual l2 norm: 0.010258798724759393
# newton iteration:  2
# sol_update_l2_norm:0.00026217230880840313 	 residual l2 norm: 0.0006375189807738045
# newton iteration:  3
# sol_update_l2_norm:1.5629460340804852e-10 	 residual l2 norm: 8.071737653236454e-10
# converged at iteration:  3
# sol_update_l2_norm:1.5629460340804852e-10 	 residual l2 norm: 8.071737653236454e-10
# epoch:  28	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0012581348419189453
# ======TIME=======stiffness matrix terms time : 0.08156728744506836
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.0831451416015625
# assembling the matrix time taken:  0.0002913475036621094
# solving Ax = b time taken:  0.005427122116088867
# total size: 28 3375000 = 94500000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:3.247378758961733 	 residual l2 norm: 0.008575045767492497
# newton iteration:  2
# sol_update_l2_norm:0.00034679141223751604 	 residual l2 norm: 0.0002955654709864541
# newton iteration:  3
# sol_update_l2_norm:2.190510197421363e-10 	 residual l2 norm: 2.8098240294509927e-10
# converged at iteration:  3
# sol_update_l2_norm:2.190510197421363e-10 	 residual l2 norm: 2.8098240294509927e-10
# epoch:  29	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0011792182922363281
# ======TIME=======stiffness matrix terms time : 0.08190488815307617
# ======TIME=======neumann bd terms time : 9.5367431640625e-07
# =======> argmax subproblem time:  0.08339262008666992
# assembling the matrix time taken:  0.00029206275939941406
# solving Ax = b time taken:  0.005584716796875
# total size: 29 3375000 = 97875000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:12.570931369180121 	 residual l2 norm: 0.012928209483247488
# newton iteration:  2
# sol_update_l2_norm:0.0024490064159279 	 residual l2 norm: 0.004189572973861066
# newton iteration:  3
# sol_update_l2_norm:8.439302704701608e-09 	 residual l2 norm: 2.8145778932590572e-08
# newton iteration:  4
# sol_update_l2_norm:5.3803380239800255e-12 	 residual l2 norm: 2.618093845421617e-13
# converged at iteration:  4
# sol_update_l2_norm:5.3803380239800255e-12 	 residual l2 norm: 2.618093845421617e-13
# epoch:  30	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0012400150299072266
# ======TIME=======stiffness matrix terms time : 0.08176016807556152
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.08338761329650879
# assembling the matrix time taken:  0.00029659271240234375
# solving Ax = b time taken:  0.00577235221862793
# total size: 30 3375000 = 101250000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:6.94051461480201 	 residual l2 norm: 0.008290951203092149
# newton iteration:  2
# sol_update_l2_norm:0.0002731913542152156 	 residual l2 norm: 9.538932258249247e-05
# newton iteration:  3
# sol_update_l2_norm:1.7263718418507108e-11 	 residual l2 norm: 3.1213262015427517e-11
# converged at iteration:  3
# sol_update_l2_norm:1.7263718418507108e-11 	 residual l2 norm: 3.1213262015427517e-11
# epoch:  31	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0013000965118408203
# ======TIME=======stiffness matrix terms time : 0.08195352554321289
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.08364319801330566
# assembling the matrix time taken:  0.0002980232238769531
# solving Ax = b time taken:  0.00592350959777832
# total size: 31 3375000 = 104625000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:5.914842442866666 	 residual l2 norm: 0.008329711181692366
# newton iteration:  2
# sol_update_l2_norm:0.00023303492334746654 	 residual l2 norm: 0.0003236007630314646
# newton iteration:  3
# sol_update_l2_norm:4.607762289201111e-11 	 residual l2 norm: 2.4502245325535917e-10
# converged at iteration:  3
# sol_update_l2_norm:4.607762289201111e-11 	 residual l2 norm: 2.4502245325535917e-10
# epoch:  32	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0012462139129638672
# ======TIME=======stiffness matrix terms time : 0.08245849609375
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.08412718772888184
# assembling the matrix time taken:  0.0002982616424560547
# solving Ax = b time taken:  0.006033182144165039
# total size: 32 3375000 = 108000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:4.571828581864156 	 residual l2 norm: 0.0058645815770380725
# newton iteration:  2
# sol_update_l2_norm:0.00013175180031177073 	 residual l2 norm: 0.00018805592692631642
# newton iteration:  3
# sol_update_l2_norm:1.3030155378252171e-11 	 residual l2 norm: 5.907395553083724e-11
# converged at iteration:  3
# sol_update_l2_norm:1.3030155378252171e-11 	 residual l2 norm: 5.907395553083724e-11
# epoch:  33	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0012061595916748047
# ======TIME=======stiffness matrix terms time : 0.08188843727111816
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.08350896835327148
# assembling the matrix time taken:  0.0004115104675292969
# solving Ax = b time taken:  0.006534576416015625
# total size: 33 3375000 = 111375000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:2.1698989234111807 	 residual l2 norm: 0.002897381313568272
# newton iteration:  2
# sol_update_l2_norm:3.0943021546476536e-05 	 residual l2 norm: 1.2797901365913243e-05
# newton iteration:  3
# sol_update_l2_norm:3.0449272050867997e-12 	 residual l2 norm: 4.727648869599112e-13
# converged at iteration:  3
# sol_update_l2_norm:3.0449272050867997e-12 	 residual l2 norm: 4.727648869599112e-13
# epoch:  34	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0012781620025634766
# ======TIME=======stiffness matrix terms time : 0.08198809623718262
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.08369326591491699
# assembling the matrix time taken:  0.00029277801513671875
# solving Ax = b time taken:  0.006776094436645508
# total size: 34 3375000 = 114750000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:11.162030614038162 	 residual l2 norm: 0.0032246856981800204
# newton iteration:  2
# sol_update_l2_norm:0.0005624005690544707 	 residual l2 norm: 0.000708540570110576
# newton iteration:  3
# sol_update_l2_norm:2.719871373768717e-10 	 residual l2 norm: 7.375117988984041e-10
# converged at iteration:  3
# sol_update_l2_norm:2.719871373768717e-10 	 residual l2 norm: 7.375117988984041e-10
# epoch:  35	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.00128936767578125
# ======TIME=======stiffness matrix terms time : 0.08252096176147461
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.08423852920532227
# assembling the matrix time taken:  0.0002989768981933594
# solving Ax = b time taken:  0.0069103240966796875
# total size: 35 3375000 = 118125000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:2.2859901646309133 	 residual l2 norm: 0.002224804493186823
# newton iteration:  2
# sol_update_l2_norm:1.9718937635532293e-05 	 residual l2 norm: 9.573492627674625e-06
# newton iteration:  3
# sol_update_l2_norm:1.8387023471231417e-12 	 residual l2 norm: 9.465222368345033e-13
# converged at iteration:  3
# sol_update_l2_norm:1.8387023471231417e-12 	 residual l2 norm: 9.465222368345033e-13
# epoch:  36	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0012166500091552734
# ======TIME=======stiffness matrix terms time : 0.08280563354492188
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.08444666862487793
# assembling the matrix time taken:  0.0002856254577636719
# solving Ax = b time taken:  0.0070400238037109375
# total size: 36 3375000 = 121500000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:6.651786635259279 	 residual l2 norm: 0.002074187398352264
# newton iteration:  2
# sol_update_l2_norm:6.397769644533412e-05 	 residual l2 norm: 4.745168511559341e-05
# newton iteration:  3
# sol_update_l2_norm:4.401906811642869e-12 	 residual l2 norm: 8.227962434668337e-12
# converged at iteration:  3
# sol_update_l2_norm:4.401906811642869e-12 	 residual l2 norm: 8.227962434668337e-12
# epoch:  37	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0012395381927490234
# ======TIME=======stiffness matrix terms time : 0.08292007446289062
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.0845952033996582
# assembling the matrix time taken:  0.0002918243408203125
# solving Ax = b time taken:  0.007160186767578125
# total size: 37 3375000 = 124875000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:8.101572746618885 	 residual l2 norm: 0.0019340000150726943
# newton iteration:  2
# sol_update_l2_norm:7.064024034667717e-05 	 residual l2 norm: 7.189136745500531e-05
# newton iteration:  3
# sol_update_l2_norm:1.395975941433397e-11 	 residual l2 norm: 2.3467369879685227e-11
# converged at iteration:  3
# sol_update_l2_norm:1.395975941433397e-11 	 residual l2 norm: 2.3467369879685227e-11
# epoch:  38	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0013086795806884766
# ======TIME=======stiffness matrix terms time : 0.08266544342041016
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.08441853523254395
# assembling the matrix time taken:  0.0002875328063964844
# solving Ax = b time taken:  0.00730133056640625
# total size: 38 3375000 = 128250000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:8.886643876487012 	 residual l2 norm: 0.0020863858097546623
# newton iteration:  2
# sol_update_l2_norm:8.055285771420939e-05 	 residual l2 norm: 4.2563832581104766e-05
# newton iteration:  3
# sol_update_l2_norm:8.988625929727992e-12 	 residual l2 norm: 2.704533298234453e-12
# converged at iteration:  3
# sol_update_l2_norm:8.988625929727992e-12 	 residual l2 norm: 2.704533298234453e-12
# epoch:  39	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0012392997741699219
# ======TIME=======stiffness matrix terms time : 0.08294320106506348
# ======TIME=======neumann bd terms time : 9.5367431640625e-07
# =======> argmax subproblem time:  0.0846104621887207
# assembling the matrix time taken:  0.00029921531677246094
# solving Ax = b time taken:  0.0074312686920166016
# total size: 39 3375000 = 131625000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:5.415224975735823 	 residual l2 norm: 0.0026197238675624976
# newton iteration:  2
# sol_update_l2_norm:3.9876319369679854e-05 	 residual l2 norm: 3.661170424860262e-05
# newton iteration:  3
# sol_update_l2_norm:3.6831507851994505e-12 	 residual l2 norm: 4.050505230787901e-12
# converged at iteration:  3
# sol_update_l2_norm:3.6831507851994505e-12 	 residual l2 norm: 4.050505230787901e-12
# epoch:  40	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0012755393981933594
# ======TIME=======stiffness matrix terms time : 0.08278012275695801
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.08449292182922363
# assembling the matrix time taken:  0.0002880096435546875
# solving Ax = b time taken:  0.007569313049316406
# total size: 40 3375000 = 135000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:1.6954992932002981 	 residual l2 norm: 0.0013373013170271818
# newton iteration:  2
# sol_update_l2_norm:9.61605214092961e-06 	 residual l2 norm: 8.734927055508345e-06
# newton iteration:  3
# sol_update_l2_norm:6.317401049623733e-12 	 residual l2 norm: 2.2206456597337375e-13
# converged at iteration:  3
# sol_update_l2_norm:6.317401049623733e-12 	 residual l2 norm: 2.2206456597337375e-13
# epoch:  41	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0013256072998046875
# ======TIME=======stiffness matrix terms time : 0.08285927772521973
# ======TIME=======neumann bd terms time : 9.5367431640625e-07
# =======> argmax subproblem time:  0.08462047576904297
# assembling the matrix time taken:  0.0002892017364501953
# solving Ax = b time taken:  0.0076982975006103516
# total size: 41 3375000 = 138375000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:3.4903111589473084 	 residual l2 norm: 0.0013762480319993188
# newton iteration:  2
# sol_update_l2_norm:1.7873105359207456e-05 	 residual l2 norm: 1.1548965729363245e-05
# newton iteration:  3
# sol_update_l2_norm:9.79173658668947e-12 	 residual l2 norm: 8.911994467044626e-14
# converged at iteration:  3
# sol_update_l2_norm:9.79173658668947e-12 	 residual l2 norm: 8.911994467044626e-14
# epoch:  42	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.001264810562133789
# ======TIME=======stiffness matrix terms time : 0.08293533325195312
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.08463120460510254
# assembling the matrix time taken:  0.0003018379211425781
# solving Ax = b time taken:  0.007824897766113281
# total size: 42 3375000 = 141750000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:4.035248458653522 	 residual l2 norm: 0.0010639671650301374
# newton iteration:  2
# sol_update_l2_norm:1.841066525316462e-05 	 residual l2 norm: 5.6171760656271755e-06
# newton iteration:  3
# sol_update_l2_norm:5.702998462096238e-12 	 residual l2 norm: 4.301905250485519e-14
# converged at iteration:  3
# sol_update_l2_norm:5.702998462096238e-12 	 residual l2 norm: 4.301905250485519e-14
# epoch:  43	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0013072490692138672
# ======TIME=======stiffness matrix terms time : 0.08322906494140625
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.08497428894042969
# assembling the matrix time taken:  0.0002834796905517578
# solving Ax = b time taken:  0.007977485656738281
# total size: 43 3375000 = 145125000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:5.364669566754556 	 residual l2 norm: 0.0010988803688887954
# newton iteration:  2
# sol_update_l2_norm:2.805805870064818e-05 	 residual l2 norm: 8.180217578224827e-06
# newton iteration:  3
# sol_update_l2_norm:4.153683239458475e-12 	 residual l2 norm: 8.661284757379248e-13
# converged at iteration:  3
# sol_update_l2_norm:4.153683239458475e-12 	 residual l2 norm: 8.661284757379248e-13
# epoch:  44	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0012595653533935547
# ======TIME=======stiffness matrix terms time : 0.0833890438079834
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.08507394790649414
# assembling the matrix time taken:  0.0002894401550292969
# solving Ax = b time taken:  0.008096456527709961
# total size: 44 3375000 = 148500000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:5.191673955694366 	 residual l2 norm: 0.0009868024854069648
# newton iteration:  2
# sol_update_l2_norm:1.6967817891186264e-05 	 residual l2 norm: 7.347964752686985e-06
# newton iteration:  3
# sol_update_l2_norm:1.3354273129012727e-11 	 residual l2 norm: 1.222443943113603e-13
# converged at iteration:  3
# sol_update_l2_norm:1.3354273129012727e-11 	 residual l2 norm: 1.222443943113603e-13
# epoch:  45	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0012891292572021484
# ======TIME=======stiffness matrix terms time : 0.08361625671386719
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.08533334732055664
# assembling the matrix time taken:  0.0002970695495605469
# solving Ax = b time taken:  0.008255243301391602
# total size: 45 3375000 = 151875000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:8.791198728062007 	 residual l2 norm: 0.0009414119276109226
# newton iteration:  2
# sol_update_l2_norm:0.00011731757015881933 	 residual l2 norm: 5.090827622166927e-05
# newton iteration:  3
# sol_update_l2_norm:1.7133202777647965e-11 	 residual l2 norm: 1.7112378847808586e-11
# converged at iteration:  3
# sol_update_l2_norm:1.7133202777647965e-11 	 residual l2 norm: 1.7112378847808586e-11
# epoch:  46	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0013256072998046875
# ======TIME=======stiffness matrix terms time : 0.08392333984375
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.08571100234985352
# assembling the matrix time taken:  0.0002930164337158203
# solving Ax = b time taken:  0.008386850357055664
# total size: 46 3375000 = 155250000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:4.498346761715928 	 residual l2 norm: 0.0009274532072683032
# newton iteration:  2
# sol_update_l2_norm:1.2803708356853291e-05 	 residual l2 norm: 1.3390107205928341e-05
# newton iteration:  3
# sol_update_l2_norm:6.220474241460724e-12 	 residual l2 norm: 8.565210175053956e-13
# converged at iteration:  3
# sol_update_l2_norm:6.220474241460724e-12 	 residual l2 norm: 8.565210175053956e-13
# epoch:  47	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0012500286102294922
# ======TIME=======stiffness matrix terms time : 0.08417582511901855
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.08584928512573242
# assembling the matrix time taken:  0.00028252601623535156
# solving Ax = b time taken:  0.008581876754760742
# total size: 47 3375000 = 158625000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:4.319745309260454 	 residual l2 norm: 0.0007754163041303855
# newton iteration:  2
# sol_update_l2_norm:1.6672282725223057e-05 	 residual l2 norm: 1.5715336194915424e-05
# newton iteration:  3
# sol_update_l2_norm:1.2208977314658414e-11 	 residual l2 norm: 7.153809592904656e-13
# converged at iteration:  3
# sol_update_l2_norm:1.2208977314658414e-11 	 residual l2 norm: 7.153809592904656e-13
# epoch:  48	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.001271963119506836
# ======TIME=======stiffness matrix terms time : 0.08482122421264648
# ======TIME=======neumann bd terms time : 9.5367431640625e-07
# =======> argmax subproblem time:  0.08655261993408203
# assembling the matrix time taken:  0.00027871131896972656
# solving Ax = b time taken:  0.008723020553588867
# total size: 48 3375000 = 162000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:4.56396823047938 	 residual l2 norm: 0.0007407017138376597
# newton iteration:  2
# sol_update_l2_norm:1.389665771282829e-05 	 residual l2 norm: 6.147002396289073e-06
# newton iteration:  3
# sol_update_l2_norm:1.6188100952260999e-12 	 residual l2 norm: 1.4677288489458844e-13
# converged at iteration:  3
# sol_update_l2_norm:1.6188100952260999e-12 	 residual l2 norm: 1.4677288489458844e-13
# epoch:  49	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.00130462646484375
# ======TIME=======stiffness matrix terms time : 0.08455634117126465
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.08631038665771484
# assembling the matrix time taken:  0.0002772808074951172
# solving Ax = b time taken:  0.008905172348022461
# total size: 49 3375000 = 165375000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:2.3583040031306712 	 residual l2 norm: 0.0005979240953532809
# newton iteration:  2
# sol_update_l2_norm:5.832211497512411e-06 	 residual l2 norm: 1.3271760899904519e-06
# newton iteration:  3
# sol_update_l2_norm:2.5569994759526013e-11 	 residual l2 norm: 1.572914775443108e-13
# converged at iteration:  3
# sol_update_l2_norm:2.5569994759526013e-11 	 residual l2 norm: 1.572914775443108e-13
# epoch:  50	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0013399124145507812
# ======TIME=======stiffness matrix terms time : 0.08460187911987305
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.08615899085998535
# assembling the matrix time taken:  0.0003025531768798828
# solving Ax = b time taken:  0.00904226303100586
# total size: 50 3375000 = 168750000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:6.030419702811868 	 residual l2 norm: 0.0004214650072793105
# newton iteration:  2
# sol_update_l2_norm:1.2136238775618988e-05 	 residual l2 norm: 7.343354667801922e-06
# newton iteration:  3
# sol_update_l2_norm:4.126156432439618e-11 	 residual l2 norm: 2.443728014531624e-13
# converged at iteration:  3
# sol_update_l2_norm:4.126156432439618e-11 	 residual l2 norm: 2.443728014531624e-13
# epoch:  51	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0013065338134765625
# ======TIME=======stiffness matrix terms time : 0.08477139472961426
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.08642005920410156
# assembling the matrix time taken:  0.0002715587615966797
# solving Ax = b time taken:  0.009278059005737305
# total size: 51 3375000 = 172125000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:1.6966836015741689 	 residual l2 norm: 0.00042255487176209655
# newton iteration:  2
# sol_update_l2_norm:2.9220494084162348e-06 	 residual l2 norm: 3.215327207152974e-06
# newton iteration:  3
# sol_update_l2_norm:2.750335783969638e-11 	 residual l2 norm: 1.6572687942569649e-13
# converged at iteration:  3
# sol_update_l2_norm:2.750335783969638e-11 	 residual l2 norm: 1.6572687942569649e-13
# epoch:  52	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0013456344604492188
# ======TIME=======stiffness matrix terms time : 0.08481955528259277
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.08638262748718262
# assembling the matrix time taken:  0.0002830028533935547
# solving Ax = b time taken:  0.009401321411132812
# total size: 52 3375000 = 175500000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:2.651896057507525 	 residual l2 norm: 0.00041036182502164127
# newton iteration:  2
# sol_update_l2_norm:2.8995590727077586e-06 	 residual l2 norm: 4.119368344166475e-06
# newton iteration:  3
# sol_update_l2_norm:3.24753427511071e-11 	 residual l2 norm: 1.869403540631303e-13
# converged at iteration:  3
# sol_update_l2_norm:3.24753427511071e-11 	 residual l2 norm: 1.869403540631303e-13
# epoch:  53	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.00138092041015625
# ======TIME=======stiffness matrix terms time : 0.0842735767364502
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.08607268333435059
# assembling the matrix time taken:  0.00027108192443847656
# solving Ax = b time taken:  0.00958704948425293
# total size: 53 3375000 = 178875000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:1.8206415417562425 	 residual l2 norm: 0.0004898052961250561
# newton iteration:  2
# sol_update_l2_norm:4.0018872640028834e-06 	 residual l2 norm: 3.0914454592411283e-06
# newton iteration:  3
# sol_update_l2_norm:2.7040630511906855e-11 	 residual l2 norm: 1.5526164574552418e-13
# converged at iteration:  3
# sol_update_l2_norm:2.7040630511906855e-11 	 residual l2 norm: 1.5526164574552418e-13
# ...
# ======TIME=======f and N(u) terms time : 0.001985311508178711
# ======TIME=======stiffness matrix terms time : 0.1400601863861084
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.1422896385192871
# assembling the matrix time taken:  1.2097477912902832
# solving Ax = b time taken:  0.16356563568115234
# total size: 496 3375000 = 1674000000
# num batches:  4
# newton iteration:  1
# sol_update_l2_norm:0.38518656366575815 	 residual l2 norm: 2.7862118892777505e-07
# newton iteration:  2
# sol_update_l2_norm:4.1938294599250866e-07 	 residual l2 norm: 1.5567140077475682e-11
# newton iteration:  3
# sol_update_l2_norm:2.093132776447692e-08 	 residual l2 norm: 9.813737840807813e-14
# converged at iteration:  3
# sol_update_l2_norm:2.093132776447692e-08 	 residual l2 norm: 9.813737840807813e-14
# epoch:  497	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.00197601318359375
# ======TIME=======stiffness matrix terms time : 0.14007329940795898
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.14228487014770508
# assembling the matrix time taken:  0.0073359012603759766
# solving Ax = b time taken:  0.16643190383911133
# total size: 497 3375000 = 1677375000
# num batches:  4
# newton iteration:  1
# sol_update_l2_norm:0.21076257989771965 	 residual l2 norm: 4.282743501641655e-07
# newton iteration:  2
# sol_update_l2_norm:2.540998286502413e-07 	 residual l2 norm: 2.928057060275898e-11
# newton iteration:  3
# sol_update_l2_norm:1.1234973868136096e-08 	 residual l2 norm: 1.7498414845118554e-13
# converged at iteration:  3
# sol_update_l2_norm:1.1234973868136096e-08 	 residual l2 norm: 1.7498414845118554e-13
# epoch:  498	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0019378662109375
# ======TIME=======stiffness matrix terms time : 0.14024066925048828
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.1424121856689453
# assembling the matrix time taken:  1.2306056022644043
# solving Ax = b time taken:  0.1675128936767578
# total size: 498 3375000 = 1680750000
# num batches:  4
# newton iteration:  1
# sol_update_l2_norm:0.23845881751194042 	 residual l2 norm: 6.029955663683217e-07
# newton iteration:  2
# sol_update_l2_norm:2.0728399262525264e-06 	 residual l2 norm: 7.569062704412116e-12
# converged at iteration:  2
# sol_update_l2_norm:2.0728399262525264e-06 	 residual l2 norm: 7.569062704412116e-12
# epoch:  499	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0019156932830810547
# ======TIME=======stiffness matrix terms time : 0.1399984359741211
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.14214754104614258
# assembling the matrix time taken:  0.2134404182434082
# solving Ax = b time taken:  0.16477298736572266
# total size: 499 3375000 = 1684125000
# num batches:  4
# newton iteration:  1
# sol_update_l2_norm:0.14911183382442908 	 residual l2 norm: 2.2675881550506742e-07
# newton iteration:  2
# sol_update_l2_norm:2.4012471471954804e-07 	 residual l2 norm: 2.786121028916628e-12
# converged at iteration:  2
# sol_update_l2_norm:2.4012471471954804e-07 	 residual l2 norm: 2.786121028916628e-12
# epoch:  500	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0019123554229736328
# ======TIME=======stiffness matrix terms time : 0.14063310623168945
# ======TIME=======neumann bd terms time : 2.384185791015625e-07
# =======> argmax subproblem time:  0.14278721809387207
# assembling the matrix time taken:  0.9490208625793457
# solving Ax = b time taken:  0.17176508903503418
# total size: 500 3375000 = 1687500000
# num batches:  4
# newton iteration:  1
# sol_update_l2_norm:0.5930433231824701 	 residual l2 norm: 3.42214525861076e-07
# newton iteration:  2
# sol_update_l2_norm:1.813487008538244e-06 	 residual l2 norm: 2.7244327282959455e-10
# newton iteration:  3
# sol_update_l2_norm:6.734450758459335e-08 	 residual l2 norm: 1.0362955331857762e-13
# converged at iteration:  3
# sol_update_l2_norm:6.734450758459335e-08 	 residual l2 norm: 1.0362955331857762e-13
# epoch:  501	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0019381046295166016
# ======TIME=======stiffness matrix terms time : 0.14073562622070312
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.14293909072875977
# assembling the matrix time taken:  0.010000944137573242
# solving Ax = b time taken:  0.16662955284118652
# total size: 501 3375000 = 1690875000
# num batches:  4
# newton iteration:  1
# sol_update_l2_norm:0.5289059277603673 	 residual l2 norm: 3.343636718095784e-07
# newton iteration:  2
# sol_update_l2_norm:6.420935419071591e-07 	 residual l2 norm: 5.928327946100781e-11
# newton iteration:  3
# sol_update_l2_norm:4.194130995263151e-08 	 residual l2 norm: 1.7741377184446955e-13
# converged at iteration:  3
# sol_update_l2_norm:4.194130995263151e-08 	 residual l2 norm: 1.7741377184446955e-13
# epoch:  502	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.001971721649169922
# ======TIME=======stiffness matrix terms time : 0.1403484344482422
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.14255452156066895
# assembling the matrix time taken:  0.8894758224487305
# solving Ax = b time taken:  0.1727278232574463
# total size: 502 3375000 = 1694250000
# num batches:  4
# newton iteration:  1
# sol_update_l2_norm:0.7741889234486883 	 residual l2 norm: 7.158899478582778e-07
# newton iteration:  2
# sol_update_l2_norm:4.8399233920605215e-06 	 residual l2 norm: 1.1546932689383622e-10
# newton iteration:  3
# sol_update_l2_norm:2.6901412279007613e-08 	 residual l2 norm: 4.181924053132429e-14
# converged at iteration:  3
# sol_update_l2_norm:2.6901412279007613e-08 	 residual l2 norm: 4.181924053132429e-14
# epoch:  503	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0019054412841796875
# ======TIME=======stiffness matrix terms time : 0.14026498794555664
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.14240694046020508
# assembling the matrix time taken:  0.01045536994934082
# solving Ax = b time taken:  0.1676790714263916
# total size: 503 3375000 = 1697625000
# num batches:  4
# newton iteration:  1
# sol_update_l2_norm:0.2815175050179809 	 residual l2 norm: 2.538480380160062e-07
# newton iteration:  2
# sol_update_l2_norm:1.7446401993669512e-06 	 residual l2 norm: 3.3617542244028025e-11
# newton iteration:  3
# sol_update_l2_norm:6.804358942540884e-08 	 residual l2 norm: 1.688600902263938e-14
# converged at iteration:  3
# sol_update_l2_norm:6.804358942540884e-08 	 residual l2 norm: 1.688600902263938e-14
# epoch:  504	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0019664764404296875
# ======TIME=======stiffness matrix terms time : 0.14064359664916992
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.1428370475769043
# assembling the matrix time taken:  1.2474827766418457
# solving Ax = b time taken:  0.16632556915283203
# total size: 504 3375000 = 1701000000
# num batches:  4
# newton iteration:  1
# sol_update_l2_norm:0.8680581560585184 	 residual l2 norm: 9.548712917936473e-07
# newton iteration:  2
# sol_update_l2_norm:1.294970342277314e-06 	 residual l2 norm: 2.1362702425087031e-10
# newton iteration:  3
# sol_update_l2_norm:2.973215513650971e-08 	 residual l2 norm: 3.930535954429633e-14
# converged at iteration:  3
# sol_update_l2_norm:2.973215513650971e-08 	 residual l2 norm: 3.930535954429633e-14
# epoch:  505	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.001978635787963867
# ======TIME=======stiffness matrix terms time : 0.14108562469482422
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.14330005645751953
# assembling the matrix time taken:  0.17475295066833496
# solving Ax = b time taken:  0.1668088436126709
# total size: 505 3375000 = 1704375000
# num batches:  4
# newton iteration:  1
# sol_update_l2_norm:0.2753124145455007 	 residual l2 norm: 1.5720001816561425e-07
# newton iteration:  2
# sol_update_l2_norm:3.068043362549885e-07 	 residual l2 norm: 1.3322570326290519e-11
# newton iteration:  3
# sol_update_l2_norm:2.716031468244731e-07 	 residual l2 norm: 2.989801988976111e-14
# converged at iteration:  3
# sol_update_l2_norm:2.716031468244731e-07 	 residual l2 norm: 2.989801988976111e-14
# epoch:  506	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.002028226852416992
# ======TIME=======stiffness matrix terms time : 0.14086079597473145
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.14317679405212402
# assembling the matrix time taken:  1.9386425018310547
# solving Ax = b time taken:  0.18884730339050293
# total size: 506 3375000 = 1707750000
# num batches:  4
# newton iteration:  1
# sol_update_l2_norm:0.16534438880273564 	 residual l2 norm: 3.9268331088797755e-07
# newton iteration:  2
# sol_update_l2_norm:4.850657864369423e-07 	 residual l2 norm: 1.86726557220984e-11
# newton iteration:  3
# sol_update_l2_norm:9.87771698989709e-08 	 residual l2 norm: 9.970517421120638e-14
# converged at iteration:  3
# sol_update_l2_norm:9.87771698989709e-08 	 residual l2 norm: 9.970517421120638e-14
# epoch:  507	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0019540786743164062
# ======TIME=======stiffness matrix terms time : 0.14055514335632324
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.14275527000427246
# assembling the matrix time taken:  0.007580995559692383
# solving Ax = b time taken:  0.16993927955627441
# total size: 507 3375000 = 1711125000
# num batches:  4
# newton iteration:  1
# sol_update_l2_norm:0.2364744877879217 	 residual l2 norm: 8.779375707311647e-07
# newton iteration:  2
# sol_update_l2_norm:5.403890951720447e-07 	 residual l2 norm: 1.4245212769647895e-11
# newton iteration:  3
# sol_update_l2_norm:2.083440590134864e-07 	 residual l2 norm: 3.687500194278351e-14
# converged at iteration:  3
# sol_update_l2_norm:2.083440590134864e-07 	 residual l2 norm: 3.687500194278351e-14
# epoch:  508	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0019373893737792969
# ======TIME=======stiffness matrix terms time : 0.14101314544677734
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.14321684837341309
# assembling the matrix time taken:  1.95249342918396
# solving Ax = b time taken:  0.17929768562316895
# total size: 508 3375000 = 1714500000
# num batches:  4
# newton iteration:  1
# sol_update_l2_norm:0.4077577486765035 	 residual l2 norm: 5.958264146267986e-07
# newton iteration:  2
# sol_update_l2_norm:6.467292503231518e-07 	 residual l2 norm: 4.850753872699378e-11
# newton iteration:  3
# sol_update_l2_norm:1.1800306243038864e-07 	 residual l2 norm: 8.442051883124526e-14
# converged at iteration:  3
# sol_update_l2_norm:1.1800306243038864e-07 	 residual l2 norm: 8.442051883124526e-14
# epoch:  509	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0019412040710449219
# ======TIME=======stiffness matrix terms time : 0.1412200927734375
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.14339542388916016
# assembling the matrix time taken:  0.007817506790161133
# solving Ax = b time taken:  0.17054438591003418
# total size: 509 3375000 = 1717875000
# num batches:  4
# newton iteration:  1
# sol_update_l2_norm:0.2559563785031654 	 residual l2 norm: 2.61163571186749e-07
# newton iteration:  2
# sol_update_l2_norm:5.967579351115046e-07 	 residual l2 norm: 8.603880045404949e-12
# converged at iteration:  2
# sol_update_l2_norm:5.967579351115046e-07 	 residual l2 norm: 8.603880045404949e-12
# epoch:  510	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.002055644989013672
# ======TIME=======stiffness matrix terms time : 0.14183425903320312
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.14415454864501953
# assembling the matrix time taken:  1.247556209564209
# solving Ax = b time taken:  0.16974759101867676
# total size: 510 3375000 = 1721250000
# num batches:  4
# newton iteration:  1
# sol_update_l2_norm:0.24013450934878455 	 residual l2 norm: 9.596207966042902e-07
# newton iteration:  2
# sol_update_l2_norm:2.2263508378096437e-07 	 residual l2 norm: 1.6764091636431637e-11
# newton iteration:  3
# sol_update_l2_norm:3.026957491409019e-07 	 residual l2 norm: 3.592595719997152e-14
# converged at iteration:  3
# sol_update_l2_norm:3.026957491409019e-07 	 residual l2 norm: 3.592595719997152e-14
# epoch:  511	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.0019304752349853516
# ======TIME=======stiffness matrix terms time : 0.14105749130249023
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.1432332992553711
# assembling the matrix time taken:  0.12003111839294434
# solving Ax = b time taken:  0.17013120651245117
# total size: 511 3375000 = 1724625000
# num batches:  4
# newton iteration:  1
# sol_update_l2_norm:0.7217484862527337 	 residual l2 norm: 2.476622271991478e-07
# newton iteration:  2
# sol_update_l2_norm:1.0870842916698197e-06 	 residual l2 norm: 1.7451898564314002e-10
# newton iteration:  3
# sol_update_l2_norm:7.568444953696664e-08 	 residual l2 norm: 3.2997529372889755e-14
# converged at iteration:  3
# sol_update_l2_norm:7.568444953696664e-08 	 residual l2 norm: 3.2997529372889755e-14
# epoch:  512	======argmax subproblem:f and N(u) terms, num batches:  4
# ======TIME=======f and N(u) terms time : 0.001958608627319336
# ======TIME=======stiffness matrix terms time : 0.14185190200805664
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.1440412998199463
# assembling the matrix time taken:  1.2589313983917236
# solving Ax = b time taken:  0.17285823822021484
# total size: 512 3375000 = 1728000000
# num batches:  4
# newton iteration:  1
# sol_update_l2_norm:0.1892991484196931 	 residual l2 norm: 3.817891954366713e-07
# newton iteration:  2
# sol_update_l2_norm:2.0991347113311697e-07 	 residual l2 norm: 1.872907133942032e-11
# newton iteration:  3
# sol_update_l2_norm:2.3246417744548868e-07 	 residual l2 norm: 1.0401682486393903e-13
# converged at iteration:  3
# sol_update_l2_norm:2.3246417744548868e-07 	 residual l2 norm: 1.0401682486393903e-13
# time taken:  1360.4073040485382
# neuron num 		 error 		 order
# 4 		 0.356994 		 * 		 3.327072 		 *
#
# 8 		 0.334854 		 0.092365 		 3.148829 		 0.079438
#
# 16 		 0.097526 		 1.779674 		 1.550509 		 1.022074
#
# 32 		 0.026739 		 1.866866 		 0.559124 		 1.471500
#
# 64 		 0.004045 		 2.724622 		 0.117953 		 2.244955
#
# 128 		 0.000847 		 2.256309 		 0.033446 		 1.818321
#
# 256 		 0.000329 		 1.362232 		 0.017239 		 0.956180
#
# 512 		 0.000121 		 1.443023 		 0.008322 		 1.050725
#
# neuron num  & 	 $\|u-u_n \|_{L^2}$ & 	 order $O(n^{-1.67})$ & 	 $ | u -u_n |_{H^1}$ & 	 order $O(n^{-1.33})$ \\ \hline \hline
# 4 		 & 0.356994 &		 * & 		 3.327072 & 		 *  \\ \hline
#
# 8 		 &  3.349e-01 &  		 0.09 &  		 3.149e+00 &  		 0.08 \\ \hline
#
# 16 		 &  9.753e-02 &  		 1.78 &  		 1.551e+00 &  		 1.02 \\ \hline
#
# 32 		 &  2.674e-02 &  		 1.87 &  		 5.591e-01 &  		 1.47 \\ \hline
#
# 64 		 &  4.045e-03 &  		 2.72 &  		 1.180e-01 &  		 2.24 \\ \hline
#
# 128 		 &  8.467e-04 &  		 2.26 &  		 3.345e-02 &  		 1.82 \\ \hline
#
# 256 		 &  3.293e-04 &  		 1.36 &  		 1.724e-02 &  		 0.96 \\ \hline
#
# 512 		 &  1.211e-04 &  		 1.44 &  		 8.322e-03 &  		 1.05 \\ \hline

# %% [markdown]
# ## Gabor function

# %%
## Gabor function test 
freq = 4 
sigma = 0.15 
def gaussian(x):
    return torch.exp(-torch.sum( (x - 0.5)**2,dim=1,keepdim=True)/(2 *sigma**2) ) 
def gaussian_grad_1(x):
    return  gaussian(x) * (- (x[:,0:1] - 0.5)/(sigma**2) ) 
def gaussian_grad_2(x):
    return  gaussian(x) * (- (x[:,1:2] - 0.5)/(sigma**2) ) 
def gaussian_grad_3(x):
    return  gaussian(x) * (- (x[:,2:3] - 0.5)/(sigma**2) ) 

def u_exact(x):
    return gaussian(x) * torch.cos(2*pi*freq*x[:,0:1]) 
def alpha(x): 
    return torch.ones(x.size(0),1).to(device)

def u_grad_1(x):
    return  torch.cos(2*pi*freq*x[:,0:1]) *gaussian_grad_1(x) \
            - 2*pi*freq * torch.sin(2*pi*freq*x[:,0:1]) * gaussian(x) 
def u_grad_2(x):
    return torch.cos(2*pi*freq*x[:,0:1]) * gaussian_grad_2(x)
def u_grad_3(x):
    return  torch.cos(2*pi*freq*x[:,0:1]) * gaussian_grad_3(x)

def u_exact_grad():
    d = 3 
    def u_grad_1(x):
        return  torch.cos(2*pi*freq*x[:,0:1]) *gaussian_grad_1(x) \
                - 2*pi*freq * torch.sin(2*pi*freq*x[:,0:1]) * gaussian(x) 
    def u_grad_2(x):
        return torch.cos(2*pi*freq*x[:,0:1]) * gaussian_grad_2(x)
    def u_grad_3(x):
        return  torch.cos(2*pi*freq*x[:,0:1]) * gaussian_grad_3(x)

    u_grad=[u_grad_1, u_grad_2,u_grad_3] 
    return u_grad

def laplace_u_exact(x):
    return - 2*pi*freq * torch.sin(2*pi*freq*x[:,0:1]) *gaussian_grad_1(x) \
            + torch.cos(2*pi*freq*x[:,0:1])*( gaussian(x) * ( ((x[:,0:1] - 0.5)/(sigma**2))**2 -1/(sigma**2))  ) \
            -( (2*pi*freq)**2 * torch.cos(2*pi*freq*x[:,0:1]) * gaussian(x) + (2*pi*freq)*torch.sin(2*pi*freq*x[:,0:1]) * gaussian_grad_1(x) ) \
            + torch.cos(2*pi*freq*x[:,0:1]) * (gaussian(x) * ( ((x[:,1:2] - 0.5)/(sigma**2))**2 -1/(sigma**2) )  ) \
            + torch.cos(2*pi*freq*x[:,0:1]) * ( gaussian(x) * ( ((x[:,2:3] - 0.5)/(sigma**2))**2 -1/(sigma**2) )   ) \

def target(x):
    return - laplace_u_exact(x) + nonlinear(u_exact(x)) 

def g_N(dim):
    u_grad = u_exact_grad() 
    bcs_N = []
    for i in range(dim):
        bcs_N.append((i, u_grad[i]))
    return bcs_N

def u_exact_approx(x):
    return 0.99 * u_exact(x)

def rhs(x):
    return  -laplace_u_exact(x) + nonlinear(u_exact(x)) 


dim = 3 
function_name = "gabor-m4" 
filename_write = "data/3DCGA-{}-order.txt".format(function_name)
Nx = 50
order = 2 
f_write = open(filename_write, "a")
f_write.write("Numerical integration Nx: {}, order: {} \n".format(Nx, order))
f_write.close() 
save = True 
write2file = True 
memory = 2**29 

for N_list in [[2**3,2**3,2**3]]: # ,[2**6,2**6],[2**7,2**7] 
    f_write = open(filename_write, "a")
    my_model = None 
    exponent = 10  
    num_epochs = 2**exponent
    plot_freq = num_epochs 
    N = np.prod(N_list)
    relu_k = 3
    err_QMC2, err_h10, my_model = CGANonlinearPoissonReLU3D(my_model,rhs,alpha, u_exact, u_exact_grad,g_N,\
                                        N_list,num_epochs,plot_freq, Nx, order, k = relu_k, \
                                        rand_deter = 'rand', linear_solver = "direct",memory = memory)

    if save: 
        folder = 'data/'

        filename = folder + 'errl2_OGA_3D_{}_relu_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,relu_k,neuron_num,N)
        torch.save(err_QMC2,filename) 
        filename = folder + 'errh10_OGA_3D_{}_relu_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,relu_k,neuron_num,N)
        torch.save(err_h10,filename) 
        filename = folder + 'model_OGA_3D_{}_relu_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,relu_k,neuron_num,N)
        torch.save(my_model.state_dict(),filename)

    show_convergence_order2(err_QMC2,err_h10,exponent,N,filename_write,write2file = write2file)
    show_convergence_order_latex2(err_QMC2,err_h10,exponent,k =relu_k,d = dim)
# Out:
# using linear solver:  direct
# epoch:  1	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0011930465698242188
# ======TIME=======stiffness matrix terms time : 7.152557373046875e-07
# ======TIME=======neumann bd terms time : 0.0018649101257324219
# =======> argmax subproblem time:  0.003202199935913086
# total size: 1 1000000 = 1000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:8.261120853651622e-05 	 residual l2 norm: 0.04028445449785256
# newton iteration:  2
# sol_update_l2_norm:2.9317167458488986e-11 	 residual l2 norm: 1.4296188621809591e-08
# converged at iteration:  2
# sol_update_l2_norm:2.9317167458488986e-11 	 residual l2 norm: 1.4296188621809591e-08
# epoch:  2	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.001280069351196289
# ======TIME=======stiffness matrix terms time : 0.02327561378479004
# ======TIME=======neumann bd terms time : 0.001840353012084961
# =======> argmax subproblem time:  0.026538372039794922
# total size: 2 1000000 = 2000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:7.912884458315908e-05 	 residual l2 norm: 0.03708329766003565
# newton iteration:  2
# sol_update_l2_norm:6.204692166819347e-11 	 residual l2 norm: 1.2330741112958133e-08
# converged at iteration:  2
# sol_update_l2_norm:6.204692166819347e-11 	 residual l2 norm: 1.2330741112958133e-08
# epoch:  3	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0013015270233154297
# ======TIME=======stiffness matrix terms time : 0.023428916931152344
# ======TIME=======neumann bd terms time : 0.001844644546508789
# =======> argmax subproblem time:  0.026714324951171875
# assembling the matrix time taken:  0.00016546249389648438
# solving Ax = b time taken:  0.0004603862762451172
# total size: 3 1000000 = 3000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.00018725543169322045 	 residual l2 norm: 0.013147345848946612
# newton iteration:  2
# sol_update_l2_norm:2.7026865507548925e-12 	 residual l2 norm: 3.8605195641830223e-10
# converged at iteration:  2
# sol_update_l2_norm:2.7026865507548925e-12 	 residual l2 norm: 3.8605195641830223e-10
# epoch:  4	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.00130462646484375
# ======TIME=======stiffness matrix terms time : 0.022466659545898438
# ======TIME=======neumann bd terms time : 0.0018563270568847656
# =======> argmax subproblem time:  0.025762081146240234
# assembling the matrix time taken:  0.00016808509826660156
# solving Ax = b time taken:  0.0004775524139404297
# total size: 4 1000000 = 4000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.00014872366483884461 	 residual l2 norm: 0.00528023647903024
# newton iteration:  2
# sol_update_l2_norm:1.6138638060961752e-12 	 residual l2 norm: 3.0297697907959397e-10
# converged at iteration:  2
# sol_update_l2_norm:1.6138638060961752e-12 	 residual l2 norm: 3.0297697907959397e-10
# epoch:  5	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012934207916259766
# ======TIME=======stiffness matrix terms time : 0.022487163543701172
# ======TIME=======neumann bd terms time : 0.001844167709350586
# =======> argmax subproblem time:  0.025758981704711914
# assembling the matrix time taken:  0.00016570091247558594
# solving Ax = b time taken:  0.0005476474761962891
# total size: 5 1000000 = 5000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.00017428131236341346 	 residual l2 norm: 0.002959576367084424
# newton iteration:  2
# sol_update_l2_norm:2.3424564547816077e-12 	 residual l2 norm: 3.2595302382866456e-10
# converged at iteration:  2
# sol_update_l2_norm:2.3424564547816077e-12 	 residual l2 norm: 3.2595302382866456e-10
# epoch:  6	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0013108253479003906
# ======TIME=======stiffness matrix terms time : 0.02251577377319336
# ======TIME=======neumann bd terms time : 0.0018396377563476562
# =======> argmax subproblem time:  0.025800466537475586
# assembling the matrix time taken:  0.00017642974853515625
# solving Ax = b time taken:  0.0005588531494140625
# total size: 6 1000000 = 6000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.10326723612931603 	 residual l2 norm: 0.0014393578132333646
# newton iteration:  2
# sol_update_l2_norm:2.9709956104292946e-09 	 residual l2 norm: 1.704519868975281e-08
# newton iteration:  3
# sol_update_l2_norm:1.9544929892642512e-14 	 residual l2 norm: 1.9941864568128505e-14
# converged at iteration:  3
# sol_update_l2_norm:1.9544929892642512e-14 	 residual l2 norm: 1.9941864568128505e-14
# epoch:  7	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012898445129394531
# ======TIME=======stiffness matrix terms time : 0.022553205490112305
# ======TIME=======neumann bd terms time : 0.0018601417541503906
# =======> argmax subproblem time:  0.025837182998657227
# assembling the matrix time taken:  0.00017762184143066406
# solving Ax = b time taken:  0.0006155967712402344
# total size: 7 1000000 = 7000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.01109723939665823 	 residual l2 norm: 0.01259242690402368
# newton iteration:  2
# sol_update_l2_norm:2.098081573740484e-09 	 residual l2 norm: 1.1598678108643556e-08
# newton iteration:  3
# sol_update_l2_norm:2.985371457000741e-14 	 residual l2 norm: 3.4930775150004894e-14
# converged at iteration:  3
# sol_update_l2_norm:2.985371457000741e-14 	 residual l2 norm: 3.4930775150004894e-14
# epoch:  8	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0013089179992675781
# ======TIME=======stiffness matrix terms time : 0.022548675537109375
# ======TIME=======neumann bd terms time : 0.002244710922241211
# =======> argmax subproblem time:  0.02634286880493164
# assembling the matrix time taken:  0.00016689300537109375
# solving Ax = b time taken:  0.0006754398345947266
# total size: 8 1000000 = 8000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.017964047514836174 	 residual l2 norm: 0.011110583740506164
# newton iteration:  2
# sol_update_l2_norm:1.780673648070342e-09 	 residual l2 norm: 5.6206097128093145e-09
# newton iteration:  3
# sol_update_l2_norm:3.742983364761447e-14 	 residual l2 norm: 2.1216742322905258e-14
# converged at iteration:  3
# sol_update_l2_norm:3.742983364761447e-14 	 residual l2 norm: 2.1216742322905258e-14
# epoch:  9	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0013093948364257812
# ======TIME=======stiffness matrix terms time : 0.022609472274780273
# ======TIME=======neumann bd terms time : 0.0018773078918457031
# =======> argmax subproblem time:  0.02593541145324707
# assembling the matrix time taken:  0.000171661376953125
# solving Ax = b time taken:  0.0007126331329345703
# total size: 9 1000000 = 9000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.0046748542633552855 	 residual l2 norm: 0.007561760565029316
# newton iteration:  2
# sol_update_l2_norm:6.967535111709061e-10 	 residual l2 norm: 4.032272762007782e-09
# newton iteration:  3
# sol_update_l2_norm:2.420737847601462e-14 	 residual l2 norm: 1.736943317576311e-14
# converged at iteration:  3
# sol_update_l2_norm:2.420737847601462e-14 	 residual l2 norm: 1.736943317576311e-14
# epoch:  10	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012998580932617188
# ======TIME=======stiffness matrix terms time : 0.022577285766601562
# ======TIME=======neumann bd terms time : 0.0018553733825683594
# =======> argmax subproblem time:  0.02586674690246582
# assembling the matrix time taken:  0.00017380714416503906
# solving Ax = b time taken:  0.0007660388946533203
# total size: 10 1000000 = 10000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.015538537010468515 	 residual l2 norm: 0.010681550362892034
# newton iteration:  2
# sol_update_l2_norm:1.299064451483482e-09 	 residual l2 norm: 7.545532232199756e-09
# newton iteration:  3
# sol_update_l2_norm:5.4789876516926967e-14 	 residual l2 norm: 2.5068179257629726e-14
# converged at iteration:  3
# sol_update_l2_norm:5.4789876516926967e-14 	 residual l2 norm: 2.5068179257629726e-14
# epoch:  11	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012965202331542969
# ======TIME=======stiffness matrix terms time : 0.022591829299926758
# ======TIME=======neumann bd terms time : 0.0019919872283935547
# =======> argmax subproblem time:  0.026047945022583008
# assembling the matrix time taken:  0.0001647472381591797
# solving Ax = b time taken:  0.0008192062377929688
# total size: 11 1000000 = 11000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.02361298590183595 	 residual l2 norm: 0.0064676930934478155
# newton iteration:  2
# sol_update_l2_norm:3.884801867491346e-09 	 residual l2 norm: 8.472795416687486e-09
# newton iteration:  3
# sol_update_l2_norm:8.519161242236224e-14 	 residual l2 norm: 2.6292058810999503e-14
# converged at iteration:  3
# sol_update_l2_norm:8.519161242236224e-14 	 residual l2 norm: 2.6292058810999503e-14
# epoch:  12	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0013079643249511719
# ======TIME=======stiffness matrix terms time : 0.02259516716003418
# ======TIME=======neumann bd terms time : 0.0018534660339355469
# =======> argmax subproblem time:  0.025888919830322266
# assembling the matrix time taken:  0.0001659393310546875
# solving Ax = b time taken:  0.0008437633514404297
# total size: 12 1000000 = 12000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.06358019256416596 	 residual l2 norm: 0.003957361561096925
# newton iteration:  2
# sol_update_l2_norm:4.235794273595713e-09 	 residual l2 norm: 1.0728029043753773e-08
# newton iteration:  3
# sol_update_l2_norm:1.04806531686332e-12 	 residual l2 norm: 4.129913415247539e-14
# converged at iteration:  3
# sol_update_l2_norm:1.04806531686332e-12 	 residual l2 norm: 4.129913415247539e-14
# epoch:  13	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012955665588378906
# ======TIME=======stiffness matrix terms time : 0.02267742156982422
# ======TIME=======neumann bd terms time : 0.001861572265625
# =======> argmax subproblem time:  0.025966882705688477
# assembling the matrix time taken:  0.00016307830810546875
# solving Ax = b time taken:  0.0009007453918457031
# total size: 13 1000000 = 13000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.17670496170267716 	 residual l2 norm: 0.0035608140069653786
# newton iteration:  2
# sol_update_l2_norm:6.354613087090283e-09 	 residual l2 norm: 1.81189011786466e-08
# newton iteration:  3
# sol_update_l2_norm:1.3654820850900359e-12 	 residual l2 norm: 2.92705738762263e-14
# converged at iteration:  3
# sol_update_l2_norm:1.3654820850900359e-12 	 residual l2 norm: 2.92705738762263e-14
# epoch:  14	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012896060943603516
# ======TIME=======stiffness matrix terms time : 0.022739410400390625
# ======TIME=======neumann bd terms time : 0.001970529556274414
# =======> argmax subproblem time:  0.026160240173339844
# assembling the matrix time taken:  0.000164031982421875
# solving Ax = b time taken:  0.0009589195251464844
# total size: 14 1000000 = 14000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.10598558412069295 	 residual l2 norm: 0.0036832693109170866
# newton iteration:  2
# sol_update_l2_norm:1.1954838659841834e-08 	 residual l2 norm: 4.5085242085870904e-08
# newton iteration:  3
# sol_update_l2_norm:6.879954038522528e-13 	 residual l2 norm: 3.1038590515205336e-14
# converged at iteration:  3
# sol_update_l2_norm:6.879954038522528e-13 	 residual l2 norm: 3.1038590515205336e-14
# epoch:  15	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0013010501861572266
# ======TIME=======stiffness matrix terms time : 0.02268671989440918
# ======TIME=======neumann bd terms time : 0.0018475055694580078
# =======> argmax subproblem time:  0.025969266891479492
# assembling the matrix time taken:  0.00018596649169921875
# solving Ax = b time taken:  0.0009627342224121094
# total size: 15 1000000 = 15000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.23310571678947087 	 residual l2 norm: 0.0037802617961453337
# newton iteration:  2
# sol_update_l2_norm:9.190217274244595e-09 	 residual l2 norm: 1.2261233298438714e-08
# newton iteration:  3
# sol_update_l2_norm:8.25171983402912e-13 	 residual l2 norm: 2.0886969808939775e-14
# converged at iteration:  3
# sol_update_l2_norm:8.25171983402912e-13 	 residual l2 norm: 2.0886969808939775e-14
# epoch:  16	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.001294851303100586
# ======TIME=======stiffness matrix terms time : 0.022735595703125
# ======TIME=======neumann bd terms time : 0.0018315315246582031
# =======> argmax subproblem time:  0.02599191665649414
# assembling the matrix time taken:  0.00016260147094726562
# solving Ax = b time taken:  0.0010592937469482422
# total size: 16 1000000 = 16000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.05311384073476879 	 residual l2 norm: 0.0034609433653475935
# newton iteration:  2
# sol_update_l2_norm:4.685830673345937e-09 	 residual l2 norm: 1.2792020413325696e-08
# newton iteration:  3
# sol_update_l2_norm:3.6285542150550246e-13 	 residual l2 norm: 2.3665749808784686e-14
# converged at iteration:  3
# sol_update_l2_norm:3.6285542150550246e-13 	 residual l2 norm: 2.3665749808784686e-14
# epoch:  17	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012879371643066406
# ======TIME=======stiffness matrix terms time : 0.022713899612426758
# ======TIME=======neumann bd terms time : 0.0018417835235595703
# =======> argmax subproblem time:  0.025976181030273438
# assembling the matrix time taken:  0.00016808509826660156
# solving Ax = b time taken:  0.0011353492736816406
# total size: 17 1000000 = 17000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.09849893710356078 	 residual l2 norm: 0.002167785544823493
# newton iteration:  2
# sol_update_l2_norm:8.110476517932095e-09 	 residual l2 norm: 1.1891169936899584e-08
# newton iteration:  3
# sol_update_l2_norm:3.0547648078978237e-12 	 residual l2 norm: 5.019324159948566e-14
# converged at iteration:  3
# sol_update_l2_norm:3.0547648078978237e-12 	 residual l2 norm: 5.019324159948566e-14
# epoch:  18	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012907981872558594
# ======TIME=======stiffness matrix terms time : 0.022790193557739258
# ======TIME=======neumann bd terms time : 0.0018475055694580078
# =======> argmax subproblem time:  0.026056766510009766
# assembling the matrix time taken:  0.00016450881958007812
# solving Ax = b time taken:  0.0011701583862304688
# total size: 18 1000000 = 18000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.367835832391612 	 residual l2 norm: 0.0017506072325901279
# newton iteration:  2
# sol_update_l2_norm:3.939139701539532e-08 	 residual l2 norm: 2.1940843794948535e-08
# newton iteration:  3
# sol_update_l2_norm:1.3682699430288796e-12 	 residual l2 norm: 5.0019451801459066e-14
# converged at iteration:  3
# sol_update_l2_norm:1.3682699430288796e-12 	 residual l2 norm: 5.0019451801459066e-14
# epoch:  19	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012955665588378906
# ======TIME=======stiffness matrix terms time : 0.0227968692779541
# ======TIME=======neumann bd terms time : 0.0018460750579833984
# =======> argmax subproblem time:  0.026072263717651367
# assembling the matrix time taken:  0.00016021728515625
# solving Ax = b time taken:  0.0012447834014892578
# total size: 19 1000000 = 19000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.4939302374983418 	 residual l2 norm: 0.004224752233647905
# newton iteration:  2
# sol_update_l2_norm:6.465694657104704e-08 	 residual l2 norm: 4.6200312787546753e-08
# newton iteration:  3
# sol_update_l2_norm:1.3104899159925247e-12 	 residual l2 norm: 2.9588232564024036e-14
# converged at iteration:  3
# sol_update_l2_norm:1.3104899159925247e-12 	 residual l2 norm: 2.9588232564024036e-14
# epoch:  20	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012960433959960938
# ======TIME=======stiffness matrix terms time : 0.022775650024414062
# ======TIME=======neumann bd terms time : 0.0018351078033447266
# =======> argmax subproblem time:  0.02604079246520996
# assembling the matrix time taken:  0.00016045570373535156
# solving Ax = b time taken:  0.0012755393981933594
# total size: 20 1000000 = 20000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.6595403130011882 	 residual l2 norm: 0.005575446555022935
# newton iteration:  2
# sol_update_l2_norm:1.0355221678587024e-07 	 residual l2 norm: 1.2004064569328606e-07
# newton iteration:  3
# sol_update_l2_norm:2.7059115035981833e-12 	 residual l2 norm: 3.5482419883973704e-14
# converged at iteration:  3
# sol_update_l2_norm:2.7059115035981833e-12 	 residual l2 norm: 3.5482419883973704e-14
# epoch:  21	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.00128936767578125
# ======TIME=======stiffness matrix terms time : 0.02279186248779297
# ======TIME=======neumann bd terms time : 0.0018515586853027344
# =======> argmax subproblem time:  0.0260617733001709
# assembling the matrix time taken:  0.00016880035400390625
# solving Ax = b time taken:  0.0013074874877929688
# total size: 21 1000000 = 21000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.2834853754138139 	 residual l2 norm: 0.0034129398699098536
# newton iteration:  2
# sol_update_l2_norm:6.78699607445259e-08 	 residual l2 norm: 3.328246668161556e-08
# newton iteration:  3
# sol_update_l2_norm:2.7002449660480606e-12 	 residual l2 norm: 4.960733250850487e-14
# converged at iteration:  3
# sol_update_l2_norm:2.7002449660480606e-12 	 residual l2 norm: 4.960733250850487e-14
# epoch:  22	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0013017654418945312
# ======TIME=======stiffness matrix terms time : 0.02285003662109375
# ======TIME=======neumann bd terms time : 0.0018460750579833984
# =======> argmax subproblem time:  0.026127099990844727
# assembling the matrix time taken:  0.0001590251922607422
# solving Ax = b time taken:  0.0013725757598876953
# total size: 22 1000000 = 22000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:7.87725107264407 	 residual l2 norm: 0.002095811165132328
# newton iteration:  2
# sol_update_l2_norm:8.752495252557779e-06 	 residual l2 norm: 6.7996151446311505e-06
# newton iteration:  3
# sol_update_l2_norm:3.6533437017111383e-11 	 residual l2 norm: 7.343389094428536e-14
# converged at iteration:  3
# sol_update_l2_norm:3.6533437017111383e-11 	 residual l2 norm: 7.343389094428536e-14
# epoch:  23	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012929439544677734
# ======TIME=======stiffness matrix terms time : 0.022870540618896484
# ======TIME=======neumann bd terms time : 0.0018229484558105469
# =======> argmax subproblem time:  0.02611708641052246
# assembling the matrix time taken:  0.00016117095947265625
# solving Ax = b time taken:  0.0014314651489257812
# total size: 23 1000000 = 23000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:2.6737275949151686 	 residual l2 norm: 0.007864405164956114
# newton iteration:  2
# sol_update_l2_norm:1.7225980202012712e-06 	 residual l2 norm: 5.608698365802487e-07
# newton iteration:  3
# sol_update_l2_norm:8.51405304916161e-12 	 residual l2 norm: 8.834745958134643e-14
# converged at iteration:  3
# sol_update_l2_norm:8.51405304916161e-12 	 residual l2 norm: 8.834745958134643e-14
# epoch:  24	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012903213500976562
# ======TIME=======stiffness matrix terms time : 0.022943735122680664
# ======TIME=======neumann bd terms time : 0.0019235610961914062
# =======> argmax subproblem time:  0.026304006576538086
# assembling the matrix time taken:  0.00016117095947265625
# solving Ax = b time taken:  0.0014882087707519531
# total size: 24 1000000 = 24000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:3.545316152555411 	 residual l2 norm: 0.003436103627623821
# newton iteration:  2
# sol_update_l2_norm:3.3204654765427532e-06 	 residual l2 norm: 3.900238588414563e-06
# newton iteration:  3
# sol_update_l2_norm:2.0065433237190243e-11 	 residual l2 norm: 1.4174796418210016e-13
# converged at iteration:  3
# sol_update_l2_norm:2.0065433237190243e-11 	 residual l2 norm: 1.4174796418210016e-13
# epoch:  25	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012822151184082031
# ======TIME=======stiffness matrix terms time : 0.022927522659301758
# ======TIME=======neumann bd terms time : 0.0018558502197265625
# =======> argmax subproblem time:  0.026199817657470703
# assembling the matrix time taken:  0.00016307830810546875
# solving Ax = b time taken:  0.0015118122100830078
# total size: 25 1000000 = 25000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:2.9824424505862246 	 residual l2 norm: 0.003238655018472678
# newton iteration:  2
# sol_update_l2_norm:2.5629513558650164e-06 	 residual l2 norm: 2.8449695938081397e-06
# newton iteration:  3
# sol_update_l2_norm:9.800463438821098e-11 	 residual l2 norm: 1.442503943011864e-13
# converged at iteration:  3
# sol_update_l2_norm:9.800463438821098e-11 	 residual l2 norm: 1.442503943011864e-13
# epoch:  26	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012843608856201172
# ======TIME=======stiffness matrix terms time : 0.02295851707458496
# ======TIME=======neumann bd terms time : 0.0018379688262939453
# =======> argmax subproblem time:  0.026210784912109375
# assembling the matrix time taken:  0.00016021728515625
# solving Ax = b time taken:  0.0015819072723388672
# total size: 26 1000000 = 26000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:8.327077502336886 	 residual l2 norm: 0.0015743401860868868
# newton iteration:  2
# sol_update_l2_norm:5.116490003402935e-06 	 residual l2 norm: 1.2248852248791201e-06
# newton iteration:  3
# sol_update_l2_norm:1.5726079326694475e-10 	 residual l2 norm: 1.2284689390774674e-13
# converged at iteration:  3
# sol_update_l2_norm:1.5726079326694475e-10 	 residual l2 norm: 1.2284689390774674e-13
# epoch:  27	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012888908386230469
# ======TIME=======stiffness matrix terms time : 0.022995948791503906
# ======TIME=======neumann bd terms time : 0.001850128173828125
# =======> argmax subproblem time:  0.026265859603881836
# assembling the matrix time taken:  0.00015926361083984375
# solving Ax = b time taken:  0.0016400814056396484
# total size: 27 1000000 = 27000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:2.4648527563964593 	 residual l2 norm: 0.002350974541139525
# newton iteration:  2
# sol_update_l2_norm:1.8833467294033235e-06 	 residual l2 norm: 2.8477345856400115e-07
# newton iteration:  3
# sol_update_l2_norm:2.735965962559552e-10 	 residual l2 norm: 1.4522766090537424e-13
# converged at iteration:  3
# sol_update_l2_norm:2.735965962559552e-10 	 residual l2 norm: 1.4522766090537424e-13
# epoch:  28	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.001295328140258789
# ======TIME=======stiffness matrix terms time : 0.023070812225341797
# ======TIME=======neumann bd terms time : 0.001863241195678711
# =======> argmax subproblem time:  0.02636551856994629
# assembling the matrix time taken:  0.0001678466796875
# solving Ax = b time taken:  0.0016813278198242188
# total size: 28 1000000 = 28000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:13.516857162068693 	 residual l2 norm: 0.0022056018420879495
# newton iteration:  2
# sol_update_l2_norm:1.3828756819876126e-05 	 residual l2 norm: 5.642679131544469e-06
# newton iteration:  3
# sol_update_l2_norm:1.045971277180315e-10 	 residual l2 norm: 1.034355748377287e-13
# converged at iteration:  3
# sol_update_l2_norm:1.045971277180315e-10 	 residual l2 norm: 1.034355748377287e-13
# epoch:  29	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012879371643066406
# ======TIME=======stiffness matrix terms time : 0.023062944412231445
# ======TIME=======neumann bd terms time : 0.001986265182495117
# =======> argmax subproblem time:  0.026485919952392578
# assembling the matrix time taken:  0.00016689300537109375
# solving Ax = b time taken:  0.0017311573028564453
# total size: 29 1000000 = 29000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:1.665068085863935 	 residual l2 norm: 0.0017711962296392911
# newton iteration:  2
# sol_update_l2_norm:1.946177281522552e-06 	 residual l2 norm: 3.4440483787254824e-07
# newton iteration:  3
# sol_update_l2_norm:1.0191724047375625e-10 	 residual l2 norm: 3.2383817964355913e-13
# converged at iteration:  3
# sol_update_l2_norm:1.0191724047375625e-10 	 residual l2 norm: 3.2383817964355913e-13
# epoch:  30	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012888908386230469
# ======TIME=======stiffness matrix terms time : 0.0231320858001709
# ======TIME=======neumann bd terms time : 0.0018613338470458984
# =======> argmax subproblem time:  0.02641582489013672
# assembling the matrix time taken:  0.0001671314239501953
# solving Ax = b time taken:  0.0017547607421875
# total size: 30 1000000 = 30000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:35.69929403743631 	 residual l2 norm: 0.0012683909646472068
# newton iteration:  2
# sol_update_l2_norm:4.855209494616301e-05 	 residual l2 norm: 8.807802243489981e-06
# newton iteration:  3
# sol_update_l2_norm:2.8174851673255587e-11 	 residual l2 norm: 3.0752969698796407e-14
# converged at iteration:  3
# sol_update_l2_norm:2.8174851673255587e-11 	 residual l2 norm: 3.0752969698796407e-14
# epoch:  31	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012891292572021484
# ======TIME=======stiffness matrix terms time : 0.023141145706176758
# ======TIME=======neumann bd terms time : 0.0018436908721923828
# =======> argmax subproblem time:  0.02640533447265625
# assembling the matrix time taken:  0.00016188621520996094
# solving Ax = b time taken:  0.0018291473388671875
# total size: 31 1000000 = 31000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:12.431664006231902 	 residual l2 norm: 0.0016095457490999747
# newton iteration:  2
# sol_update_l2_norm:1.786646840495503e-05 	 residual l2 norm: 1.1854573267950382e-05
# newton iteration:  3
# sol_update_l2_norm:6.53568129776525e-11 	 residual l2 norm: 9.900158166752392e-14
# converged at iteration:  3
# sol_update_l2_norm:6.53568129776525e-11 	 residual l2 norm: 9.900158166752392e-14
# epoch:  32	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012974739074707031
# ======TIME=======stiffness matrix terms time : 0.023157835006713867
# ======TIME=======neumann bd terms time : 0.001844167709350586
# =======> argmax subproblem time:  0.026430606842041016
# assembling the matrix time taken:  0.00016045570373535156
# solving Ax = b time taken:  0.001874685287475586
# total size: 32 1000000 = 32000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:6.857436466451787 	 residual l2 norm: 0.004148469484755079
# newton iteration:  2
# sol_update_l2_norm:1.1269228239770052e-05 	 residual l2 norm: 4.184458428572071e-06
# newton iteration:  3
# sol_update_l2_norm:3.095185731616281e-11 	 residual l2 norm: 1.0152836367943079e-13
# converged at iteration:  3
# sol_update_l2_norm:3.095185731616281e-11 	 residual l2 norm: 1.0152836367943079e-13
# epoch:  33	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012905597686767578
# ======TIME=======stiffness matrix terms time : 0.023084640502929688
# ======TIME=======neumann bd terms time : 0.001832723617553711
# =======> argmax subproblem time:  0.026340007781982422
# assembling the matrix time taken:  0.00016617774963378906
# solving Ax = b time taken:  0.002071857452392578
# total size: 33 1000000 = 33000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:7.451142175378761 	 residual l2 norm: 0.0034327202104862376
# newton iteration:  2
# sol_update_l2_norm:1.346712331765625e-05 	 residual l2 norm: 3.184735762138994e-06
# newton iteration:  3
# sol_update_l2_norm:5.54126814529497e-11 	 residual l2 norm: 1.0077150587055228e-13
# converged at iteration:  3
# sol_update_l2_norm:5.54126814529497e-11 	 residual l2 norm: 1.0077150587055228e-13
# epoch:  34	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012879371643066406
# ======TIME=======stiffness matrix terms time : 0.026221275329589844
# ======TIME=======neumann bd terms time : 0.0018432140350341797
# =======> argmax subproblem time:  0.02949237823486328
# assembling the matrix time taken:  0.0004820823669433594
# solving Ax = b time taken:  0.0019533634185791016
# total size: 34 1000000 = 34000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:5.511655827672476 	 residual l2 norm: 0.0034386787351826597
# newton iteration:  2
# sol_update_l2_norm:8.696639455692422e-06 	 residual l2 norm: 1.4498500306398376e-06
# newton iteration:  3
# sol_update_l2_norm:2.7520424446200186e-10 	 residual l2 norm: 1.1822768052081393e-13
# converged at iteration:  3
# sol_update_l2_norm:2.7520424446200186e-10 	 residual l2 norm: 1.1822768052081393e-13
# epoch:  35	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012865066528320312
# ======TIME=======stiffness matrix terms time : 0.02626490592956543
# ======TIME=======neumann bd terms time : 0.0018565654754638672
# =======> argmax subproblem time:  0.029539108276367188
# assembling the matrix time taken:  0.00016164779663085938
# solving Ax = b time taken:  0.0021283626556396484
# total size: 35 1000000 = 35000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:4.131154141622592 	 residual l2 norm: 0.0032215394965834456
# newton iteration:  2
# sol_update_l2_norm:7.442214859289125e-06 	 residual l2 norm: 4.828921442592229e-07
# newton iteration:  3
# sol_update_l2_norm:2.9557811964482186e-10 	 residual l2 norm: 9.14707496257757e-14
# converged at iteration:  3
# sol_update_l2_norm:2.9557811964482186e-10 	 residual l2 norm: 9.14707496257757e-14
# epoch:  36	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012803077697753906
# ======TIME=======stiffness matrix terms time : 0.026273012161254883
# ======TIME=======neumann bd terms time : 0.0018460750579833984
# =======> argmax subproblem time:  0.02952885627746582
# assembling the matrix time taken:  0.0001575946807861328
# solving Ax = b time taken:  0.0021724700927734375
# total size: 36 1000000 = 36000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:5.811134343011943 	 residual l2 norm: 0.0037134274440048117
# newton iteration:  2
# sol_update_l2_norm:1.2524052787430516e-05 	 residual l2 norm: 1.1094911769373988e-06
# newton iteration:  3
# sol_update_l2_norm:2.9125026004378795e-11 	 residual l2 norm: 1.1743094018448194e-13
# converged at iteration:  3
# sol_update_l2_norm:2.9125026004378795e-11 	 residual l2 norm: 1.1743094018448194e-13
# epoch:  37	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.001276254653930664
# ======TIME=======stiffness matrix terms time : 0.026305675506591797
# ======TIME=======neumann bd terms time : 0.0018417835235595703
# =======> argmax subproblem time:  0.029552698135375977
# assembling the matrix time taken:  0.00016427040100097656
# solving Ax = b time taken:  0.002203702926635742
# total size: 37 1000000 = 37000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:5.547652376498053 	 residual l2 norm: 0.0016498411445506813
# newton iteration:  2
# sol_update_l2_norm:5.642707855656452e-06 	 residual l2 norm: 1.69097990225954e-06
# newton iteration:  3
# sol_update_l2_norm:1.1904298948504826e-10 	 residual l2 norm: 1.21554522664082e-13
# converged at iteration:  3
# sol_update_l2_norm:1.1904298948504826e-10 	 residual l2 norm: 1.21554522664082e-13
# epoch:  38	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012774467468261719
# ======TIME=======stiffness matrix terms time : 0.026339292526245117
# ======TIME=======neumann bd terms time : 0.0018420219421386719
# =======> argmax subproblem time:  0.02959418296813965
# assembling the matrix time taken:  0.00016498565673828125
# solving Ax = b time taken:  0.002254486083984375
# total size: 38 1000000 = 38000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:2.755384447221937 	 residual l2 norm: 0.0016834548115016222
# newton iteration:  2
# sol_update_l2_norm:3.0159806329556836e-06 	 residual l2 norm: 5.924451222589552e-07
# newton iteration:  3
# sol_update_l2_norm:2.123650381208711e-10 	 residual l2 norm: 4.218302370349083e-14
# converged at iteration:  3
# sol_update_l2_norm:2.123650381208711e-10 	 residual l2 norm: 4.218302370349083e-14
# epoch:  39	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012748241424560547
# ======TIME=======stiffness matrix terms time : 0.026473283767700195
# ======TIME=======neumann bd terms time : 0.0018427371978759766
# =======> argmax subproblem time:  0.02972126007080078
# assembling the matrix time taken:  0.00019621849060058594
# solving Ax = b time taken:  0.002268075942993164
# total size: 39 1000000 = 39000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:102.94957886258851 	 residual l2 norm: 0.0016577345532698736
# newton iteration:  2
# sol_update_l2_norm:0.0003143282879258771 	 residual l2 norm: 3.900807432122014e-05
# newton iteration:  3
# sol_update_l2_norm:4.272612088214162e-10 	 residual l2 norm: 3.0448441055718175e-13
# converged at iteration:  3
# sol_update_l2_norm:4.272612088214162e-10 	 residual l2 norm: 3.0448441055718175e-13
# epoch:  40	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012860298156738281
# ======TIME=======stiffness matrix terms time : 0.026387929916381836
# ======TIME=======neumann bd terms time : 0.001863241195678711
# =======> argmax subproblem time:  0.029667139053344727
# assembling the matrix time taken:  0.0001633167266845703
# solving Ax = b time taken:  0.002334117889404297
# total size: 40 1000000 = 40000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:58.54973569235236 	 residual l2 norm: 0.003442758380628598
# newton iteration:  2
# sol_update_l2_norm:0.0001099390211351386 	 residual l2 norm: 5.970657378800664e-06
# newton iteration:  3
# sol_update_l2_norm:7.49181430090004e-11 	 residual l2 norm: 8.645507766010239e-13
# converged at iteration:  3
# sol_update_l2_norm:7.49181430090004e-11 	 residual l2 norm: 8.645507766010239e-13
# epoch:  41	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012874603271484375
# ======TIME=======stiffness matrix terms time : 0.026410341262817383
# ======TIME=======neumann bd terms time : 0.0018663406372070312
# =======> argmax subproblem time:  0.029697418212890625
# assembling the matrix time taken:  0.00015807151794433594
# solving Ax = b time taken:  0.002389192581176758
# total size: 41 1000000 = 41000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:4.543784262464116 	 residual l2 norm: 0.0026806882460484456
# newton iteration:  2
# sol_update_l2_norm:2.6833783186913098e-05 	 residual l2 norm: 8.770598095503952e-07
# newton iteration:  3
# sol_update_l2_norm:7.96938167996174e-10 	 residual l2 norm: 8.16013986946082e-13
# converged at iteration:  3
# sol_update_l2_norm:7.96938167996174e-10 	 residual l2 norm: 8.16013986946082e-13
# epoch:  42	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012836456298828125
# ======TIME=======stiffness matrix terms time : 0.026459693908691406
# ======TIME=======neumann bd terms time : 0.0018579959869384766
# =======> argmax subproblem time:  0.02973151206970215
# assembling the matrix time taken:  0.00015735626220703125
# solving Ax = b time taken:  0.0024175643920898438
# total size: 42 1000000 = 42000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:11.774094748962346 	 residual l2 norm: 0.002377552693260561
# newton iteration:  2
# sol_update_l2_norm:3.9758761413560885e-05 	 residual l2 norm: 2.5563735688828883e-06
# newton iteration:  3
# sol_update_l2_norm:7.850301729603161e-10 	 residual l2 norm: 3.3225639978020233e-13
# converged at iteration:  3
# sol_update_l2_norm:7.850301729603161e-10 	 residual l2 norm: 3.3225639978020233e-13
# epoch:  43	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012879371643066406
# ======TIME=======stiffness matrix terms time : 0.0264894962310791
# ======TIME=======neumann bd terms time : 0.001865386962890625
# =======> argmax subproblem time:  0.02977466583251953
# assembling the matrix time taken:  0.00019240379333496094
# solving Ax = b time taken:  0.002431154251098633
# total size: 43 1000000 = 43000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:54.82577687488914 	 residual l2 norm: 0.002555650608879384
# newton iteration:  2
# sol_update_l2_norm:0.0001495515695495338 	 residual l2 norm: 1.2582218014066543e-05
# newton iteration:  3
# sol_update_l2_norm:3.099424422227206e-10 	 residual l2 norm: 1.3403066068260962e-12
# converged at iteration:  3
# sol_update_l2_norm:3.099424422227206e-10 	 residual l2 norm: 1.3403066068260962e-12
# epoch:  44	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012812614440917969
# ======TIME=======stiffness matrix terms time : 0.026557207107543945
# ======TIME=======neumann bd terms time : 0.0018470287322998047
# =======> argmax subproblem time:  0.029824495315551758
# assembling the matrix time taken:  0.00015735626220703125
# solving Ax = b time taken:  0.0024976730346679688
# total size: 44 1000000 = 44000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:21.1812278890843 	 residual l2 norm: 0.0024161796369370223
# newton iteration:  2
# sol_update_l2_norm:7.817463108485079e-05 	 residual l2 norm: 1.242705669493791e-05
# newton iteration:  3
# sol_update_l2_norm:2.701387181505777e-10 	 residual l2 norm: 8.485559829056567e-13
# converged at iteration:  3
# sol_update_l2_norm:2.701387181505777e-10 	 residual l2 norm: 8.485559829056567e-13
# epoch:  45	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012936592102050781
# ======TIME=======stiffness matrix terms time : 0.02657151222229004
# ======TIME=======neumann bd terms time : 0.001859903335571289
# =======> argmax subproblem time:  0.029855966567993164
# assembling the matrix time taken:  0.0001590251922607422
# solving Ax = b time taken:  0.002542734146118164
# total size: 45 1000000 = 45000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:44.52125921218693 	 residual l2 norm: 0.002128060543152564
# newton iteration:  2
# sol_update_l2_norm:8.858006739736308e-05 	 residual l2 norm: 6.3975654020190456e-06
# newton iteration:  3
# sol_update_l2_norm:9.086537863374684e-10 	 residual l2 norm: 2.2951125980693845e-12
# converged at iteration:  3
# sol_update_l2_norm:9.086537863374684e-10 	 residual l2 norm: 2.2951125980693845e-12
# epoch:  46	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012958049774169922
# ======TIME=======stiffness matrix terms time : 0.02657294273376465
# ======TIME=======neumann bd terms time : 0.0018541812896728516
# =======> argmax subproblem time:  0.02985215187072754
# assembling the matrix time taken:  0.00015854835510253906
# solving Ax = b time taken:  0.002605915069580078
# total size: 46 1000000 = 46000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:34.30743745384675 	 residual l2 norm: 0.0024125985976473883
# newton iteration:  2
# sol_update_l2_norm:0.00017672762166686938 	 residual l2 norm: 8.562220582087833e-06
# newton iteration:  3
# sol_update_l2_norm:1.4866974675084884e-10 	 residual l2 norm: 6.189280331211155e-13
# converged at iteration:  3
# sol_update_l2_norm:1.4866974675084884e-10 	 residual l2 norm: 6.189280331211155e-13
# epoch:  47	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012826919555664062
# ======TIME=======stiffness matrix terms time : 0.026633501052856445
# ======TIME=======neumann bd terms time : 0.001851797103881836
# =======> argmax subproblem time:  0.029905080795288086
# assembling the matrix time taken:  0.00020575523376464844
# solving Ax = b time taken:  0.0026111602783203125
# total size: 47 1000000 = 47000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:15.351543209946593 	 residual l2 norm: 0.0023730086715863245
# newton iteration:  2
# sol_update_l2_norm:5.558191266017814e-05 	 residual l2 norm: 5.253473036890254e-06
# newton iteration:  3
# sol_update_l2_norm:1.3274424823318757e-09 	 residual l2 norm: 2.0691518641562533e-12
# converged at iteration:  3
# sol_update_l2_norm:1.3274424823318757e-09 	 residual l2 norm: 2.0691518641562533e-12
# epoch:  48	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012865066528320312
# ======TIME=======stiffness matrix terms time : 0.026692867279052734
# ======TIME=======neumann bd terms time : 0.0018591880798339844
# =======> argmax subproblem time:  0.02996969223022461
# assembling the matrix time taken:  0.0001575946807861328
# solving Ax = b time taken:  0.002691030502319336
# total size: 48 1000000 = 48000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:11.188220603471692 	 residual l2 norm: 0.0016998505423646679
# newton iteration:  2
# sol_update_l2_norm:2.42902202929915e-05 	 residual l2 norm: 1.6700173931214952e-07
# newton iteration:  3
# sol_update_l2_norm:6.392039769194481e-10 	 residual l2 norm: 3.0998361759493263e-12
# converged at iteration:  3
# sol_update_l2_norm:6.392039769194481e-10 	 residual l2 norm: 3.0998361759493263e-12
# epoch:  49	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012912750244140625
# ======TIME=======stiffness matrix terms time : 0.02661418914794922
# ======TIME=======neumann bd terms time : 0.0018565654754638672
# =======> argmax subproblem time:  0.0298922061920166
# assembling the matrix time taken:  0.00016236305236816406
# solving Ax = b time taken:  0.002772808074951172
# total size: 49 1000000 = 49000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:74.41450424420259 	 residual l2 norm: 0.001823508958172539
# newton iteration:  2
# sol_update_l2_norm:0.0001681582601107627 	 residual l2 norm: 3.807139738416143e-05
# newton iteration:  3
# sol_update_l2_norm:1.6088734279352691e-09 	 residual l2 norm: 1.2270999268390592e-12
# converged at iteration:  3
# sol_update_l2_norm:1.6088734279352691e-09 	 residual l2 norm: 1.2270999268390592e-12
# epoch:  50	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.00128936767578125
# ======TIME=======stiffness matrix terms time : 0.026682615280151367
# ======TIME=======neumann bd terms time : 0.0018498897552490234
# =======> argmax subproblem time:  0.0299527645111084
# assembling the matrix time taken:  0.00016427040100097656
# solving Ax = b time taken:  0.002803325653076172
# total size: 50 1000000 = 50000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:4.5757226964187305 	 residual l2 norm: 0.0016082814322041486
# newton iteration:  2
# sol_update_l2_norm:1.1904967779990147e-05 	 residual l2 norm: 6.703987872953113e-07
# newton iteration:  3
# sol_update_l2_norm:1.6546806388484027e-10 	 residual l2 norm: 5.099763375116216e-13
# converged at iteration:  3
# sol_update_l2_norm:1.6546806388484027e-10 	 residual l2 norm: 5.099763375116216e-13
# epoch:  51	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012819766998291016
# ======TIME=======stiffness matrix terms time : 0.026779890060424805
# ======TIME=======neumann bd terms time : 0.0018515586853027344
# =======> argmax subproblem time:  0.0300443172454834
# assembling the matrix time taken:  0.0001671314239501953
# solving Ax = b time taken:  0.002861499786376953
# total size: 51 1000000 = 51000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:60.551144128328716 	 residual l2 norm: 0.0014523566478665223
# newton iteration:  2
# sol_update_l2_norm:0.0001873215398071772 	 residual l2 norm: 6.547283976799042e-06
# newton iteration:  3
# sol_update_l2_norm:2.205104043342179e-09 	 residual l2 norm: 2.120305286806491e-12
# converged at iteration:  3
# sol_update_l2_norm:2.205104043342179e-09 	 residual l2 norm: 2.120305286806491e-12
# epoch:  52	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.001283407211303711
# ======TIME=======stiffness matrix terms time : 0.026876211166381836
# ======TIME=======neumann bd terms time : 0.0018270015716552734
# =======> argmax subproblem time:  0.030115604400634766
# assembling the matrix time taken:  0.00015544891357421875
# solving Ax = b time taken:  0.002918720245361328
# total size: 52 1000000 = 52000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:35.6451472743264 	 residual l2 norm: 0.0011523050965485582
# newton iteration:  2
# sol_update_l2_norm:9.456150979399184e-05 	 residual l2 norm: 8.202647622639185e-06
# newton iteration:  3
# sol_update_l2_norm:5.016711618812073e-09 	 residual l2 norm: 2.9206150992226333e-12
# converged at iteration:  3
# sol_update_l2_norm:5.016711618812073e-09 	 residual l2 norm: 2.9206150992226333e-12
# epoch:  53	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012836456298828125
# ======TIME=======stiffness matrix terms time : 0.026788711547851562
# ======TIME=======neumann bd terms time : 0.0018529891967773438
# =======> argmax subproblem time:  0.03005671501159668
# assembling the matrix time taken:  0.0001575946807861328
# solving Ax = b time taken:  0.0029785633087158203
# total size: 53 1000000 = 53000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:15.626189979785487 	 residual l2 norm: 0.0012689850478076277
# newton iteration:  2
# sol_update_l2_norm:3.561784249226232e-05 	 residual l2 norm: 5.044145272625972e-06
# newton iteration:  3
# sol_update_l2_norm:1.098771332224305e-09 	 residual l2 norm: 2.407692820422054e-12
# converged at iteration:  3
# sol_update_l2_norm:1.098771332224305e-09 	 residual l2 norm: 2.407692820422054e-12
# epoch:  54	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012769699096679688
# ======TIME=======stiffness matrix terms time : 0.026938438415527344
# ======TIME=======neumann bd terms time : 0.0018579959869384766
# =======> argmax subproblem time:  0.030202150344848633
# assembling the matrix time taken:  0.00015854835510253906
# solving Ax = b time taken:  0.0030241012573242188
# total size: 54 1000000 = 54000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:11.228320294269414 	 residual l2 norm: 0.0013642131283298868
# newton iteration:  2
# sol_update_l2_norm:2.0878499747499265e-05 	 residual l2 norm: 1.8434647463427591e-06
# newton iteration:  3
# sol_update_l2_norm:4.49868066091946e-10 	 residual l2 norm: 3.402726848042576e-13
# converged at iteration:  3
# sol_update_l2_norm:4.49868066091946e-10 	 residual l2 norm: 3.402726848042576e-13
# epoch:  55	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012934207916259766
# ======TIME=======stiffness matrix terms time : 0.026803970336914062
# ======TIME=======neumann bd terms time : 0.0018422603607177734
# =======> argmax subproblem time:  0.03007054328918457
# assembling the matrix time taken:  0.00016236305236816406
# solving Ax = b time taken:  0.003080129623413086
# total size: 55 1000000 = 55000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:23.36044865168952 	 residual l2 norm: 0.0012685424265067413
# newton iteration:  2
# sol_update_l2_norm:4.55182577463893e-05 	 residual l2 norm: 6.507481727286059e-06
# newton iteration:  3
# sol_update_l2_norm:2.7742146150906396e-09 	 residual l2 norm: 7.445497620586773e-13
# converged at iteration:  3
# sol_update_l2_norm:2.7742146150906396e-09 	 residual l2 norm: 7.445497620586773e-13
# epoch:  56	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012788772583007812
# ======TIME=======stiffness matrix terms time : 0.027052879333496094
# ======TIME=======neumann bd terms time : 0.0019230842590332031
# =======> argmax subproblem time:  0.030404090881347656
# assembling the matrix time taken:  0.00015401840209960938
# solving Ax = b time taken:  0.003130197525024414
# total size: 56 1000000 = 56000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:68.75064589011062 	 residual l2 norm: 0.0011866112552956067
# newton iteration:  2
# sol_update_l2_norm:0.00019470534005468863 	 residual l2 norm: 6.953813290217243e-06
# newton iteration:  3
# sol_update_l2_norm:5.814388859737947e-10 	 residual l2 norm: 9.322640835571312e-13
# converged at iteration:  3
# sol_update_l2_norm:5.814388859737947e-10 	 residual l2 norm: 9.322640835571312e-13
# epoch:  57	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012938976287841797
# ======TIME=======stiffness matrix terms time : 0.026824235916137695
# ======TIME=======neumann bd terms time : 0.0018658638000488281
# =======> argmax subproblem time:  0.03011608123779297
# assembling the matrix time taken:  0.00015783309936523438
# solving Ax = b time taken:  0.0032012462615966797
# total size: 57 1000000 = 57000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:113.9784910739018 	 residual l2 norm: 0.0018389265052298409
# newton iteration:  2
# sol_update_l2_norm:0.0004531037339662491 	 residual l2 norm: 2.243023069534812e-05
# newton iteration:  3
# sol_update_l2_norm:4.156631106707479e-10 	 residual l2 norm: 1.2736371684057325e-12
# converged at iteration:  3
# sol_update_l2_norm:4.156631106707479e-10 	 residual l2 norm: 1.2736371684057325e-12
# epoch:  58	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012824535369873047
# ======TIME=======stiffness matrix terms time : 0.02728557586669922
# ======TIME=======neumann bd terms time : 0.001975536346435547
# =======> argmax subproblem time:  0.030695676803588867
# assembling the matrix time taken:  0.00015497207641601562
# solving Ax = b time taken:  0.003251791000366211
# total size: 58 1000000 = 58000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:19.327871947429752 	 residual l2 norm: 0.0016774070733068522
# newton iteration:  2
# sol_update_l2_norm:3.824319071807511e-05 	 residual l2 norm: 5.4373129548704405e-06
# newton iteration:  3
# sol_update_l2_norm:8.682726774685632e-10 	 residual l2 norm: 9.172645668374188e-13
# converged at iteration:  3
# sol_update_l2_norm:8.682726774685632e-10 	 residual l2 norm: 9.172645668374188e-13
# epoch:  59	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012767314910888672
# ======TIME=======stiffness matrix terms time : 0.026935815811157227
# ======TIME=======neumann bd terms time : 0.0018489360809326172
# =======> argmax subproblem time:  0.030194759368896484
# assembling the matrix time taken:  0.00015783309936523438
# solving Ax = b time taken:  0.0032973289489746094
# total size: 59 1000000 = 59000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:11.873483832912157 	 residual l2 norm: 0.0015231196822963543
# newton iteration:  2
# sol_update_l2_norm:2.9893285395250316e-05 	 residual l2 norm: 2.6482161680961566e-06
# newton iteration:  3
# sol_update_l2_norm:3.428593082560612e-10 	 residual l2 norm: 1.6516142477320264e-12
# converged at iteration:  3
# sol_update_l2_norm:3.428593082560612e-10 	 residual l2 norm: 1.6516142477320264e-12
# epoch:  60	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.001295328140258789
# ======TIME=======stiffness matrix terms time : 0.027086257934570312
# ======TIME=======neumann bd terms time : 0.0019466876983642578
# =======> argmax subproblem time:  0.030476808547973633
# assembling the matrix time taken:  0.0001652240753173828
# solving Ax = b time taken:  0.0033495426177978516
# total size: 60 1000000 = 60000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:17.914703803124272 	 residual l2 norm: 0.0013561306267411742
# newton iteration:  2
# sol_update_l2_norm:2.6896603629991665e-05 	 residual l2 norm: 6.425848751234168e-06
# newton iteration:  3
# sol_update_l2_norm:3.4673141050060017e-10 	 residual l2 norm: 1.7626329685992005e-12
# converged at iteration:  3
# sol_update_l2_norm:3.4673141050060017e-10 	 residual l2 norm: 1.7626329685992005e-12
# epoch:  61	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012912750244140625
# ======TIME=======stiffness matrix terms time : 0.026998043060302734
# ======TIME=======neumann bd terms time : 0.0018401145935058594
# =======> argmax subproblem time:  0.030268430709838867
# assembling the matrix time taken:  0.0001583099365234375
# solving Ax = b time taken:  0.0034012794494628906
# total size: 61 1000000 = 61000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:6.952925538494845 	 residual l2 norm: 0.0009263523278541352
# newton iteration:  2
# sol_update_l2_norm:1.3432563915387201e-05 	 residual l2 norm: 6.318913967057079e-07
# newton iteration:  3
# sol_update_l2_norm:2.5879310859220523e-10 	 residual l2 norm: 1.5193931170805092e-12
# converged at iteration:  3
# sol_update_l2_norm:2.5879310859220523e-10 	 residual l2 norm: 1.5193931170805092e-12
# epoch:  62	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012919902801513672
# ======TIME=======stiffness matrix terms time : 0.027166366577148438
# ======TIME=======neumann bd terms time : 0.001974344253540039
# =======> argmax subproblem time:  0.030579805374145508
# assembling the matrix time taken:  0.0001556873321533203
# solving Ax = b time taken:  0.0034532546997070312
# total size: 62 1000000 = 62000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:38.11042334652964 	 residual l2 norm: 0.0014280824816912435
# newton iteration:  2
# sol_update_l2_norm:6.597992079272874e-05 	 residual l2 norm: 1.0189551020289318e-05
# newton iteration:  3
# sol_update_l2_norm:6.112129738711251e-10 	 residual l2 norm: 2.190257785674518e-12
# converged at iteration:  3
# sol_update_l2_norm:6.112129738711251e-10 	 residual l2 norm: 2.190257785674518e-12
# epoch:  63	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012965202331542969
# ======TIME=======stiffness matrix terms time : 0.027047395706176758
# ======TIME=======neumann bd terms time : 0.0018618106842041016
# =======> argmax subproblem time:  0.030339479446411133
# assembling the matrix time taken:  0.00015592575073242188
# solving Ax = b time taken:  0.003503084182739258
# total size: 63 1000000 = 63000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:6.879554385380975 	 residual l2 norm: 0.0009088878957657274
# newton iteration:  2
# sol_update_l2_norm:1.4175719224046006e-05 	 residual l2 norm: 7.482101309489147e-07
# newton iteration:  3
# sol_update_l2_norm:9.4180870774452e-10 	 residual l2 norm: 2.0484860190442346e-12
# converged at iteration:  3
# sol_update_l2_norm:9.4180870774452e-10 	 residual l2 norm: 2.0484860190442346e-12
# epoch:  64	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012929439544677734
# ======TIME=======stiffness matrix terms time : 0.02727508544921875
# ======TIME=======neumann bd terms time : 0.0019884109497070312
# =======> argmax subproblem time:  0.030707836151123047
# assembling the matrix time taken:  0.00015735626220703125
# solving Ax = b time taken:  0.0035538673400878906
# total size: 64 1000000 = 64000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:125.10894244820763 	 residual l2 norm: 0.0010473446221080857
# newton iteration:  2
# sol_update_l2_norm:0.0003556629484767956 	 residual l2 norm: 4.015663759274556e-05
# newton iteration:  3
# sol_update_l2_norm:1.0513513438754022e-09 	 residual l2 norm: 1.4748902578806835e-12
# converged at iteration:  3
# sol_update_l2_norm:1.0513513438754022e-09 	 residual l2 norm: 1.4748902578806835e-12
# epoch:  65	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0012850761413574219
# ======TIME=======stiffness matrix terms time : 0.027020931243896484
# ======TIME=======neumann bd terms time : 0.0018584728240966797
# =======> argmax subproblem time:  0.030295133590698242
# assembling the matrix time taken:  0.00015544891357421875
# solving Ax = b time taken:  0.0049664974212646484
# total size: 65 1000000 = 65000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:15.324972291187969 	 residual l2 norm: 0.0017651629501014086
# newton iteration:  2
# sol_update_l2_norm:3.82840899996131e-05 	 residual l2 norm: 5.0727724314488635e-06
# newton iteration:  3
# sol_update_l2_norm:1.003541526757835e-09 	 residual l2 norm: 3.6230987866590205e-12
# converged at iteration:  3
# sol_update_l2_norm:1.003541526757835e-09 	 residual l2 norm: 3.6230987866590205e-12
# epoch:  66	======argmax subproblem:f and N(u) terms, num batches:  1
# ======TIME=======f and N(u) terms time : 0.0014963150024414062
# ======TIME=======stiffness matrix terms time : 0.02695751190185547
# ======TIME=======neumann bd terms time : 0.0018846988677978516
# =======> argmax subproblem time:  0.030606985092163086
# assembling the matrix time taken:  0.00021076202392578125
# solving Ax = b time taken:  0.004544496536254883
# total size: 66 1000000 = 66000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:18.310456215606877 	 residual l2 norm: 0.001217978443810867
# newton iteration:  2
# sol_update_l2_norm:3.610298918778314e-05 	 residual l2 norm: 2.8788518632635425e-06
# newton iteration:  3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 83
#      81 N = np.prod(N_list)
#      82 relu_k = 3
# ---> 83 err_QMC2, err_h10, my_model = CGANonlinearPoissonReLU3D(my_model,rhs,alpha, u_exact, u_exact_grad,g_N,\
#      84                                     N_list,num_epochs,plot_freq, Nx, order, k = relu_k, \
#      85                                     rand_deter = 'rand', linear_solver = "direct",memory = memory)
#      87 if save:
#      88     folder = 'data/'
#
# Cell In[9], line 214, in CGANonlinearPoissonReLU3D(my_model, target, alpha, u_exact, u_exact_grad, g_N, N_list, num_epochs, plot_freq, Nx, order, k, rand_deter, linear_solver, memory)
#     211     my_model.fc2.weight.data[0,:num_neuron -1 ] = sol[:] # projection of previous solution
#     212     my_model = L2_projection_init(my_model,sol,gw_expand,integration_points,activation = 'relu', solver = solver)
# --> 214 sol = minimize_linear_layer_newton_method(my_model,alpha, target,\
#     215             gw_expand, integration_points,weights_bd, integration_points_bd,\
#     216             g_N,activation ='relu', solver = solver)
#     218 sol = sol.flatten()
#     219 my_model.fc2.weight.data[0,:] = sol[:]
#
# Cell In[8], line 112, in minimize_linear_layer_newton_method(model, alpha, target, weights, integration_points, weights_bd, integration_points_bd, g_N, activation, solver, memory)
#     109         sol = torch.tensor(sol).view(1,-1)
#     110     elif solver == "direct":
#     111 #         sol = np.linalg.inv( np.array(jac.detach().cpu()) )@np.array(rhs.detach().cpu())
# --> 112         sol = (torch.linalg.solve( jac.detach(), rhs.detach())).view(1,-1)
#     113     elif solver == "ls":
#     114         sol = (torch.linalg.lstsq(jac.detach().cpu(),rhs.detach().cpu(),driver='gelsd').solution).view(1,-1)
#
# KeyboardInterrupt:

# %%
folder = 'data-pb/'
neuron_num_save = load_model_data['neuron_num'] + num_epochs if load_model_data['loadOrNot'] else num_epochs
filename = folder + 'errl2_OGA_3D_{}_relu_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,relu_k,neuron_num_save,N)
torch.save(err_QMC2,filename) 
filename = folder + 'errh10_OGA_3D_{}_relu_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,relu_k,neuron_num_save,N)
torch.save(err_h10,filename) 
filename = folder + 'model_OGA_3D_{}_relu_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,relu_k,neuron_num_save,N)
torch.save(my_model.state_dict(),filename)

# %%
err_l2_512 = torch.load(folder + 'errl2_OGA_3D_{}_relu_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,relu_k,neuron_num_save,N))
err_h10_512 = torch.load(folder + 'errh10_OGA_3D_{}_relu_{}_neuron_{}_N_{}_randomized.pt'.format(function_name,relu_k,neuron_num_save,N))
show_convergence_order_latex(err_QMC2,err_h10,exponent,k =relu_k,d = 3)
# Out:
# neuron num  & 	 $\|u-u_n \|_{L^2}$ & 	 order $O(n^{-1.67})$ & 	 $ | u -u_n |_{H^1}$ & 	 order $O(n^{-1.33})$ \\ \hline \hline
# 4 		 & 0.097603 &		 * & 		 2.228954 & 		 *  \\ \hline
#
# 8 		 &  9.692e-02 &  		 0.01 &  		 2.228e+00 &  		 0.00 \\ \hline
#
# 16 		 &  9.213e-02 &  		 0.07 &  		 2.208e+00 &  		 0.01 \\ \hline
#
# 32 		 &  8.175e-02 &  		 0.17 &  		 2.080e+00 &  		 0.09 \\ \hline
#
# 64 		 &  5.566e-02 &  		 0.55 &  		 1.647e+00 &  		 0.34 \\ \hline
#
# 128 		 &  2.573e-02 &  		 1.11 &  		 1.315e+00 &  		 0.32 \\ \hline
#
# 256 		 &  8.012e-03 &  		 1.68 &  		 6.471e-01 &  		 1.02 \\ \hline
#
# 512 		 &  1.891e-03 &  		 2.08 &  		 1.716e-01 &  		 1.91 \\ \hline

# %% [markdown]
# ## Test cosine function

# %%
freq = 2 
def u_exact(x):
    return torch.cos(freq*pi*x[:,0:1])*torch.cos( freq*pi*x[:,1:2]) * torch.cos(freq*pi*x[:,2:3])  
def alpha(x): 
    return torch.ones(x.size(0),1).to(device)

def u_exact_grad():
    d = 3 
    def grad_1(x):
        return - freq*pi* torch.sin(freq*pi*x[:,0:1])*torch.cos( freq*pi*x[:,1:2]) * torch.cos(freq*pi*x[:,2:3])   
    def grad_2(x):
        return - freq*pi* torch.cos(freq*pi*x[:,0:1])*torch.sin( freq*pi*x[:,1:2]) * torch.cos(freq*pi*x[:,2:3])  
    def grad_3(x):
        return - freq*pi* torch.cos(freq*pi*x[:,0:1])*torch.cos( freq*pi*x[:,1:2]) * torch.sin(freq*pi*x[:,2:3])   
    
    u_grad=[grad_1, grad_2,grad_3] 

    return u_grad
def laplace_u_exact(x):
    return -3*(freq*pi)**2 * torch.cos(freq*pi*x[:,0:1])*torch.cos( freq*pi*x[:,1:2]) * torch.cos(freq*pi*x[:,2:3])
# def target(x):
#     z = -laplace_u_exact(x) + u_exact(x)**3 
#     return z 

def u_exact_approx(x):
    return 0.7 * u_exact(x)

def rhs(x):
    return  -laplace_u_exact(x) + nonlinear(u_exact(x))

g_N = None 


function_name = "cos4pix" 
filename_write = "3DCGA-{}-order.txt".format(function_name)
f_write = open(filename_write, "a")
f_write.write("\n")
f_write.close() 
save = False 
relu_k = 3
for N_list in [[2*3,2**3,2**3]]: # ,[2**6,2**6],[2**7,2**7] 
    # save = True 
    f_write = open(filename_write, "a")
    my_model = None 
    Nx = 50
    order = 3
    exponent = 7
    num_epochs = 2**exponent  
    plot_freq = num_epochs 
    N = np.prod(N_list)
    err_QMC2, err_h10, my_model = CGANonlinearPoissonReLU3D(my_model,rhs,alpha, u_exact, u_exact_grad,g_N, N_list,num_epochs,plot_freq, Nx, order, k = relu_k, rand_deter = 'rand', linear_solver = "direct")
    if save: 
        folder = 'data-neumann/'
        filename = folder + 'err_OGA_2D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        torch.save(err_QMC2,filename) 
        folder = 'data-neumann/'
        filename = folder + 'model_OGA_2D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        torch.save(my_model,filename)

    show_convergence_order(err_QMC2,err_h10,exponent,N,filename_write,False)
    show_convergence_order_latex(err_QMC2,err_h10,exponent,k =relu_k,d = 3)
# Out:
# using linear solver:  direct
# epoch:  1	======TIME=======f and u^3 terms time : 0.00040221214294433594
# ======TIME=======stiffness matrix terms time : 9.5367431640625e-07
# ======TIME=======neumann bd terms time : 2.384185791015625e-07
# =======> argmax subproblem time:  0.000537872314453125
# total size: 1 1000000 = 1000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.22455818462385624 	 residual l2 norm: 0.022839427539190275
# newton iteration:  2
# sol_update_l2_norm:5.874028747627114e-06 	 residual l2 norm: 5.974843031962551e-07
# newton iteration:  3
# sol_update_l2_norm:1.2049027379020042e-14 	 residual l2 norm: 1.2255821357776142e-15
# converged at iteration:  3
# sol_update_l2_norm:1.2049027379020042e-14 	 residual l2 norm: 1.2255821357776142e-15
# epoch:  2	======TIME=======f and u^3 terms time : 0.0011060237884521484
# ======TIME=======stiffness matrix terms time : 0.01655411720275879
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.017806053161621094
# total size: 2 1000000 = 2000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.3126126918518323 	 residual l2 norm: 0.03523913364146597
# newton iteration:  2
# sol_update_l2_norm:4.9761037633837134e-06 	 residual l2 norm: 2.1671035356643933e-05
# newton iteration:  3
# sol_update_l2_norm:2.300104667963837e-14 	 residual l2 norm: 1.7766352505469985e-13
# converged at iteration:  3
# sol_update_l2_norm:2.300104667963837e-14 	 residual l2 norm: 1.7766352505469985e-13
# epoch:  3	======TIME=======f and u^3 terms time : 0.0011067390441894531
# ======TIME=======stiffness matrix terms time : 0.016889095306396484
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.01813220977783203
# assembling the matrix time taken:  0.0001704692840576172
# solving Ax = b time taken:  0.00043392181396484375
# total size: 3 1000000 = 3000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.03283085202724588 	 residual l2 norm: 0.3249058078147389
# newton iteration:  2
# sol_update_l2_norm:4.958304106872741e-07 	 residual l2 norm: 1.2526890727935722e-05
# newton iteration:  3
# sol_update_l2_norm:1.55567931431469e-15 	 residual l2 norm: 2.1537796376180908e-14
# converged at iteration:  3
# sol_update_l2_norm:1.55567931431469e-15 	 residual l2 norm: 2.1537796376180908e-14
# epoch:  4	======TIME=======f and u^3 terms time : 0.0011088848114013672
# ======TIME=======stiffness matrix terms time : 0.016942977905273438
# ======TIME=======neumann bd terms time : 2.384185791015625e-07
# =======> argmax subproblem time:  0.01819586753845215
# assembling the matrix time taken:  0.0002117156982421875
# solving Ax = b time taken:  0.0004267692565917969
# total size: 4 1000000 = 4000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.01697731599927981 	 residual l2 norm: 0.11780418150872975
# newton iteration:  2
# sol_update_l2_norm:1.9452050241894974e-06 	 residual l2 norm: 1.4859715328914981e-05
# newton iteration:  3
# sol_update_l2_norm:1.8546359427104285e-14 	 residual l2 norm: 1.645878828512447e-13
# converged at iteration:  3
# sol_update_l2_norm:1.8546359427104285e-14 	 residual l2 norm: 1.645878828512447e-13
# epoch:  5	======TIME=======f and u^3 terms time : 0.0011107921600341797
# ======TIME=======stiffness matrix terms time : 0.01706838607788086
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.01832723617553711
# assembling the matrix time taken:  0.00017142295837402344
# solving Ax = b time taken:  0.0005171298980712891
# total size: 5 1000000 = 5000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.023487306548772235 	 residual l2 norm: 0.3168667636439398
# newton iteration:  2
# sol_update_l2_norm:6.158507595633069e-07 	 residual l2 norm: 9.637736113279338e-06
# newton iteration:  3
# sol_update_l2_norm:3.037926667752073e-15 	 residual l2 norm: 3.2865595676865894e-14
# converged at iteration:  3
# sol_update_l2_norm:3.037926667752073e-15 	 residual l2 norm: 3.2865595676865894e-14
# epoch:  6	======TIME=======f and u^3 terms time : 0.0011043548583984375
# ======TIME=======stiffness matrix terms time : 0.017062664031982422
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.018326520919799805
# assembling the matrix time taken:  0.00017523765563964844
# solving Ax = b time taken:  0.0005545616149902344
# total size: 6 1000000 = 6000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.14151153880468587 	 residual l2 norm: 0.15586734707439842
# newton iteration:  2
# sol_update_l2_norm:2.56515949751245e-06 	 residual l2 norm: 8.712477702794249e-05
# newton iteration:  3
# sol_update_l2_norm:1.1505596757764267e-13 	 residual l2 norm: 1.5917260822574766e-12
# converged at iteration:  3
# sol_update_l2_norm:1.1505596757764267e-13 	 residual l2 norm: 1.5917260822574766e-12
# epoch:  7	======TIME=======f and u^3 terms time : 0.0011043548583984375
# ======TIME=======stiffness matrix terms time : 0.01718592643737793
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.018444061279296875
# assembling the matrix time taken:  0.00017309188842773438
# solving Ax = b time taken:  0.0005776882171630859
# total size: 7 1000000 = 7000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.08228177147763432 	 residual l2 norm: 0.11317235512232501
# newton iteration:  2
# sol_update_l2_norm:5.665022327097344e-07 	 residual l2 norm: 5.363416668849251e-06
# newton iteration:  3
# sol_update_l2_norm:4.593564104196743e-16 	 residual l2 norm: 5.087111037169998e-15
# converged at iteration:  3
# sol_update_l2_norm:4.593564104196743e-16 	 residual l2 norm: 5.087111037169998e-15
# epoch:  8	======TIME=======f and u^3 terms time : 0.0011048316955566406
# ======TIME=======stiffness matrix terms time : 0.01702284812927246
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.01826333999633789
# assembling the matrix time taken:  0.0001633167266845703
# solving Ax = b time taken:  0.0006551742553710938
# total size: 8 1000000 = 8000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.03257422169361061 	 residual l2 norm: 0.10849609006439459
# newton iteration:  2
# sol_update_l2_norm:3.520528178893402e-07 	 residual l2 norm: 7.28494207123004e-06
# newton iteration:  3
# sol_update_l2_norm:1.2608976780617098e-15 	 residual l2 norm: 8.036108603725668e-15
# converged at iteration:  3
# sol_update_l2_norm:1.2608976780617098e-15 	 residual l2 norm: 8.036108603725668e-15
# epoch:  9	======TIME=======f and u^3 terms time : 0.0011088848114013672
# ======TIME=======stiffness matrix terms time : 0.01716756820678711
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.01842665672302246
# assembling the matrix time taken:  0.00017380714416503906
# solving Ax = b time taken:  0.0007147789001464844
# total size: 9 1000000 = 9000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.03906601645294473 	 residual l2 norm: 0.07188756493917442
# newton iteration:  2
# sol_update_l2_norm:1.2520101535040905e-07 	 residual l2 norm: 4.6711820525389696e-06
# newton iteration:  3
# sol_update_l2_norm:2.376590844433064e-15 	 residual l2 norm: 2.400956200619675e-15
# converged at iteration:  3
# sol_update_l2_norm:2.376590844433064e-15 	 residual l2 norm: 2.400956200619675e-15
# epoch:  10	======TIME=======f and u^3 terms time : 0.0011675357818603516
# ======TIME=======stiffness matrix terms time : 0.017226219177246094
# ======TIME=======neumann bd terms time : 9.5367431640625e-07
# =======> argmax subproblem time:  0.018708229064941406
# assembling the matrix time taken:  0.00017642974853515625
# solving Ax = b time taken:  0.0007486343383789062
# total size: 10 1000000 = 10000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:2.59284906381562 	 residual l2 norm: 0.04354564093171406
# newton iteration:  2
# sol_update_l2_norm:0.0002215370691417574 	 residual l2 norm: 0.0009586551155681981
# newton iteration:  3
# sol_update_l2_norm:2.1920894469180348e-10 	 residual l2 norm: 1.3152851824438048e-09
# newton iteration:  4
# sol_update_l2_norm:5.451781601316184e-15 	 residual l2 norm: 2.5775278016003238e-15
# converged at iteration:  4
# sol_update_l2_norm:5.451781601316184e-15 	 residual l2 norm: 2.5775278016003238e-15
# epoch:  11	======TIME=======f and u^3 terms time : 0.0011038780212402344
# ======TIME=======stiffness matrix terms time : 0.017102718353271484
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.018350601196289062
# assembling the matrix time taken:  0.00016927719116210938
# solving Ax = b time taken:  0.0008065700531005859
# total size: 11 1000000 = 11000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:1.1506040648352203 	 residual l2 norm: 0.3834231126213789
# newton iteration:  2
# sol_update_l2_norm:3.309394373151348e-05 	 residual l2 norm: 0.0006865011218170626
# newton iteration:  3
# sol_update_l2_norm:5.606191346042096e-11 	 residual l2 norm: 2.7649771104675013e-10
# newton iteration:  4
# sol_update_l2_norm:1.9311167608906874e-14 	 residual l2 norm: 1.0529796514390734e-14
# converged at iteration:  4
# sol_update_l2_norm:1.9311167608906874e-14 	 residual l2 norm: 1.0529796514390734e-14
# epoch:  12	======TIME=======f and u^3 terms time : 0.001107931137084961
# ======TIME=======stiffness matrix terms time : 0.01717209815979004
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.0184323787689209
# assembling the matrix time taken:  0.00018143653869628906
# solving Ax = b time taken:  0.0008037090301513672
# total size: 12 1000000 = 12000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.29456007169800663 	 residual l2 norm: 0.11534735216379899
# newton iteration:  2
# sol_update_l2_norm:1.0135690649990655e-05 	 residual l2 norm: 5.305637885335858e-05
# newton iteration:  3
# sol_update_l2_norm:2.334639919494561e-13 	 residual l2 norm: 9.319451047539626e-13
# converged at iteration:  3
# sol_update_l2_norm:2.334639919494561e-13 	 residual l2 norm: 9.319451047539626e-13
# epoch:  13	======TIME=======f and u^3 terms time : 0.001119375228881836
# ======TIME=======stiffness matrix terms time : 0.01729297637939453
# ======TIME=======neumann bd terms time : 9.5367431640625e-07
# =======> argmax subproblem time:  0.01856851577758789
# assembling the matrix time taken:  0.00017070770263671875
# solving Ax = b time taken:  0.0008883476257324219
# total size: 13 1000000 = 13000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:1.0315567433989434 	 residual l2 norm: 0.06757552637224393
# newton iteration:  2
# sol_update_l2_norm:2.012557669955244e-05 	 residual l2 norm: 3.0455188558135095e-05
# newton iteration:  3
# sol_update_l2_norm:2.0583564579846088e-13 	 residual l2 norm: 6.337185011802743e-13
# converged at iteration:  3
# sol_update_l2_norm:2.0583564579846088e-13 	 residual l2 norm: 6.337185011802743e-13
# epoch:  14	======TIME=======f and u^3 terms time : 0.0011107921600341797
# ======TIME=======stiffness matrix terms time : 0.01712775230407715
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.018381834030151367
# assembling the matrix time taken:  0.0001690387725830078
# solving Ax = b time taken:  0.0009429454803466797
# total size: 14 1000000 = 14000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:1.5374145484083406 	 residual l2 norm: 0.042497916588585066
# newton iteration:  2
# sol_update_l2_norm:3.1213154103752736e-05 	 residual l2 norm: 4.216987663744543e-05
# newton iteration:  3
# sol_update_l2_norm:3.747720015478835e-13 	 residual l2 norm: 1.4568901049425913e-12
# converged at iteration:  3
# sol_update_l2_norm:3.747720015478835e-13 	 residual l2 norm: 1.4568901049425913e-12
# epoch:  15	======TIME=======f and u^3 terms time : 0.0011475086212158203
# ======TIME=======stiffness matrix terms time : 0.017253637313842773
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.01855015754699707
# assembling the matrix time taken:  0.000179290771484375
# solving Ax = b time taken:  0.0009968280792236328
# total size: 15 1000000 = 15000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:0.9963013306958786 	 residual l2 norm: 0.057628219914070175
# newton iteration:  2
# sol_update_l2_norm:1.7269699281097047e-05 	 residual l2 norm: 3.480906685543887e-05
# newton iteration:  3
# sol_update_l2_norm:1.0177618783642401e-13 	 residual l2 norm: 3.5434159389567027e-13
# converged at iteration:  3
# sol_update_l2_norm:1.0177618783642401e-13 	 residual l2 norm: 3.5434159389567027e-13
# epoch:  16	======TIME=======f and u^3 terms time : 0.0011107921600341797
# ======TIME=======stiffness matrix terms time : 0.017343521118164062
# ======TIME=======neumann bd terms time : 1.1920928955078125e-06
# =======> argmax subproblem time:  0.018619298934936523
# assembling the matrix time taken:  0.00017380714416503906
# solving Ax = b time taken:  0.0010275840759277344
# total size: 16 1000000 = 16000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:1.1869282823546428 	 residual l2 norm: 0.0425618250538743
# newton iteration:  2
# sol_update_l2_norm:1.92918929018901e-05 	 residual l2 norm: 1.870807821060137e-05
# newton iteration:  3
# sol_update_l2_norm:3.645589931317422e-14 	 residual l2 norm: 8.784756149603309e-14
# converged at iteration:  3
# sol_update_l2_norm:3.645589931317422e-14 	 residual l2 norm: 8.784756149603309e-14
# epoch:  17	======TIME=======f and u^3 terms time : 0.0011365413665771484
# ======TIME=======stiffness matrix terms time : 0.017201662063598633
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.01862335205078125
# assembling the matrix time taken:  0.00017714500427246094
# solving Ax = b time taken:  0.0011153221130371094
# total size: 17 1000000 = 17000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:1.4837321199179716 	 residual l2 norm: 0.03326351207449635
# newton iteration:  2
# sol_update_l2_norm:3.4476095359390184e-05 	 residual l2 norm: 2.8829227155026774e-05
# newton iteration:  3
# sol_update_l2_norm:1.0249410205297529e-13 	 residual l2 norm: 3.251491160773339e-13
# converged at iteration:  3
# sol_update_l2_norm:1.0249410205297529e-13 	 residual l2 norm: 3.251491160773339e-13
# epoch:  18	======TIME=======f and u^3 terms time : 0.0011243820190429688
# ======TIME=======stiffness matrix terms time : 0.017407655715942383
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.018694400787353516
# assembling the matrix time taken:  0.000171661376953125
# solving Ax = b time taken:  0.001169443130493164
# total size: 18 1000000 = 18000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:44.5721918566062 	 residual l2 norm: 0.03606856167059472
# newton iteration:  2
# sol_update_l2_norm:0.003691585908047616 	 residual l2 norm: 0.0012539180952092673
# newton iteration:  3
# sol_update_l2_norm:4.764420257765271e-10 	 residual l2 norm: 9.378093259557812e-10
# converged at iteration:  3
# sol_update_l2_norm:4.764420257765271e-10 	 residual l2 norm: 9.378093259557812e-10
# epoch:  19	======TIME=======f and u^3 terms time : 0.0011258125305175781
# ======TIME=======stiffness matrix terms time : 0.017235755920410156
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.018497943878173828
# assembling the matrix time taken:  0.00018215179443359375
# solving Ax = b time taken:  0.0011980533599853516
# total size: 19 1000000 = 19000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:16.081425195961536 	 residual l2 norm: 0.15075441555901484
# newton iteration:  2
# sol_update_l2_norm:0.0014110128065722605 	 residual l2 norm: 0.0005018912298702132
# newton iteration:  3
# sol_update_l2_norm:3.3811275872844155e-10 	 residual l2 norm: 4.432996432510262e-10
# converged at iteration:  3
# sol_update_l2_norm:3.3811275872844155e-10 	 residual l2 norm: 4.432996432510262e-10
# epoch:  20	======TIME=======f and u^3 terms time : 0.001119852066040039
# ======TIME=======stiffness matrix terms time : 0.017367839813232422
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.018642425537109375
# assembling the matrix time taken:  0.00016927719116210938
# solving Ax = b time taken:  0.0012645721435546875
# total size: 20 1000000 = 20000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:16.466323571760725 	 residual l2 norm: 0.1456863403281408
# newton iteration:  2
# sol_update_l2_norm:0.0024740520811466055 	 residual l2 norm: 0.0009018824656661345
# newton iteration:  3
# sol_update_l2_norm:3.8882645957631487e-10 	 residual l2 norm: 3.976973157102083e-10
# converged at iteration:  3
# sol_update_l2_norm:3.8882645957631487e-10 	 residual l2 norm: 3.976973157102083e-10
# epoch:  21	======TIME=======f and u^3 terms time : 0.0011162757873535156
# ======TIME=======stiffness matrix terms time : 0.017518043518066406
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.01879262924194336
# assembling the matrix time taken:  0.00018095970153808594
# solving Ax = b time taken:  0.0013017654418945312
# total size: 21 1000000 = 21000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:21.469002117488085 	 residual l2 norm: 0.1399015275917418
# newton iteration:  2
# sol_update_l2_norm:0.0022558161668318217 	 residual l2 norm: 0.0006098465306824805
# newton iteration:  3
# sol_update_l2_norm:3.401390377036313e-11 	 residual l2 norm: 5.6590906101049593e-11
# converged at iteration:  3
# sol_update_l2_norm:3.401390377036313e-11 	 residual l2 norm: 5.6590906101049593e-11
# epoch:  22	======TIME=======f and u^3 terms time : 0.0012099742889404297
# ======TIME=======stiffness matrix terms time : 0.01757526397705078
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.018944740295410156
# assembling the matrix time taken:  0.0001735687255859375
# solving Ax = b time taken:  0.0013599395751953125
# total size: 22 1000000 = 22000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:4.30957433251461 	 residual l2 norm: 0.01722801594252449
# newton iteration:  2
# sol_update_l2_norm:0.00022237126682813038 	 residual l2 norm: 6.39326953010149e-05
# newton iteration:  3
# sol_update_l2_norm:8.407345482550571e-13 	 residual l2 norm: 2.9479996817107977e-12
# converged at iteration:  3
# sol_update_l2_norm:8.407345482550571e-13 	 residual l2 norm: 2.9479996817107977e-12
# epoch:  23	======TIME=======f and u^3 terms time : 0.0011577606201171875
# ======TIME=======stiffness matrix terms time : 0.01742243766784668
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.018718481063842773
# assembling the matrix time taken:  0.00016641616821289062
# solving Ax = b time taken:  0.0014088153839111328
# total size: 23 1000000 = 23000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:1.2622169341693181 	 residual l2 norm: 0.014578077803039395
# newton iteration:  2
# sol_update_l2_norm:5.86630372878789e-05 	 residual l2 norm: 2.2558632331597758e-05
# newton iteration:  3
# sol_update_l2_norm:1.49915314330398e-12 	 residual l2 norm: 6.650597192962242e-13
# converged at iteration:  3
# sol_update_l2_norm:1.49915314330398e-12 	 residual l2 norm: 6.650597192962242e-13
# epoch:  24	======TIME=======f and u^3 terms time : 0.0011239051818847656
# ======TIME=======stiffness matrix terms time : 0.01761341094970703
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.018893003463745117
# assembling the matrix time taken:  0.00016880035400390625
# solving Ax = b time taken:  0.0014629364013671875
# total size: 24 1000000 = 24000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:5.377628506381402 	 residual l2 norm: 0.03813389241198335
# newton iteration:  2
# sol_update_l2_norm:0.00048816580289643986 	 residual l2 norm: 0.00011420707051184815
# newton iteration:  3
# sol_update_l2_norm:2.498008896425604e-12 	 residual l2 norm: 5.1308697775378965e-12
# converged at iteration:  3
# sol_update_l2_norm:2.498008896425604e-12 	 residual l2 norm: 5.1308697775378965e-12
# epoch:  25	======TIME=======f and u^3 terms time : 0.0011112689971923828
# ======TIME=======stiffness matrix terms time : 0.017488718032836914
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.01873612403869629
# assembling the matrix time taken:  0.00016307830810546875
# solving Ax = b time taken:  0.00152587890625
# total size: 25 1000000 = 25000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:35.792613712787826 	 residual l2 norm: 0.02002325312929446
# newton iteration:  2
# sol_update_l2_norm:0.0023150034738949766 	 residual l2 norm: 0.0009494625535374098
# newton iteration:  3
# sol_update_l2_norm:2.2883755060859798e-10 	 residual l2 norm: 7.986695944191307e-10
# converged at iteration:  3
# sol_update_l2_norm:2.2883755060859798e-10 	 residual l2 norm: 7.986695944191307e-10
# epoch:  26	======TIME=======f and u^3 terms time : 0.0011267662048339844
# ======TIME=======stiffness matrix terms time : 0.01766681671142578
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.018944978713989258
# assembling the matrix time taken:  0.00016689300537109375
# solving Ax = b time taken:  0.0015797615051269531
# total size: 26 1000000 = 26000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:73.42694668168824 	 residual l2 norm: 0.0207047003106543
# newton iteration:  2
# sol_update_l2_norm:0.0037482041469253323 	 residual l2 norm: 0.0008602443143357878
# newton iteration:  3
# sol_update_l2_norm:2.955797254469979e-10 	 residual l2 norm: 6.550432336221382e-10
# converged at iteration:  3
# sol_update_l2_norm:2.955797254469979e-10 	 residual l2 norm: 6.550432336221382e-10
# epoch:  27	======TIME=======f and u^3 terms time : 0.0012111663818359375
# ======TIME=======stiffness matrix terms time : 0.017521381378173828
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.01888298988342285
# assembling the matrix time taken:  0.00017547607421875
# solving Ax = b time taken:  0.0016357898712158203
# total size: 27 1000000 = 27000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:8.4858100067225 	 residual l2 norm: 0.02849896332646717
# newton iteration:  2
# sol_update_l2_norm:0.0012539342036130498 	 residual l2 norm: 0.0013489115592605332
# newton iteration:  3
# sol_update_l2_norm:5.11723476307324e-10 	 residual l2 norm: 8.429928630105828e-10
# converged at iteration:  3
# sol_update_l2_norm:5.11723476307324e-10 	 residual l2 norm: 8.429928630105828e-10
# epoch:  28	======TIME=======f and u^3 terms time : 0.00112152099609375
# ======TIME=======stiffness matrix terms time : 0.017663955688476562
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.018940448760986328
# assembling the matrix time taken:  0.00016927719116210938
# solving Ax = b time taken:  0.0016698837280273438
# total size: 28 1000000 = 28000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:17.717961263781998 	 residual l2 norm: 0.028997346926492643
# newton iteration:  2
# sol_update_l2_norm:0.002351431573851853 	 residual l2 norm: 0.0007210737345578616
# newton iteration:  3
# sol_update_l2_norm:5.269682003558858e-10 	 residual l2 norm: 6.164082690206588e-10
# converged at iteration:  3
# sol_update_l2_norm:5.269682003558858e-10 	 residual l2 norm: 6.164082690206588e-10
# epoch:  29	======TIME=======f and u^3 terms time : 0.0011172294616699219
# ======TIME=======stiffness matrix terms time : 0.017563343048095703
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.018819808959960938
# assembling the matrix time taken:  0.00017690658569335938
# solving Ax = b time taken:  0.001699209213256836
# total size: 29 1000000 = 29000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:62.051925440559444 	 residual l2 norm: 0.021909254454492638
# newton iteration:  2
# sol_update_l2_norm:0.003436318247663865 	 residual l2 norm: 0.0011463719255214923
# newton iteration:  3
# sol_update_l2_norm:9.475338151554041e-10 	 residual l2 norm: 1.1723187935953932e-09
# converged at iteration:  3
# sol_update_l2_norm:9.475338151554041e-10 	 residual l2 norm: 1.1723187935953932e-09
# epoch:  30	======TIME=======f and u^3 terms time : 0.0012197494506835938
# ======TIME=======stiffness matrix terms time : 0.01758742332458496
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.01896071434020996
# assembling the matrix time taken:  0.00017404556274414062
# solving Ax = b time taken:  0.0017702579498291016
# total size: 30 1000000 = 30000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:63.8887536080933 	 residual l2 norm: 0.02137125781631405
# newton iteration:  2
# sol_update_l2_norm:0.005878935297360359 	 residual l2 norm: 0.002906808482263438
# newton iteration:  3
# sol_update_l2_norm:7.094700060694022e-09 	 residual l2 norm: 6.885714081598038e-09
# newton iteration:  4
# sol_update_l2_norm:1.0468616802423512e-12 	 residual l2 norm: 1.842747157365393e-12
# converged at iteration:  4
# sol_update_l2_norm:1.0468616802423512e-12 	 residual l2 norm: 1.842747157365393e-12
# epoch:  31	======TIME=======f and u^3 terms time : 0.0012056827545166016
# ======TIME=======stiffness matrix terms time : 0.017814159393310547
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.01935100555419922
# assembling the matrix time taken:  0.00017380714416503906
# solving Ax = b time taken:  0.0018188953399658203
# total size: 31 1000000 = 31000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:20.026198667080898 	 residual l2 norm: 0.023986201465906225
# newton iteration:  2
# sol_update_l2_norm:0.002690523424336921 	 residual l2 norm: 0.0005984493293561621
# newton iteration:  3
# sol_update_l2_norm:2.0413840745597447e-10 	 residual l2 norm: 3.817255910532672e-10
# converged at iteration:  3
# sol_update_l2_norm:2.0413840745597447e-10 	 residual l2 norm: 3.817255910532672e-10
# epoch:  32	======TIME=======f and u^3 terms time : 0.0011212825775146484
# ======TIME=======stiffness matrix terms time : 0.017807960510253906
# ======TIME=======neumann bd terms time : 9.5367431640625e-07
# =======> argmax subproblem time:  0.019083023071289062
# assembling the matrix time taken:  0.0001690387725830078
# solving Ax = b time taken:  0.001857757568359375
# total size: 32 1000000 = 32000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:25.63694001910547 	 residual l2 norm: 0.019754579993270873
# newton iteration:  2
# sol_update_l2_norm:0.005522978800452294 	 residual l2 norm: 0.0005450210036557745
# newton iteration:  3
# sol_update_l2_norm:5.682605322918412e-10 	 residual l2 norm: 4.996066269762029e-10
# converged at iteration:  3
# sol_update_l2_norm:5.682605322918412e-10 	 residual l2 norm: 4.996066269762029e-10
# epoch:  33	======TIME=======f and u^3 terms time : 0.0012269020080566406
# ======TIME=======stiffness matrix terms time : 0.017725467681884766
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.019107341766357422
# assembling the matrix time taken:  0.00017380714416503906
# solving Ax = b time taken:  0.0020668506622314453
# total size: 33 1000000 = 33000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:51.65411700873382 	 residual l2 norm: 0.016204070586340977
# newton iteration:  2
# sol_update_l2_norm:0.004079200247483148 	 residual l2 norm: 0.00021413117546439434
# newton iteration:  3
# sol_update_l2_norm:1.2887401540998542e-10 	 residual l2 norm: 1.6081478463677954e-10
# converged at iteration:  3
# sol_update_l2_norm:1.2887401540998542e-10 	 residual l2 norm: 1.6081478463677954e-10
# epoch:  34	======TIME=======f and u^3 terms time : 0.0011970996856689453
# ======TIME=======stiffness matrix terms time : 0.02094411849975586
# ======TIME=======neumann bd terms time : 9.5367431640625e-07
# =======> argmax subproblem time:  0.022475004196166992
# assembling the matrix time taken:  0.00018334388732910156
# solving Ax = b time taken:  0.0020928382873535156
# total size: 34 1000000 = 34000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:60.2701821396901 	 residual l2 norm: 0.025958526264395633
# newton iteration:  2
# sol_update_l2_norm:0.005648579052254733 	 residual l2 norm: 0.0010747497769728821
# newton iteration:  3
# sol_update_l2_norm:2.632924517151843e-09 	 residual l2 norm: 2.5771335067215187e-09
# newton iteration:  4
# sol_update_l2_norm:2.234773640208201e-12 	 residual l2 norm: 1.2027672229492393e-12
# converged at iteration:  4
# sol_update_l2_norm:2.234773640208201e-12 	 residual l2 norm: 1.2027672229492393e-12
# epoch:  35	======TIME=======f and u^3 terms time : 0.00119781494140625
# ======TIME=======stiffness matrix terms time : 0.020855188369750977
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.022243499755859375
# assembling the matrix time taken:  0.0001811981201171875
# solving Ax = b time taken:  0.0021359920501708984
# total size: 35 1000000 = 35000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:11.269978925815288 	 residual l2 norm: 0.015175185499883274
# newton iteration:  2
# sol_update_l2_norm:0.0014397686431383897 	 residual l2 norm: 0.00010985002922253113
# newton iteration:  3
# sol_update_l2_norm:2.112072666735338e-11 	 residual l2 norm: 1.2576708490964687e-11
# converged at iteration:  3
# sol_update_l2_norm:2.112072666735338e-11 	 residual l2 norm: 1.2576708490964687e-11
# epoch:  36	======TIME=======f and u^3 terms time : 0.0012128353118896484
# ======TIME=======stiffness matrix terms time : 0.020964622497558594
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.022467613220214844
# assembling the matrix time taken:  0.00017452239990234375
# solving Ax = b time taken:  0.002183198928833008
# total size: 36 1000000 = 36000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:10.12919737910399 	 residual l2 norm: 0.015520889428400995
# newton iteration:  2
# sol_update_l2_norm:0.0013032750576723769 	 residual l2 norm: 0.00029536638868320176
# newton iteration:  3
# sol_update_l2_norm:8.940512803615579e-11 	 residual l2 norm: 1.0913986745262902e-10
# converged at iteration:  3
# sol_update_l2_norm:8.940512803615579e-11 	 residual l2 norm: 1.0913986745262902e-10
# epoch:  37	======TIME=======f and u^3 terms time : 0.0011420249938964844
# ======TIME=======stiffness matrix terms time : 0.02084040641784668
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02214336395263672
# assembling the matrix time taken:  0.0001747608184814453
# solving Ax = b time taken:  0.0021979808807373047
# total size: 37 1000000 = 37000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:19.162474957336325 	 residual l2 norm: 0.01696216065888149
# newton iteration:  2
# sol_update_l2_norm:0.0021388476199210647 	 residual l2 norm: 0.0014354504668771576
# newton iteration:  3
# sol_update_l2_norm:1.7642080804170216e-09 	 residual l2 norm: 9.032663417153546e-10
# converged at iteration:  3
# sol_update_l2_norm:1.7642080804170216e-09 	 residual l2 norm: 9.032663417153546e-10
# epoch:  38	======TIME=======f and u^3 terms time : 0.0011293888092041016
# ======TIME=======stiffness matrix terms time : 0.020938396453857422
# ======TIME=======neumann bd terms time : 9.5367431640625e-07
# =======> argmax subproblem time:  0.022221803665161133
# assembling the matrix time taken:  0.0001747608184814453
# solving Ax = b time taken:  0.0022635459899902344
# total size: 38 1000000 = 38000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:18.021783163857915 	 residual l2 norm: 0.013290904361231651
# newton iteration:  2
# sol_update_l2_norm:0.0019041824435687598 	 residual l2 norm: 0.00020383107681570304
# newton iteration:  3
# sol_update_l2_norm:4.893536169195263e-11 	 residual l2 norm: 1.7537099354749745e-11
# converged at iteration:  3
# sol_update_l2_norm:4.893536169195263e-11 	 residual l2 norm: 1.7537099354749745e-11
# epoch:  39	======TIME=======f and u^3 terms time : 0.0011301040649414062
# ======TIME=======stiffness matrix terms time : 0.020949602127075195
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02223968505859375
# assembling the matrix time taken:  0.0001723766326904297
# solving Ax = b time taken:  0.002306699752807617
# total size: 39 1000000 = 39000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:41.14717174034268 	 residual l2 norm: 0.012680038081385299
# newton iteration:  2
# sol_update_l2_norm:0.005257981576183577 	 residual l2 norm: 0.0005996432900423627
# newton iteration:  3
# sol_update_l2_norm:2.3570779570660093e-09 	 residual l2 norm: 1.0366629035825454e-09
# converged at iteration:  3
# sol_update_l2_norm:2.3570779570660093e-09 	 residual l2 norm: 1.0366629035825454e-09
# epoch:  40	======TIME=======f and u^3 terms time : 0.0011391639709472656
# ======TIME=======stiffness matrix terms time : 0.021086931228637695
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.022378921508789062
# assembling the matrix time taken:  0.00018453598022460938
# solving Ax = b time taken:  0.0023164749145507812
# total size: 40 1000000 = 40000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:43.99697812659512 	 residual l2 norm: 0.01767799954899277
# newton iteration:  2
# sol_update_l2_norm:0.004675165850602679 	 residual l2 norm: 0.001132680956012221
# newton iteration:  3
# sol_update_l2_norm:2.347320161513514e-09 	 residual l2 norm: 1.4285923580248833e-09
# converged at iteration:  3
# sol_update_l2_norm:2.347320161513514e-09 	 residual l2 norm: 1.4285923580248833e-09
# epoch:  41	======TIME=======f and u^3 terms time : 0.0011348724365234375
# ======TIME=======stiffness matrix terms time : 0.021088600158691406
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02237558364868164
# assembling the matrix time taken:  0.00017023086547851562
# solving Ax = b time taken:  0.002378225326538086
# total size: 41 1000000 = 41000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:44.245493092111005 	 residual l2 norm: 0.013209282270043799
# newton iteration:  2
# sol_update_l2_norm:0.0034238647309506433 	 residual l2 norm: 0.0002528936882429181
# newton iteration:  3
# sol_update_l2_norm:1.0332011367386784e-10 	 residual l2 norm: 7.353785407989837e-11
# converged at iteration:  3
# sol_update_l2_norm:1.0332011367386784e-10 	 residual l2 norm: 7.353785407989837e-11
# epoch:  42	======TIME=======f and u^3 terms time : 0.001112222671508789
# ======TIME=======stiffness matrix terms time : 0.021060466766357422
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.022329092025756836
# assembling the matrix time taken:  0.00016808509826660156
# solving Ax = b time taken:  0.0024042129516601562
# total size: 42 1000000 = 42000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:48.30338153204043 	 residual l2 norm: 0.014330393735808933
# newton iteration:  2
# sol_update_l2_norm:0.003355491273143261 	 residual l2 norm: 0.00023875489486797354
# newton iteration:  3
# sol_update_l2_norm:1.0066046525182027e-10 	 residual l2 norm: 6.441656692369942e-11
# converged at iteration:  3
# sol_update_l2_norm:1.0066046525182027e-10 	 residual l2 norm: 6.441656692369942e-11
# epoch:  43	======TIME=======f and u^3 terms time : 0.0011134147644042969
# ======TIME=======stiffness matrix terms time : 0.021121740341186523
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02239060401916504
# assembling the matrix time taken:  0.00016880035400390625
# solving Ax = b time taken:  0.002445220947265625
# total size: 43 1000000 = 43000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:60.90758558523185 	 residual l2 norm: 0.0100541935526407
# newton iteration:  2
# sol_update_l2_norm:0.005240421315187705 	 residual l2 norm: 0.0026072949539005844
# newton iteration:  3
# sol_update_l2_norm:5.655070731574752e-09 	 residual l2 norm: 3.0019700775244495e-09
# newton iteration:  4
# sol_update_l2_norm:4.631810146919888e-12 	 residual l2 norm: 8.284928974010859e-13
# converged at iteration:  4
# sol_update_l2_norm:4.631810146919888e-12 	 residual l2 norm: 8.284928974010859e-13
# epoch:  44	======TIME=======f and u^3 terms time : 0.0011191368103027344
# ======TIME=======stiffness matrix terms time : 0.02113819122314453
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.022409677505493164
# assembling the matrix time taken:  0.00017118453979492188
# solving Ax = b time taken:  0.0024764537811279297
# total size: 44 1000000 = 44000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:24.313266875684864 	 residual l2 norm: 0.010804695521924862
# newton iteration:  2
# sol_update_l2_norm:0.001596613598874812 	 residual l2 norm: 4.277684687634604e-05
# newton iteration:  3
# sol_update_l2_norm:1.8076875415444906e-11 	 residual l2 norm: 1.4422585109290618e-11
# converged at iteration:  3
# sol_update_l2_norm:1.8076875415444906e-11 	 residual l2 norm: 1.4422585109290618e-11
# epoch:  45	======TIME=======f and u^3 terms time : 0.0011136531829833984
# ======TIME=======stiffness matrix terms time : 0.02120685577392578
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.022485971450805664
# assembling the matrix time taken:  0.00017142295837402344
# solving Ax = b time taken:  0.002539396286010742
# total size: 45 1000000 = 45000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:35.916474989166794 	 residual l2 norm: 0.009930119163826747
# newton iteration:  2
# sol_update_l2_norm:0.0026482159864965583 	 residual l2 norm: 0.00012791163679431588
# newton iteration:  3
# sol_update_l2_norm:7.453582228739659e-11 	 residual l2 norm: 9.637403569427592e-11
# converged at iteration:  3
# sol_update_l2_norm:7.453582228739659e-11 	 residual l2 norm: 9.637403569427592e-11
# epoch:  46	======TIME=======f and u^3 terms time : 0.001119852066040039
# ======TIME=======stiffness matrix terms time : 0.021165132522583008
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02243971824645996
# assembling the matrix time taken:  0.00016832351684570312
# solving Ax = b time taken:  0.002581357955932617
# total size: 46 1000000 = 46000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:47.99322018521568 	 residual l2 norm: 0.007353823799841184
# newton iteration:  2
# sol_update_l2_norm:0.0021065180391154274 	 residual l2 norm: 0.00017114570322005452
# newton iteration:  3
# sol_update_l2_norm:4.4220341567620855e-11 	 residual l2 norm: 1.6115023039714303e-11
# converged at iteration:  3
# sol_update_l2_norm:4.4220341567620855e-11 	 residual l2 norm: 1.6115023039714303e-11
# epoch:  47	======TIME=======f and u^3 terms time : 0.0011396408081054688
# ======TIME=======stiffness matrix terms time : 0.021159648895263672
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.022448301315307617
# assembling the matrix time taken:  0.0001678466796875
# solving Ax = b time taken:  0.0026319026947021484
# total size: 47 1000000 = 47000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:108.29971374267652 	 residual l2 norm: 0.009990045824088028
# newton iteration:  2
# sol_update_l2_norm:0.004990068607978634 	 residual l2 norm: 0.00037466657460166573
# newton iteration:  3
# sol_update_l2_norm:3.6272438469779495e-10 	 residual l2 norm: 4.089433197626107e-10
# converged at iteration:  3
# sol_update_l2_norm:3.6272438469779495e-10 	 residual l2 norm: 4.089433197626107e-10
# epoch:  48	======TIME=======f and u^3 terms time : 0.0011169910430908203
# ======TIME=======stiffness matrix terms time : 0.021266698837280273
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.0225369930267334
# assembling the matrix time taken:  0.00018024444580078125
# solving Ax = b time taken:  0.0026743412017822266
# total size: 48 1000000 = 48000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:37.77452868773267 	 residual l2 norm: 0.007419140310701316
# newton iteration:  2
# sol_update_l2_norm:0.0017830457775926997 	 residual l2 norm: 0.00033686116467271805
# newton iteration:  3
# sol_update_l2_norm:2.457904547505973e-10 	 residual l2 norm: 2.177754542551934e-10
# converged at iteration:  3
# sol_update_l2_norm:2.457904547505973e-10 	 residual l2 norm: 2.177754542551934e-10
# epoch:  49	======TIME=======f and u^3 terms time : 0.0011148452758789062
# ======TIME=======stiffness matrix terms time : 0.021263599395751953
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02253127098083496
# assembling the matrix time taken:  0.0001697540283203125
# solving Ax = b time taken:  0.00275421142578125
# total size: 49 1000000 = 49000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:49.54117929948138 	 residual l2 norm: 0.007747620282640735
# newton iteration:  2
# sol_update_l2_norm:0.003119574833914276 	 residual l2 norm: 0.0004270819574704752
# newton iteration:  3
# sol_update_l2_norm:2.550132466757833e-10 	 residual l2 norm: 9.020891367058982e-11
# converged at iteration:  3
# sol_update_l2_norm:2.550132466757833e-10 	 residual l2 norm: 9.020891367058982e-11
# epoch:  50	======TIME=======f and u^3 terms time : 0.0011138916015625
# ======TIME=======stiffness matrix terms time : 0.021344661712646484
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.022611379623413086
# assembling the matrix time taken:  0.00016498565673828125
# solving Ax = b time taken:  0.002800464630126953
# total size: 50 1000000 = 50000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:57.689104996524975 	 residual l2 norm: 0.005813372222542507
# newton iteration:  2
# sol_update_l2_norm:0.0021501291296697972 	 residual l2 norm: 0.00021777709549884074
# newton iteration:  3
# sol_update_l2_norm:5.547308974510258e-11 	 residual l2 norm: 7.984693468325425e-11
# converged at iteration:  3
# sol_update_l2_norm:5.547308974510258e-11 	 residual l2 norm: 7.984693468325425e-11
# epoch:  51	======TIME=======f and u^3 terms time : 0.001224517822265625
# ======TIME=======stiffness matrix terms time : 0.021379947662353516
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.022755861282348633
# assembling the matrix time taken:  0.0001666545867919922
# solving Ax = b time taken:  0.002835988998413086
# total size: 51 1000000 = 51000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:37.574235628506294 	 residual l2 norm: 0.009756352984682987
# newton iteration:  2
# sol_update_l2_norm:0.001670994229729918 	 residual l2 norm: 0.0004159291820468439
# newton iteration:  3
# sol_update_l2_norm:1.0817106015940336e-10 	 residual l2 norm: 1.379982535517693e-10
# converged at iteration:  3
# sol_update_l2_norm:1.0817106015940336e-10 	 residual l2 norm: 1.379982535517693e-10
# epoch:  52	======TIME=======f and u^3 terms time : 0.0011315345764160156
# ======TIME=======stiffness matrix terms time : 0.021404743194580078
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02269148826599121
# assembling the matrix time taken:  0.00017499923706054688
# solving Ax = b time taken:  0.0028738975524902344
# total size: 52 1000000 = 52000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:25.26805676270598 	 residual l2 norm: 0.004566141553527656
# newton iteration:  2
# sol_update_l2_norm:0.001542748477525642 	 residual l2 norm: 0.0002223335499867548
# newton iteration:  3
# sol_update_l2_norm:1.3456078579386672e-10 	 residual l2 norm: 2.487722912844747e-11
# converged at iteration:  3
# sol_update_l2_norm:1.3456078579386672e-10 	 residual l2 norm: 2.487722912844747e-11
# epoch:  53	======TIME=======f and u^3 terms time : 0.0011103153228759766
# ======TIME=======stiffness matrix terms time : 0.021342754364013672
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.022602319717407227
# assembling the matrix time taken:  0.00017404556274414062
# solving Ax = b time taken:  0.0029375553131103516
# total size: 53 1000000 = 53000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:27.80742862728076 	 residual l2 norm: 0.003298465747634518
# newton iteration:  2
# sol_update_l2_norm:0.0006340900385659686 	 residual l2 norm: 6.356762650440034e-05
# newton iteration:  3
# sol_update_l2_norm:8.005076963969824e-12 	 residual l2 norm: 6.66551538673978e-12
# converged at iteration:  3
# sol_update_l2_norm:8.005076963969824e-12 	 residual l2 norm: 6.66551538673978e-12
# epoch:  54	======TIME=======f and u^3 terms time : 0.0011341571807861328
# ======TIME=======stiffness matrix terms time : 0.021366119384765625
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.022660017013549805
# assembling the matrix time taken:  0.00017642974853515625
# solving Ax = b time taken:  0.0030045509338378906
# total size: 54 1000000 = 54000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:25.096887989372867 	 residual l2 norm: 0.003187346878807644
# newton iteration:  2
# sol_update_l2_norm:0.0005154592942309754 	 residual l2 norm: 0.0001160411916215077
# newton iteration:  3
# sol_update_l2_norm:1.3681615812216977e-11 	 residual l2 norm: 1.4325747281368664e-11
# converged at iteration:  3
# sol_update_l2_norm:1.3681615812216977e-11 	 residual l2 norm: 1.4325747281368664e-11
# epoch:  55	======TIME=======f and u^3 terms time : 0.0011196136474609375
# ======TIME=======stiffness matrix terms time : 0.02135920524597168
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02263641357421875
# assembling the matrix time taken:  0.00016808509826660156
# solving Ax = b time taken:  0.0030519962310791016
# total size: 55 1000000 = 55000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:43.55328160848357 	 residual l2 norm: 0.00415389245118684
# newton iteration:  2
# sol_update_l2_norm:0.0008727153858658015 	 residual l2 norm: 0.0001718991310323916
# newton iteration:  3
# sol_update_l2_norm:4.7291750620364096e-11 	 residual l2 norm: 4.718642428008542e-11
# converged at iteration:  3
# sol_update_l2_norm:4.7291750620364096e-11 	 residual l2 norm: 4.718642428008542e-11
# epoch:  56	======TIME=======f and u^3 terms time : 0.001135110855102539
# ======TIME=======stiffness matrix terms time : 0.021446704864501953
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.022739171981811523
# assembling the matrix time taken:  0.00017881393432617188
# solving Ax = b time taken:  0.003095865249633789
# total size: 56 1000000 = 56000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:21.101958561470624 	 residual l2 norm: 0.002711192005608684
# newton iteration:  2
# sol_update_l2_norm:0.0004885656503628695 	 residual l2 norm: 6.190229146507009e-05
# newton iteration:  3
# sol_update_l2_norm:8.8622124408363e-12 	 residual l2 norm: 7.619305715651763e-12
# converged at iteration:  3
# sol_update_l2_norm:8.8622124408363e-12 	 residual l2 norm: 7.619305715651763e-12
# epoch:  57	======TIME=======f and u^3 terms time : 0.0011210441589355469
# ======TIME=======stiffness matrix terms time : 0.021384239196777344
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.022661447525024414
# assembling the matrix time taken:  0.00022149085998535156
# solving Ax = b time taken:  0.003114938735961914
# total size: 57 1000000 = 57000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:34.55703107105579 	 residual l2 norm: 0.0029303393182827965
# newton iteration:  2
# sol_update_l2_norm:0.0005436500074045142 	 residual l2 norm: 9.51834906716313e-05
# newton iteration:  3
# sol_update_l2_norm:6.217751068981608e-12 	 residual l2 norm: 1.2751955661817255e-12
# converged at iteration:  3
# ...
# ======TIME=======stiffness matrix terms time : 0.023021459579467773
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02435612678527832
# assembling the matrix time taken:  0.00017189979553222656
# solving Ax = b time taken:  0.006911277770996094
# total size: 111 1000000 = 111000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:25.847010022758262 	 residual l2 norm: 0.0004270013260163316
# newton iteration:  2
# sol_update_l2_norm:7.955928717541253e-05 	 residual l2 norm: 1.684514197475536e-05
# newton iteration:  3
# sol_update_l2_norm:8.628688267784549e-11 	 residual l2 norm: 1.3584132607734492e-12
# converged at iteration:  3
# sol_update_l2_norm:8.628688267784549e-11 	 residual l2 norm: 1.3584132607734492e-12
# epoch:  112	======TIME=======f and u^3 terms time : 0.0012540817260742188
# ======TIME=======stiffness matrix terms time : 0.023059368133544922
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02448272705078125
# assembling the matrix time taken:  0.0001742839813232422
# solving Ax = b time taken:  0.006910085678100586
# total size: 112 1000000 = 112000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:50.997304388270706 	 residual l2 norm: 0.0003858202268943168
# newton iteration:  2
# sol_update_l2_norm:0.00022151076302884522 	 residual l2 norm: 6.518593149453554e-06
# newton iteration:  3
# sol_update_l2_norm:8.282389932382968e-11 	 residual l2 norm: 1.551962609998893e-12
# converged at iteration:  3
# sol_update_l2_norm:8.282389932382968e-11 	 residual l2 norm: 1.551962609998893e-12
# epoch:  113	======TIME=======f and u^3 terms time : 0.0011670589447021484
# ======TIME=======stiffness matrix terms time : 0.026245594024658203
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02760481834411621
# assembling the matrix time taken:  0.0001659393310546875
# solving Ax = b time taken:  0.0069997310638427734
# total size: 113 1000000 = 113000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:75.28040660397843 	 residual l2 norm: 0.00034967832949200933
# newton iteration:  2
# sol_update_l2_norm:0.0008195260028892696 	 residual l2 norm: 9.163395224328132e-05
# newton iteration:  3
# sol_update_l2_norm:8.80172288545831e-11 	 residual l2 norm: 1.4902709863242865e-11
# converged at iteration:  3
# sol_update_l2_norm:8.80172288545831e-11 	 residual l2 norm: 1.4902709863242865e-11
# epoch:  114	======TIME=======f and u^3 terms time : 0.0012562274932861328
# ======TIME=======stiffness matrix terms time : 0.026302576065063477
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.027730941772460938
# assembling the matrix time taken:  0.0001735687255859375
# solving Ax = b time taken:  0.00700831413269043
# total size: 114 1000000 = 114000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:48.36833515470097 	 residual l2 norm: 0.0005196809307178344
# newton iteration:  2
# sol_update_l2_norm:0.00021330678029904813 	 residual l2 norm: 1.4256645088465022e-05
# newton iteration:  3
# sol_update_l2_norm:3.234925659219173e-11 	 residual l2 norm: 2.0836083009019937e-12
# converged at iteration:  3
# sol_update_l2_norm:3.234925659219173e-11 	 residual l2 norm: 2.0836083009019937e-12
# epoch:  115	======TIME=======f and u^3 terms time : 0.0011730194091796875
# ======TIME=======stiffness matrix terms time : 0.02632284164428711
# ======TIME=======neumann bd terms time : 9.5367431640625e-07
# =======> argmax subproblem time:  0.027664899826049805
# assembling the matrix time taken:  0.000164031982421875
# solving Ax = b time taken:  0.00710749626159668
# total size: 115 1000000 = 115000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:53.125904141055635 	 residual l2 norm: 0.0003677357842337922
# newton iteration:  2
# sol_update_l2_norm:0.0003423537001758833 	 residual l2 norm: 9.519780111217083e-06
# newton iteration:  3
# sol_update_l2_norm:3.000434476408167e-11 	 residual l2 norm: 6.558981946351738e-13
# converged at iteration:  3
# sol_update_l2_norm:3.000434476408167e-11 	 residual l2 norm: 6.558981946351738e-13
# epoch:  116	======TIME=======f and u^3 terms time : 0.0011703968048095703
# ======TIME=======stiffness matrix terms time : 0.02635478973388672
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.027715444564819336
# assembling the matrix time taken:  0.00017070770263671875
# solving Ax = b time taken:  0.007127523422241211
# total size: 116 1000000 = 116000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:17.823866890548008 	 residual l2 norm: 0.0003152945813027687
# newton iteration:  2
# sol_update_l2_norm:4.95225239608627e-05 	 residual l2 norm: 3.3040741006463263e-06
# newton iteration:  3
# sol_update_l2_norm:1.9450590629867317e-11 	 residual l2 norm: 4.687606970093398e-13
# converged at iteration:  3
# sol_update_l2_norm:1.9450590629867317e-11 	 residual l2 norm: 4.687606970093398e-13
# epoch:  117	======TIME=======f and u^3 terms time : 0.0011413097381591797
# ======TIME=======stiffness matrix terms time : 0.02315998077392578
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.024468660354614258
# assembling the matrix time taken:  0.00016450881958007812
# solving Ax = b time taken:  0.007194995880126953
# total size: 117 1000000 = 117000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:23.952701479984142 	 residual l2 norm: 0.00026986726533654334
# newton iteration:  2
# sol_update_l2_norm:6.395870604088004e-05 	 residual l2 norm: 7.192231166191831e-07
# newton iteration:  3
# sol_update_l2_norm:4.445300948017188e-11 	 residual l2 norm: 1.4213707346947846e-12
# converged at iteration:  3
# sol_update_l2_norm:4.445300948017188e-11 	 residual l2 norm: 1.4213707346947846e-12
# epoch:  118	======TIME=======f and u^3 terms time : 0.00115966796875
# ======TIME=======stiffness matrix terms time : 0.023221492767333984
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.024558305740356445
# assembling the matrix time taken:  0.0001621246337890625
# solving Ax = b time taken:  0.007238864898681641
# total size: 118 1000000 = 118000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:73.33985467000666 	 residual l2 norm: 0.000276652866220907
# newton iteration:  2
# sol_update_l2_norm:0.00016656821611065885 	 residual l2 norm: 2.5497045593136234e-05
# newton iteration:  3
# sol_update_l2_norm:3.406313414917023e-11 	 residual l2 norm: 5.976848599290014e-13
# converged at iteration:  3
# sol_update_l2_norm:3.406313414917023e-11 	 residual l2 norm: 5.976848599290014e-13
# epoch:  119	======TIME=======f and u^3 terms time : 0.0011370182037353516
# ======TIME=======stiffness matrix terms time : 0.023265838623046875
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.02468395233154297
# assembling the matrix time taken:  0.00016570091247558594
# solving Ax = b time taken:  0.007272005081176758
# total size: 119 1000000 = 119000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:12.909886773097767 	 residual l2 norm: 0.00027181090153758784
# newton iteration:  2
# sol_update_l2_norm:3.3492939401937685e-05 	 residual l2 norm: 1.0344597592889226e-06
# newton iteration:  3
# sol_update_l2_norm:3.619501098602926e-11 	 residual l2 norm: 2.040212363332361e-12
# converged at iteration:  3
# sol_update_l2_norm:3.619501098602926e-11 	 residual l2 norm: 2.040212363332361e-12
# epoch:  120	======TIME=======f and u^3 terms time : 0.0011301040649414062
# ======TIME=======stiffness matrix terms time : 0.02332448959350586
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02462148666381836
# assembling the matrix time taken:  0.00016355514526367188
# solving Ax = b time taken:  0.00732111930847168
# total size: 120 1000000 = 120000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:34.29976389792156 	 residual l2 norm: 0.00027826791109056807
# newton iteration:  2
# sol_update_l2_norm:7.151458032882718e-05 	 residual l2 norm: 4.486294404206705e-06
# newton iteration:  3
# sol_update_l2_norm:7.388906766464032e-11 	 residual l2 norm: 8.063835016943161e-13
# converged at iteration:  3
# sol_update_l2_norm:7.388906766464032e-11 	 residual l2 norm: 8.063835016943161e-13
# epoch:  121	======TIME=======f and u^3 terms time : 0.0012121200561523438
# ======TIME=======stiffness matrix terms time : 0.02652454376220703
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02790689468383789
# assembling the matrix time taken:  0.00017881393432617188
# solving Ax = b time taken:  0.0073587894439697266
# total size: 121 1000000 = 121000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:24.520566100106297 	 residual l2 norm: 0.0002222623834699619
# newton iteration:  2
# sol_update_l2_norm:2.9740001587630777e-05 	 residual l2 norm: 7.661923280214365e-06
# newton iteration:  3
# sol_update_l2_norm:3.1844622793766635e-11 	 residual l2 norm: 8.462065311263194e-13
# converged at iteration:  3
# sol_update_l2_norm:3.1844622793766635e-11 	 residual l2 norm: 8.462065311263194e-13
# epoch:  122	======TIME=======f and u^3 terms time : 0.00118255615234375
# ======TIME=======stiffness matrix terms time : 0.023398876190185547
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.024916410446166992
# assembling the matrix time taken:  0.0001761913299560547
# solving Ax = b time taken:  0.007397890090942383
# total size: 122 1000000 = 122000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:57.412913265944034 	 residual l2 norm: 0.000319812680696411
# newton iteration:  2
# sol_update_l2_norm:0.0003359612797043747 	 residual l2 norm: 5.1963681932593344e-06
# newton iteration:  3
# sol_update_l2_norm:5.6883098994642655e-11 	 residual l2 norm: 7.123881661122451e-13
# converged at iteration:  3
# sol_update_l2_norm:5.6883098994642655e-11 	 residual l2 norm: 7.123881661122451e-13
# epoch:  123	======TIME=======f and u^3 terms time : 0.0011887550354003906
# ======TIME=======stiffness matrix terms time : 0.023345232009887695
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.024705886840820312
# assembling the matrix time taken:  0.0001647472381591797
# solving Ax = b time taken:  0.007447004318237305
# total size: 123 1000000 = 123000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:46.333457388972995 	 residual l2 norm: 0.0002630806141862867
# newton iteration:  2
# sol_update_l2_norm:8.726402845410391e-05 	 residual l2 norm: 2.3179794329216553e-06
# newton iteration:  3
# sol_update_l2_norm:8.374264278072867e-11 	 residual l2 norm: 2.4419757433822946e-12
# converged at iteration:  3
# sol_update_l2_norm:8.374264278072867e-11 	 residual l2 norm: 2.4419757433822946e-12
# epoch:  124	======TIME=======f and u^3 terms time : 0.0012440681457519531
# ======TIME=======stiffness matrix terms time : 0.023329973220825195
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.024745941162109375
# assembling the matrix time taken:  0.00016689300537109375
# solving Ax = b time taken:  0.007482767105102539
# total size: 124 1000000 = 124000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:32.69839699539918 	 residual l2 norm: 0.0003233713889806698
# newton iteration:  2
# sol_update_l2_norm:6.368856460884515e-05 	 residual l2 norm: 1.5908471415485726e-05
# newton iteration:  3
# sol_update_l2_norm:3.9185433273019695e-11 	 residual l2 norm: 1.887328297573768e-12
# converged at iteration:  3
# sol_update_l2_norm:3.9185433273019695e-11 	 residual l2 norm: 1.887328297573768e-12
# epoch:  125	======TIME=======f and u^3 terms time : 0.0011591911315917969
# ======TIME=======stiffness matrix terms time : 0.023413896560668945
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.024892807006835938
# assembling the matrix time taken:  0.00017333030700683594
# solving Ax = b time taken:  0.007532596588134766
# total size: 125 1000000 = 125000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:14.05352694431333 	 residual l2 norm: 0.000387807741857618
# newton iteration:  2
# sol_update_l2_norm:2.611207878973738e-05 	 residual l2 norm: 3.996282995614491e-06
# newton iteration:  3
# sol_update_l2_norm:3.813570565511454e-11 	 residual l2 norm: 1.8510771554339084e-12
# converged at iteration:  3
# sol_update_l2_norm:3.813570565511454e-11 	 residual l2 norm: 1.8510771554339084e-12
# epoch:  126	======TIME=======f and u^3 terms time : 0.0012478828430175781
# ======TIME=======stiffness matrix terms time : 0.026926755905151367
# ======TIME=======neumann bd terms time : 7.152557373046875e-07
# =======> argmax subproblem time:  0.028339147567749023
# assembling the matrix time taken:  0.00016808509826660156
# solving Ax = b time taken:  0.007543325424194336
# total size: 126 1000000 = 126000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:16.056108319894076 	 residual l2 norm: 0.00028098272995778436
# newton iteration:  2
# sol_update_l2_norm:3.648561424968245e-05 	 residual l2 norm: 5.32815520306832e-06
# newton iteration:  3
# sol_update_l2_norm:6.256677139696513e-11 	 residual l2 norm: 1.274281672591281e-12
# converged at iteration:  3
# sol_update_l2_norm:6.256677139696513e-11 	 residual l2 norm: 1.274281672591281e-12
# epoch:  127	======TIME=======f and u^3 terms time : 0.0011663436889648438
# ======TIME=======stiffness matrix terms time : 0.023628950119018555
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02496337890625
# assembling the matrix time taken:  0.0001647472381591797
# solving Ax = b time taken:  0.007612466812133789
# total size: 127 1000000 = 127000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:34.30422922520548 	 residual l2 norm: 0.00027470989713213777
# newton iteration:  2
# sol_update_l2_norm:4.7631566678164095e-05 	 residual l2 norm: 1.105984669198834e-05
# newton iteration:  3
# sol_update_l2_norm:5.5964722179648564e-11 	 residual l2 norm: 1.6554254458336307e-12
# converged at iteration:  3
# sol_update_l2_norm:5.5964722179648564e-11 	 residual l2 norm: 1.6554254458336307e-12
# epoch:  128	======TIME=======f and u^3 terms time : 0.0011510848999023438
# ======TIME=======stiffness matrix terms time : 0.027070283889770508
# ======TIME=======neumann bd terms time : 4.76837158203125e-07
# =======> argmax subproblem time:  0.02840876579284668
# assembling the matrix time taken:  0.0001735687255859375
# solving Ax = b time taken:  0.007635593414306641
# total size: 128 1000000 = 128000000
# num batches:  1
# newton iteration:  1
# sol_update_l2_norm:29.197999550071604 	 residual l2 norm: 0.00023089979782647143
# newton iteration:  2
# sol_update_l2_norm:5.333644114064348e-05 	 residual l2 norm: 5.768057386287419e-06
# newton iteration:  3
# sol_update_l2_norm:4.1910326542173285e-11 	 residual l2 norm: 2.8126170226742727e-12
# converged at iteration:  3
# sol_update_l2_norm:4.1910326542173285e-11 	 residual l2 norm: 2.8126170226742727e-12
# time taken:  31.799713611602783
# neuron num 		 error 		 order
# 4 		 0.354711 		 * 		 6.662283 		 *
#
# 8 		 0.353662 		 0.004272 		 6.661078 		 0.000261
#
# 16 		 0.352766 		 0.003660 		 6.619183 		 0.009103
#
# 32 		 0.253861 		 0.474671 		 5.051937 		 0.389817
#
# 64 		 0.080530 		 1.656446 		 2.242332 		 1.171837
#
# 128 		 0.017442 		 2.206955 		 0.663695 		 1.756408
#
# neuron num  & 	 $\|u-u_n \|_{L^2}$ & 	 order $O(n^{-1.67})$ & 	 $ | u -u_n |_{H^1}$ & 	 order $O(n^{-1.33})$ \\ \hline \hline
# 4 		 & 0.354711 &		 * & 		 6.662283 & 		 *  \\ \hline
#
# 8 		 &  3.537e-01 &  		 0.00 &  		 6.661e+00 &  		 0.00 \\ \hline
#
# 16 		 &  3.528e-01 &  		 0.00 &  		 6.619e+00 &  		 0.01 \\ \hline
#
# 32 		 &  2.539e-01 &  		 0.47 &  		 5.052e+00 &  		 0.39 \\ \hline
#
# 64 		 &  8.053e-02 &  		 1.66 &  		 2.242e+00 &  		 1.17 \\ \hline
#
# 128 		 &  1.744e-02 &  		 2.21 &  		 6.637e-01 &  		 1.76 \\ \hline

# %% [markdown]
# ## Test Neumann problem

# %%
def test_linear_neumann():

    def u_exact(x):
        return torch.cos(pi*x[:,0:1])*torch.cos( pi*x[:,1:2]) * torch.cos(pi*x[:,2:3])  
    def alpha(x): 
        return torch.ones(x.size(0),1).to(device)

    def u_exact_grad():
        d = 3 
        def grad_1(x):
            return - pi* torch.sin(pi*x[:,0:1])*torch.cos( pi*x[:,1:2]) * torch.cos(pi*x[:,2:3])   
        def grad_2(x):
            return - pi* torch.cos(pi*x[:,0:1])*torch.sin( pi*x[:,1:2]) * torch.cos(pi*x[:,2:3])  
        def grad_3(x):
            return - pi* torch.cos(pi*x[:,0:1])*torch.cos( pi*x[:,1:2]) * torch.sin(pi*x[:,2:3])   
        
        u_grad=[grad_1, grad_2,grad_3] 

        return u_grad

    def target(x):
        z = (  3 * (pi)**2 + 1)*torch.cos( pi*x[:,0:1])*torch.cos( pi*x[:,1:2] ) * torch.cos(pi*x[:,2:3]) 
        return z 

    g_N = None 
    
    def g_N(dim):
        u_grad = u_exact_grad() 
        bcs_N = []
        for i in range(dim):
            bcs_N.append((i, u_grad[i]))
        return bcs_N
    
    integration_weights, integration_points = PiecewiseGQ3D_weights_points(50, 3)
    weights_bd, pts_bd = Neumann_boundary_quadrature_points_weights(M = 999,d =3)   
    err_l2_list = [] 
    for neuron_num in [10,20,40,80]: 
        my_model = model(3, neuron_num, 1, k = 1).to(device) 
        my_model = adjust_neuron_position(my_model.cpu(),3).to(device) 
        sol = minimize_linear_layer_H1_explicit_assemble_efficient(my_model,alpha, target,  \
                            g_N, integration_weights, integration_points, w_bd = weights_bd, pts_bd = pts_bd, \
                            activation = 'relu',solver="direct" ,memory=2**29)
        my_model.fc2.weight.data[0,:] = sol[:] 
        diff_sqrd = (my_model(integration_points).detach() - u_exact(integration_points))**2
        err_l2 = torch.sqrt(torch.sum(integration_weights * diff_sqrd)) 
        print(err_l2)
        err_l2_list.append(err_l2) 
    print(err_l2_list) 


def test_linear_neumann2():

    def u_exact(x):
        return torch.sin(pi*x[:,0:1])*torch.sin( pi*x[:,1:2]) * torch.sin(pi*x[:,2:3])  
    def alpha(x): 
        return torch.ones(x.size(0),1).to(device)

    def u_exact_grad():
        d = 3 
        def grad_1(x):
            return  pi* torch.cos(pi*x[:,0:1])*torch.sin( pi*x[:,1:2]) * torch.sin(pi*x[:,2:3])   
        def grad_2(x):
            return pi* torch.sin(pi*x[:,0:1])*torch.cos( pi*x[:,1:2]) * torch.sin(pi*x[:,2:3])  
        def grad_3(x):
            return pi* torch.sin(pi*x[:,0:1])*torch.sin( pi*x[:,1:2]) * torch.cos(pi*x[:,2:3])   
        
        u_grad=[grad_1, grad_2,grad_3] 

        return u_grad
    def laplace_u_exact(x):
        return - 3*pi**2 * torch.sin(pi*x[:,0:1])*torch.sin( pi*x[:,1:2]) * torch.sin(pi*x[:,2:3])
    
    def target(x):
        return - laplace_u_exact(x) + u_exact(x) 
    
    def g_N(dim):
        u_grad = u_exact_grad() 
        bcs_N = []
        for i in range(dim):
            bcs_N.append((i, u_grad[i]))
        return bcs_N
    
    integration_weights, integration_points = PiecewiseGQ3D_weights_points(25, 3)
    weights_bd, pts_bd = Neumann_boundary_quadrature_points_weights(M = 999,d =3)   
    err_l2_list = [] 
    for neuron_num in [10,20,40,80]: 
        my_model = model(3, neuron_num, 1, k = 1).to(device) 
        my_model = adjust_neuron_position(my_model.cpu(),3).to(device) 
        sol = minimize_linear_layer_H1_explicit_assemble_efficient(my_model,alpha, target,  \
                            g_N, integration_weights, integration_points, w_bd = weights_bd, pts_bd = pts_bd, \
                            activation = 'relu',solver="direct" ,memory=2**29)
        my_model.fc2.weight.data[0,:] = sol[:] 
        diff_sqrd = (my_model(integration_points).detach() - u_exact(integration_points))**2
        err_l2 = torch.sqrt(torch.sum(integration_weights * diff_sqrd)) 
        print(err_l2)
        err_l2_list.append(err_l2) 
    print(err_l2_list) 

# print("test zero flux")
# # test_linear_neumann() # zero flux 
# print()

# print("test non-zero flux")
# test_linear_neumann2() # with non-zero flux

# %%
def test_linear_neumann3(): 
    freq = 2
    sigma = 0.15 
    def gaussian(x):
        return torch.exp(-torch.sum( (x - 0.5)**2,dim=1,keepdim=True)/(2 *sigma**2) ) 
    def gaussian_grad_1(x):
        return  gaussian(x) * (- (x[:,0:1] - 0.5)/(sigma**2) ) 
    def gaussian_grad_2(x):
        return  gaussian(x) * (- (x[:,1:2] - 0.5)/(sigma**2) ) 
    def gaussian_grad_3(x):
        return  gaussian(x) * (- (x[:,2:3] - 0.5)/(sigma**2) ) 
    
    def u_exact(x):
        return gaussian(x) * torch.cos(2*pi*freq*x[:,0:1]) 
    def alpha(x): 
        return torch.ones(x.size(0),1).to(device)

    def u_grad_1(x):
        return  torch.cos(2*pi*freq*x[:,0:1]) *gaussian_grad_1(x) \
                - 2*pi*freq * torch.sin(2*pi*freq*x[:,0:1]) * gaussian(x) 
    def u_grad_2(x):
        return torch.cos(2*pi*freq*x[:,0:1]) * gaussian_grad_2(x)
    def u_grad_3(x):
        return  torch.cos(2*pi*freq*x[:,0:1]) * gaussian_grad_3(x)

    def u_exact_grad():
        d = 3 
        def u_grad_1(x):
            return  torch.cos(2*pi*freq*x[:,0:1]) *gaussian_grad_1(x) \
                    - 2*pi*freq * torch.sin(2*pi*freq*x[:,0:1]) * gaussian(x) 
        def u_grad_2(x):
            return torch.cos(2*pi*freq*x[:,0:1]) * gaussian_grad_2(x)
        def u_grad_3(x):
            return  torch.cos(2*pi*freq*x[:,0:1]) * gaussian_grad_3(x)

        u_grad=[u_grad_1, u_grad_2,u_grad_3] 
        return u_grad
    
    def laplace_u_exact(x):
        return - 2*pi*freq * torch.sin(2*pi*freq*x[:,0:1]) *gaussian_grad_1(x) \
                + torch.cos(2*pi*freq*x[:,0:1])*( gaussian(x) * ( ((x[:,0:1] - 0.5)/(sigma**2))**2 -1/(sigma**2))  ) \
                -( (2*pi*freq)**2 * torch.cos(2*pi*freq*x[:,0:1]) * gaussian(x) + (2*pi*freq)*torch.sin(2*pi*freq*x[:,0:1]) * gaussian_grad_1(x) ) \
                + torch.cos(2*pi*freq*x[:,0:1]) * (gaussian(x) * ( ((x[:,1:2] - 0.5)/(sigma**2))**2 -1/(sigma**2) )  ) \
                + torch.cos(2*pi*freq*x[:,0:1]) * ( gaussian(x) * ( ((x[:,2:3] - 0.5)/(sigma**2))**2 -1/(sigma**2) )   ) \

    def target(x):
        return - laplace_u_exact(x) + u_exact(x)**3  
    
    def g_N(dim):
        u_grad = u_exact_grad() 
        bcs_N = []
        for i in range(dim):
            bcs_N.append((i, u_grad[i]))
        return bcs_N
    
    
    integration_weights, integration_points = PiecewiseGQ3D_weights_points(50, 3)
    weights_bd, pts_bd = Neumann_boundary_quadrature_points_weights(M = 999,d =3)   
    err_l2_list = [] 
    for neuron_num in [160,320]: 
        my_model = model(3, neuron_num, 1, k = 1).to(device) 
        my_model = adjust_neuron_position(my_model.cpu(),3).to(device) 
        sol = minimize_linear_layer_H1_explicit_assemble_efficient(my_model,alpha, target,  \
                            g_N, integration_weights, integration_points, w_bd = weights_bd, pts_bd = pts_bd, \
                            activation = 'relu',solver="direct" ,memory=2**29)
        my_model.fc2.weight.data[0,:] = sol[:] 
        diff_sqrd = (my_model(integration_points).detach() - u_exact(integration_points))**2
        err_l2 = torch.sqrt(torch.sum(integration_weights * diff_sqrd)) 
        print(err_l2)
        err_l2_list.append(err_l2) 
    print(err_l2_list) 
# test_linear_neumann3()

# %% [markdown]
# ## Test Newton solver

# %%
def test_nonlinear_cubic():
    freq = 2 

    def u_exact(x):
        return torch.sin(pi*x[:,0:1])*torch.sin( pi*x[:,1:2]) * torch.sin(pi*x[:,2:3])  
    def alpha(x): 
        return torch.ones(x.size(0),1).to(device)

    def u_exact_grad():
        d = 3 
        def grad_1(x):
            return  pi* torch.cos(pi*x[:,0:1])*torch.sin( pi*x[:,1:2]) * torch.sin(pi*x[:,2:3])   
        def grad_2(x):
            return pi* torch.sin(pi*x[:,0:1])*torch.cos( pi*x[:,1:2]) * torch.sin(pi*x[:,2:3])  
        def grad_3(x):
            return pi* torch.sin(pi*x[:,0:1])*torch.sin( pi*x[:,1:2]) * torch.cos(pi*x[:,2:3])   
        
        u_grad=[grad_1, grad_2,grad_3] 

        return u_grad
    def laplace_u_exact(x):
        return - 3*pi**2 * torch.sin(pi*x[:,0:1])*torch.sin( pi*x[:,1:2]) * torch.sin(pi*x[:,2:3])
    
    def target(x):
        return - laplace_u_exact(x) + nonlinear(u_exact(x)) 
    
    def g_N(dim):
        u_grad = u_exact_grad() 
        bcs_N = []
        for i in range(dim):
            bcs_N.append((i, u_grad[i]))
        return bcs_N
    
    def u_exact_approx(x):
        return 0.7 * u_exact(x)

    def rhs(x):
        return  -laplace_u_exact(x) + nonlinear(u_exact(x)) 

    
    err_l2_list = [] 
    err_h10_list = []  
    weights, integration_points = PiecewiseGQ3D_weights_points(40, order = 3) 
    weights_bd, integration_points_bd = Neumann_boundary_quadrature_points_weights(999, d = 3) 
#     weights_bd, integration_points_bd = None, None   
    for neuron_num in [16,32,64,128,256]: 
        my_model = model(3, neuron_num, 1, k = 3).to(device) 
        my_model = adjust_neuron_position(my_model.cpu(),3).to(device)
        sol = minimize_linear_layer_explicit_assemble(my_model,u_exact_approx,weights, integration_points,solver="direct")
        # sol = minimize_linear_layer_neumann(my_model,rhs_neumann,weights, integration_points,activation = 'relu', solver = 'direct')
        my_model.fc2.weight.data[0,:] = sol[0,:]   
        sol = minimize_linear_layer_newton_method(my_model,alpha,rhs, \
                    weights, integration_points,weights_bd, integration_points_bd,\
                     g_N,activation = 'relu',solver="direct",memory=2**29) 
        my_model.fc2.weight.data[0,:] = sol[0,:]
        # plot_2D(my_model)
        diff_sqrd = (my_model(integration_points).detach() - u_exact(integration_points))**2
        err_l2 = (weights.t() @ diff_sqrd)**0.5 
        err_l2_list.append(err_l2)
    print(err_l2_list)   
    return 0 
    
test_nonlinear_cubic()
