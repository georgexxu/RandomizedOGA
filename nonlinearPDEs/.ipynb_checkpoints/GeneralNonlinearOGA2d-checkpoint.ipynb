# %%
import torch
import numpy as np
import math 
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import time
import sys
import os 
from scipy.sparse import linalg
from pathlib import Path
import itertools
if torch.cuda.is_available():  
    device = "cuda" 
else:
    device = "cpu" 

torch.set_default_dtype(torch.float64)
pi = torch.tensor(np.pi,dtype=torch.float64)
ZERO = torch.tensor([0.]).to(device)

class model(nn.Module):
    """ ReLU k shallow neural network
    Parameters: 
    input size: input dimension
    hidden_size1 : number of hidden layers 
    num_classes: output classes 
    k: degree of relu functions
    """
    def __init__(self, input_size, hidden_size1, num_classes,k = 1):
        super().__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, num_classes,bias = False)
        self.k = k 
    def forward(self, x):
        u1 = self.fc2(F.relu(self.fc1(x))**self.k)
        return u1
    def evaluate_derivative(self, x, i):
        if self.k == 1:
            u1 = self.fc2(torch.heaviside(self.fc1(x),ZERO) * self.fc1.weight.t()[i-1:i,:] )
        else:
            u1 = self.fc2(self.k*F.relu(self.fc1(x))**(self.k-1) *self.fc1.weight.t()[i-1:i,:] )  
        return u1

def plot_2D(f): 
    
    Nx = 400
    Ny = 400 
    xs = np.linspace(0, 1, Nx)
    ys = np.linspace(0, 1, Ny)
    x, y = np.meshgrid(xs, ys, indexing='xy')
    xy_comb = np.stack((x.flatten(),y.flatten())).T
    xy_comb = torch.tensor(xy_comb)
    z = f(xy_comb).reshape(Nx,Ny)
    z = z.detach().numpy()
    plt.figure(dpi=200)
    ax = plt.axes(projection='3d')
    ax.plot_surface(x , y , z )

    plt.show()

def plot_subdomains(my_model):
    x_coord =torch.linspace(0,1,200)
    wi = my_model.fc1.weight.data
    bi = my_model.fc1.bias.data 
    for i, bias in enumerate(bi):  
        if wi[i,1] !=0: 
            plt.plot(x_coord, - wi[i,0]/wi[i,1]*x_coord - bias/wi[i,1])
        else: 
            plt.plot(x_coord,  - bias/wi[i,0]*torch.ones(x_coord.size()))

    plt.xlim([0,1])
    plt.ylim([0,1])
    plt.legend()
    plt.show()
    return 0   

## Initialization
def adjust_neuron_position(my_model,target=None):
    counter = 0 
    positions = torch.tensor([[0.,0.],[0.,1.],[1.,1.],[1.,0.]]).to(device)
    neuron_num = my_model.fc1.bias.size(0)
    for i in range(neuron_num): 
        w = my_model.fc1.weight.data[i:i+1,:]
        b = my_model.fc1.bias.data[i]
        values = torch.matmul(positions,w.T) # + b
        left_end = - torch.max(values)
        right_end = - torch.min(values) 
        off_set = (right_end - left_end)/1000 
        if b <= left_end + off_set: # nearly vanishing
            b = torch.rand(1).to(device)*(right_end - left_end - off_set*2) + left_end + off_set 
            my_model.fc1.bias.data[i] = b 
        if b >= right_end - off_set: # nearly nonvanishing everywhere
            if counter < 3:
                counter += 1
            else: # 3 or more 
                b = torch.rand(1).to(device)*(right_end - left_end - off_set*2) + left_end + off_set
                my_model.fc1.bias.data[i] = b 
    return my_model

# %%
def show_convergence_order2(err_l2,err_h10,exponent,dict_size, filename,write2file = False):
    
    if write2file:
        file_mode = "a" if os.path.exists(filename) else "w"
        f_write = open(filename, file_mode)
    
    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_l2[i] for i in neuron_nums ]
    err_list2 = [err_h10[i] for i in neuron_nums ] 
    # f_write.write('M:{}, relu {} \n'.format(M,k))
    if write2file:
        f_write.write('dictionary size: {}\n'.format(dict_size))
        f_write.write("neuron num \t\t error \t\t order \t\t h10 error \\ order \n")
    print("neuron num \t\t error \t\t order")
    for i, item in enumerate(err_list):
        if i == 0: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t")
            
            # print("*")
            print("{} \t\t {:.6f} \t\t * \t\t {:.6f} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ) )
            if write2file: 
                f_write.write("{} \t\t {} \t\t * \t\t {} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ))
        else: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t") 
            # print(np.log(err_list[i-1]/err_list[i])/np.log(2))
            print("{} \t\t {:.6f} \t\t {:.6f} \t\t {:.6f} \t\t {:.6f} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ) )
            if write2file: 
                f_write.write("{} \t\t {} \t\t {} \t\t {} \t\t {} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ))
    if write2file:     
        f_write.write("\n")
        f_write.close()

def show_convergence_order_latex2(err_l2,err_h10,exponent): 
    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_l2[i] for i in neuron_nums ]
    err_list2 = [err_h10[i] for i in neuron_nums ] 
    # f_write.write('M:{}, relu {} \n'.format(M,k))
    # f_write.write('randomized dictionary size: {}\n'.format(N))
    # f_write.write("neuron num \t\t error \t\t order \t\t h10 error \\ order \n")
    print("neuron num  & \t $\|u-u_n \|_{L^2}$ & \t order & \t $ | u -u_n |_{H^1}$ & \t order \\\ \hline \hline ")
    for i, item in enumerate(err_list):
        if i == 0: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t")

            # print("*")
            print("{} \t\t & {:.6f} &\t\t * & \t\t {:.6f} & \t\t *  \\\ \hline  \n".format(neuron_nums[i],item, err_list2[i] ) )   
            # f_write.write("{} \t\t {} \t\t * \t\t {} \t\t * \n".format(neuron_nums[i],item, err_list2[i] ))
        else: 
            # print(neuron_nums[i], end = "\t\t")
            # print(item, end = "\t\t") 
            # print(np.log(err_list[i-1]/err_list[i])/np.log(2))
            print("{} \t\t &  {:.3e} &  \t\t {:.2f} &  \t\t {:.3e} &  \t\t {:.2f} \\\ \hline  \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ) )
            # f_write.write("{} \t\t {} \t\t {} \t\t {} \t\t {} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ))
    # f_write.write("\n")
    # f_write.close()

# %% [markdown]
# ## Qaudrature rules

# %%
def PiecewiseGQ1D_weights_points(x_l,x_r,Nx, order):
    """ Output the coeffients and weights for piecewise Gauss Quadrature 
    Parameters
    ----------
    x_l : float 
    left endpoint of an interval 
    x_r: float
    right endpoint of an interval 
    Nx: int 
    number of subintervals for integration
    order: int
    order of Gauss Quadrature 
    Returns
    -------
    vectorized quadrature weights and integration points
    """
    x,w = np.polynomial.legendre.leggauss(order)
    gx = torch.tensor(x).to(device)
    gx = gx.view(1,-1) # row vector 
    gw = torch.tensor(w).to(device)    
    gw = gw.view(-1,1) # Column vector 
    nodes = torch.linspace(x_l,x_r,Nx+1).view(-1,1).to(device) 
    coef1 = ((nodes[1:,:] - nodes[:-1,:])/2) # n by 1  
    coef2 = ((nodes[1:,:] + nodes[:-1,:])/2) # n by 1  
    coef2_expand = coef2.expand(-1,gx.size(1)) # Expand to n by p shape, -1: keep the first dimension n , expand the 2nd dim (columns)
    integration_points = coef1@gx + coef2_expand
    integration_points = integration_points.flatten().view(-1,1) # Make it a column vector
    gw_expand = torch.tile(gw,(Nx,1)) # rows: n copies of current tensor, columns: 1 copy, no change
    # Modify coef1 to be compatible with func_values
    coef1_expand = coef1.expand(coef1.size(0),gx.size(1))    
    coef1_expand = coef1_expand.flatten().view(-1,1)
    return coef1_expand.to(device) * gw_expand.to(device), integration_points.to(device)

def PiecewiseGQ2D_weights_points(Nx, order): 
    """ A slight modification of PiecewiseGQ2D function that only needs the weights and integration points.
    Parameters
    ----------

    Nx: int 
        number of intervals along the dimension. No Ny, assume Nx = Ny
    order: int 
        order of the Gauss Quadrature

    Returns
    -------
    long_weights: torch.tensor
    integration_points: torch.tensor
    """

#     print("order: ",order )
    x, w = np.polynomial.legendre.leggauss(order)
    gauss_pts = np.array(np.meshgrid(x,x,indexing='ij')).reshape(2,-1).T
    weights =  (w*w[:,None]).ravel()

    gauss_pts =torch.tensor(gauss_pts)
    weights = torch.tensor(weights)

    h = 1/Nx # 100 intervals 
    long_weights =  torch.tile(weights,(Nx**2,1))
    long_weights = long_weights.reshape(-1,1)
    long_weights = long_weights * h**2 /4 

    integration_points = torch.tile(gauss_pts,(Nx**2,1))
    scale_factor = h/2 
    integration_points = scale_factor * integration_points

    index = np.arange(1,Nx+1)-0.5
    ordered_pairs = np.array(np.meshgrid(index,index,indexing='ij'))
    ordered_pairs = ordered_pairs.reshape(2,-1).T

    # print(ordered_pairs)
    # print()
    ordered_pairs = torch.tensor(ordered_pairs)
    # print(ordered_pairs.size())
    ordered_pairs = torch.tile(ordered_pairs, (1,order**2)) # number of GQ points
    # print(ordered_pairs)

    ordered_pairs =  ordered_pairs.reshape(-1,2)
    # print(ordered_pairs)
    translation = ordered_pairs*h 
    # print(translation)

    integration_points = integration_points + translation 
#     print(integration_points.size())
    # func_values = integrand2_torch(integration_points)
    return long_weights.to(device), integration_points.to(device)

def PiecewiseGQ3D_weights_points(Nx, order): 
    """ A slight modification of PiecewiseGQ2D function that only needs the weights and integration points.
    Parameters
    ----------

    Nx: int 
        number of intervals along the dimension. No Ny, assume Nx = Ny
    order: int 
        order of the Gauss Quadrature

    Returns
    -------
    long_weights: torch.tensor
    integration_points: torch.tensor
    """

    """
    Parameters
    ----------
    target : 
        Target function 
    Nx: int 
        number of intervals along the dimension. No Ny, assume Nx = Ny
    order: int 
        order of the Gauss Quadrature
    """

    # print("order: ",order )
    x, w = np.polynomial.legendre.leggauss(order)
    gauss_pts = np.array(np.meshgrid(x,x,x,indexing='ij')).reshape(3,-1).T
    weight_list = np.array(np.meshgrid(w,w,w,indexing='ij'))
    weights =   (weight_list[0]*weight_list[1]*weight_list[2]).ravel() 

    gauss_pts =torch.tensor(gauss_pts)
    weights = torch.tensor(weights)

    h = 1/Nx # 100 intervals 
    long_weights =  torch.tile(weights,(Nx**3,1))
    long_weights = long_weights.reshape(-1,1)
    long_weights = long_weights * h**3 /8 

    integration_points = torch.tile(gauss_pts,(Nx**3,1))
    # print("shape of integration_points", integration_points.size())
    scale_factor = h/2 
    integration_points = scale_factor * integration_points

    index = np.arange(1,Nx+1)-0.5
    ordered_pairs = np.array(np.meshgrid(index,index,index,indexing='ij'))
    ordered_pairs = ordered_pairs.reshape(3,-1).T

    # print(ordered_pairs)
    # print()
    ordered_pairs = torch.tensor(ordered_pairs)
    # print(ordered_pairs.size())
    ordered_pairs = torch.tile(ordered_pairs, (1,order**3)) # number of GQ points
    # print(ordered_pairs)

    ordered_pairs =  ordered_pairs.reshape(-1,3)
    # print(ordered_pairs)
    translation = ordered_pairs*h 
    # print(translation)

    integration_points = integration_points + translation 

    return long_weights.to(device), integration_points.to(device)

def MonteCarlo_Sobol_dDim_weights_points(M ,d = 4):
    Sob_integral = torch.quasirandom.SobolEngine(dimension =d, scramble= False, seed=None) 
    integration_points = Sob_integral.draw(M).double() 
    integration_points = integration_points.to(device)
    weights = torch.ones(M,1).to(device)/M 
    return weights, integration_points 

def Neumann_boundary_quadrature_points_weights(M,d):
    def generate_quadpts_on_boundary(gw_expand_bd, integration_points_bd,d):
        size_pts_bd = integration_points_bd.size(0) 
        gw_expand_bd_faces = torch.tile(gw_expand_bd,(2*d,1)) # 2d boundaries, 拉成长条

        integration_points_bd_faces = torch.zeros(2*d*integration_points_bd.size(0),d).to(device)
        for ind in range(d): 
            integration_points_bd_faces[2 *ind * size_pts_bd :(2 *ind +1) * size_pts_bd,ind:ind+1] = 0 
            integration_points_bd_faces[(2 *ind)*size_pts_bd :(2 * ind +1) * size_pts_bd,:ind] = integration_points_bd[:,:ind]
            integration_points_bd_faces[(2 *ind)*size_pts_bd :(2 * ind +1) * size_pts_bd,ind+1:] = integration_points_bd[:,ind:]

            integration_points_bd_faces[(2 *ind +1) * size_pts_bd:(2 *ind +2)*size_pts_bd,ind:ind+1] = 1
            integration_points_bd_faces[(2 *ind +1) * size_pts_bd:(2 *ind +2)*size_pts_bd,:ind] = integration_points_bd[:,:ind]        
            integration_points_bd_faces[(2 *ind +1) * size_pts_bd:(2 *ind +2)*size_pts_bd,ind+1:] = integration_points_bd[:,ind:]
        return gw_expand_bd_faces, integration_points_bd_faces
    
    if d == 1: 
        print('dim',d)
        gw_expand_bd_faces = torch.tensor([1.,1.]).view(-1,1).to(device)
        integration_points_bd_faces = torch.tensor([0.,1.]).view(-1,1).to(device) 
    elif d == 2: 
        print('dim',d)
        gw_expand_bd, integration_points_bd = PiecewiseGQ1D_weights_points(0,1,8192*4, order = 3) 
    elif d == 3: 
        gw_expand_bd, integration_points_bd = PiecewiseGQ2D_weights_points(50, order = 3) 
    elif d == 4: 
        gw_expand_bd, integration_points_bd = PiecewiseGQ3D_weights_points(25, order = 3) 
        print('dim',d)
    else: 
        gw_expand_bd, integration_points_bd = MonteCarlo_Sobol_dDim_weights_points(M ,d = d)
        print('dim >=5 ')
    gw_expand_bd_faces, integration_points_bd_faces = generate_quadpts_on_boundary(gw_expand_bd, integration_points_bd,d)
    return gw_expand_bd_faces.to(device), integration_points_bd_faces.to(device)

# %% [markdown]
# ## Linear layer minimization

# %%
def minimize_linear_layer_explicit_assemble(model,target,weights, integration_points,solver="direct"):
    """
    calls the following functions (dependency): 
    1. GQ_piecewise_2D
    input: the nn model containing parameter 
    1. define the loss function  
    2. take derivative to extract the linear system A
    3. call the cg solver in scipy to solve the linear system 
    output: sol. solution of Ax = b
    """
    start_time = time.time() 
    w = model.fc1.weight.data 
    b = model.fc1.bias.data 
    basis_value_col = F.relu(integration_points @ w.t()+ b)**(model.k) 
    weighted_basis_value_col = basis_value_col * weights 
    jac = weighted_basis_value_col.t() @ basis_value_col 
     
    rhs = weighted_basis_value_col.t() @ (target(integration_points)) 
    print("assembling the matrix time taken: ", time.time()-start_time) 
    start_time = time.time()    
    if solver == "cg": 
        sol, exit_code = linalg.cg(np.array(jac.detach().cpu()),np.array(rhs.detach().cpu()),tol=1e-12)
        sol = torch.tensor(sol).view(1,-1)
    elif solver == "direct": 
#         sol = np.linalg.inv( np.array(jac.detach().cpu()) )@np.array(rhs.detach().cpu())
        sol = (torch.linalg.solve( jac.detach(), rhs.detach())).view(1,-1)
    elif solver == "ls":
        sol = (torch.linalg.lstsq(jac.detach().cpu(),rhs.detach().cpu(),driver='gelsd').solution).view(1,-1)
        # sol = (torch.linalg.lstsq(jac.detach(),rhs.detach()).solution).view(1,-1) # gpu/cpu, driver = 'gels', cannot solve singular
    print("solving Ax = b time taken: ", time.time()-start_time)
    return sol 

def minimize_linear_layer_H1_explicit_assemble_efficient(model,target,weights, integration_points,weights_bd, integration_points_bd, g_N,activation = 'relu',solver="direct" ):

    # weights, integration_points = PiecewiseGQ2D_weights_points(Nx, order) 
    # integration_points.requires_grad_(True) 
    start_time = time.time() 
    w = model.fc1.weight.data 
    b = model.fc1.bias.data 
    neuron_num = b.size(0) 
    dim = integration_points.size(1)  

    if activation == 'relu':
        basis_value_col = F.relu(integration_points @ w.t()+ b)**(model.k) 
        if model.k == 1:  
            basis_value_dx_col = torch.heaviside(integration_points @ w.t()+ b, ZERO) * w.t()[0:1,:] 
            basis_value_dy_col = torch.heaviside(integration_points @ w.t()+ b,ZERO) * w.t()[1:2,:] 
        else: 
            basis_value_dx_col = model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * w.t()[0:1,:]
            basis_value_dy_col = model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * w.t()[1:2,:] 
    # elif activation == 'tanh': 
    #     basis_value_col = torch.tanh(integration_points @ w.t()+ b) 
    #     basis_value_dx_col = tanh_activation_dx(integration_points @ w.t()+ b) * w.t()[0:1,:]
    #     basis_value_dy_col = tanh_activation_dx(integration_points @ w.t()+ b) * w.t()[1:2,:]
    # elif activation == 'gaussian':
    #     basis_value_col = Gaussian_activation(integration_points @ w.t()+ b)
    #     basis_value_dx_col = Gaussian_activation_dx(integration_points @ w.t()+ b) * w.t()[0:1,:]
    #     basis_value_dy_col = Gaussian_activation_dx(integration_points @ w.t()+ b) * w.t()[1:2,:]
    # elif activation == 'cosine':
    #     basis_value_col = cosine_activation(integration_points @ w.t()+ b) 
    #     basis_value_dx_col = cosine_activation_dx(integration_points @ w.t()+ b) * w.t()[0:1,:]
    #     basis_value_dy_col = cosine_activation_dx(integration_points @ w.t()+ b) * w.t()[1:2,:] 

    weighted_basis_value_col = basis_value_col * weights 
    jac1 = weighted_basis_value_col.t() @ basis_value_col  # mass matrix 

    # right hand side function 
    rhs = weighted_basis_value_col.t() @ (target(integration_points)) 
    print("assembling the mass matrix time taken: ", time.time()-start_time) 

    # neumann boundary condition 
    size_pts_bd = int(integration_points_bd.size(0)/(2*dim))
    if g_N != None:
        bcs_N = g_N(dim)
        for ii, g_ii in bcs_N:
            # pts_bd_ii = pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
            weighted_g_N = -g_ii(integration_points_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:])* weights_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
            basis_value_bd_col = F.relu(integration_points_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:] @ w.t()+ b)**(model.k)
            rhs += basis_value_bd_col.t() @ weighted_g_N

            weighted_g_N = g_ii(integration_points_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:])* weights_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:]
            basis_value_bd_col = F.relu(integration_points_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:] @ w.t()+ b)**(model.k)
            rhs += basis_value_bd_col.t() @ weighted_g_N

        
    start_time = time.time() 
    weighted_basis_value_dx_col = basis_value_dx_col * weights
    weighted_basis_value_dy_col = basis_value_dy_col * weights
    jac2 = weighted_basis_value_dx_col.t() @ basis_value_dx_col + weighted_basis_value_dy_col.t() @ basis_value_dy_col 
    print("assembling the stiffness matrix time taken: ", time.time()-start_time)   
    jac = jac1 + jac2    
    
    start_time = time.time()    
    if solver == "cg": 
        sol, exit_code = linalg.cg(np.array(jac.detach().cpu()),np.array(rhs.detach().cpu()),tol=1e-12)
        sol = torch.tensor(sol).view(1,-1)
    elif solver == "direct": 
#         sol = np.linalg.inv( np.array(jac.detach().cpu()) )@np.array(rhs.detach().cpu())
        sol = (torch.linalg.solve( jac.detach(), rhs.detach())).view(1,-1)
    elif solver == "ls":
        sol = (torch.linalg.lstsq(jac.detach().cpu(),rhs.detach().cpu(),driver='gelsd').solution).view(1,-1)
        # sol = (torch.linalg.lstsq(jac.detach(),rhs.detach()).solution).view(1,-1) # gpu/cpu, driver = 'gels', cannot solve singular
    print("solving Ax = b time taken: ", time.time()-start_time)
    return sol

# %% [markdown]
# ## Newton solver for nonlinear Poisson

# %%
    
## define the nonlinearity 
def nonlinear(v):
    return torch.sinh(v)

def nonlinear_prime(v):
    return torch.cosh(v)

def minimize_linear_layer_newton_method(model,target,weights, integration_points,weights_bd, integration_points_bd, g_N,activation = 'relu', solver = 'direct'):
    """
    calls the following functions (dependency): 
    1. GQ_piecewise_2D
    input: the nn model containing parameter 
    1. define the loss function  
    2. take derivative to extract the linear system A
    3. call the cg solver in scipy to solve the linear system 
    output: sol. solution of Ax = b
    """
    start_time = time.time() 
    w = model.fc1.weight.data 
    b = model.fc1.bias.data 
    basis_value_col = F.relu(integration_points @ w.t()+ b)**(model.k) 
    weighted_basis_value_col = basis_value_col * weights 
    dim = integration_points.size(1) 
    newton_iters = 20 

    # neumann boundary condition 
    rhs3 = 0 
    size_pts_bd = int(integration_points_bd.size(0)/(2*dim))
    if g_N != None:
        bcs_N = g_N(dim)
        for ii, g_ii in bcs_N:
            weighted_g_N = -g_ii(integration_points_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:])* weights_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
            basis_value_bd_col = F.relu(integration_points_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:] @ w.t()+ b)**(model.k)
            rhs3 += basis_value_bd_col.t() @ weighted_g_N

            weighted_g_N = g_ii(integration_points_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:])* weights_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:]
            basis_value_bd_col = F.relu(integration_points_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:] @ w.t()+ b)**(model.k)
            rhs3 += basis_value_bd_col.t() @ weighted_g_N
    
    for i in range(newton_iters): 
        print("newton iteration: ", i+1) 
        coef_func = nonlinear_prime(model(integration_points).detach()) #changing after each newton iteration 
        jac2 = weighted_basis_value_col.t() @ (coef_func*basis_value_col) 

        # stiffness matrix 
        if activation == 'relu':
            basis_value_col = F.relu(integration_points @ w.t()+ b)**(model.k) 
            if model.k == 1:  
                basis_value_dx_col = torch.heaviside(integration_points @ w.t()+ b, ZERO) * w.t()[0:1,:] 
                basis_value_dy_col = torch.heaviside(integration_points @ w.t()+ b, ZERO) * w.t()[1:2,:] 
            else: 
                basis_value_dx_col = model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * w.t()[0:1,:]
                basis_value_dy_col = model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * w.t()[1:2,:]
        weighted_basis_value_dx_col = basis_value_dx_col * weights
        weighted_basis_value_dy_col = basis_value_dy_col * weights 
        jac1 =  weighted_basis_value_dx_col.t() @ basis_value_dx_col + weighted_basis_value_dy_col.t() @ basis_value_dy_col 
        jac = jac1 + jac2

        # f- u^3 term 
        rhs1 = weighted_basis_value_col.t() @ (target(integration_points) - nonlinear(model(integration_points).detach()) )

        # gradient term 
        if model!= None:
            dmy_model_dx1 = model.evaluate_derivative(integration_points,1).detach()
            dmy_model_dx2 = model.evaluate_derivative(integration_points,2).detach()
            rhs2 =  - weighted_basis_value_dx_col.t() @ dmy_model_dx1  - weighted_basis_value_dy_col.t() @ dmy_model_dx2
            rhs = rhs1 + rhs2 +rhs3   
        else: 
            rhs = rhs1 +rhs3 

        # print("assembling the matrix time taken: ", time.time()-start_time) 
        start_time = time.time()    
        if solver == "cg": 
            sol, exit_code = linalg.cg(np.array(jac.detach().cpu()),np.array(rhs.detach().cpu()),tol=1e-12)
            sol = torch.tensor(sol).view(1,-1)
        elif solver == "direct": 
    #         sol = np.linalg.inv( np.array(jac.detach().cpu()) )@np.array(rhs.detach().cpu())
            sol = (torch.linalg.solve( jac.detach(), rhs.detach())).view(1,-1)
        elif solver == "ls":
            sol = (torch.linalg.lstsq(jac.detach().cpu(),rhs.detach().cpu(),driver='gelsd').solution).view(1,-1)
            # sol = (torch.linalg.lstsq(jac.detach(),rhs.detach()).solution).view(1,-1) # gpu/cpu, driver = 'gels', cannot solve singular
        # print("solving Ax = b time taken: ", time.time()-start_time)
        ## update the solution 
        print(sol.size())
        # print(sol)
        model.fc2.weight.data[0,:] += sol[0,:]

        # print("newton iteration: ", i) 
        sol_update_l2_norm = torch.norm(sol)
        nn_linear_layer_l2_norm = torch.norm(model.fc2.weight.data[0,:])
        residual_l2_norm = torch.norm(rhs) 
        # print("sol_update_l2_norm:{} \t residual l2 norm: {} ".format(sol_update_l2_norm, residual_l2_norm))
        tol = 1e-10
        print("sol_update_l2_norm:{} \t residual l2 norm: {} ".format(sol_update_l2_norm, residual_l2_norm))
        if sol_update_l2_norm < tol*nn_linear_layer_l2_norm or sol_update_l2_norm < tol or residual_l2_norm < tol*1e-2: 
            print("converged at iteration: ", i+1 )
            print("sol_update_l2_norm:{} \t residual l2 norm: {} ".format(sol_update_l2_norm, residual_l2_norm))
            return model.fc2.weight.data[:,:] 
    print("Newton solver NOT converged at iteration!!! ")
    print("sol_update_l2_norm:{} \t residual l2 norm: {} ".format(sol_update_l2_norm, residual_l2_norm))

    return model.fc2.weight.data[:,:]

# %% [markdown]
# ## CGA for nonlinear Poisson

# %%
def generate_relu_dict2D(N_list):
    N1 = N_list[0] 
    N2 = N_list[1]
    
    theta = np.linspace(0, 2*pi, N1, endpoint= False).reshape(N1,1)
    W1 = np.cos(theta)
    W2 = np.sin(theta)
    W = np.concatenate((W1,W2),1) # N1 x 2
    b = np.linspace(-1.42, 1.42, N2,endpoint=False).reshape(N2,1)
    
    index1 = np.arange(N1)
    index2 = np.arange(N2)
    ordered_pairs = np.array(np.meshgrid(index1,index2,indexing='ij'))

    ordered_pairs = ordered_pairs.reshape(2,-1).T
    W = W[ordered_pairs[:,0],:]
    b = b[ordered_pairs[:,1],:]
    Wb = np.concatenate((W,b),1) # N1 x 3 
    Wb_tensor = torch.from_numpy(Wb) 
    return Wb_tensor

# N_list = [10,20]
# Wb = generate_relu_dict2D(N_list).to(device)
# print(Wb.shape)

def generate_relu_dict2D_QMC(s,N0):
    # add this method to your notes... otherwise you will forget it 
    # Generate randomized Sobol sequence 
    
#     Sob = torch.quasirandom.SobolEngine(dimension =2, scramble= True, seed=None) 
#     samples = Sob.draw(N0).double()

#     for i in range(s-1):
#         samples = torch.cat([samples,Sob.draw(N0).double()],0)

    samples = torch.rand(s*N0,2) 
    
    T =torch.tensor([[2*pi,0],[0,2.84]])

    shift = torch.tensor([0,-1.42]) 

    samples = samples@T + shift 

    theta = samples[:,0].reshape(s*N0,1)
    W1 = torch.cos(theta)
    W2 = torch.sin(theta)
    W = torch.cat((W1,W2),1) # N1 x 2
    # b = np.linspace(-1.42, 1.42, N2,endpoint=False).reshape(N2,1) 
    b = samples[:,1].reshape(s*N0,1)
    
    Wb = torch.cat((W,b),1) # N1 x 3 

    return Wb 


def select_greedy_neuron_ind(relu_dict_parameters,my_model,target,gw_expand, integration_points,g_N,weights_bd, integration_points_bd,k):

    func_values = - target(integration_points)
    if my_model != None: 
        func_values = - target(integration_points) + nonlinear(my_model(integration_points).detach()) 

    weight_func_values = func_values*gw_expand  
    basis_values = (F.relu( torch.matmul(integration_points,relu_dict_parameters[:,0:2].T ) - relu_dict_parameters[:,2])**k).T # uses broadcasting

    if k == 1:  
        dbasis_values_dx1 =  torch.heaviside(integration_points @ (relu_dict_parameters[:,0:2].T) - relu_dict_parameters[:,2], ZERO) * relu_dict_parameters.t()[0:1,:]  
        dbasis_values_dx2 =  torch.heaviside(integration_points @ (relu_dict_parameters[:,0:2].T) - relu_dict_parameters[:,2], ZERO) * relu_dict_parameters.t()[1:2,:] 
        weight_dbasis_values_dx1 =  dbasis_values_dx1 * gw_expand
        weight_dbasis_values_dx2 =  dbasis_values_dx2 * gw_expand 
        if my_model!= None:
            dmy_model_dx1 = my_model.evaluate_derivative(integration_points,1).detach()
            dmy_model_dx2 = my_model.evaluate_derivative(integration_points,2).detach() 
    else:  
        dbasis_values_dx1 = k * F.relu(integration_points @ (relu_dict_parameters[:,0:2].T) - relu_dict_parameters[:,2])**(k-1) * relu_dict_parameters.t()[0:1,:] 
        dbasis_values_dx2 = k * F.relu(integration_points @ (relu_dict_parameters[:,0:2].T) - relu_dict_parameters[:,2])**(k-1) * relu_dict_parameters.t()[1:2,:] 
        weight_dbasis_values_dx1 =  dbasis_values_dx1 * gw_expand
        weight_dbasis_values_dx2 =  dbasis_values_dx2 * gw_expand 
        if my_model!= None:
            dmy_model_dx1 = my_model.evaluate_derivative(integration_points,1).detach()
            dmy_model_dx2 = my_model.evaluate_derivative(integration_points,2).detach()

    #Neumann boundary condition
    output4 = 0 ##Todo 
    dim = integration_points.size(1) 
    size_pts_bd = int(integration_points_bd.size(0)/(2*dim))
    if g_N != None:
        bcs_N = g_N(dim)
        for ii, g_ii in bcs_N:
            # pts_bd_ii = pts_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
            weighted_g_N = -g_ii(integration_points_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:])* weights_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:]
            basis_value_bd_col = F.relu(integration_points_bd[2*ii*size_pts_bd:(2*ii+1)*size_pts_bd,:] @ (relu_dict_parameters[:,0:2].T) - relu_dict_parameters[:,2] )**(k)
            output4 += basis_value_bd_col.t() @ weighted_g_N

            weighted_g_N = g_ii(integration_points_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:])* weights_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:]
            basis_value_bd_col = F.relu(integration_points_bd[(2*ii+1)*size_pts_bd:(2*ii+2)*size_pts_bd,:] @ (relu_dict_parameters[:,0:2].T) - relu_dict_parameters[:,2])**(k)
            output4 += basis_value_bd_col.t() @ weighted_g_N
        
    output1 = torch.matmul(basis_values,weight_func_values) #
    if my_model!= None:
        output2 = torch.matmul(weight_dbasis_values_dx1.t(), dmy_model_dx1) 
        output3 = torch.matmul(weight_dbasis_values_dx2.t(), dmy_model_dx2) 
        output = torch.abs(output1 + output2 + output3 - output4) 
    else: 
        output = torch.abs(output1 - output4) 
    # output = torch.abs(torch.matmul(basis_values,weight_func_values)) # 
    neuron_index = torch.argmax(output.flatten())
    return neuron_index 

def L2_projection_init(model,sol,weights,integration_points,activation = 'relu', solver = 'direct'):
    start_time = time.time() 
    w = model.fc1.weight.data 
    b = model.fc1.bias.data 
    basis_value_col = F.relu(integration_points @ w.t()+ b)**(model.k) 
    weighted_basis_value_col = basis_value_col * weights 
    jac = weighted_basis_value_col.t() @ basis_value_col 
      
    rhs = jac[:,:-1] @ sol.t()

    print("assembling the matrix time taken: ", time.time()-start_time) 
    start_time = time.time()    
    if solver == "cg": 
        sol, exit_code = linalg.cg(np.array(jac.detach().cpu()),np.array(rhs.detach().cpu()),tol=1e-12)
        sol = torch.tensor(sol).view(1,-1)
    elif solver == "direct": 
#         sol = np.linalg.inv( np.array(jac.detach().cpu()) )@np.array(rhs.detach().cpu())
        sol = (torch.linalg.solve( jac.detach(), rhs.detach())).view(1,-1)
    elif solver == "ls":
        sol = (torch.linalg.lstsq(jac.detach().cpu(),rhs.detach().cpu(),driver='gelsd').solution).view(1,-1)
        # sol = (torch.linalg.lstsq(jac.detach(),rhs.detach()).solution).view(1,-1) # gpu/cpu, driver = 'gels', cannot solve singular
    print("solving Ax = b time taken: ", time.time()-start_time)
    model.fc2.weight.data[0,:] = sol[0,:]  
    return model 

def CGANonlinearPoissonReLU2D(my_model,target,u_exact, u_exact_grad,g_N, N_list,num_epochs,plot_freq, Nx, order, k =1, rand_deter = 'deter', linear_solver = "direct"): 
    """ Orthogonal greedy algorithm using 1D ReLU dictionary over [-pi,pi]
    Parameters
    ----------
    my_model: 
        nn model 
    target: 
        target function
    num_epochs: int 
        number of training epochs 
    integration_intervals: int 
        number of subintervals for piecewise numerical quadrature 

    Returns
    -------
    err: tensor 
        rank 1 torch tensor to record the L2 error history  
    model: 
        trained nn model 
    """
    #Todo Done
    gw_expand, integration_points = PiecewiseGQ2D_weights_points(Nx, order)
    gw_expand = gw_expand.to(device)
    integration_points = integration_points.to(device)
    dim = integration_points.size(1) 
    weights_bd, integration_points_bd = Neumann_boundary_quadrature_points_weights(999999,dim) #todo 

    err = torch.zeros(num_epochs+1)
    err_h10 = torch.zeros(num_epochs+1).to(device)
    if my_model == None: 
        func_values = target(integration_points)
        num_neuron = 0

        list_b = []
        list_w = []
    else: 
        func_values = target(integration_points) - my_model(integration_points).detach()
        bias = my_model.fc1.bias.detach().data
        weights = my_model.fc1.weight.detach().data
        num_neuron = int(bias.size(0))

        list_b = list(bias)
        list_w = list(weights)
    
    # initial error Todo Done
    func_values_sqrd = func_values*func_values
    err[0]= torch.sum(func_values_sqrd*gw_expand)**0.5
    ## h1 error todo 
    if u_exact_grad != None:
        u_grad = u_exact_grad() 
        for grad_i in u_grad: 
            err_h10[0] += torch.sum((grad_i(integration_points))**2 * gw_expand)**0.5
    
    start_time = time.time()
    solver = linear_solver

    N0 = np.prod(N_list)
    if rand_deter == 'deter':
        relu_dict_parameters = generate_relu_dict2D(N_list).to(device)
    print("using linear solver: ",solver)
    for i in range(num_epochs): 
        print("epoch: ",i+1, end = '\t')
        if rand_deter == 'rand':
            relu_dict_parameters = generate_relu_dict2D_QMC(1,N0).to(device) 
        
        neuron_index = select_greedy_neuron_ind(relu_dict_parameters,my_model,target,gw_expand, integration_points,g_N,weights_bd, integration_points_bd,k)

        # print(neuron_index)
        list_w.append(relu_dict_parameters[neuron_index,0:2]) # 
        list_b.append(-relu_dict_parameters[neuron_index,2])
        num_neuron += 1
        my_model = model(2,num_neuron,1,k).to(device)
        w_tensor = torch.stack(list_w, 0 ) 
        b_tensor = torch.tensor(list_b)
        my_model.fc1.weight.data[:,:] = w_tensor[:,:]
        my_model.fc1.bias.data[:] = b_tensor[:]

        ##todo 
        if num_neuron <=2: 
            my_model.fc2.weight.data[0,:] = 0.0001
        else: 
            ## Initial guess: option 1 
            my_model.fc2.weight.data[0,:num_neuron -1 ] = sol[:] # projection of previous solution
            my_model.fc2.weight.data[0,:num_neuron ] = 0.0001
            
            ## Option 2:  H1 projection onto previous solution 
            # my_model = H1_projection_init(my_model,sol,weights,integration_points,activation = 'relu', solver = solver) 
            ## Option 3:  L2 projection onto previous solution 
            my_model = L2_projection_init(my_model,sol,gw_expand,integration_points,activation = 'relu', solver = solver) 

        sol = minimize_linear_layer_newton_method(my_model,target,gw_expand, integration_points,weights_bd, integration_points_bd,g_N,activation ='relu', solver = solver)
        
        sol = sol.flatten() 
        my_model.fc2.weight.data[0,:] = sol[:]
        # sol = minimize_linear_layer_H1_explicit_assemble_efficient(my_model,target,gw_expand, integration_points,activation = 'relu',solver = solver)

        if (i+1)%plot_freq == 0: 
            plot_2D(my_model.cpu())
            my_model = my_model.to(device)

        model_values = my_model(integration_points).detach()
        # func_values = target(integration_points) - model_values
        # func_values_sqrd = func_values*func_values

        # L2 error ||u - u_n||
        diff_values_sqrd = (u_exact(integration_points) - model_values)**2 
        #Todo Done 
        err[i+1]= torch.sum(diff_values_sqrd*gw_expand)**0.5
        if u_exact_grad != None:
            for ii, grad_i in enumerate(u_grad): 
                my_model_dxi = my_model.evaluate_derivative(integration_points,ii+1).detach() 
                err_h10[i+1] += torch.sum((grad_i(integration_points) - my_model_dxi)**2 * gw_expand)**0.5

    print("time taken: ",time.time() - start_time)
    return err, err_h10.cpu(), my_model

# %% [markdown]
# In the following tests, we compare using deterministic dictionaries with using random dictionary for the following three target functions.
#
# - $\sin(\pi x_1) \sin(\pi x_2)$
# - $\sin(4\pi x_1) \sin(8\pi x_2)$
# - Gabor function

# %% [markdown]
# ## CGA experiments

# %% [markdown]
# ## Gabor function

# %%
sigma = 0.15
m = 4 

def u_exact(x):
    """Gabor function applied to a batch of points."""
    exp_term = torch.exp(-torch.sum((x - 0.5) ** 2, dim=1, keepdim=True) / (2 * sigma ** 2))
    cos_term = torch.cos(2 * math.pi * m * x[:, 0:1])  # x[:, 0:1] keeps the dimension
    return exp_term * cos_term


def u_exact_grad():
    def u_grad_x(x):
        exp_term = torch.exp(-torch.sum((x - 0.5) ** 2, dim=1, keepdim=True) / (2 * sigma ** 2))
        cos_term = torch.cos(2 * math.pi * m * x[:, 0:1])
        sin_term = torch.sin(2 * math.pi * m * x[:, 0:1])

        # Derivative with respect to x_1
        du_dx1 = exp_term * (-2 * (x[:, 0:1] - 0.5) / (2 * sigma ** 2)) * cos_term - (2 * math.pi * m * exp_term * sin_term)
        return du_dx1
        
    def u_grad_y(x):

        exp_term = torch.exp(-torch.sum((x - 0.5) ** 2, dim=1, keepdim=True) / (2 * sigma ** 2))
        cos_term = torch.cos(2 * math.pi * m * x[:, 0:1])
        sin_term = torch.sin(2 * math.pi * m * x[:, 0:1])
        du_dx_other = exp_term * (-2 * (x[:, 1:2] - 0.5) / (2 * sigma ** 2)) * cos_term
        return du_dx_other

    u_grad=[] 
    u_grad.append(u_grad_x)
    u_grad.append(u_grad_y)
    return u_grad


def laplace_u_exact(x):
    """Laplacian of the Gabor function for a batch of points, summed over all dimensions."""

    exp_term = torch.exp(-torch.sum((x - 0.5) ** 2, dim=1, keepdim=True) / (2 * sigma ** 2))
    cos_term = torch.cos(2 * math.pi * m * x[:, 0:1])
    sin_term = torch.sin(2 * math.pi * m * x[:, 0:1])

    # Laplacian in x_1: Apply the product rule twice
    laplace_x1_part_1 = exp_term * (-2 * (x[:, 0:1] - 0.5) / (2 * sigma ** 2))**2 * cos_term
    laplace_x1_part_2 = exp_term * ( - 1 / sigma ** 2) * cos_term
    laplace_x1_part_3 = exp_term * (-2 * (x[:, 0:1] - 0.5) / (2 * sigma ** 2)) * (-2*m*math.pi)*sin_term
    laplace_x1_part_4 = - (2 * math.pi * m * exp_term * (-2 * (x[:, 0:1] - 0.5) / (2 * sigma ** 2)) * sin_term) 
    laplace_x1_part_5 = - ( (2 * math.pi * m)**2 * exp_term * cos_term)

    laplace_x1 = laplace_x1_part_1 + laplace_x1_part_2 + laplace_x1_part_3 \
                + laplace_x1_part_4 + laplace_x1_part_5

    # Laplacian in other dimensions (x_i, i > 1): Only the exponential term matters here
    laplace_other = (-1 / sigma ** 2) * exp_term * cos_term \
                + exp_term * (-2 * (x[:, 1:] - 0.5) / (2 * sigma ** 2))**2 * cos_term 

    # Sum all Laplacians over each variable to get the total Laplacian
    laplace_sum = laplace_x1  + torch.sum(laplace_other, dim=1, keepdim=True)

    return laplace_sum 

def rhs(x):
    """Right-hand side of the equation using the Gabor function for a batch of points."""
    laplace_sum = laplace_u_exact(x)
    return -laplace_sum + nonlinear(u_exact(x))

def g_N(dim):
    u_grad = u_exact_grad() 
    bcs_N = []
    for i in range(dim):
        bcs_N.append((i, u_grad[i]))
    return bcs_N 

dim = 2 
function_name = "gabor2d-m4" 
filename_write = "data/2DOGA-{}-order.txt".format(function_name)
Nx = 600  
order = 2 
f_write = open(filename_write, "a")
f_write.write("Numerical integration Nx: {}, order: {} \n".format(Nx, order))
f_write.close() 
save = True 
write2file = True 
memory = 2**29 
rand_deter = 'rand'
for N_list in [[2**4,2**5]]: # ,[2**6,2**6],[2**7,2**7] 
    f_write = open(filename_write, "a")
    my_model = None 
    exponent = 9 
    num_epochs = 2**exponent  
    plot_freq = num_epochs 
    N = np.prod(N_list)
    relu_k = 3 
    err_QMC2, err_h10, my_model = CGANonlinearPoissonReLU2D(my_model,rhs,u_exact, u_exact_grad,g_N, N_list,num_epochs,plot_freq, Nx, order, k = relu_k, rand_deter = rand_deter, linear_solver = "direct")
    if save: 
        folder = 'data/'
        filename = folder + 'err_OGA_2D_{}_neuron_{}_N_{}_{}.pt'.format(function_name,num_epochs,N,rand_deter)
        torch.save(err_QMC2,filename) 
        filename = folder + 'err_h10_OGA_2D_{}_neuron_{}_N_{}_{}.pt'.format(function_name,num_epochs,N,rand_deter)
        torch.save(err_h10,filename) 
        filename = folder + 'model_OGA_2D_{}_neuron_{}_N_{}_{}.pt'.format(function_name,num_epochs,N,rand_deter)
        torch.save(my_model,filename)

    show_convergence_order2(err_QMC2,err_h10,exponent,N,filename_write,write2file = write2file)
    show_convergence_order_latex2(err_QMC2,err_h10,exponent)
# Out:
# dim 2
# using linear solver:  direct
# epoch:  1	newton iteration:  1
# torch.Size([1, 1])
# sol_update_l2_norm:3.4046468279866515e-05 	 residual l2 norm: 0.010081950064865008
# newton iteration:  2
# torch.Size([1, 1])
# sol_update_l2_norm:3.153143167433564e-12 	 residual l2 norm: 9.33718768969527e-10
# converged at iteration:  2
# sol_update_l2_norm:3.153143167433564e-12 	 residual l2 norm: 9.33718768969527e-10
# epoch:  2	newton iteration:  1
# torch.Size([1, 2])
# sol_update_l2_norm:0.00042251286888995954 	 residual l2 norm: 0.011936370808506116
# newton iteration:  2
# torch.Size([1, 2])
# sol_update_l2_norm:8.070565854580183e-11 	 residual l2 norm: 3.5177967570591455e-09
# converged at iteration:  2
# sol_update_l2_norm:8.070565854580183e-11 	 residual l2 norm: 3.5177967570591455e-09
# epoch:  3	assembling the matrix time taken:  0.0001990795135498047
# solving Ax = b time taken:  0.0006093978881835938
# newton iteration:  1
# torch.Size([1, 3])
# sol_update_l2_norm:0.0007207999504410188 	 residual l2 norm: 0.022355827396997263
# newton iteration:  2
# torch.Size([1, 3])
# sol_update_l2_norm:9.86553778186395e-11 	 residual l2 norm: 5.950165259077263e-09
# converged at iteration:  2
# sol_update_l2_norm:9.86553778186395e-11 	 residual l2 norm: 5.950165259077263e-09
# epoch:  4	assembling the matrix time taken:  0.00018358230590820312
# solving Ax = b time taken:  0.0007035732269287109
# newton iteration:  1
# torch.Size([1, 4])
# sol_update_l2_norm:0.14821493671062466 	 residual l2 norm: 0.005079305076609023
# newton iteration:  2
# torch.Size([1, 4])
# sol_update_l2_norm:2.3213994806716972e-07 	 residual l2 norm: 1.1427706920572786e-06
# newton iteration:  3
# torch.Size([1, 4])
# sol_update_l2_norm:1.0262556847189406e-14 	 residual l2 norm: 2.4322821091893928e-14
# converged at iteration:  3
# sol_update_l2_norm:1.0262556847189406e-14 	 residual l2 norm: 2.4322821091893928e-14
# epoch:  5	assembling the matrix time taken:  0.00019049644470214844
# solving Ax = b time taken:  0.0007333755493164062
# newton iteration:  1
# torch.Size([1, 5])
# sol_update_l2_norm:0.12880695574133155 	 residual l2 norm: 0.022900881087399044
# newton iteration:  2
# torch.Size([1, 5])
# sol_update_l2_norm:3.3478696679170576e-07 	 residual l2 norm: 1.0345436328797861e-06
# newton iteration:  3
# torch.Size([1, 5])
# sol_update_l2_norm:3.627872539189237e-14 	 residual l2 norm: 4.77880914817196e-14
# converged at iteration:  3
# sol_update_l2_norm:3.627872539189237e-14 	 residual l2 norm: 4.77880914817196e-14
# epoch:  6	assembling the matrix time taken:  0.00017380714416503906
# solving Ax = b time taken:  0.0008435249328613281
# newton iteration:  1
# torch.Size([1, 6])
# sol_update_l2_norm:0.12059694954653252 	 residual l2 norm: 0.061308604764872654
# newton iteration:  2
# torch.Size([1, 6])
# sol_update_l2_norm:3.4491053558666457e-07 	 residual l2 norm: 2.8080102285375367e-06
# newton iteration:  3
# torch.Size([1, 6])
# sol_update_l2_norm:4.5877652727449315e-15 	 residual l2 norm: 1.8965552387187772e-14
# converged at iteration:  3
# sol_update_l2_norm:4.5877652727449315e-15 	 residual l2 norm: 1.8965552387187772e-14
# epoch:  7	assembling the matrix time taken:  0.00016379356384277344
# solving Ax = b time taken:  0.0008747577667236328
# newton iteration:  1
# torch.Size([1, 7])
# sol_update_l2_norm:0.06190278689018241 	 residual l2 norm: 0.018880994252077562
# newton iteration:  2
# torch.Size([1, 7])
# sol_update_l2_norm:1.1475932130843587e-07 	 residual l2 norm: 3.695934181637792e-07
# newton iteration:  3
# torch.Size([1, 7])
# sol_update_l2_norm:1.6656992696165572e-14 	 residual l2 norm: 2.778321665116854e-14
# converged at iteration:  3
# sol_update_l2_norm:1.6656992696165572e-14 	 residual l2 norm: 2.778321665116854e-14
# epoch:  8	assembling the matrix time taken:  0.0001709461212158203
# solving Ax = b time taken:  0.0009665489196777344
# newton iteration:  1
# torch.Size([1, 8])
# sol_update_l2_norm:0.07414750735787888 	 residual l2 norm: 0.00986379783788316
# newton iteration:  2
# torch.Size([1, 8])
# sol_update_l2_norm:3.145597216699029e-08 	 residual l2 norm: 1.4378967483329773e-07
# newton iteration:  3
# torch.Size([1, 8])
# sol_update_l2_norm:9.805283581704426e-14 	 residual l2 norm: 3.6316808982923557e-14
# converged at iteration:  3
# sol_update_l2_norm:9.805283581704426e-14 	 residual l2 norm: 3.6316808982923557e-14
# epoch:  9	assembling the matrix time taken:  0.00016379356384277344
# solving Ax = b time taken:  0.00106048583984375
# newton iteration:  1
# torch.Size([1, 9])
# sol_update_l2_norm:0.2299558147157612 	 residual l2 norm: 0.008616235649299281
# newton iteration:  2
# torch.Size([1, 9])
# sol_update_l2_norm:9.075518947167647e-08 	 residual l2 norm: 2.549668395708668e-07
# newton iteration:  3
# torch.Size([1, 9])
# sol_update_l2_norm:2.6618322610727897e-13 	 residual l2 norm: 3.9327463818865044e-14
# converged at iteration:  3
# sol_update_l2_norm:2.6618322610727897e-13 	 residual l2 norm: 3.9327463818865044e-14
# epoch:  10	assembling the matrix time taken:  0.00017261505126953125
# solving Ax = b time taken:  0.0010676383972167969
# newton iteration:  1
# torch.Size([1, 10])
# sol_update_l2_norm:1.5730393057761298 	 residual l2 norm: 0.009584333015960202
# newton iteration:  2
# torch.Size([1, 10])
# sol_update_l2_norm:5.686717590842036e-07 	 residual l2 norm: 1.1640285873828928e-06
# newton iteration:  3
# torch.Size([1, 10])
# sol_update_l2_norm:5.143667588441955e-13 	 residual l2 norm: 4.5231212545953545e-14
# converged at iteration:  3
# sol_update_l2_norm:5.143667588441955e-13 	 residual l2 norm: 4.5231212545953545e-14
# epoch:  11	assembling the matrix time taken:  0.00017189979553222656
# solving Ax = b time taken:  0.0011565685272216797
# newton iteration:  1
# torch.Size([1, 11])
# sol_update_l2_norm:0.6715339095327398 	 residual l2 norm: 0.008258496261662786
# newton iteration:  2
# torch.Size([1, 11])
# sol_update_l2_norm:4.773774889127511e-07 	 residual l2 norm: 1.0339745975766332e-06
# newton iteration:  3
# torch.Size([1, 11])
# sol_update_l2_norm:6.658386247461501e-13 	 residual l2 norm: 3.2889300482209245e-14
# converged at iteration:  3
# sol_update_l2_norm:6.658386247461501e-13 	 residual l2 norm: 3.2889300482209245e-14
# epoch:  12	assembling the matrix time taken:  0.00017118453979492188
# solving Ax = b time taken:  0.001218557357788086
# newton iteration:  1
# torch.Size([1, 12])
# sol_update_l2_norm:18.041001375962335 	 residual l2 norm: 0.004310883367618844
# newton iteration:  2
# torch.Size([1, 12])
# sol_update_l2_norm:4.4079826703134425e-05 	 residual l2 norm: 8.778714716518988e-06
# newton iteration:  3
# torch.Size([1, 12])
# sol_update_l2_norm:1.465120193866149e-11 	 residual l2 norm: 2.9665620231610926e-14
# converged at iteration:  3
# sol_update_l2_norm:1.465120193866149e-11 	 residual l2 norm: 2.9665620231610926e-14
# epoch:  13	assembling the matrix time taken:  0.0001659393310546875
# solving Ax = b time taken:  0.0012900829315185547
# newton iteration:  1
# torch.Size([1, 13])
# sol_update_l2_norm:40.640964851662446 	 residual l2 norm: 0.007015891061759772
# newton iteration:  2
# torch.Size([1, 13])
# sol_update_l2_norm:0.0003240729292689408 	 residual l2 norm: 1.3005094311952967e-05
# newton iteration:  3
# torch.Size([1, 13])
# sol_update_l2_norm:2.6553522231216134e-11 	 residual l2 norm: 5.920101003803301e-13
# converged at iteration:  3
# sol_update_l2_norm:2.6553522231216134e-11 	 residual l2 norm: 5.920101003803301e-13
# epoch:  14	assembling the matrix time taken:  0.0001780986785888672
# solving Ax = b time taken:  0.0013532638549804688
# newton iteration:  1
# torch.Size([1, 14])
# sol_update_l2_norm:16.78170693887685 	 residual l2 norm: 0.009412007280825882
# newton iteration:  2
# torch.Size([1, 14])
# sol_update_l2_norm:5.8057764051615714e-05 	 residual l2 norm: 4.021092455475402e-06
# newton iteration:  3
# torch.Size([1, 14])
# sol_update_l2_norm:1.6703083274887641e-12 	 residual l2 norm: 8.537388715064735e-15
# converged at iteration:  3
# sol_update_l2_norm:1.6703083274887641e-12 	 residual l2 norm: 8.537388715064735e-15
# epoch:  15	assembling the matrix time taken:  0.0001747608184814453
# solving Ax = b time taken:  0.0014157295227050781
# newton iteration:  1
# torch.Size([1, 15])
# sol_update_l2_norm:18.90653343574834 	 residual l2 norm: 0.007590472622518463
# newton iteration:  2
# torch.Size([1, 15])
# sol_update_l2_norm:0.00010012364098535087 	 residual l2 norm: 1.4747086569892498e-05
# newton iteration:  3
# torch.Size([1, 15])
# sol_update_l2_norm:8.986336895953182e-12 	 residual l2 norm: 5.241704220405419e-14
# converged at iteration:  3
# sol_update_l2_norm:8.986336895953182e-12 	 residual l2 norm: 5.241704220405419e-14
# epoch:  16	assembling the matrix time taken:  0.0001704692840576172
# solving Ax = b time taken:  0.0015003681182861328
# newton iteration:  1
# torch.Size([1, 16])
# sol_update_l2_norm:14.818638987266743 	 residual l2 norm: 0.009181692954384877
# newton iteration:  2
# torch.Size([1, 16])
# sol_update_l2_norm:9.500303124005038e-05 	 residual l2 norm: 1.0096919778894878e-05
# newton iteration:  3
# torch.Size([1, 16])
# sol_update_l2_norm:2.684792509444405e-11 	 residual l2 norm: 8.535289699822894e-14
# converged at iteration:  3
# sol_update_l2_norm:2.684792509444405e-11 	 residual l2 norm: 8.535289699822894e-14
# epoch:  17	assembling the matrix time taken:  0.0001742839813232422
# solving Ax = b time taken:  0.0015709400177001953
# newton iteration:  1
# torch.Size([1, 17])
# sol_update_l2_norm:7.647421187928001 	 residual l2 norm: 0.005815330369570034
# newton iteration:  2
# torch.Size([1, 17])
# sol_update_l2_norm:4.920906780630928e-05 	 residual l2 norm: 2.2715708672975464e-06
# newton iteration:  3
# torch.Size([1, 17])
# sol_update_l2_norm:3.7287625728382845e-11 	 residual l2 norm: 5.745473778224507e-14
# converged at iteration:  3
# sol_update_l2_norm:3.7287625728382845e-11 	 residual l2 norm: 5.745473778224507e-14
# epoch:  18	assembling the matrix time taken:  0.0001709461212158203
# solving Ax = b time taken:  0.0016927719116210938
# newton iteration:  1
# torch.Size([1, 18])
# sol_update_l2_norm:61.49087011834602 	 residual l2 norm: 0.0070658388339062544
# newton iteration:  2
# torch.Size([1, 18])
# sol_update_l2_norm:0.0006638091681601977 	 residual l2 norm: 0.00017553781284672683
# newton iteration:  3
# torch.Size([1, 18])
# sol_update_l2_norm:9.661174930415898e-11 	 residual l2 norm: 5.505590764777958e-12
# converged at iteration:  3
# sol_update_l2_norm:9.661174930415898e-11 	 residual l2 norm: 5.505590764777958e-12
# epoch:  19	assembling the matrix time taken:  0.00017404556274414062
# solving Ax = b time taken:  0.0017256736755371094
# newton iteration:  1
# torch.Size([1, 19])
# sol_update_l2_norm:44.21352211239406 	 residual l2 norm: 0.005704997760525776
# newton iteration:  2
# torch.Size([1, 19])
# sol_update_l2_norm:0.00034505513720109156 	 residual l2 norm: 1.3006492152798618e-05
# newton iteration:  3
# torch.Size([1, 19])
# sol_update_l2_norm:3.102140711381563e-11 	 residual l2 norm: 2.9332488371301985e-14
# converged at iteration:  3
# sol_update_l2_norm:3.102140711381563e-11 	 residual l2 norm: 2.9332488371301985e-14
# epoch:  20	assembling the matrix time taken:  0.0001800060272216797
# solving Ax = b time taken:  0.0018024444580078125
# newton iteration:  1
# torch.Size([1, 20])
# sol_update_l2_norm:27.545951293408276 	 residual l2 norm: 0.00473060500228721
# newton iteration:  2
# torch.Size([1, 20])
# sol_update_l2_norm:0.00010206643842545638 	 residual l2 norm: 4.977872674037823e-06
# newton iteration:  3
# torch.Size([1, 20])
# sol_update_l2_norm:1.1543177170375826e-10 	 residual l2 norm: 8.066390319751647e-14
# converged at iteration:  3
# sol_update_l2_norm:1.1543177170375826e-10 	 residual l2 norm: 8.066390319751647e-14
# epoch:  21	assembling the matrix time taken:  0.00017595291137695312
# solving Ax = b time taken:  0.0018763542175292969
# newton iteration:  1
# torch.Size([1, 21])
# sol_update_l2_norm:197.06303030474695 	 residual l2 norm: 0.0035028432416631663
# newton iteration:  2
# torch.Size([1, 21])
# sol_update_l2_norm:0.001472518571617123 	 residual l2 norm: 0.00021484173640838724
# newton iteration:  3
# torch.Size([1, 21])
# sol_update_l2_norm:3.8156061658372597e-10 	 residual l2 norm: 1.1121169404659954e-11
# converged at iteration:  3
# sol_update_l2_norm:3.8156061658372597e-10 	 residual l2 norm: 1.1121169404659954e-11
# epoch:  22	assembling the matrix time taken:  0.00017023086547851562
# solving Ax = b time taken:  0.001958608627319336
# newton iteration:  1
# torch.Size([1, 22])
# sol_update_l2_norm:730.2516944940255 	 residual l2 norm: 0.0061303203510874385
# newton iteration:  2
# torch.Size([1, 22])
# sol_update_l2_norm:0.024843730538306415 	 residual l2 norm: 0.00018119831082703537
# newton iteration:  3
# torch.Size([1, 22])
# sol_update_l2_norm:1.289277863411335e-10 	 residual l2 norm: 9.368423960062426e-12
# converged at iteration:  3
# sol_update_l2_norm:1.289277863411335e-10 	 residual l2 norm: 9.368423960062426e-12
# epoch:  23	assembling the matrix time taken:  0.0001628398895263672
# solving Ax = b time taken:  0.0020270347595214844
# newton iteration:  1
# torch.Size([1, 23])
# sol_update_l2_norm:237.22502052402302 	 residual l2 norm: 0.007927048798878168
# newton iteration:  2
# torch.Size([1, 23])
# sol_update_l2_norm:0.01140942395925862 	 residual l2 norm: 0.0005930018659857352
# newton iteration:  3
# torch.Size([1, 23])
# sol_update_l2_norm:3.0344148559435148e-09 	 residual l2 norm: 9.816301682888728e-11
# converged at iteration:  3
# sol_update_l2_norm:3.0344148559435148e-09 	 residual l2 norm: 9.816301682888728e-11
# epoch:  24	assembling the matrix time taken:  0.00019216537475585938
# solving Ax = b time taken:  0.0020821094512939453
# newton iteration:  1
# torch.Size([1, 24])
# sol_update_l2_norm:95.93284450443214 	 residual l2 norm: 0.006602021836532457
# newton iteration:  2
# torch.Size([1, 24])
# sol_update_l2_norm:0.002212418304847128 	 residual l2 norm: 7.139346311511249e-05
# newton iteration:  3
# torch.Size([1, 24])
# sol_update_l2_norm:3.764204125668565e-10 	 residual l2 norm: 2.039211076170233e-12
# converged at iteration:  3
# sol_update_l2_norm:3.764204125668565e-10 	 residual l2 norm: 2.039211076170233e-12
# epoch:  25	assembling the matrix time taken:  0.0001621246337890625
# solving Ax = b time taken:  0.0021631717681884766
# newton iteration:  1
# torch.Size([1, 25])
# sol_update_l2_norm:330.58196601846277 	 residual l2 norm: 0.006298156288866931
# newton iteration:  2
# torch.Size([1, 25])
# sol_update_l2_norm:0.005868421871211715 	 residual l2 norm: 0.0002630661514901303
# newton iteration:  3
# torch.Size([1, 25])
# sol_update_l2_norm:1.738135274934482e-09 	 residual l2 norm: 2.3902191397308006e-11
# converged at iteration:  3
# sol_update_l2_norm:1.738135274934482e-09 	 residual l2 norm: 2.3902191397308006e-11
# epoch:  26	assembling the matrix time taken:  0.00016951560974121094
# solving Ax = b time taken:  0.002261638641357422
# newton iteration:  1
# torch.Size([1, 26])
# sol_update_l2_norm:184.86145078064897 	 residual l2 norm: 0.004014775929340533
# newton iteration:  2
# torch.Size([1, 26])
# sol_update_l2_norm:0.004890217536687482 	 residual l2 norm: 0.00015755015473671718
# newton iteration:  3
# torch.Size([1, 26])
# sol_update_l2_norm:7.887160415252921e-10 	 residual l2 norm: 6.573321556664146e-12
# converged at iteration:  3
# sol_update_l2_norm:7.887160415252921e-10 	 residual l2 norm: 6.573321556664146e-12
# epoch:  27	assembling the matrix time taken:  0.0001728534698486328
# solving Ax = b time taken:  0.002298593521118164
# newton iteration:  1
# torch.Size([1, 27])
# sol_update_l2_norm:384.59844349286163 	 residual l2 norm: 0.003625750793534596
# newton iteration:  2
# torch.Size([1, 27])
# sol_update_l2_norm:0.008725064161249862 	 residual l2 norm: 0.00010632206776649469
# newton iteration:  3
# torch.Size([1, 27])
# sol_update_l2_norm:3.626135535013253e-10 	 residual l2 norm: 7.0344571204827205e-12
# converged at iteration:  3
# sol_update_l2_norm:3.626135535013253e-10 	 residual l2 norm: 7.0344571204827205e-12
# epoch:  28	assembling the matrix time taken:  0.00017213821411132812
# solving Ax = b time taken:  0.0023813247680664062
# newton iteration:  1
# torch.Size([1, 28])
# sol_update_l2_norm:1156.7917113268834 	 residual l2 norm: 0.004107989557448643
# newton iteration:  2
# torch.Size([1, 28])
# sol_update_l2_norm:0.032662968561425636 	 residual l2 norm: 0.00045218731820881677
# newton iteration:  3
# torch.Size([1, 28])
# sol_update_l2_norm:3.8891643886051424e-09 	 residual l2 norm: 1.2623338696393083e-10
# converged at iteration:  3
# sol_update_l2_norm:3.8891643886051424e-09 	 residual l2 norm: 1.2623338696393083e-10
# epoch:  29	assembling the matrix time taken:  0.00017333030700683594
# solving Ax = b time taken:  0.0024442672729492188
# newton iteration:  1
# torch.Size([1, 29])
# sol_update_l2_norm:135.79076722180628 	 residual l2 norm: 0.006104669181549417
# newton iteration:  2
# torch.Size([1, 29])
# sol_update_l2_norm:0.0030021675869331198 	 residual l2 norm: 0.00016765774289020303
# newton iteration:  3
# torch.Size([1, 29])
# sol_update_l2_norm:2.0189039522058414e-09 	 residual l2 norm: 2.762412074113738e-12
# converged at iteration:  3
# sol_update_l2_norm:2.0189039522058414e-09 	 residual l2 norm: 2.762412074113738e-12
# epoch:  30	assembling the matrix time taken:  0.0001709461212158203
# solving Ax = b time taken:  0.0025436878204345703
# newton iteration:  1
# torch.Size([1, 30])
# sol_update_l2_norm:948.2091994111514 	 residual l2 norm: 0.004463939828553996
# newton iteration:  2
# torch.Size([1, 30])
# sol_update_l2_norm:0.008191474484065719 	 residual l2 norm: 0.00024824649727362677
# newton iteration:  3
# torch.Size([1, 30])
# sol_update_l2_norm:3.1814133097326736e-09 	 residual l2 norm: 2.4997499475671117e-11
# converged at iteration:  3
# sol_update_l2_norm:3.1814133097326736e-09 	 residual l2 norm: 2.4997499475671117e-11
# epoch:  31	assembling the matrix time taken:  0.00016450881958007812
# solving Ax = b time taken:  0.0026068687438964844
# newton iteration:  1
# torch.Size([1, 31])
# sol_update_l2_norm:394.9088541263351 	 residual l2 norm: 0.004629151222942247
# newton iteration:  2
# torch.Size([1, 31])
# sol_update_l2_norm:0.007707322149465838 	 residual l2 norm: 8.760256642344632e-05
# newton iteration:  3
# torch.Size([1, 31])
# sol_update_l2_norm:2.6657095711520263e-09 	 residual l2 norm: 5.211897298761601e-12
# converged at iteration:  3
# sol_update_l2_norm:2.6657095711520263e-09 	 residual l2 norm: 5.211897298761601e-12
# epoch:  32	assembling the matrix time taken:  0.000171661376953125
# solving Ax = b time taken:  0.0026760101318359375
# newton iteration:  1
# torch.Size([1, 32])
# sol_update_l2_norm:164.85626881015128 	 residual l2 norm: 0.002118654560679849
# newton iteration:  2
# torch.Size([1, 32])
# sol_update_l2_norm:0.0012844974547276775 	 residual l2 norm: 2.371340340713933e-05
# newton iteration:  3
# torch.Size([1, 32])
# sol_update_l2_norm:1.0203294260862887e-09 	 residual l2 norm: 1.6885503958798577e-12
# converged at iteration:  3
# sol_update_l2_norm:1.0203294260862887e-09 	 residual l2 norm: 1.6885503958798577e-12
# epoch:  33	assembling the matrix time taken:  0.000255584716796875
# solving Ax = b time taken:  0.002900838851928711
# newton iteration:  1
# torch.Size([1, 33])
# sol_update_l2_norm:230.5504959566527 	 residual l2 norm: 0.001894237760260742
# newton iteration:  2
# torch.Size([1, 33])
# sol_update_l2_norm:0.0016329955133289303 	 residual l2 norm: 5.8161918150115345e-05
# newton iteration:  3
# torch.Size([1, 33])
# sol_update_l2_norm:2.8148799179988948e-09 	 residual l2 norm: 2.0914792629956903e-12
# converged at iteration:  3
# sol_update_l2_norm:2.8148799179988948e-09 	 residual l2 norm: 2.0914792629956903e-12
# epoch:  34	assembling the matrix time taken:  0.0002818107604980469
# solving Ax = b time taken:  0.002882719039916992
# newton iteration:  1
# torch.Size([1, 34])
# sol_update_l2_norm:407.20551501507924 	 residual l2 norm: 0.0020330466995281127
# newton iteration:  2
# torch.Size([1, 34])
# sol_update_l2_norm:0.002787857615662665 	 residual l2 norm: 0.0001790162639300284
# newton iteration:  3
# torch.Size([1, 34])
# sol_update_l2_norm:2.630375192107388e-09 	 residual l2 norm: 2.4754727937031172e-12
# converged at iteration:  3
# sol_update_l2_norm:2.630375192107388e-09 	 residual l2 norm: 2.4754727937031172e-12
# epoch:  35	assembling the matrix time taken:  0.00020003318786621094
# solving Ax = b time taken:  0.002996683120727539
# newton iteration:  1
# torch.Size([1, 35])
# sol_update_l2_norm:79.24790678049034 	 residual l2 norm: 0.0031163568463729316
# newton iteration:  2
# torch.Size([1, 35])
# sol_update_l2_norm:0.0011998586053755583 	 residual l2 norm: 6.876872493457084e-05
# newton iteration:  3
# torch.Size([1, 35])
# sol_update_l2_norm:1.2908217488645375e-09 	 residual l2 norm: 2.296811232738932e-12
# converged at iteration:  3
# sol_update_l2_norm:1.2908217488645375e-09 	 residual l2 norm: 2.296811232738932e-12
# epoch:  36	assembling the matrix time taken:  0.000209808349609375
# solving Ax = b time taken:  0.003021717071533203
# newton iteration:  1
# torch.Size([1, 36])
# sol_update_l2_norm:504.1910023388498 	 residual l2 norm: 0.0020040529871181733
# newton iteration:  2
# torch.Size([1, 36])
# sol_update_l2_norm:0.008079253291463062 	 residual l2 norm: 0.00014495280383124368
# newton iteration:  3
# torch.Size([1, 36])
# sol_update_l2_norm:3.019431118172835e-09 	 residual l2 norm: 1.4921668075667786e-11
# converged at iteration:  3
# sol_update_l2_norm:3.019431118172835e-09 	 residual l2 norm: 1.4921668075667786e-11
# epoch:  37	assembling the matrix time taken:  0.00016260147094726562
# solving Ax = b time taken:  0.0031473636627197266
# newton iteration:  1
# torch.Size([1, 37])
# sol_update_l2_norm:187.28379686044326 	 residual l2 norm: 0.002480085013023297
# newton iteration:  2
# torch.Size([1, 37])
# sol_update_l2_norm:0.0027151459930343674 	 residual l2 norm: 2.7390376526137933e-05
# newton iteration:  3
# torch.Size([1, 37])
# sol_update_l2_norm:5.829469314074205e-09 	 residual l2 norm: 5.32194471147746e-13
# converged at iteration:  3
# sol_update_l2_norm:5.829469314074205e-09 	 residual l2 norm: 5.32194471147746e-13
# epoch:  38	assembling the matrix time taken:  0.00017642974853515625
# solving Ax = b time taken:  0.003177642822265625
# newton iteration:  1
# torch.Size([1, 38])
# sol_update_l2_norm:777.0408681152344 	 residual l2 norm: 0.0022022388798731214
# newton iteration:  2
# torch.Size([1, 38])
# sol_update_l2_norm:0.013823872314657015 	 residual l2 norm: 0.0002934434122508859
# newton iteration:  3
# torch.Size([1, 38])
# sol_update_l2_norm:4.761567205545427e-09 	 residual l2 norm: 2.5659814222609943e-11
# converged at iteration:  3
# sol_update_l2_norm:4.761567205545427e-09 	 residual l2 norm: 2.5659814222609943e-11
# epoch:  39	assembling the matrix time taken:  0.0001766681671142578
# solving Ax = b time taken:  0.003248929977416992
# newton iteration:  1
# torch.Size([1, 39])
# sol_update_l2_norm:168.9337923688727 	 residual l2 norm: 0.0038259472849140317
# newton iteration:  2
# torch.Size([1, 39])
# sol_update_l2_norm:0.0022271376422261374 	 residual l2 norm: 9.230341222205285e-05
# newton iteration:  3
# torch.Size([1, 39])
# sol_update_l2_norm:5.650406150687556e-09 	 residual l2 norm: 1.457515839511873e-12
# converged at iteration:  3
# sol_update_l2_norm:5.650406150687556e-09 	 residual l2 norm: 1.457515839511873e-12
# epoch:  40	assembling the matrix time taken:  0.0001766681671142578
# solving Ax = b time taken:  0.0032951831817626953
# newton iteration:  1
# torch.Size([1, 40])
# sol_update_l2_norm:160.39801849476746 	 residual l2 norm: 0.0026622141190667027
# newton iteration:  2
# torch.Size([1, 40])
# sol_update_l2_norm:0.0020245448689005085 	 residual l2 norm: 4.5678290047577704e-05
# newton iteration:  3
# torch.Size([1, 40])
# sol_update_l2_norm:1.0096168127846119e-09 	 residual l2 norm: 2.167037566098574e-12
# converged at iteration:  3
# sol_update_l2_norm:1.0096168127846119e-09 	 residual l2 norm: 2.167037566098574e-12
# epoch:  41	assembling the matrix time taken:  0.00017452239990234375
# solving Ax = b time taken:  0.0033817291259765625
# newton iteration:  1
# torch.Size([1, 41])
# sol_update_l2_norm:82.82279808248549 	 residual l2 norm: 0.002419150500038201
# newton iteration:  2
# torch.Size([1, 41])
# sol_update_l2_norm:0.001579976314594364 	 residual l2 norm: 1.5588538578712478e-05
# newton iteration:  3
# torch.Size([1, 41])
# sol_update_l2_norm:2.235440376386838e-09 	 residual l2 norm: 2.2476515823614835e-12
# converged at iteration:  3
# sol_update_l2_norm:2.235440376386838e-09 	 residual l2 norm: 2.2476515823614835e-12
# epoch:  42	assembling the matrix time taken:  0.000179290771484375
# solving Ax = b time taken:  0.003422975540161133
# newton iteration:  1
# torch.Size([1, 42])
# sol_update_l2_norm:1206.419171800475 	 residual l2 norm: 0.001936674381505468
# newton iteration:  2
# torch.Size([1, 42])
# sol_update_l2_norm:0.007410634376269909 	 residual l2 norm: 0.00010406010261846214
# newton iteration:  3
# torch.Size([1, 42])
# sol_update_l2_norm:2.091851940539275e-09 	 residual l2 norm: 9.731689110608423e-12
# converged at iteration:  3
# sol_update_l2_norm:2.091851940539275e-09 	 residual l2 norm: 9.731689110608423e-12
# epoch:  43	assembling the matrix time taken:  0.0001723766326904297
# solving Ax = b time taken:  0.003517627716064453
# newton iteration:  1
# torch.Size([1, 43])
# sol_update_l2_norm:219.41287834102118 	 residual l2 norm: 0.0021313379882777262
# newton iteration:  2
# torch.Size([1, 43])
# sol_update_l2_norm:0.001497665943528186 	 residual l2 norm: 4.098961660672929e-05
# newton iteration:  3
# torch.Size([1, 43])
# sol_update_l2_norm:1.4161047995898402e-09 	 residual l2 norm: 1.5019992670474743e-12
# converged at iteration:  3
# sol_update_l2_norm:1.4161047995898402e-09 	 residual l2 norm: 1.5019992670474743e-12
# epoch:  44	assembling the matrix time taken:  0.0001800060272216797
# solving Ax = b time taken:  0.003518819808959961
# newton iteration:  1
# torch.Size([1, 44])
# sol_update_l2_norm:1072.285417375202 	 residual l2 norm: 0.0018559014793797135
# newton iteration:  2
# torch.Size([1, 44])
# sol_update_l2_norm:0.007635333987936761 	 residual l2 norm: 0.00038283101422837627
# newton iteration:  3
# torch.Size([1, 44])
# sol_update_l2_norm:6.915602200034014e-09 	 residual l2 norm: 4.048068411158209e-11
# converged at iteration:  3
# sol_update_l2_norm:6.915602200034014e-09 	 residual l2 norm: 4.048068411158209e-11
# epoch:  45	assembling the matrix time taken:  0.00017213821411132812
# solving Ax = b time taken:  0.003609895706176758
# newton iteration:  1
# torch.Size([1, 45])
# sol_update_l2_norm:150.56762674877248 	 residual l2 norm: 0.0014891017901240888
# newton iteration:  2
# torch.Size([1, 45])
# sol_update_l2_norm:0.0013836338216622445 	 residual l2 norm: 4.357429451003658e-06
# newton iteration:  3
# torch.Size([1, 45])
# sol_update_l2_norm:4.022582980428723e-09 	 residual l2 norm: 3.396332915120191e-12
# converged at iteration:  3
# sol_update_l2_norm:4.022582980428723e-09 	 residual l2 norm: 3.396332915120191e-12
# epoch:  46	assembling the matrix time taken:  0.00018644332885742188
# solving Ax = b time taken:  0.003681659698486328
# newton iteration:  1
# torch.Size([1, 46])
# sol_update_l2_norm:150.355545194469 	 residual l2 norm: 0.0017698360535772025
# newton iteration:  2
# torch.Size([1, 46])
# sol_update_l2_norm:0.0006574343370439198 	 residual l2 norm: 1.1263475276478438e-05
# newton iteration:  3
# torch.Size([1, 46])
# sol_update_l2_norm:4.6962030175222915e-09 	 residual l2 norm: 4.5705223455193625e-12
# converged at iteration:  3
# sol_update_l2_norm:4.6962030175222915e-09 	 residual l2 norm: 4.5705223455193625e-12
# epoch:  47	assembling the matrix time taken:  0.0001609325408935547
# solving Ax = b time taken:  0.003763914108276367
# newton iteration:  1
# torch.Size([1, 47])
# sol_update_l2_norm:455.44797356964546 	 residual l2 norm: 0.0011070084313759994
# newton iteration:  2
# torch.Size([1, 47])
# sol_update_l2_norm:0.0016837022157774283 	 residual l2 norm: 6.161271628611318e-05
# newton iteration:  3
# torch.Size([1, 47])
# sol_update_l2_norm:4.07217552575404e-09 	 residual l2 norm: 2.104995437411628e-12
# converged at iteration:  3
# sol_update_l2_norm:4.07217552575404e-09 	 residual l2 norm: 2.104995437411628e-12
# epoch:  48	assembling the matrix time taken:  0.0001780986785888672
# solving Ax = b time taken:  0.0038080215454101562
# newton iteration:  1
# torch.Size([1, 48])
# sol_update_l2_norm:425.90909935739813 	 residual l2 norm: 0.000933287754312476
# newton iteration:  2
# torch.Size([1, 48])
# sol_update_l2_norm:0.000849266718582019 	 residual l2 norm: 2.0466494584907836e-05
# newton iteration:  3
# torch.Size([1, 48])
# sol_update_l2_norm:2.8930705740586023e-09 	 residual l2 norm: 1.8073310953820885e-12
# converged at iteration:  3
# sol_update_l2_norm:2.8930705740586023e-09 	 residual l2 norm: 1.8073310953820885e-12
# epoch:  49	assembling the matrix time taken:  0.00015974044799804688
# solving Ax = b time taken:  0.003922939300537109
# newton iteration:  1
# torch.Size([1, 49])
# sol_update_l2_norm:2182.859850228893 	 residual l2 norm: 0.0007936836365207697
# newton iteration:  2
# torch.Size([1, 49])
# sol_update_l2_norm:0.006689418144393267 	 residual l2 norm: 3.594908794893886e-05
# newton iteration:  3
# torch.Size([1, 49])
# sol_update_l2_norm:4.297717432532223e-08 	 residual l2 norm: 1.0904490605979752e-11
# converged at iteration:  3
# sol_update_l2_norm:4.297717432532223e-08 	 residual l2 norm: 1.0904490605979752e-11
# epoch:  50	assembling the matrix time taken:  0.00017833709716796875
# solving Ax = b time taken:  0.003972291946411133
# newton iteration:  1
# torch.Size([1, 50])
# sol_update_l2_norm:408.41677299835607 	 residual l2 norm: 0.0011515908105023517
# newton iteration:  2
# torch.Size([1, 50])
# sol_update_l2_norm:0.0029712376473430687 	 residual l2 norm: 9.231251803644818e-06
# newton iteration:  3
# torch.Size([1, 50])
# sol_update_l2_norm:5.579040057244662e-08 	 residual l2 norm: 1.1010209543305707e-11
# converged at iteration:  3
# sol_update_l2_norm:5.579040057244662e-08 	 residual l2 norm: 1.1010209543305707e-11
# epoch:  51	assembling the matrix time taken:  0.00017642974853515625
# solving Ax = b time taken:  0.004046201705932617
# newton iteration:  1
# torch.Size([1, 51])
# sol_update_l2_norm:184.61393704923552 	 residual l2 norm: 0.0008758265481059462
# newton iteration:  2
# torch.Size([1, 51])
# sol_update_l2_norm:0.00032996379284221 	 residual l2 norm: 6.384730926525686e-06
# newton iteration:  3
# torch.Size([1, 51])
# sol_update_l2_norm:2.541697172259863e-08 	 residual l2 norm: 5.609209899845955e-12
# converged at iteration:  3
# sol_update_l2_norm:2.541697172259863e-08 	 residual l2 norm: 5.609209899845955e-12
# epoch:  52	assembling the matrix time taken:  0.00017523765563964844
# solving Ax = b time taken:  0.0041239261627197266
# newton iteration:  1
# torch.Size([1, 52])
# sol_update_l2_norm:662.6845150933113 	 residual l2 norm: 0.0007852326722633614
# newton iteration:  2
# torch.Size([1, 52])
# sol_update_l2_norm:0.001763897981551037 	 residual l2 norm: 2.677405467752881e-05
# newton iteration:  3
# torch.Size([1, 52])
# sol_update_l2_norm:2.700299702535632e-08 	 residual l2 norm: 3.141748560020941e-12
# converged at iteration:  3
# sol_update_l2_norm:2.700299702535632e-08 	 residual l2 norm: 3.141748560020941e-12
# epoch:  53	assembling the matrix time taken:  0.00015544891357421875
# solving Ax = b time taken:  0.0042269229888916016
# newton iteration:  1
# torch.Size([1, 53])
# sol_update_l2_norm:853.5484431410675 	 residual l2 norm: 0.0006121733843177861
# newton iteration:  2
# torch.Size([1, 53])
# sol_update_l2_norm:0.002548567318505171 	 residual l2 norm: 1.909381986766175e-05
# newton iteration:  3
# torch.Size([1, 53])
# sol_update_l2_norm:2.670780762533662e-08 	 residual l2 norm: 5.018593597379e-12
# converged at iteration:  3
# sol_update_l2_norm:2.670780762533662e-08 	 residual l2 norm: 5.018593597379e-12
# epoch:  54	assembling the matrix time taken:  0.00017881393432617188
# solving Ax = b time taken:  0.0042760372161865234
# newton iteration:  1
# torch.Size([1, 54])
# sol_update_l2_norm:78.5039781399095 	 residual l2 norm: 0.0008062541767888024
# newton iteration:  2
# torch.Size([1, 54])
# sol_update_l2_norm:0.00033504169887253195 	 residual l2 norm: 5.833825430929758e-06
# newton iteration:  3
# torch.Size([1, 54])
# sol_update_l2_norm:2.4147712369464654e-08 	 residual l2 norm: 5.4697293339929e-12
# converged at iteration:  3
# sol_update_l2_norm:2.4147712369464654e-08 	 residual l2 norm: 5.4697293339929e-12
# epoch:  55	assembling the matrix time taken:  0.0001595020294189453
# solving Ax = b time taken:  0.004365205764770508
# newton iteration:  1
# torch.Size([1, 55])
# sol_update_l2_norm:1847.502458245725 	 residual l2 norm: 0.00064296568674202
# newton iteration:  2
# torch.Size([1, 55])
# sol_update_l2_norm:0.004460661669880734 	 residual l2 norm: 0.00010191039968008484
# newton iteration:  3
# torch.Size([1, 55])
# sol_update_l2_norm:1.828027593837117e-08 	 residual l2 norm: 5.321646281934241e-12
# converged at iteration:  3
# sol_update_l2_norm:1.828027593837117e-08 	 residual l2 norm: 5.321646281934241e-12
# epoch:  56	assembling the matrix time taken:  0.00018024444580078125
# solving Ax = b time taken:  0.004418611526489258
# newton iteration:  1
# torch.Size([1, 56])
# sol_update_l2_norm:303.519379392088 	 residual l2 norm: 0.0005342883598820431
# newton iteration:  2
# torch.Size([1, 56])
# sol_update_l2_norm:0.0006768934500739562 	 residual l2 norm: 1.5042224539062037e-06
# newton iteration:  3
# torch.Size([1, 56])
# sol_update_l2_norm:7.290308847107482e-08 	 residual l2 norm: 3.829145916157749e-12
# converged at iteration:  3
# sol_update_l2_norm:7.290308847107482e-08 	 residual l2 norm: 3.829145916157749e-12
# epoch:  57	assembling the matrix time taken:  0.00015592575073242188
# solving Ax = b time taken:  0.004512310028076172
# newton iteration:  1
# torch.Size([1, 57])
# sol_update_l2_norm:706.6933700490671 	 residual l2 norm: 0.000701493362177343
# newton iteration:  2
# torch.Size([1, 57])
# sol_update_l2_norm:0.0013732717664836577 	 residual l2 norm: 7.630983879823869e-05
# newton iteration:  3
# torch.Size([1, 57])
# sol_update_l2_norm:6.457228647847127e-09 	 residual l2 norm: 2.6821979895803274e-12
# converged at iteration:  3
# sol_update_l2_norm:6.457228647847127e-09 	 residual l2 norm: 2.6821979895803274e-12
# epoch:  58	assembling the matrix time taken:  0.00017786026000976562
# solving Ax = b time taken:  0.0045583248138427734
# newton iteration:  1
# torch.Size([1, 58])
# sol_update_l2_norm:872.5087786565045 	 residual l2 norm: 0.0004693810906260265
# newton iteration:  2
# torch.Size([1, 58])
# sol_update_l2_norm:0.0015236034795347915 	 residual l2 norm: 1.837149508365182e-05
# newton iteration:  3
# torch.Size([1, 58])
# sol_update_l2_norm:1.4454664241746958e-08 	 residual l2 norm: 6.359156524597361e-12
# converged at iteration:  3
# sol_update_l2_norm:1.4454664241746958e-08 	 residual l2 norm: 6.359156524597361e-12
# epoch:  59	assembling the matrix time taken:  0.00017118453979492188
# solving Ax = b time taken:  0.004657268524169922
# newton iteration:  1
# torch.Size([1, 59])
# sol_update_l2_norm:123.89704507206014 	 residual l2 norm: 0.0004976436240841079
# newton iteration:  2
# torch.Size([1, 59])
# sol_update_l2_norm:0.00010068240411309521 	 residual l2 norm: 1.5107156869829169e-06
# newton iteration:  3
# torch.Size([1, 59])
# sol_update_l2_norm:3.113335334288022e-08 	 residual l2 norm: 2.7965772917495146e-12
# converged at iteration:  3
# sol_update_l2_norm:3.113335334288022e-08 	 residual l2 norm: 2.7965772917495146e-12
# epoch:  60	assembling the matrix time taken:  0.00017714500427246094
# solving Ax = b time taken:  0.004690885543823242
# newton iteration:  1
# torch.Size([1, 60])
# sol_update_l2_norm:550.8267460643879 	 residual l2 norm: 0.00041923642952044023
# newton iteration:  2
# torch.Size([1, 60])
# sol_update_l2_norm:0.00035441386472096273 	 residual l2 norm: 4.788237412454329e-06
# newton iteration:  3
# torch.Size([1, 60])
# sol_update_l2_norm:2.28594631151149e-08 	 residual l2 norm: 3.3835104016798756e-12
# converged at iteration:  3
# sol_update_l2_norm:2.28594631151149e-08 	 residual l2 norm: 3.3835104016798756e-12
# epoch:  61	assembling the matrix time taken:  0.00015997886657714844
# solving Ax = b time taken:  0.004786968231201172
# newton iteration:  1
# torch.Size([1, 61])
# sol_update_l2_norm:2326.894624208267 	 residual l2 norm: 0.0003224809615398424
# newton iteration:  2
# torch.Size([1, 61])
# sol_update_l2_norm:0.0037296562680678787 	 residual l2 norm: 0.0001062435827552884
# newton iteration:  3
# torch.Size([1, 61])
# sol_update_l2_norm:1.0658276511623012e-08 	 residual l2 norm: 3.85102510187926e-12
# converged at iteration:  3
# sol_update_l2_norm:1.0658276511623012e-08 	 residual l2 norm: 3.85102510187926e-12
# epoch:  62	assembling the matrix time taken:  0.0001761913299560547
# solving Ax = b time taken:  0.004847049713134766
# newton iteration:  1
# torch.Size([1, 62])
# sol_update_l2_norm:154.1487076436553 	 residual l2 norm: 0.00028548320916116474
# newton iteration:  2
# torch.Size([1, 62])
# sol_update_l2_norm:0.00011253647368114507 	 residual l2 norm: 2.36932614374016e-06
# newton iteration:  3
# torch.Size([1, 62])
# sol_update_l2_norm:1.108973837136538e-08 	 residual l2 norm: 1.987719868910423e-12
# converged at iteration:  3
# sol_update_l2_norm:1.108973837136538e-08 	 residual l2 norm: 1.987719868910423e-12
# epoch:  63	assembling the matrix time taken:  0.0001773834228515625
# solving Ax = b time taken:  0.0049381256103515625
# newton iteration:  1
# torch.Size([1, 63])
# sol_update_l2_norm:667.2352450776035 	 residual l2 norm: 0.00030025146906224566
# newton iteration:  2
# torch.Size([1, 63])
# sol_update_l2_norm:0.0003798570742381671 	 residual l2 norm: 6.114464411151917e-06
# newton iteration:  3
# torch.Size([1, 63])
# sol_update_l2_norm:2.0931290948139856e-08 	 residual l2 norm: 2.7605184897850864e-12
# converged at iteration:  3
# sol_update_l2_norm:2.0931290948139856e-08 	 residual l2 norm: 2.7605184897850864e-12
# epoch:  64	assembling the matrix time taken:  0.00018548965454101562
# solving Ax = b time taken:  0.004975557327270508
# newton iteration:  1
# torch.Size([1, 64])
# sol_update_l2_norm:170.72150691862296 	 residual l2 norm: 0.0003683785815002601
# newton iteration:  2
# torch.Size([1, 64])
# sol_update_l2_norm:0.0002196818214345803 	 residual l2 norm: 1.9131594800510076e-06
# newton iteration:  3
# torch.Size([1, 64])
# sol_update_l2_norm:5.285625539186583e-08 	 residual l2 norm: 6.197283383592184e-12
# converged at iteration:  3
# sol_update_l2_norm:5.285625539186583e-08 	 residual l2 norm: 6.197283383592184e-12
# epoch:  65	assembling the matrix time taken:  0.0001678466796875
# solving Ax = b time taken:  0.006497859954833984
# newton iteration:  1
# torch.Size([1, 65])
# sol_update_l2_norm:500.44145105443835 	 residual l2 norm: 0.00025186002839325836
# newton iteration:  2
# torch.Size([1, 65])
# sol_update_l2_norm:0.00017588367414405438 	 residual l2 norm: 9.859045349524025e-07
# newton iteration:  3
# torch.Size([1, 65])
# sol_update_l2_norm:1.0778329406045223e-08 	 residual l2 norm: 1.7793081272308467e-12
# converged at iteration:  3
# sol_update_l2_norm:1.0778329406045223e-08 	 residual l2 norm: 1.7793081272308467e-12
# epoch:  66	assembling the matrix time taken:  0.00024962425231933594
# solving Ax = b time taken:  0.006730794906616211
# newton iteration:  1
# torch.Size([1, 66])
# sol_update_l2_norm:387.4402186099387 	 residual l2 norm: 0.00020866390859339328
# newton iteration:  2
# torch.Size([1, 66])
# sol_update_l2_norm:0.00046307206118615643 	 residual l2 norm: 1.2514498056658948e-05
# newton iteration:  3
# torch.Size([1, 66])
# sol_update_l2_norm:1.4048775134942103e-08 	 residual l2 norm: 1.541301902136117e-12
# converged at iteration:  3
# sol_update_l2_norm:1.4048775134942103e-08 	 residual l2 norm: 1.541301902136117e-12
# epoch:  67	assembling the matrix time taken:  0.00016117095947265625
# solving Ax = b time taken:  0.007277965545654297
# newton iteration:  1
# torch.Size([1, 67])
# sol_update_l2_norm:336.36226447572113 	 residual l2 norm: 0.0002202740951241401
# newton iteration:  2
# torch.Size([1, 67])
# sol_update_l2_norm:9.710951550535018e-05 	 residual l2 norm: 7.176007150272384e-07
# newton iteration:  3
# torch.Size([1, 67])
# sol_update_l2_norm:1.1706307265881613e-08 	 residual l2 norm: 1.136887493059241e-12
# converged at iteration:  3
# sol_update_l2_norm:1.1706307265881613e-08 	 residual l2 norm: 1.136887493059241e-12
# epoch:  68	assembling the matrix time taken:  0.00019288063049316406
# solving Ax = b time taken:  0.0066950321197509766
# newton iteration:  1
# torch.Size([1, 68])
# sol_update_l2_norm:239.30813881929984 	 residual l2 norm: 0.0002152582265876398
# newton iteration:  2
# torch.Size([1, 68])
# sol_update_l2_norm:8.865592400572101e-05 	 residual l2 norm: 6.476950982861331e-07
# newton iteration:  3
# torch.Size([1, 68])
# sol_update_l2_norm:8.111376983795269e-09 	 residual l2 norm: 4.5134231327876326e-12
# converged at iteration:  3
# sol_update_l2_norm:8.111376983795269e-09 	 residual l2 norm: 4.5134231327876326e-12
# epoch:  69	assembling the matrix time taken:  0.00016808509826660156
# solving Ax = b time taken:  0.007560253143310547
# newton iteration:  1
# torch.Size([1, 69])
# sol_update_l2_norm:184.57872675755152 	 residual l2 norm: 0.00028945824185145724
# newton iteration:  2
# torch.Size([1, 69])
# sol_update_l2_norm:0.00021320183056903005 	 residual l2 norm: 3.2404462655030854e-06
# newton iteration:  3
# torch.Size([1, 69])
# sol_update_l2_norm:2.5501650022637015e-08 	 residual l2 norm: 4.223210337384902e-12
# converged at iteration:  3
# sol_update_l2_norm:2.5501650022637015e-08 	 residual l2 norm: 4.223210337384902e-12
# epoch:  70	assembling the matrix time taken:  0.00019693374633789062
# solving Ax = b time taken:  0.006997108459472656
# newton iteration:  1
# torch.Size([1, 70])
# sol_update_l2_norm:623.9355827911842 	 residual l2 norm: 0.00021038764376635652
# newton iteration:  2
# torch.Size([1, 70])
# sol_update_l2_norm:0.00015219525347160708 	 residual l2 norm: 8.291186241199907e-07
# newton iteration:  3
# torch.Size([1, 70])
# sol_update_l2_norm:2.8105912544639845e-08 	 residual l2 norm: 1.8634502521693198e-12
# converged at iteration:  3
# sol_update_l2_norm:2.8105912544639845e-08 	 residual l2 norm: 1.8634502521693198e-12
# epoch:  71	assembling the matrix time taken:  0.0001590251922607422
# solving Ax = b time taken:  0.0074253082275390625
# newton iteration:  1
# torch.Size([1, 71])
# sol_update_l2_norm:1585.1709681331643 	 residual l2 norm: 0.00023921132116516504
# newton iteration:  2
# torch.Size([1, 71])
# sol_update_l2_norm:0.0018580020988392262 	 residual l2 norm: 3.6150205242129855e-05
# newton iteration:  3
# torch.Size([1, 71])
# sol_update_l2_norm:2.5460632083728635e-08 	 residual l2 norm: 6.405888959114641e-12
# converged at iteration:  3
# sol_update_l2_norm:2.5460632083728635e-08 	 residual l2 norm: 6.405888959114641e-12
# epoch:  72	assembling the matrix time taken:  0.00020122528076171875
# solving Ax = b time taken:  0.006773710250854492
# newton iteration:  1
# torch.Size([1, 72])
# sol_update_l2_norm:324.68670688411294 	 residual l2 norm: 0.00021170244900053727
# newton iteration:  2
# torch.Size([1, 72])
# sol_update_l2_norm:5.284685207316263e-05 	 residual l2 norm: 1.5898613835312718e-06
# newton iteration:  3
# torch.Size([1, 72])
# sol_update_l2_norm:1.0558496451633686e-08 	 residual l2 norm: 3.976775278287403e-12
# converged at iteration:  3
# sol_update_l2_norm:1.0558496451633686e-08 	 residual l2 norm: 3.976775278287403e-12
# epoch:  73	assembling the matrix time taken:  0.0001621246337890625
# solving Ax = b time taken:  0.00762939453125
# newton iteration:  1
# torch.Size([1, 73])
# sol_update_l2_norm:480.98648643175363 	 residual l2 norm: 0.00024371574144682013
# newton iteration:  2
# torch.Size([1, 73])
# sol_update_l2_norm:0.0004837159626668771 	 residual l2 norm: 1.083788608614659e-05
# newton iteration:  3
# torch.Size([1, 73])
# sol_update_l2_norm:3.2950812341216524e-08 	 residual l2 norm: 4.441904775004446e-12
# converged at iteration:  3
# sol_update_l2_norm:3.2950812341216524e-08 	 residual l2 norm: 4.441904775004446e-12
# epoch:  74	assembling the matrix time taken:  0.000202178955078125
# solving Ax = b time taken:  0.0072977542877197266
# newton iteration:  1
# torch.Size([1, 74])
# sol_update_l2_norm:78.74783076322463 	 residual l2 norm: 0.00026747105582986127
# newton iteration:  2
# torch.Size([1, 74])
# sol_update_l2_norm:2.3295314180553044e-05 	 residual l2 norm: 9.738109867374238e-08
# newton iteration:  3
# torch.Size([1, 74])
# sol_update_l2_norm:5.711677480508135e-08 	 residual l2 norm: 1.1013446918475944e-12
# converged at iteration:  3
# sol_update_l2_norm:5.711677480508135e-08 	 residual l2 norm: 1.1013446918475944e-12
# epoch:  75	assembling the matrix time taken:  0.0001609325408935547
# solving Ax = b time taken:  0.007855653762817383
# newton iteration:  1
# torch.Size([1, 75])
# sol_update_l2_norm:83.6104998790014 	 residual l2 norm: 0.00024496558426359013
# newton iteration:  2
# torch.Size([1, 75])
# sol_update_l2_norm:0.00010418738731086834 	 residual l2 norm: 4.0322015101858337e-07
# newton iteration:  3
# torch.Size([1, 75])
# sol_update_l2_norm:7.153658363278918e-08 	 residual l2 norm: 5.141173826900052e-12
# converged at iteration:  3
# sol_update_l2_norm:7.153658363278918e-08 	 residual l2 norm: 5.141173826900052e-12
# epoch:  76	assembling the matrix time taken:  0.00018835067749023438
# solving Ax = b time taken:  0.00704193115234375
# newton iteration:  1
# torch.Size([1, 76])
# sol_update_l2_norm:313.66013909014276 	 residual l2 norm: 0.00022892568644989662
# newton iteration:  2
# torch.Size([1, 76])
# sol_update_l2_norm:6.205077724395408e-05 	 residual l2 norm: 4.623310476145447e-07
# newton iteration:  3
# torch.Size([1, 76])
# sol_update_l2_norm:2.191049877354304e-08 	 residual l2 norm: 3.2952005357135082e-12
# converged at iteration:  3
# sol_update_l2_norm:2.191049877354304e-08 	 residual l2 norm: 3.2952005357135082e-12
# epoch:  77	assembling the matrix time taken:  0.00016188621520996094
# solving Ax = b time taken:  0.008077621459960938
# newton iteration:  1
# torch.Size([1, 77])
# sol_update_l2_norm:727.8878663114658 	 residual l2 norm: 0.00019940895647042585
# newton iteration:  2
# torch.Size([1, 77])
# sol_update_l2_norm:0.0003363007254400308 	 residual l2 norm: 3.772909781973753e-07
# newton iteration:  3
# torch.Size([1, 77])
# sol_update_l2_norm:4.406520421150959e-08 	 residual l2 norm: 8.174745232542068e-13
# converged at iteration:  3
# sol_update_l2_norm:4.406520421150959e-08 	 residual l2 norm: 8.174745232542068e-13
# epoch:  78	assembling the matrix time taken:  0.00021076202392578125
# solving Ax = b time taken:  0.0075836181640625
# newton iteration:  1
# torch.Size([1, 78])
# sol_update_l2_norm:84.51678093152034 	 residual l2 norm: 0.00019172691918682212
# newton iteration:  2
# torch.Size([1, 78])
# sol_update_l2_norm:2.8049427608471105e-05 	 residual l2 norm: 3.8970444194480603e-07
# newton iteration:  3
# torch.Size([1, 78])
# sol_update_l2_norm:8.506377297811834e-09 	 residual l2 norm: 1.9003510186558642e-12
# converged at iteration:  3
# sol_update_l2_norm:8.506377297811834e-09 	 residual l2 norm: 1.9003510186558642e-12
# epoch:  79	assembling the matrix time taken:  0.0001621246337890625
# solving Ax = b time taken:  0.008603811264038086
# newton iteration:  1
# torch.Size([1, 79])
# sol_update_l2_norm:210.81743020299385 	 residual l2 norm: 0.00018074766505046105
# newton iteration:  2
# torch.Size([1, 79])
# sol_update_l2_norm:0.00019516193456730203 	 residual l2 norm: 3.2767379806359414e-06
# newton iteration:  3
# torch.Size([1, 79])
# sol_update_l2_norm:4.0609425670127327e-08 	 residual l2 norm: 3.704065149148978e-12
# converged at iteration:  3
# sol_update_l2_norm:4.0609425670127327e-08 	 residual l2 norm: 3.704065149148978e-12
# epoch:  80	assembling the matrix time taken:  0.0001933574676513672
# solving Ax = b time taken:  0.00728917121887207
# newton iteration:  1
# torch.Size([1, 80])
# sol_update_l2_norm:60.04852820568826 	 residual l2 norm: 0.0001376434167333238
# newton iteration:  2
# torch.Size([1, 80])
# sol_update_l2_norm:4.46834496004863e-05 	 residual l2 norm: 8.587241462663176e-07
# newton iteration:  3
# torch.Size([1, 80])
# sol_update_l2_norm:3.6726158670757236e-08 	 residual l2 norm: 6.6946781012526285e-12
# converged at iteration:  3
# sol_update_l2_norm:3.6726158670757236e-08 	 residual l2 norm: 6.6946781012526285e-12
# epoch:  81	assembling the matrix time taken:  0.0001628398895263672
# solving Ax = b time taken:  0.008562088012695312
# newton iteration:  1
# torch.Size([1, 81])
# sol_update_l2_norm:831.8016244492932 	 residual l2 norm: 0.00016712671813564058
# newton iteration:  2
# torch.Size([1, 81])
# sol_update_l2_norm:0.0004645646557597042 	 residual l2 norm: 8.30137135728313e-06
# newton iteration:  3
# torch.Size([1, 81])
# ...
# newton iteration:  2
# torch.Size([1, 89])
# sol_update_l2_norm:1.0162352055268752e-05 	 residual l2 norm: 1.1029690919457908e-07
# newton iteration:  3
# torch.Size([1, 89])
# sol_update_l2_norm:1.2423353837170973e-07 	 residual l2 norm: 5.63629634283419e-12
# converged at iteration:  3
# sol_update_l2_norm:1.2423353837170973e-07 	 residual l2 norm: 5.63629634283419e-12
# epoch:  90	assembling the matrix time taken:  0.00019240379333496094
# solving Ax = b time taken:  0.009496927261352539
# newton iteration:  1
# torch.Size([1, 90])
# sol_update_l2_norm:366.77649620423347 	 residual l2 norm: 0.00010609460707144402
# newton iteration:  2
# torch.Size([1, 90])
# sol_update_l2_norm:3.3161661816417434e-05 	 residual l2 norm: 5.335915150511608e-07
# newton iteration:  3
# torch.Size([1, 90])
# sol_update_l2_norm:3.152740738142333e-08 	 residual l2 norm: 4.764214517984725e-12
# converged at iteration:  3
# sol_update_l2_norm:3.152740738142333e-08 	 residual l2 norm: 4.764214517984725e-12
# epoch:  91	assembling the matrix time taken:  0.00016760826110839844
# solving Ax = b time taken:  0.008925914764404297
# newton iteration:  1
# torch.Size([1, 91])
# sol_update_l2_norm:175.3287961813216 	 residual l2 norm: 0.00010172275593359632
# newton iteration:  2
# torch.Size([1, 91])
# sol_update_l2_norm:4.0568362223028836e-05 	 residual l2 norm: 1.5654606831490852e-07
# newton iteration:  3
# torch.Size([1, 91])
# sol_update_l2_norm:1.2256721424721853e-07 	 residual l2 norm: 9.810401242305311e-12
# converged at iteration:  3
# sol_update_l2_norm:1.2256721424721853e-07 	 residual l2 norm: 9.810401242305311e-12
# epoch:  92	assembling the matrix time taken:  0.00018143653869628906
# solving Ax = b time taken:  0.008861541748046875
# newton iteration:  1
# torch.Size([1, 92])
# sol_update_l2_norm:931.2215886118529 	 residual l2 norm: 9.148549859786002e-05
# newton iteration:  2
# torch.Size([1, 92])
# sol_update_l2_norm:0.00012714683346379133 	 residual l2 norm: 4.055020413175706e-06
# newton iteration:  3
# torch.Size([1, 92])
# sol_update_l2_norm:6.072830489536038e-08 	 residual l2 norm: 2.3293110578808055e-12
# converged at iteration:  3
# sol_update_l2_norm:6.072830489536038e-08 	 residual l2 norm: 2.3293110578808055e-12
# epoch:  93	assembling the matrix time taken:  0.0001785755157470703
# solving Ax = b time taken:  0.008941173553466797
# newton iteration:  1
# torch.Size([1, 93])
# sol_update_l2_norm:1710.8711867728468 	 residual l2 norm: 0.00010320200003044032
# newton iteration:  2
# torch.Size([1, 93])
# sol_update_l2_norm:0.0007579342075993257 	 residual l2 norm: 9.91118937472415e-06
# newton iteration:  3
# torch.Size([1, 93])
# sol_update_l2_norm:3.223122953868224e-07 	 residual l2 norm: 1.4363383852487884e-11
# converged at iteration:  3
# sol_update_l2_norm:3.223122953868224e-07 	 residual l2 norm: 1.4363383852487884e-11
# epoch:  94	assembling the matrix time taken:  0.00024056434631347656
# solving Ax = b time taken:  0.009551525115966797
# newton iteration:  1
# torch.Size([1, 94])
# sol_update_l2_norm:149.4582685488309 	 residual l2 norm: 0.00012386622980950656
# newton iteration:  2
# torch.Size([1, 94])
# sol_update_l2_norm:2.5882723825795485e-05 	 residual l2 norm: 1.258894235115991e-07
# newton iteration:  3
# torch.Size([1, 94])
# sol_update_l2_norm:1.0274030416853035e-08 	 residual l2 norm: 1.3114032243909225e-12
# converged at iteration:  3
# sol_update_l2_norm:1.0274030416853035e-08 	 residual l2 norm: 1.3114032243909225e-12
# epoch:  95	assembling the matrix time taken:  0.0001609325408935547
# solving Ax = b time taken:  0.009110689163208008
# newton iteration:  1
# torch.Size([1, 95])
# sol_update_l2_norm:227.932598656753 	 residual l2 norm: 0.00010787749781617843
# newton iteration:  2
# torch.Size([1, 95])
# sol_update_l2_norm:4.951304665823292e-05 	 residual l2 norm: 2.072696726588521e-06
# newton iteration:  3
# torch.Size([1, 95])
# sol_update_l2_norm:2.2502200262411118e-08 	 residual l2 norm: 1.7169255286517268e-12
# converged at iteration:  3
# sol_update_l2_norm:2.2502200262411118e-08 	 residual l2 norm: 1.7169255286517268e-12
# epoch:  96	assembling the matrix time taken:  0.0001888275146484375
# solving Ax = b time taken:  0.008350372314453125
# newton iteration:  1
# torch.Size([1, 96])
# sol_update_l2_norm:407.6240968751517 	 residual l2 norm: 0.0001026758131897434
# newton iteration:  2
# torch.Size([1, 96])
# sol_update_l2_norm:0.0002271518100983893 	 residual l2 norm: 3.4786986195689537e-06
# newton iteration:  3
# torch.Size([1, 96])
# sol_update_l2_norm:4.475238049315098e-08 	 residual l2 norm: 2.754329364913831e-12
# converged at iteration:  3
# sol_update_l2_norm:4.475238049315098e-08 	 residual l2 norm: 2.754329364913831e-12
# epoch:  97	assembling the matrix time taken:  0.0001678466796875
# solving Ax = b time taken:  0.00894308090209961
# newton iteration:  1
# torch.Size([1, 97])
# sol_update_l2_norm:225.25335512182414 	 residual l2 norm: 0.00010024238721041784
# newton iteration:  2
# torch.Size([1, 97])
# sol_update_l2_norm:5.841514607308681e-05 	 residual l2 norm: 2.483817094024585e-07
# newton iteration:  3
# torch.Size([1, 97])
# sol_update_l2_norm:6.079101124160799e-08 	 residual l2 norm: 8.742543545476846e-13
# converged at iteration:  3
# sol_update_l2_norm:6.079101124160799e-08 	 residual l2 norm: 8.742543545476846e-13
# epoch:  98	assembling the matrix time taken:  0.00026798248291015625
# solving Ax = b time taken:  0.009636878967285156
# newton iteration:  1
# torch.Size([1, 98])
# sol_update_l2_norm:1010.2840390140378 	 residual l2 norm: 0.00010129431145781024
# newton iteration:  2
# torch.Size([1, 98])
# sol_update_l2_norm:0.0002908959534872215 	 residual l2 norm: 4.683570367066896e-06
# newton iteration:  3
# torch.Size([1, 98])
# sol_update_l2_norm:3.578788094401392e-07 	 residual l2 norm: 1.4732672469932753e-12
# converged at iteration:  3
# sol_update_l2_norm:3.578788094401392e-07 	 residual l2 norm: 1.4732672469932753e-12
# epoch:  99	assembling the matrix time taken:  0.00017118453979492188
# solving Ax = b time taken:  0.009056806564331055
# newton iteration:  1
# torch.Size([1, 99])
# sol_update_l2_norm:74.3061775997694 	 residual l2 norm: 9.245572894557558e-05
# newton iteration:  2
# torch.Size([1, 99])
# sol_update_l2_norm:3.810413760337009e-05 	 residual l2 norm: 7.825938313817748e-08
# newton iteration:  3
# torch.Size([1, 99])
# sol_update_l2_norm:8.570726969790573e-08 	 residual l2 norm: 9.328789217609285e-13
# converged at iteration:  3
# sol_update_l2_norm:8.570726969790573e-08 	 residual l2 norm: 9.328789217609285e-13
# epoch:  100	assembling the matrix time taken:  0.00019216537475585938
# solving Ax = b time taken:  0.009095191955566406
# newton iteration:  1
# torch.Size([1, 100])
# sol_update_l2_norm:236.57254830797442 	 residual l2 norm: 5.6305245923270785e-05
# newton iteration:  2
# torch.Size([1, 100])
# sol_update_l2_norm:4.1104128916393536e-05 	 residual l2 norm: 2.3751370749419067e-07
# newton iteration:  3
# torch.Size([1, 100])
# sol_update_l2_norm:8.264817244535684e-08 	 residual l2 norm: 1.6533183649140549e-12
# converged at iteration:  3
# sol_update_l2_norm:8.264817244535684e-08 	 residual l2 norm: 1.6533183649140549e-12
# epoch:  101	assembling the matrix time taken:  0.00016307830810546875
# solving Ax = b time taken:  0.009183645248413086
# newton iteration:  1
# torch.Size([1, 101])
# sol_update_l2_norm:118.84511684668563 	 residual l2 norm: 5.622147202371833e-05
# newton iteration:  2
# torch.Size([1, 101])
# sol_update_l2_norm:4.537187059407664e-05 	 residual l2 norm: 3.8668845964915917e-07
# newton iteration:  3
# torch.Size([1, 101])
# sol_update_l2_norm:3.6978778813640275e-07 	 residual l2 norm: 2.504338675965008e-12
# converged at iteration:  3
# sol_update_l2_norm:3.6978778813640275e-07 	 residual l2 norm: 2.504338675965008e-12
# epoch:  102	assembling the matrix time taken:  0.0001862049102783203
# solving Ax = b time taken:  0.010091781616210938
# newton iteration:  1
# torch.Size([1, 102])
# sol_update_l2_norm:116.77317438188344 	 residual l2 norm: 5.829922914168565e-05
# newton iteration:  2
# torch.Size([1, 102])
# sol_update_l2_norm:3.434747943204849e-05 	 residual l2 norm: 1.1120146665398667e-07
# newton iteration:  3
# torch.Size([1, 102])
# sol_update_l2_norm:6.156037473797519e-07 	 residual l2 norm: 2.346463638883337e-12
# newton iteration:  4
# torch.Size([1, 102])
# sol_update_l2_norm:1.7599960475801667e-07 	 residual l2 norm: 3.721302862513537e-12
# converged at iteration:  4
# sol_update_l2_norm:1.7599960475801667e-07 	 residual l2 norm: 3.721302862513537e-12
# epoch:  103	assembling the matrix time taken:  0.00016117095947265625
# solving Ax = b time taken:  0.00945281982421875
# newton iteration:  1
# torch.Size([1, 103])
# sol_update_l2_norm:60.31959525655932 	 residual l2 norm: 5.136836059151833e-05
# newton iteration:  2
# torch.Size([1, 103])
# sol_update_l2_norm:2.1318621190533506e-05 	 residual l2 norm: 6.608140118208038e-08
# newton iteration:  3
# torch.Size([1, 103])
# sol_update_l2_norm:5.402384567326247e-07 	 residual l2 norm: 2.1962319129535516e-12
# converged at iteration:  3
# sol_update_l2_norm:5.402384567326247e-07 	 residual l2 norm: 2.1962319129535516e-12
# epoch:  104	assembling the matrix time taken:  0.0001800060272216797
# solving Ax = b time taken:  0.009506702423095703
# newton iteration:  1
# torch.Size([1, 104])
# sol_update_l2_norm:769.1763703881362 	 residual l2 norm: 4.964188071826768e-05
# newton iteration:  2
# torch.Size([1, 104])
# sol_update_l2_norm:0.00012607020481223834 	 residual l2 norm: 2.113261560298438e-06
# newton iteration:  3
# torch.Size([1, 104])
# sol_update_l2_norm:2.9823423786507603e-07 	 residual l2 norm: 1.1342186229504062e-12
# converged at iteration:  3
# sol_update_l2_norm:2.9823423786507603e-07 	 residual l2 norm: 1.1342186229504062e-12
# epoch:  105	assembling the matrix time taken:  0.0001609325408935547
# solving Ax = b time taken:  0.009423494338989258
# newton iteration:  1
# torch.Size([1, 105])
# sol_update_l2_norm:518.7101058771734 	 residual l2 norm: 4.4432856800035174e-05
# newton iteration:  2
# torch.Size([1, 105])
# sol_update_l2_norm:7.216167962538231e-05 	 residual l2 norm: 5.973395934177951e-07
# newton iteration:  3
# torch.Size([1, 105])
# sol_update_l2_norm:7.892451980123081e-07 	 residual l2 norm: 1.0199299538662269e-12
# newton iteration:  4
# torch.Size([1, 105])
# sol_update_l2_norm:5.15609069810304e-07 	 residual l2 norm: 7.545194484627215e-13
# converged at iteration:  4
# sol_update_l2_norm:5.15609069810304e-07 	 residual l2 norm: 7.545194484627215e-13
# epoch:  106	assembling the matrix time taken:  0.00017833709716796875
# solving Ax = b time taken:  0.010168790817260742
# newton iteration:  1
# torch.Size([1, 106])
# sol_update_l2_norm:185.45919937625584 	 residual l2 norm: 5.082669268858458e-05
# newton iteration:  2
# torch.Size([1, 106])
# sol_update_l2_norm:3.476871084855871e-05 	 residual l2 norm: 3.911590738259652e-07
# newton iteration:  3
# torch.Size([1, 106])
# sol_update_l2_norm:9.052049677855475e-07 	 residual l2 norm: 1.3509648510605757e-12
# newton iteration:  4
# torch.Size([1, 106])
# sol_update_l2_norm:6.720484670999543e-07 	 residual l2 norm: 3.973120242516901e-12
# newton iteration:  5
# torch.Size([1, 106])
# sol_update_l2_norm:2.1811484260845783e-07 	 residual l2 norm: 1.2312480777922123e-12
# converged at iteration:  5
# sol_update_l2_norm:2.1811484260845783e-07 	 residual l2 norm: 1.2312480777922123e-12
# epoch:  107	assembling the matrix time taken:  0.0001609325408935547
# solving Ax = b time taken:  0.009543657302856445
# newton iteration:  1
# torch.Size([1, 107])
# sol_update_l2_norm:373.4522946892026 	 residual l2 norm: 3.456089320456e-05
# newton iteration:  2
# torch.Size([1, 107])
# sol_update_l2_norm:7.238630596875394e-05 	 residual l2 norm: 5.929574475934584e-08
# newton iteration:  3
# torch.Size([1, 107])
# sol_update_l2_norm:5.738266740901169e-07 	 residual l2 norm: 1.0937215753479688e-12
# newton iteration:  4
# torch.Size([1, 107])
# sol_update_l2_norm:3.7970174297542775e-07 	 residual l2 norm: 1.51779879349643e-12
# converged at iteration:  4
# sol_update_l2_norm:3.7970174297542775e-07 	 residual l2 norm: 1.51779879349643e-12
# epoch:  108	assembling the matrix time taken:  0.0001964569091796875
# solving Ax = b time taken:  0.009638786315917969
# newton iteration:  1
# torch.Size([1, 108])
# sol_update_l2_norm:708.8847500771207 	 residual l2 norm: 6.889991886395838e-05
# newton iteration:  2
# torch.Size([1, 108])
# sol_update_l2_norm:0.00011910903585722556 	 residual l2 norm: 1.774242169856796e-06
# newton iteration:  3
# torch.Size([1, 108])
# sol_update_l2_norm:4.546206346782503e-07 	 residual l2 norm: 1.9551071514304082e-12
# converged at iteration:  3
# sol_update_l2_norm:4.546206346782503e-07 	 residual l2 norm: 1.9551071514304082e-12
# epoch:  109	assembling the matrix time taken:  0.00016427040100097656
# solving Ax = b time taken:  0.009659051895141602
# newton iteration:  1
# torch.Size([1, 109])
# sol_update_l2_norm:75.4703495729997 	 residual l2 norm: 4.76274621754564e-05
# newton iteration:  2
# torch.Size([1, 109])
# sol_update_l2_norm:4.882616504443848e-05 	 residual l2 norm: 1.373403185545635e-07
# newton iteration:  3
# torch.Size([1, 109])
# sol_update_l2_norm:6.250490910440288e-07 	 residual l2 norm: 2.549848015548485e-12
# newton iteration:  4
# torch.Size([1, 109])
# sol_update_l2_norm:5.473066544858982e-07 	 residual l2 norm: 5.510348569910474e-12
# newton iteration:  5
# torch.Size([1, 109])
# sol_update_l2_norm:8.382647173747693e-07 	 residual l2 norm: 3.9834885716170555e-12
# newton iteration:  6
# torch.Size([1, 109])
# sol_update_l2_norm:8.776677326712413e-07 	 residual l2 norm: 1.3325244053113293e-12
# newton iteration:  7
# torch.Size([1, 109])
# sol_update_l2_norm:6.225229473303704e-07 	 residual l2 norm: 9.708813329923455e-12
# newton iteration:  8
# torch.Size([1, 109])
# sol_update_l2_norm:8.011007201033804e-08 	 residual l2 norm: 1.6044850517895396e-12
# converged at iteration:  8
# sol_update_l2_norm:8.011007201033804e-08 	 residual l2 norm: 1.6044850517895396e-12
# epoch:  110	assembling the matrix time taken:  0.0001862049102783203
# solving Ax = b time taken:  0.010454177856445312
# newton iteration:  1
# torch.Size([1, 110])
# sol_update_l2_norm:63.66070968521878 	 residual l2 norm: 3.0259162952304973e-05
# newton iteration:  2
# torch.Size([1, 110])
# sol_update_l2_norm:3.067458233964009e-05 	 residual l2 norm: 1.2702110546200284e-07
# newton iteration:  3
# torch.Size([1, 110])
# sol_update_l2_norm:2.2716086805524304e-07 	 residual l2 norm: 4.860996305029656e-12
# converged at iteration:  3
# sol_update_l2_norm:2.2716086805524304e-07 	 residual l2 norm: 4.860996305029656e-12
# epoch:  111	assembling the matrix time taken:  0.00016236305236816406
# solving Ax = b time taken:  0.009801626205444336
# newton iteration:  1
# torch.Size([1, 111])
# sol_update_l2_norm:121.25604407148954 	 residual l2 norm: 3.107878163941517e-05
# newton iteration:  2
# torch.Size([1, 111])
# sol_update_l2_norm:2.0631491163121045e-05 	 residual l2 norm: 1.5309572419578088e-07
# newton iteration:  3
# torch.Size([1, 111])
# sol_update_l2_norm:6.982765410080327e-07 	 residual l2 norm: 2.0917032337959675e-12
# newton iteration:  4
# torch.Size([1, 111])
# sol_update_l2_norm:4.496347708297332e-07 	 residual l2 norm: 2.153211668786848e-12
# converged at iteration:  4
# sol_update_l2_norm:4.496347708297332e-07 	 residual l2 norm: 2.153211668786848e-12
# epoch:  112	assembling the matrix time taken:  0.000186920166015625
# solving Ax = b time taken:  0.009824037551879883
# newton iteration:  1
# torch.Size([1, 112])
# sol_update_l2_norm:375.53818858992435 	 residual l2 norm: 2.979551676242053e-05
# newton iteration:  2
# torch.Size([1, 112])
# sol_update_l2_norm:3.311917729854697e-05 	 residual l2 norm: 1.5519352526056862e-07
# newton iteration:  3
# torch.Size([1, 112])
# sol_update_l2_norm:1.213505201953719e-06 	 residual l2 norm: 1.0474596348565128e-12
# newton iteration:  4
# torch.Size([1, 112])
# sol_update_l2_norm:8.051559514415469e-07 	 residual l2 norm: 2.3760869605689005e-12
# newton iteration:  5
# torch.Size([1, 112])
# sol_update_l2_norm:2.876269868111711e-07 	 residual l2 norm: 2.0904824461431787e-12
# converged at iteration:  5
# sol_update_l2_norm:2.876269868111711e-07 	 residual l2 norm: 2.0904824461431787e-12
# epoch:  113

# %% [markdown]
# ## test Neumann problem
#
# with neumann boundary conditon

# %%
def test_neumann_problem_2d():
    # sine example 
    def u_exact(x):
        return torch.sin(pi*x[:,0:1])*torch.sin(pi*x[:,1:2])  

    def u_exact_grad():
        def u_grad_x(x):
            return pi*torch.cos(pi*x[:,0:1])*torch.sin(pi*x[:,1:2])
        def u_grad_y(x):
            return pi*torch.sin(pi*x[:,0:1])*torch.cos(pi*x[:,1:2]) 

        u_grad=[] 
        u_grad.append(u_grad_x)
        u_grad.append(u_grad_y)
        return u_grad

    def laplace_u_exact(x):
        return -2*pi**2 * torch.sin(pi*x[:,0:1])*torch.sin(pi*x[:,1:2])

    def rhs(x):
        return -laplace_u_exact(x) + u_exact(x) 
    
    def g_N(dim):
        u_grad = u_exact_grad() 
        bcs_N = []
        for i in range(dim):
            bcs_N.append((i, u_grad[i]))
        return bcs_N

    # ## cosine example 
    # def u_exact(x):
    #     return torch.cos(2*pi*x[:,0:1])*torch.cos(2*pi*x[:,1:2])  

    # def u_exact_grad():
    #     def u_grad_x(x):
    #         return -2*pi*torch.sin(2*pi*x[:,0:1])*torch.cos(2*pi*x[:,1:2])
    #     def u_grad_y(x):
    #         return -2*pi*torch.cos(2*pi*x[:,0:1])*torch.sin(2*pi*x[:,1:2]) 

    #     u_grad=[] 
    #     u_grad.append(u_grad_x)
    #     u_grad.append(u_grad_y)
    #     return u_grad

    # def laplace_u_exact(x):
    #     return -2*(2*pi)**2 * torch.cos(2*pi*x[:,0:1])*torch.cos(2*pi*x[:,1:2])

    # def rhs(x):
    #     return -laplace_u_exact(x) + u_exact(x) 
    
    # def g_N(dim):
    #     return None 
    
    err_l2_list = [] 
    err_h10_list = []  
    weights, integration_points = PiecewiseGQ2D_weights_points(75, order = 3) 
    weights_bd, integration_points_bd = Neumann_boundary_quadrature_points_weights(50, d = 2)   
    for neuron_num in [4,8,16,32,64,128]: 
        my_model = model(2, neuron_num, 1, k = 1).to(device) 
        my_model = adjust_neuron_position(my_model)
        sol = minimize_linear_layer_H1_explicit_assemble_efficient(my_model,rhs,weights, integration_points,weights_bd, integration_points_bd, g_N,activation = 'relu',solver="direct" )
        my_model.fc2.weight.data[0,:] = sol[:]
        # plot_2D(my_model)
        diff_sqrd = (my_model(integration_points).detach() - u_exact(integration_points))**2
        err_l2 = (weights.t() @ diff_sqrd)**0.5 
        err_l2_list.append(err_l2)
    print(err_l2_list)   
    return 0 

test_neumann_problem_2d() # passed!

# %% [markdown]
# ## test Newton solver

# %%
def test_nonlinear():
#     freq = 1
#     def u_exact(x):
#         return torch.sin(freq*pi*x[:,0:1])*torch.sin(freq*pi*x[:,1:2])
#     def u_exact_approx(x):
#         return torch.sin(freq*pi*x[:,0:1])*torch.sin(freq*pi*x[:,1:2])*0.5 
    
#     def u_exact_grad():
#         def u_grad_x(x):
#             return freq*pi*torch.cos(freq*pi*x[:,0:1])*torch.sin(freq*pi*x[:,1:2])
#         def u_grad_y(x):
#             return freq*pi*torch.sin(freq*pi*x[:,0:1])*torch.cos(freq*pi*x[:,1:2]) 

#         u_grad=[] 
#         u_grad.append(u_grad_x)
#         u_grad.append(u_grad_y)
#         return u_grad
    
#     def laplace_u_exact(x):
#         return -2*(freq*pi)**2 * torch.sin(freq*pi*x[:,0:1])*torch.sin(freq*pi*x[:,1:2]) 
#     def rhs(x):
#         return  -laplace_u_exact(x) + nonlinear(u_exact(x))

#     def g_N(dim):
#         u_grad = u_exact_grad() 
#         bcs_N = []
#         for i in range(dim):
#             bcs_N.append((i, u_grad[i]))
#         return bcs_N
    

    def u_exact(x):
        """Gabor function applied to a batch of points."""
        m = 8
        sigma = 0.15
        exp_term = torch.exp(-torch.sum((x - 0.5) ** 2, dim=1, keepdim=True) / (2 * sigma ** 2))
        cos_term = torch.cos(2 * math.pi * m * x[:, 0:1])  # x[:, 0:1] keeps the dimension
        return exp_term * cos_term
    def u_exact_approx(x):
        return u_exact(x)*0.99 
    

    def u_exact_grad():
        def u_grad_x(x):
            m = 8
            sigma = 0.15
            exp_term = torch.exp(-torch.sum((x - 0.5) ** 2, dim=1, keepdim=True) / (2 * sigma ** 2))
            cos_term = torch.cos(2 * math.pi * m * x[:, 0:1])
            sin_term = torch.sin(2 * math.pi * m * x[:, 0:1])

            # Derivative with respect to x_1
            du_dx1 = exp_term * (-2 * (x[:, 0:1] - 0.5) / (2 * sigma ** 2)) * cos_term - (2 * math.pi * m * exp_term * sin_term)
            return du_dx1

        def u_grad_y(x):
            m = 8
            sigma = 0.15
            exp_term = torch.exp(-torch.sum((x - 0.5) ** 2, dim=1, keepdim=True) / (2 * sigma ** 2))
            cos_term = torch.cos(2 * math.pi * m * x[:, 0:1])
            sin_term = torch.sin(2 * math.pi * m * x[:, 0:1])
            du_dx_other = exp_term * (-2 * (x[:, 1:2] - 0.5) / (2 * sigma ** 2)) * cos_term
            return du_dx_other

        u_grad=[] 
        u_grad.append(u_grad_x)
        u_grad.append(u_grad_y)
        return u_grad


    def laplace_u_exact(x):
        m = 8
        sigma = 0.15
        """Laplacian of the Gabor function for a batch of points, summed over all dimensions."""
        exp_term = torch.exp(-torch.sum((x - 0.5) ** 2, dim=1, keepdim=True) / (2 * sigma ** 2))
        cos_term = torch.cos(2 * math.pi * m * x[:, 0:1])
        sin_term = torch.sin(2 * math.pi * m * x[:, 0:1])

        # Laplacian in x_1: Apply the product rule twice
        laplace_x1_part_1 = exp_term * (-2 * (x[:, 0:1] - 0.5) / (2 * sigma ** 2))**2 * cos_term
        laplace_x1_part_2 = exp_term * ( - 1 / sigma ** 2) * cos_term
        laplace_x1_part_3 = exp_term * (-2 * (x[:, 0:1] - 0.5) / (2 * sigma ** 2)) * (-2*m*math.pi)*sin_term
        laplace_x1_part_4 = - (2 * math.pi * m * exp_term * (-2 * (x[:, 0:1] - 0.5) / (2 * sigma ** 2)) * sin_term) 
        laplace_x1_part_5 = - ( (2 * math.pi * m)**2 * exp_term * cos_term)

        laplace_x1 = laplace_x1_part_1 + laplace_x1_part_2 + laplace_x1_part_3 \
                    + laplace_x1_part_4 + laplace_x1_part_5

        # Laplacian in other dimensions (x_i, i > 1): Only the exponential term matters here
        laplace_other = (-1 / sigma ** 2) * exp_term * (-2 * (x[:, 1:] - 0.5) / (2 * sigma ** 2)) * cos_term \
                    + exp_term * (-2 * (x[:, 1:] - 0.5) / (2 * sigma ** 2))**2 * cos_term 

        # Sum all Laplacians over each variable to get the total Laplacian
        laplace_sum = laplace_x1  + torch.sum(laplace_other, dim=1, keepdim=True)

        return laplace_sum 

    def rhs(x):
        """Right-hand side of the equation using the Gabor function for a batch of points."""
        laplace_sum = laplace_u_exact(x)
        return -laplace_sum + nonlinear(u_exact(x))

    def g_N(dim):
        u_grad = u_exact_grad() 
        bcs_N = []
        for i in range(dim):
            bcs_N.append((i, u_grad[i]))
        return bcs_N 
    err_l2_list = [] 
    err_h10_list = []  
    weights, integration_points = PiecewiseGQ2D_weights_points(400, order = 3) 
    weights_bd, integration_points_bd = Neumann_boundary_quadrature_points_weights(999999, d = 2)   
    for neuron_num in [16,32,64,128,256,512]: 
        my_model = model(2, neuron_num, 1, k = 3).to(device) 
        my_model = adjust_neuron_position(my_model)
        sol = minimize_linear_layer_explicit_assemble(my_model,u_exact_approx,weights, integration_points,solver="direct")
        # sol = minimize_linear_layer_neumann(my_model,rhs_neumann,weights, integration_points,activation = 'relu', solver = 'direct')
        my_model.fc2.weight.data[0,:] = sol[0,:]   
        sol = minimize_linear_layer_newton_method(my_model,rhs,weights, integration_points,weights_bd, integration_points_bd, g_N,activation = 'relu',solver="direct" )
        my_model.fc2.weight.data[0,:] = sol[0,:]
        # plot_2D(my_model)
        diff_sqrd = (my_model(integration_points).detach() - u_exact(integration_points))**2
        err_l2 = (weights.t() @ diff_sqrd)**0.5 
        err_l2_list.append(err_l2)
    print(err_l2_list)   
    return 0 
    
test_nonlinear()
