# %%
"""
2025/07/21 Using the PINN loss function to solve the Neumann boundary value problem 
-\lap u + u = f in \Omega,
u = 0 on \partial\Omega, 
\Omega = (0,1) x (0,1) 

Exact solution: u = \sin(\pi x1)\sin(\pi x2)
f = (\pi^2 + 1)\sin(\pi x1)\sin(\pi x2)
author: Xiaofeng Xu 

log: July 25th Make the code dimension dependent 
"""
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import time
import sys
import os 
from scipy.sparse import linalg
from pathlib import Path
if torch.cuda.is_available():  
    device = "cuda" 
else:  
    device = "cpu" 

torch.set_default_dtype(torch.float64)
pi = torch.tensor(np.pi)
ZERO = torch.tensor([0.]).to(device)

class model(nn.Module):
    """ ReLU k shallow neural network
    Parameters: 
    input size: input dimension
    hidden_size1 : number of hidden layers 
    num_classes: output classes 
    k: degree of relu functions
    """
    def __init__(self, input_size, hidden_size1, num_classes,k = 1):
        super().__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, num_classes,bias = False)
        self.k = k 
    def forward(self, x):
        u1 = self.fc2(F.relu(self.fc1(x))**self.k)
        return u1
    def evaluate_derivative(self, x, i):
        if self.k == 1:
            ## ZERO = torch.tensor([0.]).to(device)
            u1 = self.fc2(torch.heaviside(self.fc1(x),ZERO) * self.fc1.weight.t()[i-1:i,:] )
        else:
            u1 = self.fc2(self.k*F.relu(self.fc1(x))**(self.k-1) *self.fc1.weight.t()[i-1:i,:] )  
        return u1
    def evaluate_2ndderivative(self,x,i,j): 
        if self.k == 2:
            u1 = self.fc2( 2 * torch.heaviside(self.fc1(x),ZERO) * (self.fc1.weight.t()[i-1:i,:])*self.fc1.weight.t()[j-1:j,:]) 
        else:
            u1 = self.fc2( self.k*(self.k-1)*F.relu(self.fc1(x))**(self.k-2) * (self.fc1.weight.t()[i-1:i,:])* (self.fc1.weight.t()[j-1:j,:]))  
        return u1

# %%
def PiecewiseGQ1D_weights_points(x_l,x_r,Nx, order):
    """ Output the coeffients and weights for piecewise Gauss Quadrature 
    Parameters
    ----------
    x_l : float 
    left endpoint of an interval 
    x_r: float
    right endpoint of an interval 
    Nx: int 
    number of subintervals for integration
    order: int
    order of Gauss Quadrature 
    Returns
    -------
    vectorized quadrature weights and integration points
    """
    x,w = np.polynomial.legendre.leggauss(order)
    gx = torch.tensor(x).to(device)
    gx = gx.view(1,-1) # row vector 
    gw = torch.tensor(w).to(device)    
    gw = gw.view(-1,1) # Column vector 
    nodes = torch.linspace(x_l,x_r,Nx+1).view(-1,1).to(device) 
    coef1 = ((nodes[1:,:] - nodes[:-1,:])/2) # n by 1  
    coef2 = ((nodes[1:,:] + nodes[:-1,:])/2) # n by 1  
    coef2_expand = coef2.expand(-1,gx.size(1)) # Expand to n by p shape, -1: keep the first dimension n , expand the 2nd dim (columns)
    integration_points = coef1@gx + coef2_expand
    integration_points = integration_points.flatten().view(-1,1) # Make it a column vector
    gw_expand = torch.tile(gw,(Nx,1)) # rows: n copies of current tensor, columns: 1 copy, no change
    # Modify coef1 to be compatible with func_values
    coef1_expand = coef1.expand(coef1.size(0),gx.size(1))    
    coef1_expand = coef1_expand.flatten().view(-1,1)
    return coef1_expand.to(device) * gw_expand.to(device), integration_points.to(device)

def plot_solution_modified(r1,r2,model,x_test,u_true,name=None): 
    # Plot function: test results 
    u_model_cpu = model(x_test).cpu().detach()
    
    w = model.fc1.weight.data.squeeze()
    b = model.fc1.bias.data.squeeze()
    x_model_pt = (-b/w).view(-1,1)
    x_model_pt = x_model_pt[x_model_pt>=r1].reshape(-1,1)
    u_model_pt = model(x_model_pt).cpu().detach()
    plt.figure(dpi = 100)
    plt.plot(x_test.cpu(),u_model_cpu,'-.',label = "nn function")
    plt.plot(x_test.cpu(),u_true.cpu(),label = "true")
    # plt.plot(x_model_pt.cpu(),u_model_pt.cpu(),'.r')
    if name!=None: 
        plt.title(name)
    plt.legend()
    plt.show()

def show_convergence_order2_PINN(err_l2,err_h10,err_energy, exponent,dict_size, filename,write2file = False):
    
    if write2file:
        file_mode = "a" if os.path.exists(filename) else "w"
        f_write = open(filename, file_mode)
    
    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_l2[i] for i in neuron_nums ]
    err_list2 = [err_h10[i] for i in neuron_nums ] 
    err_list3 = [err_energy[i] for i in neuron_nums ]
    # f_write.write('M:{}, relu {} \n'.format(M,k))
    if write2file:
        f_write.write('dictionary size: {}\n'.format(dict_size))
        f_write.write("neuron num \t\t error \t\t order \t\t h10 error \t\t order  \t\t energy err \t\t order \n")
    print("neuron num \t\t error \t\t order")
    for i, item in enumerate(err_list):
        if i == 0: 
            # print(neuron_nums[i], end = "\t\t")s
            # print(item, end = "\t\t")
            
            # print("*")
            print("{} \t\t {:.3e} \t\t * \t\t {:.3e} \t\t * \t\t {:.3e} \t\t * \n".format(neuron_nums[i],item, err_list2[i],err_list3[i] ) )
            if write2file: 
                f_write.write("{} \t\t {} \t\t * \t\t {} \t\t *  \t\t {} \t\t * \n".format(neuron_nums[i],item, err_list2[i],err_list3[i] ))
        else: 
            print("{} \t\t {:.3e} \t\t {:.2f} \t\t {:.3e} \t\t {:.2f} \t\t {:.3e} \t\t {:.2f}  \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2), 
                                                                            err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2),
                                                                             err_list3[i] , np.log(err_list3[i-1]/err_list3[i])/np.log(2) ) )
            if write2file: 
                f_write.write("{} \t\t {} \t\t {} \t\t {} \t\t {} \t\t {} \t\t {} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2),err_list3[i] , np.log(err_list3[i-1]/err_list3[i])/np.log(2) ))
    if write2file:     
        f_write.write("\n")
        f_write.close()

def show_convergence_order_latex2(err_l2,err_h10,exponent,k=1,d=1): 
    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_l2[i] for i in neuron_nums ]
    err_list2 = [err_h10[i] for i in neuron_nums ] 
    l2_order = -1/2-(2*k + 1)/(2*d)
    h1_order =  -1/2-(2*(k-1)+ 1)/(2*d)
    print("neuron num  & \t $\|u-u_n \|_{{L^2}}$ & \t order $O(n^{{{:.2f}}})$  & \t $ | u -u_n |_{{H^1}}$ & \t order $O(n^{{{:.2f}}})$  \\\ \hline \hline ".format(l2_order,h1_order))
    for i, item in enumerate(err_list):
        if i == 0: 
            print("{} \t\t & {:.6f} &\t\t * & \t\t {:.6f} & \t\t *  \\\ \hline  \n".format(neuron_nums[i],item, err_list2[i] ) )   
        else: 
            print("{} \t\t &  {:.3e} &  \t\t {:.2f} &  \t\t {:.3e} &  \t\t {:.2f} \\\ \hline  \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2) ) )

def Neumann_boundary_quadrature_points(M, dim):
    """
    the boundary is in dimension dim - 1. 
    If 1D problem, the boundary is 0D, the quadrature points are 0 and 1. 
    """
    if dim == 1: 
        weights_bd = torch.tensor([1.,1.]).view(-1,1).to(device)
        integration_points_bd = torch.tensor([0.,1.]).view(-1,1).to(device) 
    
    return weights_bd.to(device), integration_points_bd.to(device)

# %%
## 
# TODO
def minimize_linear_layer_PINN_neumann(model,target,weights, integration_points,weights_bd, integration_points_bd, g_D, activation = 'relu', solver = 'direct'):
    """
    calls the following functions (dependency): 
    1. GQ_piecewise_2D
    input: the nn model containing parameter 
    1. define the loss function  
    2. take derivative to extract the linear system A
    3. call the cg solver in scipy to solve the linear system 
    output: sol. solution of Ax = b
    """
    start_time = time.time() 
    w = model.fc1.weight.data 
    b = model.fc1.bias.data 
    basis_value_bd_col = F.relu(integration_points_bd @ w.t()+ b)**(model.k) 
    weighted_basis_value_bd_col = basis_value_bd_col * weights_bd
    jac2 = weighted_basis_value_bd_col.t() @ (basis_value_bd_col)  # (u,v)_{\partial \Omega}

    # (Lu, Lv)_{\Omega} 
    basis_value_col = F.relu(integration_points @ w.t()+ b)**(model.k) 
    if activation == 'relu':
        basis_value_col = F.relu(integration_points @ w.t()+ b)**(model.k) 
        if model.k == 1:
            assert False, "k must be at least 2"
        if model.k == 2:  
            
            basis_value_d11_col = 2 * torch.heaviside(integration_points @ w.t()+ b, ZERO) * (w.t()[0:1,:])**2 
            L_basis_col = - basis_value_d11_col + basis_value_col 
        else: 
            basis_value_d11_col = model.k * (model.k -1) * F.relu(integration_points @ w.t()+ b)**(model.k-2) * (w.t()[0:1,:])**2 
            L_basis_col = - basis_value_d11_col + basis_value_col 
        weighted_L_basis_col = L_basis_col * weights 
    jac1 =  weighted_L_basis_col.t() @L_basis_col 
    jac = jac1 + jac2

    rhs1 = weighted_L_basis_col.t() @ (target(integration_points) )

    # Dirichlet boundary (g,v)_{\partial \Omega}, g = 0 
    rhs2 = weighted_basis_value_bd_col.t() @ (g_D(integration_points_bd))
    rhs = rhs1 + rhs2 

    print("assembling the matrix time taken: ", time.time()-start_time) 
    start_time = time.time()    
    if solver == "cg": 
        sol, exit_code = linalg.cg(np.array(jac.detach().cpu()),np.array(rhs.detach().cpu()),tol=1e-12)
        sol = torch.tensor(sol).view(1,-1)
    elif solver == "direct": 
#         sol = np.linalg.inv( np.array(jac.detach().cpu()) )@np.array(rhs.detach().cpu())
        sol = (torch.linalg.solve( jac.detach(), rhs.detach())).view(1,-1)
    elif solver == "ls":
        sol = (torch.linalg.lstsq(jac.detach().cpu(),rhs.detach().cpu(),driver='gelsd').solution).view(1,-1)
        # sol = (torch.linalg.lstsq(jac.detach(),rhs.detach()).solution).view(1,-1) # gpu/cpu, driver = 'gels', cannot solve singular
    print("solving Ax = b time taken: ", time.time()-start_time)
    ## update the solution 
    return sol

# %%
def relu_dict(x_l,x_r,N):
    """generate relu dictionary parameters 
    
    Parameters
    ----------
    x_l: float 
    x_r: float
    N: int 
        number of dictionary elements 
        
    Returns
    torch tensor
        containing relu dictionary parameters, corresponds to nodal points
        
    """
    # w = 1 
    relu_dict_parameters = torch.zeros((2*N,2)).to(device)
    relu_dict_parameters[:N,0] = torch.ones(N)[:]
    relu_dict_parameters[:N,1] = torch.linspace(x_l,x_r,N+1)[:-1] # relu(x-bi)  
    relu_dict_parameters[N:2*N,0] = -torch.ones(N)[:]
    relu_dict_parameters[N:2*N,1] = -torch.linspace(x_l,x_r,N+1)[1:] + 1/(2*N) # relu(-x - -bi) 
    
    return relu_dict_parameters

# relu dictionary
def relu_dict_MC(x_l,x_r,N):
    """generate relu dictionary parameters 
    
    Parameters
    ----------
    x_l: float 
    x_r: float
    N: int 
       number of dictionary elements  
        
    Returns
    torch tensor
        containing relu dictionary parameters, corresponds to nodal points
    """
    # w = 1 
    random_value = torch.randint(0, 2, (N,)) * 2 - 1 # +1 or -1  
    relu_dict_parameters = torch.zeros((N,2)).to(device)
    relu_dict_parameters[:N,0] = random_value[:]
    relu_dict_parameters[:N,1] = (torch.rand(N)*(x_r-x_l) + x_l)*random_value # relu(x-bi) 

    return relu_dict_parameters


#TODO 
def select_greedy_neuron_ind(relu_dict_parameters,my_model,target,weights, integration_points,g_D,weights_bd, integration_points_bd,k): 

    residual_values = - target(integration_points)
    if my_model!= None:
        residual_values +=  - my_model.evaluate_2ndderivative(integration_points,1,1).detach() + my_model(integration_points).detach()  

    weight_residual_values = residual_values*weights # 1. weights * ( Lu - f ) 

    basis_values = (F.relu(integration_points @ (relu_dict_parameters[:,0:1].T) - relu_dict_parameters[:,1])**k) # uses broadcasting
    # output1 = torch.matmul(basis_values,weight_func_values) # 

    # ============TODO=========== DONE 
    # L (basis values)
    if k == 1:
        assert k>=2, "k must be at least 2"
    elif k == 2:  
        dbasis_values_d11 =  2 * torch.heaviside(integration_points @ (relu_dict_parameters[:,0:1].T) - relu_dict_parameters[:,1], ZERO) * (relu_dict_parameters.t()[0:1,:])**2 
        Lg = - dbasis_values_d11 + basis_values
    else:  
        dbasis_values_d11 = k *(k-1) * F.relu(integration_points @ (relu_dict_parameters[:,0:1].T) - relu_dict_parameters[:,1])**(k-2) * (relu_dict_parameters.t()[0:1,:])**2  
        Lg = - dbasis_values_d11 + basis_values 
    output2 = torch.matmul(Lg.t(), weight_residual_values) 
    #============TODO===========

    # Dirichlet boundary condition # 3. (u^{n-1},g)_{\partial \Omega}
    basis_values_bd_col = (F.relu(relu_dict_parameters[:,0] *integration_points_bd - relu_dict_parameters[:,1])**k) 
    weighted_basis_value_col_bd = basis_values_bd_col * weights_bd
    # dudn = g_N(integration_points_bd)* (torch.tensor([-1,1]).view(-1,1)).to(device)

    if my_model!= None:
        u_n_1 = my_model(integration_points_bd).detach()  
        output3 =  weighted_basis_value_col_bd.t() @ (u_n_1 - g_D(integration_points_bd)) 
        output = torch.abs(output2 + output3)
    else:
        g_bd = g_D(integration_points_bd)   
        output3 =  weighted_basis_value_col_bd.t() @ (- g_bd)
        output = torch.abs(output2 + output3)
    neuron_index = torch.argmax(output.flatten())
    
    return neuron_index 


def OGANeumannReLU1D(my_model,target,u_exact,du_exact,g_D, N,num_epochs,plot_freq = 10,Nx = 1024,order =5, k = 1,rand_deter = 'deter', solver = 'direct'): 
    """ Orthogonal greedy algorithm to solve a 1D Neumann problem 1D ReLU dictionary over [0,1]
    """

    integration_weights, integration_points = PiecewiseGQ1D_weights_points(x_l= 0,x_r=1, Nx = Nx,order =order)
    weights_bd, integration_points_bd = Neumann_boundary_quadrature_points(M = 2,dim = 1) 

    err = torch.zeros(num_epochs+1)
    err_h10 = torch.zeros(num_epochs+1) 
    err_energy = torch.zeros(num_epochs+1) # added 
    if my_model == None: 
        func_values = u_exact(integration_points)
        num_neuron = 0
        list_a = []
        list_b = []
        list_w = []
    else: 
        func_values = u_exact(integration_points) - my_model(integration_points).detach()
        bias = my_model.fc1.bias.detach().data
        integration_weights = my_model.fc1.weight.detach().data
        num_neuron = int(bias.size(0))
        list_a = list(my_model.fc2.weight.detach().data)
        list_b = list(bias)
        list_w = list(integration_weights)
        
    func_values_sqrd = func_values*func_values
    err[0]= torch.sum(func_values_sqrd*integration_weights)**0.5
    if my_model!= None:
        err_h10[0] = torch.sum( (my_model.evaluate_derivative(integration_points,1).detach() - du_exact(integration_points) )**2*integration_weights)**0.5
        Lu = - my_model.evaluate_2ndderivative(integration_points,1,1).detach() +  my_model(integration_points).detach()
        energy  = 0.5 * integration_weights.t() @ ( Lu - target(integration_points) ) **2 \
                    + 0.5 * weights_bd.t() @ (my_model(integration_points_bd).detach() - g_D(integration_points_bd))**2  # added  
        err_energy[0] = energy  
    else: 
        err_h10[0] = torch.sum( du_exact(integration_points)**2*integration_weights)**0.5
        energy  = 0.5 * integration_weights.t() @ target(integration_points)**2 + 0.5 * weights_bd.t() @ (g_D(integration_points_bd))**2 # add boundary energy 1/2 \int |u-g|^2 ds  # added  
        err_energy[0] = energy 

    start_time = time.time()
    
    solver = "direct"
    print("using linear solver: ",solver)
    if rand_deter == 'deter': 
        relu_dict_parameters = relu_dict(0,1,N).to(device) 
    for i in range(num_epochs): 
        print('epoch: ',i+1)
        if rand_deter == 'rand': 
            relu_dict_parameters = relu_dict_MC(0,1,N).to(device)    
        # start_argmax = time.time() 
        neuron_index = select_greedy_neuron_ind(relu_dict_parameters,my_model,target,integration_weights, integration_points,g_D,weights_bd, integration_points_bd, k) 
        # print("argmax time: ", time.time() - start_argmax) 
        # print("selected neuron index: ",neuron_index,relu_dict_parameters[neuron_index,0],-relu_dict_parameters[neuron_index,1] ) 
        list_w.append(relu_dict_parameters[neuron_index,0])
        list_b.append(-relu_dict_parameters[neuron_index,1]) # different sign convention 
        num_neuron += 1
        my_model = model(1,num_neuron,1,k).to(device)
        my_model.fc1.weight.data[:,0] = torch.tensor(list_w)[:]
        my_model.fc1.bias.data[:] = torch.tensor(list_b)[:]

        sol = minimize_linear_layer_PINN_neumann(my_model,target,integration_weights, integration_points,weights_bd, integration_points_bd,g_D,activation ='relu', solver = solver)
        sol = sol.flatten() 
        my_model.fc2.weight.data[0,:] = sol[:]

        if (i+1)%plot_freq == 0: 
            x_test = torch.linspace(0,1,200).view(-1,1).to(device)
            u_true = u_exact(x_test)
            plot_solution_modified(0,1,my_model,x_test,u_true)
        func_values = u_exact(integration_points) - my_model(integration_points).detach()
        func_values_sqrd = func_values*func_values
        err[i+1]= torch.sum(func_values_sqrd*integration_weights)**0.5
        err_h10[i+1] = torch.sum( (my_model.evaluate_derivative(integration_points,1).detach() - du_exact(integration_points) )**2*integration_weights)**0.5 
        Lu = - my_model.evaluate_2ndderivative(integration_points,1,1).detach() +  my_model(integration_points).detach() 
        energy  = 0.5 * integration_weights.t() @ ( Lu - target(integration_points) ) **2  \
                    + 0.5 * weights_bd.t() @ (my_model(integration_points_bd).detach() - g_D(integration_points_bd))**2 # added  
        err_energy[i+1] = energy  
    print("time taken: ",time.time() - start_time)
    return err, err_h10,err_energy, my_model

# %% [markdown]
# ## deterministic dictionary

# %%
m = 2 
def u_exact(x):
    return torch.sin(m*pi*x)

def du_exact(x):
    return m *pi*torch.cos(m*pi*x)

def rhs(x):
    return  (m*pi)**2 * torch.sin(m*pi*x) + torch.sin(m*pi*x)

def g_N(x):
    return du_exact(x) 

dim = 1 
function_name = "sine1d" 
filename_write = "data/1DPINNNeumannOGA-{}-order.txt".format(function_name)
Nx = 2**11 
order = 2  
f_write = open(filename_write, "a")
f_write.write("Integration points: Nx {}, order {} \n".format(Nx,order))
f_write.close() 

save = True 
write2file = True
rand_deter = 'deter'
for N in [2**10]: # 2**12,2**14
    f_write = open(filename_write, "a")
    my_model = None 
    exponent = 8 
    num_epochs = 2**exponent  
    plot_freq = num_epochs 
    relu_k = 3   
    err_QMC2, err_h10, err_energy, my_model = OGANeumannReLU1D(None,rhs,u_exact,du_exact,u_exact, N,num_epochs,plot_freq, Nx, order, k =relu_k, rand_deter = rand_deter,solver = "direct")

    if save: 
        folder = 'data/'
        filename = folder + 'err_NeumannOGA_1D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        torch.save(err_QMC2,filename) 
        folder = 'data/'
        filename = folder + 'model_NeumannOGA_1D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        torch.save(my_model,filename)

    show_convergence_order2_PINN(err_QMC2,err_h10,err_energy, exponent,2*N,filename_write,write2file = write2file)
    # show_convergence_order_latex2(err_QMC2,err_h10,exponent,k=relu_k,d = dim)
# Out:
# using linear solver:  direct
# epoch:  1
# assembling the matrix time taken:  0.00032401084899902344
# solving Ax = b time taken:  0.00017881393432617188
# epoch:  2
# assembling the matrix time taken:  0.0005340576171875
# solving Ax = b time taken:  7.390975952148438e-05
# epoch:  3
# assembling the matrix time taken:  0.0004937648773193359
# solving Ax = b time taken:  6.794929504394531e-05
# epoch:  4
# assembling the matrix time taken:  0.0006492137908935547
# solving Ax = b time taken:  0.00013899803161621094
# epoch:  5
# assembling the matrix time taken:  0.0005738735198974609
# solving Ax = b time taken:  5.888938903808594e-05
# epoch:  6
# assembling the matrix time taken:  0.0005261898040771484
# solving Ax = b time taken:  6.198883056640625e-05
# epoch:  7
# assembling the matrix time taken:  0.000579833984375
# solving Ax = b time taken:  7.295608520507812e-05
# epoch:  8
# assembling the matrix time taken:  0.0005109310150146484
# solving Ax = b time taken:  6.008148193359375e-05
# epoch:  9
# assembling the matrix time taken:  0.0012569427490234375
# solving Ax = b time taken:  0.0002110004425048828
# epoch:  10
# assembling the matrix time taken:  0.0011789798736572266
# solving Ax = b time taken:  6.389617919921875e-05
# epoch:  11
# assembling the matrix time taken:  0.0013127326965332031
# solving Ax = b time taken:  7.200241088867188e-05
# epoch:  12
# assembling the matrix time taken:  0.0013439655303955078
# solving Ax = b time taken:  6.985664367675781e-05
# epoch:  13
# assembling the matrix time taken:  0.00133514404296875
# solving Ax = b time taken:  7.009506225585938e-05
# epoch:  14
# assembling the matrix time taken:  0.0014448165893554688
# solving Ax = b time taken:  0.00018715858459472656
# epoch:  15
# assembling the matrix time taken:  0.001439809799194336
# solving Ax = b time taken:  8.440017700195312e-05
# epoch:  16
# assembling the matrix time taken:  0.0012221336364746094
# solving Ax = b time taken:  8.082389831542969e-05
# epoch:  17
# assembling the matrix time taken:  0.001497030258178711
# solving Ax = b time taken:  7.295608520507812e-05
# epoch:  18
# assembling the matrix time taken:  0.0014328956604003906
# solving Ax = b time taken:  0.0001919269561767578
# epoch:  19
# assembling the matrix time taken:  0.001558065414428711
# solving Ax = b time taken:  7.390975952148438e-05
# epoch:  20
# assembling the matrix time taken:  0.0018968582153320312
# solving Ax = b time taken:  7.200241088867188e-05
# epoch:  21
# assembling the matrix time taken:  0.0016560554504394531
# solving Ax = b time taken:  8.225440979003906e-05
# epoch:  22
# assembling the matrix time taken:  0.0015850067138671875
# solving Ax = b time taken:  0.000164031982421875
# epoch:  23
# assembling the matrix time taken:  0.0068988800048828125
# solving Ax = b time taken:  8.702278137207031e-05
# epoch:  24
# assembling the matrix time taken:  0.0013818740844726562
# solving Ax = b time taken:  6.699562072753906e-05
# epoch:  25
# assembling the matrix time taken:  0.001986980438232422
# solving Ax = b time taken:  7.390975952148438e-05
# epoch:  26
# assembling the matrix time taken:  0.0012731552124023438
# solving Ax = b time taken:  0.0001609325408935547
# epoch:  27
# assembling the matrix time taken:  0.001934051513671875
# solving Ax = b time taken:  7.390975952148438e-05
# epoch:  28
# assembling the matrix time taken:  0.002065896987915039
# solving Ax = b time taken:  7.605552673339844e-05
# epoch:  29
# assembling the matrix time taken:  0.001901865005493164
# solving Ax = b time taken:  7.390975952148438e-05
# epoch:  30
# assembling the matrix time taken:  0.0019288063049316406
# solving Ax = b time taken:  0.00014901161193847656
# epoch:  31
# assembling the matrix time taken:  0.005723237991333008
# solving Ax = b time taken:  8.20159912109375e-05
# epoch:  32
# assembling the matrix time taken:  0.002443075180053711
# solving Ax = b time taken:  8.916854858398438e-05
# epoch:  33
# assembling the matrix time taken:  0.002161741256713867
# solving Ax = b time taken:  9.298324584960938e-05
# epoch:  34
# assembling the matrix time taken:  0.0019638538360595703
# solving Ax = b time taken:  0.00024509429931640625
# epoch:  35
# assembling the matrix time taken:  0.002000093460083008
# solving Ax = b time taken:  8.0108642578125e-05
# epoch:  36
# assembling the matrix time taken:  0.0021877288818359375
# solving Ax = b time taken:  8.58306884765625e-05
# epoch:  37
# assembling the matrix time taken:  0.002273082733154297
# solving Ax = b time taken:  9.489059448242188e-05
# epoch:  38
# assembling the matrix time taken:  0.002268075942993164
# solving Ax = b time taken:  9.202957153320312e-05
# epoch:  39
# assembling the matrix time taken:  0.0022430419921875
# solving Ax = b time taken:  0.00024008750915527344
# epoch:  40
# assembling the matrix time taken:  0.0018281936645507812
# solving Ax = b time taken:  8.487701416015625e-05
# epoch:  41
# assembling the matrix time taken:  0.002160787582397461
# solving Ax = b time taken:  6.985664367675781e-05
# epoch:  42
# assembling the matrix time taken:  0.0026810169219970703
# solving Ax = b time taken:  8.392333984375e-05
# epoch:  43
# assembling the matrix time taken:  0.0024199485778808594
# solving Ax = b time taken:  7.772445678710938e-05
# epoch:  44
# assembling the matrix time taken:  0.002465963363647461
# solving Ax = b time taken:  0.0002949237823486328
# epoch:  45
# assembling the matrix time taken:  0.002727031707763672
# solving Ax = b time taken:  9.489059448242188e-05
# epoch:  46
# assembling the matrix time taken:  0.0021708011627197266
# solving Ax = b time taken:  8.487701416015625e-05
# epoch:  47
# assembling the matrix time taken:  0.002429962158203125
# solving Ax = b time taken:  8.392333984375e-05
# epoch:  48
# assembling the matrix time taken:  0.0023207664489746094
# solving Ax = b time taken:  8.702278137207031e-05
# epoch:  49
# assembling the matrix time taken:  0.0030820369720458984
# solving Ax = b time taken:  0.0002422332763671875
# epoch:  50
# assembling the matrix time taken:  0.003385305404663086
# solving Ax = b time taken:  9.417533874511719e-05
# epoch:  51
# assembling the matrix time taken:  0.003383636474609375
# solving Ax = b time taken:  9.393692016601562e-05
# epoch:  52
# assembling the matrix time taken:  0.003294229507446289
# solving Ax = b time taken:  8.702278137207031e-05
# epoch:  53
# assembling the matrix time taken:  0.003367900848388672
# solving Ax = b time taken:  0.00010013580322265625
# epoch:  54
# assembling the matrix time taken:  0.0033447742462158203
# solving Ax = b time taken:  8.797645568847656e-05
# epoch:  55
# assembling the matrix time taken:  0.003640890121459961
# solving Ax = b time taken:  9.989738464355469e-05
# epoch:  56
# assembling the matrix time taken:  0.0035152435302734375
# solving Ax = b time taken:  9.012222290039062e-05
# epoch:  57
# assembling the matrix time taken:  0.0037479400634765625
# solving Ax = b time taken:  0.00013494491577148438
# epoch:  58
# assembling the matrix time taken:  0.0036869049072265625
# solving Ax = b time taken:  9.274482727050781e-05
# epoch:  59
# assembling the matrix time taken:  0.004166841506958008
# solving Ax = b time taken:  0.00010395050048828125
# epoch:  60
# assembling the matrix time taken:  0.003551006317138672
# solving Ax = b time taken:  9.298324584960938e-05
# epoch:  61
# assembling the matrix time taken:  0.0038089752197265625
# solving Ax = b time taken:  0.0002338886260986328
# epoch:  62
# assembling the matrix time taken:  0.003610849380493164
# solving Ax = b time taken:  9.703636169433594e-05
# epoch:  63
# assembling the matrix time taken:  0.004423856735229492
# solving Ax = b time taken:  0.00010180473327636719
# epoch:  64
# assembling the matrix time taken:  0.0034949779510498047
# solving Ax = b time taken:  0.00010204315185546875
# epoch:  65
# assembling the matrix time taken:  0.004058122634887695
# solving Ax = b time taken:  0.00019669532775878906
# epoch:  66
# assembling the matrix time taken:  0.0038268566131591797
# solving Ax = b time taken:  0.00021219253540039062
# epoch:  67
# assembling the matrix time taken:  0.0037059783935546875
# solving Ax = b time taken:  0.00015115737915039062
# epoch:  68
# assembling the matrix time taken:  0.0036649703979492188
# solving Ax = b time taken:  0.00017905235290527344
# epoch:  69
# assembling the matrix time taken:  0.0040090084075927734
# solving Ax = b time taken:  0.00021791458129882812
# epoch:  70
# assembling the matrix time taken:  0.003654956817626953
# solving Ax = b time taken:  0.00019788742065429688
# epoch:  71
# assembling the matrix time taken:  0.0038530826568603516
# solving Ax = b time taken:  0.00012993812561035156
# epoch:  72
# assembling the matrix time taken:  0.004544973373413086
# solving Ax = b time taken:  0.0001690387725830078
# epoch:  73
# assembling the matrix time taken:  0.004252195358276367
# solving Ax = b time taken:  0.00014400482177734375
# epoch:  74
# assembling the matrix time taken:  0.003895998001098633
# solving Ax = b time taken:  0.00026297569274902344
# epoch:  75
# assembling the matrix time taken:  0.004441976547241211
# solving Ax = b time taken:  0.00016307830810546875
# epoch:  76
# assembling the matrix time taken:  0.0045011043548583984
# solving Ax = b time taken:  0.0001819133758544922
# epoch:  77
# assembling the matrix time taken:  0.004746913909912109
# solving Ax = b time taken:  0.0002560615539550781
# epoch:  78
# assembling the matrix time taken:  0.0041501522064208984
# solving Ax = b time taken:  0.0002219676971435547
# epoch:  79
# assembling the matrix time taken:  0.004495143890380859
# solving Ax = b time taken:  0.0002238750457763672
# epoch:  80
# assembling the matrix time taken:  0.004004955291748047
# solving Ax = b time taken:  0.0002181529998779297
# epoch:  81
# assembling the matrix time taken:  0.004721164703369141
# solving Ax = b time taken:  0.00031685829162597656
# epoch:  82
# assembling the matrix time taken:  0.004714012145996094
# solving Ax = b time taken:  0.00013113021850585938
# epoch:  83
# assembling the matrix time taken:  0.004437923431396484
# solving Ax = b time taken:  0.000247955322265625
# epoch:  84
# assembling the matrix time taken:  0.00409698486328125
# solving Ax = b time taken:  0.00013017654418945312
# epoch:  85
# assembling the matrix time taken:  0.00432276725769043
# solving Ax = b time taken:  0.00014901161193847656
# epoch:  86
# assembling the matrix time taken:  0.00459599494934082
# solving Ax = b time taken:  0.00023794174194335938
# epoch:  87
# assembling the matrix time taken:  0.004988193511962891
# solving Ax = b time taken:  0.0002567768096923828
# epoch:  88
# assembling the matrix time taken:  0.004373073577880859
# solving Ax = b time taken:  0.000125885009765625
# epoch:  89
# assembling the matrix time taken:  0.005075931549072266
# solving Ax = b time taken:  0.0002720355987548828
# epoch:  90
# assembling the matrix time taken:  0.004522085189819336
# solving Ax = b time taken:  0.00032401084899902344
# epoch:  91
# assembling the matrix time taken:  0.004959583282470703
# solving Ax = b time taken:  0.0002639293670654297
# epoch:  92
# assembling the matrix time taken:  0.004612922668457031
# solving Ax = b time taken:  0.00031185150146484375
# epoch:  93
# assembling the matrix time taken:  0.005062103271484375
# solving Ax = b time taken:  0.0002880096435546875
# epoch:  94
# assembling the matrix time taken:  0.004960060119628906
# solving Ax = b time taken:  0.00032210350036621094
# epoch:  95
# assembling the matrix time taken:  0.0051119327545166016
# solving Ax = b time taken:  0.00013709068298339844
# epoch:  96
# assembling the matrix time taken:  0.00420689582824707
# solving Ax = b time taken:  0.00029397010803222656
# epoch:  97
# assembling the matrix time taken:  0.005505084991455078
# solving Ax = b time taken:  0.00032591819763183594
# epoch:  98
# assembling the matrix time taken:  0.005026102066040039
# solving Ax = b time taken:  0.00028586387634277344
# epoch:  99
# assembling the matrix time taken:  0.00479888916015625
# solving Ax = b time taken:  0.00014209747314453125
# epoch:  100
# assembling the matrix time taken:  0.004467010498046875
# solving Ax = b time taken:  0.00013399124145507812
# epoch:  101
# assembling the matrix time taken:  0.005367755889892578
# solving Ax = b time taken:  0.0002849102020263672
# epoch:  102
# assembling the matrix time taken:  0.0050318241119384766
# solving Ax = b time taken:  0.0002460479736328125
# epoch:  103
# assembling the matrix time taken:  0.005276918411254883
# solving Ax = b time taken:  0.0002970695495605469
# epoch:  104
# assembling the matrix time taken:  0.004378795623779297
# solving Ax = b time taken:  0.00013899803161621094
# epoch:  105
# assembling the matrix time taken:  0.005379915237426758
# solving Ax = b time taken:  0.00016880035400390625
# epoch:  106
# assembling the matrix time taken:  0.005507946014404297
# solving Ax = b time taken:  0.00015687942504882812
# epoch:  107
# assembling the matrix time taken:  0.005629777908325195
# solving Ax = b time taken:  0.00027108192443847656
# epoch:  108
# assembling the matrix time taken:  0.0058209896087646484
# solving Ax = b time taken:  0.0002219676971435547
# epoch:  109
# assembling the matrix time taken:  0.0054209232330322266
# solving Ax = b time taken:  0.00037097930908203125
# epoch:  110
# assembling the matrix time taken:  0.00558781623840332
# solving Ax = b time taken:  0.00020813941955566406
# epoch:  111
# assembling the matrix time taken:  0.005464792251586914
# solving Ax = b time taken:  0.00015616416931152344
# epoch:  112
# assembling the matrix time taken:  0.005250215530395508
# solving Ax = b time taken:  0.0001671314239501953
# epoch:  113
# assembling the matrix time taken:  0.005964040756225586
# solving Ax = b time taken:  0.00027823448181152344
# epoch:  114
# assembling the matrix time taken:  0.0196533203125
# solving Ax = b time taken:  0.00023102760314941406
# epoch:  115
# assembling the matrix time taken:  0.018474102020263672
# solving Ax = b time taken:  0.0004942417144775391
# epoch:  116
# assembling the matrix time taken:  0.0057370662689208984
# solving Ax = b time taken:  0.00027298927307128906
# epoch:  117
# assembling the matrix time taken:  0.00585484504699707
# solving Ax = b time taken:  0.00015401840209960938
# epoch:  118
# assembling the matrix time taken:  0.00661778450012207
# solving Ax = b time taken:  0.0002579689025878906
# epoch:  119
# assembling the matrix time taken:  0.007451772689819336
# solving Ax = b time taken:  0.0003731250762939453
# epoch:  120
# assembling the matrix time taken:  0.005450010299682617
# solving Ax = b time taken:  0.0002810955047607422
# epoch:  121
# assembling the matrix time taken:  0.00650787353515625
# solving Ax = b time taken:  0.00017786026000976562
# epoch:  122
# assembling the matrix time taken:  0.007860898971557617
# solving Ax = b time taken:  0.0003800392150878906
# epoch:  123
# assembling the matrix time taken:  0.006400108337402344
# solving Ax = b time taken:  0.00038504600524902344
# epoch:  124
# assembling the matrix time taken:  0.006417751312255859
# solving Ax = b time taken:  0.0002841949462890625
# epoch:  125
# assembling the matrix time taken:  0.007576704025268555
# solving Ax = b time taken:  0.00017786026000976562
# epoch:  126
# assembling the matrix time taken:  0.006058931350708008
# solving Ax = b time taken:  0.000209808349609375
# epoch:  127
# assembling the matrix time taken:  0.006873130798339844
# solving Ax = b time taken:  0.0004799365997314453
# epoch:  128
# assembling the matrix time taken:  0.005756855010986328
# solving Ax = b time taken:  0.0001850128173828125
# epoch:  129
# assembling the matrix time taken:  0.005285024642944336
# solving Ax = b time taken:  0.00017595291137695312
# epoch:  130
# assembling the matrix time taken:  0.0061266422271728516
# solving Ax = b time taken:  0.0003120899200439453
# epoch:  131
# assembling the matrix time taken:  0.007093906402587891
# solving Ax = b time taken:  0.00018095970153808594
# epoch:  132
# assembling the matrix time taken:  0.006791830062866211
# solving Ax = b time taken:  0.00047516822814941406
# epoch:  133
# assembling the matrix time taken:  0.006827116012573242
# solving Ax = b time taken:  0.00017309188842773438
# epoch:  134
# assembling the matrix time taken:  0.006448984146118164
# solving Ax = b time taken:  0.0004601478576660156
# epoch:  135
# assembling the matrix time taken:  0.006302356719970703
# solving Ax = b time taken:  0.0002512931823730469
# epoch:  136
# assembling the matrix time taken:  0.006307840347290039
# solving Ax = b time taken:  0.00042700767517089844
# epoch:  137
# assembling the matrix time taken:  0.007434368133544922
# solving Ax = b time taken:  0.00029587745666503906
# epoch:  138
# assembling the matrix time taken:  0.007609128952026367
# solving Ax = b time taken:  0.0005362033843994141
# epoch:  139
# assembling the matrix time taken:  0.007994890213012695
# solving Ax = b time taken:  0.0001888275146484375
# epoch:  140
# assembling the matrix time taken:  0.005616903305053711
# solving Ax = b time taken:  0.00017976760864257812
# epoch:  141
# assembling the matrix time taken:  0.006891012191772461
# solving Ax = b time taken:  0.0001881122589111328
# epoch:  142
# assembling the matrix time taken:  0.0062100887298583984
# solving Ax = b time taken:  0.0004229545593261719
# epoch:  143
# assembling the matrix time taken:  0.0066950321197509766
# solving Ax = b time taken:  0.00019621849060058594
# epoch:  144
# assembling the matrix time taken:  0.005149126052856445
# solving Ax = b time taken:  0.00016689300537109375
# epoch:  145
# assembling the matrix time taken:  0.006566762924194336
# solving Ax = b time taken:  0.00018095970153808594
# epoch:  146
# assembling the matrix time taken:  0.006630897521972656
# solving Ax = b time taken:  0.0001900196075439453
# epoch:  147
# assembling the matrix time taken:  0.007546901702880859
# solving Ax = b time taken:  0.00019407272338867188
# epoch:  148
# assembling the matrix time taken:  0.0067138671875
# solving Ax = b time taken:  0.0003788471221923828
# epoch:  149
# assembling the matrix time taken:  0.006722927093505859
# solving Ax = b time taken:  0.00020194053649902344
# epoch:  150
# assembling the matrix time taken:  0.007097959518432617
# solving Ax = b time taken:  0.0004029273986816406
# epoch:  151
# assembling the matrix time taken:  0.006772041320800781
# solving Ax = b time taken:  0.00029397010803222656
# epoch:  152
# assembling the matrix time taken:  0.006091117858886719
# solving Ax = b time taken:  0.000244140625
# epoch:  153
# assembling the matrix time taken:  0.007370948791503906
# solving Ax = b time taken:  0.00021576881408691406
# epoch:  154
# assembling the matrix time taken:  0.0069789886474609375
# solving Ax = b time taken:  0.0004582405090332031
# epoch:  155
# assembling the matrix time taken:  0.0063629150390625
# solving Ax = b time taken:  0.0004868507385253906
# epoch:  156
# assembling the matrix time taken:  0.0072672367095947266
# solving Ax = b time taken:  0.00029730796813964844
# epoch:  157
# assembling the matrix time taken:  0.007931232452392578
# solving Ax = b time taken:  0.0004527568817138672
# epoch:  158
# assembling the matrix time taken:  0.007102012634277344
# solving Ax = b time taken:  0.0005769729614257812
# epoch:  159
# assembling the matrix time taken:  0.006723165512084961
# solving Ax = b time taken:  0.0001971721649169922
# epoch:  160
# assembling the matrix time taken:  0.007564067840576172
# solving Ax = b time taken:  0.0004570484161376953
# epoch:  161
# assembling the matrix time taken:  0.00750422477722168
# solving Ax = b time taken:  0.00030493736267089844
# epoch:  162
# assembling the matrix time taken:  0.006683826446533203
# solving Ax = b time taken:  0.0004749298095703125
# epoch:  163
# assembling the matrix time taken:  0.008537054061889648
# solving Ax = b time taken:  0.00026226043701171875
# epoch:  164
# assembling the matrix time taken:  0.007714033126831055
# solving Ax = b time taken:  0.0003941059112548828
# epoch:  165
# assembling the matrix time taken:  0.007548093795776367
# solving Ax = b time taken:  0.0002281665802001953
# epoch:  166
# assembling the matrix time taken:  0.00832509994506836
# solving Ax = b time taken:  0.00045013427734375
# epoch:  167
# assembling the matrix time taken:  0.007740020751953125
# solving Ax = b time taken:  0.00057220458984375
# epoch:  168
# assembling the matrix time taken:  0.007359027862548828
# solving Ax = b time taken:  0.00022292137145996094
# epoch:  169
# assembling the matrix time taken:  0.0077779293060302734
# solving Ax = b time taken:  0.0002651214599609375
# epoch:  170
# assembling the matrix time taken:  0.009089231491088867
# solving Ax = b time taken:  0.0004901885986328125
# epoch:  171
# assembling the matrix time taken:  0.009351253509521484
# solving Ax = b time taken:  0.00029587745666503906
# epoch:  172
# assembling the matrix time taken:  0.007266044616699219
# solving Ax = b time taken:  0.0004980564117431641
# epoch:  173
# assembling the matrix time taken:  0.007776021957397461
# solving Ax = b time taken:  0.0004909038543701172
# epoch:  174
# assembling the matrix time taken:  0.007922172546386719
# solving Ax = b time taken:  0.00022482872009277344
# epoch:  175
# assembling the matrix time taken:  0.008463144302368164
# solving Ax = b time taken:  0.00047898292541503906
# epoch:  176
# assembling the matrix time taken:  0.008117914199829102
# solving Ax = b time taken:  0.0005650520324707031
# epoch:  177
# assembling the matrix time taken:  0.00783085823059082
# solving Ax = b time taken:  0.00023293495178222656
# epoch:  178
# assembling the matrix time taken:  0.008170127868652344
# solving Ax = b time taken:  0.0005719661712646484
# epoch:  179
# assembling the matrix time taken:  0.008105993270874023
# solving Ax = b time taken:  0.0003063678741455078
# epoch:  180
# assembling the matrix time taken:  0.008683919906616211
# solving Ax = b time taken:  0.0005259513854980469
# epoch:  181
# assembling the matrix time taken:  0.008587121963500977
# solving Ax = b time taken:  0.00046706199645996094
# epoch:  182
# assembling the matrix time taken:  0.00915384292602539
# solving Ax = b time taken:  0.0009331703186035156
# epoch:  183
# assembling the matrix time taken:  0.008594989776611328
# solving Ax = b time taken:  0.0005939006805419922
# epoch:  184
# assembling the matrix time taken:  0.007620096206665039
# solving Ax = b time taken:  0.0005130767822265625
# epoch:  185
# assembling the matrix time taken:  0.00863790512084961
# solving Ax = b time taken:  0.0005140304565429688
# epoch:  186
# assembling the matrix time taken:  0.008671283721923828
# solving Ax = b time taken:  0.0006518363952636719
# epoch:  187
# assembling the matrix time taken:  0.008869171142578125
# solving Ax = b time taken:  0.0005950927734375
# epoch:  188
# assembling the matrix time taken:  0.007706165313720703
# solving Ax = b time taken:  0.0005900859832763672
# epoch:  189
# assembling the matrix time taken:  0.009557962417602539
# solving Ax = b time taken:  0.0008120536804199219
# epoch:  190
# assembling the matrix time taken:  0.008435249328613281
# solving Ax = b time taken:  0.0008118152618408203
# epoch:  191
# assembling the matrix time taken:  0.009100675582885742
# solving Ax = b time taken:  0.000579833984375
# epoch:  192
# assembling the matrix time taken:  0.008374929428100586
# solving Ax = b time taken:  0.0006527900695800781
# epoch:  193
# assembling the matrix time taken:  0.008964776992797852
# solving Ax = b time taken:  0.0007879734039306641
# epoch:  194
# assembling the matrix time taken:  0.009422063827514648
# solving Ax = b time taken:  0.0006380081176757812
# epoch:  195
# assembling the matrix time taken:  0.00940394401550293
# solving Ax = b time taken:  0.0005791187286376953
# epoch:  196
# assembling the matrix time taken:  0.009469747543334961
# solving Ax = b time taken:  0.00039005279541015625
# epoch:  197
# assembling the matrix time taken:  0.0085906982421875
# solving Ax = b time taken:  0.0004909038543701172
# epoch:  198
# assembling the matrix time taken:  0.009474992752075195
# solving Ax = b time taken:  0.0006380081176757812
# epoch:  199
# assembling the matrix time taken:  0.009728193283081055
# solving Ax = b time taken:  0.0007228851318359375
# epoch:  200
# assembling the matrix time taken:  0.008755922317504883
# solving Ax = b time taken:  0.0006010532379150391
# epoch:  201
# assembling the matrix time taken:  0.010091066360473633
# solving Ax = b time taken:  0.00037980079650878906
# epoch:  202
# assembling the matrix time taken:  0.009233951568603516
# solving Ax = b time taken:  0.0007157325744628906
# epoch:  203
# assembling the matrix time taken:  0.010210752487182617
# solving Ax = b time taken:  0.0006389617919921875
# epoch:  204
# assembling the matrix time taken:  0.010075807571411133
# solving Ax = b time taken:  0.00045108795166015625
# epoch:  205
# assembling the matrix time taken:  0.009392261505126953
# solving Ax = b time taken:  0.0006899833679199219
# epoch:  206
# assembling the matrix time taken:  0.01006007194519043
# solving Ax = b time taken:  0.0005328655242919922
# epoch:  207
# assembling the matrix time taken:  0.009788990020751953
# solving Ax = b time taken:  0.0006310939788818359
# epoch:  208
# assembling the matrix time taken:  0.008723020553588867
# solving Ax = b time taken:  0.0008020401000976562
# epoch:  209
# assembling the matrix time taken:  0.010098934173583984
# solving Ax = b time taken:  0.00067901611328125
# epoch:  210
# assembling the matrix time taken:  0.009633064270019531
# solving Ax = b time taken:  0.0009300708770751953
# epoch:  211
# assembling the matrix time taken:  0.009317159652709961
# solving Ax = b time taken:  0.000885009765625
# epoch:  212
# assembling the matrix time taken:  0.009811162948608398
# solving Ax = b time taken:  0.000576019287109375
# epoch:  213
# assembling the matrix time taken:  0.009804010391235352
# solving Ax = b time taken:  0.0010509490966796875
# epoch:  214
# assembling the matrix time taken:  0.010004997253417969
# solving Ax = b time taken:  0.0004527568817138672
# epoch:  215
# assembling the matrix time taken:  0.009688854217529297
# solving Ax = b time taken:  0.0005519390106201172
# epoch:  216
# assembling the matrix time taken:  0.008806228637695312
# solving Ax = b time taken:  0.00086212158203125
# epoch:  217
# assembling the matrix time taken:  0.009874105453491211
# solving Ax = b time taken:  0.001112222671508789
# epoch:  218
# assembling the matrix time taken:  0.010015010833740234
# solving Ax = b time taken:  0.0010340213775634766
# epoch:  219
# assembling the matrix time taken:  0.009725809097290039
# solving Ax = b time taken:  0.0007009506225585938
# epoch:  220
# assembling the matrix time taken:  0.009960174560546875
# solving Ax = b time taken:  0.0006368160247802734
# epoch:  221
# assembling the matrix time taken:  0.011338949203491211
# solving Ax = b time taken:  0.0006971359252929688
# epoch:  222
# assembling the matrix time taken:  0.009758949279785156
# solving Ax = b time taken:  0.0008249282836914062
# epoch:  223
# assembling the matrix time taken:  0.010934114456176758
# solving Ax = b time taken:  0.0007367134094238281
# epoch:  224
# assembling the matrix time taken:  0.010052919387817383
# solving Ax = b time taken:  0.00041484832763671875
# epoch:  225
# assembling the matrix time taken:  0.010837078094482422
# solving Ax = b time taken:  0.0008530616760253906
# epoch:  226
# assembling the matrix time taken:  0.010448217391967773
# solving Ax = b time taken:  0.00113677978515625
# epoch:  227
# assembling the matrix time taken:  0.01781296730041504
# solving Ax = b time taken:  0.0012669563293457031
# epoch:  228
# assembling the matrix time taken:  0.010517120361328125
# solving Ax = b time taken:  0.001055002212524414
# epoch:  229
# assembling the matrix time taken:  0.010411977767944336
# solving Ax = b time taken:  0.0007789134979248047
# epoch:  230
# assembling the matrix time taken:  0.010210037231445312
# solving Ax = b time taken:  0.0007579326629638672
# epoch:  231
# assembling the matrix time taken:  0.011687994003295898
# solving Ax = b time taken:  0.0008289813995361328
# epoch:  232
# assembling the matrix time taken:  0.009908914566040039
# solving Ax = b time taken:  0.0003440380096435547
# epoch:  233
# assembling the matrix time taken:  0.01183176040649414
# solving Ax = b time taken:  0.0008199214935302734
# epoch:  234
# assembling the matrix time taken:  0.01061105728149414
# solving Ax = b time taken:  0.0004229545593261719
# epoch:  235
# assembling the matrix time taken:  0.011293888092041016
# solving Ax = b time taken:  0.0004558563232421875
# epoch:  236
# assembling the matrix time taken:  0.011320829391479492
# solving Ax = b time taken:  0.0008308887481689453
# epoch:  237
# assembling the matrix time taken:  0.011596918106079102
# solving Ax = b time taken:  0.0008308887481689453
# epoch:  238
# assembling the matrix time taken:  0.011435985565185547
# solving Ax = b time taken:  0.0008230209350585938
# epoch:  239
# assembling the matrix time taken:  0.011868953704833984
# solving Ax = b time taken:  0.0006639957427978516
# epoch:  240
# assembling the matrix time taken:  0.010468006134033203
# solving Ax = b time taken:  0.0009989738464355469
# epoch:  241
# assembling the matrix time taken:  0.010856151580810547
# solving Ax = b time taken:  0.0010492801666259766
# epoch:  242
# assembling the matrix time taken:  0.012057781219482422
# solving Ax = b time taken:  0.0009860992431640625
# epoch:  243
# assembling the matrix time taken:  0.010953903198242188
# solving Ax = b time taken:  0.0007543563842773438
# epoch:  244
# assembling the matrix time taken:  0.011049032211303711
# solving Ax = b time taken:  0.0009009838104248047
# epoch:  245
# assembling the matrix time taken:  0.012202024459838867
# solving Ax = b time taken:  0.0007288455963134766
# epoch:  246
# assembling the matrix time taken:  0.010951757431030273
# solving Ax = b time taken:  0.000701904296875
# epoch:  247
# assembling the matrix time taken:  0.0122528076171875
# solving Ax = b time taken:  0.0006992816925048828
# epoch:  248
# assembling the matrix time taken:  0.011010169982910156
# solving Ax = b time taken:  0.0005338191986083984
# epoch:  249
# assembling the matrix time taken:  0.012592792510986328
# solving Ax = b time taken:  0.0009710788726806641
# epoch:  250
# assembling the matrix time taken:  0.011227846145629883
# solving Ax = b time taken:  0.0012001991271972656
# epoch:  251
# assembling the matrix time taken:  0.011733055114746094
# solving Ax = b time taken:  0.0009260177612304688
# epoch:  252
# assembling the matrix time taken:  0.010276079177856445
# solving Ax = b time taken:  0.0007541179656982422
# epoch:  253
# assembling the matrix time taken:  0.013010025024414062
# solving Ax = b time taken:  0.0005309581756591797
# epoch:  254
# assembling the matrix time taken:  0.011434078216552734
# solving Ax = b time taken:  0.0007460117340087891
# epoch:  255
# assembling the matrix time taken:  0.012611150741577148
# solving Ax = b time taken:  0.0009279251098632812
# epoch:  256
# assembling the matrix time taken:  0.010483264923095703
# solving Ax = b time taken:  0.0007860660552978516
# time taken:  16.088305711746216
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 43
#      40     filename = folder + 'model_NeumannOGA_1D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
#      41     torch.save(my_model,filename)
# ---> 43 show_convergence_order2(err_QMC2,err_h10,exponent,2*N,filename_write,write2file = write2file)
#      44 show_convergence_order_latex2(err_QMC2,err_h10,exponent,k=relu_k,d = dim)
#
# NameError: name 'show_convergence_order2' is not defined

# %% [markdown]
# ## cosine example

# %%
m = 2 
def u_exact(x):
    return torch.cos(m*pi*x)

def du_exact(x):
    return -m *pi*torch.sin(m*pi*x)

def rhs(x):
    return  ((m*pi)**2 + 1) * torch.cos(m*pi*x) 

dim = 1 
function_name = "cosine1d" 
filename_write = "data/1DPINNNeumannOGA-{}-order.txt".format(function_name)
Nx = 2**10 
order = 2  
f_write = open(filename_write, "a")
f_write.write("Integration points: Nx {}, order {} \n".format(Nx,order))
f_write.close() 

save = True 
write2file = True
rand_deter = 'deter'
for N in [2**11]: # 2**12,2**14
    f_write = open(filename_write, "a")
    my_model = None 
    exponent = 8 
    num_epochs = 2**exponent  
    plot_freq = num_epochs 
    relu_k = 3   
    err_QMC2, err_h10, err_energy, my_model = OGANeumannReLU1D(None,rhs,u_exact,du_exact,u_exact, N,num_epochs,plot_freq, Nx, order, k =relu_k, rand_deter = rand_deter,solver = "direct")

    if save: 
        folder = 'data/'
        filename = folder + 'err_NeumannOGA_1D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        torch.save(err_QMC2,filename) 
        folder = 'data/'
        filename = folder + 'model_NeumannOGA_1D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        torch.save(my_model,filename)

    show_convergence_order2_PINN(err_QMC2,err_h10,err_energy, exponent,2*N,filename_write,write2file = write2file)
    # show_convergence_order_latex2(err_QMC2,err_h10,exponent,k=relu_k,d = dim)
# Out:
# using linear solver:  direct
# epoch:  1
# assembling the matrix time taken:  0.00015783309936523438
# solving Ax = b time taken:  6.508827209472656e-05
# epoch:  2
# assembling the matrix time taken:  0.0001652240753173828
# solving Ax = b time taken:  5.984306335449219e-05
# epoch:  3
# assembling the matrix time taken:  0.0001919269561767578
# solving Ax = b time taken:  5.888938903808594e-05
# epoch:  4
# assembling the matrix time taken:  0.0005831718444824219
# solving Ax = b time taken:  0.00018596649169921875
# epoch:  5
# assembling the matrix time taken:  0.00023102760314941406
# solving Ax = b time taken:  5.602836608886719e-05
# epoch:  6
# assembling the matrix time taken:  0.0002732276916503906
# solving Ax = b time taken:  5.793571472167969e-05
# epoch:  7
# assembling the matrix time taken:  0.00027298927307128906
# solving Ax = b time taken:  5.888938903808594e-05
# epoch:  8
# assembling the matrix time taken:  0.00021028518676757812
# solving Ax = b time taken:  6.008148193359375e-05
# epoch:  9
# assembling the matrix time taken:  0.0002911090850830078
# solving Ax = b time taken:  0.00014209747314453125
# epoch:  10
# assembling the matrix time taken:  0.00036406517028808594
# solving Ax = b time taken:  7.200241088867188e-05
# epoch:  11
# assembling the matrix time taken:  0.00033402442932128906
# solving Ax = b time taken:  7.224082946777344e-05
# epoch:  12
# assembling the matrix time taken:  0.00033092498779296875
# solving Ax = b time taken:  6.413459777832031e-05
# epoch:  13
# assembling the matrix time taken:  0.0006201267242431641
# solving Ax = b time taken:  6.198883056640625e-05
# epoch:  14
# assembling the matrix time taken:  0.0003771781921386719
# solving Ax = b time taken:  0.00018405914306640625
# epoch:  15
# assembling the matrix time taken:  0.00037789344787597656
# solving Ax = b time taken:  5.91278076171875e-05
# epoch:  16
# assembling the matrix time taken:  0.00032830238342285156
# solving Ax = b time taken:  6.079673767089844e-05
# epoch:  17
# assembling the matrix time taken:  0.001094818115234375
# solving Ax = b time taken:  6.413459777832031e-05
# epoch:  18
# assembling the matrix time taken:  0.0014240741729736328
# solving Ax = b time taken:  6.4849853515625e-05
# epoch:  19
# assembling the matrix time taken:  0.0015342235565185547
# solving Ax = b time taken:  0.00014400482177734375
# epoch:  20
# assembling the matrix time taken:  0.0018229484558105469
# solving Ax = b time taken:  6.604194641113281e-05
# epoch:  21
# assembling the matrix time taken:  0.0010571479797363281
# solving Ax = b time taken:  6.67572021484375e-05
# epoch:  22
# assembling the matrix time taken:  0.0012171268463134766
# solving Ax = b time taken:  7.390975952148438e-05
# epoch:  23
# assembling the matrix time taken:  0.0013582706451416016
# solving Ax = b time taken:  6.4849853515625e-05
# epoch:  24
# assembling the matrix time taken:  0.0009419918060302734
# solving Ax = b time taken:  0.00016117095947265625
# epoch:  25
# assembling the matrix time taken:  0.001123189926147461
# solving Ax = b time taken:  6.890296936035156e-05
# epoch:  26
# assembling the matrix time taken:  0.0010721683502197266
# solving Ax = b time taken:  7.295608520507812e-05
# epoch:  27
# assembling the matrix time taken:  0.001352071762084961
# solving Ax = b time taken:  7.700920104980469e-05
# epoch:  28
# assembling the matrix time taken:  0.0018410682678222656
# solving Ax = b time taken:  0.0002079010009765625
# epoch:  29
# assembling the matrix time taken:  0.0013899803161621094
# solving Ax = b time taken:  6.699562072753906e-05
# epoch:  30
# assembling the matrix time taken:  0.0010869503021240234
# solving Ax = b time taken:  7.390975952148438e-05
# epoch:  31
# assembling the matrix time taken:  0.0012519359588623047
# solving Ax = b time taken:  8.606910705566406e-05
# epoch:  32
# assembling the matrix time taken:  0.001271963119506836
# solving Ax = b time taken:  7.390975952148438e-05
# epoch:  33
# assembling the matrix time taken:  0.0011639595031738281
# solving Ax = b time taken:  8.296966552734375e-05
# epoch:  34
# assembling the matrix time taken:  0.001399993896484375
# solving Ax = b time taken:  7.677078247070312e-05
# epoch:  35
# assembling the matrix time taken:  0.0012972354888916016
# solving Ax = b time taken:  7.677078247070312e-05
# epoch:  36
# assembling the matrix time taken:  0.001055002212524414
# solving Ax = b time taken:  7.295608520507812e-05
# epoch:  37
# assembling the matrix time taken:  0.0015778541564941406
# solving Ax = b time taken:  7.390975952148438e-05
# epoch:  38
# assembling the matrix time taken:  0.002053976058959961
# solving Ax = b time taken:  0.00016307830810546875
# epoch:  39
# assembling the matrix time taken:  0.002410888671875
# solving Ax = b time taken:  7.796287536621094e-05
# epoch:  40
# assembling the matrix time taken:  0.001148223876953125
# solving Ax = b time taken:  8.702278137207031e-05
# epoch:  41
# assembling the matrix time taken:  0.0017600059509277344
# solving Ax = b time taken:  7.486343383789062e-05
# epoch:  42
# assembling the matrix time taken:  0.0015139579772949219
# solving Ax = b time taken:  8.988380432128906e-05
# epoch:  43
# assembling the matrix time taken:  0.0022089481353759766
# solving Ax = b time taken:  0.00015592575073242188
# epoch:  44
# assembling the matrix time taken:  0.0019140243530273438
# solving Ax = b time taken:  8.225440979003906e-05
# epoch:  45
# assembling the matrix time taken:  0.0017180442810058594
# solving Ax = b time taken:  7.915496826171875e-05
# epoch:  46
# assembling the matrix time taken:  0.00145721435546875
# solving Ax = b time taken:  8.082389831542969e-05
# epoch:  47
# assembling the matrix time taken:  0.0015659332275390625
# solving Ax = b time taken:  8.20159912109375e-05
# epoch:  48
# assembling the matrix time taken:  0.0010440349578857422
# solving Ax = b time taken:  0.00021886825561523438
# epoch:  49
# assembling the matrix time taken:  0.002313852310180664
# solving Ax = b time taken:  8.320808410644531e-05
# epoch:  50
# assembling the matrix time taken:  0.0016679763793945312
# solving Ax = b time taken:  8.487701416015625e-05
# epoch:  51
# assembling the matrix time taken:  0.0018470287322998047
# solving Ax = b time taken:  8.606910705566406e-05
# epoch:  52
# assembling the matrix time taken:  0.0014891624450683594
# solving Ax = b time taken:  8.988380432128906e-05
# epoch:  53
# assembling the matrix time taken:  0.002978801727294922
# solving Ax = b time taken:  0.00015020370483398438
# epoch:  54
# assembling the matrix time taken:  0.0014541149139404297
# solving Ax = b time taken:  8.511543273925781e-05
# epoch:  55
# assembling the matrix time taken:  0.0016322135925292969
# solving Ax = b time taken:  9.608268737792969e-05
# epoch:  56
# assembling the matrix time taken:  0.001522064208984375
# solving Ax = b time taken:  9.489059448242188e-05
# epoch:  57
# assembling the matrix time taken:  0.002279996871948242
# solving Ax = b time taken:  8.606910705566406e-05
# epoch:  58
# assembling the matrix time taken:  0.0014491081237792969
# solving Ax = b time taken:  0.00017595291137695312
# epoch:  59
# assembling the matrix time taken:  0.002004861831665039
# solving Ax = b time taken:  8.797645568847656e-05
# epoch:  60
# assembling the matrix time taken:  0.0016787052154541016
# solving Ax = b time taken:  9.703636169433594e-05
# epoch:  61
# assembling the matrix time taken:  0.002413034439086914
# solving Ax = b time taken:  9.918212890625e-05
# epoch:  62
# assembling the matrix time taken:  0.0014150142669677734
# solving Ax = b time taken:  9.322166442871094e-05
# epoch:  63
# assembling the matrix time taken:  0.0019850730895996094
# solving Ax = b time taken:  0.00023293495178222656
# epoch:  64
# assembling the matrix time taken:  0.0013036727905273438
# solving Ax = b time taken:  8.96453857421875e-05
# epoch:  65
# assembling the matrix time taken:  0.002140045166015625
# solving Ax = b time taken:  0.0006000995635986328
# epoch:  66
# assembling the matrix time taken:  0.0020151138305664062
# solving Ax = b time taken:  0.00010704994201660156
# epoch:  67
# assembling the matrix time taken:  0.0022220611572265625
# solving Ax = b time taken:  0.00011491775512695312
# epoch:  68
# assembling the matrix time taken:  0.0016851425170898438
# solving Ax = b time taken:  0.0002582073211669922
# epoch:  69
# assembling the matrix time taken:  0.0017621517181396484
# solving Ax = b time taken:  0.00010085105895996094
# epoch:  70
# assembling the matrix time taken:  0.0017962455749511719
# solving Ax = b time taken:  0.00011587142944335938
# epoch:  71
# assembling the matrix time taken:  0.0016167163848876953
# solving Ax = b time taken:  0.0001010894775390625
# epoch:  72
# assembling the matrix time taken:  0.0017139911651611328
# solving Ax = b time taken:  0.0001049041748046875
# epoch:  73
# assembling the matrix time taken:  0.002021312713623047
# solving Ax = b time taken:  0.0007407665252685547
# epoch:  74
# assembling the matrix time taken:  0.001898050308227539
# solving Ax = b time taken:  0.0004260540008544922
# epoch:  75
# assembling the matrix time taken:  0.002287149429321289
# solving Ax = b time taken:  0.0004870891571044922
# epoch:  76
# assembling the matrix time taken:  0.0014269351959228516
# solving Ax = b time taken:  0.00010800361633300781
# epoch:  77
# assembling the matrix time taken:  0.0023636817932128906
# solving Ax = b time taken:  0.0005619525909423828
# epoch:  78
# assembling the matrix time taken:  0.001964092254638672
# solving Ax = b time taken:  0.000148773193359375
# epoch:  79
# assembling the matrix time taken:  0.0019180774688720703
# solving Ax = b time taken:  0.0005161762237548828
# epoch:  80
# assembling the matrix time taken:  0.0017819404602050781
# solving Ax = b time taken:  0.00011181831359863281
# epoch:  81
# assembling the matrix time taken:  0.001911163330078125
# solving Ax = b time taken:  0.00045490264892578125
# epoch:  82
# assembling the matrix time taken:  0.0024871826171875
# solving Ax = b time taken:  0.00011801719665527344
# epoch:  83
# assembling the matrix time taken:  0.002270936965942383
# solving Ax = b time taken:  0.00017309188842773438
# epoch:  84
# assembling the matrix time taken:  0.002093076705932617
# solving Ax = b time taken:  0.00044226646423339844
# epoch:  85
# assembling the matrix time taken:  0.002592802047729492
# solving Ax = b time taken:  0.00013685226440429688
# epoch:  86
# assembling the matrix time taken:  0.0023169517517089844
# solving Ax = b time taken:  0.00012993812561035156
# epoch:  87
# assembling the matrix time taken:  0.002820730209350586
# solving Ax = b time taken:  0.0005538463592529297
# epoch:  88
# assembling the matrix time taken:  0.0020089149475097656
# solving Ax = b time taken:  0.00021886825561523438
# epoch:  89
# assembling the matrix time taken:  0.0027060508728027344
# solving Ax = b time taken:  0.0005817413330078125
# epoch:  90
# assembling the matrix time taken:  0.0018229484558105469
# solving Ax = b time taken:  0.00039505958557128906
# epoch:  91
# assembling the matrix time taken:  0.0020880699157714844
# solving Ax = b time taken:  0.0005009174346923828
# epoch:  92
# assembling the matrix time taken:  0.0021209716796875
# solving Ax = b time taken:  0.0003249645233154297
# epoch:  93
# assembling the matrix time taken:  0.004029035568237305
# solving Ax = b time taken:  0.00019097328186035156
# epoch:  94
# assembling the matrix time taken:  0.002706289291381836
# solving Ax = b time taken:  0.00015425682067871094
# epoch:  95
# assembling the matrix time taken:  0.0029649734497070312
# solving Ax = b time taken:  0.0006232261657714844
# epoch:  96
# assembling the matrix time taken:  0.002271890640258789
# solving Ax = b time taken:  0.00037407875061035156
# epoch:  97
# assembling the matrix time taken:  0.003215789794921875
# solving Ax = b time taken:  0.00015687942504882812
# epoch:  98
# assembling the matrix time taken:  0.003359079360961914
# solving Ax = b time taken:  0.0001609325408935547
# epoch:  99
# assembling the matrix time taken:  0.004008054733276367
# solving Ax = b time taken:  0.0002872943878173828
# epoch:  100
# assembling the matrix time taken:  0.0031890869140625
# solving Ax = b time taken:  0.00019025802612304688
# epoch:  101
# assembling the matrix time taken:  0.004498720169067383
# solving Ax = b time taken:  0.00018095970153808594
# epoch:  102
# assembling the matrix time taken:  0.0035829544067382812
# solving Ax = b time taken:  0.00014328956604003906
# epoch:  103
# assembling the matrix time taken:  0.004176139831542969
# solving Ax = b time taken:  0.0002980232238769531
# epoch:  104
# assembling the matrix time taken:  0.0027730464935302734
# solving Ax = b time taken:  0.0005447864532470703
# epoch:  105
# assembling the matrix time taken:  0.0034999847412109375
# solving Ax = b time taken:  0.0003600120544433594
# epoch:  106
# assembling the matrix time taken:  0.003377199172973633
# solving Ax = b time taken:  0.0005817413330078125
# epoch:  107
# assembling the matrix time taken:  0.00335693359375
# solving Ax = b time taken:  0.000347137451171875
# epoch:  108
# assembling the matrix time taken:  0.003387928009033203
# solving Ax = b time taken:  0.00014019012451171875
# epoch:  109
# assembling the matrix time taken:  0.0035457611083984375
# solving Ax = b time taken:  0.00014090538024902344
# epoch:  110
# assembling the matrix time taken:  0.0034112930297851562
# solving Ax = b time taken:  0.0001590251922607422
# epoch:  111
# assembling the matrix time taken:  0.0037097930908203125
# solving Ax = b time taken:  0.00034928321838378906
# epoch:  112
# assembling the matrix time taken:  0.003376007080078125
# solving Ax = b time taken:  0.000591278076171875
# epoch:  113
# assembling the matrix time taken:  0.00333404541015625
# solving Ax = b time taken:  0.0006031990051269531
# epoch:  114
# assembling the matrix time taken:  0.0035452842712402344
# solving Ax = b time taken:  0.00014400482177734375
# epoch:  115
# assembling the matrix time taken:  0.00395965576171875
# solving Ax = b time taken:  0.0007488727569580078
# epoch:  116
# assembling the matrix time taken:  0.0031249523162841797
# solving Ax = b time taken:  0.0006477832794189453
# epoch:  117
# assembling the matrix time taken:  0.0035400390625
# solving Ax = b time taken:  0.0005710124969482422
# epoch:  118
# assembling the matrix time taken:  0.0036458969116210938
# solving Ax = b time taken:  0.0006060600280761719
# epoch:  119
# assembling the matrix time taken:  0.003798961639404297
# solving Ax = b time taken:  0.0002808570861816406
# epoch:  120
# assembling the matrix time taken:  0.003328561782836914
# solving Ax = b time taken:  0.0005922317504882812
# epoch:  121
# assembling the matrix time taken:  0.0035419464111328125
# solving Ax = b time taken:  0.0006070137023925781
# epoch:  122
# assembling the matrix time taken:  0.003400087356567383
# solving Ax = b time taken:  0.0005960464477539062
# epoch:  123
# assembling the matrix time taken:  0.004128932952880859
# solving Ax = b time taken:  0.0005042552947998047
# epoch:  124
# assembling the matrix time taken:  0.003734111785888672
# solving Ax = b time taken:  0.0006058216094970703
# epoch:  125
# assembling the matrix time taken:  0.0042378902435302734
# solving Ax = b time taken:  0.0006000995635986328
# epoch:  126
# assembling the matrix time taken:  0.0037670135498046875
# solving Ax = b time taken:  0.0005748271942138672
# epoch:  127
# assembling the matrix time taken:  0.003738880157470703
# solving Ax = b time taken:  0.000308990478515625
# epoch:  128
# assembling the matrix time taken:  0.003172159194946289
# solving Ax = b time taken:  0.0006000995635986328
# epoch:  129
# assembling the matrix time taken:  0.003865957260131836
# solving Ax = b time taken:  0.0001659393310546875
# epoch:  130
# assembling the matrix time taken:  0.003957986831665039
# solving Ax = b time taken:  0.0002009868621826172
# epoch:  131
# assembling the matrix time taken:  0.0031981468200683594
# solving Ax = b time taken:  0.00016927719116210938
# epoch:  132
# assembling the matrix time taken:  0.0036432743072509766
# solving Ax = b time taken:  0.0006527900695800781
# epoch:  133
# assembling the matrix time taken:  0.003985881805419922
# solving Ax = b time taken:  0.0006310939788818359
# epoch:  134
# assembling the matrix time taken:  0.004083871841430664
# solving Ax = b time taken:  0.0002231597900390625
# epoch:  135
# assembling the matrix time taken:  0.004247188568115234
# solving Ax = b time taken:  0.0002942085266113281
# epoch:  136
# assembling the matrix time taken:  0.0039980411529541016
# solving Ax = b time taken:  0.00017690658569335938
# epoch:  137
# assembling the matrix time taken:  0.003921985626220703
# solving Ax = b time taken:  0.0006451606750488281
# epoch:  138
# assembling the matrix time taken:  0.003698110580444336
# solving Ax = b time taken:  0.00022411346435546875
# epoch:  139
# assembling the matrix time taken:  0.0037431716918945312
# solving Ax = b time taken:  0.0003948211669921875
# epoch:  140
# assembling the matrix time taken:  0.004075050354003906
# solving Ax = b time taken:  0.0006468296051025391
# epoch:  141
# assembling the matrix time taken:  0.0040130615234375
# solving Ax = b time taken:  0.0005211830139160156
# epoch:  142
# assembling the matrix time taken:  0.0038709640502929688
# solving Ax = b time taken:  0.0004899501800537109
# epoch:  143
# assembling the matrix time taken:  0.004152059555053711
# solving Ax = b time taken:  0.0002319812774658203
# epoch:  144
# assembling the matrix time taken:  0.0038590431213378906
# solving Ax = b time taken:  0.0005500316619873047
# epoch:  145
# assembling the matrix time taken:  0.003961086273193359
# solving Ax = b time taken:  0.00019502639770507812
# epoch:  146
# assembling the matrix time taken:  0.004167795181274414
# solving Ax = b time taken:  0.00024890899658203125
# epoch:  147
# assembling the matrix time taken:  0.004354953765869141
# solving Ax = b time taken:  0.0008559226989746094
# epoch:  148
# assembling the matrix time taken:  0.0037169456481933594
# solving Ax = b time taken:  0.0002579689025878906
# epoch:  149
# assembling the matrix time taken:  0.003957986831665039
# solving Ax = b time taken:  0.00023794174194335938
# epoch:  150
# assembling the matrix time taken:  0.0038368701934814453
# solving Ax = b time taken:  0.0006010532379150391
# epoch:  151
# assembling the matrix time taken:  0.005133867263793945
# solving Ax = b time taken:  0.0006580352783203125
# epoch:  152
# assembling the matrix time taken:  0.0035588741302490234
# solving Ax = b time taken:  0.0005528926849365234
# epoch:  153
# assembling the matrix time taken:  0.004433870315551758
# solving Ax = b time taken:  0.0005447864532470703
# epoch:  154
# assembling the matrix time taken:  0.0039021968841552734
# solving Ax = b time taken:  0.0006136894226074219
# epoch:  155
# assembling the matrix time taken:  0.0054318904876708984
# solving Ax = b time taken:  0.0005750656127929688
# epoch:  156
# assembling the matrix time taken:  0.0038347244262695312
# solving Ax = b time taken:  0.0005970001220703125
# epoch:  157
# assembling the matrix time taken:  0.004624128341674805
# solving Ax = b time taken:  0.0002110004425048828
# epoch:  158
# assembling the matrix time taken:  0.003660917282104492
# solving Ax = b time taken:  0.00020813941955566406
# epoch:  159
# assembling the matrix time taken:  0.00397491455078125
# solving Ax = b time taken:  0.00023293495178222656
# epoch:  160
# assembling the matrix time taken:  0.004085063934326172
# solving Ax = b time taken:  0.0002620220184326172
# epoch:  161
# assembling the matrix time taken:  0.004171133041381836
# solving Ax = b time taken:  0.0006871223449707031
# epoch:  162
# assembling the matrix time taken:  0.004139900207519531
# solving Ax = b time taken:  0.0005712509155273438
# epoch:  163
# assembling the matrix time taken:  0.004540205001831055
# solving Ax = b time taken:  0.0003387928009033203
# epoch:  164
# assembling the matrix time taken:  0.004611015319824219
# solving Ax = b time taken:  0.0006382465362548828
# epoch:  165
# assembling the matrix time taken:  0.004454135894775391
# solving Ax = b time taken:  0.0007071495056152344
# epoch:  166
# assembling the matrix time taken:  0.0038640499114990234
# solving Ax = b time taken:  0.0006458759307861328
# epoch:  167
# assembling the matrix time taken:  0.005155086517333984
# solving Ax = b time taken:  0.0007429122924804688
# epoch:  168
# assembling the matrix time taken:  0.004007101058959961
# solving Ax = b time taken:  0.0006849765777587891
# epoch:  169
# assembling the matrix time taken:  0.004378080368041992
# solving Ax = b time taken:  0.0003020763397216797
# epoch:  170
# assembling the matrix time taken:  0.005013942718505859
# solving Ax = b time taken:  0.00028204917907714844
# epoch:  171
# assembling the matrix time taken:  0.004755973815917969
# solving Ax = b time taken:  0.0007481575012207031
# epoch:  172
# assembling the matrix time taken:  0.0045566558837890625
# solving Ax = b time taken:  0.0006539821624755859
# epoch:  173
# assembling the matrix time taken:  0.004739999771118164
# solving Ax = b time taken:  0.0006380081176757812
# epoch:  174
# assembling the matrix time taken:  0.004382133483886719
# solving Ax = b time taken:  0.0006911754608154297
# epoch:  175
# assembling the matrix time taken:  0.00506281852722168
# solving Ax = b time taken:  0.0003802776336669922
# epoch:  176
# assembling the matrix time taken:  0.0040187835693359375
# solving Ax = b time taken:  0.0002009868621826172
# epoch:  177
# assembling the matrix time taken:  0.00455927848815918
# solving Ax = b time taken:  0.0003409385681152344
# epoch:  178
# assembling the matrix time taken:  0.0046999454498291016
# solving Ax = b time taken:  0.0006840229034423828
# epoch:  179
# assembling the matrix time taken:  0.0048329830169677734
# solving Ax = b time taken:  0.0008540153503417969
# epoch:  180
# assembling the matrix time taken:  0.004469156265258789
# solving Ax = b time taken:  0.0002460479736328125
# epoch:  181
# assembling the matrix time taken:  0.006127119064331055
# solving Ax = b time taken:  0.0005791187286376953
# epoch:  182
# assembling the matrix time taken:  0.004645824432373047
# solving Ax = b time taken:  0.0002880096435546875
# epoch:  183
# assembling the matrix time taken:  0.004788875579833984
# solving Ax = b time taken:  0.0008878707885742188
# epoch:  184
# assembling the matrix time taken:  0.0044689178466796875
# solving Ax = b time taken:  0.00026488304138183594
# epoch:  185
# assembling the matrix time taken:  0.004828929901123047
# solving Ax = b time taken:  0.0003540515899658203
# epoch:  186
# assembling the matrix time taken:  0.004474163055419922
# solving Ax = b time taken:  0.00033783912658691406
# epoch:  187
# assembling the matrix time taken:  0.005422115325927734
# solving Ax = b time taken:  0.0008091926574707031
# epoch:  188
# assembling the matrix time taken:  0.004705905914306641
# solving Ax = b time taken:  0.00028896331787109375
# epoch:  189
# assembling the matrix time taken:  0.004965782165527344
# solving Ax = b time taken:  0.0010061264038085938
# epoch:  190
# assembling the matrix time taken:  0.004854917526245117
# solving Ax = b time taken:  0.0006473064422607422
# epoch:  191
# assembling the matrix time taken:  0.005277156829833984
# solving Ax = b time taken:  0.0008261203765869141
# epoch:  192
# assembling the matrix time taken:  0.004294872283935547
# solving Ax = b time taken:  0.0002779960632324219
# epoch:  193
# assembling the matrix time taken:  0.005000114440917969
# solving Ax = b time taken:  0.0007028579711914062
# epoch:  194
# assembling the matrix time taken:  0.005460023880004883
# solving Ax = b time taken:  0.0006856918334960938
# epoch:  195
# assembling the matrix time taken:  0.004583835601806641
# solving Ax = b time taken:  0.0009431838989257812
# epoch:  196
# assembling the matrix time taken:  0.005218982696533203
# solving Ax = b time taken:  0.0003876686096191406
# epoch:  197
# assembling the matrix time taken:  0.0048770904541015625
# solving Ax = b time taken:  0.0006110668182373047
# epoch:  198
# assembling the matrix time taken:  0.004697084426879883
# solving Ax = b time taken:  0.0007162094116210938
# epoch:  199
# assembling the matrix time taken:  0.005246877670288086
# solving Ax = b time taken:  0.0011479854583740234
# epoch:  200
# assembling the matrix time taken:  0.00498199462890625
# solving Ax = b time taken:  0.0003256797790527344
# epoch:  201
# assembling the matrix time taken:  0.0054972171783447266
# solving Ax = b time taken:  0.0007717609405517578
# epoch:  202
# assembling the matrix time taken:  0.004714250564575195
# solving Ax = b time taken:  0.0005109310150146484
# epoch:  203
# assembling the matrix time taken:  0.005688190460205078
# solving Ax = b time taken:  0.0009467601776123047
# epoch:  204
# assembling the matrix time taken:  0.005454063415527344
# solving Ax = b time taken:  0.0007128715515136719
# epoch:  205
# assembling the matrix time taken:  0.0046350955963134766
# solving Ax = b time taken:  0.00038909912109375
# epoch:  206
# assembling the matrix time taken:  0.005259990692138672
# solving Ax = b time taken:  0.00032901763916015625
# epoch:  207
# assembling the matrix time taken:  0.004805803298950195
# solving Ax = b time taken:  0.0007638931274414062
# epoch:  208
# assembling the matrix time taken:  0.004794120788574219
# solving Ax = b time taken:  0.0010631084442138672
# epoch:  209
# assembling the matrix time taken:  0.005221128463745117
# solving Ax = b time taken:  0.00121307373046875
# epoch:  210
# assembling the matrix time taken:  0.0043468475341796875
# solving Ax = b time taken:  0.0006148815155029297
# epoch:  211
# assembling the matrix time taken:  0.0056340694427490234
# solving Ax = b time taken:  0.0006639957427978516
# epoch:  212
# assembling the matrix time taken:  0.005136013031005859
# solving Ax = b time taken:  0.0006840229034423828
# epoch:  213
# assembling the matrix time taken:  0.005500078201293945
# solving Ax = b time taken:  0.0012650489807128906
# epoch:  214
# assembling the matrix time taken:  0.005062103271484375
# solving Ax = b time taken:  0.000743865966796875
# epoch:  215
# assembling the matrix time taken:  0.005491018295288086
# solving Ax = b time taken:  0.00040030479431152344
# epoch:  216
# assembling the matrix time taken:  0.004818916320800781
# solving Ax = b time taken:  0.0011162757873535156
# epoch:  217
# assembling the matrix time taken:  0.005550861358642578
# solving Ax = b time taken:  0.0006530284881591797
# epoch:  218
# assembling the matrix time taken:  0.005542755126953125
# solving Ax = b time taken:  0.0003330707550048828
# epoch:  219
# assembling the matrix time taken:  0.005295753479003906
# solving Ax = b time taken:  0.0006279945373535156
# epoch:  220
# assembling the matrix time taken:  0.005566120147705078
# solving Ax = b time taken:  0.0008471012115478516
# epoch:  221
# assembling the matrix time taken:  0.005251169204711914
# solving Ax = b time taken:  0.0003571510314941406
# epoch:  222
# assembling the matrix time taken:  0.005079984664916992
# solving Ax = b time taken:  0.0007050037384033203
# epoch:  223
# assembling the matrix time taken:  0.005769014358520508
# solving Ax = b time taken:  0.0007588863372802734
# epoch:  224
# assembling the matrix time taken:  0.004963874816894531
# solving Ax = b time taken:  0.0007460117340087891
# epoch:  225
# assembling the matrix time taken:  0.0059070587158203125
# solving Ax = b time taken:  0.0012240409851074219
# epoch:  226
# assembling the matrix time taken:  0.00528717041015625
# solving Ax = b time taken:  0.0008301734924316406
# epoch:  227
# assembling the matrix time taken:  0.005196094512939453
# solving Ax = b time taken:  0.0009219646453857422
# epoch:  228
# assembling the matrix time taken:  0.0053119659423828125
# solving Ax = b time taken:  0.0003910064697265625
# epoch:  229
# assembling the matrix time taken:  0.0054988861083984375
# solving Ax = b time taken:  0.000431060791015625
# epoch:  230
# assembling the matrix time taken:  0.005690097808837891
# solving Ax = b time taken:  0.0005488395690917969
# epoch:  231
# assembling the matrix time taken:  0.006124734878540039
# solving Ax = b time taken:  0.0008370876312255859
# epoch:  232
# assembling the matrix time taken:  0.004878997802734375
# solving Ax = b time taken:  0.0008330345153808594
# epoch:  233
# assembling the matrix time taken:  0.005850076675415039
# solving Ax = b time taken:  0.0013000965118408203
# epoch:  234
# assembling the matrix time taken:  0.005818843841552734
# solving Ax = b time taken:  0.00044798851013183594
# epoch:  235
# assembling the matrix time taken:  0.0063321590423583984
# solving Ax = b time taken:  0.0009548664093017578
# epoch:  236
# assembling the matrix time taken:  0.005488872528076172
# solving Ax = b time taken:  0.0004220008850097656
# epoch:  237
# assembling the matrix time taken:  0.005304098129272461
# solving Ax = b time taken:  0.001239776611328125
# epoch:  238
# assembling the matrix time taken:  0.005873918533325195
# solving Ax = b time taken:  0.0011069774627685547
# epoch:  239
# assembling the matrix time taken:  0.006158113479614258
# solving Ax = b time taken:  0.001104116439819336
# epoch:  240
# assembling the matrix time taken:  0.0056650638580322266
# solving Ax = b time taken:  0.0007770061492919922
# epoch:  241
# assembling the matrix time taken:  0.006065845489501953
# solving Ax = b time taken:  0.0004718303680419922
# epoch:  242
# assembling the matrix time taken:  0.0057599544525146484
# solving Ax = b time taken:  0.0004928112030029297
# epoch:  243
# assembling the matrix time taken:  0.006273031234741211
# solving Ax = b time taken:  0.0007238388061523438
# epoch:  244
# assembling the matrix time taken:  0.005681753158569336
# solving Ax = b time taken:  0.0008561611175537109
# epoch:  245
# assembling the matrix time taken:  0.006117820739746094
# solving Ax = b time taken:  0.001268148422241211
# epoch:  246
# assembling the matrix time taken:  0.005455970764160156
# solving Ax = b time taken:  0.001146078109741211
# epoch:  247
# assembling the matrix time taken:  0.00580286979675293
# solving Ax = b time taken:  0.0013430118560791016
# epoch:  248
# assembling the matrix time taken:  0.0051212310791015625
# solving Ax = b time taken:  0.0008628368377685547
# epoch:  249
# assembling the matrix time taken:  0.006577968597412109
# solving Ax = b time taken:  0.0008518695831298828
# epoch:  250
# assembling the matrix time taken:  0.00577092170715332
# solving Ax = b time taken:  0.0009210109710693359
# epoch:  251
# assembling the matrix time taken:  0.00620269775390625
# solving Ax = b time taken:  0.0007879734039306641
# epoch:  252
# assembling the matrix time taken:  0.0053119659423828125
# solving Ax = b time taken:  0.0010230541229248047
# epoch:  253
# assembling the matrix time taken:  0.006619930267333984
# solving Ax = b time taken:  0.0011799335479736328
# epoch:  254
# assembling the matrix time taken:  0.005671262741088867
# solving Ax = b time taken:  0.0005550384521484375
# epoch:  255
# assembling the matrix time taken:  0.006298065185546875
# solving Ax = b time taken:  0.0013420581817626953
# epoch:  256
# assembling the matrix time taken:  0.005807161331176758
# solving Ax = b time taken:  0.0007658004760742188
# time taken:  13.828942775726318
# neuron num 		 error 		 order
# 4 		 3.224e+00 		 * 		 7.880e-01 		 * 		 2.175e+01 		 *
#
# 8 		 4.180e-01 		 2.95 		 8.127e-02 		 3.28 		 1.368e+00 		 3.99
#
# 16 		 6.134e-03 		 6.09 		 4.708e-03 		 4.11 		 4.594e-02 		 4.90
#
# 32 		 3.121e-04 		 4.30 		 4.377e-04 		 3.43 		 1.919e-03 		 4.58
#
# 64 		 2.789e-05 		 3.48 		 5.026e-05 		 3.12 		 1.070e-04 		 4.16
#
# 128 		 1.788e-06 		 3.96 		 5.914e-06 		 3.09 		 6.164e-06 		 4.12
#
# 256 		 2.799e-07 		 2.68 		 1.411e-06 		 2.07 		 3.736e-07 		 4.04
# /var/folders/45/p1_q2drx75983lk7ph_1gx6mhpr5_w/T/ipykernel_1202/843720377.py:77: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   print("{} \t\t {:.3e} \t\t {:.2f} \t\t {:.3e} \t\t {:.2f} \t\t {:.3e} \t\t {:.2f}  \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),
# /var/folders/45/p1_q2drx75983lk7ph_1gx6mhpr5_w/T/ipykernel_1202/843720377.py:78: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2),
# /var/folders/45/p1_q2drx75983lk7ph_1gx6mhpr5_w/T/ipykernel_1202/843720377.py:79: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   err_list3[i] , np.log(err_list3[i-1]/err_list3[i])/np.log(2) ) )
# /var/folders/45/p1_q2drx75983lk7ph_1gx6mhpr5_w/T/ipykernel_1202/843720377.py:81: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   f_write.write("{} \t\t {} \t\t {} \t\t {} \t\t {} \t\t {} \t\t {} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2),err_list3[i] , np.log(err_list3[i-1]/err_list3[i])/np.log(2) ))

# %%
err_energy
# Out:
# tensor([455839.6569,      0.0000,      0.0000,      0.0000,      0.0000,
#              0.0000,      0.0000,      0.0000,      0.0000,      0.0000,
#              0.0000,      0.0000,      0.0000,      0.0000,      0.0000,
#              0.0000,      0.0000,      0.0000,      0.0000,      0.0000,
#              0.0000,      0.0000,      0.0000,      0.0000,      0.0000,
#              0.0000,      0.0000,      0.0000,      0.0000,      0.0000,
#              0.0000,      0.0000,      0.0000,      0.0000,      0.0000,
#              0.0000,      0.0000,      0.0000,      0.0000,      0.0000,
#              0.0000,      0.0000,      0.0000,      0.0000,      0.0000,
#              0.0000,      0.0000,      0.0000,      0.0000,      0.0000,
#              0.0000,      0.0000,      0.0000,      0.0000,      0.0000,
#              0.0000,      0.0000,      0.0000,      0.0000,      0.0000,
#              0.0000,      0.0000,      0.0000,      0.0000,      0.0000])
