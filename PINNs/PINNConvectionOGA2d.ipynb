# %%
"""
2025/07/21 Using the PINN loss function to solve the Neumann boundary value problem 
-\lap u + u = f in \Omega,
u = 0 on \partial\Omega, 
\Omega = (0,1) x (0,1) 

Exact solution: u = \sin(\pi x1)\sin(\pi x2)
f = (\pi^2 + 1)\sin(\pi x1)\sin(\pi x2)
author: Xiaofeng Xu 

log: July 25th Make the code dimension dependent 
"""
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import time
import sys
import os 
from scipy.sparse import linalg
from pathlib import Path
if torch.cuda.is_available():  
    device = "cuda" 
else:  
    device = "cpu" 

torch.set_default_dtype(torch.float64)
pi = torch.tensor(np.pi)
ZERO = torch.tensor([0.]).to(device)

B = torch.tensor([1.,2.]).to(device)  # for the convection diffusion term 
C = -4   
class model(nn.Module):
    """ ReLU k shallow neural network
    Parameters: 
    input size: input dimension
    hidden_size1 : number of hidden layers 
    num_classes: output classes 
    k: degree of relu functions
    """
    def __init__(self, input_size, hidden_size1, num_classes,k = 1):
        super().__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, num_classes,bias = False)
        self.k = k 
    def forward(self, x):
        u1 = self.fc2(F.relu(self.fc1(x))**self.k)
        return u1
    def evaluate_derivative(self, x, i):
        if self.k == 1:
            ## ZERO = torch.tensor([0.]).to(device)
            u1 = self.fc2(torch.heaviside(self.fc1(x),ZERO) * self.fc1.weight.t()[i-1:i,:] )
        else:
            u1 = self.fc2(self.k*F.relu(self.fc1(x))**(self.k-1) *self.fc1.weight.t()[i-1:i,:] )  
        return u1
    def evaluate_2ndderivative(self,x,i,j): 
        if self.k == 2:
            u1 = self.fc2( 2 * torch.heaviside(self.fc1(x),ZERO) * (self.fc1.weight.t()[i-1:i,:])*self.fc1.weight.t()[j-1:j,:]) 
        else:
            u1 = self.fc2( self.k*(self.k-1)*F.relu(self.fc1(x))**(self.k-2) * (self.fc1.weight.t()[i-1:i,:])* (self.fc1.weight.t()[j-1:j,:]))  
        return u1
    
def plot_2D(f): 
    
    Nx = 400
    Ny = 400 
    xs = np.linspace(0, 1, Nx)
    ys = np.linspace(0, 1, Ny)
    x, y = np.meshgrid(xs, ys, indexing='xy')
    xy_comb = np.stack((x.flatten(),y.flatten())).T
    xy_comb = torch.tensor(xy_comb)
    z = f(xy_comb).reshape(Nx,Ny)
    z = z.detach().numpy()
    plt.figure(dpi=200)
    ax = plt.axes(projection='3d')
    ax.plot_surface(x , y , z )

    plt.show()

def plot_subdomains(my_model):
    x_coord =torch.linspace(0,1,200)
    wi = my_model.fc1.weight.data
    bi = my_model.fc1.bias.data 
    for i, bias in enumerate(bi):  
        if wi[i,1] !=0: 
            plt.plot(x_coord, - wi[i,0]/wi[i,1]*x_coord - bias/wi[i,1])
        else: 
            plt.plot(x_coord,  - bias/wi[i,0]*torch.ones(x_coord.size()))

    plt.xlim([0,1])
    plt.ylim([0,1])
    plt.legend()
    plt.show()
    return 0

# %%
def PiecewiseGQ1D_weights_points(x_l,x_r,Nx, order):
    """ Output the coeffients and weights for piecewise Gauss Quadrature 
    Parameters
    ----------
    x_l : float 
    left endpoint of an interval 
    x_r: float
    right endpoint of an interval 
    Nx: int 
    number of subintervals for integration
    order: int
    order of Gauss Quadrature 
    Returns
    -------
    vectorized quadrature weights and integration points
    """
    x,w = np.polynomial.legendre.leggauss(order)
    gx = torch.tensor(x).to(device)
    gx = gx.view(1,-1) # row vector 
    gw = torch.tensor(w).to(device)    
    gw = gw.view(-1,1) # Column vector 
    nodes = torch.linspace(x_l,x_r,Nx+1).view(-1,1).to(device) 
    coef1 = ((nodes[1:,:] - nodes[:-1,:])/2) # n by 1  
    coef2 = ((nodes[1:,:] + nodes[:-1,:])/2) # n by 1  
    coef2_expand = coef2.expand(-1,gx.size(1)) # Expand to n by p shape, -1: keep the first dimension n , expand the 2nd dim (columns)
    integration_points = coef1@gx + coef2_expand
    integration_points = integration_points.flatten().view(-1,1) # Make it a column vector
    gw_expand = torch.tile(gw,(Nx,1)) # rows: n copies of current tensor, columns: 1 copy, no change
    # Modify coef1 to be compatible with func_values
    coef1_expand = coef1.expand(coef1.size(0),gx.size(1))    
    coef1_expand = coef1_expand.flatten().view(-1,1)
    return coef1_expand.to(device) * gw_expand.to(device), integration_points.to(device)

def plot_solution_modified(r1,r2,model,x_test,u_true,name=None): 
    # Plot function: test results 
    u_model_cpu = model(x_test).cpu().detach()
    
    w = model.fc1.weight.data.squeeze()
    b = model.fc1.bias.data.squeeze()
    x_model_pt = (-b/w).view(-1,1)
    x_model_pt = x_model_pt[x_model_pt>=r1].reshape(-1,1)
    u_model_pt = model(x_model_pt).cpu().detach()
    plt.figure(dpi = 100)
    plt.plot(x_test.cpu(),u_model_cpu,'-.',label = "nn function")
    plt.plot(x_test.cpu(),u_true.cpu(),label = "true")
    # plt.plot(x_model_pt.cpu(),u_model_pt.cpu(),'.r')
    if name!=None: 
        plt.title(name)
    plt.legend()
    plt.show()

def plot_2D(f): 
    
    Nx = 400
    Ny = 400 
    xs = np.linspace(0, 1, Nx)
    ys = np.linspace(0, 1, Ny)
    x, y = np.meshgrid(xs, ys, indexing='xy')
    xy_comb = np.stack((x.flatten(),y.flatten())).T
    xy_comb = torch.tensor(xy_comb)
    z = f(xy_comb).reshape(Nx,Ny)
    z = z.detach().numpy()
    plt.figure(dpi=200)
    ax = plt.axes(projection='3d')
    ax.plot_surface(x , y , z )

    plt.show()

def PiecewiseGQ2D_weights_points(Nx, order): 
    """ A slight modification of PiecewiseGQ2D function that only needs the weights and integration points.
    Parameters
    ----------

    Nx: int 
        number of intervals along the dimension. No Ny, assume Nx = Ny
    order: int 
        order of the Gauss Quadrature

    Returns
    -------
    long_weights: torch.tensor
    integration_points: torch.tensor
    """

#     print("order: ",order )
    x, w = np.polynomial.legendre.leggauss(order)
    gauss_pts = np.array(np.meshgrid(x,x,indexing='ij')).reshape(2,-1).T
    weights =  (w*w[:,None]).ravel()

    gauss_pts =torch.tensor(gauss_pts)
    weights = torch.tensor(weights)

    h = 1/Nx # 100 intervals 
    long_weights =  torch.tile(weights,(Nx**2,1))
    long_weights = long_weights.reshape(-1,1)
    long_weights = long_weights * h**2 /4 

    integration_points = torch.tile(gauss_pts,(Nx**2,1))
    scale_factor = h/2 
    integration_points = scale_factor * integration_points

    index = np.arange(1,Nx+1)-0.5
    ordered_pairs = np.array(np.meshgrid(index,index,indexing='ij'))
    ordered_pairs = ordered_pairs.reshape(2,-1).T

    # print(ordered_pairs)
    # print()
    ordered_pairs = torch.tensor(ordered_pairs)
    # print(ordered_pairs.size())
    ordered_pairs = torch.tile(ordered_pairs, (1,order**2)) # number of GQ points
    # print(ordered_pairs)

    ordered_pairs =  ordered_pairs.reshape(-1,2)
    # print(ordered_pairs)
    translation = ordered_pairs*h 
    # print(translation)

    integration_points = integration_points + translation 
#     print(integration_points.size())
    # func_values = integrand2_torch(integration_points)
    return long_weights, integration_points

def Neumann_boundary_quadrature_points_weights(M,d):
    def generate_quadpts_on_boundary(gw_expand_bd, integration_points_bd,d):
        size_pts_bd = integration_points_bd.size(0) 
        gw_expand_bd_faces = torch.tile(gw_expand_bd,(2*d,1)) # 2d boundaries, 拉成长条

        integration_points_bd_faces = torch.zeros(2*d*integration_points_bd.size(0),d).to(device)
        for ind in range(d): 
            integration_points_bd_faces[2 *ind * size_pts_bd :(2 *ind +1) * size_pts_bd,ind:ind+1] = 0 
            integration_points_bd_faces[(2 *ind)*size_pts_bd :(2 * ind +1) * size_pts_bd,:ind] = integration_points_bd[:,:ind]
            integration_points_bd_faces[(2 *ind)*size_pts_bd :(2 * ind +1) * size_pts_bd,ind+1:] = integration_points_bd[:,ind:]

            integration_points_bd_faces[(2 *ind +1) * size_pts_bd:(2 *ind +2)*size_pts_bd,ind:ind+1] = 1
            integration_points_bd_faces[(2 *ind +1) * size_pts_bd:(2 *ind +2)*size_pts_bd,:ind] = integration_points_bd[:,:ind]        
            integration_points_bd_faces[(2 *ind +1) * size_pts_bd:(2 *ind +2)*size_pts_bd,ind+1:] = integration_points_bd[:,ind:]
        return gw_expand_bd_faces, integration_points_bd_faces
    
    if d == 1: 
        print('dim',d)
        gw_expand_bd_faces = torch.tensor([1.,1.]).view(-1,1).to(device)
        integration_points_bd_faces = torch.tensor([0.,1.]).view(-1,1).to(device) 
    elif d == 2: 
        print('dim',d)
        gw_expand_bd, integration_points_bd = PiecewiseGQ1D_weights_points(0,1,1024, order = 3) 
    elif d == 3: 
        gw_expand_bd, integration_points_bd = PiecewiseGQ2D_weights_points(200, order = 3) 
    elif d == 4: 
        gw_expand_bd, integration_points_bd = PiecewiseGQ3D_weights_points(25, order = 3) 
        print('dim',d)
    else: 
        gw_expand_bd, integration_points_bd = MonteCarlo_Sobol_dDim_weights_points(M ,d = d-1)
        print('dim >=5 ')
    if d != 1: 
        gw_expand_bd_faces, integration_points_bd_faces = generate_quadpts_on_boundary(gw_expand_bd, integration_points_bd,d)
    return gw_expand_bd_faces.to(device), integration_points_bd_faces.to(device) 


def show_convergence_order2_PINN(err_l2,err_h10,err_energy, exponent,dict_size, filename,write2file = False):
    
    if write2file:
        file_mode = "a" if os.path.exists(filename) else "w"
        f_write = open(filename, file_mode)
    
    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_l2[i] for i in neuron_nums ]
    err_list2 = [err_h10[i] for i in neuron_nums ] 
    err_list3 = [err_energy[i] for i in neuron_nums ]
    # f_write.write('M:{}, relu {} \n'.format(M,k))
    if write2file:
        f_write.write('dictionary size: {}\n'.format(dict_size))
        f_write.write("neuron num \t\t error \t\t order \t\t h10 error \t\t order  \t\t energy err \t\t order \n")
    print("neuron num \t\t error \t\t order")
    for i, item in enumerate(err_list):
        if i == 0: 
            # print(neuron_nums[i], end = "\t\t")s
            # print(item, end = "\t\t")
            
            # print("*")
            print("{} \t\t {:.3e} \t\t * \t\t {:.3e} \t\t * \t\t {:.3e} \t\t * \n".format(neuron_nums[i],item, err_list2[i],err_list3[i] ) )
            if write2file: 
                f_write.write("{} \t\t {} \t\t * \t\t {} \t\t *  \t\t {} \t\t * \n".format(neuron_nums[i],item, err_list2[i],err_list3[i] ))
        else: 
            print("{} \t\t {:.3e} \t\t {:.2f} \t\t {:.3e} \t\t {:.2f} \t\t {:.3e} \t\t {:.2f}  \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2), 
                                                                            err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2),
                                                                             err_list3[i] , np.log(err_list3[i-1]/err_list3[i])/np.log(2) ) )
            if write2file: 
                f_write.write("{} \t\t {} \t\t {} \t\t {} \t\t {} \t\t {} \t\t {} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2),err_list3[i] , np.log(err_list3[i-1]/err_list3[i])/np.log(2) ))
    if write2file:     
        f_write.write("\n")
        f_write.close()

def show_convergence_order_latex2(err_l2,err_h10,err_energy, exponent,k=1,d=1): 
    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_l2[i] for i in neuron_nums ]
    err_list2 = [err_h10[i] for i in neuron_nums ] 
    err_list3 = [err_energy[i] for i in neuron_nums ]
    l2_order = -1/2-(2*k + 1)/(2*d)
    h1_order =  -1/2-(2*(k-1)+ 1)/(2*d)
    print("neuron num  & \t $\|u-u_n \|_{{L^2}}$ & \t order $O(n^{{{:.2f}}})$  & \t $ | u -u_n |_{{H^1}}$ & \t order $O(n^{{{:.2f}}})$ \t loss \t order \\\ \hline \hline ".format(l2_order,h1_order))
    for i, item in enumerate(err_list):
        if i == 0: 
            print("{} \t\t & {:.3e} &\t\t * & \t \t {:.3e} & \t\t * & \t\t {:.3e} & \t\t * \\\ \hline  \n".format(neuron_nums[i],item, err_list2[i], err_list3[i] ) )   
        else: 
            print("{} \t\t &  {:.3e} &  \t\t {:.2f} &  \t\t {:.3e} &  \t\t {:.2f} &  \t\t {:.3e} &  \t\t {:.2f} \\\ \hline  \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2), err_list3[i], np.log(err_list3[i-1]/err_list3[i])/np.log(2) ) )

# %%
## 1. TODO modify this code to be compatiable with dimension 
def minimize_linear_layer_PINN_neumann(model,target,weights, integration_points,weights_bd, integration_points_bd, g_N, activation = 'relu', solver = 'direct'):
    """
    calls the following functions (dependency): 
    1. GQ_piecewise_2D
    input: the nn model containing parameter 
    1. define the loss function  
    2. take derivative to extract the linear system A
    3. call the cg solver in scipy to solve the linear system 
    output: sol. solution of Ax = b
    """
    dim = integration_points.size(1)  # dimension of the problem 
    start_time = time.time() 
    w = model.fc1.weight.data 
    b = model.fc1.bias.data 
    basis_value_bd_col = F.relu(integration_points_bd @ w.t()+ b)**(model.k) 
    weighted_basis_value_bd_col = basis_value_bd_col * weights_bd
    jac2 = weighted_basis_value_bd_col.t() @ (basis_value_bd_col)  # (u,v)_{\partial \Omega}

    # (Lu, Lv)_{\Omega} 
    basis_value_col = F.relu(integration_points @ w.t()+ b)**(model.k) 
    if activation == 'relu':

        if model.k == 1:
            assert False, "k must be at least 2"
        if model.k == 2:  
            for ii in range(dim): 
                if ii == 0: 
                    L_basis_col = C * basis_value_col  - 2 * torch.heaviside(integration_points @ w.t()+ b, ZERO) * (w.t()[ii:ii+1,:])**2 
                else: 
                    L_basis_col -= 2 * torch.heaviside(integration_points @ w.t()+ b, ZERO) * (w.t()[ii:ii+1,:])**2
                L_basis_col += B[ii] * model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * (w.t()[ii:ii+1,:]) 
            # basis_value_d11_col = 2 * torch.heaviside(integration_points @ w.t()+ b, ZERO) * (w.t()[0:1,:])**2 
            # L_basis_col = - basis_value_d11_col + basis_value_col 
        else: 
            for ii in range(dim): 
                if ii == 0: 
                    L_basis_col = C * basis_value_col  - model.k * (model.k -1) * F.relu(integration_points @ w.t()+ b)**(model.k-2) * (w.t()[ii:ii+1,:])**2 
                else: 
                    L_basis_col -= model.k * (model.k -1) * F.relu(integration_points @ w.t()+ b)**(model.k-2) * (w.t()[ii:ii+1,:])**2
                L_basis_col += B[ii] * model.k * F.relu(integration_points @ w.t()+ b)**(model.k-1) * (w.t()[ii:ii+1,:]) 
            # basis_value_d11_col = model.k * (model.k -1) * F.relu(integration_points @ w.t()+ b)**(model.k-2) * (w.t()[0:1,:])**2 
            # L_basis_col = - basis_value_d11_col + basis_value_col 
        weighted_L_basis_col = L_basis_col * weights 
    jac1 =  weighted_L_basis_col.t() @L_basis_col 
    jac = jac1 + jac2

    rhs1 = weighted_L_basis_col.t() @ (target(integration_points) )

    # Dirichlet boundary (g,v)_{\partial \Omega}, g = 0 
    rhs = rhs1  
    print("assembling the matrix time taken: ", time.time()-start_time) 
    start_time = time.time()    
    if solver == "cg": 
        sol, exit_code = linalg.cg(np.array(jac.detach().cpu()),np.array(rhs.detach().cpu()),tol=1e-12)
        sol = torch.tensor(sol).view(1,-1)
    elif solver == "direct": 
#         sol = np.linalg.inv( np.array(jac.detach().cpu()) )@np.array(rhs.detach().cpu())
        sol = (torch.linalg.solve( jac.detach(), rhs.detach())).view(1,-1)
    elif solver == "ls":
        sol = (torch.linalg.lstsq(jac.detach().cpu(),rhs.detach().cpu(),driver='gelsd').solution).view(1,-1)
        # sol = (torch.linalg.lstsq(jac.detach(),rhs.detach()).solution).view(1,-1) # gpu/cpu, driver = 'gels', cannot solve singular
    print("solving Ax = b time taken: ", time.time()-start_time)
    ## update the solution 
    return sol

# %%
def compute_gradient_error(u_exact_grad,my_model,M,batch_size_2,weights,integration_points):
    """
    Parameters
    ----------
    u_exact_grad: list or None
        a list that contains ways of evaluating partial derivatives that gives the gradient  
    """
    err_h10 = 0 
     # initial gradient error 
    if u_exact_grad != None and my_model!=None:
        u_grad = u_exact_grad() 
        for ii, grad_i in enumerate(u_grad): 
            for jj in range(0,M,batch_size_2): 
                end_index = jj + batch_size_2 
                my_model_dxi = my_model.evaluate_derivative(integration_points[jj:end_index,:],ii+1).detach() 
                err_h10 += torch.sum((grad_i(integration_points[jj:end_index,:]) - my_model_dxi)**2 * weights[jj:end_index,:])
    elif u_exact_grad != None and my_model==None:
        u_grad = u_exact_grad() 
        for grad_i in u_grad: 
            for jj in range(0,M,batch_size_2): 
                end_index = jj + batch_size_2 
                err_h10 += torch.sum((grad_i(integration_points[jj:end_index,:]))**2 * weights[jj:end_index,:])
    return err_h10**0.5

# %%
def generate_relu_dict4plusD_sphere(dim, s,N0): 
    samples = torch.randn(s*N0,dim +1) 
    samples = samples/samples.norm(dim=1,keepdim=True)  
    Wb = samples 
    return Wb 

def generate_relu_dict2D(N_list):
    N1 = N_list[0] 
    N2 = N_list[1]
    
    theta = np.linspace(0, 2*pi, N1, endpoint= False).reshape(N1,1)
    W1 = np.cos(theta)
    W2 = np.sin(theta)
    W = np.concatenate((W1,W2),1) # N1 x 2
    b = np.linspace(-1.42, 1.42, N2,endpoint=False).reshape(N2,1)
    
    index1 = np.arange(N1)
    index2 = np.arange(N2)
    ordered_pairs = np.array(np.meshgrid(index1,index2,indexing='ij'))

    ordered_pairs = ordered_pairs.reshape(2,-1).T
    W = W[ordered_pairs[:,0],:]
    b = b[ordered_pairs[:,1],:]
    Wb = np.concatenate((W,b),1) # N1 x 3 
    Wb_tensor = torch.from_numpy(Wb) 
    return Wb_tensor


#2 TODO Make this compatible with dimension  
def select_greedy_neuron_ind(relu_dict_parameters,my_model,target,weights, integration_points,g_N,weights_bd, integration_points_bd,k): 
    dim = integration_points.size(1) 
    residual_values = - target(integration_points)
    if my_model!= None:
        residual_values +=  C * my_model(integration_points).detach() 
        for ii in range(dim):
             residual_values -= my_model.evaluate_2ndderivative(integration_points,ii+1,ii+1).detach() 
             residual_values += B[ii] * my_model.evaluate_derivative(integration_points,ii+1).detach() 
            
    weight_residual_values = residual_values*weights # 1. weights * ( Lu - f ) 

    basis_values = (F.relu(integration_points @ (relu_dict_parameters[:,0:dim].T) - relu_dict_parameters[:,dim])**k) # uses broadcasting
    # output1 = torch.matmul(basis_values,weight_func_values) # 

    # ============TODO 
    # L (basis values)
    if k == 1:
        assert k>=2, "k must be at least 2"
    elif k == 2:  
        for ii in range(dim): 
            if ii == 0: 
                Lg = C * basis_values - 2 * torch.heaviside(integration_points @ (relu_dict_parameters[:,0:dim].T) - relu_dict_parameters[:,dim], ZERO) * (relu_dict_parameters.t()[ii:ii+1,:])**2 
            else: 
                Lg -= 2 * torch.heaviside(integration_points @ (relu_dict_parameters[:,0:dim].T) - relu_dict_parameters[:,dim], ZERO) * (relu_dict_parameters.t()[ii:ii+1,:])**2 
            Lg += B[ii] * k * F.relu(integration_points @ (relu_dict_parameters[:,0:dim].T) - relu_dict_parameters[:,dim])**(k-1) * (relu_dict_parameters.t()[ii:ii+1,:])
        # dbasis_values_d11 =  2 * torch.heaviside(integration_points @ (relu_dict_parameters[:,0:dim].T) - relu_dict_parameters[:,dim], ZERO) * (relu_dict_parameters.t()[0:1,:])**2 
        # Lg = - dbasis_values_d11 + basis_values
    else:  
        for ii in range(dim): 
            if ii == 0: 
                Lg = C *  basis_values - k * (k-1) * F.relu(integration_points @ (relu_dict_parameters[:,0:dim].T) - relu_dict_parameters[:,dim])**(k-2) * (relu_dict_parameters.t()[ii:ii+1,:])**2
            else: 
                Lg -= k * (k-1) * F.relu(integration_points @ (relu_dict_parameters[:,0:dim].T) - relu_dict_parameters[:,dim])**(k-2) * (relu_dict_parameters.t()[ii:ii+1,:])**2
            Lg += B[ii] * k * F.relu(integration_points @ (relu_dict_parameters[:,0:dim].T) - relu_dict_parameters[:,dim])**(k-1) * (relu_dict_parameters.t()[ii:ii+1,:])
        # dbasis_values_d11 = k *(k-1) * F.relu(integration_points @ (relu_dict_parameters[:,0:dim].T) - relu_dict_parameters[:,1])**(k-2) * (relu_dict_parameters.t()[0:1,:])**2  
        # Lg = - dbasis_values_d11 + basis_values 
    output2 = torch.matmul(Lg.t(), weight_residual_values) 
    #============TODO===========

    # Dirichlet boundary condition # 3. (u^{n-1},g)_{\partial \Omega}
    basis_values_bd_col = (F.relu(integration_points_bd  @ relu_dict_parameters[:,0:dim].T - relu_dict_parameters[:,dim])**k) 
    weighted_basis_value_col_bd = basis_values_bd_col * weights_bd
    # dudn = g_N(integration_points_bd)* (torch.tensor([-1,1]).view(-1,1)).to(device):

    if my_model!= None:
        u_n_1 = my_model(integration_points_bd).detach()  
        output3 =  weighted_basis_value_col_bd.t() @ u_n_1 
        output = torch.abs(output2 + output3)
    else:
        output = torch.abs(output2)
    neuron_index = torch.argmax(output.flatten())
    
    return neuron_index 

def OGANeumannPINNReLU2D(my_model,target,u_exact,u_exact_grad,g_N, N,num_epochs,plot_freq = 10,Nx = 1024,order =5, k = 1,rand_deter = 'deter', solver = 'direct'): 
    """ Orthogonal greedy algorithm to solve a 1D Neumann problem 1D ReLU dictionary over [0,1]
    """
    dim = 2 
    integration_weights, integration_points = PiecewiseGQ2D_weights_points(Nx = Nx,order =order)
    weights_bd, integration_points_bd = Neumann_boundary_quadrature_points_weights(M = 2,d= dim) 

    err = torch.zeros(num_epochs+1)
    err_h10 = torch.zeros(num_epochs+1) 
    err_energy = torch.zeros(num_epochs+1) # added 
    if my_model == None: 
        func_values = u_exact(integration_points)
        num_neuron = 0
        list_a = []
        list_b = []
        list_w = []
    else: 
        func_values = u_exact(integration_points) - my_model(integration_points).detach()
        bias = my_model.fc1.bias.detach().data
        integration_weights = my_model.fc1.weight.detach().data
        num_neuron = int(bias.size(0))
        list_a = list(my_model.fc2.weight.detach().data)
        list_b = list(bias)
        list_w = list(integration_weights)
        
    func_values_sqrd = func_values*func_values
    err[0]= torch.sum(func_values_sqrd*integration_weights)**0.5
    if my_model!= None:
        # err_h10[0] = torch.sum( (my_model.evaluate_derivative(integration_points,1).detach() - du_exact(integration_points) )**2*integration_weights)**0.5
        err_h10[0] = compute_gradient_error(u_exact_grad,my_model,integration_points.size(0),integration_points.size(0),integration_weights,integration_points)
        ## TODO 
        Lu = C * my_model(integration_points).detach()  
        for ii in range(dim): 
            Lu -= my_model.evaluate_2ndderivative(integration_points,ii+1,ii+1).detach()
            Lu += B[ii] * my_model.evaluate_derivative(integration_points,ii+1).detach() 
        energy  = 0.5 * integration_weights.t() @ ( Lu - target(integration_points) ) **2  + 0.5 * weights_bd.t() @ my_model(integration_points_bd).detach()**2  # added  
        err_energy[0] = energy  
    else: 
        # todo 
        err_h10[0] = compute_gradient_error(u_exact_grad,my_model,integration_points.size(0),integration_points.size(0),integration_weights,integration_points)
        ## TODO  
        energy  = 0.5 * integration_weights.t() @ target(integration_points)**2  # add boundary energy 1/2 \int |u-g|^2 ds  # added  
        err_energy[0] = energy 

    start_time = time.time()
    
    solver = "direct"
    print("using linear solver: ",solver)
    # if rand_deter == 'deter': 
    #     relu_dict_parameters = relu_dict(0,1,N).to(device) 
    for i in range(num_epochs): 
        print('epoch: ',i+1)
        if rand_deter == 'rand': 
            relu_dict_parameters = generate_relu_dict4plusD_sphere(dim, 1, N) # 100 samples, 2D 
        # start_argmax = time.time() 
        neuron_index = select_greedy_neuron_ind(relu_dict_parameters,my_model,target,integration_weights, integration_points,g_N,weights_bd, integration_points_bd, k) 
        # print("argmax time: ", time.time() - start_argmax) 
        # print("selected neuron index: ",neuron_index,relu_dict_parameters[neuron_index,0],-relu_dict_parameters[neuron_index,1] ) 
        list_w.append(relu_dict_parameters[neuron_index,0:dim])
        list_b.append(-relu_dict_parameters[neuron_index,dim]) # different sign convention 
        num_neuron += 1
        my_model = model(dim,num_neuron,1,k).to(device)
        w_tensor = torch.stack(list_w, 0)  
        my_model.fc1.weight.data[:,0:dim] = w_tensor[:,:]
        my_model.fc1.bias.data[:] = torch.tensor(list_b)[:]

        sol = minimize_linear_layer_PINN_neumann(my_model,target,integration_weights, integration_points,weights_bd, integration_points_bd,g_N,activation ='relu', solver = solver)
        sol = sol.flatten() 
        my_model.fc2.weight.data[0,:] = sol[:]

        if (i+1)%plot_freq == 0: 
            ## TODO DONE 
            plot_2D(my_model.cpu())
            
        func_values = u_exact(integration_points) - my_model(integration_points).detach()
        func_values_sqrd = func_values*func_values
        err[i+1]= torch.sum(func_values_sqrd*integration_weights)**0.5
        err_h10[i+1] = compute_gradient_error(u_exact_grad,my_model,integration_points.size(0),integration_points.size(0),integration_weights,integration_points)
        ## TODO 
        Lu = C *  my_model(integration_points).detach()  
        for ii in range(dim): 
            Lu -= my_model.evaluate_2ndderivative(integration_points,ii+1,ii+1).detach()
            Lu += B[ii] * my_model.evaluate_derivative(integration_points,ii+1).detach()
        energy  = 0.5 * integration_weights.t() @ ( Lu - target(integration_points) ) **2  + 0.5 * weights_bd.t() @ my_model(integration_points_bd).detach()**2  # added  
        err_energy[i+1] = energy  
    print("time taken: ",time.time() - start_time)
    return err, err_h10,err_energy, my_model

# %% [markdown]
#  ## Main

# %%
m1 = 2
m2 = 2  
def u_exact(x):
    return torch.sin(m1 * pi*x[:,0:1])*torch.sin(m2 * pi*x[:,1:2]) 

def u_exact_grad(): 
    def grad_1(x):
        return  m1*pi* torch.cos(m1*pi*x[:,0:1])*torch.sin( m2*pi*x[:,1:2]) 
    def grad_2(x):
        return  m2*pi* torch.sin(m1*pi*x[:,0:1])*torch.cos( m2*pi*x[:,1:2]) 

    u_grad=[grad_1, grad_2] 

    return u_grad

def rhs(x):
    u_x = u_exact_grad() 
    z = ( (m1*pi)**2 + (m2*pi)**2 + C)*torch.sin(m1 * pi*x[:,0:1])*torch.sin(m2  * pi*x[:,1:2] )
    convection_term = B[0] * u_x[0](x) + B[1] * u_x[1](x) 
    return z + convection_term

dim = 2  
function_name = "sinpix2d" 
filename_write = "data/2DOGA-{}-order.txt".format(function_name)
Nx = 50  
order = 2  
f_write = open(filename_write, "a")
f_write.write("Integration points: Nx {}, order {} \n".format(Nx,order))
f_write.close() 

save = False 
write2file = True
rand_deter = 'rand'
for N in [2**10]: # 2**12,2**14
    f_write = open(filename_write, "a")
    my_model = None 
    exponent = 10
    num_epochs = 2**exponent  
    plot_freq = num_epochs 
    relu_k = 3     
    err_QMC2, err_h10, err_energy, my_model = OGANeumannPINNReLU2D(None,rhs,u_exact,u_exact_grad,None, N,num_epochs,plot_freq, Nx, order, k =relu_k, rand_deter = rand_deter,solver = "direct")

    if save: 
        folder = 'data/'
        filename = folder + 'err_NeumannOGA_2D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        torch.save(err_QMC2,filename) 
        folder = 'data/'
        filename = folder + 'model_NeumannOGA_2D_{}_neuron_{}_N_{}_deterministic.pt'.format(function_name,num_epochs,N)
        torch.save(my_model,filename)
    show_convergence_order2_PINN(err_QMC2,err_h10,err_energy, exponent,2*N,filename_write,write2file = write2file)
# Out:
# dim 2
# using linear solver:  direct
# epoch:  1
# assembling the matrix time taken:  0.0007810592651367188
# solving Ax = b time taken:  0.0036368370056152344
# epoch:  2
# assembling the matrix time taken:  0.0016438961029052734
# solving Ax = b time taken:  0.0011119842529296875
# epoch:  3
# assembling the matrix time taken:  0.001978158950805664
# solving Ax = b time taken:  0.000164031982421875
# epoch:  4
# assembling the matrix time taken:  0.0034270286560058594
# solving Ax = b time taken:  8.225440979003906e-05
# epoch:  5
# assembling the matrix time taken:  0.0035157203674316406
# solving Ax = b time taken:  0.0001590251922607422
# epoch:  6
# assembling the matrix time taken:  0.0031490325927734375
# solving Ax = b time taken:  0.00013589859008789062
# epoch:  7
# assembling the matrix time taken:  0.004114389419555664
# solving Ax = b time taken:  8.082389831542969e-05
# epoch:  8
# assembling the matrix time taken:  0.003186941146850586
# solving Ax = b time taken:  0.00018787384033203125
# epoch:  9
# assembling the matrix time taken:  0.0040471553802490234
# solving Ax = b time taken:  8.0108642578125e-05
# epoch:  10
# assembling the matrix time taken:  0.004579067230224609
# solving Ax = b time taken:  0.00019788742065429688
# epoch:  11
# assembling the matrix time taken:  0.004060268402099609
# solving Ax = b time taken:  9.083747863769531e-05
# epoch:  12
# assembling the matrix time taken:  0.004845142364501953
# solving Ax = b time taken:  0.00010204315185546875
# epoch:  13
# assembling the matrix time taken:  0.0043659210205078125
# solving Ax = b time taken:  7.987022399902344e-05
# epoch:  14
# assembling the matrix time taken:  0.0045490264892578125
# solving Ax = b time taken:  0.00015497207641601562
# epoch:  15
# assembling the matrix time taken:  0.004853248596191406
# solving Ax = b time taken:  8.416175842285156e-05
# epoch:  16
# assembling the matrix time taken:  0.00415802001953125
# solving Ax = b time taken:  0.00020194053649902344
# epoch:  17
# assembling the matrix time taken:  0.00521397590637207
# solving Ax = b time taken:  8.082389831542969e-05
# epoch:  18
# assembling the matrix time taken:  0.005547046661376953
# solving Ax = b time taken:  0.00016498565673828125
# epoch:  19
# assembling the matrix time taken:  0.005652904510498047
# solving Ax = b time taken:  8.225440979003906e-05
# epoch:  20
# assembling the matrix time taken:  0.007091045379638672
# solving Ax = b time taken:  0.0002110004425048828
# epoch:  21
# assembling the matrix time taken:  0.007353782653808594
# solving Ax = b time taken:  8.797645568847656e-05
# epoch:  22
# assembling the matrix time taken:  0.0077669620513916016
# solving Ax = b time taken:  0.0002238750457763672
# epoch:  23
# assembling the matrix time taken:  0.00869131088256836
# solving Ax = b time taken:  0.00011301040649414062
# epoch:  24
# assembling the matrix time taken:  0.008050918579101562
# solving Ax = b time taken:  0.00016117095947265625
# epoch:  25
# assembling the matrix time taken:  0.008872032165527344
# solving Ax = b time taken:  8.606910705566406e-05
# epoch:  26
# assembling the matrix time taken:  0.008938074111938477
# solving Ax = b time taken:  0.00015997886657714844
# epoch:  27
# assembling the matrix time taken:  0.008582115173339844
# solving Ax = b time taken:  8.702278137207031e-05
# epoch:  28
# assembling the matrix time taken:  0.008872032165527344
# solving Ax = b time taken:  0.0002472400665283203
# epoch:  29
# assembling the matrix time taken:  0.008575201034545898
# solving Ax = b time taken:  8.511543273925781e-05
# epoch:  30
# assembling the matrix time taken:  0.008493661880493164
# solving Ax = b time taken:  0.00015115737915039062
# epoch:  31
# assembling the matrix time taken:  0.009684085845947266
# solving Ax = b time taken:  9.179115295410156e-05
# epoch:  32
# assembling the matrix time taken:  0.009407997131347656
# solving Ax = b time taken:  0.0018987655639648438
# epoch:  33
# assembling the matrix time taken:  0.00947117805480957
# solving Ax = b time taken:  0.0031397342681884766
# epoch:  34
# assembling the matrix time taken:  0.009994983673095703
# solving Ax = b time taken:  9.083747863769531e-05
# epoch:  35
# assembling the matrix time taken:  0.009027957916259766
# solving Ax = b time taken:  9.202957153320312e-05
# epoch:  36
# assembling the matrix time taken:  0.010078907012939453
# solving Ax = b time taken:  0.00025081634521484375
# epoch:  37
# assembling the matrix time taken:  0.012243032455444336
# solving Ax = b time taken:  9.822845458984375e-05
# epoch:  38
# assembling the matrix time taken:  0.010987043380737305
# solving Ax = b time taken:  9.799003601074219e-05
# epoch:  39
# assembling the matrix time taken:  0.01183009147644043
# solving Ax = b time taken:  0.00016689300537109375
# epoch:  40
# assembling the matrix time taken:  0.011473894119262695
# solving Ax = b time taken:  0.0003101825714111328
# epoch:  41
# assembling the matrix time taken:  0.019444942474365234
# solving Ax = b time taken:  0.00015807151794433594
# epoch:  42
# assembling the matrix time taken:  0.013849020004272461
# solving Ax = b time taken:  0.00017309188842773438
# epoch:  43
# assembling the matrix time taken:  0.012589216232299805
# solving Ax = b time taken:  0.0002219676971435547
# epoch:  44
# assembling the matrix time taken:  0.01421499252319336
# solving Ax = b time taken:  0.0001068115234375
# epoch:  45
# assembling the matrix time taken:  0.01297307014465332
# solving Ax = b time taken:  0.0001049041748046875
# epoch:  46
# assembling the matrix time taken:  0.012415885925292969
# solving Ax = b time taken:  0.00025010108947753906
# epoch:  47
# assembling the matrix time taken:  0.013916015625
# solving Ax = b time taken:  9.298324584960938e-05
# epoch:  48
# assembling the matrix time taken:  0.012182950973510742
# solving Ax = b time taken:  9.393692016601562e-05
# epoch:  49
# assembling the matrix time taken:  0.012131929397583008
# solving Ax = b time taken:  0.0001621246337890625
# epoch:  50
# assembling the matrix time taken:  0.013428926467895508
# solving Ax = b time taken:  0.00015497207641601562
# epoch:  51
# assembling the matrix time taken:  0.014261960983276367
# solving Ax = b time taken:  0.00010013580322265625
# epoch:  52
# assembling the matrix time taken:  0.012964963912963867
# solving Ax = b time taken:  0.00011086463928222656
# epoch:  53
# assembling the matrix time taken:  0.013734102249145508
# solving Ax = b time taken:  0.00025081634521484375
# epoch:  54
# assembling the matrix time taken:  0.014506816864013672
# solving Ax = b time taken:  0.00012111663818359375
# epoch:  55
# assembling the matrix time taken:  0.015104055404663086
# solving Ax = b time taken:  0.00010704994201660156
# epoch:  56
# assembling the matrix time taken:  0.014141321182250977
# solving Ax = b time taken:  9.822845458984375e-05
# epoch:  57
# assembling the matrix time taken:  0.01446390151977539
# solving Ax = b time taken:  0.00010275840759277344
# epoch:  58
# assembling the matrix time taken:  0.014418840408325195
# solving Ax = b time taken:  0.00010395050048828125
# epoch:  59
# assembling the matrix time taken:  0.015352964401245117
# solving Ax = b time taken:  0.00015282630920410156
# epoch:  60
# assembling the matrix time taken:  0.015105962753295898
# solving Ax = b time taken:  0.00023102760314941406
# epoch:  61
# assembling the matrix time taken:  0.01671600341796875
# solving Ax = b time taken:  0.0001399517059326172
# epoch:  62
# assembling the matrix time taken:  0.01668691635131836
# solving Ax = b time taken:  0.00025010108947753906
# epoch:  63
# assembling the matrix time taken:  0.01865100860595703
# solving Ax = b time taken:  0.00014591217041015625
# epoch:  64
# assembling the matrix time taken:  0.017877817153930664
# solving Ax = b time taken:  0.0008881092071533203
# epoch:  65
# assembling the matrix time taken:  0.018584012985229492
# solving Ax = b time taken:  0.004415035247802734
# epoch:  66
# assembling the matrix time taken:  0.017673969268798828
# solving Ax = b time taken:  0.000186920166015625
# epoch:  67
# assembling the matrix time taken:  0.01723003387451172
# solving Ax = b time taken:  0.0005471706390380859
# epoch:  68
# assembling the matrix time taken:  0.021663188934326172
# solving Ax = b time taken:  0.000225067138671875
# epoch:  69
# assembling the matrix time taken:  0.02095198631286621
# solving Ax = b time taken:  0.00016689300537109375
# epoch:  70
# assembling the matrix time taken:  0.018695354461669922
# solving Ax = b time taken:  0.00027489662170410156
# epoch:  71
# assembling the matrix time taken:  0.038874149322509766
# solving Ax = b time taken:  0.00031495094299316406
# epoch:  72
# assembling the matrix time taken:  0.020192861557006836
# solving Ax = b time taken:  0.00017404556274414062
# epoch:  73
# assembling the matrix time taken:  0.019635915756225586
# solving Ax = b time taken:  0.0003421306610107422
# epoch:  74
# assembling the matrix time taken:  0.01909780502319336
# solving Ax = b time taken:  0.00015616416931152344
# epoch:  75
# assembling the matrix time taken:  0.02040386199951172
# solving Ax = b time taken:  0.0002970695495605469
# epoch:  76
# assembling the matrix time taken:  0.020257949829101562
# solving Ax = b time taken:  0.00017786026000976562
# epoch:  77
# assembling the matrix time taken:  0.028519153594970703
# solving Ax = b time taken:  0.00027489662170410156
# epoch:  78
# assembling the matrix time taken:  0.02176499366760254
# solving Ax = b time taken:  0.0005750656127929688
# epoch:  79
# assembling the matrix time taken:  0.0236051082611084
# solving Ax = b time taken:  0.0002281665802001953
# epoch:  80
# assembling the matrix time taken:  0.026077985763549805
# solving Ax = b time taken:  0.0005869865417480469
# epoch:  81
# assembling the matrix time taken:  0.023029565811157227
# solving Ax = b time taken:  0.0002460479736328125
# epoch:  82
# assembling the matrix time taken:  0.023411273956298828
# solving Ax = b time taken:  0.00028014183044433594
# epoch:  83
# assembling the matrix time taken:  0.022627830505371094
# solving Ax = b time taken:  0.0004868507385253906
# epoch:  84
# assembling the matrix time taken:  0.02286076545715332
# solving Ax = b time taken:  0.00016689300537109375
# epoch:  85
# assembling the matrix time taken:  0.024604082107543945
# solving Ax = b time taken:  0.00016689300537109375
# epoch:  86
# assembling the matrix time taken:  0.024950027465820312
# solving Ax = b time taken:  0.00016689300537109375
# epoch:  87
# assembling the matrix time taken:  0.025472164154052734
# solving Ax = b time taken:  0.0002810955047607422
# epoch:  88
# assembling the matrix time taken:  0.023898839950561523
# solving Ax = b time taken:  0.00047278404235839844
# epoch:  89
# assembling the matrix time taken:  0.02620410919189453
# solving Ax = b time taken:  0.0005650520324707031
# epoch:  90
# assembling the matrix time taken:  0.028378963470458984
# solving Ax = b time taken:  0.0001990795135498047
# epoch:  91
# assembling the matrix time taken:  0.0256650447845459
# solving Ax = b time taken:  0.00026488304138183594
# epoch:  92
# assembling the matrix time taken:  0.02815985679626465
# solving Ax = b time taken:  0.00017404556274414062
# epoch:  93
# assembling the matrix time taken:  0.026294231414794922
# solving Ax = b time taken:  0.0007767677307128906
# epoch:  94
# assembling the matrix time taken:  0.026639223098754883
# solving Ax = b time taken:  0.0001499652862548828
# epoch:  95
# assembling the matrix time taken:  0.027329206466674805
# solving Ax = b time taken:  0.0001556873321533203
# epoch:  96
# assembling the matrix time taken:  0.024587154388427734
# solving Ax = b time taken:  0.00017905235290527344
# epoch:  97
# assembling the matrix time taken:  0.02451491355895996
# solving Ax = b time taken:  0.0002751350402832031
# epoch:  98
# assembling the matrix time taken:  0.027308225631713867
# solving Ax = b time taken:  0.00028705596923828125
# epoch:  99
# assembling the matrix time taken:  0.02766704559326172
# solving Ax = b time taken:  0.0001678466796875
# epoch:  100
# assembling the matrix time taken:  0.028123855590820312
# solving Ax = b time taken:  0.00017213821411132812
# epoch:  101
# assembling the matrix time taken:  0.027313709259033203
# solving Ax = b time taken:  0.00017499923706054688
# epoch:  102
# assembling the matrix time taken:  0.027701377868652344
# solving Ax = b time taken:  0.00019693374633789062
# epoch:  103
# assembling the matrix time taken:  0.029296159744262695
# solving Ax = b time taken:  0.0006341934204101562
# epoch:  104
# assembling the matrix time taken:  0.02705216407775879
# solving Ax = b time taken:  0.0001609325408935547
# epoch:  105
# assembling the matrix time taken:  0.02272486686706543
# solving Ax = b time taken:  0.0002989768981933594
# epoch:  106
# assembling the matrix time taken:  0.026571035385131836
# solving Ax = b time taken:  0.00017309188842773438
# epoch:  107
# assembling the matrix time taken:  0.02823495864868164
# solving Ax = b time taken:  0.00017499923706054688
# epoch:  108
# assembling the matrix time taken:  0.018616914749145508
# solving Ax = b time taken:  0.00017905235290527344
# epoch:  109
# assembling the matrix time taken:  0.02964305877685547
# solving Ax = b time taken:  0.00022602081298828125
# epoch:  110
# assembling the matrix time taken:  0.027932167053222656
# solving Ax = b time taken:  0.00019812583923339844
# epoch:  111
# assembling the matrix time taken:  0.020512104034423828
# solving Ax = b time taken:  0.00018215179443359375
# epoch:  112
# assembling the matrix time taken:  0.026376962661743164
# solving Ax = b time taken:  0.00032711029052734375
# epoch:  113
# assembling the matrix time taken:  0.027769088745117188
# solving Ax = b time taken:  0.0006420612335205078
# epoch:  114
# assembling the matrix time taken:  0.020839214324951172
# solving Ax = b time taken:  0.00017499923706054688
# epoch:  115
# assembling the matrix time taken:  0.028429269790649414
# solving Ax = b time taken:  0.00043487548828125
# epoch:  116
# assembling the matrix time taken:  0.028596878051757812
# solving Ax = b time taken:  0.0003101825714111328
# epoch:  117
# assembling the matrix time taken:  0.021123170852661133
# solving Ax = b time taken:  0.0005521774291992188
# epoch:  118
# assembling the matrix time taken:  0.02914881706237793
# solving Ax = b time taken:  0.0005950927734375
# epoch:  119
# assembling the matrix time taken:  0.02985095977783203
# solving Ax = b time taken:  0.00020503997802734375
# epoch:  120
# assembling the matrix time taken:  0.01947307586669922
# solving Ax = b time taken:  0.0005879402160644531
# epoch:  121
# assembling the matrix time taken:  0.029673099517822266
# solving Ax = b time taken:  0.0007719993591308594
# epoch:  122
# assembling the matrix time taken:  0.029640913009643555
# solving Ax = b time taken:  0.00048470497131347656
# epoch:  123
# assembling the matrix time taken:  0.02166891098022461
# solving Ax = b time taken:  0.0006201267242431641
# epoch:  124
# assembling the matrix time taken:  0.030357837677001953
# solving Ax = b time taken:  0.0007200241088867188
# epoch:  125
# assembling the matrix time taken:  0.03177595138549805
# solving Ax = b time taken:  0.00019407272338867188
# epoch:  126
# assembling the matrix time taken:  0.02276015281677246
# solving Ax = b time taken:  0.0004150867462158203
# epoch:  127
# assembling the matrix time taken:  0.0313718318939209
# solving Ax = b time taken:  0.0007991790771484375
# epoch:  128
# assembling the matrix time taken:  0.027653932571411133
# solving Ax = b time taken:  0.0006432533264160156
# epoch:  129
# assembling the matrix time taken:  0.02194523811340332
# solving Ax = b time taken:  0.0007920265197753906
# epoch:  130
# assembling the matrix time taken:  0.023752927780151367
# solving Ax = b time taken:  0.0003230571746826172
# epoch:  131
# assembling the matrix time taken:  0.02357006072998047
# solving Ax = b time taken:  0.00020194053649902344
# epoch:  132
# assembling the matrix time taken:  0.022903919219970703
# solving Ax = b time taken:  0.00033593177795410156
# epoch:  133
# assembling the matrix time taken:  0.022951126098632812
# solving Ax = b time taken:  0.0001971721649169922
# epoch:  134
# assembling the matrix time taken:  0.022783279418945312
# solving Ax = b time taken:  0.00038909912109375
# epoch:  135
# assembling the matrix time taken:  0.02466297149658203
# solving Ax = b time taken:  0.0002090930938720703
# epoch:  136
# assembling the matrix time taken:  0.021955013275146484
# solving Ax = b time taken:  0.00021982192993164062
# epoch:  137
# assembling the matrix time taken:  0.024609088897705078
# solving Ax = b time taken:  0.00020503997802734375
# epoch:  138
# assembling the matrix time taken:  0.02534198760986328
# solving Ax = b time taken:  0.00020813941955566406
# epoch:  139
# assembling the matrix time taken:  0.025903940200805664
# solving Ax = b time taken:  0.0003788471221923828
# epoch:  140
# assembling the matrix time taken:  0.02549004554748535
# solving Ax = b time taken:  0.0001850128173828125
# epoch:  141
# assembling the matrix time taken:  0.025058984756469727
# solving Ax = b time taken:  0.00061798095703125
# epoch:  142
# assembling the matrix time taken:  0.024780988693237305
# solving Ax = b time taken:  0.00020003318786621094
# epoch:  143
# assembling the matrix time taken:  0.02413177490234375
# solving Ax = b time taken:  0.0002319812774658203
# epoch:  144
# assembling the matrix time taken:  0.030831098556518555
# solving Ax = b time taken:  0.00034499168395996094
# epoch:  145
# assembling the matrix time taken:  0.03398609161376953
# solving Ax = b time taken:  0.0002231597900390625
# epoch:  146
# assembling the matrix time taken:  0.022542715072631836
# solving Ax = b time taken:  0.0003521442413330078
# epoch:  147
# assembling the matrix time taken:  0.025721073150634766
# solving Ax = b time taken:  0.00022482872009277344
# epoch:  148
# assembling the matrix time taken:  0.02572798728942871
# solving Ax = b time taken:  0.00022792816162109375
# epoch:  149
# assembling the matrix time taken:  0.03393411636352539
# solving Ax = b time taken:  0.0003809928894042969
# epoch:  150
# assembling the matrix time taken:  0.033245086669921875
# solving Ax = b time taken:  0.00022482872009277344
# epoch:  151
# assembling the matrix time taken:  0.03407001495361328
# solving Ax = b time taken:  0.0003819465637207031
# epoch:  152
# assembling the matrix time taken:  0.03475809097290039
# solving Ax = b time taken:  0.00019598007202148438
# epoch:  153
# assembling the matrix time taken:  0.03788590431213379
# solving Ax = b time taken:  0.000225067138671875
# epoch:  154
# assembling the matrix time taken:  0.03896522521972656
# solving Ax = b time taken:  0.0002219676971435547
# epoch:  155
# assembling the matrix time taken:  0.036216020584106445
# solving Ax = b time taken:  0.0003628730773925781
# epoch:  156
# assembling the matrix time taken:  0.03540778160095215
# solving Ax = b time taken:  0.0003478527069091797
# epoch:  157
# assembling the matrix time taken:  0.036087989807128906
# solving Ax = b time taken:  0.00044798851013183594
# epoch:  158
# assembling the matrix time taken:  0.03662610054016113
# solving Ax = b time taken:  0.00023698806762695312
# epoch:  159
# assembling the matrix time taken:  0.039897918701171875
# solving Ax = b time taken:  0.0002620220184326172
# epoch:  160
# assembling the matrix time taken:  0.03245902061462402
# solving Ax = b time taken:  0.00021123886108398438
# epoch:  161
# assembling the matrix time taken:  0.02742290496826172
# solving Ax = b time taken:  0.0002598762512207031
# epoch:  162
# assembling the matrix time taken:  0.034806013107299805
# solving Ax = b time taken:  0.0003509521484375
# epoch:  163
# assembling the matrix time taken:  0.03702235221862793
# solving Ax = b time taken:  0.0008661746978759766
# epoch:  164
# assembling the matrix time taken:  0.0234529972076416
# solving Ax = b time taken:  0.0003979206085205078
# epoch:  165
# assembling the matrix time taken:  0.04085421562194824
# solving Ax = b time taken:  0.0004069805145263672
# epoch:  166
# assembling the matrix time taken:  0.03785276412963867
# solving Ax = b time taken:  0.0003819465637207031
# epoch:  167
# assembling the matrix time taken:  0.025667190551757812
# solving Ax = b time taken:  0.000370025634765625
# epoch:  168
# assembling the matrix time taken:  0.04082894325256348
# solving Ax = b time taken:  0.00024700164794921875
# epoch:  169
# assembling the matrix time taken:  0.042762041091918945
# solving Ax = b time taken:  0.0004200935363769531
# epoch:  170
# assembling the matrix time taken:  0.03124403953552246
# solving Ax = b time taken:  0.0003681182861328125
# epoch:  171
# assembling the matrix time taken:  0.02907109260559082
# solving Ax = b time taken:  0.0002949237823486328
# epoch:  172
# assembling the matrix time taken:  0.02710890769958496
# solving Ax = b time taken:  0.0003960132598876953
# epoch:  173
# assembling the matrix time taken:  0.02940082550048828
# solving Ax = b time taken:  0.0002789497375488281
# epoch:  174
# assembling the matrix time taken:  0.028975725173950195
# solving Ax = b time taken:  0.0003829002380371094
# epoch:  175
# assembling the matrix time taken:  0.029259204864501953
# solving Ax = b time taken:  0.000804901123046875
# epoch:  176
# assembling the matrix time taken:  0.02587890625
# solving Ax = b time taken:  0.00041294097900390625
# epoch:  177
# assembling the matrix time taken:  0.03374290466308594
# solving Ax = b time taken:  0.0002732276916503906
# epoch:  178
# assembling the matrix time taken:  0.029287099838256836
# solving Ax = b time taken:  0.00043392181396484375
# epoch:  179
# assembling the matrix time taken:  0.03235673904418945
# solving Ax = b time taken:  0.0004189014434814453
# epoch:  180
# assembling the matrix time taken:  0.03027200698852539
# solving Ax = b time taken:  0.0002810955047607422
# epoch:  181
# assembling the matrix time taken:  0.03148007392883301
# solving Ax = b time taken:  0.000286102294921875
# epoch:  182
# assembling the matrix time taken:  0.04141497611999512
# solving Ax = b time taken:  0.0004799365997314453
# epoch:  183
# assembling the matrix time taken:  0.041529178619384766
# solving Ax = b time taken:  0.00046896934509277344
# epoch:  184
# assembling the matrix time taken:  0.04006695747375488
# solving Ax = b time taken:  0.0002658367156982422
# epoch:  185
# assembling the matrix time taken:  0.045352935791015625
# solving Ax = b time taken:  0.00031185150146484375
# epoch:  186
# assembling the matrix time taken:  0.043627023696899414
# solving Ax = b time taken:  0.0004901885986328125
# epoch:  187
# assembling the matrix time taken:  0.04485130310058594
# solving Ax = b time taken:  0.0005078315734863281
# epoch:  188
# assembling the matrix time taken:  0.04658317565917969
# solving Ax = b time taken:  0.0004470348358154297
# epoch:  189
# assembling the matrix time taken:  0.04817485809326172
# solving Ax = b time taken:  0.0006949901580810547
# epoch:  190
# assembling the matrix time taken:  0.04374504089355469
# solving Ax = b time taken:  0.0009605884552001953
# epoch:  191
# assembling the matrix time taken:  0.044265031814575195
# solving Ax = b time taken:  0.0003437995910644531
# epoch:  192
# assembling the matrix time taken:  0.039669036865234375
# solving Ax = b time taken:  0.0007407665252685547
# epoch:  193
# assembling the matrix time taken:  0.04787802696228027
# solving Ax = b time taken:  0.0004780292510986328
# epoch:  194
# assembling the matrix time taken:  0.05063223838806152
# solving Ax = b time taken:  0.0012938976287841797
# epoch:  195
# assembling the matrix time taken:  0.04695892333984375
# solving Ax = b time taken:  0.0004978179931640625
# epoch:  196
# assembling the matrix time taken:  0.04503798484802246
# solving Ax = b time taken:  0.0004801750183105469
# epoch:  197
# assembling the matrix time taken:  0.046334028244018555
# solving Ax = b time taken:  0.0005631446838378906
# epoch:  198
# assembling the matrix time taken:  0.0463559627532959
# solving Ax = b time taken:  0.0004410743713378906
# epoch:  199
# assembling the matrix time taken:  0.046649932861328125
# solving Ax = b time taken:  0.00035190582275390625
# epoch:  200
# assembling the matrix time taken:  0.04388618469238281
# solving Ax = b time taken:  0.00045108795166015625
# epoch:  201
# assembling the matrix time taken:  0.04774188995361328
# solving Ax = b time taken:  0.0004680156707763672
# epoch:  202
# assembling the matrix time taken:  0.04643821716308594
# solving Ax = b time taken:  0.0004968643188476562
# epoch:  203
# assembling the matrix time taken:  0.04758310317993164
# solving Ax = b time taken:  0.0004818439483642578
# epoch:  204
# assembling the matrix time taken:  0.04718804359436035
# solving Ax = b time taken:  0.0004818439483642578
# epoch:  205
# assembling the matrix time taken:  0.04818105697631836
# solving Ax = b time taken:  0.00036978721618652344
# epoch:  206
# assembling the matrix time taken:  0.05030035972595215
# solving Ax = b time taken:  0.0004818439483642578
# epoch:  207
# assembling the matrix time taken:  0.05023813247680664
# solving Ax = b time taken:  0.0004858970642089844
# epoch:  208
# assembling the matrix time taken:  0.045990943908691406
# solving Ax = b time taken:  0.00043010711669921875
# epoch:  209
# assembling the matrix time taken:  0.055062055587768555
# solving Ax = b time taken:  0.0005018711090087891
# epoch:  210
# assembling the matrix time taken:  0.05092310905456543
# solving Ax = b time taken:  0.0005519390106201172
# epoch:  211
# assembling the matrix time taken:  0.05177617073059082
# solving Ax = b time taken:  0.0004978179931640625
# epoch:  212
# assembling the matrix time taken:  0.048796892166137695
# solving Ax = b time taken:  0.0008671283721923828
# epoch:  213
# assembling the matrix time taken:  0.052371978759765625
# solving Ax = b time taken:  0.0005109310150146484
# epoch:  214
# assembling the matrix time taken:  0.05582714080810547
# solving Ax = b time taken:  0.0004799365997314453
# epoch:  215
# assembling the matrix time taken:  0.057086944580078125
# solving Ax = b time taken:  0.0003657341003417969
# epoch:  216
# assembling the matrix time taken:  0.047776222229003906
# solving Ax = b time taken:  0.00047707557678222656
# epoch:  217
# assembling the matrix time taken:  0.0531771183013916
# solving Ax = b time taken:  0.0005319118499755859
# epoch:  218
# assembling the matrix time taken:  0.05225491523742676
# solving Ax = b time taken:  0.000576019287109375
# epoch:  219
# assembling the matrix time taken:  0.053427934646606445
# solving Ax = b time taken:  0.0005130767822265625
# epoch:  220
# assembling the matrix time taken:  0.051695823669433594
# solving Ax = b time taken:  0.0005218982696533203
# epoch:  221
# assembling the matrix time taken:  0.05346393585205078
# solving Ax = b time taken:  0.0005087852478027344
# epoch:  222
# assembling the matrix time taken:  0.052168846130371094
# solving Ax = b time taken:  0.0005338191986083984
# epoch:  223
# assembling the matrix time taken:  0.05305790901184082
# solving Ax = b time taken:  0.00039196014404296875
# epoch:  224
# assembling the matrix time taken:  0.04686403274536133
# solving Ax = b time taken:  0.0007278919219970703
# epoch:  225
# assembling the matrix time taken:  0.05785512924194336
# solving Ax = b time taken:  0.0005447864532470703
# epoch:  226
# assembling the matrix time taken:  0.054110050201416016
# solving Ax = b time taken:  0.0005002021789550781
# epoch:  227
# assembling the matrix time taken:  0.05411887168884277
# solving Ax = b time taken:  0.0005497932434082031
# epoch:  228
# assembling the matrix time taken:  0.05841684341430664
# solving Ax = b time taken:  0.0004968643188476562
# epoch:  229
# assembling the matrix time taken:  0.05560803413391113
# solving Ax = b time taken:  0.0005769729614257812
# epoch:  230
# assembling the matrix time taken:  0.05914592742919922
# solving Ax = b time taken:  0.0005118846893310547
# epoch:  231
# assembling the matrix time taken:  0.0571141242980957
# solving Ax = b time taken:  0.0005559921264648438
# epoch:  232
# assembling the matrix time taken:  0.06941103935241699
# solving Ax = b time taken:  0.0005140304565429688
# epoch:  233
# assembling the matrix time taken:  0.055568695068359375
# solving Ax = b time taken:  0.0004553794860839844
# epoch:  234
# assembling the matrix time taken:  0.05502486228942871
# solving Ax = b time taken:  0.0005810260772705078
# epoch:  235
# assembling the matrix time taken:  0.06414270401000977
# solving Ax = b time taken:  0.0005550384521484375
# epoch:  236
# assembling the matrix time taken:  0.054579973220825195
# solving Ax = b time taken:  0.0005648136138916016
# epoch:  237
# assembling the matrix time taken:  0.05638718605041504
# solving Ax = b time taken:  0.00042891502380371094
# epoch:  238
# assembling the matrix time taken:  0.056607723236083984
# solving Ax = b time taken:  0.0005850791931152344
# epoch:  239
# assembling the matrix time taken:  0.05752396583557129
# solving Ax = b time taken:  0.0005939006805419922
# epoch:  240
# assembling the matrix time taken:  0.05034995079040527
# solving Ax = b time taken:  0.0005030632019042969
# epoch:  241
# assembling the matrix time taken:  0.06247401237487793
# solving Ax = b time taken:  0.0006651878356933594
# epoch:  242
# assembling the matrix time taken:  0.057485103607177734
# solving Ax = b time taken:  0.0005888938903808594
# epoch:  243
# assembling the matrix time taken:  0.05777120590209961
# solving Ax = b time taken:  0.0004527568817138672
# epoch:  244
# assembling the matrix time taken:  0.0622708797454834
# solving Ax = b time taken:  0.0005271434783935547
# epoch:  245
# assembling the matrix time taken:  0.06502890586853027
# solving Ax = b time taken:  0.0004379749298095703
# epoch:  246
# assembling the matrix time taken:  0.05844402313232422
# solving Ax = b time taken:  0.0006270408630371094
# epoch:  247
# assembling the matrix time taken:  0.058203935623168945
# solving Ax = b time taken:  0.0005857944488525391
# epoch:  248
# assembling the matrix time taken:  0.05403780937194824
# solving Ax = b time taken:  0.0005650520324707031
# epoch:  249
# assembling the matrix time taken:  0.05897378921508789
# solving Ax = b time taken:  0.0006189346313476562
# epoch:  250
# assembling the matrix time taken:  0.05839109420776367
# solving Ax = b time taken:  0.0006070137023925781
# epoch:  251
# assembling the matrix time taken:  0.05975079536437988
# solving Ax = b time taken:  0.0006110668182373047
# epoch:  252
# assembling the matrix time taken:  0.05729794502258301
# solving Ax = b time taken:  0.0004711151123046875
# epoch:  253
# assembling the matrix time taken:  0.060132741928100586
# solving Ax = b time taken:  0.00046706199645996094
# epoch:  254
# assembling the matrix time taken:  0.059638023376464844
# solving Ax = b time taken:  0.0006477832794189453
# epoch:  255
# assembling the matrix time taken:  0.060224056243896484
# solving Ax = b time taken:  0.0005419254302978516
# epoch:  256
# assembling the matrix time taken:  0.05737709999084473
# solving Ax = b time taken:  0.0005576610565185547
# epoch:  257
# assembling the matrix time taken:  0.06951498985290527
# solving Ax = b time taken:  0.0006530284881591797
# epoch:  258
# assembling the matrix time taken:  0.06434130668640137
# solving Ax = b time taken:  0.0006401538848876953
# epoch:  259
# assembling the matrix time taken:  0.0657200813293457
# solving Ax = b time taken:  0.0006489753723144531
# epoch:  260
# assembling the matrix time taken:  0.06232786178588867
# solving Ax = b time taken:  0.0004930496215820312
# epoch:  261
# assembling the matrix time taken:  0.07230091094970703
# solving Ax = b time taken:  0.0005550384521484375
# epoch:  262
# assembling the matrix time taken:  0.06456184387207031
# solving Ax = b time taken:  0.0006020069122314453
# epoch:  263
# assembling the matrix time taken:  0.06859111785888672
# solving Ax = b time taken:  0.0006420612335205078
# epoch:  264
# assembling the matrix time taken:  0.06026911735534668
# solving Ax = b time taken:  0.0005748271942138672
# epoch:  265
# assembling the matrix time taken:  0.06678986549377441
# solving Ax = b time taken:  0.0006489753723144531
# epoch:  266
# assembling the matrix time taken:  0.06551384925842285
# solving Ax = b time taken:  0.0006031990051269531
# epoch:  267
# assembling the matrix time taken:  0.07373619079589844
# solving Ax = b time taken:  0.0006420612335205078
# epoch:  268
# assembling the matrix time taken:  0.06361913681030273
# solving Ax = b time taken:  0.0006070137023925781
# epoch:  269
# assembling the matrix time taken:  0.06596779823303223
# solving Ax = b time taken:  0.0006518363952636719
# epoch:  270
# assembling the matrix time taken:  0.06540489196777344
# solving Ax = b time taken:  0.0005970001220703125
# epoch:  271
# assembling the matrix time taken:  0.06862998008728027
# solving Ax = b time taken:  0.0006198883056640625
# epoch:  272
# assembling the matrix time taken:  0.05884504318237305
# solving Ax = b time taken:  0.0005602836608886719
# epoch:  273
# assembling the matrix time taken:  0.08034586906433105
# solving Ax = b time taken:  0.000637054443359375
# epoch:  274
# assembling the matrix time taken:  0.07388901710510254
# solving Ax = b time taken:  0.0006861686706542969
# epoch:  275
# assembling the matrix time taken:  0.0678567886352539
# solving Ax = b time taken:  0.0006310939788818359
# epoch:  276
# assembling the matrix time taken:  0.06522965431213379
# solving Ax = b time taken:  0.0006239414215087891
# epoch:  277
# assembling the matrix time taken:  0.06866312026977539
# solving Ax = b time taken:  0.0006849765777587891
# epoch:  278
# assembling the matrix time taken:  0.0686483383178711
# solving Ax = b time taken:  0.0006890296936035156
# epoch:  279
# assembling the matrix time taken:  0.06924104690551758
# solving Ax = b time taken:  0.0006401538848876953
# epoch:  280
# assembling the matrix time taken:  0.06357383728027344
# solving Ax = b time taken:  0.0006921291351318359
# epoch:  281
# assembling the matrix time taken:  0.07062697410583496
# solving Ax = b time taken:  0.0006761550903320312
# epoch:  282
# assembling the matrix time taken:  0.07589292526245117
# solving Ax = b time taken:  0.0006527900695800781
# epoch:  283
# assembling the matrix time taken:  0.07911205291748047
# solving Ax = b time taken:  0.0005369186401367188
# epoch:  284
# assembling the matrix time taken:  0.06614089012145996
# solving Ax = b time taken:  0.0006639957427978516
# epoch:  285
# assembling the matrix time taken:  0.07009482383728027
# solving Ax = b time taken:  0.0006892681121826172
# epoch:  286
# assembling the matrix time taken:  0.06933093070983887
# solving Ax = b time taken:  0.0006930828094482422
# epoch:  287
# assembling the matrix time taken:  0.07032299041748047
# solving Ax = b time taken:  0.0006921291351318359
# epoch:  288
# assembling the matrix time taken:  0.0696098804473877
# solving Ax = b time taken:  0.00045800209045410156
# epoch:  289
# assembling the matrix time taken:  0.08411693572998047
# solving Ax = b time taken:  0.0007200241088867188
# epoch:  290
# assembling the matrix time taken:  0.07098197937011719
# solving Ax = b time taken:  0.0007219314575195312
# epoch:  291
# assembling the matrix time taken:  0.07147693634033203
# solving Ax = b time taken:  0.0007171630859375
# epoch:  292
# assembling the matrix time taken:  0.06924891471862793
# solving Ax = b time taken:  0.0006468296051025391
# epoch:  293
# assembling the matrix time taken:  0.07144808769226074
# solving Ax = b time taken:  0.0007359981536865234
# epoch:  294
# assembling the matrix time taken:  0.07084298133850098
# solving Ax = b time taken:  0.0007288455963134766
# epoch:  295
# assembling the matrix time taken:  0.07303500175476074
# solving Ax = b time taken:  0.0007450580596923828
# epoch:  296
# assembling the matrix time taken:  0.0673379898071289
# solving Ax = b time taken:  0.0006170272827148438
# epoch:  297
# assembling the matrix time taken:  0.07405281066894531
# solving Ax = b time taken:  0.0007348060607910156
# epoch:  298
# assembling the matrix time taken:  0.08000421524047852
# solving Ax = b time taken:  0.0006730556488037109
# epoch:  299
# assembling the matrix time taken:  0.07397294044494629
# solving Ax = b time taken:  0.0007238388061523438
# epoch:  300
# assembling the matrix time taken:  0.07156872749328613
# solving Ax = b time taken:  0.0007278919219970703
# epoch:  301
# assembling the matrix time taken:  0.07402706146240234
# solving Ax = b time taken:  0.0007829666137695312
# epoch:  302
# assembling the matrix time taken:  0.07282304763793945
# solving Ax = b time taken:  0.0006978511810302734
# epoch:  303
# assembling the matrix time taken:  0.08281588554382324
# solving Ax = b time taken:  0.0007097721099853516
# epoch:  304
# assembling the matrix time taken:  0.06617498397827148
# solving Ax = b time taken:  0.0006330013275146484
# epoch:  305
# assembling the matrix time taken:  0.07743191719055176
# solving Ax = b time taken:  0.0007641315460205078
# epoch:  306
# assembling the matrix time taken:  0.07534098625183105
# solving Ax = b time taken:  0.0007276535034179688
# epoch:  307
# assembling the matrix time taken:  0.07617878913879395
# solving Ax = b time taken:  0.0007939338684082031
# epoch:  308
# assembling the matrix time taken:  0.0725400447845459
# solving Ax = b time taken:  0.0006358623504638672
# epoch:  309
# assembling the matrix time taken:  0.07631111145019531
# solving Ax = b time taken:  0.0008130073547363281
# epoch:  310
# assembling the matrix time taken:  0.07504987716674805
# solving Ax = b time taken:  0.0007128715515136719
# epoch:  311
# assembling the matrix time taken:  0.07665681838989258
# solving Ax = b time taken:  0.0008282661437988281
# epoch:  312
# assembling the matrix time taken:  0.06979107856750488
# solving Ax = b time taken:  0.0006101131439208984
# epoch:  313
# assembling the matrix time taken:  0.07823491096496582
# solving Ax = b time taken:  0.0007710456848144531
# epoch:  314
# assembling the matrix time taken:  0.07892394065856934
# solving Ax = b time taken:  0.0007569789886474609
# epoch:  315
# assembling the matrix time taken:  0.08636093139648438
# solving Ax = b time taken:  0.0007982254028320312
# epoch:  316
# assembling the matrix time taken:  0.07412195205688477
# solving Ax = b time taken:  0.0007150173187255859
# epoch:  317
# assembling the matrix time taken:  0.07699799537658691
# solving Ax = b time taken:  0.0006949901580810547
# epoch:  318
# assembling the matrix time taken:  0.07589507102966309
# solving Ax = b time taken:  0.0008268356323242188
# epoch:  319
# assembling the matrix time taken:  0.07778406143188477
# solving Ax = b time taken:  0.0008299350738525391
# epoch:  320
# assembling the matrix time taken:  0.07596993446350098
# solving Ax = b time taken:  0.0006310939788818359
# epoch:  321
# assembling the matrix time taken:  0.08428025245666504
# solving Ax = b time taken:  0.0008337497711181641
# epoch:  322
# assembling the matrix time taken:  0.0789330005645752
# solving Ax = b time taken:  0.0008399486541748047
# epoch:  323
# assembling the matrix time taken:  0.08192873001098633
# solving Ax = b time taken:  0.0008399486541748047
# epoch:  324
# assembling the matrix time taken:  0.07746005058288574
# solving Ax = b time taken:  0.0008242130279541016
# epoch:  325
# assembling the matrix time taken:  0.08193111419677734
# solving Ax = b time taken:  0.0008668899536132812
# epoch:  326
# assembling the matrix time taken:  0.08893966674804688
# solving Ax = b time taken:  0.0008311271667480469
# epoch:  327
# assembling the matrix time taken:  0.0894782543182373
# solving Ax = b time taken:  0.0008928775787353516
# epoch:  328
# assembling the matrix time taken:  0.11170411109924316
# solving Ax = b time taken:  0.0005898475646972656
# epoch:  329
# assembling the matrix time taken:  0.09679102897644043
# solving Ax = b time taken:  0.0007197856903076172
# epoch:  330
# assembling the matrix time taken:  0.09165072441101074
# solving Ax = b time taken:  0.0009131431579589844
# epoch:  331
# assembling the matrix time taken:  0.08999109268188477
# solving Ax = b time taken:  0.0008237361907958984
# epoch:  332
# assembling the matrix time taken:  0.0890500545501709
# solving Ax = b time taken:  0.0008380413055419922
# epoch:  333
# assembling the matrix time taken:  0.0854799747467041
# solving Ax = b time taken:  0.0009090900421142578
# epoch:  334
# assembling the matrix time taken:  0.0859379768371582
# solving Ax = b time taken:  0.00086212158203125
# epoch:  335
# assembling the matrix time taken:  0.09284090995788574
# solving Ax = b time taken:  0.000865936279296875
# epoch:  336
# assembling the matrix time taken:  0.07390093803405762
# solving Ax = b time taken:  0.000720977783203125
# epoch:  337
# assembling the matrix time taken:  0.09751510620117188
# solving Ax = b time taken:  0.0009090900421142578
# epoch:  338
# assembling the matrix time taken:  0.08911895751953125
# solving Ax = b time taken:  0.0008032321929931641
# epoch:  339
# assembling the matrix time taken:  0.08616280555725098
# solving Ax = b time taken:  0.0009801387786865234
# epoch:  340
# assembling the matrix time taken:  0.08301401138305664
# solving Ax = b time taken:  0.0008130073547363281
# epoch:  341
# assembling the matrix time taken:  0.0872659683227539
# solving Ax = b time taken:  0.0009970664978027344
# epoch:  342
# assembling the matrix time taken:  0.08521819114685059
# solving Ax = b time taken:  0.0009000301361083984
# epoch:  343
# assembling the matrix time taken:  0.0868680477142334
# solving Ax = b time taken:  0.0009369850158691406
# epoch:  344
# assembling the matrix time taken:  0.08633708953857422
# solving Ax = b time taken:  0.0007231235504150391
# epoch:  345
# assembling the matrix time taken:  0.09649896621704102
# solving Ax = b time taken:  0.0009469985961914062
# epoch:  346
# assembling the matrix time taken:  0.08636617660522461
# solving Ax = b time taken:  0.0008969306945800781
# epoch:  347
# assembling the matrix time taken:  0.08683013916015625
# solving Ax = b time taken:  0.000804901123046875
# epoch:  348
# assembling the matrix time taken:  0.08319377899169922
# solving Ax = b time taken:  0.0008978843688964844
# epoch:  349
# assembling the matrix time taken:  0.0870509147644043
# solving Ax = b time taken:  0.0009000301361083984
# epoch:  350
# assembling the matrix time taken:  0.08544111251831055
# solving Ax = b time taken:  0.000782012939453125
# epoch:  351
# assembling the matrix time taken:  0.08684587478637695
# solving Ax = b time taken:  0.0009150505065917969
# epoch:  352
# assembling the matrix time taken:  0.0861809253692627
# solving Ax = b time taken:  0.0006368160247802734
# epoch:  353
# assembling the matrix time taken:  0.10361170768737793
# solving Ax = b time taken:  0.0009889602661132812
# epoch:  354
# assembling the matrix time taken:  0.08812689781188965
# solving Ax = b time taken:  0.0010340213775634766
# epoch:  355
# assembling the matrix time taken:  0.08991312980651855
# solving Ax = b time taken:  0.0010149478912353516
# epoch:  356
# assembling the matrix time taken:  0.08513617515563965
# solving Ax = b time taken:  0.0008869171142578125
# epoch:  357
# assembling the matrix time taken:  0.08890700340270996
# solving Ax = b time taken:  0.0010221004486083984
# epoch:  358
# assembling the matrix time taken:  0.08794689178466797
# solving Ax = b time taken:  0.0009839534759521484
# epoch:  359
# assembling the matrix time taken:  0.09022712707519531
# solving Ax = b time taken:  0.0009400844573974609
# epoch:  360
# assembling the matrix time taken:  0.08221316337585449
# solving Ax = b time taken:  0.0007679462432861328
# epoch:  361
# assembling the matrix time taken:  0.09104490280151367
# solving Ax = b time taken:  0.0009913444519042969
# epoch:  362
# assembling the matrix time taken:  0.08999490737915039
# solving Ax = b time taken:  0.0009632110595703125
# epoch:  363
# assembling the matrix time taken:  0.09072303771972656
# solving Ax = b time taken:  0.0010287761688232422
# epoch:  364
# assembling the matrix time taken:  0.09538483619689941
# solving Ax = b time taken:  0.0010120868682861328
# epoch:  365
# assembling the matrix time taken:  0.09063100814819336
# solving Ax = b time taken:  0.0010449886322021484
# epoch:  366
# assembling the matrix time taken:  0.08980178833007812
# solving Ax = b time taken:  0.0009510517120361328
# epoch:  367
# assembling the matrix time taken:  0.09069514274597168
# solving Ax = b time taken:  0.0010340213775634766
# epoch:  368
# assembling the matrix time taken:  0.08037185668945312
# solving Ax = b time taken:  0.0006477832794189453
# epoch:  369
# assembling the matrix time taken:  0.09934091567993164
# solving Ax = b time taken:  0.001027822494506836
# epoch:  370
# assembling the matrix time taken:  0.09100222587585449
# solving Ax = b time taken:  0.001010894775390625
# epoch:  371
# assembling the matrix time taken:  0.09277582168579102
# solving Ax = b time taken:  0.0010700225830078125
# epoch:  372
# assembling the matrix time taken:  0.08823776245117188
# solving Ax = b time taken:  0.0009131431579589844
# epoch:  373
# assembling the matrix time taken:  0.09241223335266113
# solving Ax = b time taken:  0.0010900497436523438
# epoch:  374
# assembling the matrix time taken:  0.09233307838439941
# solving Ax = b time taken:  0.0009667873382568359
# epoch:  375
# assembling the matrix time taken:  0.0939798355102539
# solving Ax = b time taken:  0.0010390281677246094
# epoch:  376
# assembling the matrix time taken:  0.08572888374328613
# solving Ax = b time taken:  0.0007979869842529297
# epoch:  377
# assembling the matrix time taken:  0.09555387496948242
# solving Ax = b time taken:  0.0012118816375732422
# epoch:  378
# assembling the matrix time taken:  0.09343409538269043
# solving Ax = b time taken:  0.0010609626770019531
# epoch:  379
# assembling the matrix time taken:  0.09494614601135254
# solving Ax = b time taken:  0.0010988712310791016
# epoch:  380
# assembling the matrix time taken:  0.08956503868103027
# solving Ax = b time taken:  0.001013040542602539
# epoch:  381
# assembling the matrix time taken:  0.09466338157653809
# solving Ax = b time taken:  0.001032114028930664
# epoch:  382
# assembling the matrix time taken:  0.09314107894897461
# solving Ax = b time taken:  0.0010030269622802734
# epoch:  383
# assembling the matrix time taken:  0.09404110908508301
# solving Ax = b time taken:  0.001085042953491211
# epoch:  384
# assembling the matrix time taken:  0.08402085304260254
# solving Ax = b time taken:  0.0008490085601806641
# epoch:  385
# assembling the matrix time taken:  0.09830880165100098
# solving Ax = b time taken:  0.0011358261108398438
# epoch:  386
# assembling the matrix time taken:  0.09847283363342285
# solving Ax = b time taken:  0.0011970996856689453
# epoch:  387
# assembling the matrix time taken:  0.10010075569152832
# solving Ax = b time taken:  0.0011599063873291016
# epoch:  388
# assembling the matrix time taken:  0.09551692008972168
# solving Ax = b time taken:  0.0010533332824707031
# epoch:  389
# assembling the matrix time taken:  0.10971331596374512
# solving Ax = b time taken:  0.0011420249938964844
# epoch:  390
# assembling the matrix time taken:  0.10722804069519043
# solving Ax = b time taken:  0.0011591911315917969
# epoch:  391
# assembling the matrix time taken:  0.1022799015045166
# solving Ax = b time taken:  0.0010597705841064453
# epoch:  392
# assembling the matrix time taken:  0.10383415222167969
# solving Ax = b time taken:  0.0007698535919189453
# epoch:  393
# assembling the matrix time taken:  0.10886287689208984
# solving Ax = b time taken:  0.0010068416595458984
# epoch:  394
# assembling the matrix time taken:  0.10511326789855957
# solving Ax = b time taken:  0.0011010169982910156
# epoch:  395
# assembling the matrix time taken:  0.11207985877990723
# solving Ax = b time taken:  0.0011239051818847656
# epoch:  396
# assembling the matrix time taken:  0.11990618705749512
# solving Ax = b time taken:  0.0017750263214111328
# epoch:  397
# assembling the matrix time taken:  0.11684608459472656
# solving Ax = b time taken:  0.0013239383697509766
# epoch:  398
# assembling the matrix time taken:  0.12097311019897461
# solving Ax = b time taken:  0.00102996826171875
# epoch:  399
# assembling the matrix time taken:  0.10134696960449219
# solving Ax = b time taken:  0.0012485980987548828
# epoch:  400
# assembling the matrix time taken:  0.10099911689758301
# solving Ax = b time taken:  0.0008511543273925781
# epoch:  401
# assembling the matrix time taken:  0.12394189834594727
# solving Ax = b time taken:  0.0010328292846679688
# epoch:  402
# assembling the matrix time taken:  0.10399699211120605
# solving Ax = b time taken:  0.0012097358703613281
# epoch:  403
# assembling the matrix time taken:  0.11374378204345703
# solving Ax = b time taken:  0.0012059211730957031
# epoch:  404
# assembling the matrix time taken:  0.09788370132446289
# solving Ax = b time taken:  0.0010669231414794922
# epoch:  405
# assembling the matrix time taken:  0.10083913803100586
# solving Ax = b time taken:  0.0012331008911132812
# epoch:  406
# assembling the matrix time taken:  0.10016107559204102
# solving Ax = b time taken:  0.0012390613555908203
# epoch:  407
# assembling the matrix time taken:  0.10887908935546875
# solving Ax = b time taken:  0.0011091232299804688
# epoch:  408
# assembling the matrix time taken:  0.1012120246887207
# solving Ax = b time taken:  0.0010402202606201172
# epoch:  409
# assembling the matrix time taken:  0.11178803443908691
# solving Ax = b time taken:  0.0014159679412841797
# epoch:  410
# assembling the matrix time taken:  0.1025228500366211
# ...
# epoch:  905
# assembling the matrix time taken:  0.2491130828857422
# solving Ax = b time taken:  0.005015850067138672
# epoch:  906
# assembling the matrix time taken:  0.2451481819152832
# solving Ax = b time taken:  0.005532979965209961
# epoch:  907
# assembling the matrix time taken:  0.2520120143890381
# solving Ax = b time taken:  0.004821062088012695
# epoch:  908
# assembling the matrix time taken:  0.23724603652954102
# solving Ax = b time taken:  0.004701852798461914
# epoch:  909
# assembling the matrix time taken:  0.2470400333404541
# solving Ax = b time taken:  0.0052738189697265625
# epoch:  910
# assembling the matrix time taken:  0.24479413032531738
# solving Ax = b time taken:  0.0046651363372802734
# epoch:  911
# assembling the matrix time taken:  0.24879693984985352
# solving Ax = b time taken:  0.005187034606933594
# epoch:  912
# assembling the matrix time taken:  0.23308801651000977
# solving Ax = b time taken:  0.003929853439331055
# epoch:  913
# assembling the matrix time taken:  0.2621331214904785
# solving Ax = b time taken:  0.0049021244049072266
# epoch:  914
# assembling the matrix time taken:  0.24790620803833008
# solving Ax = b time taken:  0.004817962646484375
# epoch:  915
# assembling the matrix time taken:  0.2534170150756836
# solving Ax = b time taken:  0.005336284637451172
# epoch:  916
# assembling the matrix time taken:  0.24273109436035156
# solving Ax = b time taken:  0.004606008529663086
# epoch:  917
# assembling the matrix time taken:  0.2651057243347168
# solving Ax = b time taken:  0.004858970642089844
# epoch:  918
# assembling the matrix time taken:  0.24762701988220215
# solving Ax = b time taken:  0.0050048828125
# epoch:  919
# assembling the matrix time taken:  0.25102806091308594
# solving Ax = b time taken:  0.004984855651855469
# epoch:  920
# assembling the matrix time taken:  0.22915410995483398
# solving Ax = b time taken:  0.003994941711425781
# epoch:  921
# assembling the matrix time taken:  0.2627437114715576
# solving Ax = b time taken:  0.005467891693115234
# epoch:  922
# assembling the matrix time taken:  0.25240087509155273
# solving Ax = b time taken:  0.005555868148803711
# epoch:  923
# assembling the matrix time taken:  0.25832295417785645
# solving Ax = b time taken:  0.0056493282318115234
# epoch:  924
# assembling the matrix time taken:  0.24126577377319336
# solving Ax = b time taken:  0.005033016204833984
# epoch:  925
# assembling the matrix time taken:  0.2528831958770752
# solving Ax = b time taken:  0.005693912506103516
# epoch:  926
# assembling the matrix time taken:  0.2654299736022949
# solving Ax = b time taken:  0.0048291683197021484
# epoch:  927
# assembling the matrix time taken:  0.2675290107727051
# solving Ax = b time taken:  0.005266904830932617
# epoch:  928
# assembling the matrix time taken:  0.22745299339294434
# solving Ax = b time taken:  0.00374603271484375
# epoch:  929
# assembling the matrix time taken:  0.27852916717529297
# solving Ax = b time taken:  0.005339860916137695
# epoch:  930
# assembling the matrix time taken:  0.252824068069458
# solving Ax = b time taken:  0.005617856979370117
# epoch:  931
# assembling the matrix time taken:  0.2581150531768799
# solving Ax = b time taken:  0.005594015121459961
# epoch:  932
# assembling the matrix time taken:  0.24377894401550293
# solving Ax = b time taken:  0.005213260650634766
# epoch:  933
# assembling the matrix time taken:  0.25420308113098145
# solving Ax = b time taken:  0.0052089691162109375
# epoch:  934
# assembling the matrix time taken:  0.2496960163116455
# solving Ax = b time taken:  0.005154848098754883
# epoch:  935
# assembling the matrix time taken:  0.25972604751586914
# solving Ax = b time taken:  0.005304098129272461
# epoch:  936
# assembling the matrix time taken:  0.23237824440002441
# solving Ax = b time taken:  0.004045009613037109
# epoch:  937
# assembling the matrix time taken:  0.2606477737426758
# solving Ax = b time taken:  0.005884885787963867
# epoch:  938
# assembling the matrix time taken:  0.25559401512145996
# solving Ax = b time taken:  0.006123065948486328
# epoch:  939
# assembling the matrix time taken:  0.2608633041381836
# solving Ax = b time taken:  0.00578618049621582
# epoch:  940
# assembling the matrix time taken:  0.24764537811279297
# solving Ax = b time taken:  0.005523204803466797
# epoch:  941
# assembling the matrix time taken:  0.2671668529510498
# solving Ax = b time taken:  0.006019115447998047
# epoch:  942
# assembling the matrix time taken:  0.2533419132232666
# solving Ax = b time taken:  0.005372285842895508
# epoch:  943
# assembling the matrix time taken:  0.2563772201538086
# solving Ax = b time taken:  0.005085945129394531
# epoch:  944
# assembling the matrix time taken:  0.23070311546325684
# solving Ax = b time taken:  0.004196882247924805
# epoch:  945
# assembling the matrix time taken:  0.2596890926361084
# solving Ax = b time taken:  0.00581812858581543
# epoch:  946
# assembling the matrix time taken:  0.27236008644104004
# solving Ax = b time taken:  0.005197048187255859
# epoch:  947
# assembling the matrix time taken:  0.2600278854370117
# solving Ax = b time taken:  0.0058820247650146484
# epoch:  948
# assembling the matrix time taken:  0.2495558261871338
# solving Ax = b time taken:  0.004823923110961914
# epoch:  949
# assembling the matrix time taken:  0.2612929344177246
# solving Ax = b time taken:  0.00545811653137207
# epoch:  950
# assembling the matrix time taken:  0.25455188751220703
# solving Ax = b time taken:  0.0052433013916015625
# epoch:  951
# assembling the matrix time taken:  0.2577860355377197
# solving Ax = b time taken:  0.005572080612182617
# epoch:  952
# assembling the matrix time taken:  0.24039864540100098
# solving Ax = b time taken:  0.004147052764892578
# epoch:  953
# assembling the matrix time taken:  0.2626328468322754
# solving Ax = b time taken:  0.005460977554321289
# epoch:  954
# assembling the matrix time taken:  0.2703738212585449
# solving Ax = b time taken:  0.005610942840576172
# epoch:  955
# assembling the matrix time taken:  0.26283907890319824
# solving Ax = b time taken:  0.00538325309753418
# epoch:  956
# assembling the matrix time taken:  0.25063276290893555
# solving Ax = b time taken:  0.005219936370849609
# epoch:  957
# assembling the matrix time taken:  0.26074695587158203
# solving Ax = b time taken:  0.0054590702056884766
# epoch:  958
# assembling the matrix time taken:  0.2559990882873535
# solving Ax = b time taken:  0.005689859390258789
# epoch:  959
# assembling the matrix time taken:  0.2727091312408447
# solving Ax = b time taken:  0.005033969879150391
# epoch:  960
# assembling the matrix time taken:  0.2335679531097412
# solving Ax = b time taken:  0.0040700435638427734
# epoch:  961
# assembling the matrix time taken:  0.26549482345581055
# solving Ax = b time taken:  0.005438804626464844
# epoch:  962
# assembling the matrix time taken:  0.2635776996612549
# solving Ax = b time taken:  0.005785703659057617
# epoch:  963
# assembling the matrix time taken:  0.2669970989227295
# solving Ax = b time taken:  0.006014108657836914
# epoch:  964
# assembling the matrix time taken:  0.27335500717163086
# solving Ax = b time taken:  0.005177974700927734
# epoch:  965
# assembling the matrix time taken:  0.27017688751220703
# solving Ax = b time taken:  0.005563974380493164
# epoch:  966
# assembling the matrix time taken:  0.28011012077331543
# solving Ax = b time taken:  0.005743980407714844
# epoch:  967
# assembling the matrix time taken:  0.26729488372802734
# solving Ax = b time taken:  0.00601506233215332
# epoch:  968
# assembling the matrix time taken:  0.2588977813720703
# solving Ax = b time taken:  0.004538059234619141
# epoch:  969
# assembling the matrix time taken:  0.2710878849029541
# solving Ax = b time taken:  0.0064389705657958984
# epoch:  970
# assembling the matrix time taken:  0.2655820846557617
# solving Ax = b time taken:  0.005419015884399414
# epoch:  971
# assembling the matrix time taken:  0.26903605461120605
# solving Ax = b time taken:  0.0060880184173583984
# epoch:  972
# assembling the matrix time taken:  0.2633938789367676
# solving Ax = b time taken:  0.005424976348876953
# epoch:  973
# assembling the matrix time taken:  0.2794790267944336
# solving Ax = b time taken:  0.005525112152099609
# epoch:  974
# assembling the matrix time taken:  0.2767980098724365
# solving Ax = b time taken:  0.006357908248901367
# epoch:  975
# assembling the matrix time taken:  0.2749049663543701
# solving Ax = b time taken:  0.005352020263671875
# epoch:  976
# assembling the matrix time taken:  0.23694396018981934
# solving Ax = b time taken:  0.004019975662231445
# epoch:  977
# assembling the matrix time taken:  0.32124900817871094
# solving Ax = b time taken:  0.006511211395263672
# epoch:  978
# assembling the matrix time taken:  0.27403712272644043
# solving Ax = b time taken:  0.005630016326904297
# epoch:  979
# assembling the matrix time taken:  0.2689380645751953
# solving Ax = b time taken:  0.006089925765991211
# epoch:  980
# assembling the matrix time taken:  0.2568831443786621
# solving Ax = b time taken:  0.005944967269897461
# epoch:  981
# assembling the matrix time taken:  0.26895618438720703
# solving Ax = b time taken:  0.006136894226074219
# epoch:  982
# assembling the matrix time taken:  0.26114606857299805
# solving Ax = b time taken:  0.0061299800872802734
# epoch:  983
# assembling the matrix time taken:  0.26757097244262695
# solving Ax = b time taken:  0.00630497932434082
# epoch:  984
# assembling the matrix time taken:  0.24101924896240234
# solving Ax = b time taken:  0.005242109298706055
# epoch:  985
# assembling the matrix time taken:  0.28782200813293457
# solving Ax = b time taken:  0.005677223205566406
# epoch:  986
# assembling the matrix time taken:  0.28058409690856934
# solving Ax = b time taken:  0.005476951599121094
# epoch:  987
# assembling the matrix time taken:  0.2704050540924072
# solving Ax = b time taken:  0.005978822708129883
# epoch:  988
# assembling the matrix time taken:  0.2558121681213379
# solving Ax = b time taken:  0.005589008331298828
# epoch:  989
# assembling the matrix time taken:  0.2659919261932373
# solving Ax = b time taken:  0.005975008010864258
# epoch:  990
# assembling the matrix time taken:  0.2613217830657959
# solving Ax = b time taken:  0.00602412223815918
# epoch:  991
# assembling the matrix time taken:  0.2866239547729492
# solving Ax = b time taken:  0.0056378841400146484
# epoch:  992
# assembling the matrix time taken:  0.24990487098693848
# solving Ax = b time taken:  0.004268169403076172
# epoch:  993
# assembling the matrix time taken:  0.3025069236755371
# solving Ax = b time taken:  0.006042957305908203
# epoch:  994
# assembling the matrix time taken:  0.28912901878356934
# solving Ax = b time taken:  0.006084918975830078
# epoch:  995
# assembling the matrix time taken:  0.27121400833129883
# solving Ax = b time taken:  0.006395101547241211
# epoch:  996
# assembling the matrix time taken:  0.2576768398284912
# solving Ax = b time taken:  0.005751132965087891
# epoch:  997
# assembling the matrix time taken:  0.26924920082092285
# solving Ax = b time taken:  0.0058519840240478516
# epoch:  998
# assembling the matrix time taken:  0.26735591888427734
# solving Ax = b time taken:  0.00581812858581543
# epoch:  999
# assembling the matrix time taken:  0.2711758613586426
# solving Ax = b time taken:  0.006195068359375
# epoch:  1000
# assembling the matrix time taken:  0.2461228370666504
# solving Ax = b time taken:  0.0054700374603271484
# epoch:  1001
# assembling the matrix time taken:  0.27286791801452637
# solving Ax = b time taken:  0.0063898563385009766
# epoch:  1002
# assembling the matrix time taken:  0.27959775924682617
# solving Ax = b time taken:  0.00587916374206543
# epoch:  1003
# assembling the matrix time taken:  0.2952239513397217
# solving Ax = b time taken:  0.006048917770385742
# epoch:  1004
# assembling the matrix time taken:  0.2728140354156494
# solving Ax = b time taken:  0.0054721832275390625
# epoch:  1005
# assembling the matrix time taken:  0.2723970413208008
# solving Ax = b time taken:  0.0063779354095458984
# epoch:  1006
# assembling the matrix time taken:  0.2691178321838379
# solving Ax = b time taken:  0.006066322326660156
# epoch:  1007
# assembling the matrix time taken:  0.2714989185333252
# solving Ax = b time taken:  0.0063021183013916016
# epoch:  1008
# assembling the matrix time taken:  0.25870418548583984
# solving Ax = b time taken:  0.0042688846588134766
# epoch:  1009
# assembling the matrix time taken:  0.33130502700805664
# solving Ax = b time taken:  0.006262063980102539
# epoch:  1010
# assembling the matrix time taken:  0.27660608291625977
# solving Ax = b time taken:  0.0062181949615478516
# epoch:  1011
# assembling the matrix time taken:  0.2878408432006836
# solving Ax = b time taken:  0.006337881088256836
# epoch:  1012
# assembling the matrix time taken:  0.28057193756103516
# solving Ax = b time taken:  0.005412101745605469
# epoch:  1013
# assembling the matrix time taken:  0.2759830951690674
# solving Ax = b time taken:  0.005769968032836914
# epoch:  1014
# assembling the matrix time taken:  0.27040886878967285
# solving Ax = b time taken:  0.006151914596557617
# epoch:  1015
# assembling the matrix time taken:  0.2745800018310547
# solving Ax = b time taken:  0.0065348148345947266
# epoch:  1016
# assembling the matrix time taken:  0.25030994415283203
# solving Ax = b time taken:  0.0055408477783203125
# epoch:  1017
# assembling the matrix time taken:  0.2947261333465576
# solving Ax = b time taken:  0.006121158599853516
# epoch:  1018
# assembling the matrix time taken:  0.2871689796447754
# solving Ax = b time taken:  0.00623321533203125
# epoch:  1019
# assembling the matrix time taken:  0.2837028503417969
# solving Ax = b time taken:  0.0067958831787109375
# epoch:  1020
# assembling the matrix time taken:  0.2681879997253418
# solving Ax = b time taken:  0.006239175796508789
# epoch:  1021
# assembling the matrix time taken:  0.2817997932434082
# solving Ax = b time taken:  0.007033109664916992
# epoch:  1022
# assembling the matrix time taken:  0.27898597717285156
# solving Ax = b time taken:  0.006810188293457031
# epoch:  1023
# assembling the matrix time taken:  0.2849302291870117
# solving Ax = b time taken:  0.007415056228637695
# epoch:  1024
# assembling the matrix time taken:  0.2546982765197754
# solving Ax = b time taken:  0.005511045455932617
# time taken:  529.5286908149719
# neuron num 		 error 		 order
# 4 		 3.016e+00 		 * 		 1.167e+01 		 * 		 5.972e+02 		 *
#
# 8 		 1.905e+00 		 0.66 		 7.043e+00 		 0.73 		 3.517e+02 		 0.76
#
# 16 		 6.418e-01 		 1.57 		 5.002e+00 		 0.49 		 5.510e+01 		 2.67
#
# 32 		 2.579e-01 		 1.32 		 2.031e+00 		 1.30 		 6.764e+00 		 3.03
#
# 64 		 5.328e-02 		 2.28 		 6.164e-01 		 1.72 		 9.870e-01 		 2.78
#
# 128 		 2.623e-02 		 1.02 		 3.017e-01 		 1.03 		 1.361e-01 		 2.86
#
# 256 		 1.001e-02 		 1.39 		 1.338e-01 		 1.17 		 2.619e-02 		 2.38
#
# 512 		 2.693e-03 		 1.89 		 4.849e-02 		 1.46 		 4.273e-03 		 2.62
#
# 1024 		 1.048e-03 		 1.36 		 2.214e-02 		 1.13 		 6.331e-04 		 2.75
# /var/folders/45/p1_q2drx75983lk7ph_1gx6mhpr5_w/T/ipykernel_81425/3057554446.py:184: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   print("{} \t\t {:.3e} \t\t {:.2f} \t\t {:.3e} \t\t {:.2f} \t\t {:.3e} \t\t {:.2f}  \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),
# /var/folders/45/p1_q2drx75983lk7ph_1gx6mhpr5_w/T/ipykernel_81425/3057554446.py:185: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2),
# /var/folders/45/p1_q2drx75983lk7ph_1gx6mhpr5_w/T/ipykernel_81425/3057554446.py:186: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   err_list3[i] , np.log(err_list3[i-1]/err_list3[i])/np.log(2) ) )
# /var/folders/45/p1_q2drx75983lk7ph_1gx6mhpr5_w/T/ipykernel_81425/3057554446.py:188: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   f_write.write("{} \t\t {} \t\t {} \t\t {} \t\t {} \t\t {} \t\t {} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2),err_list3[i] , np.log(err_list3[i-1]/err_list3[i])/np.log(2) ))

# %%
def show_convergence_order_latex2(err_l2,err_h10,err_energy, exponent,k=1,d=1): 
    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_l2[i] for i in neuron_nums ]
    err_list2 = [err_h10[i] for i in neuron_nums ] 
    err_list3 = [err_energy[i] for i in neuron_nums ]
    l2_order = -1/2-(2*k + 1)/(2*d)
    h1_order =  -1/2-(2*(k-1)+ 1)/(2*d)
    print("neuron num  & \t $\|u-u_n \|_{{L^2}}$ & \t order $O(n^{{{:.2f}}})$  & \t $ | u -u_n |_{{H^1}}$ & \t order $O(n^{{{:.2f}}})$ & \t loss & \t order \\\ \hline \hline ".format(l2_order,h1_order))
    for i, item in enumerate(err_list):
        if i == 0: 
            print("{} \t\t & {:.2e} &\t\t * & \t \t {:.2e} & \t\t * & \t\t {:.2e} & \t\t * \\\ \hline  \n".format(neuron_nums[i],item, err_list2[i], err_list3[i] ) )   
        else: 
            print("{} \t\t &  {:.2e} &  \t\t {:.2f} &  \t\t {:.2e} &  \t\t {:.2f} &  \t\t {:.2e} &  \t\t {:.2f} \\\ \hline  \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2), err_list3[i], np.log(err_list3[i-1]/err_list3[i])/np.log(2) ) )



show_convergence_order_latex2(err_QMC2,err_h10,err_energy, exponent,k=3,d=2)
# Out:
# neuron num  & 	 $\|u-u_n \|_{L^2}$ & 	 order $O(n^{-2.25})$  & 	 $ | u -u_n |_{H^1}$ & 	 order $O(n^{-1.75})$ 	 loss 	 order \\ \hline \hline
# 4 		 & 3.02e+00 &		 * & 	 	 1.17e+01 & 		 * & 		 5.97e+02 & 		 * \\ \hline
#
# 8 		 &  1.91e+00 &  		 0.66 &  		 7.04e+00 &  		 0.73 &  		 3.52e+02 &  		 0.76 \\ \hline
#
# 16 		 &  6.42e-01 &  		 1.57 &  		 5.00e+00 &  		 0.49 &  		 5.51e+01 &  		 2.67 \\ \hline
#
# 32 		 &  2.58e-01 &  		 1.32 &  		 2.03e+00 &  		 1.30 &  		 6.76e+00 &  		 3.03 \\ \hline
#
# 64 		 &  5.33e-02 &  		 2.28 &  		 6.16e-01 &  		 1.72 &  		 9.87e-01 &  		 2.78 \\ \hline
#
# 128 		 &  2.62e-02 &  		 1.02 &  		 3.02e-01 &  		 1.03 &  		 1.36e-01 &  		 2.86 \\ \hline
#
# 256 		 &  1.00e-02 &  		 1.39 &  		 1.34e-01 &  		 1.17 &  		 2.62e-02 &  		 2.38 \\ \hline
#
# 512 		 &  2.69e-03 &  		 1.89 &  		 4.85e-02 &  		 1.46 &  		 4.27e-03 &  		 2.62 \\ \hline
#
# 1024 		 &  1.05e-03 &  		 1.36 &  		 2.21e-02 &  		 1.13 &  		 6.33e-04 &  		 2.75 \\ \hline
# /var/folders/45/p1_q2drx75983lk7ph_1gx6mhpr5_w/T/ipykernel_81425/1986762027.py:13: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   print("{} \t\t &  {:.2e} &  \t\t {:.2f} &  \t\t {:.2e} &  \t\t {:.2f} &  \t\t {:.2e} &  \t\t {:.2f} \\\ \hline  \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2), err_list3[i], np.log(err_list3[i-1]/err_list3[i])/np.log(2) ) )

# %%
show_convergence_order2_PINN(err_QMC2,err_h10,err_energy, exponent,2*N,filename_write,write2file = write2file)
# show_convergence_order_latex2(err_QMC2,err_h10,exponent,k=relu_k,d = dim)

def show_convergence_order_latex2(err_l2,err_h10,err_energy, exponent,k=1,d=1): 
    neuron_nums = [2**j for j in range(2,exponent+1)]
    err_list = [err_l2[i] for i in neuron_nums ]
    err_list2 = [err_h10[i] for i in neuron_nums ] 
    err_list3 = [err_energy[i] for i in neuron_nums ]
    l2_order = -1/2-(2*k + 1)/(2*d)
    h1_order =  -1/2-(2*(k-1)+ 1)/(2*d)
    print("neuron num  & \t $\|u-u_n \|_{{L^2}}$ & \t order $O(n^{{{:.2f}}})$  & \t $ | u -u_n |_{{H^1}}$ & \t order $O(n^{{{:.2f}}})$ \t loss \t order \\\ \hline \hline ".format(l2_order,h1_order))
    for i, item in enumerate(err_list):
        if i == 0: 
            print("{} \t\t & {:.3e} &\t\t * & \t \t {:.3e} & \t\t * & \t\t {:.3e} & \t\t * \\\ \hline  \n".format(neuron_nums[i],item, err_list2[i], err_list3[i] ) )   
        else: 
            print("{} \t\t &  {:.3e} &  \t\t {:.2f} &  \t\t {:.3e} &  \t\t {:.2f} &  \t\t {:.3e} &  \t\t {:.2f} \\\ \hline  \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2), err_list3[i], np.log(err_list3[i-1]/err_list3[i])/np.log(2) ) )


show_convergence_order_latex2(err_QMC2,err_h10,err_energy, exponent,k=3,d=2)
# Out:
# neuron num 		 error 		 order
# 4 		 3.016e+00 		 * 		 1.167e+01 		 * 		 5.972e+02 		 *
#
# 8 		 1.905e+00 		 0.66 		 7.043e+00 		 0.73 		 3.517e+02 		 0.76
#
# 16 		 6.418e-01 		 1.57 		 5.002e+00 		 0.49 		 5.510e+01 		 2.67
#
# 32 		 2.579e-01 		 1.32 		 2.031e+00 		 1.30 		 6.764e+00 		 3.03
#
# 64 		 5.328e-02 		 2.28 		 6.164e-01 		 1.72 		 9.870e-01 		 2.78
#
# 128 		 2.623e-02 		 1.02 		 3.017e-01 		 1.03 		 1.361e-01 		 2.86
#
# 256 		 1.001e-02 		 1.39 		 1.338e-01 		 1.17 		 2.619e-02 		 2.38
#
# 512 		 2.693e-03 		 1.89 		 4.849e-02 		 1.46 		 4.273e-03 		 2.62
#
# 1024 		 1.048e-03 		 1.36 		 2.214e-02 		 1.13 		 6.331e-04 		 2.75
# /var/folders/45/p1_q2drx75983lk7ph_1gx6mhpr5_w/T/ipykernel_81425/191100526.py:184: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   print("{} \t\t {:.3e} \t\t {:.2f} \t\t {:.3e} \t\t {:.2f} \t\t {:.3e} \t\t {:.2f}  \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),
# /var/folders/45/p1_q2drx75983lk7ph_1gx6mhpr5_w/T/ipykernel_81425/191100526.py:185: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2),
# /var/folders/45/p1_q2drx75983lk7ph_1gx6mhpr5_w/T/ipykernel_81425/191100526.py:186: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   err_list3[i] , np.log(err_list3[i-1]/err_list3[i])/np.log(2) ) )
# /var/folders/45/p1_q2drx75983lk7ph_1gx6mhpr5_w/T/ipykernel_81425/191100526.py:188: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   f_write.write("{} \t\t {} \t\t {} \t\t {} \t\t {} \t\t {} \t\t {} \n".format(neuron_nums[i],item,np.log(err_list[i-1]/err_list[i])/np.log(2),err_list2[i] , np.log(err_list2[i-1]/err_list2[i])/np.log(2),err_list3[i] , np.log(err_list3[i-1]/err_list3[i])/np.log(2) ))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 show_convergence_order2_PINN(err_QMC2,err_h10,err_energy, exponent,2*N,filename_write,write2file = write2file)
#       2 # show_convergence_order_latex2(err_QMC2,err_h10,exponent,k=relu_k,d = dim)
# ----> 4 show_convergence_order_latex2(err_l2,err_h10,err_energy, exponent,k=3,d=2)
#
# NameError: name 'err_l2' is not defined
